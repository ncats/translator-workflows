# %%
import biclusterco, importlib, asyncio

# %%
importlib.reload(biclusterco)
# Out:
# <module 'biclusterco' from '/Users/colincurtis/Documents/renci/translator-workflows/WorkFlow9/biclusterco.py'>

# %%
GetInputObject = biclusterco.GetInput()

# %%
curated_geneset = GetInputObject.run_getinput('https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt')

# %%
curated_geneset
# Out:
# ['ncbigene:2175',
#  'ncbigene:2187',
#  'ncbigene:2176',
#  'ncbigene:2178',
#  'ncbigene:2188',
#  'ncbigene:2189',
#  'ncbigene:55120',
#  'ncbigene:57697',
#  'ncbigene:2177',
#  'ncbigene:55215',
#  'ncbigene:29089']

# %%
GetBiclustersObject = biclusterco.GetBiclusters()

# %%
# %timeit -n 1 related_biclusters = GetBiclustersObject.find_related_biclusters(curated_geneset)
# Out:
# 2min 20s ± 1.38 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Syncronous method, total = 150 s, is for the gene list available at https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt

# %%
import asyncio

# %%
importlib.reload(biclusterco)
# Out:
# <module 'biclusterco' from '/Users/colincurtis/Documents/renci/translator-workflows/WorkFlow9/biclusterco.py'>

# %%
GetBiclustersObject = biclusterco.GetBiclusters

# %%
loop = asyncio.get_event_loop()

# %%
curated_geneset
# Out:
# ['ncbigene:2175',
#  'ncbigene:2187',
#  'ncbigene:2176',
#  'ncbigene:2178',
#  'ncbigene:2188',
#  'ncbigene:2189',
#  'ncbigene:55120',
#  'ncbigene:57697',
#  'ncbigene:2177',
#  'ncbigene:55215',
#  'ncbigene:29089']

# %%
# %timeit -n 1 -r 1 biclusters_and_genes_for_each_input_gene = loop.run_until_complete(GetBiclustersObject.find_related_biclusters_async(curated_geneset))
# Out:
# 9.98 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# # Async method, 10s, is for the same gene list as before. Performance (time) improved 15x!

# %%
biclusters_and_genes_for_each_input_gene = loop.run_until_complete(GetBiclustersObject.find_related_biclusters_async(curated_geneset))

# %%
biclusters_and_genes_for_each_input_gene
# Out:
# defaultdict(dict,
#             {'ncbigene:2175': {'related_biclusters': defaultdict(dict,
#                           {'55': ['ncbigene:60496',
#                             'ncbigene:11057',
#                             'ncbigene:84448',
#                             'ncbigene:55902',
#                             'ncbigene:8165',
#                             'ncbigene:8852',
#                             'ncbigene:10327',
#                             'ncbigene:144245',
#                             'ncbigene:23452',
#                             'ncbigene:415',
#                             'ncbigene:64422',
#                             'ncbigene:476',
#                             'ncbigene:27087',
#                             'ncbigene:283870',
#                             'ncbigene:686',
#                             'ncbigene:10950',
#                             'ncbigene:150590',
#                             'ncbigene:285668',
# ...
