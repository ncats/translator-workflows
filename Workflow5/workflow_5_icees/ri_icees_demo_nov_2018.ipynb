# %% [markdown]
# # RI ICEES USAGE DEMO - November 13 2018
#
# ## 1) 'iceeshelper.py', an ICEES client for python
#
#
# ## 2)  An ICEES-fed analysis (ICEES functionality 4, 'association to all features')

# %% [markdown]
# ![icees_api_header_pic](icees_api_header_pic.png)

# %% [markdown]
# ## 'iceeshelper' is a module for conveniently accessing the ICEES API with python

# %% [markdown]
# ## 'iceeshelper' available at https://github.com/NCATS-Tangerine/icees-api/tree/master/demonstrations

# %%
import iceeshelper

# %% [markdown]
# ### Below, we see the web UI for the ICEES API Cohort discovery.

# %% [markdown]
# ![icees_define_cohort_pic](icees_define_cohort_pic.png)

# %% [markdown]
# ### iceeshelper.DefineCohort() works as follows: The inputs as seen above can be wrapped up in the following code.

# %%
DefineCohortObject = iceeshelper.DefineCohort()

# %%
define_a_cohort = DefineCohortObject.run_define_cohort('AvgDailyPM2.5Exposure', '2','>')

# %%
define_a_cohort['return value']
# Out:
# {'size': 21492, 'cohort_id': 'COHORT:45'}

# %% [markdown]
# ## We've given parameters related to PM2.5Exposure and retrieved a size an id for the pertinent cohort, COHORT:45. Now, let's look at an inverse operation, where we use a cohort_id to get back the cohort's defining parameters.

# %% [markdown]
# ![get_cohort_definition_pic](get_cohort_definition_pic.png)

# %%
CohortDefinitionObject = iceeshelper.GetCohortDefinition()

# %%
cohort_definition = CohortDefinitionObject.run_get_cohort_definition('COHORT:45')

# %%
cohort_definition['return value']
# Out:
# {'size': 21492,
#  'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 2}}}

# %% [markdown]
# ## Well, that is pretty basic stuff but useful in exploring the ICEES API data!

# %% [markdown]
# ## Next, we'll look at the more detailed outputs, starting with the 'association to all features' endpoint.

# %% [markdown]
# ![assoc_to_all_features_pic](assoc_to_all_features_pic.png)

# %% [markdown]
# ## Obviously, the above can be interrogated manually at the web UI (above) or via a call. Alternatively, using 'iceeshelper':

# %%
AssociationToAllFeaturesObject = iceeshelper.AssociationToAllFeatures()

# %%
assoc_to_all_features = AssociationToAllFeaturesObject.run_association_to_all_features('TotalEDInpatientVisits','<', '2','0.1','COHORT:45')

# %%
assoc_to_all_features
# Out:
# {'return value': [{'chi_squared': 1060.0560114209925,
#    'feature_matrix': [[{'frequency': 1705,
#       'column_percentage': 0.09524075522288013,
#       'total_percentage': 0.0793318444072213,
#       'row_percentage': 0.9440753045404208},
#      {'frequency': 101,
#       'column_percentage': 0.028133704735376044,
#       'total_percentage': 0.004699423041131584,
#       'row_percentage': 0.055924695459579184}],
#     [{'frequency': 3319,
#       'column_percentage': 0.18539827952184113,
#       'total_percentage': 0.15442955518332402,
#       'row_percentage': 0.9620289855072464},
#      {'frequency': 131,
#       'column_percentage': 0.03649025069637883,
#       'total_percentage': 0.0060952912711706685,
#       'row_percentage': 0.03797101449275362}],
#     [{'frequency': 2434,
#       'column_percentage': 0.13596246229471567,
#       'total_percentage': 0.11325144239717104,
#       'row_percentage': 0.7304921968787516},
#      {'frequency': 898,
#       'column_percentage': 0.2501392757660167,
#       'total_percentage': 0.04178298901916992,
#       'row_percentage': 0.2695078031212485}],
#     [{'frequency': 3462,
#       'column_percentage': 0.19338621383085688,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.7513020833333334},
#      {'frequency': 1146,
#       'column_percentage': 0.3192200557103064,
#       'total_percentage': 0.05332216638749302,
#       'row_percentage': 0.24869791666666666}],
#     [{'frequency': 4966,
#       'column_percentage': 0.27739917327672886,
#       'total_percentage': 0.23106272101246975,
#       'row_percentage': 0.833501174890903},
#      {'frequency': 992,
#       'column_percentage': 0.2763231197771588,
#       'total_percentage': 0.04615670947329239,
#       'row_percentage': 0.16649882510909703}],
#     [{'frequency': 2016,
#       'column_percentage': 0.11261311585297733,
#       'total_percentage': 0.09380234505862646,
#       'row_percentage': 0.8622754491017964},
#      {'frequency': 322,
#       'column_percentage': 0.08969359331476323,
#       'total_percentage': 0.014982319002419505,
#       'row_percentage': 0.1377245508982036}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': '0-2'},
#      {'operator': '=', 'value': '3-17'},
#      {'operator': '=', 'value': '18-34'},
#      {'operator': '=', 'value': '35-50'},
#      {'operator': '=', 'value': '51-69'},
#      {'operator': '=', 'value': '70+'}],
#     'feature_name': 'AgeStudyStart'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 1806, 'percentage': 0.08403126744835288},
#     {'frequency': 3450, 'percentage': 0.1605248464544947},
#     {'frequency': 3332, 'percentage': 0.15503443141634096},
#     {'frequency': 4608, 'percentage': 0.21440536013400335},
#     {'frequency': 5958, 'percentage': 0.27721943048576214},
#     {'frequency': 2338, 'percentage': 0.10878466406104598}],
#    'p_value': 2.2695809715411036e-220,
#    'total': 21492},
#   {'chi_squared': 142.0098891207954,
#    'feature_matrix': [[{'frequency': 4776,
#       'column_percentage': 0.2667858339850296,
#       'total_percentage': 0.2222222222222222,
#       'row_percentage': 0.7890302329423426},
#      {'frequency': 1277,
#       'column_percentage': 0.3557103064066852,
#       'total_percentage': 0.059417457658663686,
#       'row_percentage': 0.21096976705765735}],
#     [{'frequency': 225,
#       'column_percentage': 0.012568428108591219,
#       'total_percentage': 0.010469011725293133,
#       'row_percentage': 0.8687258687258688},
#      {'frequency': 34,
#       'column_percentage': 0.00947075208913649,
#       'total_percentage': 0.0015819839940442956,
#       'row_percentage': 0.13127413127413126}],
#     [{'frequency': 10215,
#       'column_percentage': 0.5706066361300414,
#       'total_percentage': 0.4752931323283082,
#       'row_percentage': 0.8430304530824462},
#      {'frequency': 1902,
#       'column_percentage': 0.5298050139275766,
#       'total_percentage': 0.08849804578447794,
#       'row_percentage': 0.15696954691755385}],
#     [{'frequency': 3,
#       'column_percentage': 0.00016757904144788292,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 0.75},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.25}],
#     [{'frequency': 153,
#       'column_percentage': 0.008546531113842029,
#       'total_percentage': 0.00711892797319933,
#       'row_percentage': 0.8595505617977528},
#      {'frequency': 25,
#       'column_percentage': 0.006963788300835654,
#       'total_percentage': 0.0011632235250325703,
#       'row_percentage': 0.1404494382022472}],
#     [{'frequency': 2076,
#       'column_percentage': 0.11596469668193497,
#       'total_percentage': 0.09659408151870463,
#       'row_percentage': 0.8722689075630252},
#      {'frequency': 304,
#       'column_percentage': 0.08467966573816156,
#       'total_percentage': 0.014144798064396055,
#       'row_percentage': 0.12773109243697478}],
#     [{'frequency': 454,
#       'column_percentage': 0.02536029493911295,
#       'total_percentage': 0.021124139214591477,
#       'row_percentage': 0.906187624750499},
#      {'frequency': 47,
#       'column_percentage': 0.01309192200557103,
#       'total_percentage': 0.002186860227061232,
#       'row_percentage': 0.09381237524950099}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=',
#       'value': 'African American'},
#      {'operator': '=', 'value': 'Asian'},
#      {'operator': '=', 'value': 'Caucasian'},
#      {'operator': '=', 'value': 'Hawaiian / Other Pac'},
#      {'operator': '=', 'value': 'Native American'},
#      {'operator': '=', 'value': 'Other'},
#      {'operator': '=', 'value': 'Unknown'}],
#     'feature_name': 'Race'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 6053, 'percentage': 0.2816396798808859},
#     {'frequency': 259, 'percentage': 0.012050995719337428},
#     {'frequency': 12117, 'percentage': 0.5637911781127861},
#     {'frequency': 4, 'percentage': 0.00018611576400521124},
#     {'frequency': 178, 'percentage': 0.0082821514982319},
#     {'frequency': 2380, 'percentage': 0.11073887958310069},
#     {'frequency': 501, 'percentage': 0.023310999441652706}],
#    'p_value': 8.323153234155206e-24,
#    'total': 21492},
#   {'chi_squared': 65.07497769256474,
#    'feature_matrix': [[{'frequency': 1512,
#       'column_percentage': 0.08445983688973299,
#       'total_percentage': 0.07035175879396985,
#       'row_percentage': 0.8615384615384616},
#      {'frequency': 243,
#       'column_percentage': 0.06768802228412256,
#       'total_percentage': 0.011306532663316583,
#       'row_percentage': 0.13846153846153847}],
#     [{'frequency': 11364,
#       'column_percentage': 0.6347894090045805,
#       'total_percentage': 0.5287548855388051,
#       'row_percentage': 0.8206831804723045},
#      {'frequency': 2483,
#       'column_percentage': 0.6916434540389972,
#       'total_percentage': 0.11553136050623487,
#       'row_percentage': 0.17931681952769554}],
#     [{'frequency': 1774,
#       'column_percentage': 0.09909507317618144,
#       'total_percentage': 0.08254234133631119,
#       'row_percentage': 0.8852295409181636},
#      {'frequency': 230,
#       'column_percentage': 0.06406685236768803,
#       'total_percentage': 0.010701656430299647,
#       'row_percentage': 0.11477045908183632}],
#     [{'frequency': 3252,
#       'column_percentage': 0.18165568092950507,
#       'total_percentage': 0.15131211613623674,
#       'row_percentage': 0.8368502316006176},
#      {'frequency': 634,
#       'column_percentage': 0.1766016713091922,
#       'total_percentage': 0.029499348594825982,
#       'row_percentage': 0.1631497683993824}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 'H'},
#      {'operator': '=', 'value': 'N'},
#      {'operator': '=', 'value': 'U'},
#      {'operator': '=', 'value': None}],
#     'feature_name': 'Ethnicity'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 1755, 'percentage': 0.08165829145728644},
#     {'frequency': 13847, 'percentage': 0.64428624604504},
#     {'frequency': 2004, 'percentage': 0.09324399776661083},
#     {'frequency': 3886, 'percentage': 0.18081146473106272}],
#    'p_value': 1.4525420897863528e-11,
#    'total': 21492},
#   {'chi_squared': 52.25000067396003,
#    'feature_matrix': [[{'frequency': 11484,
#       'column_percentage': 0.6414925706624958,
#       'total_percentage': 0.5343383584589615,
#       'row_percentage': 0.8195247270391779},
#      {'frequency': 2529,
#       'column_percentage': 0.7044568245125348,
#       'total_percentage': 0.11767169179229481,
#       'row_percentage': 0.18047527296082208}],
#     [{'frequency': 6418,
#       'column_percentage': 0.3585074293375042,
#       'total_percentage': 0.29862274334636146,
#       'row_percentage': 0.858136114453804},
#      {'frequency': 1061,
#       'column_percentage': 0.29554317548746517,
#       'total_percentage': 0.049367206402382284,
#       'row_percentage': 0.14186388554619603}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'AsthmaDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 14013, 'percentage': 0.6520100502512562},
#     {'frequency': 7479, 'percentage': 0.3479899497487437}],
#    'p_value': 2.649263337688825e-11,
#    'total': 21492},
#   {'chi_squared': 829.4049371696476,
#    'feature_matrix': [[{'frequency': 5083,
#       'column_percentage': 0.2839347558931963,
#       'total_percentage': 0.23650660710962218,
#       'row_percentage': 0.961232980332829},
#      {'frequency': 205,
#       'column_percentage': 0.057103064066852366,
#       'total_percentage': 0.009538432905267076,
#       'row_percentage': 0.03876701966717095}],
#     [{'frequency': 12819,
#       'column_percentage': 0.7160652441068037,
#       'total_percentage': 0.5964544946957008,
#       'row_percentage': 0.791100962725253},
#      {'frequency': 3385,
#       'column_percentage': 0.9428969359331476,
#       'total_percentage': 0.15750046528941,
#       'row_percentage': 0.20889903727474698}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'CoughDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 5288, 'percentage': 0.24604504001488925},
#     {'frequency': 16204, 'percentage': 0.7539549599851108}],
#    'p_value': 1.8148983659744737e-179,
#    'total': 21492},
#   {'chi_squared': 55.15931597104202,
#    'feature_matrix': [[{'frequency': 17603,
#       'column_percentage': 0.9832979555356943,
#       'total_percentage': 0.8190489484459333,
#       'row_percentage': 0.8356515547116069},
#      {'frequency': 3462,
#       'column_percentage': 0.9643454038997215,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.16434844528839307}],
#     [{'frequency': 299,
#       'column_percentage': 0.016702044464305663,
#       'total_percentage': 0.01391215335938954,
#       'row_percentage': 0.7002341920374707},
#      {'frequency': 128,
#       'column_percentage': 0.03565459610027855,
#       'total_percentage': 0.00595570444816676,
#       'row_percentage': 0.2997658079625293}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'PneumoniaDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21065, 'percentage': 0.9801321421924437},
#     {'frequency': 427, 'percentage': 0.0198678578075563}],
#    'p_value': 6.3493014912896275e-12,
#    'total': 21492},
#   {'chi_squared': 49.506670225338226,
#    'feature_matrix': [[{'frequency': 16502,
#       'column_percentage': 0.9217964473243213,
#       'total_percentage': 0.767820584403499,
#       'row_percentage': 0.8383884570441498},
#      {'frequency': 3181,
#       'column_percentage': 0.8860724233983287,
#       'total_percentage': 0.14800856132514423,
#       'row_percentage': 0.16161154295585023}],
#     [{'frequency': 1400,
#       'column_percentage': 0.07820355267567869,
#       'total_percentage': 0.06514051740182393,
#       'row_percentage': 0.7739082365948038},
#      {'frequency': 409,
#       'column_percentage': 0.11392757660167131,
#       'total_percentage': 0.01903033686953285,
#       'row_percentage': 0.22609176340519624}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'ObesityICD'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 19683, 'percentage': 0.9158291457286433},
#     {'frequency': 1809, 'percentage': 0.08417085427135679}],
#    'p_value': 1.0175504777400289e-10,
#    'total': 21492},
#   {'chi_squared': 49.807982479207446,
#    'feature_matrix': [[{'frequency': 7,
#       'column_percentage': 0.0003910177633783935,
#       'total_percentage': 0.0003257025870091197,
#       'row_percentage': 0.6363636363636364},
#      {'frequency': 4,
#       'column_percentage': 0.0011142061281337048,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 0.36363636363636365}],
#     [{'frequency': 4166,
#       'column_percentage': 0.23271142889062674,
#       'total_percentage': 0.1938395682114275,
#       'row_percentage': 0.8036265432098766},
#      {'frequency': 1018,
#       'column_percentage': 0.2835654596100279,
#       'total_percentage': 0.04736646193932626,
#       'row_percentage': 0.19637345679012347}],
#     [{'frequency': 13627,
#       'column_percentage': 0.7611998659367668,
#       'total_percentage': 0.6340498790247534,
#       'row_percentage': 0.8420044488383589},
#      {'frequency': 2557,
#       'column_percentage': 0.7122562674094708,
#       'total_percentage': 0.11897450214033128,
#       'row_percentage': 0.15799555116164113}],
#     [{'frequency': 100,
#       'column_percentage': 0.005585968048262764,
#       'total_percentage': 0.004652894100130281,
#       'row_percentage': 0.9090909090909091},
#      {'frequency': 10,
#       'column_percentage': 0.002785515320334262,
#       'total_percentage': 0.0004652894100130281,
#       'row_percentage': 0.09090909090909091}],
#     [{'frequency': 2,
#       'column_percentage': 0.00011171936096525528,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 0.6666666666666666},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.3333333333333333}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'AvgDailyOzoneExposure'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 11, 'percentage': 0.0005118183510143309},
#     {'frequency': 5184, 'percentage': 0.24120603015075376},
#     {'frequency': 16184, 'percentage': 0.7530243811650846},
#     {'frequency': 110, 'percentage': 0.005118183510143309},
#     {'frequency': 3, 'percentage': 0.00013958682300390843}],
#    'p_value': 1.1705944615386469e-07,
#    'total': 21492},
#   {'chi_squared': 75.2614740980578,
#    'feature_matrix': [[{'frequency': 16779,
#       'column_percentage': 0.9372695788180092,
#       'total_percentage': 0.7807091010608599,
#       'row_percentage': 0.8278567199526347},
#      {'frequency': 3489,
#       'column_percentage': 0.971866295264624,
#       'total_percentage': 0.1623394751535455,
#       'row_percentage': 0.17214328004736532}],
#     [{'frequency': 1103,
#       'column_percentage': 0.06161322757233829,
#       'total_percentage': 0.051321421924437,
#       'row_percentage': 0.9207011686143572},
#      {'frequency': 95,
#       'column_percentage': 0.026462395543175487,
#       'total_percentage': 0.004420249395123767,
#       'row_percentage': 0.07929883138564274}],
#     [{'frequency': 12,
#       'column_percentage': 0.0006703161657915317,
#       'total_percentage': 0.0005583472920156337,
#       'row_percentage': 0.8},
#      {'frequency': 3,
#       'column_percentage': 0.0008356545961002785,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 0.2}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 8,
#       'column_percentage': 0.0004468774438610211,
#       'total_percentage': 0.0003722315280104225,
#       'row_percentage': 0.8},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 0.2}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'MaxDailyOzoneExposure'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20268, 'percentage': 0.9430485762144054},
#     {'frequency': 1198, 'percentage': 0.055741671319560766},
#     {'frequency': 15, 'percentage': 0.0006979341150195422},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 10, 'percentage': 0.0004652894100130281}],
#    'p_value': 1.4031511182720637e-12,
#    'total': 21492},
#   {'chi_squared': 21.680610501349456,
#    'feature_matrix': [[{'frequency': 8617,
#       'column_percentage': 0.4813428667188024,
#       'total_percentage': 0.4009398846082263,
#       'row_percentage': 0.8256203890006707},
#      {'frequency': 1820,
#       'column_percentage': 0.5069637883008357,
#       'total_percentage': 0.08468267262237111,
#       'row_percentage': 0.1743796109993293}],
#     [{'frequency': 8026,
#       'column_percentage': 0.44832979555356944,
#       'total_percentage': 0.37344128047645636,
#       'row_percentage': 0.8348242146869149},
#      {'frequency': 1588,
#       'column_percentage': 0.4423398328690808,
#       'total_percentage': 0.07388795831006886,
#       'row_percentage': 0.16517578531308508}],
#     [{'frequency': 937,
#       'column_percentage': 0.0523405206122221,
#       'total_percentage': 0.04359761771822073,
#       'row_percentage': 0.8740671641791045},
#      {'frequency': 135,
#       'column_percentage': 0.037604456824512536,
#       'total_percentage': 0.00628140703517588,
#       'row_percentage': 0.1259328358208955}],
#     [{'frequency': 200,
#       'column_percentage': 0.011171936096525528,
#       'total_percentage': 0.009305788200260562,
#       'row_percentage': 0.8658008658008658},
#      {'frequency': 31,
#       'column_percentage': 0.008635097493036212,
#       'total_percentage': 0.0014423971710403871,
#       'row_percentage': 0.1341991341991342}],
#     [{'frequency': 122,
#       'column_percentage': 0.006814881018880572,
#       'total_percentage': 0.0056765308021589425,
#       'row_percentage': 0.8840579710144928},
#      {'frequency': 16,
#       'column_percentage': 0.004456824512534819,
#       'total_percentage': 0.000744463056020845,
#       'row_percentage': 0.11594202898550725}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstResidentialDensity'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 10437, 'percentage': 0.48562255723059744},
#     {'frequency': 9614, 'percentage': 0.4473292387865252},
#     {'frequency': 1072, 'percentage': 0.04987902475339661},
#     {'frequency': 231, 'percentage': 0.010748185371300949},
#     {'frequency': 138, 'percentage': 0.0064209938581797875}],
#    'p_value': 0.00994823994849266,
#    'total': 21492},
#   {'chi_squared': 22.22229595565054,
#    'feature_matrix': [[{'frequency': 7417,
#       'column_percentage': 0.4143112501396492,
#       'total_percentage': 0.3451051554066629,
#       'row_percentage': 0.8306641281218502},
#      {'frequency': 1512,
#       'column_percentage': 0.4211699164345404,
#       'total_percentage': 0.07035175879396985,
#       'row_percentage': 0.16933587187814986}],
#     [{'frequency': 9148,
#       'column_percentage': 0.5110043570550776,
#       'total_percentage': 0.4256467522799181,
#       'row_percentage': 0.8291489168857065},
#      {'frequency': 1885,
#       'column_percentage': 0.5250696378830083,
#       'total_percentage': 0.0877070537874558,
#       'row_percentage': 0.17085108311429348}],
#     [{'frequency': 1013,
#       'column_percentage': 0.0565858563289018,
#       'total_percentage': 0.047133817234319746,
#       'row_percentage': 0.8778162911611785},
#      {'frequency': 141,
#       'column_percentage': 0.03927576601671309,
#       'total_percentage': 0.006560580681183696,
#       'row_percentage': 0.12218370883882149}],
#     [{'frequency': 121,
#       'column_percentage': 0.006759021338397945,
#       'total_percentage': 0.00563000186115764,
#       'row_percentage': 0.8962962962962963},
#      {'frequency': 14,
#       'column_percentage': 0.0038997214484679664,
#       'total_percentage': 0.0006514051740182394,
#       'row_percentage': 0.1037037037037037}],
#     [{'frequency': 203,
#       'column_percentage': 0.01133951513797341,
#       'total_percentage': 0.00944537502326447,
#       'row_percentage': 0.8423236514522822},
#      {'frequency': 38,
#       'column_percentage': 0.010584958217270195,
#       'total_percentage': 0.0017680997580495068,
#       'row_percentage': 0.15767634854771784}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstResidentialDesnity25Plus'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 8929, 'percentage': 0.4154569142006328},
#     {'frequency': 11033, 'percentage': 0.5133538060673739},
#     {'frequency': 1154, 'percentage': 0.05369439791550344},
#     {'frequency': 135, 'percentage': 0.00628140703517588},
#     {'frequency': 241, 'percentage': 0.011213474781313978}],
#    'p_value': 0.00820053178764048,
#    'total': 21492},
#   {'chi_squared': 12.527619966828084,
#    'feature_matrix': [[{'frequency': 14050,
#       'column_percentage': 0.7848285107809183,
#       'total_percentage': 0.6537316210683045,
#       'row_percentage': 0.8329381076594735},
#      {'frequency': 2818,
#       'column_percentage': 0.784958217270195,
#       'total_percentage': 0.13111855574167133,
#       'row_percentage': 0.16706189234052643}],
#     [{'frequency': 3178,
#       'column_percentage': 0.17752206457379063,
#       'total_percentage': 0.14786897450214034,
#       'row_percentage': 0.8420773714891362},
#      {'frequency': 596,
#       'column_percentage': 0.166016713091922,
#       'total_percentage': 0.027731248836776475,
#       'row_percentage': 0.1579226285108638}],
#     [{'frequency': 617,
#       'column_percentage': 0.03446542285778125,
#       'total_percentage': 0.028708356597803835,
#       'row_percentage': 0.79204107830552},
#      {'frequency': 162,
#       'column_percentage': 0.04512534818941504,
#       'total_percentage': 0.007537688442211055,
#       'row_percentage': 0.2079589216944801}],
#     [{'frequency': 44,
#       'column_percentage': 0.002457825941235616,
#       'total_percentage': 0.0020472734040573237,
#       'row_percentage': 0.7857142857142857},
#      {'frequency': 12,
#       'column_percentage': 0.003342618384401114,
#       'total_percentage': 0.0005583472920156337,
#       'row_percentage': 0.21428571428571427}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4}],
#     'feature_name': 'EstProbabilityESL'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 16868, 'percentage': 0.7848501768099758},
#     {'frequency': 3774, 'percentage': 0.1756002233389168},
#     {'frequency': 779, 'percentage': 0.03624604504001489},
#     {'frequency': 56, 'percentage': 0.0026056206960729574}],
#    'p_value': 0.08448912614797445,
#    'total': 21492},
#   {'chi_squared': 19.701359831241504,
#    'feature_matrix': [[{'frequency': 9489,
#       'column_percentage': 0.5300525080996537,
#       'total_percentage': 0.4415131211613624,
#       'row_percentage': 0.8314203101726102},
#      {'frequency': 1924,
#       'column_percentage': 0.5359331476323119,
#       'total_percentage': 0.0895216824865066,
#       'row_percentage': 0.16857968982738983}],
#     [{'frequency': 6689,
#       'column_percentage': 0.3736454027482963,
#       'total_percentage': 0.3112320863577145,
#       'row_percentage': 0.8271299616668728},
#      {'frequency': 1398,
#       'column_percentage': 0.3894150417827298,
#       'total_percentage': 0.06504745951982133,
#       'row_percentage': 0.17287003833312725}],
#     [{'frequency': 1122,
#       'column_percentage': 0.06267456150150821,
#       'total_percentage': 0.05220547180346175,
#       'row_percentage': 0.8765625},
#      {'frequency': 158,
#       'column_percentage': 0.04401114206128134,
#       'total_percentage': 0.007351572678205844,
#       'row_percentage': 0.1234375}],
#     [{'frequency': 156,
#       'column_percentage': 0.008714110155289912,
#       'total_percentage': 0.0072585147962032385,
#       'row_percentage': 0.8342245989304813},
#      {'frequency': 31,
#       'column_percentage': 0.008635097493036212,
#       'total_percentage': 0.0014423971710403871,
#       'row_percentage': 0.1657754010695187}],
#     [{'frequency': 4,
#       'column_percentage': 0.00022343872193051055,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 0.8},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.2}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstHouseholdIncome'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 11413, 'percentage': 0.5310348036478689},
#     {'frequency': 8087, 'percentage': 0.3762795458775358},
#     {'frequency': 1280, 'percentage': 0.0595570444816676},
#     {'frequency': 187, 'percentage': 0.008700911967243626},
#     {'frequency': 5, 'percentage': 0.00023264470500651406}],
#    'p_value': 0.019847565963857026,
#    'total': 21492},
#   {'chi_squared': 21491.999999999993,
#    'feature_matrix': [[{'frequency': 14813,
#       'column_percentage': 0.8274494469891632,
#       'total_percentage': 0.6892332030522985,
#       'row_percentage': 1.0},
#      {'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0}],
#     [{'frequency': 3089,
#       'column_percentage': 0.17255055301083677,
#       'total_percentage': 0.14372789875302439,
#       'row_percentage': 1.0},
#      {'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2344,
#       'column_percentage': 0.6529247910863509,
#       'total_percentage': 0.10906383770705379,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 690,
#       'column_percentage': 0.19220055710306408,
#       'total_percentage': 0.03210496929089894,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 262,
#       'column_percentage': 0.07298050139275766,
#       'total_percentage': 0.012190582542341337,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 118,
#       'column_percentage': 0.03286908077994429,
#       'total_percentage': 0.005490415038153731,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 60,
#       'column_percentage': 0.016713091922005572,
#       'total_percentage': 0.0027917364600781687,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 29,
#       'column_percentage': 0.00807799442896936,
#       'total_percentage': 0.0013493392890377815,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 17,
#       'column_percentage': 0.004735376044568245,
#       'total_percentage': 0.0007909919970221478,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 15,
#       'column_percentage': 0.004178272980501393,
#       'total_percentage': 0.0006979341150195422,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 9,
#       'column_percentage': 0.0025069637883008357,
#       'total_percentage': 0.0004187604690117253,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 9,
#       'column_percentage': 0.0025069637883008357,
#       'total_percentage': 0.0004187604690117253,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 4,
#       'column_percentage': 0.0011142061281337048,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 7,
#       'column_percentage': 0.0019498607242339832,
#       'total_percentage': 0.0003257025870091197,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 3,
#       'column_percentage': 0.0008356545961002785,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 5,
#       'column_percentage': 0.001392757660167131,
#       'total_percentage': 0.00023264470500651406,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5},
#      {'operator': '=', 'value': 6},
#      {'operator': '=', 'value': 7},
#      {'operator': '=', 'value': 8},
#      {'operator': '=', 'value': 9},
#      {'operator': '=', 'value': 10},
#      {'operator': '=', 'value': 11},
#      {'operator': '=', 'value': 12},
#      {'operator': '=', 'value': 13},
#      {'operator': '=', 'value': 14},
#      {'operator': '=', 'value': 15},
#      {'operator': '=', 'value': 16},
#      {'operator': '=', 'value': 17},
#      {'operator': '=', 'value': 18},
#      {'operator': '=', 'value': 19},
#      {'operator': '=', 'value': 20},
#      {'operator': '=', 'value': 21},
#      {'operator': '=', 'value': 22},
#      {'operator': '=', 'value': 23},
#      {'operator': '=', 'value': 25},
#      {'operator': '=', 'value': 27},
#      {'operator': '=', 'value': 33},
#      {'operator': '=', 'value': 37},
#      {'operator': '=', 'value': 50},
#      {'operator': '=', 'value': 51}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 14813, 'percentage': 0.6892332030522985},
#     {'frequency': 3089, 'percentage': 0.14372789875302439},
#     {'frequency': 2344, 'percentage': 0.10906383770705379},
#     {'frequency': 690, 'percentage': 0.03210496929089894},
#     {'frequency': 262, 'percentage': 0.012190582542341337},
#     {'frequency': 118, 'percentage': 0.005490415038153731},
#     {'frequency': 60, 'percentage': 0.0027917364600781687},
#     {'frequency': 29, 'percentage': 0.0013493392890377815},
#     {'frequency': 17, 'percentage': 0.0007909919970221478},
#     {'frequency': 15, 'percentage': 0.0006979341150195422},
#     {'frequency': 9, 'percentage': 0.0004187604690117253},
#     {'frequency': 9, 'percentage': 0.0004187604690117253},
#     {'frequency': 4, 'percentage': 0.00018611576400521124},
#     {'frequency': 7, 'percentage': 0.0003257025870091197},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 3, 'percentage': 0.00013958682300390843},
#     {'frequency': 5, 'percentage': 0.00023264470500651406},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05}],
#    'p_value': 0.0,
#    'total': 21492},
#   {'chi_squared': 109.96216990797932,
#    'feature_matrix': [[{'frequency': 16201,
#       'column_percentage': 0.9049826834990504,
#       'total_percentage': 0.7538153731621068,
#       'row_percentage': 0.8420915848017049},
#      {'frequency': 3038,
#       'column_percentage': 0.8462395543175487,
#       'total_percentage': 0.14135492276195794,
#       'row_percentage': 0.15790841519829513}],
#     [{'frequency': 1701,
#       'column_percentage': 0.09501731650094962,
#       'total_percentage': 0.07914572864321608,
#       'row_percentage': 0.7549933422103862},
#      {'frequency': 552,
#       'column_percentage': 0.15376044568245126,
#       'total_percentage': 0.02568397543271915,
#       'row_percentage': 0.24500665778961384}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Prednisone'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 19239, 'percentage': 0.8951702959240647},
#     {'frequency': 2253, 'percentage': 0.10482970407593523}],
#    'p_value': 1.1180903063022454e-23,
#    'total': 21492},
#   {'chi_squared': 16.13859593375987,
#    'feature_matrix': [[{'frequency': 17594,
#       'column_percentage': 0.9827952184113506,
#       'total_percentage': 0.8186301879769217,
#       'row_percentage': 0.8316709997636492},
#      {'frequency': 3561,
#       'column_percentage': 0.9919220055710306,
#       'total_percentage': 0.1656895589056393,
#       'row_percentage': 0.16832900023635075}],
#     [{'frequency': 308,
#       'column_percentage': 0.017204781588649312,
#       'total_percentage': 0.014330913828401265,
#       'row_percentage': 0.913946587537092},
#      {'frequency': 29,
#       'column_percentage': 0.00807799442896936,
#       'total_percentage': 0.0013493392890377815,
#       'row_percentage': 0.08605341246290801}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Mometasone'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21155, 'percentage': 0.984319746882561},
#     {'frequency': 337, 'percentage': 0.015680253117439046}],
#    'p_value': 0.00106215012725766,
#    'total': 21492},
#   {'chi_squared': 10.373908512214845,
#    'feature_matrix': [[{'frequency': 17043,
#       'column_percentage': 0.9520165344654229,
#       'total_percentage': 0.7929927414852038,
#       'row_percentage': 0.8311631309436722},
#      {'frequency': 3462,
#       'column_percentage': 0.9643454038997215,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.16883686905632772}],
#     [{'frequency': 859,
#       'column_percentage': 0.04798346553457714,
#       'total_percentage': 0.03996836032011911,
#       'row_percentage': 0.8703140830800405},
#      {'frequency': 128,
#       'column_percentage': 0.03565459610027855,
#       'total_percentage': 0.00595570444816676,
#       'row_percentage': 0.12968591691995948}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Budesonide'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20505, 'percentage': 0.9540759352317141},
#     {'frequency': 987, 'percentage': 0.04592406476828587}],
#    'p_value': 0.015641103266372428,
#    'total': 21492},
#   {'chi_squared': 8.06006470961281,
#    'feature_matrix': [[{'frequency': 12803,
#       'column_percentage': 0.7151714892190817,
#       'total_percentage': 0.5957100316396798,
#       'row_percentage': 0.8375637838545074},
#      {'frequency': 2483,
#       'column_percentage': 0.6916434540389972,
#       'total_percentage': 0.11553136050623487,
#       'row_percentage': 0.1624362161454926}],
#     [{'frequency': 5099,
#       'column_percentage': 0.2848285107809183,
#       'total_percentage': 0.23725107016564304,
#       'row_percentage': 0.8216242346116661},
#      {'frequency': 1107,
#       'column_percentage': 0.30835654596100276,
#       'total_percentage': 0.05150753768844221,
#       'row_percentage': 0.17837576538833386}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Albuterol'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 15286, 'percentage': 0.7112413921459148},
#     {'frequency': 6206, 'percentage': 0.28875860785408525}],
#    'p_value': 0.04478652335107,
#    'total': 21492},
#   {'chi_squared': 159.86442847726266,
#    'feature_matrix': [[{'frequency': 15741,
#       'column_percentage': 0.8792872304770417,
#       'total_percentage': 0.7324120603015075,
#       'row_percentage': 0.8456083803384368},
#      {'frequency': 2874,
#       'column_percentage': 0.8005571030640668,
#       'total_percentage': 0.13372417643774429,
#       'row_percentage': 0.15439161966156326}],
#     [{'frequency': 2161,
#       'column_percentage': 0.12071276952295833,
#       'total_percentage': 0.10054904150381537,
#       'row_percentage': 0.7511296489398679},
#      {'frequency': 716,
#       'column_percentage': 0.19944289693593314,
#       'total_percentage': 0.033314721756932814,
#       'row_percentage': 0.24887035106013208}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Diphenhydramine'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 18615, 'percentage': 0.8661362367392518},
#     {'frequency': 2877, 'percentage': 0.1338637632607482}],
#    'p_value': 1.9605955442282923e-34,
#    'total': 21492},
#   {'chi_squared': 13.357145608459799,
#    'feature_matrix': [[{'frequency': 16917,
#       'column_percentage': 0.9449782147246117,
#       'total_percentage': 0.7871300949190396,
#       'row_percentage': 0.830771497323577},
#      {'frequency': 3446,
#       'column_percentage': 0.9598885793871866,
#       'total_percentage': 0.16033873069048948,
#       'row_percentage': 0.16922850267642292}],
#     [{'frequency': 985,
#       'column_percentage': 0.05502178527538822,
#       'total_percentage': 0.04583100688628327,
#       'row_percentage': 0.8724534986713907},
#      {'frequency': 144,
#       'column_percentage': 0.04011142061281337,
#       'total_percentage': 0.006700167504187605,
#       'row_percentage': 0.1275465013286094}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Cetirizine'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20363, 'percentage': 0.9474688256095292},
#     {'frequency': 1129, 'percentage': 0.05253117439047087}],
#    'p_value': 0.003924597447558311,
#    'total': 21492},
#   {'chi_squared': 191.75741131714443,
#    'feature_matrix': [[{'frequency': 17129,
#       'column_percentage': 0.9568204669869288,
#       'total_percentage': 0.7969942304113158,
#       'row_percentage': 0.8412651637935269},
#      {'frequency': 3232,
#       'column_percentage': 0.9002785515320334,
#       'total_percentage': 0.15038153731621068,
#       'row_percentage': 0.15873483620647316}],
#     [{'frequency': 773,
#       'column_percentage': 0.04317953301307117,
#       'total_percentage': 0.035966871394007074,
#       'row_percentage': 0.6834659593280283},
#      {'frequency': 358,
#       'column_percentage': 0.09972144846796657,
#       'total_percentage': 0.016657360878466407,
#       'row_percentage': 0.3165340406719717}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Ipratropium'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20361, 'percentage': 0.9473757677275265},
#     {'frequency': 1131, 'percentage': 0.05262423227247348}],
#    'p_value': 2.546658420195129e-41,
#    'total': 21492},
#   {'chi_squared': 18.565974934801602,
#    'feature_matrix': [[{'frequency': 17876,
#       'column_percentage': 0.9985476483074517,
#       'total_percentage': 0.8317513493392891,
#       'row_percentage': 0.8334576650503543},
#      {'frequency': 3572,
#       'column_percentage': 0.9949860724233983,
#       'total_percentage': 0.16620137725665363,
#       'row_percentage': 0.16654233494964565}],
#     [{'frequency': 26,
#       'column_percentage': 0.0014523516925483186,
#       'total_percentage': 0.001209752466033873,
#       'row_percentage': 0.5909090909090909},
#      {'frequency': 18,
#       'column_percentage': 0.005013927576601671,
#       'total_percentage': 0.0008375209380234506,
#       'row_percentage': 0.4090909090909091}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Salmeterol'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21448, 'percentage': 0.9979527265959427},
#     {'frequency': 44, 'percentage': 0.0020472734040573237}],
#    'p_value': 0.0003361168690149911,
#    'total': 21492}],
#  'terms and conditions': "The Translator Integrated Clinical and Environmental Exposures Service (ICEES) is providing you with Data that have been de-identified in accordance with 45 C.F.R. §§ 164.514(a) and (b) and that UNC Health Care System (UNCHCS) is permitted to provide under 45 C.F.R. § 164.502(d)(2). Recipient agrees to notify UNCHCS via NC TraCS in the event that Recipient receives any identifiable data in error and to take such measures to return the identifiable data and/or destroy it at the direction of UNCHCS.\n\nRestrictions on Recipient’s Use of Data. Recipient further agrees to use the data exclusively for the purposes and functionalities provided by the ICEES: cohort discovery; feature-rich cohort discovery; hypothesis-driven queries; and exploratory queries. Recipient agrees to use appropriate safeguards to protect the Data from misuse and unauthorized access or disclosure. Recipient will report to UNCHCS any unauthorized access, use, or disclosure of the Data not provided for by the Service of which Recipient becomes aware. Recipient will not attempt to identify the individuals whose information is contained in any Data transferred pursuant to this Service Agreement or attempt to contact those individuals. Recipient agrees not to sell the Data to any third party for any purpose. Recipient agrees not to disclose or publish the Data in any manner that would identify the Data as originating from UNCHCS. Finally, Recipient agrees to reasonably limit the number of queries to the Service per IP address within a given time interval, in order to prevent rapid ‘attacks’ on the Service.\n\nWe kindly request that Translator team members provide proper attribution for any products (e.g., manuscripts, podium presentations, software) derived from work related to Green Team's clinical datasets. Attribution should include acknowledgement of the funder (National Center for Advancing Translational Sciences [NCATS], Biomedical Data Translator Program awards, OT3TR002020 and OT2TR002514), the North Carolina Translational and Clinical Sciences (NC TraCS) Institute (NCATS, Center for Translational Science Award, UL1TR002489), UNC Hospitals and Health Care System, and all Green Team members who contributed to the work.\n"}

# %% [markdown]
# ## The above encapsulates a manual 'requests' call, which follows:

# %%
assoc_to_all_features_data = '{"feature":{"TotalEDInpatientVisits":{"operator":"<", "value":2}},"maximum_p_value":0.1}'
data_for_all_cohorts = {}
cohort_45_response = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A45/associations_to_all_features', headers = json_headers, data=assoc_to_all_features_data, verify = False)
cohort_45_response_json = cohort_45_response.json()

# %%
cohort_45_response_json
# Out:
# {'return value': [{'chi_squared': 1060.0560114209925,
#    'feature_matrix': [[{'frequency': 1705,
#       'column_percentage': 0.09524075522288013,
#       'total_percentage': 0.0793318444072213,
#       'row_percentage': 0.9440753045404208},
#      {'frequency': 101,
#       'column_percentage': 0.028133704735376044,
#       'total_percentage': 0.004699423041131584,
#       'row_percentage': 0.055924695459579184}],
#     [{'frequency': 3319,
#       'column_percentage': 0.18539827952184113,
#       'total_percentage': 0.15442955518332402,
#       'row_percentage': 0.9620289855072464},
#      {'frequency': 131,
#       'column_percentage': 0.03649025069637883,
#       'total_percentage': 0.0060952912711706685,
#       'row_percentage': 0.03797101449275362}],
#     [{'frequency': 2434,
#       'column_percentage': 0.13596246229471567,
#       'total_percentage': 0.11325144239717104,
#       'row_percentage': 0.7304921968787516},
#      {'frequency': 898,
#       'column_percentage': 0.2501392757660167,
#       'total_percentage': 0.04178298901916992,
#       'row_percentage': 0.2695078031212485}],
#     [{'frequency': 3462,
#       'column_percentage': 0.19338621383085688,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.7513020833333334},
#      {'frequency': 1146,
#       'column_percentage': 0.3192200557103064,
#       'total_percentage': 0.05332216638749302,
#       'row_percentage': 0.24869791666666666}],
#     [{'frequency': 4966,
#       'column_percentage': 0.27739917327672886,
#       'total_percentage': 0.23106272101246975,
#       'row_percentage': 0.833501174890903},
#      {'frequency': 992,
#       'column_percentage': 0.2763231197771588,
#       'total_percentage': 0.04615670947329239,
#       'row_percentage': 0.16649882510909703}],
#     [{'frequency': 2016,
#       'column_percentage': 0.11261311585297733,
#       'total_percentage': 0.09380234505862646,
#       'row_percentage': 0.8622754491017964},
#      {'frequency': 322,
#       'column_percentage': 0.08969359331476323,
#       'total_percentage': 0.014982319002419505,
#       'row_percentage': 0.1377245508982036}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': '0-2'},
#      {'operator': '=', 'value': '3-17'},
#      {'operator': '=', 'value': '18-34'},
#      {'operator': '=', 'value': '35-50'},
#      {'operator': '=', 'value': '51-69'},
#      {'operator': '=', 'value': '70+'}],
#     'feature_name': 'AgeStudyStart'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 1806, 'percentage': 0.08403126744835288},
#     {'frequency': 3450, 'percentage': 0.1605248464544947},
#     {'frequency': 3332, 'percentage': 0.15503443141634096},
#     {'frequency': 4608, 'percentage': 0.21440536013400335},
#     {'frequency': 5958, 'percentage': 0.27721943048576214},
#     {'frequency': 2338, 'percentage': 0.10878466406104598}],
#    'p_value': 2.2695809715411036e-220,
#    'total': 21492},
#   {'chi_squared': 142.0098891207954,
#    'feature_matrix': [[{'frequency': 4776,
#       'column_percentage': 0.2667858339850296,
#       'total_percentage': 0.2222222222222222,
#       'row_percentage': 0.7890302329423426},
#      {'frequency': 1277,
#       'column_percentage': 0.3557103064066852,
#       'total_percentage': 0.059417457658663686,
#       'row_percentage': 0.21096976705765735}],
#     [{'frequency': 225,
#       'column_percentage': 0.012568428108591219,
#       'total_percentage': 0.010469011725293133,
#       'row_percentage': 0.8687258687258688},
#      {'frequency': 34,
#       'column_percentage': 0.00947075208913649,
#       'total_percentage': 0.0015819839940442956,
#       'row_percentage': 0.13127413127413126}],
#     [{'frequency': 10215,
#       'column_percentage': 0.5706066361300414,
#       'total_percentage': 0.4752931323283082,
#       'row_percentage': 0.8430304530824462},
#      {'frequency': 1902,
#       'column_percentage': 0.5298050139275766,
#       'total_percentage': 0.08849804578447794,
#       'row_percentage': 0.15696954691755385}],
#     [{'frequency': 3,
#       'column_percentage': 0.00016757904144788292,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 0.75},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.25}],
#     [{'frequency': 153,
#       'column_percentage': 0.008546531113842029,
#       'total_percentage': 0.00711892797319933,
#       'row_percentage': 0.8595505617977528},
#      {'frequency': 25,
#       'column_percentage': 0.006963788300835654,
#       'total_percentage': 0.0011632235250325703,
#       'row_percentage': 0.1404494382022472}],
#     [{'frequency': 2076,
#       'column_percentage': 0.11596469668193497,
#       'total_percentage': 0.09659408151870463,
#       'row_percentage': 0.8722689075630252},
#      {'frequency': 304,
#       'column_percentage': 0.08467966573816156,
#       'total_percentage': 0.014144798064396055,
#       'row_percentage': 0.12773109243697478}],
#     [{'frequency': 454,
#       'column_percentage': 0.02536029493911295,
#       'total_percentage': 0.021124139214591477,
#       'row_percentage': 0.906187624750499},
#      {'frequency': 47,
#       'column_percentage': 0.01309192200557103,
#       'total_percentage': 0.002186860227061232,
#       'row_percentage': 0.09381237524950099}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=',
#       'value': 'African American'},
#      {'operator': '=', 'value': 'Asian'},
#      {'operator': '=', 'value': 'Caucasian'},
#      {'operator': '=', 'value': 'Hawaiian / Other Pac'},
#      {'operator': '=', 'value': 'Native American'},
#      {'operator': '=', 'value': 'Other'},
#      {'operator': '=', 'value': 'Unknown'}],
#     'feature_name': 'Race'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 6053, 'percentage': 0.2816396798808859},
#     {'frequency': 259, 'percentage': 0.012050995719337428},
#     {'frequency': 12117, 'percentage': 0.5637911781127861},
#     {'frequency': 4, 'percentage': 0.00018611576400521124},
#     {'frequency': 178, 'percentage': 0.0082821514982319},
#     {'frequency': 2380, 'percentage': 0.11073887958310069},
#     {'frequency': 501, 'percentage': 0.023310999441652706}],
#    'p_value': 8.323153234155206e-24,
#    'total': 21492},
#   {'chi_squared': 65.07497769256474,
#    'feature_matrix': [[{'frequency': 1512,
#       'column_percentage': 0.08445983688973299,
#       'total_percentage': 0.07035175879396985,
#       'row_percentage': 0.8615384615384616},
#      {'frequency': 243,
#       'column_percentage': 0.06768802228412256,
#       'total_percentage': 0.011306532663316583,
#       'row_percentage': 0.13846153846153847}],
#     [{'frequency': 11364,
#       'column_percentage': 0.6347894090045805,
#       'total_percentage': 0.5287548855388051,
#       'row_percentage': 0.8206831804723045},
#      {'frequency': 2483,
#       'column_percentage': 0.6916434540389972,
#       'total_percentage': 0.11553136050623487,
#       'row_percentage': 0.17931681952769554}],
#     [{'frequency': 1774,
#       'column_percentage': 0.09909507317618144,
#       'total_percentage': 0.08254234133631119,
#       'row_percentage': 0.8852295409181636},
#      {'frequency': 230,
#       'column_percentage': 0.06406685236768803,
#       'total_percentage': 0.010701656430299647,
#       'row_percentage': 0.11477045908183632}],
#     [{'frequency': 3252,
#       'column_percentage': 0.18165568092950507,
#       'total_percentage': 0.15131211613623674,
#       'row_percentage': 0.8368502316006176},
#      {'frequency': 634,
#       'column_percentage': 0.1766016713091922,
#       'total_percentage': 0.029499348594825982,
#       'row_percentage': 0.1631497683993824}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 'H'},
#      {'operator': '=', 'value': 'N'},
#      {'operator': '=', 'value': 'U'},
#      {'operator': '=', 'value': None}],
#     'feature_name': 'Ethnicity'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 1755, 'percentage': 0.08165829145728644},
#     {'frequency': 13847, 'percentage': 0.64428624604504},
#     {'frequency': 2004, 'percentage': 0.09324399776661083},
#     {'frequency': 3886, 'percentage': 0.18081146473106272}],
#    'p_value': 1.4525420897863528e-11,
#    'total': 21492},
#   {'chi_squared': 52.25000067396003,
#    'feature_matrix': [[{'frequency': 11484,
#       'column_percentage': 0.6414925706624958,
#       'total_percentage': 0.5343383584589615,
#       'row_percentage': 0.8195247270391779},
#      {'frequency': 2529,
#       'column_percentage': 0.7044568245125348,
#       'total_percentage': 0.11767169179229481,
#       'row_percentage': 0.18047527296082208}],
#     [{'frequency': 6418,
#       'column_percentage': 0.3585074293375042,
#       'total_percentage': 0.29862274334636146,
#       'row_percentage': 0.858136114453804},
#      {'frequency': 1061,
#       'column_percentage': 0.29554317548746517,
#       'total_percentage': 0.049367206402382284,
#       'row_percentage': 0.14186388554619603}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'AsthmaDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 14013, 'percentage': 0.6520100502512562},
#     {'frequency': 7479, 'percentage': 0.3479899497487437}],
#    'p_value': 2.649263337688825e-11,
#    'total': 21492},
#   {'chi_squared': 829.4049371696476,
#    'feature_matrix': [[{'frequency': 5083,
#       'column_percentage': 0.2839347558931963,
#       'total_percentage': 0.23650660710962218,
#       'row_percentage': 0.961232980332829},
#      {'frequency': 205,
#       'column_percentage': 0.057103064066852366,
#       'total_percentage': 0.009538432905267076,
#       'row_percentage': 0.03876701966717095}],
#     [{'frequency': 12819,
#       'column_percentage': 0.7160652441068037,
#       'total_percentage': 0.5964544946957008,
#       'row_percentage': 0.791100962725253},
#      {'frequency': 3385,
#       'column_percentage': 0.9428969359331476,
#       'total_percentage': 0.15750046528941,
#       'row_percentage': 0.20889903727474698}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'CoughDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 5288, 'percentage': 0.24604504001488925},
#     {'frequency': 16204, 'percentage': 0.7539549599851108}],
#    'p_value': 1.8148983659744737e-179,
#    'total': 21492},
#   {'chi_squared': 55.15931597104202,
#    'feature_matrix': [[{'frequency': 17603,
#       'column_percentage': 0.9832979555356943,
#       'total_percentage': 0.8190489484459333,
#       'row_percentage': 0.8356515547116069},
#      {'frequency': 3462,
#       'column_percentage': 0.9643454038997215,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.16434844528839307}],
#     [{'frequency': 299,
#       'column_percentage': 0.016702044464305663,
#       'total_percentage': 0.01391215335938954,
#       'row_percentage': 0.7002341920374707},
#      {'frequency': 128,
#       'column_percentage': 0.03565459610027855,
#       'total_percentage': 0.00595570444816676,
#       'row_percentage': 0.2997658079625293}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'PneumoniaDx'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21065, 'percentage': 0.9801321421924437},
#     {'frequency': 427, 'percentage': 0.0198678578075563}],
#    'p_value': 6.3493014912896275e-12,
#    'total': 21492},
#   {'chi_squared': 49.506670225338226,
#    'feature_matrix': [[{'frequency': 16502,
#       'column_percentage': 0.9217964473243213,
#       'total_percentage': 0.767820584403499,
#       'row_percentage': 0.8383884570441498},
#      {'frequency': 3181,
#       'column_percentage': 0.8860724233983287,
#       'total_percentage': 0.14800856132514423,
#       'row_percentage': 0.16161154295585023}],
#     [{'frequency': 1400,
#       'column_percentage': 0.07820355267567869,
#       'total_percentage': 0.06514051740182393,
#       'row_percentage': 0.7739082365948038},
#      {'frequency': 409,
#       'column_percentage': 0.11392757660167131,
#       'total_percentage': 0.01903033686953285,
#       'row_percentage': 0.22609176340519624}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'ObesityICD'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 19683, 'percentage': 0.9158291457286433},
#     {'frequency': 1809, 'percentage': 0.08417085427135679}],
#    'p_value': 1.0175504777400289e-10,
#    'total': 21492},
#   {'chi_squared': 49.807982479207446,
#    'feature_matrix': [[{'frequency': 7,
#       'column_percentage': 0.0003910177633783935,
#       'total_percentage': 0.0003257025870091197,
#       'row_percentage': 0.6363636363636364},
#      {'frequency': 4,
#       'column_percentage': 0.0011142061281337048,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 0.36363636363636365}],
#     [{'frequency': 4166,
#       'column_percentage': 0.23271142889062674,
#       'total_percentage': 0.1938395682114275,
#       'row_percentage': 0.8036265432098766},
#      {'frequency': 1018,
#       'column_percentage': 0.2835654596100279,
#       'total_percentage': 0.04736646193932626,
#       'row_percentage': 0.19637345679012347}],
#     [{'frequency': 13627,
#       'column_percentage': 0.7611998659367668,
#       'total_percentage': 0.6340498790247534,
#       'row_percentage': 0.8420044488383589},
#      {'frequency': 2557,
#       'column_percentage': 0.7122562674094708,
#       'total_percentage': 0.11897450214033128,
#       'row_percentage': 0.15799555116164113}],
#     [{'frequency': 100,
#       'column_percentage': 0.005585968048262764,
#       'total_percentage': 0.004652894100130281,
#       'row_percentage': 0.9090909090909091},
#      {'frequency': 10,
#       'column_percentage': 0.002785515320334262,
#       'total_percentage': 0.0004652894100130281,
#       'row_percentage': 0.09090909090909091}],
#     [{'frequency': 2,
#       'column_percentage': 0.00011171936096525528,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 0.6666666666666666},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.3333333333333333}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'AvgDailyOzoneExposure'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 11, 'percentage': 0.0005118183510143309},
#     {'frequency': 5184, 'percentage': 0.24120603015075376},
#     {'frequency': 16184, 'percentage': 0.7530243811650846},
#     {'frequency': 110, 'percentage': 0.005118183510143309},
#     {'frequency': 3, 'percentage': 0.00013958682300390843}],
#    'p_value': 1.1705944615386469e-07,
#    'total': 21492},
#   {'chi_squared': 75.2614740980578,
#    'feature_matrix': [[{'frequency': 16779,
#       'column_percentage': 0.9372695788180092,
#       'total_percentage': 0.7807091010608599,
#       'row_percentage': 0.8278567199526347},
#      {'frequency': 3489,
#       'column_percentage': 0.971866295264624,
#       'total_percentage': 0.1623394751535455,
#       'row_percentage': 0.17214328004736532}],
#     [{'frequency': 1103,
#       'column_percentage': 0.06161322757233829,
#       'total_percentage': 0.051321421924437,
#       'row_percentage': 0.9207011686143572},
#      {'frequency': 95,
#       'column_percentage': 0.026462395543175487,
#       'total_percentage': 0.004420249395123767,
#       'row_percentage': 0.07929883138564274}],
#     [{'frequency': 12,
#       'column_percentage': 0.0006703161657915317,
#       'total_percentage': 0.0005583472920156337,
#       'row_percentage': 0.8},
#      {'frequency': 3,
#       'column_percentage': 0.0008356545961002785,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 0.2}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 8,
#       'column_percentage': 0.0004468774438610211,
#       'total_percentage': 0.0003722315280104225,
#       'row_percentage': 0.8},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 0.2}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'MaxDailyOzoneExposure'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20268, 'percentage': 0.9430485762144054},
#     {'frequency': 1198, 'percentage': 0.055741671319560766},
#     {'frequency': 15, 'percentage': 0.0006979341150195422},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 10, 'percentage': 0.0004652894100130281}],
#    'p_value': 1.4031511182720637e-12,
#    'total': 21492},
#   {'chi_squared': 21.680610501349456,
#    'feature_matrix': [[{'frequency': 8617,
#       'column_percentage': 0.4813428667188024,
#       'total_percentage': 0.4009398846082263,
#       'row_percentage': 0.8256203890006707},
#      {'frequency': 1820,
#       'column_percentage': 0.5069637883008357,
#       'total_percentage': 0.08468267262237111,
#       'row_percentage': 0.1743796109993293}],
#     [{'frequency': 8026,
#       'column_percentage': 0.44832979555356944,
#       'total_percentage': 0.37344128047645636,
#       'row_percentage': 0.8348242146869149},
#      {'frequency': 1588,
#       'column_percentage': 0.4423398328690808,
#       'total_percentage': 0.07388795831006886,
#       'row_percentage': 0.16517578531308508}],
#     [{'frequency': 937,
#       'column_percentage': 0.0523405206122221,
#       'total_percentage': 0.04359761771822073,
#       'row_percentage': 0.8740671641791045},
#      {'frequency': 135,
#       'column_percentage': 0.037604456824512536,
#       'total_percentage': 0.00628140703517588,
#       'row_percentage': 0.1259328358208955}],
#     [{'frequency': 200,
#       'column_percentage': 0.011171936096525528,
#       'total_percentage': 0.009305788200260562,
#       'row_percentage': 0.8658008658008658},
#      {'frequency': 31,
#       'column_percentage': 0.008635097493036212,
#       'total_percentage': 0.0014423971710403871,
#       'row_percentage': 0.1341991341991342}],
#     [{'frequency': 122,
#       'column_percentage': 0.006814881018880572,
#       'total_percentage': 0.0056765308021589425,
#       'row_percentage': 0.8840579710144928},
#      {'frequency': 16,
#       'column_percentage': 0.004456824512534819,
#       'total_percentage': 0.000744463056020845,
#       'row_percentage': 0.11594202898550725}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstResidentialDensity'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 10437, 'percentage': 0.48562255723059744},
#     {'frequency': 9614, 'percentage': 0.4473292387865252},
#     {'frequency': 1072, 'percentage': 0.04987902475339661},
#     {'frequency': 231, 'percentage': 0.010748185371300949},
#     {'frequency': 138, 'percentage': 0.0064209938581797875}],
#    'p_value': 0.00994823994849266,
#    'total': 21492},
#   {'chi_squared': 22.22229595565054,
#    'feature_matrix': [[{'frequency': 7417,
#       'column_percentage': 0.4143112501396492,
#       'total_percentage': 0.3451051554066629,
#       'row_percentage': 0.8306641281218502},
#      {'frequency': 1512,
#       'column_percentage': 0.4211699164345404,
#       'total_percentage': 0.07035175879396985,
#       'row_percentage': 0.16933587187814986}],
#     [{'frequency': 9148,
#       'column_percentage': 0.5110043570550776,
#       'total_percentage': 0.4256467522799181,
#       'row_percentage': 0.8291489168857065},
#      {'frequency': 1885,
#       'column_percentage': 0.5250696378830083,
#       'total_percentage': 0.0877070537874558,
#       'row_percentage': 0.17085108311429348}],
#     [{'frequency': 1013,
#       'column_percentage': 0.0565858563289018,
#       'total_percentage': 0.047133817234319746,
#       'row_percentage': 0.8778162911611785},
#      {'frequency': 141,
#       'column_percentage': 0.03927576601671309,
#       'total_percentage': 0.006560580681183696,
#       'row_percentage': 0.12218370883882149}],
#     [{'frequency': 121,
#       'column_percentage': 0.006759021338397945,
#       'total_percentage': 0.00563000186115764,
#       'row_percentage': 0.8962962962962963},
#      {'frequency': 14,
#       'column_percentage': 0.0038997214484679664,
#       'total_percentage': 0.0006514051740182394,
#       'row_percentage': 0.1037037037037037}],
#     [{'frequency': 203,
#       'column_percentage': 0.01133951513797341,
#       'total_percentage': 0.00944537502326447,
#       'row_percentage': 0.8423236514522822},
#      {'frequency': 38,
#       'column_percentage': 0.010584958217270195,
#       'total_percentage': 0.0017680997580495068,
#       'row_percentage': 0.15767634854771784}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstResidentialDesnity25Plus'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 8929, 'percentage': 0.4154569142006328},
#     {'frequency': 11033, 'percentage': 0.5133538060673739},
#     {'frequency': 1154, 'percentage': 0.05369439791550344},
#     {'frequency': 135, 'percentage': 0.00628140703517588},
#     {'frequency': 241, 'percentage': 0.011213474781313978}],
#    'p_value': 0.00820053178764048,
#    'total': 21492},
#   {'chi_squared': 12.527619966828084,
#    'feature_matrix': [[{'frequency': 14050,
#       'column_percentage': 0.7848285107809183,
#       'total_percentage': 0.6537316210683045,
#       'row_percentage': 0.8329381076594735},
#      {'frequency': 2818,
#       'column_percentage': 0.784958217270195,
#       'total_percentage': 0.13111855574167133,
#       'row_percentage': 0.16706189234052643}],
#     [{'frequency': 3178,
#       'column_percentage': 0.17752206457379063,
#       'total_percentage': 0.14786897450214034,
#       'row_percentage': 0.8420773714891362},
#      {'frequency': 596,
#       'column_percentage': 0.166016713091922,
#       'total_percentage': 0.027731248836776475,
#       'row_percentage': 0.1579226285108638}],
#     [{'frequency': 617,
#       'column_percentage': 0.03446542285778125,
#       'total_percentage': 0.028708356597803835,
#       'row_percentage': 0.79204107830552},
#      {'frequency': 162,
#       'column_percentage': 0.04512534818941504,
#       'total_percentage': 0.007537688442211055,
#       'row_percentage': 0.2079589216944801}],
#     [{'frequency': 44,
#       'column_percentage': 0.002457825941235616,
#       'total_percentage': 0.0020472734040573237,
#       'row_percentage': 0.7857142857142857},
#      {'frequency': 12,
#       'column_percentage': 0.003342618384401114,
#       'total_percentage': 0.0005583472920156337,
#       'row_percentage': 0.21428571428571427}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4}],
#     'feature_name': 'EstProbabilityESL'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 16868, 'percentage': 0.7848501768099758},
#     {'frequency': 3774, 'percentage': 0.1756002233389168},
#     {'frequency': 779, 'percentage': 0.03624604504001489},
#     {'frequency': 56, 'percentage': 0.0026056206960729574}],
#    'p_value': 0.08448912614797445,
#    'total': 21492},
#   {'chi_squared': 19.701359831241504,
#    'feature_matrix': [[{'frequency': 9489,
#       'column_percentage': 0.5300525080996537,
#       'total_percentage': 0.4415131211613624,
#       'row_percentage': 0.8314203101726102},
#      {'frequency': 1924,
#       'column_percentage': 0.5359331476323119,
#       'total_percentage': 0.0895216824865066,
#       'row_percentage': 0.16857968982738983}],
#     [{'frequency': 6689,
#       'column_percentage': 0.3736454027482963,
#       'total_percentage': 0.3112320863577145,
#       'row_percentage': 0.8271299616668728},
#      {'frequency': 1398,
#       'column_percentage': 0.3894150417827298,
#       'total_percentage': 0.06504745951982133,
#       'row_percentage': 0.17287003833312725}],
#     [{'frequency': 1122,
#       'column_percentage': 0.06267456150150821,
#       'total_percentage': 0.05220547180346175,
#       'row_percentage': 0.8765625},
#      {'frequency': 158,
#       'column_percentage': 0.04401114206128134,
#       'total_percentage': 0.007351572678205844,
#       'row_percentage': 0.1234375}],
#     [{'frequency': 156,
#       'column_percentage': 0.008714110155289912,
#       'total_percentage': 0.0072585147962032385,
#       'row_percentage': 0.8342245989304813},
#      {'frequency': 31,
#       'column_percentage': 0.008635097493036212,
#       'total_percentage': 0.0014423971710403871,
#       'row_percentage': 0.1657754010695187}],
#     [{'frequency': 4,
#       'column_percentage': 0.00022343872193051055,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 0.8},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 0.2}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5}],
#     'feature_name': 'EstHouseholdIncome'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 11413, 'percentage': 0.5310348036478689},
#     {'frequency': 8087, 'percentage': 0.3762795458775358},
#     {'frequency': 1280, 'percentage': 0.0595570444816676},
#     {'frequency': 187, 'percentage': 0.008700911967243626},
#     {'frequency': 5, 'percentage': 0.00023264470500651406}],
#    'p_value': 0.019847565963857026,
#    'total': 21492},
#   {'chi_squared': 21491.999999999993,
#    'feature_matrix': [[{'frequency': 14813,
#       'column_percentage': 0.8274494469891632,
#       'total_percentage': 0.6892332030522985,
#       'row_percentage': 1.0},
#      {'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0}],
#     [{'frequency': 3089,
#       'column_percentage': 0.17255055301083677,
#       'total_percentage': 0.14372789875302439,
#       'row_percentage': 1.0},
#      {'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2344,
#       'column_percentage': 0.6529247910863509,
#       'total_percentage': 0.10906383770705379,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 690,
#       'column_percentage': 0.19220055710306408,
#       'total_percentage': 0.03210496929089894,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 262,
#       'column_percentage': 0.07298050139275766,
#       'total_percentage': 0.012190582542341337,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 118,
#       'column_percentage': 0.03286908077994429,
#       'total_percentage': 0.005490415038153731,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 60,
#       'column_percentage': 0.016713091922005572,
#       'total_percentage': 0.0027917364600781687,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 29,
#       'column_percentage': 0.00807799442896936,
#       'total_percentage': 0.0013493392890377815,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 17,
#       'column_percentage': 0.004735376044568245,
#       'total_percentage': 0.0007909919970221478,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 15,
#       'column_percentage': 0.004178272980501393,
#       'total_percentage': 0.0006979341150195422,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 9,
#       'column_percentage': 0.0025069637883008357,
#       'total_percentage': 0.0004187604690117253,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 9,
#       'column_percentage': 0.0025069637883008357,
#       'total_percentage': 0.0004187604690117253,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 4,
#       'column_percentage': 0.0011142061281337048,
#       'total_percentage': 0.00018611576400521124,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 7,
#       'column_percentage': 0.0019498607242339832,
#       'total_percentage': 0.0003257025870091197,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 3,
#       'column_percentage': 0.0008356545961002785,
#       'total_percentage': 0.00013958682300390843,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 5,
#       'column_percentage': 0.001392757660167131,
#       'total_percentage': 0.00023264470500651406,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 2,
#       'column_percentage': 0.0005571030640668524,
#       'total_percentage': 9.305788200260562e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}],
#     [{'frequency': 0,
#       'column_percentage': 0.0,
#       'total_percentage': 0.0,
#       'row_percentage': 0.0},
#      {'frequency': 1,
#       'column_percentage': 0.0002785515320334262,
#       'total_percentage': 4.652894100130281e-05,
#       'row_percentage': 1.0}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1},
#      {'operator': '=', 'value': 2},
#      {'operator': '=', 'value': 3},
#      {'operator': '=', 'value': 4},
#      {'operator': '=', 'value': 5},
#      {'operator': '=', 'value': 6},
#      {'operator': '=', 'value': 7},
#      {'operator': '=', 'value': 8},
#      {'operator': '=', 'value': 9},
#      {'operator': '=', 'value': 10},
#      {'operator': '=', 'value': 11},
#      {'operator': '=', 'value': 12},
#      {'operator': '=', 'value': 13},
#      {'operator': '=', 'value': 14},
#      {'operator': '=', 'value': 15},
#      {'operator': '=', 'value': 16},
#      {'operator': '=', 'value': 17},
#      {'operator': '=', 'value': 18},
#      {'operator': '=', 'value': 19},
#      {'operator': '=', 'value': 20},
#      {'operator': '=', 'value': 21},
#      {'operator': '=', 'value': 22},
#      {'operator': '=', 'value': 23},
#      {'operator': '=', 'value': 25},
#      {'operator': '=', 'value': 27},
#      {'operator': '=', 'value': 33},
#      {'operator': '=', 'value': 37},
#      {'operator': '=', 'value': 50},
#      {'operator': '=', 'value': 51}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 14813, 'percentage': 0.6892332030522985},
#     {'frequency': 3089, 'percentage': 0.14372789875302439},
#     {'frequency': 2344, 'percentage': 0.10906383770705379},
#     {'frequency': 690, 'percentage': 0.03210496929089894},
#     {'frequency': 262, 'percentage': 0.012190582542341337},
#     {'frequency': 118, 'percentage': 0.005490415038153731},
#     {'frequency': 60, 'percentage': 0.0027917364600781687},
#     {'frequency': 29, 'percentage': 0.0013493392890377815},
#     {'frequency': 17, 'percentage': 0.0007909919970221478},
#     {'frequency': 15, 'percentage': 0.0006979341150195422},
#     {'frequency': 9, 'percentage': 0.0004187604690117253},
#     {'frequency': 9, 'percentage': 0.0004187604690117253},
#     {'frequency': 4, 'percentage': 0.00018611576400521124},
#     {'frequency': 7, 'percentage': 0.0003257025870091197},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 3, 'percentage': 0.00013958682300390843},
#     {'frequency': 5, 'percentage': 0.00023264470500651406},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 2, 'percentage': 9.305788200260562e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05},
#     {'frequency': 1, 'percentage': 4.652894100130281e-05}],
#    'p_value': 0.0,
#    'total': 21492},
#   {'chi_squared': 109.96216990797932,
#    'feature_matrix': [[{'frequency': 16201,
#       'column_percentage': 0.9049826834990504,
#       'total_percentage': 0.7538153731621068,
#       'row_percentage': 0.8420915848017049},
#      {'frequency': 3038,
#       'column_percentage': 0.8462395543175487,
#       'total_percentage': 0.14135492276195794,
#       'row_percentage': 0.15790841519829513}],
#     [{'frequency': 1701,
#       'column_percentage': 0.09501731650094962,
#       'total_percentage': 0.07914572864321608,
#       'row_percentage': 0.7549933422103862},
#      {'frequency': 552,
#       'column_percentage': 0.15376044568245126,
#       'total_percentage': 0.02568397543271915,
#       'row_percentage': 0.24500665778961384}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Prednisone'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 19239, 'percentage': 0.8951702959240647},
#     {'frequency': 2253, 'percentage': 0.10482970407593523}],
#    'p_value': 1.1180903063022454e-23,
#    'total': 21492},
#   {'chi_squared': 16.13859593375987,
#    'feature_matrix': [[{'frequency': 17594,
#       'column_percentage': 0.9827952184113506,
#       'total_percentage': 0.8186301879769217,
#       'row_percentage': 0.8316709997636492},
#      {'frequency': 3561,
#       'column_percentage': 0.9919220055710306,
#       'total_percentage': 0.1656895589056393,
#       'row_percentage': 0.16832900023635075}],
#     [{'frequency': 308,
#       'column_percentage': 0.017204781588649312,
#       'total_percentage': 0.014330913828401265,
#       'row_percentage': 0.913946587537092},
#      {'frequency': 29,
#       'column_percentage': 0.00807799442896936,
#       'total_percentage': 0.0013493392890377815,
#       'row_percentage': 0.08605341246290801}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Mometasone'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21155, 'percentage': 0.984319746882561},
#     {'frequency': 337, 'percentage': 0.015680253117439046}],
#    'p_value': 0.00106215012725766,
#    'total': 21492},
#   {'chi_squared': 10.373908512214845,
#    'feature_matrix': [[{'frequency': 17043,
#       'column_percentage': 0.9520165344654229,
#       'total_percentage': 0.7929927414852038,
#       'row_percentage': 0.8311631309436722},
#      {'frequency': 3462,
#       'column_percentage': 0.9643454038997215,
#       'total_percentage': 0.16108319374651034,
#       'row_percentage': 0.16883686905632772}],
#     [{'frequency': 859,
#       'column_percentage': 0.04798346553457714,
#       'total_percentage': 0.03996836032011911,
#       'row_percentage': 0.8703140830800405},
#      {'frequency': 128,
#       'column_percentage': 0.03565459610027855,
#       'total_percentage': 0.00595570444816676,
#       'row_percentage': 0.12968591691995948}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Budesonide'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20505, 'percentage': 0.9540759352317141},
#     {'frequency': 987, 'percentage': 0.04592406476828587}],
#    'p_value': 0.015641103266372428,
#    'total': 21492},
#   {'chi_squared': 8.06006470961281,
#    'feature_matrix': [[{'frequency': 12803,
#       'column_percentage': 0.7151714892190817,
#       'total_percentage': 0.5957100316396798,
#       'row_percentage': 0.8375637838545074},
#      {'frequency': 2483,
#       'column_percentage': 0.6916434540389972,
#       'total_percentage': 0.11553136050623487,
#       'row_percentage': 0.1624362161454926}],
#     [{'frequency': 5099,
#       'column_percentage': 0.2848285107809183,
#       'total_percentage': 0.23725107016564304,
#       'row_percentage': 0.8216242346116661},
#      {'frequency': 1107,
#       'column_percentage': 0.30835654596100276,
#       'total_percentage': 0.05150753768844221,
#       'row_percentage': 0.17837576538833386}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Albuterol'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 15286, 'percentage': 0.7112413921459148},
#     {'frequency': 6206, 'percentage': 0.28875860785408525}],
#    'p_value': 0.04478652335107,
#    'total': 21492},
#   {'chi_squared': 159.86442847726266,
#    'feature_matrix': [[{'frequency': 15741,
#       'column_percentage': 0.8792872304770417,
#       'total_percentage': 0.7324120603015075,
#       'row_percentage': 0.8456083803384368},
#      {'frequency': 2874,
#       'column_percentage': 0.8005571030640668,
#       'total_percentage': 0.13372417643774429,
#       'row_percentage': 0.15439161966156326}],
#     [{'frequency': 2161,
#       'column_percentage': 0.12071276952295833,
#       'total_percentage': 0.10054904150381537,
#       'row_percentage': 0.7511296489398679},
#      {'frequency': 716,
#       'column_percentage': 0.19944289693593314,
#       'total_percentage': 0.033314721756932814,
#       'row_percentage': 0.24887035106013208}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Diphenhydramine'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 18615, 'percentage': 0.8661362367392518},
#     {'frequency': 2877, 'percentage': 0.1338637632607482}],
#    'p_value': 1.9605955442282923e-34,
#    'total': 21492},
#   {'chi_squared': 13.357145608459799,
#    'feature_matrix': [[{'frequency': 16917,
#       'column_percentage': 0.9449782147246117,
#       'total_percentage': 0.7871300949190396,
#       'row_percentage': 0.830771497323577},
#      {'frequency': 3446,
#       'column_percentage': 0.9598885793871866,
#       'total_percentage': 0.16033873069048948,
#       'row_percentage': 0.16922850267642292}],
#     [{'frequency': 985,
#       'column_percentage': 0.05502178527538822,
#       'total_percentage': 0.04583100688628327,
#       'row_percentage': 0.8724534986713907},
#      {'frequency': 144,
#       'column_percentage': 0.04011142061281337,
#       'total_percentage': 0.006700167504187605,
#       'row_percentage': 0.1275465013286094}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Cetirizine'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20363, 'percentage': 0.9474688256095292},
#     {'frequency': 1129, 'percentage': 0.05253117439047087}],
#    'p_value': 0.003924597447558311,
#    'total': 21492},
#   {'chi_squared': 191.75741131714443,
#    'feature_matrix': [[{'frequency': 17129,
#       'column_percentage': 0.9568204669869288,
#       'total_percentage': 0.7969942304113158,
#       'row_percentage': 0.8412651637935269},
#      {'frequency': 3232,
#       'column_percentage': 0.9002785515320334,
#       'total_percentage': 0.15038153731621068,
#       'row_percentage': 0.15873483620647316}],
#     [{'frequency': 773,
#       'column_percentage': 0.04317953301307117,
#       'total_percentage': 0.035966871394007074,
#       'row_percentage': 0.6834659593280283},
#      {'frequency': 358,
#       'column_percentage': 0.09972144846796657,
#       'total_percentage': 0.016657360878466407,
#       'row_percentage': 0.3165340406719717}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Ipratropium'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 20361, 'percentage': 0.9473757677275265},
#     {'frequency': 1131, 'percentage': 0.05262423227247348}],
#    'p_value': 2.546658420195129e-41,
#    'total': 21492},
#   {'chi_squared': 18.565974934801602,
#    'feature_matrix': [[{'frequency': 17876,
#       'column_percentage': 0.9985476483074517,
#       'total_percentage': 0.8317513493392891,
#       'row_percentage': 0.8334576650503543},
#      {'frequency': 3572,
#       'column_percentage': 0.9949860724233983,
#       'total_percentage': 0.16620137725665363,
#       'row_percentage': 0.16654233494964565}],
#     [{'frequency': 26,
#       'column_percentage': 0.0014523516925483186,
#       'total_percentage': 0.001209752466033873,
#       'row_percentage': 0.5909090909090909},
#      {'frequency': 18,
#       'column_percentage': 0.005013927576601671,
#       'total_percentage': 0.0008375209380234506,
#       'row_percentage': 0.4090909090909091}]],
#    'feature_b': {'feature_qualifiers': [{'operator': '=', 'value': 0},
#      {'operator': '=', 'value': 1}],
#     'feature_name': 'Salmeterol'},
#    'columns': [{'frequency': 17902, 'percentage': 0.8329611018053229},
#     {'frequency': 3590, 'percentage': 0.1670388981946771}],
#    'feature_a': {'feature_qualifiers': [{'operator': '<', 'value': 2},
#      {'operator': '>=', 'value': 2}],
#     'feature_name': 'TotalEDInpatientVisits'},
#    'rows': [{'frequency': 21448, 'percentage': 0.9979527265959427},
#     {'frequency': 44, 'percentage': 0.0020472734040573237}],
#    'p_value': 0.0003361168690149911,
#    'total': 21492}],
#  'terms and conditions': "The Translator Integrated Clinical and Environmental Exposures Service (ICEES) is providing you with Data that have been de-identified in accordance with 45 C.F.R. §§ 164.514(a) and (b) and that UNC Health Care System (UNCHCS) is permitted to provide under 45 C.F.R. § 164.502(d)(2). Recipient agrees to notify UNCHCS via NC TraCS in the event that Recipient receives any identifiable data in error and to take such measures to return the identifiable data and/or destroy it at the direction of UNCHCS.\n\nRestrictions on Recipient’s Use of Data. Recipient further agrees to use the data exclusively for the purposes and functionalities provided by the ICEES: cohort discovery; feature-rich cohort discovery; hypothesis-driven queries; and exploratory queries. Recipient agrees to use appropriate safeguards to protect the Data from misuse and unauthorized access or disclosure. Recipient will report to UNCHCS any unauthorized access, use, or disclosure of the Data not provided for by the Service of which Recipient becomes aware. Recipient will not attempt to identify the individuals whose information is contained in any Data transferred pursuant to this Service Agreement or attempt to contact those individuals. Recipient agrees not to sell the Data to any third party for any purpose. Recipient agrees not to disclose or publish the Data in any manner that would identify the Data as originating from UNCHCS. Finally, Recipient agrees to reasonably limit the number of queries to the Service per IP address within a given time interval, in order to prevent rapid ‘attacks’ on the Service.\n\nWe kindly request that Translator team members provide proper attribution for any products (e.g., manuscripts, podium presentations, software) derived from work related to Green Team's clinical datasets. Attribution should include acknowledgement of the funder (National Center for Advancing Translational Sciences [NCATS], Biomedical Data Translator Program awards, OT3TR002020 and OT2TR002514), the North Carolina Translational and Clinical Sciences (NC TraCS) Institute (NCATS, Center for Translational Science Award, UL1TR002489), UNC Hospitals and Health Care System, and all Green Team members who contributed to the work.\n"}

# %% [markdown]
# ## The last function I'll mention here is the endpoint which allows us to look at a dictionary of all the cohorts, their IDs, and the features which define them!

# %%
GetDictionaryObject = iceeshelper.GetDictionary()

# %%
dictionary = GetDictionaryObject.run_get_dictionary()

# %%
dictionary
# Out:
# {'return value': [{'size': 22920,
#    'cohort_id': 'COHORT:55',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 1}}},
#   {'size': 23093, 'cohort_id': 'COHORT:56', 'features': {}},
#   {'size': 3759,
#    'cohort_id': 'COHORT:21',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '3-17'}}},
#   {'size': 2013,
#    'cohort_id': 'COHORT:23',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '0-2'}}},
#   {'size': 22339,
#    'cohort_id': 'COHORT:26',
#    'features': {'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 1}}},
#   {'size': 3650,
#    'cohort_id': 'COHORT:27',
#    'features': {'TotalEDInpatientVisits': {'operator': '>', 'value': 1},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 1}}},
#   {'size': 18689,
#    'cohort_id': 'COHORT:30',
#    'features': {'TotalEDInpatientVisits': {'operator': '<', 'value': 2},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 1}}},
#   {'size': 3958,
#    'cohort_id': 'COHORT:31',
#    'features': {'TotalEDInpatientVisits': {'operator': '<', 'value': 2},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 992,
#    'cohort_id': 'COHORT:32',
#    'features': {'TotalEDInpatientVisits': {'operator': '>', 'value': 1},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 3158,
#    'cohort_id': 'COHORT:33',
#    'features': {'TotalEDInpatientVisits': {'operator': '<', 'value': 1},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 1218,
#    'cohort_id': 'COHORT:34',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '0-2'},
#     'Sex': {'operator': '=', 'value': 'M'}}},
#   {'size': 482,
#    'cohort_id': 'COHORT:35',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '0-2'},
#     'Race': {'operator': '=', 'value': 'African American'}}},
#   {'size': 291,
#    'cohort_id': 'COHORT:36',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '0-2'},
#     'Race': {'operator': '=', 'value': 'African American'},
#     'Sex': {'operator': '=', 'value': 'M'}}},
#   {'size': 353,
#    'cohort_id': 'COHORT:37',
#    'features': {'AgeStudyStart': {'operator': '=', 'value': '18-34'},
#     'Race': {'operator': '=', 'value': 'African American'},
#     'Sex': {'operator': '=', 'value': 'M'}}},
#   {'size': 2567,
#    'cohort_id': 'COHORT:38',
#    'features': {'Race': {'operator': '=', 'value': 'African American'},
#     'Sex': {'operator': '=', 'value': 'M'}}},
#   {'size': 362,
#    'cohort_id': 'COHORT:39',
#    'features': {'TotalEDInpatientVisits': {'operator': '>', 'value': 2},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 1792,
#    'cohort_id': 'COHORT:40',
#    'features': {'TotalEDInpatientVisits': {'operator': '>', 'value': 0},
#     'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 19323,
#    'cohort_id': 'COHORT:41',
#    'features': {'TotalEDInpatientVisits': {'operator': '<', 'value': 2},
#     'MaxDailyPM2.5Exposure': {'operator': '<', 'value': 4}}},
#   {'size': 15418,
#    'cohort_id': 'COHORT:42',
#    'features': {'TotalEDInpatientVisits': {'operator': '<', 'value': 2},
#     'MaxDailyPM2.5Exposure': {'operator': '<', 'value': 3}}},
#   {'size': 1474,
#    'cohort_id': 'COHORT:43',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<', 'value': 3},
#     'TotalEDInpatientVisits': {'operator': '<', 'value': 2}}},
#   {'size': 1601,
#    'cohort_id': 'COHORT:44',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<', 'value': 3}}},
#   {'size': 21492,
#    'cohort_id': 'COHORT:45',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 4950,
#    'cohort_id': 'COHORT:46',
#    'features': {'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 2}}},
#   {'size': 17902,
#    'cohort_id': 'COHORT:49',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 2},
#     'TotalEDInpatientVisits': {'operator': '<', 'value': 2}}},
#   {'size': 6679,
#    'cohort_id': 'COHORT:50',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 2},
#     'TotalEDInpatientVisits': {'operator': '>', 'value': 0}}},
#   {'size': 23065,
#    'cohort_id': 'COHORT:51',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<', 'value': 5}}},
#   {'size': 19685,
#    'cohort_id': 'COHORT:52',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<', 'value': 4}}},
#   {'size': 173,
#    'cohort_id': 'COHORT:53',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<', 'value': 2}}},
#   {'size': 3408,
#    'cohort_id': 'COHORT:54',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '>', 'value': 3}}},
#   {'size': 23093, 'cohort_id': 'COHORT:22', 'features': {}},
#   {'size': 75,
#    'cohort_id': 'COHORT:57',
#    'features': {'MaxDailyPM2.5Exposure': {'operator': '>', 'value': 3}}},
#   {'size': 22057,
#    'cohort_id': 'COHORT:58',
#    'features': {'MajorRoadwayHighwayExposure': {'operator': '>', 'value': 1}}},
#   {'size': 1036,
#    'cohort_id': 'COHORT:59',
#    'features': {'MajorRoadwayHighwayExposure': {'operator': '<=',
#      'value': 1}}},
#   {'size': 6379,
#    'cohort_id': 'COHORT:60',
#    'features': {'Race': {'operator': '=', 'value': 'African American'}}},
#   {'size': 19685,
#    'cohort_id': 'COHORT:61',
#    'features': {'AvgDailyPM2.5Exposure': {'operator': '<=', 'value': 3}}},
#   {'size': 8084,
#    'cohort_id': 'COHORT:62',
#    'features': {'AsthmaDx': {'operator': '=', 'value': 1}}}],
#  'terms and conditions': "The Translator Integrated Clinical and Environmental Exposures Service (ICEES) is providing you with Data that have been de-identified in accordance with 45 C.F.R. §§ 164.514(a) and (b) and that UNC Health Care System (UNCHCS) is permitted to provide under 45 C.F.R. § 164.502(d)(2). Recipient agrees to notify UNCHCS via NC TraCS in the event that Recipient receives any identifiable data in error and to take such measures to return the identifiable data and/or destroy it at the direction of UNCHCS.\n\nRestrictions on Recipient’s Use of Data. Recipient further agrees to use the data exclusively for the purposes and functionalities provided by the ICEES: cohort discovery; feature-rich cohort discovery; hypothesis-driven queries; and exploratory queries. Recipient agrees to use appropriate safeguards to protect the Data from misuse and unauthorized access or disclosure. Recipient will report to UNCHCS any unauthorized access, use, or disclosure of the Data not provided for by the Service of which Recipient becomes aware. Recipient will not attempt to identify the individuals whose information is contained in any Data transferred pursuant to this Service Agreement or attempt to contact those individuals. Recipient agrees not to sell the Data to any third party for any purpose. Recipient agrees not to disclose or publish the Data in any manner that would identify the Data as originating from UNCHCS. Finally, Recipient agrees to reasonably limit the number of queries to the Service per IP address within a given time interval, in order to prevent rapid ‘attacks’ on the Service.\n\nWe kindly request that Translator team members provide proper attribution for any products (e.g., manuscripts, podium presentations, software) derived from work related to Green Team's clinical datasets. Attribution should include acknowledgement of the funder (National Center for Advancing Translational Sciences [NCATS], Biomedical Data Translator Program awards, OT3TR002020 and OT2TR002514), the North Carolina Translational and Clinical Sciences (NC TraCS) Institute (NCATS, Center for Translational Science Award, UL1TR002489), UNC Hospitals and Health Care System, and all Green Team members who contributed to the work.\n"}

# %% [markdown]
# # How might we utilize ICEES API for analysis? Ros, ICEES, and a bit of math...

# %% [markdown]
# ![ros_asthma_graph_large](ros_asthma_graph_large.png)
