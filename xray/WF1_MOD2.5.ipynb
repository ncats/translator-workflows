# %% [markdown]
# # Workflow 1
# ## Module 2
# ### Component MOD2.5
# #### What drugs/compounds target gene products of [gene]?

# %%
import requests
import json
import sys

# %%
url_str = "https://rtx.ncats.io/api/rtx/v1/query"

# %%
request_data = {"query_type_id": "Q9", 
                "terms": {"protein": "UniProtKB:P23219"}}

# %%
response_content = requests.post(url_str, json=request_data, 
                                headers={"accept": "application/json"})

# %%
response_content.status_code
# Out:
# 200

# %%
response_content.json()
# Out:
# {'context': 'https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld',
#  'datetime': '2018-09-17 17:58:09',
#  'id': 'http://rtx.ncats.io/api/rtx/v1/response/406',
#  'message': '108 results found',
#  'original_question_text': '',
#  'query_type_id': 'Q9',
#  'reasoner_id': 'RTX',
#  'response_code': 'OK',
#  'restated_question_text': '',
#  'result_list': [{'confidence': 1.0,
#    'essence': 'pitavastatin',
#    'id': 'http://rtx.ncats.io/api/rtx/v1/result/6269',
#    'reasoner_id': 'RTX',
#    'result_graph': {'edge_list': [{'is_defined_by': 'RTX',
#       'provided_by': 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201753',
#       'source_id': 'CHEMBL.COMPOUND:CHEMBL1201753',
#       'target_id': 'UniProtKB:P23219',
#       'type': 'physically_interacts_with'}],
# ...
