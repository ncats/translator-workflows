# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q25 - "What drugs target proteins associated with $phenotypic_feature"
#### Set protein to the curie id of the desired protein and run.
request = { "query_type_id": "Q25", "terms": { "phenotypic_feature": "HP:0012378" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID	Jaccard index
# Fatigue	HP:0012378	masitinib	CHEMBL.COMPOUND:CHEMBL1908391	0.041667
# Fatigue	HP:0012378	ponatinib	CHEMBL.COMPOUND:CHEMBL1171086	0.040541
# Fatigue	HP:0012378	vemurafenib	CHEMBL.COMPOUND:CHEMBL1229517	0.038462
# Fatigue	HP:0012378	clorazepic acid	CHEMBL.COMPOUND:CHEMBL1213252	0.037975
# Fatigue	HP:0012378	metrizoic acid	CHEMBL.COMPOUND:CHEMBL1736	0.037975
# Fatigue	HP:0012378	hydroxyurea	CHEMBL.COMPOUND:CHEMBL467	0.032787
# Fatigue	HP:0012378	trapidil	CHEMBL.COMPOUND:CHEMBL132767	0.028571
# Fatigue	HP:0012378	triethylenemelamine	CHEMBL.COMPOUND:CHEMBL502384	0.028571
# Fatigue	HP:0012378	frentizole	CHEMBL.COMPOUND:CHEMBL128988	0.028571
# Fatigue	HP:0012378	iodamide	CHEMBL.COMPOUND:CHEMBL1201239	0.028571
# Fatigue	HP:0012378	ufenamate	CHEMBL.COMPOUND:CHEMBL2105605	0.028571
# Fatigue	HP:0012378	azelastine	CHEMBL.COMPOUND:CHEMBL639	0.028571
# Fatigue	HP:0012378	orbifloxacin	CHEMBL.COMPOUND:CHEMBL295433	0.028571
# Fatigue	HP:0012378	derenofylline	CHEMBL.COMPOUND:CHEMBL592435	0.028571
# Fatigue	HP:0012378	chlorquinaldol	CHEMBL.COMPOUND:CHEMBL224325	0.028571
# Fatigue	HP:0012378	eltrombopag	CHEMBL.COMPOUND:CHEMBL461101	0.028571
# Fatigue	HP:0012378	tedizolid	CHEMBL.COMPOUND:CHEMBL1257051	0.028571
# Fatigue	HP:0012378	chloroxylenol	CHEMBL.COMPOUND:CHEMBL398440	0.028571
# Fatigue	HP:0012378	tetrofosmin	CHEMBL.COMPOUND:CHEMBL1615784	0.028571
# Fatigue	HP:0012378	trioxsalen	CHEMBL.COMPOUND:CHEMBL1475	0.028571

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2019-02-14 00:48:15",
#     "id": "https://rtx.ncats.io/api/rtx/v1/response/803",
#     "message": "20 results found",
#     "n_results": 20,
#     "original_question_text": "",
#     "query_type_id": "Q25",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 0.041666666666666664,
#             "essence": "masitinib",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33178",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1908391",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P22607",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P22607",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1908391",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1908391",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a protooncogene that encodes a protein tyrosine kinase involved in a variety of cellular processes, including cell division, adhesion, differentiation, and response to stress. The activity of the protein is negatively regulated by its SH3 domain, whereby deletion of the region encoding this domain results in an oncogene. The ubiquitously expressed protein has DNA-binding activity that is regulated by CDC2-mediated phosphorylation, suggesting a cell cycle function. This gene has been found fused to a variety of translocation partner genes in various leukemias, most notably the t(9;22) translocation that results in a fusion with the 5' end of the breakpoint cluster region gene (BCR; MIM:151410). Alternative splicing of this gene results in two transcript variants, which contain alternative first exons that are spliced to the remaining common exons. [provided by RefSeq, Aug 2014].",
#                         "id": "UniProtKB:P00519",
#                         "name": "ABL proto-oncogene 1, non-receptor tyrosine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P00519"
#                     },
#                     {
#                         "description": "This gene encodes a member of the fibroblast growth factor receptor (FGFR) family, with its amino acid sequence being highly conserved between members and among divergent species. FGFR family members differ from one another in their ligand affinities and tissue distribution. A full-length representative protein would consist of an extracellular region, composed of three immunoglobulin-like domains, a single hydrophobic membrane-spanning segment and a cytoplasmic tyrosine kinase domain. The extracellular portion of the protein interacts with fibroblast growth factors, setting in motion a cascade of downstream signals, ultimately influencing mitogenesis and differentiation. This particular family member binds acidic and basic fibroblast growth hormone and plays a role in bone development and maintenance. Mutations in this gene lead to craniosynostosis and multiple types of skeletal dysplasia. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P22607",
#                         "name": "fibroblast growth factor receptor 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P22607"
#                     },
#                     {
#                         "description": "A member of the class of benzamides that is the carboxamide resulting from the formal condensation of the carboxy group of 4-[(4-methylpiperazin-1-yl)methyl]benzoic acid with the primary amino group of 4-methyl-<element>N</element><smallsup>3</smallsup>-[4-(pyridin-3-yl)-1,3-thiazol-2-yl]benzene-1,3-diamine. It is a highly selective oral tyrosine kinase inhibitor.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1908391",
#                         "name": "masitinib",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1908391"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a protein belonging to the RAF family of serine/threonine protein kinases. This protein plays a role in regulating the MAP kinase/ERK signaling pathway, which affects cell division, differentiation, and secretion. Mutations in this gene, most commonly the V600E mutation, are the most frequently identified cancer-causing mutations in melanoma, and have been identified in various other cancers as well, including non-Hodgkin lymphoma, colorectal cancer, thyroid carcinoma, non-small cell lung carcinoma, hairy cell leukemia and adenocarcinoma of lung. Mutations in this gene are also associated with cardiofaciocutaneous, Noonan, and Costello syndromes, which exhibit overlapping phenotypes. A pseudogene of this gene has been identified on the X chromosome. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P15056",
#                         "name": "B-Raf proto-oncogene, serine/threonine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P15056"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "masitinib",
#                 "CHEMBL.COMPOUND:CHEMBL1908391",
#                 "0.041667"
#             ],
#             "text": "The chemical_substance masitinib involves similar proteins as Fatigue with similarity value 0.041667"
#         },
#         {
#             "confidence": 0.04054054054054054,
#             "essence": "ponatinib",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33179",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1171086",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P22607",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1171086",
#                         "target_id": "UniProtKB:P22607",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1171086",
#                         "target_id": "UniProtKB:P15056",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a protooncogene that encodes a protein tyrosine kinase involved in a variety of cellular processes, including cell division, adhesion, differentiation, and response to stress. The activity of the protein is negatively regulated by its SH3 domain, whereby deletion of the region encoding this domain results in an oncogene. The ubiquitously expressed protein has DNA-binding activity that is regulated by CDC2-mediated phosphorylation, suggesting a cell cycle function. This gene has been found fused to a variety of translocation partner genes in various leukemias, most notably the t(9;22) translocation that results in a fusion with the 5' end of the breakpoint cluster region gene (BCR; MIM:151410). Alternative splicing of this gene results in two transcript variants, which contain alternative first exons that are spliced to the remaining common exons. [provided by RefSeq, Aug 2014].",
#                         "id": "UniProtKB:P00519",
#                         "name": "ABL proto-oncogene 1, non-receptor tyrosine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P00519"
#                     },
#                     {
#                         "description": "This gene encodes a member of the fibroblast growth factor receptor (FGFR) family, with its amino acid sequence being highly conserved between members and among divergent species. FGFR family members differ from one another in their ligand affinities and tissue distribution. A full-length representative protein would consist of an extracellular region, composed of three immunoglobulin-like domains, a single hydrophobic membrane-spanning segment and a cytoplasmic tyrosine kinase domain. The extracellular portion of the protein interacts with fibroblast growth factors, setting in motion a cascade of downstream signals, ultimately influencing mitogenesis and differentiation. This particular family member binds acidic and basic fibroblast growth hormone and plays a role in bone development and maintenance. Mutations in this gene lead to craniosynostosis and multiple types of skeletal dysplasia. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P22607",
#                         "name": "fibroblast growth factor receptor 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P22607"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1171086",
#                         "name": "ponatinib",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1171086"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a protein belonging to the RAF family of serine/threonine protein kinases. This protein plays a role in regulating the MAP kinase/ERK signaling pathway, which affects cell division, differentiation, and secretion. Mutations in this gene, most commonly the V600E mutation, are the most frequently identified cancer-causing mutations in melanoma, and have been identified in various other cancers as well, including non-Hodgkin lymphoma, colorectal cancer, thyroid carcinoma, non-small cell lung carcinoma, hairy cell leukemia and adenocarcinoma of lung. Mutations in this gene are also associated with cardiofaciocutaneous, Noonan, and Costello syndromes, which exhibit overlapping phenotypes. A pseudogene of this gene has been identified on the X chromosome. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P15056",
#                         "name": "B-Raf proto-oncogene, serine/threonine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P15056"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "ponatinib",
#                 "CHEMBL.COMPOUND:CHEMBL1171086",
#                 "0.040541"
#             ],
#             "text": "The chemical_substance ponatinib involves similar proteins as Fatigue with similarity value 0.040541"
#         },
#         {
#             "confidence": 0.038461538461538464,
#             "essence": "vemurafenib",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33180",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P22607",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "Pharos",
#                         "source_id": "UniProtKB:P22607",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1229517",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P23458",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P23458",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1229517",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1229517",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the fibroblast growth factor receptor (FGFR) family, with its amino acid sequence being highly conserved between members and among divergent species. FGFR family members differ from one another in their ligand affinities and tissue distribution. A full-length representative protein would consist of an extracellular region, composed of three immunoglobulin-like domains, a single hydrophobic membrane-spanning segment and a cytoplasmic tyrosine kinase domain. The extracellular portion of the protein interacts with fibroblast growth factors, setting in motion a cascade of downstream signals, ultimately influencing mitogenesis and differentiation. This particular family member binds acidic and basic fibroblast growth hormone and plays a role in bone development and maintenance. Mutations in this gene lead to craniosynostosis and multiple types of skeletal dysplasia. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P22607",
#                         "name": "fibroblast growth factor receptor 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P22607"
#                     },
#                     {
#                         "description": "This gene encodes a membrane protein that is a member of a class of protein-tyrosine kinases (PTK) characterized by the presence of a second phosphotransferase-related domain immediately N-terminal to the PTK domain. The encoded kinase phosphorylates STAT proteins (signal transducers and activators of transcription) and plays a key role in interferon-alpha/beta and interferon-gamma signal transduction. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Mar 2016].",
#                         "id": "UniProtKB:P23458",
#                         "name": "Janus kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P23458"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a protein belonging to the RAF family of serine/threonine protein kinases. This protein plays a role in regulating the MAP kinase/ERK signaling pathway, which affects cell division, differentiation, and secretion. Mutations in this gene, most commonly the V600E mutation, are the most frequently identified cancer-causing mutations in melanoma, and have been identified in various other cancers as well, including non-Hodgkin lymphoma, colorectal cancer, thyroid carcinoma, non-small cell lung carcinoma, hairy cell leukemia and adenocarcinoma of lung. Mutations in this gene are also associated with cardiofaciocutaneous, Noonan, and Costello syndromes, which exhibit overlapping phenotypes. A pseudogene of this gene has been identified on the X chromosome. [provided by RefSeq, Aug 2017].",
#                         "id": "UniProtKB:P15056",
#                         "name": "B-Raf proto-oncogene, serine/threonine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P15056"
#                     },
#                     {
#                         "description": "A pyrrolopyridine that is 1<element>H</element>-pyrrolo[2,3-b]pyridine which is substituted at position 5 by a p-chlorophenyl group and at positions 3 by a 3-amino-2,6-difluorobenzoyl group, the amino group of which has undergone formal condensation with propane-1-sulfonic acid to give the corresponding sulfonamide. An inhibitor of BRAF and other kinases.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1229517",
#                         "name": "vemurafenib",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1229517"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "vemurafenib",
#                 "CHEMBL.COMPOUND:CHEMBL1229517",
#                 "0.038462"
#             ],
#             "text": "The chemical_substance vemurafenib involves similar proteins as Fatigue with similarity value 0.038462"
#         },
#         {
#             "confidence": 0.0379746835443038,
#             "essence": "clorazepic acid",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33181",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "Pharos",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1213252",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1213252",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P31749",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1213252",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P31749",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Retinoid X receptors (RXRs) and retinoic acid receptors (RARs) are nuclear receptors that mediate the biological effects of retinoids by their involvement in retinoic acid-mediated gene activation. These receptors function as transcription factors by binding as homodimers or heterodimers to specific sequences in the promoters of target genes. The protein encoded by this gene is a member of the steroid and thyroid hormone receptor superfamily of transcriptional regulators. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, May 2014].",
#                         "id": "UniProtKB:P19793",
#                         "name": "retinoid X receptor alpha",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P19793"
#                     },
#                     {
#                         "description": "A 1,4-benzodiazepinone in which the oxo group is at position 2, and which is substituted at positions 3, 5, and 7 by carboxy, phenyl and chloro groups, respectively.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1213252",
#                         "name": "clorazepic acid",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1213252"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     },
#                     {
#                         "description": "The serine-threonine protein kinase encoded by the AKT1 gene is catalytically inactive in serum-starved primary and immortalized fibroblasts. AKT1 and the related AKT2 are activated by platelet-derived growth factor. The activation is rapid and specific, and it is abrogated by mutations in the pleckstrin homology domain of AKT1. It was shown that the activation occurs through phosphatidylinositol 3-kinase. In the developing nervous system AKT is a critical mediator of growth factor-induced neuronal survival. Survival factors can suppress apoptosis in a transcription-independent manner by activating the serine/threonine kinase AKT1, which then phosphorylates and inactivates components of the apoptotic machinery. Mutations in this gene have been associated with the Proteus syndrome. Multiple alternatively spliced transcript variants have been found for this gene. [provided by RefSeq, Jul 2011].",
#                         "id": "UniProtKB:P31749",
#                         "name": "AKT serine/threonine kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P31749"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "clorazepic acid",
#                 "CHEMBL.COMPOUND:CHEMBL1213252",
#                 "0.037975"
#             ],
#             "text": "The chemical_substance clorazepic acid involves similar proteins as Fatigue with similarity value 0.037975"
#         },
#         {
#             "confidence": 0.0379746835443038,
#             "essence": "metrizoic acid",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33182",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "Pharos",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1736",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:O14746",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1736",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:Q06124",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1736",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:O14746",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:Q06124",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Retinoid X receptors (RXRs) and retinoic acid receptors (RARs) are nuclear receptors that mediate the biological effects of retinoids by their involvement in retinoic acid-mediated gene activation. These receptors function as transcription factors by binding as homodimers or heterodimers to specific sequences in the promoters of target genes. The protein encoded by this gene is a member of the steroid and thyroid hormone receptor superfamily of transcriptional regulators. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, May 2014].",
#                         "id": "UniProtKB:P19793",
#                         "name": "retinoid X receptor alpha",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P19793"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1736",
#                         "name": "metrizoic acid",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1736"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "Telomerase is a ribonucleoprotein polymerase that maintains telomere ends by addition of the telomere repeat TTAGGG. The enzyme consists of a protein component with reverse transcriptase activity, encoded by this gene, and an RNA component which serves as a template for the telomere repeat. Telomerase expression plays a role in cellular senescence, as it is normally repressed in postnatal somatic cells resulting in progressive shortening of telomeres. Deregulation of telomerase expression in somatic cells may be involved in oncogenesis. Studies in mouse suggest that telomerase also participates in chromosomal repair, since de novo synthesis of telomere repeats may occur at double-stranded breaks. Alternatively spliced variants encoding different isoforms of telomerase reverse transcriptase have been identified; the full-length sequence of some variants has not been determined. Alternative splicing at this locus is thought to be one mechanism of regulation of telomerase activity. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O14746",
#                         "name": "telomerase reverse transcriptase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O14746"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a member of the protein tyrosine phosphatase (PTP) family. PTPs are known to be signaling molecules that regulate a variety of cellular processes including cell growth, differentiation, mitotic cycle, and oncogenic transformation. This PTP contains two tandem Src homology-2 domains, which function as phospho-tyrosine binding domains and mediate the interaction of this PTP with its substrates. This PTP is widely expressed in most tissues and plays a regulatory role in various cell signaling events that are important for a diversity of cell functions, such as mitogenic activation, metabolic control, transcription regulation, and cell migration. Mutations in this gene are a cause of Noonan syndrome as well as acute myeloid leukemia. [provided by RefSeq, Aug 2016].",
#                         "id": "UniProtKB:Q06124",
#                         "name": "protein tyrosine phosphatase, non-receptor type 11",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q06124"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "metrizoic acid",
#                 "CHEMBL.COMPOUND:CHEMBL1736",
#                 "0.037975"
#             ],
#             "text": "The chemical_substance metrizoic acid involves similar proteins as Fatigue with similarity value 0.037975"
#         },
#         {
#             "confidence": 0.03278688524590164,
#             "essence": "hydroxyurea",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33183",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "Pharos",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL467",
#                         "target_id": "UniProtKB:P00519",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "Pharos",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL467",
#                         "target_id": "UniProtKB:P23458",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P23458",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A member of the class of ureas that is urea in which one of the hydrogens is replaced by a hydroxy group. An antineoplastic used in the treatment of chronic myeloid leukaemia as well as for sickle-cell disease.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL467",
#                         "name": "hydroxyurea",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL467"
#                     },
#                     {
#                         "description": "This gene is a protooncogene that encodes a protein tyrosine kinase involved in a variety of cellular processes, including cell division, adhesion, differentiation, and response to stress. The activity of the protein is negatively regulated by its SH3 domain, whereby deletion of the region encoding this domain results in an oncogene. The ubiquitously expressed protein has DNA-binding activity that is regulated by CDC2-mediated phosphorylation, suggesting a cell cycle function. This gene has been found fused to a variety of translocation partner genes in various leukemias, most notably the t(9;22) translocation that results in a fusion with the 5' end of the breakpoint cluster region gene (BCR; MIM:151410). Alternative splicing of this gene results in two transcript variants, which contain alternative first exons that are spliced to the remaining common exons. [provided by RefSeq, Aug 2014].",
#                         "id": "UniProtKB:P00519",
#                         "name": "ABL proto-oncogene 1, non-receptor tyrosine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P00519"
#                     },
#                     {
#                         "description": "This gene encodes a membrane protein that is a member of a class of protein-tyrosine kinases (PTK) characterized by the presence of a second phosphotransferase-related domain immediately N-terminal to the PTK domain. The encoded kinase phosphorylates STAT proteins (signal transducers and activators of transcription) and plays a key role in interferon-alpha/beta and interferon-gamma signal transduction. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Mar 2016].",
#                         "id": "UniProtKB:P23458",
#                         "name": "Janus kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P23458"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "hydroxyurea",
#                 "CHEMBL.COMPOUND:CHEMBL467",
#                 "0.032787"
#             ],
#             "text": "The chemical_substance hydroxyurea involves similar proteins as Fatigue with similarity value 0.032787"
#         },
#         {
#             "confidence": 0.02857142857142857,
#             "essence": "trapidil",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33184",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P37023",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL132767",
#                         "target_id": "UniProtKB:P37023",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL132767",
#                         "target_id": "UniProtKB:P04637",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a type I cell-surface receptor for the TGF-beta superfamily of ligands. It shares with other type I receptors a high degree of similarity in serine-threonine kinase subdomains, a glycine- and serine-rich region (called the GS domain) preceding the kinase domain, and a short C-terminal tail. The encoded protein, sometimes termed ALK1, shares similar domain structures with other closely related ALK or activin receptor-like kinase proteins that form a subfamily of receptor serine/threonine kinases. Mutations in this gene are associated with hemorrhagic telangiectasia type 2, also known as Rendu-Osler-Weber syndrome 2. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P37023",
#                         "name": "activin A receptor like type 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P37023"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL132767",
#                         "name": "trapidil",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL132767"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "trapidil",
#                 "CHEMBL.COMPOUND:CHEMBL132767",
#                 "0.028571"
#             ],
#             "text": "The chemical_substance trapidil involves similar proteins as Fatigue with similarity value 0.028571"
#         },
#         {
#             "confidence": 0.02857142857142857,
#             "essence": "triethylenemelamine",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33185",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P42336",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P42336",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL502384",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P15056",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL502384",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Phosphatidylinositol 3-kinase is composed of an 85 kDa regulatory subunit and a 110 kDa catalytic subunit. The protein encoded by this gene represents the catalytic subunit, which uses ATP to phosphorylate PtdIns, PtdIns4P and PtdIns(4,5)P2. This gene has been found to be oncogenic and has been implicated in cervical cancers. A pseudogene of this gene has been defined on chromosome 22. [provided by RefSeq, Apr 2016].",
#                         "id": "UniProtKB:P42336",
#                         "name": "phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P42336"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
# ...
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33195",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL398440",
#                         "target_id": "UniProtKB:P04637",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL398440",
#                         "target_id": "UniProtKB:P00519",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P00519",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A member of the class of phenols that is 3,5-xylenol which is substituted at position 4 by chlorine. It is bactericidal against most Gram-positive bacteria but less effective against Staphylococci and Gram-negative bacteria, and often inactive against Pseudomonas species. It is ineffective against bacterial spores.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL398440",
#                         "name": "chloroxylenol",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL398440"
#                     },
#                     {
#                         "description": "This gene is a protooncogene that encodes a protein tyrosine kinase involved in a variety of cellular processes, including cell division, adhesion, differentiation, and response to stress. The activity of the protein is negatively regulated by its SH3 domain, whereby deletion of the region encoding this domain results in an oncogene. The ubiquitously expressed protein has DNA-binding activity that is regulated by CDC2-mediated phosphorylation, suggesting a cell cycle function. This gene has been found fused to a variety of translocation partner genes in various leukemias, most notably the t(9;22) translocation that results in a fusion with the 5' end of the breakpoint cluster region gene (BCR; MIM:151410). Alternative splicing of this gene results in two transcript variants, which contain alternative first exons that are spliced to the remaining common exons. [provided by RefSeq, Aug 2014].",
#                         "id": "UniProtKB:P00519",
#                         "name": "ABL proto-oncogene 1, non-receptor tyrosine kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P00519"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "chloroxylenol",
#                 "CHEMBL.COMPOUND:CHEMBL398440",
#                 "0.028571"
#             ],
#             "text": "The chemical_substance chloroxylenol involves similar proteins as Fatigue with similarity value 0.028571"
#         },
#         {
#             "confidence": 0.02857142857142857,
#             "essence": "tetrofosmin",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33196",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1615784",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1615784",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P19793",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1615784",
#                         "name": "tetrofosmin",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1615784"
#                     },
#                     {
#                         "description": "Retinoid X receptors (RXRs) and retinoic acid receptors (RARs) are nuclear receptors that mediate the biological effects of retinoids by their involvement in retinoic acid-mediated gene activation. These receptors function as transcription factors by binding as homodimers or heterodimers to specific sequences in the promoters of target genes. The protein encoded by this gene is a member of the steroid and thyroid hormone receptor superfamily of transcriptional regulators. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, May 2014].",
#                         "id": "UniProtKB:P19793",
#                         "name": "retinoid X receptor alpha",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P19793"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "tetrofosmin",
#                 "CHEMBL.COMPOUND:CHEMBL1615784",
#                 "0.028571"
#             ],
#             "text": "The chemical_substance tetrofosmin involves similar proteins as Fatigue with similarity value 0.028571"
#         },
#         {
#             "confidence": 0.02857142857142857,
#             "essence": "trioxsalen",
#             "id": "https://rtx.ncats.io/api/rtx/v1/result/33197",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "UniProtKB:Q92793",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1475",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "ChEMBL",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1475",
#                         "target_id": "UniProtKB:P04637",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:Q92793",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "BioLink",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "HP:0012378",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "7<element>H</element>-Furo[3,2-g]chromen-7-one in which positions 2, 5, and 9 are substituted by methyl groups. Like other psoralens, trioxsalen causes photosensitization of the skin. It is administered orally in conjunction with UV-A for phototherapy treatment of vitiligo. After photoactivation it creates interstrand cross-links in DNA, inhibiting DNA synthesis and cell division, and can lead to cell injury; recovery from the cell injury may be followed by increased melanisation of the epidermis.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1475",
#                         "name": "trioxsalen",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1475"
#                     },
#                     {
#                         "description": "A subjective feeling of tiredness characterized by a lack of energy and motivation.",
#                         "id": "HP:0012378",
#                         "name": "Fatigue",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012378"
#                     },
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     },
#                     {
#                         "description": "This gene is ubiquitously expressed and is involved in the transcriptional coactivation of many different transcription factors. First isolated as a nuclear protein that binds to cAMP-response element binding protein (CREB), this gene is now known to play critical roles in embryonic development, growth control, and homeostasis by coupling chromatin remodeling to transcription factor recognition. The protein encoded by this gene has intrinsic histone acetyltransferase activity and also acts as a scaffold to stabilize additional protein interactions with the transcription complex. This protein acetylates both histone and non-histone proteins. This protein shares regions of very high sequence similarity with protein p300 in its bromodomain, cysteine-histidine-rich regions, and histone acetyltransferase domain. Mutations in this gene cause Rubinstein-Taybi syndrome (RTS). Chromosomal translocations involving this gene have been associated with acute myeloid leukemia. Alternative splicing results in multiple transcript variants encoding different isoforms. [provided by RefSeq, Feb 2009].",
#                         "id": "UniProtKB:Q92793",
#                         "name": "CREB binding protein",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92793"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fatigue",
#                 "HP:0012378",
#                 "trioxsalen",
#                 "CHEMBL.COMPOUND:CHEMBL1475",
#                 "0.028571"
#             ],
#             "text": "The chemical_substance trioxsalen involves similar proteins as Fatigue with similarity value 0.028571"
#         }
#     ],
#     "schema_version": "0.5",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID",
#         "Jaccard index"
#     ],
#     "terms": {
#         "phenotypic_feature": "HP:0012378"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
