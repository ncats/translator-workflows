# %% [markdown]
# # Workflow 1, Module 1, Question 1

# %% [markdown]
# ## What are the defining symptoms / phenotypes of [condition x]?

# %% [markdown]
# ### Approach 1:  Expand

# %% [markdown]
# ROBOKOP expand will return all phenotypes associated with a condition, ranked using its normal algorithm.  It is then up to the user to set a threshhold on how many of these symptoms are interesting/acceptable.

# %%
import requests
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://robokop.renci.org:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %% [markdown]
# Note that here we are returning a simple format of the output for display.  To get the identifiers it may be more useful to call with csv = False and parse the result

# %%
diabetes = 'MONDO:0005148' #type 2 diabetes
diabetes_phenotypes = expand('disease',diabetes,'phenotypic_feature',csv=True)
n = 20
print( f"Returned {len(diabetes_phenotypes)} phenotypes" )
print( f"Top {n}:")
diabetes_phenotypes[:20]
# Out:
# Return Status: 200
# Returned 194 phenotypes
# Top 20:
# ['Maturity-onset diabetes of the young(HP:0004904)',
#  'Recurrent hypoglycemia(HP:0001988)',
#  'Glucose intolerance(HP:0000833)',
#  'Beta-cell dysfunction(HP:0006279)',
#  'Hyperinsulinemia(HP:0000842)',
#  'Increased adipose tissue(HP:0009126)',
#  'Decreased HDL cholesterol concentration(HP:0003233)',
#  'Maternal diabetes(HP:0009800)',
#  'Acanthosis nigricans(HP:0000956)',
#  'Insulin-resistant diabetes mellitus(HP:0000831)',
#  'Hyperglycemia(HP:0003074)',
#  'Ketoacidosis(HP:0001993)',
#  'Accelerated atherosclerosis(HP:0004943)',
#  'Hypoglycemia(HP:0001943)',
#  'Type I diabetes mellitus(HP:0100651)',
#  'Fasting hyperinsulinemia(HP:0008283)',
#  'Hypertriglyceridemia(HP:0002155)',
#  'Glycosuria(HP:0003076)',
#  'Increased body weight(HP:0004324)',
#  'Diabetic ketoacidosis(HP:0001953)']

# %%
asthma = 'MONDO:0004979' #Asthma
asthma_phenotypes = expand('disease',asthma,'phenotypic_feature',csv=True)
n = 20
print( f"Returned {len(asthma_phenotypes)} phenotypes" )
print( f"Top {n}:")
asthma_phenotypes[:20]
# Out:
# Return Status: 200
# Returned 128 phenotypes
# Top 20:
# ['Exercise-induced asthma(HP:0012652)',
#  'Allergic rhinitis(HP:0003193)',
#  'Obstructive lung disease(HP:0006536)',
#  'Status asthmaticus(HP:0012653)',
#  'Increased IgE level(HP:0003212)',
#  'Chronic bronchitis(HP:0004469)',
#  'Chronic rhinitis(HP:0002257)',
#  'Nasal polyposis(HP:0100582)',
#  'Allergic conjunctivitis(HP:0007879)',
#  'Bronchiolitis(HP:0011950)',
#  'Asthma(HP:0002099)',
#  'Eosinophilia(HP:0001880)',
#  'Eczema(HP:0000964)',
#  'Hypersensitivity pneumonitis(HP:0006516)',
#  'Recurrent respiratory infections(HP:0002205)',
#  'Chronic sinusitis(HP:0011109)',
#  'Atopic dermatitis(HP:0001047)',
#  'Bronchiectasis(HP:0002110)',
#  'IgE deficiency(HP:0005479)',
#  'Recurrent bronchitis(HP:0002837)']

# %% [markdown]
# ### Approach 2: Enriched Expansion (No Descendants)

# %% [markdown]
# Here we will start with a condition and find phenotypes that have a high enrichment factor.  That is, they are linked to the condition at a higher rate than might be expected.  Given that we are doing enrichment with a single input, we're really finding the phenotypes that are linked specifically to this condition.

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
enriched_diabetes_phenotypes = enrichment('disease',[diabetes],'phenotypic_feature')
pd.DataFrame(enriched_diabetes_phenotypes)
# Out:
# Return Status: 200
#             id                                          name         p
# 0   HP:0000745                         Diminished motivation  0.002678
# 1   HP:0005974                         Episodic ketoacidosis  0.004603
# 2   HP:0006279                         Beta-cell dysfunction  0.005691
# 3   HP:0100739                                       Bulimia  0.005859
# 4   HP:0008711                  Benign prostatic hyperplasia  0.006361
# 5   HP:0001993                                  Ketoacidosis  0.008704
# 6   HP:0001095                      Hypertensive retinopathy  0.008955
# 7   HP:0009126                      Increased adipose tissue  0.009123
# 8   HP:0004904          Maturity-onset diabetes of the young  0.009960
# 9   HP:0008887                           Adipose tissue loss  0.009960
# 10  HP:0001950                         Respiratory alkalosis  0.010127
# 11  HP:0012605                                Hypernatriuria  0.010462
# 12  HP:0007485                   Absence of subcutaneous fat  0.010713
# 13  HP:0008283                      Fasting hyperinsulinemia  0.010964
# 14  HP:0009059          Congenital generalized lipodystrophy  0.011215
# 15  HP:0001325                             Hypoglycemic coma  0.012805
# 16  HP:0002189                  Excessive daytime sleepiness  0.013642
# 17  HP:0001946                                       Ketosis  0.014814
# 18  HP:0100546                       Carotid artery stenosis  0.015065
# 19  HP:0004417                     Intermittent claudication  0.015567
# 20  HP:0004943                   Accelerated atherosclerosis  0.016070
# 21  HP:0002578                                 Gastroparesis  0.016153
# 22  HP:0003233       Decreased HDL cholesterol concentration  0.017409
# 23  HP:0005202                 Helicobacter pylori infection  0.017576
# 24  HP:0002634                              Arteriosclerosis  0.018581
# 25  HP:0001988                        Recurrent hypoglycemia  0.018832
# 26  HP:0000166                          Severe periodontitis  0.019250
# 27  HP:0002153                                  Hyperkalemia  0.019669
# 28  HP:0011106                                   Hypovolemia  0.020338
# 29  HP:0004950                  Peripheral arterial stenosis  0.021008
# ..         ...                                           ...       ...
# 66  HP:0001959                                    Polydipsia  0.036659
# 67  HP:0002181                                Cerebral edema  0.036826
# 68  HP:0002140                               Ischemic stroke  0.036994
# 69  HP:0001677               Coronary artery atherosclerosis  0.037245
# 70  HP:0006510         Chronic obstructive pulmonary disease  0.038082
# 71  HP:0000147                            Polycystic ovaries  0.038919
# 72  HP:0000103                                      Polyuria  0.039002
# 73  HP:0000802                                     Impotence  0.040007
# 74  HP:0002870                       Obstructive sleep apnea  0.041095
# 75  HP:0002900                                   Hypokalemia  0.041346
# 76  HP:0002150                                Hypercalciuria  0.041681
# 77  HP:0100710                                   Impulsivity  0.041932
# 78  HP:0010535                                   Sleep apnea  0.041932
# 79  HP:0000956                          Acanthosis nigricans  0.042266
# 80  HP:0003074                                 Hyperglycemia  0.042936
# 81  HP:0100753                                 Schizophrenia  0.043187
# 82  HP:0012622                        Chronic kidney disease  0.043522
# 83  HP:0002894                      Neoplasm of the pancreas  0.043773
# 84  HP:0001695                                Cardiac arrest  0.044777
# 85  HP:0000704                                 Periodontitis  0.046200
# 86  HP:0100820                                Glomerulopathy  0.046368
# 87  HP:0002788  Recurrent upper respiratory tract infections  0.046451
# 88  HP:0100724                            Hypercoagulability  0.046702
# 89  HP:0100598                               Pulmonary edema  0.046953
# 90  HP:0002459                                  Dysautonomia  0.047121
# 91  HP:0000712                            Emotional lability  0.047456
# 92  HP:0003003                                  Colon cancer  0.047539
# 93  HP:0003128                               Lactic acidosis  0.048627
# 94  HP:0001081                                Cholelithiasis  0.049130
# 95  HP:0002155                          Hypertriglyceridemia  0.049464
#
# [96 rows x 3 columns]

# %%
enriched_asthma_phenotypes = enrichment('disease',[asthma],'phenotypic_feature')
pd.DataFrame(enriched_asthma_phenotypes)
# Out:
# Return Status: 200
#             id                                          name         p
# 0   HP:0012652                       Exercise-induced asthma  0.000335
# 1   HP:0012653                            Status asthmaticus  0.000418
# 2   HP:0010865                 Oppositional defiant disorder  0.005775
# 3   HP:0007879                       Allergic conjunctivitis  0.008704
# 4   HP:0002257                              Chronic rhinitis  0.010211
# 5   HP:0005943                            Respiratory arrest  0.010546
# 6   HP:0001686                                 Loss of voice  0.011215
# 7   HP:0005972                          Respiratory acidosis  0.011550
# 8   HP:0100033                                          Tics  0.012136
# 9   HP:0100845                            Anaphylactic shock  0.013308
# 10  HP:0002913                                 Myoglobinuria  0.014647
# 11  HP:0003750                Increased muscle fatiguability  0.017492
# 12  HP:0000711                                  Restlessness  0.017995
# 13  HP:0005479                                IgE deficiency  0.017995
# 14  HP:0002783  Recurrent lower respiratory tract infections  0.018915
# 15  HP:0003261                           Increased IgA level  0.021259
# 16  HP:0100582                               Nasal polyposis  0.021761
# 17  HP:0003193                             Allergic rhinitis  0.021761
# 18  HP:0100665                                    Angioedema  0.021845
# 19  HP:0011109                             Chronic sinusitis  0.022598
# 20  HP:0006516                  Hypersensitivity pneumonitis  0.022933
# 21  HP:0003237                           Increased IgG level  0.023686
# 22  HP:0002837                          Recurrent bronchitis  0.023853
# 23  HP:0002883                              Hyperventilation  0.025276
# 24  HP:0004469                            Chronic bronchitis  0.025778
# 25  HP:0003201                                Rhabdomyolysis  0.027787
# 26  HP:0006536                      Obstructive lung disease  0.029377
# 27  HP:0003212                           Increased IgE level  0.030716
# 28  HP:0003712                   Skeletal muscle hypertrophy  0.031470
# 29  HP:0000751                           Personality changes  0.033311
# 30  HP:0011950                                 Bronchiolitis  0.034901
# 31  HP:0007302                    Bipolar affective disorder  0.035236
# 32  HP:0100827                                 Lymphocytosis  0.035822
# 33  HP:0006510         Chronic obstructive pulmonary disease  0.038082
# 34  HP:0002310                          Orofacial dyskinesia  0.038500
# 35  HP:0001742                             Nasal obstruction  0.039588
# 36  HP:0001047                             Atopic dermatitis  0.040509
# 37  HP:0002870                       Obstructive sleep apnea  0.041095
# 38  HP:0000388                                  Otitis media  0.041430
# 39  HP:0100710                                   Impulsivity  0.041932
# 40  HP:0010535                                   Sleep apnea  0.041932
# 41  HP:0002843                    Abnormal T cell morphology  0.042936
# 42  HP:0006528                          Chronic lung disease  0.043103
# 43  HP:0100753                                 Schizophrenia  0.043187
# 44  HP:0001962                                  Palpitations  0.044610
# 45  HP:0001695                                Cardiac arrest  0.044777
# 46  HP:0001618                                     Dysphonia  0.045949
# 47  HP:0002133                            Status epilepticus  0.046284
# 48  HP:0002788  Recurrent upper respiratory tract infections  0.046451
# 49  HP:0002110                                Bronchiectasis  0.047623
# 50  HP:0003128                               Lactic acidosis  0.048627

# %% [markdown]
# ### Approach 3: Enriched Expansion with Descendants

# %% [markdown]
# Sometimes it can be useful to enrich on a larger set of inputs.  We use the descendents of the input condition to generate an input set here.

# %%
desc_enriched_diabetes_phenotypes = enrichment('disease',[diabetes],'phenotypic_feature',include_descendants=True)
pd.DataFrame(desc_enriched_diabetes_phenotypes)
# Out:
# Return Status: 200
#             id                                  name         p
# 0   HP:0004904  Maturity-onset diabetes of the young  0.000004
# 1   HP:0000831   Insulin-resistant diabetes mellitus  0.000104
# 2   HP:0005974                 Episodic ketoacidosis  0.000124
# 3   HP:0006279                 Beta-cell dysfunction  0.000190
# 4   HP:0003074                         Hyperglycemia  0.000305
# 5   HP:0001993                          Ketoacidosis  0.000445
# 6   HP:0100651              Type I diabetes mellitus  0.000505
# 7   HP:0008887                   Adipose tissue loss  0.000583
# 8   HP:0001950                 Respiratory alkalosis  0.000602
# 9   HP:0007485           Absence of subcutaneous fat  0.000674
# 10  HP:0009059  Congenital generalized lipodystrophy  0.000738
# 11  HP:0001397                     Hepatic steatosis  0.000740
# 12  HP:0001325                     Hypoglycemic coma  0.000961
# 13  HP:0001946                               Ketosis  0.001284
# 14  HP:0001988                Recurrent hypoglycemia  0.002066
# 15  HP:0002153                          Hyperkalemia  0.002252
# 16  HP:0011106                           Hypovolemia  0.002406
# 17  HP:0001953                 Diabetic ketoacidosis  0.002605
# 18  HP:0100578                           Lipoatrophy  0.003989
# 19  HP:0003201                        Rhabdomyolysis  0.004451
# 20  HP:0003076                            Glycosuria  0.005361
# 21  HP:0001513                               Obesity  0.005572
# 22  HP:0001735                    Acute pancreatitis  0.005682
# 23  HP:0003712           Skeletal muscle hypertrophy  0.005682
# 24  HP:0000819                     Diabetes mellitus  0.005872
# 25  HP:0002574               Episodic abdominal pain  0.006320
# 26  HP:0002148                      Hypophosphatemia  0.006320
# 27  HP:0009800                     Maternal diabetes  0.007056
# 28  HP:0000842                      Hyperinsulinemia  0.007222
# 29  HP:0001959                            Polydipsia  0.007659
# ..         ...                                   ...       ...
# 36  HP:0100598                       Pulmonary edema  0.012396
# 37  HP:0003128                       Lactic acidosis  0.013266
# 38  HP:0002155                  Hypertriglyceridemia  0.013711
# 39  HP:0000855                    Insulin resistance  0.014576
# 40  HP:0003077                        Hyperlipidemia  0.014668
# 41  HP:0005978             Type II diabetes mellitus  0.015370
# 42  HP:0011947           Respiratory tract infection  0.016671
# 43  HP:0004395                          Malnutrition  0.017215
# 44  HP:0003560                    Muscular dystrophy  0.019209
# 45  HP:0001944                           Dehydration  0.021909
# 46  HP:0100739                               Bulimia  0.023233
# 47  HP:0001941                              Acidosis  0.023262
# 48  HP:0002344  Progressive neurologic deterioration  0.023722
# 49  HP:0001259                                  Coma  0.025064
# 50  HP:0008711          Benign prostatic hyperplasia  0.025205
# 51  HP:0001254                              Lethargy  0.028470
# 52  HP:0002018                                Nausea  0.028470
# 53  HP:0001658                 Myocardial infarction  0.028533
# 54  HP:0001433                    Hepatosplenomegaly  0.032597
# 55  HP:0001943                          Hypoglycemia  0.032597
# 56  HP:0001095              Hypertensive retinopathy  0.035348
# 57  HP:0000479           Abnormal retinal morphology  0.035715
# 58  HP:0009126              Increased adipose tissue  0.036000
# 59  HP:0002615                           Hypotension  0.038812
# 60  HP:0000246                             Sinusitis  0.039676
# 61  HP:0012605                        Hypernatriuria  0.041201
# 62  HP:0002039                              Anorexia  0.041946
# 63  HP:0008283              Fasting hyperinsulinemia  0.043146
# 64  HP:0001733                          Pancreatitis  0.045797
# 65  HP:0000077             Abnormality of the kidney  0.048997
#
# [66 rows x 3 columns]

# %%
desc_enriched_asthma_phenotypes = enrichment('disease',[asthma],'phenotypic_feature',include_descendants=True)
pd.DataFrame(desc_enriched_asthma_phenotypes)
# Out:
# Return Status: 200
#             id                                   name             p
# 0   HP:0012653                     Status asthmaticus  4.202662e-07
# 1   HP:0005943                     Respiratory arrest  3.287244e-04
# 2   HP:0005972                   Respiratory acidosis  3.943284e-04
# 3   HP:0002099                                 Asthma  5.570363e-04
# 4   HP:0002913                          Myoglobinuria  6.337839e-04
# 5   HP:0003750         Increased muscle fatiguability  9.030892e-04
# 6   HP:0012652                Exercise-induced asthma  1.004100e-03
# 7   HP:0004469                     Chronic bronchitis  1.953331e-03
# 8   HP:0003201                         Rhabdomyolysis  2.267048e-03
# 9   HP:0011950                          Bronchiolitis  3.561395e-03
# 10  HP:0001695                         Cardiac arrest  5.825700e-03
# 11  HP:0003128                        Lactic acidosis  6.853409e-03
# 12  HP:0002107                           Pneumothorax  7.469854e-03
# 13  HP:0100750                            Atelectasis  8.493769e-03
# 14  HP:0011947            Respiratory tract infection  8.648907e-03
# 15  HP:0002097                              Emphysema  9.309804e-03
# 16  HP:0001941                               Acidosis  1.215460e-02
# 17  HP:0001880                           Eosinophilia  1.221579e-02
# 18  HP:0001259                                   Coma  1.311940e-02
# 19  HP:0003236  Elevated serum creatine phosphokinase  1.525552e-02
# 20  HP:0010865          Oppositional defiant disorder  1.722665e-02
# 21  HP:0002615                            Hypotension  2.056428e-02
# 22  HP:0003198                               Myopathy  2.215869e-02
# 23  HP:0003470                              Paralysis  2.228051e-02
# 24  HP:0007879                Allergic conjunctivitis  2.588867e-02
# 25  HP:0003115                           Abnormal EKG  2.899333e-02
# 26  HP:0002257                       Chronic rhinitis  3.032353e-02
# 27  HP:0002090                              Pneumonia  3.282294e-02
# 28  HP:0001686                          Loss of voice  3.327262e-02
# 29  HP:0100033                                   Tics  3.597069e-02
# 30  HP:0002527                                  Falls  3.722808e-02
# 31  HP:0001337                                 Tremor  3.805602e-02
# 32  HP:0000737                           Irritability  3.842083e-02
# 33  HP:0100845                     Anaphylactic shock  3.939733e-02
# 34  HP:0002835                             Aspiration  4.661260e-02
