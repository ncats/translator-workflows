# %% [markdown]
# # Extract PTSD-related Dense Dynamic Data Cloud using Blackboard
#
# ## John C. Earls (ISB)
# ## Chunhua Weng, Chi Yuan,Barnett Chiu, Sunny Shang, James J. Cimino(Columbia)
# ## Mike Yu (UCSD)
# ## Ken Gersing, Rajarshi Guha, Mark Williams (NCATS)
#
#
# **APIs used**:
# * http://isbtranslatorapi.adversary.us/
# * http://www.ndexbio.org/
# * http://biothings.io/
#
#
# **Preconditions**:
# * The problem of understanding PTSD has been posed to the blackboard.
# * Some text based knowledge source has proposed that Thyroxine is a key driver of cardiac related pathologies associated with PTSD based on this pnas paper http://www.pnas.org/content/111/8/3188.full performed on mouse models:
#
# > **Thyroxine**, an important signaling molecule, affects an array of cardiovascular activities. Elevating the Thyroxine level in the heart causes vasodilation and an increase in heart rate (33). Thyroxine has been implicated in the initial injury process, because it is a well-known signaling molecule for stress and tissue injury (34⇓–36). From this study, we observed a gradual increase in the Thyroxine deaminase transcript level (peaking in the T3R1 group). This observation may imply a compensatory process in heart tissue to reduce the Thyroxine level after the tissue is in the wound-healing stage
#
# * The blue team recognizes this beacon as a request to contextualize Thyroxine using Dense Dynamic Data Clouds
#
# **Blackboard steps performed**:
# * Create seeds from *Thyroxine*
# * Query HPWP API for Thyroxine specific subnetwork
# * Write Thyroxine specific subnetwork back to blackboard
# * NDEx imports network from blackboard
# * Some service calculates enrichment for certain metabolic pathways and returns to blackboard
# * Some service suggests using correlated Clinical Labs as features for PTSD biomarker

# %%
import urllib2
import json
import requests
import logging
import pandas
from collections import Counter
logging.basicConfig(level=logging.WARNING,
                    format='%(asctime)s %(levelname)s %(message)s',)

#Some helper query functions to API
base_url = 'http://isbtranslatorapi.adversary.us'
def query_isb(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    return req.json()

def get_analytes(kwargs):
    kw_local = kwargs.copy()
    frm = 0
    size = 1000
    meta = []
    kw_local['from'] = frm
    kw_local['size'] = size
    res = query_isb('/v1/analyte', data=kw_local)
    meta += res
    # Note: this is relying on the pagination, it would be smarter to just partition
    # the *sig_ids* set which would greatly speed up the query
    while len(res) > 0:
        kw_local['from'] += size
        logging.debug("Saving records from %i to %i" %(frm, frm+size))
        res = query_isb('/v1/analyte', data=kw_local)
        meta+=res
    return meta

# %% [markdown]
# ### The data service identifies a set of metabolites in the DDDC which contain adenosine

# %%
clin_vars = get_analytes({'category':"Metabolites"})
thyroxine = [x['_id'] for x in clin_vars if x['_id'].find('thyroxine') >-1]
for met in thyroxine:
    print met
# Out:
# METAB.None.amino-acid.phenylalanine-and-tyrosine-metabolism.thyroxine

# %% [markdown]
# ### The data service queries the correlation network from the Hundred Person Wellness Project for analytes related to these seeds

# %%
def get_correlations(kwargs):
    kw_local = kwargs.copy()
    sigs = []
    frm = 0
    size = 10000
    meta = []
    kw_local['from'] = frm
    kw_local['size'] = size
    res = query_isb('v1/correlation', data=kw_local)
    correlations = res[:]
    while len(res) > 0:
        logging.debug("Saving records from %i to %i" %(frm, frm+size))
        kw_local['from'] += size
        frm = kw_local['from']
        res = query_isb('v1/correlation', data=kw_local)
        correlations += res
    return correlations
# get correlation network based on seed network
acorr = get_correlations({'ids1':','.join(thyroxine)})
adf = pandas.DataFrame(acorr)
sig_adf = adf[adf.bh_adjusted_pvalue < .1]
nodes = set(sig_adf._id_1.tolist() + sig_adf._id_2.tolist())
my_nodes = {a['_id']: a for a in get_analytes({'ids':','.join(nodes)})}
num_edges = len(sig_adf)
print "%i edges in HPWP in thyroxine seeded network." % (num_edges,)
num_nodes = len(my_nodes)
print "%i total nodes in HPWP thyroxine seeded subnetwork" % (num_nodes,)
for k, v in Counter([v['category'] for v in my_nodes.values()]).items():
    print "%i %s in HPWP Adenosine seeded network" % (v, k)
# Out:
# 51 edges in HPWP in thyroxine seeded network.
# 52 total nodes in HPWP thyroxine seeded subnetwork
# 46 Metabolites in HPWP Adenosine seeded network
# 6 Clinical Labs in HPWP Adenosine seeded network

# %% [markdown]
# ### The data service writes the HPWP seeded subnetwork back to the blackboard and is recognized by UCSD's NDEx service as consumable
#
# NDEx service ingests correlation network and generates an NDEx network object that is further computed on and produces a visualization.
#
# see : http://www.ndexbio.org/#/newNetwork/88fd2073-35c1-11e7-8f50-0ac135e8bacf

# %%
rec = sig_adf.to_dict('records')
json.dump(rec, open('thyroxine_sig_edges.json', 'w'))

# %% [markdown]
# ### Some data source performs basic metabolic pathway enrichment on adenisine seeded HPWP correlation network and returns results to blackboard

# %%
import scipy.stats
super_pathways_condition = []
for k, v in my_nodes.items():
    if 'super_pathway' in v:
        super_pathways_condition.append(v['super_pathway'])
spc = Counter(super_pathways_condition)
super_pathways_background = []
for v in clin_vars:
    super_pathways_background.append(v['super_pathway'])
spb = Counter(super_pathways_background)
df = pandas.DataFrame([spc, spb], index=['Thyroxine-seeded HPWP', 'Total HPWP']).fillna(0.0)
perc = (df.iloc[0]/df.iloc[1])*100
perc.name = "Percent"
df = df.append(perc)
s = df.sum(axis=1)
not_ashpwp_total = s['Total HPWP'] - s['Thyroxine-seeded HPWP']
odr = {}
pv = {}
for c in df.columns:
    ct = [[df.loc['Thyroxine-seeded HPWP',c],  df.loc['Total HPWP',c]-df.loc['Thyroxine-seeded HPWP',c]],
          [s['Thyroxine-seeded HPWP'], not_ashpwp_total]
    ]
    res = scipy.stats.fisher_exact(ct)
    odr[c] = res[0]
    pv[c] = res[1]
df = df.append(pandas.Series(odr, name="Fisher OR"))
df = df.append(pandas.Series(pv, name="Fisher p-value"))
df.transpose().sort_values("Fisher p-value")
# Out:
#                         Thyroxine-seeded HPWP  Total HPWP    Percent  \
# lipid                                    41.0       252.0  16.269841
# amino-acid                                2.0       156.0   1.282051
# xenobiotics                               2.0        91.0   2.197802
# cofactors-and-vitamins                    0.0        24.0   0.000000
# peptide                                   0.0        27.0   0.000000
# carbohydrate                              0.0        18.0   0.000000
# nucleotide                                1.0        32.0   3.125000
# energy                                    0.0         7.0   0.000000
#
#                         Fisher OR  Fisher p-value
# lipid                    2.369771        0.000265
# amino-acid               0.158385        0.002480
# xenobiotics              0.274060        0.072539
# cofactors-and-vitamins   0.000000        0.246258
# peptide                  0.000000        0.249249
# carbohydrate             0.000000        0.387358
# nucleotide               0.393408        0.501928
# energy                   0.000000        1.000000

# %%
import scipy.stats
super_pathways_condition = []
for k, v in my_nodes.items():
    if 'sub_pathway' in v:
        super_pathways_condition.append(v['sub_pathway'])
spc = Counter(super_pathways_condition)
super_pathways_background = []
for v in clin_vars:
    super_pathways_background.append(v['sub_pathway'])
spb = Counter(super_pathways_background)
df = pandas.DataFrame([spc, spb], index=['Thyroxine-seeded HPWP', 'Total HPWP']).fillna(0)
df = df.fillna(0.0)
perc = (df.iloc[0]/df.iloc[1])*100
perc.name = "Percent"
df = df.append(perc)
s = df.sum(axis=1)
not_ashpwp_total = s['Total HPWP'] - s['Thyroxine-seeded HPWP']
odr = {}
pv = {}
for c in df.columns:
    ct = [[df.loc['Thyroxine-seeded HPWP',c],  df.loc['Total HPWP',c]-df.loc['Thyroxine-seeded HPWP',c]],
          [s['Thyroxine-seeded HPWP'], not_ashpwp_total]
    ]
    res = scipy.stats.fisher_exact(ct)
    odr[c] = res[0]
    pv[c] = res[1]
df = df.append(pandas.Series(odr, name="Fisher OR"))
df = df.append(pandas.Series(pv, name="Fisher p-value"))
df.transpose().sort_values('Fisher p-value')
# Out:
#                                                     Thyroxine-seeded HPWP  \
# lysolipid                                                            16.0
# fatty-acid-metabolism(acyl-carnitine)                                 9.0
# polyunsaturated-fatty-acid-(n3-and-n6)                                3.0
# fatty-acid,-monohydroxy                                               3.0
# phospholipid-metabolism                                               2.0
# quantitative-total-fatty-acid                                         1.0
# sterol                                                                1.0
# pyrimidine-metabolism,-cytidine-containing                            1.0
# steroid                                                               0.0
# sphingolipid-metabolism                                               2.0
# endocannabinoid                                                       1.0
# leucine,-isoleucine-and-valine-metabolism                             0.0
# chemical                                                              0.0
# primary-bile-acid-metabolism                                          1.0
# food-component/plant                                                  1.0
# mole-%-total-fatty-acid                                               1.0
# drug                                                                  1.0
# gamma-glutamyl-amino-acid                                             0.0
# xanthine-metabolism                                                   0.0
# methionine,-cysteine,-sam-and-taurine-metabolism                      0.0
# urea-cycle;-arginine-and-proline-metabolism                           0.0
# benzoate-metabolism                                                   0.0
# phenylalanine-and-tyrosine-metabolism                                 1.0
# monoacylglycerol                                                      0.0
# nicotinate-and-nicotinamide-metabolism                                0.0
# tryptophan-metabolism                                                 1.0
# oxidative-phosphorylation                                             0.0
# pantothenate-and-coa-metabolism                                       0.0
# pentose-metabolism                                                    0.0
# tocopherol-metabolism                                                 0.0
# ...                                                                   ...
# aminosugar-metabolism                                                 0.0
# ascorbate-and-aldarate-metabolism                                     0.0
# bacterial/fungal                                                      0.0
# carnitine-metabolism                                                  0.0
# creatine-metabolism                                                   0.0
# dipeptide                                                             0.0
# dipeptide-derivative                                                  0.0
# fatty-acid,-amide                                                     0.0
# fatty-acid,-amino                                                     0.0
# fatty-acid,-branched                                                  0.0
# fatty-acid,-dicarboxylate                                             0.0
# fatty-acid-metabolism(acyl-glycine)                                   0.0
# fatty-acid-metabolism-(also-bcaa-metabolism)                          0.0
# mevalonate-metabolism                                                 0.0
# fatty-acid-synthesis                                                  0.0
# fructose,-mannose-and-galactose-metabolism                            0.0
# glutamate-metabolism                                                  0.0
# glutathione-metabolism                                                0.0
# glycerolipid-metabolism                                               0.0
# glycine,-serine-and-threonine-metabolism                              0.0
# glycolysis,-gluconeogenesis,-and-pyruvate-metab...                    0.0
# guanidino-and-acetamido-metabolism                                    0.0
# hemoglobin-and-porphyrin-metabolism                                   0.0
# histidine-metabolism                                                  0.0
# inositol-metabolism                                                   0.0
# ketone-bodies                                                         0.0
# vitamin-b6-metabolism                                                 0.0
# lysine-metabolism                                                     0.0
# fibrinogen-cleavage-peptide                                           0.0
# long-chain-fatty-acid                                                 1.0
#
#                                                     Total HPWP     Percent  \
# lysolipid                                                 40.0   40.000000
# fatty-acid-metabolism(acyl-carnitine)                     14.0   64.285714
# polyunsaturated-fatty-acid-(n3-and-n6)                    11.0   27.272727
# fatty-acid,-monohydroxy                                   11.0   27.272727
# phospholipid-metabolism                                    6.0   33.333333
# quantitative-total-fatty-acid                              1.0  100.000000
# sterol                                                     2.0   50.000000
# pyrimidine-metabolism,-cytidine-containing                 2.0   50.000000
# steroid                                                   33.0    0.000000
# sphingolipid-metabolism                                   11.0   18.181818
# endocannabinoid                                            3.0   33.333333
# leucine,-isoleucine-and-valine-metabolism                 29.0    0.000000
# chemical                                                  18.0    0.000000
# primary-bile-acid-metabolism                               7.0   14.285714
# food-component/plant                                      32.0    3.125000
# mole-%-total-fatty-acid                                   32.0    3.125000
# drug                                                       9.0   11.111111
# gamma-glutamyl-amino-acid                                 13.0    0.000000
# xanthine-metabolism                                       15.0    0.000000
# methionine,-cysteine,-sam-and-taurine-metabolism          15.0    0.000000
# urea-cycle;-arginine-and-proline-metabolism               15.0    0.000000
# benzoate-metabolism                                       16.0    0.000000
# phenylalanine-and-tyrosine-metabolism                     28.0    3.571429
# monoacylglycerol                                          10.0    0.000000
# nicotinate-and-nicotinamide-metabolism                     5.0    0.000000
# tryptophan-metabolism                                     18.0    5.555556
# oxidative-phosphorylation                                  1.0    0.000000
# pantothenate-and-coa-metabolism                            1.0    0.000000
# pentose-metabolism                                         6.0    0.000000
# tocopherol-metabolism                                      7.0    0.000000
# ...                                                        ...         ...
# aminosugar-metabolism                                      3.0    0.000000
# ascorbate-and-aldarate-metabolism                          3.0    0.000000
# bacterial/fungal                                           1.0    0.000000
# carnitine-metabolism                                       2.0    0.000000
# creatine-metabolism                                        3.0    0.000000
# dipeptide                                                  6.0    0.000000
# dipeptide-derivative                                       1.0    0.000000
# fatty-acid,-amide                                          3.0    0.000000
# fatty-acid,-amino                                          2.0    0.000000
# fatty-acid,-branched                                       3.0    0.000000
# fatty-acid,-dicarboxylate                                 12.0    0.000000
# fatty-acid-metabolism(acyl-glycine)                        3.0    0.000000
# fatty-acid-metabolism-(also-bcaa-metabolism)               3.0    0.000000
# mevalonate-metabolism                                      1.0    0.000000
# fatty-acid-synthesis                                       2.0    0.000000
# fructose,-mannose-and-galactose-metabolism                 4.0    0.000000
# glutamate-metabolism                                       6.0    0.000000
# glutathione-metabolism                                     3.0    0.000000
# glycerolipid-metabolism                                    2.0    0.000000
# glycine,-serine-and-threonine-metabolism                   8.0    0.000000
# glycolysis,-gluconeogenesis,-and-pyruvate-metab...         5.0    0.000000
# guanidino-and-acetamido-metabolism                         2.0    0.000000
# hemoglobin-and-porphyrin-metabolism                        6.0    0.000000
# histidine-metabolism                                      10.0    0.000000
# inositol-metabolism                                        2.0    0.000000
# ketone-bodies                                              2.0    0.000000
# vitamin-b6-metabolism                                      1.0    0.000000
# lysine-metabolism                                         10.0    0.000000
# fibrinogen-cleavage-peptide                                2.0    0.000000
# long-chain-fatty-acid                                     15.0    6.666667
#
#                                                     Fisher OR  Fisher p-value
# lysolipid                                            8.130435    8.139297e-08
# fatty-acid-metabolism(acyl-carnitine)               21.952174    2.510230e-07
# polyunsaturated-fatty-acid-(n3-and-n6)               4.573370    4.916191e-02
# fatty-acid,-monohydroxy                              4.573370    4.916191e-02
# phospholipid-metabolism                              6.097826    7.353896e-02
# quantitative-total-fatty-acid                             inf    7.730263e-02
# sterol                                              12.195652    1.485124e-01
# pyrimidine-metabolism,-cytidine-containing          12.195652    1.485124e-01
# steroid                                              0.000000    1.592649e-01
# sphingolipid-metabolism                              2.710145    2.076860e-01
# endocannabinoid                                      6.097826    2.141189e-01
# leucine,-isoleucine-and-valine-metabolism            0.000000    2.575609e-01
# chemical                                             0.000000    3.873578e-01
# primary-bile-acid-metabolism                         2.032609    4.289654e-01
# food-component/plant                                 0.393408    5.019283e-01
# mole-%-total-fatty-acid                              0.393408    5.019283e-01
# drug                                                 1.524457    5.128450e-01
# gamma-glutamyl-amino-acid                            0.000000    6.133778e-01
# xanthine-metabolism                                  0.000000    6.174898e-01
# methionine,-cysteine,-sam-and-taurine-metabolism     0.000000    6.174898e-01
# urea-cycle;-arginine-and-proline-metabolism          0.000000    6.174898e-01
# benzoate-metabolism                                  0.000000    6.221152e-01
# phenylalanine-and-tyrosine-metabolism                0.451691    7.134222e-01
# monoacylglycerol                                     0.000000    1.000000e+00
# nicotinate-and-nicotinamide-metabolism               0.000000    1.000000e+00
# tryptophan-metabolism                                0.717391    1.000000e+00
# oxidative-phosphorylation                            0.000000    1.000000e+00
# pantothenate-and-coa-metabolism                      0.000000    1.000000e+00
# pentose-metabolism                                   0.000000    1.000000e+00
# tocopherol-metabolism                                0.000000    1.000000e+00
# ...                                                       ...             ...
# aminosugar-metabolism                                0.000000    1.000000e+00
# ascorbate-and-aldarate-metabolism                    0.000000    1.000000e+00
# bacterial/fungal                                     0.000000    1.000000e+00
# carnitine-metabolism                                 0.000000    1.000000e+00
# creatine-metabolism                                  0.000000    1.000000e+00
# dipeptide                                            0.000000    1.000000e+00
# dipeptide-derivative                                 0.000000    1.000000e+00
# fatty-acid,-amide                                    0.000000    1.000000e+00
# fatty-acid,-amino                                    0.000000    1.000000e+00
# fatty-acid,-branched                                 0.000000    1.000000e+00
# fatty-acid,-dicarboxylate                            0.000000    1.000000e+00
# fatty-acid-metabolism(acyl-glycine)                  0.000000    1.000000e+00
# fatty-acid-metabolism-(also-bcaa-metabolism)         0.000000    1.000000e+00
# mevalonate-metabolism                                0.000000    1.000000e+00
# fatty-acid-synthesis                                 0.000000    1.000000e+00
# fructose,-mannose-and-galactose-metabolism           0.000000    1.000000e+00
# glutamate-metabolism                                 0.000000    1.000000e+00
# glutathione-metabolism                               0.000000    1.000000e+00
# glycerolipid-metabolism                              0.000000    1.000000e+00
# glycine,-serine-and-threonine-metabolism             0.000000    1.000000e+00
# glycolysis,-gluconeogenesis,-and-pyruvate-metab...   0.000000    1.000000e+00
# guanidino-and-acetamido-metabolism                   0.000000    1.000000e+00
# hemoglobin-and-porphyrin-metabolism                  0.000000    1.000000e+00
# histidine-metabolism                                 0.000000    1.000000e+00
# inositol-metabolism                                  0.000000    1.000000e+00
# ketone-bodies                                        0.000000    1.000000e+00
# vitamin-b6-metabolism                                0.000000    1.000000e+00
# lysine-metabolism                                    0.000000    1.000000e+00
# fibrinogen-cleavage-peptide                          0.000000    1.000000e+00
# long-chain-fatty-acid                                0.871118    1.000000e+00
#
# [73 rows x 5 columns]

# %% [markdown]
# ### Some data source searches for drug targets for proteins in the adenisine seeded HPWP correlation network and returns results to blackboard

# %% [markdown]
# ### Note these are just a few trivial examples of ways one could leverage DDDC and the Blackboard approach to better understand PTSD.
#
# We havent even looked at the clinical labs, which are enriched for cardiac markers and obvious candidates for study for the purpose of developing cheap ranges to identify solidiers undergoing PTSD.

# %%
print "Clinical Labs"
cl = pandas.DataFrame([v for v in my_nodes.values() if v['category'] == "Clinical Labs"])
sig_adf[sig_adf._id_1.isin(cl._id.tolist()) | sig_adf._id_2.isin(cl._id.tolist())]
# Out:
# Clinical Labs
#                                                  _id_1  \
# 208  METAB.None.amino-acid.phenylalanine-and-tyrosi...
# 209  METAB.None.amino-acid.phenylalanine-and-tyrosi...
# 246  METAB.None.amino-acid.phenylalanine-and-tyrosi...
# 265  METAB.None.amino-acid.phenylalanine-and-tyrosi...
# 293  METAB.None.amino-acid.phenylalanine-and-tyrosi...
# 304  METAB.None.amino-acid.phenylalanine-and-tyrosi...
#
#                                           _id_2  bh_adjusted_pvalue  \
# 208           CHEMS.None.Genova.ldl_cholesterol            0.002067
# 209              CHEMS.None.Genova.ldl_particle            0.087355
# 246              CHEMS.None.Genova.pyruvic_acid            0.076353
# 265         CHEMS.None.Genova.total_cholesterol            0.000505
# 293    CHEMS.None.Quest.cholesterol_total_quest            0.000495
# 304  CHEMS.None.Quest.ldl_particle_number_quest            0.056252
#
#      coefficient                       description    pvalue  \
# 208    -0.405385  mean value, age and sex adjusted  0.000015
# 209    -0.279575  mean value, age and sex adjusted  0.003386
# 246     0.285582  mean value, age and sex adjusted  0.002736
# 265    -0.435114  mean value, age and sex adjusted  0.000003
# 293    -0.435632  mean value, age and sex adjusted  0.000002
# 304    -0.299529  mean value, age and sex adjusted  0.001637
#
#                                study      test
# 208  Hundred Person Wellness Project  SPEARMAN
# 209  Hundred Person Wellness Project  SPEARMAN
# 246  Hundred Person Wellness Project  SPEARMAN
# 265  Hundred Person Wellness Project  SPEARMAN
# 293  Hundred Person Wellness Project  SPEARMAN
# 304  Hundred Person Wellness Project  SPEARMAN
