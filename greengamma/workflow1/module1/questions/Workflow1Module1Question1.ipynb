# %% [markdown]
# # Workflow 1, Module 1, Question 1

# %% [markdown]
# ## What are the defining symptoms / phenotypes of [condition x]?

# %% [markdown]
# ### Approach 1:  Expand

# %% [markdown]
# ROBOKOP expand will return all phenotypes associated with a condition, ranked using its normal algorithm.  It is then up to the user to set a threshhold on how many of these symptoms are interesting/acceptable.

# %%
import requests
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,output_format=None,predicate=None):
    url=f'http://robokop.renci.org:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild'       : rebuild, 
              'output_format' : output_format,
              'predicate'     : predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %% [markdown]
# Note that here we are returning a simple format of the output for display.  To get the identifiers it may be more useful to call with csv = False and parse the result

# %%
diabetes = 'MONDO:0005148' #type 2 diabetes
diabetes_phenotypes = expand('disease',diabetes,'phenotypic_feature',output_format='csv').split('\n')
n = 20
print( f"Returned {len(diabetes_phenotypes)} phenotypes" )
print( f"Top {n}:")
diabetes_phenotypes[:(n+1)]  # +1 because there's a header that comes back
# Out:
# Return Status: 200
# Returned 251 phenotypes
# Top 20:
# ['n0,n1',
#  'MONDO:0005148,HP:0002578',
#  'MONDO:0005148,HP:0000093',
#  'MONDO:0005148,HP:0001824',
#  'MONDO:0005148,HP:0004324',
#  'MONDO:0005148,HP:0001513',
#  'MONDO:0005148,HP:0000010',
#  'MONDO:0005148,HP:0000831',
#  'MONDO:0005148,HP:0000708',
#  'MONDO:0005148,HP:0004325',
#  'MONDO:0005148,HP:0001268',
#  'MONDO:0005148,HP:0003881',
#  'MONDO:0005148,HP:0001325',
#  'MONDO:0005148,HP:0000166',
#  'MONDO:0005148,HP:0001941',
#  'MONDO:0005148,HP:0011675',
#  'MONDO:0005148,HP:0002870',
#  'MONDO:0005148,HP:0001943',
#  'MONDO:0005148,HP:0001262',
#  'MONDO:0005148,HP:0001271',
#  'MONDO:0005148,HP:0003774']

# %%
asthma = 'MONDO:0004979' #Asthma
asthma_phenotypes = expand('disease',asthma,'phenotypic_feature',output_format='csv').split('\n')
n = 20
print( f"Returned {len(asthma_phenotypes)} phenotypes" )
print( f"Top {n}:")
asthma_phenotypes[:(n+1)]
# Out:
# Return Status: 200
# Returned 251 phenotypes
# Top 20:
# ['n0,n1',
#  'MONDO:0004979,HP:0100749',
#  'MONDO:0004979,HP:0001609',
#  'MONDO:0004979,HP:0002094',
#  'MONDO:0004979,HP:0002093',
#  'MONDO:0004979,HP:0001337',
#  'MONDO:0004979,HP:0002870',
#  'MONDO:0004979,HP:0001618',
#  'MONDO:0004979,HP:0002076',
#  'MONDO:0004979,HP:0001025',
#  'MONDO:0004979,HP:0000709',
#  'MONDO:0004979,HP:0006510',
#  'MONDO:0004979,HP:0002133',
#  'MONDO:0004979,HP:0002960',
#  'MONDO:0004979,HP:0002206',
#  'MONDO:0004979,HP:0001047',
#  'MONDO:0004979,HP:0006516',
#  'MONDO:0004979,HP:0011947',
#  'MONDO:0004979,HP:0100033',
#  'MONDO:0004979,HP:0002110',
#  'MONDO:0004979,HP:0100633']

# %% [markdown]
# ### Approach 2: Enriched Expansion (No Descendants)

# %% [markdown]
# Here we will start with a condition and find phenotypes that have a high enrichment factor.  That is, they are linked to the condition at a higher rate than might be expected.  Given that we are doing enrichment with a single input, we're really finding the phenotypes that are linked specifically to this condition.

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'max_results': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
enriched_diabetes_phenotypes = enrichment('disease',[diabetes],'phenotypic_feature')
pd.DataFrame(enriched_diabetes_phenotypes)
# Out:
# Return Status: 200
#                id                                               name         p
# 0   UMLS:C0206064                               Microvascular Angina  0.000219
# 1    MESH:D053201                        Urinary Bladder, Overactive  0.000437
# 2     NCIT:C53652                            Acute Coronary Syndrome  0.000510
# 3     NCIT:C94250                                         Overweight  0.000656
# 4     NCIT:C76325                                       Birth Weight  0.001239
# 5      HP:0012603                Abnormal urine sodium concentration  0.001458
# 6     NCIT:C81328                                        Body Weight  0.002041
# 7      HP:0008776                   Abnormal renal artery morphology  0.002915
# 8      HP:0025323                       Abnormal arterial physiology  0.003207
# 9      HP:0040063                           Decreased adipose tissue  0.004373
# 10     HP:0005974                              Episodic ketoacidosis  0.004519
# 11     HP:0011016         Abnormality of urine glucose concentration  0.004592
# 12     HP:0006279                              Beta-cell dysfunction  0.004956
# 13     HP:0030082                         Abnormal drinking behavior  0.005102
# 14     HP:0008711                       Benign prostatic hyperplasia  0.005612
# 15     HP:0010979  Abnormality lipoprotein cholesterol concentration  0.005758
# 16     HP:0009059               Congenital generalized lipodystrophy  0.005904
# 17     HP:0005979                             Metabolic ketoacidosis  0.005977
# 18     HP:0100739                                            Bulimia  0.005977
# 19     HP:0012093       Abnormality of endocrine pancreas physiology  0.006050
# 20     HP:0006476          Abnormality of the pancreatic islet cells  0.006122
# 21     HP:0000745                              Diminished motivation  0.006122
# 22     HP:0012592                                        Albuminuria  0.006487
# 23     HP:0011998                         Postprandial hyperglycemia  0.006487
# 24     HP:0001952                         Abnormal glucose tolerance  0.006706
# 25     HP:0011280         Abnormality of urine calcium concentration  0.006851
# 26     HP:0010981                                Hypolipoproteinemia  0.007216
# 27     HP:0040214                             Abnormal insulin level  0.007580
# 28     HP:0001001             Abnormality of subcutaneous fat tissue  0.008163
# 29     HP:0040215                 Abnormal circulating insulin level  0.008236
# ..            ...                                                ...       ...
# 70     HP:0002686                      Prenatal maternal abnormality  0.016254
# 71     HP:0000719                             Inappropriate behavior  0.016691
# 72     HP:0011733                  Abnormality of adrenal physiology  0.017493
# 73     HP:0000166                               Severe periodontitis  0.017711
# 74     HP:0012614                            Abnormal urine cytology  0.017930
# 75     HP:0002153                                       Hyperkalemia  0.017930
# 76     HP:0011106                                        Hypovolemia  0.017930
# 77     HP:0003464                   Abnormal cholesterol homeostasis  0.018003
# 78     HP:0001988                             Recurrent hypoglycemia  0.018513
# 79     HP:0002329                                         Drowsiness  0.018659
# 80     HP:0005344                 Abnormal carotid artery morphology  0.018659
# 81     HP:0100639                             Erectile abnormalities  0.019023
# 82     HP:0004363                 Abnormality of calcium homeostasis  0.019023
# 83     HP:0031263                Abnormal renal corpuscle morphology  0.019169
# 84     HP:0000095         Abnormality of renal glomerulus morphology  0.019169
# 85     HP:0006280                               Chronic pancreatitis  0.019388
# 86     HP:0001041                                    Facial erythema  0.019461
# 87     HP:0001575                                       Mood changes  0.019534
# 88     HP:0001953                              Diabetic ketoacidosis  0.019606
# 89     HP:0002152                                   Hyperproteinemia  0.019606
# 90     HP:0004950                       Peripheral arterial stenosis  0.019971
# 91     HP:0010927  Abnormality of divalent inorganic cation homeo...  0.020044
# 92     HP:0100273                              Neoplasm of the colon  0.020408
# 93     HP:0002359                                     Frequent falls  0.020627
# 94     HP:0001520                          Large for gestational age  0.020773
# 95     HP:0004798  Recurrent infection of the gastrointestinal tract  0.020991
# 96     HP:0011035             Abnormality of renal cortex morphology  0.021064
# 97     HP:0006543                           Cardiorespiratory arrest  0.021064
# 98     HP:0009145                Abnormal cerebral artery morphology  0.021064
# 99     HP:0025155     Abnormality of hepatobiliary system physiology  0.021501
#
# [100 rows x 3 columns]

# %%
enriched_asthma_phenotypes = enrichment('disease',[asthma],'phenotypic_feature')
pd.DataFrame(enriched_asthma_phenotypes)
# Out:
# Return Status: 200
#                id                                        name         p
# 0      HP:0012417                                  Hypocapnia  0.000146
# 1      HP:0025095                                      Sneeze  0.000146
# 2      HP:0012652                     Exercise-induced asthma  0.000292
# 3      HP:0012653                          Status asthmaticus  0.000364
# 4      HP:0012416                                 Hypercapnia  0.000364
# 5   UMLS:C0026635                             Mouth Breathing  0.000510
# 6    NCIT:C116315                                     Snoring  0.000583
# 7     EFO:1001793                               fetal hypoxia  0.000729
# 8   UMLS:C0600467                     Neurogenic Inflammation  0.000802
# 9     NCIT:C76325                                Birth Weight  0.001239
# 10  UMLS:C0033931                 Psychophysiologic Disorders  0.001603
# 11     NCIT:C3376                             Sleep Disorders  0.001749
# 12     HP:0012763                          Paroxysmal dyspnea  0.002114
# 13     HP:0010865               Oppositional defiant disorder  0.005831
# 14     HP:0007879                     Allergic conjunctivitis  0.008017
# 15     HP:0001621                                  Weak voice  0.008309
# 16     HP:0012393                                     Allergy  0.008528
# 17     HP:0011948           Acute respiratory tract infection  0.008892
# 18     HP:0012387                                  Bronchitis  0.009257
# 19     HP:0005952                Decreased pulmonary function  0.010277
# 20     HP:0001686                               Loss of voice  0.010350
# 21     HP:0001950                       Respiratory alkalosis  0.010350
# 22     HP:0002257                            Chronic rhinitis  0.010496
# 23     HP:0005972                        Respiratory acidosis  0.011079
# 24     HP:0025337                                     Red eye  0.011152
# 25     HP:0005943                          Respiratory arrest  0.011370
# 26     HP:0100033                                        Tics  0.011589
# 27     HP:0100754                                       Mania  0.012172
# 28     HP:0100845                          Anaphylactic shock  0.012536
# 29     HP:0012418                                   Hypoxemia  0.012974
# ..            ...                                         ...       ...
# 70     HP:0006536                    Obstructive lung disease  0.030321
# 71     HP:0000751                         Personality changes  0.030685
# 72     HP:0011950                               Bronchiolitis  0.031195
# 73     HP:0000734                               Disinhibition  0.031268
# 74     HP:0004930    Abnormality of the pulmonary vasculature  0.031414
# 75     HP:0001879                  Abnormality of eosinophils  0.031487
# 76     HP:0100660                                  Dyskinesia  0.031633
# 77     HP:0001739              Abnormality of the nasopharynx  0.031851
# 78     HP:0010307                                     Stridor  0.032143
# 79     HP:0002087  Abnormality of the upper respiratory tract  0.032289
# 80     HP:0002577                  Abnormality of the stomach  0.032362
# 81     HP:0004386               Gastrointestinal inflammation  0.032872
# 82     HP:0100827                               Lymphocytosis  0.033090
# 83     HP:0030163                Abnormal vascular physiology  0.033673
# 84     HP:0006510       Chronic obstructive pulmonary disease  0.034184
# 85     HP:0005368             Abnormality of humoral immunity  0.034548
# 86     HP:0100326                Immunologic hypersensitivity  0.035204
# 87     HP:0001742                           Nasal obstruction  0.035933
# 88     HP:0031466       Impairment in personality functioning  0.036953
# 89     HP:0001047                           Atopic dermatitis  0.037099
# 90     HP:0100710                                 Impulsivity  0.037682
# 91     HP:0001695                              Cardiac arrest  0.037682
# 92     HP:0002870                     Obstructive sleep apnea  0.037755
# 93     HP:0006528                        Chronic lung disease  0.038484
# 94     HP:0100753                               Schizophrenia  0.038630
# 95     HP:0010701               Abnormal immunoglobulin level  0.038921
# 96     HP:0002846                  Abnormal B cell morphology  0.039067
# 97     HP:0002793             Abnormal pattern of respiration  0.039577
# 98     HP:0100007   Neoplasm of the peripheral nervous system  0.040015
# 99     HP:0003712                 Skeletal muscle hypertrophy  0.040160
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Approach 3: Enriched Expansion with Descendants

# %% [markdown]
# Sometimes it can be useful to enrich on a larger set of inputs.  We use the descendents of the input condition to generate an input set here.

# %%
desc_enriched_diabetes_phenotypes = enrichment('disease',[diabetes],'phenotypic_feature',include_descendants=True)
pd.DataFrame(desc_enriched_diabetes_phenotypes)
# Out:
# Return Status: 200
#             id                                               name  \
# 0   HP:0011014                       Abnormal glucose homeostasis
# 1   HP:0011013  Abnormality of carbohydrate metabolism/homeost...
# 2   HP:0000819                                  Diabetes mellitus
# 3   HP:0000818                Abnormality of the endocrine system
# 4   HP:0100651                           Type I diabetes mellitus
# 5   HP:0012337                               Abnormal homeostasis
# 6   HP:0030082                         Abnormal drinking behavior
# 7   HP:0006217  Limited mobility of proximal interphalangeal j...
# 8   HP:0410050    Decreased level of 1,5 anhydroglucitol in serum
# 9   HP:0001993                                       Ketoacidosis
# 10  HP:0008320     Impaired collagen-induced platelet aggregation
# 11  HP:0000873                                 Diabetes insipidus
# 12  HP:0001889                               Megaloblastic anemia
# 13  HP:0001959                                         Polydipsia
# 14  HP:0010935             Abnormality of the upper urinary tract
# 15  HP:0004904               Maturity-onset diabetes of the young
# 16  HP:0025289                           Cervical lymphadenopathy
# 17  HP:0010625                      Anterior pituitary dysgenesis
# 18  HP:0003074                                      Hyperglycemia
# 19  HP:0001924                               Sideroblastic anemia
# 20  HP:0001946                                            Ketosis
# 21  HP:0011015         Abnormality of blood glucose concentration
# 22  HP:0001972                                  Macrocytic anemia
# 23  HP:0005974                              Episodic ketoacidosis
# 24  HP:0011016         Abnormality of urine glucose concentration
# 25  HP:0000135                                       Hypogonadism
# 26  HP:0012220      Non-caseating epithelioid cell granulomatosis
# 27  HP:0008542                         Low-frequency hearing loss
# 28  HP:0006279                              Beta-cell dysfunction
# 29  HP:0031137                             Storage in hepatocytes
# ..         ...                                                ...
# 70  HP:0000029                                 Testicular atrophy
# 71  HP:0002459                                       Dysautonomia
# 72  HP:0002257                                   Chronic rhinitis
# 73  HP:0030053                                         Stiff skin
# 74  HP:0012130         Abnormal erythroid lineage cell morphology
# 75  HP:0002926                  Abnormality of thyroid physiology
# 76  HP:0005101                  High-frequency hearing impairment
# 77  HP:0005397              Exaggerated cellular immune processes
# 78  HP:0001084                                      Corneal arcus
# 79  HP:0002155                               Hypertriglyceridemia
# 80  HP:0012094                             Abnormal pancreas size
# 81  HP:0008193                      Primary gonadal insufficiency
# 82  HP:0012719  Functional abnormality of the gastrointestinal...
# 83  HP:0000011                                 Neurogenic bladder
# 84  HP:0001325                                  Hypoglycemic coma
# 85  HP:0012091                 Abnormality of pancreas physiology
# 86  HP:0000364                                Hearing abnormality
# 87  HP:0000831                Insulin-resistant diabetes mellitus
# 88  HP:0045058                     Abnormality of the testis size
# 89  HP:0000855                                 Insulin resistance
# 90  HP:0410009          Abnormality of the somatic nervous system
# 91  HP:0000407                   Sensorineural hearing impairment
# 92  HP:0000863                         Central diabetes insipidus
# 93  HP:0045010                   Abnormality of peripheral nerves
# 94  HP:0007302                         Bipolar affective disorder
# 95  HP:0011751             Abnormality of the posterior pituitary
# 96  HP:0002592                                      Gastric ulcer
# 97  HP:0000077                          Abnormality of the kidney
# 98  HP:0002270        Abnormality of the autonomic nervous system
# 99  HP:0001877                    Abnormal erythrocyte morphology
#
#                p
# 0   4.522681e-21
# 1   3.590805e-20
# 2   1.813143e-18
# 3   5.391267e-11
# 4   2.620584e-09
# 5   2.969068e-09
# 6   3.289071e-08
# 7   7.367831e-07
# 8   1.512499e-06
# 9   1.551586e-06
# 10  2.691032e-06
# 11  6.181883e-06
# 12  1.322663e-05
# 13  2.508974e-05
# 14  3.027178e-05
# 15  4.326216e-05
# 16  5.048950e-05
# 17  5.341270e-05
# 18  5.348958e-05
# 19  5.431690e-05
# 20  5.456862e-05
# 21  5.943674e-05
# 22  6.587478e-05
# 23  8.087302e-05
# 24  8.484239e-05
# 25  9.553418e-05
# 26  9.750970e-05
# 27  9.750970e-05
# 28  1.066051e-04
# 29  1.126541e-04
# ..           ...
# 70  9.462146e-04
# 71  9.638417e-04
# 72  9.699590e-04
# 73  1.009462e-03
# 74  1.018826e-03
# 75  1.130262e-03
# 76  1.134066e-03
# 77  1.155735e-03
# 78  1.155735e-03
# 79  1.164257e-03
# 80  1.175631e-03
# 81  1.245037e-03
# 82  1.302281e-03
# 83  1.419516e-03
# 84  1.436488e-03
# 85  1.507048e-03
# 86  1.524154e-03
# 87  1.629571e-03
# 88  1.645573e-03
# 89  1.819107e-03
# 90  1.875944e-03
# 91  1.885194e-03
# 92  1.895305e-03
# 93  1.912445e-03
# 94  1.930523e-03
# 95  2.055443e-03
# 96  2.132440e-03
# 97  2.202805e-03
# 98  2.248567e-03
# 99  2.268204e-03
#
# [100 rows x 3 columns]

# %%
desc_enriched_asthma_phenotypes = enrichment('disease',[asthma],'phenotypic_feature',include_descendants=True)
pd.DataFrame(desc_enriched_asthma_phenotypes)
# Out:
# Return Status: 200
#                id                                               name  \
# 0      HP:0100326                       Immunologic hypersensitivity
# 1      HP:0012653                                 Status asthmaticus
# 2      HP:0002099                                             Asthma
# 3      HP:0002795                 Functional respiratory abnormality
# 4      HP:0002793                    Abnormal pattern of respiration
# 5      HP:0012417                                         Hypocapnia
# 6      HP:0025095                                             Sneeze
# 7      HP:0011948                  Acute respiratory tract infection
# 8      HP:0012387                                         Bronchitis
# 9      HP:0010978            Abnormality of immune system physiology
# 10     HP:0005972                               Respiratory acidosis
# 11     HP:0005943                                 Respiratory arrest
# 12     HP:0002086              Abnormality of the respiratory system
# 13     HP:0012652                            Exercise-induced asthma
# 14     HP:0012416                                        Hypercapnia
# 15     HP:0002913                                      Myoglobinuria
# 16  UMLS:C0026635                                    Mouth Breathing
# 17     HP:0003750                     Increased muscle fatiguability
# 18   NCIT:C116315                                            Snoring
# 19    EFO:1001793                                      fetal hypoxia
# 20  UMLS:C0600467                            Neurogenic Inflammation
# 21     HP:0006543                           Cardiorespiratory arrest
# 22     HP:0002791                                    Hypoventilation
# 23     HP:0002883                                   Hyperventilation
# 24     HP:0004469                                 Chronic bronchitis
# 25    NCIT:C76325                                       Birth Weight
# 26     HP:0003201                                     Rhabdomyolysis
# 27  UMLS:C0033931                        Psychophysiologic Disorders
# 28     NCIT:C3376                                    Sleep Disorders
# 29     HP:0011950                                      Bronchiolitis
# 30     HP:0001879                         Abnormality of eosinophils
# 31     HP:0001739                     Abnormality of the nasopharynx
# 32     HP:0012763                                 Paroxysmal dyspnea
# 33     HP:0001695                                     Cardiac arrest
# 34     HP:0012433                           Abnormal social behavior
# 35     HP:0003128                                    Lactic acidosis
# 36     HP:0002107                                       Pneumothorax
# 37     HP:0000600                         Abnormality of the pharynx
# 38     HP:0030956  Abnormality of cardiovascular system electroph...
# 39     HP:0100750                                        Atelectasis
# 40     HP:0002097                                          Emphysema
# 41     HP:0002788       Recurrent upper respiratory tract infections
# 42     HP:0001911                        Abnormality of granulocytes
# 43     HP:0002878                                Respiratory failure
# 44     HP:0001942                                 Metabolic acidosis
# 45     HP:0000735                       Impaired social interactions
# 46     HP:0010865                      Oppositional defiant disorder
# 47     HP:0001880                                       Eosinophilia
# 48     HP:0001941                                           Acidosis
# 49     HP:0001259                                               Coma
# 50     HP:0007879                            Allergic conjunctivitis
# 51     HP:0003236              Elevated serum creatine phosphokinase
# 52     HP:0001621                                         Weak voice
# 53     HP:0012393                                            Allergy
# 54     HP:0030972                   Abnormal systemic blood pressure
# 55     HP:0001284                                          Areflexia
#
#                p
# 0   5.299831e-08
# 1   1.062095e-06
# 2   2.217554e-06
# 3   1.208274e-04
# 4   5.807957e-04
# 5   7.287567e-04
# 6   7.287567e-04
# 7   7.706434e-04
# 8   8.347656e-04
# 9   1.031134e-03
# 10  1.192943e-03
# 11  1.256033e-03
# 12  1.329903e-03
# 13  1.457089e-03
# 14  1.821095e-03
# 15  2.198526e-03
# 16  2.548790e-03
# 17  2.823518e-03
# 18  2.912478e-03
# 19  3.639536e-03
# 20  4.002906e-03
# 21  4.239800e-03
# 22  4.561876e-03
# 23  5.303488e-03
# 24  5.464664e-03
# 25  6.180900e-03
# 26  6.235468e-03
# 27  7.992983e-03
# 28  8.717076e-03
# 29  9.120321e-03
# 30  9.286290e-03
# 31  9.495711e-03
# 32  1.052546e-02
# 33  1.313850e-02
# 34  1.633080e-02
# 35  1.827112e-02
# 36  1.901675e-02
# 37  1.954080e-02
# 38  2.121181e-02
# 39  2.127262e-02
# 40  2.294369e-02
# 41  2.294369e-02
# 42  2.499638e-02
# 43  2.499638e-02
# 44  2.801304e-02
# 45  2.877322e-02
# 46  2.882065e-02
# 47  3.089120e-02
# 48  3.285274e-02
# 49  3.389022e-02
# 50  3.945545e-02
# 51  3.999984e-02
# 52  4.086636e-02
# 53  4.192345e-02
# 54  4.559599e-02
# 55  4.568055e-02
