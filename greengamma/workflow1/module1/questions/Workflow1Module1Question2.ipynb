# %% [markdown]
# # Workflow 1, Module 1, Question 2

# %% [markdown]
# ## What conditions present [symptoms]?

# %% [markdown]
# ### Approach 1:  Quick to find conditions that have every symptom.

# %% [markdown]
# If this question means find any condition that has all of the given set of symptoms, then we can use the quick service.  Here we will do what's called a "star query" in the quick notebook. First, we'll define a quick function that takes a question and calls the service, then we'll define a function for creating the proper question format. Finally, we'll show some examples using symptom lists derived from the workflow1, module1 question 1 notebook.

# %%
import requests
import pandas as pd

# %%
def quick(question):
    url=f'http://robokop.renci.org:80/api/simple/quick/'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %%
def make_star_question(types,curies,shared_type):
    """Create a question to find entities of shared_type that are linked to all of the nodes specified in the
    types and curies arrays."""
    question = {
                'rebuild': 'False',  #We're doing disease/phenotype, so they're cached.
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    question['machine_question']['nodes'].append( {'id': 0, 'type': shared_type})
    for i,t in enumerate(types):
        newnode = {'id': i+1, 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        question['machine_question']['edges'].append( {'source_id': 0, 'target_id': i+1})
    return question

# %%
def make_shared_symptom_question(curies):
    types = [ 'phenotypic_feature' for c in curies ]
    shared_type = 'disease'
    return make_star_question(types,curies,shared_type)

# %% [markdown]
# We will use this function to pretty print quick results.

# %%
def extract_node_info(returnanswer):
    nodes = [{'name': answer['nodes'][0]['name'], 'id': answer['nodes'][0]['id']} for answer in returnanswer['answers']]
    return pd.DataFrame(nodes)

# %% [markdown]
# We can now pass a list of curies to make_shared_symptom_question, and then pass the result to quick.  We'll be using (arbitrarily) the top 5 phenotypes from ROBOKOP's answers to question 1.

# %%
# These are "Maturity-onset diabetes of the young", "Recurrent hypoglycemia", "Glucose intolerance", 
# "Beta-cell dysfunction", and "Hyperinsulinemia"
diabetes_symptoms=['HP:0004904', 'HP:0001988', 'HP:0000833', 'HP:0006279','HP:0000842']
diabetes_question = make_shared_symptom_question(diabetes_symptoms)
diabetes_question
# Out:
# {'machine_question': {'edges': [{'source_id': 0, 'target_id': 1},
#    {'source_id': 0, 'target_id': 2},
#    {'source_id': 0, 'target_id': 3},
#    {'source_id': 0, 'target_id': 4},
#    {'source_id': 0, 'target_id': 5}],
#   'nodes': [{'id': 0, 'type': 'disease'},
#    {'curie': 'HP:0004904', 'id': 1, 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0001988', 'id': 2, 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0000833', 'id': 3, 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0006279', 'id': 4, 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0000842', 'id': 5, 'type': 'phenotypic_feature'}]},
#  'rebuild': 'False'}

# %%
diabetes_answer = quick(diabetes_question)
diabetes_nodes = extract_node_info(diabetes_answer)
diabetes_nodes
# Out:
# Return Status: 200
#                id                                               name
# 0   MONDO:0002908                         glucose metabolism disease
# 1   MONDO:0005048  pancreatic insulin-producing neuroendocrine tumor
# 2   MONDO:0002177                          hyperinsulinism (disease)
# 3   MONDO:0005147                           type 1 diabetes mellitus
# 4   MONDO:0005148                           type 2 diabetes mellitus
# 5   MONDO:0002356                                   pancreas disease
# 6   MONDO:0005893                     pancreatic endocrine carcinoma
# 7   MONDO:0005815                 pancreatic neuroendocrine neoplasm
# 8   MONDO:0009831                      malignant pancreatic neoplasm
# 9   MONDO:0021040                                pancreatic neoplasm
# 10  MONDO:0019954                    pancreatic neuroendocrine tumor
# 11  MONDO:0005066                                  metabolic disease
# 12  MONDO:0005015                        diabetes mellitus (disease)
# 13  MONDO:0003847                          inherited genetic disease
# 14  MONDO:0002082                           endocrine gland neoplasm
# 15  MONDO:0005151                           endocrine system disease
# 16  MONDO:0004972                                            adenoma
# 17  MONDO:0021200                                       rare disease
# 18  MONDO:0021470                        benign neoplasm of pancreas
# 19  MONDO:0007179                                 autoimmune disease
# 20  MONDO:0002120                           neuroendocrine carcinoma
# 21  MONDO:0001933                         endocrine pancreas disease
# 22  MONDO:0019496                            neuroendocrine neoplasm
# 23  MONDO:0021198                               rare genetic disease
# 24  MONDO:0000627                          benign endocrine neoplasm
# 25  MONDO:0021069                       malignant endocrine neoplasm
# 26  MONDO:0005046                              immune system disease
# 27  MONDO:0023370                     neoplastic disease or syndrome
# 28  MONDO:0019041                       rare genetic inherited tumor
# 29  MONDO:0015936                     rare tumor of endocrine glands
# 30  MONDO:0002516                            digestive system cancer
# 31  MONDO:0020031                                         rare tumor
# 32  MONDO:0019997                     rare gastroenterologic disease
# 33  MONDO:0000569             autoimmune disease of endocrine system
# 34  MONDO:0020033                               rare digestive tumor
# 35  MONDO:0018520                  rare epithelial tumor of pancreas
# 36  MONDO:0015112                            rare pancreatic disease
# 37  MONDO:0015078     gastroenteropancreatic neuroendocrine neoplasm
# 38  MONDO:0000385                   benign digestive system neoplasm
# 39  MONDO:0000386   digestive system neuroendocrine tumor, grade 1/2
# 40  MONDO:0005165                                    benign neoplasm
# 41  MONDO:0006181                         digestive system carcinoma
# 42  MONDO:0000605                  hypersensitivity reaction disease
# 43  MONDO:0015122                             rare diabetes mellitus
# 44  MONDO:0004993                                          carcinoma
# 45  MONDO:0004992                                             cancer
# 46  MONDO:0016645                            rare neoplastic disease
# 47  MONDO:0005626                                epithelial neoplasm
# 48  MONDO:0005070                                 neoplasm (disease)
# 49  MONDO:0021199                       disease by anatomical system
# 50  MONDO:0021195              disease by cellular process disrupted
# 51  MONDO:0021194             disease by subcellular system affected
# 52  MONDO:0015967                     rare genetic diabetes mellitus
# 53  MONDO:0021223                          digestive system neoplasm
# 54  MONDO:0015618                         genetic pancreatic disease
# 55  MONDO:0015615           rare genetic gastroenterological disease
# 56  MONDO:0020005                             rare endocrine disease
# 57  MONDO:0019214             inborn carbohydrate metabolic disorder
# 58  MONDO:0015513                     rare genetic endocrine disease
# 59  MONDO:0004335                           digestive system disease

# %%
#['Exercise-induced asthma(HP:0012652)',
# 'Allergic rhinitis(HP:0003193)',
# 'Obstructive lung disease(HP:0006536)',
# 'Status asthmaticus(HP:0012653)',
# 'Increased IgE level(HP:0003212)',
asthma_symptoms=['HP:0012652','HP:0003193','HP:0006536','HP:0012653','HP:0003212']
asthma_question = make_shared_symptom_question(asthma_symptoms)

# %%
asthma_answer = quick(asthma_question)
asthma_nodes = extract_node_info(asthma_answer)
asthma_nodes
# Out:
# Return Status: 200
#               id                             name
# 0  MONDO:0001358                bronchial disease
# 1  MONDO:0005087       respiratory system disease
# 2  MONDO:0004979                           asthma
# 3  MONDO:0000270  lower respiratory tract disease
# 4  MONDO:0021199     disease by anatomical system

# %% [markdown]
# ### Approach 2: Enriched Expansion

# %% [markdown]
# A downside of the intersection approach above is that the conditions that come out must be attached to every phenotype.  The results then, can be very sensitive to exactly which phenotypes are chosen as input.  A less sensitive way to handle this is to find conditions that are enriched for the list of phenotypes.  This lets us be more open in which phenotypes we're including, and also which conditions are returning.  We'll use the same list of phenotypes for illustration, but it would also make sense to go back to the list and be more inclusive.  We'll also use `include_descendants=True`, but experimentation with that option would be worthwhile.

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
diabetes_enriched = enrichment('phenotypic_feature',diabetes_symptoms,'disease',threshhold=0.01,include_descendants=True)
diabetes_enriched_frame = pd.DataFrame(diabetes_enriched)
diabetes_enriched_frame
# Out:
# Return Status: 200
#                id                                               name  \
# 0   MONDO:0021470                        benign neoplasm of pancreas
# 1   MONDO:0005048  pancreatic insulin-producing neuroendocrine tumor
# 2   MONDO:0002177                          hyperinsulinism (disease)
# 3   MONDO:0018520                  rare epithelial tumor of pancreas
# 4   MONDO:0019954                    pancreatic neuroendocrine tumor
# 5   MONDO:0005893                     pancreatic endocrine carcinoma
# 6   MONDO:0005815                 pancreatic neuroendocrine neoplasm
# 7   MONDO:0015078     gastroenteropancreatic neuroendocrine neoplasm
# 8   MONDO:0000386   digestive system neuroendocrine tumor, grade 1/2
# 9   MONDO:0009831                      malignant pancreatic neoplasm
# 10  MONDO:0000385                   benign digestive system neoplasm
# 11  MONDO:0021040                                pancreatic neoplasm
# 12  MONDO:0015112                            rare pancreatic disease
# 13  MONDO:0002120                           neuroendocrine carcinoma
# 14  MONDO:0019496                            neuroendocrine neoplasm
# 15  MONDO:0005148                           type 2 diabetes mellitus
# 16  MONDO:0006181                         digestive system carcinoma
# 17  MONDO:0020033                               rare digestive tumor
# 18  MONDO:0000627                          benign endocrine neoplasm
# 19  MONDO:0004972                                            adenoma
# 20  MONDO:0002909                                      hyperglycemia
# 21  MONDO:0001076                                glucose intolerance
# 22  MONDO:0005147                           type 1 diabetes mellitus
# 23  MONDO:0005406                               gestational diabetes
# 24  MONDO:0021069                       malignant endocrine neoplasm
# 25  MONDO:0015967                     rare genetic diabetes mellitus
# 26  MONDO:0015122                             rare diabetes mellitus
# 27  MONDO:0002516                            digestive system cancer
# 28  MONDO:0015887                      rare diabetes mellitus type 2
# 29  MONDO:0011236      hyperinsulinism due to glucokinase deficiency
# ..            ...                                                ...
# 70  MONDO:0015330                        overgrowth/obesity syndrome
# 71  MONDO:0015615           rare genetic gastroenterological disease
# 72  MONDO:0002816                             adrenal cortex disease
# 73  MONDO:0014148                       estrogen resistance syndrome
# 74  MONDO:0005294                        peripheral vascular disease
# 75  MONDO:0007761                       hyperlipoproteinemia type IV
# 76  MONDO:0005827                              lipoatrophic diabetes
# 77  MONDO:0016365               familial primary hyperparathyroidism
# 78  MONDO:0015897                           rare hyperparathyroidism
# 79  MONDO:0016166                        genetic hyperparathyroidism
# 80  MONDO:0015076                             rare parathyroid tumor
# 81  MONDO:0021227                             adrenal gland neoplasm
# 82  MONDO:0017169                       multiple endocrine neoplasia
# 83  MONDO:0019716                                overgrowth syndrome
# 84  MONDO:0005495                              adrenal gland disease
# 85  MONDO:0007179                                 autoimmune disease
# 86  MONDO:0000605                  hypersensitivity reaction disease
# 87  MONDO:0004335                           digestive system disease
# 88  MONDO:0021360                         tumor of parathyroid gland
# 89  MONDO:0017713   disorder of fatty acid oxidation and ketogenesis
# 90  MONDO:0016789                       pyruvate metabolism disorder
# 91  MONDO:0012552                multiple endocrine neoplasia type 4
# 92  MONDO:0019041                       rare genetic inherited tumor
# 93  MONDO:0001741                                hyperparathyroidism
# 94  MONDO:0015079                       multiple polyglandular tumor
# 95  MONDO:0017820   disease with Cushing syndrome as a major feature
# 96  MONDO:0002311                           retinal vascular disease
# 97  MONDO:0020031                                         rare tumor
# 98  MONDO:0016464                 insulin-resistance syndrome type B
# 99  MONDO:0009278  hyperinsulinism due to short chain 3-hydroxyla...
#
#                p
# 0   2.629818e-15
# 1   2.629818e-15
# 2   1.766995e-13
# 3   1.148293e-12
# 4   1.148293e-12
# 5   1.676656e-12
# 6   1.676656e-12
# 7   8.604489e-12
# 8   1.109926e-11
# 9   1.962547e-11
# 10  3.794658e-11
# 11  3.895274e-11
# 12  2.843028e-10
# 13  3.074325e-10
# 14  3.074325e-10
# 15  1.436773e-09
# 16  4.794554e-09
# 17  5.531602e-09
# 18  5.973074e-09
# 19  1.111178e-08
# 20  1.657817e-08
# 21  1.657817e-08
# 22  2.692273e-08
# 23  4.165429e-08
# 24  5.385590e-08
# 25  6.529136e-08
# 26  6.588415e-08
# 27  1.073687e-07
# 28  1.259813e-07
# 29  1.707836e-07
# ..           ...
# 70  8.168413e-05
# 71  8.551414e-05
# 72  1.017931e-04
# 73  1.053443e-04
# 74  1.147638e-04
# 75  1.170018e-04
# 76  1.170018e-04
# 77  1.200985e-04
# 78  1.258163e-04
# 79  1.258163e-04
# 80  1.258163e-04
# 81  1.303988e-04
# 82  1.472284e-04
# 83  1.515432e-04
# 84  1.580727e-04
# 85  1.844215e-04
# 86  2.515753e-04
# 87  2.560375e-04
# 88  2.754378e-04
# 89  2.754378e-04
# 90  3.160143e-04
# 91  3.435068e-04
# 92  3.469734e-04
# 93  3.778920e-04
# 94  3.838780e-04
# 95  3.899254e-04
# 96  3.960344e-04
# 97  4.157662e-04
# 98  4.297569e-04
# 99  4.528032e-04
#
# [100 rows x 3 columns]

# %%
asthma_enriched = enrichment('phenotypic_feature',asthma_symptoms,'disease',threshhold=0.1,include_descendants=True)
asthma_enriched_frame = pd.DataFrame(asthma_enriched)
asthma_enriched_frame
# Out:
# Return Status: 200
#                id                                               name  \
# 0   MONDO:0004979                                             asthma
# 1   MONDO:0001358                                  bronchial disease
# 2   MONDO:0004822                                     bronchiectasis
# 3   MONDO:0003781                                         bronchitis
# 4   MONDO:0003014                                           rhinitis
# 5   MONDO:0000771                       allergic respiratory disease
# 6   MONDO:0020028                  rare allergic respiratory disease
# 7   MONDO:0005990                                         tracheitis
# 8   MONDO:0000270                    lower respiratory tract disease
# 9   MONDO:0005324                         seasonal allergic rhinitis
# 10  MONDO:0002267                           obstructive lung disease
# 11  MONDO:0005002              chronic obstructive pulmonary disease
# 12  MONDO:0002232                               nasal cavity disease
# 13  MONDO:0005749                             eosinophilic pneumonia
# 14  MONDO:0011786                                  allergic rhinitis
# 15  MONDO:0016575                         primary ciliary dyskinesia
# 16  MONDO:0004553                      extrinsic allergic alveolitis
# 17  MONDO:0018395    male infertility due to sperm motility disorder
# 18  MONDO:0015490              predominantly small-vessel vasculitis
# 19  MONDO:0020027                              rare allergic disease
# 20  MONDO:0002567                                   tracheal disease
# 21  MONDO:0002436                                       nose disease
# 22  MONDO:0002211                                  B cell deficiency
# 23  MONDO:0005249                                          pneumonia
# 24  MONDO:0005271                                   allergic disease
# 25  MONDO:0005296                               sleep apnea syndrome
# 26  MONDO:0005087                         respiratory system disease
# 27  MONDO:0000807                                      latex allergy
# 28  MONDO:0017034  secondary interstitial lung disease in childho...
# 29  MONDO:0017035  secondary interstitial lung disease in childho...
# ..            ...                                                ...
# 70  MONDO:0018830                                     Kimura disease
# 71  MONDO:0007817                         IgE responsiveness, atopic
# 72  MONDO:0008903                                        lung cancer
# 73  MONDO:0019724                       secondary glomerular disease
# 74  MONDO:0001342                     dysgammaglobulinemia (disease)
# 75  MONDO:0003739        selective immunoglobulin deficiency disease
# 76  MONDO:0015575                  rare bacterial infectious disease
# 77  MONDO:0018037                                 hyper-IgE syndrome
# 78  MONDO:0002468                       hyperimmunoglobulin syndrome
# 79  MONDO:0018389  male infertility due to gonadal dysgenesis or ...
# 80  MONDO:0015112                            rare pancreatic disease
# 81  MONDO:0021117                                      lung neoplasm
# 82  MONDO:0006932                                    pulmonary edema
# 83  MONDO:0010518                           Wiskott-Aldrich syndrome
# 84  MONDO:0002273                  plasma protein metabolism disease
# 85  MONDO:0019305            immune deficiency with skin involvement
# 86  MONDO:0018305                      chronic granulomatous disease
# 87  MONDO:0012682  susceptibility to infection due to TYK2 defici...
# 88  MONDO:0017898  autosomal recessive mendelian susceptibility t...
# 89  MONDO:0005812                                          influenza
# 90  MONDO:0002806                             bronchogenic carcinoma
# 91  MONDO:0001672                                    bronchus cancer
# 92  MONDO:0004664                                      helminthiasis
# 93  MONDO:0000376                          respiratory system cancer
# 94  MONDO:0005279                       pulmonary embolism (disease)
# 95  MONDO:0019602                     other inborn metabolic disease
# 96  MONDO:0005910                 phagocyte bactericidal dysfunction
# 97  MONDO:0013766          familial cold autoinflammatory syndrome 3
# 98  MONDO:0009663            mucus inspissation of respiratory tract
# 99  MONDO:0005141                              Pseudomonas infection
#
#                p
# 0   7.980555e-10
# 1   2.861786e-08
# 2   3.276216e-07
# 3   5.080914e-07
# 4   7.192519e-07
# 5   8.659652e-07
# 6   8.659652e-07
# 7   1.559496e-06
# 8   3.748559e-06
# 9   5.007883e-06
# 10  5.329081e-06
# 11  7.790182e-06
# 12  8.626669e-06
# 13  8.978444e-06
# 14  1.721941e-05
# 15  2.806317e-05
# 16  2.806317e-05
# 17  3.633498e-05
# 18  3.876156e-05
# 19  4.359030e-05
# 20  5.288136e-05
# 21  5.541555e-05
# 22  7.254495e-05
# 23  7.903537e-05
# 24  8.594311e-05
# 25  1.239607e-04
# 26  1.430282e-04
# 27  1.557749e-04
# 28  2.009446e-04
# 29  2.009446e-04
# ..           ...
# 70  2.914034e-03
# 71  2.914034e-03
# 72  2.947713e-03
# 73  3.297033e-03
# 74  3.313691e-03
# 75  3.313691e-03
# 76  3.605752e-03
# 77  3.751542e-03
# 78  3.827027e-03
# 79  3.913940e-03
# 80  3.913940e-03
# 81  4.102538e-03
# 82  4.215137e-03
# 83  4.294888e-03
# 84  4.704236e-03
# 85  4.771811e-03
# 86  4.788216e-03
# 87  4.852593e-03
# 88  4.852593e-03
# 89  4.872896e-03
# 90  4.872896e-03
# 91  4.872896e-03
# 92  5.315700e-03
# 93  5.466932e-03
# 94  5.575439e-03
# 95  5.666378e-03
# 96  5.758007e-03
# 97  5.820635e-03
# 98  5.820635e-03
# 99  6.322209e-03
#
# [100 rows x 3 columns]
