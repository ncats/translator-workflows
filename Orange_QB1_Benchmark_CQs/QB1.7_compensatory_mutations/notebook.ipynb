# %%
import requests
import pandas as pd
pd.options.display.max_colwidth=100

# %%
def query_and_format_result(query):
    params = {'query': query, 'format': 'json'}
    results = requests.get('https://query.wikidata.org/sparql', params=params).json()['results']['bindings']
    return pd.DataFrame([{k:v['value'] for k,v in item.items()} for item in results])

# %% [markdown]
# ### Get the gene sets

# %%
url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt"
core_genes = list(pd.DataFrame.from_csv(url, sep="\t", header=None)[1])
core_genes_quotes = '"' + '" "'.join(core_genes) + '"'
print(core_genes_quotes)
# Out:
# "FANCA" "FANCB" "FANCC" "FANCE" "FANCF" "FANCG" "FANCL" "FANCM" "FANCD2" "FANCI" "UBE2T"

# %%
url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_2_effector_proteins.txt"
effector_genes = list(pd.DataFrame.from_csv(url, sep="\t", header=None)[1])
effector_genes_quotes = '"' + '" "'.join(effector_genes) + '"'
print(effector_genes_quotes)
# Out:
# "BRCA2" "BRIP1" "PALB2" "RAD51C" "SLX4" "ERCC4" "RAD51" "BRCA1" "MAD2L2" "XRCC2" "RFWD3"

# %%
url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_3_associated_proteins.txt"
ass_genes = list(pd.DataFrame.from_csv(url, sep="\t", header=None)[1])
ass_genes_quotes = '"' + '" "'.join(ass_genes) + '"'
print(ass_genes_quotes)
# Out:
# "FAAP100" "FAAP24" "FAAP20" "CENPS" "CENPX"

# %%
all_genes = set(core_genes) | set(effector_genes) | set(ass_genes)
all_genes_quotes = '"' + '" "'.join(all_genes) + '"'

# %% [markdown]
# ### Exploratory query showing all variants on these genes

# %%
query = """select ?geneLabel ?variantLabel ?variant where {
  values ?hgnc {**hgnc**}
  # ?gene wdt:P353 ?hgnc .
  # ?variant wdt:P3433 ?gene .
  SERVICE wikibase:label {  bd:serviceParam wikibase:language "en" }
}"""

# %%
# Core FA genes
query_and_format_result(query.replace("**hgnc**", core_genes_quotes))
# Out:
#   geneLabel                                   variant            variantLabel
# 0     FANCC  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION

# %%
# All FA genes
query_and_format_result(query.replace("**hgnc**", all_genes_quotes))
# Out:
#    geneLabel                                   variant  \
# 0      BRCA1  http://www.wikidata.org/entity/Q28381200
# 1      BRCA1  http://www.wikidata.org/entity/Q28444937
# 2      BRCA1  http://www.wikidata.org/entity/Q28444960
# 3      BRCA1  http://www.wikidata.org/entity/Q28445085
# 4      BRCA1  http://www.wikidata.org/entity/Q28445090
# 5      BRCA1  http://www.wikidata.org/entity/Q28532483
# 6      BRCA1  http://www.wikidata.org/entity/Q29938723
# 7      BRCA1  http://www.wikidata.org/entity/Q29938724
# 8      BRCA1  http://www.wikidata.org/entity/Q29938725
# 9      BRCA1  http://www.wikidata.org/entity/Q29938726
# 10     BRCA1  http://www.wikidata.org/entity/Q29938727
# 11     BRCA1  http://www.wikidata.org/entity/Q29938728
# 12     BRCA1  http://www.wikidata.org/entity/Q29938730
# 13     BRCA1  http://www.wikidata.org/entity/Q29938732
# 14     BRCA1  http://www.wikidata.org/entity/Q29938734
# 15     BRCA1  http://www.wikidata.org/entity/Q29938735
# 16     BRCA1  http://www.wikidata.org/entity/Q29938736
# 17     BRCA1  http://www.wikidata.org/entity/Q32965138
# 18     BRCA2  http://www.wikidata.org/entity/Q28371604
# 19     BRCA2  http://www.wikidata.org/entity/Q28371625
# 20     BRCA2  http://www.wikidata.org/entity/Q28444938
# 21     BRCA2  http://www.wikidata.org/entity/Q28444961
# 22     BRCA2  http://www.wikidata.org/entity/Q29938737
# 23     BRCA2  http://www.wikidata.org/entity/Q29938738
# 24     BRCA2  http://www.wikidata.org/entity/Q29938739
# 25     BRCA2  http://www.wikidata.org/entity/Q29938740
# 26     BRCA2  http://www.wikidata.org/entity/Q29938741
# 27     BRCA2  http://www.wikidata.org/entity/Q29938742
# 28     BRCA2  http://www.wikidata.org/entity/Q29938743
# 29     PALB2  http://www.wikidata.org/entity/Q28371488
# 30     PALB2  http://www.wikidata.org/entity/Q28439607
# 31     FANCC  http://www.wikidata.org/entity/Q28445146
#
#                     variantLabel
# 0                   BRCA1 P968FS
# 1         BRCA1 LOSS-OF-FUNCTION
# 2                 BRCA1 MUTATION
# 3               BRCA1 EXPRESSION
# 4          BRCA1 UNDEREXPRESSION
# 5      BRCA1 TRUNCATING MUTATION
# 6                      BRCA1 M1V
# 7                      BRCA1 M1I
# 8                     BRCA1 C61G
# 9                     BRCA1 C64Y
# 10                    BRCA1 R71G
# 11                    BRCA1 R71K
# 12                  BRCA1 R1495M
# 13                  BRCA1 E1559K
# 14                  BRCA1 D1692N
# 15                  BRCA1 R1443*
# 16                  BRCA1 Q1467*
# 17                  BRCA1 W1815X
# 18                  BRCA2 D3095E
# 19     BRCA2 TRUNCATING MUTATION
# 20        BRCA2 LOSS-OF-FUNCTION
# 21                BRCA2 MUTATION
# 22                     BRCA2 M1R
# 23                     BRCA2 M1I
# 24                   BRCA2 V159M
# 25                   BRCA2 V211L
# 26                   BRCA2 V211I
# 27                  BRCA2 R2336P
# 28                  BRCA2 R2336H
# 29  PALB2 BIALLELIC INACTIVATION
# 30               PALB2 L531FS*30
# 31        FANCC LOSS-OF-FUNCTION

# %% [markdown]
# ### Get variants on these genes that are negative therapeutic predictors for drugs where the drug is used to treat any kind of cancer

# %%
query = """select ?geneLabel ?variantLabel ?variant ?drugLabel ?cid ?diseaseLabel ?ref where {
  values ?hgnc {**hgnc**}
  # ?gene wdt:P353 ?hgnc .
  # ?variant wdt:P3433 ?gene .
  # ?variant p:P3355 ?s .
  # ?s ps:P3355 ?drug .
  # ?s prov:wasDerivedFrom/pr:P854 ?ref .
  # ?drug wdt:P662 ?cid .
  # ?s pq:P2175 ?disease .
  # ?disease wdt:P279* wd:Q12078 .
  SERVICE wikibase:label {  bd:serviceParam wikibase:language "en" }
}
"""

# %%
# Core FA genes
query_and_format_result(query.replace("**hgnc**", core_genes_quotes))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# All FA genes
query_and_format_result(query.replace("**hgnc**", all_genes_quotes))
# Out:
#         cid   diseaseLabel drugLabel geneLabel  \
# 0  23725625  breast cancer  olaparib     BRCA2
# 1  23725625  breast cancer  olaparib     BRCA1
#
#                                                   ref  \
# 0  https://civic.genome.wustl.edu/links/evidence/1776
# 1  https://civic.genome.wustl.edu/links/evidence/1775
#
#                                     variant    variantLabel
# 0  http://www.wikidata.org/entity/Q28444961  BRCA2 MUTATION
# 1  http://www.wikidata.org/entity/Q28444960  BRCA1 MUTATION

# %% [markdown]
# ### What about any kind of predictor for any drug?

# %%
query = """
select ?geneLabel ?variantLabel ?variant ?drugLabel ?cid ?diseaseLabel ?ref ?pLabel where {
  values ?hgnc {**hgnc**}
  values ?predictor {p:P3355 p:P3354}
  # ?gene wdt:P353 ?hgnc .
  # ?variant wdt:P3433 ?gene .
  # ?variant ?predictor ?s .
  # ?p wikibase:claim ?predictor .
  # ?s ps:P3355|ps:P3354 ?drug .
  # ?s prov:wasDerivedFrom/pr:P854 ?ref .
  # ?s pq:P2175 ?disease .
  SERVICE wikibase:label {  bd:serviceParam wikibase:language "en" }
}"""

# %%
# Core FA genes
query_and_format_result(query.replace("**hgnc**", core_genes_quotes))
# Out:
#         diseaseLabel     drugLabel geneLabel                          pLabel  \
# 0  pancreatic cancer     melphalan     FANCC  positive therapeutic predictor
# 1  pancreatic cancer   gemcitabine     FANCC  positive therapeutic predictor
# 2  pancreatic cancer     mitomycin     FANCC  positive therapeutic predictor
# 3  pancreatic cancer  chlorambucil     FANCC  positive therapeutic predictor
# 4  pancreatic cancer     cisplatin     FANCC  positive therapeutic predictor
#
#                                                   ref  \
# 0  https://civic.genome.wustl.edu/links/evidence/1307
# 1  https://civic.genome.wustl.edu/links/evidence/1307
# 2  https://civic.genome.wustl.edu/links/evidence/1307
# 3  https://civic.genome.wustl.edu/links/evidence/1307
# 4  https://civic.genome.wustl.edu/links/evidence/1307
#
#                                     variant            variantLabel
# 0  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION
# 1  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION
# 2  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION
# 3  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION
# 4  http://www.wikidata.org/entity/Q28445146  FANCC LOSS-OF-FUNCTION

# %%
# All FA genes
query_and_format_result(query.replace("**hgnc**", all_genes_quotes))
# Out:
#                               diseaseLabel     drugLabel geneLabel  \
# 0                            breast cancer      olaparib     BRCA2
# 1                            breast cancer      olaparib     BRCA1
# 2                                   cancer      olaparib     BRCA2
# 3                                   cancer      olaparib     BRCA2
# 4                                   cancer      olaparib     BRCA2
# 5   triple-receptor negative breast cancer     cisplatin     BRCA2
# 6   triple-receptor negative breast cancer   Carboplatin     BRCA2
# 7                        pancreatic cancer     mitomycin     BRCA2
# 8                           ovarian cancer      olaparib     BRCA1
# 9                           ovarian cancer      olaparib     BRCA1
# 10                          ovarian cancer      olaparib     BRCA2
# 11                          ovarian cancer      olaparib     BRCA2
# 12                          ovarian cancer     rucaparib     BRCA1
# 13                                  cancer      olaparib     BRCA1
# 14                                  cancer      olaparib     BRCA1
# 15                                  cancer      olaparib     BRCA1
# 16  triple-receptor negative breast cancer   Carboplatin     BRCA1
# 17  triple-receptor negative breast cancer     cisplatin     BRCA1
# 18                            mesothelioma   Vinorelbine     BRCA1
# 19                         prostate cancer      olaparib     PALB2
# 20                       pancreatic cancer     mitomycin     PALB2
# 21                       pancreatic cancer     melphalan     FANCC
# 22                       pancreatic cancer   gemcitabine     FANCC
# 23                       pancreatic cancer     mitomycin     FANCC
# 24                       pancreatic cancer  chlorambucil     FANCC
# 25                       pancreatic cancer     cisplatin     FANCC
# 26                          ovarian cancer     rucaparib     BRCA2
# 27                          ovarian cancer     rucaparib     BRCA1
# 28                          ovarian cancer     rucaparib     BRCA1
# 29                          ovarian cancer     rucaparib     BRCA2
# 30                          ovarian cancer     rucaparib     BRCA1
# 31                          ovarian cancer     rucaparib     BRCA1
# 32                          ovarian cancer     rucaparib     BRCA1
# 33                          ovarian cancer     rucaparib     BRCA1
# 34                          ovarian cancer     rucaparib     BRCA2
# 35                          ovarian cancer     rucaparib     BRCA1
# 36                          ovarian cancer     rucaparib     BRCA1
# 37                          ovarian cancer     rucaparib     BRCA2
# 38                          ovarian cancer     rucaparib     BRCA2
# 39                          ovarian cancer     rucaparib     BRCA1
# 40                          ovarian cancer     rucaparib     BRCA2
# 41                          ovarian cancer     rucaparib     BRCA1
# 42                          ovarian cancer     rucaparib     BRCA1
# 43                          ovarian cancer     rucaparib     BRCA2
# 44                          ovarian cancer      olaparib     BRCA1
#
#                             pLabel  \
# 0   negative therapeutic predictor
# 1   negative therapeutic predictor
# 2   positive therapeutic predictor
# 3   positive therapeutic predictor
# 4   positive therapeutic predictor
# 5   positive therapeutic predictor
# 6   positive therapeutic predictor
# 7   positive therapeutic predictor
# 8   positive therapeutic predictor
# 9   positive therapeutic predictor
# 10  positive therapeutic predictor
# 11  positive therapeutic predictor
# 12  positive therapeutic predictor
# 13  positive therapeutic predictor
# 14  positive therapeutic predictor
# 15  positive therapeutic predictor
# 16  positive therapeutic predictor
# 17  positive therapeutic predictor
# 18  positive therapeutic predictor
# 19  positive therapeutic predictor
# 20  positive therapeutic predictor
# 21  positive therapeutic predictor
# 22  positive therapeutic predictor
# 23  positive therapeutic predictor
# 24  positive therapeutic predictor
# 25  positive therapeutic predictor
# 26  positive therapeutic predictor
# 27  positive therapeutic predictor
# 28  positive therapeutic predictor
# 29  positive therapeutic predictor
# 30  positive therapeutic predictor
# 31  positive therapeutic predictor
# 32  positive therapeutic predictor
# 33  positive therapeutic predictor
# 34  positive therapeutic predictor
# 35  positive therapeutic predictor
# 36  positive therapeutic predictor
# 37  positive therapeutic predictor
# 38  positive therapeutic predictor
# 39  positive therapeutic predictor
# 40  positive therapeutic predictor
# 41  positive therapeutic predictor
# 42  positive therapeutic predictor
# 43  positive therapeutic predictor
# 44  positive therapeutic predictor
#
#                                                    ref  \
# 0   https://civic.genome.wustl.edu/links/evidence/1776
# 1   https://civic.genome.wustl.edu/links/evidence/1775
# 2   https://civic.genome.wustl.edu/links/evidence/1371
# 3   https://civic.genome.wustl.edu/links/evidence/1678
# 4   https://civic.genome.wustl.edu/links/evidence/1773
# 5   https://civic.genome.wustl.edu/links/evidence/1685
# 6   https://civic.genome.wustl.edu/links/evidence/1685
# 7   https://civic.genome.wustl.edu/links/evidence/1308
# 8    https://civic.genome.wustl.edu/links/evidence/211
# 9    https://civic.genome.wustl.edu/links/evidence/845
# 10   https://civic.genome.wustl.edu/links/evidence/212
# 11   https://civic.genome.wustl.edu/links/evidence/650
# 12  https://civic.genome.wustl.edu/links/evidence/1897
# 13  https://civic.genome.wustl.edu/links/evidence/1370
# 14  https://civic.genome.wustl.edu/links/evidence/1677
# 15  https://civic.genome.wustl.edu/links/evidence/1772
# 16  https://civic.genome.wustl.edu/links/evidence/1684
# 17  https://civic.genome.wustl.edu/links/evidence/1684
# 18   https://civic.genome.wustl.edu/links/evidence/933
# 19  https://civic.genome.wustl.edu/links/evidence/1963
# 20  https://civic.genome.wustl.edu/links/evidence/1305
# 21  https://civic.genome.wustl.edu/links/evidence/1307
# 22  https://civic.genome.wustl.edu/links/evidence/1307
# 23  https://civic.genome.wustl.edu/links/evidence/1307
# 24  https://civic.genome.wustl.edu/links/evidence/1307
# 25  https://civic.genome.wustl.edu/links/evidence/1307
# 26  https://civic.genome.wustl.edu/links/evidence/2885
# 27  https://civic.genome.wustl.edu/links/evidence/2877
# 28  https://civic.genome.wustl.edu/links/evidence/2874
# 29  https://civic.genome.wustl.edu/links/evidence/2884
# 30  https://civic.genome.wustl.edu/links/evidence/2875
# 31  https://civic.genome.wustl.edu/links/evidence/2872
# 32  https://civic.genome.wustl.edu/links/evidence/2878
# 33  https://civic.genome.wustl.edu/links/evidence/2873
# 34  https://civic.genome.wustl.edu/links/evidence/2880
# 35  https://civic.genome.wustl.edu/links/evidence/2870
# 36  https://civic.genome.wustl.edu/links/evidence/2869
# 37  https://civic.genome.wustl.edu/links/evidence/2882
# 38  https://civic.genome.wustl.edu/links/evidence/2881
# 39  https://civic.genome.wustl.edu/links/evidence/2868
# 40  https://civic.genome.wustl.edu/links/evidence/2879
# 41  https://civic.genome.wustl.edu/links/evidence/2876
# 42  https://civic.genome.wustl.edu/links/evidence/2871
# 43  https://civic.genome.wustl.edu/links/evidence/2883
# 44  https://civic.genome.wustl.edu/links/evidence/4623
#
#                                      variant                  variantLabel
# 0   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 1   http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 2   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 3   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 4   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 5   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 6   http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 7   http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 8   http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 9   http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 10  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 11  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 12  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 13  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 14  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 15  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 16  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 17  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 18  http://www.wikidata.org/entity/Q28445085              BRCA1 EXPRESSION
# 19  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 20  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 21  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 22  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 23  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 24  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 25  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 26  http://www.wikidata.org/entity/Q29938743                  BRCA2 R2336H
# 27  http://www.wikidata.org/entity/Q29938735                  BRCA1 R1443*
# 28  http://www.wikidata.org/entity/Q29938730                  BRCA1 R1495M
# 29  http://www.wikidata.org/entity/Q29938742                  BRCA2 R2336P
# 30  http://www.wikidata.org/entity/Q29938732                  BRCA1 E1559K
# 31  http://www.wikidata.org/entity/Q29938727                    BRCA1 R71G
# 32  http://www.wikidata.org/entity/Q29938736                  BRCA1 Q1467*
# 33  http://www.wikidata.org/entity/Q29938728                    BRCA1 R71K
# 34  http://www.wikidata.org/entity/Q29938738                     BRCA2 M1I
# 35  http://www.wikidata.org/entity/Q29938725                    BRCA1 C61G
# 36  http://www.wikidata.org/entity/Q29938724                     BRCA1 M1I
# 37  http://www.wikidata.org/entity/Q29938740                   BRCA2 V211L
# 38  http://www.wikidata.org/entity/Q29938739                   BRCA2 V159M
# 39  http://www.wikidata.org/entity/Q29938723                     BRCA1 M1V
# 40  http://www.wikidata.org/entity/Q29938737                     BRCA2 M1R
# 41  http://www.wikidata.org/entity/Q29938734                  BRCA1 D1692N
# 42  http://www.wikidata.org/entity/Q29938726                    BRCA1 C64Y
# 43  http://www.wikidata.org/entity/Q29938741                   BRCA2 V211I
# 44  http://www.wikidata.org/entity/Q32965138                  BRCA1 W1815X
