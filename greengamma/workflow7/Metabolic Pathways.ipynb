# %% [markdown]
# # Metabolic Pathways

# %% [markdown]
# ## Query Pattern

# %% [markdown]
# Most of our information about metabolism of chemicals comes from kegg.  We are not storing kegg reactions as entities themselves.  Instead, if we have a reaction where chemical A -> chemical B, and it's catalyzed by a gene C, we create the following relationships:
#
# ```
# A derives_into B
# C increases_degradation_of A
# C increases_synthesis_of B
# ```
#
# So we can look for reactions using that pattern.

# %% [markdown]
# ## Functions

# %%
import requests
import pandas as pd

robokop_server = 'robokop.renci.org'

def quick(question):
    url=f'http://{robokop_server}:80/api/simple/quick/'
    #print(url)
    response = requests.post(url,json=question)
    #print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return {}
    #return response

# %%
def make_decomposition_question(chemical_identifier):
    """Given a chemical input, construct a graph query tofind chemicals that it metabolizes into, 
    and the gene that catalyzes the rxn."""
    question = {
                'machine_question': {
                    'nodes': [
                        {
                            'id': 'n0',
                            'curie': chemical_identifier,
                            'type': 'chemical_substance'
                        },
                        {
                            'id': 'n1',
                            'type': 'gene'
                        },
                        {
                            'id': 'n2',
                            'type': 'chemical_substance'
                        }
                    ],
                    'edges': [
                        {
                            'id': 'e0',
                            'source_id': 'n1',
                            'target_id': 'n0',
                            'type': 'increases_degradation_of'
                        },
                        {
                            'id': 'e1',
                            'source_id': 'n1',
                            'target_id': 'n2',
                            'type': 'increases_synthesis_of'
                        },
                        {
                            'id': 'e2',
                            'source_id': 'n0',
                            'target_id': 'n2',
                            'type': 'derives_into'
                        }
                    ]
                }
            }
    return question

# %%
import pandas as pd
def answers2frame(graph_answers, input_chem):
    """Convert the answer from a decomposition query into a pandas DataFrame"""
    answers = []
    for graph_answer in graph_answers['answers']:
        try:
            for node in graph_answer['nodes']:
                if node['type'] == 'gene':
                    gene = node
                elif node['type'] == 'chemical_substance':
                    if node['id'] == input_chem:
                        reactant=node
                    else:
                        product=node
            ans = { 'score': graph_answer['score'],
                    'reactant': reactant['name'] if 'name' in reactant else reactant['id'],
                    'gene': gene['name'],
                    'product': product['name'] if 'name' in product else product['id'],
                    'product_id': product['id']
                  }
        except IndexError:
            #Can this happen here?
            continue
        answers.append(ans)
    df = pd.DataFrame(answers)
    ordered_columns = ['score','reactant','gene','product','product_id']
    df = df[ordered_columns]
    return df

# %% [markdown]
# ## Example

# %% [markdown]
# Suppose we wanted to investigate the metabolism of Prostaglandin H2 (CHEBI:15554).  We can do that with the following code, which creates the question, calls the ROBOKOP quick service, then creates and displays a data frame of the answers.

# %%
chem_id = 'CHEBI:15554'  #Prostaglandin H2
q = make_decomposition_question(chem_id)
a = quick(q)
# Out:
# http://robokop.renci.org:80/api/simple/quick/

# %%
df = answers2frame(a,chem_id)
df
# Out:
#    score          reactant    gene                product   product_id
# 0      0  prostaglandin H2   HPGDS       prostaglandin D2  CHEBI:15555
# 1      0  prostaglandin H2  TBXAS1         thromboxane A2  CHEBI:15627
# 2      0  prostaglandin H2   PTGES       prostaglandin E2  CHEBI:15551
# 3      0  prostaglandin H2  PTGES2       prostaglandin E2  CHEBI:15551
# 4      0  prostaglandin H2   PTGDS       prostaglandin D2  CHEBI:15555
# 5      0  prostaglandin H2  PTGES3       prostaglandin E2  CHEBI:15551
# 6      0  prostaglandin H2  PRXL2B  prostaglandin F2alpha  CHEBI:15553

# %% [markdown]
# ## Tracing Pathways Recursively

# %% [markdown]
# The code above asks about a single step.  Given a chemical, what does it metabolize into?  Now, we can write a function to recursively take the outputs and pass them back as inputs, so that we can trace out multiple steps.  The tricky thing here is that there are a bunch of 'balancing' chemicals that we don't want to consider part of our pathways.  These are things like water or carbon dioxide that will often appear as the product of a reaction. But we don't want to then use them to look for reactions where they are on the left hand side, because we will get an explosion of reactions.

# %%
def find_pathway(input_chemical_with_label,accumulator,max_products=0):
    """Pass in the identifier for the chemical you want the metabolic pathway of, and an empty dict for accumulator.
    Results will be passed out in accumulator."""
    dead_ends = ['CHEBI:16526', #carbon dioxide
                 'CHEBI:15741', #succinic acid / succinate
                 'CHEBI:15846', #NAD(+)
                 'CHEBI:18009', #NADP(+)
                 'CHEBI:44409', #NADP Zwitterion
                 'CHEBI:58349', #NADP(3-)
                 'CHEBI:16908', #NADH
                 'CHEBI:16474', #NADPH
                 'CHEBI:15377', #Water
                 'CHEBI:15379', #dioxygen
                 'CHEBI:16526', #carbon dioxide
                 'CHEBI:16842', #formaldehyde
                 'CHEBI:17659', #UDP
                 'CHEBI:15713', #ADP
                 'CHEBI:16761', #ADP? 
                 'CHEBI:16134', #ammonia
                 'CHEBI:16240', #hydrogen peroxide
                 'CHEBI:24636', #proton
                 'CHEBI:15378', #hydron 
                 'CHEBI:29888', #diphosphoric acid
                 'CHEBI:30769', #citric acid
                ]
    input_chemical = input_chemical_with_label[0]
    input_label = input_chemical_with_label[1]
    if input_chemical_with_label not in accumulator and input_chemical not in dead_ends:
        print(input_chemical, input_label)
        q = make_decomposition_question(input_chemical)
        a = quick(q)
        answers = []
        if 'answers' in a:
            kg_nodes_by_id = { n['id']: n for n in a['knowledge_graph']['nodes'] }
            for answer in a['answers']:
                gene_id = answer['node_bindings']['n1']
                gene = kg_nodes_by_id[gene_id]
                product_id = answer['node_bindings']['n2']
                product = kg_nodes_by_id[product_id]
                if product['id'] not in dead_ends:
                    answers.append( {'gene':gene, 'product':product, 'score':answer['score']})
            accumulator[input_chemical_with_label] = answers
            distinct_products = set([(answer['product']['id'],answer['product']['name']) for answer in answers])
            #print('  ',len(distinct_products))
            if max_products > 0 and len(distinct_products) <= max_products:
                for product in distinct_products:
                    find_pathway(product,accumulator)

# %%
q = make_decomposition_question('CHEBI:50616')
a = quick(q)
import json
print(json.dumps(a,indent=4))
# Out:
# "No results found"

# %%
kg_nodes_by_id = { n['id']: n for n in a['knowledge_graph']['nodes'] }

# %%
pathway = {}
chem_id = ('CHEBI:17053', 'L-aspartic acid')
#chem_id = ('CHEBI:6121','ketamine') #nothing
#chem_id = ('CHEBI:16236', 'ethanol')
#chem_id = ('CHEBI:16714' , 'codeine')
#chem_id = ('CHEBI:15554', 'Prostaglandin H2')
#chem_id = ('CHEBI:18243', 'dopamine')
#chem_id = ('CHEBI:16436','CDP-choline')
#chem_id = ('CHEBI:27732','caffeine')
#chem_id = ('CHEBI:41774', 'tamoxifen')
#chem_id = ('CHEBI:27432', 'alpha-linolenic acid')

find_pathway(chem_id,pathway,max_products=20)
# Out:
# CHEBI:17053 L-aspartic acid
# CHEBI:26078 phosphoric acid
# CHEBI:50616 iminoaspartic acid
# CHEBI:17196 L-asparagine
# CHEBI:21547 N-acetyl-L-aspartic acid
# CHEBI:57966 beta-alanine zwitterion
# CHEBI:16015 L-glutamic acid
# CHEBI:58048 L-asparagine zwitterion
# CHEBI:30744 oxaloacetic acid
# CHEBI:18319 SAICAR
# CHEBI:16958 beta-alanine
# CHEBI:17552 GDP
# CHEBI:16027 adenosine 5'-monophosphate
# CHEBI:15859 N-carbamoyl-L-aspartic acid
# CHEBI:18237 glutamic acid

# %%
flatter = []
for k,v in pathway.items():
    for o in v:
        flatter.append({'reactant':k[0],
                        'reactantname': k[1],
                        'geneid':o['gene']['id'], 
                        'genename':o['gene']['name'] if 'name' in o['gene'] else '', 
                        'productid': o['product']['id'], 
                        'productname': o['product']['name'] if 'name' in o['product'] else '',
                        'score': o['score']})

# %%
df = pd.DataFrame(flatter)
ordered_columns = ['reactant','reactantname','genename','productname','productid']
df = df[ordered_columns]

df.sort_values(by=['reactantname','productname','genename'],inplace=True)

from IPython.display import display
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#         reactant                reactantname      genename  \
# 144  CHEBI:17552                         GDP           AK9
# 145  CHEBI:17552                         GDP          NME1
# 134  CHEBI:17552                         GDP     NME1-NME2
# 137  CHEBI:17552                         GDP          NME2
# 133  CHEBI:17552                         GDP          NME3
# 139  CHEBI:17552                         GDP          NME4
# 141  CHEBI:17552                         GDP          NME6
# 138  CHEBI:17552                         GDP          NME7
# 142  CHEBI:17552                         GDP        ENTPD1
# 136  CHEBI:17552                         GDP        ENTPD3
# 135  CHEBI:17552                         GDP        ENTPD8
# 146  CHEBI:17552                         GDP        ENTPD1
# 143  CHEBI:17552                         GDP        ENTPD3
# 140  CHEBI:17552                         GDP        ENTPD8
# 67   CHEBI:17196                L-asparagine          ASPG
# 69   CHEBI:17196                L-asparagine          NARS
# 68   CHEBI:17196                L-asparagine         NARS2
# 110  CHEBI:58048     L-asparagine zwitterion          ASPG
# 112  CHEBI:58048     L-asparagine zwitterion          NARS
# 111  CHEBI:58048     L-asparagine zwitterion         NARS2
# 12   CHEBI:17053             L-aspartic acid          ADSS
# 23   CHEBI:17053             L-aspartic acid        ADSSL1
# 3    CHEBI:17053             L-aspartic acid          ASNS
# 10   CHEBI:17053             L-aspartic acid          ASNS
# 26   CHEBI:17053             L-aspartic acid          ASNS
# 8    CHEBI:17053             L-aspartic acid           CAD
# 17   CHEBI:17053             L-aspartic acid          GOT1
# 13   CHEBI:17053             L-aspartic acid          GOT2
# 1    CHEBI:17053             L-aspartic acid         NAT8L
# 18   CHEBI:17053             L-aspartic acid           CAD
# 25   CHEBI:17053             L-aspartic acid         PAICS
# 29   CHEBI:17053             L-aspartic acid          ASNS
# 15   CHEBI:17053             L-aspartic acid          ASS1
# 0    CHEBI:17053             L-aspartic acid          DARS
# 28   CHEBI:17053             L-aspartic acid         DARS2
# 20   CHEBI:17053             L-aspartic acid         GADL1
# 27   CHEBI:17053             L-aspartic acid         GADL1
# 5    CHEBI:17053             L-aspartic acid          ASNS
# 6    CHEBI:17053             L-aspartic acid           CAD
# 19   CHEBI:17053             L-aspartic acid          GOT1
# 2    CHEBI:17053             L-aspartic acid          GOT2
# 11   CHEBI:17053             L-aspartic acid         ASPDH
# 24   CHEBI:17053             L-aspartic acid         ASPDH
# 22   CHEBI:17053             L-aspartic acid          GOT1
# 14   CHEBI:17053             L-aspartic acid          GOT2
# 9    CHEBI:17053             L-aspartic acid         IL4I1
# 16   CHEBI:17053             L-aspartic acid          ADSS
# 7    CHEBI:17053             L-aspartic acid        ADSSL1
# 4    CHEBI:17053             L-aspartic acid           CAD
# 21   CHEBI:17053             L-aspartic acid         PAICS
# 94   CHEBI:16015             L-glutamic acid        RIMKLA
# 106  CHEBI:16015             L-glutamic acid        RIMKLB
# 92   CHEBI:16015             L-glutamic acid         GLUD1
# 89   CHEBI:16015             L-glutamic acid         GLUD2
# 97   CHEBI:16015             L-glutamic acid          FTCD
# 93   CHEBI:16015             L-glutamic acid          PPAT
# 96   CHEBI:16015             L-glutamic acid      ALDH18A1
# 85   CHEBI:16015             L-glutamic acid          GCLC
# 98   CHEBI:16015             L-glutamic acid          GLUL
# 107  CHEBI:16015             L-glutamic acid          PPAT
# 101  CHEBI:16015             L-glutamic acid          GLUL
# 100  CHEBI:16015             L-glutamic acid          PPAT
# 95   CHEBI:16015             L-glutamic acid          NAGS
# 91   CHEBI:16015             L-glutamic acid          FTCD
# 88   CHEBI:16015             L-glutamic acid          FTCD
# 104  CHEBI:16015             L-glutamic acid         EARS2
# 99   CHEBI:16015             L-glutamic acid          EPRS
# 108  CHEBI:16015             L-glutamic acid          FPGS
# 83   CHEBI:16015             L-glutamic acid          GAD1
# 84   CHEBI:16015             L-glutamic acid          GAD2
# 86   CHEBI:16015             L-glutamic acid          GAD1
# 87   CHEBI:16015             L-glutamic acid          GAD2
# 102  CHEBI:16015             L-glutamic acid          FPGS
# 103  CHEBI:16015             L-glutamic acid          GCLC
# 105  CHEBI:16015             L-glutamic acid          GLUL
# 109  CHEBI:16015             L-glutamic acid        RIMKLA
# 90   CHEBI:16015             L-glutamic acid        RIMKLB
# 71   CHEBI:21547    N-acetyl-L-aspartic acid        RIMKLA
# 70   CHEBI:21547    N-acetyl-L-aspartic acid        RIMKLB
# 72   CHEBI:21547    N-acetyl-L-aspartic acid          ASPA
# 74   CHEBI:21547    N-acetyl-L-aspartic acid          ASPA
# 73   CHEBI:21547    N-acetyl-L-aspartic acid        RIMKLA
# 14                                    oxaloacetic acid  CHEBI:30744
# 9                                     oxaloacetic acid  CHEBI:30744
# 16                                     phosphoric acid  CHEBI:26078
# 7                                      phosphoric acid  CHEBI:26078
# 4                                      phosphoric acid  CHEBI:26078
# 21                                     phosphoric acid  CHEBI:26078
# 94   2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 106  2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 92                                  2-oxoglutaric acid  CHEBI:30915
# 89                                  2-oxoglutaric acid  CHEBI:30915
# 97                        5,6,7,8-tetrahydrofolic acid  CHEBI:20506
# 93     5-O-phosphono-alpha-D-ribofuranosyl diphosphate  CHEBI:17111
# 96                          L-gamma-glutamyl phosphate  CHEBI:17798
# 85                         L-gamma-glutamyl-L-cysteine  CHEBI:17515
# 98                                         L-glutamine  CHEBI:18050
# 107                                        L-glutamine  CHEBI:18050
# 101                             L-glutamine zwitterion  CHEBI:58359
# 100                             L-glutamine zwitterion  CHEBI:58359
# 95                            N-acetyl-L-glutamic acid  CHEBI:17533
# 91                       N-formimidoyl-L-glutamic acid   CHEBI:7274
# 88                            N-formyl-L-glutamic acid  CHEBI:48309
# 104                         adenosine 5'-monophosphate  CHEBI:16027
# 99                          adenosine 5'-monophosphate  CHEBI:16027
# 108                                  dihydrofolic acid  CHEBI:15633
# 83                             gamma-aminobutyric acid  CHEBI:16865
# 84                             gamma-aminobutyric acid  CHEBI:16865
# 86                  gamma-aminobutyric acid zwitterion  CHEBI:59888
# 87                  gamma-aminobutyric acid zwitterion  CHEBI:59888
# 102                                    phosphoric acid  CHEBI:26078
# 103                                    phosphoric acid  CHEBI:26078
# 105                                    phosphoric acid  CHEBI:26078
# 109                                    phosphoric acid  CHEBI:26078
# 90                                     phosphoric acid  CHEBI:26078
# 71   2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 70   2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 72                                     L-aspartic acid  CHEBI:17053
# 74                                         acetic acid  CHEBI:15366
# 73                                     phosphoric acid  CHEBI:26078
# 75                                     phosphoric acid  CHEBI:26078
# 122                                AICA ribonucleotide  CHEBI:18406
# 121                                       fumaric acid  CHEBI:18012
# 160    5-O-phosphono-alpha-D-ribofuranosyl diphosphate  CHEBI:17111
# 161                                                IMP  CHEBI:17202
# 157                                                IMP  CHEBI:17202
# 154                                                IMP  CHEBI:17202
# 173                                            adenine  CHEBI:16708
# 152                                          adenosine  CHEBI:16335
# 174                                          adenosine  CHEBI:16335
# 177                                          adenosine  CHEBI:16335
# 163                                          adenosine  CHEBI:16335
# 164                                          adenosine  CHEBI:16335
# 170                                          adenosine  CHEBI:16335
# 172                                          adenosine  CHEBI:16335
# 166                                          adenosine  CHEBI:16335
# 147                                          adenosine  CHEBI:16335
# 158                                          adenosine  CHEBI:16335
# 148                                    phosphoric acid  CHEBI:26078
# 179                                    phosphoric acid  CHEBI:26078
# 150                                    phosphoric acid  CHEBI:26078
# 178                                    phosphoric acid  CHEBI:26078
# 159                                    phosphoric acid  CHEBI:26078
# 175                                    phosphoric acid  CHEBI:26078
# 169                                    phosphoric acid  CHEBI:26078
# 168                                    phosphoric acid  CHEBI:26078
# 149                                    phosphoric acid  CHEBI:26078
# 151                                    phosphoric acid  CHEBI:26078
# 167                           thiamine(1+) diphosphate   CHEBI:9532
# 171                           thiamine(1+) diphosphate   CHEBI:9532
# 180                           thiamine(1+) diphosphate   CHEBI:9532
# 162                           thiamine(1+) diphosphate   CHEBI:9532
# 156                           thiamine(1+) diphosphate   CHEBI:9532
# 153                           thiamine(1+) diphosphate   CHEBI:9532
# 176                           thiamine(1+) diphosphate   CHEBI:9532
# 155                           thiamine(1+) diphosphate   CHEBI:9532
# 165                           thiamine(1+) diphosphate   CHEBI:9532
# 129                                3-oxopropanoic acid  CHEBI:17960
# 130                                    L-glutamic acid  CHEBI:16015
# 127                                           anserine  CHEBI:18323
# 132                                anserine zwitterion  CHEBI:58445
# 131                             beta-alanyl-L-arginine  CHEBI:28712
# 126                               beta-alanyl-L-lysine  CHEBI:27749
# 125                                          carnosine  CHEBI:15727
# 123                               carnosine zwitterion  CHEBI:57485
# 128                                      glutamic acid  CHEBI:18237
# 124                                    phosphoric acid  CHEBI:26078
# 82                                 3-oxopropanoic acid  CHEBI:17960
# 77                                     L-glutamic acid  CHEBI:16015
# 76                                            anserine  CHEBI:18323
# 78                              beta-alanyl-L-arginine  CHEBI:28712
# 81                                beta-alanyl-L-lysine  CHEBI:27749
# 80                                           carnosine  CHEBI:15727
# 79                                     phosphoric acid  CHEBI:26078
# 191  2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 187  2-[(2-acetamido-3-carboxy-1-oxopropyl)amino]pe...  CHEBI:95120
# 185                                 2-oxoglutaric acid  CHEBI:30915
# 184                                 2-oxoglutaric acid  CHEBI:30915
# 190                       5,6,7,8-tetrahydrofolic acid  CHEBI:20506
# 199    5-O-phosphono-alpha-D-ribofuranosyl diphosphate  CHEBI:17111
# 202                         L-gamma-glutamyl phosphate  CHEBI:17798
# 183                        L-gamma-glutamyl-L-cysteine  CHEBI:17515
# 188                                        L-glutamine  CHEBI:18050
# 200                                        L-glutamine  CHEBI:18050
# 189                           N-acetyl-L-glutamic acid  CHEBI:17533
# 197                      N-formimidoyl-L-glutamic acid   CHEBI:7274
# 203                           N-formyl-L-glutamic acid  CHEBI:48309
# 195                         adenosine 5'-monophosphate  CHEBI:16027
# 186                         adenosine 5'-monophosphate  CHEBI:16027
# 194                                  dihydrofolic acid  CHEBI:15633
# 181                            gamma-aminobutyric acid  CHEBI:16865
# 182                            gamma-aminobutyric acid  CHEBI:16865
# 193                                    phosphoric acid  CHEBI:26078
# 201                                    phosphoric acid  CHEBI:26078
# 196                                    phosphoric acid  CHEBI:26078
# 192                                    phosphoric acid  CHEBI:26078
# 198                                    phosphoric acid  CHEBI:26078
# 118                                                ATP  CHEBI:15422
# 117                                                GDP  CHEBI:17552
# 120                                                GDP  CHEBI:17552
# 115                                                IDP  CHEBI:17808
# 116                                                IDP  CHEBI:17808
# 119                            phosphoenolpyruvic acid  CHEBI:44897
# 114                            phosphoenolpyruvic acid  CHEBI:44897
# 113                                       pyruvic acid  CHEBI:32816
# 39                                           1H-purine  CHEBI:35586
# 37                  2-deoxy-alpha-D-ribose 1-phosphate  CHEBI:11563
# 42                  2-deoxy-alpha-D-ribose 1-phosphate  CHEBI:11563
# 46          3-phospho-D-glyceroyl dihydrogen phosphate  CHEBI:16001
# 33          3-phospho-D-glyceroyl dihydrogen phosphate  CHEBI:16001
# 60                                           3H-purine  CHEBI:35588
# 58                  5-deoxy-alpha-D-ribose 1-phosphate  CHEBI:48462
# 63                                      5-fluorouracil  CHEBI:46345
# 56                                      5-fluorouracil  CHEBI:46345
# 59                                      5-fluorouracil  CHEBI:46345
# 53                                           7H-purine  CHEBI:17258
# 51                                         7H-xanthine  CHEBI:48517
# 43                                           9H-purine  CHEBI:35589
# 52                                         9H-xanthine  CHEBI:17712
# 45                                                 ATP  CHEBI:15422
# 47                                                 CDP  CHEBI:17239
# 44                                D-ribose 1-phosphate  CHEBI:35425
# 38                                D-ribose 1-phosphate  CHEBI:35425
# 64                                D-ribose 1-phosphate  CHEBI:35425
# 36                                                 GDP  CHEBI:17552
# 66                                                 GDP  CHEBI:17552
# 62                          L-gamma-glutamyl phosphate  CHEBI:17798
# 61          S-methyl-5-thio-alpha-D-ribose 1-phosphate  CHEBI:27859
# 54                                             adenine  CHEBI:16708
# 35                                             adenine  CHEBI:16708
# 34                         alpha-D-glucose 1-phosphate  CHEBI:29042
# 49                         alpha-D-glucose 1-phosphate  CHEBI:29042
# 50                         alpha-D-glucose 1-phosphate  CHEBI:29042
# 32                         alpha-D-glucose 1-phosphate  CHEBI:29042
# 31                          alpha-D-ribose 1-phosphate  CHEBI:16300
# 65                          alpha-D-ribose 1-phosphate  CHEBI:16300
# 30                          alpha-D-ribose 1-phosphate  CHEBI:16300
# 40                                             guanine  CHEBI:16235
# 55                                        hypoxanthine  CHEBI:17368
# 57                                        nicotinamide  CHEBI:17154
# 48                                      nicotinic acid  CHEBI:15940
# 41                                              uracil  CHEBI:17568

# %%
products_and_reactants = df[ ['reactant','reactantname','productid','productname']]
products_and_reactants.drop_duplicates(inplace=True)
products_and_reactants
# Out:
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        reactant reactantname    productid             productname
# 0   CHEBI:16714      codeine  CHEBI:17303                morphine
# 24  CHEBI:16714      codeine  CHEBI:80579              norcodeine
# 25  CHEBI:16714      codeine  CHEBI:80580   Codeine-6-glucuronide
# 44  CHEBI:17303     morphine  CHEBI:80581  Morphine-6-glucuronide
# 45  CHEBI:17303     morphine  CHEBI:80631  Morphine-3-glucuronide
# 69  CHEBI:17303     morphine   CHEBI:7633             Normorphine
