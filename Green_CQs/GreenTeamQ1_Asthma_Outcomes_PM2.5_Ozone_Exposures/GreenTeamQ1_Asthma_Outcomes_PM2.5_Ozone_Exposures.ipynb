# %% [markdown]
# ### Question 1:
# Among pediatric patients with an 'asthma-like phenotype', is exposure to particulate
# matter <=2.5 micrometers in diameter (PM2.5) and ozone associated with responsiveness
# to treatment? (In other words, are exposures higher in patients who are non-responsive
# to treatment than in patients who are responsive to treatment?)
#
# *** Imports ***
# Greentranslator gets us a Python [API](https://stars.renci.org/var/greentranslator/index.html?highlight=greenquery#greentranslator.api.GreenQuery) for Green services.
#
# *** Query ***
# The [GreenQuery](https://stars.renci.org/var/greentranslator/index.html?highlight=greenquery#greentranslator.api.GreenQuery) provides access to clinical, exposures, and chembio data. It tracks provenance and is able to report it in W3C PROV format.

# %% [markdown]
# import pprint
# import json
# import traceback
# from datetime import datetime, timedelta
# from dateutil.parser import parse as parse_date
#
# from greent.core import GreenT # Clinical API is IP restricted to translator.ncats.io, must use core.
# greent_core = GreenT ()
#
# from greent import client
# greent = client.GraphQL ("http://stars.renci.org:5000/graphql")

# %%
import pprint
import json
import traceback
from datetime import datetime, timedelta
from dateutil.parser import parse as parse_date
from greent.core import GreenT # Clinical API is IP restricted to translator.ncats.io, must use core. greent_core = GreenT ()
from greent.client import GraphQL
greent = GraphQL ("http://localhost:5000/graphql")
from greent.endotype import Endotype
# Out:
# /usr/local/lib/python3.4/dist-packages/cachier/mongo_core.py:24: UserWarning: Cachier warning: pymongo was not found. MongoDB cores will not work.
#   "Cachier warning: pymongo was not found. MongoDB cores will not work.")

# %% [markdown]
# ### Clinical Query
# For now, we can filter by age, sex, race, and location. Soon, the interface will change to specify an age range.
#
#
# Here's an example response:
# ```
# [{'birth_date': '2006-08-02 00:00:00',
#   'diag': {'ICD10:B08.4': {'2016-07-08 00:00:00': 'OUTPATIENT'},
#            ...
#            'ICD9:V19.2': {'2006-12-19 00:00:00': 'OUTPATIENT'}},
#   'geoCode': {'GEO:LAT': '35.22056', 'GEO:LONG': '-80.69664'},
#   'medList': {'MDCTN:10427': '2016-03-10 00:00:00',
#               ...
#               'MDCTN:9502': '2017-01-20 00:00:00'},
#   'patient_id': '32227752',
#   'race': 'white',
#   'sex': 'M'},
#   ...]
# ```

# %%
patients = greent.get_patients (age=8, sex='male', race='white') #, location='OUTPATIENT')
pprint.pprint (patients)
# Out:
# ------------------------> b'{"variables": {"age": 8, "race": "white", "sex": "male"}, "query": "\\nquery queryPatients ($age : Int, $sex : String, $race : String) {\\n  patients (age: $age, sex: $sex, race: $race) {\\n    birthDate\\n    race\\n    sex\\n    patientId\\n    diagnoses {\\n      diagnosis\\n    }\\n    geoCode {\\n      latitude\\n      longitude\\n    }\\n    prescriptions {\\n      medication\\n      date\\n    }\\n  }\\n}  \\n            "}'
# None

# %%
meds = {}

for x in patients:
    medList = x['medList']
    # Collect the unique meds
    for m in medList.keys():
        try:
            meds[medList[m]] = meds[medList[m]]+1
        except KeyError:
            meds[medList[m]] = 1
pprint.pprint(meds)
# Out:
# {None: 115,
#  '0.3 ML Enoxaparin sodium 100 MG/ML Prefilled Syringe': 1,
#  '0.3 ML Epinephrine 0.5 MG/ML Auto-Injector [Epipen]': 4,
#  '10 Ml Sodium Chloride 9 Mg/Ml Prefilled Syringe': 1,
#  '120 ACTUAT Fluticasone propionate 0.05 MG/ACTUAT Nasal Inhaler': 1,
#  '2 ML Diazepam 0.005 MG/MG Prefilled Applicator': 1,
#  '2 ML Somatropin 5 MG/ML Prefilled Syringe [Nutropin]': 4,
#  '200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler': 2,
#  '5 Ml Sodium Chloride 9 Mg/Ml Prefilled Syringe': 2,
#  'ACETAMINOPHEN 160 MG/5 ML (5 ML) ORAL SUSPENSION': 6,
#  'ACETAMINOPHEN 325 MG TABLET': 1,
#  'ACETAMINOPHEN 80 MG CHEWABLE TABLET': 2,
#  'ACETAMINOPHEN 80 MG RECTAL SUPPOSITORY': 2,
#  'ALBENDAZOLE 200 MG TABLET': 2,
#  'ALBENZA 200 MG TABLET': 1,
#  'ALBUTEROL 90 MCG INHALER': 1,
#  'ALBUTEROL SULF HFA 90 MCG INH': 1,
#  'ALBUTEROL SULFATE 2.5 MG/3 ML (0.083 %) SOLUTION FOR NEBULIZATION': 4,
#  'ALBUTEROL SULFATE HFA 90 MCG/ACTUATION AEROSOL INHALER': 7,
#  'ALTEPLASE 2 MG SOLUTION FOR INJECTION': 1,
#  'AMOXICILLIN 400 MG/5 ML ORAL SUSPENSION': 4,
#  'AMOXICILLIN 500 MG CAPSULE': 1,
#  'AMOXICILLIN 500 MG TABLET': 1,
#  'AMOXICILLIN 600 MG-POTASSIUM CLAVULANATE 42.9 MG/5 ML ORAL SUSPENSION': 1,
#  'AMOXICILLIN 875 MG TABLET': 1,
#  'AMOXIL 400 MG/5 ML SUSPENSION': 1,
#  'AUGMENTIN 200-28.5 SUSPEN': 1,
#  'AUGMENTIN 250-62.5 MG/5 ML': 5,
#  'AUGMENTIN 400-57 MG/5 ML': 1,
#  'AUGMENTIN ES-600 SUSPENSION': 20,
#  'AZITHROMYCIN 200 MG/5 ML ORAL SUSPENSION': 3,
#  'AZITHROMYCIN 250 MG TABLET': 3,
#  'Acetaminophen 32 MG/ML Oral Suspension': 26,
#  'Acetaminophen 80 MG Chewable Tablet': 1,
#  'Albuterol': 3,
#  'Albuterol 0.83 MG/ML Inhalant Solution': 11,
#  'Aluminum Hydroxide 64 MG/ML Oral Suspension': 1,
#  'Amoxicillin': 2,
#  'Amoxicillin / Clavulanate': 2,
#  'Amoxicillin 120 MG/ML / Clavulanate 8.58 MG/ML Oral Suspension': 1,
#  'Amoxicillin 25 MG/ML Oral Suspension': 2,
#  'Amoxicillin 250 MG Oral Capsule': 1,
#  'Amoxicillin 50 MG/ML Oral Suspension': 5,
#  'Amoxicillin 80 MG/ML / Clavulanate 11.4 MG/ML Oral Suspension': 1,
#  'Amoxicillin 80 MG/ML Oral Suspension': 29,
#  'Antipyrine 54 MG/ML / Benzocaine 14 MG/ML Otic Solution': 1,
#  'Azithromycin 20 MG/ML Oral Suspension': 8,
#  'Azithromycin 40 MG/ML Oral Suspension': 13,
#  'BACITRACIN ZINC OINTMENT': 1,
#  'BACLOFEN POWDER': 10,
#  'BACTROBAN 2% OINTMENT': 3,
#  'BENEFIBER FOR CHILDREN POWDER': 1,
#  'BETAMETHASONE VALERATE 0.1 % TOPICAL OINTMENT': 1,
#  'BUDESONIDE 0.25 MG/2 ML SUSPENSION FOR NEBULIZATION': 1,
#  'CALMOSEPTINE OINTMENT': 1,
#  'CARBIDOPA 10 MG-LEVODOPA 100 MG TABLET': 3,
#  'CEPHALEXIN 250 MG/5 ML ORAL SUSPENSION': 3,
#  'CETIRIZINE 5 MG TABLET': 1,
#  'CHILD ZYRTEC 1 MG/ML SOLUTION': 3,
#  'CHILD ZYRTEC 5 MG/5 ML SPOON': 1,
#  "CHILDREN'S MOTRIN 100 MG/5 ML": 1,
#  'CIPRO HC OTIC SUSPENSION': 1,
#  'CLINDAMYCIN 150 MG/ML INJECTION SOLUTION': 1,
#  'CLONAZEPAM 0.5 MG TABLET': 4,
#  'CLONIDINE HCL ER 0.1 MG TABLET,EXTENDED RELEASE,12 HR': 2,
#  'Calcitriol 0.001 MG/ML Oral Solution': 3,
#  'Calcium Chloride 0.0014 MEQ/ML / Potassium Chloride 0.004 MEQ/ML / Sodium Chloride 0.103 MEQ/ML / Sodium Lactate 0.028 MEQ/ML Injectable Solution': 31,
#  'Carbidopa 10 MG / Levodopa 100 MG Disintegrating Oral Tablet': 3,
#  'Cefazolin': 2,
#  'Ceftriaxone': 1,
#  'Ceftriaxone 350 MG/ML Injectable Solution': 2,
#  'Cefuroxime 25 MG/ML Oral Suspension': 3,
#  'Cephalexin 250 MG Oral Capsule': 1,
#  'Cephalexin 50 MG/ML Oral Suspension': 3,
#  'Cholestyramine Resin 66.7 MG/ML Oral Suspension': 1,
#  'Ciprofloxacin 3 MG/ML / Dexamethasone 1 MG/ML Otic Suspension': 1,
#  'Citric Acid 66.8 MG/ML / sodium citrate 100 MG/ML Oral Solution': 3,
#  'Clindamycin 15 MG/ML Oral Solution': 1,
#  'Clobetasol Propionate 0.0005 MG/MG Topical Ointment': 1,
#  'Clonazepam 0.125 MG Disintegrating Oral Tablet': 1,
#  'Clotrimazole 10 MG/ML Topical Cream': 1,
#  'Codeine': 1,
#  'Codeine Phosphate 2 MG/ML / Guaifenesin 20 MG/ML Oral Solution': 1,
#  'Cyproheptadine hydrochloride 0.4 MG/ML Oral Solution': 4,
#  'D-VI-SOL 400 UNITS/ML DROP': 1,
#  'DESONIDE 0.05 % TOPICAL CREAM': 1,
#  'DEXMEDETOMIDINE 200 MCG/2 ML INTRAVENOUS SOLUTION': 3,
#  'DIAZEPAM 2 MG TABLET': 2,
#  'DIAZEPAM 5 MG-7.5 MG-10 MG RECTAL KIT': 3,
#  'DIAZEPAM 5 MG/ML INJECTION SYRINGE': 1,
#  'DIFLUCAN 40 MG/ML SUSPENSION': 1,
#  'DOCUSATE SODIUM 50 MG/5 ML ORAL LIQUID': 1,
#  'DORNASE ALFA 1 MG/ML SOLUTION FOR INHALATION': 4,
#  'Desmopressin Acetate 0.2 MG Oral Tablet': 1,
#  'Dexamethasone': 1,
#  'Dexmedetomidine 0.1 MG/ML Injectable Solution': 1,
#  'Diphenhydramine': 2,
#  'Diphenhydramine Hydrochloride 2.5 MG/ML Oral Solution': 2,
#  'Diphenhydramine Hydrochloride 25 MG Oral Capsule': 6,
#  'Divalproex Sodium 250 MG Delayed Release Oral Tablet': 1,
#  'Divalproex Sodium 500 MG Delayed Release Oral Tablet': 1,
#  'Dornase Alfa 1 MG/ML Inhalant Solution': 1,
#  'Doxycycline Calcium 10 MG/ML Oral Suspension': 1,
#  'EGG YOLK PHOSPHOLIPIDS 12 MG/ML / Glycerin 22.5 MG/ML / Soybean Oil 200 MG/ML Injectable Suspension': 21,
#  'ELOCON 0.1% CREAM': 1,
#  'ENOXAPARIN 20 MG/1 ML SUBCUTANEOUS SYRINGE': 2,
#  'EPINEPHRINE 0.15 MG/0.3 ML (1:2,000) INJECTION,AUTO-INJECTOR': 2,
#  'EPINEPHRINE 0.3 MG/0.3 ML (1:1,000) INJECTION,AUTO-INJECTOR': 2,
#  'EPOETIN ALFA 10,000 UNIT/ML INJECTION SOLUTION': 1,
#  'EPOETIN ALFA 20,000 UNIT/ML INJECTION SOLUTION': 1,
#  'EPOGEN 2,000 UNITS/ML VIAL': 10,
#  'EPOGEN 4,000 UNITS/ML VIAL': 1,
#  'ERYPED 200 MG/5 ML SUSPENSION': 1,
#  'ERYPED 400 MG/5 ML SUSPENSION': 1,
#  'ESOMEPRAZOLE MAGNESIUM DR 10 MG GRANULES DELAYED RELEASE FOR SUSP': 3,
#  'ESOMEPRAZOLE MAGNESIUM DR 20 MG GRANULES DELAYED RELEASE FOR SUSP': 2,
#  'Endopeptidases': 1,
#  'Epinephrine': 1,
#  'Epoetin Alfa 10000 UNT/ML Injectable Solution': 4,
#  'Erythromycin Ethylsuccinate 40 MG/ML Oral Suspension': 1,
#  'Esomeprazole 8 MG/ML Injectable Solution': 1,
#  'FENTANYL (PF) 50 MCG/ML INJECTION SOLUTION': 2,
#  'FENTANYL 12 MCG/HR TRANSDERMAL PATCH': 1,
#  'FER-IN-SOL 15 MG/ML DROPS': 1,
#  'FLAGYL 250 MG TABLET': 1,
#  'FLONASE 0.05% NASAL SPRAY': 4,
#  'FLORASTOR KIDS PACKETS': 1,
#  'FLOVENT HFA 110 MCG INHALER': 2,
#  'FLOVENT HFA 44 MCG INHALER': 4,
#  'FLOXIN 0.3% EAR DROPS': 1,
#  'FLUCONAZOLE 10 MG/ML ORAL SUSPENSION': 1,
#  'FLUCONAZOLE 100 MG TABLET': 1,
#  'FLUTICASONE 110 MCG/ACTUATION HFA AEROSOL INHALER': 3,
#  'FLUTICASONE 44 MCG/ACTUATION HFA AEROSOL INHALER': 3,
#  'FLUTICASONE 50 MCG/ACTUATION NASAL SPRAY,SUSPENSION': 6,
#  'FUROSEMIDE 10 MG/ML ORAL SOLUTION': 1,
#  'Famotidine 10 MG/ML Injectable Solution': 1,
#  'Famotidine 8 MG/ML Oral Suspension': 2,
#  'Filgrastim': 2,
#  'Fluconazole 2 MG/ML Injectable Solution': 1,
#  'Fluocinonide 0.5 MG/ML Topical Cream': 1,
#  'Fluticasone': 3,
#  'Furosemide 10 MG/ML Injectable Solution': 1,
#  'GAMUNEX 10% VIAL': 2,
#  'GLUTAMINE (GLUTASOLVE) 15 G ORAL POWDER': 3,
#  'GLYCERIN LIQUID': 3,
#  'GLYCOPYRROLATE 0.2 MG/ML INJECTION SOLUTION': 1,
#  'GLYCOPYRROLATE 1 MG/5 ML (0.2 MG/ML) ORAL SOLUTION': 1,
#  'GOLYTELY PACKET': 1,
#  'GOLYTELY SOLUTION': 2,
#  'GUANFACINE 1 MG TABLET': 5,
#  'Gentamicin Sulfate (USP) 0.001 MG/MG Topical Ointment': 1,
#  'Gentamicin Sulfate (USP) 1 MG/ML Topical Cream': 1,
#  'Gentamicin Sulfate (USP) 3 MG/ML Ophthalmic Solution': 1,
#  'Glucose 100 MG/ML / Sodium Chloride 0.0769 MEQ/ML Injectable Solution': 1,
#  'Glucose 50 MG/ML / Sodium Chloride 0.0385 MEQ/ML Injectable Solution': 2,
#  'Glucose 50 MG/ML / Sodium Chloride 0.0769 MEQ/ML Injectable Solution': 26,
#  'Glucose 50 MG/ML / Sodium Chloride 0.154 MEQ/ML Injectable Solution': 23,
#  'Glycopyrrolate 0.2 MG/ML Injectable Solution': 1,
#  'HEPARIN, PORCINE (PF) 100 UNIT/ML INTRAVENOUS SYRINGE': 5,
#  'HYDROCODONE 7.5 MG-ACETAMINOPHEN 325 MG/15 ML ORAL SOLUTION': 1,
#  'HYDROCORTISONE 1 % TOPICAL CREAM': 2,
#  'HYDROCORTISONE VAL 0.2% OINTMT': 1,
#  'Hydralazine Hydrochloride 20 MG/ML Injectable Solution': 1,
#  'Hydrocortisone 0.01 MG/MG Topical Ointment': 1,
#  'Hydrocortisone 0.025 MG/MG Topical Ointment': 1,
#  'Hydroxyzine Hydrochloride 2 MG/ML Oral Solution': 4,
#  'Hyoscyamine Sulfate 0.125 MG Sublingual Tablet': 1,
#  'IBUPROFEN 200 MG TABLET': 1,
#  'IBUPROFEN 400 MG TABLET': 1,
#  'INTRALIPID 20% IV FAT EMUL': 1,
#  'IRINOTECAN (CAMPTOSAR) IV SYRINGE (QS 50 ML D5W)': 1,
#  'Ibuprofen 20 MG/ML Oral Suspension': 2,
#  'Irinotecan': 1,
#  'Iron': 8,
#  'KAYEXALATE POWDER': 3,
#  'LANSOPRAZOLE 30 MG DELAYED RELEASE,DISINTEGRATING TABLET': 1,
#  'LEUCOVORIN CALCIUM 50 MG SOLUTION FOR INJECTION': 1,
#  'LEVETIRACETAM 100 MG/ML ORAL SOLUTION': 1,
#  'LIDOCAINE 4 % TOPICAL CREAM': 6,
#  'LIPASE-PROTEASE-AMYLASE 12,000-38,000-60,000 UNIT CAPSULE,DELAYED REL': 1,
#  'LIPASE-PROTEASE-AMYLASE 6,000-19,000-30,000 UNIT CAPSULE,DELAYED REL': 1,
#  'LIPASE-PROTEASE-AMYLASE 935 MG (16,000-60K-60K UNIT) TABLET': 1,
#  'LISINOPRIL 2.5 MG TABLET': 1,
#  'LOCOID 0.1% OINTMENT': 1,
#  'LORATADINE 10 MG DISINTEGRATING TABLET': 1,
#  'LORATADINE 5 MG/5 ML ORAL SOLUTION': 1,
#  'LORAZEPAM 0.5 MG TABLET': 1,
#  'LORAZEPAM 1 MG TABLET': 1,
#  'LORTAB 7.5-500 MG/15 ML ELIXIR': 1,
#  'Labetalol': 1,
#  'Lactulose 667 MG/ML Oral Solution': 2,
#  'Levetiracetam 100 MG/ML Oral Solution': 1,
#  'Levofloxacin 5 MG/ML Injectable Solution': 1,
#  'Lidocaine Hydrochloride 20 MG/ML Injectable Solution': 1,
#  'Lipase': 2,
#  'Lisdexamfetamine': 1,
#  'Loperamide Hydrochloride 0.2 MG/ML Oral Solution': 2,
#  'Loratadine 1 MG/ML Oral Solution': 1,
#  'Lorazepam 2 MG/ML Oral Solution': 2,
#  'MEPHYTON 5 MG TABLET': 8,
#  'MESNA 100 MG/ML INTRAVENOUS SOLUTION': 1,
#  'METHYLIN 5 MG CHEWABLE TABLET': 1,
#  'METHYLPHENIDATE 5 MG/ML (25 MG/5 ML) ORAL SUSP,EXTENDED RELEASE 24 HR': 1,
#  'METOCLOPRAMIDE 5 MG/5 ML ORAL SOLUTION': 1,
#  'MISOPROSTOL 100 MCG TABLET': 1,
#  'MOMETASONE 50 MCG/ACTUATION NASAL SPRAY': 1,
#  'MONTELUKAST 5 MG CHEWABLE TABLET': 1,
#  'Magnesium Hydroxide': 1,
#  'Metoclopramide 1 MG/ML Oral Solution': 2,
#  'Metronidazole Pwdr': 1,
#  'Midazolam 1 MG/ML Injectable Solution': 1,
#  'Morphine Sulfate': 1,
#  'Morphine Sulfate 20 MG/ML Oral Solution': 1,
#  'Mupirocin 0.02 MG/MG Topical Ointment': 2,
#  'NEOSTIGMINE METHYLSULFATE 0.5 MG/ML INJECTION SOLUTION': 3,
#  'NEXIUM DR 10 MG PACKET': 1,
#  'Nystatin 100 UNT/MG Topical Ointment': 2,
#  'Nystatin 100000 UNT/ML Oral Suspension': 7,
#  'Nystatin 100000 UNT/ML Topical Cream': 5,
#  'OMEPRAZOLE 2 MG/ML ORAL SUSPENSION': 1,
#  'OMEPRAZOLE POWDER': 2,
#  'OMNICEF 125 MG/5 ML SUSP': 4,
#  'OMNICEF 250 MG/5 ML SUSPENSION': 7,
#  'ONDANSETRON 4 MG DISINTEGRATING TABLET': 5,
#  'ONDANSETRON HCL 4 MG/5 ML ORAL SOLUTION': 2,
#  'ORAPRED 15 MG/5 ML SOLUTION': 25,
#  'ORAPRED ODT 10 MG TABLET': 1,
#  'ORAPRED ODT 15 MG TABLET': 1,
#  'OSELTAMIVIR 12 MG/ML ORAL SUSPENSION': 1,
#  'OSELTAMIVIR 6 MG/ML ORAL SUSPENSION': 2,
#  'Ofloxacin 3 MG/ML Otic Solution': 1,
#  'Omeprazole 20 MG Delayed Release Oral Capsule': 5,
#  'Oseltamivir': 1,
#  'Oxycodone Hydrochloride 1 MG/ML Oral Solution': 3,
#  'PHENERGAN 12.5 MG SUPPOS': 1,
#  'PHYTONADIONE LIQUID': 1,
#  'POLY-VI-SOL DROPS': 1,
#  'POLYETHYLENE GLYCOL 3350 142 MG/ML Oral Solution': 4,
#  'POLYETHYLENE GLYCOL 3350 17 GRAM ORAL POWDER PACKET': 3,
#  'POLYETHYLENE GLYCOL 3350 17 GRAM/DOSE ORAL POWDER': 6,
#  'POLYTRIM EYE DROPS': 1,
#  'POTASSIUM CHLORIDE 20 MEQ/L IN DEXTROSE 5 %-0.2 % SODIUM CHLORIDE IV': 1,
#  'PREDNISOLONE 15 MG/5 ML ORAL SOLUTION': 1,
#  'PREDNISOLONE SODIUM PHOSPHATE 15 MG/5 ML ORAL SOLUTION': 13,
#  'PREDNISONE 20 MG TABLET': 1,
#  'PREVACID 15 MG SOLUTAB': 21,
#  'PREVACID 30 MG SOLUTAB': 2,
#  'PROCRIT 2,000 UNITS/ML VIAL': 1,
#  'PROPOFOL 10 MG/ML INTRAVENOUS EMULSION': 4,
#  'PULMICORT 0.5 MG/2 ML RESPULE': 2,
#  'PULMOZYME 1 MG/ML AMPUL': 3,
#  'PULMOZYME 1 MG/ML SOLUTION FOR INHALATION': 1,
#  'Pentamidine Isethionate 50 MG/ML Inhalant Solution': 2,
#  'Polymyxin B': 3,
#  'Potassium Chloride': 7,
#  'Potassium Chloride 1.33 MEQ/ML Oral Solution': 1,
#  'Prednisone 5 MG Oral Tablet': 1,
#  'Prilocaine': 1,
#  'Promethazine Hydrochloride 12.5 MG Oral Tablet': 1,
#  'Promethazine Hydrochloride 25 MG/ML Injectable Solution': 4,
#  'Protamines': 1,
#  'QUETIAPINE 25 MG TABLET': 3,
#  'QVAR 40 MCG ORAL INHALER': 6,
#  'RANITIDINE 150 MG TABLET': 1,
#  'RENVELA 0.8 GM POWDER PACKET': 1,
#  'RISPERIDONE 0.25 MG DISINTEGRATING TABLET': 2,
#  'RISPERIDONE 0.25 MG TABLET': 1,
#  'RISPERIDONE 0.5 MG DISINTEGRATING TABLET': 2,
#  'ROBINUL 1 MG TABLET': 1,
#  'ROCURONIUM 10 MG/ML INTRAVENOUS SOLUTION': 1,
#  'Ranitidine 15 MG/ML Oral Solution': 3,
#  'Risperidone 0.25 MG Oral Tablet': 1,
#  'SEPTRA SUSPENSION': 2,
#  'SEVELAMER CARBONATE 0.8 GRAM ORAL POWDER PACKET': 1,
#  'SEVELAMER CARBONATE 2.4 GRAM ORAL POWDER PACKET': 2,
#  'SILVER NITRATE APPLICATOR': 1,
#  'SODIUM CHLORIDE 0.9 % INJECTION SYRINGE': 31,
#  'SODIUM CHLORIDE 0.9 % INTRAVENOUS SOLUTION': 14,
#  'SODIUM CHLORIDE 0.9 % IRRIGATION SOLUTION': 1,
#  'SODIUM CHLORIDE 3 % FOR NEBULIZATION': 2,
#  'SODIUM CHLORIDE POWDER': 3,
#  'SUPRAX 100 MG/5 ML SUSPENSION': 4,
#  'Salmeterol': 2,
#  'Sodium': 2,
#  'Sodium Bicarbonate 650 MG Oral Tablet': 2,
#  'Sodium Chloride 0.0769 MEQ/ML Injectable Solution': 1,
#  'Sodium Chloride 0.154 MEQ/ML Injectable Solution': 23,
#  'Sodium Sulfate': 3,
#  'Sodium polystyrene sulfonate 250 MG/ML Oral Suspension': 5,
#  'Sulfacetamide Sodium 100 MG/ML Ophthalmic Solution': 1,
#  'Sulfamethoxazole 40 MG/ML / Trimethoprim 8 MG/ML Oral Suspension': 7,
#  'TAMIFLU 12 MG/ML SUSPENSION': 1,
#  'TAMIFLU 45 MG GELCAP': 1,
#  'TAMIFLU 6 MG/ML SUSPENSION': 1,
#  'TENEX 1 MG TABLET': 1,
#  'TOBI 300 MG/5 ML SOLUTION': 1,
#  'TOBRAMYCIN 0.3 % EYE DROPS': 1,
#  'TRIMETHOPRIM-SULFAMETHOXASOLE IV 0.64 MG/ML PEDIATRIC': 1,
#  'Tobramycin 60 MG/ML Inhalant Solution': 1,
#  'Tobramycin Sulfate': 3,
#  'Triamcinolone': 1,
#  'Triamcinolone Acetonide 0.001 MG/MG Topical Ointment': 2,
#  'Triamcinolone Acetonide 1 MG/ML Topical Cream': 2,
#  'Triamcinolone Acetonide 5 MG/ML Topical Cream': 1,
#  'Trimethoprim': 17,
#  'VALPROIC ACID (AS SODIUM SALT) 250 MG/5 ML ORAL SOLUTION': 1,
#  'VENTOLIN HFA 90 MCG INHALER': 3,
#  'VENTOLIN HFA 90 MCG/ACTUATION AEROSOL INHALER': 1,
#  'VIGAMOX 0.5% EYE DROPS': 1,
#  'VIOKACE 10,440-39,150 UNITS TB': 1,
#  'VUSION OINTMENT': 3,
#  'Valproic Acid 50 MG/ML Oral Solution': 1,
#  'Vancomycin': 1,
#  'Vancomycin 100 MG/ML Injectable Solution': 7,
#  'Vancomycin 5 MG/ML Injectable Solution': 13,
#  'Vancomycin 50 MG/ML Injectable Solution': 1,
#  'Vincristine Sulfate 1 MG/ML Injectable Solution': 1,
#  'WESTCORT 0.2% CREAM': 2,
#  'WHITE PETROLATUM 41 % TOPICAL OINTMENT': 1,
#  'Water 1000 MG/ML Irrigation Solution': 2,
#  'XOPENEX 0.63 MG/3 ML SOLUTION': 2,
#  'XOPENEX HFA 45 MCG INHALER': 1,
#  'ZENPEP DR 10,000 UNITS CAPSULE': 3,
#  'ZENPEP DR 5,000 UNITS CAPSULE': 4,
#  'ZITHROMAX 200 MG/5 ML SUSP': 8,
#  'ZOFRAN 4 MG/5 ML ORAL SOLN': 1,
#  'ZOFRAN ODT 4 MG TABLET': 1,
#  'ZYVOX 100 MG/5 ML SUSPENSION': 2,
#  'Zinc Sulfate 220 MG Oral Capsule': 4,
#  'cefdinir 25 MG/ML Oral Suspension': 1,
#  'cefdinir 300 MG Oral Capsule': 1,
#  'cefdinir 50 MG/ML Oral Suspension': 19,
#  'cefepime 160 MG/ML Injectable Solution': 1,
#  'cefepime 280 MG/ML Injectable Solution': 2,
#  'cefpodoxime 10 MG/ML Oral Suspension': 1,
#  'cefpodoxime 20 MG/ML Oral Suspension': 1,
#  'cetirizine hydrochloride 1 MG/ML Oral Solution': 7,
#  'cetirizine hydrochloride 10 MG Oral Tablet': 1,
#  'cetirizine hydrochloride 5 MG Oral Tablet': 1,
#  'chlorhexidine gluconate 1.2 MG/ML Mouthwash': 1,
#  'clavulanate potassium': 6,
#  'ferrous sulfate 75 MG/ML Oral Solution': 1,
#  'gadoterate meglumine': 1,
#  'lansoprazole 15 MG Disintegrating Oral Tablet': 2,
#  'lansoprazole 30 MG Disintegrating Oral Tablet': 5,
#  'linezolid 20 MG/ML Oral Suspension': 2,
#  'lisdexamfetamine dimesylate 20 MG Oral Capsule': 6,
#  'montelukast 5 MG Chewable Tablet': 1,
#  'olopatadine 2 MG/ML Ophthalmic Solution': 1,
#  'oxcarbazepine 60 MG/ML Oral Suspension': 1,
#  'pantoprazole 40 MG Oral Granules': 1,
#  'prednisolone 3 MG/ML Oral Solution': 8,
#  'quetiapine 25 MG Oral Tablet': 1,
#  'rocuronium bromide 10 MG/ML Injectable Solution': 1,
#  'sevelamer carbonate 26.7 MG/ML Oral Suspension': 3,
#  'sevelamer carbonate 40 MG/ML Oral Suspension': 8,
#  '{6 (Azithromycin 250 MG Oral Tablet) } Pack': 1}

# %%
import requests
def med2rxnorm(txt):
    annos = []
    url = 'http://data.bioontology.org/annotator?text=%s&apikey=b792dd1b-cdc2-4cc8-aaf2-4fa4fbf47e4e'
    try:
        resp = requests.get(url % urllib.parse.quote(txt)).json()
        if len(resp) > 0:
            for aresp in resp:
                annos.extend([ x['text'] for x in aresp['annotations'] ])
    except TypeError:
        print ("type error: {}".format (txt))
    return (annos)

c = 0
for med in meds:
    if c > 50:
        continue
    c = c + 1
    print (med2rxnorm (med))
# Out:
# ['RISPERIDONE 0.25 MG', 'RISPERIDONE']
# ['CHLORHEXIDINE GLUCONATE 1.2 MG/ML MOUTHWASH', 'CHLORHEXIDINE GLUCONATE 1.2 MG/ML', 'CHLORHEXIDINE GLUCONATE', 'CHLORHEXIDINE', 'GLUCONATE', 'MOUTHWASH']
# ['CEPHALEXIN 250 MG', 'CEPHALEXIN', 'ORAL SUSPENSION']
# ['CITRIC ACID 66.8 MG/ML / SODIUM CITRATE 100 MG/ML ORAL SOLUTION', 'CITRIC ACID 66.8 MG/ML', 'CITRIC ACID', 'SODIUM CITRATE 100 MG/ML', 'SODIUM CITRATE', 'SODIUM', 'CITRATE', 'ORAL SOLUTION']
# ['SODIUM CHLORIDE 0.154 MEQ/ML INJECTABLE SOLUTION', 'SODIUM CHLORIDE 0.154 MEQ/ML', 'SODIUM CHLORIDE', 'SODIUM', 'INJECTABLE SOLUTION']
# ['VANCOMYCIN']
# ['AUGMENTIN']
# ['LABETALOL']
# ['GLUCOSE 50 MG/ML', 'GLUCOSE', 'SODIUM CHLORIDE 0.0769 MEQ/ML INJECTABLE SOLUTION', 'SODIUM CHLORIDE 0.0769 MEQ/ML', 'SODIUM CHLORIDE', 'SODIUM', 'INJECTABLE SOLUTION']
# ['ACETAMINOPHEN 80 MG CHEWABLE TABLET', 'ACETAMINOPHEN 80 MG', 'ACETAMINOPHEN', 'CHEWABLE TABLET']
# ['MEPHYTON']
# ['SEVELAMER CARBONATE 26.7 MG/ML ORAL SUSPENSION', 'SEVELAMER CARBONATE 26.7 MG/ML', 'SEVELAMER CARBONATE', 'SEVELAMER', 'ORAL SUSPENSION']
# ['ZYRTEC']
# ['MIDAZOLAM 1 MG/ML INJECTABLE SOLUTION', 'MIDAZOLAM 1 MG/ML', 'MIDAZOLAM', 'INJECTABLE SOLUTION']
# ['DIVALPROEX SODIUM 250 MG DELAYED RELEASE ORAL TABLET', 'DIVALPROEX SODIUM 250 MG', 'DIVALPROEX SODIUM', 'SODIUM', 'DELAYED RELEASE ORAL TABLET', 'ORAL TABLET']
# ['BACLOFEN']
# ['METOCLOPRAMIDE 1 MG/ML ORAL SOLUTION', 'METOCLOPRAMIDE 1 MG/ML', 'METOCLOPRAMIDE', 'ORAL SOLUTION']
# ['CALCIUM CHLORIDE 0.0014 MEQ/ML / POTASSIUM CHLORIDE 0.004 MEQ/ML / SODIUM CHLORIDE 0.103 MEQ/ML / SODIUM LACTATE 0.028 MEQ/ML INJECTABLE SOLUTION', 'CALCIUM CHLORIDE 0.0014 MEQ/ML', 'CALCIUM CHLORIDE', 'CALCIUM', 'POTASSIUM CHLORIDE 0.004 MEQ/ML', 'POTASSIUM CHLORIDE', 'POTASSIUM', 'SODIUM CHLORIDE 0.103 MEQ/ML', 'SODIUM CHLORIDE', 'SODIUM', 'SODIUM', 'SODIUM LACTATE 0.028 MEQ/ML', 'SODIUM LACTATE', 'LACTATE', 'INJECTABLE SOLUTION']
# ['CHOLESTYRAMINE RESIN', 'ORAL SUSPENSION']
# ['FLUTICASONE PROPIONATE 0.05 MG/ACTUAT', 'FLUTICASONE PROPIONATE', 'FLUTICASONE', 'PROPIONATE']
# ['DIPHENHYDRAMINE HYDROCHLORIDE 25 MG ORAL CAPSULE', 'DIPHENHYDRAMINE HYDROCHLORIDE 25 MG', 'DIPHENHYDRAMINE HYDROCHLORIDE', 'DIPHENHYDRAMINE', 'ORAL CAPSULE']
# ['LORATADINE 5 MG', 'LORATADINE', 'ORAL SOLUTION']
# ['CEPHALEXIN 50 MG/ML ORAL SUSPENSION', 'CEPHALEXIN 50 MG/ML', 'CEPHALEXIN', 'ORAL SUSPENSION']
# ['POTASSIUM CHLORIDE', 'POTASSIUM']
# ['FLUTICASONE', 'AEROSOL']
# ['AMOXICILLIN 875 MG', 'AMOXICILLIN']
# ['CLONAZEPAM 0.125 MG DISINTEGRATING ORAL TABLET', 'CLONAZEPAM 0.125 MG', 'CLONAZEPAM', 'DISINTEGRATING ORAL TABLET', 'ORAL TABLET']
# ['GOLYTELY']
# ['POLYTRIM', 'EYE DROPS']
# ['PROCRIT']
# ['SUPRAX']
# ['TOBRAMYCIN 60 MG/ML INHALANT SOLUTION', 'TOBRAMYCIN 60 MG/ML', 'TOBRAMYCIN', 'INHALANT SOLUTION']
# ['SULFAMETHOXAZOLE 40 MG/ML / TRIMETHOPRIM 8 MG/ML ORAL SUSPENSION', 'SULFAMETHOXAZOLE 40 MG/ML', 'SULFAMETHOXAZOLE', 'TRIMETHOPRIM 8 MG/ML', 'TRIMETHOPRIM', 'ORAL SUSPENSION']
# ['SEVELAMER CARBONATE', 'SEVELAMER', 'ORAL POWDER']
# ['GLYCOPYRROLATE 1 MG', 'GLYCOPYRROLATE', 'ORAL SOLUTION']
# ['TOBRAMYCIN', 'EYE DROPS']
# ['INTRALIPID']
# ['ORAPRED']
# ['POTASSIUM CHLORIDE 1.33 MEQ/ML ORAL SOLUTION', 'POTASSIUM CHLORIDE 1.33 MEQ/ML', 'POTASSIUM CHLORIDE 1.33 MEQ', 'POTASSIUM CHLORIDE', 'POTASSIUM', 'ORAL SOLUTION']
# ['DIAZEPAM 5 MG/ML', 'DIAZEPAM 5 MG', 'DIAZEPAM', 'INJECTION']
# ['DEXAMETHASONE']
# ['EGG YOLK PHOSPHOLIPIDS', 'PHOSPHOLIPIDS', 'GLYCERIN', 'SOYBEAN OIL 200 MG/ML INJECTABLE SUSPENSION', 'SOYBEAN OIL 200 MG/ML', 'SOYBEAN OIL', 'INJECTABLE SUSPENSION']
# ['LIPASE']
# ['ZOFRAN']
# ['ANTIPYRINE 54 MG/ML / BENZOCAINE 14 MG/ML OTIC SOLUTION', 'ANTIPYRINE 54 MG/ML', 'ANTIPYRINE', 'BENZOCAINE 14 MG/ML', 'BENZOCAINE', 'OTIC SOLUTION']
# ['XOPENEX']
# ['VIGAMOX', 'EYE DROPS']
# ['PULMICORT']
# ['AMOXICILLIN 500 MG', 'AMOXICILLIN']
# ['CETIRIZINE']
# ['FUROSEMIDE 10 MG/ML ORAL SOLUTION', 'FUROSEMIDE 10 MG/ML', 'FUROSEMIDE', 'ORAL SOLUTION']

# %% [markdown]
# ### Exposures
# Now we want to find exposures data corresponding to our clinical data. We iterate over each returned patient, over each visit for that patient. In the context of a visit, we calculate a date prior to the visit date by a week, look up exposure data in the patient's location during that time interval.
#
# Response structure:
# ```
# [{'end_time': datetime.datetime(2010, 1, 7, 23, 0, tzinfo=tzlocal()),
#  'exposure_type': 'pm25',
#  'latitude': '35.9131996',
#  'longitude': '-79.0558445',
#  'start_time': datetime.datetime(2010, 1, 7, 0, 0, tzinfo=tzlocal()),
#  'units': '7dayrisk',
#  'value': '4.714285714285714'},
#  ...]
# ```

# %%
# We'll use the Environmental Exposures endpoint to address the second part of the question:
#  > ... is exposure to particulate matter <=2.5 micrometers in diameter (PM2.5) 
#    and ozone associated with responsiveness to treatment?
exposures = []
for patient in patients:
    for diagnosis, visit in patient['diag'].items ():
        for date, visit_type in visit.items ():
            
            visit_date = parse_date (date)
            start_date = (visit_date - timedelta(days=7)).isoformat ().split('T')[0]
            end_date = visit_date.isoformat ().split('T')[0]

            geo_location = "{0},{1}".format (patient['geoCode']['GEO:LAT'], patient['geoCode']['GEO:LONG'])

            if not start_date.startswith ("2010-1"):
                continue

            try:
                response = greent.get_exposure_scores (
                    exposure_type = 'pm25',
                    start_date = start_date,
                    end_date = end_date,
                    exposure_point = geo_location)
                
                exposure_set = json.loads (response['data']['exposureScore'])
                
                for exposure in exposure_set:
                    print ("start: {0} end: {1} loc: {2} value: {0} units: {1}".format (
                        start_date, end_date, geo_location, exposure['value'], exposure['units']))
                    exposures.append (exposure)
            except: 
                print ('.') 
                traceback.print_exc ()
# Out:
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 35.27658,-80.75361 value: 2010-11-14 units: 2010-11-21
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-12-23 end: 2010-12-30 loc: 35.27658,-80.75361 value: 2010-12-23 units: 2010-12-30
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-11-10 end: 2010-11-17 loc: 35.27658,-80.75361 value: 2010-11-10 units: 2010-11-17
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 44.51101,-73.01033 value: 2010-10-30 units: 2010-11-06
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-14 end: 2010-11-21 loc: 44.51101,-73.01033 value: 2010-11-14 units: 2010-11-21
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-10-23 end: 2010-10-30 loc: 44.51101,-73.01033 value: 2010-10-23 units: 2010-10-30
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-11-17 end: 2010-11-24 loc: 44.51101,-73.01033 value: 2010-11-17 units: 2010-11-24
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-10-25 end: 2010-11-01 loc: 44.51101,-73.01033 value: 2010-10-25 units: 2010-11-01
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-16 end: 2010-12-23 loc: 35.10358,-80.63818 value: 2010-12-16 units: 2010-12-23
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-12-03 end: 2010-12-10 loc: 34.97423,-80.44429 value: 2010-12-03 units: 2010-12-10
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-11-19 end: 2010-11-26 loc: 34.88018,-80.52109 value: 2010-11-19 units: 2010-11-26
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-12-02 end: 2010-12-09 loc: 34.88018,-80.52109 value: 2010-12-02 units: 2010-12-09
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-10-18 end: 2010-10-25 loc: 34.88018,-80.52109 value: 2010-10-18 units: 2010-10-25
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-12-26 end: 2011-01-02 loc: 44.31477,-73.10609 value: 2010-12-26 units: 2011-01-02
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-30 end: 2010-12-07 loc: 35.56878,-80.50115 value: 2010-11-30 units: 2010-12-07
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-16 end: 2010-11-23 loc: 35.56878,-80.50115 value: 2010-11-16 units: 2010-11-23
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-13 end: 2010-11-20 loc: 35.56878,-80.50115 value: 2010-11-13 units: 2010-11-20
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-01 end: 2010-11-08 loc: 35.56878,-80.50115 value: 2010-11-01 units: 2010-11-08
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-11-18 end: 2010-11-25 loc: 35.56878,-80.50115 value: 2010-11-18 units: 2010-11-25
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-10-30 end: 2010-11-06 loc: 35.29329,-80.67754 value: 2010-10-30 units: 2010-11-06
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-12-28 end: 2011-01-04 loc: 35.29329,-80.67754 value: 2010-12-28 units: 2011-01-04
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27
# start: 2010-10-20 end: 2010-10-27 loc: 35.26250,-80.99058 value: 2010-10-20 units: 2010-10-27

# %%
print (query.prov_json ())
# Out:
# {
#   "prefix": {
#     "expo.pm25-o3": "http://purl.translator.org/prov/expo.pm25-o3",
#     "blazegraph": "http://purl.translator.org/prov/blazegraph",
#     "biochem": "http://purl.translator.org/prov/biochem",
#     "expo": "http://purl.translator.org/prov/expo",
#     "default": "http://purl.translator.org/prov/",
#     "clinical.med.prescribed": "http://purl.translator.org/prov/clinical.med.prescribed",
#     "TODO": "http://purl.translator.org/prov/TODO"
#   }
# }

# %%
query.provenance.document.plot ()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-5-75bec23d97fe> in <module>()
# ----> 1 query.provenance.document.plot ()
#
# /usr/local/lib/python3.4/dist-packages/prov/model.py in plot(self, filename, show_nary, use_labels, show_element_attributes, show_relation_attributes)
#    1476                 size = (scale * size[0], scale * size[1])
#    1477
# -> 1478                 plt.figure(figsize=size)
#    1479                 plt.subplots_adjust(bottom=0, top=1, left=0, right=1)
#    1480                 plt.xticks([])
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     433                                         frameon=frameon,
#     434                                         FigureClass=FigureClass,
# --> 435                                         **kwargs)
#     436
#     437         if figLabel:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py in new_figure_manager(num, *args, **kwargs)
#      79     FigureClass = kwargs.pop('FigureClass', Figure)
#      80     figure = FigureClass(*args, **kwargs)
# ---> 81     return new_figure_manager_given_figure(num, figure)
#      82
#      83
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py in new_figure_manager_given_figure(num, figure)
#      87     """
#      88     _focus = windowing.FocusManager()
# ---> 89     window = Tk.Tk()
#      90     window.withdraw()
#      91
#
# /usr/lib/python3.4/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    1852                 baseName = baseName + ext
#    1853         interactive = 0
# -> 1854         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    1855         if useTk:
#    1856             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
exposures = list(map(lambda exp : Endotype.create_exposure (**exp), [{
    "exposure_type": "pm25",
    "units"        : "",
    "value"        : 2
}]))
visits = list(map(lambda v : Endotype.create_visit(**v), [{
    "icd_codes"  : "ICD9:V12,ICD9:E002",
    "lat"        : "20",
    "lon"        : "20",
    "time"       : "2017-10-12 21:12:29",
    "visit_type" : "INPATIENT",
    "exposures"  : exposures
}]))
request = Endotype.create_request (dob= "2017-10-04", model_type="M0", race="1", sex="M", visits = visits)
print (json.dumps (request))
response = greent.get_endotypes (query = json.dumps(request))
print (response)
#endo = json.loads (response['endotype'])
# Out:
# {"race": "1", "model_type": "M0", "visits": [{"exposures": [{"value": 2, "exposure_type": "pm25", "units": ""}], "lat": "20", "time": "2017-10-12 21:12:29", "icd_codes": "ICD9:V12,ICD9:E002", "visit_type": "INPATIENT", "lon": "20"}], "date_of_birth": "2017-10-04", "sex": "M"}
# ------------------------> b'{"variables": {"query": "{\\"race\\": \\"1\\", \\"model_type\\": \\"M0\\", \\"visits\\": [{\\"exposures\\": [{\\"value\\": 2, \\"exposure_type\\": \\"pm25\\", \\"units\\": \\"\\"}], \\"lat\\": \\"20\\", \\"time\\": \\"2017-10-12 21:12:29\\", \\"icd_codes\\": \\"ICD9:V12,ICD9:E002\\", \\"visit_type\\": \\"INPATIENT\\", \\"lon\\": \\"20\\"}], \\"date_of_birth\\": \\"2017-10-04\\", \\"sex\\": \\"M\\"}"}, "query": "\\n                  query get_endotype ( $query : String) {\\n                      endotype (query:$query)\\n            }"}'
# {'endotype': ['{\'periods\': [{\'end_time\': \'2017-10-12 21:12:29\', \'start_time\': \'2017-10-12 21:12:29\'}], \'endotype_id\': \'E0\', \'endotype_evidence\': \'pre_ed %in% c("[0,0.5)", "[0.5,1.5)")\', \'endotype_description\': \'[0,0.5)\'}']}

# %%
def endotype_to_obj (response):
    result = None
    if 'endotype' in response and len(response['endotype']) > 0:
        print(response['endotype'][0])
        text = response['endotype'][0].replace ('"', '\\"').replace ("'", '"')
    return json.dumps (json.loads (text), indent=2)

print (endotype_to_obj (response))
# Out:
# {'periods': [{'end_time': '2017-10-12 21:12:29', 'start_time': '2017-10-12 21:12:29'}], 'endotype_id': 'E0', 'endotype_evidence': 'pre_ed %in% c("[0,0.5)", "[0.5,1.5)")', 'endotype_description': '[0,0.5)'}
# {"periods": [{"end_time": "2017-10-12 21:12:29", "start_time": "2017-10-12 21:12:29"}], "endotype_id": "E0", "endotype_evidence": "pre_ed %in% c(\"[0,0.5)\", \"[0.5,1.5)\")", "endotype_description": "[0,0.5)"}
# {
#   "periods": [
#     {
#       "end_time": "2017-10-12 21:12:29",
#       "start_time": "2017-10-12 21:12:29"
#     }
#   ],
#   "endotype_evidence": "pre_ed %in% c(\"[0,0.5)\", \"[0.5,1.5)\")",
#   "endotype_id": "E0",
#   "endotype_description": "[0,0.5)"
# }

# %%
# %matplotlib inline

# %%
import seaborn as sns
import numpy as np
import pandas as pd

sns.set_style("darkgrid", { "font.family" : "serif" })
sns.jointplot(x="days",
              y="values",
              data = pd.DataFrame({
                  "days" : [ exposure.end_time.timetuple().tm_yday for exposure in exposures ],
                  "values" : [ float(exposure.value) for exposure in exposures ],
              }),
              kind='reg');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fa5a69f3c010> in <module>()
#       7               y="values",
#       8               data = pd.DataFrame({
# ----> 9                   "days" : [ exposure.end_time.timetuple().tm_yday for exposure in exposures ],
#      10                   "values" : [ float(exposure.value) for exposure in exposures ],
#      11               }),
#
# NameError: name 'exposures' is not defined

# %%
sns.set_style("darkgrid", { "font.family" : "serif" })
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-7-c27a5103803c> in <module>()
#       1 sns.set_style("darkgrid", { "font.family" : "serif" })
#       2 tips = sns.load_dataset("tips")
# ----> 3 ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
#
# /usr/local/lib/python3.4/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2900
#    2901     if ax is None:
# -> 2902         ax = plt.gca()
#    2903
#    2904     plotter.plot(ax, kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in gca(**kwargs)
#     826     matplotlib.figure.Figure.gca : The figure's gca method.
#     827     """
# --> 828     ax =  gcf().gca(**kwargs)
#     829     return ax
#     830
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in gcf()
#     460         return figManager.canvas.figure
#     461     else:
# --> 462         return figure()
#     463
#     464 fignum_exists = _pylab_helpers.Gcf.has_fignum
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     433                                         frameon=frameon,
#     434                                         FigureClass=FigureClass,
# --> 435                                         **kwargs)
#     436
#     437         if figLabel:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py in new_figure_manager(num, *args, **kwargs)
#      79     FigureClass = kwargs.pop('FigureClass', Figure)
#      80     figure = FigureClass(*args, **kwargs)
# ---> 81     return new_figure_manager_given_figure(num, figure)
#      82
#      83
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py in new_figure_manager_given_figure(num, figure)
#      87     """
#      88     _focus = windowing.FocusManager()
# ---> 89     window = Tk.Tk()
#      90     window.withdraw()
#      91
#
# /usr/lib/python3.4/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    1852                 baseName = baseName + ext
#    1853         interactive = 0
# -> 1854         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    1855         if useTk:
#    1856             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
# http://bokeh.pydata.org/en/latest/docs/gallery/texas.html
# http://briank.im/determining-counties-from-longlat/
from bokeh.io import show, output_notebook
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)
from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure

from bokeh.sampledata.us_counties import data as counties
from bokeh.sampledata.unemployment import data as unemployment

palette.reverse()

counties = {
    code: county for code, county in counties.items() if county["state"] == "nc"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment[county_id] for county_id in counties]
color_mapper = LogColorMapper(palette=palette)

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    plot_width=900,
    plot_height=380,
    title="NC Unemployment, 2009", tools=TOOLS,
    x_axis_location=None, y_axis_location=None
)
p.grid.grid_line_color = None

p.patches('x', 'y', source=source,
          fill_color={ 'field': 'rate', 'transform': color_mapper },
          fill_alpha=0.7, line_color="white", line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Name", "@name"),
    ("Unemployment rate)", "@rate%"),
    ("(Long, Lat)", "($x, $y)"),
]
output_notebook()
show(p, new='window')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ac268a6b-c992-466b-a3d4-4167167d90e8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="464b271e-e12b-41dc-a0b0-75e8746a0cb7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("464b271e-e12b-41dc-a0b0-75e8746a0cb7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("464b271e-e12b-41dc-a0b0-75e8746a0cb7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '464b271e-e12b-41dc-a0b0-75e8746a0cb7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d9ff400b-fe31-4a04-a27e-6080645c2b59":{"roots":{"references":[{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"cd198a4c-c382-4864-a572-c61cc542709a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e2c3c41-0862-4619-b2b6-797cb2fcae3a","type":"BasicTicker"}},"id":"f1f4da86-5bc0-4f15-a283-8e14bc7b2c93","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"cd198a4c-c382-4864-a572-c61cc542709a","subtype":"Figure","type":"Plot"},"point_policy":"follow_mouse","tooltips":[["Name","@name"],["Unemployment rate)","@rate%"],["(Long, Lat)","($x, $y)"]]},"id":"1e064aa2-6aa5-4a9d-805e-5fd63f5bcdef","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["name","y","x","rate"],"data":{"name":["Lee","Franklin","Clay","Tyrrell","Anson","Madison","Transylvania","Currituck","Robeson","Iredell","Hoke","Catawba","Pamlico","Carteret","Graham","Stanly","Beaufort","Pitt","Mitchell","Harnett","Davie","New Hanover","Burke","Forsyth","Chowan","Wayne","Alleghany","Macon","Yancey","Swain","Cumberland","Richmond","McDowell","Hertford","Caswell","Wake","Camden","Gates","Scotland","Avery","Person","Jones","Halifax","Davidson","Perquimans","Buncombe","Edgecombe","Watauga","Alexander","Nash","Yadkin","Surry","Craven","Orange","Lincoln","Henderson","Columbus","Vance","Caldwell","Mecklenburg","Sampson","Ashe","Rowan","Johnston","Guilford","Cherokee","Pender","Brunswick","Greene","Washington","Alamance","Randolph","Moore","Wilson","Stokes","Durham","Onslow","Lenoir","Gaston","Cleveland","Union","Cabarrus","Martin","Rutherford","Dare","Rockingham","Jackson","Hyde","Chatham","Pasquotank","Bladen","Granville","Warren","Bertie","Polk","Montgomery","Wilkes","Haywood","Duplin","Northampton"],"rate":[13.5,9.7,10.8,8.8,14.8,9.3,8.5,5.0,11.5,12.1,8.3,13.6,10.1,7.6,13.4,11.9,11.2,10.0,11.0,10.9,12.1,9.1,14.1,9.5,11.9,8.8,10.9,9.2,10.9,9.1,9.1,13.2,14.1,9.4,12.4,8.3,7.1,7.1,16.5,7.9,10.8,10.9,13.1,12.5,10.3,8.2,16.3,6.9,13.6,11.9,9.3,11.8,10.0,6.3,13.2,8.6,12.5,13.0,15.2,11.0,8.3,10.0,12.8,9.5,11.0,14.2,10.8,10.5,10.2,11.7,11.8,11.0,9.5,11.9,10.1,8.0,8.3,11.4,13.3,14.3,10.0,11.4,10.6,14.3,6.8,11.7,7.8,5.9,8.0,9.1,12.0,10.2,12.7,10.5,8.2,13.3,12.9,8.5,8.7,10.7],"x":[[-79.30382,-79.31218,-79.32077,-79.32726,-79.32916,-79.32905,-79.3415,-79.34553,-79.34959,-79.35491,-79.35679,-79.3576,-79.34476,-79.34177,-79.35001,-79.3499,-79.34113,-79.33406,-79.32031,-79.31157,-79.31732,-79.32191,-79.31069,-79.3037,-79.29177,-79.26176,-79.25355,-79.24471,-79.24453,-79.23663,-79.22706,-79.21902,-79.20955,-79.16705,-79.15797,-79.15201,-79.09446,-79.05105,-79.04768,-79.04049,-78.96985,-78.96976,-78.97059,-78.98155,-78.98536,-78.98677,-78.99748,-79.00441,-79.01131,-79.02407,-79.03131,-79.03758,-79.04537,-79.05014,-79.05771,-79.06407,-79.0695,-79.08554,-79.09247,-79.09643,-79.10664,-79.10875,-79.11082,-79.11623,-79.1315,-79.13418,-79.14529,-79.18293,-79.1833,-79.18358,-79.19838,-79.21523,-79.23361,-79.26548,-79.27139,-79.27184,-79.27602,-79.27729,-79.28946,-79.29733,-79.30379],[-78.1979,-78.18201,-78.17148,-78.15454,-78.13375,-78.12641,-78.12618,-78.1196,-78.11479,-78.11032,-78.1084,-78.09981,-78.09162,-78.08481,-78.07993,-78.07368,-78.06712,-78.06153,-78.05758,-78.05055,-78.0445,-78.03139,-78.01167,-78.00655,-78.01069,-78.0383,-78.05182,-78.05835,-78.0598,-78.07429,-78.08771,-78.09935,-78.10388,-78.11085,-78.12141,-78.13642,-78.14796,-78.15772,-78.16478,-78.17472,-78.17736,-78.1801,-78.18408,-78.19066,-78.20179,-78.21281,-78.21755,-78.22651,-78.23918,-78.25232,-78.2549,-78.25492,-78.26424,-78.26957,-78.26991,-78.27517,-78.28229,-78.29071,-78.2982,-78.301,-78.30446,-78.30729,-78.31045,-78.31508,-78.31898,-78.32411,-78.33207,-78.34262,-78.35198,-78.38895,-78.40572,-78.42159,-78.44001,-78.45726,-78.49258,-78.51461,-78.54493,-78.5465,-78.54649,-78.54636,-78.54622,-78.546,-78.54591,-78.54586,-78.54581,-78.5455,-78.54539,-78.54537,-78.54521,-78.54499,-78.5448,-78.54094,-78.53674,-78.53312,-78.52886,-78.52665,-78.52508,-78.52214,-78.52009,-7 ...
