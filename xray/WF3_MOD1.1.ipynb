# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q5 - "What are the phenotypes of the disease $disease"
#### Set diease to the DOID/OMIM curie id of the desired condition and run. (e.g. neutropenia - DOID:1227)
request = { "query_type_id": "Q5", "terms": { "disease": "DOID:1227" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# neutropenia	DOID:1227	Leukopenia	HP:0001882
# neutropenia	DOID:1227	Conjunctivitis	HP:0000509
# neutropenia	DOID:1227	Pulmonic stenosis	HP:0001642
# neutropenia	DOID:1227	Abnormal facial shape	HP:0001999
# neutropenia	DOID:1227	Gingivitis	HP:0000230
# neutropenia	DOID:1227	Pectus carinatum	HP:0000768
# neutropenia	DOID:1227	Abnormality of the mouth	HP:0000153
# neutropenia	DOID:1227	Midface retrusion	HP:0011800
# neutropenia	DOID:1227	Broad thumb	HP:0011304
# neutropenia	DOID:1227	Clinodactyly	HP:0030084
# neutropenia	DOID:1227	Cyclic neutropenia	HP:0040289
# neutropenia	DOID:1227	Recurrent bacterial infections	HP:0002718
# neutropenia	DOID:1227	Congenital neutropenia	HP:0005549
# neutropenia	DOID:1227	Periodontitis	HP:0000704
# neutropenia	DOID:1227	Carious teeth	HP:0000670
# neutropenia	DOID:1227	Acute monocytic leukemia	HP:0004845
# neutropenia	DOID:1227	Respiratory insufficiency	HP:0002093
# neutropenia	DOID:1227	Atrial septal defect	HP:0001631
# neutropenia	DOID:1227	Eosinophilia	HP:0001880
# neutropenia	DOID:1227	Monocytosis	HP:0012311
# neutropenia	DOID:1227	Thrombocytopenia	HP:0001873
# neutropenia	DOID:1227	B lymphocytopenia	HP:0010976
# neutropenia	DOID:1227	High palate	HP:0000218
# neutropenia	DOID:1227	Metacarpophalangeal joint contracture	HP:0006070
# neutropenia	DOID:1227	Malar flattening	HP:0000272
# neutropenia	DOID:1227	Recurrent pneumonia	HP:0006532
# neutropenia	DOID:1227	Erythroid hypoplasia	HP:0012133
# neutropenia	DOID:1227	Pulmonary arterial hypertension	HP:0002092
# neutropenia	DOID:1227	Curly eyelashes	HP:0007665
# neutropenia	DOID:1227	Cleft palate	HP:0000175
# neutropenia	DOID:1227	Neutropenia	HP:0001875
# neutropenia	DOID:1227	Chronic irritative conjunctivitis	HP:0007717
# neutropenia	DOID:1227	Recurrent skin infections	HP:0001581
# neutropenia	DOID:1227	Wide nasal bridge	HP:0000431
# neutropenia	DOID:1227	Concave nail	HP:0001598
# neutropenia	DOID:1227	Recurrent respiratory infections	HP:0002205
# neutropenia	DOID:1227	Growth delay	HP:0001510
# neutropenia	DOID:1227	Cryptorchidism	HP:0000028
# neutropenia	DOID:1227	Pes cavus	HP:0001761
# neutropenia	DOID:1227	Recurrent otitis media	HP:0000403
# neutropenia	DOID:1227	Downturned corners of mouth	HP:0002714
# neutropenia	DOID:1227	Oral ulcer	HP:0000155
# neutropenia	DOID:1227	Hypoplastic fingernail	HP:0001804
# neutropenia	DOID:1227	Fever	HP:0001945
# neutropenia	DOID:1227	Myelodysplasia	HP:0002863
# neutropenia	DOID:1227	Anteverted nares	HP:0000463
# neutropenia	DOID:1227	Sepsis	HP:0100806
# neutropenia	DOID:1227	Lymphocytosis	HP:0100827
# neutropenia	DOID:1227	Fatigue	HP:0012378
# neutropenia	DOID:1227	Monocytopenia	HP:0012312
# neutropenia	DOID:1227	Blepharitis	HP:0000498
# neutropenia	DOID:1227	Short eyelashes	HP:0010764
# neutropenia	DOID:1227	Premature loss of teeth	HP:0006480
# neutropenia	DOID:1227	Curly hair	HP:0002212
# neutropenia	DOID:1227	Splenomegaly	HP:0001744
# neutropenia	DOID:1227	IgA deficiency	HP:0002720
# neutropenia	DOID:1227	Ulnar deviation of finger	HP:0009465
# neutropenia	DOID:1227	Neonatal death	HP:0003811
# neutropenia	DOID:1227	Hearing impairment	HP:0000365
# neutropenia	DOID:1227	Lymphopenia	HP:0001888
# neutropenia	DOID:1227	Trichorrhexis nodosa	HP:0009886
# neutropenia	DOID:1227	Recurrent aphthous stomatitis	HP:0011107
# neutropenia	DOID:1227	Mitral regurgitation	HP:0001653
# neutropenia	DOID:1227	Increased susceptibility to fractures	HP:0002659
# neutropenia	DOID:1227	Hypertelorism	HP:0000316
# neutropenia	DOID:1227	Clubbing of fingers	HP:0100759
# neutropenia	DOID:1227	Hepatomegaly	HP:0002240
# neutropenia	DOID:1227	Increased antibody level in blood	HP:0010702
# neutropenia	DOID:1227	Pectus excavatum	HP:0000767
# neutropenia	DOID:1227	Abnormality of eosinophils	HP:0001879
# neutropenia	DOID:1227	Short stature	HP:0004322
# neutropenia	DOID:1227	Anemia	HP:0001903
# neutropenia	DOID:1227	Overlapping toe	HP:0001845
# neutropenia	DOID:1227	Abnormality of the skin	HP:0000951
# neutropenia	DOID:1227	Global developmental delay	HP:0001263
# neutropenia	DOID:1227	Sparse pubic hair	HP:0002225
# neutropenia	DOID:1227	Lymphadenopathy	HP:0002716
# neutropenia	DOID:1227	Failure to thrive	HP:0001508
# neutropenia	DOID:1227	C1-C2 subluxation	HP:0003320
# neutropenia	DOID:1227	Hypoplasia of dental enamel	HP:0006297
# neutropenia	DOID:1227	Seizures	HP:0001250
# neutropenia	DOID:1227	Growth abnormality	HP:0001507
# neutropenia	DOID:1227	Microcephaly	HP:0000252
# neutropenia	DOID:1227	Varicose veins	HP:0002619
# neutropenia	DOID:1227	Hydronephrosis	HP:0000126
# neutropenia	DOID:1227	Osteoporosis	HP:0000939
# neutropenia	DOID:1227	Hypoplasia of the thymus	HP:0000778
# neutropenia	DOID:1227	Intellectual disability, mild	HP:0001256
# neutropenia	DOID:1227	Epicanthus	HP:0000286
# neutropenia	DOID:1227	Leukemia	HP:0001909
# neutropenia	DOID:1227	Thrombocytosis	HP:0001894
# neutropenia	DOID:1227	Abdominal pain	HP:0002027
# neutropenia	DOID:1227	Patent ductus arteriosus	HP:0001643
# neutropenia	DOID:1227	Acute myeloid leukemia	HP:0004808
# neutropenia	DOID:1227	Single transverse palmar crease	HP:0000954
# neutropenia	DOID:1227	Synophrys	HP:0000664
# neutropenia	DOID:1227	Long-tract signs	HP:0002423
# neutropenia	DOID:1227	Poikiloderma	HP:0001029
# neutropenia	DOID:1227	Extramedullary hematopoiesis	HP:0001978
# neutropenia	DOID:1227	Recurrent infections	HP:0002719
# neutropenia	DOID:1227	Congenital agranulocytosis	HP:0005541

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-13 19:47:38",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/384",
#     "message": "101 results found",
#     "original_question_text": "",
#     "query_type_id": "Q5",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "Leukopenia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4611",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001882",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An abnormal decreased number of leukocytes in the blood.",
#                         "id": "HP:0001882",
#                         "name": "Leukopenia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001882"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Leukopenia",
#                 "HP:0001882"
#             ],
#             "text": "neutropenia and Leukopenia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Conjunctivitis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4615",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000509",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Inflammation of the conjunctiva.",
#                         "id": "HP:0000509",
#                         "name": "Conjunctivitis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000509"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Conjunctivitis",
#                 "HP:0000509"
#             ],
#             "text": "neutropenia and Conjunctivitis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Pulmonic stenosis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4647",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001642",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A narrowing of the right ventricular outflow tract that can occur at the pulmonary valve (valvular stenosis) or just below the pulmonary valve (infundibular stenosis).",
#                         "id": "HP:0001642",
#                         "name": "Pulmonic stenosis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001642"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Pulmonic stenosis",
#                 "HP:0001642"
#             ],
#             "text": "neutropenia and Pulmonic stenosis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Abnormal facial shape",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4635",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001999",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An abnormal morphology (form) of the face or its components.",
#                         "id": "HP:0001999",
#                         "name": "Abnormal facial shape",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001999"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Abnormal facial shape",
#                 "HP:0001999"
#             ],
#             "text": "neutropenia and Abnormal facial shape are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Gingivitis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4641",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000230",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Inflammation of the gingiva.",
#                         "id": "HP:0000230",
#                         "name": "Gingivitis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000230"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Gingivitis",
#                 "HP:0000230"
#             ],
#             "text": "neutropenia and Gingivitis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Pectus carinatum",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4666",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000768",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A deformity of the chest caused by overgrowth of the ribs and characterized by protrusion of the sternum.",
#                         "id": "HP:0000768",
#                         "name": "Pectus carinatum",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000768"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Pectus carinatum",
#                 "HP:0000768"
#             ],
#             "text": "neutropenia and Pectus carinatum are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Abnormality of the mouth",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4680",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000153",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An abnormality of the mouth.",
#                         "id": "HP:0000153",
#                         "name": "Abnormality of the mouth",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000153"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Abnormality of the mouth",
#                 "HP:0000153"
#             ],
#             "text": "neutropenia and Abnormality of the mouth are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Midface retrusion",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4646",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0011800",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Posterior positions and/or vertical shortening of the infraorbital and perialar regions, or increased concavity of the face and/or reduced nasolabial angle.",
#                         "id": "HP:0011800",
#                         "name": "Midface retrusion",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011800"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Midface retrusion",
#                 "HP:0011800"
#             ],
#             "text": "neutropenia and Midface retrusion are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Broad thumb",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4696",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0011304",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Increased thumb width without increased dorso-ventral dimension.",
#                         "id": "HP:0011304",
#                         "name": "Broad thumb",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011304"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Broad thumb",
#                 "HP:0011304"
#             ],
#             "text": "neutropenia and Broad thumb are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Clinodactyly",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4619",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0030084",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An angulation of a digit at an interphalangeal joint in the plane of the palm (finger) or sole (toe).",
#                         "id": "HP:0030084",
#                         "name": "Clinodactyly",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0030084"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Clinodactyly",
#                 "HP:0030084"
#             ],
#             "text": "neutropenia and Clinodactyly are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Cyclic neutropenia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4682",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0040289",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Recurrent episodes of abnormally low levels of neutrophils in the body (neutropenia).",
#                         "id": "HP:0040289",
#                         "name": "Cyclic neutropenia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0040289"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Cyclic neutropenia",
#                 "HP:0040289"
#             ],
#             "text": "neutropenia and Cyclic neutropenia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Recurrent bacterial infections",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4624",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0002718",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Increased susceptibility to bacterial infections, as manifested by recurrent episodes of bacterial infection.",
#                         "id": "HP:0002718",
#                         "name": "Recurrent bacterial infections",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0002718"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Recurrent bacterial infections",
#                 "HP:0002718"
#             ],
#             "text": "neutropenia and Recurrent bacterial infections are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Congenital neutropenia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4610",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0005549",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A form of neutropenia with congenital onset.",
#                         "id": "HP:0005549",
#                         "name": "Congenital neutropenia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0005549"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Congenital neutropenia",
#                 "HP:0005549"
#             ],
#             "text": "neutropenia and Congenital neutropenia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Periodontitis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4613",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000704",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Inflammation of the periodontium.",
#                         "id": "HP:0000704",
#                         "name": "Periodontitis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000704"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Periodontitis",
#                 "HP:0000704"
#             ],
#             "text": "neutropenia and Periodontitis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Carious teeth",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4678",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000670",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Caries is a multifactorial bacterial infection affecting the structure of the tooth. This term has been used to describe the presence of more than expected dental caries.",
#                         "id": "HP:0000670",
#                         "name": "Carious teeth",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000670"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Carious teeth",
#                 "HP:0000670"
#             ],
#             "text": "neutropenia and Carious teeth are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Acute monocytic leukemia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4657",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0004845",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The accumulation of transformed primitive hematopoietic blast cells, which lose their ability of normal differentiation and proliferation.",
#                         "id": "HP:0004845",
#                         "name": "Acute monocytic leukemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0004845"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Acute monocytic leukemia",
#                 "HP:0004845"
#             ],
#             "text": "neutropenia and Acute monocytic leukemia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Respiratory insufficiency",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4685",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0002093",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "HP:0002093",
#                         "name": "Respiratory insufficiency",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0002093"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Respiratory insufficiency",
#                 "HP:0002093"
#             ],
#             "text": "neutropenia and Respiratory insufficiency are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Atrial septal defect",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4662",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001631",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Atrial septal defect (ASD) is a congenital abnormality of the interatrial septum that enables blood flow between the left and right atria via the interatrial septum.",
#                         "id": "HP:0001631",
#                         "name": "Atrial septal defect",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001631"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Atrial septal defect",
#                 "HP:0001631"
#             ],
#             "text": "neutropenia and Atrial septal defect are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Eosinophilia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4602",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001880",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Increased count of eosinophils in the blood.",
#                         "id": "HP:0001880",
#                         "name": "Eosinophilia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001880"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Eosinophilia",
#                 "HP:0001880"
#             ],
#             "text": "neutropenia and Eosinophilia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Monocytosis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4690",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0012311",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An increased number of circulating monocytes.",
#                         "id": "HP:0012311",
#                         "name": "Monocytosis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012311"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Monocytosis",
#                 "HP:0012311"
#             ],
#             "text": "neutropenia and Monocytosis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Thrombocytopenia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4660",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001873",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A reduction in the number of circulating thrombocytes.",
#                         "id": "HP:0001873",
#                         "name": "Thrombocytopenia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001873"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Thrombocytopenia",
#                 "HP:0001873"
#             ],
#             "text": "neutropenia and Thrombocytopenia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "B lymphocytopenia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4687",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0010976",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An abnormal decrease from the normal count of B cells.",
#                         "id": "HP:0010976",
#                         "name": "B lymphocytopenia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0010976"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "B lymphocytopenia",
#                 "HP:0010976"
#             ],
#             "text": "neutropenia and B lymphocytopenia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "High palate",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4634",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000218",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Height of the palate more than 2 SD above the mean (objective) or palatal height at the level of the first permanent molar more than twice the height of the teeth (subjective).",
#                         "id": "HP:0000218",
#                         "name": "High palate",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000218"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "High palate",
#                 "HP:0000218"
#             ],
#             "text": "neutropenia and High palate are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Metacarpophalangeal joint contracture",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4606",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0006070",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A chronic loss of joint motion in metacarpophalangeal joints due to structural changes in muscle, tendons, ligaments, or skin that prevents normal movement.",
#                         "id": "HP:0006070",
#                         "name": "Metacarpophalangeal joint contracture",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0006070"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Metacarpophalangeal joint contracture",
#                 "HP:0006070"
#             ],
#             "text": "neutropenia and Metacarpophalangeal joint contracture are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Malar flattening",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4670",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000272",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Underdevelopment of the malar prominence of the jugal bone (zygomatic bone in mammals), appreciated in profile, frontal view, and/or by palpation.",
#                         "id": "HP:0000272",
#                         "name": "Malar flattening",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000272"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Malar flattening",
#                 "HP:0000272"
#             ],
#             "text": "neutropenia and Malar flattening are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Recurrent pneumonia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4681",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0006532",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An increased susceptibility to pneumonia as manifested by a history of recurrent episodes of pneumonia.",
#                         "id": "HP:0006532",
#                         "name": "Recurrent pneumonia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0006532"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Recurrent pneumonia",
#                 "HP:0006532"
#             ],
#             "text": "neutropenia and Recurrent pneumonia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Erythroid hypoplasia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4672",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0012133",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Decreased count of erythroid precursor cells, that is, erythroid lineage cells in the bone marrow.",
#                         "id": "HP:0012133",
#                         "name": "Erythroid hypoplasia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0012133"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Erythroid hypoplasia",
#                 "HP:0012133"
#             ],
#             "text": "neutropenia and Erythroid hypoplasia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Pulmonary arterial hypertension",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4698",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0002092",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Pulmonary hypertension is defined mean pulmonary artery pressure of 25mmHg or more and pulmonary capillary wedge pressure of 15mmHg or less when measured by right heart catheterisation at rest and in a supine position.",
#                         "id": "HP:0002092",
#                         "name": "Pulmonary arterial hypertension",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0002092"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Pulmonary arterial hypertension",
#                 "HP:0002092"
#             ],
#             "text": "neutropenia and Pulmonary arterial hypertension are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
# ...
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4676",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001643",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "In utero, the ductus arteriosus (DA) serves to divert ventricular output away from the lungs and toward the placenta by connecting the main pulmonary artery to the descending aorta. A patent ductus arteriosus (PDA) in the first 3 days of life is a physiologic shunt in healthy term and preterm newborn infants, and normally is substantially closed within about 24 hours after bith and completely closed after about three weeks. Failure of physiologcal closure is referred to a persistent or patent ductus arteriosus (PDA). Depending on the degree of left-to-right shunting, PDA can have clinical consequences.",
#                         "id": "HP:0001643",
#                         "name": "Patent ductus arteriosus",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001643"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Patent ductus arteriosus",
#                 "HP:0001643"
#             ],
#             "text": "neutropenia and Patent ductus arteriosus are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Acute myeloid leukemia",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4659",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0004808",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A form of leukemia characterized by overproduction of an early myeloid cell.",
#                         "id": "HP:0004808",
#                         "name": "Acute myeloid leukemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0004808"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Acute myeloid leukemia",
#                 "HP:0004808"
#             ],
#             "text": "neutropenia and Acute myeloid leukemia are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Single transverse palmar crease",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4638",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000954",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The distal and proximal transverse palmar creases are merged into a single transverse palmar crease.",
#                         "id": "HP:0000954",
#                         "name": "Single transverse palmar crease",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000954"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Single transverse palmar crease",
#                 "HP:0000954"
#             ],
#             "text": "neutropenia and Single transverse palmar crease are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Synophrys",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4689",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0000664",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Meeting of the medial eyebrows in the midline.",
#                         "id": "HP:0000664",
#                         "name": "Synophrys",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0000664"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Synophrys",
#                 "HP:0000664"
#             ],
#             "text": "neutropenia and Synophrys are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Long-tract signs",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4693",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0002423",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "HP:0002423",
#                         "name": "Long-tract signs",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0002423"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Long-tract signs",
#                 "HP:0002423"
#             ],
#             "text": "neutropenia and Long-tract signs are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Poikiloderma",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4658",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001029",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Poikiloderma refers to a patch of skin with (1) reticulated hypopigmentation and hyperpigmentation, (2) wrinkling secondary to epidermal atrophy, and (3) telangiectasias.",
#                         "id": "HP:0001029",
#                         "name": "Poikiloderma",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001029"
#                     },
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Poikiloderma",
#                 "HP:0001029"
#             ],
#             "text": "neutropenia and Poikiloderma are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Extramedullary hematopoiesis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4683",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0001978",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     },
#                     {
#                         "description": "The process of hematopoiesis occurring outside of the bone marrow (in the liver, thymus, and spleen) in the postnatal organisms.",
#                         "id": "HP:0001978",
#                         "name": "Extramedullary hematopoiesis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0001978"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Extramedullary hematopoiesis",
#                 "HP:0001978"
#             ],
#             "text": "neutropenia and Extramedullary hematopoiesis are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Recurrent infections",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4655",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0002719",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     },
#                     {
#                         "description": "Increased susceptibility to infections.",
#                         "id": "HP:0002719",
#                         "name": "Recurrent infections",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0002719"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Recurrent infections",
#                 "HP:0002719"
#             ],
#             "text": "neutropenia and Recurrent infections are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Congenital agranulocytosis",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/4609",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_1227",
#                         "source_id": "DOID:1227",
#                         "target_id": "HP:0005541",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "DOID:1227",
#                         "name": "neutropenia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_1227"
#                     },
#                     {
#                         "description": "Congenital onset of a marked decrease in the number of granulocytes.",
#                         "id": "HP:0005541",
#                         "name": "Congenital agranulocytosis",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0005541"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "neutropenia",
#                 "DOID:1227",
#                 "Congenital agranulocytosis",
#                 "HP:0005541"
#             ],
#             "text": "neutropenia and Congenital agranulocytosis are connected by the relationship has_phenotype"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "disease": "DOID:1227"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
