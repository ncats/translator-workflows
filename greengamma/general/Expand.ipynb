# %% [markdown]
# # Using ROBOKOP's expand service

# %% [markdown]
# The most basic functionality in answering questions is to start with an entity and find other connected entities.
# In this context, an entity is defined by a curie-formatted identifier.
#
# ROBOKOP's expand service performs this function.  The user provides an identifier and its biolink-model type, and the type of entities that it wants returned.  ROBOKOP will call out to any sources that it is aware of that can answer the particular question.  If multiple services can provide the information, ROBOKOP will call all of them.  It will then rank the results based on literature co-occurence data.

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# The following python function shows how to call the ROBOKOP expand service.  For the moment, let's focus only on the arguments `type1`, `identifier`, and `type2`.    The expand service is called when a user has an `identifier` of `type1`, and wants to know what entities of `type2` are connected to it.

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %% [markdown]
# ## Basic Usage

# %% [markdown]
# In this example, we have the `disease` Fanconi Anemia defined by the curie identifier `MONDO:0019391`.  We want to know the `phenotypic_feature`s that are associated with it.  We can call the function above like this:

# %%
fanconi_phenotypes = expand('disease', 'MONDO:0019391', 'phenotypic_feature')
# Out:
# Return Status: 200

# %% [markdown]
# ## Service Output

# %% [markdown]
# The result that comes back is json in the KG-standard.
#
# Importantly, results are ranked using ROBOKOP's standard ranking algorithm, which is looking at literature co-occurance based on the `omnicorp` repository.

# %%
#Uncomment to see a big long json (which uses up lots of room in the github render)
#print(json.dumps(fanconi_phenotypes,indent=4))

# %% [markdown]
# This output has plenty of information, but for display purposes, it's sometimes easier to tabularize with the following function:

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %%
fanconi_pheno_frame = parse_answer(fanconi_phenotypes)
fanconi_pheno_frame
# Out:
#       result_id                         result_name  \
# 0    HP:0005528         Bone marrow hypocellularity
# 1    HP:0004810       Congenital hypoplastic anemia
# 2    HP:0001908                  Hypoplastic anemia
# 3    HP:0010972     Anemia of inadequate production
# 4    HP:0004820       Acute myelomonocytic leukemia
# 5    HP:0001972                   Macrocytic anemia
# 6    HP:0000953       Hyperpigmentation of the skin
# 7    HP:0001876                        Pancytopenia
# 8    HP:0003974                       Absent radius
# 9    HP:0001905         Congenital thrombocytopenia
# 10   HP:0000286                          Epicanthus
# 11   HP:0003254           Abnormality of DNA repair
# 12   HP:0000957                   Cafe-au-lait spot
# 13   HP:0004859    Amegakaryocytic thrombocytopenia
# 14   HP:0003468       Abnormal vertebral morphology
# 15   HP:0002863                      Myelodysplasia
# 16   HP:0002023                        Anal atresia
# 17   HP:0009777                        Absent thumb
# 18   HP:0002984            Hypoplasia of the radius
# 19   HP:0004430    Severe combined immunodeficiency
# 20   HP:0005510        Transient erythroblastopenia
# 21   HP:0001172            Abnormality of the thumb
# 22   HP:0000824           Growth hormone deficiency
# 23   HP:0005505                   Refractory anemia
# 24   HP:0001000    Abnormality of skin pigmentation
# 25   HP:0001896                   Reticulocytopenia
# 26   HP:0004808              Acute myeloid leukemia
# 27   HP:0000104                      Renal agenesis
# 28   HP:0000164        Abnormality of the dentition
# 29   HP:0000086                      Ectopic kidney
# ..          ...                                 ...
# 156  HP:0010469                       Absent testis
# 157  HP:0009942        Duplication of thumb phalanx
# 158  HP:0007874     Almond-shaped palpebral fissure
# 159  HP:0100542     Abnormal localization of kidney
# 160  HP:0001679          Abnormal aortic morphology
# 161  HP:0000470                          Short neck
# 162  HP:0001646    Abnormal aortic valve morphology
# 163  HP:0000453                     Choanal atresia
# 164  HP:0001537                    Umbilical hernia
# 165  HP:0001284                           Areflexia
# 166  HP:0000072                         Hydroureter
# 167  HP:0000010  Recurrent urinary tract infections
# 168  HP:0003774      Stage 5 chronic kidney disease
# 169  HP:0000083                 Renal insufficiency
# 170  HP:0004349        Reduced bone mineral density
# 171  HP:0001562                     Oligohydramnios
# 172  HP:0006824             Cranial nerve paralysis
# 173  HP:0007354       Amyotrophic lateral sclerosis
# 174  HP:0002245                 Meckel diverticulum
# 175  HP:0001762                 Talipes equinovarus
# 176  HP:0000027                         Azoospermia
# 177  HP:0001824                         Weight loss
# 178  HP:0002414                        Spina bifida
# 179  HP:0002251               Aganglionic megacolon
# 180  HP:0000483                         Astigmatism
# 181  HP:0000505                   Visual impairment
# 182  HP:0000520                           Proptosis
# 183  HP:0100026          Arteriovenous malformation
# 184  HP:0000639                           Nystagmus
# 185  HP:0001639         Hypertrophic cardiomyopathy
#
#                             source           type
# 0    biolink.disease_get_phenotype  has_phenotype
# 1    biolink.disease_get_phenotype  has_phenotype
# 2    biolink.disease_get_phenotype  has_phenotype
# 3    biolink.disease_get_phenotype  has_phenotype
# 4    biolink.disease_get_phenotype  has_phenotype
# 5    biolink.disease_get_phenotype  has_phenotype
# 6    biolink.disease_get_phenotype  has_phenotype
# 7    biolink.disease_get_phenotype  has_phenotype
# 8    biolink.disease_get_phenotype  has_phenotype
# 9    biolink.disease_get_phenotype  has_phenotype
# 10   biolink.disease_get_phenotype  has_phenotype
# 11   biolink.disease_get_phenotype  has_phenotype
# 12   biolink.disease_get_phenotype  has_phenotype
# 13   biolink.disease_get_phenotype  has_phenotype
# 14   biolink.disease_get_phenotype  has_phenotype
# 15   biolink.disease_get_phenotype  has_phenotype
# 16   biolink.disease_get_phenotype  has_phenotype
# 17   biolink.disease_get_phenotype  has_phenotype
# 18   biolink.disease_get_phenotype  has_phenotype
# 19   biolink.disease_get_phenotype  has_phenotype
# 20   biolink.disease_get_phenotype  has_phenotype
# 21   biolink.disease_get_phenotype  has_phenotype
# 22   biolink.disease_get_phenotype  has_phenotype
# 23   biolink.disease_get_phenotype  has_phenotype
# 24   biolink.disease_get_phenotype  has_phenotype
# 25   biolink.disease_get_phenotype  has_phenotype
# 26   biolink.disease_get_phenotype  has_phenotype
# 27   biolink.disease_get_phenotype  has_phenotype
# 28   biolink.disease_get_phenotype  has_phenotype
# 29   biolink.disease_get_phenotype  has_phenotype
# ..                             ...            ...
# 156  biolink.disease_get_phenotype  has_phenotype
# 157  biolink.disease_get_phenotype  has_phenotype
# 158  biolink.disease_get_phenotype  has_phenotype
# 159  biolink.disease_get_phenotype  has_phenotype
# 160  biolink.disease_get_phenotype  has_phenotype
# 161  biolink.disease_get_phenotype  has_phenotype
# 162  biolink.disease_get_phenotype  has_phenotype
# 163  biolink.disease_get_phenotype  has_phenotype
# 164  biolink.disease_get_phenotype  has_phenotype
# 165  biolink.disease_get_phenotype  has_phenotype
# 166  biolink.disease_get_phenotype  has_phenotype
# 167  biolink.disease_get_phenotype  has_phenotype
# 168  biolink.disease_get_phenotype  has_phenotype
# 169  biolink.disease_get_phenotype  has_phenotype
# 170  biolink.disease_get_phenotype  has_phenotype
# 171  biolink.disease_get_phenotype  has_phenotype
# 172  biolink.disease_get_phenotype  has_phenotype
# 173  biolink.disease_get_phenotype  has_phenotype
# 174  biolink.disease_get_phenotype  has_phenotype
# 175  biolink.disease_get_phenotype  has_phenotype
# 176  biolink.disease_get_phenotype  has_phenotype
# 177  biolink.disease_get_phenotype  has_phenotype
# 178  biolink.disease_get_phenotype  has_phenotype
# 179  biolink.disease_get_phenotype  has_phenotype
# 180  biolink.disease_get_phenotype  has_phenotype
# 181  biolink.disease_get_phenotype  has_phenotype
# 182  biolink.disease_get_phenotype  has_phenotype
# 183  biolink.disease_get_phenotype  has_phenotype
# 184  biolink.disease_get_phenotype  has_phenotype
# 185  biolink.disease_get_phenotype  has_phenotype
#
# [186 rows x 4 columns]

# %% [markdown]
# In this case, all of the results are coming from biolink's disease to phenotype function.  As mentioned above, results here are ranked by their literature co-occurence with the query term.
#
# If the caller doesn't want to dig around in a json return, they can also ask for a csv-style list:

# %%
fanconi_phenotypes_csv = expand('disease', 'MONDO:0019391', 'phenotypic_feature',csv=True)
# Out:
# Return Status: 200

# %%
fanconi_phenotypes_csv
# Out:
# ['Bone marrow hypocellularity(HP:0005528)',
#  'Congenital hypoplastic anemia(HP:0004810)',
#  'Hypoplastic anemia(HP:0001908)',
#  'Anemia of inadequate production(HP:0010972)',
#  'Acute myelomonocytic leukemia(HP:0004820)',
#  'Macrocytic anemia(HP:0001972)',
#  'Hyperpigmentation of the skin(HP:0000953)',
#  'Pancytopenia(HP:0001876)',
#  'Absent radius(HP:0003974)',
#  'Congenital thrombocytopenia(HP:0001905)',
#  'Epicanthus(HP:0000286)',
#  'Abnormality of DNA repair(HP:0003254)',
#  'Cafe-au-lait spot(HP:0000957)',
#  'Amegakaryocytic thrombocytopenia(HP:0004859)',
#  'Abnormal vertebral morphology(HP:0003468)',
#  'Myelodysplasia(HP:0002863)',
#  'Anal atresia(HP:0002023)',
#  'Absent thumb(HP:0009777)',
#  'Hypoplasia of the radius(HP:0002984)',
#  'Severe combined immunodeficiency(HP:0004430)',
#  'Transient erythroblastopenia(HP:0005510)',
#  'Abnormality of the thumb(HP:0001172)',
#  'Growth hormone deficiency(HP:0000824)',
#  'Refractory anemia(HP:0005505)',
#  'Abnormality of skin pigmentation(HP:0001000)',
#  'Reticulocytopenia(HP:0001896)',
#  'Acute myeloid leukemia(HP:0004808)',
#  'Renal agenesis(HP:0000104)',
#  'Abnormality of the dentition(HP:0000164)',
#  'Ectopic kidney(HP:0000086)',
#  'Microphthalmia(HP:0000568)',
#  'Abnormality of the cell cycle(HP:0011018)',
#  'T-cell acute lymphoblastic leukemias(HP:0006727)',
#  'Autoimmune thrombocytopenia(HP:0001973)',
#  'Microcephaly(HP:0000252)',
#  'Hypotelorism(HP:0000601)',
#  'Increased sensitivity to ionizing radiation(HP:0011133)',
#  'Microtia(HP:0008551)',
#  'Abnormality of the kidney(HP:0000077)',
#  'Esophageal atresia(HP:0002032)',
#  'Increased hemoglobin(HP:0001900)',
#  'Micropenis(HP:0000054)',
#  'Abnormality of the outer ear(HP:0000356)',
#  'Horseshoe kidney(HP:0000085)',
#  'Telangiectasia(HP:0001009)',
#  'Acute leukemia(HP:0002488)',
#  'External genital hypoplasia(HP:0003241)',
#  'High palate(HP:0000218)',
#  'Chromosomal breakage induced by crosslinking agents(HP:0003221)',
#  'Triphalangeal thumb(HP:0001199)',
#  'Short palpebral fissure(HP:0012745)',
#  'Duodenal atresia(HP:0002247)',
#  'Abnormal lung lobation(HP:0002101)',
#  'Abnormality of cardiovascular system morphology(HP:0030680)',
#  'Facial hypotonia(HP:0000297)',
#  'Anteverted nares(HP:0000463)',
#  'Severe short stature(HP:0003510)',
#  'Growth delay(HP:0001510)',
#  'Tracheoesophageal fistula(HP:0002575)',
#  'Ichthyosis(HP:0008064)',
#  'Hypogonadotrophic hypogonadism(HP:0000044)',
#  'Finger syndactyly(HP:0006101)',
#  'Hypoplasia of the ulna(HP:0003022)',
#  'Nephroblastoma(HP:0002667)',
#  'Medulloblastoma(HP:0002885)',
#  'Micrognathia(HP:0000347)',
#  'Abnormality of the face(HP:0000271)',
#  'Anemia(HP:0001903)',
#  'Acute lymphoblastic leukemia(HP:0006721)',
#  'Renal hypoplasia(HP:0000089)',
#  'Squamous cell carcinoma(HP:0002860)',
#  'Failure to thrive(HP:0001508)',
#  'Ventriculomegaly(HP:0002119)',
#  'Abnormality of the liver(HP:0001392)',
#  'Hypertelorism(HP:0000316)',
#  'Cryptorchidism(HP:0000028)',
#  'Hemolytic anemia(HP:0001878)',
#  'Ataxia(HP:0001251)',
#  'Neutropenia(HP:0001875)',
#  'Renal cyst(HP:0000107)',
#  'Hypospadias(HP:0000047)',
#  'Thrombocytopenia(HP:0001873)',
#  'Ovarian neoplasm(HP:0100615)',
#  'Global developmental delay(HP:0001263)',
#  'Facial asymmetry(HP:0000324)',
#  'Vitiligo(HP:0001045)',
#  'Leukopenia(HP:0001882)',
#  'Intrauterine growth retardation(HP:0001511)',
#  'Leukemia(HP:0001909)',
#  'Breast carcinoma(HP:0003002)',
#  'Abnormal heart morphology(HP:0001627)',
#  'Tetralogy of Fallot(HP:0001636)',
#  'Hydrocephalus(HP:0000238)',
#  'Infertility(HP:0000789)',
#  'Ventricular septal defect(HP:0001629)',
#  'Ptosis(HP:0000508)',
#  'Hepatocellular carcinoma(HP:0001402)',
#  'Neuroblastoma(HP:0003006)',
#  'Immunodeficiency(HP:0002721)',
#  'Patent ductus arteriosus(HP:0001643)',
#  'Strabismus(HP:0000486)',
#  'Hydronephrosis(HP:0000126)',
#  'Cleft palate(HP:0000175)',
#  'Intellectual disability(HP:0001249)',
#  'Imbalanced hemoglobin synthesis(HP:0005560)',
#  'Complement deficiency(HP:0004431)',
#  'Hypoplasia of the premaxilla(HP:0010650)',
#  'Sepsis(HP:0100806)',
#  'Scoliosis(HP:0002650)',
#  'Normochromic anemia(HP:0001895)',
#  'Hip dislocation(HP:0002827)',
#  'Reduced factor VIII activity(HP:0003125)',
#  'Small for gestational age(HP:0001518)',
#  'Hearing impairment(HP:0000365)',
#  'Metrorrhagia(HP:0100608)',
#  'Cerebral hypoplasia(HP:0006872)',
#  'Low-set ears(HP:0000369)',
#  'Atrial septal defect(HP:0001631)',
#  'Cataract(HP:0000518)',
#  'Pyridoxine-responsive sideroblastic anemia(HP:0005522)',
#  'Wide nasal bridge(HP:0000431)',
#  'Dolichocephaly(HP:0000268)',
#  'Aplasia/Hypoplasia of fingers(HP:0006265)',
#  'Absent scaphoid(HP:0011835)',
#  'Bulbous nose(HP:0000414)',
#  'Sloping forehead(HP:0000340)',
#  'Upslanted palpebral fissure(HP:0000582)',
#  'Anemic pallor(HP:0001017)',
#  'Abnormality of the preputium(HP:0100587)',
#  'Extrahepatic biliary duct atresia(HP:0005242)',
#  'Pelvic kidney(HP:0000125)',
#  'Prolonged G2 phase of cell cycle(HP:0003214)',
#  'Duplicated collecting system(HP:0000081)',
#  'Hypopigmented skin patches(HP:0001053)',
#  'Abnormality of femur morphology(HP:0002823)',
#  'Aplasia/Hypoplasia of the uvula(HP:0010293)',
#  'Abnormal carotid artery morphology(HP:0005344)',
#  'Rectal atresia(HP:0025023)',
#  'Depressed nasal bridge(HP:0005280)',
#  'Aplasia/Hypoplasia of the iris(HP:0008053)',
#  'Bicornuate uterus(HP:0000813)',
#  'Abnormality of chromosome stability(HP:0003220)',
#  'Abnormality of the hypothalamus-pituitary axis(HP:0000864)',
#  'Multiple cafe-au-lait spots(HP:0007565)',
#  'Frontal bossing(HP:0002007)',
#  'Clinodactyly of the 5th finger(HP:0004209)',
#  'Elevated alpha-fetoprotein(HP:0006254)',
#  'Deficient excision of UV-induced pyrimidine dimers in DNA(HP:0003213)',
#  'Decreased fertility in males(HP:0012041)',
#  'Blepharophimosis(HP:0000581)',
#  'Aplasia/Hypoplasia of the radius(HP:0006501)',
#  'Complete duplication of thumb phalanx(HP:0009943)',
#  'Renal hypoplasia/aplasia(HP:0008678)',
#  'Irregular hyperpigmentation(HP:0007400)',
#  'Pes planus(HP:0001763)',
#  'Bruising susceptibility(HP:0000978)',
#  'Absent testis(HP:0010469)',
#  'Duplication of thumb phalanx(HP:0009942)',
#  'Almond-shaped palpebral fissure(HP:0007874)',
#  'Abnormal localization of kidney(HP:0100542)',
#  'Abnormal aortic morphology(HP:0001679)',
#  'Short neck(HP:0000470)',
#  'Abnormal aortic valve morphology(HP:0001646)',
#  'Choanal atresia(HP:0000453)',
#  'Umbilical hernia(HP:0001537)',
#  'Areflexia(HP:0001284)',
#  'Hydroureter(HP:0000072)',
#  'Recurrent urinary tract infections(HP:0000010)',
#  'Stage 5 chronic kidney disease(HP:0003774)',
#  'Renal insufficiency(HP:0000083)',
#  'Reduced bone mineral density(HP:0004349)',
#  'Oligohydramnios(HP:0001562)',
#  'Cranial nerve paralysis(HP:0006824)',
#  'Amyotrophic lateral sclerosis(HP:0007354)',
#  'Meckel diverticulum(HP:0002245)',
#  'Talipes equinovarus(HP:0001762)',
#  'Azoospermia(HP:0000027)',
#  'Weight loss(HP:0001824)',
#  'Spina bifida(HP:0002414)',
#  'Aganglionic megacolon(HP:0002251)',
#  'Astigmatism(HP:0000483)',
#  'Visual impairment(HP:0000505)',
#  'Proptosis(HP:0000520)',
#  'Arteriovenous malformation(HP:0100026)',
#  'Nystagmus(HP:0000639)',
#  'Hypertrophic cardiomyopathy(HP:0001639)']

# %% [markdown]
# ## Curie inputs and synonymization

# %% [markdown]
# ROBOKOP will perform identifier translations when it can.  This means that for most common input types, there are a range of curie prefixes that will work without the user doing any work.
#
# For example, Fanconi Anemia is identified as `MONDO:0019339`, which is ROBOKOP's preferred identifier, but that is equivalent to `DOID:13636`, `Orphanet:84`, `NCIT:C62505`, `UMLS:C0015625`, `MeSH:D005199`, and `MedDRA:10055206`.  We can see that calling expand with any of these inputs will produce the same results:

# %%
equivalents=['MedDRA:10055206','DOID:13636','UMLS:C0015625','Orphanet:84','NCIT:C62505','MeSH:D005199']
for equivalent_id in equivalents:
    e_result = expand('disease', equivalent_id, 'phenotypic_feature',csv=True)
    print(equivalent_id, len(e_result), e_result[0])
# Out:
# Return Status: 200
# MedDRA:10055206 186 Bone marrow hypocellularity(HP:0005528)
# Return Status: 200
# DOID:13636 186 Bone marrow hypocellularity(HP:0005528)
# Return Status: 200
# UMLS:C0015625 186 Bone marrow hypocellularity(HP:0005528)
# Return Status: 200
# Orphanet:84 186 Bone marrow hypocellularity(HP:0005528)
# Return Status: 200
# NCIT:C62505 186 Bone marrow hypocellularity(HP:0005528)
# Return Status: 200
# MeSH:D005199 186 Bone marrow hypocellularity(HP:0005528)

# %% [markdown]
# ## Query Types

# %% [markdown]
# The `type1` and `type2` arguments are chosen from the [biolink-model](https://biolink.github.io/biolink-model/).  While any type in the model is potentially acceptable, only some types are exposed via ROBOKOP.  The current list of acceptable types is:
#
# * disease_or_phenotypic_feature
#     * **phenotypic_feature**
#     * **disease**
#        * genetic_condition
#
# * **gene**
#
# * **anatomical_entity**
#     * **cell**
#     * gross_anatomical_structure
#     * cellular_component
#
# * **biological_process_or_activity**
#     * biological_process
#         * pathway
#     * molecular_activity
#
# * **chemical_substance**
#     * metabolite
#     * drug
#
# ROBOKOP understands the hierarchical nature of these relationships and can figure out services to call at a different level of the heirarchy.  For instance, suppose an adverse events service returns a mix of diseases and phenotypic features, but the caller only wants diseases.  The user can then ask for diseases, and the service will be called an automatically filtered.  On the other hand, if a user is willing to accept, say, either disease or phenotypic features for a query, then any function that returns both, or either type will automatically get called.
#
# Because of ROBOKOP's caching (see below), some types will return more quickly than others.  These types are in **bold** above.
#
# Note that `genetic_condition` above is not part of the biolink model, but is an additional type that descends from disease in ROBOKOP.
#
# As an example, we'll call expand twice with the same gene, once asking for a disease, and once asking for a genetic condition. There are no translator services that return only genetic condition, but the service knows how to recognize genetic conditions and returns only those diseases that are genetic conditions:

# %%
NPC1_diseases = set(expand('gene', 'HGNC:7897', 'disease',csv=True,rebuild=True)) #HGNC:7897 = "NPC1"
NPC1_genetic_conditions = set(expand('gene', 'HGNC:7897', 'genetic_condition',csv=True,rebuild=True))
# Out:
# Return Status: 200
# Return Status: 200

# %%
print('There are',len(NPC1_genetic_conditions),'Genetic Conditions associated with NPC1')
print('There are',len(NPC1_diseases),'Diseases associated with NPC1')
print(len(NPC1_diseases.intersection(NPC1_genetic_conditions)),'of these are in common. In other words, everything in the genetic condition list is also in the disease list')
# Out:
# There are 16 Genetic Conditions associated with NPC1
# There are 39 Diseases associated with NPC1
# 16 of these are in common. In other words, everything in the genetic condition list is also in the disease list

# %% [markdown]
# ## Caching and Rebuilding

# %% [markdown]
# ROBOKOP maintains caches results.  The cache is built both opportunistically (including the results of all previous queries) and proactively (pre-loading data that expected to be heavily used).  By default, expand only looks in its cache.  If a result has not been previously cached, then this call will not return anything (and may return a status code of 500).
#
# If a user wants to force the service to look beyond its local cache, it sends a parameter `rebuild=True`, as seen in the NPC1 examples above.
#
# If a user wants to be sure to retreive all relevant data, they should use `rebuild=True`, but this will be at the expense of performance.  In order to increase performance without sacrificing reliability, certain type pairs are preloaded into the cache.  In this case, there will be no difference in results between calling `rebuild=True` and `rebuild=False`, but calling with `rebuild=True` will be noticeably slower.
#
# Certain pairs of types are preloaded into ROBOKOP's cache, so there is no point in using rebuild for them. The following list will be updated as the preloaded list is modified.  Note that with the data loaded, it doesn't matter which type is the query and which is the resut.  That is, if a row in this table specifies `disease` and `phenotypic_feature`, then there is no reason to use rebuild for `type1='disease' type2='phenotypic_feature'` or `type1='phenotypic_feature' type2='disease'`.
#
# | type | type |
# |------|------|
# | disease | phenotypic_feature |
# | genetic_condition | phenotypic_feature |
# | gene    | biological_process_or_activity |
# | gene    | disease |
# | disease | chemical_substance |
# | gene | chemical_substance |
# | anatomical_entity | phenotypic_feature |

# %% [markdown]
# ## Specifying Predicates

# %% [markdown]
# The responses can be filtered by a predicate, which should also come from the biolink model.  Here, we look up any chemical that is associated with asthma:

# %%
asthma = "MONDO:0004979"
asthma_chemicals = expand('disease',asthma,'chemical_substance',rebuild=True)
# Out:
# Return Status: 200

# %% [markdown]
# There are multiple types that come back from this query: treats, contributes_to, associated_with, etc...

# %%
asthma_chem_frame = parse_answer(asthma_chemicals)
asthma_chem_frame
# Out:
#             result_id                                        result_name  \
# 0         CHEBI:93095  2-(4-(4,4-bis(4-fluorophenyl)butyl)piperazin-1...
# 1         CHEBI:27744                                         glyphosate
# 2         CHEBI:33101                                   Nitrogen Dioxide
# 3         CHEBI:18422                                     Sulfur Dioxide
# 4         CHEBI:34905                                           Paraquat
# 5         CHEBI:25812                                              Ozone
# 6          CHEBI:3001                                     Beclomethasone
# 7        MESH:D000393                                     Air Pollutants
# 8         CHEBI:10100                                        zafirlukast
# 9        MESH:D014028                            Tobacco Smoke Pollution
# 10       MESH:D001335                                  Vehicle Emissions
# 11        CHEBI:38764                                            Phorate
# 12        CHEBI:50730                                        montelukast
# 13        CHEBI:53556                           Toluene 2,4-Diisocyanate
# 14         CHEBI:3207                                         Budesonide
# 15        CHEBI:34623                                           Chlordan
# 16         CHEBI:5134                                        Fluticasone
# 17         CHEBI:3903                                          Coumaphos
# 18       MESH:D004391                                               Dust
# 19        CHEBI:83569                                      pendimethalin
# 20         CHEBI:2555                                           Aldicarb
# 21         CHEBI:4738                                               EPTC
# 22        CHEBI:48991                                     methylxanthine
# 23        CHEBI:27928                                          Parathion
# 24         CHEBI:7492                                         Nedocromil
# 25        CHEBI:34682                                           Diazinon
# 26         CHEBI:2659                                      Aminophylline
# 27        CHEBI:23012                                   Carbon Disulfide
# 28       CHEBI:128458                                    Cromolyn Sodium
# 29        CHEBI:28666                                     Leukotriene D4
# ..                ...                                                ...
# 177      MESH:D011433                                        Propranolol
# 178      MESH:D007660                                         Ketoprofen
# 179      MESH:D004731                                         Endotoxins
# 180      MESH:D004396                                    Coloring Agents
# 181      MESH:D005659                             Fungicides, Industrial
# 182      MESH:D012997                                           Solvents
# 183       CHEBI:38069                                          cyanazine
# 184       CHEBI:31810                                         Fleroxacin
# 185      MESH:D006221                                          Halothane
# 186  PUBCHEM:11954221                                        flunisolide
# 187      MESH:C009264                                           fenoprop
# 188      MESH:D007052                                          Ibuprofen
# 189      MESH:C011685                                         bitolterol
# 190      MESH:D028321                                 Plant Preparations
# 191      MESH:D013645                                         Tartrazine
# 192      MESH:C047766                                         bambuterol
# 193    PUBCHEM:042771  3-(2,4-diamino-6-(3-hydroxyphenyl)pteridin-7-y...
# 194      MESH:D006024                                     Glycopyrrolate
# 195      MESH:C038459                                            curdlan
# 196       CHEBI:92579                                   Dextromethorphan
# 197      PUBCHEM:4396               phosphatidylinositol 3,4-diphosphate
# 198       CHEBI:25434                                        Mustard Gas
# 199       CHEBI:15407                                          Ephedrine
# 200      MESH:C446402                                     ovalbumin-alum
# 201       CHEBI:68444                                   1-Methylxanthine
# 202       CHEBI:27595                                          11b-PGF2a
# 203    PUBCHEM:119226                                   3-Chlorotyrosine
# 204       CHEBI:62207                                   3-Methylxanthine
# 205       CHEBI:28209                                             5-HETE
# 206    PUBCHEM:273429                                   Isoleucylproline
#
#                          source            type
# 0       ctd.disease_to_exposure  contributes_to
# 1       ctd.disease_to_exposure  contributes_to
# 2       ctd.disease_to_exposure  contributes_to
# 3       ctd.disease_to_exposure  contributes_to
# 4       ctd.disease_to_exposure  contributes_to
# 5       ctd.disease_to_exposure  contributes_to
# 6       ctd.disease_to_chemical          treats
# 7       ctd.disease_to_exposure  contributes_to
# 8       ctd.disease_to_chemical          treats
# 9       ctd.disease_to_exposure  contributes_to
# 10      ctd.disease_to_exposure  contributes_to
# 11      ctd.disease_to_exposure  contributes_to
# 12      ctd.disease_to_chemical          treats
# 13      ctd.disease_to_chemical  contributes_to
# 14      ctd.disease_to_chemical          treats
# 15      ctd.disease_to_exposure  contributes_to
# 16      ctd.disease_to_chemical          treats
# 17      ctd.disease_to_exposure  contributes_to
# 18      ctd.disease_to_exposure  contributes_to
# 19      ctd.disease_to_exposure  contributes_to
# 20      ctd.disease_to_exposure  contributes_to
# 21      ctd.disease_to_exposure  contributes_to
# 22      ctd.disease_to_chemical          treats
# 23      ctd.disease_to_exposure  contributes_to
# 24      ctd.disease_to_chemical          treats
# 25      ctd.disease_to_exposure  contributes_to
# 26      ctd.disease_to_chemical          treats
# 27      ctd.disease_to_exposure  contributes_to
# 28      ctd.disease_to_chemical          treats
# 29      ctd.disease_to_chemical  contributes_to
# ..                          ...             ...
# 177     ctd.disease_to_chemical          treats
# 178     ctd.disease_to_chemical  contributes_to
# 179     ctd.disease_to_exposure  contributes_to
# 180     ctd.disease_to_chemical  contributes_to
# 181     ctd.disease_to_chemical  contributes_to
# 182     ctd.disease_to_chemical  contributes_to
# 183     ctd.disease_to_exposure          treats
# 184     ctd.disease_to_chemical  contributes_to
# 185     ctd.disease_to_chemical          treats
# 186     ctd.disease_to_chemical          treats
# 187     ctd.disease_to_exposure  contributes_to
# 188     ctd.disease_to_chemical  contributes_to
# 189     ctd.disease_to_chemical          treats
# 190     ctd.disease_to_chemical          treats
# 191     ctd.disease_to_chemical  contributes_to
# 192     ctd.disease_to_chemical          treats
# 193     ctd.disease_to_chemical          treats
# 194     ctd.disease_to_chemical          treats
# 195     ctd.disease_to_chemical  contributes_to
# 196     ctd.disease_to_chemical  contributes_to
# 197     ctd.disease_to_chemical  contributes_to
# 198     ctd.disease_to_chemical  contributes_to
# 199     ctd.disease_to_chemical          treats
# 200     ctd.disease_to_chemical  contributes_to
# 201  hmdb.disease_to_metabolite      related_to
# 202  hmdb.disease_to_metabolite      related_to
# 203  hmdb.disease_to_metabolite      related_to
# 204  hmdb.disease_to_metabolite      related_to
# 205  hmdb.disease_to_metabolite      related_to
# 206  hmdb.disease_to_metabolite      related_to
#
# [207 rows x 4 columns]

# %% [markdown]
# Now we can do an expand setting the predicate to treats, and we'll only return the chemicals above with that predicate type.  Note that we don't need to rebuild, since this will be a subset of the previous query, and so everything will already be in our local cache.

# %%
asthma_treatment = expand('disease',asthma,'chemical_substance',predicate='treats')
# Out:
# Return Status: 200

# %%
asthma_treat_frame = parse_answer(asthma_treatment)
asthma_treat_frame
# Out:
#                result_id                                        result_name  \
# 0             CHEBI:3001                                     Beclomethasone
# 1            CHEBI:10100                                        zafirlukast
# 2            CHEBI:50730                                        montelukast
# 3             CHEBI:3207                                         Budesonide
# 4             CHEBI:5134                                        Fluticasone
# 5             CHEBI:7492                                         Nedocromil
# 6             CHEBI:2659                                      Aminophylline
# 7           CHEBI:128458                                    Cromolyn Sodium
# 8            CHEBI:47564                                 Mometasone Furoate
# 9            CHEBI:47657                                        Roflumilast
# 10          CHEBI:126237                                       enprofylline
# 11            CHEBI:6538  4-(8-Chloro-5,6-dihydro-benzo[5,6]cyclohepta[1...
# 12          CHEBI:135418                                         oxitropium
# 13           CHEBI:77572                                          tranilast
# 14           CHEBI:94714                                        doxofylline
# 15           CHEBI:71418                            Triamcinolone Acetonide
# 16            CHEBI:8378                                       Prednisolone
# 17            CHEBI:8382                                         Prednisone
# 18           CHEBI:18185                                   gamma-Tocopherol
# 19           CHEBI:41879                                      Dexamethasone
# 20           CHEBI:17650                                     Hydrocortisone
# 21           CHEBI:28918                                        Epinephrine
# 22            CHEBI:7565                                         Nifedipine
# 23          CHEBI:617099                                        Carbimazole
# 24           CHEBI:48991                                     methylxanthine
# 25           CHEBI:17489                                         Cyclic AMP
# 26           CHEBI:63918                                         artesunate
# 27           CHEBI:50131                                         decitabine
# 28           CHEBI:27744                                         glyphosate
# 29           CHEBI:44185                                       Methotrexate
# ..                   ...                                                ...
# 64          MESH:C099445                                            S 28463
# 65           CHEBI:45713                                        resveratrol
# 66          MESH:D018927                              Anti-Asthmatic Agents
# 67       MESH:D000068297            Fluticasone-Salmeterol Drug Combination
# 68   CHEMBL:CHEMBL511115                                         Cilomilast
# 69      PUBCHEM:58886963                                   arsenic trioxide
# 70         PUBCHEM:31110                                          FR 173657
# 71          MESH:D016593                                        Terfenadine
# 72   CHEMBL:CHEMBL172498                                          doqualast
# 73  CHEMBL:CHEMBL2104472                                         apaflurane
# 74          MESH:D013578                                         Synephrine
# 75          MESH:C024070                                        pycnogenols
# 76          MESH:C034206                                          Ribomunyl
# 77          MESH:D064747                                       Lansoprazole
# 78    CHEMBL:CHEMBL58061    Trimethoprim, Sulfamethoxazole Drug Combination
# 79           CHEBI:34846                                         metribuzin
# 80            CHEBI:4806                           epigallocatechin gallate
# 81  CHEMBL:CHEMBL3184894                    ambroxol-theophylline-7-acetate
# 82   CHEMBL:CHEMBL280481                                          verlukast
# 83          MESH:D058988                     Phosphodiesterase 4 Inhibitors
# 84          MESH:D011433                                        Propranolol
# 85           CHEBI:38069                                          cyanazine
# 86          MESH:D006221                                          Halothane
# 87      PUBCHEM:11954221                                        flunisolide
# 88          MESH:C011685                                         bitolterol
# 89          MESH:D028321                                 Plant Preparations
# 90          MESH:C047766                                         bambuterol
# 91        PUBCHEM:042771  3-(2,4-diamino-6-(3-hydroxyphenyl)pteridin-7-y...
# 92          MESH:D006024                                     Glycopyrrolate
# 93           CHEBI:15407                                          Ephedrine
#
#                      source    type
# 0   ctd.disease_to_chemical  treats
# 1   ctd.disease_to_chemical  treats
# 2   ctd.disease_to_chemical  treats
# 3   ctd.disease_to_chemical  treats
# 4   ctd.disease_to_chemical  treats
# 5   ctd.disease_to_chemical  treats
# 6   ctd.disease_to_chemical  treats
# 7   ctd.disease_to_chemical  treats
# 8   ctd.disease_to_chemical  treats
# 9   ctd.disease_to_chemical  treats
# 10  ctd.disease_to_chemical  treats
# 11  ctd.disease_to_chemical  treats
# 12  ctd.disease_to_chemical  treats
# 13  ctd.disease_to_chemical  treats
# 14  ctd.disease_to_chemical  treats
# 15  ctd.disease_to_chemical  treats
# 16  ctd.disease_to_chemical  treats
# 17  ctd.disease_to_chemical  treats
# 18  ctd.disease_to_chemical  treats
# 19  ctd.disease_to_chemical  treats
# 20  ctd.disease_to_chemical  treats
# 21  ctd.disease_to_chemical  treats
# 22  ctd.disease_to_chemical  treats
# 23  ctd.disease_to_chemical  treats
# 24  ctd.disease_to_chemical  treats
# 25  ctd.disease_to_chemical  treats
# 26  ctd.disease_to_chemical  treats
# 27  ctd.disease_to_chemical  treats
# 28  ctd.disease_to_exposure  treats
# 29  ctd.disease_to_chemical  treats
# ..                      ...     ...
# 64  ctd.disease_to_chemical  treats
# 65  ctd.disease_to_chemical  treats
# 66  ctd.disease_to_chemical  treats
# 67  ctd.disease_to_chemical  treats
# 68  ctd.disease_to_chemical  treats
# 69  ctd.disease_to_chemical  treats
# 70  ctd.disease_to_chemical  treats
# 71  ctd.disease_to_chemical  treats
# 72  ctd.disease_to_chemical  treats
# 73  ctd.disease_to_chemical  treats
# 74  ctd.disease_to_chemical  treats
# 75  ctd.disease_to_chemical  treats
# 76  ctd.disease_to_chemical  treats
# 77  ctd.disease_to_chemical  treats
# 78  ctd.disease_to_chemical  treats
# 79  ctd.disease_to_exposure  treats
# 80  ctd.disease_to_chemical  treats
# 81  ctd.disease_to_chemical  treats
# 82  ctd.disease_to_chemical  treats
# 83  ctd.disease_to_chemical  treats
# 84  ctd.disease_to_chemical  treats
# 85  ctd.disease_to_exposure  treats
# 86  ctd.disease_to_chemical  treats
# 87  ctd.disease_to_chemical  treats
# 88  ctd.disease_to_chemical  treats
# 89  ctd.disease_to_chemical  treats
# 90  ctd.disease_to_chemical  treats
# 91  ctd.disease_to_chemical  treats
# 92  ctd.disease_to_chemical  treats
# 93  ctd.disease_to_chemical  treats
#
# [94 rows x 4 columns]

# %% [markdown]
# ## Data sources and allowed hops

# %% [markdown]
# ROBOKOP can join many kinds of types, but only those for which it has a configured knowledge source.  For instance, ROBOKOP doesn't currently have a way to join `chemical_substance` and `biological_process_or_activity` directly.  Currently, these are the service hops that are configured in ROBOKOP.  As above, ROBOKOP will traverse the biolink-model hierarchy, so for instance if there is an entry from `metabolite` to `disease` below, then it will also be possible to call `chemical_substance` to `disease`.
#
# The most up-to-date list, and information about which services are configured for each pair of types, can always be found in [this file](https://github.com/NCATS-Gamma/robokop-interfaces/blob/master/greent/rosetta.yml)
#
# | input type | output type |
# |------------|------------|
# | anatomical_entity | cell |
# | anatomical_entity | gene |
# | anatomical_entity | phenotypic_feature |
# | cell | anatomical_entity |
# | cell | biological_process_or_activity |
# | biological_process_or_activity | gene |
# | biological_process_or_activity | cell |
# | chemical_substance | gene |
# | chemical_substance | disease |
# | chemical_substance | phenotypic_feature |
# | disease | phenotypic_feature |
# | disease | gene |
# | disease | chemical_substance |
# | metabolite | pathway |
# | gene | anatomical_entity |
# | gene | disease |
# | gene | chemical_substance |
# | gene | pathway |
# | gene | biological_process_or_activity |
# | pathway | gene |
# | pathway | metabolite |
# | phenotypic_feature | anatomical_entity |
# | phenotypic_feature | disease |
