# %% [markdown]
# # Workflow 1, Module 2, Question 3

# %% [markdown]
# ## What pathways/processes are [genes] involved in?

# %% [markdown]
# ### Strategy 1: expand with loop

# %% [markdown]
# If you want to know the pathways / processes that a gene is involved in, you can use expand.  If you have a list of genes and you want to know the union of all processes that the genes are involved with, this is the best approach.

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import json
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %% [markdown]
# These are some genes from Questions 1 and 2:

# %%
PRKAA1 = 'HGNC:9376'
XBP1 = 'HGNC:12801'
MTATP1 = 'HGNC:7414'
NEIL1 = 'HGNC:18448'
FRK = 'HGNC:3955'

mody_genes = [PRKAA1,XBP1,MTATP1,NEIL1,FRK]

# %% [markdown]
# Expand takes a single gene, so you need to call it individually.  Here we combine the results into a single frame, but you may wish to handle it differently.

# %%
pframes = []
for gene in mody_genes:
    processes = expand('gene',gene,'biological_process_or_activity')
    process_frame = parse_answer(processes)
    process_frame['gene'] = gene
    pframes.append(process_frame)
all_processes = pd.concat(pframes)
all_processes
# Out:
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
#      result_id                                        result_name  \
# 0   GO:0004679              AMP-activated protein kinase activity
# 1   GO:0004674           protein serine/threonine kinase activity
# 2   GO:0055089                             fatty acid homeostasis
# 3   GO:0016236                                     macroautophagy
# 4   GO:0008284          positive regulation of cell proliferation
# 5   GO:0097009                                 energy homeostasis
# 6   GO:0009631                                   cold acclimation
# 7   GO:0019395                               fatty acid oxidation
# 8   GO:0006633                    fatty acid biosynthetic process
# 9   GO:0004672                            protein kinase activity
# 10  GO:0001666                                response to hypoxia
# 11  GO:0001666                                response to hypoxia
# 12  GO:0043066           negative regulation of apoptotic process
# 13  GO:0043066           negative regulation of apoptotic process
# 14  GO:0042593                                glucose homeostasis
# 15  GO:0042593                                glucose homeostasis
# 16  GO:0006695                   cholesterol biosynthetic process
# 17  GO:0008610                         lipid biosynthetic process
# 18  GO:0006468                            protein phosphorylation
# 19  GO:0007050                                  cell cycle arrest
# 20  GO:0007050                                  cell cycle arrest
# 21  GO:0006006                          glucose metabolic process
# 22  GO:0006006                          glucose metabolic process
# 23  GO:0050995     negative regulation of lipid catabolic process
# 24  GO:0010628             positive regulation of gene expression
# 25  GO:0009411                                     response to UV
# 26  GO:0034599              cellular response to oxidative stress
# 27  GO:0071456                       cellular response to hypoxia
# 28  GO:0010629             negative regulation of gene expression
# 29  GO:0010332                        response to gamma radiation
# ..         ...                                                ...
# 0   GO:0019104                         DNA N-glycosylase activity
# 1   GO:0006284                               base-excision repair
# 2   GO:0006284                               base-excision repair
# 3   GO:0016798       hydrolase activity, acting on glycosyl bonds
# 4   GO:0006289                         nucleotide-excision repair
# 5   GO:0006289                         nucleotide-excision repair
# 6   GO:0006979                       response to oxidative stress
# 7   GO:0006979                       response to oxidative stress
# 8   GO:0003906  DNA-(apurinic or apyrimidinic site) endonuclea...
# 9   GO:0008022                         protein C-terminus binding
# 10  GO:0032074           negative regulation of nuclease activity
# 11  GO:0045008                                   depyrimidination
# 12  GO:0140078  class I DNA-(apurinic or apyrimidinic site) en...
# 13  GO:0008022                         protein C-terminus binding
# 14  GO:0003684                                damaged DNA binding
# 15  GO:0008270                                   zinc ion binding
# 0   GO:0004713                   protein tyrosine kinase activity
# 1   GO:0005524                                        ATP binding
# 2   GO:0043312                           neutrophil degranulation
# 3   GO:0007169  transmembrane receptor protein tyrosine kinase...
# 4   GO:0004715  non-membrane spanning protein tyrosine kinase ...
# 5   GO:0038083              peptidyl-tyrosine autophosphorylation
# 6   GO:0000122  negative regulation of transcription by RNA po...
# 7   GO:0030154                               cell differentiation
# 8   GO:0030154                               cell differentiation
# 9   GO:0008285          negative regulation of cell proliferation
# 10  GO:0008285          negative regulation of cell proliferation
# 11  GO:0006468                            protein phosphorylation
# 12  GO:0045087                             innate immune response
# 13  GO:0005102                         signaling receptor binding
#
#                                   source                  type        gene
# 0   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 1   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 2   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 3   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 4   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 5   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 6   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 7   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 8   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 9   biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 10    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 11  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 12    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 13  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 14    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 15  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 16  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 17  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 18  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 19    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 20  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 21    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 22  biolink.gene_get_process_or_function  actively_involved_in   HGNC:9376
# 23    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 24    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 25    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 26    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 27    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 28    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# 29    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:9376
# ..                                   ...                   ...         ...
# 0   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 1     quickgo.go_term_to_gene_annotation  actively_involved_in  HGNC:18448
# 2   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 3   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 4     quickgo.go_term_to_gene_annotation  actively_involved_in  HGNC:18448
# 5   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 6     quickgo.go_term_to_gene_annotation  actively_involved_in  HGNC:18448
# 7   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 8   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 9   biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 10  biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 11  biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 12  biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 13    quickgo.go_term_to_gene_annotation        contributes_to  HGNC:18448
# 14    quickgo.go_term_to_gene_annotation        contributes_to  HGNC:18448
# 15  biolink.gene_get_process_or_function  actively_involved_in  HGNC:18448
# 0   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 1   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 2   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 3   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 4   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 5   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 6     quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:3955
# 7   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 8     quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:3955
# 9   biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 10    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:3955
# 11  biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
# 12    quickgo.go_term_to_gene_annotation  actively_involved_in   HGNC:3955
# 13  biolink.gene_get_process_or_function  actively_involved_in   HGNC:3955
#
# [200 rows x 5 columns]

# %% [markdown]
# ### Enrichment

# %% [markdown]
# If you don't care about every process that every gene is involved with, but are instead trying to find the most common process, you can use enrichment and do a single call:

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://{robokop_server}/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
enriched_processes = enrichment('gene',mody_genes,'biological_process_or_activity')
pd.DataFrame(enriched_processes)
# Out:
# Return Status: 200
#             id                                               name         p
# 0   GO:0055089                             fatty acid homeostasis  0.000004
# 1   GO:0006633                    fatty acid biosynthetic process  0.000025
# 2   GO:0042149            cellular response to glucose starvation  0.000025
# 3   GO:0071333              cellular response to glucose stimulus  0.000064
# 4   GO:0009631                                   cold acclimation  0.000425
# 5   GO:0062028              regulation of stress granule assembly  0.000425
# 6   GO:0050405           [acetyl-CoA carboxylase] kinase activity  0.000425
# 7   GO:2000758  positive regulation of peptidyl-lysine acetyla...  0.000425
# 8   GO:0047322  [hydroxymethylglutaryl-CoA reductase (NADPH)] ...  0.000425
# 9   GO:0035404                     histone-serine phosphorylation  0.000638
# 10  GO:0006990  positive regulation of transcription from RNA ...  0.000638
# 11  GO:0035470      positive regulation of vascular wound healing  0.000638
# 12  GO:0055092                                 sterol homeostasis  0.000638
# 13  GO:1990418    response to insulin-like growth factor stimulus  0.000638
# 14  GO:0061762                       CAMKK-AMPK signaling cascade  0.000638
# 15  GO:1903489                   positive regulation of lactation  0.000638
# 16  GO:0008022                         protein C-terminus binding  0.000780
# 17  GO:2001274  negative regulation of glucose import in respo...  0.000851
# 18  GO:0071417       cellular response to organonitrogen compound  0.000851
# 19  GO:0061744                                     motor behavior  0.000851
# 20  GO:0031670                      cellular response to nutrient  0.001063
# 21  GO:1900103  positive regulation of endoplasmic reticulum u...  0.001063
# 22  GO:1904428       negative regulation of tubulin deacetylation  0.001063
# 23  GO:0035174                     histone serine kinase activity  0.001063
# 24  GO:0045542  positive regulation of cholesterol biosyntheti...  0.001063
# 25  GO:0071332             cellular response to fructose stimulus  0.001063
# 26  GO:0045348  positive regulation of MHC class II biosynthet...  0.001276
# 27  GO:0004679              AMP-activated protein kinase activity  0.001276
# 28  GO:0016798       hydrolase activity, acting on glycosyl bonds  0.001276
# 29  GO:0002639   positive regulation of immunoglobulin production  0.001276
# ..         ...                                                ...       ...
# 70  GO:0032007               negative regulation of TOR signaling  0.006154
# 71  GO:0070507  regulation of microtubule cytoskeleton organiz...  0.006154
# 72  GO:0010332                        response to gamma radiation  0.006365
# 73  GO:0022857                 transmembrane transporter activity  0.006577
# 74  GO:0042407                                  cristae formation  0.006577
# 75  GO:1903955  positive regulation of protein targeting to mi...  0.006577
# 76  GO:0043066           negative regulation of apoptotic process  0.006608
# 77  GO:0070059  intrinsic apoptotic signaling pathway in respo...  0.006789
# 78  GO:0038083              peptidyl-tyrosine autophosphorylation  0.007000
# 79  GO:0097009                                 energy homeostasis  0.007000
# 80  GO:0030968    endoplasmic reticulum unfolded protein response  0.008269
# 81  GO:0006468                            protein phosphorylation  0.008644
# 82  GO:0006695                   cholesterol biosynthetic process  0.008691
# 83  GO:0031648                            protein destabilization  0.008902
# 84  GO:0014823                               response to activity  0.008902
# 85  GO:0004715  non-membrane spanning protein tyrosine kinase ...  0.009114
# 86  GO:0010508                   positive regulation of autophagy  0.009114
# 87  GO:0042752                     regulation of circadian rhythm  0.010169
# 88  GO:0045600    positive regulation of fat cell differentiation  0.010380
# 89  GO:0048666                                 neuron development  0.010591
# 90  GO:0048511                                   rhythmic process  0.010802
# 91  GO:0009411                                     response to UV  0.010802
# 92  GO:0001085     RNA polymerase II transcription factor binding  0.011013
# 93  GO:0036498            IRE1-mediated unfolded protein response  0.011223
# 94  GO:0071230           cellular response to amino acid stimulus  0.011434
# 95  GO:0030154                               cell differentiation  0.011598
# 96  GO:0001889                                  liver development  0.011856
# 97  GO:0070301             cellular response to hydrogen peroxide  0.012698
# 98  GO:0006284                               base-excision repair  0.012909
# 99  GO:0007169  transmembrane receptor protein tyrosine kinase...  0.014171
#
# [100 rows x 3 columns]
