# %% [markdown]
# # Using ROBOKOP's Quick Question Answering Service

# %% [markdown]
# The expand, enrich, and similarity services each offer bite-sized approaches to interacting with ROBOKOP.  The ROBOKOP "quick" service offers a slightly more complex approach to answering questions.   We'll be using the following function to call the quick service.  Note that calling the service requires posting a question.  We'll discuss the format of the question below.

# %%
import requests

def quick(question):
    #url=f'http://127.0.0.1:80/api/simple/quick/'
    url=f'http://robokop.renci.org:80/api/simple/quick/'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %% [markdown]
# ## Question Format and Basic Usage

# %% [markdown]
# The question is a python dictionary.  It takes a key `machine_question`, which is a dictionary containing a list of `nodes` and a list of `edges`.   Each node object needs an integer `id`.   Any node can also have a `curie` specifying that node.  The edges define connections between the nodes using the identifiers of the nodes as source and targets. The following function shows how to construct a single-hop question.  It takes a specified node of `type1` and looks for any node of `type2`.

# %%
def make_one_step_question(type1, id1, type2):
    question = {
                'machine_question': {
                    'nodes': [
                        {
                            'id': 0,
                            'curie': id1,
                            'type': type1
                        },
                        {
                            'id': 1,
                            'type': type2
                        }
                    ],
                    'edges': [
                        {
                            'source_id': 0,
                            'target_id': 1
                        }
                    ]
                }
            }
    return question

# %% [markdown]
# Here, we will specify a one-hop question asking for the phenotypes associated with Fanconi Anemia (MONDO:0019391).  We first construct the question then use it to call the quick service.  In fact, this is how the expand function is implemented internally.

# %%
q = make_one_step_question('disease','MONDO:0019391','phenotypic_feature')
r = quick(q)
# Out:
# Return Status: 200

# %%
import json
print( json.dumps(r, indent=4))
# Out:
# {
#     "answers": [
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0005528",
#                     "equivalent_identifiers": [
#                         "HP:0005528",
#                         "UMLS:C1855710",
#                         "MEDDRA:10065553"
#                     ],
#                     "name": "Bone marrow hypocellularity",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 2571
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0005528",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1176905,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.08679,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.7849926330420856
#                     },
#                     "weight": 0.5631162788353057
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "13c91762-9702-47b3-adb2-4a8a6c572ca9",
#                     "publications": [
#                         "PMID:95616",
#                         "PMID:283689",
#                         "PMID:303430",
#                         "PMID:617986",
#                         "PMID:890097",
#                         "PMID:1613241",
#                         "PMID:1641375",
#                         "PMID:2087661",
#                         "PMID:1777602",
#                         "PMID:2454138",
#                         "PMID:2741928",
#                         "PMID:2691723",
#                         "PMID:6992072",
#                         "PMID:6378486",
#                         "PMID:6778045",
#                         "PMID:3535929",
#                         "PMID:7552587",
#                         "PMID:7182868",
#                         "PMID:7518843",
#                         "PMID:7544677",
#                         "PMID:7662964",
#                         "PMID:7691316",
#                         "PMID:7670120",
#                         "PMID:7686032",
#                         "PMID:7712649",
#                         "PMID:7698059",
#                         "PMID:8032812",
#                         "PMID:7846061",
#                         "PMID:7743239",
#                         "PMID:7853372",
#                         "PMID:8630504",
#                         "PMID:8286733",
#                         "PMID:8597846",
#                         "PMID:8673053",
#                         "PMID:8687457",
#                         "PMID:8673470",
#                         "PMID:8680512",
#                         "PMID:8782494",
#                         "PMID:8704210",
#                         "PMID:8703809",
#                         "PMID:8898923",
#                         "PMID:8844212",
#                         "PMID:28558075",
#                         "PMID:28637614",
#                         "PMID:28631178",
#                         "PMID:28811338",
#                         "PMID:28644950",
#                         "PMID:29031493",
#                         "PMID:28837162",
#                         "PMID:28911102",
#                         "PMID:29051281",
#                         "PMID:29100324",
#                         "PMID:29167174",
#                         "PMID:29146883",
#                         "PMID:29133208",
#                         "PMID:29150103"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0005528",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 539,
#                         "ngd": 0.18968663594826718
#                     },
#                     "weight": 0.9670240909092558
#                 }
#             ],
#             "score": 1.2495822303269084
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0004810",
#                     "equivalent_identifiers": [
#                         "HP:0004810",
#                         "UMLS:C0220686",
#                         "MEDDRA:10063429",
#                         "UMLS:C0002876",
#                         "NCIT:C84646",
#                         "MEDDRA:10062988",
#                         "MEDDRA:10062989",
#                         "NCIT:C61236",
#                         "UMLS:C1260899",
#                         "UMLS:C0265265"
#                     ],
#                     "name": "Congenital hypoplastic anemia",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 266
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0004810",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:9443046",
#                         "PMID:1746615",
#                         "PMID:9021520",
#                         "PMID:10698294",
#                         "PMID:8160759"
#                     ],
#                     "id": 1177022,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.089241,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 5,
#                         "ngd": 0.5649769611733756
#                     },
#                     "weight": 0.7426935317028206
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "f4ac51c2-06ed-433d-b5a4-3b5782076719",
#                     "publications": [
#                         "PMID:273451",
#                         "PMID:615597",
#                         "PMID:1746615",
#                         "PMID:1776145",
#                         "PMID:1956715",
#                         "PMID:3296341",
#                         "PMID:5938027",
#                         "PMID:7626383",
#                         "PMID:8160759",
#                         "PMID:9021520",
#                         "PMID:9371275",
#                         "PMID:9443046",
#                         "PMID:10698294",
#                         "PMID:11176237",
#                         "PMID:11264183",
#                         "PMID:11563776",
#                         "PMID:14952013",
#                         "PMID:18026880",
#                         "PMID:20278337",
#                         "PMID:19213990"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0004810",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 20,
#                         "ngd": 0.4561633523033205
#                     },
#                     "weight": 0.8237228815574845
#                 }
#             ],
#             "score": 1.1960696474088945
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0001908",
#                     "name": "Hypoplastic anemia",
#                     "equivalent_identifiers": [
#                         "HP:0012133",
#                         "HP:0001915",
#                         "UMLS:C0002874",
#                         "MEDDRA:10002274",
#                         "MEDDRA:10021072",
#                         "MEDDRA:10002967",
#                         "MEDDRA:10002037",
#                         "MEDDRA:10002968",
#                         "MEDDRA:10021075",
#                         "MEDDRA:10021074",
#                         "MEDDRA:10002294",
#                         "UMLS:C0178416",
#                         "UMLS:C0542035",
#                         "MEDDRA:10002970",
#                         "MEDDRA:10002969",
#                         "HP:0001908",
#                         "MEDDRA:10002061"
#                     ],
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 283
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0001908",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:6207874",
#                         "PMID:8727007",
#                         "PMID:2454138",
#                         "PMID:21325596",
#                         "PMID:20191926"
#                     ],
#                     "id": 1176954,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.087741,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 5,
#                         "ngd": 0.5649769611733756
#                     },
#                     "weight": 0.7426935317028206
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "64063d5a-914d-4012-99f8-6b74ea2a1a78",
#                     "publications": [
#                         "PMID:283689",
#                         "PMID:660362",
#                         "PMID:1746615",
#                         "PMID:1776145",
#                         "PMID:2454138",
#                         "PMID:5938027",
#                         "PMID:6207874",
#                         "PMID:6465473",
#                         "PMID:6992072",
#                         "PMID:7626383",
#                         "PMID:8438892",
#                         "PMID:13923041",
#                         "PMID:8727007",
#                         "PMID:12993536",
#                         "PMID:13444313",
#                         "PMID:14360748",
#                         "PMID:14884730",
#                         "PMID:14953949",
#                         "PMID:24426331"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0001908",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 19,
#                         "ngd": 0.4604012121173081
#                     },
#                     "weight": 0.8207464953385964
#                 }
#             ],
#             "score": 1.1930932611900067
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0010972",
#                     "equivalent_identifiers": [
#                         "UMLS:C0392708",
#                         "HP:0010972",
#                         "UMLS:C0678199"
#                     ],
#                     "name": "Anemia of inadequate production",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 1242
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0010972",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:11022796",
#                         "PMID:615596",
#                         "PMID:694417",
#                         "PMID:9009445",
#                         "PMID:1718488"
#                     ],
#                     "id": 1176870,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0861342,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 5,
#                         "ngd": 0.5758163111975636
#                     },
#                     "weight": 0.7341840286697484
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "1ee652d4-743f-46a3-9628-135f47679630",
#                     "publications": [
#                         "PMID:644412",
#                         "PMID:694417",
#                         "PMID:1718488",
#                         "PMID:1749630",
#                         "PMID:11022796",
#                         "PMID:9009445",
#                         "PMID:10192448",
#                         "PMID:6156625",
#                         "PMID:7698059",
#                         "PMID:19213990",
#                         "PMID:17631177",
#                         "PMID:20824457"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0010972",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 12,
#                         "ngd": 0.5073694247768785
#                     },
#                     "weight": 0.7867053755594082
#                 }
#             ],
#             "score": 1.1547973898942825
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "equivalent_identifiers": [
#                         "UMLS:C1405984",
#                         "UMLS:C1838608",
#                         "UMLS:C1849314",
#                         "HP:0003974"
#                     ],
#                     "name": "Absent radius",
#                     "id": "HP:0003974",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 231
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0003974",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:21910217"
#                     ],
#                     "id": 1176819,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0855858,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 1,
#                         "ngd": 0.6604012121173081
#                     },
#                     "weight": 0.66601481411901
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "e0e5e3bc-d37b-4cb8-9c3b-7a47e401bd1e",
#                     "publications": [
#                         "PMID:3367608",
#                         "PMID:4017281",
#                         "PMID:4951233",
#                         "PMID:7262642",
#                         "PMID:7686032",
#                         "PMID:9934984",
#                         "PMID:10388017",
#                         "PMID:11446655",
#                         "PMID:20333885",
#                         "PMID:12718078",
#                         "PMID:14577674",
#                         "PMID:16945723",
#                         "PMID:18024606",
#                         "PMID:24032294",
#                         "PMID:20435624",
#                         "PMID:24888387",
#                         "PMID:23401811",
#                         "PMID:24246701",
#                         "PMID:25581972"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0003974",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 19,
#                         "ngd": 0.4604012121173081
#                     },
#                     "weight": 0.8207464953385964
#                 }
#             ],
#             "score": 1.154753902398101
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0004820",
#                     "equivalent_identifiers": [
#                         "UMLS:C0023479",
#                         "HP:0004820",
#                         "MEDDRA:10054297",
#                         "NCIT:C7463",
#                         "MEDDRA:10000890"
#                     ],
#                     "name": "Acute myelomonocytic leukemia",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 679
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0004820",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:6778045",
#                         "PMID:7240694",
#                         "PMID:269749",
#                         "PMID:2816920"
#                     ],
#                     "id": 1177261,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0946574,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 4,
#                         "ngd": 0.5808132103829006
#                     },
#                     "weight": 0.7302402272079278
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "cea4bf54-6f2b-4497-b42b-d4c91e285733",
#                     "publications": [
#                         "PMID:269749",
#                         "PMID:2659993",
#                         "PMID:2816920",
#                         "PMID:6940973",
#                         "PMID:6778045",
#                         "PMID:23937881",
#                         "PMID:7240694",
#                         "PMID:27976485",
#                         "PMID:28419882"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0004820",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 9,
#                         "ngd": 0.5206072112501043
#                     },
#                     "weight": 0.7767914848236331
#                 }
#             ],
#             "score": 1.1429115984275966
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0000953",
#                     "equivalent_identifiers": [
#                         "MEDDRA:10040865",
#                         "UMLS:C0162834",
#                         "MEDDRA:10020715",
#                         "MEDDRA:10020713",
#                         "MEDDRA:10050574",
#                         "HP:0000953"
#                     ],
#                     "name": "Hyperpigmentation of the skin",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 863
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0000953",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:8597846",
#                         "PMID:1163071",
#                         "PMID:7581463",
#                         "PMID:2691723",
#                         "PMID:7154038"
#                     ],
#                     "id": 1177303,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0954974,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 5,
#                         "ngd": 0.5649769611733756
#                     },
#                     "weight": 0.7426935317028206
#                 },
#                 {
#                     "type": "literature_co-occurrence",
#                     "id": "e00c3489-0122-4b57-9ee9-0448a284f945",
#                     "publications": [
#                         "PMID:1163071",
#                         "PMID:2691723",
#                         "PMID:7154038",
#                         "PMID:7581463",
#                         "PMID:9226464",
#                         "PMID:8597846",
#                         "PMID:10731985",
#                         "PMID:9475178"
#                     ],
#                     "source_database": "omnicorp",
#                     "source_id": "MONDO:0019391",
#                     "target_id": "HP:0000953",
#                     "edge_source": "omnicorp.term_to_term",
#                     "scoring": {
#                         "num_pubs": 8,
#                         "ngd": 0.5297587093622392
#                     },
#                     "weight": 0.7698639645046533
#                 }
#             ],
#             "score": 1.1422107303560638
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0001972",
#                     "name": "Macrocytic anemia",
#                     "equivalent_identifiers": [
#                         "MEDDRA:10074043",
#                         "NCIT:C34381",
#                         "MEDDRA:10002297",
#                         "MEDDRA:10025380",
#                         "UMLS:C0002886",
#                         "MEDDRA:10002064",
#                         "MEDDRA:10025381",
#                         "HP:0001972"
#                     ],
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 724
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0001972",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [
#                         "PMID:9443046",
#                         "PMID:8037347",
#                         "PMID:10753603",
#                         "PMID:10698294",
#                         "PMID:8160759"
#                     ],
#                     "id": 1176998,
#                     "predicate_id": "RO:0002200",
# ...
#                         "UMLS:C0085758",
#                         "UMLS:C3661523",
#                         "MEDDRA:10027110",
#                         "HP:0011286",
#                         "MEDDRA:10001472",
#                         "MEDDRA:10034276",
#                         "MEDDRA:10027114",
#                         "MEDDRA:10010539",
#                         "HP:0002251",
#                         "MEDDRA:10049896",
#                         "NCIT:C34700",
#                         "UMLS:C0025160",
#                         "MEDDRA:10020109",
#                         "MEDDRA:10078849"
#                     ],
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 7673
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0002251",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1176888,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.086511,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.8835563010980384
#                     },
#                     "weight": 0.4830992667039563
#                 }
#             ],
#             "score": 0.48409926670395637
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "equivalent_identifiers": [
#                         "MEDDRA:10003569",
#                         "MEDDRA:10003570",
#                         "UMLS:C0004106",
#                         "HP:0000483"
#                     ],
#                     "name": "Astigmatism",
#                     "id": "HP:0000483",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 9816
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0000483",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1177048,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0897424,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9078843039851845
#                     },
#                     "weight": 0.46387101295859384
#                 }
#             ],
#             "score": 0.46487101295859384
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0000505",
#                     "name": "Visual impairment",
#                     "equivalent_identifiers": [
#                         "UMLS:C0042798",
#                         "MEDDRA:10047508",
#                         "MEDDRA:10047517",
#                         "MEDDRA:10068171",
#                         "MEDDRA:10047516",
#                         "MEDDRA:10005178",
#                         "MEDDRA:10000187",
#                         "HP:0000572",
#                         "HP:0012508",
#                         "UMLS:C0271185",
#                         "MEDDRA:10036163",
#                         "HP:0000505",
#                         "HP:0012047",
#                         "UMLS:C0018975",
#                         "MEDDRA:10047510",
#                         "MEDDRA:10019451",
#                         "UMLS:C3665386",
#                         "MEDDRA:10063341",
#                         "UMLS:C3665347",
#                         "MEDDRA:10000186",
#                         "MEDDRA:10047571"
#                     ],
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 9826
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0000505",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1176979,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0887377,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9079848756718102
#                     },
#                     "weight": 0.4637920715477184
#                 }
#             ],
#             "score": 0.4647920715477186
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "equivalent_identifiers": [
#                         "MEDDRA:10015687",
#                         "MEDDRA:10006548",
#                         "MEDDRA:10015685",
#                         "UMLS:C1837760",
#                         "NCIT:C118763",
#                         "NCIT:C87114",
#                         "MEDDRA:10015683",
#                         "MEDDRA:10036905",
#                         "UMLS:C1848490",
#                         "UMLS:C0015300",
#                         "UMLS:C1862425",
#                         "HP:0000520"
#                     ],
#                     "name": "Proptosis",
#                     "id": "HP:0000520",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 10167
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0000520",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1177250,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0943246,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9113544879651518
#                     },
#                     "weight": 0.46114989839963044
#                 }
#             ],
#             "score": 0.46214989839963055
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0100026",
#                     "equivalent_identifiers": [
#                         "UMLS:C0003857",
#                         "HP:0100026",
#                         "MEDDRA:10000035",
#                         "MEDDRA:10019389",
#                         "MEDDRA:10003186",
#                         "MEDDRA:10003193",
#                         "NCIT:C2882",
#                         "UMLS:C0334533",
#                         "MEDDRA:10003229",
#                         "UMLS:CN226888",
#                         "MEDDRA:10055898"
#                     ],
#                     "name": "Arteriovenous malformation",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 13514
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0100026",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1177239,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0940788,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9394627673627135
#                     },
#                     "weight": 0.4393256650657853
#                 }
#             ],
#             "score": 0.4403256650657853
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "equivalent_identifiers": [
#                         "HP:0012044",
#                         "UMLS:C0271385",
#                         "MEDDRA:10029869",
#                         "UMLS:C0271388",
#                         "HP:0010544",
#                         "UMLS:C0344243",
#                         "HP:0001583",
#                         "UMLS:C4020734",
#                         "HP:0000639",
#                         "UMLS:C0271386",
#                         "NCIT:C3282",
#                         "UMLS:C0028738",
#                         "UMLS:C0240595",
#                         "HP:0000666",
#                         "MEDDRA:10029868",
#                         "MEDDRA:10029864",
#                         "MEDDRA:10078756",
#                         "HP:0012043"
#                     ],
#                     "name": "Nystagmus",
#                     "id": "HP:0000639",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 15351
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0000639",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1177029,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0894475,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9520516259048698
#                     },
#                     "weight": 0.4296838887325011
#                 }
#             ],
#             "score": 0.4306838887325012
#         },
#         {
#             "id": null,
#             "answerset": null,
#             "natural_answer": null,
#             "nodes": [
#                 {
#                     "id": "MONDO:0019391",
#                     "name": "Fanconi anemia",
#                     "equivalent_identifiers": [
#                         "MONDO:0019391",
#                         "MEDDRA:10055206",
#                         "ORPHANET:84",
#                         "MEDDRA:10016218",
#                         "DOID:13636",
#                         "UMLS:C0015625",
#                         "MESH:D005199"
#                     ],
#                     "type": "disease",
#                     "omnicorp_article_count": 4009
#                 },
#                 {
#                     "id": "HP:0001639",
#                     "equivalent_identifiers": [
#                         "UMLS:C0007194",
#                         "MEDDRA:10020203",
#                         "MEDDRA:10065229",
#                         "MEDDRA:10020871",
#                         "HP:0001639",
#                         "MEDDRA:10020876",
#                         "NCIT:C34449",
#                         "MEDDRA:10020204"
#                     ],
#                     "name": "Hypertrophic cardiomyopathy",
#                     "type": "phenotypic_feature",
#                     "omnicorp_article_count": 16622
#                 }
#             ],
#             "edges": [
#                 {
#                     "relation": "RO:0002200",
#                     "target_id": "HP:0001639",
#                     "edge_source": "biolink.disease_get_phenotype",
#                     "publications": [],
#                     "id": 1176972,
#                     "predicate_id": "RO:0002200",
#                     "source_database": "biolink",
#                     "source_id": "MONDO:0019391",
#                     "type": "has_phenotype",
#                     "ctime": 1535693672.0886626,
#                     "relation_label": "has phenotype",
#                     "scoring": {
#                         "num_pubs": 0,
#                         "ngd": 0.9599085487099057
#                     },
#                     "weight": 0.42371039675254113
#                 }
#             ],
#             "score": 0.42471039675254113
#         }
#     ],
#     "misc_info": {
#         "natural_question": null,
#         "num_total_paths": 186
#     },
#     "filename": null,
#     "timestamp": "2018-09-09T20:59:05.434737"
# }

# %% [markdown]
# The output can be simplified with a function like this:

# %%
import pandas as pd

def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"], 
                 "relation": edge["relation_label"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %%
parse_answer(r)
# Out:
#           relation   result_id  \
# 0    has phenotype  HP:0005528
# 1    has phenotype  HP:0004810
# 2    has phenotype  HP:0001908
# 3    has phenotype  HP:0010972
# 4    has phenotype  HP:0003974
# 5    has phenotype  HP:0004820
# 6    has phenotype  HP:0000953
# 7    has phenotype  HP:0001972
# 8    has phenotype  HP:0001876
# 9    has phenotype  HP:0001000
# 10   has phenotype  HP:0001905
# 11   has phenotype  HP:0002023
# 12   has phenotype  HP:0003254
# 13   has phenotype  HP:0000957
# 14   has phenotype  HP:0004859
# 15   has phenotype  HP:0003468
# 16   has phenotype  HP:0009777
# 17   has phenotype  HP:0002984
# 18   has phenotype  HP:0004430
# 19   has phenotype  HP:0000077
# 20   has phenotype  HP:0005510
# 21   has phenotype  HP:0000568
# 22   has phenotype  HP:0001172
# 23   has phenotype  HP:0000824
# 24   has phenotype  HP:0005505
# 25   has phenotype  HP:0000286
# 26   has phenotype  HP:0001896
# 27   has phenotype  HP:0002863
# 28   has phenotype  HP:0000164
# 29   has phenotype  HP:0000086
# ..             ...         ...
# 156  has phenotype  HP:0005280
# 157  has phenotype  HP:0005522
# 158  has phenotype  HP:0009943
# 159  has phenotype  HP:0000125
# 160  has phenotype  HP:0008678
# 161  has phenotype  HP:0003213
# 162  has phenotype  HP:0007400
# 163  has phenotype  HP:0000453
# 164  has phenotype  HP:0001537
# 165  has phenotype  HP:0001284
# 166  has phenotype  HP:0000072
# 167  has phenotype  HP:0000010
# 168  has phenotype  HP:0003774
# 169  has phenotype  HP:0000083
# 170  has phenotype  HP:0004349
# 171  has phenotype  HP:0001562
# 172  has phenotype  HP:0006824
# 173  has phenotype  HP:0007354
# 174  has phenotype  HP:0002245
# 175  has phenotype  HP:0001762
# 176  has phenotype  HP:0000027
# 177  has phenotype  HP:0001824
# 178  has phenotype  HP:0002414
# 179  has phenotype  HP:0002251
# 180  has phenotype  HP:0000483
# 181  has phenotype  HP:0000505
# 182  has phenotype  HP:0000520
# 183  has phenotype  HP:0100026
# 184  has phenotype  HP:0000639
# 185  has phenotype  HP:0001639
#
#                                            result_name  \
# 0                          Bone marrow hypocellularity
# 1                        Congenital hypoplastic anemia
# 2                                   Hypoplastic anemia
# 3                      Anemia of inadequate production
# 4                                        Absent radius
# 5                        Acute myelomonocytic leukemia
# 6                        Hyperpigmentation of the skin
# 7                                    Macrocytic anemia
# 8                                         Pancytopenia
# 9                     Abnormality of skin pigmentation
# 10                         Congenital thrombocytopenia
# 11                                        Anal atresia
# 12                           Abnormality of DNA repair
# 13                                   Cafe-au-lait spot
# 14                    Amegakaryocytic thrombocytopenia
# 15                       Abnormal vertebral morphology
# 16                                        Absent thumb
# 17                            Hypoplasia of the radius
# 18                    Severe combined immunodeficiency
# 19                           Abnormality of the kidney
# 20                        Transient erythroblastopenia
# 21                                      Microphthalmia
# 22                            Abnormality of the thumb
# 23                           Growth hormone deficiency
# 24                                   Refractory anemia
# 25                                          Epicanthus
# 26                                   Reticulocytopenia
# 27                                      Myelodysplasia
# 28                        Abnormality of the dentition
# 29                                      Ectopic kidney
# ..                                                 ...
# 156                             Depressed nasal bridge
# 157         Pyridoxine-responsive sideroblastic anemia
# 158              Complete duplication of thumb phalanx
# 159                                      Pelvic kidney
# 160                           Renal hypoplasia/aplasia
# 161  Deficient excision of UV-induced pyrimidine di...
# 162                        Irregular hyperpigmentation
# 163                                    Choanal atresia
# 164                                   Umbilical hernia
# 165                                          Areflexia
# 166                                        Hydroureter
# 167                 Recurrent urinary tract infections
# 168                     Stage 5 chronic kidney disease
# 169                                Renal insufficiency
# 170                       Reduced bone mineral density
# 171                                    Oligohydramnios
# 172                            Cranial nerve paralysis
# 173                      Amyotrophic lateral sclerosis
# 174                                Meckel diverticulum
# 175                                Talipes equinovarus
# 176                                        Azoospermia
# 177                                        Weight loss
# 178                                       Spina bifida
# 179                              Aganglionic megacolon
# 180                                        Astigmatism
# 181                                  Visual impairment
# 182                                          Proptosis
# 183                         Arteriovenous malformation
# 184                                          Nystagmus
# 185                        Hypertrophic cardiomyopathy
#
#                             source
# 0    biolink.disease_get_phenotype
# 1    biolink.disease_get_phenotype
# 2    biolink.disease_get_phenotype
# 3    biolink.disease_get_phenotype
# 4    biolink.disease_get_phenotype
# 5    biolink.disease_get_phenotype
# 6    biolink.disease_get_phenotype
# 7    biolink.disease_get_phenotype
# 8    biolink.disease_get_phenotype
# 9    biolink.disease_get_phenotype
# 10   biolink.disease_get_phenotype
# 11   biolink.disease_get_phenotype
# 12   biolink.disease_get_phenotype
# 13   biolink.disease_get_phenotype
# 14   biolink.disease_get_phenotype
# 15   biolink.disease_get_phenotype
# 16   biolink.disease_get_phenotype
# 17   biolink.disease_get_phenotype
# 18   biolink.disease_get_phenotype
# 19   biolink.disease_get_phenotype
# 20   biolink.disease_get_phenotype
# 21   biolink.disease_get_phenotype
# 22   biolink.disease_get_phenotype
# 23   biolink.disease_get_phenotype
# 24   biolink.disease_get_phenotype
# 25   biolink.disease_get_phenotype
# 26   biolink.disease_get_phenotype
# 27   biolink.disease_get_phenotype
# 28   biolink.disease_get_phenotype
# 29   biolink.disease_get_phenotype
# ..                             ...
# 156  biolink.disease_get_phenotype
# 157  biolink.disease_get_phenotype
# 158  biolink.disease_get_phenotype
# 159  biolink.disease_get_phenotype
# 160  biolink.disease_get_phenotype
# 161  biolink.disease_get_phenotype
# 162  biolink.disease_get_phenotype
# 163  biolink.disease_get_phenotype
# 164  biolink.disease_get_phenotype
# 165  biolink.disease_get_phenotype
# 166  biolink.disease_get_phenotype
# 167  biolink.disease_get_phenotype
# 168  biolink.disease_get_phenotype
# 169  biolink.disease_get_phenotype
# 170  biolink.disease_get_phenotype
# 171  biolink.disease_get_phenotype
# 172  biolink.disease_get_phenotype
# 173  biolink.disease_get_phenotype
# 174  biolink.disease_get_phenotype
# 175  biolink.disease_get_phenotype
# 176  biolink.disease_get_phenotype
# 177  biolink.disease_get_phenotype
# 178  biolink.disease_get_phenotype
# 179  biolink.disease_get_phenotype
# 180  biolink.disease_get_phenotype
# 181  biolink.disease_get_phenotype
# 182  biolink.disease_get_phenotype
# 183  biolink.disease_get_phenotype
# 184  biolink.disease_get_phenotype
# 185  biolink.disease_get_phenotype
#
# [186 rows x 4 columns]

# %% [markdown]
# ## Multi-step questions

# %% [markdown]
# It's straightforward to generalize this linear query to an N-item path.  This function constructs a question from a list of types and a list of identifiers.  The types are the types of nodes that will be traversed along the path, and the identifiers represent fixed elements in the path.  The length of types and ids should be equal, and free nodes should specify an id of None:

# %%
def make_N_step_question(types,curies):
    question = {
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    for i,t in enumerate(types):
        newnode = {'id': i, 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        if i > 0:
            question['machine_question']['edges'].append( {'source_id': i-1, 'target_id': i})
    return question

# %% [markdown]
# We can recapitulate our previous question with this new function like this:

# %%
newq = make_N_step_question(['disease','phenotypic_feature'],['MONDO:0019391',None])
q == newq
# Out:
# True

# %% [markdown]
# Now we could expand to a longer query.  The following question will start at the disease MONDO:0019391, go to a gene, and from there to a biological process or activity.

# %%
two_step_question = make_N_step_question(['disease','gene','biological_process_or_activity'],['MONDO:0019391',None,None])

# %%
two_step_answer = quick(two_step_question)
# Out:
# Return Status: 200

# %% [markdown]
# We can extract the node names along the paths with a simple function:

# %%
def extract_node_names(returnanswer):
    nodes = [{f'node_{i}': node['name'] for i,node in enumerate(answer['nodes'])} for answer in returnanswer['answers']]
    return pd.DataFrame(nodes)

# %%
two_step_nodes = extract_node_names(two_step_answer)
two_step_nodes
# Out:
#              node_0  node_1                                             node_2
# 0    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 1    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 2    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 3    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 4    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 5    Fanconi anemia  FANCD2                      interstrand cross-link repair
# 6    Fanconi anemia   FANCM                      interstrand cross-link repair
# 7    Fanconi anemia   FANCM                      interstrand cross-link repair
# 8    Fanconi anemia   FANCA                      interstrand cross-link repair
# 9    Fanconi anemia   FANCA                      interstrand cross-link repair
# 10   Fanconi anemia   FANCA                      interstrand cross-link repair
# 11   Fanconi anemia   FANCA                      interstrand cross-link repair
# 12   Fanconi anemia   FANCA                      interstrand cross-link repair
# 13   Fanconi anemia   FANCA                      interstrand cross-link repair
# 14   Fanconi anemia   FANCG                      interstrand cross-link repair
# 15   Fanconi anemia   FANCG                      interstrand cross-link repair
# 16   Fanconi anemia   FANCI                      interstrand cross-link repair
# 17   Fanconi anemia   FANCI                      interstrand cross-link repair
# 18   Fanconi anemia   FANCI                      interstrand cross-link repair
# 19   Fanconi anemia   FANCI                      interstrand cross-link repair
# 20   Fanconi anemia   FANCM                      interstrand cross-link repair
# 21   Fanconi anemia   FANCM                      interstrand cross-link repair
# 22   Fanconi anemia   FANCM                      interstrand cross-link repair
# 23   Fanconi anemia   FANCM                      interstrand cross-link repair
# 24   Fanconi anemia   FANCC                      interstrand cross-link repair
# 25   Fanconi anemia   FANCC                      interstrand cross-link repair
# 26   Fanconi anemia   FANCC                      interstrand cross-link repair
# 27   Fanconi anemia   FANCC                      interstrand cross-link repair
# 28   Fanconi anemia    SLX4                      interstrand cross-link repair
# 29   Fanconi anemia    SLX4                      interstrand cross-link repair
# ..              ...     ...                                                ...
# 220  Fanconi anemia     BLM  double-strand break repair via nonhomologous e...
# 221  Fanconi anemia     BLM  double-strand break repair via nonhomologous e...
# 222  Fanconi anemia     BLM  double-strand break repair via nonhomologous e...
# 223  Fanconi anemia   FANCG                                         DNA repair
# 224  Fanconi anemia   FANCG                                         DNA repair
# 225  Fanconi anemia   FANCG                                         DNA repair
# 226  Fanconi anemia   FANCG                                         DNA repair
# 227  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 228  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 229  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 230  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 231  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 232  Fanconi anemia   RAD51  double-strand break repair via homologous reco...
# 233  Fanconi anemia     BLM                                  helicase activity
# 234  Fanconi anemia     BLM                                  helicase activity
# 235  Fanconi anemia     BLM                                  helicase activity
# 236  Fanconi anemia     BLM                                  helicase activity
# 237  Fanconi anemia  RAD51C                                         DNA repair
# 238  Fanconi anemia  RAD51C                                         DNA repair
# 239  Fanconi anemia  RAD51C                                         DNA repair
# 240  Fanconi anemia  RAD51C                                         DNA repair
# 241  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 242  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 243  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 244  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 245  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 246  Fanconi anemia   ERCC4                         nucleotide-excision repair
# 247  Fanconi anemia   MUS81                                         DNA repair
# 248  Fanconi anemia   MUS81                                         DNA repair
# 249  Fanconi anemia   ERCC4                               telomere maintenance
#
# [250 rows x 3 columns]

# %% [markdown]
# At the node name level there are what appear to be several repeated paths.  In fact, these paths differ in the predicates, which we are not showing:

# %%
print(f"The first answer's second edge comes from {two_step_answer['answers'][0]['edges'][1]['edge_source']}")
print(f"The second answer's second edge comes from {two_step_answer['answers'][1]['edges'][1]['edge_source']}")
# Out:
# The first answer's second edge comes from biolink.gene_get_process_or_function
# The second answer's second edge comes from quickgo.go_term_to_gene_annotation

# %% [markdown]
# ## Specifying multiple fixed nodes

# %% [markdown]
# The examples above have all started from one known node and expanded from it, sometimes in multiple steps.  It's also possible to have more than one node specified.  For instance, if we wanted to look for genes that link Fanconi Aneima (MONDO:0019391) and DNA repair (GO:0006281), we could rerun our previous query, but setting the final curie, like this:

# %%
two_step_question_fixed_ends = \
   make_N_step_question(['disease','gene','biological_process_or_activity'],['MONDO:0019391',None,'GO:0006281'])
two_step_answer_fixed_ends = quick(two_step_question_fixed_ends)
# Out:
# Return Status: 200

# %%
extract_node_names(two_step_answer_fixed_ends)
# Out:
#             node_0    node_1      node_2
# 0   Fanconi anemia    FANCD2  DNA repair
# So far, we've only looked at linear paths.  But the question format is actually more general than that - we can define a path pattern generally. So for instance, in the above query, we find all genes that are linked to both FA and DNA repair.  But what if we wanted to find entities that are connected to more than two specified entities.  Here is a query-generation function for the star query:

# %%
def make_star_question(types,curies,shared_type):
    """Create a question to find entities of shared_type that are linked to all of the nodes specified in the
    types and curies arrays."""
    question = {
                'rebuild': True,
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    question['machine_question']['nodes'].append( {'id': 0, 'type': shared_type})
    for i,t in enumerate(types):
        newnode = {'id': i+1, 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        question['machine_question']['edges'].append( {'source_id': 0, 'target_id': i+1})
    return question

# %% [markdown]
# Suppose I have this set of GO terms, and I'd like to find genes that they all have in common:
#
# * 'voltage-gated sodium channel activity(GO:0005248)',
# * 'muscle contraction(GO:0006936)',
# * 'voltage-gated ion channel activity(GO:0005244)',
# * 'regulation of ion transmembrane transport(GO:0034765)',
# * 'sodium ion transmembrane transport(GO:0035725)',
# * 'neuronal action potential(GO:0019228)',
# * 'membrane depolarization during action potential(GO:0086010)',
# * 'sodium ion transport(GO:0006814)'

# %%
go_terms=['GO:0005248','GO:0006936','GO:0005244','GO:0034765','GO:0035725','GO:0019228','GO:0086010','GO:0006814']
types = ['biological_process_or_activity' for g in go_terms]
star_q = make_star_question(types,go_terms,'gene')
star_q
# Out:
# {'machine_question': {'edges': [{'source_id': 0, 'target_id': 1},
#    {'source_id': 0, 'target_id': 2},
#    {'source_id': 0, 'target_id': 3},
#    {'source_id': 0, 'target_id': 4},
#    {'source_id': 0, 'target_id': 5},
#    {'source_id': 0, 'target_id': 6},
#    {'source_id': 0, 'target_id': 7},
#    {'source_id': 0, 'target_id': 8}],
#   'nodes': [{'id': 0, 'type': 'gene'},
#    {'curie': 'GO:0005248', 'id': 1, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006936', 'id': 2, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0005244', 'id': 3, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0034765', 'id': 4, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0035725', 'id': 5, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0019228', 'id': 6, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0086010', 'id': 7, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006814',
#     'id': 8,
#     'type': 'biological_process_or_activity'}]},
#  'rebuild': 'True'}

# %%
common_gene_answer = quick(star_q)
# Out:
# Return Status: 200

# %%
extract_node_names(common_gene_answer)
# Out:
#    node_0                                 node_1              node_2  \
# 0   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 1   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 2   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 3   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 4   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 5   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 6   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 7   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 8   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 9   SCN4A  voltage-gated sodium channel activity  muscle contraction
# 10  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 11  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 12  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 13  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 14  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 15  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 16  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 17  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 18  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 19  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 20  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 21  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 22  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 23  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 24  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 25  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 26  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 27  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 28  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 29  SCN4A  voltage-gated sodium channel activity  muscle contraction
# ..    ...                                    ...                 ...
# 34  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 35  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 36  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 37  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 38  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 39  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 40  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 41  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 42  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 43  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 44  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 45  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 46  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 47  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 48  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 49  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 50  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 51  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 52  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 53  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 54  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 55  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 56  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 57  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 58  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 59  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 60  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 61  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 62  SCN7A  voltage-gated sodium channel activity  muscle contraction
# 63  SCN7A  voltage-gated sodium channel activity  muscle contraction
#
#                                 node_3  \
# 0   voltage-gated ion channel activity
# 1   voltage-gated ion channel activity
# 2   voltage-gated ion channel activity
# 3   voltage-gated ion channel activity
# 4   voltage-gated ion channel activity
# 5   voltage-gated ion channel activity
# 6   voltage-gated ion channel activity
# 7   voltage-gated ion channel activity
# 8   voltage-gated ion channel activity
# 9   voltage-gated ion channel activity
# 10  voltage-gated ion channel activity
# 11  voltage-gated ion channel activity
# 12  voltage-gated ion channel activity
# 13  voltage-gated ion channel activity
# 14  voltage-gated ion channel activity
# 15  voltage-gated ion channel activity
# 16  voltage-gated ion channel activity
# 17  voltage-gated ion channel activity
# 18  voltage-gated ion channel activity
# 19  voltage-gated ion channel activity
# 20  voltage-gated ion channel activity
# 21  voltage-gated ion channel activity
# 22  voltage-gated ion channel activity
# 23  voltage-gated ion channel activity
# 24  voltage-gated ion channel activity
# 25  voltage-gated ion channel activity
# 26  voltage-gated ion channel activity
# 27  voltage-gated ion channel activity
# 28  voltage-gated ion channel activity
# 29  voltage-gated ion channel activity
# ..                                 ...
# 34  voltage-gated ion channel activity
# 35  voltage-gated ion channel activity
# 36  voltage-gated ion channel activity
# 37  voltage-gated ion channel activity
# 38  voltage-gated ion channel activity
# 39  voltage-gated ion channel activity
# 40  voltage-gated ion channel activity
# 41  voltage-gated ion channel activity
# 42  voltage-gated ion channel activity
# 43  voltage-gated ion channel activity
# 44  voltage-gated ion channel activity
# 45  voltage-gated ion channel activity
# 46  voltage-gated ion channel activity
# 47  voltage-gated ion channel activity
# 48  voltage-gated ion channel activity
# 49  voltage-gated ion channel activity
# 50  voltage-gated ion channel activity
# 51  voltage-gated ion channel activity
# 52  voltage-gated ion channel activity
# 53  voltage-gated ion channel activity
# 54  voltage-gated ion channel activity
# 55  voltage-gated ion channel activity
# 56  voltage-gated ion channel activity
# 57  voltage-gated ion channel activity
# 58  voltage-gated ion channel activity
# 59  voltage-gated ion channel activity
# 60  voltage-gated ion channel activity
# 61  voltage-gated ion channel activity
# 62  voltage-gated ion channel activity
# 63  voltage-gated ion channel activity
#
#                                        node_4  \
# 0   regulation of ion transmembrane transport
# 1   regulation of ion transmembrane transport
# 2   regulation of ion transmembrane transport
# 3   regulation of ion transmembrane transport
# 4   regulation of ion transmembrane transport
# 5   regulation of ion transmembrane transport
# 6   regulation of ion transmembrane transport
# 7   regulation of ion transmembrane transport
# 8   regulation of ion transmembrane transport
# 9   regulation of ion transmembrane transport
# 10  regulation of ion transmembrane transport
# 11  regulation of ion transmembrane transport
# 12  regulation of ion transmembrane transport
# 13  regulation of ion transmembrane transport
# 14  regulation of ion transmembrane transport
# 15  regulation of ion transmembrane transport
# 16  regulation of ion transmembrane transport
# 17  regulation of ion transmembrane transport
# 18  regulation of ion transmembrane transport
# 19  regulation of ion transmembrane transport
# 20  regulation of ion transmembrane transport
# 21  regulation of ion transmembrane transport
# 22  regulation of ion transmembrane transport
# 23  regulation of ion transmembrane transport
# 24  regulation of ion transmembrane transport
# 25  regulation of ion transmembrane transport
# 26  regulation of ion transmembrane transport
# 27  regulation of ion transmembrane transport
# 28  regulation of ion transmembrane transport
# 29  regulation of ion transmembrane transport
# ..                                        ...
# 34  regulation of ion transmembrane transport
# 35  regulation of ion transmembrane transport
# 36  regulation of ion transmembrane transport
# 37  regulation of ion transmembrane transport
# 38  regulation of ion transmembrane transport
# 39  regulation of ion transmembrane transport
# 40  regulation of ion transmembrane transport
# 41  regulation of ion transmembrane transport
# 42  regulation of ion transmembrane transport
# 43  regulation of ion transmembrane transport
# 44  regulation of ion transmembrane transport
# 45  regulation of ion transmembrane transport
# 46  regulation of ion transmembrane transport
# 47  regulation of ion transmembrane transport
# 48  regulation of ion transmembrane transport
# 49  regulation of ion transmembrane transport
# 50  regulation of ion transmembrane transport
# 51  regulation of ion transmembrane transport
# 52  regulation of ion transmembrane transport
# 53  regulation of ion transmembrane transport
# 54  regulation of ion transmembrane transport
# 55  regulation of ion transmembrane transport
# 56  regulation of ion transmembrane transport
# 57  regulation of ion transmembrane transport
# 58  regulation of ion transmembrane transport
# 59  regulation of ion transmembrane transport
# 60  regulation of ion transmembrane transport
# 61  regulation of ion transmembrane transport
# 62  regulation of ion transmembrane transport
# 63  regulation of ion transmembrane transport
#
#                                 node_5                     node_6  \
# 0   sodium ion transmembrane transport  neuronal action potential
# 1   sodium ion transmembrane transport  neuronal action potential
# 2   sodium ion transmembrane transport  neuronal action potential
# 3   sodium ion transmembrane transport  neuronal action potential
# 4   sodium ion transmembrane transport  neuronal action potential
# 5   sodium ion transmembrane transport  neuronal action potential
# 6   sodium ion transmembrane transport  neuronal action potential
# 7   sodium ion transmembrane transport  neuronal action potential
# 8   sodium ion transmembrane transport  neuronal action potential
# 9   sodium ion transmembrane transport  neuronal action potential
# 10  sodium ion transmembrane transport  neuronal action potential
# 11  sodium ion transmembrane transport  neuronal action potential
# 12  sodium ion transmembrane transport  neuronal action potential
# 13  sodium ion transmembrane transport  neuronal action potential
# 14  sodium ion transmembrane transport  neuronal action potential
# 15  sodium ion transmembrane transport  neuronal action potential
# 16  sodium ion transmembrane transport  neuronal action potential
# 17  sodium ion transmembrane transport  neuronal action potential
# 18  sodium ion transmembrane transport  neuronal action potential
# 19  sodium ion transmembrane transport  neuronal action potential
# 20  sodium ion transmembrane transport  neuronal action potential
# 21  sodium ion transmembrane transport  neuronal action potential
# 22  sodium ion transmembrane transport  neuronal action potential
# 23  sodium ion transmembrane transport  neuronal action potential
# 24  sodium ion transmembrane transport  neuronal action potential
# 25  sodium ion transmembrane transport  neuronal action potential
# 26  sodium ion transmembrane transport  neuronal action potential
# 27  sodium ion transmembrane transport  neuronal action potential
# 28  sodium ion transmembrane transport  neuronal action potential
# 29  sodium ion transmembrane transport  neuronal action potential
# ..                                 ...                        ...
# 34  sodium ion transmembrane transport  neuronal action potential
# 35  sodium ion transmembrane transport  neuronal action potential
# 36  sodium ion transmembrane transport  neuronal action potential
# 37  sodium ion transmembrane transport  neuronal action potential
# 38  sodium ion transmembrane transport  neuronal action potential
# 39  sodium ion transmembrane transport  neuronal action potential
# 40  sodium ion transmembrane transport  neuronal action potential
# 41  sodium ion transmembrane transport  neuronal action potential
# 42  sodium ion transmembrane transport  neuronal action potential
# 43  sodium ion transmembrane transport  neuronal action potential
# 44  sodium ion transmembrane transport  neuronal action potential
# 45  sodium ion transmembrane transport  neuronal action potential
# 46  sodium ion transmembrane transport  neuronal action potential
# 47  sodium ion transmembrane transport  neuronal action potential
# 52  membrane depolarization during action potential  sodium ion transport
# 53  membrane depolarization during action potential  sodium ion transport
# 54  membrane depolarization during action potential  sodium ion transport
# 55  membrane depolarization during action potential  sodium ion transport
# 56  membrane depolarization during action potential  sodium ion transport
# 57  membrane depolarization during action potential  sodium ion transport
# 58  membrane depolarization during action potential  sodium ion transport
# 59  membrane depolarization during action potential  sodium ion transport
# 60  membrane depolarization during action potential  sodium ion transport
# 61  membrane depolarization during action potential  sodium ion transport
# 62  membrane depolarization during action potential  sodium ion transport
# 63  membrane depolarization during action potential  sodium ion transport
#
# [64 rows x 9 columns]

# %% [markdown]
# Again, we get back multiple paths with the same answer node (node_0) due to differences in edge sources.  However, we can see that there are two genes that share this set of GO terms, SCN4A and SCN7A.
#
# We can also have more than one unspecified node.  Suppose, for instance that we wanted to do the previous query, but we also wanted to know what chemicals interact with the genes that we find.  We can do another star query, where one of our spokes is unspecified:

# %%
go_terms=['GO:0005248','GO:0006936','GO:0005244','GO:0034765','GO:0035725','GO:0019228','GO:0086010','GO:0006814',None]
types = ['biological_process_or_activity' for i in range(8)]+['chemical_substance']
star_q_compound = make_star_question(types,go_terms,'gene')
star_q_compound
# Out:
# {'machine_question': {'edges': [{'source_id': 0, 'target_id': 1},
#    {'source_id': 0, 'target_id': 2},
#    {'source_id': 0, 'target_id': 3},
#    {'source_id': 0, 'target_id': 4},
#    {'source_id': 0, 'target_id': 5},
#    {'source_id': 0, 'target_id': 6},
#    {'source_id': 0, 'target_id': 7},
#    {'source_id': 0, 'target_id': 8},
#    {'source_id': 0, 'target_id': 9}],
#   'nodes': [{'id': 0, 'type': 'gene'},
#    {'curie': 'GO:0005248', 'id': 1, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006936', 'id': 2, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0005244', 'id': 3, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0034765', 'id': 4, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0035725', 'id': 5, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0019228', 'id': 6, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0086010', 'id': 7, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006814', 'id': 8, 'type': 'biological_process_or_activity'},
#    {'id': 9, 'type': 'chemical_substance'}]},
#  'rebuild': 'True'}

# %%
common_gene_compound_answer = quick(star_q_compound)
# Out:
# Return Status: 200

# %%
cgc_nodes = extract_node_names(common_gene_compound_answer)
cgc_nodes[['node_0','node_9']].drop_duplicates()
# Out:
#     node_0         node_9
# 0    SCN4A    lamotrigine
# 32   SCN4A  carbamazepine
# 64   SCN4A     benzocaine
# 96   SCN4A      phenytoin
# 128  SCN4A      lidocaine
# 160  SCN4A      tocainide
# 192  SCN4A     mexiletine
# 224  SCN7A     benzocaine

# %% [markdown]
# Many other graph shapes are possible, these are simply a couple of examples.  For instance, we could add onto this query an edge from node 0 to a new disease node (node 10) and also include an edge from the target node (node 9) to this same disease node. Now we would be finding genes that share a set of GO terms, then looking for disease,drug pairs such that the disease, the drug, and the gene are all interconnected.

# %% [markdown]
# ## Rebuild and caching

# %% [markdown]
# For details on ROBOKOP caching, see the notebook on the expand service.  Briefly, the quick service will only run against the cache unless the rebuild parameter is passed, in which case services are re-queried.   The rebuild parameter is passed as part of the json query as seen in the `make_star_query` function above.  Another example is seen below in the Edge Properties section.

# %% [markdown]
# ## Edge Properties

# %% [markdown]
# TODO: come up with a nice example.
