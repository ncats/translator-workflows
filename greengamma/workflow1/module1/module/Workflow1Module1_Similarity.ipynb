# %% [markdown]
# # Workflow 1, Module 1 (Condition similarity)

# %% [markdown]
# Module one can be interpreted as: "Find me genetic conditions that are phenotypically similar to disease X".  We can attack this problem with our similiarity endpont directly.  This is because
# 1. ROBOKOP implements genetic_condition as a type, so we can use it in the query
# 2. ROBOKOP's similarity endpoint does not require that the query and result type are the same.

# %%
import requests
import pandas as pd

# %%
def similarity(type1,ident,type2,by_type,threshhold=None,maxresults=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/similarity/{type1}/{ident}/{type2}/{by_type}'
    params = { 'threshhold': threshhold, 'max_results': maxresults, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.get(url, params = params)
    print( 'Return code:',response.status_code )
    return response.json()

# %%
diabetes = 'MONDO:0005148'
asthma = 'MONDO:0004979'

# %%
gc_similar_to_diabetes=similarity('disease',diabetes,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_diabetes)
# Out:
# Return code: 200
#                 id                                               name  \
# 0    MONDO:0011565                               metabolic syndrome X
# 1    MONDO:0011382                                 sickle cell anemia
# 2    MONDO:0009061                                    cystic fibrosis
# 3    MONDO:0009693                                   multiple myeloma
# 4    MONDO:0006507                         hereditary hemochromatosis
# 5    MONDO:0012819                              diabetic ketoacidosis
# 6    MONDO:0002413                         glycogen storage disease I
# 7    MONDO:0008315                                    prostate cancer
# 8    MONDO:0018150                                    Gaucher disease
# 9    MONDO:0002615                            xanthomatosis (disease)
# 10   MONDO:0010526                                      Fabry disease
# 11   MONDO:0010196                                    Werner syndrome
# 12   MONDO:0010602                                       hemophilia A
# 13   MONDO:0008364                                    Raynaud disease
# 14   MONDO:0008763                                   Alstrom syndrome
# 15   MONDO:0010200                                     Wilson disease
# 16   MONDO:0001076                                glucose intolerance
# 17   MONDO:0008056                          myotonic dystrophy type 1
# 18   MONDO:0009410                                  Addison's disease
# 19   MONDO:0010789                                     MELAS syndrome
# 20   MONDO:0016239                                         cystinosis
# 21   MONDO:0019402                                   beta thalassemia
# 22   MONDO:0008575                                nicotine dependence
# 23   MONDO:0007886                           uterine corpus leiomyoma
# 24   MONDO:0010086                       sudden infant death syndrome
# 25   MONDO:0008678                                  Williams syndrome
# 26   MONDO:0000984                                        thalassemia
# 27   MONDO:0002408                       bilirubin metabolic disorder
# 28   MONDO:0019499                                    Turner syndrome
# 29   MONDO:0013282                     alpha 1-antitrypsin deficiency
# ..             ...                                                ...
# 220  MONDO:0016013                       fetal methylmercury syndrome
# 221  MONDO:0004639                perinatal necrotizing enterocolitis
# 222  MONDO:0011441                       reflex sympathetic dystrophy
# 223  MONDO:0008996               Joubert syndrome with hepatic defect
# 224  MONDO:0015780                             dyskeratosis congenita
# 225  MONDO:0011929                  chromosome 1p36 deletion syndrome
# 226  MONDO:0019609                                 Zellweger syndrome
# 227  MONDO:0006277                      lung lymphangioleiomyomatosis
# 228  MONDO:0019773                                   myelomeningocele
# 229  MONDO:0012552                multiple endocrine neoplasia type 4
# 230  MONDO:0009499                                     Krabbe disease
# 231  MONDO:0007032                                prune belly syndome
# 232  MONDO:0015285                                     Carney complex
# 233  MONDO:0019154                    androgen insensitivity syndrome
# 234  MONDO:0008713                       acrodermatitis enteropathica
# 235  MONDO:0016422               autoimmune polyendocrinopathy type 3
# 236  MONDO:0015028                                   48,XXYY syndrome
# 237  MONDO:0009874                         Rabson-Mendenhall syndrome
# 238  MONDO:0018030                                       tetrasomy 9p
# 239  MONDO:0009254                                        fucosidosis
# 240  MONDO:0008963                           Chediak-Higashi syndrome
# 241  MONDO:0009319   pantothenate kinase-associated neurodegeneration
# 242  MONDO:0017608                   dystrophic epidermolysis bullosa
# 243  MONDO:0018570                                   hypophosphatasia
# 244  MONDO:0014402  severe neurodegenerative syndrome with lipodys...
# 245  MONDO:0008891                  riboflavin transporter deficiency
# 246  MONDO:0015779                45,X/46,XY mixed gonadal dysgenesis
# 247  MONDO:0012072    familial partial lipodystrophy, Kobberling type
# 248  MONDO:0013647  primary microcephaly-epilepsy-permanent neonat...
# 249  MONDO:0014198            mitochondrial DNA depletion syndrome 13
#
#      similarity
# 0      0.471591
# 1      0.320917
# 2      0.318508
# 3      0.313594
# 4      0.302215
# 5      0.299603
# 6      0.298791
# 7      0.293443
# 8      0.286465
# 9      0.280315
# 10     0.277860
# 11     0.275602
# 12     0.273414
# 13     0.273282
# 14     0.266667
# 15     0.261834
# 16     0.259109
# 17     0.258741
# 18     0.258514
# 19     0.256480
# 20     0.256452
# 21     0.250377
# 22     0.249538
# 23     0.247748
# 24     0.242376
# 25     0.238494
# 26     0.238245
# 27     0.236975
# 28     0.233950
# 29     0.232014
# ..          ...
# 220    0.155515
# 221    0.155080
# 222    0.154882
# 223    0.154839
# 224    0.154494
# 225    0.154481
# 226    0.154421
# 227    0.154362
# 228    0.153610
# 229    0.153584
# 230    0.153199
# 231    0.153125
# 232    0.153078
# 233    0.153078
# 234    0.152801
# 235    0.152778
# 236    0.152648
# 237    0.152574
# 238    0.152497
# 239    0.152439
# 240    0.152439
# 241    0.152429
# 242    0.152411
# 243    0.151938
# 244    0.151737
# 245    0.151608
# 246    0.151608
# 247    0.151575
# 248    0.151568
# 249    0.151565
#
# [250 rows x 3 columns]

# %%
gc_similar_to_asthma=similarity('disease',asthma,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_asthma)
# Out:
# Return code: 200
#                 id                                               name  \
# 0    MONDO:0010086                       sudden infant death syndrome
# 1    MONDO:0009061                                    cystic fibrosis
# 2    MONDO:0007186                    gastroesophageal reflux disease
# 3    MONDO:0018305                      chronic granulomatous disease
# 4    MONDO:0009971              newborn respiratory distress syndrome
# 5    MONDO:0010518                           Wiskott-Aldrich syndrome
# 6    MONDO:0013282                     alpha 1-antitrypsin deficiency
# 7    MONDO:0018229                           Stevens-Johnson syndrome
# 8    MONDO:0010602                                       hemophilia A
# 9    MONDO:0011382                                 sickle cell anemia
# 10   MONDO:0008364                                    Raynaud disease
# 11   MONDO:0008575                                nicotine dependence
# 12   MONDO:0008840                              ataxia telangiectasia
# 13   MONDO:0011096                       autosomal agammaglobulinemia
# 14   MONDO:0015977                                 agammaglobulinemia
# 15   MONDO:0001901                   selective IgG deficiency disease
# 16   MONDO:0015517                   common variable immunodeficiency
# 17   MONDO:0010526                                      Fabry disease
# 18   MONDO:0009623                         Nijmegen breakage syndrome
# 19   MONDO:0015974         severe combined immunodeficiency (disease)
# 20   MONDO:0010383                                 fragile X syndrome
# 21   MONDO:0010604                                       hemophilia B
# 22   MONDO:0018150                                    Gaucher disease
# 23   MONDO:0012819                              diabetic ketoacidosis
# 24   MONDO:0008315                                    prostate cancer
# 25   MONDO:0008848            atrioventricular dissociation (disease)
# 26   MONDO:0009693                                   multiple myeloma
# 27   MONDO:0005761                             filarial elephantiasis
# 28   MONDO:0009666              holocarboxylase synthetase deficiency
# 29   MONDO:0005835                                     Lynch syndrome
# ..             ...                                                ...
# 220  MONDO:0012987          agammaglobulinemia 6, autosomal recessive
# 221  MONDO:0012198                                      PCWH syndrome
# 222  MONDO:0018060                   congenital fibrinogen deficiency
# 223  MONDO:0002457                          Treacher-Collins syndrome
# 224  MONDO:0013540              deafness-lymphedema-leukemia syndrome
# 225  MONDO:0016021           early infantile epileptic encephalopathy
# 226  MONDO:0011628                                 propionic acidemia
# 227  MONDO:0014722                                   Roifman syndrome
# 228  MONDO:0009212                     congenital factor X deficiency
# 229  MONDO:0013546  mitochondrial complex V (ATP synthase) deficie...
# 230  MONDO:0010217                      de Sanctis-Cacchione syndrome
# 231  MONDO:0010278                              Christianson syndrome
# 232  MONDO:0018859                                      Leigh disease
# 233  MONDO:0009026                                  Costello syndrome
# 234  MONDO:0008375                                 retinal detachment
# 235  MONDO:0008346                            pulmonary hemosiderosis
# 236  MONDO:0014200  aldosterone-producing adenoma with seizures an...
# 237  MONDO:0008763                                   Alstrom syndrome
# 238  MONDO:0013361                             prothrombin deficiency
# 239  MONDO:0011776                                     CINCA syndrome
# 240  MONDO:0009723                                     Leigh syndrome
# 241  MONDO:0010733                    hereditary spastic paraplegia 2
# 242  MONDO:0010512  mental retardation, X-linked, syndromic, Bain ...
# 243  MONDO:0012084     aromatic L-amino acid decarboxylase deficiency
# 244  MONDO:0016028                                    erythromelalgia
# 245  MONDO:0017314              Ehlers-Danlos syndrome, vascular type
# 246  MONDO:0018306                                 Griscelli syndrome
# 247  MONDO:0010726                                      Rett syndrome
# 248  MONDO:0008667                          von Hippel-Lindau disease
# 249  MONDO:0008542                                tetralogy of fallot
#
#      similarity
# 0      0.337778
# 1      0.324468
# 2      0.317352
# 3      0.297240
# 4      0.296954
# 5      0.280412
# 6      0.276119
# 7      0.275362
# 8      0.270833
# 9      0.266892
# 10     0.263359
# 11     0.263158
# 12     0.251586
# 13     0.249322
# 14     0.246729
# 15     0.243169
# 16     0.242489
# 17     0.239640
# 18     0.233471
# 19     0.233273
# 20     0.232877
# 21     0.231818
# 22     0.228311
# 23     0.225888
# 24     0.224206
# 25     0.222500
# 26     0.221884
# 27     0.221264
# 28     0.220430
# 29     0.220264
# ..          ...
# 220    0.162080
# 221    0.161987
# 222    0.161972
# 223    0.161616
# 224    0.161616
# 225    0.161585
# 226    0.161520
# 227    0.161504
# 228    0.161473
# 229    0.161426
# 230    0.161290
# 231    0.160944
# 232    0.160542
# 233    0.160393
# 234    0.160305
# 235    0.160173
# 236    0.160099
# 237    0.160072
# 238    0.160000
# 239    0.159806
# 240    0.159794
# 241    0.159794
# 242    0.159794
# 243    0.159780
# 244    0.159686
# 245    0.159555
# 246    0.159524
# 247    0.159341
# 248    0.159251
# 249    0.158986
#
# [250 rows x 3 columns]
