# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q63 - "Which pathways does $protein participate in"
#### Set protein to the curie id of the desired protein and run.
request = { "query_type_id": "Q63", "terms": { "protein": "UniProtKB:Q96N76" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# urocanate hydratase 1	UniProtKB:Q96N76	Resolution of Abasic Sites (AP sites)	REACT:R-HSA-73933
# urocanate hydratase 1	UniProtKB:Q96N76	GABA synthesis, release, reuptake and degradation	REACT:R-HSA-888590
# urocanate hydratase 1	UniProtKB:Q96N76	Metabolism of folate and pterines	REACT:R-HSA-196757
# urocanate hydratase 1	UniProtKB:Q96N76	Nucleotide Excision Repair	REACT:R-HSA-5696398
# urocanate hydratase 1	UniProtKB:Q96N76	Cardiac conduction	REACT:R-HSA-5576891
# urocanate hydratase 1	UniProtKB:Q96N76	Abacavir transport and metabolism	REACT:R-HSA-2161522
# urocanate hydratase 1	UniProtKB:Q96N76	Nucleobase biosynthesis	REACT:R-HSA-8956320
# urocanate hydratase 1	UniProtKB:Q96N76	Galactose catabolism	REACT:R-HSA-70370
# urocanate hydratase 1	UniProtKB:Q96N76	HDR through Homologous Recombination (HR) or Single Strand Annealing (SSA)	REACT:R-HSA-5693567
# urocanate hydratase 1	UniProtKB:Q96N76	Cholesterol biosynthesis	REACT:R-HSA-191273
# ...

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-14 20:09:00",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/397",
#     "message": "58 results found",
#     "original_question_text": "",
#     "query_type_id": "Q63",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "Resolution of Abasic Sites (AP sites)",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22311",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q96N76",
#                         "source_id": "UniProtKB:Q96N76",
#                         "target_id": "REACT:R-HSA-73933",
# ...
