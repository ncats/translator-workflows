# %% [markdown]
# # Workflow 1, Module 2, Question 5

# %% [markdown]
# ## What drugs/compounds target gene products of [gene]?

# %% [markdown]
# This is a simple expand from gene to chemical.   The only subtlety is whether we want to limit the predicates for the compounds.

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import json
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %% [markdown]
# These are some of the genes from question 4:

# %%
prkaa2 = 'HGNC:9377'
prkaa1 = 'HGNC:9376'
elovl6 = 'HGNC:9376'

# %%
prkaa2_chemicals = expand('gene',prkaa2,'chemical_substance')
parse_answer(prkaa2_chemicals)
# Out:
# Return Status: 200
#                result_id                                        result_name  \
# 0            CHEBI:18406                                AICA ribonucleotide
# 1            CHEBI:15366            2-(carboxymethylamino)-2-oxoacetic acid
# 2            CHEBI:39867                                      Valproic Acid
# 3            CHEBI:16221                                                ADP
# 4             CHEBI:2504                                       Aflatoxin B1
# 5            CHEBI:15738  8,12-Epoxy-1H,8H-2,7b,12a-triazadibenzo(a,g)cy...
# 6           MESH:C406082                            monomethylarsonous acid
# 7            CHEBI:75249                             potassium chromate(VI)
# 8           CHEBI:132082                                         entinostat
# 9           MESH:C438505  6,8-diallyl 5,7-dihydroxy 2-(2-allyl 3-hydroxy...
# 10           CHEBI:31440                                     Copper Sulfate
# 11           CHEBI:15743                                      butyraldehyde
# 12           CHEBI:45713                                        resveratrol
# 13          MESH:C544151                                          jinfukang
# 14  CHEMBL:CHEMBL1908395                                       JNJ-28312141
# 15           CHEBI:30614  7,8-Dihydro-7,8-dihydroxybenzo(a)pyrene 9,10-o...
# 16            CHEBI:9464                             testosterone enanthate
# 17          MESH:D002945                                          Cisplatin
# 18   CHEMBL:CHEMBL117649                                             tempol
# 19           CHEBI:27684                             Phenylmercuric Acetate
# 20           CHEBI:15379                                             Oxygen
# 21           CHEBI:46024                                     trichostatin A
# 22            CHEBI:3423                                         Carmustine
# 23           CHEBI:72564                                       temozolomide
# 24            CHEBI:2663                                         Amiodarone
# 25           CHEBI:15940                                             Niacin
# 26           CHEBI:17514                                            Calcium
# 27            CHEBI:4031                                       Cyclosporine
#
#                        source                                 type
# 0   ctd.gene_to_drug_extended  increases_molecular_modification_of
# 1   hmdb.enzyme_to_metabolite                       interacts_with
# 2   ctd.gene_to_drug_extended              increases_expression_of
# 3   hmdb.enzyme_to_metabolite                       interacts_with
# 4   ctd.gene_to_drug_extended              increases_expression_of
# 5        pharos.gene_get_drug              directly_interacts_with
# 6   ctd.gene_to_drug_extended              increases_expression_of
# 7   ctd.gene_to_drug_extended              increases_expression_of
# 8   ctd.gene_to_drug_extended              increases_expression_of
# 9   ctd.gene_to_drug_extended  increases_molecular_modification_of
# 10  ctd.gene_to_drug_extended              increases_expression_of
# 11  ctd.gene_to_drug_extended              decreases_expression_of
# 12  ctd.gene_to_drug_extended  increases_molecular_modification_of
# 13  ctd.gene_to_drug_extended              decreases_expression_of
# 14       pharos.gene_get_drug              directly_interacts_with
# 15  ctd.gene_to_drug_extended              decreases_expression_of
# 16  ctd.gene_to_drug_extended                affects_expression_of
# 17  ctd.gene_to_drug_extended              decreases_expression_of
# 18  ctd.gene_to_drug_extended                decreases_activity_of
# 19  ctd.gene_to_drug_extended              decreases_expression_of
# 20  ctd.gene_to_drug_extended              increases_expression_of
# 21  ctd.gene_to_drug_extended              increases_expression_of
# 22  ctd.gene_to_drug_extended                  affects_response_to
# 23  ctd.gene_to_drug_extended                  affects_response_to
# 24  ctd.gene_to_drug_extended  increases_molecular_modification_of
# 25  ctd.gene_to_drug_extended                increases_activity_of
# 26  hmdb.enzyme_to_metabolite                       interacts_with
# 27  ctd.gene_to_drug_extended              decreases_expression_of
