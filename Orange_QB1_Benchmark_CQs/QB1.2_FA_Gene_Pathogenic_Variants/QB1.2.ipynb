# %% [markdown]
# # Orange QB1.2_FA_Gene_Pathogenic_Variants

# %% [markdown]
# ## Query:
# What core FA gene variants are pathogenic, and for what conditions? (i.e. cause or contribute to pathogenic outcomes)

# %% [markdown]
# ## Input:
# Hardcoded tsv file from:
# https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt

# %% [markdown]
# ## Goals:
#
# A benchmarking query to assess information in the Translator system about pathogenicity of variants in human FA core genes.
# This query is independently answerable using only CIViC data accessible via Wikidata, or ClinVar data accessible via Monarch/Biolink. This query will be used as a simple test case for aggregating results that are from different primary sources, served different knowledge beacons, and may use differnet IRIs for equivalent concepts.

# %% [markdown]
# ## Proposed Data Types, Sources, and Access Endpoints:
#
# ClinVar variant-disease associations (via Monarch/Biolink)
#
# CIViC variant-disease associations (via Wikidata, and soon via Biolink))

# %% [markdown]
# ## Proposed Sub-Queries/Tasks:
#
# ### Input: FA Gene X
#
# Retrieve all variants of Gene X
# Gene -[has_affected_feature]-> Variant (Monarch)
# Gene-[biological variant of] -> Variant (Wikidata)
#
# Retrieve all diseases caused by variants in set above
# Variant -[causes_or_contribues_to_condition*]-> Disease (Monarch)
# Variant-[positive diagnostic predictor] -> Variant (Wikidata)
#
# Output: Set of diseases associated with variant in FA gene(s)

# %%
import requests
import pandas as pd
from pprint import pprint

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_all_genes = "FA_4_all_genes.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_all_genes, sep='\t', names=columns)

# %%
fa_genes
# Out:
#          gene_curie gene_symbol
# 0     NCBIGene:2175       FANCA
# 1     NCBIGene:2187       FANCB
# 2     NCBIGene:2176       FANCC
# 3     NCBIGene:2178       FANCE
# 4     NCBIGene:2188       FANCF
# 5     NCBIGene:2189       FANCG
# 6    NCBIGene:55120       FANCL
# 7    NCBIGene:57697       FANCM
# 8     NCBIGene:2177      FANCD2
# 9    NCBIGene:55215       FANCI
# 10   NCBIGene:29089       UBE2T
# 11     NCBIGene:675       BRCA2
# 12   NCBIGene:83990       BRIP1
# 13   NCBIGene:79728       PALB2
# 14    NCBIGene:5889      RAD51C
# 15   NCBIGene:84464        SLX4
# 16    NCBIGene:2072       ERCC4
# 17    NCBIGene:5888       RAD51
# 18     NCBIGene:672       BRCA1
# 19   NCBIGene:10459      MAD2L2
# 20    NCBIGene:7516       XRCC2
# 21   NCBIGene:55159       RFWD3
# 22   NCBIGene:80233     FAAP100
# 23   NCBIGene:91442      FAAP24
# 24  NCBIGene:199990      FAAP20
# 25  NCBIGene:378708       CENPS
# 26  NCBIGene:201254       CENPX

# %%
#  return gene disease association data from biolink
def query_biolink_gene_disease(gene_curie):
    bl_url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/diseases/'
    params = {
        'fetch_objects': True,   
    }
    r = requests.get(url=bl_url.format(gene_curie), params=params)
    return r.json()

# %%
# geno terms to human readable labels
term_map_reversed = {
    "GENO:0000840": "pathogenic",
    "GENO:0000841": "likely pathogenic",
    "GENO:0000843": "benign",
    "GENO:0000844": "likely benign",
    "GENO:0000845": "uncertain significance"    
}

# %%
"""
Look for pathogenic variants and the disease 
they are implicated with via biolink
"""
result_set = []
for index, row in fa_genes.iterrows():
    bl_dat = query_biolink_gene_disease(row[0])
    for assoc in bl_dat['associations']:
        edges = assoc['evidence_graph']['edges']
        nodes = assoc['evidence_graph']['nodes']
        node_map = dict()
        for node in nodes:
            node_map[node['id']] = node['lbl']
        for edge in edges:
            if edge['pred'] in term_map_reversed.keys():
                pd_row = [row[1], row[0], node_map[edge['sub']], 
                       edge['sub'], term_map_reversed[edge['pred']], 
                       edge['pred'], node_map[edge['obj']], edge['obj']]
                result_set.append(pd_row)
    column_names = ['gene_name', 'gene_curie', 'variant_name', 'variant_curie', 
                    'relation_label', 'relation_curie', 'disease_label', 'disease_curie']
result_frame = pd.DataFrame(data=result_set, columns=column_names)
result_frame.to_csv('FA_pathogenic_variant_BioLink.csv', sep=',')
result_frame

# Returns dataFrame with FA gene ClinVar data.
# Out:
#     gene_name      gene_curie  \
# 0       FANCA   NCBIGene:2175
# 1       FANCA   NCBIGene:2175
# 2       FANCA   NCBIGene:2175
# 3       FANCA   NCBIGene:2175
# 4       FANCA   NCBIGene:2175
# 5       FANCA   NCBIGene:2175
# 6       FANCA   NCBIGene:2175
# 7       FANCA   NCBIGene:2175
# 8       FANCA   NCBIGene:2175
# 9       FANCA   NCBIGene:2175
# 10      FANCA   NCBIGene:2175
# 11      FANCA   NCBIGene:2175
# 12      FANCA   NCBIGene:2175
# 13      FANCA   NCBIGene:2175
# 14      FANCA   NCBIGene:2175
# 15      FANCA   NCBIGene:2175
# 16      FANCA   NCBIGene:2175
# 17      FANCA   NCBIGene:2175
# 18      FANCA   NCBIGene:2175
# 19      FANCA   NCBIGene:2175
# 20      FANCA   NCBIGene:2175
# 21      FANCA   NCBIGene:2175
# 22      FANCA   NCBIGene:2175
# 23      FANCA   NCBIGene:2175
# 24      FANCA   NCBIGene:2175
# 25      FANCA   NCBIGene:2175
# 26      FANCA   NCBIGene:2175
# 27      FANCA   NCBIGene:2175
# 28      FANCA   NCBIGene:2175
# 29      FANCA   NCBIGene:2175
# ..        ...             ...
# 543     BRCA1    NCBIGene:672
# 544     BRCA1    NCBIGene:672
# 545     BRCA1    NCBIGene:672
# 546     BRCA1    NCBIGene:672
# 547     BRCA1    NCBIGene:672
# 548     BRCA1    NCBIGene:672
# 549     BRCA1    NCBIGene:672
# 550     BRCA1    NCBIGene:672
# 551     BRCA1    NCBIGene:672
# 552     BRCA1    NCBIGene:672
# 553     BRCA1    NCBIGene:672
# 554     BRCA1    NCBIGene:672
# 555     BRCA1    NCBIGene:672
# 556     BRCA1    NCBIGene:672
# 557     BRCA1    NCBIGene:672
# 558     BRCA1    NCBIGene:672
# 559     BRCA1    NCBIGene:672
# 560     BRCA1    NCBIGene:672
# 561     BRCA1    NCBIGene:672
# 562     BRCA1    NCBIGene:672
# 563     BRCA1    NCBIGene:672
# 564     BRCA1    NCBIGene:672
# 565     BRCA1    NCBIGene:672
# 566     BRCA1    NCBIGene:672
# 567     BRCA1    NCBIGene:672
# 568     BRCA1    NCBIGene:672
# 569     BRCA1    NCBIGene:672
# 570     BRCA1    NCBIGene:672
# 571     BRCA1    NCBIGene:672
# 572    MAD2L2  NCBIGene:10459
#
#                                           variant_name          variant_curie  \
# 0           NM_000135.3(FANCA):c.2557C>T (p.Arg853Ter)  ClinVarVariant:192384
# 1    NC_000016.9:g.(89829945_89831038)_(89836251_89...  ClinVarVariant:402242
# 2             NM_000135.2(FANCA):c.154C>T (p.Arg52Ter)  ClinVarVariant:371668
# 3                       NM_000135.3(FANCA):c.2151+1G>A  ClinVarVariant:435130
# 4                       NM_000135.3(FANCA):c.2601+1G>T  ClinVarVariant:435128
# 5        NM_000135.2(FANCA):c.1615delG (p.Asp539Thrfs)    ClinVarVariant:3443
# 6    NC_000016.9:g.(89837128_89837200)_(89847471_89...  ClinVarVariant:402243
# 7        NM_000135.3(FANCA):c.3558dup (p.Arg1187Glufs)    ClinVarVariant:3444
# 8    NM_000135.2(FANCA):c.3720_3724delAAACA (p.Glu1...    ClinVarVariant:3448
# 9                       NM_000135.2(FANCA):c.3066+1G>T  ClinVarVariant:156400
# 10           NM_000135.2(FANCA):c.3624C>T (p.Ser1208=)  ClinVarVariant:419528
# 11                   NM_000135.2(FANCA):c.1007_3066del    ClinVarVariant:3445
# 12               NM_000135.3(FANCA):c.1A>G (p.Met1Val)  ClinVarVariant:435134
# 13          NM_000135.3(FANCA):c.2398G>T (p.Glu800Ter)  ClinVarVariant:435129
# 14          NM_000135.3(FANCA):c.1340C>G (p.Ser447Ter)  ClinVarVariant:435132
# 15          NM_000135.2(FANCA):c.2574C>G (p.Ser858Arg)  ClinVarVariant:134256
# 16   NM_000135.2(FANCA):c.3761_3762delAG (p.Glu1254...  ClinVarVariant:370466
# 17   NM_000135.2(FANCA):c.1115_1118delTTGG (p.Val37...    ClinVarVariant:3440
# 18        NM_000135.3(FANCA):c.2839dup (p.Ser947Phefs)  ClinVarVariant:188383
# 19      NM_000135.2(FANCA):c.4015delC (p.Leu1339Serfs)  ClinVarVariant:208638
# 20           NM_000135.3(FANCA):c.513G>A (p.Trp171Ter)    ClinVarVariant:3447
# 21   NM_000135.2(FANCA):c.987_990delTCAC (p.His330A...  ClinVarVariant:208580
# 22                              FANCA, IVS7DS, G-A, +5  ClinVarVariant:192385
# 23            NM_000135.2(FANCA):c.295C>T (p.Gln99Ter)  ClinVarVariant:370361
# 24           NM_000135.2(FANCA):c.811C>T (p.Gln271Ter)  ClinVarVariant:371093
# 25         NM_000135.3(FANCA):c.3482C>T (p.Thr1161Met)  ClinVarVariant:435126
# 26       NM_000135.2(FANCA):c.1606delT (p.Ser536Glnfs)    ClinVarVariant:3446
# 27   NM_000135.2(FANCA):c.3788_3790delTCT (p.Phe126...   ClinVarVariant:41003
# 28          NM_000135.2(FANCA):c.2762A>T (p.Lys921Ile)  ClinVarVariant:203995
# 29                           FANCA, 156-BP DEL, NT1515    ClinVarVariant:3441
# ..                                                 ...                    ...
# 543                             NM_007294.3:c.2726insA  ClinVarVariant:182108
# 544  NM_007294.3(BRCA1):c.4251_4252delGT (p.Leu1418...   ClinVarVariant:37579
# 545     NM_007294.3(BRCA1):c.68_69delAG (p.Glu23Valfs)   ClinVarVariant:17662
# 546        NM_007294.3(BRCA1):c.4327C>T (p.Arg1443Ter)   ClinVarVariant:17675
# 547        NM_007294.3(BRCA1):c.4484G>T (p.Arg1495Met)   ClinVarVariant:37598
# 548        NM_007294.3(BRCA1):c.4689C>G (p.Tyr1563Ter)   ClinVarVariant:37607
# 549  NM_007294.3(BRCA1):c.3228_3229delAG (p.Gly1077...   ClinVarVariant:37516
# 550  NM_007294.3(BRCA1):c.4655_4658delACTT (p.Tyr15...   ClinVarVariant:55252
# 551      NM_007294.3(BRCA1):c.2938delA (p.Ile980Tyrfs)  ClinVarVariant:182073
# 552        NM_007294.3(BRCA1):c.5095C>T (p.Arg1699Trp)   ClinVarVariant:55396
# 553         NM_007294.3(BRCA1):c.1059G>A (p.Trp353Ter)   ClinVarVariant:54110
# 554                NM_007294.3(BRCA1):c.135-?_441+?del   ClinVarVariant:89055
# 555        NM_007294.3(BRCA1):c.5123C>A (p.Ala1708Glu)   ClinVarVariant:55407
# 556                             NM_007294.3:c.3764insA  ClinVarVariant:182114
# 557               NM_007294.3(BRCA1):c.?-232_4484+?del   ClinVarVariant:89068
# 558     NM_007294.3(BRCA1):c.3648dupA (p.Ser1217Ilefs)   ClinVarVariant:37535
# 559      NM_007294.3(BRCA1):c.1140dupG (p.Lys381Glufs)  ClinVarVariant:231732
# 560          NM_007294.3(BRCA1):c.427G>T (p.Glu143Ter)   ClinVarVariant:37581
# 561     NM_007294.3(BRCA1):c.5266dupC (p.Gln1756Profs)   ClinVarVariant:17677
# 562           NM_007294.3(BRCA1):c.181T>G (p.Cys61Gly)   ClinVarVariant:17661
# 563              NM_007294.3(BRCA1):c.4186-?_4675+?del   ClinVarVariant:89061
# 564                             NM_007294.3:c.3908insT  ClinVarVariant:182115
# 565     NM_007294.3(BRCA1):c.3485delA (p.Asp1162Valfs)   ClinVarVariant:37531
# 566  NM_007294.3(BRCA1):c.4964_4982del19 (p.Ser1655...   ClinVarVariant:37616
# 567  NM_007294.3(BRCA1):c.3436_3439delTGTT (p.Cys11...   ClinVarVariant:54885
# 568     NM_007294.3(BRCA1):c.5266dupC (p.Gln1756Profs)   ClinVarVariant:17677
# 569  NM_007294.3(BRCA1):c.3839_3843delCTCAGinsAGGC ...   ClinVarVariant:55021
# 570        NM_007294.3(BRCA1):c.5095C>T (p.Arg1699Trp)   ClinVarVariant:55396
# 571  NM_007294.3(BRCA1):c.594_597delTGTG (p.Ser198A...  ClinVarVariant:209105
# 572          NM_006341.3(MAD2L2):c.254T>A (p.Val85Glu)  ClinVarVariant:372196
#
#         relation_label relation_curie  \
# 0           pathogenic   GENO:0000840
# 1    likely pathogenic   GENO:0000841
# 2           pathogenic   GENO:0000840
# 3           pathogenic   GENO:0000840
# 4           pathogenic   GENO:0000840
# 5           pathogenic   GENO:0000840
# 6    likely pathogenic   GENO:0000841
# 7           pathogenic   GENO:0000840
# 8           pathogenic   GENO:0000840
# 9           pathogenic   GENO:0000840
# 10   likely pathogenic   GENO:0000841
# 11          pathogenic   GENO:0000840
# 12          pathogenic   GENO:0000840
# 13          pathogenic   GENO:0000840
# 14          pathogenic   GENO:0000840
# 15          pathogenic   GENO:0000840
# 16          pathogenic   GENO:0000840
# 17          pathogenic   GENO:0000840
# 18   likely pathogenic   GENO:0000841
# 19   likely pathogenic   GENO:0000841
# 20          pathogenic   GENO:0000840
# 21          pathogenic   GENO:0000840
# 22          pathogenic   GENO:0000840
# 23          pathogenic   GENO:0000840
# 24   likely pathogenic   GENO:0000841
# 25   likely pathogenic   GENO:0000841
# 26          pathogenic   GENO:0000840
# 27          pathogenic   GENO:0000840
# 28   likely pathogenic   GENO:0000841
# 29          pathogenic   GENO:0000840
# ..                 ...            ...
# 543         pathogenic   GENO:0000840
# 544         pathogenic   GENO:0000840
# 545         pathogenic   GENO:0000840
# 546         pathogenic   GENO:0000840
# 547         pathogenic   GENO:0000840
# 548         pathogenic   GENO:0000840
# 549         pathogenic   GENO:0000840
# 550         pathogenic   GENO:0000840
# 551         pathogenic   GENO:0000840
# 552         pathogenic   GENO:0000840
# 553         pathogenic   GENO:0000840
# 554         pathogenic   GENO:0000840
# 555         pathogenic   GENO:0000840
# 556         pathogenic   GENO:0000840
# 557         pathogenic   GENO:0000840
# 558         pathogenic   GENO:0000840
# 559  likely pathogenic   GENO:0000841
# 560         pathogenic   GENO:0000840
# 561         pathogenic   GENO:0000840
# 562         pathogenic   GENO:0000840
# 563         pathogenic   GENO:0000840
# 564         pathogenic   GENO:0000840
# 565         pathogenic   GENO:0000840
# 566         pathogenic   GENO:0000840
# 567         pathogenic   GENO:0000840
# 568         pathogenic   GENO:0000840
# 569         pathogenic   GENO:0000840
# 570         pathogenic   GENO:0000840
# 571         pathogenic   GENO:0000840
# 572         pathogenic   GENO:0000840
#
#                                     disease_label disease_curie
# 0         Fanconi Anemia, Complementation Group a   OMIM:227650
# 1         Fanconi Anemia, Complementation Group a   OMIM:227650
# 2         Fanconi Anemia, Complementation Group a   OMIM:227650
# 3         Fanconi Anemia, Complementation Group a   OMIM:227650
# 4         Fanconi Anemia, Complementation Group a   OMIM:227650
# 5         Fanconi Anemia, Complementation Group a   OMIM:227650
# 6         Fanconi Anemia, Complementation Group a   OMIM:227650
# 7         Fanconi Anemia, Complementation Group a   OMIM:227650
# 8         Fanconi Anemia, Complementation Group a   OMIM:227650
# 9         Fanconi Anemia, Complementation Group a   OMIM:227650
# 10        Fanconi Anemia, Complementation Group a   OMIM:227650
# 11        Fanconi Anemia, Complementation Group a   OMIM:227650
# 12        Fanconi Anemia, Complementation Group a   OMIM:227650
# 13        Fanconi Anemia, Complementation Group a   OMIM:227650
# 14        Fanconi Anemia, Complementation Group a   OMIM:227650
# 15        Fanconi Anemia, Complementation Group a   OMIM:227650
# 16        Fanconi Anemia, Complementation Group a   OMIM:227650
# 17        Fanconi Anemia, Complementation Group a   OMIM:227650
# 18        Fanconi Anemia, Complementation Group a   OMIM:227650
# 19        Fanconi Anemia, Complementation Group a   OMIM:227650
# 20        Fanconi Anemia, Complementation Group a   OMIM:227650
# 21        Fanconi Anemia, Complementation Group a   OMIM:227650
# 22        Fanconi Anemia, Complementation Group a   OMIM:227650
# 23        Fanconi Anemia, Complementation Group a   OMIM:227650
# 24        Fanconi Anemia, Complementation Group a   OMIM:227650
# 25        Fanconi Anemia, Complementation Group a   OMIM:227650
# 26        Fanconi Anemia, Complementation Group a   OMIM:227650
# 27        Fanconi Anemia, Complementation Group a   OMIM:227650
# 28        Fanconi Anemia, Complementation Group a   OMIM:227650
# 29        Fanconi Anemia, Complementation Group a   OMIM:227650
# ..                                            ...           ...
# 543                     Familial cancer of breast   OMIM:114480
# 544                     Familial cancer of breast   OMIM:114480
# 545                     Familial cancer of breast   OMIM:114480
# 546                     Familial cancer of breast   OMIM:114480
# 547                     Familial cancer of breast   OMIM:114480
# 548                     Familial cancer of breast   OMIM:114480
# 549                     Familial cancer of breast   OMIM:114480
# 550                     Familial cancer of breast   OMIM:114480
# 551                     Familial cancer of breast   OMIM:114480
# 552                     Familial cancer of breast   OMIM:114480
# 553                     Familial cancer of breast   OMIM:114480
# 554                     Familial cancer of breast   OMIM:114480
# 555                     Familial cancer of breast   OMIM:114480
# 556                     Familial cancer of breast   OMIM:114480
# 557                     Familial cancer of breast   OMIM:114480
# 558                     Familial cancer of breast   OMIM:114480
# 559                     Familial cancer of breast   OMIM:114480
# 560                     Familial cancer of breast   OMIM:114480
# 561                     Familial cancer of breast   OMIM:114480
# 562                     Familial cancer of breast   OMIM:114480
# 563                     Familial cancer of breast   OMIM:114480
# 564                     Familial cancer of breast   OMIM:114480
# 565                     Familial cancer of breast   OMIM:114480
# 566                     Familial cancer of breast   OMIM:114480
# 567                     Familial cancer of breast   OMIM:114480
# 568  Porokeratosis punctata palmaris et plantaris   OMIM:175860
# 569                 Tumor Predisposition Syndrome   OMIM:614327
# 570       Fanconi Anemia, Complementation Group a   OMIM:227650
# 571       Fanconi Anemia, Complementation Group a   OMIM:227650
# 572       Fanconi Anemia, Complementation Group 5   OMIM:617243
#
# [573 rows x 8 columns]

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def execute_query(query):
    endpoint = SPARQLWrapper('https://query.wikidata.org/sparql')
    endpoint.setQuery(query)
    endpoint.setReturnFormat(JSON)
    return endpoint.query().convert()

def var_query(entrez):
    """
    query wikidata by entrez id for variant that is 'positive diagnostic predictor of a disease'
    """    
    query = """
    SELECT distinct ?gene ?geneLabel ?variant ?variantLabel ?disease ?diseaseLabel
     WHERE {
      # ?gene wdt:P351 '%s'. 
      OPTIONAL {?variant wdt:P3433 ?gene.}        # variant of gene
      OPTIONAL {?variant wdt:P3433 ?gene;
                         wdt:P3356 ?disease.}    # variant is a positive diagnostic predictor of disease
       SERVICE wikibase:label {
            bd:serviceParam wikibase:language "en" .
      }
    }
    """ % (entrez)
    r = execute_query(query)
    return r['results']['bindings']

def keycheck(ckey, cdict):
    if ckey in cdict.keys():
        return cdict[ckey]['value']
    else:
        return None

# %%
"""
Look for variants of FA genes in wikidata that are 'positive diagnostic predictors' for a disease
"""
wd_columns = ['gene', 'geneLabel', 'variant', 'variantLabel', 'disease', "diseaseLabel"]
wd_result_frame = pd.DataFrame(columns=wd_columns)
  
for index, row in fa_genes.iterrows():
    entrez_id = row[0].split(":")[-1]
    wd_hits = var_query(entrez_id)
    for hit in wd_hits:
        result = dict()
        result['gene'] = keycheck('gene', hit)
        result['geneLabel'] = keycheck('geneLabel', hit)
        result['variant'] = keycheck('variant', hit)
        result['variantLabel'] = keycheck('variantLabel', hit)
        result['disease'] = keycheck('disease', hit)
        result['diseaseLabel'] = keycheck('diseaseLabel', hit)
        wd_result_frame = wd_result_frame.append(result, ignore_index=True)
        
wd_result_frame.to_csv('FA_pathogenic_variant_Wikidata.csv', sep=',')  
wd_result_frame

# Returns dataframe linking FA genes to Civic variant data
# Out:
#                                         gene geneLabel  \
# 0   http://www.wikidata.org/entity/Q17927056     FANCA
# 1   http://www.wikidata.org/entity/Q17927471     FANCB
# 2   http://www.wikidata.org/entity/Q18250517     FANCC
# 3   http://www.wikidata.org/entity/Q17927077     FANCE
# 4   http://www.wikidata.org/entity/Q17927502     FANCF
# 5   http://www.wikidata.org/entity/Q17927524     FANCG
# 6   http://www.wikidata.org/entity/Q18041564     FANCL
# 7   http://www.wikidata.org/entity/Q18044458     FANCM
# 8   http://www.wikidata.org/entity/Q17927069    FANCD2
# 9   http://www.wikidata.org/entity/Q18041663     FANCI
# 10  http://www.wikidata.org/entity/Q18039587     UBE2T
# 11  http://www.wikidata.org/entity/Q17853272     BRCA2
# 12  http://www.wikidata.org/entity/Q17853272     BRCA2
# 13  http://www.wikidata.org/entity/Q17853272     BRCA2
# 14  http://www.wikidata.org/entity/Q17853272     BRCA2
# 15  http://www.wikidata.org/entity/Q17853272     BRCA2
# 16  http://www.wikidata.org/entity/Q17853272     BRCA2
# 17  http://www.wikidata.org/entity/Q17853272     BRCA2
# 18  http://www.wikidata.org/entity/Q17853272     BRCA2
# 19  http://www.wikidata.org/entity/Q17853272     BRCA2
# 20  http://www.wikidata.org/entity/Q17853272     BRCA2
# 21  http://www.wikidata.org/entity/Q17853272     BRCA2
# 22  http://www.wikidata.org/entity/Q18047355     BRIP1
# 23  http://www.wikidata.org/entity/Q18046302     PALB2
# 24  http://www.wikidata.org/entity/Q18046302     PALB2
# 25  http://www.wikidata.org/entity/Q18031015    RAD51C
# 26  http://www.wikidata.org/entity/Q18047618      SLX4
# 27  http://www.wikidata.org/entity/Q17917469     ERCC4
# 28  http://www.wikidata.org/entity/Q14907732     RAD51
# 29    http://www.wikidata.org/entity/Q227339     BRCA1
# 30    http://www.wikidata.org/entity/Q227339     BRCA1
# 31    http://www.wikidata.org/entity/Q227339     BRCA1
# 32    http://www.wikidata.org/entity/Q227339     BRCA1
# 33    http://www.wikidata.org/entity/Q227339     BRCA1
# 34    http://www.wikidata.org/entity/Q227339     BRCA1
# 35    http://www.wikidata.org/entity/Q227339     BRCA1
# 36    http://www.wikidata.org/entity/Q227339     BRCA1
# 37    http://www.wikidata.org/entity/Q227339     BRCA1
# 38    http://www.wikidata.org/entity/Q227339     BRCA1
# 39    http://www.wikidata.org/entity/Q227339     BRCA1
# 40    http://www.wikidata.org/entity/Q227339     BRCA1
# 41    http://www.wikidata.org/entity/Q227339     BRCA1
# 42    http://www.wikidata.org/entity/Q227339     BRCA1
# 43    http://www.wikidata.org/entity/Q227339     BRCA1
# 44    http://www.wikidata.org/entity/Q227339     BRCA1
# 45    http://www.wikidata.org/entity/Q227339     BRCA1
# 46    http://www.wikidata.org/entity/Q227339     BRCA1
# 47    http://www.wikidata.org/entity/Q227339     BRCA1
# 48  http://www.wikidata.org/entity/Q18035401    MAD2L2
# 49  http://www.wikidata.org/entity/Q18032394     XRCC2
# 50  http://www.wikidata.org/entity/Q18041606     RFWD3
# 51  http://www.wikidata.org/entity/Q18046665   FAAP100
# 52  http://www.wikidata.org/entity/Q18048517    FAAP24
# 53  http://www.wikidata.org/entity/Q18053146    FAAP20
# 54  http://www.wikidata.org/entity/Q18056210     CENPS
# 55  http://www.wikidata.org/entity/Q18053211     CENPX
#
#                                      variant                  variantLabel  \
# 0                                       None                          None
# 1                                       None                          None
# 2   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 3                                       None                          None
# 4                                       None                          None
# 5                                       None                          None
# 6                                       None                          None
# 7                                       None                          None
# 8                                       None                          None
# 9                                       None                          None
# 10                                      None                          None
# 11  http://www.wikidata.org/entity/Q29938738                     BRCA2 M1I
# 12  http://www.wikidata.org/entity/Q29938739                   BRCA2 V159M
# 13  http://www.wikidata.org/entity/Q29938740                   BRCA2 V211L
# 14  http://www.wikidata.org/entity/Q28371625     BRCA2 TRUNCATING MUTATION
# 15  http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 16  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 17  http://www.wikidata.org/entity/Q29938737                     BRCA2 M1R
# 18  http://www.wikidata.org/entity/Q29938742                  BRCA2 R2336P
# 19  http://www.wikidata.org/entity/Q29938743                  BRCA2 R2336H
# 20  http://www.wikidata.org/entity/Q29938741                   BRCA2 V211I
# 21  http://www.wikidata.org/entity/Q28371604                  BRCA2 D3095E
# 22                                      None                          None
# 23  http://www.wikidata.org/entity/Q28439607               PALB2 L531FS*30
# 24  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 25                                      None                          None
# 26                                      None                          None
# 27                                      None                          None
# 28                                      None                          None
# 29  http://www.wikidata.org/entity/Q29938727                    BRCA1 R71G
# 30  http://www.wikidata.org/entity/Q29938724                     BRCA1 M1I
# 31  http://www.wikidata.org/entity/Q28445090         BRCA1 UNDEREXPRESSION
# 32  http://www.wikidata.org/entity/Q29938730                  BRCA1 R1495M
# 33  http://www.wikidata.org/entity/Q29938735                  BRCA1 R1443*
# 34  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 35  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 36  http://www.wikidata.org/entity/Q28532483     BRCA1 TRUNCATING MUTATION
# 37  http://www.wikidata.org/entity/Q29938734                  BRCA1 D1692N
# 38  http://www.wikidata.org/entity/Q29938732                  BRCA1 E1559K
# 39  http://www.wikidata.org/entity/Q29938736                  BRCA1 Q1467*
# 40  http://www.wikidata.org/entity/Q28445085              BRCA1 EXPRESSION
# 41  http://www.wikidata.org/entity/Q32965138                  BRCA1 W1815X
# 42  http://www.wikidata.org/entity/Q29938723                     BRCA1 M1V
# 43  http://www.wikidata.org/entity/Q29938726                    BRCA1 C64Y
# 44  http://www.wikidata.org/entity/Q29938725                    BRCA1 C61G
# 45  http://www.wikidata.org/entity/Q29938728                    BRCA1 R71K
# 46  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 47  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 48                                      None                          None
# 49                                      None                          None
# 50                                      None                          None
# 51                                      None                          None
# 52                                      None                          None
# 53                                      None                          None
# 54                                      None                          None
# 55                                      None                          None
#
#                                    disease    diseaseLabel
# 0                                     None            None
# 1                                     None            None
# 2                                     None            None
# 3                                     None            None
# 4                                     None            None
# 5                                     None            None
# 6                                     None            None
# 7                                     None            None
# 8                                     None            None
# 9                                     None            None
# 10                                    None            None
# 11                                    None            None
# 12                                    None            None
# 13                                    None            None
# 14                                    None            None
# 15                                    None            None
# 16                                    None            None
# 17                                    None            None
# 18                                    None            None
# 19                                    None            None
# 20                                    None            None
# 21  http://www.wikidata.org/entity/Q128581   breast cancer
# 22                                    None            None
# 23  http://www.wikidata.org/entity/Q128581   breast cancer
# 24                                    None            None
# 25                                    None            None
# 26                                    None            None
# 27                                    None            None
# 28                                    None            None
# 29                                    None            None
# 30                                    None            None
# 31                                    None            None
# 32                                    None            None
# 33                                    None            None
# 34                                    None            None
# 35                                    None            None
# 36                                    None            None
# 37                                    None            None
# 38                                    None            None
# 39                                    None            None
# 40                                    None            None
# 41                                    None            None
# 42                                    None            None
# 43                                    None            None
# 44                                    None            None
# 45                                    None            None
# 46  http://www.wikidata.org/entity/Q128581   breast cancer
# 47  http://www.wikidata.org/entity/Q172341  ovarian cancer
# 48                                    None            None
# 49                                    None            None
# 50                                    None            None
# 51                                    None            None
# 52                                    None            None
# 53                                    None            None
# 54                                    None            None
# 55                                    None            None

# %% [markdown]
# ## Results Summary

# %%
summary_table = pd.DataFrame(columns=['gene_name', 'variant_count', 'disease_count'])
for index, row in fa_genes.iterrows():
    result = dict()
    gene_frame = result_frame[result_frame.gene_name == row[1]]
    result['gene_name'] = row[1]
    result['variant_count'] = gene_frame['gene_name'].count()
    result['disease_count'] = len(set(gene_frame['disease_label'].tolist()))
    summary_table = summary_table.append(result, ignore_index=True)
summary_table
# Out:
#    gene_name  variant_count  disease_count
# 0      FANCA             32              1
# 1      FANCB              7              1
# 2      FANCC             42              2
# 3      FANCE              4              2
# 4      FANCF              6              1
# 5      FANCG              9              1
# 6      FANCL              7              1
# 7      FANCM              0              0
# 8     FANCD2              6              1
# 9      FANCI              7              1
# 10     UBE2T              2              1
# 11     BRCA2             24              6
# 12     BRIP1             79              5
# 13     PALB2            206              6
# 14    RAD51C             56              2
# 15      SLX4              6              1
# 16     ERCC4              8              3
# 17     RAD51              5              3
# 18     BRCA1             66              4
# 19    MAD2L2              1              1
# 20     XRCC2              0              0
# 21     RFWD3              0              0
# 22   FAAP100              0              0
# 23    FAAP24              0              0
# 24    FAAP20              0              0
# 25     CENPS              0              0
# 26     CENPX              0              0
