# %% [markdown]
# # This is some boilerplate code for interacting with the Pioneer 100 data source
#
# The documentation is available at http://isbtranslatorapi.adversary.us/

# %%
import urllib2
import json
import requests

# %%
base_url = 'http://isbtranslatorapi.adversary.us'

# %% [markdown]
# ## Metadata access
#
# How do I find the different things I am interested in?

# %%
# The base metadata takes a minute.  It is counting a lot of stuff
def query_isb(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    return req.json()

# %%
print json.dumps( query_isb('v1/metadata'), indent=2)
# Out:
# [
#   {
#     "count": 989596,
#     "key": "analytes"
#   },
#   {
#     "count": 16553204,
#     "key": "correlation"
#   }
# ]

# %% [markdown]
# ## Analytes
#
# Analytes are the nodes in the correlation network

# %%
print "These are the queryable fields."
print json.dumps( query_isb('v1/metadata/analytes'), indent=2)
# Out:
# These are the queryable fields.
# {
#   "fields": [
#     "type",
#     "phylum",
#     "vendor",
#     "pubmed_id",
#     "hmdb",
#     "hgnc_id",
#     "gene_location",
#     "_id",
#     "aggregation_level",
#     "description",
#     "uniprot",
#     "tissue_id",
#     "tissue_description",
#     "sub_pathway",
#     "order",
#     "subsystem",
#     "pubchem",
#     "tissue",
#     "nsamples",
#     "health_status",
#     "name",
#     "abbreviation",
#     "kegg",
#     "kingdom",
#     "super_pathway",
#     "study_title",
#     "class",
#     "source_project",
#     "measurement_technology",
#     "family",
#     "category",
#     "peptide"
#   ],
#   "Unique Analytes": 989596
# }

# %%
print "You can view see what values are associated with a field"
print "Note most queries are paginated using from and size."

print json.dumps( query_isb('v1/metadata/analytes/category', data={'from':0, 'size':20}), indent=2)
# Out:
# You can view see what values are associated with a field
# Note most queries are paginated using from and size.
# {
#   "count": 6,
#   "category": [
#     "Proteomics",
#     "Metabolites",
#     "Genetics",
#     "Clinical Labs",
#     "gene expression",
#     "Microbiome"
#   ]
# }

# %% [markdown]
# ### The categories associated with the Pioneer 100 dataset are Proteomics, Metabolites, Genetics, Clinical Labs, and Microbiome.

# %% [markdown]
# ## You can query for an analyte using the `v1/analyte` endpoint.

# %%
print json.dumps( query_isb('v1/analyte'), indent=2)

# %% [markdown]
# ## Some example analytes from each category

# %%
p100_categories = ["Proteomics", "Metabolites", "Genetics", "Clinical Labs", "Microbiome"]
                   
for category in p100_categories:
    print "Category:" , category
    print "="*20
    print json.dumps( query_isb('v1/analyte', data={'category':category, 'size':2}), indent=2)
    print
# Out:
# Category: Proteomics
# ====================
# [
#   {
#     "category": "Proteomics",
#     "subsystem": "brain",
#     "vendor": "ISB",
#     "description": "Extracellular matrix and cell adhesion protein that plays a role in nervous system development and in synaptic plasticity. Both soluble and membranous forms promote neurite outgrowth of cerebellar and hippocampal neurons and suppress neuronal cell death. Plays a role in neuronal positioning of pyramidal neurons and in regulation of both the number of interneurons and the efficacy of GABAergic synapses. May play a role in regulating cell migration in nerve regeneration and cortical development. Potentiates integrin-dep [...] (1224 aa)",
#     "measurement_technology": "mass spectometry",
#     "abbreviation": "CHL1",
#     "uniprot": "O00533",
#     "peptide": "VIAVNEVGR",
#     "_id": "PROTE.None.brain.CHL1.VIAVNEVGR",
#     "name": "cell adhesion molecule with homology to L1CAM (close homolog of L1)"
#   },
#   {
#     "category": "Proteomics",
#     "subsystem": "brain",
#     "vendor": "ISB",
#     "description": " Induces KLC1 association with vesicles and functions as a cargo in axonal anterograde transport. Complex formation with APBA2 and APP, stabilizes APP metabolism and enhances APBA2- mediated suppression of beta-APP40 secretion, due to the retardation of intracellular APP maturation. In complex with APBA2 and C99, a C-terminal APP fragment, abolishes C99 interaction with PSEN1 and thus APP C99 cleavage by gamma-secretase, most probably through stabilization of the direct interaction between APBA2 and APP. The intracellular fragment AlcICD suppresses APBB1-dependent transac [...] (981 aa)",
#     "measurement_technology": "mass spectometry",
#     "abbreviation": "CLSTN1",
#     "uniprot": "O94985",
#     "peptide": "AASEFESSEGVFLFPELR",
#     "_id": "PROTE.None.brain.CLSTN1.AASEFESSEGVFLFPELR",
#     "name": "calsyntenin 1"
#   }
# ]
#
# Category: Metabolites
# ====================
# [
#   {
#     "category": "Metabolites",
#     "kegg": "c00041",
#     "vendor": "Metabolon",
#     "name": "alanine",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "5950",
#     "hmdb": "hmdb00161",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00152",
#     "vendor": "Metabolon",
#     "name": "asparagine",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "6267",
#     "hmdb": "hmdb00168",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   }
# ]
#
# Category: Genetics
# ====================
# [
#   {
#     "category": "Genetics",
#     "study_title": "Genome-wide association study identifies three novel susceptibility loci for severe Acne vulgaris.",
#     "vendor": "New York Genome Center/Complete Genomics",
#     "name": "Acne (severe)",
#     "measurement_technology": "WGS",
#     "pubmed_id": "24927181",
#     "_id": "GENOM.trait.acne-(.PMID24927181.acne-(severe)",
#     "type": "Multivariate Genetic Risk score"
#   },
#   {
#     "category": "Genetics",
#     "study_title": "Genetic associations for activated partial thromboplastin time and prothrombin time, their gene expression profiles, and risk of coronary artery disease.",
#     "vendor": "New York Genome Center/Complete Genomics",
#     "name": "Activated partial thromboplastin time",
#     "measurement_technology": "WGS",
#     "pubmed_id": "22703881",
#     "_id": "GENOM.trait.activa.PMID22703881.activated-partial-thromboplastin-time",
#     "type": "Multivariate Genetic Risk score"
#   }
# ]
#
# Category: Clinical Labs
# ====================
# [
#   {
#     "category": "Clinical Labs",
#     "_id": "CHEMS.None.AGES.3-deoxyglucosone hydroimidazolones",
#     "vendor": "AGES",
#     "name": "3-deoxyglucosone hydroimidazolones"
#   },
#   {
#     "category": "Clinical Labs",
#     "_id": "CHEMS.None.AGES.aminoadipic acid",
#     "vendor": "AGES",
#     "name": "aminoadipic acid"
#   }
# ]
#
# Category: Microbiome
# ====================
# [
#   {
#     "category": "Microbiome",
#     "aggregation_level": "Shannon Diversity",
#     "_id": "MICRO.aggregate.diversity",
#     "vendor": "Second Genome"
#   },
#   {
#     "category": "Microbiome",
#     "kingdom": "Archaea",
#     "vendor": "Second Genome",
#     "phylum": "Euryarchaeota",
#     "_id": "MICRO.class.Archaea.Euryarchaeota.Methanobacteria",
#     "aggregation_level": "class",
#     "class": "Methanobacteria"
#   }
# ]

# %% [markdown]
# ## You can use a comma separated list to query for multiple values in fields

# %%
print json.dumps( query_isb('v1/analyte', data={'category':'Proteomics,Metabolites'}), indent=2)
# Out:
# [
#   {
#     "category": "Metabolites",
#     "kegg": "c00041",
#     "vendor": "Metabolon",
#     "name": "alanine",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "5950",
#     "hmdb": "hmdb00161",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00152",
#     "vendor": "Metabolon",
#     "name": "asparagine",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "6267",
#     "hmdb": "hmdb00168",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c02847",
#     "vendor": "Metabolon",
#     "name": "n-acetylalanine",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "88064",
#     "hmdb": "hmdb00766",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylalanine",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c01042",
#     "vendor": "Metabolon",
#     "name": "n-acetylaspartate-(naa)",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "65065",
#     "hmdb": "hmdb00812",
#     "_id": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylaspartate-(naa)",
#     "sub_pathway": "alanine-and-aspartate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00300",
#     "vendor": "Metabolon",
#     "name": "creatine",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "586",
#     "hmdb": "hmdb00064",
#     "_id": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "sub_pathway": "creatine-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00791",
#     "vendor": "Metabolon",
#     "name": "creatinine",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "588",
#     "hmdb": "hmdb00562",
#     "_id": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "sub_pathway": "creatine-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00581",
#     "vendor": "Metabolon",
#     "name": "guanidinoacetate",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "763",
#     "hmdb": "hmdb00128",
#     "_id": "METAB.None.amino-acid.creatine-metabolism.guanidinoacetate",
#     "sub_pathway": "creatine-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00025",
#     "vendor": "Metabolon",
#     "name": "glutamate",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "611",
#     "hmdb": "hmdb00148",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00064",
#     "vendor": "Metabolon",
#     "name": "glutamine",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "5961",
#     "hmdb": "hmdb00641",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c12270",
#     "vendor": "Metabolon",
#     "name": "n-acetyl-aspartyl-glutamate-(naag)",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "5255",
#     "hmdb": "hmdb01067",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "sub_pathway": "glutamate-metabolism"
#   }
# ]

# %% [markdown]
# ## Multiple options are treated as AND operations

# %%
print json.dumps( query_isb('v1/analyte', data={'super_pathway':'amino-acid', "sub_pathway":"glutamate-metabolism"}), indent=2)
# Out:
# [
#   {
#     "category": "Metabolites",
#     "kegg": "c00025",
#     "vendor": "Metabolon",
#     "name": "glutamate",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "611",
#     "hmdb": "hmdb00148",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00064",
#     "vendor": "Metabolon",
#     "name": "glutamine",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "5961",
#     "hmdb": "hmdb00641",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c12270",
#     "vendor": "Metabolon",
#     "name": "n-acetyl-aspartyl-glutamate-(naag)",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "5255",
#     "hmdb": "hmdb01067",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00624",
#     "vendor": "Metabolon",
#     "name": "n-acetylglutamate",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "70914",
#     "hmdb": "hmdb01138",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c02716",
#     "vendor": "Metabolon",
#     "name": "n-acetylglutamine",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "182230",
#     "hmdb": "hmdb06029",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "vendor": "Metabolon",
#     "name": "pyroglutamine*",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "134508",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "sub_pathway": "glutamate-metabolism"
#   }
# ]

# %% [markdown]
# The `_id` field is what you then use to query the correlations

# %% [markdown]
# # Correlations

# %%
my_analytes = query_isb('v1/analyte', data={'category':'Metabolites', "sub_pathway":"glutamate-metabolism"})
print json.dumps(my_analytes, indent=2)
# Out:
# [
#   {
#     "category": "Metabolites",
#     "kegg": "c00025",
#     "vendor": "Metabolon",
#     "name": "glutamate",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "611",
#     "hmdb": "hmdb00148",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00064",
#     "vendor": "Metabolon",
#     "name": "glutamine",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "5961",
#     "hmdb": "hmdb00641",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c12270",
#     "vendor": "Metabolon",
#     "name": "n-acetyl-aspartyl-glutamate-(naag)",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "5255",
#     "hmdb": "hmdb01067",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c00624",
#     "vendor": "Metabolon",
#     "name": "n-acetylglutamate",
#     "measurement_technology": "lc/ms-neg",
#     "super_pathway": "amino-acid",
#     "pubchem": "70914",
#     "hmdb": "hmdb01138",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "kegg": "c02716",
#     "vendor": "Metabolon",
#     "name": "n-acetylglutamine",
#     "measurement_technology": "lc/ms-polar",
#     "super_pathway": "amino-acid",
#     "pubchem": "182230",
#     "hmdb": "hmdb06029",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "sub_pathway": "glutamate-metabolism"
#   },
#   {
#     "category": "Metabolites",
#     "vendor": "Metabolon",
#     "name": "pyroglutamine*",
#     "measurement_technology": "lc/ms-pos",
#     "super_pathway": "amino-acid",
#     "pubchem": "134508",
#     "_id": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "sub_pathway": "glutamate-metabolism"
#   }
# ]

# %%
# join together some interesting ids and look for correlations
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'size':50}), indent=2)
# Out:
# [
#   {
#     "coefficient": 0.174321453409167,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "bh_adjusted_pvalue": 0.380768641466359,
#     "test": "SPEARMAN",
#     "pvalue": 0.071174338089057
#   },
#   {
#     "coefficient": 0.0314956879203117,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "bh_adjusted_pvalue": 0.927871281472151,
#     "test": "SPEARMAN",
#     "pvalue": 0.746252687001929
#   },
#   {
#     "coefficient": -0.0951822953880743,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.712749411749223,
#     "test": "SPEARMAN",
#     "pvalue": 0.327145240842785
#   },
#   {
#     "coefficient": 0.353101450932198,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.00908972639444744,
#     "test": "SPEARMAN",
#     "pvalue": 0.000178017705823694
#   },
#   {
#     "coefficient": 0.00110329546218717,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.997848143810193,
#     "test": "SPEARMAN",
#     "pvalue": 0.990958272822273
#   },
#   {
#     "coefficient": 0.134966227481018,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.546993769237379,
#     "test": "SPEARMAN",
#     "pvalue": 0.163719531770426
#   },
#   {
#     "coefficient": -0.301176324884686,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "bh_adjusted_pvalue": 0.0427030376686474,
#     "test": "SPEARMAN",
#     "pvalue": 0.00153820186142305
#   },
#   {
#     "coefficient": 0.441712355846865,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "bh_adjusted_pvalue": 0.000202525760180394,
#     "test": "SPEARMAN",
#     "pvalue": 1.70569104408648e-06
#   },
#   {
#     "coefficient": 0.0768148008776386,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.78309270860601,
#     "test": "SPEARMAN",
#     "pvalue": 0.429432989069325
#   },
#   {
#     "coefficient": 0.0426706552314205,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.896867292842454,
#     "test": "SPEARMAN",
#     "pvalue": 0.661033838093209
#   },
#   {
#     "coefficient": 0.0763098522364768,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.784961961582687,
#     "test": "SPEARMAN",
#     "pvalue": 0.432481218131176
#   },
#   {
#     "coefficient": 0.0109034527600716,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.978107802550403,
#     "test": "SPEARMAN",
#     "pvalue": 0.910825939901672
#   },
#   {
#     "coefficient": 0.0704602398849162,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylalanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.806109140849991,
#     "test": "SPEARMAN",
#     "pvalue": 0.468682069299607
#   },
#   {
#     "coefficient": 0.282803166709537,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylalanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.0662371291226396,
#     "test": "SPEARMAN",
#     "pvalue": 0.00302126315087721
#   },
#   {
#     "coefficient": 0.268973839807648,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylalanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.0898030049740608,
#     "test": "SPEARMAN",
#     "pvalue": 0.00488074139288451
#   },
#   {
#     "coefficient": 0.32770299236903,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylalanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.0205217722436239,
#     "test": "SPEARMAN",
#     "pvalue": 0.000536026847713796
#   },
#   {
#     "coefficient": 0.136204711957091,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylaspartate-(naa)",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.541339157791267,
#     "test": "SPEARMAN",
#     "pvalue": 0.159851945452905
#   },
#   {
#     "coefficient": -0.0289710099364562,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylaspartate-(naa)",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.934863405236493,
#     "test": "SPEARMAN",
#     "pvalue": 0.765982001595894
#   },
#   {
#     "coefficient": 0.198425290405967,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylaspartate-(naa)",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.287301596032533,
#     "test": "SPEARMAN",
#     "pvalue": 0.0395308333236486
#   },
#   {
#     "coefficient": 0.122714757971553,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.n-acetylaspartate-(naa)",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.598923826972085,
#     "test": "SPEARMAN",
#     "pvalue": 0.205786138187994
#   },
#   {
#     "coefficient": 0.126496899025408,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "bh_adjusted_pvalue": 0.583722750476077,
#     "test": "SPEARMAN",
#     "pvalue": 0.192047930111613
#   },
#   {
#     "coefficient": -0.11429333574712,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "bh_adjusted_pvalue": 0.634437895965535,
#     "test": "SPEARMAN",
#     "pvalue": 0.23887069449625
#   },
#   {
#     "coefficient": 0.0019911019653796,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.996244621807336,
#     "test": "SPEARMAN",
#     "pvalue": 0.98368329777163
#   },
#   {
#     "coefficient": 0.235826497851706,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.16700928132717,
#     "test": "SPEARMAN",
#     "pvalue": 0.0140093800725071
#   },
#   {
#     "coefficient": -0.049331697970143,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.876939942914987,
#     "test": "SPEARMAN",
#     "pvalue": 0.612145417654671
#   },
#   {
#     "coefficient": -0.38943668009946,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.0023033853790729,
#     "test": "SPEARMAN",
#     "pvalue": 3.10339165693022e-05
#   },
#   {
#     "coefficient": 0.0180056589213753,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "bh_adjusted_pvalue": 0.961621661251383,
#     "test": "SPEARMAN",
#     "pvalue": 0.853262045278031
#   },
#   {
#     "coefficient": 0.064653807039079,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "bh_adjusted_pvalue": 0.826668446064484,
#     "test": "SPEARMAN",
#     "pvalue": 0.506191385141059
#   },
#   {
#     "coefficient": 0.158821343850925,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.445810615461645,
#     "test": "SPEARMAN",
#     "pvalue": 0.100641344674983
#   },
#   {
#     "coefficient": 0.0995455714653177,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.695094501234242,
#     "test": "SPEARMAN",
#     "pvalue": 0.305354322329998
#   },
#   {
#     "coefficient": 0.107024456768948,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.665109800672299,
#     "test": "SPEARMAN",
#     "pvalue": 0.270262344200234
#   },
#   {
#     "coefficient": 0.326007221317176,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatinine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.0215893494952134,
#     "test": "SPEARMAN",
#     "pvalue": 0.000575063332501729
#   },
#   {
#     "coefficient": -0.0953537778539922,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.guanidinoacetate",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetyl-aspartyl-glutamate-(naag)",
#     "bh_adjusted_pvalue": 0.71200752247483,
#     "test": "SPEARMAN",
#     "pvalue": 0.326270485666012
#   },
#   {
#     "coefficient": 0.107490925719512,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.guanidinoacetate",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.662988403724825,
#     "test": "SPEARMAN",
#     "pvalue": 0.268167834658907
#   },
#   {
#     "coefficient": 0.271727281526324,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.guanidinoacetate",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamine",
#     "bh_adjusted_pvalue": 0.084598468036275,
#     "test": "SPEARMAN",
#     "pvalue": 0.00444470722013541
#   },
#   {
#     "coefficient": 0.124067564091572,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.guanidinoacetate",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.593388996557289,
#     "test": "SPEARMAN",
#     "pvalue": 0.200793588495818
#   },
#   {
#     "coefficient": -0.038805077145291,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.3-deoxyglucosone hydroimidazolones",
#     "bh_adjusted_pvalue": 0.926090210187125,
#     "test": "SPEARMAN",
#     "pvalue": 0.705896163591883
#   },
#   {
#     "coefficient": 0.399905322953924,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.aminoadipic acid",
#     "bh_adjusted_pvalue": 0.00516408025939737,
#     "test": "SPEARMAN",
#     "pvalue": 4.9442403457688e-05
#   },
#   {
#     "coefficient": -0.090078479802854,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.carboxyethyl-lysine",
#     "bh_adjusted_pvalue": 0.778413255185955,
#     "test": "SPEARMAN",
#     "pvalue": 0.38023966856251
#   },
#   {
#     "coefficient": -0.179099178479989,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.carboxymethyl-lysine",
#     "bh_adjusted_pvalue": 0.440295962346975,
#     "test": "SPEARMAN",
#     "pvalue": 0.0792118538854537
#   },
#   {
#     "coefficient": -0.257035030507048,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.glyoxal-hydroimidazolone-1",
#     "bh_adjusted_pvalue": 0.170890024579748,
#     "test": "SPEARMAN",
#     "pvalue": 0.0110365952539846
#   },
#   {
#     "coefficient": 0.265661161371765,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.methionine sulfoxide",
#     "bh_adjusted_pvalue": 0.149037748261974,
#     "test": "SPEARMAN",
#     "pvalue": 0.00853904726450627
#   },
#   {
#     "coefficient": -0.104627411805392,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.1_methylhistidine_plasma",
#     "bh_adjusted_pvalue": 0.709245238876608,
#     "test": "SPEARMAN",
#     "pvalue": 0.283491338792928
#   },
#   {
#     "coefficient": -0.121581068335763,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.2_hydroxyphenylacetic_acid",
#     "bh_adjusted_pvalue": 0.640605781049776,
#     "test": "SPEARMAN",
#     "pvalue": 0.210038005958133
#   },
#   {
#     "coefficient": 0.0825501667910532,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.3_hydroxyisovaleric_acid",
#     "bh_adjusted_pvalue": 0.788445519431379,
#     "test": "SPEARMAN",
#     "pvalue": 0.395683839716018
#   },
#   {
#     "coefficient": -0.309979112434102,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.3_hydroxyphenylacetic_acid",
#     "bh_adjusted_pvalue": 0.0434388427611063,
#     "test": "SPEARMAN",
#     "pvalue": 0.00109572800744996
#   },
#   {
#     "coefficient": 0.209343191064842,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.3_hydroxypropionic_acid",
#     "bh_adjusted_pvalue": 0.282628508630379,
#     "test": "SPEARMAN",
#     "pvalue": 0.0296753534896406
#   },
#   {
#     "coefficient": -0.205102556041423,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.3_methyl_4_hydroxyphenylglycol",
#     "bh_adjusted_pvalue": 0.298309750313983,
#     "test": "SPEARMAN",
#     "pvalue": 0.0332229281600918
#   },
#   {
#     "coefficient": 0.052548051490037,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.3_methylhistidine_plasma",
#     "bh_adjusted_pvalue": 0.884569690834711,
#     "test": "SPEARMAN",
#     "pvalue": 0.590888808194493
#   },
#   {
#     "coefficient": -0.152983077659483,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.4_hydroxyphenylacetic_acid",
#     "bh_adjusted_pvalue": 0.510927913121809,
#     "test": "SPEARMAN",
#     "pvalue": 0.113954299973144
#   }
# ]

# %%
# same thing but drop the crumby pvalues 
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'bh_adjusted_pvalue': .01}), indent=2)
# Out:
# [
#   {
#     "coefficient": 0.353101450932198,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.alanine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.n-acetylglutamate",
#     "bh_adjusted_pvalue": 0.00908972639444744,
#     "test": "SPEARMAN",
#     "pvalue": 0.000178017705823694
#   },
#   {
#     "coefficient": 0.441712355846865,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.alanine-and-aspartate-metabolism.asparagine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.glutamine",
#     "bh_adjusted_pvalue": 0.000202525760180394,
#     "test": "SPEARMAN",
#     "pvalue": 1.70569104408648e-06
#   },
#   {
#     "coefficient": -0.38943668009946,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.creatine-metabolism.creatine",
#     "_id_2": "METAB.None.amino-acid.glutamate-metabolism.pyroglutamine*",
#     "bh_adjusted_pvalue": 0.0023033853790729,
#     "test": "SPEARMAN",
#     "pvalue": 3.10339165693022e-05
#   },
#   {
#     "coefficient": 0.399905322953924,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.AGES.aminoadipic acid",
#     "bh_adjusted_pvalue": 0.00516408025939737,
#     "test": "SPEARMAN",
#     "pvalue": 4.9442403457688e-05
#   },
#   {
#     "coefficient": -0.403709755021657,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.adiponectin",
#     "bh_adjusted_pvalue": 0.00206007579157449,
#     "test": "SPEARMAN",
#     "pvalue": 1.47395374147464e-05
#   },
#   {
#     "coefficient": 0.478247821929563,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.body_mass_index",
#     "bh_adjusted_pvalue": 5.81646160028885e-05,
#     "test": "SPEARMAN",
#     "pvalue": 1.65260112798599e-07
#   },
#   {
#     "coefficient": 0.602658943574547,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.c_peptide",
#     "bh_adjusted_pvalue": 4.92297494919028e-09,
#     "test": "SPEARMAN",
#     "pvalue": 5.17180951136195e-12
#   },
#   {
#     "coefficient": 0.450817876094392,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.glucose",
#     "bh_adjusted_pvalue": 0.000241929697924113,
#     "test": "SPEARMAN",
#     "pvalue": 9.7758280118799e-07
#   },
#   {
#     "coefficient": 0.8206175669586,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.glutamic_acid_plasma",
#     "bh_adjusted_pvalue": 2.00927142760085e-23,
#     "test": "SPEARMAN",
#     "pvalue": 2.87840617090588e-27
#   },
#   {
#     "coefficient": -0.386037117645575,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.hdl_cholesterol",
#     "bh_adjusted_pvalue": 0.00422698610361006,
#     "test": "SPEARMAN",
#     "pvalue": 3.68707810611833e-05
#   }
# ]

# %%
# next page of bonf sig correlations
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'bh_adjusted_pvalue': .01, 'from':10, 'size':10}), indent=2)
# Out:
# [
#   {
#     "coefficient": -0.369891889650906,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.hippuric_acid",
#     "bh_adjusted_pvalue": 0.00725628805829692,
#     "test": "SPEARMAN",
#     "pvalue": 8.14856199971786e-05
#   },
#   {
#     "coefficient": 0.553218557133643,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.homa_ir",
#     "bh_adjusted_pvalue": 3.49060856537096e-07,
#     "test": "SPEARMAN",
#     "pvalue": 5.33388124498582e-10
#   },
#   {
#     "coefficient": 0.429884781705221,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.hs_crp",
#     "bh_adjusted_pvalue": 0.0006476371053654,
#     "test": "SPEARMAN",
#     "pvalue": 3.43278746486925e-06
#   },
#   {
#     "coefficient": 0.403187585338697,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.hs_crp_relative_risk",
#     "bh_adjusted_pvalue": 0.00210420197130115,
#     "test": "SPEARMAN",
#     "pvalue": 1.51557337028352e-05
#   },
#   {
#     "coefficient": 0.538916109603359,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.insulin",
#     "bh_adjusted_pvalue": 1.02059683387745e-06,
#     "test": "SPEARMAN",
#     "pvalue": 1.77884986445703e-09
#   },
#   {
#     "coefficient": -0.381960490398248,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.isovalerylglycine",
#     "bh_adjusted_pvalue": 0.00490264636416623,
#     "test": "SPEARMAN",
#     "pvalue": 4.52225416522906e-05
#   },
#   {
#     "coefficient": 0.452808978059771,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.leptin",
#     "bh_adjusted_pvalue": 0.000220570031301384,
#     "test": "SPEARMAN",
#     "pvalue": 8.63679419655395e-07
#   },
#   {
#     "coefficient": 0.450421938876665,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.proinsulin",
#     "bh_adjusted_pvalue": 0.00024586722007189,
#     "test": "SPEARMAN",
#     "pvalue": 1.00187042218249e-06
#   },
#   {
#     "coefficient": -0.754285938204118,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.ratio_plasma_gln_gln",
#     "bh_adjusted_pvalue": 1.6732993912587e-17,
#     "test": "SPEARMAN",
#     "pvalue": 6.64656820163926e-21
#   },
#   {
#     "coefficient": -0.366953423456896,
#     "description": "mean value, age and sex adjusted",
#     "study": "Hundred Person Wellness Project",
#     "_id_1": "METAB.None.amino-acid.glutamate-metabolism.glutamate",
#     "_id_2": "CHEMS.None.Genova.total_lc_omega9",
#     "bh_adjusted_pvalue": 0.00809897302884329,
#     "test": "SPEARMAN",
#     "pvalue": 9.37206566223221e-05
#   }
# ]

# %%
# hmm leptin looks interesting and I would like to learn more about it

print json.dumps(query_isb('v1/analyte/CHEMS.None.Genova.leptin'), indent=2)
# Out:
# [
#   {
#     "category": "Clinical Labs",
#     "_id": "CHEMS.None.Genova.leptin",
#     "vendor": "Genova",
#     "name": "leptin"
#   }
# ]

# %%
# in fact I would like to learn about all of the bsig genes

sigs = []

frm = 0
size=1000
res = query_isb('v1/correlation', data={'ids1':ids, 'bh_adjusted_pvalue': .01, 'from':frm, 'size':size})
correlations = res[:]
while len(res) > 0:
    print "Saving records from %i to %i" %(frm, frm+size)
    sigs += [x['_id_1'] for x in res]
    sigs += [x['_id_2'] for x in res]
    frm += size
    res =  query_isb('v1/correlation', data={'ids1':ids, 'bh_adjusted_pvalue': .01, 'from':frm, 'size':size})
    correlations += res
# Out:
# Saving records from 0 to 1000

# %%
sigs = list(set(sigs))
print len(sigs)
# Out:
# 100

# %%
sig_ids = ','.join(sigs)

frm = 0
size = 1000
meta = []
res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
meta += res
# Note: this is relying on the pagination, it would be smarter to just partition
# the *sig_ids* set which would greatly speed up the query
while len(res) > 0:
    frm += size
    print "Saving records from %i to %i" %(frm, frm+size)
    res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
    meta+=res
# Out:
# Saving records from 1000 to 2000

# %%
sig_ids = ','.join(sigs)

frm = 0
size = 1000
meta = []
res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
meta += res
# Note: this is relying on the pagination, it would be smarter to just partition
# the *sig_ids* set which would greatly speed up the query
while len(res) > 0:
    frm += size
    print "Saving records from %i to %i" %(frm, frm+size)
    res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
    meta+=res
# Out:
# Saving records from 1000 to 2000

# %%
len(meta)
# Out:
# 100

# %%
#faster less dumb way of doing the same as above
sig_list = sigs
sig_ids = ','.join(sigs)

frm = 0
size = 1000
res = []
sub_sig = sig_list[frm:frm+size]
res += query_isb('/v1/analyte', data={'ids':','.join(sub_sig), 'size':size})

while len(sub_sig) > 0:
    frm += size
    sub_sig = sig_list[frm:frm+size]
    print "Saving records from %i to %i" %(frm, frm+size)
    res += query_isb('/v1/analyte', data={'ids':','.join(sub_sig), 'size':size})
# Out:
# Saving records from 1000 to 2000

# %% [markdown]
# # Pandas 4 life

# %%
import pandas

corr_net = pandas.DataFrame(correlations)
corr_net.head()
# Out:
#                                                _id_1  \
# 0  METAB.None.amino-acid.alanine-and-aspartate-me...
# 1  METAB.None.amino-acid.alanine-and-aspartate-me...
# 2  METAB.None.amino-acid.creatine-metabolism.crea...
# 3  METAB.None.amino-acid.glutamate-metabolism.glu...
# 4  METAB.None.amino-acid.glutamate-metabolism.glu...
#
#                                                _id_2  bh_adjusted_pvalue  \
# 0  METAB.None.amino-acid.glutamate-metabolism.n-a...            0.009090
# 1  METAB.None.amino-acid.glutamate-metabolism.glu...            0.000203
# 2  METAB.None.amino-acid.glutamate-metabolism.pyr...            0.002303
# 3                   CHEMS.None.AGES.aminoadipic acid            0.005164
# 4                      CHEMS.None.Genova.adiponectin            0.002060
#
#    coefficient                       description    pvalue  \
# 0     0.353101  mean value, age and sex adjusted  0.000178
# 1     0.441712  mean value, age and sex adjusted  0.000002
# 2    -0.389437  mean value, age and sex adjusted  0.000031
# 3     0.399905  mean value, age and sex adjusted  0.000049
# 4    -0.403710  mean value, age and sex adjusted  0.000015
#
#                              study      test
# 0  Hundred Person Wellness Project  SPEARMAN
# 1  Hundred Person Wellness Project  SPEARMAN
# 2  Hundred Person Wellness Project  SPEARMAN
# 3  Hundred Person Wellness Project  SPEARMAN
# 4  Hundred Person Wellness Project  SPEARMAN

# %%
metadata = pandas.DataFrame(res)
metadata.head()
# Out:
#                                    _id abbreviation       category  \
# 0     CHEMS.None.AGES.aminoadipic acid          NaN  Clinical Labs
# 1        CHEMS.None.Genova.adiponectin          NaN  Clinical Labs
# 2  CHEMS.None.Genova.asparagine_plasma          NaN  Clinical Labs
# 3    CHEMS.None.Genova.body_mass_index          NaN  Clinical Labs
# 4          CHEMS.None.Genova.c_peptide          NaN  Clinical Labs
#
#   description       hmdb kegg measurement_technology              name  \
# 0         NaN        NaN  NaN                    NaN  aminoadipic acid
# 1         NaN        NaN  NaN                    NaN       adiponectin
# 2         NaN  HMDB00168  NaN                    NaN        asparagine
# 3         NaN        NaN  NaN                    NaN   body_mass_index
# 4         NaN        NaN  NaN                    NaN         c_peptide
#
#   peptide pubchem sub_pathway subsystem super_pathway uniprot  vendor
# 0     NaN     NaN         NaN       NaN           NaN     NaN    AGES
# 1     NaN     NaN         NaN       NaN           NaN     NaN  Genova
# 2     NaN     NaN         NaN       NaN           NaN     NaN  Genova
# 3     NaN     NaN         NaN       NaN           NaN     NaN  Genova
# 4     NaN     NaN         NaN       NaN           NaN     NaN  Genova
