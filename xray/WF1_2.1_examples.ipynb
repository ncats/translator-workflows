# %% [markdown]
# ##

# %%
#### Import some needed modules
from IPython.core.display import display, HTML
import pandas as pd
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

def execute_example(disease_id, disease_name, query_type='Q7'):
    display(HTML('<h3>{}</h3>'.format(disease_name)))

    #### Create a dict of the request, specifying the query type and its parameters
    request = { "query_type_id": query_type, "terms": { "disease": "{}".format(disease_id) } }

    #### Send the request to RTX and check the status
    response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
    if response_content.status_code != 200:
        print("Error")
        return

    #### Unpack the response content into a dict
    response_dict = response_content.json()
    if 'result_list' not in response_dict:
        print("No results found")
        return
    
    #### Display the summary table of the results
    if "table_column_names" in response_dict:
        result_frame = pd.DataFrame(
            [r['row_data'] for r in response_dict['result_list'][1:]], 
            columns = response_dict['table_column_names']
        )
    
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(result_frame)

    #### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.

# %%
execute_example("DOID:2841","Asthma")
# Out:
# <h3>Asthma</h3>
#    source name  source ID                                        target name  \
# 0       asthma  DOID:2841                             ADCYAP receptor type I
# 1       asthma  DOID:2841                                         arginase 1
# 2       asthma  DOID:2841                      poly(ADP-ribose) polymerase 1
# 3       asthma  DOID:2841                    NAD(P)H quinone dehydrogenase 1
# 4       asthma  DOID:2841                                adrenoceptor beta 2
# 5       asthma  DOID:2841                               phosphodiesterase 4D
# 6       asthma  DOID:2841      protein phosphatase 2 catalytic subunit alpha
# 7       asthma  DOID:2841      protein phosphatase 2 catalytic subunit alpha
# 8       asthma  DOID:2841                  interleukin 1 receptor antagonist
# 9       asthma  DOID:2841           MYB proto-oncogene, transcription factor
# 10      asthma  DOID:2841                     glutathione S-transferase pi 1
# 11      asthma  DOID:2841                          BCL2, apoptosis regulator
# 12      asthma  DOID:2841                   secretoglobin family 1A member 1
# 13      asthma  DOID:2841                             superoxide dismutase 1
# 14      asthma  DOID:2841                        IKAROS family zinc finger 3
# 15      asthma  DOID:2841                          neuropeptide S receptor 1
# 16      asthma  DOID:2841                                          filaggrin
# 17      asthma  DOID:2841                                   heme oxygenase 1
# 18      asthma  DOID:2841                     ribonuclease A family member 3
# 19      asthma  DOID:2841  major histocompatibility complex, class II, DR...
# 20      asthma  DOID:2841                                      interleukin 4
# 21      asthma  DOID:2841  major histocompatibility complex, class II, DQ...
# 22      asthma  DOID:2841                                     interleukin 13
# 23      asthma  DOID:2841               vascular endothelial growth factor A
# 24      asthma  DOID:2841                  intercellular adhesion molecule 1
# 25      asthma  DOID:2841                      dynein axonemal heavy chain 5
# 26      asthma  DOID:2841                   plasminogen activator, urokinase
# 27      asthma  DOID:2841                                      interleukin 5
# 28      asthma  DOID:2841                              tumor necrosis factor
# 29      asthma  DOID:2841  major histocompatibility complex, class II, DR...
# 30      asthma  DOID:2841                                         keratin 19
# 31      asthma  DOID:2841        ORMDL sphingolipid biosynthesis regulator 3
# 32      asthma  DOID:2841                                           catalase
# 33      asthma  DOID:2841                                 interleukin 1 beta
# 34      asthma  DOID:2841             aldehyde dehydrogenase 2 family member
# 35      asthma  DOID:2841                            nitric oxide synthase 2
# 36      asthma  DOID:2841                                      CD14 molecule
# 37      asthma  DOID:2841                  transforming growth factor beta 1
# 38      asthma  DOID:2841                      C-C motif chemokine ligand 11
# 39      asthma  DOID:2841                       C-C motif chemokine ligand 5
# 40      asthma  DOID:2841                     glutathione S-transferase mu 1
# 41      asthma  DOID:2841  major histocompatibility complex, class II, DQ...
# 42      asthma  DOID:2841                                           T-box 21
# 43      asthma  DOID:2841                          matrix metallopeptidase 9
# 44      asthma  DOID:2841                        arachidonate 5-lipoxygenase
# 45      asthma  DOID:2841                       C-C motif chemokine ligand 2
#
#            target ID
# 0   UniProtKB:P41586
# 1   UniProtKB:P05089
# 2   UniProtKB:P09874
# 3   UniProtKB:P15559
# 4   UniProtKB:P07550
# 5   UniProtKB:Q08499
# 6   UniProtKB:B3KUN1
# 7   UniProtKB:P67775
# 8   UniProtKB:P18510
# 9   UniProtKB:P10242
# 10  UniProtKB:P09211
# 11  UniProtKB:P10415
# 12  UniProtKB:P11684
# 13  UniProtKB:P00441
# 14  UniProtKB:Q9UKT9
# 15  UniProtKB:Q6W5P4
# 16  UniProtKB:P20930
# 17  UniProtKB:P09601
# 18  UniProtKB:P12724
# 19  UniProtKB:P01911
# 20  UniProtKB:P05112
# 21  UniProtKB:P01909
# 22  UniProtKB:P35225
# 23  UniProtKB:P15692
# 24  UniProtKB:P05362
# 25  UniProtKB:Q8TE73
# 26  UniProtKB:P00749
# 27  UniProtKB:P05113
# 28  UniProtKB:P01375
# 29  UniProtKB:P04229
# 30  UniProtKB:P08727
# 31  UniProtKB:Q8N138
# 32  UniProtKB:P04040
# 33  UniProtKB:P01584
# 34  UniProtKB:P05091
# 35  UniProtKB:P35228
# 36  UniProtKB:P08571
# 37  UniProtKB:P01137
# 38  UniProtKB:P51671
# 39  UniProtKB:P13501
# 40  UniProtKB:P09488
# 41  UniProtKB:P01920
# 42  UniProtKB:Q9UL17
# 43  UniProtKB:P14780
# 44  UniProtKB:P09917
# 45  UniProtKB:P13500

# %%
execute_example("DOID:9352","T2Diabetes")
# Out:
# <h3>T2Diabetes</h3>
#                  source name  source ID  \
# 0   type 2 diabetes mellitus  DOID:9352
# 1   type 2 diabetes mellitus  DOID:9352
# 2   type 2 diabetes mellitus  DOID:9352
# 3   type 2 diabetes mellitus  DOID:9352
# 4   type 2 diabetes mellitus  DOID:9352
# 5   type 2 diabetes mellitus  DOID:9352
# 6   type 2 diabetes mellitus  DOID:9352
# 7   type 2 diabetes mellitus  DOID:9352
# 8   type 2 diabetes mellitus  DOID:9352
# 9   type 2 diabetes mellitus  DOID:9352
# 10  type 2 diabetes mellitus  DOID:9352
# 11  type 2 diabetes mellitus  DOID:9352
# 12  type 2 diabetes mellitus  DOID:9352
# 13  type 2 diabetes mellitus  DOID:9352
# 14  type 2 diabetes mellitus  DOID:9352
# 15  type 2 diabetes mellitus  DOID:9352
# 16  type 2 diabetes mellitus  DOID:9352
# 17  type 2 diabetes mellitus  DOID:9352
# 18  type 2 diabetes mellitus  DOID:9352
# 19  type 2 diabetes mellitus  DOID:9352
# 20  type 2 diabetes mellitus  DOID:9352
# 21  type 2 diabetes mellitus  DOID:9352
# 22  type 2 diabetes mellitus  DOID:9352
# 23  type 2 diabetes mellitus  DOID:9352
# 24  type 2 diabetes mellitus  DOID:9352
# 25  type 2 diabetes mellitus  DOID:9352
# 26  type 2 diabetes mellitus  DOID:9352
# 27  type 2 diabetes mellitus  DOID:9352
# 28  type 2 diabetes mellitus  DOID:9352
# 29  type 2 diabetes mellitus  DOID:9352
# 30  type 2 diabetes mellitus  DOID:9352
# 31  type 2 diabetes mellitus  DOID:9352
# 32  type 2 diabetes mellitus  DOID:9352
# 33  type 2 diabetes mellitus  DOID:9352
# 34  type 2 diabetes mellitus  DOID:9352
# 35  type 2 diabetes mellitus  DOID:9352
# 36  type 2 diabetes mellitus  DOID:9352
# 37  type 2 diabetes mellitus  DOID:9352
# 38  type 2 diabetes mellitus  DOID:9352
# 39  type 2 diabetes mellitus  DOID:9352
# 40  type 2 diabetes mellitus  DOID:9352
# 41  type 2 diabetes mellitus  DOID:9352
# 42  type 2 diabetes mellitus  DOID:9352
# 43  type 2 diabetes mellitus  DOID:9352
# 44  type 2 diabetes mellitus  DOID:9352
# 45  type 2 diabetes mellitus  DOID:9352
# 46  type 2 diabetes mellitus  DOID:9352
# 47  type 2 diabetes mellitus  DOID:9352
# 48  type 2 diabetes mellitus  DOID:9352
# 49  type 2 diabetes mellitus  DOID:9352
# 50  type 2 diabetes mellitus  DOID:9352
# 51  type 2 diabetes mellitus  DOID:9352
# 52  type 2 diabetes mellitus  DOID:9352
# 53  type 2 diabetes mellitus  DOID:9352
#
#                                           target name             target ID
# 0                                 prospero homeobox 1      UniProtKB:Q92786
# 1                    nuclear factor kappa B subunit 1      UniProtKB:P19838
# 2   ATPase sarcoplasmic/endoplasmic reticulum Ca2+...      UniProtKB:P16615
# 3                              superoxide dismutase 1      UniProtKB:P00441
# 4                  RELA proto-oncogene, NF-kB subunit  UniProtKB:A0A087WVP0
# 5                   TIMP metallopeptidase inhibitor 1      UniProtKB:P01033
# 6                   hepatocyte nuclear factor 4 alpha      UniProtKB:P41235
# 7                                     HNF1 homeobox A      UniProtKB:P20823
# 8                      glutathione S-transferase mu 1      UniProtKB:P09488
# 9                                            glucagon      UniProtKB:P01275
# 10                            nitric oxide synthase 2      UniProtKB:P35228
# 11                                    HNF1 homeobox B      UniProtKB:P35680
# 12                          BCL2, apoptosis regulator      UniProtKB:P10415
# 13                            nitric oxide synthase 3      UniProtKB:P29474
# 14                 RELA proto-oncogene, NF-kB subunit      UniProtKB:Q04206
# 15                                            insulin      UniProtKB:P01308
# 16                                   insulin receptor      UniProtKB:P06213
# 17                  carnitine palmitoyltransferase 1A      UniProtKB:P50416
# 18                secreted frizzled related protein 4      UniProtKB:Q6FHJ7
# 19                                          cyclin D2      UniProtKB:P30279
# 20                                          caspase 8      UniProtKB:Q14790
# 21                       8-oxoguanine DNA glycosylase      UniProtKB:O15527
# 22                              glucokinase regulator      UniProtKB:Q14397
# 23                          PPARG coactivator 1 alpha      UniProtKB:Q9UBK2
# 24                                        haptoglobin      UniProtKB:P00738
# 25  mitogen-activated protein kinase 8 interacting...      UniProtKB:Q9UQF2
# 26                  intercellular adhesion molecule 1      UniProtKB:P05362
# 27                  activating transcription factor 3      UniProtKB:P18847
# 28                  transforming growth factor beta 1      UniProtKB:P01137
# 29                   solute carrier family 2 member 4      UniProtKB:P14672
# 30                                        glucokinase      UniProtKB:P35557
# 31                                          sirtuin 1      UniProtKB:Q96EB6
# 32            growth factor receptor bound protein 14      UniProtKB:Q14449
# 33                         neuronal differentiation 1      UniProtKB:Q13562
# 34                           G protein subunit beta 3      UniProtKB:P16520
# 35                 pancreatic and duodenal homeobox 1      UniProtKB:P52945
# 36                            high mobility group 20A      UniProtKB:Q9NP66
# 37                 TNF receptor superfamily member 1B      UniProtKB:P20333
# 38                       insulin receptor substrate 1      UniProtKB:P35568
# 39          ATP binding cassette subfamily C member 8      UniProtKB:Q09428
# 40                             Kruppel like factor 11      UniProtKB:O14901
# 41                   epidermal growth factor receptor      UniProtKB:P00533
# 42                    Fas cell surface death receptor      UniProtKB:P25445
# 43                                       paired box 4      UniProtKB:O43316
# 44                      AKT serine/threonine kinase 2      UniProtKB:P31751
# 45        protein phosphatase 1 regulatory subunit 3A      UniProtKB:Q16821
# 46                      transcription factor 7 like 2      UniProtKB:Q9NQB0
# 47                 TNF receptor superfamily member 1A      UniProtKB:P19438
# 48      cytochrome P450 family 1 subfamily A member 2      UniProtKB:P05177
# 49  CDK5 regulatory subunit associated protein 1 l...      UniProtKB:Q5VV42
# 50                              tumor necrosis factor      UniProtKB:P01375
# 51                  synaptosome associated protein 25      UniProtKB:P60880
# 52  potassium voltage-gated channel subfamily J me...      UniProtKB:Q14654
# 53                                        BCL2 like 1      UniProtKB:Q07817

# %%
execute_example("DOID:14330","Parkinson")
# Out:
# <h3>Parkinson</h3>
#             source name   source ID  \
# 0   Parkinson's disease  DOID:14330
# 1   Parkinson's disease  DOID:14330
# 2   Parkinson's disease  DOID:14330
# 3   Parkinson's disease  DOID:14330
# 4   Parkinson's disease  DOID:14330
# 5   Parkinson's disease  DOID:14330
# 6   Parkinson's disease  DOID:14330
# 7   Parkinson's disease  DOID:14330
# 8   Parkinson's disease  DOID:14330
# 9   Parkinson's disease  DOID:14330
# 10  Parkinson's disease  DOID:14330
# 11  Parkinson's disease  DOID:14330
# 12  Parkinson's disease  DOID:14330
# 13  Parkinson's disease  DOID:14330
# 14  Parkinson's disease  DOID:14330
# 15  Parkinson's disease  DOID:14330
# 16  Parkinson's disease  DOID:14330
# 17  Parkinson's disease  DOID:14330
# 18  Parkinson's disease  DOID:14330
# 19  Parkinson's disease  DOID:14330
# 20  Parkinson's disease  DOID:14330
# 21  Parkinson's disease  DOID:14330
# 22  Parkinson's disease  DOID:14330
# 23  Parkinson's disease  DOID:14330
# 24  Parkinson's disease  DOID:14330
# 25  Parkinson's disease  DOID:14330
# 26  Parkinson's disease  DOID:14330
# 27  Parkinson's disease  DOID:14330
# 28  Parkinson's disease  DOID:14330
# 29  Parkinson's disease  DOID:14330
# 30  Parkinson's disease  DOID:14330
# 31  Parkinson's disease  DOID:14330
# 32  Parkinson's disease  DOID:14330
# 33  Parkinson's disease  DOID:14330
# 34  Parkinson's disease  DOID:14330
# 35  Parkinson's disease  DOID:14330
# 36  Parkinson's disease  DOID:14330
# 37  Parkinson's disease  DOID:14330
#
#                                           target name         target ID
# 0                  microtubule associated protein tau  UniProtKB:P10636
# 1              parkin RBR E3 ubiquitin protein ligase  UniProtKB:O60260
# 2                               ribosomal protein L14  UniProtKB:P50914
# 3                                             insulin  UniProtKB:P01308
# 4       cytochrome P450 family 2 subfamily D member 6  UniProtKB:P10635
# 5               insulin like growth factor 2 receptor  UniProtKB:P11717
# 6                             glucosylceramidase beta  UniProtKB:P04062
# 7                   brain derived neurotrophic factor  UniProtKB:P23560
# 8                    solute carrier family 6 member 3  UniProtKB:Q01959
# 9                                ribosomal protein S8  UniProtKB:P62241
# 10                            metastasis associated 1  UniProtKB:Q13330
# 11                     glutathione S-transferase mu 1  UniProtKB:P09488
# 12                                   insulin receptor  UniProtKB:P06213
# 13          ATP binding cassette subfamily B member 1  UniProtKB:P08183
# 14                     glutathione S-transferase pi 1  UniProtKB:P09211
# 15                            metastasis associated 1  UniProtKB:Q9BRL8
# 16                                    synuclein alpha  UniProtKB:P37840
# 17                               dopamine receptor D1  UniProtKB:P21728
# 18   mitogen-activated protein kinase kinase kinase 5  UniProtKB:Q99683
# 19                                monoamine oxidase B  UniProtKB:P27338
# 20      cytochrome P450 family 2 subfamily E member 1  UniProtKB:P05181
# 21                  glutathione S-transferase alpha 4  UniProtKB:O15217
# 22                     PTEN induced putative kinase 1  UniProtKB:Q9BXM7
# 23                              tumor necrosis factor  UniProtKB:P01375
# 24                                      interleukin 6  UniProtKB:P05231
# 25                                monoamine oxidase A  UniProtKB:P21397
# 26                    NAD(P)H quinone dehydrogenase 1  UniProtKB:P15559
# 27                  Parkinsonism associated deglycase  UniProtKB:Q99497
# 28                               dopamine receptor D2  UniProtKB:P14416
# 29                    ATPase cation transporting 13A2  UniProtKB:Q9NQ11
# 30                       insulin like growth factor 2  UniProtKB:P01344
# 31  major histocompatibility complex, class II, DR...  UniProtKB:P01903
# 32                                   heme oxygenase 1  UniProtKB:P09601
# 33                                            insulin  UniProtKB:I3WAC9
# 34       heat shock protein family A (Hsp70) member 9  UniProtKB:P38646
# 35                              fibrinogen beta chain  UniProtKB:P02675
# 36                               ribosomal protein L6  UniProtKB:Q02878
# 37                       leucine rich repeat kinase 2  UniProtKB:Q5S007

# %%
execute_example("DOID:1936","atherosclerosis")
# Out:
# <h3>atherosclerosis</h3>
#         source name  source ID  \
# 0   atherosclerosis  DOID:1936
# 1   atherosclerosis  DOID:1936
# 2   atherosclerosis  DOID:1936
# 3   atherosclerosis  DOID:1936
# 4   atherosclerosis  DOID:1936
# 5   atherosclerosis  DOID:1936
# 6   atherosclerosis  DOID:1936
# 7   atherosclerosis  DOID:1936
# 8   atherosclerosis  DOID:1936
# 9   atherosclerosis  DOID:1936
# 10  atherosclerosis  DOID:1936
# 11  atherosclerosis  DOID:1936
# 12  atherosclerosis  DOID:1936
# 13  atherosclerosis  DOID:1936
# 14  atherosclerosis  DOID:1936
# 15  atherosclerosis  DOID:1936
# 16  atherosclerosis  DOID:1936
# 17  atherosclerosis  DOID:1936
# 18  atherosclerosis  DOID:1936
# 19  atherosclerosis  DOID:1936
# 20  atherosclerosis  DOID:1936
# 21  atherosclerosis  DOID:1936
# 22  atherosclerosis  DOID:1936
# 23  atherosclerosis  DOID:1936
# 24  atherosclerosis  DOID:1936
# 25  atherosclerosis  DOID:1936
# 26  atherosclerosis  DOID:1936
# 27  atherosclerosis  DOID:1936
# 28  atherosclerosis  DOID:1936
# 29  atherosclerosis  DOID:1936
# 30  atherosclerosis  DOID:1936
# 31  atherosclerosis  DOID:1936
# 32  atherosclerosis  DOID:1936
# 33  atherosclerosis  DOID:1936
# 34  atherosclerosis  DOID:1936
# 35  atherosclerosis  DOID:1936
# 36  atherosclerosis  DOID:1936
#
#                                           target name         target ID
# 0                                      lipoprotein(a)  UniProtKB:P08519
# 1                vascular endothelial growth factor A  UniProtKB:P15692
# 2           ATP binding cassette subfamily A member 1  UniProtKB:O95477
# 3                                    interferon gamma  UniProtKB:P01579
# 4    peroxisome proliferator activated receptor gamma  UniProtKB:P37231
# 5                             nitric oxide synthase 3  UniProtKB:P29474
# 6                        C-C motif chemokine ligand 3  UniProtKB:P10147
# 7                            serpin family E member 1  UniProtKB:P05121
# 8                        C-C motif chemokine ligand 2  UniProtKB:P13500
# 9                           matrix metallopeptidase 1  UniProtKB:P03956
# 10                  intercellular adhesion molecule 1  UniProtKB:P05362
# 11                       arachidonate 15-lipoxygenase  UniProtKB:P16050
# 12                                         Fas ligand  UniProtKB:P48023
# 13    adiponectin, C1Q and collagen domain containing  UniProtKB:Q15848
# 14                              tumor necrosis factor  UniProtKB:P01375
# 15                                        haptoglobin  UniProtKB:P00738
# 16                                    angiotensinogen  UniProtKB:P01019
# 17              prostaglandin-endoperoxide synthase 2  UniProtKB:P35354
# 18                                estrogen receptor 1  UniProtKB:P03372
# 19                             superoxide dismutase 1  UniProtKB:P00441
# 20                                         Fas ligand  UniProtKB:Q53ZZ1
# 21                       cytochrome b-245 alpha chain  UniProtKB:P13498
# 22                   low density lipoprotein receptor  UniProtKB:P01130
# 23                                      interleukin 6  UniProtKB:P05231
# 24  signal transducer and activator of transcripti...  UniProtKB:P40763
# 25                                          sirtuin 1  UniProtKB:Q96EB6
# 26  transient receptor potential cation channel su...  UniProtKB:Q8NER1
# 27                                   apolipoprotein E  UniProtKB:P02649
# 28  advanced glycosylation end-product specific re...  UniProtKB:Q15109
# 29                        arachidonate 5-lipoxygenase  UniProtKB:P09917
# 30                      poly(ADP-ribose) polymerase 1  UniProtKB:P09874
# 31                               toll like receptor 4  UniProtKB:O00206
# 32                     glutathione S-transferase mu 1  UniProtKB:P09488
# 33                       insulin like growth factor 2  UniProtKB:P01344
# 34                                 C-reactive protein  UniProtKB:P02741
# 35                                      paraoxonase 1  UniProtKB:P27169
# 36                  vascular cell adhesion molecule 1  UniProtKB:P19320

# %%
execute_example("DOID:10652","Alzheimers")
# Out:
# <h3>Alzheimers</h3>
#             source name   source ID  \
# 0   Alzheimer's disease  DOID:10652
# 1   Alzheimer's disease  DOID:10652
# 2   Alzheimer's disease  DOID:10652
# 3   Alzheimer's disease  DOID:10652
# 4   Alzheimer's disease  DOID:10652
# 5   Alzheimer's disease  DOID:10652
# 6   Alzheimer's disease  DOID:10652
# 7   Alzheimer's disease  DOID:10652
# 8   Alzheimer's disease  DOID:10652
# 9   Alzheimer's disease  DOID:10652
# 10  Alzheimer's disease  DOID:10652
# 11  Alzheimer's disease  DOID:10652
# 12  Alzheimer's disease  DOID:10652
# 13  Alzheimer's disease  DOID:10652
# 14  Alzheimer's disease  DOID:10652
# 15  Alzheimer's disease  DOID:10652
# 16  Alzheimer's disease  DOID:10652
# 17  Alzheimer's disease  DOID:10652
# 18  Alzheimer's disease  DOID:10652
# 19  Alzheimer's disease  DOID:10652
# 20  Alzheimer's disease  DOID:10652
# 21  Alzheimer's disease  DOID:10652
# 22  Alzheimer's disease  DOID:10652
# 23  Alzheimer's disease  DOID:10652
# 24  Alzheimer's disease  DOID:10652
# 25  Alzheimer's disease  DOID:10652
# 26  Alzheimer's disease  DOID:10652
# 27  Alzheimer's disease  DOID:10652
# 28  Alzheimer's disease  DOID:10652
# 29  Alzheimer's disease  DOID:10652
# 30  Alzheimer's disease  DOID:10652
# 31  Alzheimer's disease  DOID:10652
# 32  Alzheimer's disease  DOID:10652
# 33  Alzheimer's disease  DOID:10652
# 34  Alzheimer's disease  DOID:10652
# 35  Alzheimer's disease  DOID:10652
# 36  Alzheimer's disease  DOID:10652
# 37  Alzheimer's disease  DOID:10652
# 38  Alzheimer's disease  DOID:10652
# 39  Alzheimer's disease  DOID:10652
# 40  Alzheimer's disease  DOID:10652
# 41  Alzheimer's disease  DOID:10652
# 42  Alzheimer's disease  DOID:10652
#
#                                           target name         target ID
# 0                               tumor necrosis factor  UniProtKB:P01375
# 1                                    beta-secretase 1  UniProtKB:P56817
# 2                        insulin like growth factor 2  UniProtKB:P01344
# 3               insulin like growth factor 1 receptor  UniProtKB:P08069
# 4                               butyrylcholinesterase  UniProtKB:P06276
# 5              BCL2 associated X, apoptosis regulator  UniProtKB:Q07812
# 6                                  interleukin 1 beta  UniProtKB:P01584
# 7                         sortilin related receptor 1  UniProtKB:Q92673
# 8                     angiotensin I converting enzyme  UniProtKB:P12821
# 9                                              reelin  UniProtKB:P78509
# 10  complement C3b/C4b receptor 1 (Knops blood group)  UniProtKB:P17927
# 11              insulin like growth factor 2 receptor  UniProtKB:P11717
# 12                                          enolase 1  UniProtKB:P06733
# 13                                       presenilin 1  UniProtKB:P49768
# 14                                        transferrin  UniProtKB:P02787
# 15                methylenetetrahydrofolate reductase  UniProtKB:P42898
# 16               vascular endothelial growth factor A  UniProtKB:P15692
# 17                                      prion protein  UniProtKB:P04156
# 18                       insulin like growth factor 1  UniProtKB:P05019
# 19                    coagulation factor II, thrombin  UniProtKB:P00734
# 20                  brain derived neurotrophic factor  UniProtKB:P23560
# 21                           insulin degrading enzyme  UniProtKB:P14735
# 22      cytochrome P450 family 2 subfamily D member 6  UniProtKB:P10635
# 23                                estrogen receptor 1  UniProtKB:P03372
# 24                                            insulin  UniProtKB:P01308
# 25                                   insulin receptor  UniProtKB:P06213
# 26   peroxisome proliferator activated receptor gamma  UniProtKB:P37231
# 27                   plasminogen activator, urokinase  UniProtKB:P00749
# 28                                      prion protein  UniProtKB:F7VJQ1
# 29                                          clusterin  UniProtKB:P10909
# 30                                          nicastrin  UniProtKB:Q92542
# 31                          BCL2, apoptosis regulator  UniProtKB:P10415
# 32                     amyloid beta precursor protein  UniProtKB:P05067
# 33                                monoamine oxidase B  UniProtKB:P27338
# 34                 microtubule associated protein tau  UniProtKB:P10636
# 35                                       presenilin 2  UniProtKB:P49810
# 36                      ATP synthase F1 subunit alpha  UniProtKB:P25705
# 37                                   heme oxygenase 1  UniProtKB:P09601
# 38                                   apolipoprotein E  UniProtKB:P02649
# 39                   solute carrier family 2 member 4  UniProtKB:P14672
# 40                                             leptin  UniProtKB:P41159
# 41                                     neuropeptide Y  UniProtKB:P01303
# 42                                            insulin  UniProtKB:I3WAC9

# %%
execute_example("DOID:0050427","XP")
# Out:
# <h3>XP</h3>
#               source name     source ID  \
# 0   xeroderma pigmentosum  DOID:0050427
# 1   xeroderma pigmentosum  DOID:0050427
# 2   xeroderma pigmentosum  DOID:0050427
# 3   xeroderma pigmentosum  DOID:0050427
# 4   xeroderma pigmentosum  DOID:0050427
# 5   xeroderma pigmentosum  DOID:0050427
# 6   xeroderma pigmentosum  DOID:0050427
# 7   xeroderma pigmentosum  DOID:0050427
# 8   xeroderma pigmentosum  DOID:0050427
# 9   xeroderma pigmentosum  DOID:0050427
# 10  xeroderma pigmentosum  DOID:0050427
# 11  xeroderma pigmentosum  DOID:0050427
# 12  xeroderma pigmentosum  DOID:0050427
# 13  xeroderma pigmentosum  DOID:0050427
# 14  xeroderma pigmentosum  DOID:0050427
# 15  xeroderma pigmentosum  DOID:0050427
# 16  xeroderma pigmentosum  DOID:0050427
# 17  xeroderma pigmentosum  DOID:0050427
# 18  xeroderma pigmentosum  DOID:0050427
#
#                                           target name         target ID
# 0          general transcription factor IIH subunit 5  UniProtKB:Q6ZYL4
# 1                ERCC excision repair 5, endonuclease  UniProtKB:P28715
# 2          general transcription factor IIH subunit 1  UniProtKB:P32780
# 3                                  DNA polymerase eta  UniProtKB:Q9Y253
# 4   XPC complex subunit, DNA damage recognition an...  UniProtKB:Q01831
# 5   RAD23 homolog A, nucleotide excision repair pr...  UniProtKB:P54725
# 6               damage specific DNA binding protein 2  UniProtKB:Q92466
# 7   ERCC excision repair 3, TFIIH core complex hel...  UniProtKB:P19447
# 8                                   tumor protein p53  UniProtKB:P04637
# 9       XPA, DNA damage recognition and repair factor  UniProtKB:P23025
# 10         general transcription factor IIH subunit 4  UniProtKB:Q92759
# 11         general transcription factor IIH subunit 2  UniProtKB:Q13888
# 12                               DNA polymerase theta  UniProtKB:O75417
# 13      nuclear receptor subfamily 1 group H member 2  UniProtKB:P55055
# 14                                          centrin 2  UniProtKB:P41208
# 15                 X-ray repair cross complementing 1  UniProtKB:P18887
# 16  ERCC excision repair 4, endonuclease catalytic...  UniProtKB:Q92889
# 17  ERCC excision repair 2, TFIIH core complex hel...  UniProtKB:P18074
# 18                smoothened, frizzled class receptor  UniProtKB:Q99835

# %%
execute_example("DOID:13636","FA")
# Out:
# <h3>FA</h3>
#        source name   source ID  \
# 0   Fanconi anemia  DOID:13636
# 1   Fanconi anemia  DOID:13636
# 2   Fanconi anemia  DOID:13636
# 3   Fanconi anemia  DOID:13636
# 4   Fanconi anemia  DOID:13636
# 5   Fanconi anemia  DOID:13636
# 6   Fanconi anemia  DOID:13636
# 7   Fanconi anemia  DOID:13636
# 8   Fanconi anemia  DOID:13636
# 9   Fanconi anemia  DOID:13636
# 10  Fanconi anemia  DOID:13636
# 11  Fanconi anemia  DOID:13636
# 12  Fanconi anemia  DOID:13636
# 13  Fanconi anemia  DOID:13636
# 14  Fanconi anemia  DOID:13636
# 15  Fanconi anemia  DOID:13636
# 16  Fanconi anemia  DOID:13636
# 17  Fanconi anemia  DOID:13636
# 18  Fanconi anemia  DOID:13636
#
#                                           target name         target ID
# 0                          FA complementation group I  UniProtKB:Q9NVI1
# 1                          FA complementation group B  UniProtKB:Q8NB91
# 2                      partner and localizer of BRCA2  UniProtKB:Q86YC2
# 3                          FA complementation group M  UniProtKB:Q8IYD8
# 4                                     RAD51 paralog C  UniProtKB:O43502
# 5                  X-ray repair cross complementing 2  UniProtKB:O43543
# 6                               tumor necrosis factor  UniProtKB:P01375
# 7                          FA complementation group G  UniProtKB:O15287
# 8                          FA complementation group L  UniProtKB:Q9NW38
# 9                          FA complementation group A  UniProtKB:O15360
# 10  ERCC excision repair 4, endonuclease catalytic...  UniProtKB:Q92889
# 11                                  RAD51 recombinase  UniProtKB:Q06609
# 12                       BRCA2, DNA repair associated  UniProtKB:P51587
# 13                         FA complementation group C  UniProtKB:Q00597
# 14                        FA complementation group D2  UniProtKB:Q9BXW9
# 15    BRCA1 interacting protein C-terminal helicase 1  UniProtKB:Q9BX63
# 16                         FA complementation group F  UniProtKB:Q9NPI8
# 17                         FA complementation group E  UniProtKB:Q9HB96
# 18                  ubiquitin conjugating enzyme E2 T  UniProtKB:Q9NPD8

# %%
execute_example("DOID:3302","Chordoma")
# Out:
# <h3>Chordoma</h3>
#    source name  source ID                                        target name  \
# 0     chordoma  DOID:3302                                      CD24 molecule
# 1     chordoma  DOID:3302                     phosphatase and tensin homolog
# 2     chordoma  DOID:3302                              TSC complex subunit 2
# 3     chordoma  DOID:3302                              TSC complex subunit 1
# 4     chordoma  DOID:3302  phosphatidylinositol-4,5-bisphosphate 3-kinase...
# 5     chordoma  DOID:3302  phosphatidylinositol-4,5-bisphosphate 3-kinase...
# 6     chordoma  DOID:3302       MET proto-oncogene, receptor tyrosine kinase
# 7     chordoma  DOID:3302  phosphatidylinositol-4,5-bisphosphate 3-kinase...
# 8     chordoma  DOID:3302                          matrix metallopeptidase 1
# 9     chordoma  DOID:3302                      AKT serine/threonine kinase 1
# 10    chordoma  DOID:3302                                            T-box 1
# 11    chordoma  DOID:3302                   plasminogen activator, urokinase
# 12    chordoma  DOID:3302                                  tumor protein p53
# 13    chordoma  DOID:3302                   epidermal growth factor receptor
# 14    chordoma  DOID:3302                                  androgen receptor
# 15    chordoma  DOID:3302  phosphatidylinositol-4,5-bisphosphate 3-kinase...
# 16    chordoma  DOID:3302                      marker of proliferation Ki-67
#
#            target ID
# 0   UniProtKB:P25063
# 1   UniProtKB:P60484
# 2   UniProtKB:P49815
# 3   UniProtKB:Q92574
# 4   UniProtKB:P48736
# 5   UniProtKB:O00329
# 6   UniProtKB:P08581
# 7   UniProtKB:P42336
# 8   UniProtKB:P03956
# 9   UniProtKB:P31749
# 10  UniProtKB:O43435
# 11  UniProtKB:P00749
# 12  UniProtKB:P04637
# 13  UniProtKB:P00533
# 14  UniProtKB:P10275
# 15  UniProtKB:P42338
# 16  UniProtKB:P46013

# %%
execute_example("DOID:0050946","ARSACS")
# Out:
# <h3>ARSACS</h3>
# No results found

# %%
execute_example("DOID:0110858","PKD")
# Out:
# <h3>PKD</h3>
#                     source name     source ID  \
# 0   polycystic kidney disease 1  DOID:0110858
# 1   polycystic kidney disease 1  DOID:0110858
# 2   polycystic kidney disease 1  DOID:0110858
# 3   polycystic kidney disease 1  DOID:0110858
# 4   polycystic kidney disease 1  DOID:0110858
# 5   polycystic kidney disease 1  DOID:0110858
# 6   polycystic kidney disease 1  DOID:0110858
# 7   polycystic kidney disease 1  DOID:0110858
# 8   polycystic kidney disease 1  DOID:0110858
# 9   polycystic kidney disease 1  DOID:0110858
# 10  polycystic kidney disease 1  DOID:0110858
# 11  polycystic kidney disease 1  DOID:0110858
# 12  polycystic kidney disease 1  DOID:0110858
# 13  polycystic kidney disease 1  DOID:0110858
# 14  polycystic kidney disease 1  DOID:0110858
# 15  polycystic kidney disease 1  DOID:0110858
#
#                                           target name         target ID
# 0   polycystin 2, transient receptor potential cat...  UniProtKB:Q13563
# 1   polycystin 1, transient receptor potential cha...  UniProtKB:P98161
# 2      SEC63 homolog, protein translocation regulator  UniProtKB:Q9UGP8
# 3        autosomal dominant polycystic kidney disease          DOID:898
# 4                             Meckel syndrome, type 1  UniProtKB:Q9NXB0
# 5                    protein kinase C substrate 80K-H  UniProtKB:P14314
# 6   EYA transcriptional coactivator and phosphatase 1  UniProtKB:Q99502
# 7                    carnitine palmitoyltransferase 2  UniProtKB:P23786
# 8                             zinc finger protein 423  UniProtKB:Q2M1K9
# 9                               NIMA related kinase 1  UniProtKB:Q96PY6
# 10       electron transfer flavoprotein subunit alpha  UniProtKB:P13804
# 11                       glucosidase II alpha subunit  UniProtKB:Q14697
# 12                                     nephrocystin 3  UniProtKB:Q7Z494
# 13       electron transfer flavoprotein dehydrogenase  UniProtKB:Q16134
# 14                      PKHD1, fibrocystin/polyductin  UniProtKB:P08F94
# 15        electron transfer flavoprotein subunit beta  UniProtKB:P38117

# %%
execute_example("DOID:9562","PCD")
# Out:
# <h3>PCD</h3>
#                    source name  source ID  \
# 0   primary ciliary dyskinesia  DOID:9562
# 1   primary ciliary dyskinesia  DOID:9562
# 2   primary ciliary dyskinesia  DOID:9562
# 3   primary ciliary dyskinesia  DOID:9562
# 4   primary ciliary dyskinesia  DOID:9562
# 5   primary ciliary dyskinesia  DOID:9562
# 6   primary ciliary dyskinesia  DOID:9562
# 7   primary ciliary dyskinesia  DOID:9562
# 8   primary ciliary dyskinesia  DOID:9562
# 9   primary ciliary dyskinesia  DOID:9562
# 10  primary ciliary dyskinesia  DOID:9562
# 11  primary ciliary dyskinesia  DOID:9562
# 12  primary ciliary dyskinesia  DOID:9562
# 13  primary ciliary dyskinesia  DOID:9562
# 14  primary ciliary dyskinesia  DOID:9562
# 15  primary ciliary dyskinesia  DOID:9562
# 16  primary ciliary dyskinesia  DOID:9562
# 17  primary ciliary dyskinesia  DOID:9562
# 18  primary ciliary dyskinesia  DOID:9562
# 19  primary ciliary dyskinesia  DOID:9562
# 20  primary ciliary dyskinesia  DOID:9562
# 21  primary ciliary dyskinesia  DOID:9562
#
#                                        target name         target ID
# 0                    radial spoke head component 1  UniProtKB:Q8WYR4
# 1                                         cyclin O  UniProtKB:P22674
# 2                 coiled-coil domain containing 39  UniProtKB:Q9UFE4
# 3              dynein regulatory complex subunit 1  UniProtKB:Q96MC2
# 4        cilia and flagella associated protein 298  UniProtKB:P57076
# 5              zinc finger MYND-type containing 10  UniProtKB:O75800
# 6                       sperm associated antigen 1  UniProtKB:Q07617
# 7                      radial spoke head 9 homolog  UniProtKB:Q9H1X1
# 8             dynein axonemal intermediate chain 1  UniProtKB:Q9UI46
# 9                   dynein axonemal heavy chain 11  UniProtKB:Q96DT5
# 10                   dynein axonemal heavy chain 5  UniProtKB:Q8TE73
# 11               coiled-coil domain containing 151  UniProtKB:A5D8V7
# 12                  radial spoke head component 4A  UniProtKB:Q5TD94
# 13               dynein axonemal assembly factor 3  UniProtKB:Q8N9W5
# 14  HYDIN, axonemal central pair apparatus protein  UniProtKB:Q4G0P3
# 15                leucine rich repeat containing 6  UniProtKB:Q86X45
# 16                coiled-coil domain containing 40  UniProtKB:Q4G0X9
# 17                   dynein axonemal light chain 1  UniProtKB:Q4LDG9
# 18               dynein axonemal assembly factor 1  UniProtKB:Q8NEP3
# 19                        NME/NM23 family member 8  UniProtKB:Q8N427
# 20                   armadillo repeat containing 4  UniProtKB:Q5T2S8
# 21               dynein axonemal assembly factor 2  UniProtKB:Q9NVR5

# %%
execute_example("DOID:0050524","MODY")
# Out:
# <h3>MODY</h3>
#                              source name     source ID  \
# 0   maturity-onset diabetes of the young  DOID:0050524
# 1   maturity-onset diabetes of the young  DOID:0050524
# 2   maturity-onset diabetes of the young  DOID:0050524
# 3   maturity-onset diabetes of the young  DOID:0050524
# 4   maturity-onset diabetes of the young  DOID:0050524
# 5   maturity-onset diabetes of the young  DOID:0050524
# 6   maturity-onset diabetes of the young  DOID:0050524
# 7   maturity-onset diabetes of the young  DOID:0050524
# 8   maturity-onset diabetes of the young  DOID:0050524
# 9   maturity-onset diabetes of the young  DOID:0050524
# 10  maturity-onset diabetes of the young  DOID:0050524
#
#                                           target name         target ID
# 0                   hepatocyte nuclear factor 4 alpha  UniProtKB:P41235
# 1                               carboxyl ester lipase  UniProtKB:P19835
# 2   potassium voltage-gated channel subfamily J me...  UniProtKB:Q14654
# 3                              Kruppel like factor 11  UniProtKB:O14901
# 4           ATP binding cassette subfamily C member 8  UniProtKB:Q09428
# 5                  pancreatic and duodenal homeobox 1  UniProtKB:P52945
# 6                                         glucokinase  UniProtKB:P35557
# 7                                             insulin  UniProtKB:I3WAC9
# 8                                        paired box 4  UniProtKB:O43316
# 9                                     HNF1 homeobox A  UniProtKB:P20823
# 10                                            insulin  UniProtKB:P01308

# %%
execute_example("DOID:3087","gingivitis")
# Out:
# <h3>gingivitis</h3>
#    source name  source ID                                        target name  \
# 0   gingivitis  DOID:3087                                     interleukin 10
# 1   gingivitis  DOID:3087                                        plasminogen
# 2   gingivitis  DOID:3087                    lysosomal trafficking regulator
# 3   gingivitis  DOID:3087                           fermitin family member 1
# 4   gingivitis  DOID:3087                               toll like receptor 2
# 5   gingivitis  DOID:3087                              tumor necrosis factor
# 6   gingivitis  DOID:3087                                 interleukin 1 beta
# 7   gingivitis  DOID:3087                                    interleukin 17A
# 8   gingivitis  DOID:3087                                      interleukin 6
# 9   gingivitis  DOID:3087                   beta-1,4-galactosyltransferase 7
# 10  gingivitis  DOID:3087                                         keratin 6A
# 11  gingivitis  DOID:3087                                        CD40 ligand
# 12  gingivitis  DOID:3087                            integrin subunit beta 2
# 13  gingivitis  DOID:3087                                        cathepsin C
# 14  gingivitis  DOID:3087                                     interleukin 11
# 15  gingivitis  DOID:3087            sterile alpha motif domain containing 9
# 16  gingivitis  DOID:3087  signal transducer and activator of transcripti...
# 17  gingivitis  DOID:3087                  interleukin 1 receptor antagonist
# 18  gingivitis  DOID:3087  ALMS1, centrosome and basal body associated pr...
#
#            target ID
# 0   UniProtKB:P22301
# 1   UniProtKB:P00747
# 2   UniProtKB:Q99698
# 3   UniProtKB:Q9BQL6
# 4   UniProtKB:O60603
# 5   UniProtKB:P01375
# 6   UniProtKB:P01584
# 7   UniProtKB:Q16552
# 8   UniProtKB:P05231
# 9   UniProtKB:Q9UBV7
# 10  UniProtKB:P02538
# 11  UniProtKB:P29965
# 12  UniProtKB:P05107
# 13  UniProtKB:P53634
# 14  UniProtKB:P20809
# 15  UniProtKB:Q5K651
# 16  UniProtKB:P40763
# 17  UniProtKB:P18510
# 18  UniProtKB:Q8TCU4

# %%
execute_example("DOID:8566","HSV")
# Out:
# <h3>HSV</h3>
#        source name  source ID  \
# 0   herpes simplex  DOID:8566
# 1   herpes simplex  DOID:8566
# 2   herpes simplex  DOID:8566
# 3   herpes simplex  DOID:8566
# 4   herpes simplex  DOID:8566
# 5   herpes simplex  DOID:8566
# 6   herpes simplex  DOID:8566
# 7   herpes simplex  DOID:8566
# 8   herpes simplex  DOID:8566
# 9   herpes simplex  DOID:8566
# 10  herpes simplex  DOID:8566
# 11  herpes simplex  DOID:8566
# 12  herpes simplex  DOID:8566
# 13  herpes simplex  DOID:8566
# 14  herpes simplex  DOID:8566
# 15  herpes simplex  DOID:8566
# 16  herpes simplex  DOID:8566
# 17  herpes simplex  DOID:8566
# 18  herpes simplex  DOID:8566
#
#                                           target name         target ID
# 0                                galactosidase beta 1  UniProtKB:P16278
# 1                             early growth response 1  UniProtKB:P18146
# 2                                    interferon gamma  UniProtKB:P01579
# 3                    nuclear factor kappa B subunit 1  UniProtKB:P19838
# 4    endogenous retrovirus group W member 1, envelope  UniProtKB:Q9UQF0
# 5                                toll like receptor 9  UniProtKB:Q9NR96
# 6                                   tumor protein p53  UniProtKB:P04637
# 7                     nectin cell adhesion molecule 1  UniProtKB:Q15223
# 8                            Sp1 transcription factor  UniProtKB:P08047
# 9                               tumor necrosis factor  UniProtKB:P01375
# 10                             promyelocytic leukemia  UniProtKB:P29590
# 11                                      interleukin 2  UniProtKB:P60568
# 12                   telomerase reverse transcriptase  UniProtKB:O14746
# 13                                host cell factor C1  UniProtKB:P51610
# 14                 TNF receptor superfamily member 14  UniProtKB:Q92956
# 15                                   apolipoprotein E  UniProtKB:P02649
# 16                  erb-b2 receptor tyrosine kinase 2  UniProtKB:P04626
# 17  atypical chemokine receptor 1 (Duffy blood group)  UniProtKB:Q16570
# 18                        nuclear RNA export factor 1  UniProtKB:Q9UBU9

# %%
execute_example("DOID:8622","Measles")
# Out:
# <h3>Measles</h3>
#    source name  source ID                                        target name  \
# 0      measles  DOID:8622                     interferon regulatory factor 3
# 1      measles  DOID:8622  major histocompatibility complex, class II, DP...
# 2      measles  DOID:8622  signaling lymphocytic activation molecule fami...
# 3      measles  DOID:8622  major histocompatibility complex, class II, DP...
# 4      measles  DOID:8622                                      interleukin 6
# 5      measles  DOID:8622                                   interferon gamma
# 6      measles  DOID:8622  major histocompatibility complex, class II, DR...
# 7      measles  DOID:8622                          interleukin 18 receptor 1
# 8      measles  DOID:8622                      indoleamine 2,3-dioxygenase 1
# 9      measles  DOID:8622       interferon alpha and beta receptor subunit 2
# 10     measles  DOID:8622                     C-X-C motif chemokine ligand 8
# 11     measles  DOID:8622                                      CD46 molecule
# 12     measles  DOID:8622                   solute carrier family 5 member 5
# 13     measles  DOID:8622                                 interleukin 1 beta
# 14     measles  DOID:8622  transporter 1, ATP binding cassette subfamily ...
# 15     measles  DOID:8622                           MX dynamin like GTPase 1
# 16     measles  DOID:8622                                  interferon beta 1
# 17     measles  DOID:8622  eukaryotic translation initiation factor 2 alp...
# 18     measles  DOID:8622                           myosin binding protein H
#
#            target ID
# 0   UniProtKB:Q14653
# 1   UniProtKB:P20036
# 2   UniProtKB:Q13291
# 3   UniProtKB:P04440
# 4   UniProtKB:P05231
# 5   UniProtKB:P01579
# 6   UniProtKB:P01911
# 7   UniProtKB:Q13478
# 8   UniProtKB:P14902
# 9   UniProtKB:P48551
# 10  UniProtKB:P10145
# 11  UniProtKB:P15529
# 12  UniProtKB:Q92911
# 13  UniProtKB:P01584
# 14  UniProtKB:Q03518
# 15  UniProtKB:P20591
# 16  UniProtKB:P01574
# 17  UniProtKB:P19525
# 18  UniProtKB:Q13203

# %%
execute_example("DOID:1508","Candidiasis")
# Out:
# <h3>Candidiasis</h3>
#     source name  source ID                         target name  \
# 0   candidiasis  DOID:1508               tumor necrosis factor
# 1   candidiasis  DOID:1508    Fc fragment of IgG receptor IIIa
# 2   candidiasis  DOID:1508                toll like receptor 6
# 3   candidiasis  DOID:1508    Fc fragment of IgG receptor IIIb
# 4   candidiasis  DOID:1508                toll like receptor 2
# 5   candidiasis  DOID:1508     Fc fragment of IgG receptor IIa
# 6   candidiasis  DOID:1508                     interleukin 17A
# 7   candidiasis  DOID:1508   interleukin 1 receptor antagonist
# 8   candidiasis  DOID:1508                autoimmune regulator
# 9   candidiasis  DOID:1508            mannose binding lectin 2
# 10  candidiasis  DOID:1508                toll like receptor 1
# 11  candidiasis  DOID:1508                      interleukin 10
# 12  candidiasis  DOID:1508                    defensin beta 4A
# 13  candidiasis  DOID:1508                  interleukin 1 beta
# 14  candidiasis  DOID:1508        cytochrome b-245 alpha chain
# 15  candidiasis  DOID:1508                toll like receptor 4
# 16  candidiasis  DOID:1508                       interleukin 4
# 17  candidiasis  DOID:1508  C-type lectin domain containing 7A
#
#            target ID
# 0   UniProtKB:P01375
# 1   UniProtKB:P08637
# 2   UniProtKB:Q9Y2C9
# 3   UniProtKB:O75015
# 4   UniProtKB:O60603
# 5   UniProtKB:P12318
# 6   UniProtKB:Q16552
# 7   UniProtKB:P18510
# 8   UniProtKB:O43918
# 9   UniProtKB:P11226
# 10  UniProtKB:Q15399
# 11  UniProtKB:P22301
# 12  UniProtKB:O15263
# 13  UniProtKB:P01584
# 14  UniProtKB:P13498
# 15  UniProtKB:O00206
# 16  UniProtKB:P05112
# 17  UniProtKB:Q9BXN2

# %%
execute_example("DOID:12128","Pica")
# Out:
# <h3>Pica</h3>
# Empty DataFrame
# Columns: [source name, source ID, target name, target ID]
# Index: []

# %%
execute_example("DOID:0080234","Mental retardation, autosomal dominant 49 (MRD49)")
# Out:
# <h3>Mental retardation, autosomal dominant 49 (MRD49)</h3>
# No results found
