# %% [markdown]
# # This is some boilerplate code for interacting with the TCGA/GTEx data source
#
# The documentation is available at http://http://isbtranslatorapi.adversary.us/

# %%
import urllib2
import json
import requests

# %%
base_url = 'http://isbtranslatorapi.adversary.us'

# %% [markdown]
# ## Metadata access
#
# How do I find the different things I am interested in?

# %%
# The base metadata takes a minute.  It is counting a lot of stuff
def query_isb(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    return req.json()

# %%
print json.dumps( query_isb('v1/metadata'), indent=2)
# Out:
# [
#   {
#     "count": 989596,
#     "key": "analytes"
#   },
#   {
#     "count": 16553204,
#     "key": "correlation"
#   }
# ]

# %% [markdown]
# ## Analytes
#
# Analytes are the nodes in the correlation network

# %%
print "These are the queryable fields."
print json.dumps( query_isb('v1/metadata/analytes'), indent=2)
# Out:
# These are the queryable fields.
# {
#   "fields": [
#     "type",
#     "phylum",
#     "vendor",
#     "pubmed_id",
#     "hmdb",
#     "hgnc_id",
#     "gene_location",
#     "_id",
#     "aggregation_level",
#     "description",
#     "uniprot",
#     "tissue_id",
#     "tissue_description",
#     "sub_pathway",
#     "order",
#     "subsystem",
#     "pubchem",
#     "tissue",
#     "nsamples",
#     "health_status",
#     "name",
#     "abbreviation",
#     "kegg",
#     "kingdom",
#     "super_pathway",
#     "study_title",
#     "class",
#     "source_project",
#     "measurement_technology",
#     "family",
#     "category",
#     "peptide"
#   ],
#   "Unique Analytes": 989596
# }

# %%
print "You can view see what values are associated with a field"
print "Note most queries are paginated using from and size."

print json.dumps( query_isb('v1/metadata/analytes/abbreviation', data={'from':0, 'size':20}), indent=2)
# Out:
# You can view see what values are associated with a field
# Note most queries are paginated using from and size.
# {
#   "count": 18385,
#   "abbreviation": [
#     "CHPF2",
#     "PARK7",
#     "RETN",
#     "PITX2",
#     "ZNF500",
#     "CASQ1",
#     "MMAA",
#     "WDR37",
#     "EVX1",
#     "ANKRD52",
#     "MRPL10",
#     "ADAT2",
#     "ZFYVE21",
#     "UBE2G2",
#     "APOBEC3H",
#     "FUZ",
#     "PRKAR2A",
#     "DSCR9",
#     "SLC5A4",
#     "SIGLEC1"
#   ]
# }

# %% [markdown]
# ## You can query for an analyte using the `v1/analyte` endpoint.

# %%
print json.dumps( query_isb('v1/analyte', data={'abbreviation':'CHPF2'}), indent=2)
# Out:
# [
#   {
#     "category": "gene expression",
#     "nsamples": "577",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Adipose Tissue",
#     "tissue_id": "GTEx - Adipose Tissue",
#     "_id": "gtex.adipose-tissue.CHPF2",
#     "tissue_description": "Adipose Tissue healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "145",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Adrenal Gland",
#     "tissue_id": "GTEx - Adrenal Gland",
#     "_id": "gtex.adrenal-gland.CHPF2",
#     "tissue_description": "Adrenal Gland healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "689",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Blood Vessel",
#     "tissue_id": "GTEx - Blood Vessel",
#     "_id": "gtex.blood-vessel.CHPF2",
#     "tissue_description": "Blood Vessel healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "511",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Blood",
#     "tissue_id": "GTEx - Blood",
#     "_id": "gtex.blood.CHPF2",
#     "tissue_description": "Blood healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.CHPF2",
#     "tissue_description": "Brain healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "214",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Breast",
#     "tissue_id": "GTEx - Breast",
#     "_id": "gtex.breast.CHPF2",
#     "tissue_description": "Breast healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "345",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Colon",
#     "tissue_id": "GTEx - Colon",
#     "_id": "gtex.colon.CHPF2",
#     "tissue_description": "Colon healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "686",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Esophagus",
#     "tissue_id": "GTEx - Esophagus",
#     "_id": "gtex.esophagus.CHPF2",
#     "tissue_description": "Esophagus healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "412",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Heart",
#     "tissue_id": "GTEx - Heart",
#     "_id": "gtex.heart.CHPF2",
#     "tissue_description": "Heart healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "119",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Liver",
#     "tissue_id": "GTEx - Liver",
#     "_id": "gtex.liver.CHPF2",
#     "tissue_description": "Liver healthy tissue"
#   }
# ]

# %% [markdown]
# You can use a comma separated list to query for multiple genes

# %%
print json.dumps( query_isb('v1/analyte', data={'abbreviation':'CHPF2,BRCA2'}), indent=2)
# Out:
# [
#   {
#     "category": "gene expression",
#     "nsamples": "577",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Adipose Tissue",
#     "tissue_id": "GTEx - Adipose Tissue",
#     "_id": "gtex.adipose-tissue.BRCA2",
#     "tissue_description": "Adipose Tissue healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "577",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Adipose Tissue",
#     "tissue_id": "GTEx - Adipose Tissue",
#     "_id": "gtex.adipose-tissue.CHPF2",
#     "tissue_description": "Adipose Tissue healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "145",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Adrenal Gland",
#     "tissue_id": "GTEx - Adrenal Gland",
#     "_id": "gtex.adrenal-gland.BRCA2",
#     "tissue_description": "Adrenal Gland healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "145",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Adrenal Gland",
#     "tissue_id": "GTEx - Adrenal Gland",
#     "_id": "gtex.adrenal-gland.CHPF2",
#     "tissue_description": "Adrenal Gland healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "689",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Blood Vessel",
#     "tissue_id": "GTEx - Blood Vessel",
#     "_id": "gtex.blood-vessel.BRCA2",
#     "tissue_description": "Blood Vessel healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "689",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Blood Vessel",
#     "tissue_id": "GTEx - Blood Vessel",
#     "_id": "gtex.blood-vessel.CHPF2",
#     "tissue_description": "Blood Vessel healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "511",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Blood",
#     "tissue_id": "GTEx - Blood",
#     "_id": "gtex.blood.BRCA2",
#     "tissue_description": "Blood healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "511",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Blood",
#     "tissue_id": "GTEx - Blood",
#     "_id": "gtex.blood.CHPF2",
#     "tissue_description": "Blood healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.BRCA2",
#     "tissue_description": "Brain healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.CHPF2",
#     "tissue_description": "Brain healthy tissue"
#   }
# ]

# %%
print json.dumps( query_isb('v1/analyte', data={'abbreviation':'CHPF2,BRCA2', "tissue":"Brain"}), indent=2)
# Out:
# [
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.BRCA2",
#     "tissue_description": "Brain healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.CHPF2",
#     "tissue_description": "Brain healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "120",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "TCGA",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Cancer",
#     "tissue": "Brain",
#     "tissue_id": "TCGA - GBM",
#     "_id": "tcga.gbm.BRCA2",
#     "tissue_description": "Glioblastoma multiforme"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "120",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "TCGA",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Cancer",
#     "tissue": "Brain",
#     "tissue_id": "TCGA - GBM",
#     "_id": "tcga.gbm.CHPF2",
#     "tissue_description": "Glioblastoma multiforme"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "507",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "TCGA",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Cancer",
#     "tissue": "Brain",
#     "tissue_id": "TCGA - LGG",
#     "_id": "tcga.lgg.BRCA2",
#     "tissue_description": "Brain Lower Grade Glioma"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "507",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "TCGA",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Cancer",
#     "tissue": "Brain",
#     "tissue_id": "TCGA - LGG",
#     "_id": "tcga.lgg.CHPF2",
#     "tissue_description": "Brain Lower Grade Glioma"
#   }
# ]

# %% [markdown]
# The `_id` field is what you then use to query the correlations

# %% [markdown]
# # Correlations

# %%
my_analytes = query_isb('v1/analyte', data={'abbreviation':'CHPF2,BRCA2', "tissue":"Brain", 'source_project':'GTEx'})
print json.dumps(my_analytes, indent=2)
# Out:
# [
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "BRCA2, DNA repair associated",
#     "gene_location": "13q13.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:1101",
#     "abbreviation": "BRCA2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.BRCA2",
#     "tissue_description": "Brain healthy tissue"
#   },
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "chondroitin polymerizing factor 2",
#     "gene_location": "7q36.1",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:29270",
#     "abbreviation": "CHPF2",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.CHPF2",
#     "tissue_description": "Brain healthy tissue"
#   }
# ]

# %%
# join together some interesting ids and look for correlations
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'size':50}), indent=2)
# Out:
# [
#   {
#     "coefficient": 0.138,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A1BG",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 8.637e-07
#   },
#   {
#     "coefficient": 0.163,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A1CF",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.31e-09
#   },
#   {
#     "coefficient": 0.153,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A2M",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.654e-08
#   },
#   {
#     "coefficient": 0.025,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A2ML1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.382
#   },
#   {
#     "coefficient": 0.053,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A4GALT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.06019
#   },
#   {
#     "coefficient": 0.138,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A4GNT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 9.217e-07
#   },
#   {
#     "coefficient": 0.233,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAAS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 5.877e-17
#   },
#   {
#     "coefficient": 0.097,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AACS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.000572
#   },
#   {
#     "coefficient": 0.018,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AADAC",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.5248
#   },
#   {
#     "coefficient": 0.006,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AADACL2",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.8178
#   },
#   {
#     "coefficient": 0.027,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AADACL3",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.3304
#   },
#   {
#     "coefficient": 0.083,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AADACL4",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.00311
#   },
#   {
#     "coefficient": 0.117,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AADAT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.281e-05
#   },
#   {
#     "coefficient": 0.173,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAGAB",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.602e-10
#   },
#   {
#     "coefficient": 0.152,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAK1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.084e-08
#   },
#   {
#     "coefficient": 0.222,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAMP",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.78e-15
#   },
#   {
#     "coefficient": 0.221,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AANAT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.08e-15
#   },
#   {
#     "coefficient": 0.211,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.037e-14
#   },
#   {
#     "coefficient": 0.17,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARS2",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.265e-09
#   },
#   {
#     "coefficient": 0.171,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARSD1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.072e-09
#   },
#   {
#     "coefficient": 0.293,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASDH",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.781e-26
#   },
#   {
#     "coefficient": 0.203,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASDHPPT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.202e-13
#   },
#   {
#     "coefficient": 0.293,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.465e-26
#   },
#   {
#     "coefficient": 0.258,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AATF",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.228e-20
#   },
#   {
#     "coefficient": 0.192,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AATK",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.314e-12
#   },
#   {
#     "coefficient": 0.156,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABAT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.621e-08
#   },
#   {
#     "coefficient": 0.139,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 7.003e-07
#   },
#   {
#     "coefficient": 0.23,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA10",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.41e-16
#   },
#   {
#     "coefficient": 0.21,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA11P",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.55e-14
#   },
#   {
#     "coefficient": 0.085,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA12",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.002402
#   },
#   {
#     "coefficient": 0.084,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA13",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.002771
#   },
#   {
#     "coefficient": 0.143,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA17P",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.599e-07
#   },
#   {
#     "coefficient": 0.218,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA2",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.617e-15
#   },
#   {
#     "coefficient": 0.163,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA3",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 5.576e-09
#   },
#   {
#     "coefficient": 0.094,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA4",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.000788
#   },
#   {
#     "coefficient": 0.264,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA5",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.783e-21
#   },
#   {
#     "coefficient": 0.246,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA6",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 9.529e-19
#   },
#   {
#     "coefficient": 0.163,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA7",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 5.978e-09
#   },
#   {
#     "coefficient": 0.099,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA8",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.0004373
#   },
#   {
#     "coefficient": 0.217,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA9",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 7.278e-15
#   },
#   {
#     "coefficient": 0.134,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.88e-06
#   },
#   {
#     "coefficient": 0.328,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB10",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.674e-33
#   },
#   {
#     "coefficient": 0.075,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB11",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.007421
#   },
#   {
#     "coefficient": 0.17,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB4",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.292e-09
#   },
#   {
#     "coefficient": 0.053,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB5",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 0.05985
#   },
#   {
#     "coefficient": 0.186,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB6",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.226e-11
#   },
#   {
#     "coefficient": 0.404,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB7",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.692e-50
#   },
#   {
#     "coefficient": 0.211,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB8",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.7e-14
#   },
#   {
#     "coefficient": 0.15,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCB9",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 9.072e-08
#   },
#   {
#     "coefficient": 0.241,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCC1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.939e-18
#   }
# ]

# %%
# same thing but drop the crumby pvalues (Bonf sig)
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'pvalue': .05/18385}), indent=2)
# Out:
# [
#   {
#     "coefficient": 0.138,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A1BG",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 8.637e-07
#   },
#   {
#     "coefficient": 0.163,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A1CF",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.31e-09
#   },
#   {
#     "coefficient": 0.153,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A2M",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.654e-08
#   },
#   {
#     "coefficient": 0.138,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.A4GNT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 9.217e-07
#   },
#   {
#     "coefficient": 0.233,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAAS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 5.877e-17
#   },
#   {
#     "coefficient": 0.173,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAGAB",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.602e-10
#   },
#   {
#     "coefficient": 0.152,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAK1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.084e-08
#   },
#   {
#     "coefficient": 0.222,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AAMP",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.78e-15
#   },
#   {
#     "coefficient": 0.221,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AANAT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.08e-15
#   },
#   {
#     "coefficient": 0.211,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 4.037e-14
#   }
# ]

# %%
# next page of bonf sig correlations
ids = ','.join([analyte['_id'] for analyte in my_analytes])
print json.dumps( query_isb('v1/correlation', data={'ids1':ids, 'pvalue': .05/18385, 'from':10, 'size':10}), indent=2)
# Out:
# [
#   {
#     "coefficient": 0.17,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARS2",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.265e-09
#   },
#   {
#     "coefficient": 0.171,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AARSD1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.072e-09
#   },
#   {
#     "coefficient": 0.293,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASDH",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.781e-26
#   },
#   {
#     "coefficient": 0.203,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASDHPPT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 3.202e-13
#   },
#   {
#     "coefficient": 0.293,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AASS",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.465e-26
#   },
#   {
#     "coefficient": 0.258,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AATF",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.228e-20
#   },
#   {
#     "coefficient": 0.192,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.AATK",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 6.314e-12
#   },
#   {
#     "coefficient": 0.156,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABAT",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 2.621e-08
#   },
#   {
#     "coefficient": 0.139,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA1",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 7.003e-07
#   },
#   {
#     "coefficient": 0.23,
#     "description": "tissue/condition specific gene expression",
#     "study": "GTEx",
#     "_id_1": "gtex.brain.ABCA10",
#     "_id_2": "gtex.brain.BRCA2",
#     "bh_adjusted_pvalue": null,
#     "test": "SPEARMAN",
#     "pvalue": 1.41e-16
#   }
# ]

# %%
# hmm abca10 looks interesting and I would like to learn more about it

print json.dumps(query_isb('v1/analyte/gtex.brain.ABCA10'), indent=2)
# Out:
# [
#   {
#     "category": "gene expression",
#     "nsamples": "1259",
#     "name": "ATP binding cassette subfamily A member 10",
#     "gene_location": "17q24.3",
#     "source_project": "GTEx",
#     "hgnc_id": "HGNC:30",
#     "abbreviation": "ABCA10",
#     "health_status": "Healthy",
#     "tissue": "Brain",
#     "tissue_id": "GTEx - Brain",
#     "_id": "gtex.brain.ABCA10",
#     "tissue_description": "Brain healthy tissue"
#   }
# ]

# %%
# in fact I would like to learn about all of the bsig genes

sigs = []

frm = 0
size=1000
res = query_isb('v1/correlation', data={'ids1':ids, 'pvalue': .01/18385, 'from':frm, 'size':size})
correlations = res[:]
while len(res) > 0:
    print "Saving records from %i to %i" %(frm, frm+size)
    sigs += [x['_id_1'] for x in res]
    sigs += [x['_id_2'] for x in res]
    frm += size
    res =  query_isb('v1/correlation', data={'ids1':ids, 'pvalue': .01/18385, 'from':frm, 'size':size})
    correlations += res
# Out:
# Saving records from 0 to 1000
# Saving records from 1000 to 2000
# Saving records from 2000 to 3000
# Saving records from 3000 to 4000
# Saving records from 4000 to 5000
# Saving records from 5000 to 6000
# Saving records from 6000 to 7000
# Saving records from 7000 to 8000
# Saving records from 8000 to 9000
# Saving records from 9000 to 10000

# %%
sigs = list(set(sigs))
print len(sigs)
# Out:
# 9940

# %%
sig_ids = ','.join(sigs)

frm = 0
size = 1000
meta = []
res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
meta += res
# Note: this is relying on the pagination, it would be smarter to just partition
# the *sig_ids* set which would greatly speed up the query
while len(res) > 0:
    frm += size
    print "Saving records from %i to %i" %(frm, frm+size)
    res = query_isb('/v1/analyte', data={'ids':sig_ids, 'from':frm, 'size':size})
    meta+=res
# Out:
# Saving records from 1000 to 2000
# Saving records from 2000 to 3000
# Saving records from 3000 to 4000
# Saving records from 4000 to 5000
# Saving records from 5000 to 6000
# Saving records from 6000 to 7000
# Saving records from 7000 to 8000
# Saving records from 8000 to 9000
# Saving records from 9000 to 10000
# Saving records from 10000 to 11000

# %%
len(meta)
# Out:
# 9940

# %%
#faster less dumb way of doing the same as above
sig_list = sigs
sig_ids = ','.join(sigs)

frm = 0
size = 1000
res = []
sub_sig = sig_list[frm:frm+size]
res += query_isb('/v1/analyte', data={'ids':','.join(sub_sig), 'size':size})

while len(sub_sig) > 0:
    frm += size
    sub_sig = sig_list[frm:frm+size]
    print "Saving records from %i to %i" %(frm, frm+size)
    res += query_isb('/v1/analyte', data={'ids':','.join(sub_sig), 'size':size})
# Out:
# Saving records from 1000 to 2000
# Saving records from 2000 to 3000
# Saving records from 3000 to 4000
# Saving records from 4000 to 5000
# Saving records from 5000 to 6000
# Saving records from 6000 to 7000
# Saving records from 7000 to 8000
# Saving records from 8000 to 9000
# Saving records from 9000 to 10000
# Saving records from 10000 to 11000

# %% [markdown]
# # Pandas 4 life

# %%
import pandas

corr_net = pandas.DataFrame(correlations)
corr_net.head()
# Out:
#               _id_1             _id_2 bh_adjusted_pvalue  coefficient  \
# 0   gtex.brain.A1CF  gtex.brain.BRCA2               None        0.163
# 1    gtex.brain.A2M  gtex.brain.BRCA2               None        0.153
# 2   gtex.brain.AAAS  gtex.brain.BRCA2               None        0.233
# 3  gtex.brain.AAGAB  gtex.brain.BRCA2               None        0.173
# 4   gtex.brain.AAK1  gtex.brain.BRCA2               None        0.152
#
#                                  description        pvalue study      test
# 0  tissue/condition specific gene expression  6.310000e-09  GTEx  SPEARMAN
# 1  tissue/condition specific gene expression  4.654000e-08  GTEx  SPEARMAN
# 2  tissue/condition specific gene expression  5.877000e-17  GTEx  SPEARMAN
# 3  tissue/condition specific gene expression  6.602000e-10  GTEx  SPEARMAN
# 4  tissue/condition specific gene expression  6.084000e-08  GTEx  SPEARMAN

# %%
metadata = pandas.DataFrame(res)
metadata.head()
# Out:
#                 _id abbreviation         category  gene_location  \
# 0   gtex.brain.AAAS         AAAS  gene expression       12q13.13
# 1  gtex.brain.AARS2        AARS2  gene expression         6p21.1
# 2  gtex.brain.ABCA2        ABCA2  gene expression         9q34.3
# 3  gtex.brain.ABCA5        ABCA5  gene expression        17q24.3
# 4  gtex.brain.ABCA6        ABCA6  gene expression  17q24.2-q24.3
#
#   health_status     hgnc_id                                       name  \
# 0       Healthy  HGNC:13666               aladin WD repeat nucleoporin
# 1       Healthy  HGNC:21022    alanyl-tRNA synthetase 2, mitochondrial
# 2       Healthy     HGNC:32  ATP binding cassette subfamily A member 2
# 3       Healthy     HGNC:35  ATP binding cassette subfamily A member 5
# 4       Healthy     HGNC:36  ATP binding cassette subfamily A member 6
#
#   nsamples source_project tissue    tissue_description     tissue_id
# 0     1259           GTEx  Brain  Brain healthy tissue  GTEx - Brain
# 1     1259           GTEx  Brain  Brain healthy tissue  GTEx - Brain
# 2     1259           GTEx  Brain  Brain healthy tissue  GTEx - Brain
# 3     1259           GTEx  Brain  Brain healthy tissue  GTEx - Brain
# 4     1259           GTEx  Brain  Brain healthy tissue  GTEx - Brain
