# %%
import json
import requests

# %% [markdown]
# # BigGIM example
#
# swagger api specification: http://biggim.ncats.io/api

# %%
base_url = 'http://biggim.ncats.io/api'

# %%
#a couple of simple helper functions
def post(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()

def get(endpoint, data={}, base_url=base_url):
    req = requests.get('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()
    

def jprint(dct):
    print(json.dumps(dct, indent=2))

# %% [markdown]
# ## Example Metadata

# %% [markdown]
# ### Get available studies

# %%
try:
    studies = get('metadata/study')
    jprint(studies)
except requests.HTTPError as e:
    print(e)
# Out:
# [
#   {
#     "substudies": [
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Boolean Flag For Interaction",
#             "name": "BioGRID_Interaction",
#             "datatype": "BOOLEAN"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Experimental System Used",
#             "name": "BioGRID_Experimental_System",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Experimental System Type",
#             "name": "BioGRID_Experimental_System_Type",
#             "datatype": "STRING"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "High or Low Throughput Measurement",
#             "name": "BioGRID_Throughput",
#             "datatype": "STRING"
#           }
#         ],
#         "name": "Default",
#         "description": "Default",
#         "tissue_hierarchy": null,
#         "cell_of_origin": null
#       }
#     ],
#     "name": "BioGRID",
#     "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#   },
#   {
#     "substudies": [
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_OV_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_OV_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "OV",
#         "description": "Ovarian serous cystadenocarcinoma",
#         "tissue_hierarchy": "0 - ovarian serous carcinoma cell|1 - ovary cancer cell|2 - ovary|3 - female reproductive gland|3 - internal female genital organ|4 - female reproductive system|4 - endocrine gland|5 - reproductive system|5 - gland|6 - urogenital system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "ovarian serous carcinoma cell"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_ACC_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_ACC_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "ACC",
#         "description": "Adrenocortical carcinoma",
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "adrenocortical carcinoma cell"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_GBM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_GBM_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "GBM",
#         "description": "Glioblastoma multiforme",
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "glioblastoma cell"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_LGG_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_LGG_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "LGG",
#         "description": "Brain Lower Grade Glioma",
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "glioma cell"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UCS_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UCS_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "UCS",
#         "description": "Uterine Carcinosarcoma",
#         "tissue_hierarchy": "0 - uterine sarcoma cell|1 - sarcoma cell|1 - uterine cancer cell|2 - cartilage|2 - skeletal muscle cancer cell|2 - bone cancer cell|2 - uterus|3 - connective tissue|3 - skeletal system|3 - skeletal muscle cell|3 - bone|3 - internal female genital organ|4 - whole body|4 - skeletal muscle|4 - female reproductive system|5 - animal|5 - muscle|5 - vertebrate muscular system|5 - reproductive system|6 - tissues, cell types and enzyme sources|6 - muscular system|6 - urogenital system",
#         "cell_of_origin": "uterine sarcoma cell"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "TCGA_UVM_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "TCGA_UVM_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
# ...
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "Blood_Vessel",
#         "description": "Blood_Vessel",
#         "tissue_hierarchy": "0 - blood vessel|1 - vascular system|2 - cardiovascular system|3 - whole body|4 - animal|5 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "Blood Vessel"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "Adrenal_Gland",
#         "description": "Adrenal_Gland",
#         "tissue_hierarchy": "0 - adrenal gland|1 - viscus|1 - endocrine gland|2 - whole body|2 - gland|3 - animal|4 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "Adrenal Gland"
#       },
#       {
#         "columns": [
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "CRC_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "Spearman Rank Correlation Coefficient",
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "datatype": "FLOAT"
#           },
#           {
#             "table": {
#               "name": "FA_v1"
#             },
#             "interactions_type": "P-value (-log10)",
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "datatype": "FLOAT"
#           }
#         ],
#         "name": "Adipose_Tissue",
#         "description": "Adipose_Tissue",
#         "tissue_hierarchy": "0 - adipose tissue|1 - connective tissue|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "cell_of_origin": "Adipose Tissue"
#       }
#     ],
#     "name": "GTEx",
#     "description": "Genotype-Tissue Expression (GTEx) program\n\n        Genotype-Tissue Expression (GTEx) program is providing valuable insights into the mechanisms of gene regulation by studying human gene expression and regulation in multiple tissues from health individuals; exploring disease-related perturbations in a variety of human diseases; and examining sexual dimorphisms in gene expression and regulation in multiple tissues. Genetic variation between individuals underlying the many differences in gene expression  will be examined for correlation with differences in gene expression level to identify regions of the genome that influence whether and how much a gene is expressed. Identifying unique genomic variations associated with gene expression is expected to stimulate research towards understanding the genetic basis of complex diseases. \n        \n        https://www.gtexportal.org/home/\n        "
#   }
# ]

# %%
study_names = [s['name'] for s in studies]
study_names
# Out:
# ['BioGRID', 'TCGA', 'GIANT', 'GTEx']

# %% [markdown]
# ### Get a single study

# %%
try:
    tcga = get('metadata/study/%s' % ('TCGA'))
    jprint(tcga)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# {
#   "name": "TCGA",
#   "substudies": [
#     {
#       "cell_of_origin": "ovarian serous carcinoma cell",
#       "tissue_hierarchy": "0 - ovarian serous carcinoma cell|1 - ovary cancer cell|2 - ovary|3 - female reproductive gland|3 - internal female genital organ|4 - female reproductive system|4 - endocrine gland|5 - reproductive system|5 - gland|6 - urogenital system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "Ovarian serous cystadenocarcinoma",
#       "name": "OV",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_OV_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_OV_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "adrenocortical carcinoma cell",
#       "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Adrenocortical carcinoma",
#       "name": "ACC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_ACC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_ACC_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "glioblastoma cell",
#       "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#       "description": "Glioblastoma multiforme",
#       "name": "GBM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_GBM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_GBM_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "glioma cell",
#       "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Brain Lower Grade Glioma",
#       "name": "LGG",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_LGG_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_LGG_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "uterine sarcoma cell",
#       "tissue_hierarchy": "0 - uterine sarcoma cell|1 - sarcoma cell|1 - uterine cancer cell|2 - cartilage|2 - skeletal muscle cancer cell|2 - bone cancer cell|2 - uterus|3 - connective tissue|3 - skeletal system|3 - skeletal muscle cell|3 - bone|3 - internal female genital organ|4 - whole body|4 - skeletal muscle|4 - female reproductive system|5 - animal|5 - muscle|5 - vertebrate muscular system|5 - reproductive system|6 - tissues, cell types and enzyme sources|6 - muscular system|6 - urogenital system",
#       "description": "Uterine Carcinosarcoma",
#       "name": "UCS",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCS_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCS_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "uveal melanoma cell",
#       "tissue_hierarchy": "0 - uveal melanoma cell|1 - melanoma cell|2 - skin cancer cell|2 - melanocyte|3 - skin|3 - epidermal cell|4 - integument|4 - epidermis|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "Uveal Melanoma",
#       "name": "UVM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UVM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UVM_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "urinary bladder cancer cell",
#       "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Bladder Urothelial Carcinoma",
#       "name": "BLCA",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BLCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BLCA_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "breast cancer cell",
#       "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#       "description": "Breast invasive carcinoma",
#       "name": "BRCA",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_BRCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_BRCA_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell",
#       "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#       "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#       "name": "CESC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_CESC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_CESC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_CESC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_CESC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_CESC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_CESC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
# ...
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THCA_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THCA_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "thymoma cell",
#       "tissue_hierarchy": "0 - thymoma cell|1 - thymic cancer cell|2 - thymus|3 - immune system|3 - thorax|3 - endocrine gland|3 - lymphoid tissue|4 - whole body|4 - trunk|4 - gland|4 - hematopoietic system|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Thymoma",
#       "name": "THYM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_THYM_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_THYM_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "endometrioid carcinoma cell",
#       "tissue_hierarchy": "0 - endometrioid carcinoma cell|1 - uterine endometrium|1 - ovary cancer cell|2 - mucosa|2 - uterus|2 - ovary|3 - integument|3 - internal female genital organ|3 - female reproductive gland|4 - whole body|4 - female reproductive system|4 - endocrine gland|5 - animal|5 - reproductive system|5 - gland|6 - tissues, cell types and enzyme sources|6 - urogenital system",
#       "description": "Uterine Corpus Endometrial Carcinoma",
#       "name": "UCEC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_UCEC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_UCEC_Pvalue"
#         }
#       ]
#     }
#   ],
#   "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
# }

# %% [markdown]
# ### what an error looks like

# %%
try:
    ta = get('metadata/study/%s' % ('TCSG'))
    jprint(studies)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# 404 Client Error: NOT FOUND for url: http://biggim.ncats.io/api/metadata/study/TCSG
# {
#   "message": "[TCSG] not a valid study",
#   "status": "error"
# }

# %% [markdown]
# ### Get all tables

# %%
try:
    tables = get('/metadata/table')
    jprint(tables)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# [
#   {
#     "default": true,
#     "name": "BigGIM_70_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 146013971730,
#     "num_rows": 51090886
#   },
#   {
#     "default": false,
#     "name": "BigGIM_80_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 41062787154,
#     "num_rows": 14210893
#   },
#   {
#     "default": false,
#     "name": "BigGIM_90_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 3389718425,
#     "num_rows": 1173151
#   },
#   {
#     "default": false,
#     "name": "BigGIM_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions.",
#     "num_bytes": 931457211953,
#     "num_rows": 411827180
#   },
#   {
#     "default": false,
#     "name": "CRC_70_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 26765474,
#     "num_rows": 8604
#   },
#   {
#     "default": false,
#     "name": "CRC_80_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 6536954,
#     "num_rows": 2100
#   },
#   {
#     "default": false,
#     "name": "CRC_90_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 412721,
#     "num_rows": 132
#   },
#   {
#     "default": false,
#     "name": "CRC_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020).",
#     "num_bytes": 83725184,
#     "num_rows": 27028
#   },
#   {
#     "default": false,
#     "name": "FA_70_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 482470699,
#     "num_rows": 161445
#   },
#   {
#     "default": false,
#     "name": "FA_80_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 160188930,
#     "num_rows": 53392
#   },
#   {
#     "default": false,
#     "name": "FA_90_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 12467222,
#     "num_rows": 4151
#   },
#   {
#     "default": false,
#     "name": "FA_v1",
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes.",
#     "num_bytes": 1519402925,
#     "num_rows": 587730
#   }
# ]

# %% [markdown]
# ### Get one table
#
# The default table

# %%
default_table = [t for t in tables if t['default'] == True][0]['name']

# %%
try:
    table = get('/metadata/table/%s' %  (default_table,))
    jprint(table)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# {
#   "name": "BigGIM_70_v1",
#   "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#   "num_rows": 51090886,
#   "columns": [
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_ACC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "adrenocortical carcinoma cell",
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Adrenocortical carcinoma",
#         "name": "ACC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_ACC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "adrenocortical carcinoma cell",
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Adrenocortical carcinoma",
#         "name": "ACC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_BLCA_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "urinary bladder cancer cell",
#         "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Bladder Urothelial Carcinoma",
#         "name": "BLCA"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_BLCA_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "urinary bladder cancer cell",
#         "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Bladder Urothelial Carcinoma",
#         "name": "BLCA"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_BRCA_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "breast cancer cell",
#         "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "description": "Breast invasive carcinoma",
#         "name": "BRCA"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_BRCA_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "breast cancer cell",
#         "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "description": "Breast invasive carcinoma",
#         "name": "BRCA"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_CESC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell",
#         "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#         "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#         "name": "CESC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_CESC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell",
#         "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#         "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#         "name": "CESC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_CHOL_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "cholangiocarcinoma cell",
#         "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Cholangiocarcinoma",
#         "name": "CHOL"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_CHOL_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "cholangiocarcinoma cell",
#         "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Cholangiocarcinoma",
#         "name": "CHOL"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_COAD_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "colorectal adenocarcinoma cell",
#         "tissue_hierarchy": "0 - colorectal adenocarcinoma cell|1 - rectal cancer cell|1 - colonic cancer cell|1 - adenocarcinoma cell|2 - rectum|2 - gastrointestinal cancer cell|2 - colon|2 - carcinoma cell|3 - large intestine|3 - colorectum|3 - gastrointestinal tract|3 - epithelioma cell|4 - intestine|4 - alimentary canal|4 - epithelial cell|5 - viscus|5 - epithelium|6 - whole body|6 - integument|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Colon adenocarcinoma",
#         "name": "COAD"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_COAD_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "colorectal adenocarcinoma cell",
#         "tissue_hierarchy": "0 - colorectal adenocarcinoma cell|1 - rectal cancer cell|1 - colonic cancer cell|1 - adenocarcinoma cell|2 - rectum|2 - gastrointestinal cancer cell|2 - colon|2 - carcinoma cell|3 - large intestine|3 - colorectum|3 - gastrointestinal tract|3 - epithelioma cell|4 - intestine|4 - alimentary canal|4 - epithelial cell|5 - viscus|5 - epithelium|6 - whole body|6 - integument|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Colon adenocarcinoma",
#         "name": "COAD"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_DLBC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "diffuse large B-cell lymphoma cell",
#         "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#         "name": "DLBC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_DLBC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "diffuse large B-cell lymphoma cell",
#         "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#         "name": "DLBC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_ESCA_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "esophageal cancer cell",
#         "tissue_hierarchy": "0 - esophageal cancer cell|1 - esophagus|2 - alimentary canal|3 - viscus|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Esophageal carcinoma",
#         "name": "ESCA"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_ESCA_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "esophageal cancer cell",
#         "tissue_hierarchy": "0 - esophageal cancer cell|1 - esophagus|2 - alimentary canal|3 - viscus|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Esophageal carcinoma",
#         "name": "ESCA"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_GBM_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "glioblastoma cell",
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "description": "Glioblastoma multiforme",
#         "name": "GBM"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_GBM_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "glioblastoma cell",
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "description": "Glioblastoma multiforme",
#         "name": "GBM"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_HNSC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "head and neck cancer cell",
#         "tissue_hierarchy": "0 - head and neck cancer cell|1 - head|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "description": "Head and Neck squamous cell carcinoma",
#         "name": "HNSC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_HNSC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "head and neck cancer cell",
#         "tissue_hierarchy": "0 - head and neck cancer cell|1 - head|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "description": "Head and Neck squamous cell carcinoma",
#         "name": "HNSC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_KICH_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "chromophobe renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - chromophobe renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "description": "Kidney Chromophobe",
#         "name": "KICH"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_KICH_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "chromophobe renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - chromophobe renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "description": "Kidney Chromophobe",
#         "name": "KICH"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_KIRC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "renal clear cell,renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - renal clear cell|0 - renal cell carcinoma cell|1 - renal tubule|1 - kidney cancer cell|1 - adenocarcinoma cell|2 - nephron|2 - kidney|2 - carcinoma cell|3 - excretory gland|3 - viscus|3 - urinary system|3 - urinary tract|3 - epithelioma cell|4 - gland|4 - whole body|4 - urogenital system|4 - epithelial cell|5 - animal|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "description": "Kidney renal clear cell carcinoma",
#         "name": "KIRC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_KIRC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "renal clear cell,renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - renal clear cell|0 - renal cell carcinoma cell|1 - renal tubule|1 - kidney cancer cell|1 - adenocarcinoma cell|2 - nephron|2 - kidney|2 - carcinoma cell|3 - excretory gland|3 - viscus|3 - urinary system|3 - urinary tract|3 - epithelioma cell|4 - gland|4 - whole body|4 - urogenital system|4 - epithelial cell|5 - animal|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "description": "Kidney renal clear cell carcinoma",
#         "name": "KIRC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_KIRP_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "papillary renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - papillary renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "description": "Kidney renal papillary cell carcinoma",
#         "name": "KIRP"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_KIRP_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "papillary renal cell carcinoma cell",
#         "tissue_hierarchy": "0 - papillary renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "description": "Kidney renal papillary cell carcinoma",
#         "name": "KIRP"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_LAML_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "acute myeloid leukemia cell",
#         "tissue_hierarchy": "0 - acute myeloid leukemia cell|1 - myeloid leukemia cell|2 - leukemia cell|3 - leukocyte|3 - blood cancer cell|4 - hematopoietic cell|5 - blood|6 - hematopoietic system|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "description": "Acute Myeloid Leukemia",
#         "name": "LAML"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_LAML_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "acute myeloid leukemia cell",
#         "tissue_hierarchy": "0 - acute myeloid leukemia cell|1 - myeloid leukemia cell|2 - leukemia cell|3 - leukocyte|3 - blood cancer cell|4 - hematopoietic cell|5 - blood|6 - hematopoietic system|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "description": "Acute Myeloid Leukemia",
#         "name": "LAML"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_LGG_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "glioma cell",
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Brain Lower Grade Glioma",
#         "name": "LGG"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_LGG_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "glioma cell",
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Brain Lower Grade Glioma",
#         "name": "LGG"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_LIHC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "liver cancer cell,hepatocyte",
#         "tissue_hierarchy": "0 - liver cancer cell|0 - hepatocyte|1 - liver|2 - digestive gland|2 - viscus|3 - endocrine gland|3 - whole body|4 - gland|4 - animal|5 - tissues, cell types and enzyme sources",
#         "description": "Liver hepatocellular carcinoma",
#         "name": "LIHC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_LIHC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "liver cancer cell,hepatocyte",
#         "tissue_hierarchy": "0 - liver cancer cell|0 - hepatocyte|1 - liver|2 - digestive gland|2 - viscus|3 - endocrine gland|3 - whole body|4 - gland|4 - animal|5 - tissues, cell types and enzyme sources",
#         "description": "Liver hepatocellular carcinoma",
#         "name": "LIHC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_LUAD_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "lung adenocarcinoma cell",
#         "tissue_hierarchy": "0 - lung adenocarcinoma cell|1 - carcinoma cell|1 - non-small cell lung cancer cell|2 - epithelioma cell|2 - bronchogenic carcinoma cell|3 - epithelial cell|3 - lung cancer cell|4 - epithelium|4 - lung|5 - integument|5 - respiratory system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Lung adenocarcinoma",
#         "name": "LUAD"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_LUAD_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "lung adenocarcinoma cell",
#         "tissue_hierarchy": "0 - lung adenocarcinoma cell|1 - carcinoma cell|1 - non-small cell lung cancer cell|2 - epithelioma cell|2 - bronchogenic carcinoma cell|3 - epithelial cell|3 - lung cancer cell|4 - epithelium|4 - lung|5 - integument|5 - respiratory system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Lung adenocarcinoma",
#         "name": "LUAD"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_LUSC_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "lung squamous cell carcinoma cell",
#         "tissue_hierarchy": "0 - lung squamous cell carcinoma cell|1 - lung cancer cell|2 - lung|3 - respiratory system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Lung squamous cell carcinoma",
#         "name": "LUSC"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_LUSC_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "lung squamous cell carcinoma cell",
#         "tissue_hierarchy": "0 - lung squamous cell carcinoma cell|1 - lung cancer cell|2 - lung|3 - respiratory system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Lung squamous cell carcinoma",
#         "name": "LUSC"
#       }
#     },
#     {
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "datatype": "FLOAT",
#       "name": "TCGA_MESO_Correlation",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "cell_of_origin": "mesothelioma cell",
#         "tissue_hierarchy": "0 - mesothelioma cell|1 - mesothelium|2 - mesoderm|2 - squamous epithelium|2 - coelom|3 - germ layer|3 - epithelium|4 - embryo|4 - integument|5 - embryonic structure|5 - whole body|6 - organism form|6 - animal|7 - tissues, cell types and enzyme sources",
#         "description": "Mesothelioma",
#         "name": "MESO"
#       }
#     },
#     {
#       "interactions_type": "P-value (-log10)",
#       "datatype": "FLOAT",
#       "name": "TCGA_MESO_Pvalue",
#       "substudy": {
#         "study": {
#           "name": "TCGA",
# ...
#         "description": "uterine_endometrium",
#         "name": "uterine_endometrium"
#       }
#     },
#     {
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_uterus_KnownFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "uterus",
#         "tissue_hierarchy": "0 - uterus|1 - internal female genital organ|2 - female reproductive system|3 - reproductive system|4 - urogenital system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#         "description": "uterus",
#         "name": "uterus"
#       }
#     },
#     {
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_uterus_ProbabilityOfFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "uterus",
#         "tissue_hierarchy": "0 - uterus|1 - internal female genital organ|2 - female reproductive system|3 - reproductive system|4 - urogenital system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#         "description": "uterus",
#         "name": "uterus"
#       }
#     },
#     {
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vascular_endothelial_cell_KnownFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vascular endothelial cell",
#         "tissue_hierarchy": "0 - vascular endothelial cell|1 - vascular endothelium|1 - endothelial cell|2 - endothelium|2 - blood vessel endothelium|2 - heart|3 - epithelium|3 - blood vessel|3 - cardiovascular system|4 - integument|4 - vascular system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "vascular_endothelial_cell",
#         "name": "vascular_endothelial_cell"
#       }
#     },
#     {
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vascular_endothelial_cell_ProbabilityOfFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vascular endothelial cell",
#         "tissue_hierarchy": "0 - vascular endothelial cell|1 - vascular endothelium|1 - endothelial cell|2 - endothelium|2 - blood vessel endothelium|2 - heart|3 - epithelium|3 - blood vessel|3 - cardiovascular system|4 - integument|4 - vascular system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "vascular_endothelial_cell",
#         "name": "vascular_endothelial_cell"
#       }
#     },
#     {
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vascular_endothelium_KnownFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vascular endothelium",
#         "tissue_hierarchy": "0 - vascular endothelium|1 - endothelium|2 - epithelium|3 - integument|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "vascular_endothelium",
#         "name": "vascular_endothelium"
#       }
#     },
#     {
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vascular_endothelium_ProbabilityOfFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vascular endothelium",
#         "tissue_hierarchy": "0 - vascular endothelium|1 - endothelium|2 - epithelium|3 - integument|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "vascular_endothelium",
#         "name": "vascular_endothelium"
#       }
#     },
#     {
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vermiform_appendix_KnownFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vermiform appendix",
#         "tissue_hierarchy": "0 - vermiform appendix|1 - cecum|2 - large intestine|2 - ileocecum|3 - intestine|4 - gastrointestinal tract|5 - alimentary canal|6 - viscus|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "description": "vermiform_appendix",
#         "name": "vermiform_appendix"
#       }
#     },
#     {
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "datatype": "FLOAT",
#       "name": "GIANT_vermiform_appendix_ProbabilityOfFunctionalInteraction",
#       "substudy": {
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "cell_of_origin": "vermiform appendix",
#         "tissue_hierarchy": "0 - vermiform appendix|1 - cecum|2 - large intestine|2 - ileocecum|3 - intestine|4 - gastrointestinal tract|5 - alimentary canal|6 - viscus|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "description": "vermiform_appendix",
#         "name": "vermiform_appendix"
#       }
#     },
#     {
#       "interactions_type": "Boolean Flag For Interaction",
#       "datatype": "BOOLEAN",
#       "name": "BioGRID_Interaction",
#       "substudy": {
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "cell_of_origin": null,
#         "tissue_hierarchy": null,
#         "description": "Default",
#         "name": "Default"
#       }
#     },
#     {
#       "interactions_type": "Experimental System Used",
#       "datatype": "STRING",
#       "name": "BioGRID_Experimental_System",
#       "substudy": {
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "cell_of_origin": null,
#         "tissue_hierarchy": null,
#         "description": "Default",
#         "name": "Default"
#       }
#     },
#     {
#       "interactions_type": "Experimental System Type",
#       "datatype": "STRING",
#       "name": "BioGRID_Experimental_System_Type",
#       "substudy": {
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "cell_of_origin": null,
#         "tissue_hierarchy": null,
#         "description": "Default",
#         "name": "Default"
#       }
#     },
#     {
#       "interactions_type": "High or Low Throughput Measurement",
#       "datatype": "STRING",
#       "name": "BioGRID_Throughput",
#       "substudy": {
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "cell_of_origin": null,
#         "tissue_hierarchy": null,
#         "description": "Default",
#         "name": "Default"
#       }
#     }
#   ],
#   "default": true,
#   "num_bytes": 146013971730
# }

# %% [markdown]
# ### First 10 columns in default table

# %%
jprint(table['columns'][:10])
# Out:
# [
#   {
#     "interactions_type": "Spearman Rank Correlation Coefficient",
#     "datatype": "FLOAT",
#     "name": "TCGA_ACC_Correlation",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "adrenocortical carcinoma cell",
#       "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Adrenocortical carcinoma",
#       "name": "ACC"
#     }
#   },
#   {
#     "interactions_type": "P-value (-log10)",
#     "datatype": "FLOAT",
#     "name": "TCGA_ACC_Pvalue",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "adrenocortical carcinoma cell",
#       "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Adrenocortical carcinoma",
#       "name": "ACC"
#     }
#   },
#   {
#     "interactions_type": "Spearman Rank Correlation Coefficient",
#     "datatype": "FLOAT",
#     "name": "TCGA_BLCA_Correlation",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "urinary bladder cancer cell",
#       "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Bladder Urothelial Carcinoma",
#       "name": "BLCA"
#     }
#   },
#   {
#     "interactions_type": "P-value (-log10)",
#     "datatype": "FLOAT",
#     "name": "TCGA_BLCA_Pvalue",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "urinary bladder cancer cell",
#       "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Bladder Urothelial Carcinoma",
#       "name": "BLCA"
#     }
#   },
#   {
#     "interactions_type": "Spearman Rank Correlation Coefficient",
#     "datatype": "FLOAT",
#     "name": "TCGA_BRCA_Correlation",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "breast cancer cell",
#       "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#       "description": "Breast invasive carcinoma",
#       "name": "BRCA"
#     }
#   },
#   {
#     "interactions_type": "P-value (-log10)",
#     "datatype": "FLOAT",
#     "name": "TCGA_BRCA_Pvalue",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "breast cancer cell",
#       "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#       "description": "Breast invasive carcinoma",
#       "name": "BRCA"
#     }
#   },
#   {
#     "interactions_type": "Spearman Rank Correlation Coefficient",
#     "datatype": "FLOAT",
#     "name": "TCGA_CESC_Correlation",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell",
#       "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#       "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#       "name": "CESC"
#     }
#   },
#   {
#     "interactions_type": "P-value (-log10)",
#     "datatype": "FLOAT",
#     "name": "TCGA_CESC_Pvalue",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell",
#       "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#       "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#       "name": "CESC"
#     }
#   },
#   {
#     "interactions_type": "Spearman Rank Correlation Coefficient",
#     "datatype": "FLOAT",
#     "name": "TCGA_CHOL_Correlation",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "cholangiocarcinoma cell",
#       "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Cholangiocarcinoma",
#       "name": "CHOL"
#     }
#   },
#   {
#     "interactions_type": "P-value (-log10)",
#     "datatype": "FLOAT",
#     "name": "TCGA_CHOL_Pvalue",
#     "substudy": {
#       "study": {
#         "name": "TCGA",
#         "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#       },
#       "cell_of_origin": "cholangiocarcinoma cell",
#       "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Cholangiocarcinoma",
#       "name": "CHOL"
#     }
#   }
# ]

# %% [markdown]
# ### Get a single column

# %%
try:
    column = get('/metadata/table/%s/column/%s' %  (default_table,'TCGA_ACC_Correlation'))
    jprint(column)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# {
#   "interactions_type": "Spearman Rank Correlation Coefficient",
#   "datatype": "FLOAT",
#   "name": "TCGA_ACC_Correlation",
#   "substudy": {
#     "study": {
#       "name": "TCGA",
#       "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#     },
#     "cell_of_origin": "adrenocortical carcinoma cell",
#     "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#     "description": "Adrenocortical carcinoma",
#     "name": "ACC"
#   }
# }

# %% [markdown]
# ### list all tissues

# %%
tissues = get('metadata/tissue')
jprint(tissues)
# Out:
# {
#   "tissues": [
#     "B_lymphocyte",
#     "B_lymphoma_cell_line",
#     "T_lymphocyte",
#     "acute_myeloid_leukemia_cell",
#     "adenocarcinoma_cell",
#     "adipose_tissue",
#     "adrenal_cortex",
#     "adrenal_gland",
#     "adrenal_gland_cancer_cell",
#     "adrenocortical_carcinoma_cell",
#     "adult_stem_cell",
#     "alimentary_canal",
#     "amygdala",
#     "animal",
#     "aorta",
#     "artery",
#     "astroblast",
#     "astrocyte",
#     "astrocytoma_cell",
#     "astroglia",
#     "astroglial_cell",
#     "avian_pallium",
#     "basal_ganglion",
#     "basophil",
#     "bile_duct",
#     "bile_duct_epithelium",
#     "biliary_epithelium",
#     "bladder",
#     "blast_cell",
#     "blastomere",
#     "blastula",
#     "blood",
#     "blood_cancer_cell",
#     "blood_plasma",
#     "blood_platelet",
#     "blood_vessel",
#     "blood_vessel_endothelium",
#     "bone",
#     "bone_cancer_cell",
#     "bone_marrow",
#     "bone_marrow_cell",
#     "brain",
#     "brain_stem",
#     "brain_ventricle",
#     "breast",
#     "breast_cancer_cell",
#     "breast_epithelium",
#     "bronchial_epithelial_cell",
#     "bronchial_epithelium",
#     "bronchoalveolar_system",
#     "bronchogenic_carcinoma_cell",
#     "bronchus",
#     "capsular_epithelium",
#     "carcinoid_cell",
#     "carcinoma_cell",
#     "cardiac_muscle",
#     "cardiovascular_system",
#     "cartilage",
#     "caudate_nucleus",
#     "caudate_putamen",
#     "cecum",
#     "cell_culture",
#     "central_nervous_system",
#     "cerebellar_cortex",
#     "cerebellum",
#     "cerebral_cortex",
#     "cerebral_hemisphere",
#     "cerebral_lobe",
#     "cervical_adenocarcinoma_cell",
#     "cervical_carcinoma_cell",
#     "cervical_squamous_cell_carcinoma_cell",
#     "cholangiocarcinoma_cell",
#     "chondrocyte",
#     "choroid",
#     "chromophobe_renal_cell_carcinoma_cell",
#     "cochlea",
#     "coelom",
#     "colon",
#     "colonic_cancer_cell",
#     "colorectal_adenocarcinoma_cell",
#     "colorectum",
#     "connecting_stalk",
#     "connective_tissue",
#     "cornea",
#     "corpus_callosum",
#     "corpus_luteum",
#     "corpus_striatum",
#     "culture_condition",
#     "culture_condition_CD8__cell",
#     "culture_condition_antigen_presenting_cell",
#     "dendritic_cell",
#     "dentate_gyrus",
#     "diencephalon",
#     "diffuse_large_B_cell_lymphoma_cell",
#     "digestive_gland",
#     "duodenum",
#     "ear",
#     "ectoderm",
#     "embryo",
#     "embryonic_structure",
#     "endocrine_gland",
#     "endocrine_pancreas",
#     "endometrioid_carcinoma_cell",
#     "endothelial_cell",
#     "endothelium",
#     "eosinophil",
#     "epidermal_cell",
#     "epidermis",
#     "epithelial_cell",
#     "epithelioma_cell",
#     "epithelium",
#     "esophageal_cancer_cell",
#     "esophagus",
#     "excretory_gland",
#     "exocrine_gland",
#     "exocrine_pancreas",
#     "eye",
#     "female_reproductive_gland",
#     "female_reproductive_system",
#     "fetus",
#     "fibroblast",
#     "forebrain",
#     "frontal_lobe",
#     "gametocyte",
#     "ganglion",
#     "gastric_adenocarcinoma_cell",
#     "gastric_cancer_cell",
#     "gastrointestinal_cancer_cell",
#     "gastrointestinal_tract",
#     "germ_cell",
#     "germ_layer",
#     "gland",
#     "glia",
#     "glial_cell",
#     "glioblastoma_cell",
#     "glioma_cell",
#     "glomerular_epithelium",
#     "gonad",
#     "granulocyte",
#     "hair_follicle",
#     "head",
#     "head_and_neck_cancer_cell",
#     "heart",
#     "hematopoietic_cell",
#     "hematopoietic_stem_cell",
#     "hematopoietic_system",
#     "hepatocyte",
#     "hindbrain",
#     "hippocampus",
#     "hypophysis",
#     "hypothalamus",
#     "ileocecum",
#     "ileum",
#     "immune_system",
#     "inner_ear",
#     "integument",
#     "internal_female_genital_organ",
#     "internal_male_genital_organ",
#     "intestinal_mucosa",
#     "intestine",
#     "jejunum",
#     "keratinocyte",
#     "kidney",
#     "kidney_cancer_cell",
#     "large_granular_lymphocyte",
#     "large_intestine",
#     "lateral_ventricle",
#     "lens",
#     "leukemia_cell",
#     "leukocyte",
#     "limbic_system",
#     "liver",
#     "liver_cancer_cell",
#     "locus_ceruleus",
#     "lung",
#     "lung_adenocarcinoma_cell",
#     "lung_cancer_cell",
#     "lung_squamous_cell_carcinoma_cell",
#     "lymph_node",
#     "lymphocyte",
#     "lymphoid_cell",
#     "lymphoid_cell_line",
#     "lymphoid_tissue",
#     "lymphoma_cell",
#     "lymphoma_cell_line",
#     "macroglia",
#     "macrophage",
#     "male_reproductive_gland",
#     "male_reproductive_system",
#     "mammary_epithelium",
#     "mammary_gland",
#     "marrow_cell",
#     "mast_cell",
#     "mature_ovarian_follicle",
#     "medulla_oblongata",
#     "megakaryoblast",
#     "megakaryocyte",
#     "melanocyte",
#     "melanoma_cell",
#     "mesoderm",
#     "mesothelioma_cell",
#     "mesothelium",
#     "metencephalon",
#     "midbrain",
#     "monocyte",
#     "mononuclear_cell",
#     "mononuclear_phagocyte",
#     "morula",
#     "mouth",
#     "mucosa",
#     "muscle",
#     "muscular_system",
#     "myelencephalon",
#     "myeloid_leukemia_cell",
#     "myeloid_progenitor_cell",
#     "myometrium",
#     "natural_killer_cell",
#     "neck",
#     "neostriatum",
#     "nephron",
#     "nerve",
#     "nervous_system",
#     "neural_crest",
#     "neural_crest_cell",
#     "neural_plate",
#     "neuroblast",
#     "neuroendocrine_cell",
#     "neuroendocrine_tumor_cell",
#     "neuron",
#     "neutrophil",
#     "non_small_cell_lung_cancer_cell",
#     "nucleus_accumbens",
#     "nucleus_lentiformis",
#     "null_cell",
#     "occipital_lobe",
#     "occipital_pole",
#     "organism_form",
#     "osteoblast",
#     "osteogenic_cell",
#     "other_source",
#     "ovarian_follicle",
#     "ovarian_serous_carcinoma_cell",
#     "ovary",
#     "ovary_cancer_cell",
#     "oviduct",
#     "pancreas",
#     "pancreatic_duct",
#     "pancreatic_ductal_adenocarcinoma_cell",
#     "pancreatic_ductal_carcinoma_cell",
#     "pancreatic_islet",
#     "papillary_renal_cell_carcinoma_cell",
#     "parietal_lobe",
#     "periosteum",
#     "peripheral_blood",
#     "peripheral_nervous_system",
#     "phagocyte",
#     "pheochromocytoma_cell",
#     "placenta",
#     "podocyte",
#     "pons",
#     "pre_T_lymphocyte",
#     "preosteoblast",
#     "primary_spermatocyte",
#     "prostate_adenocarcinoma_cell",
#     "prostate_gland",
#     "rectal_adenocarcinoma_cell",
#     "rectal_cancer_cell",
#     "rectum",
#     "renal_cell_carcinoma_cell",
#     "renal_clear_cell",
#     "renal_corpuscle",
#     "renal_glomerular_capsule",
#     "renal_glomerulus",
#     "renal_tubule",
#     "reproductive_system",
#     "respiratory_epithelium",
#     "respiratory_system",
#     "retina",
#     "salivary_gland",
#     "sarcoma_cell",
#     "secondary_spermatocyte",
#     "semen",
#     "sense_organ",
#     "serum",
#     "skeletal_muscle",
#     "skeletal_muscle_cancer_cell",
#     "skeletal_muscle_cell",
#     "skeletal_system",
#     "skin",
#     "skin_cancer_cell",
#     "skin_fibroblast",
#     "small_intestine",
#     "smooth_muscle",
#     "spermatid",
#     "spermatocyte",
#     "spermatogonium",
#     "spinal_cord",
#     "spleen",
#     "squamous_cell_carcinoma_cell",
#     "squamous_epithelium",
#     "stomach",
#     "stratum_spinosum",
#     "substantia_nigra",
#     "subthalamic_nucleus",
#     "tear_gland",
#     "telencephalon",
#     "temporal_lobe",
#     "testicular_cancer_cell",
#     "testis",
#     "thalamus",
#     "thorax",
#     "throat",
#     "thymic_cancer_cell",
#     "thymocyte",
#     "thymoma_cell",
#     "thymus",
#     "thyroid_cancer_cell",
#     "thyroid_gland",
#     "tissues__cell_types_and_enzyme_sources",
#     "tonsil",
#     "tooth",
#     "trachea",
#     "trophoblast",
#     "trunk",
#     "umbilical_cord",
#     "umbilical_vein",
#     "umbilical_vein_endothelial_cell",
#     "umbilical_vein_endothelium",
#     "urinary_bladder",
#     "urinary_bladder_cancer_cell",
#     "urinary_system",
#     "urinary_tract",
#     "uroepithelium",
#     "urogenital_system",
#     "uterine_cancer_cell",
#     "uterine_cervix",
#     "uterine_endometrium",
#     "uterine_sarcoma_cell",
#     "uterus",
#     "uveal_melanoma_cell",
#     "vascular_endothelial_cell",
#     "vascular_endothelium",
#     "vascular_system",
#     "vermiform_appendix",
#     "vertebrate_muscular_system",
#     "vestibular_labyrinth",
#     "vestibular_system",
#     "viscus",
#     "whole_body",
#     "zygote"
#   ]
# }

# %%
substudies = get('metadata/tissue/%s' % ("lymphoid_cell",))
jprint(substudies)
# Out:
# {
#   "tissue": "lymphoid_cell",
#   "substudies": [
#     {
#       "cell_of_origin": "natural killer cell",
#       "tissue_hierarchy": "0 - natural killer cell|1 - null cell|1 - large granular lymphocyte|2 - lymphocyte|3 - leukocyte|3 - lymphoid cell|4 - hematopoietic cell|4 - lymphoid tissue|5 - blood|5 - immune system|5 - hematopoietic system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "natural_killer_cell",
#       "name": "natural_killer_cell",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "B-lymphocyte",
#       "tissue_hierarchy": "0 - B-lymphocyte|1 - lymphocyte|2 - leukocyte|2 - lymphoid cell|3 - hematopoietic cell|3 - lymphoid tissue|4 - blood|4 - immune system|4 - hematopoietic system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "b_lymphocyte",
#       "name": "b_lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "T-lymphocyte",
#       "tissue_hierarchy": "0 - T-lymphocyte|1 - lymphocyte|2 - leukocyte|2 - lymphoid cell|3 - hematopoietic cell|3 - lymphoid tissue|4 - blood|4 - immune system|4 - hematopoietic system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "t_lymphocyte",
#       "name": "t_lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "thymocyte",
#       "tissue_hierarchy": "0 - thymocyte|1 - thymus|1 - pre-T-lymphocyte|2 - immune system|2 - thorax|2 - endocrine gland|2 - lymphoid tissue|2 - T-lymphocyte|3 - whole body|3 - trunk|3 - gland|3 - hematopoietic system|3 - lymphocyte|4 - animal|4 - leukocyte|4 - lymphoid cell|5 - tissues, cell types and enzyme sources|5 - hematopoietic cell|6 - blood",
#       "description": "thymocyte",
#       "name": "thymocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "diffuse large B-cell lymphoma cell",
#       "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#       "name": "DLBC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Spearman Rank Correlation Coefficient",
#           "name": "TCGA_DLBC_Correlation"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "P-value (-log10)",
#           "name": "TCGA_DLBC_Pvalue"
#         }
#       ]
#     },
#     {
#       "cell_of_origin": "lymphocyte",
#       "tissue_hierarchy": "0 - lymphocyte|1 - leukocyte|1 - lymphoid cell|2 - hematopoietic cell|2 - lymphoid tissue|3 - blood|3 - immune system|3 - hematopoietic system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "lymphocyte",
#       "name": "lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Binary Call For Known Functional Interaction",
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Example query

# %%
example_query = {
  "restriction_join": "union",
  "restriction_gt": "TCGA_GBM_Correlation,.2, GTEx_Brain_Correlation,.2",
  "restriction_lt": "TCGA_GBM_Pvalue,.05, GTEx_Brain_Pvalue,.01",
  "table": default_table,
  "ids2": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,3333,1111,112,3333",
  "columns": "TCGA_GBM_Correlation,TCGA_GBM_Pvalue,GTEx_Brain_Correlation,GTEx_Brain_Pvalue",
  "ids1": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,5722,1111,112,3333",
  "limit": 100000
}
try:
    query_submit = get('biggim/query', data=example_query)
    jprint(query_submit)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# {
#   "request_id": "c6f3dd0e-8602-44e2-90fb-b3d46a9b0915",
#   "status": "submitted"
# }

# %% [markdown]
# ### Check the status of the query

# %%
import time
try:
    while True:
        query_status = get('biggim/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(1)
            print("Checking again")
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
# Out:
# {
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/c6f3dd0e-8602-44e2-90fb-b3d46a9b0915000000000000.csv"
#   ],
#   "size": "2.72 KB",
#   "rows": 54,
#   "request_id": "c6f3dd0e-8602-44e2-90fb-b3d46a9b0915",
#   "status": "complete",
#   "processed_data": "0B"
# }

# %% [markdown]
# ### Get the results as dataframe

# %%
import pandas
result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
result
# Out:
#               GPID  Gene1  Gene2  TCGA_GBM_Correlation  TCGA_GBM_Pvalue  \
# 0   21760000005888   5888   2176                0.5430             9.83
# 1   51110000005888   5888   5111                0.5431             9.83
# 2   11110000005888   5888   1111                0.6530            15.20
# 3    1120000005888   5888    112                0.0019             0.01
# 4   10190000005888   5888   1019                0.5021             8.29
# 5   10190000005706   5706   1019                0.2200             1.80
# 6   51110000005706   5706   5111                0.3278             3.59
# 7    8890000005706   5706    889               -0.0382             0.17
# 8   10190000006996   6996   1019                0.3294             3.62
# 9    8890000006996   6996    889                0.0360             0.16
# 10  57060000006996   6996   5706                0.4229             5.83
# 11  51110000006996   6996   5111                0.2376             2.05
# 12  68150000006996   6996   6815                0.0446             0.20
# 13  21760000006996   6996   2176                0.0334             0.14
# 14   1120000001111   1111    112               -0.0028             0.01
# 15  10190000001111   1111   1019                0.4050             5.35
# 16  51110000057697  57697   5111                0.3341             3.72
# 17  69960000057697  57697   6996                0.3473             3.99
# 18  11110000057697  57697   1111                0.5158             8.78
# 19  71120000057697  57697   7112                0.6052            12.61
# 20  68150000057697  57697   6815                0.2524             2.27
# 21  10190000057697  57697   1019                0.2391             2.07
# 22  58880000057697  57697   5888                0.4545             6.74
# 23  21760000057697  57697   2176                0.5478            10.02
# 24  57060000057697  57697   5706                0.2880             2.85
# 25   8890000057697  57697    889                0.2489             2.21
# 26   1120000000889    889    112                0.1300             0.80
# 27   1120000002176   2176    112                0.2329             1.98
# 28  10190000002176   2176   1019                0.3024             3.10
# 29   8890000002176   2176    889                0.1706             1.20
# 30  11110000002176   2176   1111                0.7111            19.04
# 31  51110000006815   6815   5111                0.0325             0.14
# 32  10190000006815   6815   1019               -0.1305             0.81
# 33  11110000006815   6815   1111               -0.1197             0.72
# 34   8890000006815   6815    889                0.0928             0.50
# 35  57060000006815   6815   5706                0.4009             5.24
# 36  21760000006815   6815   2176               -0.2341             2.00
# 37  21760000007112   7112   2176                0.5989            12.30
# 38  69960000007112   7112   6996                0.4991             8.18
# 39   1120000007112   7112    112               -0.0171             0.07
# 40  11110000007112   7112   1111                0.7026            18.42
# 41  10190000007112   7112   1019                0.5341             9.48
# 42  58880000007112   7112   5888                0.7331            20.76
# 43  57060000007112   7112   5706                0.1942             1.47
# 44  51110000007112   7112   5111                0.6164            13.18
# 45   8890000007112   7112    889                0.0584             0.28
# 46  68150000007112   7112   6815               -0.1275             0.78
# 47   1120000005111   5111    112               -0.2945             2.96
# 48  11110000005111   5111   1111                0.6174            13.23
# 49  21760000005111   5111   2176                0.3506             4.06
# 50   8890000005111   5111    889                0.0933             0.51
# 51  10190000005111   5111   1019                0.4983             8.16
# 52   8890000001019   1019    889               -0.0116             0.05
# 53   1120000001019   1019    112               -0.2191             1.79
#
#     GTEx_Brain_Correlation  GTEx_Brain_Pvalue
# 0                   0.5403              95.62
# 1                   0.5510             100.17
# 2                  -0.0131               0.19
# 3                   0.5560             102.35
# 4                   0.3958              47.76
# 5                   0.4353              58.63
# 6                   0.7406             218.54
# 7                   0.8163             301.20
# 8                   0.4184              53.80
# 9                   0.8080             290.39
# 10                  0.6719             165.37
# 11                  0.6761             168.19
# 12                  0.5802             113.44
# 13                  0.6541             153.85
# 14                 -0.2528              19.09
# 15                  0.2117              13.49
# 16                  0.6808             171.41
# 17                  0.8152             299.70
# 18                  0.1124               4.19
# 19                  0.6201             133.93
# 20                  0.5279              90.55
# 21                  0.3888              45.98
# 22                  0.6227             135.34
# 23                  0.5941             120.24
# 24                  0.7209             201.65
# 25                  0.8262             314.88
# 26                  0.7565             233.37
# 27                  0.6387             144.51
# 28                  0.5253              89.52
# 29                  0.7029             187.50
# 30                 -0.0246               0.42
# 31                  0.7579             234.72
# 32                  0.5813             113.97
# 33                  0.2608              20.30
# 34                  0.6010             123.74
# 35                  0.4885              75.74
# 36                  0.5937             120.03
# 37                  0.7369             215.25
# 38                  0.6653             161.01
# 39                  0.7397             217.76
# 40                 -0.0678               1.79
# 41                  0.4414              60.44
# 42                  0.5651             106.40
# 43                  0.7647             241.41
# 44                  0.7789             256.21
# 45                  0.8263             315.00
# 46                  0.6142             130.73
# 47                  0.5295              91.17
# 48                  0.1711               9.00
# 49                  0.7075             191.00
# 50                  0.7489             226.12
# 51                  0.6435             147.39
# 52                  0.4816              73.38
# 53                  0.4109              51.74

# %% [markdown]
# # Full example
#
# Lets get relationships for a certain tissue where any tissue related correlation has a pvalue < .05
#
#  Assume we are interested in issues in lymphoid tissues

# %%
# get lymphoid substudies
substudies = get('metadata/tissue/%s' % ("blood",))


# we only want things in a specific table
table = default_table
pvalue_columns = []
column_names = []
for ss in substudies['substudies']:
    for column in ss['columns']:
        # only if column is from our table
        if column['table']['name'] == table:
            # add column to select
            column_names.append(column['name'])
            if column['interactions_type'] == 'P-value (-log10)':
                #add pvalue to where
                pvalue_columns.append(column['name'])
 
# grab columns with lower pvalues
pv = []
for p in pvalue_columns:
    pv.append(p)
    pv.append(str(.05))
query_arg = {}
query_arg['table'] = table
query_arg['columns'] = ','.join(sorted(column_names))
if len(pv):
    query_arg['restriction_lt'] = ','.join(pv)
# get if any of the lymphoid columns have 
query_arg['restriction_join'] = 'union'
query_arg['limit'] = 1000000
jprint(query_arg)

try:
    query_submit = get('biggim/query', data=query_arg)
    jprint(query_submit)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())

try:
    ctr = 1
    while True:
        
        query_status = get('biggim/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(ctr)
            ctr += 1
            #linear backoff
            print("Checking again")
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
if query_status['request_uri']:
    result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
    result.head()
else:
    print("Error see above")
# Out:
# {
#   "columns": "GIANT_b_lymphocyte_KnownFunctionalInteraction,GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_basophil_KnownFunctionalInteraction,GIANT_basophil_ProbabilityOfFunctionalInteraction,GIANT_blood_KnownFunctionalInteraction,GIANT_blood_ProbabilityOfFunctionalInteraction,GIANT_blood_plasma_KnownFunctionalInteraction,GIANT_blood_plasma_ProbabilityOfFunctionalInteraction,GIANT_blood_platelet_KnownFunctionalInteraction,GIANT_blood_platelet_ProbabilityOfFunctionalInteraction,GIANT_dendritic_cell_KnownFunctionalInteraction,GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction,GIANT_eosinophil_KnownFunctionalInteraction,GIANT_eosinophil_ProbabilityOfFunctionalInteraction,GIANT_granulocyte_KnownFunctionalInteraction,GIANT_granulocyte_ProbabilityOfFunctionalInteraction,GIANT_hematopoietic_stem_cell_KnownFunctionalInteraction,GIANT_hematopoietic_stem_cell_ProbabilityOfFunctionalInteraction,GIANT_leukocyte_KnownFunctionalInteraction,GIANT_leukocyte_ProbabilityOfFunctionalInteraction,GIANT_lymphocyte_KnownFunctionalInteraction,GIANT_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_macrophage_KnownFunctionalInteraction,GIANT_macrophage_ProbabilityOfFunctionalInteraction,GIANT_megakaryocyte_KnownFunctionalInteraction,GIANT_megakaryocyte_ProbabilityOfFunctionalInteraction,GIANT_monocyte_KnownFunctionalInteraction,GIANT_monocyte_ProbabilityOfFunctionalInteraction,GIANT_mononuclear_phagocyte_KnownFunctionalInteraction,GIANT_mononuclear_phagocyte_ProbabilityOfFunctionalInteraction,GIANT_natural_killer_cell_KnownFunctionalInteraction,GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction,GIANT_neutrophil_KnownFunctionalInteraction,GIANT_neutrophil_ProbabilityOfFunctionalInteraction,GIANT_t_lymphocyte_KnownFunctionalInteraction,GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_thymocyte_KnownFunctionalInteraction,GIANT_thymocyte_ProbabilityOfFunctionalInteraction,GTEx_Blood_Correlation,GTEx_Blood_Pvalue,TCGA_DLBC_Correlation,TCGA_DLBC_Pvalue,TCGA_LAML_Correlation,TCGA_LAML_Pvalue",
#   "restriction_lt": "TCGA_LAML_Pvalue,0.05,GTEx_Blood_Pvalue,0.05,TCGA_DLBC_Pvalue,0.05",
#   "table": "BigGIM_70_v1",
#   "limit": 1000000,
#   "restriction_join": "union"
# }
# {
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "submitted"
# }
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "message": "Extraction job is running.",
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "running"
# }
# Checking again
# {
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec000000000000.csv"
#   ],
#   "size": "269.42 MB",
#   "rows": 1000000,
#   "request_id": "fda4fcaa-fc2c-4940-8b11-06dc6d36c9ec",
#   "status": "complete",
#   "processed_data": "0B"
# }

# %%
result.describe()
# Out:
#                GPID         Gene1         Gene2  \
# count  1.000000e+06  1.000000e+06  1.000000e+06
# mean   1.113490e+15  3.162595e+06  1.113490e+05
# std    2.864479e+16  1.724336e+07  2.864479e+06
# min    1.000000e+10  1.300000e+01  1.000000e+00
# 25%    3.768000e+13  5.108500e+04  3.768000e+03
# 50%    8.633000e+13  8.390300e+04  8.633000e+03
# 75%    5.124800e+14  1.710240e+05  5.124800e+04
# max    1.053787e+18  1.092866e+08  1.053787e+08
#
#        GIANT_b_lymphocyte_KnownFunctionalInteraction  \
# count                                  981572.000000
# mean                                        0.000091
# std                                         0.009522
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction  \
# count                                      981572.000000
# mean                                            0.032410
# std                                             0.040762
# min                                             0.000014
# 25%                                             0.007402
# 50%                                             0.020462
# 75%                                             0.043506
# max                                             0.996109
#
#        GIANT_basophil_KnownFunctionalInteraction  \
# count                              981572.000000
# mean                                    0.000002
# std                                     0.001427
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        GIANT_basophil_ProbabilityOfFunctionalInteraction  \
# count                                      981572.000000
# mean                                            0.267310
# std                                             0.232961
# min                                             0.000075
# 25%                                             0.090176
# 50%                                             0.185712
# 75%                                             0.384964
# max                                             0.999977
#
#        GIANT_blood_KnownFunctionalInteraction  \
# count                           981572.000000
# mean                                 0.000878
# std                                  0.029621
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        GIANT_blood_ProbabilityOfFunctionalInteraction  \
# count                                   981572.000000
# mean                                         0.050434
# std                                          0.044822
# min                                          0.000326
# 25%                                          0.024408
# 50%                                          0.041415
# 75%                                          0.064434
# max                                          0.996149
#
#        GIANT_blood_plasma_KnownFunctionalInteraction        ...         \
# count                                  981572.000000        ...
# mean                                        0.000184        ...
# std                                         0.013578        ...
# min                                         0.000000        ...
# 25%                                         0.000000        ...
# 50%                                         0.000000        ...
# 75%                                         0.000000        ...
# max                                         1.000000        ...
#
#        GIANT_t_lymphocyte_KnownFunctionalInteraction  \
# count                                  981572.000000
# mean                                        0.000125
# std                                         0.011193
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction  \
# count                                      981572.000000
# mean                                            0.042617
# std                                             0.039923
# min                                             0.000208
# 25%                                             0.017192
# 50%                                             0.033352
# 75%                                             0.056911
# max                                             0.994210
#
#        GIANT_thymocyte_KnownFunctionalInteraction  \
# count                               981572.000000
# mean                                     0.000023
# std                                      0.004841
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        GIANT_thymocyte_ProbabilityOfFunctionalInteraction  \
# count                                      981572.000000
# mean                                            0.045766
# std                                             0.059814
# min                                             0.000011
# 25%                                             0.011122
# 50%                                             0.027561
# 75%                                             0.058950
# max                                             0.999469
#
#        GTEx_Blood_Correlation  GTEx_Blood_Pvalue  TCGA_DLBC_Correlation  \
# count           992398.000000      992398.000000          903756.000000
# mean                 0.236475          33.171874               0.019585
# std                  0.384304          44.131055               0.166694
# min                 -0.889700           0.000000              -0.894700
# 25%                 -0.003100           0.750000              -0.014000
# 50%                  0.145400           9.300000               0.002400
# 75%                  0.613700          57.717500               0.018500
# max                  0.962600         290.040000               0.920300
#
#        TCGA_DLBC_Pvalue  TCGA_LAML_Correlation  TCGA_LAML_Pvalue
# count     903756.000000          699181.000000     699181.000000
# mean           0.375821               0.039455          1.247562
# std            0.895111               0.156253          2.369636
# min            0.000000              -0.766900          0.000000
# 25%            0.020000              -0.008200          0.030000
# 50%            0.030000               0.004200          0.280000
# 75%            0.300000               0.108900          1.460000
# max           15.110000               0.933900         72.630000
#
# [8 rows x 47 columns]
