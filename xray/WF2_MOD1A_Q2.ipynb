# %%
#### This can also be used for:
# MOD1D Q2

# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
######
# BP #
######

# %%
#### Create a dict of the request, specifying the the query type to Q50 - "Which biological processes does $protein participate in"
#### Set protein to the curie id of the desired protein and run.
request = { "query_type_id": "Q50", "terms": { "protein": "UniProtKB:Q8IY92" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	interstrand cross-link repair	GO:0036297
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	response to intra-S DNA damage checkpoint signaling	GO:0072429
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DNA repair	GO:0006281
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	positive regulation of t-circle formation	GO:1904431
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	meiotic DNA double-strand break processing	GO:0000706
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DNA double-strand break processing involved in repair via single-strand annealing	GO:0010792
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	double-strand break repair via homologous recombination	GO:0000724
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleotide-excision repair	GO:0006289
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	telomeric D-loop disassembly	GO:0061820
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	t-circle formation	GO:0090656
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	negative regulation of telomere maintenance via telomere lengthening	GO:1904357
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	positive regulation of catalytic activity	GO:0043085
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	resolution of meiotic recombination intermediates	GO:0000712
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DNA replication	GO:0006260

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-11 21:37:04",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/375",
#     "message": "14 results found",
#     "original_question_text": "",
#     "query_type_id": "Q50",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "interstrand cross-link repair",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7057",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0036297",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Removal of a DNA interstrand crosslink (a covalent attachment of DNA bases on opposite strands of the DNA) and restoration of the DNA. DNA interstrand crosslinks occur when both strands of duplex DNA are covalently tethered together (e.g. by an exogenous or endogenous agent), thus preventing the strand unwinding necessary for essential DNA functions such as transcription and replication.",
#                         "id": "GO:0036297",
#                         "name": "interstrand cross-link repair",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0036297"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "interstrand cross-link repair",
#                 "GO:0036297"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and interstrand cross-link repair are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "response to intra-S DNA damage checkpoint signaling",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7058",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0072429",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A process that occurs in response to signals generated as a result of intra-S DNA damage checkpoint signaling.",
#                         "id": "GO:0072429",
#                         "name": "response to intra-S DNA damage checkpoint signaling",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0072429"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "response to intra-S DNA damage checkpoint signaling",
#                 "GO:0072429"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and response to intra-S DNA damage checkpoint signaling are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "DNA repair",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7059",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0006281",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The process of restoring DNA after damage. Genomes are subject to damage by chemical and physical agents in the environment (e.g. UV and ionizing radiations, chemical mutagens, fungal and bacterial toxins, etc.) and by free radicals or alkylating agents endogenously generated in metabolism. DNA is also damaged because of errors during its replication. A variety of different DNA repair pathways have been reported that include direct reversal, base excision repair, nucleotide excision repair, photoreactivation, bypass, double-strand break repair pathway, and mismatch repair pathway.",
#                         "id": "GO:0006281",
#                         "name": "DNA repair",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0006281"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "DNA repair",
#                 "GO:0006281"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and DNA repair are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "positive regulation of t-circle formation",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7060",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:1904431",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any process that activates or increases the frequency, rate or extent of t-circle formation.",
#                         "id": "GO:1904431",
#                         "name": "positive regulation of t-circle formation",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_1904431"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "positive regulation of t-circle formation",
#                 "GO:1904431"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and positive regulation of t-circle formation are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "meiotic DNA double-strand break processing",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7061",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000706",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The cell cycle process in which the 5' to 3' exonucleolytic resection of the DNA at the site of the break to form a 3' single-strand DNA overhang occurs. This takes place during meiosis.",
#                         "id": "GO:0000706",
#                         "name": "meiotic DNA double-strand break processing",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000706"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "meiotic DNA double-strand break processing",
#                 "GO:0000706"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and meiotic DNA double-strand break processing are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "DNA double-strand break processing involved in repair via single-strand annealing",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7062",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0010792",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The 5' to 3' exonucleolytic resection of the DNA at the site of the break to form a 3' single-strand DNA overhang that results in the repair of a double strand break via single-strand annealing.",
#                         "id": "GO:0010792",
#                         "name": "DNA double-strand break processing involved in repair via single-strand annealing",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0010792"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "DNA double-strand break processing involved in repair via single-strand annealing",
#                 "GO:0010792"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and DNA double-strand break processing involved in repair via single-strand annealing are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "double-strand break repair via homologous recombination",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7063",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000724",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The error-free repair of a double-strand break in DNA in which the broken DNA molecule is repaired using homologous sequences. A strand in the broken DNA searches for a homologous region in an intact chromosome to serve as the template for DNA synthesis. The restoration of two intact DNA molecules results in the exchange, reciprocal or nonreciprocal, of genetic material between the intact DNA molecule and the broken DNA molecule.",
#                         "id": "GO:0000724",
#                         "name": "double-strand break repair via homologous recombination",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000724"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "double-strand break repair via homologous recombination",
#                 "GO:0000724"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and double-strand break repair via homologous recombination are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nucleotide-excision repair",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7064",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0006289",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A DNA repair process in which a small region of the strand surrounding the damage is removed from the DNA helix as an oligonucleotide. The small gap left in the DNA helix is filled in by the sequential action of DNA polymerase and DNA ligase. Nucleotide excision repair recognizes a wide range of substrates, including damage caused by UV irradiation (pyrimidine dimers and 6-4 photoproducts) and chemicals (intrastrand cross-links and bulky adducts).",
#                         "id": "GO:0006289",
#                         "name": "nucleotide-excision repair",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0006289"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "nucleotide-excision repair",
#                 "GO:0006289"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and nucleotide-excision repair are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "telomeric D-loop disassembly",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7065",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0061820",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A telomere loop disassembly process that results in the disassembly of telomeric D-loops. A telomeric D-loop is a three-stranded DNA displacement loop that forms at the site where the telomeric 3' single-stranded DNA overhang (formed of the repeat sequence TTAGGG in mammals) is tucked back inside the double-stranded component of telomeric DNA molecule, thus forming a t-loop or telomeric-loop and protecting the chromosome terminus.",
#                         "id": "GO:0061820",
#                         "name": "telomeric D-loop disassembly",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0061820"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "telomeric D-loop disassembly",
#                 "GO:0061820"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and telomeric D-loop disassembly are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "t-circle formation",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7066",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0090656",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "A telomere maintenance process that results in the formation of a telomeric circle, or t-circle. A t-circle is an extrachromosomal duplex or single-stranded circular DNA molecule composed of t-arrays. T-circles are involved in the control of telomere length via alternative-lengthening of telomeres (ALT) pathway and telomere rapid deletion (TRD).",
#                         "id": "GO:0090656",
#                         "name": "t-circle formation",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0090656"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "t-circle formation",
#                 "GO:0090656"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and t-circle formation are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "negative regulation of telomere maintenance via telomere lengthening",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7067",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:1904357",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "Any process that stops, prevents or reduces the frequency, rate or extent of telomere maintenance via telomere lengthening.",
#                         "id": "GO:1904357",
#                         "name": "negative regulation of telomere maintenance via telomere lengthening",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_1904357"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "negative regulation of telomere maintenance via telomere lengthening",
#                 "GO:1904357"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and negative regulation of telomere maintenance via telomere lengthening are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "positive regulation of catalytic activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7068",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0043085",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "Any process that activates or increases the activity of an enzyme.",
#                         "id": "GO:0043085",
#                         "name": "positive regulation of catalytic activity",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0043085"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "positive regulation of catalytic activity",
#                 "GO:0043085"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and positive regulation of catalytic activity are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "resolution of meiotic recombination intermediates",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7069",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000712",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "The cleavage and rejoining of intermediates, such as Holliday junctions, formed during meiotic recombination to produce two intact molecules in which genetic material has been exchanged.",
#                         "id": "GO:0000712",
#                         "name": "resolution of meiotic recombination intermediates",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000712"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "resolution of meiotic recombination intermediates",
#                 "GO:0000712"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and resolution of meiotic recombination intermediates are connected by the relationship involved_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "DNA replication",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7070",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0006260",
#                         "type": "involved_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "The cellular metabolic process in which a cell duplicates one or more molecules of DNA. DNA replication begins when specific sequences, known as origins of replication, are recognized and bound by initiation proteins, and ends when the original DNA molecule has been completely duplicated and the copies topologically separated. The unit of replication usually corresponds to the genome of the cell, an organelle, or a virus. The template for replication can either be an existing DNA molecule or RNA.",
#                         "id": "GO:0006260",
#                         "name": "DNA replication",
#                         "type": "biological_process",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0006260"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "DNA replication",
#                 "GO:0006260"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and DNA replication are connected by the relationship involved_in"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "protein": "UniProtKB:Q8IY92"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }

# %%
######
# MF #
######

# %%
#### Create a dict of the request, specifying the the query type to Q56 - "Which molecular function is $protein capable of"
#### Set protein to the curie id of the desired protein and run.
request = { "query_type_id": "Q56", "terms": { "protein": "UniProtKB:Q8IY92" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	3'-flap endonuclease activity	GO:0048257
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	endodeoxyribonuclease activity	GO:0004520
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein binding	GO:0005515
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	crossover junction endodeoxyribonuclease activity	GO:0008821
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	enzyme activator activity	GO:0008047
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	5'-flap endonuclease activity	GO:0017108

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-14 20:07:51",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/393",
#     "message": "6 results found",
#     "original_question_text": "",
#     "query_type_id": "Q56",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "3'-flap endonuclease activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22290",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0048257",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Catalysis of the cleavage of a 3' flap structure in DNA, but not other DNA structures; processes the 3' ends of Okazaki fragments in lagging strand DNA synthesis.",
#                         "id": "GO:0048257",
#                         "name": "3'-flap endonuclease activity",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0048257"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "3'-flap endonuclease activity",
#                 "GO:0048257"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and 3'-flap endonuclease activity are connected by the relationship capable_of"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "endodeoxyribonuclease activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22291",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0004520",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Catalysis of the hydrolysis of ester linkages within deoxyribonucleic acid by creating internal breaks.",
#                         "id": "GO:0004520",
#                         "name": "endodeoxyribonuclease activity",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0004520"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "endodeoxyribonuclease activity",
#                 "GO:0004520"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and endodeoxyribonuclease activity are connected by the relationship capable_of"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "protein binding",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22292",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0005515",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Interacting selectively and non-covalently with any protein or protein complex (a complex of two or more proteins that may include other nonprotein molecules).",
#                         "id": "GO:0005515",
#                         "name": "protein binding",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0005515"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "protein binding",
#                 "GO:0005515"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and protein binding are connected by the relationship capable_of"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "crossover junction endodeoxyribonuclease activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22293",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0008821",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Catalysis of the endonucleolytic cleavage at a junction such as a reciprocal single-stranded crossover between two homologous DNA duplexes (Holliday junction).",
#                         "id": "GO:0008821",
#                         "name": "crossover junction endodeoxyribonuclease activity",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0008821"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "crossover junction endodeoxyribonuclease activity",
#                 "GO:0008821"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and crossover junction endodeoxyribonuclease activity are connected by the relationship capable_of"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "enzyme activator activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22294",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0008047",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Binds to and increases the activity of an enzyme.",
#                         "id": "GO:0008047",
#                         "name": "enzyme activator activity",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0008047"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "enzyme activator activity",
#                 "GO:0008047"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and enzyme activator activity are connected by the relationship capable_of"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "5'-flap endonuclease activity",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22295",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0017108",
#                         "type": "capable_of"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "Catalysis of the cleavage of a 5' flap structure in DNA, but not other DNA structures; processes the 5' ends of Okazaki fragments in lagging strand DNA synthesis.",
#                         "id": "GO:0017108",
#                         "name": "5'-flap endonuclease activity",
#                         "type": "molecular_function",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0017108"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "5'-flap endonuclease activity",
#                 "GO:0017108"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and 5'-flap endonuclease activity are connected by the relationship capable_of"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "protein": "UniProtKB:Q8IY92"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }

# %%
######
# CC #
######

# %%
#### Create a dict of the request, specifying the the query type to Q57 - "Which cellular component is $protein expressed in"
#### Set protein to the curie id of the desired protein and run.
request = { "query_type_id": "Q57", "terms": { "protein": "UniProtKB:Q8IY92" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nuclear chromatin	GO:0000790
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoplasm	GO:0005654
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ERCC4-ERCC1 complex	GO:0070522
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	chromosome, telomeric region	GO:0000781
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nuclear chromosome, telomeric region	GO:0000784
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	Holliday junction resolvase complex	GO:0048476
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	cytosol	GO:0005829
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	Slx1-Slx4 complex	GO:0033557
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	cell junction	GO:0030054

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-14 20:07:58",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/394",
#     "message": "9 results found",
#     "original_question_text": "",
#     "query_type_id": "Q57",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "nuclear chromatin",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22296",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000790",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The ordered and organized complex of DNA, protein, and sometimes RNA, that forms the chromosome in the nucleus.",
#                         "id": "GO:0000790",
#                         "name": "nuclear chromatin",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000790"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "nuclear chromatin",
#                 "GO:0000790"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and nuclear chromatin are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nucleoplasm",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22297",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0005654",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "That part of the nuclear content other than the chromosomes or the nucleolus.",
#                         "id": "GO:0005654",
#                         "name": "nucleoplasm",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0005654"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "nucleoplasm",
#                 "GO:0005654"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and nucleoplasm are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ERCC4-ERCC1 complex",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22298",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0070522",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A heterodimeric nucleotide-excision repair complex that has endonuclease activity specific for bubble structures characteristic of certain DNA lesions. The subunits are known as XPF/ERCC4 and ERCC1 in mammals, and Rad1p and Rad10p in S. cerevisiae.",
#                         "id": "GO:0070522",
#                         "name": "ERCC4-ERCC1 complex",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0070522"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "ERCC4-ERCC1 complex",
#                 "GO:0070522"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and ERCC4-ERCC1 complex are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "chromosome, telomeric region",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22299",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000781",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The terminal region of a linear chromosome that includes the telomeric DNA repeats and associated proteins.",
#                         "id": "GO:0000781",
#                         "name": "chromosome, telomeric region",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000781"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "chromosome, telomeric region",
#                 "GO:0000781"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and chromosome, telomeric region are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nuclear chromosome, telomeric region",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22300",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0000784",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The terminal region of a linear nuclear chromosome that includes the telomeric DNA repeats and associated proteins.",
#                         "id": "GO:0000784",
#                         "name": "nuclear chromosome, telomeric region",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0000784"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "nuclear chromosome, telomeric region",
#                 "GO:0000784"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and nuclear chromosome, telomeric region are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Holliday junction resolvase complex",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22301",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0048476",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A protein complex that mediates the conversion of a Holliday junction into two separate duplex DNA molecules; the complex includes a single- or multisubunit helicase that catalyzes the extension of heteroduplex DNA by branch migration and a nuclease that resolves the junction by nucleolytic cleavage.",
#                         "id": "GO:0048476",
#                         "name": "Holliday junction resolvase complex",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0048476"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "Holliday junction resolvase complex",
#                 "GO:0048476"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and Holliday junction resolvase complex are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytosol",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22302",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0005829",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The part of the cytoplasm that does not contain organelles but which does contain other particulate matter, such as protein complexes.",
#                         "id": "GO:0005829",
#                         "name": "cytosol",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0005829"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "cytosol",
#                 "GO:0005829"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and cytosol are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Slx1-Slx4 complex",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22303",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0033557",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "A heterodimeric protein complex that possesses an endonuclease activity that specifically cleaves certain types of branched DNA structures; because such structures often form during the replication ribosomal DNA (rDNA) repeats, the complex plays a role in the maintenance of rDNA. The subunits are known as Slx1 and Slx 4 in budding and fission yeasts, and are conserved in eukaryotes.",
#                         "id": "GO:0033557",
#                         "name": "Slx1-Slx4 complex",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0033557"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "Slx1-Slx4 complex",
#                 "GO:0033557"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and Slx1-Slx4 complex are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cell junction",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/22304",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "GO:0030054",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "A cellular component that forms a specialized region of connection between two or more cells or between a cell and the extracellular matrix. At a cell junction, anchoring proteins extend through the plasma membrane to link cytoskeletal proteins in one cell to cytoskeletal proteins in neighboring cells or to proteins in the extracellular matrix.",
#                         "id": "GO:0030054",
#                         "name": "cell junction",
#                         "type": "cellular_component",
#                         "uri": "http://purl.obolibrary.org/obo/GO_0030054"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "cell junction",
#                 "GO:0030054"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and cell junction are connected by the relationship expressed_in"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "protein": "UniProtKB:Q8IY92"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
