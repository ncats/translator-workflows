# %% [markdown]
# ### Accessing `ndex` data
#
# This notebook explores the API for [NDEx](http://home.ndexbio.org/index/).
#
# #### API and Documentation
#
# - http://www.home.ndexbio.org/using-the-ndex-server-api/

# %% [markdown]
# ##### Notes from Chris M and Dexter P
#
# > I see there are some docs here
# > http://www.home.ndexbio.org/using-the-ndex-server-api/
#
# > It sounds like we should be using v2, but I note the link is currently broken
# > http://www.ndexbio.org/v2
#
# > Basically we need two calls:
#
# > What networks mention gene G? (any ID type is fine)
# > Fetch graph object for network N (assuming some standard graph representation)
# > As an aside: Another useful query would be "what networks exist for disease D", where D would be something like a disease ontology ID, and the results would include data-derived ontologies based on gene sets for D. I can do text searches on the web interface like this: http://ndexbio.org/#/search?searchType=All&searchString=fanconi This may require Mike to add additional metadata to graphs like this one:
# > http://ndexbio.org/#/newNetwork/ab9bb6de-081a-11e7-aba2-0ac135e8bacf -- we don't really need this right now but might be useful to have in the future.
#
#
# > http://www.ndexbio.org/v2 is just the root URL
#
# > To get the status of the public server, try this get:
#
# > http://www.ndexbio.org/v2/admin/status
#
# > Here is the section from the docs about searching for networks:
#
# > Search Networks
#
# > /search/network?start={number}&size={number}
#
# > Method: POST
#
# > Authentication: Optional
#
# > Description:
#
# > Returns a SearchResult object which contains an array of NetworkSummary objects and total hit count of the search.
# > The POSTed JSON object must have a searchString parameter.
# > The start and size parameter are optional. The default values are start = 0 and size = 100
# > The search can also be constrained to networks owned by a specified account, by permissions, by group permissions as > specified by the following parameters in the POSTed JSON object:
# > searchString	Required. A whitespace-delimited string that is handled according to Lucene search string protocol.
# > permission	Optional. By default, this parameter is not set, meaning that there is no filtering of networks based > on permission. If this parameter is set, it must be either ‘WRITE’ or ‘READ’.
#
# > If set to ‘WRITE’, the search will only return networks for which the authenticated user has edit or admin permission.
#
# > If set to READ, the search will only return networks for which the authenticated user has edit, admin, or read permission. Note that this only includes networks that are readable due to explicit permission, not networks that are readable because they have been made PUBLIC.
#
# > includeGroups	Optional. Boolean value, defaults to false.
#
# > If includeGroups is true, the search will also return networks based on permissions from the authenticated user’s group memberships.
#
# > This enables search to return a network where a group has permission to access the network and the user is a member of the group.
#
# > accountName	Optional. String value. If the accountName parameter is provided, then the search will be constrained to networks owned by that account.

# %% [markdown]
# ##### CURL command for NDEx
#
# `curl -H 'Content-Type: application/json'  --data-binary '{"searchString":"Fanconi Anemia"}' http://www.ndexbio.org/v2/search/network/`

# %%
# !curl -H 'Content-Type: application/json'  --data-binary '{"searchString":"Fanconi Anemia"}' http://www.ndexbio.org/v2/search/network/
# Out:
# {"numFound":23,"start":0,"networks":[{"ownerUUID":"bf69b56e-a1fa-11e5-87e3-06603eb7f303","isReadOnly":false,"subnetworkIds":[1305],"errorMessage":null,"isValid":true,"warnings":[],"isShowcase":true,"visibility":"PUBLIC","edgeCount":192,"nodeCount":142,"uri":null,"version":null,"owner":"mikeyu","name":"Fanconi Anemia Gene Ontology (FangO)","properties":[{"subNetworkId":1305,"predicateString":"Parameters","dataType":"string","value":"Integrated Similarity Threshold >3, CLIXO alpha=0.1"},{"subNetworkId":1305,"predicateString":"disease","dataType":"string","value":"Fanconi Anemia"},{"subNetworkId":1305,"predicateString":"networkType","dataType":"string","value":"Data-Driven Gene Ontology"},{"subNetworkId":1305,"predicateString":"author","dataType":"string","value":"Michael Yu"},{"subNetworkId":1305,"predicateString":"organism","dataType":"string","value":"Homo Sapiens"},{"subNetworkId":1305,"predicateString":"methods","dataType":"string","value":"CLIXO"},{"subNetworkId":1305,"predicateSt
# ...

# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize
from urllib.parse import urlencode

pd.set_option('max_colwidth', 3800)
pd.set_option('display.expand_frame_repr', False)

ndexBase = "http://www.ndexbio.org/v2/search/network/"
headers = {'Content-Type': 'application/json'}

json = requests.post(ndexBase, headers=headers, json={'searchString': 'Fanconi Anemia'})

df = pd.DataFrame.from_records(json.json()['networks'])
df
# Out:
#      creationTime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description  edgeCount errorMessage                            externalId isDeleted isReadOnly isShowcase isValid  modifi
# ...
