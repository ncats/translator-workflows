# %% [markdown]
# # Using ROBOKOP's expand service

# %% [markdown]
# The most basic functionality in answering questions is to start with an entity and find other connected entities.
# In this context, an entity is defined by a curie-formatted identifier.
#
# ROBOKOP's expand service performs this function.  The user provides an identifier and its biolink-model type, and the type of entities that it wants returned.  ROBOKOP will call out to any sources that it is aware of that can answer the particular question.  If multiple services can provide the information, ROBOKOP will call all of them.  It will then rank the results based on literature co-occurence data.

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# The following python function shows how to call the ROBOKOP expand service.  For the moment, let's focus only on the arguments `type1`, `identifier`, and `type2`.    The expand service is called when a user has an `identifier` of `type1`, and wants to know what entities of `type2` are connected to it.

# %%
def expand(type1,identifier,type2,rebuild=None,output_format=None,predicate=None,direction=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    print(url)
    params = {'rebuild': rebuild, 
              'predicate': predicate,
              'output_format': output_format,
              'direction': direction}
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %% [markdown]
# ## Basic Usage

# %%
complex_parts = expand('cellular_component','GO:1990157','chemical_substance')
# Out:
# http://robokop.renci.org:80/api/simple/expand/cellular_component/GO:1990157/chemical_substance
# Return Status: 200

# %%
x={ name:n['name'] for n in complex_parts['knowledge_graph']['nodes']}
import pd
df = pd.DataFrame(x)
df.head()
# Out:
#   File "<ipython-input-6-64d4c6d41b1c>", line 1
#     x={node_id:n['id'], name:n['name'] for n in complex_parts['knowledge_graph']['nodes']}
#                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# In this example, we have the `disease` Fanconi Anemia defined by the curie identifier `MONDO:0019391`.  We want to know the `phenotypic_feature`s that are associated with it.  We can call the function above like this:

# %%
fanconi_phenotypes = expand('disease', 'MONDO:0019391', 'phenotypic_feature')
# Out:
# Return Status: 200

# %% [markdown]
# ## Service Output

# %% [markdown]
# The result that comes back is json in the KG-standard.
#
# Importantly, results are ranked using ROBOKOP's standard ranking algorithm, which is looking at literature co-occurance based on the `omnicorp` repository.

# %%
#Uncomment to see a big long json (which uses up lots of room in the github render)
#print(json.dumps(fanconi_phenotypes,indent=4))

# %% [markdown]
# This output has plenty of information, but for display purposes, it's sometimes easier to tabularize with the following function:

# %%
def parse_answer(returnanswer):
    #First, parse out the parts of the kg that we want, names and types
    kg_node_names = { n['id']: n['name'] if 'name' in n else n['id'] for n in returnanswer['knowledge_graph']['nodes'] }
    kg_edge_types = { e['id']: e['type'] for e in returnanswer['knowledge_graph']['edges']}
    kg_edge_sources = { e['id']: e['edge_source'] for e in returnanswer['knowledge_graph']['edges']}
    #now put the answers into a table, looking up node/edge info from the above dicts
    #because of the question, we know that we're interested in the binding for "n1" and "e0"
    # -By definition, this will always be the case for the expand function
    #this is quick-n-dirty, so we're also limiting ourselves to the first edge, even if there is more than one
    answers = [ {"result_id": answer['node_bindings']['n1'], 
                 "result_name": kg_node_names[answer['node_bindings']['n1']], #if 'name' in node else node['id'], 
                 "type":        kg_edge_types[answer['edge_bindings']['e0'][0]],
                 "source":      kg_edge_sources[answer['edge_bindings']['e0'][0]],
                 "score" :      answer['score']}
              for answer in returnanswer['answers']]
    return pd.DataFrame(answers)

# %%
fanconi_pheno_frame = parse_answer(fanconi_phenotypes)
fanconi_pheno_frame
# Out:
#       result_id                                     result_name     score  \
# 0    HP:0005505                               Refractory anemia  1.619721
# 1    HP:0100615                                Ovarian neoplasm  1.619721
# 2    HP:0002488                                  Acute leukemia  1.619721
# 3    HP:0002860                         Squamous cell carcinoma  1.619721
# 4    HP:0004430                Severe combined immunodeficiency  1.619721
# 5    HP:0002721                                Immunodeficiency  1.619721
# 6    HP:0001402                        Hepatocellular carcinoma  1.619721
# 7    HP:0000286                                      Epicanthus  1.619721
# 8    HP:0003002                                Breast carcinoma  1.619721
# 9    HP:0004377                          Hematological neoplasm  1.619721
# 10   HP:0007354                   Amyotrophic lateral sclerosis  1.619721
# 11   HP:0008064                                      Ichthyosis  1.619721
# 12   HP:0006721                    Acute lymphoblastic leukemia  1.619721
# 13   HP:0003254                       Abnormality of DNA repair  1.619721
# 14   HP:0001915                                 Aplastic anemia  1.619721
# 15   HP:0000824                       Growth hormone deficiency  1.619721
# 16   HP:0004808                          Acute myeloid leukemia  1.619721
# 17   HP:0005560                 Imbalanced hemoglobin synthesis  1.619721
# 18   HP:0100806                                          Sepsis  1.619721
# 19   HP:0005510                    Transient erythroblastopenia  1.619721
# 20   HP:0001972                               Macrocytic anemia  1.619721
# 21   HP:0001251                                          Ataxia  1.619721
# 22   HP:0011018                   Abnormality of the cell cycle  1.619721
# 23   HP:0004431                           Complement deficiency  1.619721
# 24   HP:0004810                   Congenital hypoplastic anemia  1.619721
# 25   HP:0000789                                     Infertility  1.619721
# 26   HP:0000953                   Hyperpigmentation of the skin  1.619721
# 27   HP:0001900                            Increased hemoglobin  1.619721
# 28   HP:0001908                              Hypoplastic anemia  1.619721
# 29   HP:0000135                                    Hypogonadism  1.619721
# ..          ...                                             ...       ...
# 220  HP:0001053                      Hypopigmented skin patches  0.517653
# 221  HP:0001631                            Atrial septal defect  0.517653
# 222  HP:0002823                 Abnormality of femur morphology  0.517653
# 223  HP:0005344              Abnormal carotid artery morphology  0.517653
# 224  HP:0004349                    Reduced bone mineral density  0.517653
# 225  HP:0000218                                     High palate  0.517653
# 226  HP:0000486                                      Strabismus  0.517653
# 227  HP:0008053                  Aplasia/Hypoplasia of the iris  0.517653
# 228  HP:0000813                               Bicornuate uterus  0.517653
# 229  HP:0001639                     Hypertrophic cardiomyopathy  0.517653
# 230  HP:0100026                      Arteriovenous malformation  0.517653
# 231  HP:0000864  Abnormality of the hypothalamus-pituitary axis  0.517653
# 232  HP:0007565                     Multiple cafe-au-lait spots  0.517653
# 233  HP:0008572                       External ear malformation  0.517653
# 234  HP:0002007                                 Frontal bossing  0.517653
# 235  HP:0004209                  Clinodactyly of the 5th finger  0.517653
# 236  HP:0000957                               Cafe-au-lait spot  0.517653
# 237  HP:0002023                                    Anal atresia  0.517653
# 238  HP:0001903                                          Anemia  0.517653
# 239  HP:0100760                                Clubbing of toes  0.517653
# 240  HP:0000639                                       Nystagmus  0.517653
# 241  HP:0002827                                 Hip dislocation  0.517653
# 242  HP:0001199                             Triphalangeal thumb  0.517653
# 243  HP:0012745                         Short palpebral fissure  0.517653
# 244  HP:0006101                               Finger syndactyly  0.517653
# 245  HP:0003022                          Hypoplasia of the ulna  0.517653
# 246  HP:0002251                           Aganglionic megacolon  0.517653
# 247  HP:0001636                             Tetralogy of Fallot  0.517653
# 248  HP:0000483                                     Astigmatism  0.517653
# 249  HP:0006501                Aplasia/Hypoplasia of the radius  0.517653
#
#                             source           type
# 0    biolink.disease_get_phenotype  has_phenotype
# 1    biolink.disease_get_phenotype  has_phenotype
# 2    biolink.disease_get_phenotype  has_phenotype
# 3    biolink.disease_get_phenotype  has_phenotype
# 4    biolink.disease_get_phenotype  has_phenotype
# 5    biolink.disease_get_phenotype  has_phenotype
# 6    biolink.disease_get_phenotype  has_phenotype
# 7    biolink.disease_get_phenotype  has_phenotype
# 8    biolink.disease_get_phenotype  has_phenotype
# 9    biolink.disease_get_phenotype  has_phenotype
# 10   biolink.disease_get_phenotype  has_phenotype
# 11   biolink.disease_get_phenotype  has_phenotype
# 12   biolink.disease_get_phenotype  has_phenotype
# 13   biolink.disease_get_phenotype  has_phenotype
# 14   biolink.disease_get_phenotype  has_phenotype
# 15   biolink.disease_get_phenotype  has_phenotype
# 16   biolink.disease_get_phenotype  has_phenotype
# 17   biolink.disease_get_phenotype  has_phenotype
# 18   biolink.disease_get_phenotype  has_phenotype
# 19   biolink.disease_get_phenotype  has_phenotype
# 20   biolink.disease_get_phenotype  has_phenotype
# 21   biolink.disease_get_phenotype  has_phenotype
# 22   biolink.disease_get_phenotype  has_phenotype
# 23   biolink.disease_get_phenotype  has_phenotype
# 24   biolink.disease_get_phenotype  has_phenotype
# 25   biolink.disease_get_phenotype  has_phenotype
# 26   biolink.disease_get_phenotype  has_phenotype
# 27   biolink.disease_get_phenotype  has_phenotype
# 28   biolink.disease_get_phenotype  has_phenotype
# 29   biolink.disease_get_phenotype  has_phenotype
# ..                             ...            ...
# 220  biolink.disease_get_phenotype  has_phenotype
# 221  biolink.disease_get_phenotype  has_phenotype
# 222  biolink.disease_get_phenotype  has_phenotype
# 223  biolink.disease_get_phenotype  has_phenotype
# 224  biolink.disease_get_phenotype  has_phenotype
# 225  biolink.disease_get_phenotype  has_phenotype
# 226  biolink.disease_get_phenotype  has_phenotype
# 227  biolink.disease_get_phenotype  has_phenotype
# 228  biolink.disease_get_phenotype  has_phenotype
# 229  biolink.disease_get_phenotype  has_phenotype
# 230  biolink.disease_get_phenotype  has_phenotype
# 231  biolink.disease_get_phenotype  has_phenotype
# 232  biolink.disease_get_phenotype  has_phenotype
# 233  biolink.disease_get_phenotype  has_phenotype
# 234  biolink.disease_get_phenotype  has_phenotype
# 235  biolink.disease_get_phenotype  has_phenotype
# 236  biolink.disease_get_phenotype  has_phenotype
# 237  biolink.disease_get_phenotype  has_phenotype
# 238  biolink.disease_get_phenotype  has_phenotype
# 239  biolink.disease_get_phenotype  has_phenotype
# 240  biolink.disease_get_phenotype  has_phenotype
# 241  biolink.disease_get_phenotype  has_phenotype
# 242  biolink.disease_get_phenotype  has_phenotype
# 243  biolink.disease_get_phenotype  has_phenotype
# 244  biolink.disease_get_phenotype  has_phenotype
# 245  biolink.disease_get_phenotype  has_phenotype
# 246  biolink.disease_get_phenotype  has_phenotype
# 247  biolink.disease_get_phenotype  has_phenotype
# 248  biolink.disease_get_phenotype  has_phenotype
# 249  biolink.disease_get_phenotype  has_phenotype
#
# [250 rows x 5 columns]

# %% [markdown]
# In this case, all of the results are coming from biolink's disease to phenotype function.  As mentioned above, results here are ranked by their literature co-occurence with the query term.
#
# If the caller doesn't want to dig around in a json return, they can also ask for a csv-style list:

# %%
fanconi_phenotypes_csv = expand('disease', 'MONDO:0019391', 'phenotypic_feature',output_format = 'csv')
# Out:
# Return Status: 200

# %%
#fanconi_phenotypes_csv
fanconi_phenotypes_csv.split('\n')
# Out:
# ['n0,n1',
#  'MONDO:0019391,HP:0005505',
#  'MONDO:0019391,HP:0100615',
#  'MONDO:0019391,HP:0002488',
#  'MONDO:0019391,HP:0002860',
#  'MONDO:0019391,HP:0004430',
#  'MONDO:0019391,HP:0002721',
#  'MONDO:0019391,HP:0001402',
#  'MONDO:0019391,HP:0000286',
#  'MONDO:0019391,HP:0003002',
#  'MONDO:0019391,HP:0004377',
#  'MONDO:0019391,HP:0007354',
#  'MONDO:0019391,HP:0008064',
#  'MONDO:0019391,HP:0006721',
#  'MONDO:0019391,HP:0003254',
#  'MONDO:0019391,HP:0001915',
#  'MONDO:0019391,HP:0000824',
#  'MONDO:0019391,HP:0004808',
#  'MONDO:0019391,HP:0005560',
#  'MONDO:0019391,HP:0100806',
#  'MONDO:0019391,HP:0005510',
#  'MONDO:0019391,HP:0001972',
#  'MONDO:0019391,HP:0001251',
#  'MONDO:0019391,HP:0011018',
#  'MONDO:0019391,HP:0004431',
#  'MONDO:0019391,HP:0004810',
#  'MONDO:0019391,HP:0000789',
#  'MONDO:0019391,HP:0000953',
#  'MONDO:0019391,HP:0001900',
#  'MONDO:0019391,HP:0001908',
#  'MONDO:0019391,HP:0000135',
#  'MONDO:0019391,HP:0100608',
#  'MONDO:0019391,HP:0010650',
#  'MONDO:0019391,HP:0010972',
#  'MONDO:0019391,HP:0001009',
#  'MONDO:0019391,HP:0004820',
#  'MONDO:0019391,HP:0001878',
#  'MONDO:0019391,HP:0000164',
#  'MONDO:0019391,HP:0001973',
#  'MONDO:0019391,HP:0001895',
#  'MONDO:0019391,HP:0004859',
#  'MONDO:0019391,HP:0003220',
#  'MONDO:0019391,HP:0002863',
#  'MONDO:0019391,HP:0005528',
#  'MONDO:0019391,HP:0001873',
#  'MONDO:0019391,HP:0001905',
#  'MONDO:0019391,HP:0000175',
#  'MONDO:0019391,HP:0003125',
#  'MONDO:0019391,HP:0000316',
#  'MONDO:0019391,HP:0006265',
#  'MONDO:0019391,HP:0000077',
#  'MONDO:0019391,HP:0001876',
#  'MONDO:0019391,HP:0000252',
#  'MONDO:0019391,HP:0001909',
#  'MONDO:0019391,HP:0001875',
#  'MONDO:0019391,HP:0001882',
#  'MONDO:0019391,HP:0009778',
#  'MONDO:0019391,HP:0001392',
#  'MONDO:0019391,HP:0000297',
#  'MONDO:0019391,HP:0006872',
#  'MONDO:0019391,HP:0000601',
#  'MONDO:0019391,HP:0000463',
#  'MONDO:0019391,HP:0011133',
#  'MONDO:0019391,HP:0005387',
#  'MONDO:0019391,HP:0000606',
#  'MONDO:0019391,HP:0001574',
#  'MONDO:0019391,HP:0006802',
#  'MONDO:0019391,HP:0007378',
#  'MONDO:0019391,HP:0001874',
#  'MONDO:0019391,HP:0002060',
#  'MONDO:0019391,HP:0000858',
#  'MONDO:0019391,HP:0011792',
#  'MONDO:0019391,HP:0002664',
#  'MONDO:0019391,HP:0005561',
#  'MONDO:0019391,HP:3000030',
#  'MONDO:0019391,HP:0005518',
#  'MONDO:0019391,HP:0003474',
#  'MONDO:0019391,HP:0011282',
#  'MONDO:0019391,HP:0011873',
#  'MONDO:0019391,HP:0000008',
#  'MONDO:0019391,HP:0011368',
#  'MONDO:0019391,HP:0100013',
#  'MONDO:0019391,HP:0011992',
#  'MONDO:0019391,HP:0005339',
#  'MONDO:0019391,HP:0040075',
#  'MONDO:0019391,HP:0012337',
#  'MONDO:0019391,HP:0012372',
#  'MONDO:0019391,HP:0011024',
#  'MONDO:0019391,HP:0009601',
#  'MONDO:0019391,HP:0031492',
#  'MONDO:0019391,HP:0040195',
#  'MONDO:0019391,HP:0000929',
#  'MONDO:0019391,HP:0000830',
#  'MONDO:0019391,HP:0000078',
#  'MONDO:0019391,HP:0012503',
#  'MONDO:0019391,HP:0011991',
#  'MONDO:0019391,HP:0001072',
#  'MONDO:0019391,HP:0001911',
#  'MONDO:0019391,HP:0011927',
#  'MONDO:0019391,HP:0004447',
#  'MONDO:0019391,HP:0010831',
#  'MONDO:0019391,HP:0008069',
#  'MONDO:0019391,HP:0012244',
#  'MONDO:0019391,HP:0002896',
#  'MONDO:0019391,HP:0000818',
#  'MONDO:0019391,HP:0010785',
#  'MONDO:0019391,HP:0011276',
#  'MONDO:0019391,HP:0008373',
#  'MONDO:0019391,HP:0000326',
#  'MONDO:0019391,HP:0011793',
#  'MONDO:0019391,HP:0000079',
#  'MONDO:0019391,HP:0007373',
#  'MONDO:0019391,HP:0008056',
#  'MONDO:0019391,HP:0012638',
#  'MONDO:0019391,HP:0001901',
#  'MONDO:0019391,HP:0011297',
#  'MONDO:0019391,HP:0002012',
#  'MONDO:0019391,HP:0100547',
#  'MONDO:0019391,HP:0010787',
#  'MONDO:0019391,HP:0002398',
#  'MONDO:0019391,HP:0031093',
#  'MONDO:0019391,HP:0000137',
#  'MONDO:0019391,HP:0011446',
#  'MONDO:0019391,HP:0009381',
#  'MONDO:0019391,HP:0012145',
#  'MONDO:0019391,HP:0011747',
#  'MONDO:0019391,HP:0000002',
#  'MONDO:0019391,HP:0012374',
#  'MONDO:0019391,HP:0011124',
#  'MONDO:0019391,HP:0001317',
#  'MONDO:0019391,HP:0011443',
#  'MONDO:0019391,HP:0410042',
#  'MONDO:0019391,HP:0007367',
#  'MONDO:0019391,HP:0011902',
#  'MONDO:0019391,HP:0010662',
#  'MONDO:0019391,HP:0002180',
#  'MONDO:0019391,HP:0031065',
#  'MONDO:0019391,HP:0002450',
#  'MONDO:0019391,HP:0031072',
#  'MONDO:0019391,HP:0001156',
#  'MONDO:0019391,HP:0002665',
#  'MONDO:0019391,HP:0007379',
#  'MONDO:0019391,HP:0025065',
#  'MONDO:0019391,HP:0011283',
#  'MONDO:0019391,HP:0012757',
#  'MONDO:0019391,HP:0003117',
#  'MONDO:0019391,HP:0009830',
#  'MONDO:0019391,HP:0000144',
#  'MONDO:0019391,HP:0025035',
#  'MONDO:0019391,HP:0030012',
#  'MONDO:0019391,HP:0000769',
#  'MONDO:0019391,HP:0045060',
#  'MONDO:0019391,HP:0011354',
#  'MONDO:0019391,HP:0007364',
#  'MONDO:0019391,HP:0000765',
#  'MONDO:0019391,HP:0005368',
#  'MONDO:0019391,HP:0010756',
#  'MONDO:0019391,HP:0000140',
#  'MONDO:0019391,HP:0004364',
#  'MONDO:0019391,HP:0030791',
#  'MONDO:0019391,HP:0012130',
#  'MONDO:0019391,HP:0001167',
#  'MONDO:0019391,HP:0100887',
#  'MONDO:0019391,HP:0000759',
#  'MONDO:0019391,HP:0010758',
#  'MONDO:0019391,HP:0030731',
#  'MONDO:0019391,HP:0002692',
#  'MONDO:0019391,HP:0000951',
#  'MONDO:0019391,HP:0100568',
#  'MONDO:0019391,HP:0004823',
#  'MONDO:0019391,HP:0010978',
#  'MONDO:0019391,HP:0031071',
#  'MONDO:0019391,HP:0001999',
#  'MONDO:0019391,HP:0011895',
#  'MONDO:0019391,HP:0012324',
#  'MONDO:0019391,HP:0030680',
#  'MONDO:0019391,HP:0003468',
#  'MONDO:0019391,HP:0002119',
#  'MONDO:0019391,HP:0001263',
#  'MONDO:0019391,HP:0002575',
#  'MONDO:0019391,HP:0012210',
#  'MONDO:0019391,HP:0001172',
#  'MONDO:0019391,HP:0001872',
#  'MONDO:0019391,HP:0002960',
#  'MONDO:0019391,HP:0000163',
#  'MONDO:0019391,HP:0011842',
#  'MONDO:0019391,HP:0030976',
#  'MONDO:0019391,HP:0001928',
#  'MONDO:0019391,HP:0410004',
#  'MONDO:0019391,HP:0100737',
#  'MONDO:0019391,HP:0011875',
#  'MONDO:0019391,HP:0000202',
#  'MONDO:0019391,HP:0011338',
#  'MONDO:0019391,HP:0010989',
#  'MONDO:0019391,HP:0000152',
#  'MONDO:0019391,HP:0003256',
#  'MONDO:0019391,HP:0000924',
#  'MONDO:0019391,HP:0000153',
#  'MONDO:0019391,HP:0001249',
#  'MONDO:0019391,HP:0001824',
#  'MONDO:0019391,HP:0000568',
#  'MONDO:0019391,HP:0000268',
#  'MONDO:0019391,HP:0000028',
#  'MONDO:0019391,HP:0006824',
#  'MONDO:0019391,HP:0001000',
#  'MONDO:0019391,HP:0002245',
#  'MONDO:0019391,HP:0000347',
#  'MONDO:0019391,HP:0001347',
#  'MONDO:0019391,HP:0000324',
#  'MONDO:0019391,HP:0001629',
#  'MONDO:0019391,HP:0000340',
#  'MONDO:0019391,HP:0001537',
#  'MONDO:0019391,HP:0000047',
#  'MONDO:0019391,HP:0001511',
#  'MONDO:0019391,HP:0000582',
#  'MONDO:0019391,HP:0001643',
#  'MONDO:0019391,HP:0100587',
#  'MONDO:0019391,HP:0002414',
#  'MONDO:0019391,HP:0000453',
#  'MONDO:0019391,HP:0000027',
#  'MONDO:0019391,HP:0000010',
#  'MONDO:0019391,HP:0001053',
#  'MONDO:0019391,HP:0001631',
#  'MONDO:0019391,HP:0002823',
#  'MONDO:0019391,HP:0005344',
#  'MONDO:0019391,HP:0004349',
#  'MONDO:0019391,HP:0000218',
#  'MONDO:0019391,HP:0000486',
#  'MONDO:0019391,HP:0008053',
#  'MONDO:0019391,HP:0000813',
#  'MONDO:0019391,HP:0001639',
#  'MONDO:0019391,HP:0100026',
#  'MONDO:0019391,HP:0000864',
#  'MONDO:0019391,HP:0007565',
#  'MONDO:0019391,HP:0008572',
#  'MONDO:0019391,HP:0002007',
#  'MONDO:0019391,HP:0004209',
#  'MONDO:0019391,HP:0000957',
#  'MONDO:0019391,HP:0002023',
#  'MONDO:0019391,HP:0001903',
#  'MONDO:0019391,HP:0100760',
#  'MONDO:0019391,HP:0000639',
#  'MONDO:0019391,HP:0002827',
#  'MONDO:0019391,HP:0001199',
#  'MONDO:0019391,HP:0012745',
#  'MONDO:0019391,HP:0006101',
#  'MONDO:0019391,HP:0003022',
#  'MONDO:0019391,HP:0002251',
#  'MONDO:0019391,HP:0001636',
#  'MONDO:0019391,HP:0000483',
#  'MONDO:0019391,HP:0006501']

# %% [markdown]
# ## Curie inputs and synonymization

# %% [markdown]
# ROBOKOP will perform identifier translations when it can.  This means that for most common input types, there are a range of curie prefixes that will work without the user doing any work.
#
# For example, Fanconi Anemia is identified as `MONDO:0019339`, which is ROBOKOP's preferred identifier, but that is equivalent to `DOID:13636`, `Orphanet:84`, `NCIT:C62505`, `UMLS:C0015625`, `MeSH:D005199`, and `MedDRA:10055206`.  We can see that calling expand with any of these inputs will produce the same results:

# %%
equivalents=['MedDRA:10055206','DOID:13636','UMLS:C0015625','Orphanet:84','NCIT:C62505','MeSH:D005199']
for equivalent_id in equivalents:
    e_result = expand('disease', equivalent_id, 'phenotypic_feature',output_format='csv')
    print(equivalent_id, len(e_result.split('\n')), e_result.split('\n')[1])
# Out:
# Return Status: 200
# MedDRA:10055206 251 MONDO:0019391,HP:0005505
# Return Status: 200
# DOID:13636 251 MONDO:0019391,HP:0005505
# Return Status: 200
# UMLS:C0015625 251 MONDO:0019391,HP:0005505
# Return Status: 200
# Orphanet:84 251 MONDO:0019391,HP:0005505
# Return Status: 200
# NCIT:C62505 251 MONDO:0019391,HP:0005505
# Return Status: 200
# MeSH:D005199 251 MONDO:0019391,HP:0005505

# %% [markdown]
# ## Query Types

# %% [markdown]
# The `type1` and `type2` arguments are chosen from the [biolink-model](https://biolink.github.io/biolink-model/).  While any type in the model is potentially acceptable, only some types are exposed via ROBOKOP.  The current list of acceptable types is:
#
# * disease_or_phenotypic_feature
#     * **phenotypic_feature**
#     * **disease**
#        * genetic_condition
#
# * **gene**
#
# * **anatomical_entity**
#     * **cell**
#     * gross_anatomical_structure
#     * cellular_component
#
# * **biological_process_or_activity**
#     * biological_process
#         * pathway
#     * molecular_activity
#
# * **chemical_substance**
#     * metabolite
#     * drug
#
# ROBOKOP understands the hierarchical nature of these relationships and can figure out services to call at a different level of the heirarchy.  For instance, suppose an adverse events service returns a mix of diseases and phenotypic features, but the caller only wants diseases.  The user can then ask for diseases, and the service will be called an automatically filtered.  On the other hand, if a user is willing to accept, say, either disease or phenotypic features for a query, then any function that returns both, or either type will automatically get called.
#
# Because of ROBOKOP's caching (see below), some types will return more quickly than others.  These types are in **bold** above.
#
# Note that `genetic_condition` above is not part of the biolink model, but is an additional type that descends from disease in ROBOKOP.
#
# As an example, we'll call expand twice with the same gene, once asking for a disease, and once asking for a genetic condition. There are no translator services that return only genetic condition, but the service knows how to recognize genetic conditions and returns only those diseases that are genetic conditions:

# %%
#HGNC:7897 = "NPC1"
expand_result_disease = expand('gene', 'HGNC:7897', 'genetic_condition',output_format='csv',rebuild=True).split('\n')
NPC1_diseases = set([n.split(',')[1] for n in expand_result_disease[1:]]) 
expand_result_gc = expand('gene', 'HGNC:7897', 'genetic_condition',output_format='csv',rebuild=True).split('\n')
NPC1_genetic_conditions = set([n.split(',')[1] for n in expand_result_gc[1:]])
# Out:
# Return Status: 200
# Return Status: 200

# %%
print('There are',len(NPC1_genetic_conditions),'Genetic Conditions associated with NPC1')
print('There are',len(NPC1_diseases),'Diseases associated with NPC1')
print(len(NPC1_diseases.intersection(NPC1_genetic_conditions)),'of these are in common. In other words, everything in the genetic condition list is also in the disease list')
# Out:
# There are 21 Genetic Conditions associated with NPC1
# There are 21 Diseases associated with NPC1
# 21 of these are in common. In other words, everything in the genetic condition list is also in the disease list

# %% [markdown]
# ## Caching and Rebuilding

# %% [markdown]
# ROBOKOP maintains caches results.  The cache is built both opportunistically (including the results of all previous queries) and proactively (pre-loading data that expected to be heavily used).  By default, expand only looks in its cache.  If a result has not been previously cached, then this call will not return anything (and may return a status code of 500).
#
# If a user wants to force the service to look beyond its local cache, it sends a parameter `rebuild=True`, as seen in the NPC1 examples above.
#
# If a user wants to be sure to retreive all relevant data, they should use `rebuild=True`, but this will be at the expense of performance.  In order to increase performance without sacrificing reliability, certain type pairs are preloaded into the cache.  In this case, there will be no difference in results between calling `rebuild=True` and `rebuild=False`, but calling with `rebuild=True` will be noticeably slower.
#
# Certain pairs of types are preloaded into ROBOKOP's cache, so there is no point in using rebuild for them. The following list will be updated as the preloaded list is modified.  Note that with the data loaded, it doesn't matter which type is the query and which is the resut.  That is, if a row in this table specifies `disease` and `phenotypic_feature`, then there is no reason to use rebuild for `type1='disease' type2='phenotypic_feature'` or `type1='phenotypic_feature' type2='disease'`.
#
# | type | type |
# |------|------|
# | disease | phenotypic_feature |
# | genetic_condition | phenotypic_feature |
# | gene    | biological_process_or_activity |
# | gene    | disease |
# | disease | chemical_substance |
# | gene | chemical_substance |
# | anatomical_entity | phenotypic_feature |

# %% [markdown]
# ## Specifying Predicates

# %% [markdown]
# The responses can be filtered by a predicate, which should also come from the biolink model.  Here, we look up any chemical that is associated with asthma:

# %%
asthma = "MONDO:0004979"

# %%
asthma_chemicals = expand('disease',asthma,'chemical_substance',rebuild=True)

# %% [markdown]
# There are multiple types that come back from this query: treats, contributes_to, associated_with, etc...

# %%
asthma_chem_frame = parse_answer(asthma_chemicals)
asthma_chem_frame
# Out:
#             result_id                                        result_name  \
# 0        MESH:D000393                                     Air Pollutants
# 1         CHEBI:28177                                       theophylline
# 2        MESH:D014028                            Tobacco Smoke Pollution
# 3        MESH:D001335                                  Vehicle Emissions
# 4          CHEBI:9449                                        terbutaline
# 5         CHEBI:41879                                      dexamethasone
# 6          CHEBI:8382                                         prednisone
# 7        MESH:D052638                                 Particulate Matter
# 8         CHEBI:25812                                              ozone
# 9        MESH:D004391                                               Dust
# 10         CHEBI:3001                                     beclomethasone
# 11         CHEBI:3207                                         budesonide
# 12        CHEBI:94810  N-[4-oxo-2-(2H-tetrazol-5-yl)-1-benzopyran-8-y...
# 13        CHEBI:27744                                         glyphosate
# 14        CHEBI:34905                                           paraquat
# 15   PUBCHEM:21868678                                       beta-Glucans
# 16         CHEBI:5134                                        fluticasone
# 17        CHEBI:18422                                     sulfur dioxide
# 18         CHEBI:8378                                       prednisolone
# 19        CHEBI:10100                                        zafirlukast
# 20        CHEBI:25944                                          pesticide
# 21       MESH:D053260                                               Soot
# 22         CHEBI:2549                                          albuterol
# 23        CHEBI:53556                           toluene 2,4-diisocyanate
# 24       MESH:D000305                            Adrenal Cortex Hormones
# 25         CHEBI:2659                                      aminophylline
# 26    MESH:D000068759                                Formoterol Fumarate
# 27        CHEBI:24527                                          herbicide
# 28        CHEBI:27928                                          parathion
# 29        CHEBI:16130                                                DDT
# ..                ...                                                ...
# 220       CHEBI:38940                                          sunitinib
# 221       CHEBI:53760                                        eszopiclone
# 222       CHEBI:59809                               docetaxel trihydrate
# 223       CHEBI:16709                                         pyridoxine
# 224       CHEBI:80630                                         irinotecan
# 225        CHEBI:6532                                         loperamide
# 226       CHEBI:83329  5-[1-hydroxy-2-(isopropanylamino)ethyl]benzene...
# 227        CHEBI:3082                                          betaxolol
# 228        CHEBI:7824                                      oxcarbazepine
# 229        CHEBI:9241                                     spironolactone
# 230        CHEBI:4728                                         dyphylline
# 231       CHEBI:65346                                         aclidinium
# 232      CHEBI:474053                                          cefazolin
# 233      CHEBI:135931                                    dexlansoprazole
# 234        CHEBI:4784                                          enalapril
# 235       CHEBI:50815                                       norgestimate
# 236      CHEBI:521033                                        dutasteride
# 237       CHEBI:28445                                        vincristine
# 238        CHEBI:3515                                         cefuroxime
# 239        CHEBI:2038                                      5-azacytidine
# 240       CHEBI:82719                                      orciprenaline
# 241       CHEBI:32139                           sodium hydrogencarbonate
# 242        CHEBI:6897                                       metipranolol
# 243       CHEBI:44423                                        hydroxyurea
# 244        CHEBI:5951                                      Iopanoic acid
# 245       CHEBI:17823                                         calcitriol
# 246      CHEBI:102166                                         thiopental
# 247        CHEBI:8707                                         quetiapine
# 248      CHEBI:135913                                     secretin human
# 249        CHEBI:7986                                     Pentoxifylline
#
#         score                      source            type
# 0    1.779961     ctd.disease_to_exposure         affects
# 1    1.775978  hmdb.metabolite_to_disease      related_to
# 2    1.716335     ctd.disease_to_exposure         affects
# 3    1.716335     ctd.disease_to_exposure         affects
# 4    1.665752     ctd.disease_to_chemical  contributes_to
# 5    1.575013     ctd.disease_to_chemical  contributes_to
# 6    1.447142   mychem.get_adverse_events          treats
# 7    1.372814     ctd.disease_to_chemical  contributes_to
# 8    1.358147     ctd.disease_to_chemical  contributes_to
# 9    1.354406     ctd.disease_to_exposure         affects
# 10   1.259326     ctd.disease_to_chemical          treats
# 11   1.257232      mychem.get_drugcentral          treats
# 12   1.250675      mychem.get_drugcentral          treats
# 13   1.222442     ctd.disease_to_chemical  contributes_to
# 14   1.222442     ctd.disease_to_chemical  contributes_to
# 15   1.222442     ctd.disease_to_exposure         affects
# 16   1.209326   mychem.get_adverse_events          treats
# 17   1.147884     ctd.disease_to_exposure  contributes_to
# 18   1.121354      mychem.get_drugcentral          treats
# 19   1.068687      mychem.get_drugcentral          treats
# 20   1.058360     ctd.disease_to_chemical  contributes_to
# 21   1.058360     ctd.disease_to_exposure  contributes_to
# 22   1.001000     ctd.disease_to_chemical          treats
# 23   1.000915     ctd.disease_to_chemical  contributes_to
# 24   0.951000     ctd.disease_to_chemical          treats
# 25   0.951000     ctd.disease_to_chemical          treats
# 26   0.951000     ctd.disease_to_chemical          treats
# 27   0.947259     ctd.disease_to_chemical  contributes_to
# 28   0.947259     ctd.disease_to_chemical  contributes_to
# 29   0.947259     ctd.disease_to_exposure  contributes_to
# ..        ...                         ...             ...
# 220  0.259326   mychem.get_adverse_events        prevents
# 221  0.259326   mychem.get_adverse_events        prevents
# 222  0.259326   mychem.get_adverse_events        prevents
# 223  0.259326   mychem.get_adverse_events        prevents
# 224  0.259326   mychem.get_adverse_events        prevents
# 225  0.259326   mychem.get_adverse_events        prevents
# 226  0.259326      mychem.get_drugcentral          treats
# 227  0.259326      mychem.get_drugcentral  contributes_to
# 228  0.259326   mychem.get_adverse_events        prevents
# 229  0.259326   mychem.get_adverse_events        prevents
# 230  0.259326      mychem.get_drugcentral          treats
# 231  0.259326   mychem.get_adverse_events          treats
# 232  0.259326   mychem.get_adverse_events        prevents
# 233  0.259326   mychem.get_adverse_events  contributes_to
# 234  0.259326   mychem.get_adverse_events        prevents
# 235  0.259326      mychem.get_drugcentral  contributes_to
# 236  0.259326   mychem.get_adverse_events        prevents
# 237  0.259326   mychem.get_adverse_events        prevents
# 238  0.259326   mychem.get_adverse_events        prevents
# 239  0.259326   mychem.get_adverse_events        prevents
# 240  0.259326      mychem.get_drugcentral          treats
# 241  0.259326   mychem.get_adverse_events        prevents
# 242  0.259326      mychem.get_drugcentral  contributes_to
# 243  0.259326   mychem.get_adverse_events        prevents
# 244  0.259326      mychem.get_drugcentral  contributes_to
# 245  0.259326   mychem.get_adverse_events        prevents
# 246  0.259326      mychem.get_drugcentral  contributes_to
# 247  0.259326   mychem.get_adverse_events        prevents
# 248  0.259326      mychem.get_drugcentral  contributes_to
# 249  0.259326   mychem.get_adverse_events        prevents
#
# [250 rows x 5 columns]

# %% [markdown]
# Now we can do an expand setting the predicate to treats, and we'll only return the chemicals above with that predicate type.  Note that we don't need to rebuild, since this will be a subset of the previous query, and so everything will already be in our local cache.
#
# Note that there is one extra subtlety when using predicates.  Edges with predicates have a direction.  That is, the statement (disease)-treats->(drug) is different from (drug)-treats->(disease).   And we are specifically looking for the latter case, where the direction of the edge is towards our input parameter (here the disease).  Without specifying the `direction` parameter, expand will assume that we are looking for outward edges, i.e. cases where our input into expand is the subject.  But here we want inward edges, where the input is the object, so we specify `direction=in`.

# %%
asthma_treatment = expand('disease',asthma,'chemical_substance',predicate='treats',direction='in')
# Out:
# http://robokop.renci.org:80/api/simple/expand/disease/MONDO:0004979/chemical_substance
# Return Status: 200

# %%
asthma_treat_frame = parse_answer(asthma_treatment)
asthma_treat_frame
# Out:
#            result_id                                        result_name  \
# 0         CHEBI:8382                                         prednisone
# 1        CHEBI:28177                                       theophylline
# 2         CHEBI:3207                                         budesonide
# 3         CHEBI:3001                                     beclomethasone
# 4         CHEBI:9449                                        terbutaline
# 5         CHEBI:5134                                        fluticasone
# 6         CHEBI:2549                                          albuterol
# 7         CHEBI:8378                                       prednisolone
# 8        CHEBI:94810  N-[4-oxo-2-(2H-tetrazol-5-yl)-1-benzopyran-8-y...
# 9        CHEBI:10100                                        zafirlukast
# 10        CHEBI:2659                                      aminophylline
# 11       CHEBI:41879                                      dexamethasone
# 12       CHEBI:28918                                     (R)-adrenaline
# 13       CHEBI:35523                               bronchodilator agent
# 14      MESH:D000305                            Adrenal Cortex Hormones
# 15   MESH:D000068759                                Formoterol Fumarate
# 16       CHEBI:50730                                        montelukast
# 17       CHEBI:17650                                           cortisol
# 18       CHEBI:24261                                     glucocorticoid
# 19        CHEBI:6888                          6alpha-methylprednisolone
# 20       CHEBI:71418                            triamcinolone acetonide
# 21       CHEBI:91495  3-hydroxy-2-phenylpropanoic acid (8-methyl-8-p...
# 22       CHEBI:64317                                       isoprenaline
# 23       CHEBI:93856      2-(tert-butylamino)-1-(2-chlorophenyl)ethanol
# 24        CHEBI:7492                                         nedocromil
# 25      CHEBI:149226                                          fenoterol
# 26       CHEBI:47564                                 mometasone furoate
# 27       CHEBI:77572                                          tranilast
# 28        CHEBI:3133                                         bitolterol
# 29      CHEBI:126237                                       enprofylline
# ..               ...                                                ...
# 96        CHEBI:3002                        beclomethasone dipropionate
# 97        CHEBI:6792                                     metaproterenol
# 98       CHEBI:90960                                         tiotropium
# 99        CHEBI:9667                                      triamcinolone
# 100       CHEBI:3077                                      betamethasone
# 101       CHEBI:5106                                        flunisolide
# 102      CHEBI:74899                                fluticasone furoate
# 103       CHEBI:6970                                         mometasone
# 104      CHEBI:82719                                      orciprenaline
# 105     CHEBI:134938                                            ozagrel
# 106      CHEBI:68575                                        indacaterol
# 107       CHEBI:8245                                         Pirbuterol
# 108     CHEBI:135612                                         reproterol
# 109      CHEBI:31684                                          Ibudilast
# 110       CHEBI:4728                                         dyphylline
# 111      CHEBI:31677                           hydrocortisone succinate
# 112      CHEBI:65346                                         aclidinium
# 113     CHEBI:134936                                         pemirolast
# 114       CHEBI:9669                            Triamcinolone diacetate
# 115      CHEBI:59773                                   cromoglycic acid
# 116       CHEBI:3897                                  Cortisone acetate
# 117      CHEBI:83332                              orciprenaline sulfate
# 118     CHEBI:134857                                ethylnorepinephrine
# 119      CHEBI:31275                              betamethasone acetate
# 120     CHEBI:204734                                           desonide
# 121      CHEBI:83329  5-[1-hydroxy-2-(isopropanylamino)ethyl]benzene...
# 122      CHEBI:17609                                cortisol 21-acetate
# 123      CHEBI:18357                                  (R)-noradrenaline
# 124      CHEBI:91899                                           LSM-1835
# 125      CHEBI:94615    2-(1,3-dimethyl-2,6-dioxo-7-purinyl)acetic acid
#
#         score                     source    type
# 0    1.594186  mychem.get_adverse_events  treats
# 1    1.504095     mychem.get_drugcentral  treats
# 2    1.450466     mychem.get_drugcentral  treats
# 3    1.441718    ctd.disease_to_chemical  treats
# 4    1.403697     mychem.get_drugcentral  treats
# 5    1.376925  mychem.get_adverse_events  treats
# 6    1.290118    ctd.disease_to_chemical  treats
# 7    1.268903     mychem.get_drugcentral  treats
# 8    1.250675     mychem.get_drugcentral  treats
# 9    1.182609     mychem.get_drugcentral  treats
# 10   1.092792    ctd.disease_to_chemical  treats
# 11   1.049026     mychem.get_drugcentral  treats
# 12   1.002080    ctd.disease_to_chemical  treats
# 13   0.967944    ctd.disease_to_chemical  treats
# 14   0.951000    ctd.disease_to_chemical  treats
# 15   0.951000    ctd.disease_to_chemical  treats
# 16   0.948080    ctd.disease_to_chemical  treats
# 17   0.921782    ctd.disease_to_chemical  treats
# 18   0.917419    ctd.disease_to_chemical  treats
# 19   0.909539     mychem.get_drugcentral  treats
# 20   0.906367     mychem.get_drugcentral  treats
# 21   0.902040    ctd.disease_to_chemical  treats
# 22   0.849305    ctd.disease_to_chemical  treats
# 23   0.798438     mychem.get_drugcentral  treats
# 24   0.786060    ctd.disease_to_chemical  treats
# 25   0.781304    ctd.disease_to_chemical  treats
# 26   0.772727    ctd.disease_to_chemical  treats
# 27   0.768422     mychem.get_drugcentral  treats
# 28   0.767504    ctd.disease_to_chemical  treats
# 29   0.753797    ctd.disease_to_chemical  treats
# ..        ...                        ...     ...
# 96   0.403364     mychem.get_drugcentral  treats
# 97   0.380197     mychem.get_drugcentral  treats
# 98   0.367196  mychem.get_adverse_events  treats
# 99   0.366321     mychem.get_drugcentral  treats
# 100  0.365818     mychem.get_drugcentral  treats
# 101  0.365606     mychem.get_drugcentral  treats
# 102  0.362830     mychem.get_drugcentral  treats
# 103  0.362078  mychem.get_adverse_events  treats
# 104  0.361843     mychem.get_drugcentral  treats
# 105  0.361841     mychem.get_drugcentral  treats
# 106  0.361371  mychem.get_adverse_events  treats
# 107  0.360936     mychem.get_drugcentral  treats
# 108  0.360788     mychem.get_drugcentral  treats
# 109  0.360051     mychem.get_drugcentral  treats
# 110  0.359894     mychem.get_drugcentral  treats
# 111  0.359751     mychem.get_drugcentral  treats
# 112  0.359622  mychem.get_adverse_events  treats
# 113  0.359595     mychem.get_drugcentral  treats
# 114  0.359583     mychem.get_drugcentral  treats
# 115  0.359524     mychem.get_drugcentral  treats
# 116  0.359453     mychem.get_drugcentral  treats
# 117  0.359443     mychem.get_drugcentral  treats
# 118  0.359366     mychem.get_drugcentral  treats
# 119  0.359347     mychem.get_drugcentral  treats
# 120  0.359339     mychem.get_drugcentral  treats
# 121  0.259326     mychem.get_drugcentral  treats
# 122  0.259326     mychem.get_drugcentral  treats
# 123  0.259326     mychem.get_drugcentral  treats
# 124  0.259326     mychem.get_drugcentral  treats
# 125  0.259326     mychem.get_drugcentral  treats
#
# [126 rows x 5 columns]

# %% [markdown]
# ## Data sources and allowed hops

# %% [markdown]
# ROBOKOP can join many kinds of types, but only those for which it has a configured knowledge source.  For instance, ROBOKOP doesn't currently have a way to join `chemical_substance` and `biological_process_or_activity` directly.  Currently, these are the service hops that are configured in ROBOKOP.  As above, ROBOKOP will traverse the biolink-model hierarchy, so for instance if there is an entry from `metabolite` to `disease` below, then it will also be possible to call `chemical_substance` to `disease`.
#
# The most up-to-date list, and information about which services are configured for each pair of types, can always be found in [this file](https://github.com/NCATS-Gamma/robokop-interfaces/blob/master/greent/rosetta.yml)
#
# | input type | output type |
# |------------|------------|
# | anatomical_entity | cell |
# | anatomical_entity | gene |
# | anatomical_entity | phenotypic_feature |
# | cell | anatomical_entity |
# | cell | biological_process_or_activity |
# | biological_process_or_activity | gene |
# | biological_process_or_activity | cell |
# | chemical_substance | gene |
# | chemical_substance | disease |
# | chemical_substance | phenotypic_feature |
# | disease | phenotypic_feature |
# | disease | gene |
# | disease | chemical_substance |
# | metabolite | pathway |
# | gene | anatomical_entity |
# | gene | disease |
# | gene | chemical_substance |
# | gene | pathway |
# | gene | biological_process_or_activity |
# | pathway | gene |
# | pathway | metabolite |
# | phenotypic_feature | anatomical_entity |
# | phenotypic_feature | disease |
