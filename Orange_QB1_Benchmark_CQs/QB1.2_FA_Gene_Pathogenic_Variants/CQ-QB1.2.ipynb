# %%
import requests
import pandas as pd
from pprint import pprint

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/"
FA_all_genes = "master/FA_gene_sets/FA_4_all_genes.txt"
fa_genes = pd.read_csv(base_url + FA_all_genes, sep='\t')

# %%
fa_genes
# Out:
#       NCBIGene:2175    FANCA
# 0     NCBIGene:2187    FANCB
# 1     NCBIGene:2176    FANCC
# 2     NCBIGene:2178    FANCE
# 3     NCBIGene:2188    FANCF
# 4     NCBIGene:2189    FANCG
# 5    NCBIGene:55120    FANCL
# 6    NCBIGene:57697    FANCM
# 7     NCBIGene:2177   FANCD2
# 8    NCBIGene:55215    FANCI
# 9    NCBIGene:29089    UBE2T
# 10     NCBIGene:675    BRCA2
# 11   NCBIGene:83990    BRIP1
# 12   NCBIGene:79728    PALB2
# 13    NCBIGene:5889   RAD51C
# 14   NCBIGene:84464     SLX4
# 15    NCBIGene:2072    ERCC4
# 16    NCBIGene:5888    RAD51
# 17     NCBIGene:672    BRCA1
# 18   NCBIGene:10459   MAD2L2
# 19    NCBIGene:7516    XRCC2
# 20   NCBIGene:55159    RFWD3
# 21   NCBIGene:80233  FAAP100
# 22   NCBIGene:91442   FAAP24
# 23  NCBIGene:199990   FAAP20
# 24  NCBIGene:378708    CENPS
# 25  NCBIGene:201254    CENPX

# %%
#  return gene disease association data from biolink
def query_biolink_gene_disease(gene_curie):
    bl_url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/diseases/'
    params = {
        'fetch_objects': True,   
    }
    r = requests.get(url=bl_url.format(gene_curie), params=params)
    return r.json()

# %%
term_map_reversed = {
    "GENO:0000840": "pathogenic",
    "GENO:0000841": "likely pathogenic",
    "GENO:0000843": "benign",
    "GENO:0000844": "likely benign",
    "GENO:0000845": "uncertain significance"    
}

# %%
"""
Look for pathogenic variants and the disease 
they are implicated with via biolink
"""
result_set = []
for index, row in fa_genes.iterrows():
    bl_dat = query_biolink_gene_disease(row[0])
    for assoc in bl_dat['associations']:
        edges = assoc['evidence_graph']['edges']
        nodes = assoc['evidence_graph']['nodes']
        node_map = dict()
        for node in nodes:
            node_map[node['id']] = node['lbl']
        for edge in edges:
            if edge['pred'] in term_map_reversed.keys():
                pd_row = [row[1], row[0], node_map[edge['sub']], 
                       edge['sub'], term_map_reversed[edge['pred']], 
                       edge['pred'], node_map[edge['obj']], edge['obj']]
                result_set.append(pd_row)
    column_names = ['gene_name', 'gene_curie', 'variant_name', 'variant_curie', 
                    'relation_label', 'relation_curie', 'disease_label', 'disease_curie']
result_frame = pd.DataFrame(data=result_set, columns=column_names)
result_frame
# Out:
#      gene_name      gene_curie  \
# 0        FANCB   NCBIGene:2187
# 1        FANCB   NCBIGene:2187
# 2        FANCB   NCBIGene:2187
# 3        FANCB   NCBIGene:2187
# 4        FANCB   NCBIGene:2187
# 5        FANCB   NCBIGene:2187
# 6        FANCB   NCBIGene:2187
# 7        FANCC   NCBIGene:2176
# 8        FANCC   NCBIGene:2176
# 9        FANCC   NCBIGene:2176
# 10       FANCC   NCBIGene:2176
# 11       FANCC   NCBIGene:2176
# 12       FANCC   NCBIGene:2176
# 13       FANCC   NCBIGene:2176
# 14       FANCC   NCBIGene:2176
# 15       FANCC   NCBIGene:2176
# 16       FANCC   NCBIGene:2176
# 17       FANCC   NCBIGene:2176
# 18       FANCC   NCBIGene:2176
# 19       FANCC   NCBIGene:2176
# 20       FANCC   NCBIGene:2176
# 21       FANCC   NCBIGene:2176
# 22       FANCC   NCBIGene:2176
# 23       FANCC   NCBIGene:2176
# 24       FANCC   NCBIGene:2176
# 25       FANCC   NCBIGene:2176
# 26       FANCC   NCBIGene:2176
# 27       FANCC   NCBIGene:2176
# 28       FANCC   NCBIGene:2176
# 29       FANCC   NCBIGene:2176
# ...        ...             ...
# 5566     BRCA1    NCBIGene:672
# 5567     BRCA1    NCBIGene:672
# 5568     BRCA1    NCBIGene:672
# 5569     BRCA1    NCBIGene:672
# 5570     BRCA1    NCBIGene:672
# 5571     BRCA1    NCBIGene:672
# 5572     BRCA1    NCBIGene:672
# 5573     BRCA1    NCBIGene:672
# 5574     BRCA1    NCBIGene:672
# 5575     BRCA1    NCBIGene:672
# 5576     BRCA1    NCBIGene:672
# 5577     BRCA1    NCBIGene:672
# 5578     BRCA1    NCBIGene:672
# 5579     BRCA1    NCBIGene:672
# 5580     BRCA1    NCBIGene:672
# 5581     BRCA1    NCBIGene:672
# 5582     BRCA1    NCBIGene:672
# 5583     BRCA1    NCBIGene:672
# 5584     BRCA1    NCBIGene:672
# 5585     BRCA1    NCBIGene:672
# 5586     BRCA1    NCBIGene:672
# 5587     BRCA1    NCBIGene:672
# 5588     BRCA1    NCBIGene:672
# 5589     BRCA1    NCBIGene:672
# 5590     BRCA1    NCBIGene:672
# 5591     BRCA1    NCBIGene:672
# 5592     BRCA1    NCBIGene:672
# 5593     BRCA1    NCBIGene:672
# 5594     BRCA1    NCBIGene:672
# 5595    MAD2L2  NCBIGene:10459
#
#                                            variant_name  \
# 0                                FANCB, 1-BP DEL, 1650T
# 1                                FANCB, 1-BP INS, 1838T
# 2                                      FANCB, LEU717TER
# 3                                    FANCB, 3314-BP DEL
# 4                                FANCB, IVS7DS, G-A, +5
# 5                               FANCB, 2-BP DEL, 1857AG
# 6                                 FANCB, 1-BP INS, 811T
# 7          NM_000136.2(FANCC):c.595dupC (p.Leu199Profs)
# 8            NM_000136.2(FANCC):c.67delG (p.Asp23Ilefs)
# 9            NM_000136.2(FANCC):c.1599G>A (p.Trp533Ter)
# 10           NM_000136.2(FANCC):c.1498G>T (p.Gly500Ter)
# 11              NM_000136.2(FANCC):c.65G>A (p.Trp22Ter)
# 12           NM_000136.2(FANCC):c.1487T>G (p.Leu496Arg)
# 13           NM_000136.2(FANCC):c.1309C>T (p.Gln437Ter)
# 14                                    FANCC, 250-BP DEL
# 15              NM_000136.2(FANCC):c.37C>T (p.Gln13Ter)
# 16            NM_000136.2(FANCC):c.553C>T (p.Arg185Ter)
# 17                        NM_000136.2(FANCC):c.844-1G>C
# 18                        NM_000136.2(FANCC):c.996+1G>T
# 19          NM_000136.2(FANCC):c.117delT (p.Gln40Serfs)
# 20    NM_000136.2(FANCC):c.487_490delGAGA (p.Glu163I...
# 21            NM_000136.2(FANCC):c.339G>A (p.Trp113Ter)
# 22           NM_000136.2(FANCC):c.1517G>A (p.Trp506Ter)
# 23        NM_000136.2(FANCC):c.1144delC (p.Gln382Argfs)
# 24                        NM_000136.2(FANCC):c.457-1G>T
# 25                       NM_000136.2(FANCC):c.1533+2T>C
# 26        NM_000136.2(FANCC):c.1555dupA (p.Thr519Asnfs)
# 27         NM_000136.2(FANCC):c.831delA (p.Asp278Ilefs)
# 28                        NM_000136.2(FANCC):c.843+1G>A
# 29                        NM_000136.2(FANCC):c.686+1G>T
# ...                                                 ...
# 5566         NM_007294.3(BRCA1):c.2800C>T (p.Gln934Ter)
# 5567      NM_007294.3(BRCA1):c.1923dupT (p.Asp642Terfs)
# 5568  NM_007294.3(BRCA1):c.1601_1602delAG (p.Gln534A...
# 5569  NM_007294.3(BRCA1):c.2125_2126insA (p.Phe709Ty...
# 5570        NM_007294.3(BRCA1):c.5444G>A (p.Trp1815Ter)
# 5571      NM_007294.3(BRCA1):c.1812delA (p.Ala605Hisfs)
# 5572  NM_007294.3(BRCA1):c.2110_2111delAA (p.Asn704C...
# 5573     NM_007294.3(BRCA1):c.3214delC (p.Leu1072Terfs)
# 5574                      NM_007294.3(BRCA1):c.212+1G>T
# 5575  NM_007294.3(BRCA1):c.2226_2227delTA (p.Asn742L...
# 5576      NM_007294.3(BRCA1):c.1961delA (p.Lys654Serfs)
# 5577  NM_007294.3(BRCA1):c.2912_2913delAT (p.His971A...
# 5578                     NM_007294.3(BRCA1):c.4675+1G>A
# 5579  NM_007294.3(BRCA1):c.5062_5064delGTT (p.Val168...
# 5580        NM_007294.3(BRCA1):c.4222C>T (p.Gln1408Ter)
# 5581          NM_007294.3(BRCA1):c.505C>T (p.Gln169Ter)
# 5582  NM_007294.3(BRCA1):c.3869_3870delAA (p.Lys1290...
# 5583         NM_007294.3(BRCA1):c.1960A>T (p.Lys654Ter)
# 5584  NM_007294.3(BRCA1):c.1953_1956delGAAA (p.Lys65...
# 5585     NM_007294.3(BRCA1):c.5335delC (p.Gln1779Asnfs)
# 5586  NM_007294.3(BRCA1):c.3770_3771delAG (p.Glu1257...
# 5587  NM_007294.3(BRCA1):c.3700_3704delGTAAA (p.Val1...
# 5588     NM_007294.3(BRCA1):c.3764dupA (p.Asn1255Lysfs)
# 5589        NM_007294.3(BRCA1):c.4656C>G (p.Tyr1552Ter)
# 5590                     NM_007294.3(BRCA1):c.5277+1G>A
# 5591        NM_007294.3(BRCA1):c.3910G>T (p.Glu1304Ter)
# 5592     NM_007294.3(BRCA1):c.5259delA (p.Glu1754Asnfs)
# 5593        NM_007294.3(BRCA1):c.5095C>T (p.Arg1699Trp)
# 5594  NM_007294.3(BRCA1):c.594_597delTGTG (p.Ser198A...
# 5595          NM_006341.3(MAD2L2):c.254T>A (p.Val85Glu)
#
#               variant_curie     relation_label relation_curie  \
# 0      ClinVarVariant:10868         pathogenic   GENO:0000840
# 1      ClinVarVariant:10866         pathogenic   GENO:0000840
# 2      ClinVarVariant:37043         pathogenic   GENO:0000840
# 3      ClinVarVariant:10867         pathogenic   GENO:0000840
# 4      ClinVarVariant:10870         pathogenic   GENO:0000840
# 5      ClinVarVariant:37044         pathogenic   GENO:0000840
# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def execute_query(query):
    endpoint = SPARQLWrapper('https://query.wikidata.org/sparql')
    endpoint.setQuery(query)
    endpoint.setReturnFormat(JSON)
    return endpoint.query().convert()

def var_query(entrez):
    """
    query wikidata by entrez id for variant that is 'positive diagnostic predictor of a disease'
    """    
    query = """
    SELECT distinct ?gene ?geneLabel ?variant ?variantLabel ?disease ?diseaseLabel
     WHERE {
      # ?gene wdt:P351 '%s'. 
      OPTIONAL {?variant wdt:P3433 ?gene.}        # variant of gene
      OPTIONAL {?variant wdt:P3433 ?gene;
                         wdt:P3356 ?disease.}    # variant is a positive diagnostic predictor of disease
       SERVICE wikibase:label {
            bd:serviceParam wikibase:language "en" .
      }
    }
    """ % (entrez)
    r = execute_query(query)
    return r['results']['bindings']

def keycheck(ckey, cdict):
    if ckey in cdict.keys():
        return cdict[ckey]['value']
    else:
        return None

# %%
"""
Look for variants of FA genes in wikidata that are 'positive diagnostic predictors' for a disease
"""
wd_columns = ['gene', 'geneLabel', 'variant', 'variantLabel', 'disease', "diseaseLabel"]
wd_result_frame = pd.DataFrame(columns=wd_columns)

    
for index, row in fa_genes.iterrows():
    entrez_id = row[0].split(":")[-1]
    wd_hits = var_query(entrez_id)
    for hit in wd_hits:
        result = dict()
        result['gene'] = keycheck('gene', hit)
        result['geneLabel'] = keycheck('geneLabel', hit)
        result['variant'] = keycheck('variant', hit)
        result['variantLabel'] = keycheck('variantLabel', hit)
        result['disease'] = keycheck('disease', hit)
        result['diseaseLabel'] = keycheck('diseaseLabel', hit)
        wd_result_frame = wd_result_frame.append(result, ignore_index=True)
wd_result_frame
# Out:
#                                         gene geneLabel  \
# 0   http://www.wikidata.org/entity/Q17927471     FANCB
# 1   http://www.wikidata.org/entity/Q18250517     FANCC
# 2   http://www.wikidata.org/entity/Q17927077     FANCE
# 3   http://www.wikidata.org/entity/Q17927502     FANCF
# 4   http://www.wikidata.org/entity/Q17927524     FANCG
# 5   http://www.wikidata.org/entity/Q18041564     FANCL
# 6   http://www.wikidata.org/entity/Q18044458     FANCM
# 7   http://www.wikidata.org/entity/Q17927069    FANCD2
# 8   http://www.wikidata.org/entity/Q18041663     FANCI
# 9   http://www.wikidata.org/entity/Q18039587     UBE2T
# 10  http://www.wikidata.org/entity/Q17853272     BRCA2
# 11  http://www.wikidata.org/entity/Q17853272     BRCA2
# 12  http://www.wikidata.org/entity/Q17853272     BRCA2
# 13  http://www.wikidata.org/entity/Q17853272     BRCA2
# 14  http://www.wikidata.org/entity/Q17853272     BRCA2
# 15  http://www.wikidata.org/entity/Q17853272     BRCA2
# 16  http://www.wikidata.org/entity/Q17853272     BRCA2
# 17  http://www.wikidata.org/entity/Q17853272     BRCA2
# 18  http://www.wikidata.org/entity/Q17853272     BRCA2
# 19  http://www.wikidata.org/entity/Q17853272     BRCA2
# 20  http://www.wikidata.org/entity/Q17853272     BRCA2
# 21  http://www.wikidata.org/entity/Q18047355     BRIP1
# 22  http://www.wikidata.org/entity/Q18046302     PALB2
# 23  http://www.wikidata.org/entity/Q18046302     PALB2
# 24  http://www.wikidata.org/entity/Q18031015    RAD51C
# 25  http://www.wikidata.org/entity/Q18047618      SLX4
# 26  http://www.wikidata.org/entity/Q17917469     ERCC4
# 27  http://www.wikidata.org/entity/Q14907732     RAD51
# 28    http://www.wikidata.org/entity/Q227339     BRCA1
# 29    http://www.wikidata.org/entity/Q227339     BRCA1
# 30    http://www.wikidata.org/entity/Q227339     BRCA1
# 31    http://www.wikidata.org/entity/Q227339     BRCA1
# 32    http://www.wikidata.org/entity/Q227339     BRCA1
# 33    http://www.wikidata.org/entity/Q227339     BRCA1
# 34    http://www.wikidata.org/entity/Q227339     BRCA1
# 35    http://www.wikidata.org/entity/Q227339     BRCA1
# 36    http://www.wikidata.org/entity/Q227339     BRCA1
# 37    http://www.wikidata.org/entity/Q227339     BRCA1
# 38    http://www.wikidata.org/entity/Q227339     BRCA1
# 39    http://www.wikidata.org/entity/Q227339     BRCA1
# 40    http://www.wikidata.org/entity/Q227339     BRCA1
# 41    http://www.wikidata.org/entity/Q227339     BRCA1
# 42    http://www.wikidata.org/entity/Q227339     BRCA1
# 43    http://www.wikidata.org/entity/Q227339     BRCA1
# 44    http://www.wikidata.org/entity/Q227339     BRCA1
# 45    http://www.wikidata.org/entity/Q227339     BRCA1
# 46    http://www.wikidata.org/entity/Q227339     BRCA1
# 47  http://www.wikidata.org/entity/Q18035401    MAD2L2
# 48  http://www.wikidata.org/entity/Q18032394     XRCC2
# 49  http://www.wikidata.org/entity/Q18041606     RFWD3
# 50  http://www.wikidata.org/entity/Q18046665   FAAP100
# 51  http://www.wikidata.org/entity/Q18048517    FAAP24
# 52  http://www.wikidata.org/entity/Q18053146    FAAP20
# 53  http://www.wikidata.org/entity/Q18056210     CENPS
# 54  http://www.wikidata.org/entity/Q18053211     CENPX
#
#                                      variant                  variantLabel  \
# 0                                       None                          None
# 1   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 2                                       None                          None
# 3                                       None                          None
# 4                                       None                          None
# 5                                       None                          None
# 6                                       None                          None
# 7                                       None                          None
# 8                                       None                          None
# 9                                       None                          None
# 10  http://www.wikidata.org/entity/Q29938738                     BRCA2 M1I
# 11  http://www.wikidata.org/entity/Q29938739                   BRCA2 V159M
# 12  http://www.wikidata.org/entity/Q29938740                   BRCA2 V211L
# 13  http://www.wikidata.org/entity/Q28371625     BRCA2 TRUNCATING MUTATION
# 14  http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 15  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 16  http://www.wikidata.org/entity/Q29938737                     BRCA2 M1R
# 17  http://www.wikidata.org/entity/Q29938742                  BRCA2 R2336P
# 18  http://www.wikidata.org/entity/Q29938743                  BRCA2 R2336H
# 19  http://www.wikidata.org/entity/Q29938741                   BRCA2 V211I
# 20  http://www.wikidata.org/entity/Q28371604                  BRCA2 D3095E
# 21                                      None                          None
# 22  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 23  http://www.wikidata.org/entity/Q28439607               PALB2 L531FS*30
# 24                                      None                          None
# 25                                      None                          None
# 26                                      None                          None
# 27                                      None                          None
# 28  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 29  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 30  http://www.wikidata.org/entity/Q29938727                    BRCA1 R71G
# 31  http://www.wikidata.org/entity/Q29938724                     BRCA1 M1I
# 32  http://www.wikidata.org/entity/Q28445090         BRCA1 UNDEREXPRESSION
# 33  http://www.wikidata.org/entity/Q29938730                  BRCA1 R1495M
# 34  http://www.wikidata.org/entity/Q29938735                  BRCA1 R1443*
# 35  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 36  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 37  http://www.wikidata.org/entity/Q28532483     BRCA1 TRUNCATING MUTATION
# 38  http://www.wikidata.org/entity/Q29938734                  BRCA1 D1692N
# 39  http://www.wikidata.org/entity/Q29938732                  BRCA1 E1559K
# 40  http://www.wikidata.org/entity/Q29938736                  BRCA1 Q1467*
# 41  http://www.wikidata.org/entity/Q28445085              BRCA1 EXPRESSION
# 42  http://www.wikidata.org/entity/Q32965138                  BRCA1 W1815X
# 43  http://www.wikidata.org/entity/Q29938723                     BRCA1 M1V
# 44  http://www.wikidata.org/entity/Q29938726                    BRCA1 C64Y
# 45  http://www.wikidata.org/entity/Q29938725                    BRCA1 C61G
# 46  http://www.wikidata.org/entity/Q29938728                    BRCA1 R71K
# 47                                      None                          None
# 48                                      None                          None
# 49                                      None                          None
# 50                                      None                          None
# 51                                      None                          None
# 52                                      None                          None
# 53                                      None                          None
# 54                                      None                          None
#
#                                    disease    diseaseLabel
# 0                                     None            None
# 1                                     None            None
# 2                                     None            None
# 3                                     None            None
# 4                                     None            None
# 5                                     None            None
# 6                                     None            None
# 7                                     None            None
# 8                                     None            None
# 9                                     None            None
# 10                                    None            None
# 11                                    None            None
# 12                                    None            None
# 13                                    None            None
# 14                                    None            None
# 15                                    None            None
# 16                                    None            None
# 17                                    None            None
# 18                                    None            None
# 19                                    None            None
# 20  http://www.wikidata.org/entity/Q128581   breast cancer
# 21                                    None            None
# 22                                    None            None
# 23  http://www.wikidata.org/entity/Q128581   breast cancer
# 24                                    None            None
# 25                                    None            None
# 26                                    None            None
# 27                                    None            None
# 28  http://www.wikidata.org/entity/Q128581   breast cancer
# 29  http://www.wikidata.org/entity/Q172341  ovarian cancer
# 30                                    None            None
# 31                                    None            None
# 32                                    None            None
# 33                                    None            None
# 34                                    None            None
# 35                                    None            None
# 36                                    None            None
# 37                                    None            None
# 38                                    None            None
# 39                                    None            None
# 40                                    None            None
# 41                                    None            None
# 42                                    None            None
# 43                                    None            None
# 44                                    None            None
# 45                                    None            None
# 46                                    None            None
# 47                                    None            None
# 48                                    None            None
# 49                                    None            None
# 50                                    None            None
# 51                                    None            None
# 52                                    None            None
# 53                                    None            None
# 54                                    None            None
