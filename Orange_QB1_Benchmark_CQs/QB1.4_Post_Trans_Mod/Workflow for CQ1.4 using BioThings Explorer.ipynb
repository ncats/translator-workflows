# %% [markdown]
# ## Orange QB1.4

# %% [markdown]
# ### Query:
# Return sequences of FA genes associated with functional post-translational modifications.

# %%
# import biothing explorer (current in local, will make it an independent python package)
from visual import pathViewer

# %%
# pathViewer is a Python class for graphically display API connection maps and explore bio-entity relaitonships
k = pathViewer()

# %% [markdown]
# #### Show All Available IDs
# Users could call the **availbale_ids** function to retrieve all IDs as well as descriptions for these ids used in BioThings Explorer

# %%
k.available_ids()
# Out:
# <table>
# <tbody>
# <tr><td>Preferred Name              </td><td>URI                                               </td><td>Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                </td><td>Identifier pattern                                                                                                          </td><td>Type  </td></tr>
# <tr><td>DrugBank                    </td><td>http://identifiers.org/drugbank/                  </td><td>The DrugBank database is a bioinformatics and chemoinformatics resource that combines detailed drug (i.e. chemical, pharmacological and pharmaceutical) data with comprehensive drug target (i.e. sequence, structure, and pathway) information. This collection references drug information.                                                                                                                                                                                                                                                                                              </td><td>^DB\d{5}$                                                                                                                   </td><td>Entity</td></tr>
# <tr><td>PubMed                      </td><td>http://identifiers.org/pubmed/                    </td><td>PubMed is a service of the U.S. National Library of Medicine that includes citations from MEDLINE and other life science journals for biomedical articles back to the 1950s.                                                                                                                                                                                                                                                                                                                                                                                                               </td><td>^\d+$                                                                                                                       </td><td>Entity</td></tr>
# <tr><td>CHEMBL ID                   </td><td>http://identifiers.org/chembl/                    </td><td>nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        </td><td>nan                                                                                                                         </td><td>Entity</td></tr>
# <tr><td>dbSNP                       </td><td>http://identifiers.org/dbsnp/                     </td><td>The dbSNP database is a repository for both single base nucleotide subsitutions and short deletion and insertion polymorphisms.                                                                                                                                                                                                                                                                                                                                                                                                                                                            </td><td>^rs\d+$                                                                                                                     </td><td>Entity</td></tr>
# <tr><td>RXCUI                       </td><td>http://identifiers.org/rxcui/                     </td><td>nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        </td><td>nan                                                                                                                         </td><td>Entity</td></tr>
# <tr><td>Protein Data Bank           </td><td>http://identifiers.org/pdb/                       </td><td>The Protein Data Bank is the single worldwide archive of structural data of biological macromolecules.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     </td><td>^[0-9][A-Za-z0-9]{3}$                                                                                                       </td><td>Entity</td></tr>
# <tr><td>Experimental Factor Ontology</td><td>http://identifiers.org/efo/                       </td><td>The Experimental Factor Ontology (EFO) provides a systematic description of many experimental variables available in EBI databases. It combines parts of several biological ontologies, such as anatomy, disease and chemical compounds. The scope of EFO is to support the annotation, analysis and visualization of data handled by the EBI Functional Genomics Team.                                                                                                                                                                                                                    </td><td>^\d{7}$                                                                                                                     </td><td>Entity</td></tr>
# <tr><td>RefSeq                      </td><td>http://identifiers.org/refseq/                    </td><td>The Reference Sequence (RefSeq) collection aims to provide a comprehensive, integrated, non-redundant set of sequences, including genomic DNA, transcript (RNA), and protein products.                                                                                                                                                                                                                                                                                                                                                                                                     </td><td>^((AC|AP|NC|NG|NM|NP|NR|NT|NW|XM|XP|XR|YP|ZP)_\d+|(NZ\_[A-Z]{4}\d+))(\.\d+)?$                                               </td><td>Entity</td></tr>
# <tr><td>ClinVar Variant             </td><td>http://identifiers.org/clinvar/                   </td><td>ClinVar archives reports of relationships among medically important variants and phenotypes. It records human variation, interpretations of the relationship specific variations to human health, and supporting evidence for each interpretation. Each ClinVar record (RCV identifier) represents an aggregated view of interpretations of the same variation and condition from one

# %% [markdown]
# #### Show How APIs/Endpoints/Bio-Entities can be connected together
# graph is **interactive**

# %%
k.show_api_road_map()
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file6"];    frame.runVis([{"border_width": 0, "value": 2, "y": 1000.0, "degree": 11, "title": "UniProt Knowledgebase", "id": "UniProt Knowledgebase", "node_shape": "dot", "x": 1000.0, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 996.5844930066698, "degree": 2, "title": "https://api.monarchinitiative.org/api/bioentity/gene/{gene id}/interactions/", "id": "https://api.monarchinitiative.org/api/bioentity/gene/{gene id}/interactions/", "node_shape": "dot", "x": 996.5844930066698, "color": "blue"}, {"border_width": 0, "value": 2, "y": 986.3613034027223, "degree": 7, "title": "NCBI Gene", "id": "NCBI Gene", "node_shape": "dot", "x": 986.3613034027223, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 969.4002659393303, "degree": 1, "title": "PTM Object", "id": "PTM Object", "node_shape": "dot", "x": 969.4002659393303, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 945.8172417006347, "degree": 3, "title": "Orphanet", "id": "Orphanet", "node_shape": "dot", "x": 945.8172417006347, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 915.7733266550574, "degree": 6, "title": "biolink", "id": "biolink", "node_shape": "dot", "x": 915.7733266550574, "color": "red"}, {"border_width": 0, "value": 2, "y": 879.473751206489, "degree": 2, "title": "CHEMBL ID", "id": "CHEMBL ID", "node_shape": "dot", "x": 879.473751206489, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 837.1664782625286, "degree": 2, "title": "HGVS ID", "id": "HGVS ID", "node_shape": "dot", "x": 837.1664782625286, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 789.1405093963937, "degree": 2, "title": "InChIKey", "id": "InChIKey", "node_shape": "dot", "x": 789.1405093963937, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 735.7239106731317, "degree": 3, "title": "https://api.monarchinitiative.org/api/bioentity/gene/{gene id}/phenotypes/", "id": "https://api.monarchinitiative.org/api/bioentity/gene/{gene id}/phenotypes/", "node_shape": "dot", "x": 735.7239106731317, "color": "blue"}, {"border_width": 0, "value": 2, "y": 677.2815716257411, "degree": 3, "title": "http://www.ebi.ac.uk/proteins/api/features/accession?categories=TOPOLOGY", "id": "http://www.ebi.ac.uk/proteins/api/features/accession?categories=TOPOLOGY", "node_shape": "dot", "x": 677.2815716257411, "color": "blue"}, {"border_width": 0, "value": 2, "y": 614.2127126896678, "degree": 2, "title": "UniGene", "id": "UniGene", "node_shape": "dot", "x": 614.2127126896678, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 546.948158122427, "degree": 1, "title": "ZFIN Gene ID", "id": "ZFIN Gene ID", "node_shape": "dot", "x": 546.948158122427, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 475.9473930370736, "degree": 2, "title": "KEGG Pathway", "id": "KEGG Pathway", "node_shape": "dot", "x": 475.9473930370736, "color": "yellow"}, {"border_width": 0, "value": 2, "y": 401.6954246529695, "degree": 17, "title": "http://myvariant.info/v1/variant/variantid", "id": "http://myvariant.info/v1/variant/variantid", "node_shape": "dot", "x": 401.6954246529695, "color": "blue"}, {"border_width": 0, "value": 2, "y": 324.69946920468357, "degree": 16, "title": "http://mychem.info/v1/query", "id": "http://mychem.info/v1/query", "node_shape": "dot", "x": 324.69946920468357, "color": "blue"}, {"border_width": 0, "value": 2, "y": 245.48548714079922, "degree": 2, "title": "mychem.info", "id": "mychem.info", "node_shape": "dot", "x": 245.48548714079922, "color": "red"}, {"border_width": 0, "value": 2, "y": 164.59459028073397, "degree": 4, "title": "https://api.monarchinitiative.org/api/bioentity/disease/{disease id}/genes/", "id": "https://api.monarchinitiative.org/api/bioentity/disease/{disease id}/genes/", "node_shape": "dot", "x": 164.59459028073397, "color": "blue"}, {"border_width": 0, "value": 2, "y": 82 ...

# %% [markdown]
# #### Find Path
# The CQ question above ask to find the path connecting **NCBI Gene IDs** and **PTM info**.
# **find_path** function could be used here to find how two different biological entities/concepts can be connected together through API endpoints

# %%
k.find_path('NCBI Gene', 'PTM Object')
# Out:
# Path 0: [{'input': 'NCBI Gene', 'endpoint': 'http://mygene.info/v3/gene/geneid', 'output': 'UniProt Knowledgebase'}, {'input': 'UniProt Knowledgebase', 'endpoint': 'http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM', 'output': 'PTM Object'}]
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file7"];    frame.runVis([{"border_width": 0, "value": 2, "y": 1000.0, "degree": 2, "title": "UniProt Knowledgebase", "id": "UniProt Knowledgebase", "node_shape": "dot", "x": 1000.0, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 309.01699437494744, "degree": 1, "title": "NCBI Gene", "id": "NCBI Gene", "node_shape": "dot", "x": 309.01699437494744, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": -809.0169943749473, "degree": 2, "title": "http://mygene.info/v3/gene/geneid", "id": "http://mygene.info/v3/gene/geneid", "node_shape": "dot", "x": -809.0169943749473, "color": "rgba(256, 76, 179, 1)"}, {"border_width": 0, "value": 2, "y": -809.0169943749474, "degree": 2, "title": "http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM", "id": "http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM", "node_shape": "dot", "x": -809.0169943749474, "color": "rgba(256, 76, 179, 1)"}, {"border_width": 0, "value": 2, "y": 309.0169943749472, "degree": 1, "title": "PTM Object", "id": "PTM Object", "node_shape": "dot", "x": 309.0169943749472, "color": "rgba(256, 230, 25, 1)"}], [{"target": 2, "title": "test", "source": 0, "color": "gray"}, {"target": 3, "title": "test", "source": 0, "color": "gray"}, {"target": 2, "title": "test", "source": 1, "color": "gray"}, {"target": 4, "title": "test", "source": 3, "color": "gray"}]);}</script><iframe name="style_file7" src="style_file7.html" height="1200px" width="100%;"></iframe></body></html>

# %% [markdown]
# #### Find output for single input
# Users could utilize **find_output** function to find the output for one single input using the selected path

# %%
# 675 is a NCBI Gene ID in the FA Gene List
# find_output takes two parameters
# the first parameter is path, users should select the path ID based on the results from 'find_path'
# the second parameter is value, which represent the input value
k.find_output(path=k.paths[0], value='675')
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file8"];    frame.runVis([{"border_width": 0, "value": 2, "y": 1000.0, "degree": 1, "title": "675", "id": "675", "node_shape": "dot", "x": 1000.0, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": -499.9999999999998, "degree": 2, "title": "P51587", "id": "P51587", "node_shape": "dot", "x": -499.9999999999998, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": -500.00000000000045, "degree": 1, "title": "10 PTM Objects", "id": "10 PTM Objects", "node_shape": "dot", "x": -500.00000000000045, "color": "rgba(256, 230, 25, 1)"}], [{"target": 1, "title": "test", "source": 0, "color": "gray"}, {"target": 2, "title": "test", "source": 1, "color": "gray"}]);}</script><iframe name="style_file8" src="style_file8.html" height="1200px" width="100%;"></iframe></body></html>

# %% [markdown]
# #### Print result summary

# %%
k.result_summary()
# Out:
# Your exploration starts from NCBI Gene: 675.
#  It goes through 2 API Endpoints.
#  The final output comes from API Endpoint http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM.
#  You can access the final output by calling the 'final_results' object in pathViewer Class.

# %% [markdown]
# #### Explore results
# The final results is represented using a dictionary with the key being the input, and the value being the final output

# %%
k.final_results
# Out:
# {'675': [{'begin': '70',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '70',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '445',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '445',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '492',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '492',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '755',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '755',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1970',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1970',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2035',
#    'category': 'PTM',
#    'description': 'Phosphothreonine',
#    'end': '2035',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2095',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '2095',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3291',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by CDK1 and CDK2',
#    'end': '3291',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/15800615',
#       'id': '15800615',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15800615'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3319',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '3319',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3387',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by CHEK1 and CHEK2',
#    'end': '3387',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18317453',
#       'id': '18317453',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18317453'}}],
#    'type': 'MOD_RES'}]}

# %% [markdown]
# #### Explorer a list of Inputs
# FA Gene List contains 26 different genes, users could input all these genes together using **find_output** function

# %%
import pandas as pd
'''
return list of FA genes from github txt file
'''
def get_fa_gene_list():
    gene_list_url = 'https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_4_all_genes.txt'
    gl = pd.read_table(gene_list_url, header=None)
    return [_gene.replace('NCBIGene:','') for _gene in gl[0].values.tolist()]
gene_list = get_fa_gene_list()

print(gene_list)
# Out:
# ['2175', '2187', '2176', '2178', '2188', '2189', '55120', '57697', '2177', '55215', '29089', '675', '83990', '79728', '5889', '84464', '2072', '5888', '672', '10459', '7516', '55159', '80233', '91442', '199990', '378708', '201254']

# %%
k.find_output(path=k.paths[0], value=gene_list)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file9"];    frame.runVis([{"border_width": 0, "value": 2, "y": 1000.0, "degree": 1, "title": "675", "id": "675", "node_shape": "dot", "x": 1000.0, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 996.6725824941932, "degree": 1, "title": "201254", "id": "201254", "node_shape": "dot", "x": 996.6725824941932, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 986.7124733912889, "degree": 1, "title": "378708", "id": "378708", "node_shape": "dot", "x": 986.7124733912889, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 970.1859555740645, "degree": 1, "title": "2189", "id": "2189", "node_shape": "dot", "x": 970.1859555740645, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 947.2030102919101, "degree": 1, "title": "2 PTM Objects", "id": "2 PTM Objects", "node_shape": "dot", "x": 947.2030102919101, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 917.9165852537594, "degree": 1, "title": "1 PTM Objects (9)", "id": "1 PTM Objects (9)", "node_shape": "dot", "x": 917.9165852537594, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 882.5215767863212, "degree": 1, "title": "57697", "id": "57697", "node_shape": "dot", "x": 882.5215767863212, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 841.2535328311812, "degree": 1, "title": "5 PTM Objects", "id": "5 PTM Objects", "node_shape": "dot", "x": 841.2535328311812, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 794.3870854121127, "degree": 1, "title": "2177", "id": "2177", "node_shape": "dot", "x": 794.3870854121127, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 742.2341230042699, "degree": 1, "title": "30 PTM Objects", "id": "30 PTM Objects", "node_shape": "dot", "x": 742.2341230042699, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 685.1417149678442, "degree": 1, "title": "1 PTM Objects (1)", "id": "1 PTM Objects (1)", "node_shape": "dot", "x": 685.1417149678442, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 623.4898018587336, "degree": 2, "title": "Q92889", "id": "Q92889", "node_shape": "dot", "x": 623.4898018587336, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 557.6886669868295, "degree": 1, "title": "55159", "id": "55159", "node_shape": "dot", "x": 557.6886669868295, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 488.1762060482814, "degree": 1, "title": "8 PTM Objects", "id": "8 PTM Objects", "node_shape": "dot", "x": 488.1762060482814, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 415.41501300188645, "degree": 2, "title": "P51587", "id": "P51587", "node_shape": "dot", "x": 415.41501300188645, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 339.8893015826169, "degree": 1, "title": "10459", "id": "10459", "node_shape": "dot", "x": 339.8893015826169, "color": "rgba(256, 230, 25, 1)"}, {"border_width": 0, "value": 2, "y": 262.10168293910226, "degree": 2, "title": "O43502", "id": "O43502", "node_shape": "dot", "x": 262.10168293910226, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 182.56982083936168, "degree": 2, "title": "Q8NB91", "id": "Q8NB91", "node_shape": "dot", "x": 182.56982083936168, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 101.82298670383554, "degree": 2, "title": "O15287", "id": "O15287", "node_shape": "dot", "x": 101.82298670383554, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": 20.398537391405437, "degree": 2, "title": "Q8N2Z9", "id": "Q8N2Z9", "node_shape": "dot", "x": 20.398537391405437, "color": "rgba(256, 25, 230, 1)"}, {"border_width": 0, "value": 2, "y": -61.1616608218424 ...

# %%
k.result_summary()
# Out:
# Your exploration starts from NCBI Gene: ['2175', '2187', '2176', '2178', '2188', '2189', '55120', '57697', '2177', '55215', '29089', '675', '83990', '79728', '5889', '84464', '2072', '5888', '672', '10459', '7516', '55159', '80233', '91442', '199990', '378708', '201254'].
#  It goes through 2 API Endpoints.
#  The final output comes from API Endpoint http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM.
#  You can access the final output by calling the 'final_results' object in pathViewer Class.

# %% [markdown]
# Each key in the final_results represent one input (e.g. NCBI Gene ID)

# %%
k.final_results
# Out:
# {'10459': [],
#  '199990': [{'begin': '113',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '113',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '137',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '137',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'}],
#  '201254': [{'begin': '1',
#    'category': 'PTM',
#    'description': 'N-acetylmethionine',
#    'end': '1',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'}],
#  '2072': [{'begin': '289',
#    'category': 'PTM',
#    'description': 'N6-acetyllysine',
#    'end': '289',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19608861',
#       'id': '19608861',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19608861'}}],
#    'type': 'MOD_RES'},
#   {'begin': '521',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '521',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q9QZD4',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q9QZD4'}}],
#    'type': 'MOD_RES'},
#   {'begin': '764',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '764',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q9QZD4',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q9QZD4'}}],
#    'type': 'MOD_RES'},
#   {'begin': '500',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '500',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'}],
#  '2175': [{'begin': '1449',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1449',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18691976',
#       'id': '18691976',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18691976'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'}],
#  '2176': [],
#  '2177': [{'begin': '8',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '8',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '222',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM',
#    'end': '222',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/12086603',
#       'id': '12086603',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/12086603'}}],
#    'type': 'MOD_RES'},
#   {'begin': '592',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '592',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '594',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '594',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '717',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '717',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1257',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1257',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1401',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM',
#    'end': '1401',
#    'evidences': [{'code': 'ECO:0000305'}],
#    'type': 'MOD_RES'},
#   {'begin': '1404',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM',
#    'end': '1404',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/12086603',
#       'id': '12086603',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/12086603'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1412',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1412',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1423',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1423',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1426',
#    'category': 'PTM',
#    'description': 'Phosphothreonine',
#    'end': '1426',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1435',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1435',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}}],
#    'type': 'MOD_RES'},
#   {'begin': '561',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '561',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11239454',
#       'id': '11239454',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11239454'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19111657',
#       'id': '19111657',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19111657'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20603015',
#       'id': '20603015',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20603015'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20603016',
#       'id': '20603016',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20603016'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20603073',
#       'id': '20603073',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20603073'}}],
#    'type': 'CROSSLNK'}],
#  '2178': [{'begin': '249',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '249',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19690332',
#       'id': '19690332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19690332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '346',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by CHEK1',
#    'end': '346',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17296736',
#       'id': '17296736',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17296736'}}],
#    'type': 'MOD_RES'},
#   {'begin': '374',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by CHEK1',
#    'end': '374',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17296736',
#       'id': '17296736',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17296736'}}],
#    'type': 'MOD_RES'}],
#  '2187': [{'begin': '2',
#    'category': 'PTM',
#    'description': 'N-acetylthreonine',
#    'end': '2',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'}],
#  '2188': [],
#  '2189': [{'begin': '7',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '7',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18212739',
#       'id': '18212739',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18212739'}}],
#    'type': 'MOD_RES'}],
#  '29089': [{'begin': '184',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '184',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '91',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '91',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/16916645',
#       'id': '16916645',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/16916645'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19111657',
#       'id': '19111657',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19111657'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '182',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '182',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19111657',
#       'id': '19111657',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19111657'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '191',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '191',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '192',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '192',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'}],
#  '378708': [{'begin': '1',
#    'category': 'PTM',
#    'description': 'N-acetylmethionine',
#    'end': '1',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'}],
#  '55120': [{'begin': '2',
#    'category': 'PTM',
#    'description': 'N-acetylalanine',
#    'end': '2',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'}],
#  '55159': [{'begin': '46',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM and ATR',
#    'end': '46',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20173098',
#       'id': '20173098',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20173098'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28575657',
#       'id': '28575657',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28575657'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28575658',
#       'id': '28575658',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28575658'}}],
#    'type': 'MOD_RES'},
#   {'begin': '63',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM and ATR',
#    'end': '63',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20173098',
#       'id': '20173098',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20173098'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28575657',
#       'id': '28575657',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28575657'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28575658',
#       'id': '28575658',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28575658'}}],
#    'type': 'MOD_RES'}],
#  '55215': [{'begin': '407',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '407',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/16964243',
#       'id': '16964243',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/16964243'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '556',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '556',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q8K368',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q8K368'}}],
#    'type': 'MOD_RES'},
#   {'begin': '730',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '730',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17412408',
#       'id': '17412408',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17412408'}}],
#    'type': 'MOD_RES'},
#   {'begin': '952',
#    'category': 'PTM',
#    'description': 'Phosphothreonine',
#    'end': '952',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17412408',
#       'id': '17412408',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17412408'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1121',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1121',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17412408',
#       'id': '17412408',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17412408'}}],
#    'type': 'MOD_RES'},
#   {'begin': '523',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '523',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17412408',
#       'id': '17412408',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17412408'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17460694',
#       'id': '17460694',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17460694'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19589784',
#       'id': '19589784',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19589784'}}],
#    'type': 'CROSSLNK'}],
#  '57697': [{'begin': '34',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '34',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1673',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1673',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1674',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1674',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'}],
#  '5888': [{'begin': '2',
#    'category': 'PTM',
#    'description': 'N-acetylalanine',
#    'end': '2',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'},
#   {'begin': '54',
#    'category': 'PTM',
#    'description': 'Phosphotyrosine; by ABL1',
#    'end': '54',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/9461559',
#       'id': '9461559',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9461559'}}],
#    'type': 'MOD_RES'},
#   {'begin': '309',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by CHEK1',
#    'end': '309',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/15665856',
#       'id': '15665856',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15665856'}}],
#    'type': 'MOD_RES'},
#   {'begin': '58',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '58',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23393192',
#       'id': '23393192',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23393192'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '64',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in ubiquitin)',
#    'end': '64',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23393192',
#       'id': '23393192',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23393192'}}],
#    'type': 'CROSSLNK'}],
#  '5889': [{'begin': '20',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '20',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'}],
#  '672': [{'begin': '1',
#    'category': 'PTM',
#    'description': 'N-acetylmethionine',
#    'end': '1',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22814378',
#       'id': '22814378',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22814378'}}],
#    'type': 'MOD_RES'},
#   {'begin': '114',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '114',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '308',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by AURKA',
#    'end': '308',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/14990569',
#       'id': '14990569',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/14990569'}}],
#    'type': 'MOD_RES'},
#   {'begin': '395',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '395',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19690332',
#       'id': '19690332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19690332'}}],
#    'type': 'MOD_RES'},
#   {'begin': '398',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '398',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19690332',
#       'id': '19690332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19690332'}}],
#    'type': 'MOD_RES'},
#   {'begin': '423',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '423',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '434',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '434',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '551',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '551',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '694',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '694',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '708',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '708',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '725',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '725',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'P48754',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/P48754'}}],
#    'type': 'MOD_RES'},
#   {'begin': '753',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '753',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}}],
#    'type': 'MOD_RES'},
#   {'begin': '840',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '840',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'P48754',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/P48754'}}],
#    'type': 'MOD_RES'},
#   {'begin': '988',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by CHEK2',
#    'end': '988',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/10724175',
#       'id': '10724175',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10724175'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20364141',
#       'id': '20364141',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20364141'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1009',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1009',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1143',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATR; in vitro',
#    'end': '1143',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1189',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1189',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1191',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1191',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1211',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1211',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1217',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1217',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1218',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1218',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1280',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATR; in vitro',
#    'end': '1280',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1328',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1328',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1336',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1336',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17081983',
#       'id': '17081983',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17081983'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1342',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1342',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21406692',
#       'id': '21406692',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21406692'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1387',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM and ATR',
#    'end': '1387',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1394',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by ATR; in vitro',
#    'end': '1394',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1423',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM and ATR',
#    'end': '1423',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1457',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATR; in vitro',
#    'end': '1457',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/11114888',
#       'id': '11114888',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11114888'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1524',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by ATM',
#    'end': '1524',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/21144835',
#       'id': '21144835',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/21144835'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1542',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1542',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '109',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '109',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '301',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '301',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '339',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '339',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '443',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '443',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '459',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '459',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '519',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '519',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '583',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '583',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '654',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '654',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '734',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '734',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '739',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '739',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '918',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '918',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '987',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '987',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1079',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1079',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'}],
#  '675': [{'begin': '70',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '70',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '445',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '445',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '492',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '492',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '755',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '755',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1970',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1970',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2035',
#    'category': 'PTM',
#    'description': 'Phosphothreonine',
#    'end': '2035',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2095',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '2095',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3291',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by CDK1 and CDK2',
#    'end': '3291',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/15800615',
#       'id': '15800615',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15800615'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3319',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '3319',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3387',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by CHEK1 and CHEK2',
#    'end': '3387',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18317453',
#       'id': '18317453',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18317453'}}],
#    'type': 'MOD_RES'}],
#  '7516': [{'begin': '10',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '10',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'}],
#  '79728': [{'begin': '172',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '172',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '190',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '190',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '285',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '285',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '376',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '376',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
# ...
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '990',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '990',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/14576433',
#       'id': '14576433',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/14576433'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1004',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1004',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1032',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1032',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/19690332',
#       'id': '19690332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19690332'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1237',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1237',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1249',
#    'category': 'PTM',
#    'description': 'N6-acetyllysine',
#    'end': '1249',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/22792074',
#       'id': '22792074',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22792074'}}],
#    'type': 'MOD_RES'}],
#  '84464': [{'begin': '169',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '169',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '287',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '287',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1028',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1028',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1044',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1044',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/20068231',
#       'id': '20068231',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20068231'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1070',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1070',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1121',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1121',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q6P1D7',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q6P1D7'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1135',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1135',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q6P1D7',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q6P1D7'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1185',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1185',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1464',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1464',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q6P1D7',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q6P1D7'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1469',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1469',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18220336',
#       'id': '18220336',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18220336'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18669648',
#       'id': '18669648',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18669648'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1610',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1610',
#    'evidences': [{'code': 'ECO:0000250',
#      'source': {'id': 'Q6P1D7',
#       'name': 'UniProtKB',
#       'url': 'http://www.uniprot.org/uniprot/Q6P1D7'}}],
#    'type': 'MOD_RES'},
#   {'begin': '68',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '68',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '291',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '291',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '347',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '347',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '359',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '359',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '412',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '412',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '458',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '458',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '835',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '835',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '902',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '902',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '970',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '970',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1081',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1081',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1093',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1093',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1112',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1112',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1120',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1120',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1169',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1169',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1179',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1179',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1180',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1180',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1575',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1575',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25218447',
#       'id': '25218447',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25218447'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25755297',
#       'id': '25755297',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25755297'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/25772364',
#       'id': '25772364',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25772364'}},
#     {'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1576',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1576',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'},
#   {'begin': '1657',
#    'category': 'PTM',
#    'description': 'Glycyl lysine isopeptide (Lys-Gly) (interchain with G-Cter in SUMO2)',
#    'end': '1657',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/28112733',
#       'id': '28112733',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/28112733'}}],
#    'type': 'CROSSLNK'}],
#  '91442': []}

# %% [markdown]
# #### Retrieve output for a specific NCBI Gene ID in the FA Gene List

# %%
k.final_results['199990']
# Out:
# [{'begin': '113',
#   'category': 'PTM',
#   'description': 'Phosphoserine',
#   'end': '113',
#   'evidences': [{'code': 'ECO:0000244',
#     'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#      'id': '23186163',
#      'name': 'PubMed',
#      'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#   'type': 'MOD_RES'},
#  {'begin': '137',
#   'category': 'PTM',
#   'description': 'Phosphoserine',
#   'end': '137',
#   'evidences': [{'code': 'ECO:0000244',
#     'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#      'id': '23186163',
#      'name': 'PubMed',
#      'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#   'type': 'MOD_RES'}]
