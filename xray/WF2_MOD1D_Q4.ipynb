# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q3 - "What proteins are the target of $chemical_substance"
request = { "query_type_id": "Q3", "terms": { "chemical_substance": "CHEMBL.COMPOUND:CHEMBL1276308" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	amyloid beta precursor protein	UniProtKB:P05067
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	myosin light chain kinase	UniProtKB:Q15746
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	nuclear receptor subfamily 3 group C member 2	UniProtKB:P08235
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	cytochrome P450 family 19 subfamily A member 1	UniProtKB:P11511
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	tyrosine hydroxylase	UniProtKB:P07101
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	solute carrier family 6 member 2	UniProtKB:P23975
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	nuclear receptor subfamily 3 group C member 1	UniProtKB:P04150
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	cytochrome P450 family 2 subfamily D member 6	UniProtKB:P10635
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	Bloom syndrome RecQ like helicase	UniProtKB:P54132
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	estrogen receptor 2	UniProtKB:Q92731
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	cytochrome P450 family 3 subfamily A member 4	UniProtKB:P08684
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	calcium voltage-gated channel subunit alpha1 H	UniProtKB:O95180
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	EBP, cholestenol delta-isomerase	UniProtKB:Q15125
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	TNF superfamily member 11	UniProtKB:O14788
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	progesterone receptor	UniProtKB:P06401
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	tyrosyl-DNA phosphodiesterase 1	UniProtKB:Q9NUW8
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	sex hormone binding globulin	UniProtKB:P04278
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	colony stimulating factor 1 receptor	UniProtKB:P07333
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	hypoxia inducible factor 1 subunit alpha	UniProtKB:Q16665
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	nuclear factor kappa B subunit 1	UniProtKB:P19838
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	cytochrome P450 family 3 subfamily A member 5	UniProtKB:P20815
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	hydroxysteroid 11-beta dehydrogenase 2	UniProtKB:P80365
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	androgen receptor	UniProtKB:P10275
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	apurinic/apyrimidinic endodeoxyribonuclease 1	UniProtKB:P27695
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	estrogen receptor 1	UniProtKB:P03372
# mifepristone	CHEMBL.COMPOUND:CHEMBL1276308	cytochrome P450 family 2 subfamily C member 19	UniProtKB:P33261

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-12 21:56:25",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/382",
#     "message": "26 results found",
#     "original_question_text": "",
#     "query_type_id": "Q3",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "amyloid beta precursor protein",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7122",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P05067",
#                         "source_id": "UniProtKB:P05067",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a cell surface receptor and transmembrane precursor protein that is cleaved by secretases to form a number of peptides. Some of these peptides are secreted and can bind to the acetyltransferase complex APBB1/TIP60 to promote transcriptional activation, while others form the protein basis of the amyloid plaques found in the brains of patients with Alzheimer disease. In addition, two of the peptides are antimicrobial peptides, having been shown to have bacteriocidal and antifungal activities. Mutations in this gene have been implicated in autosomal dominant Alzheimer disease and cerebroarterial amyloidosis (cerebral amyloid angiopathy). Multiple transcript variants encoding several different isoforms have been found for this gene. [provided by RefSeq, Aug 2014].",
#                         "id": "UniProtKB:P05067",
#                         "name": "amyloid beta precursor protein",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P05067"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "amyloid beta precursor protein",
#                 "UniProtKB:P05067"
#             ],
#             "text": "mifepristone and amyloid beta precursor protein are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "myosin light chain kinase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7123",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q15746",
#                         "source_id": "UniProtKB:Q15746",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene, a muscle member of the immunoglobulin gene superfamily, encodes myosin light chain kinase which is a calcium/calmodulin dependent enzyme. This kinase phosphorylates myosin regulatory light chains to facilitate myosin interaction with actin filaments to produce contractile activity. This gene encodes both smooth muscle and nonmuscle isoforms. In addition, using a separate promoter in an intron in the 3' region, it encodes telokin, a small protein identical in sequence to the C-terminus of myosin light chain kinase, that is independently expressed in smooth muscle and functions to stabilize unphosphorylated myosin filaments. A pseudogene is located on the p arm of chromosome 3. Four transcript variants that produce four isoforms of the calcium/calmodulin dependent enzyme have been identified as well as two transcripts that produce two isoforms of telokin. Additional variants have been identified but lack full length transcripts. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q15746",
#                         "name": "myosin light chain kinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q15746"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "myosin light chain kinase",
#                 "UniProtKB:Q15746"
#             ],
#             "text": "mifepristone and myosin light chain kinase are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nuclear receptor subfamily 3 group C member 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7124",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P08235",
#                         "source_id": "UniProtKB:P08235",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes the mineralocorticoid receptor, which mediates aldosterone actions on salt and water balance within restricted target cells. The protein functions as a ligand-dependent transcription factor that binds to mineralocorticoid response elements in order to transactivate target genes. Mutations in this gene cause autosomal dominant pseudohypoaldosteronism type I, a disorder characterized by urinary salt wasting. Defects in this gene are also associated with early onset hypertension with severe exacerbation in pregnancy. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2009].",
#                         "id": "UniProtKB:P08235",
#                         "name": "nuclear receptor subfamily 3 group C member 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P08235"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "nuclear receptor subfamily 3 group C member 2",
#                 "UniProtKB:P08235"
#             ],
#             "text": "mifepristone and nuclear receptor subfamily 3 group C member 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 19 subfamily A member 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7125",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P11511",
#                         "source_id": "UniProtKB:P11511",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and catalyzes the last steps of estrogen biosynthesis. Mutations in this gene can result in either increased or decreased aromatase activity; the associated phenotypes suggest that estrogen functions both as a sex steroid hormone and in growth or differentiation. Alternative promoter use and alternative splicing results in multiple transcript variants that have different tissue specificities. [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P11511",
#                         "name": "cytochrome P450 family 19 subfamily A member 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P11511"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "cytochrome P450 family 19 subfamily A member 1",
#                 "UniProtKB:P11511"
#             ],
#             "text": "mifepristone and cytochrome P450 family 19 subfamily A member 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tyrosine hydroxylase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7126",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P07101",
#                         "source_id": "UniProtKB:P07101",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is involved in the conversion of tyrosine to dopamine. It is the rate-limiting enzyme in the synthesis of catecholamines, hence plays a key role in the physiology of adrenergic neurons. Mutations in this gene have been associated with autosomal recessive Segawa syndrome. Alternatively spliced transcript variants encoding different isoforms have been noted for this gene. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P07101",
#                         "name": "tyrosine hydroxylase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P07101"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "tyrosine hydroxylase",
#                 "UniProtKB:P07101"
#             ],
#             "text": "mifepristone and tyrosine hydroxylase are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "solute carrier family 6 member 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7127",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P23975",
#                         "source_id": "UniProtKB:P23975",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the sodium:neurotransmitter symporter family. This member is a multi-pass membrane protein, which is responsible for reuptake of norepinephrine into presynaptic nerve terminals and is a regulator of norepinephrine homeostasis. Mutations in this gene cause orthostatic intolerance, a syndrome characterized by lightheadedness, fatigue, altered mentation and syncope. Alternatively spliced transcript variants encoding different isoforms have been identified in this gene.[provided by RefSeq, Feb 2010].",
#                         "id": "UniProtKB:P23975",
#                         "name": "solute carrier family 6 member 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P23975"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "solute carrier family 6 member 2",
#                 "UniProtKB:P23975"
#             ],
#             "text": "mifepristone and solute carrier family 6 member 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nuclear receptor subfamily 3 group C member 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7128",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P04150",
#                         "source_id": "UniProtKB:P04150",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes glucocorticoid receptor, which can function both as a transcription factor that binds to glucocorticoid response elements in the promoters of glucocorticoid responsive genes to activate their transcription, and as a regulator of other transcription factors. This receptor is typically found in the cytoplasm, but upon ligand binding, is transported into the nucleus. It is involved in inflammatory responses, cellular proliferation, and differentiation in target tissues. Mutations in this gene are associated with generalized glucocorticoid resistance. Alternative splicing of this gene results in transcript variants encoding either the same or different isoforms. Additional isoforms resulting from the use of alternate in-frame translation initiation sites have also been described, and shown to be functional, displaying diverse cytoplasm-to-nucleus trafficking patterns and distinct transcriptional activities (PMID:15866175). [provided by RefSeq, Feb 2011].",
#                         "id": "UniProtKB:P04150",
#                         "name": "nuclear receptor subfamily 3 group C member 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04150"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "nuclear receptor subfamily 3 group C member 1",
#                 "UniProtKB:P04150"
#             ],
#             "text": "mifepristone and nuclear receptor subfamily 3 group C member 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 2 subfamily D member 6",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7129",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P10635",
#                         "source_id": "UniProtKB:P10635",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and is known to metabolize as many as 25% of commonly prescribed drugs. Its substrates include antidepressants, antipsychotics, analgesics and antitussives, beta adrenergic blocking agents, antiarrythmics and antiemetics. The gene is highly polymorphic in the human population; certain alleles result in the poor metabolizer phenotype, characterized by a decreased ability to metabolize the enzyme's substrates. Some individuals with the poor metabolizer phenotype have no functional protein since they carry 2 null alleles whereas in other individuals the gene is absent. This gene can vary in copy number and individuals with the ultrarapid metabolizer phenotype can have 3 or more active copies of the gene. Alternatively spliced transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jul 2014].",
#                         "id": "UniProtKB:P10635",
#                         "name": "cytochrome P450 family 2 subfamily D member 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P10635"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "cytochrome P450 family 2 subfamily D member 6",
#                 "UniProtKB:P10635"
#             ],
#             "text": "mifepristone and cytochrome P450 family 2 subfamily D member 6 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Bloom syndrome RecQ like helicase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7130",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P54132",
#                         "source_id": "UniProtKB:P54132",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The Bloom syndrome gene product is related to the RecQ subset of DExH box-containing DNA helicases and has both DNA-stimulated ATPase and ATP-dependent DNA helicase activities. Mutations causing Bloom syndrome delete or alter helicase motifs and may disable the 3'-5' helicase activity.  The normal protein may act to suppress inappropriate recombination. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P54132",
#                         "name": "Bloom syndrome RecQ like helicase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P54132"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "Bloom syndrome RecQ like helicase",
#                 "UniProtKB:P54132"
#             ],
#             "text": "mifepristone and Bloom syndrome RecQ like helicase are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "estrogen receptor 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7131",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92731",
#                         "source_id": "UniProtKB:Q92731",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the family of estrogen receptors and superfamily of nuclear receptor transcription factors. The gene product contains an N-terminal DNA binding domain and C-terminal ligand binding domain and is localized to the nucleus, cytoplasm, and mitochondria. Upon binding to 17beta-estradiol or related ligands, the encoded protein forms homo- or hetero-dimers that interact with specific DNA sequences to activate transcription. Some isoforms dominantly inhibit the activity of other estrogen receptor family members. Several alternatively spliced transcript variants of this gene have been described, but the full-length nature of some of these variants has not been fully characterized. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q92731",
#                         "name": "estrogen receptor 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92731"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "estrogen receptor 2",
#                 "UniProtKB:Q92731"
#             ],
#             "text": "mifepristone and estrogen receptor 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 3 subfamily A member 4",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7132",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P08684",
#                         "source_id": "UniProtKB:P08684",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases that catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and its expression is induced by glucocorticoids and some pharmacological agents. This enzyme is involved in the metabolism of approximately half the drugs in use today, including acetaminophen, codeine, cyclosporin A, diazepam and erythromycin. The enzyme also metabolizes some steroids and carcinogens. This gene is part of a cluster of cytochrome P450 genes on chromosome 7q21.1. Previously another CYP3A gene, CYP3A3, was thought to exist; however, it is now thought that this sequence represents a transcript variant of CYP3A4. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Feb 2011].",
#                         "id": "UniProtKB:P08684",
#                         "name": "cytochrome P450 family 3 subfamily A member 4",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P08684"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "cytochrome P450 family 3 subfamily A member 4",
#                 "UniProtKB:P08684"
#             ],
#             "text": "mifepristone and cytochrome P450 family 3 subfamily A member 4 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "calcium voltage-gated channel subunit alpha1 H",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7133",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O95180",
#                         "source_id": "UniProtKB:O95180",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a T-type member of the alpha-1 subunit family, a protein in the voltage-dependent calcium channel complex. Calcium channels mediate the influx of calcium ions into the cell upon membrane polarization and consist of a complex of alpha-1, alpha-2/delta, beta, and gamma subunits in a 1:1:1:1 ratio. The alpha-1 subunit has 24 transmembrane segments and forms the pore through which ions pass into the cell. There are multiple isoforms of each of the proteins in the complex, either encoded by different genes or the result of alternative splicing of transcripts. Alternate transcriptional splice variants, encoding different isoforms, have been characterized for the gene described here. Studies suggest certain mutations in this gene lead to childhood absence epilepsy (CAE). [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O95180",
#                         "name": "calcium voltage-gated channel subunit alpha1 H",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O95180"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "calcium voltage-gated channel subunit alpha1 H",
#                 "UniProtKB:O95180"
#             ],
#             "text": "mifepristone and calcium voltage-gated channel subunit alpha1 H are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "EBP, cholestenol delta-isomerase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7134",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q15125",
#                         "source_id": "UniProtKB:Q15125",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is an integral membrane protein of the endoplasmic reticulum. It is a high affinity binding protein for the antiischemic phenylalkylamine Ca2+ antagonist [3H]emopamil and the photoaffinity label [3H]azidopamil. It is similar to sigma receptors and may be a member of a superfamily of high affinity drug-binding proteins in the endoplasmic reticulum of different tissues. This protein shares structural features with bacterial and eukaryontic drug transporting proteins. It has four putative transmembrane segments and contains two conserved glutamate residues which may be involved in the transport of cationic amphiphilics. Another prominent feature of this protein is its high content of aromatic amino acid residues (>23%) in its transmembrane segments. These aromatic amino acid residues have been suggested to be involved in the drug transport by the P-glycoprotein. Mutations in this gene cause Chondrodysplasia punctata 2 (CDPX2; also known as Conradi-Hunermann syndrome). [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q15125",
#                         "name": "EBP, cholestenol delta-isomerase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q15125"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "EBP, cholestenol delta-isomerase",
#                 "UniProtKB:Q15125"
#             ],
#             "text": "mifepristone and EBP, cholestenol delta-isomerase are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "TNF superfamily member 11",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7135",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O14788",
#                         "source_id": "UniProtKB:O14788",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes a member of the tumor necrosis factor (TNF) cytokine family which is a ligand for osteoprotegerin and functions as a key factor for osteoclast differentiation and activation. This protein was shown to be a dentritic cell survival factor and is involved in the regulation of T cell-dependent immune response. T cell activation was reported to induce expression of this gene and lead to an increase of osteoclastogenesis and bone loss. This protein was shown to activate antiapoptotic kinase AKT/PKB through a signaling complex involving SRC kinase and tumor necrosis factor receptor-associated factor (TRAF) 6, which indicated this protein may have a role in the regulation of cell apoptosis. Targeted disruption of the related gene in mice led to severe osteopetrosis and a lack of osteoclasts. The deficient mice exhibited defects in early differentiation of T and B lymphocytes, and failed to form lobulo-alveolar mammary structures during pregnancy. Two alternatively spliced transcript variants have been found. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O14788",
#                         "name": "TNF superfamily member 11",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O14788"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "TNF superfamily member 11",
#                 "UniProtKB:O14788"
#             ],
#             "text": "mifepristone and TNF superfamily member 11 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "progesterone receptor",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7136",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P06401",
#                         "source_id": "UniProtKB:P06401",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes a member of the steroid receptor superfamily. The encoded protein mediates the physiological effects of progesterone, which plays a central role in reproductive events associated with the establishment and maintenance of pregnancy. This gene uses two distinct promotors and translation start sites in the first exon to produce several transcript variants, both protein coding and non-protein coding. Two of the isoforms (A and B) are identical except for an additional 165 amino acids found in the N-terminus of isoform B and mediate their own response genes and physiologic effects with little overlap. [provided by RefSeq, Sep 2015].",
#                         "id": "UniProtKB:P06401",
#                         "name": "progesterone receptor",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P06401"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "progesterone receptor",
#                 "UniProtKB:P06401"
#             ],
#             "text": "mifepristone and progesterone receptor are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tyrosyl-DNA phosphodiesterase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7137",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NUW8",
#                         "source_id": "UniProtKB:Q9NUW8",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is involved in repairing stalled topoisomerase I-DNA complexes by catalyzing the hydrolysis of the phosphodiester bond between the tyrosine residue of topoisomerase I and the 3-prime phosphate of DNA. This protein may also remove glycolate from single-stranded DNA containing 3-prime phosphoglycolate, suggesting a role in repair of free-radical mediated DNA double-strand breaks. This gene is a member of the phospholipase D family and contains two PLD phosphodiesterase domains. Mutations in this gene are associated with the disease spinocerebellar ataxia with axonal neuropathy (SCAN1). [provided by RefSeq, Aug 2016].",
#                         "id": "UniProtKB:Q9NUW8",
#                         "name": "tyrosyl-DNA phosphodiesterase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NUW8"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "tyrosyl-DNA phosphodiesterase 1",
#                 "UniProtKB:Q9NUW8"
#             ],
#             "text": "mifepristone and tyrosyl-DNA phosphodiesterase 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "sex hormone binding globulin",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7138",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P04278",
#                         "source_id": "UniProtKB:P04278",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes a steroid binding protein that was first described as a plasma protein secreted by the liver but is now thought to participate in the regulation of steroid responses. The encoded protein transports androgens and estrogens in the blood, binding each steroid molecule as a dimer formed from identical or nearly identical monomers. Polymorphisms in this gene have been associated with polycystic ovary syndrome and type 2 diabetes mellitus. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Jan 2014].",
#                         "id": "UniProtKB:P04278",
#                         "name": "sex hormone binding globulin",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04278"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "sex hormone binding globulin",
#                 "UniProtKB:P04278"
#             ],
#             "text": "mifepristone and sex hormone binding globulin are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "colony stimulating factor 1 receptor",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7139",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P07333",
#                         "source_id": "UniProtKB:P07333",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is the receptor for colony stimulating factor 1, a cytokine which controls the production, differentiation, and function of macrophages. This receptor mediates most if not all of the biological effects of this cytokine. Ligand binding activates the receptor kinase through a process of oligomerization and transphosphorylation. The encoded protein is a tyrosine kinase transmembrane receptor and member of the CSF1/PDGF receptor family of tyrosine-protein kinases. Mutations in this gene have been associated with a predisposition to myeloid malignancy. The first intron of this gene contains a transcriptionally inactive ribosomal protein L7 processed pseudogene oriented in the opposite direction. Alternative splicing results in multiple transcript variants. Expression of a splice variant from an LTR promoter has been found in Hodgkin lymphoma (HL), HL cell lines and anaplastic large cell lymphoma. [provided by RefSeq, Mar 2017].",
#                         "id": "UniProtKB:P07333",
#                         "name": "colony stimulating factor 1 receptor",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P07333"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "colony stimulating factor 1 receptor",
#                 "UniProtKB:P07333"
#             ],
#             "text": "mifepristone and colony stimulating factor 1 receptor are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "hypoxia inducible factor 1 subunit alpha",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7140",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q16665",
#                         "source_id": "UniProtKB:Q16665",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
# ...
#             ],
#             "text": "mifepristone and nuclear factor kappa B subunit 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 3 subfamily A member 5",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7142",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P20815",
#                         "source_id": "UniProtKB:P20815",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. The encoded protein metabolizes drugs as well as the steroid hormones testosterone and progesterone. This gene is part of a cluster of cytochrome P450 genes on chromosome 7q21.1. Two pseudogenes of this gene have been identified within this cluster on chromosome 7. Expression of this gene is widely variable among populations, and a single nucleotide polymorphism that affects transcript splicing has been associated with susceptibility to hypertensions. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Apr 2014].",
#                         "id": "UniProtKB:P20815",
#                         "name": "cytochrome P450 family 3 subfamily A member 5",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P20815"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "cytochrome P450 family 3 subfamily A member 5",
#                 "UniProtKB:P20815"
#             ],
#             "text": "mifepristone and cytochrome P450 family 3 subfamily A member 5 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "hydroxysteroid 11-beta dehydrogenase 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7143",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P80365",
#                         "source_id": "UniProtKB:P80365",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "There are at least two isozymes of the corticosteroid 11-beta-dehydrogenase, a microsomal enzyme complex responsible for the interconversion of cortisol and cortisone. The type I isozyme has both 11-beta-dehydrogenase (cortisol to cortisone) and 11-oxoreductase (cortisone to cortisol) activities. The type II isozyme, encoded by this gene, has only 11-beta-dehydrogenase activity. In aldosterone-selective epithelial tissues such as the kidney, the type II isozyme catalyzes the glucocorticoid cortisol to the inactive metabolite cortisone, thus preventing illicit activation of the mineralocorticoid receptor. In tissues that do not express the mineralocorticoid receptor, such as the placenta and testis, it protects cells from the growth-inhibiting and/or pro-apoptotic effects of cortisol, particularly during embryonic development. Mutations in this gene cause the syndrome of apparent mineralocorticoid excess and hypertension. [provided by RefSeq, Feb 2010].",
#                         "id": "UniProtKB:P80365",
#                         "name": "hydroxysteroid 11-beta dehydrogenase 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P80365"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "hydroxysteroid 11-beta dehydrogenase 2",
#                 "UniProtKB:P80365"
#             ],
#             "text": "mifepristone and hydroxysteroid 11-beta dehydrogenase 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "androgen receptor",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7144",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P10275",
#                         "source_id": "UniProtKB:P10275",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "The androgen receptor gene is more than 90 kb long and codes for a protein that has 3 major functional domains: the N-terminal domain, DNA-binding domain, and androgen-binding domain. The protein functions as a steroid-hormone activated transcription factor. Upon binding the hormone ligand, the receptor dissociates from accessory proteins, translocates into the nucleus, dimerizes, and then stimulates transcription of androgen responsive genes. This gene contains 2 polymorphic trinucleotide repeat segments that encode polyglutamine and polyglycine tracts in the N-terminal transactivation domain of its protein. Expansion of the polyglutamine tract from the normal 9-34 repeats to the pathogenic 38-62 repeats causes spinal bulbar muscular atrophy (SBMA, also known as Kennedy's disease). Mutations in this gene are also associated with complete androgen insensitivity (CAIS). Alternative splicing results in multiple transcript variants encoding different isoforms. [provided by RefSeq, Jan 2017].",
#                         "id": "UniProtKB:P10275",
#                         "name": "androgen receptor",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P10275"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "androgen receptor",
#                 "UniProtKB:P10275"
#             ],
#             "text": "mifepristone and androgen receptor are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "apurinic/apyrimidinic endodeoxyribonuclease 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7145",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P27695",
#                         "source_id": "UniProtKB:P27695",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "Apurinic/apyrimidinic (AP) sites occur frequently in DNA molecules by spontaneous hydrolysis, by DNA damaging agents or by DNA glycosylases that remove specific abnormal bases. AP sites are pre-mutagenic lesions that can prevent normal DNA replication so the cell contains systems to identify and repair such sites. Class II AP endonucleases cleave the phosphodiester backbone 5' to the AP site. This gene encodes the major AP endonuclease in human cells. Splice variants have been found for this gene; all encode the same protein. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P27695",
#                         "name": "apurinic/apyrimidinic endodeoxyribonuclease 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P27695"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "apurinic/apyrimidinic endodeoxyribonuclease 1",
#                 "UniProtKB:P27695"
#             ],
#             "text": "mifepristone and apurinic/apyrimidinic endodeoxyribonuclease 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "estrogen receptor 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7146",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P03372",
#                         "source_id": "UniProtKB:P03372",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes an estrogen receptor, a ligand-activated transcription factor composed of several domains important for hormone binding, DNA binding, and activation of transcription. The protein localizes to the nucleus where it may form a homodimer or a heterodimer with estrogen receptor 2. Estrogen and its receptors are essential for sexual development and reproductive function, but also play a role in other tissues such as bone. Estrogen receptors are also involved in pathological processes including breast cancer, endometrial cancer, and osteoporosis. Alternative promoter usage and alternative splicing result in dozens of transcript variants, but the full-length nature of many of these variants has not been determined. [provided by RefSeq, Mar 2014].",
#                         "id": "UniProtKB:P03372",
#                         "name": "estrogen receptor 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P03372"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "estrogen receptor 1",
#                 "UniProtKB:P03372"
#             ],
#             "text": "mifepristone and estrogen receptor 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 2 subfamily C member 19",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7147",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P33261",
#                         "source_id": "UniProtKB:P33261",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1276308",
#                         "name": "mifepristone",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1276308"
#                     },
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and is known to metabolize many xenobiotics, including the anticonvulsive drug mephenytoin, omeprazole, diazepam and some barbiturates. Polymorphism within this gene is associated with variable ability to metabolize mephenytoin, known as the poor metabolizer and extensive metabolizer phenotypes. The gene is located within a cluster of cytochrome P450 genes on chromosome 10q24. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P33261",
#                         "name": "cytochrome P450 family 2 subfamily C member 19",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P33261"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "mifepristone",
#                 "CHEMBL.COMPOUND:CHEMBL1276308",
#                 "cytochrome P450 family 2 subfamily C member 19",
#                 "UniProtKB:P33261"
#             ],
#             "text": "mifepristone and cytochrome P450 family 2 subfamily C member 19 are connected by the relationship physically_interacts_with"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "chemical_substance": "CHEMBL.COMPOUND:CHEMBL1276308"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
