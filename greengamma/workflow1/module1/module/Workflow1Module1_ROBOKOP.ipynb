# %% [markdown]
# # Workflow 1, Module 1 (condition similarity)

# %% [markdown]
# One approach to solving this module is to not define quite so tightly what's going on at the subquestion level in terms of enrichements and archetypes and so on, but simply pass the question to ROBOKOP and let its scoring bring the the best answers to the top.  Here we will use the quick service to start with a disease, find relevant phenotypes, and from there find genetic conditions. The answers will come out ranked by path.
#
# For more details, see the "quick" notebook in greengamma/general.
#
# First, we'll have a quick function that calls the quick service, and some functions for properly creating the question.  Then we'll create the question, run it, and pretty print it for two examples: diabetes and asthma.

# %%
import requests
import pandas as pd

def quick(question):
    url=f'http://robokop.renci.org:80/api/simple/quick/'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %%
def make_N_step_question(types,curies):
    question = {
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    for i,t in enumerate(types):
        newnode = {'id': i, 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        if i > 0:
            question['machine_question']['edges'].append( {'source_id': i-1, 'target_id': i})
    return question

# %%
def extract_final_nodes(returnanswer):
    nodes = [{'node_name': answer['nodes'][2]['name'], 'node_id': answer['nodes'][2]['id']} for answer in returnanswer['answers']]
    return pd.DataFrame(nodes)

# %%
diabetes = 'MONDO:0005148' #type 2 diabetes
asthma = 'MONDO:0004979' #asthma

# %%
diabetes_question = make_N_step_question(['disease','phenotypic_feature','genetic_condition'],[diabetes,None,None])
diabetes_answer = quick(diabetes_question)
# Out:
# Return Status: 200

# %%
diabetes_frame = extract_final_nodes(diabetes_answer)
diabetes_frame
# Out:
#            node_id                                       node_name
# 0    MONDO:0001076                             glucose intolerance
# 1    MONDO:0001076                             glucose intolerance
# 2    MONDO:0018911  maturity-onset diabetes of the young (disease)
# 3    MONDO:0001076                             glucose intolerance
# 4    MONDO:0001076                             glucose intolerance
# 5    MONDO:0001076                             glucose intolerance
# 6    MONDO:0001076                             glucose intolerance
# 7    MONDO:0001076                             glucose intolerance
# 8    MONDO:0001076                             glucose intolerance
# 9    MONDO:0001076                             glucose intolerance
# 10   MONDO:0001076                             glucose intolerance
# 11   MONDO:0001076                             glucose intolerance
# 12   MONDO:0001076                             glucose intolerance
# 13   MONDO:0001076                             glucose intolerance
# 14   MONDO:0005066                               metabolic disease
# 15   MONDO:0001076                             glucose intolerance
# 16   MONDO:0001076                             glucose intolerance
# 17   MONDO:0001076                             glucose intolerance
# 18   MONDO:0010894     maturity-onset diabetes of the young type 3
# 19   MONDO:0005066                               metabolic disease
# 20   MONDO:0001076                             glucose intolerance
# 21   MONDO:0005066                               metabolic disease
# 22   MONDO:0018911  maturity-onset diabetes of the young (disease)
# 23   MONDO:0018911  maturity-onset diabetes of the young (disease)
# 24   MONDO:0018911  maturity-onset diabetes of the young (disease)
# 25   MONDO:0018911  maturity-onset diabetes of the young (disease)
# 26   MONDO:0001076                             glucose intolerance
# 27   MONDO:0012819                           diabetic ketoacidosis
# 28   MONDO:0008487                       polycystic ovary syndrome
# 29   MONDO:0001076                             glucose intolerance
# ..             ...                                             ...
# 220  MONDO:0005803         hyperinsulinemic hypoglycemia (disease)
# 221  MONDO:0008487                       polycystic ovary syndrome
# 222  MONDO:0020088                  familial partial lipodystrophy
# 223  MONDO:0005066                               metabolic disease
# 224  MONDO:0016391                      neonatal diabetes mellitus
# 225  MONDO:0005066                               metabolic disease
# 226  MONDO:0008783                                 Tangier disease
# 227  MONDO:0008487                       polycystic ovary syndrome
# 228  MONDO:0009387          familial lipoprotein lipase deficiency
# 229  MONDO:0005066                               metabolic disease
# 230  MONDO:0012819                           diabetic ketoacidosis
# 231  MONDO:0012819                           diabetic ketoacidosis
# 232  MONDO:0012819                           diabetic ketoacidosis
# 233  MONDO:0010523         X-linked reticulate pigmentary disorder
# 234  MONDO:0005066                               metabolic disease
# 235  MONDO:0005066                               metabolic disease
# 236  MONDO:0005066                               metabolic disease
# 237  MONDO:0019169               pyruvate dehydrogenase deficiency
# 238  MONDO:0005066                               metabolic disease
# 239  MONDO:0012819                           diabetic ketoacidosis
# 240  MONDO:0005066                               metabolic disease
# 241  MONDO:0005066                               metabolic disease
# 242  MONDO:0005066                               metabolic disease
# 243  MONDO:0017182                        familial hyperinsulinism
# 244  MONDO:0020573            hereditary predisposition to disease
# 245  MONDO:0005066                               metabolic disease
# 246  MONDO:0000275                               monogenic disease
# 247  MONDO:0011565                            metabolic syndrome X
# 248  MONDO:0012819                           diabetic ketoacidosis
# 249  MONDO:0012819                           diabetic ketoacidosis
#
# [250 rows x 2 columns]

# %% [markdown]
# It appears that we are getting repeat answers, but that's not the case.  For quick, an answer is the entire path. In this case, (`asthma`)-(`phenotypic_feature`)-(`genetic_condition`).  So if two paths have the same final `genetic_condition`, say, "glucose intolerance", but different `phenotypic_features` then they are considered different paths.  But here we're just writing that final node. If we look at the intermediate nodes, we can see this:

# %%
def extract_both_nodenames(returnanswer):
    nodes = [{'phenotypic_feature': answer['nodes'][1]['name'], 'genetic_condition': answer['nodes'][2]['name']} for answer in returnanswer['answers']]
    return pd.DataFrame(nodes)

# %%
nameframe = extract_both_nodenames(diabetes_answer)
nameframe
# Out:
#                                   genetic_condition  \
# 0                               glucose intolerance
# 1                               glucose intolerance
# 2    maturity-onset diabetes of the young (disease)
# 3                               glucose intolerance
# 4                               glucose intolerance
# 5                               glucose intolerance
# 6                               glucose intolerance
# 7                               glucose intolerance
# 8                               glucose intolerance
# 9                               glucose intolerance
# 10                              glucose intolerance
# 11                              glucose intolerance
# 12                              glucose intolerance
# 13                              glucose intolerance
# 14                                metabolic disease
# 15                              glucose intolerance
# 16                              glucose intolerance
# 17                              glucose intolerance
# 18      maturity-onset diabetes of the young type 3
# 19                                metabolic disease
# 20                              glucose intolerance
# 21                                metabolic disease
# 22   maturity-onset diabetes of the young (disease)
# 23   maturity-onset diabetes of the young (disease)
# 24   maturity-onset diabetes of the young (disease)
# 25   maturity-onset diabetes of the young (disease)
# 26                              glucose intolerance
# 27                            diabetic ketoacidosis
# 28                        polycystic ovary syndrome
# 29                              glucose intolerance
# ..                                              ...
# 220         hyperinsulinemic hypoglycemia (disease)
# 221                       polycystic ovary syndrome
# 222                  familial partial lipodystrophy
# 223                               metabolic disease
# 224                      neonatal diabetes mellitus
# 225                               metabolic disease
# 226                                 Tangier disease
# 227                       polycystic ovary syndrome
# 228          familial lipoprotein lipase deficiency
# 229                               metabolic disease
# 230                           diabetic ketoacidosis
# 231                           diabetic ketoacidosis
# 232                           diabetic ketoacidosis
# 233         X-linked reticulate pigmentary disorder
# 234                               metabolic disease
# 235                               metabolic disease
# 236                               metabolic disease
# 237               pyruvate dehydrogenase deficiency
# 238                               metabolic disease
# 239                           diabetic ketoacidosis
# 240                               metabolic disease
# 241                               metabolic disease
# 242                               metabolic disease
# 243                        familial hyperinsulinism
# 244            hereditary predisposition to disease
# 245                               metabolic disease
# 246                               monogenic disease
# 247                            metabolic syndrome X
# 248                           diabetic ketoacidosis
# 249                           diabetic ketoacidosis
#
#                           phenotypic_feature
# 0                      Increased body weight
# 1       Maturity-onset diabetes of the young
# 2       Maturity-onset diabetes of the young
# 3                   Increased adipose tissue
# 4    Decreased HDL cholesterol concentration
# 5                        Glucose intolerance
# 6                   Fasting hyperinsulinemia
# 7        Insulin-resistant diabetes mellitus
# 8                       Acanthosis nigricans
# 9                           Hyperinsulinemia
# 10                         Maternal diabetes
# 11                 Large for gestational age
# 12                        Polycystic ovaries
# 13                      Hypertriglyceridemia
# 14                     Increased body weight
# 15              Peripheral arterial stenosis
# 16               Abnormal retinal morphology
# 17                             Hyperglycemia
# 18      Maturity-onset diabetes of the young
# 19   Decreased HDL cholesterol concentration
# 20                         Hepatic steatosis
# 21      Maturity-onset diabetes of the young
# 22                         Maternal diabetes
# 23                                Polydipsia
# 24                       Glucose intolerance
# 25                 Large for gestational age
# 26                            Hyperlipidemia
# 27                              Ketoacidosis
# 28                      Acanthosis nigricans
# 29                  Type I diabetes mellitus
# ..                                       ...
# 220                        Hypoglycemic coma
# 221                       Insulin resistance
# 222     Congenital generalized lipodystrophy
# 223                            Periodontitis
# 224                               Glycosuria
# 225                     Mental deterioration
# 226  Decreased HDL cholesterol concentration
# 227                    Hashimoto thyroiditis
# 228  Decreased HDL cholesterol concentration
# 229                         Hypophosphatemia
# 230                              Hypovolemia
# 231                                 Lethargy
# 232                              Weight loss
# 233                        Visual impairment
# 234                   Chronic kidney disease
# 235                       Acute pancreatitis
# 236           Paroxysmal atrial fibrillation
# 237                          Lactic acidosis
# 238                                 Lethargy
# 239     Progressive neurologic deterioration
# 240            Helicobacter pylori infection
# 241                              Sleep apnea
# 242                           Cardiomyopathy
# 243                        Hypoglycemic coma
# 244                             Abnormal EKG
# 245                     Recurrent infections
# 246      Insulin-resistant diabetes mellitus
# 247                        Maternal diabetes
# 248                Abnormality of the kidney
# 249                         Hypophosphatemia
#
# [250 rows x 2 columns]

# %%
asthma_question = make_N_step_question(['disease','phenotypic_feature','genetic_condition'],[asthma,None,None])
asthma_answer = quick(asthma_question)
# Out:
# Return Status: 200

# %%
asthma_frame = extract_final_nodes(asthma_answer)
asthma_frame
# Out:
#            node_id                              node_name
# 0    MONDO:0007186        gastroesophageal reflux disease
# 1    MONDO:0007186        gastroesophageal reflux disease
# 2    MONDO:0011292                     dermatitis, atopic
# 3    MONDO:0011292                     dermatitis, atopic
# 4    MONDO:0011292                     dermatitis, atopic
# 5    MONDO:0009061                        cystic fibrosis
# 6    MONDO:0009061                        cystic fibrosis
# 7    MONDO:0007186        gastroesophageal reflux disease
# 8    MONDO:0013282         alpha 1-antitrypsin deficiency
# 9    MONDO:0007186        gastroesophageal reflux disease
# 10   MONDO:0009061                        cystic fibrosis
# 11   MONDO:0009061                        cystic fibrosis
# 12   MONDO:0009061                        cystic fibrosis
# 13   MONDO:0009061                        cystic fibrosis
# 14   MONDO:0009061                        cystic fibrosis
# 15   MONDO:0007186        gastroesophageal reflux disease
# 16   MONDO:0009061                        cystic fibrosis
# 17   MONDO:0009061                        cystic fibrosis
# 18   MONDO:0007186        gastroesophageal reflux disease
# 19   MONDO:0007186        gastroesophageal reflux disease
# 20   MONDO:0007186        gastroesophageal reflux disease
# 21   MONDO:0009061                        cystic fibrosis
# 22   MONDO:0007186        gastroesophageal reflux disease
# 23   MONDO:0007186        gastroesophageal reflux disease
# 24   MONDO:0007186        gastroesophageal reflux disease
# 25   MONDO:0013282         alpha 1-antitrypsin deficiency
# 26   MONDO:0018037                     hyper-IgE syndrome
# 27   MONDO:0009061                        cystic fibrosis
# 28   MONDO:0008345          idiopathic pulmonary fibrosis
# 29   MONDO:0007186        gastroesophageal reflux disease
# ..             ...                                    ...
# 220  MONDO:0011612                 glycine encephalopathy
# 221  MONDO:0009971  newborn respiratory distress syndrome
# 222  MONDO:0005083                              psoriasis
# 223  MONDO:0005066                      metabolic disease
# 224  MONDO:0019950          congenital muscular dystrophy
# 225  MONDO:0015514       genetic endocrine growth disease
# 226  MONDO:0015514       genetic endocrine growth disease
# 227  MONDO:0010826             childhood absence epilepsy
# 228  MONDO:0011612                 glycine encephalopathy
# 229  MONDO:0015517       common variable immunodeficiency
# 230  MONDO:0005083                              psoriasis
# 231  MONDO:0015977                     agammaglobulinemia
# 232  MONDO:0017989                 His bundle tachycardia
# 233  MONDO:0011382                     sickle cell anemia
# 234  MONDO:0008903                            lung cancer
# 235  MONDO:0010086           sudden infant death syndrome
# 236  MONDO:0008903                            lung cancer
# 237  MONDO:0019091             bronchopulmonary dysplasia
# 238  MONDO:0008575                    nicotine dependence
# 239  MONDO:0009971  newborn respiratory distress syndrome
# 240  MONDO:0010086           sudden infant death syndrome
# 241  MONDO:0016575             primary ciliary dyskinesia
# 242  MONDO:0015977                     agammaglobulinemia
# 243  MONDO:0015517       common variable immunodeficiency
# 244  MONDO:0018037                     hyper-IgE syndrome
# 245  MONDO:0011382                     sickle cell anemia
# 246  MONDO:0007921                   yellow nail syndrome
# 247  MONDO:0019091             bronchopulmonary dysplasia
# 248  MONDO:0011382                     sickle cell anemia
# 249  MONDO:0008903                            lung cancer
#
# [250 rows x 2 columns]
