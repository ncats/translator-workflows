# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q10 - "What proteins are associated with $phenotypic_feature"
#### Set diease to the curie id of the desired phenotype and run.
request = { "query_type_id": "Q10", "terms": { "phenotypic_feature": "HP:0011106" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# Hypovolemia	HP:0011106	steroidogenic acute regulatory protein	UniProtKB:P49675
# Hypovolemia	HP:0011106	cytochrome P450 family 21 subfamily A member 2	UniProtKB:Q16874
# Hypovolemia	HP:0011106	lipase A, lysosomal acid type	UniProtKB:P38571
# Hypovolemia	HP:0011106	insulin like growth factor 2	UniProtKB:P01344
# Hypovolemia	HP:0011106	INS-IGF2 readthrough	UniProtKB:F8WCM5
# Hypovolemia	HP:0011106	cytochrome P450 family 21 subfamily A member 2	UniProtKB:P08686

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-13 19:52:28",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/385",
#     "message": "6 results found",
#     "original_question_text": "",
#     "query_type_id": "Q10",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "steroidogenic acute regulatory protein",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7311",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P49675",
#                         "source_id": "UniProtKB:P49675",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene plays a key role in the acute regulation of steroid hormone synthesis by enhancing the conversion of cholesterol into pregnenolone. This protein permits the cleavage of cholesterol into pregnenolone by mediating the transport of cholesterol from the outer mitochondrial membrane to the inner mitochondrial membrane. Mutations in this gene are a cause of congenital lipoid adrenal hyperplasia (CLAH), also called lipoid CAH. A pseudogene of this gene is located on chromosome 13. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P49675",
#                         "name": "steroidogenic acute regulatory protein",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P49675"
#                     },
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "steroidogenic acute regulatory protein",
#                 "UniProtKB:P49675"
#             ],
#             "text": "Hypovolemia and steroidogenic acute regulatory protein are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 21 subfamily A member 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7312",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q16874",
#                         "source_id": "UniProtKB:Q16874",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     },
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and hydroxylates steroids at the 21 position. Its activity is required for the synthesis of steroid hormones including cortisol and aldosterone. Mutations in this gene cause congenital adrenal hyperplasia. A related pseudogene is located near this gene; gene conversion events involving the functional gene and the pseudogene are thought to account for many cases of steroid 21-hydroxylase deficiency. Two transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q16874",
#                         "name": "cytochrome P450 family 21 subfamily A member 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q16874"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "cytochrome P450 family 21 subfamily A member 2",
#                 "UniProtKB:Q16874"
#             ],
#             "text": "Hypovolemia and cytochrome P450 family 21 subfamily A member 2 are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "lipase A, lysosomal acid type",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7313",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P38571",
#                         "source_id": "UniProtKB:P38571",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     },
#                     {
#                         "description": "This gene encodes lipase A, the lysosomal acid lipase (also known as cholesterol ester hydrolase). This enzyme functions in the lysosome to catalyze the hydrolysis of cholesteryl esters and triglycerides. Mutations in this gene can result in Wolman disease and cholesteryl ester storage disease. Alternatively spliced transcript variants have been found for this gene. [provided by RefSeq, Jan 2014].",
#                         "id": "UniProtKB:P38571",
#                         "name": "lipase A, lysosomal acid type",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P38571"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "lipase A, lysosomal acid type",
#                 "UniProtKB:P38571"
#             ],
#             "text": "Hypovolemia and lipase A, lysosomal acid type are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "insulin like growth factor 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7314",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P01344",
#                         "source_id": "UniProtKB:P01344",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     },
#                     {
#                         "description": "This gene encodes a member of the insulin family of polypeptide growth factors, which are involved in development and growth. It is an imprinted gene, expressed only from the paternal allele, and epigenetic changes at this locus are associated with Wilms tumour, Beckwith-Wiedemann syndrome, rhabdomyosarcoma, and Silver-Russell syndrome. A read-through INS-IGF2 gene exists, whose 5' region overlaps the INS gene and the 3' region overlaps this gene. Alternatively spliced transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Oct 2010].",
#                         "id": "UniProtKB:P01344",
#                         "name": "insulin like growth factor 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P01344"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "insulin like growth factor 2",
#                 "UniProtKB:P01344"
#             ],
#             "text": "Hypovolemia and insulin like growth factor 2 are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "INS-IGF2 readthrough",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7315",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/F8WCM5",
#                         "source_id": "UniProtKB:F8WCM5",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     },
#                     {
#                         "description": "This locus includes two alternatively spliced read-through transcript variants which align to the INS gene in the 5' region and to the IGF2 gene in the 3' region. One transcript is predicted to encode a protein which shares the N-terminus with the INS protein but has a distinct and longer C-terminus, whereas the other transcript is a candidate for nonsense-mediated decay (NMD). The transcripts are imprinted and are paternally expressed in the limb and eye. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:F8WCM5",
#                         "name": "INS-IGF2 readthrough",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/F8WCM5"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "INS-IGF2 readthrough",
#                 "UniProtKB:F8WCM5"
#             ],
#             "text": "Hypovolemia and INS-IGF2 readthrough are connected by the relationship has_phenotype"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cytochrome P450 family 21 subfamily A member 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7316",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P08686",
#                         "source_id": "UniProtKB:P08686",
#                         "target_id": "HP:0011106",
#                         "type": "has_phenotype"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "An decrease in the amount of intravascular fluid, particularly in the volume of the circulating blood.",
#                         "id": "HP:0011106",
#                         "name": "Hypovolemia",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011106"
#                     },
#                     {
#                         "description": "This gene encodes a member of the cytochrome P450 superfamily of enzymes. The cytochrome P450 proteins are monooxygenases which catalyze many reactions involved in drug metabolism and synthesis of cholesterol, steroids and other lipids. This protein localizes to the endoplasmic reticulum and hydroxylates steroids at the 21 position. Its activity is required for the synthesis of steroid hormones including cortisol and aldosterone. Mutations in this gene cause congenital adrenal hyperplasia. A related pseudogene is located near this gene; gene conversion events involving the functional gene and the pseudogene are thought to account for many cases of steroid 21-hydroxylase deficiency. Two transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P08686",
#                         "name": "cytochrome P450 family 21 subfamily A member 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P08686"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Hypovolemia",
#                 "HP:0011106",
#                 "cytochrome P450 family 21 subfamily A member 2",
#                 "UniProtKB:P08686"
#             ],
#             "text": "Hypovolemia and cytochrome P450 family 21 subfamily A member 2 are connected by the relationship has_phenotype"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "phenotypic_feature": "HP:0011106"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
