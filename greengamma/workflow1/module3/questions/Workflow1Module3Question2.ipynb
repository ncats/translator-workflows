# %% [markdown]
# # Workflow 1, Module 3, Question 2

# %% [markdown]
# ## What proteins produce agent [x]?

# %% [markdown]
# Let's run Q1 and use the endogenous output of that.

# %% [markdown]
# ### Expand service

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %% [markdown]
# ### Question 1

# %%
input_identifier='MONDO:0004979'
type1 = 'disease'
type2 = 'chemical_substance'

# %%
result = expand(type1,input_identifier,type2)
result_frame = parse_answer(result)
endogenous = result_frame[ result_frame['type'] == 'related_to' ]
endogenous
# Out:
# Return Status: 200
#           result_id                                result_name  \
# 23      CHEBI:68447                      1,3-dimethyluric acid
# 38      CHEBI:28946                                Theobromine
# 49      CHEBI:25858                               Paraxanthine
# 50      CHEBI:68449                      1,7-Dimethyluric acid
# 51     CHEBI:691622                   1,3,7-trimethyluric acid
# 96      CHEBI:27732                                   Caffeine
# 118     CHEBI:62205                           3-methylxanthine
# 238     CHEBI:68444                           1-methylxanthine
# 239     CHEBI:27595                                  11b-PGF2a
# 243     CHEBI:62207                       3-methyl-7H-xanthine
# 244     CHEBI:28209  5-hydroxy-6,8,11,14-eicosatetraenoic acid
# 490  PUBCHEM:119226                           3-Chlorotyrosine
# 509  PUBCHEM:273429                           Isoleucylproline
#
#                          source        type
# 23   hmdb.metabolite_to_disease  related_to
# 38   hmdb.metabolite_to_disease  related_to
# 49   hmdb.metabolite_to_disease  related_to
# 50   hmdb.metabolite_to_disease  related_to
# 51   hmdb.metabolite_to_disease  related_to
# 96   hmdb.metabolite_to_disease  related_to
# 118  hmdb.metabolite_to_disease  related_to
# 238  hmdb.metabolite_to_disease  related_to
# 239  hmdb.metabolite_to_disease  related_to
# 243  hmdb.metabolite_to_disease  related_to
# 244  hmdb.metabolite_to_disease  related_to
# 490  hmdb.disease_to_metabolite  related_to
# 509  hmdb.disease_to_metabolite  related_to

# %% [markdown]
# ### Question 2

# %%
identifiers = list(endogenous['result_id'])

# %%
genes = {}
for ident in identifiers:
    print(ident)
    genes[ident] = expand('chemical_substance',ident,'gene')
# Out:
# CHEBI:68447
# Return Status: 200
# CHEBI:28946
# Return Status: 200
# CHEBI:25858
# Return Status: 200
# CHEBI:68449
# Return Status: 200
# CHEBI:691622
# Return Status: 200
# CHEBI:27732
# Return Status: 200
# CHEBI:62205
# Return Status: 200
# CHEBI:68444
# Return Status: 200
# CHEBI:27595
# Return Status: 200
# CHEBI:62207
# Return Status: 200
# CHEBI:28209
# Return Status: 200
# PUBCHEM:119226
# Return Status: 200
# PUBCHEM:273429
# Return Status: 200

# %%
results = []
for chemical in genes:
    if 'answers' in genes[chemical]:
        frame = parse_answer(genes[chemical])
        frame['Chemical'] = chemical
        results.append(frame)
all_results = pd.concat(results)
all_results
# Out:
#       result_id result_name                     source  \
# 0     HGNC:2596      CYP1A2  hmdb.enzyme_to_metabolite
# 1     HGNC:8781       PDE4B  hmdb.enzyme_to_metabolite
# 2    HGNC:12805         XDH  hmdb.enzyme_to_metabolite
# 3     HGNC:2631      CYP2E1  hmdb.enzyme_to_metabolite
# 4      HGNC:262      ADORA1  hmdb.enzyme_to_metabolite
# 5      HGNC:263     ADORA2A  hmdb.enzyme_to_metabolite
# 0     HGNC:7646        NAT2   kegg.chemical_get_enzyme
# 1     HGNC:2596      CYP1A2   kegg.chemical_get_enzyme
# 2     HGNC:2610      CYP2A6  hmdb.enzyme_to_metabolite
# 3    HGNC:12805         XDH  hmdb.enzyme_to_metabolite
# 4     HGNC:2622      CYP2C8  hmdb.enzyme_to_metabolite
# 5     HGNC:2638      CYP3A5  hmdb.enzyme_to_metabolite
# 6     HGNC:2615      CYP2B6  hmdb.enzyme_to_metabolite
# 7     HGNC:2621     CYP2C19  hmdb.enzyme_to_metabolite
# 8     HGNC:2623      CYP2C9  hmdb.enzyme_to_metabolite
# 9     HGNC:2631      CYP2E1  hmdb.enzyme_to_metabolite
# 10    HGNC:2625      CYP2D6  hmdb.enzyme_to_metabolite
# 11    HGNC:2637      CYP3A4  hmdb.enzyme_to_metabolite
# 12    HGNC:2595      CYP1A1  hmdb.enzyme_to_metabolite
# 13   HGNC:20244      CYP4X1  hmdb.enzyme_to_metabolite
# 14    HGNC:2632      CYP2F1  hmdb.enzyme_to_metabolite
# 15   HGNC:17450     CYP3A43  hmdb.enzyme_to_metabolite
# 16    HGNC:2608     CYP2A13  hmdb.enzyme_to_metabolite
# 17   HGNC:20583      CYP4Z1  hmdb.enzyme_to_metabolite
# 18    HGNC:2611      CYP2A7  hmdb.enzyme_to_metabolite
# 19    HGNC:2634      CYP2J2  hmdb.enzyme_to_metabolite
# 20    HGNC:7645        NAT1  hmdb.enzyme_to_metabolite
# 21    HGNC:2640      CYP3A7  hmdb.enzyme_to_metabolite
# 22    HGNC:2594     CYP19A1  hmdb.enzyme_to_metabolite
# 23    HGNC:2644      CYP4B1  hmdb.enzyme_to_metabolite
# ..          ...         ...                        ...
# 119   HGNC:3570       ACSL3  ctd.gene_to_drug_extended
# 120   HGNC:6535        LDHA  ctd.gene_to_drug_extended
# 121   HGNC:1540    SERPINA6  ctd.gene_to_drug_extended
# 122  HGNC:28106      TMEM97  ctd.gene_to_drug_extended
# 123  HGNC:10436     RPS6KB1  ctd.gene_to_drug_extended
# 124   HGNC:9722    ALDH18A1  ctd.gene_to_drug_extended
# 125  HGNC:20726       SCFD1  ctd.gene_to_drug_extended
# 126   HGNC:5969       IL12A  ctd.gene_to_drug_extended
# 127  HGNC:11280      SQSTM1  ctd.gene_to_drug_extended
# 128   HGNC:5344       ICAM1  ctd.gene_to_drug_extended
# 129   HGNC:9449        PRNP  ctd.gene_to_drug_extended
# 130   HGNC:6025       CXCL8  ctd.gene_to_drug_extended
# 131   HGNC:9884         RB1  ctd.gene_to_drug_extended
# 0     HGNC:2596      CYP1A2  hmdb.enzyme_to_metabolite
# 1    HGNC:12805         XDH  hmdb.enzyme_to_metabolite
# 0      HGNC:386      AKR1C3  hmdb.enzyme_to_metabolite
# 0     HGNC:4556        GPX4  hmdb.enzyme_to_metabolite
# 1     HGNC:6877       MAPK3  ctd.gene_to_drug_extended
# 2     HGNC:7940        NPPB  ctd.gene_to_drug_extended
# 3     HGNC:7794       NFKB1  ctd.gene_to_drug_extended
# 4     HGNC:4558        GPX6  hmdb.enzyme_to_metabolite
# 5     HGNC:3402       EPHX2  ctd.gene_to_drug_extended
# 6     HGNC:4559        GPX7  hmdb.enzyme_to_metabolite
# 7     HGNC:4555        GPX3  hmdb.enzyme_to_metabolite
# 8     HGNC:4557        GPX5  hmdb.enzyme_to_metabolite
# 9     HGNC:4554        GPX2  hmdb.enzyme_to_metabolite
# 10    HGNC:4553        GPX1  hmdb.enzyme_to_metabolite
# 11    HGNC:6871       MAPK1  ctd.gene_to_drug_extended
# 12    HGNC:6893        MAPT       pharos.gene_get_drug
# 13    HGNC:9955        RELA  ctd.gene_to_drug_extended
#
#                                        type     Chemical
# 0                            interacts_with  CHEBI:28946
# 1                            interacts_with  CHEBI:28946
# 2                            interacts_with  CHEBI:28946
# 3                            interacts_with  CHEBI:28946
# 4                            interacts_with  CHEBI:28946
# 5                            interacts_with  CHEBI:28946
# 0    negatively_regulates__entity_to_entity  CHEBI:25858
# 1    negatively_regulates__entity_to_entity  CHEBI:25858
# 2                            interacts_with  CHEBI:25858
# 3                            interacts_with  CHEBI:25858
# 4                            interacts_with  CHEBI:25858
# 5                            interacts_with  CHEBI:25858
# 6                            interacts_with  CHEBI:25858
# 7                            interacts_with  CHEBI:25858
# 8                            interacts_with  CHEBI:25858
# 9                            interacts_with  CHEBI:25858
# 10                           interacts_with  CHEBI:25858
# 11                           interacts_with  CHEBI:25858
# 12                           interacts_with  CHEBI:25858
# 13                           interacts_with  CHEBI:25858
# 14                           interacts_with  CHEBI:25858
# 15                           interacts_with  CHEBI:25858
# 16                           interacts_with  CHEBI:25858
# 17                           interacts_with  CHEBI:25858
# 18                           interacts_with  CHEBI:25858
# 19                           interacts_with  CHEBI:25858
# 20                           interacts_with  CHEBI:25858
# 21                           interacts_with  CHEBI:25858
# 22                           interacts_with  CHEBI:25858
# 23                           interacts_with  CHEBI:25858
# ..                                      ...          ...
# 119                 increases_expression_of  CHEBI:27732
# 120                 decreases_expression_of  CHEBI:27732
# 121                 decreases_expression_of  CHEBI:27732
# 122                 decreases_expression_of  CHEBI:27732
# 123                 decreases_expression_of  CHEBI:27732
# 124                 decreases_expression_of  CHEBI:27732
# 125                 decreases_expression_of  CHEBI:27732
# 126                 decreases_expression_of  CHEBI:27732
# 127                 decreases_expression_of  CHEBI:27732
# 128                 decreases_expression_of  CHEBI:27732
# 129                 decreases_expression_of  CHEBI:27732
# 130                 increases_expression_of  CHEBI:27732
# 131     decreases_molecular_modification_of  CHEBI:27732
# 0                            interacts_with  CHEBI:68444
# 1                            interacts_with  CHEBI:68444
# 0                            interacts_with  CHEBI:27595
# 0                            interacts_with  CHEBI:28209
# 1       increases_molecular_modification_of  CHEBI:28209
# 2                   increases_expression_of  CHEBI:28209
# 3                     increases_activity_of  CHEBI:28209
# 4                            interacts_with  CHEBI:28209
# 5                     increases_activity_of  CHEBI:28209
# 6                            interacts_with  CHEBI:28209
# 7                            interacts_with  CHEBI:28209
# 8                            interacts_with  CHEBI:28209
# 9                            interacts_with  CHEBI:28209
# 10                           interacts_with  CHEBI:28209
# 11      increases_molecular_modification_of  CHEBI:28209
# 12                  directly_interacts_with  CHEBI:28209
# 13                    increases_activity_of  CHEBI:28209
#
# [193 rows x 5 columns]

# %% [markdown]
# Are there any predicates indicating a production?

# %%
all_results['type'].value_counts()
# Out:
# interacts_with                            69
# decreases_expression_of                   48
# increases_expression_of                   27
# negatively_regulates__entity_to_entity    11
# directly_interacts_with                   10
# affects_expression_of                      9
# increases_activity_of                      6
# increases_molecular_modification_of        4
# decreases_activity_of                      3
# positively_regulates__entity_to_entity     2
# affects_response_to                        2
# affects_activity_of                        1
# decreases_molecular_modification_of        1
# Name: type, dtype: int64

# %%
all_results[all_results['type']=='positively_regulates__entity_to_entity']
# Out:
#           result_id     result_name                    source  \
# 30   EC:1.14.13.179  EC:1.14.13.179  kegg.chemical_get_enzyme
# 115    EC:2.1.1.160    EC:2.1.1.160  kegg.chemical_get_enzyme
#
#                                        type     Chemical
# 30   positively_regulates__entity_to_entity  CHEBI:25858
# 115  positively_regulates__entity_to_entity  CHEBI:27732

# %% [markdown]
# We're finding enzymes involved in creating the endogenous chemicals. But how come our genes are in EC format, rather than being translated to our normal HGNC?   It's because these are non-human enzymes and at the moment we're not synonymizing non-human genes. In fact, for the most part, we don't accept non-human genes, but we're not checking for that in the KEGG client.
#
# The upshot is that we're not finding a good answer for this question for asthma.

# %% [markdown]
# ### Cystic Fibrosis

# %%
cf = 'MONDO:0009061'
result = expand(type1,cf,type2)
result_frame = parse_answer(result)
endogenous = result_frame[ result_frame['type'] == 'related_to' ]
endogenous
# Out:
# Return Status: 200
#                result_id                   result_name  \
# 4            CHEBI:31835                 methylparaben
# 5            CHEBI:16325              Lithocholic Acid
# 6            CHEBI:30805               Dodecanoic acid
# 7            CHEBI:30813                   Capric acid
# 8            CHEBI:17201                Glycyl-glycine
# 10           CHEBI:28621               Triethanolamine
# 12           CHEBI:16755         Chenodeoxycholic Acid
# 13           CHEBI:28834              Deoxycholic Acid
# 14            CHEBI:6650                    Malic acid
# 15           CHEBI:16359                   Cholic acid
# 27           CHEBI:16919                      Creatine
# 32           CHEBI:16737                    Creatinine
# 36           CHEBI:17196                  L-Asparagine
# 37           CHEBI:17712                      Xanthine
# 38            CHEBI:8207                   Pilocarpine
# 39           CHEBI:28911                     Cobalamin
# 40           CHEBI:32063                 propylparaben
# 41           CHEBI:17243  Monoethylhexyl phthalic acid
# 42           CHEBI:49059                 Threonic acid
# 65       PUBCHEM:3952518         Prolyl-Hydroxyproline
# 67        PUBCHEM:417360              Glycyl-Histidine
# 69      PUBCHEM:23617285              Glycocholic acid
# 72  CHEMBL:CHEMBL2004044                 Glycyl-Serine
#
#                         source        type
# 4   hmdb.metabolite_to_disease  related_to
# 5   hmdb.metabolite_to_disease  related_to
# 6   hmdb.metabolite_to_disease  related_to
# 7   hmdb.metabolite_to_disease  related_to
# 8   hmdb.metabolite_to_disease  related_to
# 10  hmdb.metabolite_to_disease  related_to
# 12  hmdb.metabolite_to_disease  related_to
# 13  hmdb.metabolite_to_disease  related_to
# 14  hmdb.metabolite_to_disease  related_to
# 15  hmdb.metabolite_to_disease  related_to
# 27  hmdb.metabolite_to_disease  related_to
# 32  hmdb.metabolite_to_disease  related_to
# 36  hmdb.metabolite_to_disease  related_to
# 37  hmdb.metabolite_to_disease  related_to
# 38  hmdb.metabolite_to_disease  related_to
# 39  hmdb.metabolite_to_disease  related_to
# 40  hmdb.metabolite_to_disease  related_to
# 41  hmdb.metabolite_to_disease  related_to
# 42  hmdb.metabolite_to_disease  related_to
# 65  hmdb.disease_to_metabolite  related_to
# 67  hmdb.disease_to_metabolite  related_to
# 69  hmdb.disease_to_metabolite  related_to
# 72  hmdb.disease_to_metabolite  related_to

# %%
identifiers = list(endogenous['result_id'])
genes = {}
for ident in identifiers:
    print(ident)
    genes[ident] = expand('chemical_substance',ident,'gene')
# Out:
# CHEBI:31835
# Return Status: 200
# CHEBI:16325
# Return Status: 200
# CHEBI:30805
# Return Status: 200
# CHEBI:30813
# Return Status: 200
# CHEBI:17201
# Return Status: 200
# CHEBI:28621
# Return Status: 200
# CHEBI:16755
# Return Status: 200
# CHEBI:28834
# Return Status: 200
# CHEBI:6650
# Return Status: 200
# CHEBI:16359
# Return Status: 200
# CHEBI:16919
# Return Status: 200
# CHEBI:16737
# Return Status: 200
# CHEBI:17196
# Return Status: 200
# CHEBI:17712
# Return Status: 200
# CHEBI:8207
# Return Status: 200
# CHEBI:28911
# Return Status: 200
# CHEBI:32063
# Return Status: 200
# CHEBI:17243
# Return Status: 200
# CHEBI:49059
# Return Status: 200
# PUBCHEM:3952518
# Return Status: 200
# PUBCHEM:417360
# Return Status: 200
# PUBCHEM:23617285
# Return Status: 200
# CHEMBL:CHEMBL2004044
# Return Status: 200

# %%
results = []
for chemical in genes:
    if 'answers' in genes[chemical]:
        frame = parse_answer(genes[chemical])
        frame['Chemical'] = chemical
        results.append(frame)
all_results = pd.concat(results)
all_results['type'].value_counts()
# Out:
# increases_expression_of                   166
# interacts_with                            128
# decreases_expression_of                    82
# directly_interacts_with                    23
# affects_response_to                        21
# increases_activity_of                      19
# affects_expression_of                       9
# increases_molecular_modification_of         8
# decreases_activity_of                       8
# negatively_regulates__entity_to_entity      4
# positively_regulates__entity_to_entity      3
# affects_molecular_modification_of           2
# Name: type, dtype: int64

# %%
all_results[all_results['type']=='positively_regulates__entity_to_entity']
# Out:
#       result_id  result_name                    source  \
# 52  EC:2.8.3.25  EC:2.8.3.25  kegg.chemical_get_enzyme
# 49  EC:3.5.1.24  EC:3.5.1.24  kegg.chemical_get_enzyme
# 54  EC:2.8.3.25  EC:2.8.3.25  kegg.chemical_get_enzyme
#
#                                       type     Chemical
# 52  positively_regulates__entity_to_entity  CHEBI:16325
# 49  positively_regulates__entity_to_entity  CHEBI:28834
# 54  positively_regulates__entity_to_entity  CHEBI:28834
