# %% [markdown]
# Q1.5
# This query aims to expand the FA-ensemblage gene set based on upstream TF binding site motif patterns.

# %% [markdown]
# Data
#  - FA gene sets  'https://github.com/NCATS-Tangerine/cq-notebooks/tree/master/FA_gene_sets'
#  - motif simalarity datastore 'jaspar.nt'

# %%
import csv
import yaml
import requests
import json
import re

# %% [markdown]
# Untill the hackathon blazegraph instance is available
# We are running a local instance [described here](http://localhost:8888/notebooks/LocalBlazeGraph.ipynb)

# %%
bg_host = 'http://localhost:9999'
bg = bg_host + '/blazegraph/sparql?format=json&query='

# %% [markdown]
# which offers:
#
#     rdf:Description rdf:nodeID="service"
#         rdf:type
#             rdf:resource="http://www.w3.org/ns/sparql-service-description#Service"
#         endpoint
#             rdf:resource="http://localhost:9999/blazegraph/sparql"
#         endpoint
#             rdf:resource="http://localhost:9999/bigdata/LBS/sparql"
#
# Trying the blazegraph/sparql endpoint yields

# %%
x = requests.get(bg + 'SELECT ?g1 WHERE{?g1 <http://purl.obolibrary.org/obo/SO_adjacent_to> ?o} LIMIT 1')
print(x.text)
# Out:
# {
#   "head" : {
#     "vars" : [ "g1" ]
#   },
#   "results" : {
#     "bindings" : [ {
#       "g1" : {
#         "type" : "uri",
#         "value" : "http://www.ncbi.nlm.nih.gov/gene/6309"
#       }
#     } ]
#   }
# }

# %% [markdown]
# Blazegraph is working localy,
# there is a process in place to refresh it when I change the RDF
# Using the RDF stored in Blazegraph to address the FD TF-binding motif question
# in this notebook follows.

# %%
# Want to use existing translation tables when constructing SPARQL queries
yamlurl='https://raw.githubusercontent.com/TomConlin/Jaspar_FA/master/translation_tables/curie_map.yaml'
rsponse = requests.get(yamlurl)
PREFIX = yaml.load(rsponse.text)
# print(PREFIX)

yamlurl='https://raw.githubusercontent.com/TomConlin/Jaspar_FA/master/translation_tables/translation_table.yaml'
rsponse = requests.get(yamlurl)
TT = yaml.load(rsponse.text)
# print(TT)

# redecorate the curie base IRI map 
# to look like a sparql prefix namespace map  
# except the bnode: skolemIRI which is given a java 
#     "org.openrdf.query.MalformedQueryException:
# for no good reason

prefixns = ""
for p in PREFIX: 
    if len(p) > 1:
       prefixns += 'PREFIX ' + p + ': <' + PREFIX[p] + '>\n'

print(prefixns)
# Out:
# PREFIX RO: <http://purl.obolibrary.org/obo/RO_>
# PREFIX SO: <http://purl.obolibrary.org/obo/SO_>
# PREFIX JASPAR: <http://fantom.gsc.riken.jp/5/sstar/JASPAR_motif:>
# PREFIX OIO: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX NCBIGene: <http://www.ncbi.nlm.nih.gov/gene/>
# PREFIX GENO: <http://purl.obolibrary.org/obo/GENO_>
# PREFIX SWO: <http://www.ebi.ac.uk/efo/swo/SWO_>

# %% [markdown]
# The Fanconi Anemia genes come as symbols/aliases in three sets [here](https://docs.google.com/spreadsheets/d/1yX-5sfrC3vrahf4_k7-5rl4Oqzm853ollIMmUo1PTc0)
# I converted them to NCBI gene identifiers and current symbols [here](https://github.com/NCATS-Tangerine/cq-notebooks/tree/master/FA_gene_sets)

# %%
fagene=[]

fa1 = '../FA_gene_sets/FA_1_core_complex.txt'
core_complex = {}
with open(fa1, 'r') as tabfile:
    filereader = csv.reader(tabfile, delimiter='\t')
    for row in filereader:   
        (fa_gene, fa_symbol) = row
        fagene.append(fa_gene)
        core_complex[fa_gene]=fa_symbol
        
fa2 = '../FA_gene_sets/FA_2_effector_proteins.txt'
effector_proteins = {}
with open(fa2, 'r') as tabfile:
    filereader = csv.reader(tabfile, delimiter='\t')
    for row in filereader:   
        (fa_gene, fa_symbol) = row
        fagene.append(fa_gene)
        effector_proteins[fa_gene]=fa_symbol
        
fa3 = '../FA_gene_sets/FA_3_associated_proteins.txt'
associated_proteins = {} 
with open(fa3, 'r') as tabfile:
    filereader = csv.reader(tabfile, delimiter='\t')
    for row in filereader:   
        (fa_gene, fa_symbol) = row
        fagene.append(fa_gene)
        associated_proteins[fa_gene]=fa_symbol

# %% [markdown]
# We can get all the triples patterns available in 'jaspar.nt'
# from this [GraphViz dot file](https://github.com/TomConlin/Jaspar_FA/blob/master/jaspar_target_model.gv) since we used it to guide
# generating the RDF data in the first place.
#
# ![](https://github.com/TomConlin/Jaspar_FA/blob/master/jaspar_target_model.png?raw=true)

# %% [markdown]
# Composing the query by atomizing the GraphViz elements
# and selectivly translating with the same tables
# the data was generates with means
# the SPARQL query remains free of semanticly obsolete clauses.
#
# I did this manually, but in general, the rules were roughly:
#
# -    remove angle brackets
# -    add trailing dot
# -    replace BNODE: with __?__
# -    if the element (predicate) is a curie then wrap it in a TT lookup
# -    if the object is a LITERAL wrap it in quotes
# -    give the items of intrest specific __?names__
# -    formating to suit sensibilities

# %% [markdown]
# In particular we want:
#     candidate genes which share motif similarity with FA genes
#
#     <NCBIGene:fagene><SO:adjacent_to><BNODE:gene1_upstream_region>
#     <BNODE:gene1_upstream_region><RO:member of><BNODE:pairwise_similarity>
#     <BNODE:gene2_upstream_region><RO:member of><BNODE:pairwise_similarity>
#     <NCBIGene:xyz><SO:adjacent_to><BNODE:gene2_upstream_region>
#
#     when <NCBIGene:xyz> is not <NCBIGene:fagene>
#
# we may also be interested in limiting by region extent size
# or Jaccard similarity score
#
#     <BNODE:pairwise_similarity><SWO:Similarity score><0.73>
#     <BNODE:gene1_upstream_region><GENO:has_extent><1k>

# %% [markdown]
# Much of the effort to this point has been developing and maintaining a context
# in which we are able to __write a readable query__.
#
# Here, given a (fa) gene, we are looking for other genes
# with optimal matches (similarity=1) within their 1k start regions.

# %%
selectstr = ' '.join([
    'SELECT ?fagene ?candidate\n',
    'WHERE{\n',
        '?fagene', 'SO:adjacent_to', '?gene1_upstream_region .\n', 
        '?gene1_upstream_region',  TT['RO:member of'], '?pairwise_similarity .\n',
        '?gene2_upstream_region',  TT['RO:member of'], '?pairwise_similarity .\n',
        'FILTER(?gene1_upstream_region != ?gene2_upstream_region) \n', 
        '?candidate', 'SO:adjacent_to', '?gene2_upstream_region .\n',
        '?pairwise_similarity', TT['SWO:Similarity score'], "'1' .\n", 
        '?gene1_upstream_region', TT['GENO:has_extent'], "'1k' .\n",
    'FILTER(?fagene != ?candidate)\n}'
    ]) 

# note the abscence of opaque identifiers the query engine actually uses

query = prefixns + "\n" + selectstr
print(query)
# Out:
# PREFIX RO: <http://purl.obolibrary.org/obo/RO_>
# PREFIX SO: <http://purl.obolibrary.org/obo/SO_>
# PREFIX JASPAR: <http://fantom.gsc.riken.jp/5/sstar/JASPAR_motif:>
# PREFIX OIO: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX NCBIGene: <http://www.ncbi.nlm.nih.gov/gene/>
# PREFIX GENO: <http://purl.obolibrary.org/obo/GENO_>
# PREFIX SWO: <http://www.ebi.ac.uk/efo/swo/SWO_>
#
# SELECT ?fagene ?candidate
#  WHERE{
#  ?fagene SO:adjacent_to ?gene1_upstream_region .
#  ?gene1_upstream_region RO:0002350 ?pairwise_similarity .
#  ?gene2_upstream_region RO:0002350 ?pairwise_similarity .
#  FILTER(?gene1_upstream_region != ?gene2_upstream_region)
#  ?candidate SO:adjacent_to ?gene2_upstream_region .
#  ?pairwise_similarity SWO:0000425 '1' .
#  ?gene1_upstream_region GENO:0000678 '1k' .
#  FILTER(?fagene != ?candidate)
# }

# %%
# apply our query to each gene in the FA Core complex
candidate_set = {}
for fagene in core_complex:
    payload = {
        'format' : 'json', 
        # '$fagene':  fagene, 
        # BG is not accepting the curie. Wants IRI or LITERAL
        '$fagene': '<' + re.sub('NCBIGene:',PREFIX['NCBIGene'],fagene) + '>',
        'query': query
    }
    response = requests.post(bg_host + '/blazegraph/sparql', data=payload)
 
    resp = json.loads(response.text)
    if resp['results']['bindings'] != []:
        print(core_complex[fagene], '\t', 
              re.sub('NCBIGene:', PREFIX['NCBIGene'],fagene))
        candidate_set[core_complex[fagene]]=[]
        for hit in resp['results']['bindings']:
            candidate_set[core_complex[fagene]].append(hit['candidate']['value'])
            print('\t', hit['candidate']['value'])
# Out:
# UBE2T 	 http://www.ncbi.nlm.nih.gov/gene/29089
# 	 http://www.ncbi.nlm.nih.gov/gene/3608
# 	 http://www.ncbi.nlm.nih.gov/gene/171392
# 	 http://www.ncbi.nlm.nih.gov/gene/340252
# 	 http://www.ncbi.nlm.nih.gov/gene/8125
# 	 http://www.ncbi.nlm.nih.gov/gene/54958

# %% [markdown]
# UBE2T is the only gene in the Fancomi Anemia core complex
# with optimal associations with other genes
# Briefly those associated genes are:
#
# - ILF2 http://www.ncbi.nlm.nih.gov/gene/3608
#     a transcription factor required for T-cell expression of the interleukin 2 gene
#
# - ZNF675 https://www.ncbi.nlm.nih.gov/gene/171392
#     the novel zinc finger protein TIZ may play a role during osteoclast differentiation by modulating TRAF6 signaling activity.
#
# - ZNF680 http://www.ncbi.nlm.nih.gov/gene/340252
#     obsevered expressed in thyroid but fairly uncharaterizied
#
# - ANP32A http://www.ncbi.nlm.nih.gov/gene/8125
#     expressed lymph nodes & bone marrow
#     The tumor suppressor acidic nuclear phosphoprotein 32 family, member A
#
# - TMEM160 http://www.ncbi.nlm.nih.gov/gene/54958
#     Not much to see here
#
# ----
# Where to go next
#
# - We can look for ideal similarity in larger upstream regions but counter intiutivly larger regions average fewer associations because the number of distinct motifs between the larger regions grows faster than the number of motifs the regions will have in common.  (and I dropped any that dipped below the negotiable threshold of one part in five)
# - We can look for less ideal similarity in the same 1k region
# - We can look for less ideal similarity in larger regions
#
# For now I am going with looking for less similarity within the same 1k start regions

# %%
# small changes to expose the similarity score
selectstr = ' '.join([
    'SELECT ?fagene ?candidate ?score\n',
    'WHERE{\n',
        '?fagene', 'SO:adjacent_to', '?gene1_upstream_region .\n', 
        '?gene1_upstream_region',  TT['RO:member of'], '?pairwise_similarity .\n',
        '?gene2_upstream_region',  TT['RO:member of'], '?pairwise_similarity .\n',
        'FILTER(?gene1_upstream_region != ?gene2_upstream_region) \n', 
        '?candidate', 'SO:adjacent_to', '?gene2_upstream_region .\n',
        '?pairwise_similarity', TT['SWO:Similarity score'], '?score .\n', 
        '?gene1_upstream_region', TT['GENO:has_extent'], "'1k' .\n",
    'FILTER(?fagene != ?candidate)\n',
    #'FILTER(xsd:float(?score) >= 0.5)\n',
    '}\n',
    'ORDER by DESC(?score)\n'
    ])
query = prefixns + "\n" + selectstr
print(selectstr)
# Out:
# SELECT ?fagene ?candidate ?score
#  WHERE{
#  ?fagene SO:adjacent_to ?gene1_upstream_region .
#  ?gene1_upstream_region RO:0002350 ?pairwise_similarity .
#  ?gene2_upstream_region RO:0002350 ?pairwise_similarity .
#  FILTER(?gene1_upstream_region != ?gene2_upstream_region)
#  ?candidate SO:adjacent_to ?gene2_upstream_region .
#  ?pairwise_similarity SWO:0000425 ?score .
#  ?gene1_upstream_region GENO:0000678 '1k' .
#  FILTER(?fagene != ?candidate)
#  }
#  ORDER by DESC(?score)

# %%
# apply our query to each gene in the FA Core complex
# lowering the association threshold to 1 part in 5 similar 
# keeping the score for consideration in later processing
candidate_core_complex = {}
for fagene in core_complex:
    payload = {
        'format' : 'json', 
        '$fagene': '<' + re.sub('NCBIGene:',PREFIX['NCBIGene'],fagene) + '>',
        'query'  : query
    }
    response = requests.post(bg_host + '/blazegraph/sparql', data=payload)
    # print(response)
    resp = json.loads(response.text)
    # print(response.text)
    
    if resp['results']['bindings'] != []:
        # print(core_complex[fagene], '\t', 
              # re.sub('NCBIGene:', PREFIX['NCBIGene'], fagene))
        candidate_core_complex[core_complex[fagene]]={}
        for hit in resp['results']['bindings']:
            candidate_core_complex[core_complex[fagene]][
                hit['candidate']['value']] = hit['score']['value']
            # print('\t', hit['candidate']['value'], hit['score']['value'])

# %%
# print(candidate_core_complex)

# %%
# the next FA geneset is effector_proteins
candidate_effector_proteins = {}
for fagene in effector_proteins:
    payload = {
        'format' : 'json', 
        '$fagene': '<' + re.sub('NCBIGene:',PREFIX['NCBIGene'],fagene) + '>',
        'query'  : query
    }
    response = requests.post(bg_host + '/blazegraph/sparql', data=payload)
    # print(response)
    resp = json.loads(response.text)
    # print(response.text)
    
    if resp['results']['bindings'] != []:
        # print(effector_proteins[fagene], '\t', 
              # re.sub('NCBIGene:', PREFIX['NCBIGene'],fagene))
        candidate_effector_proteins[effector_proteins[fagene]]={}
        for hit in resp['results']['bindings']:
            candidate_effector_proteins[effector_proteins[fagene]][
                    hit['candidate']['value']] = hit['score']['value']
            # print('\t', hit['candidate']['value'], hit['score']['value'])

# %%
# and finally associated_proteins
candidate_associated_proteins = {}
for fagene in associated_proteins:
    payload = {
        'format' : 'json', 
        '$fagene': '<' + re.sub('NCBIGene:',PREFIX['NCBIGene'],fagene) + '>',
        'query'  : query
    }
    response = requests.post(bg_host + '/blazegraph/sparql', data=payload)
    # print(response)
    resp = json.loads(response.text)
    # print(response.text)
    
    if resp['results']['bindings'] != []:
        # print(associated_proteins[fagene], '\t', 
              # re.sub('NCBIGene:', PREFIX['NCBIGene'],fagene))
        candidate_associated_proteins[associated_proteins[fagene]]={}
        for hit in resp['results']['bindings']:
            candidate_associated_proteins[
                associated_proteins[fagene]][
                   hit['candidate']['value']] = hit['score']['value']
            # print('\t', hit['candidate']['value'], hit['score']['value'])

# %%
# Researchers would like to see gene symbols. 
# Here we are calling HGNC for only the freshest in gene fashion wear.
# http://rest.genenames.org/search/entrez_id/673
def entrez_symbol(ncbigene_uri):
    api_uri = re.sub(
        'http://www.ncbi.nlm.nih.gov/gene/',
        'http://rest.genenames.org/search/entrez_id/', ncbigene_uri)
    response = requests.get(api_uri, headers={'Accept': 'application/json'})
    if str(response) == '<Response [200]>':
        hgnc = json.loads(response.text)
        if hgnc['response']['numFound'] > 0:
            symbol = hgnc['response']['docs'][0]['symbol']
        else:
            symbol = ""  # none found    
    else: # it will be ugly so someone will notice
        symbol = 'ERROR ' + api_uri + ' ' + str(response)
    return symbol

# %% [markdown]
#     # quick tests
#     entrez_symbol('http://www.ncbi.nlm.nih.gov/gene/672')

# %% [markdown]
#     entrez_symbol('http://www.ncbi.nlm.nih.gov/gene/-1')

# %%
# what have we got in the candidate sets?

# homoiconic coders, avert your eyes
fa_sets={
    'candidate_core_complex' : candidate_core_complex,
    'candidate_effector_proteins' : candidate_effector_proteins,
    'candidate_associated_proteins' : candidate_associated_proteins
}
# keep a stash of gene symbols
ncbigene_symbol = {}

for fas in fa_sets:
    print(fas +' set has', '(' + str(len(fa_sets[fas])) +') genes with hits')
    for fa in fa_sets[fas]:
        print('  ', fa, '(' + str(len(fa_sets[fas][fa])) +') associations')
        hits = []
        for c in fa_sets[fas][fa]:
            # try to be nice to our friends at HGNC
            if c not in ncbigene_symbol:
                ncbigene_symbol[c] = entrez_symbol(c)
            symbol = ncbigene_symbol[c]
            #print(symbol,'\t', c, fa_sets[fas][fa][c])
            hits.append([fa_sets[fas][fa][c], symbol, c])
        # reorder the set  
        hits.sort()
        # output the set
# Out:
# candidate_effector_proteins set has (4) genes with hits
#    SLX4 (67) associations
# EIF3E 	 http://www.ncbi.nlm.nih.gov/gene/3646 0.25
# AREL1 	 http://www.ncbi.nlm.nih.gov/gene/9870 0.25
# WDR46 	 http://www.ncbi.nlm.nih.gov/gene/9277 0.2
# ZNF329 	 http://www.ncbi.nlm.nih.gov/gene/79673 0.2
# MEA1 	 http://www.ncbi.nlm.nih.gov/gene/4201 0.2
# N6AMT1 	 http://www.ncbi.nlm.nih.gov/gene/29104 0.25
# MIS18A 	 http://www.ncbi.nlm.nih.gov/gene/54069 0.2
# HEATR5B 	 http://www.ncbi.nlm.nih.gov/gene/54497 0.2
# IKZF2 	 http://www.ncbi.nlm.nih.gov/gene/22807 0.25
# PTGES3L 	 http://www.ncbi.nlm.nih.gov/gene/100885848 0.25
# SUGP2 	 http://www.ncbi.nlm.nih.gov/gene/10147 0.2
# PSPC1 	 http://www.ncbi.nlm.nih.gov/gene/55269 0.25
# TMEM161B 	 http://www.ncbi.nlm.nih.gov/gene/153396 0.2
# RAB14 	 http://www.ncbi.nlm.nih.gov/gene/51552 0.25
# CCDC127 	 http://www.ncbi.nlm.nih.gov/gene/133957 0.25
# RBFOX2 	 http://www.ncbi.nlm.nih.gov/gene/23543 0.25
# SOS2 	 http://www.ncbi.nlm.nih.gov/gene/6655 0.2
# SMG6 	 http://www.ncbi.nlm.nih.gov/gene/23293 0.25
# NPRL3 	 http://www.ncbi.nlm.nih.gov/gene/8131 0.25
# MEIS2 	 http://www.ncbi.nlm.nih.gov/gene/4212 0.2
# DHRS13 	 http://www.ncbi.nlm.nih.gov/gene/147015 0.2
# TOLLIP 	 http://www.ncbi.nlm.nih.gov/gene/54472 0.2
# SAYSD1 	 http://www.ncbi.nlm.nih.gov/gene/55776 0.2
# EEF1D 	 http://www.ncbi.nlm.nih.gov/gene/1936 0.2
# UNKL 	 http://www.ncbi.nlm.nih.gov/gene/64718 0.2
# VPS13C 	 http://www.ncbi.nlm.nih.gov/gene/54832 0.2
# FBXW5 	 http://www.ncbi.nlm.nih.gov/gene/54461 0.2
# RAB35 	 http://www.ncbi.nlm.nih.gov/gene/11021 0.25
# FAM227A 	 http://www.ncbi.nlm.nih.gov/gene/646851 0.25
# EIF3G 	 http://www.ncbi.nlm.nih.gov/gene/8666 0.25
# STRADA 	 http://www.ncbi.nlm.nih.gov/gene/92335 0.2
# STK32C 	 http://www.ncbi.nlm.nih.gov/gene/282974 0.2
# RNF19A 	 http://www.ncbi.nlm.nih.gov/gene/25897 0.25
# DENND6A 	 http://www.ncbi.nlm.nih.gov/gene/201627 0.2
# POU4F1 	 http://www.ncbi.nlm.nih.gov/gene/5457 0.25
# MAD1L1 	 http://www.ncbi.nlm.nih.gov/gene/8379 0.25
# NARFL 	 http://www.ncbi.nlm.nih.gov/gene/64428 0.2
# FAM58A 	 http://www.ncbi.nlm.nih.gov/gene/92002 0.2
# ZBTB17 	 http://www.ncbi.nlm.nih.gov/gene/7709 0.25
# NOB1 	 http://www.ncbi.nlm.nih.gov/gene/28987 0.25
# MRPS33 	 http://www.ncbi.nlm.nih.gov/gene/51650 0.2
# MBD1 	 http://www.ncbi.nlm.nih.gov/gene/4152 0.25
# CDCA3 	 http://www.ncbi.nlm.nih.gov/gene/83461 0.2
# BNIP3 	 http://www.ncbi.nlm.nih.gov/gene/664 0.2
# TMEM203 	 http://www.ncbi.nlm.nih.gov/gene/94107 0.2
# MPHOSPH6 	 http://www.ncbi.nlm.nih.gov/gene/10200 0.2
# TXNDC9 	 http://www.ncbi.nlm.nih.gov/gene/10190 0.25
# UNC93B1 	 http://www.ncbi.nlm.nih.gov/gene/81622 0.25
# TMEM184B 	 http://www.ncbi.nlm.nih.gov/gene/25829 0.25
# ASCC1 	 http://www.ncbi.nlm.nih.gov/gene/51008 0.2
# ZNF287 	 http://www.ncbi.nlm.nih.gov/gene/57336 0.25
# ARHGEF39 	 http://www.ncbi.nlm.nih.gov/gene/84904 0.25
# ZC3H8 	 http://www.ncbi.nlm.nih.gov/gene/84524 0.25
# C10orf111 	 http://www.ncbi.nlm.nih.gov/gene/221060 0.2
# CCDC93 	 http://www.ncbi.nlm.nih.gov/gene/54520 0.2
# PRKAR2A 	 http://www.ncbi.nlm.nih.gov/gene/5576 0.25
# PRELID3B 	 http://www.ncbi.nlm.nih.gov/gene/51012 0.2
# EID2B 	 http://www.ncbi.nlm.nih.gov/gene/126272 0.25
# CCDC96 	 http://www.ncbi.nlm.nih.gov/gene/257236 0.2
# C10orf88 	 http://www.ncbi.nlm.nih.gov/gene/80007 0.25
# HIRIP3 	 http://www.ncbi.nlm.nih.gov/gene/8479 0.25
# SIRT6 	 http://www.ncbi.nlm.nih.gov/gene/51548 0.25
# SDHB 	 http://www.ncbi.nlm.nih.gov/gene/6390 0.2
# UBE2V1 	 http://www.ncbi.nlm.nih.gov/gene/7335 0.25
# PPM1F 	 http://www.ncbi.nlm.nih.gov/gene/9647 0.25
# TWF2 	 http://www.ncbi.nlm.nih.gov/gene/11344 0.2
# CXorf38 	 http://www.ncbi.nlm.nih.gov/gene/159013 0.2
#    PALB2 (21) associations
# C16orf46 	 http://www.ncbi.nlm.nih.gov/gene/123775 0.333333
# LRRC47 	 http://www.ncbi.nlm.nih.gov/gene/57470 0.25
# MCAT 	 http://www.ncbi.nlm.nih.gov/gene/27349 0.2
# RGL2 	 http://www.ncbi.nlm.nih.gov/gene/5863 0.2
# C2orf68 	 http://www.ncbi.nlm.nih.gov/gene/388969 0.25
# FAAP100 	 http://www.ncbi.nlm.nih.gov/gene/80233 0.25
# LYSMD1 	 http://www.ncbi.nlm.nih.gov/gene/388695 0.25
# OTUD7B 	 http://www.ncbi.nlm.nih.gov/gene/56957 0.2
# PGAP3 	 http://www.ncbi.nlm.nih.gov/gene/93210 0.333333
# WDR27 	 http://www.ncbi.nlm.nih.gov/gene/253769 0.2
# TMEM230 	 http://www.ncbi.nlm.nih.gov/gene/29058 0.2
# PPID 	 http://www.ncbi.nlm.nih.gov/gene/5481 0.25
# ZNF384 	 http://www.ncbi.nlm.nih.gov/gene/171017 0.2
# MUT 	 http://www.ncbi.nlm.nih.gov/gene/4594 0.25
# KIAA0825 	 http://www.ncbi.nlm.nih.gov/gene/285600 0.2
# NTHL1 	 http://www.ncbi.nlm.nih.gov/gene/4913 0.25
# EMC7 	 http://www.ncbi.nlm.nih.gov/gene/56851 0.2
# FBXW2 	 http://www.ncbi.nlm.nih.gov/gene/26190 0.25
# LRRC41 	 http://www.ncbi.nlm.nih.gov/gene/10489 0.2
# DPM3 	 http://www.ncbi.nlm.nih.gov/gene/54344 0.25
# FBXW9 	 http://www.ncbi.nlm.nih.gov/gene/84261 0.333333
#    XRCC2 (9) associations
# ZNF347 	 http://www.ncbi.nlm.nih.gov/gene/84671 0.25
# SMC1A 	 http://www.ncbi.nlm.nih.gov/gene/8243 0.25
# PRKN 	 http://www.ncbi.nlm.nih.gov/gene/5071 0.2
# ATP5G3 	 http://www.ncbi.nlm.nih.gov/gene/518 0.2
# RNF122 	 http://www.ncbi.nlm.nih.gov/gene/79845 0.2
# PEX11A 	 http://www.ncbi.nlm.nih.gov/gene/8800 0.333333
# PDRG1 	 http://www.ncbi.nlm.nih.gov/gene/81572 0.333333
# MAGI1 	 http://www.ncbi.nlm.nih.gov/gene/9223 0.2
# COPS2 	 http://www.ncbi.nlm.nih.gov/gene/9318 0.333333
#    BRIP1 (7) associations
# LMBR1L 	 http://www.ncbi.nlm.nih.gov/gene/55716 0.333333
# ATP5E 	 http://www.ncbi.nlm.nih.gov/gene/514 0.2
# ISOC2 	 http://www.ncbi.nlm.nih.gov/gene/79763 0.2
# ABL2 	 http://www.ncbi.nlm.nih.gov/gene/27 1
# TMEM53 	 http://www.ncbi.nlm.nih.gov/gene/79639 0.5
# GOLGB1 	 http://www.ncbi.nlm.nih.gov/gene/2804 0.25
#  	 http://www.ncbi.nlm.nih.gov/gene/109504726 1
# candidate_associated_proteins set has (3) genes with hits
#    CENPX (31) associations
# IARS 	 http://www.ncbi.nlm.nih.gov/gene/3376 0.2
# TBCCD1 	 http://www.ncbi.nlm.nih.gov/gene/55171 0.2
# EPHB4 	 http://www.ncbi.nlm.nih.gov/gene/2050 0.2
# FMN1 	 http://www.ncbi.nlm.nih.gov/gene/342184 0.2
# CYB5RL 	 http://www.ncbi.nlm.nih.gov/gene/606495 0.2
# HYI 	 http://www.ncbi.nlm.nih.gov/gene/81888 0.2
# ROGDI 	 http://www.ncbi.nlm.nih.gov/gene/79641 0.2
# FUCA1 	 http://www.ncbi.nlm.nih.gov/gene/2517 0.2
# FKBP3 	 http://www.ncbi.nlm.nih.gov/gene/2287 0.2
# KLHL25 	 http://www.ncbi.nlm.nih.gov/gene/64410 0.2
# NUP43 	 http://www.ncbi.nlm.nih.gov/gene/348995 0.2
# DHX57 	 http://www.ncbi.nlm.nih.gov/gene/90957 0.2
# RBM23 	 http://www.ncbi.nlm.nih.gov/gene/55147 0.2
# PDK4 	 http://www.ncbi.nlm.nih.gov/gene/5166 0.2
# ZNF550 	 http://www.ncbi.nlm.nih.gov/gene/162972 0.2
# CCDC153 	 http://www.ncbi.nlm.nih.gov/gene/283152 0.2
# LZIC 	 http://www.ncbi.nlm.nih.gov/gene/84328 0.2
# PPIL1 	 http://www.ncbi.nlm.nih.gov/gene/51645 0.2
# RRN3 	 http://www.ncbi.nlm.nih.gov/gene/54700 0.2
# C16orf87 	 http://www.ncbi.nlm.nih.gov/gene/388272 0.2
# PGK2 	 http://www.ncbi.nlm.nih.gov/gene/5232 0.2
# HLA-DMA 	 http://www.ncbi.nlm.nih.gov/gene/3108 0.2
# RABL3 	 http://www.ncbi.nlm.nih.gov/gene/285282 0.2
# VPS52 	 http://www.ncbi.nlm.nih.gov/gene/6293 0.2
# CYP39A1 	 http://www.ncbi.nlm.nih.gov/gene/51302 0.2
# ZFAT 	 http://www.ncbi.nlm.nih.gov/gene/57623 0.2
# RTBDN 	 http://www.ncbi.nlm.nih.gov/gene/83546 0.2
# XRN1 	 http://www.ncbi.nlm.nih.gov/gene/54464 0.2
# ZNF20 	 http://www.ncbi.nlm.nih.gov/gene/7568 0.2
# SLC26A6 	 http://www.ncbi.nlm.nih.gov/gene/65010 0.2
# ALDH4A1 	 http://www.ncbi.nlm.nih.gov/gene/8659 0.2
#    FAAP100 (30) associations
# C16orf46 	 http://www.ncbi.nlm.nih.gov/gene/123775 0.5
# WDR27 	 http://www.ncbi.nlm.nih.gov/gene/253769 0.25
# NTHL1 	 http://www.ncbi.nlm.nih.gov/gene/4913 0.333333
# PGAP3 	 http://www.ncbi.nlm.nih.gov/gene/93210 0.5
# OTUD7B 	 http://www.ncbi.nlm.nih.gov/gene/56957 0.25
# SF3B6 	 http://www.ncbi.nlm.nih.gov/gene/51639 0.2
# STAU1 	 http://www.ncbi.nlm.nih.gov/gene/6780 0.2
# CYB561A3 	 http://www.ncbi.nlm.nih.gov/gene/220002 0.2
# TMEM230 	 http://www.ncbi.nlm.nih.gov/gene/29058 0.25
# PPID 	 http://www.ncbi.nlm.nih.gov/gene/5481 0.333333
# ZNF384 	 http://www.ncbi.nlm.nih.gov/gene/171017 0.25
# MUT 	 http://www.ncbi.nlm.nih.gov/gene/4594 0.333333
# TAF12 	 http://www.ncbi.nlm.nih.gov/gene/6883 0.2
# LRRC41 	 http://www.ncbi.nlm.nih.gov/gene/10489 0.333333
# DPM3 	 http://www.ncbi.nlm.nih.gov/gene/54344 0.333333
# LYSMD1 	 http://www.ncbi.nlm.nih.gov/gene/388695 0.333333
# LRRC47 	 http://www.ncbi.nlm.nih.gov/gene/57470 0.333333
# RGL2 	 http://www.ncbi.nlm.nih.gov/gene/5863 0.25
# FBXW2 	 http://www.ncbi.nlm.nih.gov/gene/26190 0.333333
# MED19 	 http://www.ncbi.nlm.nih.gov/gene/219541 0.2
# C7orf49 	 http://www.ncbi.nlm.nih.gov/gene/78996 0.2
# PALB2 	 http://www.ncbi.nlm.nih.gov/gene/79728 0.25
# KIAA0825 	 http://www.ncbi.nlm.nih.gov/gene/285600 0.25
# RPS6 	 http://www.ncbi.nlm.nih.gov/gene/6194 0.2
# C2orf68 	 http://www.ncbi.nlm.nih.gov/gene/388969 0.333333
# EMC7 	 http://www.ncbi.nlm.nih.gov/gene/56851 0.25
# MCAT 	 http://www.ncbi.nlm.nih.gov/gene/27349 0.25
# CAGE1 	 http://www.ncbi.nlm.nih.gov/gene/285782 0.2
# KNOP1 	 http://www.ncbi.nlm.nih.gov/gene/400506 0.2
# FBXW9 	 http://www.ncbi.nlm.nih.gov/gene/84261 0.5
#    FAAP20 (30) associations
# MYO1A 	 http://www.ncbi.nlm.nih.gov/gene/4640 0.25
# ANKRD18A 	 http://www.ncbi.nlm.nih.gov/gene/253650 0.5
# C8orf59 	 http://www.ncbi.nlm.nih.gov/gene/401466 0.2
# ZNF414 	 http://www.ncbi.nlm.nih.gov/gene/84330 0.25
# CEACAM1 	 http://www.ncbi.nlm.nih.gov/gene/634 0.25
# DBNDD1 	 http://www.ncbi.nlm.nih.gov/gene/79007 0.25
# MIF4GD 	 http://www.ncbi.nlm.nih.gov/gene/57409 0.2
# BCAT2 	 http://www.ncbi.nlm.nih.gov/gene/587 0.333333
# ANXA2 	 http://www.ncbi.nlm.nih.gov/gene/302 0.2
# SP6 	 http://www.ncbi.nlm.nih.gov/gene/80320 0.2
# PTGIR 	 http://www.ncbi.nlm.nih.gov/gene/5739 0.25
# GPR20 	 http://www.ncbi.nlm.nih.gov/gene/2843 0.5
# LHB 	 http://www.ncbi.nlm.nih.gov/gene/3972 0.2
# RPS27L 	 http://www.ncbi.nlm.nih.gov/gene/51065 0.333333
# PRTFDC1 	 http://www.ncbi.nlm.nih.gov/gene/56952 0.25
# MATN3 	 http://www.ncbi.nlm.nih.gov/gene/4148 0.5
# AMT 	 http://www.ncbi.nlm.nih.gov/gene/275 0.25
# UNKL 	 http://www.ncbi.nlm.nih.gov/gene/64718 0.333333
# MYH7 	 http://www.ncbi.nlm.nih.gov/gene/4625 0.25
# BEGAIN 	 http://www.ncbi.nlm.nih.gov/gene/57596 0.25
# CHST15 	 http://www.ncbi.nlm.nih.gov/gene/51363 0.5
# SFRP5 	 http://www.ncbi.nlm.nih.gov/gene/6425 0.25
# KIAA0895L 	 http://www.ncbi.nlm.nih.gov/gene/653319 0.333333
# NAA10 	 http://www.ncbi.nlm.nih.gov/gene/8260 0.333333
# HSD17B11 	 http://www.ncbi.nlm.nih.gov/gene/51170 0.25
# ZSCAN10 	 http://www.ncbi.nlm.nih.gov/gene/84891 0.25
# C16orf47 	 http://www.ncbi.nlm.nih.gov/gene/388289 0.25
# CD70 	 http://www.ncbi.nlm.nih.gov/gene/970 0.25
# AGMO 	 http://www.ncbi.nlm.nih.gov/gene/392636 0.25
# VWCE 	 http://www.ncbi.nlm.nih.gov/gene/220001 0.25
# candidate_core_complex set has (5) genes with hits
#    UBE2T (28) associations
# PDIA6 	 http://www.ncbi.nlm.nih.gov/gene/10130 0.5
# ZNF77 	 http://www.ncbi.nlm.nih.gov/gene/58492 0.25
# ZNF680 	 http://www.ncbi.nlm.nih.gov/gene/340252 1
# ANP32A 	 http://www.ncbi.nlm.nih.gov/gene/8125 1
# KANSL2 	 http://www.ncbi.nlm.nih.gov/gene/54934 0.25
# RHOF 	 http://www.ncbi.nlm.nih.gov/gene/54509 0.333333
# CFAP43 	 http://www.ncbi.nlm.nih.gov/gene/80217 0.5
# SLC43A2 	 http://www.ncbi.nlm.nih.gov/gene/124935 0.25
# MPP7 	 http://www.ncbi.nlm.nih.gov/gene/143098 0.333333
# GOLGB1 	 http://www.ncbi.nlm.nih.gov/gene/2804 0.25
# CKB 	 http://www.ncbi.nlm.nih.gov/gene/1152 0.5
# BUB1 	 http://www.ncbi.nlm.nih.gov/gene/699 0.2
# CDR2 	 http://www.ncbi.nlm.nih.gov/gene/1039 0.5
# DHCR24 	 http://www.ncbi.nlm.nih.gov/gene/1718 0.5
# ULK4 	 http://www.ncbi.nlm.nih.gov/gene/54986 0.5
# ANKRD9 	 http://www.ncbi.nlm.nih.gov/gene/122416 0.25
# MRPL51 	 http://www.ncbi.nlm.nih.gov/gene/51258 0.2
# ATG2A 	 http://www.ncbi.nlm.nih.gov/gene/23130 0.333333
# ZNF675 	 http://www.ncbi.nlm.nih.gov/gene/171392 1
# DEDD2 	 http://www.ncbi.nlm.nih.gov/gene/162989 0.25
# C12orf76 	 http://www.ncbi.nlm.nih.gov/gene/400073 0.2
# ILF2 	 http://www.ncbi.nlm.nih.gov/gene/3608 1
# TFDP2 	 http://www.ncbi.nlm.nih.gov/gene/7029 0.25
# TYSND1 	 http://www.ncbi.nlm.nih.gov/gene/219743 0.5
# TMEM160 	 http://www.ncbi.nlm.nih.gov/gene/54958 1
# ALS2CR12 	 http://www.ncbi.nlm.nih.gov/gene/130540 0.333333
# CCDC148 	 http://www.ncbi.nlm.nih.gov/gene/130940 0.2
# TECPR1 	 http://www.ncbi.nlm.nih.gov/gene/25851 0.333333
#    FANCA (36) associations
# IARS 	 http://www.ncbi.nlm.nih.gov/gene/3376 0.2
# TBCCD1 	 http://www.ncbi.nlm.nih.gov/gene/55171 0.25
# CCDC191 	 http://www.ncbi.nlm.nih.gov/gene/57577 0.2
# TMEM161A 	 http://www.ncbi.nlm.nih.gov/gene/54929 0.2
# LRRC24 	 http://www.ncbi.nlm.nih.gov/gene/441381 0.25
# CYB5RL 	 http://www.ncbi.nlm.nih.gov/gene/606495 0.25
# AIFM1 	 http://www.ncbi.nlm.nih.gov/gene/9131 0.2
# HYI 	 http://www.ncbi.nlm.nih.gov/gene/81888 0.25
# NDUFAB1 	 http://www.ncbi.nlm.nih.gov/gene/4706 0.25
# TTLL6 	 http://www.ncbi.nlm.nih.gov/gene/284076 0.2
# SLC16A1 	 http://www.ncbi.nlm.nih.gov/gene/6566 0.2
# LIG4 	 http://www.ncbi.nlm.nih.gov/gene/3981 0.2
# NUP43 	 http://www.ncbi.nlm.nih.gov/gene/348995 0.25
# ROCK1 	 http://www.ncbi.nlm.nih.gov/gene/6093 0.25
# STMN4 	 http://www.ncbi.nlm.nih.gov/gene/81551 0.2
# ZNF20 	 http://www.ncbi.nlm.nih.gov/gene/7568 0.25
# PAXIP1 	 http://www.ncbi.nlm.nih.gov/gene/22976 0.25
# PPIL1 	 http://www.ncbi.nlm.nih.gov/gene/51645 0.25
# KDM5C 	 http://www.ncbi.nlm.nih.gov/gene/8242 0.2
# C3orf18 	 http://www.ncbi.nlm.nih.gov/gene/51161 0.2
# CLCC1 	 http://www.ncbi.nlm.nih.gov/gene/23155 0.2
# RBM23 	 http://www.ncbi.nlm.nih.gov/gene/55147 0.2
# PGK2 	 http://www.ncbi.nlm.nih.gov/gene/5232 0.25
# IL17RD 	 http://www.ncbi.nlm.nih.gov/gene/54756 0.25
# SMARCD3 	 http://www.ncbi.nlm.nih.gov/gene/6604 0.25
# ATAD2 	 http://www.ncbi.nlm.nih.gov/gene/29028 0.2
# KIF14 	 http://www.ncbi.nlm.nih.gov/gene/9928 0.2
# SPTLC2 	 http://www.ncbi.nlm.nih.gov/gene/9517 0.2
# ZFAT 	 http://www.ncbi.nlm.nih.gov/gene/57623 0.2
# ALDH4A1 	 http://www.ncbi.nlm.nih.gov/gene/8659 0.25
# PDK4 	 http://www.ncbi.nlm.nih.gov/gene/5166 0.25
# GANAB 	 http://www.ncbi.nlm.nih.gov/gene/23193 0.2
# EBPL 	 http://www.ncbi.nlm.nih.gov/gene/84650 0.2
# NUP62CL 	 http://www.ncbi.nlm.nih.gov/gene/54830 0.2
# BORCS6 	 http://www.ncbi.nlm.nih.gov/gene/54785 0.2
# DHX57 	 http://www.ncbi.nlm.nih.gov/gene/90957 0.25
#    FANCL (7) associations
# TTC33 	 http://www.ncbi.nlm.nih.gov/gene/23548 0.2
# STAG1 	 http://www.ncbi.nlm.nih.gov/gene/10274 0.2
# TRIM33 	 http://www.ncbi.nlm.nih.gov/gene/51592 0.2
# CSTF2T 	 http://www.ncbi.nlm.nih.gov/gene/23283 0.25
# MED14 	 http://www.ncbi.nlm.nih.gov/gene/9282 0.25
# IGF2BP2 	 http://www.ncbi.nlm.nih.gov/gene/10644 0.333333
# SEPHS1 	 http://www.ncbi.nlm.nih.gov/gene/22929 0.2
#    FANCC (21) associations
# WWTR1 	 http://www.ncbi.nlm.nih.gov/gene/25937 0.25
# TGFBR3 	 http://www.ncbi.nlm.nih.gov/gene/7049 0.25
# ALX3 	 http://www.ncbi.nlm.nih.gov/gene/257 0.25
# CD163L1 	 http://www.ncbi.nlm.nih.gov/gene/283316 0.25
# C1orf198 	 http://www.ncbi.nlm.nih.gov/gene/84886 0.2
# SLC7A8 	 http://www.ncbi.nlm.nih.gov/gene/23428 0.25
# MAPK10 	 http://www.ncbi.nlm.nih.gov/gene/5602 0.25
# ANXA11 	 http://www.ncbi.nlm.nih.gov/gene/311 0.25
# DDAH1 	 http://www.ncbi.nlm.nih.gov/gene/23576 0.2
# PLAGL1 	 http://www.ncbi.nlm.nih.gov/gene/5325 0.25
# KRT39 	 http://www.ncbi.nlm.nih.gov/gene/390792 0.25
# GSTA1 	 http://www.ncbi.nlm.nih.gov/gene/2938 0.25
# FCRL4 	 http://www.ncbi.nlm.nih.gov/gene/83417 0.25
# GSTA2 	 http://www.ncbi.nlm.nih.gov/gene/2939 0.2
# SMC1B 	 http://www.ncbi.nlm.nih.gov/gene/27127 0.2
# TKTL2 	 http://www.ncbi.nlm.nih.gov/gene/84076 0.25
# NPHS1 	 http://www.ncbi.nlm.nih.gov/gene/4868 0.25
# PCYT1B 	 http://www.ncbi.nlm.nih.gov/gene/9468 0.25
# AMELY 	 http://www.ncbi.nlm.nih.gov/gene/266 0.25
# PEG3 	 http://www.ncbi.nlm.nih.gov/gene/5178 0.25
# TOMM5 	 http://www.ncbi.nlm.nih.gov/gene/401505 0.25
#    FANCB (13) associations
# RBM39 	 http://www.ncbi.nlm.nih.gov/gene/9584 0.25
# RHBDF2 	 http://www.ncbi.nlm.nih.gov/gene/79651 0.25
# SEMA6A 	 http://www.ncbi.nlm.nih.gov/gene/57556 0.333333
# GPR157 	 http://www.ncbi.nlm.nih.gov/gene/80045 0.333333
# LARGE1 	 http://www.ncbi.nlm.nih.gov/gene/9215 0.333333
# GPAM 	 http://www.ncbi.nlm.nih.gov/gene/57678 0.333333
# FYCO1 	 http://www.ncbi.nlm.nih.gov/gene/79443 0.333333
# TMEM134 	 http://www.ncbi.nlm.nih.gov/gene/80194 0.333333
# KCNJ10 	 http://www.ncbi.nlm.nih.gov/gene/3766 0.333333
# PLXND1 	 http://www.ncbi.nlm.nih.gov/gene/23129 0.333333
# GGT7 	 http://www.ncbi.nlm.nih.gov/gene/2686 0.333333
# SLC35E2 	 http://www.ncbi.nlm.nih.gov/gene/9906 0.333333
# RNF126 	 http://www.ncbi.nlm.nih.gov/gene/55658 0.25

# %% [markdown]
# well they went in ordered by score...
