# %%
import requests

tk_bio = "https://kba.ncats.io/statements"
riluzole = "wd:Q415744"

params = {
    'c': riluzole
}

solr_request = requests.get(tk_bio, params=params)
response = solr_request.json()

# Get list of wd ids where drug is a therapeutic area
disease_set = {doc['object']['id'] for doc in response
                   if doc['predicate']['name'] == 'therapeutic area' or
                       doc['predicate']['name'] == 'medical condition treated'
              }

disease_set
# Out:
# {'wd:Q206901'}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# Get DOIDs from wikidata

omim_set = set()

sparql = SPARQLWrapper("http://query.wikidata.org/sparql")

for disease in disease_set:

    doid_xrefs = """
        SELECT ?disease
        WHERE
        {{
            {} wdt:P492 ?disease
        }}
        LIMIT 20
    """.format(disease)

    sparql.setQuery(doid_xrefs)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    for result in results["results"]["bindings"]:
        omim_set.add("OMIM:{}".format(result["disease"]["value"]))

omim_set
# Out:
# {'OMIM:105400'}

# %%
import biolink_client
from biolink_client.api_client import ApiClient
from biolink_client.rest import ApiException

# Get phenotypes for each disease

MONARCH_API = "https://api.monarchinitiative.org/api"

disease_hpo_map = {}


client = ApiClient(host=MONARCH_API)
client.set_default_header('Content-Type', 'text/plain')
api_instance = biolink_client.BioentityApi(client)

for disease in omim_set:
    api_response = api_instance.get_disease_phenotype_associations(disease, rows=500)
    disease_hpo_map[disease] = api_response.objects
    
disease_hpo_map
# Out:
# {'OMIM:105400': ['HP:0001257',
#   'HP:0001324',
#   'HP:0001347',
#   'HP:0002314',
#   'HP:0002380',
#   'HP:0002398',
#   'HP:0003202',
#   'HP:0003394',
#   'HP:0007024',
#   'HP:0007354',
#   'HP:0010535']}

# %%
import requests
import pandas as pd

# Get similar diseases

OWLSIM_API = "http://owlsim3.monarchinitiative.org/api"

# Use phenodigm algorithm, with a cutoff of 70/100
matcher = 'phenodigm'
score_cutoff = 50

result_set = []


for disease, profile in disease_hpo_map.items():
    params = {
        'id': profile
    }
    url = "{}/match/{}".format(OWLSIM_API, matcher)
    req = requests.get(url, params=params)
    owlsim_results = req.json()
    for match in owlsim_results['matches']:
        try:
            if (match['matchId'].startswith("OMIM") \
                    or  match['matchId'].startswith("Orphanet") \
                    or  match['matchId'].startswith("DOID")) \
                    and match['rawScore'] >= score_cutoff:
                result = [disease, match['matchId'],
                          match['matchLabel'], match['rawScore']]
                result_set.append(result)
        except TypeError as e:
            # TypeError when score is NaN
            #print(e)
            #print(match)
            continue
            
# Create a table of query gene, matched gene, and sim score
column_names = ['query_disease', 'match_disease', 'match_label', 'sim_score']
result_frame = pd.DataFrame(data=result_set, columns=column_names)

result_frame.head(30)
# Out:
#    query_disease   match_disease  \
# 0    OMIM:105400     OMIM:105400
# 1    OMIM:105400     OMIM:614808
# 2    OMIM:105400     OMIM:613954
# 3    OMIM:105400     OMIM:312920
# 4    OMIM:105400  Orphanet:85162
# 5    OMIM:105400     OMIM:603563
# 6    OMIM:105400     OMIM:182600
# 7    OMIM:105400     OMIM:182601
# 8    OMIM:105400     OMIM:607259
# 9    OMIM:105400     OMIM:600363
# 10   OMIM:105400     OMIM:608627
# 11   OMIM:105400     OMIM:602099
# 12   OMIM:105400     OMIM:602440
# 13   OMIM:105400     OMIM:604360
# 14   OMIM:105400     OMIM:607596
# 15   OMIM:105400     OMIM:137200
# 16   OMIM:105400     OMIM:183050
# 17   OMIM:105400     OMIM:602433
# 18   OMIM:105400        DOID:332
# 19   OMIM:105400     OMIM:616586
# 20   OMIM:105400     OMIM:616439
# 21   OMIM:105400     OMIM:616437
# 22   OMIM:105400        DOID:681
# 23   OMIM:105400     OMIM:253550
# 24   OMIM:105400     OMIM:614696
# 25   OMIM:105400     OMIM:615575
# 26   OMIM:105400     OMIM:611302
# 27   OMIM:105400     OMIM:604484
# 28   OMIM:105400     OMIM:608030
# 29   OMIM:105400       DOID:4952
#
#                                           match_label   sim_score
# 0                Amyotrophic lateral sclerosis type 1  100.000000
# 1                    Amyotrophic Lateral Sclerosis 18   62.304265
# 2   Amyotrophic Lateral Sclerosis 14 With or Witho...   60.378501
# 3                      Spastic Paraplegia 2, X-Linked   60.187194
# 4         Facial onset sensory and motor neuronopathy   59.714106
# 5                     hereditary spastic paraplegia 8   59.450566
# 6                                Spastic paraplegia 3   58.100485
# 7            Spastic paraplegia 4, autosomal dominant   57.087924
# 8           Spastic Paraplegia 7, Autosomal Recessive   57.087924
# 9                     hereditary spastic paraplegia 6   55.833389
# 10               amyotrophic lateral sclerosis type 8   55.012490
# 11          Amyotrophic Lateral Sclerosis 5, Juvenile   54.954672
# 12                              Amyotrophy, Monomelic   54.602596
# 13                   hereditary spastic paraplegia 11   54.200252
# 14                  Pontocerebellar hypoplasia type 1   53.683357
# 15                         Gamstorp-Wohlfart syndrome   53.040800
# 16  Spinocerebellar Ataxia With Rigidity and Perip...   53.005916
# 17               Amyotrophic lateral sclerosis type 4   52.521927
# 18                      amyotrophic lateral sclerosis   52.486974
# 19         Spastic Paraplegia 9B, Autosomal Recessive   52.378068
# 20  Frontotemporal dementia and/or amyotrophic lat...   52.341968
# 21  Frontotemporal dementia and/or amyotrophic lat...   52.341968
# 22                           progressive bulbar palsy   51.672713
# 23               intermediate spinal muscular atrophy   51.271812
# 24                   Amyotrophic lateral sclerosis 17   51.112805
# 25     Neuronopathy, Distal Hereditary Motor, Type 2D   50.731908
# 26              Spastic Ataxia 2, Autosomal Recessive   50.510849
# 27  Neuropathy, Hereditary Motor and Sensory, Okin...   50.389614
# 28  Amyotrophic Lateral Sclerosis 6 With or Withou...   50.300491
# 29                         postpoliomyelitis syndrome   50.260302
