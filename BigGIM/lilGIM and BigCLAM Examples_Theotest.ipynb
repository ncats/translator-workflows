# %% [markdown]
# # lilGIM and BigCLAM example
#
# swagger api specification: http://biggim.ncats.io/api

# %%
# A few helper functions for posting and getting api requests
import json
import requests
import pandas
import time

base_url = 'http://biggim.ncats.io/api'

#a couple of simple helper functions
def post(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()

def get(endpoint, data={}, base_url=base_url):
    req = requests.get('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    print("Sent: GET %s?%s" % (req.request.url,req.request.body))
    return req.json()
    

def jprint(dct):
    print(json.dumps(dct, indent=2))
    
def wrapper(endpoint, data={}, base_url=base_url):
    try:
        response = get(endpoint, data, base_url)
        jprint(response)
    except requests.HTTPError as e:

        print(e)
        if e.response.status_code == 400:
            jprint(e.response.json())
        raise
    try:
        ctr = 1
        while True:
            query_status = get('%s/status/%s'% (endpoint.split('/')[0],response['request_id'],))
            jprint(query_status)
            if query_status['status'] !='running':
                # query has finished
                break
            else:
                time.sleep(ctr)
                ctr += 1
                #linear backoff
                print("Checking again")
    except requests.HTTPError as e:
        print(e)
        if e.response.status_code == 400:
            jprint(e.response.json())
        raise
    return pandas.concat(map(pandas.read_csv, query_status['request_uri']))

# %% [markdown]
# ## lilGIM
#
# Lil' GIM is a simplified interface to BigGIM

# %% [markdown]
# ### Run the simplest query possible.
#
# You provide a list of entrez gene ids. A query request is triggered, which returns a `request_id`
# You then query a `results` endpoint to find out if the request is finished processing and where the result is.
# Provided their are no errors you can download the CSV and interact with the values.
#
# This query will look at all tissues (`whole_body` in the Brenda tissue ontology) and limit the number of rows to 1000.

# %%
endpoint = "lilgim/query"
data = {'ids':'5111,6996,57697,6815,889,7112,2176,1019,5888,5706'}
try:
    response = get(endpoint, data)
    jprint(response)
except requests.HTTPError as e:
    print(e)
    jprint(e.response.json())
# Out:
# Sent: GET http://biggim.ncats.io/api/lilgim/query?ids=5111%2C6996%2C57697%2C6815%2C889%2C7112%2C2176%2C1019%2C5888%2C5706
# {
#   "status": "submitted",
#   "request_id": "7c939bfb-b14a-4faa-991c-7e91b7331e90"
# }

# %% [markdown]
# ## Check query status
#
# These can take a while to run as they are querying gigs of data. So we keep pinging the server to find out when the query is done and where the results can be found.

# %%
import time
try:
    ctr = 1
    while True:
        query_status = get('lilgim/status/%s'% (response['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(ctr)
            ctr += 1
            #linear backoff
            print("Checking again")
except requests.HTTPError as e:
    print(e)
    jprint(e.response.json())
# Out:
# Sent: GET http://biggim.ncats.io/api/lilgim/status/7c939bfb-b14a-4faa-991c-7e91b7331e90?None
# {
#   "message": "Extraction job is running.",
#   "status": "running",
#   "request_id": "7c939bfb-b14a-4faa-991c-7e91b7331e90"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/lilgim/status/7c939bfb-b14a-4faa-991c-7e91b7331e90?None
# {
#   "status": "complete",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/7c939bfb-b14a-4faa-991c-7e91b7331e90000000000000.csv"
#   ],
#   "request_id": "7c939bfb-b14a-4faa-991c-7e91b7331e90",
#   "size": "320.3 KB",
#   "processed_data": "15.58 GB",
#   "rows": 5541
# }

# %% [markdown]
# ## Get the results from google cloud
#
# This grabs the results, which could be multiple files and creates a dataframe from them.

# %%
results = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
results.head()
# Out:
#     Gene1 Symbol1  Gene2 Symbol2  maxCorr  minCorr   aveCorr
# 0  113130   CDCA5   5888   RAD51   0.9695   0.2743  0.722643
# 1    5888   RAD51    701   BUB1B   0.9555   0.2071  0.697161
# 2    9133   CCNB2   5888   RAD51   0.9674   0.0481  0.693683
# 3    8318   CDC45   5888   RAD51   0.9794   0.0142  0.691496
# 4   51203  NUSAP1   5888   RAD51   0.9532   0.0814  0.671044

# %% [markdown]
# ## Simplified w/ wrapper
#
# All query resources follow the same pattern. Query the endpoint, wait for the query to finish, get the result.
#
# This simplified helper function performs all of the above and will be used for the rest of the tutorial.

# %%
#same query as before, it just waits for the results automatically
endpoint = "lilgim/query"
data = {'ids':'5111,6996,57697,6815,889,7112,2176,1019,5888,5706'}
results = wrapper(endpoint, data)
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/lilgim/query?ids=5111%2C6996%2C57697%2C6815%2C889%2C7112%2C2176%2C1019%2C5888%2C5706
# {
#   "status": "submitted",
#   "request_id": "84c4355a-a58b-4c98-8f9d-6c1c542a068d"
# }
# Sent: GET http://biggim.ncats.io/api/lilgim/status/84c4355a-a58b-4c98-8f9d-6c1c542a068d?None
# {
#   "message": "Extraction job is running.",
#   "status": "running",
#   "request_id": "84c4355a-a58b-4c98-8f9d-6c1c542a068d"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/lilgim/status/84c4355a-a58b-4c98-8f9d-6c1c542a068d?None
# {
#   "status": "complete",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/84c4355a-a58b-4c98-8f9d-6c1c542a068d000000000000.csv"
#   ],
#   "request_id": "84c4355a-a58b-4c98-8f9d-6c1c542a068d",
#   "size": "320.3 KB",
#   "processed_data": "0B",
#   "rows": 5541
# }
#     Gene1 Symbol1  Gene2 Symbol2  maxCorr  minCorr   aveCorr
# 0  113130   CDCA5   5888   RAD51   0.9695   0.2743  0.722643
# 1    5888   RAD51    701   BUB1B   0.9555   0.2071  0.697161
# 2    9133   CCNB2   5888   RAD51   0.9674   0.0481  0.693683
# 3    8318   CDC45   5888   RAD51   0.9794   0.0142  0.691496
# 4   51203  NUSAP1   5888   RAD51   0.9532   0.0814  0.671044

# %% [markdown]
# ## Optional parameters
#
# - `limit` - the maximum number of relationships to return (default:1000)
# -  `tissue` - restrict query to specific tissue from the Brenda tissue ontology (default:whole_body)

# %% [markdown]
# ### View available tissues via the `metadata/tissue` endpoint

# %%
try:
    response = get('/metadata/tissue')
    print("Available Tissues")
    jprint(response)
except response.HTTPError as e:
    print(e)
# Out:
# Sent: GET http://biggim.ncats.io/api//metadata/tissue?None
# Available Tissues
# {
#   "tissues": [
#     "B_lymphocyte",
#     "B_lymphoma_cell_line",
#     "T_lymphocyte",
#     "acute_myeloid_leukemia_cell",
#     "adenocarcinoma_cell",
#     "adipose_tissue",
#     "adrenal_cortex",
#     "adrenal_gland",
#     "adrenal_gland_cancer_cell",
#     "adrenocortical_carcinoma_cell",
#     "adult_stem_cell",
#     "alimentary_canal",
#     "amygdala",
#     "animal",
#     "aorta",
#     "artery",
#     "astroblast",
#     "astrocyte",
#     "astrocytoma_cell",
#     "astroglia",
#     "astroglial_cell",
#     "avian_pallium",
#     "basal_ganglion",
#     "basophil",
#     "bile_duct",
#     "bile_duct_epithelium",
#     "biliary_epithelium",
#     "bladder",
#     "blast_cell",
#     "blastomere",
#     "blastula",
#     "blood",
#     "blood_cancer_cell",
#     "blood_plasma",
#     "blood_platelet",
#     "blood_vessel",
#     "blood_vessel_endothelium",
#     "bone",
#     "bone_cancer_cell",
#     "bone_marrow",
#     "bone_marrow_cell",
#     "brain",
#     "brain_stem",
#     "brain_ventricle",
#     "breast",
#     "breast_cancer_cell",
#     "breast_epithelium",
#     "bronchial_epithelial_cell",
#     "bronchial_epithelium",
#     "bronchoalveolar_system",
#     "bronchogenic_carcinoma_cell",
#     "bronchus",
#     "capsular_epithelium",
#     "carcinoid_cell",
#     "carcinoma_cell",
#     "cardiac_muscle",
#     "cardiovascular_system",
#     "cartilage",
#     "caudate_nucleus",
#     "caudate_putamen",
#     "cecum",
#     "cell_culture",
#     "central_nervous_system",
#     "cerebellar_cortex",
#     "cerebellum",
#     "cerebral_cortex",
#     "cerebral_hemisphere",
#     "cerebral_lobe",
#     "cervical_adenocarcinoma_cell",
#     "cervical_carcinoma_cell",
#     "cervical_squamous_cell_carcinoma_cell",
#     "cholangiocarcinoma_cell",
#     "chondrocyte",
#     "choroid",
#     "chromophobe_renal_cell_carcinoma_cell",
#     "cochlea",
#     "coelom",
#     "colon",
#     "colonic_cancer_cell",
#     "colorectal_adenocarcinoma_cell",
#     "colorectum",
#     "connecting_stalk",
#     "connective_tissue",
#     "cornea",
#     "corpus_callosum",
#     "corpus_luteum",
#     "corpus_striatum",
#     "culture_condition",
#     "culture_condition_CD8__cell",
#     "culture_condition_antigen_presenting_cell",
#     "dendritic_cell",
#     "dentate_gyrus",
#     "diencephalon",
#     "diffuse_large_B_cell_lymphoma_cell",
#     "digestive_gland",
#     "duodenum",
#     "ear",
#     "ectoderm",
#     "embryo",
#     "embryonic_structure",
#     "endocrine_gland",
#     "endocrine_pancreas",
#     "endometrioid_carcinoma_cell",
#     "endothelial_cell",
#     "endothelium",
#     "eosinophil",
#     "epidermal_cell",
#     "epidermis",
#     "epithelial_cell",
#     "epithelioma_cell",
#     "epithelium",
#     "esophageal_cancer_cell",
#     "esophagus",
#     "excretory_gland",
#     "exocrine_gland",
#     "exocrine_pancreas",
#     "eye",
#     "female_reproductive_gland",
#     "female_reproductive_system",
#     "fetus",
#     "fibroblast",
#     "forebrain",
#     "frontal_lobe",
#     "gametocyte",
#     "ganglion",
#     "gastric_adenocarcinoma_cell",
#     "gastric_cancer_cell",
#     "gastrointestinal_cancer_cell",
#     "gastrointestinal_tract",
#     "germ_cell",
#     "germ_layer",
#     "gland",
#     "glia",
#     "glial_cell",
#     "glioblastoma_cell",
#     "glioma_cell",
#     "glomerular_epithelium",
#     "gonad",
#     "granulocyte",
#     "hair_follicle",
#     "head",
#     "head_and_neck_cancer_cell",
#     "heart",
#     "hematopoietic_cell",
#     "hematopoietic_stem_cell",
#     "hematopoietic_system",
#     "hepatocyte",
#     "hindbrain",
#     "hippocampus",
#     "hypophysis",
#     "hypothalamus",
#     "ileocecum",
#     "ileum",
#     "immune_system",
#     "inner_ear",
#     "integument",
#     "internal_female_genital_organ",
#     "internal_male_genital_organ",
#     "intestinal_mucosa",
#     "intestine",
#     "jejunum",
#     "keratinocyte",
#     "kidney",
#     "kidney_cancer_cell",
#     "large_granular_lymphocyte",
#     "large_intestine",
#     "lateral_ventricle",
#     "lens",
#     "leukemia_cell",
#     "leukocyte",
#     "limbic_system",
#     "liver",
#     "liver_cancer_cell",
#     "locus_ceruleus",
#     "lung",
#     "lung_adenocarcinoma_cell",
#     "lung_cancer_cell",
#     "lung_squamous_cell_carcinoma_cell",
#     "lymph_node",
#     "lymphocyte",
#     "lymphoid_cell",
#     "lymphoid_cell_line",
#     "lymphoid_tissue",
#     "lymphoma_cell",
#     "lymphoma_cell_line",
#     "macroglia",
#     "macrophage",
#     "male_reproductive_gland",
#     "male_reproductive_system",
#     "mammary_epithelium",
#     "mammary_gland",
#     "marrow_cell",
#     "mast_cell",
#     "mature_ovarian_follicle",
#     "medulla_oblongata",
#     "megakaryoblast",
#     "megakaryocyte",
#     "melanocyte",
#     "melanoma_cell",
#     "mesoderm",
#     "mesothelioma_cell",
#     "mesothelium",
#     "metencephalon",
#     "midbrain",
#     "monocyte",
#     "mononuclear_cell",
#     "mononuclear_phagocyte",
#     "morula",
#     "mouth",
#     "mucosa",
#     "muscle",
#     "muscular_system",
#     "myelencephalon",
#     "myeloid_leukemia_cell",
#     "myeloid_progenitor_cell",
#     "myometrium",
#     "natural_killer_cell",
#     "neck",
#     "neostriatum",
#     "nephron",
#     "nerve",
#     "nervous_system",
#     "neural_crest",
#     "neural_crest_cell",
#     "neural_plate",
#     "neuroblast",
#     "neuroendocrine_cell",
#     "neuroendocrine_tumor_cell",
#     "neuron",
#     "neutrophil",
#     "non_small_cell_lung_cancer_cell",
#     "nucleus_accumbens",
#     "nucleus_lentiformis",
#     "null_cell",
#     "occipital_lobe",
#     "occipital_pole",
#     "organism_form",
#     "osteoblast",
#     "osteogenic_cell",
#     "other_source",
#     "ovarian_follicle",
#     "ovarian_serous_carcinoma_cell",
#     "ovary",
#     "ovary_cancer_cell",
#     "oviduct",
#     "pancreas",
#     "pancreatic_duct",
#     "pancreatic_ductal_adenocarcinoma_cell",
#     "pancreatic_ductal_carcinoma_cell",
#     "pancreatic_islet",
#     "papillary_renal_cell_carcinoma_cell",
#     "parietal_lobe",
#     "periosteum",
#     "peripheral_blood",
#     "peripheral_nervous_system",
#     "phagocyte",
#     "pheochromocytoma_cell",
#     "placenta",
#     "podocyte",
#     "pons",
#     "pre_T_lymphocyte",
#     "preosteoblast",
#     "primary_spermatocyte",
#     "prostate_adenocarcinoma_cell",
#     "prostate_gland",
#     "rectal_adenocarcinoma_cell",
#     "rectal_cancer_cell",
#     "rectum",
#     "renal_cell_carcinoma_cell",
#     "renal_clear_cell",
#     "renal_corpuscle",
#     "renal_glomerular_capsule",
#     "renal_glomerulus",
#     "renal_tubule",
#     "reproductive_system",
#     "respiratory_epithelium",
#     "respiratory_system",
#     "retina",
#     "salivary_gland",
#     "sarcoma_cell",
#     "secondary_spermatocyte",
#     "semen",
#     "sense_organ",
#     "serum",
#     "skeletal_muscle",
#     "skeletal_muscle_cancer_cell",
#     "skeletal_muscle_cell",
#     "skeletal_system",
#     "skin",
#     "skin_cancer_cell",
#     "skin_fibroblast",
#     "small_intestine",
#     "smooth_muscle",
#     "spermatid",
#     "spermatocyte",
#     "spermatogonium",
#     "spinal_cord",
#     "spleen",
#     "squamous_cell_carcinoma_cell",
#     "squamous_epithelium",
#     "stomach",
#     "stratum_spinosum",
#     "substantia_nigra",
#     "subthalamic_nucleus",
#     "tear_gland",
#     "telencephalon",
#     "temporal_lobe",
#     "testicular_cancer_cell",
#     "testis",
#     "thalamus",
#     "thorax",
#     "throat",
#     "thymic_cancer_cell",
#     "thymocyte",
#     "thymoma_cell",
#     "thymus",
#     "thyroid_cancer_cell",
#     "thyroid_gland",
#     "tissues__cell_types_and_enzyme_sources",
#     "tonsil",
#     "tooth",
#     "trachea",
#     "trophoblast",
#     "trunk",
#     "umbilical_cord",
#     "umbilical_vein",
#     "umbilical_vein_endothelial_cell",
#     "umbilical_vein_endothelium",
#     "urinary_bladder",
#     "urinary_bladder_cancer_cell",
#     "urinary_system",
#     "urinary_tract",
#     "uroepithelium",
#     "urogenital_system",
#     "uterine_cancer_cell",
#     "uterine_cervix",
#     "uterine_endometrium",
#     "uterine_sarcoma_cell",
#     "uterus",
#     "uveal_melanoma_cell",
#     "vascular_endothelial_cell",
#     "vascular_endothelium",
#     "vascular_system",
#     "vermiform_appendix",
#     "vertebrate_muscular_system",
#     "vestibular_labyrinth",
#     "vestibular_system",
#     "viscus",
#     "whole_body",
#     "zygote"
#   ]
# }

# %% [markdown]
# ### Getting brain only correlations

# %%
endpoint = "lilgim/query"
data = {'ids':'768, 886, 887, 55775, 9376',
        'tissue': 'connective_tissue',
        'limit':100
       }
results = wrapper(endpoint, data)
brain_lgresults = results.copy()
results.head()

# %% [markdown]
# # BigCLAM
#
# **Big CLAM (Cell Line Association Miner)** is an **NCATS Translator Knowledge Source** that integrates large-scale high-quality data of various cell line resources to uncover associations between genomic and molecular features of cell lines, drug response measurements and gene knockdown viability scores. The cell line data comes from five different sources: 1) CCLE - Cancer Cell Line Encyclopedia, 2) GDSC - Genomics of Drug Sensitivity in Cancer, 3) CTRP - Cancer Therapeutics Response Portal, 4) CMap - Connectivity Map, and 5) CDM - Cancer Dependency Map. These data are stored as a Google BigQuery tables enabling fast access and real-time association analysis.

# %% [markdown]
# ## Genes to genes
#
# Genomic aberrations in INPUT genes decrease viability upon knockdown of OUTPUT genes

# %%
#data = {"ids": "TCOF1,DDX46,COPE,RIPK1"}
data = {"ids": "KRAS"}
endpoint = 'bigclam/g2g/query'
results = wrapper(endpoint, data)
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/bigclam/g2g/query?ids=KRAS
# {
#   "status": "submitted",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/e41b7994-2240-4bfc-95b8-5dd568fbf9e7?None
# {
#   "status": "complete",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/e41b7994-2240-4bfc-95b8-5dd568fbf9e7000000000000.csv"
#   ],
#   "request_id": "e41b7994-2240-4bfc-95b8-5dd568fbf9e7",
#   "size": "2.48 KB",
#   "processed_data": "1.68 GB",
#   "rows": 100
# }
#   gene_label           F
# 0       KRAS  274.194751
# 1    HERPUD2   43.998930
# 2    ALDH1L1   37.803953
# 3      CDKL1   34.873793
# 4       CD3D   33.624580

# %% [markdown]
# ## Optional parameters
#
# - `limit` - the maximum number of relationships to return (default:100)
# -  `tissue` - restrict query to specific tissue from the Brenda tissue ontology (default:whole_body)

# %%
# little fun using correlated genes from lilgim
# example is really about adding a limit parameter

#data = {"ids": "TCOF1,DDX46,COPE,RIPK1", "limit":1000}
data = {"ids": "ALDH2", "limit":1000}
endpoint = 'bigclam/g2g/query'
results = wrapper(endpoint, data)
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/bigclam/g2g/query?ids=ALDH2&limit=1000
# {
#   "status": "submitted",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/4fcb6912-cc42-4521-a1fd-526d810e936c?None
# {
#   "status": "complete",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/4fcb6912-cc42-4521-a1fd-526d810e936c000000000000.csv"
#   ],
#   "request_id": "4fcb6912-cc42-4521-a1fd-526d810e936c",
#   "size": "24.59 KB",
#   "processed_data": "1.68 GB",
#   "rows": 1000
# }
#   gene_label          F
# 0    SLC18A2  15.114880
# 1      VPS41  13.830312
# 2     PRDM12  11.892317
# 3    MRGPRX1  11.819508
# 4     TUBA1A  11.716667

# %% [markdown]
# ## Genes to Drugs
#
# Genomic aberrations in INPUT genes lead to sensitivity to OUTPUT drugs

# %%
data = {"ids": "TCOF1,DDX46,COPE,RIPK1"}
#data = {"ids": "EGFR,BRAF,KRAS"}
endpoint = 'bigclam/g2d/query'
results = wrapper(endpoint, data)
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/bigclam/g2d/query?ids=TCOF1%2CDDX46%2CCOPE%2CRIPK1
# {
#   "status": "submitted",
#   "request_id": "3b0d4cef-1197-49aa-aecf-459ead5b0c5e"
# }
# Sent: GET http://biggim.ncats.io/api/bigclam/status/3b0d4cef-1197-49aa-aecf-459ead5b0c5e?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "3b0d4cef-1197-49aa-aecf-459ead5b0c5e"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/3b0d4cef-1197-49aa-aecf-459ead5b0c5e?None
# {
#   "message": "Query job is running.",
#   "status": "running",
#   "request_id": "3b0d4cef-1197-49aa-aecf-459ead5b0c5e"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/bigclam/status/3b0d4cef-1197-49aa-aecf-459ead5b0c5e?None
# {
#   "status": "complete",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/3b0d4cef-1197-49aa-aecf-459ead5b0c5e000000000000.csv"
#   ],
#   "request_id": "3b0d4cef-1197-49aa-aecf-459ead5b0c5e",
#   "size": "5.57 KB",
#   "processed_data": "1.51 GB",
#   "rows": 100
# }
#    Drug_Rank  Drug_Score   Drug_Name          Drug_Target1  \
# 0          1    0.149727  BMS-708163           g-secretase
# 1          2    0.130008     TAK-715                  p38a
# 2          3    0.116224  Phenformin  AAPK1 (AMPK) agonist
# 3          4    0.096146    T0901317                   LXR
# 4          5    0.093796      EX-527                 SIRT1
#
#             Drug_Target2
# 0                  other
# 1  JNK and p38 signaling
# 2             metabolism
# 3                  other
# 4                  other
