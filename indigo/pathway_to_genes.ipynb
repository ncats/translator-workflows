# %%
import requests

# define query sent to the reasoner
query = {"query_type_id": "pathwayToGenes", "terms": {"pathway": "GO:0007049"}}

# send query
r = requests.post("https://indigo.ncats.io/reasoner/api/v0/query", json=query)
print(r.text)
# Out:
# {
#   "context": "translator_indigo_qa",
#   "datetime": "2018-10-02 11:40:22.364281",
#   "result_list": [
#     {
#       "result_graph": {
#         "edge_list": [
#           {
#             "attribute_list": [
#               {
#                 "name": "evidence_code",
#                 "value": "IEA"
#               },
#               {
#                 "name": "id",
#                 "value": 3252475
#               }
#             ],
#             "provided_by": "go",
#             "source_id": "545985",
#             "target_id": "585042",
#             "type": "PART_OF"
#           },
#           {
#             "attribute_list": [
#               {
#                 "name": "evidence_code",
#                 "value": "IEA"
#               },
#               {
#                 "name": "id",
#                 "value": 3248793
#               }
#             ],
#             "provided_by": "go",
#             "source_id": "567238",
#             "target_id": "585042",
# ...
