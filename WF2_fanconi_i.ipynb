# %%
from BioLink.biolink_client import BioLinkWrapper
import pandas as pd
from pprint import pprint
from collections import defaultdict
from mygene import MyGeneInfo
from GraphVisuals.graphviz_wrapper import PathGraph

# %% [markdown]
# # Workflow II Rare Disease Candidates

# %%
from Modules.Mod0_lookups import LookUp

# workflow input is a disease identifier
lu = LookUp()
# Out:
# Mod O DiseaseGeneLookup metadata:
# {'data_type': 'disease',
#  'input_type': {'complexity': 'single', 'id_type': ['MONDO', 'DO', 'OMIM']},
#  'limit': None,
#  'output_type': {'complexity': 'set', 'id_type': 'HGNC'},
#  'predicate': 'blm:gene associated with condition',
#  'source': 'Monarch Biolink',
#  'taxon': 'human'}

# %%
input_disease = 'MONDO:0019391' # Fanconi anemia  
input_object = {
    'input': input_disease,
    'parameters': {
        'taxon': 'human',
        'threshold': None,
    },
}

lu.load_input_object(input_object=input_object)
input_object = lu.input_object
# Out:
# {'description': 'Fanconi anemia (FA) is a hereditary DNA repair disorder '
#                 'characterized by progressive pancytopenia with bone marrow '
#                 'failure, variable congenital malformations and predisposition '
#                 'to develop hematological or solid tumors.',
#  'id': 'MONDO:0019391',
#  'label': 'Fanconi anemia'}

# %%
# start a list of final candidates from each module
results = list()

# define workflow modules
worklow_modules = [
    ('Mod1A', 'Mod1A Functional Similarity'),
    ('Mod1B', 'Mod1B Phenotype Similarity'),
    ('Mod1C', 'Mod1C Coexpression'),
    ('Mod1D', 'Mod1D Gene Chemical Interaction'),
    ('Mod1E', 'Mod1E Gene Interaction'),
    ('Mod3', 'Mod3 Candidate Merging')
]

# instantiate workflow graph
path_graph = PathGraph(input_curie=input_object['id'], input_label=input_object['label'])
path_graph.load_nodes(node_list=worklow_modules)

# %% [markdown]
# ## Disease Associated Genes

# %%
# get genes associated with disease from Biolink
disease_associated_genes = lu.disease_geneset_lookup()
# create list of gene curies for downstream module input
input_curie_set = disease_associated_genes['hit_id'].tolist()
# # show the 
disease_associated_genes
# Out:
#          input_id     input_label      hit_id hit_label             ncbi  \
# 0   MONDO:0019391  Fanconi anemia   HGNC:1100     BRCA1     NCBIGene:672
# 1   MONDO:0019391  Fanconi anemia   HGNC:1101     BRCA2     NCBIGene:675
# 2   MONDO:0019391  Fanconi anemia  HGNC:11892       TNF    NCBIGene:7124
# 3   MONDO:0019391  Fanconi anemia  HGNC:12829     XRCC2    NCBIGene:7516
# 4   MONDO:0019391  Fanconi anemia  HGNC:20473     BRIP1   NCBIGene:83990
# 5   MONDO:0019391  Fanconi anemia  HGNC:20748     FANCL   NCBIGene:55120
# 6   MONDO:0019391  Fanconi anemia  HGNC:23168     FANCM   NCBIGene:57697
# 7   MONDO:0019391  Fanconi anemia  HGNC:23845      SLX4   NCBIGene:84464
# 8   MONDO:0019391  Fanconi anemia  HGNC:25009     UBE2T   NCBIGene:29089
# 9   MONDO:0019391  Fanconi anemia  HGNC:25539     RFWD3   NCBIGene:55159
# 10  MONDO:0019391  Fanconi anemia  HGNC:25568     FANCI   NCBIGene:55215
# 11  MONDO:0019391  Fanconi anemia  HGNC:26144     PALB2   NCBIGene:79728
# 12  MONDO:0019391  Fanconi anemia  HGNC:28623  FANCD2OS  NCBIGene:115795
# 13  MONDO:0019391  Fanconi anemia   HGNC:3436     ERCC4    NCBIGene:2072
# 14  MONDO:0019391  Fanconi anemia   HGNC:3582     FANCA    NCBIGene:2175
# 15  MONDO:0019391  Fanconi anemia   HGNC:3583     FANCB    NCBIGene:2187
# 16  MONDO:0019391  Fanconi anemia   HGNC:3584     FANCC    NCBIGene:2176
# 17  MONDO:0019391  Fanconi anemia   HGNC:3585    FANCD2    NCBIGene:2177
# 18  MONDO:0019391  Fanconi anemia   HGNC:3586     FANCE    NCBIGene:2178
# 19  MONDO:0019391  Fanconi anemia   HGNC:3587     FANCF    NCBIGene:2188
# 20  MONDO:0019391  Fanconi anemia   HGNC:3588     FANCG    NCBIGene:2189
# 21  MONDO:0019391  Fanconi anemia   HGNC:6764    MAD2L2   NCBIGene:10459
# 22  MONDO:0019391  Fanconi anemia   HGNC:7532       MX1    NCBIGene:4599
# 23  MONDO:0019391  Fanconi anemia   HGNC:9817     RAD51    NCBIGene:5888
# 24  MONDO:0019391  Fanconi anemia   HGNC:9820    RAD51C    NCBIGene:5889
#
#                                  sources
# 0                                clinvar
# 1   orphane, omim, ctd, orphane, clinvar
# 2                                    ctd
# 3                     orphane, ctd, omim
# 4       ctd, orphane, omim, ctd, clinvar
# 5       ctd, orphane, ctd, omim, clinvar
# 6                           ctd, orphane
# 7       ctd, orphane, ctd, omim, clinvar
# 8            omim, ctd, clinvar, orphane
# 9                                orphane
# 10           orphane, ctd, omim, clinvar
# 11           omim, ctd, clinvar, orphane
# 12                               clinvar
# 13           orphane, ctd, omim, clinvar
# 14           ctd, omim, clinvar, orphane
# 15           omim, ctd, clinvar, orphane
# 16      ctd, orphane, omim, ctd, clinvar
# 17      ctd, omim, clinvar, ctd, orphane
# 18           orphane, omim, ctd, clinvar
# 19           ctd, omim, clinvar, orphane
# 20      ctd, orphane, omim, ctd, clinvar
# 21           omim, ctd, clinvar, orphane
# 22                                   ctd
# 23           ctd, omim, clinvar, orphane
# 24      omim, ctd, clinvar, ctd, orphane

# %%
## Get mouse orthologs from Monarch Initiative
from Modules.ortholog_traversal import OrthologTraversal
ot = OrthologTraversal()
mouse_orthologs = pd.DataFrame(ot.ortholog_set_by_taxid(gene_set=disease_associated_genes['hit_id'].tolist(), 
                                                        taxon_name='mouse'))
mouse_orthologs
# Out:
#          hit_id hit_label    input_id input_label    sources
# 0    MGI:104537     Brca1   HGNC:1100       BRCA1  [panther]
# 1    MGI:109337     Brca2   HGNC:1101       BRCA2  [panther]
# 2    MGI:104798       Tnf  HGNC:11892         TNF  [panther]
# 3   MGI:1927345     Xrcc2  HGNC:12829       XRCC2  [panther]
# 4   MGI:2442836     Brip1  HGNC:20473       BRIP1  [panther]
# 5   MGI:1914280     Fancl  HGNC:20748       FANCL  [panther]
# 6   MGI:2442306     Fancm  HGNC:23168       FANCM  [panther]
# 7    MGI:106299      Slx4  HGNC:23845        SLX4  [panther]
# 8   MGI:1914446     Ube2t  HGNC:25009       UBE2T  [panther]
# 9   MGI:2384584     Rfwd3  HGNC:25539       RFWD3  [panther]
# 10  MGI:2384790     Fanci  HGNC:25568       FANCI  [panther]
# 11  MGI:3040695     Palb2  HGNC:26144       PALB2  [panther]
# 12  MGI:1918229  Fancd2os  HGNC:28623    FANCD2OS  [panther]
# 13  MGI:1354163     Ercc4   HGNC:3436       ERCC4  [panther]
# 14  MGI:1341823     Fanca   HGNC:3582       FANCA  [panther]
# 15  MGI:2448558     Fancb   HGNC:3583       FANCB  [panther]
# 16    MGI:95480     Fancc   HGNC:3584       FANCC  [panther]
# 17  MGI:2448480    Fancd2   HGNC:3585      FANCD2  [panther]
# 18  MGI:1920025     Fance   HGNC:3586       FANCE  [panther]
# 19  MGI:3689889     Fancf   HGNC:3587       FANCF  [panther]
# 20  MGI:1926471     Fancg   HGNC:3588       FANCG  [panther]
# 21  MGI:1919140    Mad2l2   HGNC:6764      MAD2L2  [panther]
# 22    MGI:97243       Mx1   HGNC:7532         MX1  [panther]
# 23    MGI:97244       Mx2   HGNC:7532         MX1  [panther]
# 24    MGI:97890     Rad51   HGNC:9817       RAD51  [panther]
# 25  MGI:2150020    Rad51c   HGNC:9820      RAD51C  [panther]

# %% [markdown]
# # Mod1A Functional Similarity
# ## Find similar genes based on GO functional annotations using OntoBio Jaccard similarity

# %%
from Modules.Mod1A_functional_sim import FunctionalSimilarity

# %% [markdown]
# ## Mod1A_human

# %%
# Module specification
mod1a_input_object_human = {
    'input': input_curie_set,
    'parameters': {
        'taxon': 'human',
        'threshold': 0.65,  # jaccard index threshold
    },
}
    
func_sim_human = FunctionalSimilarity()
# Out:
# Mod1A Functional Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:macromolecular machine to biological process association',
#                'macromolecular machine to molecular activity association'],
#  'source': 'Monarch Biolink'}

# %%
func_sim_human.load_input_object(mod1a_input_object_human)
func_sim_human.load_gene_set()

# %%
func_sim_human.load_associations()

# %%
Mod1A_results_human = pd.DataFrame(func_sim_human.compute_similarity())
Mod1A_results_human = Mod1A_results_human[~Mod1A_results_human['hit_curie'].isin(input_curie_set)]
Mod1A_results_human
# Out:
#      hit_curie hit_name  hit_score input_curie input_name
# 6   HGNC:20193     HFM1   0.720000  HGNC:23168      FANCM
# 9   HGNC:20922    SLX1A   0.785235  HGNC:23845       SLX4
# 10  HGNC:19907   UBE2R2   0.661972  HGNC:25009      UBE2T
# 12  HGNC:21647   UBE2D4   0.718310  HGNC:25009      UBE2T
# 14  HGNC:25356    SPRTN   0.666667  HGNC:25568      FANCI
# 20        None   E9PQ18   0.750000   HGNC:3583      FANCB
# 21        None   M0R2N6   0.750000   HGNC:3583      FANCB
# 22  HGNC:26171  FAAP100   0.866667   HGNC:3583      FANCB
# 23  HGNC:31412     SWI5   0.675676   HGNC:3583      FANCB
# 24  HGNC:29641     MUM1   0.735294   HGNC:3583      FANCB
# 25  HGNC:25021    ASTE1   0.806452   HGNC:3583      FANCB
# 26  HGNC:21700    RAD9B   0.925926   HGNC:3583      FANCB
# 27        None   Q6ZNB5   0.750000   HGNC:3583      FANCB
# 28  HGNC:22223    EEPD1   0.800000   HGNC:3583      FANCB
# 29  HGNC:32961     EID3   0.703704   HGNC:3583      FANCB
# 31  HGNC:17008   TOPBP1   0.714286   HGNC:3583      FANCB
# 32  HGNC:28467   FAAP24   0.838710   HGNC:3583      FANCB
# 33  HGNC:27849     PAXX   0.694444   HGNC:3583      FANCB
# 36  HGNC:24994     INIP   0.862069   HGNC:3583      FANCB
# 40        None   E9PQ18   0.709677   HGNC:3586      FANCE
# 41        None   M0R2N6   0.709677   HGNC:3586      FANCE
# 42  HGNC:26171  FAAP100   0.766667   HGNC:3586      FANCE
# 43  HGNC:25021    ASTE1   0.709677   HGNC:3586      FANCE
# 44  HGNC:21700    RAD9B   0.814815   HGNC:3586      FANCE
# 45        None   Q6ZNB5   0.709677   HGNC:3586      FANCE
# 46  HGNC:22223    EEPD1   0.758621   HGNC:3586      FANCE
# 48  HGNC:28467   FAAP24   0.741935   HGNC:3586      FANCE
# 51  HGNC:24994     INIP   0.758621   HGNC:3586      FANCE
# 52  HGNC:26171  FAAP100   0.666667   HGNC:3587      FANCF
# 53  HGNC:29304    UVSSA   0.723404   HGNC:3587      FANCF
# 54  HGNC:21700    RAD9B   0.694444   HGNC:3587      FANCF
# 56  HGNC:16760   COPS7B   0.695652   HGNC:3587      FANCF
# 59  HGNC:24994     INIP   0.657895   HGNC:3587      FANCF
# 60  HGNC:16758   COPS7A   0.695652   HGNC:3587      FANCF
# 65   HGNC:9822   RAD51B   0.715190   HGNC:9820     RAD51C

# %% [markdown]
# ## Mod1A Mouse

# %%
# Module specification
mod1a_input_object_mouse = {
    'input': mouse_orthologs['hit_id'].tolist(),
    'parameters': {
        'taxon': 'mouse',
        'threshold': 0.65,  # jaccard index threshold
    },
}
    
func_sim_mouse = FunctionalSimilarity()
# Out:
# Mod1A Functional Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:macromolecular machine to biological process association',
#                'macromolecular machine to molecular activity association'],
#  'source': 'Monarch Biolink'}

# %%
func_sim_mouse.load_input_object(mod1a_input_object_mouse)
func_sim_mouse.load_gene_set() 
func_sim_mouse.load_associations()

# %%
Mod1A_results_mouse = pd.DataFrame(func_sim_mouse.compute_similarity())

# %%
### filter results and traverse back to human orthologs
Mod1A_results_mouse = Mod1A_results_mouse[~Mod1A_results_mouse['hit_name'].isin(mouse_orthologs['hit_label'])]
Mod1A_results_mouse = Mod1A_results_mouse.sort_values('hit_score', ascending=False)

def trim_mgi_prefix(curie):
    return curie[4:]

Mod1A_results_mouse['hit_id'] = Mod1A_results_mouse['hit_curie'].apply(trim_mgi_prefix)

def back2human(gene_curie):
    hits = ot.single_gene_ortholog(gene=gene_curie, taxon_name='human')
    return hits

human_hits = []
for term in Mod1A_results_mouse['hit_id'].tolist():
    human_hits = human_hits + back2human(gene_curie=term)
    
Mod1A_results_mouse_merged = pd.merge(Mod1A_results_mouse, pd.DataFrame(human_hits), how='outer', left_on='hit_id', right_on='gene_id')
Mod1A_results_mouse_traversed = pd.merge(mouse_orthologs, Mod1A_results_mouse_merged, left_on='hit_id', right_on='input_curie')
Mod1A_results_mouse_final = Mod1A_results_mouse_traversed[['input_id', 'input_label', 'gene_id', 'hit_name', 'hit_score', 'orth_id', 'orth_label']]

# %%
Mod1A_results_mouse_final
# Out:
#      input_id input_label      gene_id hit_name  hit_score     orth_id  \
# 0  HGNC:23168       FANCM   MGI:894324    Cenpx   0.651786  HGNC:11422
# 1  HGNC:25009       UBE2T  MGI:1920568  Ube2d2b   0.685714  HGNC:12475
# 2  HGNC:25009       UBE2T  MGI:1930715  Ube2d2a   0.671429  HGNC:12475
# 3  HGNC:25009       UBE2T  MGI:1914049    Ube2w   0.670213  HGNC:25616
# 4  HGNC:25009       UBE2T  MGI:1914865   Ube2r2   0.657143  HGNC:19907
# 5   HGNC:7532         MX1          NaN    Tgtp1   0.727273         NaN
# 6   HGNC:7532         MX1   MGI:109493   Rab33a   0.697674   HGNC:9773
# 7   HGNC:7532         MX1   MGI:109493   Rab33a   0.697674   HGNC:9768
#
#   orth_label
# 0      CENPX
# 1     UBE2D2
# 2     UBE2D2
# 3      UBE2W
# 4     UBE2R2
# 5        NaN
# 6     RAB33A
# 7      RAB28

# %% [markdown]
# # MOD1B Phenotype Similarity
# ## Find similar genes based on OwlSim calculated Phenotype Similarity

# %% [markdown]
# ## Mod1B Human

# %%
from Modules.Mod1B1_phenotype_similarity import PhenotypeSimilarity

# %%
# Module specification
mod1b_input_object_human = {
    'input': input_curie_set,
     'parameters': {
        'taxon': 'human',
        'threshold': .65,
    },
}


pheno_sim_human = PhenotypeSimilarity()
# Out:
# Mod1B Phenotype Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:has phenotype'],
#  'source': 'Monarch Biolink'}

# %%
pheno_sim_human.load_input_object(mod1b_input_object_human)
pheno_sim_human.load_gene_set()
pheno_sim_human.load_associations()

# %%
# compute phenotype similarity
Mod1B_results = pd.DataFrame(pheno_sim_human.compute_similarity())
Mod1B_results = Mod1B_results[~Mod1B_results['hit_curie'].isin(input_curie_set)].sort_values('hit_score', ascending=False)

# %%
Mod1B_results
# Out:
#     hit_curie hit_name  hit_score input_curie input_name
# 18  HGNC:6709      LTA   0.967532  HGNC:11892        TNF

# %%
Mod1B_results.shape
# Out:
# (1, 5)

# %% [markdown]
# ## Mod1B Mouse

# %%
# Module specification
mod1b_input_object_mouse = {
    'input': mouse_orthologs['hit_id'].tolist(),
     'parameters': {
        'taxon': 'mouse',
        'threshold': .65,
    },
}


pheno_sim_mouse = PhenotypeSimilarity()
# Out:
# Mod1B Phenotype Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:has phenotype'],
#  'source': 'Monarch Biolink'}

# %%
pheno_sim_mouse.load_input_object(mod1b_input_object_mouse)
pheno_sim_mouse.load_gene_set()
pheno_sim_mouse.load_associations()

# %%
Mod1B_results_mouse = pd.DataFrame(pheno_sim_mouse.compute_similarity())
Mod1B_results_mouse = Mod1B_results_mouse[~Mod1B_results_mouse['hit_name'].isin(
    mouse_orthologs['hit_label'].tolist())].sort_values('hit_score', ascending=False)

# %%
Mod1B_results_mouse.shape
# Out:
# (226, 5)

# %%
def number_of_annotations(mgi_curie):
    return pheno_sim_mouse.associations.annotations(mgi_curie)

# %%
Mod1B_results_mouse['hit_annotations'] = Mod1B_results_mouse['hit_curie'].apply(number_of_annotations)
Mod1B_results_mouse['input_annotations'] = Mod1B_results_mouse['input_curie'].apply(number_of_annotations)

# %%
Mod1B_results_mouse
# Out:
#        hit_curie       hit_name  hit_score  input_curie input_name  \
# 84    MGI:107848         Tubb4a   1.000000  MGI:2384790       None
# 41   MGI:1925584          Cdk19   1.000000  MGI:2384790       None
# 43   MGI:1933134          Tusc3   1.000000  MGI:2384790       None
# 151  MGI:2449143          Gbgt1   1.000000  MGI:2384790       None
# 81   MGI:1921442         Arpc5l   1.000000  MGI:2384790       None
# 149  MGI:2681306       Tas2r138   1.000000  MGI:2384790       None
# 146  MGI:1924311  4931406P16Rik   1.000000  MGI:2384790       None
# 48   MGI:1922896          Rai14   1.000000  MGI:2384790       None
# 49   MGI:2385884          Ddx27   1.000000  MGI:2384790       None
# 75   MGI:1923953           Cpb1   1.000000  MGI:2384790       None
# 144  MGI:3608413         Rhbdl2   1.000000  MGI:2384790       None
# 91   MGI:1913416        S100a14   1.000000  MGI:2384790       None
# 141  MGI:1918724         Ppp6r2   1.000000  MGI:2384790       None
# 54   MGI:1921703         Cfap53   1.000000  MGI:2384790       None
# 55   MGI:1919115         Fbxo30   1.000000  MGI:2384790       None
# 133  MGI:1891307           Ubn1   1.000000  MGI:2384790       None
# 98   MGI:2137642          Snx18   1.000000  MGI:2384790       None
# 127  MGI:2384841          Chpt1   1.000000  MGI:2384790       None
# 59   MGI:2444946          Tmco3   1.000000  MGI:2384790       None
# 126  MGI:1913860           Abi3   1.000000  MGI:2384790       None
# 10   MGI:1196464         Adgre4   1.000000  MGI:2384790       None
# 122  MGI:1918990        Nectin4   1.000000  MGI:2384790       None
# 63   MGI:3587025          Cdkl4   1.000000  MGI:2384790       None
# 64   MGI:3513546          Spef1   1.000000  MGI:2384790       None
# 65   MGI:2684957          Rexo4   1.000000  MGI:2384790       None
# 66   MGI:2443143           Wdr3   1.000000  MGI:2384790       None
# 119  MGI:1922567         Parpbp   1.000000  MGI:2384790       None
# 118  MGI:1098568        Tmem222   1.000000  MGI:2384790       None
# 109  MGI:1924877         Efcab6   1.000000  MGI:2384790       None
# 157  MGI:2384301        Mettl22   1.000000  MGI:2384790       None
# ..           ...            ...        ...          ...        ...
# 147  MGI:1914318        Dynlrb1   0.666667  MGI:2384790       None
# 148  MGI:3027876          l1Rk7   0.666667  MGI:2384790       None
# 46   MGI:1914868       Aasdhppt   0.666667  MGI:2384790       None
# 152  MGI:1346006           Ptpa   0.666667  MGI:2384790       None
# 154  MGI:3630308         Rsph3b   0.666667  MGI:2384790       None
# 124  MGI:1919865          Anks3   0.666667  MGI:2384790       None
# 155  MGI:1309480           Rtf1   0.666667  MGI:2384790       None
# 156  MGI:1923531        Tax1bp3   0.666667  MGI:2384790       None
# 42   MGI:2442308          Arl15   0.666667  MGI:2384790       None
# 158  MGI:1891840          Ncbp1   0.666667  MGI:2384790       None
# 160  MGI:1915082          Brix1   0.666667  MGI:2384790       None
# 161  MGI:1202305          Vps72   0.666667  MGI:2384790       None
# 143  MGI:1913415          Bccip   0.666667  MGI:2384790       None
# 52   MGI:1351869           Pdxk   0.666667  MGI:2384790       None
# 140  MGI:1926232          Srsf7   0.666667  MGI:2384790       None
# 139  MGI:1926465         Hnrnpm   0.666667  MGI:2384790       None
# 138  MGI:2442040          G3bp2   0.666667  MGI:2384790       None
# 137  MGI:2442510          Dars2   0.666667  MGI:2384790       None
# 136  MGI:1914667          Ears2   0.666667  MGI:2384790       None
# 135  MGI:1916457         Srsf11   0.666667  MGI:2384790       None
# 134  MGI:1914243        Smarcd3   0.666667  MGI:2384790       None
# 56   MGI:3033917         l4Jus5   0.666667  MGI:2384790       None
# 132  MGI:1913284         Psmd14   0.666667  MGI:2384790       None
# 131  MGI:3033928        l4Jus16   0.666667  MGI:2384790       None
# 57   MGI:2149543          Ubap1   0.666667  MGI:2384790       None
# 129  MGI:1261890         Fbxo28   0.666667  MGI:2384790       None
# 128  MGI:1914542           Pigc   0.666667  MGI:2384790       None
# 60   MGI:1861452           Pigo   0.666667  MGI:2384790       None
# 125  MGI:1913590         Psenen   0.666667  MGI:2384790       None
# 235  MGI:2384576           Tti2   0.666667  MGI:2384790       None
#
#     hit_annotations input_annotations
# 84     [MP:0011110]      [MP:0011110]
# 41     [MP:0011110]      [MP:0011110]
# 43     [MP:0011110]      [MP:0011110]
# 151    [MP:0011110]      [MP:0011110]
# 81     [MP:0011110]      [MP:0011110]
# 149    [MP:0011110]      [MP:0011110]
# 146    [MP:0011110]      [MP:0011110]
# 48     [MP:0011110]      [MP:0011110]
# 49     [MP:0011110]      [MP:0011110]
# 75     [MP:0011110]      [MP:0011110]
# 144    [MP:0011110]      [MP:0011110]
# 91     [MP:0011110]      [MP:0011110]
# 141    [MP:0011110]      [MP:0011110]
# 54     [MP:0011110]      [MP:0011110]
# 55     [MP:0011110]      [MP:0011110]
# 133    [MP:0011110]      [MP:0011110]
# 98     [MP:0011110]      [MP:0011110]
# 127    [MP:0011110]      [MP:0011110]
# 59     [MP:0011110]      [MP:0011110]
# 126    [MP:0011110]      [MP:0011110]
# 10     [MP:0011110]      [MP:0011110]
# 122    [MP:0011110]      [MP:0011110]
# 63     [MP:0011110]      [MP:0011110]
# 64     [MP:0011110]      [MP:0011110]
# 65     [MP:0011110]      [MP:0011110]
# 66     [MP:0011110]      [MP:0011110]
# 119    [MP:0011110]      [MP:0011110]
# 118    [MP:0011110]      [MP:0011110]
# 109    [MP:0011110]      [MP:0011110]
# 157    [MP:0011110]      [MP:0011110]
# ..              ...               ...
# 147    [MP:0011100]      [MP:0011110]
# 148    [MP:0011100]      [MP:0011110]
# 46     [MP:0011100]      [MP:0011110]
# 152    [MP:0011100]      [MP:0011110]
# 154    [MP:0011100]      [MP:0011110]
# 124    [MP:0011100]      [MP:0011110]
# 155    [MP:0011100]      [MP:0011110]
# 156    [MP:0011100]      [MP:0011110]
# 42     [MP:0011100]      [MP:0011110]
# 158    [MP:0011100]      [MP:0011110]
# 160    [MP:0011100]      [MP:0011110]
# 161    [MP:0011100]      [MP:0011110]
# 143    [MP:0011100]      [MP:0011110]
# 52     [MP:0011100]      [MP:0011110]
# 140    [MP:0011100]      [MP:0011110]
# 139    [MP:0011100]      [MP:0011110]
# 138    [MP:0011100]      [MP:0011110]
# 137    [MP:0011100]      [MP:0011110]
# 136    [MP:0011100]      [MP:0011110]
# 135    [MP:0011100]      [MP:0011110]
# 134    [MP:0011100]      [MP:0011110]
# 56     [MP:0011100]      [MP:0011110]
# 132    [MP:0011100]      [MP:0011110]
# 131    [MP:0011100]      [MP:0011110]
# 57     [MP:0011100]      [MP:0011110]
# 129    [MP:0011100]      [MP:0011110]
# 128    [MP:0011100]      [MP:0011110]
# 60     [MP:0011100]      [MP:0011110]
# 125    [MP:0011100]      [MP:0011110]
# 235    [MP:0011100]      [MP:0011110]
#
# [226 rows x 7 columns]

# %%
human_phits = []
for term in Mod1B_results_mouse['hit_curie'].tolist():
    human_phits = human_phits + back2human(gene_curie=term)
    
Mod1B_results_mouse_merged = pd.merge(Mod1B_results_mouse, pd.DataFrame(human_phits), how='outer', left_on='hit_curie', right_on='gene_id')
Mod1B_results_mouse_traversed = pd.merge(mouse_orthologs, Mod1B_results_mouse_merged, left_on='hit_id', right_on='input_curie')
Mod1B_results_mouse_final = Mod1B_results_mouse_traversed[['input_id', 'input_label', 'gene_id', 'hit_name', 'hit_score', 'orth_id', 'orth_label']]

# %%
Mod1B_results_mouse_final
# Out:
#        input_id input_label      gene_id       hit_name  hit_score  \
# 0    HGNC:25568       FANCI   MGI:107848         Tubb4a   1.000000
# 1    HGNC:25568       FANCI  MGI:1925584          Cdk19   1.000000
# 2    HGNC:25568       FANCI  MGI:1933134          Tusc3   1.000000
# 3    HGNC:25568       FANCI  MGI:2449143          Gbgt1   1.000000
# 4    HGNC:25568       FANCI  MGI:1921442         Arpc5l   1.000000
# 5    HGNC:25568       FANCI  MGI:2681306       Tas2r138   1.000000
# 6    HGNC:25568       FANCI  MGI:1924311  4931406P16Rik   1.000000
# 7    HGNC:25568       FANCI  MGI:1922896          Rai14   1.000000
# 8    HGNC:25568       FANCI  MGI:2385884          Ddx27   1.000000
# 9    HGNC:25568       FANCI  MGI:1923953           Cpb1   1.000000
# 10   HGNC:25568       FANCI  MGI:3608413         Rhbdl2   1.000000
# 11   HGNC:25568       FANCI  MGI:1913416        S100a14   1.000000
# 12   HGNC:25568       FANCI  MGI:1918724         Ppp6r2   1.000000
# 13   HGNC:25568       FANCI  MGI:1921703         Cfap53   1.000000
# 14   HGNC:25568       FANCI  MGI:1919115         Fbxo30   1.000000
# 15   HGNC:25568       FANCI  MGI:1891307           Ubn1   1.000000
# 16   HGNC:25568       FANCI  MGI:2137642          Snx18   1.000000
# 17   HGNC:25568       FANCI  MGI:2384841          Chpt1   1.000000
# 18   HGNC:25568       FANCI  MGI:2444946          Tmco3   1.000000
# 19   HGNC:25568       FANCI  MGI:1913860           Abi3   1.000000
# 20   HGNC:25568       FANCI  MGI:1196464         Adgre4   1.000000
# 21   HGNC:25568       FANCI  MGI:1918990        Nectin4   1.000000
# 22   HGNC:25568       FANCI  MGI:3587025          Cdkl4   1.000000
# 23   HGNC:25568       FANCI  MGI:3513546          Spef1   1.000000
# 24   HGNC:25568       FANCI  MGI:2684957          Rexo4   1.000000
# 25   HGNC:25568       FANCI  MGI:2443143           Wdr3   1.000000
# 26   HGNC:25568       FANCI  MGI:1922567         Parpbp   1.000000
# 27   HGNC:25568       FANCI  MGI:1098568        Tmem222   1.000000
# 28   HGNC:25568       FANCI  MGI:1924877         Efcab6   1.000000
# 29   HGNC:25568       FANCI  MGI:2384301        Mettl22   1.000000
# ..          ...         ...          ...            ...        ...
# 205  HGNC:25568       FANCI  MGI:1914318        Dynlrb1   0.666667
# 206  HGNC:25568       FANCI          NaN          l1Rk7   0.666667
# 207  HGNC:25568       FANCI  MGI:1914868       Aasdhppt   0.666667
# 208  HGNC:25568       FANCI  MGI:1346006           Ptpa   0.666667
# 209  HGNC:25568       FANCI  MGI:3630308         Rsph3b   0.666667
# 210  HGNC:25568       FANCI  MGI:1919865          Anks3   0.666667
# 211  HGNC:25568       FANCI  MGI:1309480           Rtf1   0.666667
# 212  HGNC:25568       FANCI  MGI:1923531        Tax1bp3   0.666667
# 213  HGNC:25568       FANCI  MGI:2442308          Arl15   0.666667
# 214  HGNC:25568       FANCI  MGI:1891840          Ncbp1   0.666667
# 215  HGNC:25568       FANCI  MGI:1915082          Brix1   0.666667
# 216  HGNC:25568       FANCI  MGI:1202305          Vps72   0.666667
# 217  HGNC:25568       FANCI  MGI:1913415          Bccip   0.666667
# 218  HGNC:25568       FANCI  MGI:1351869           Pdxk   0.666667
# 219  HGNC:25568       FANCI  MGI:1926232          Srsf7   0.666667
# 220  HGNC:25568       FANCI  MGI:1926465         Hnrnpm   0.666667
# 221  HGNC:25568       FANCI  MGI:2442040          G3bp2   0.666667
# 222  HGNC:25568       FANCI  MGI:2442510          Dars2   0.666667
# 223  HGNC:25568       FANCI  MGI:1914667          Ears2   0.666667
# 224  HGNC:25568       FANCI  MGI:1916457         Srsf11   0.666667
# 225  HGNC:25568       FANCI  MGI:1914243        Smarcd3   0.666667
# 226  HGNC:25568       FANCI          NaN         l4Jus5   0.666667
# 227  HGNC:25568       FANCI  MGI:1913284         Psmd14   0.666667
# 228  HGNC:25568       FANCI          NaN        l4Jus16   0.666667
# 229  HGNC:25568       FANCI  MGI:2149543          Ubap1   0.666667
# 230  HGNC:25568       FANCI  MGI:1261890         Fbxo28   0.666667
# 231  HGNC:25568       FANCI  MGI:1914542           Pigc   0.666667
# 232  HGNC:25568       FANCI  MGI:1861452           Pigo   0.666667
# 233  HGNC:25568       FANCI  MGI:1913590         Psenen   0.666667
# 234  HGNC:25568       FANCI  MGI:2384576           Tti2   0.666667
#
#         orth_id orth_label
# 0    HGNC:20774     TUBB4A
# 1    HGNC:19338      CDK19
# 2    HGNC:30242      TUSC3
# 3    HGNC:20460      GBGT1
# 4    HGNC:23366     ARPC5L
# 5     HGNC:9584    TAS2R38
# 6    HGNC:29016   KIAA0355
# 7    HGNC:14873      RAI14
# 8    HGNC:15837      DDX27
# 9     HGNC:2299       CPB1
# 10   HGNC:16083     RHBDL2
# 11   HGNC:18901    S100A14
# 12   HGNC:19253     PPP6R2
# 13   HGNC:26530     CFAP53
# 14   HGNC:15600     FBXO30
# 15   HGNC:12506       UBN1
# 16   HGNC:19245      SNX18
# 17   HGNC:17852      CHPT1
# 18   HGNC:20329      TMCO3
# 19   HGNC:29859       ABI3
# 20   HGNC:19240    ADGRE4P
# 21   HGNC:19688    NECTIN4
# 22   HGNC:19287      CDKL4
# 23   HGNC:15874      SPEF1
# 24   HGNC:12820      REXO4
# 25   HGNC:12755       WDR3
# 26   HGNC:26074     PARPBP
# 27   HGNC:25363    TMEM222
# 28   HGNC:24204     EFCAB6
# 29   HGNC:28368    METTL22
# ..          ...        ...
# 205  HGNC:15468    DYNLRB1
# 206         NaN        NaN
# 207  HGNC:14235   AASDHPPT
# 208   HGNC:9308       PTPA
# 209  HGNC:21054      RSPH3
# 210  HGNC:29422      ANKS3
# 211  HGNC:28996       RTF1
# 212  HGNC:30684    TAX1BP3
# 213  HGNC:25945      ARL15
# 214   HGNC:7658      NCBP1
# 215  HGNC:24170      BRIX1
# 216  HGNC:11644      VPS72
# 217    HGNC:978      BCCIP
# 218   HGNC:8819       PDXK
# 219  HGNC:10789      SRSF7
# 220   HGNC:5046     HNRNPM
# 221  HGNC:30291      G3BP2
# 222  HGNC:25538      DARS2
# 223  HGNC:29419      EARS2
# 224  HGNC:10782     SRSF11
# 225  HGNC:11108    SMARCD3
# 226         NaN        NaN
# 227  HGNC:16889     PSMD14
# 228         NaN        NaN
# 229  HGNC:12461      UBAP1
# 230  HGNC:29046     FBXO28
# 231   HGNC:8960       PIGC
# 232  HGNC:23215       PIGO
# 233  HGNC:30100     PSENEN
# 234  HGNC:26262       TTI2
#
# [235 rows x 7 columns]
