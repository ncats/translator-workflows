# %%
from pprint import pprint
import os
import sys
import pandas as pd
from BioLink.biolink_client import BioLinkWrapper

# %%
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# MVP1 workflow
input_disease = 'MONDO:0019391'  # Fanconi Anemia

blw = BioLinkWrapper()

# get fa related genes from BioLink
fa_gene_associations = blw.disease2genes(input_disease)
fa_gene_curies = fa_gene_associations['objects']

# %% [markdown]
# # Mod1A Human Functional Similarity analysis

# %%
from Modules.Mod1A_functional_sim import FunctionalSim

# %%
# human analysis
fsim = FunctionalSim()
fsim.load_gene_set(gene_set=fa_gene_curies)
fsim.load_associations(group='human')
fsim.gene_set
human_fsim_genes = fsim.compute_similarity()
human_fsim_genes_df = pd.DataFrame(data=human_fsim_genes)
human_fsim_genes_df
# Out:
# loading ontology -- this can take a while
#    input_gene input_gene_curie sim_gene_name     sim_hit_curie  sim_score
# 0        SLX4       HGNC:23845         SLX1A  UniProtKB:Q9BQ83   0.760638
# 1       FANCA        HGNC:3582        FANCD2  UniProtKB:Q9BXW9   0.700461
# 2       FANCB        HGNC:3583       FAAP100  UniProtKB:Q0VG06   0.810345
# 3       FANCB        HGNC:3583        FAAP24  UniProtKB:Q9BTP7   0.903846
# 4       FANCB        HGNC:3583         FANCE  UniProtKB:Q9HB96   0.957447
# 5       FANCB        HGNC:3583          INIP  UniProtKB:Q9NRY2   0.862745
# 6      FANCD2        HGNC:3585         FANCA  UniProtKB:O15360   0.700461
# 7       FANCE        HGNC:3586       FAAP100  UniProtKB:Q0VG06   0.775862
# 8       FANCE        HGNC:3586         FANCB  UniProtKB:Q8NB91   0.957447
# 9       FANCE        HGNC:3586        FAAP24  UniProtKB:Q9BTP7   0.865385
# 10      FANCE        HGNC:3586         FANCF  UniProtKB:Q9NPI8   0.957447
# 11      FANCE        HGNC:3586          INIP  UniProtKB:Q9NRY2   0.823529
# 12      FANCF        HGNC:3587       FAAP100  UniProtKB:Q0VG06   0.810345
# 13      FANCF        HGNC:3587        FAAP24  UniProtKB:Q9BTP7   0.903846
# 14      FANCF        HGNC:3587         FANCE  UniProtKB:Q9HB96   0.957447
# 15      FANCF        HGNC:3587          INIP  UniProtKB:Q9NRY2   0.862745

# %% [markdown]
# # Mod1B Phenotype Similarity Analysis

# %%
from Modules.Mod1B_phenotype_similarity import PhenotypeSim

# get fa related phenotypes from Biolink
fa_disease_associations = blw.disease2phenotypes(disease_curie=input_disease)
fa_phenotype_curies = fa_disease_associations['objects']

# %%
fa_phenotype_curies
# Out:
# ['HP:0000010',
#  'HP:0000027',
#  'HP:0000028',
#  'HP:0000047',
#  'HP:0000054',
#  'HP:0000072',
#  'HP:0000077',
#  'HP:0000081',
#  'HP:0000083',
#  'HP:0000085',
#  'HP:0000086',
#  'HP:0000089',
#  'HP:0000104',
#  'HP:0000107',
#  'HP:0000125',
#  'HP:0000126',
#  'HP:0000135',
#  'HP:0000164',
#  'HP:0000175',
#  'HP:0000218',
#  'HP:0000238',
#  'HP:0000252',
#  'HP:0000268',
#  'HP:0000286',
#  'HP:0000297',
#  'HP:0000316',
#  'HP:0000324',
#  'HP:0000340',
#  'HP:0000347',
#  'HP:0000365',
#  'HP:0000369',
#  'HP:0000414',
#  'HP:0000431',
#  'HP:0000453',
#  'HP:0000463',
#  'HP:0000470',
#  'HP:0000483',
#  'HP:0000486',
#  'HP:0000505',
#  'HP:0000508',
#  'HP:0000518',
#  'HP:0000520',
#  'HP:0000568',
#  'HP:0000581',
#  'HP:0000582',
#  'HP:0000601',
#  'HP:0000639',
#  'HP:0000789',
#  'HP:0000813',
#  'HP:0000815',
#  'HP:0000824',
#  'HP:0000864',
#  'HP:0000953',
#  'HP:0000957',
#  'HP:0000978',
#  'HP:0001000',
#  'HP:0001009',
#  'HP:0001017',
#  'HP:0001045',
#  'HP:0001053',
#  'HP:0001172',
#  'HP:0001199',
#  'HP:0001249',
#  'HP:0001251',
#  'HP:0001263',
#  'HP:0001347',
#  'HP:0001392',
#  'HP:0001402',
#  'HP:0001508',
#  'HP:0001510',
#  'HP:0001511',
#  'HP:0001518',
#  'HP:0001537',
#  'HP:0001562',
#  'HP:0001627',
#  'HP:0001629',
#  'HP:0001631',
#  'HP:0001636',
#  'HP:0001639',
#  'HP:0001643',
#  'HP:0001646',
#  'HP:0001679',
#  'HP:0001763',
#  'HP:0001770',
#  'HP:0001824',
#  'HP:0001873',
#  'HP:0001875',
#  'HP:0001876',
#  'HP:0001878',
#  'HP:0001882',
#  'HP:0001895',
#  'HP:0001896',
#  'HP:0001900',
#  'HP:0001903',
#  'HP:0001905',
#  'HP:0001908',
#  'HP:0001909',
#  'HP:0001915',
#  'HP:0001972',
#  'HP:0001973',
#  'HP:0001999',
#  'HP:0002007',
#  'HP:0002023',
#  'HP:0002032',
#  'HP:0002101',
#  'HP:0002119',
#  'HP:0002245',
#  'HP:0002251',
#  'HP:0002414',
#  'HP:0002488',
#  'HP:0002575',
#  'HP:0002650',
#  'HP:0002667',
#  'HP:0002721',
#  'HP:0002823',
#  'HP:0002827',
#  'HP:0002860',
#  'HP:0002863',
#  'HP:0002885',
#  'HP:0002984',
#  'HP:0003002',
#  'HP:0003006',
#  'HP:0003022',
#  'HP:0003125',
#  'HP:0003213',
#  'HP:0003214',
#  'HP:0003220',
#  'HP:0003221',
#  'HP:0003241',
#  'HP:0003254',
#  'HP:0003468',
#  'HP:0003774',
#  'HP:0003974',
#  'HP:0004209',
#  'HP:0004322',
#  'HP:0004349',
#  'HP:0004377',
#  'HP:0004430',
#  'HP:0004431',
#  'HP:0004808',
#  'HP:0004810',
#  'HP:0004820',
#  'HP:0004859',
#  'HP:0005280',
#  'HP:0005344',
#  'HP:0005505',
#  'HP:0005510',
#  'HP:0005522',
#  'HP:0005528',
#  'HP:0005560',
#  'HP:0005912',
#  'HP:0006101',
#  'HP:0006254',
#  'HP:0006265',
#  'HP:0006501',
#  'HP:0006721',
#  'HP:0006727',
#  'HP:0006824',
#  'HP:0006872',
#  'HP:0007354',
#  'HP:0007400',
#  'HP:0007565',
#  'HP:0007874',
#  'HP:0008053',
#  'HP:0008064',
#  'HP:0008551',
#  'HP:0008572',
#  'HP:0008678',
#  'HP:0009777',
#  'HP:0009778',
#  'HP:0009942',
#  'HP:0009943',
#  'HP:0010293',
#  'HP:0010469',
#  'HP:0010650',
#  'HP:0010972',
#  'HP:0011018',
#  'HP:0011133',
#  'HP:0011835',
#  'HP:0012041',
#  'HP:0012210',
#  'HP:0012745',
#  'HP:0025023',
#  'HP:0030680',
#  'HP:0040012',
#  'HP:0100026',
#  'HP:0100542',
#  'HP:0100587',
#  'HP:0100608',
#  'HP:0100615',
#  'HP:0100760',
#  'HP:0100806',
#  'HP:0100867']

# %%
phenosim = PhenotypeSim(phenotype_set=fa_phenotype_curies)
phenosim_disease_associations = phenosim.phenotype_simsearch(return_type='disease')

# %%
phenosim_genes = []
for disease in phenosim_disease_associations['data']:
    disease_genes = blw.disease2genes(disease_curie=disease['matchId'])
    disease['genes'] = disease_genes['objects']
    phenosim_genes.append(disease)
phenosim_genes_df = pd.DataFrame(data=phenosim_genes)

# %%
phenosim_genes_df
# Out:
#                                                 genes         matchId  \
# 0   [HGNC:1100, HGNC:1101, HGNC:11892, HGNC:12829,...      DOID:13636
# 1                              [HGNC:1100, HGNC:3582]     OMIM:227650
# 2                                         [HGNC:3584]     OMIM:227645
# 3                             [HGNC:28623, HGNC:3585]     OMIM:227646
# 4                                         [HGNC:3586]     OMIM:600901
# 5                                                  []     OMIM:606895
# 6      [HGNC:16466, HGNC:30497, HGNC:3811, HGNC:4319]     OMIM:200990
# 7   [HGNC:10301, HGNC:10306, HGNC:10310, HGNC:1032...      DOID:12449
# 8                                        [HGNC:25009]     OMIM:616435
# 9                                        [HGNC:27230]     OMIM:268300
# 10                                        [HGNC:3749]     OMIM:147791
# 11  [HGNC:10848, HGNC:12926, HGNC:13243, HGNC:1583...       DOID:1148
# 12                                        [HGNC:2860]     OMIM:270400
# 13                                        [HGNC:1101]     OMIM:605724
# 14                                        [HGNC:1149]     OMIM:257300
# 15  [HGNC:10017, HGNC:1014, HGNC:10381, HGNC:10388...       DOID:1240
# 16                           [HGNC:10727, HGNC:20626]     OMIM:214800
# 17                                       [HGNC:26144]     OMIM:610832
# 18  [HGNC:10500, HGNC:10937, HGNC:11179, HGNC:1269...     OMIM:190685
# 19                            [HGNC:1058, HGNC:12572]     OMIM:210900
# 20                           [HGNC:10848, HGNC:13243]     OMIM:174500
# 21                                       [HGNC:23845]     OMIM:613951
# 22                           [HGNC:18704, HGNC:20893]    Orphanet:568
# 23  [HGNC:12744, HGNC:2586, HGNC:2903, HGNC:3327, ...     OMIM:194050
# 24  [HGNC:10768, HGNC:10938, HGNC:11180, HGNC:1550...       DOID:8955
# 25                                        [HGNC:9949]     OMIM:268400
# 26  [HGNC:10449, HGNC:10705, HGNC:11592, HGNC:1231...    Orphanet:567
# 27  [HGNC:10301, HGNC:10306, HGNC:10310, HGNC:1032...       DOID:1339
# 28                                       [HGNC:20748]     OMIM:614083
# 29                             [HGNC:28519, HGNC:795]     OMIM:208900
# 30  [HGNC:10848, HGNC:13243, HGNC:35126, HGNC:3600...      DOID:11193
# 31  [HGNC:12814, HGNC:12816, HGNC:2718, HGNC:3434,...    DOID:0050427
# 32                                       [HGNC:15924]     OMIM:607323
# 33                                                 []     OMIM:164210
# 34  [HGNC:10527, HGNC:11100, HGNC:11110, HGNC:1163...     OMIM:113970
# 35                                       [HGNC:20473]     OMIM:609054
# 36  [HGNC:10896, HGNC:14000, HGNC:4084, HGNC:6229,...     OMIM:607872
# 37  [HGNC:10301, HGNC:10306, HGNC:10310, HGNC:1032...       DOID:1340
# 38                                                 []     OMIM:264480
# 39                                                 []  Orphanet:59315
# 40                                                 []    MESH:D004480
# 41                                                 []   Orphanet:3082
# 42  [HGNC:12874, HGNC:1753, HGNC:20038, HGNC:27963...     OMIM:192350
# 43  [HGNC:11164, HGNC:1190, HGNC:12910, HGNC:13542...     OMIM:176270
# 44                                       [HGNC:10402]     OMIM:105650
# 45  [HGNC:14281, HGNC:3688, HGNC:6024, HGNC:6190, ...     OMIM:247640
# 46  [HGNC:19400, HGNC:3433, HGNC:3434, HGNC:3436, ...       DOID:2962
# 47                                       [HGNC:28434]     OMIM:300707
# 48  [HGNC:1232, HGNC:12687, HGNC:25355, HGNC:25941...       DOID:8432
# 49                            [HGNC:12851, HGNC:8574]     OMIM:247200
# 50                             [HGNC:2348, HGNC:3373]       DOID:1933
# 51                                                 []     OMIM:129900
# 52                                        [HGNC:9949]     OMIM:218600
# 53                            [HGNC:30650, HGNC:9865]     OMIM:601186
# 54                                                 []    MESH:D004392
# 55                [HGNC:12872, HGNC:20393, HGNC:3800]     OMIM:220200
# 56                                                 []  Orphanet:99776
#
#                                            matchLabel  percentageScore  rank  \
# 0                                      Fanconi anemia             7719    12
# 1             Fanconi Anemia, Complementation Group a             5328    16
# 2             Fanconi anemia, complementation group C             5328    16
# 3            Fanconi Anemia, Complementation Group D2             5328    16
# 4             Fanconi Anemia, Complementation Group E             5328    16
# 5   Symphalangism, Distal, With Microdontia, Denta...             5094    19
# 6                               acrocallosal syndrome             5042    21
# 7                                     aplastic anemia             4637    25
# 8             Fanconi anemia, complementation group T             4453    34
# 9                                    Roberts syndrome             4452    35
# 10                                  Jacobsen syndrome             4446    36
# 11                                        polydactyly             4426    37
# 12                         Smith-Lemli-Opitz Syndrome             4366    39
# 13           Fanconi anemia, complementation group D1             4359    40
# 14            mosaic variegated aneuploidy syndrome 1             4348    41
# 15                                           leukemia             4318    45
# 16                                 CHARGE association             4274    52
# 17            Fanconi Anemia, Complementation Group N             4272    53
# 18                                      Down Syndrome             4225    62
# 19                                     Bloom syndrome             4204    65
# 20                            Polydactyly, Preaxial 2             4201    66
# 21            Fanconi anemia, complementation group P             4168    74
# 22                          Microphthalmia, Lenz type             4163    75
# 23                           Williams-Beuren syndrome             4155    76
# 24                               sideroblastic anemia             4146    77
# 25                          Rothmund-Thomson Syndrome             4108    84
# 26                          22q11.2 deletion syndrome             4097    87
# 27                            Diamond-Blackfan anemia             4096    88
# 28           Fanconi Anemia, Complementation Group 50             4096    89
# 29                              ataxia telangiectasia             4089    92
# 30                                         syndactyly             4086    97
# 31                              xeroderma pigmentosum             4077   102
# 32                          Duane-Radial Ray Syndrome             4077   103
# 33                                 Goldenhar syndrome             4073   104
# 34                                   Burkitt lymphoma             4072   105
# 35            Fanconi Anemia, Complementation Group J             4058   112
# 36                  chromosome 1p36 deletion syndrome             4044   116
# 37                              pure red-cell aplasia             4043   117
# 38                          Pseudotrisomy 13 Syndrome             4037   120
# 39                             Rhombencephalosynapsis             4031   124
# 40                                         Ectromelia             4031   125
# 41  Intellectual disability-polydactyly-uncombable...             4019   131
# 42                                  VATER association             4005   135
# 43                              Prader-Willi syndrome             4000   137
# 44                          Diamond-Blackfan Anemia 1             4000   138
# 45  Lymphoblastic Leukemia, Acute, With Lymphomato...             3996   142
# 46                                  Cockayne syndrome             3996   143
# 47                                      STAR syndrome             3991   145
# 48                                       polycythemia             3987   147
# 49               Miller-Dieker Lissencephaly Syndrome             3986   148
# 50                          Rubinstein-Taybi syndrome             3985   149
# 51  ectrodactyly, ectodermal dysplasia, and cleft ...             3984   150
# 52                             Baller-Gerold syndrome             3980   153
# 53                         Microphthalmia syndromic 9             3980   154
# 54                                           Dwarfism             3980   155
# 55                                                DWS             3974   159
# 56                                   Mosaic trisomy 9             3973   162
#
#      rawScore        score significance
# 0   77.192996  7719.299615          NaN
# 1   53.281557  5328.155713          NaN
# 2   53.281557  5328.155713          NaN
# 3   53.281557  5328.155713          NaN
# 4   53.281557  5328.155713          NaN
# 5   50.936417  5093.641650          NaN
# 6   50.417038  5041.703753          NaN
# 7   46.370548  4637.054834          NaN
# 8   44.531556  4453.155616          NaN
# 9   44.519949  4451.994932          NaN
# 10  44.463623  4446.362274          NaN
# 11  44.263670  4426.366980          NaN
# 12  43.659307  4365.930701          NaN
# 13  43.590706  4359.070617          NaN
# 14  43.481223  4348.122309          NaN
# 15  43.181644  4318.164450          NaN
# 16  42.736674  4273.667436          NaN
# 17  42.723316  4272.331556          NaN
# 18  42.250627  4225.062704          NaN
# 19  42.038064  4203.806388          NaN
# 20  42.007823  4200.782322          NaN
# 21  41.679789  4167.978930          NaN
# 22  41.625768  4162.576785          NaN
# 23  41.551156  4155.115581          NaN
# 24  41.462260  4146.226047          NaN
# 25  41.077633  4107.763306          NaN
# 26  40.972690  4097.268950          NaN
# 27  40.961495  4096.149520          NaN
# 28  40.955681  4095.568139          NaN
# 29  40.893919  4089.391900          NaN
# 30  40.859476  4085.947636          NaN
# 31  40.770857  4077.085680          NaN
# 32  40.768014  4076.801357          NaN
# 33  40.733767  4073.376677          NaN
# 34  40.716636  4071.663575          NaN
# 35  40.583475  4058.347549          NaN
# 36  40.436689  4043.668908          NaN
# 37  40.433324  4043.332375          NaN
# 38  40.368106  4036.810610          NaN
# 39  40.307002  4030.700150          NaN
# 40  40.306109  4030.610873          NaN
# 41  40.193841  4019.384100          NaN
# 42  40.045119  4004.511866          NaN
# 43  40.003823  4000.382295          NaN
# 44  40.000473  4000.047314          NaN
# 45  39.955662  3995.566163          NaN
# 46  39.955404  3995.540390          NaN
# 47  39.909198  3990.919768          NaN
# 48  39.867845  3986.784520          NaN
# 49  39.855545  3985.554510          NaN
# 50  39.852422  3985.242234          NaN
# 51  39.841518  3984.151819          NaN
# 52  39.804952  3980.495217          NaN
# 53  39.804712  3980.471228          NaN
# 54  39.801259  3980.125933          NaN
# 55  39.743059  3974.305864          NaN
# 56  39.726645  3972.664477          NaN
