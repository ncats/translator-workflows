# %%
import pandas as pd
import requests
from pprint import pprint
import ontobio

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_1_core_complex = "FA_1_core_complex.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_1_core_complex, sep='\t', names=columns)

# %%
fa_genes
# Out:
#         gene_curie gene_symbol
# 0    NCBIGene:2175       FANCA
# 1    NCBIGene:2187       FANCB
# 2    NCBIGene:2176       FANCC
# 3    NCBIGene:2178       FANCE
# 4    NCBIGene:2188       FANCF
# 5    NCBIGene:2189       FANCG
# 6   NCBIGene:55120       FANCL
# 7   NCBIGene:57697       FANCM
# 8    NCBIGene:2177      FANCD2
# 9   NCBIGene:55215       FANCI
# 10  NCBIGene:29089       UBE2T

# %%
class BioLinkWrapper(object):
    def __init__(self):
        self.endpoint = 'https://api.monarchinitiative.org/api/'
        
    def get_gene(self, gene_curie):
        url = '{}bioentity/gene/{}'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

    def get_orthologs(self, gene_curie):
        url = '{}bioentity/gene/{}/homologs/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

    def get_phenotypes(self,gene_curie):
        url = '{}bioentity/gene/{}/phenotypes/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_diseases(self, gene_curie):
        url = '{}bioentity/gene/{}/diseases/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_interactions(self, gene_curie):
        url = '{}bioentity/gene/{}/interactions/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_functions(self, gene_curie):
        url = '{}bioentity/gene/{}/functions/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_disease_models(self, disease_curie):
        url = '{}/bioentity/disease/{}/models/'.format(self.endpoint, disease_curie)
        response = requests.get(url)
        return response.json()
    
    def get_all_phenotypes_for_taxon(self, taxon_curie):
        # get phenotypes associated with taxid
        url = "mart/gene/phenotype/{}".format(self.endpoint, taxon_curie)
        response = requests.get(url)
        return response.json()
    
    def get_gene_function(self, gene_curie):
        # get function associated with gene
        url = "{}bioentity/gene/{}/function/".format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

# %% [markdown]
# # Get orthologs

# %%
fa_genes_orthologs = list()
BLW = BioLinkWrapper()
for index, gene in fa_genes.iterrows():
    orthologs = BLW.get_orthologs(gene[0])
    for orth in orthologs['associations']:
        orth_dict = {
            'gene_name': gene[1],
            'gene_curie': gene[0],
            'ortholog_name': orth['object']['label'],
            'ortholog_curie': orth['object']['id'],
            'orth_tax_label': orth['object']['taxon']['label'],
            'orth_tax_id': orth['object']['taxon']['id']
        }
        fa_genes_orthologs.append(orth_dict)

# %%
orth_columns  = [ 'gene_name', 'gene_curie', 'ortholog_name', 'ortholog_curie', 'orth_tax_label', 'orth_tax_id']
orth_df = pd.DataFrame(data=fa_genes_orthologs, columns=orth_columns)
orth_df
# Out:
#     gene_name      gene_curie ortholog_name             ortholog_curie  \
# 0       FANCA   NCBIGene:2175         FANCA            NCBIGene:415854
# 1       FANCA   NCBIGene:2175         FANCA            NCBIGene:454393
# 2       FANCA   NCBIGene:2175         Fanca                MGI:1341823
# 3       FANCA   NCBIGene:2175         FANCA         NCBIGene:100052495
# 4       FANCA   NCBIGene:2175         FANCA         NCBIGene:100027499
# 5       FANCA   NCBIGene:2175         FANCA         NCBIGene:100621453
# 6       FANCA   NCBIGene:2175         Fanca                RGD:1311380
# 7       FANCA   NCBIGene:2175         FANCA            NCBIGene:618375
# 8       FANCA   NCBIGene:2175         FANCA         NCBIGene:100080126
# 9       FANCB   NCBIGene:2187         FANCB            NCBIGene:616549
# 10      FANCB   NCBIGene:2187         FANCB         NCBIGene:100031860
# 11      FANCB   NCBIGene:2187         FANCB            NCBIGene:737001
# 12      FANCB   NCBIGene:2187         FANCB         NCBIGene:100156438
# 13      FANCB   NCBIGene:2187         fancb         NCBIGene:100564315
# 14      FANCB   NCBIGene:2187         FANCB            NCBIGene:418628
# 15      FANCB   NCBIGene:2187         FANCB            NCBIGene:712083
# 16      FANCB   NCBIGene:2187         Fancb                MGI:2448558
# 17      FANCB   NCBIGene:2187         FANCB         NCBIGene:100055607
# 18      FANCB   NCBIGene:2187         Fancb                RGD:1561555
# 19      FANCB   NCBIGene:2187         fancb     ZFIN:ZDB-GENE-060510-1
# 20      FANCC   NCBIGene:2176         FANCC            NCBIGene:709398
# 21      FANCC   NCBIGene:2176         FANCC            NCBIGene:465257
# 22      FANCC   NCBIGene:2176         fancc     Xenbase:XB-GENE-986037
# 23      FANCC   NCBIGene:2176         fancc         NCBIGene:100555906
# 24      FANCC   NCBIGene:2176         FANCC            NCBIGene:427468
# 25      FANCC   NCBIGene:2176         fancc     ZFIN:ZDB-GENE-060510-2
# 26      FANCC   NCBIGene:2176         FANCC         NCBIGene:100013900
# 27      FANCC   NCBIGene:2176         Fancc                  MGI:95480
# 28      FANCC   NCBIGene:2176         Fancc                   RGD:2593
# 29      FANCC   NCBIGene:2176         FANCC         NCBIGene:100061359
# ..        ...             ...           ...                        ...
# 90     FANCD2   NCBIGene:2177     AT4G14970            NCBIGene:827156
# 91     FANCD2   NCBIGene:2177        fancd2     ZFIN:ZDB-GENE-040116-5
# 92     FANCD2   NCBIGene:2177        FANCD2         NCBIGene:100522343
# 93     FANCD2   NCBIGene:2177        fancd2     Xenbase:XB-GENE-984801
# 94     FANCD2   NCBIGene:2177        FANCD2            NCBIGene:415935
# 95     FANCD2   NCBIGene:2177        Fancd2                RGD:1303172
# 96     FANCD2   NCBIGene:2177        FANCD2         NCBIGene:100024226
# 97     FANCD2   NCBIGene:2177        FANCD2         NCBIGene:100051871
# 98      FANCI  NCBIGene:55215         FANCI            NCBIGene:453636
# 99      FANCI  NCBIGene:55215         FANCI        FlyBase:FBgn0033354
# 100     FANCI  NCBIGene:55215         FANCI         NCBIGene:100069712
# 101     FANCI  NCBIGene:55215         fanci         NCBIGene:100552745
# 102     FANCI  NCBIGene:55215         FANCI         NCBIGene:100016421
# 103     FANCI  NCBIGene:55215         FANCI         NCBIGene:100156260
# 104     FANCI  NCBIGene:55215         Fanci                MGI:2384790
# 105     FANCI  NCBIGene:55215     AT5G49110            NCBIGene:834970
# 106     FANCI  NCBIGene:55215         FANCI            NCBIGene:522442
# 107     FANCI  NCBIGene:55215         fanci  ZFIN:ZDB-GENE-030131-2905
# 108     FANCI  NCBIGene:55215         FANCI            NCBIGene:699878
# 109     FANCI  NCBIGene:55215         FANCI            NCBIGene:415491
# 110     FANCI  NCBIGene:55215        fnci-1    WormBase:WBGene00020935
# 111     FANCI  NCBIGene:55215         Fanci                RGD:2321863
# 112     UBE2T  NCBIGene:29089         Ube2t                MGI:1914446
# 113     UBE2T  NCBIGene:29089         Ube2t                RGD:1310816
# 114     UBE2T  NCBIGene:29089         ube2t   ZFIN:ZDB-GENE-061013-547
# 115     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:505314
# 116     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:705911
# 117     UBE2T  NCBIGene:29089         ube2t         NCBIGene:100567260
# 118     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:421149
# 119     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:457628
#
#                     orth_tax_label      orth_tax_id
# 0                    Gallus gallus   NCBITaxon:9031
# 1                  Pan troglodytes   NCBITaxon:9598
# 2                     Mus musculus  NCBITaxon:10090
# 3                   Equus caballus   NCBITaxon:9796
# 4            Monodelphis domestica  NCBITaxon:13616
# 5                       Sus scrofa   NCBITaxon:9823
# 6                Rattus norvegicus  NCBITaxon:10116
# 7                       Bos taurus   NCBITaxon:9913
# 8         Ornithorhynchus anatinus   NCBITaxon:9258
# 9                       Bos taurus   NCBITaxon:9913
# 10           Monodelphis domestica  NCBITaxon:13616
# 11                 Pan troglodytes   NCBITaxon:9598
# 12                      Sus scrofa   NCBITaxon:9823
# 13             Anolis carolinensis  NCBITaxon:28377
# 14                   Gallus gallus   NCBITaxon:9031
# 15                  Macaca mulatta   NCBITaxon:9544
# 16                    Mus musculus  NCBITaxon:10090
# 17                  Equus caballus   NCBITaxon:9796
# 18               Rattus norvegicus  NCBITaxon:10116
# 19                     Danio rerio   NCBITaxon:7955
# 20                  Macaca mulatta   NCBITaxon:9544
# 21                 Pan troglodytes   NCBITaxon:9598
# 22   Xenopus (Silurana) tropicalis   NCBITaxon:8364
# 23             Anolis carolinensis  NCBITaxon:28377
# 24                   Gallus gallus   NCBITaxon:9031
# 25                     Danio rerio   NCBITaxon:7955
# 26           Monodelphis domestica  NCBITaxon:13616
# 27                    Mus musculus  NCBITaxon:10090
# 28               Rattus norvegicus  NCBITaxon:10116
# 29                  Equus caballus   NCBITaxon:9796
# ..                             ...              ...
# 90            Arabidopsis thaliana   NCBITaxon:3702
# 91                     Danio rerio   NCBITaxon:7955
# 92                      Sus scrofa   NCBITaxon:9823
# 93   Xenopus (Silurana) tropicalis   NCBITaxon:8364
# 94                   Gallus gallus   NCBITaxon:9031
# 95               Rattus norvegicus  NCBITaxon:10116
# 96           Monodelphis domestica  NCBITaxon:13616
# 97                  Equus caballus   NCBITaxon:9796
# 98                 Pan troglodytes   NCBITaxon:9598
# 99         Drosophila melanogaster   NCBITaxon:7227
# 100                 Equus caballus   NCBITaxon:9796
# 101            Anolis carolinensis  NCBITaxon:28377
# 102          Monodelphis domestica  NCBITaxon:13616
# 103                     Sus scrofa   NCBITaxon:9823
# 104                   Mus musculus  NCBITaxon:10090
# 105           Arabidopsis thaliana   NCBITaxon:3702
# 106                     Bos taurus   NCBITaxon:9913
# 107                    Danio rerio   NCBITaxon:7955
# 108                 Macaca mulatta   NCBITaxon:9544
# 109                  Gallus gallus   NCBITaxon:9031
# 110         Caenorhabditis elegans   NCBITaxon:6239
# 111              Rattus norvegicus  NCBITaxon:10116
# 112                   Mus musculus  NCBITaxon:10090
# 113              Rattus norvegicus  NCBITaxon:10116
# 114                    Danio rerio   NCBITaxon:7955
# 115                     Bos taurus   NCBITaxon:9913
# 116                 Macaca mulatta   NCBITaxon:9544
# 117            Anolis carolinensis  NCBITaxon:28377
# 118                  Gallus gallus   NCBITaxon:9031
# 119                Pan troglodytes   NCBITaxon:9598
#
# [120 rows x 6 columns]

# %%
def query_mygene(gene_curie):
    gene_curie = gene_curie.replace('NCBIGene:', '')
    url = 'https://mygene.info/v3/query?q={}&fields=all'.format(gene_curie)
    hit = requests.get(url)
    hit = hit.json()
    uniprot = hit['hits'][0]['uniprot']
    if 'Swiss-Prot' in uniprot.keys():
        if isinstance(uniprot['Swiss-Prot'], list):
            return uniprot['Swiss-Prot']
        elif isinstance(uniprot['Swiss-Prot'], str):
            return [uniprot['Swiss-Prot']]
        else:
            return None

# %%
query_mygene(gene_curie='NCBIGene:2187')
# Out:
# ['Q8NB91']

# %%
from ontobio.ontol_factory import OntologyFactory
# Create ontology object, for GO
# Transparently uses remote SPARQL service.
# (May take a few seconds to run first time, Jupyter will show '*'. BE PATIENT, do
# not re-execute cell)
ofactory = OntologyFactory()
ont = ofactory.create('go')

# %%
from ontobio.io.gafparser import GafParser
from ontobio.assoc_factory import AssociationSetFactory

p = GafParser()
afactory = AssociationSetFactory()

def make_assocs(group, parse=False):
    url = "http://geneontology.org/gene-associations/gene_association.{}.gz".format(group)
    if group == 'human':
        url = "http://geneontology.org/gene-associations/goa_human.gaf.gz"
    assocs = p.parse(url)
    if parse:
        return assocs
    else:
        return afactory.create_from_assocs(assocs, ontology=ont)

# %%
asoc_mouse = make_assocs(group='mgi')

# %%
asoc_mouse.associations('MGI:MGI:1920025')
# Out:
# [{'aspect': 'F',
#   'date': '2009-11-10',
#   'evidence': {'has_supporting_reference': ['MGI:MGI:2156816',
#     'GO_REF:0000015'],
#    'type': 'ND',
#    'with_support_from': []},
#   'negated': False,
#   'object': {'id': 'GO:0003674', 'taxon': 'NCBITaxon:10090'},
#   'provided_by': 'MGI',
#   'qualifiers': [],
#   'relation': {'id': 'enables'},
#   'source_line': 'MGI\tMGI:1920025\tFance\t\tGO:0003674\tMGI:MGI:2156816|GO_REF:0000015\tND\t\tF\tFanconi anemia, complementation group E\t2810451D06Rik\tprotein\ttaxon:10090\t20091110\tMGI\t\t\n',
#   'subject': {'fullname': 'Fanconi anemia, complementation group E',
#    'id': 'MGI:MGI:1920025',
#    'label': 'Fance',
#    'synonyms': ['2810451D06Rik'],
#    'taxon': {'id': 'NCBITaxon:10090'},
#    'type': 'protein'},
#   'subject_extensions': [{'filler': '\n', 'property': 'isoform'}]},
#  {'aspect': 'P',
#   'date': '2009-11-10',
#   'evidence': {'has_supporting_reference': ['MGI:MGI:2156816',
#     'GO_REF:0000015'],
#    'type': 'ND',
#    'with_support_from': []},
#   'negated': False,
#   'object': {'id': 'GO:0008150', 'taxon': 'NCBITaxon:10090'},
#   'provided_by': 'MGI',
#   'qualifiers': [],
#   'relation': {'id': 'involved_in'},
#   'source_line': 'MGI\tMGI:1920025\tFance\t\tGO:0008150\tMGI:MGI:2156816|GO_REF:0000015\tND\t\tP\tFanconi anemia, complementation group E\t2810451D06Rik\tprotein\ttaxon:10090\t20091110\tMGI\t\t\n',
#   'subject': {'fullname': 'Fanconi anemia, complementation group E',
#    'id': 'MGI:MGI:1920025',
#    'label': 'Fance',
#    'synonyms': ['2810451D06Rik'],
#    'taxon': {'id': 'NCBITaxon:10090'},
#    'type': 'protein'},
#   'subject_extensions': [{'filler': '\n', 'property': 'isoform'}]},
#  {'aspect': 'C',
#   'date': '2011-08-30',
#   'evidence': {'has_supporting_reference': ['MGI:MGI:4834177',
#     'GO_REF:0000096'],
#    'type': 'ISO',
#    'with_support_from': ['UniProtKB:Q9HB96']},
#   'negated': False,
#   'object': {'id': 'GO:0043240', 'taxon': 'NCBITaxon:10090'},
#   'provided_by': 'MGI',
#   'qualifiers': [],
#   'relation': {'id': 'part_of'},
#   'source_line': 'MGI\tMGI:1920025\tFance\t\tGO:0043240\tMGI:MGI:4834177|GO_REF:0000096\tISO\tUniProtKB:Q9HB96\tC\tFanconi anemia, complementation group E\t2810451D06Rik\tprotein\ttaxon:10090\t20110830\tMGI\t\t\n',
#   'subject': {'fullname': 'Fanconi anemia, complementation group E',
#    'id': 'MGI:MGI:1920025',
#    'label': 'Fance',
#    'synonyms': ['2810451D06Rik'],
#    'taxon': {'id': 'NCBITaxon:10090'},
#    'type': 'protein'},
#   'subject_extensions': [{'filler': '\n', 'property': 'isoform'}]}]

# %%
asoc_mouse.meta('MGI:MGI:1920025')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-cd15b4e21fa7> in <module>()
# ----> 1 asoc_mouse.meta('MGI:MGI:1920025')
#
# TypeError: 'NoneType' object is not callable

# %%
mouse_assocs = make_assocs(group='mgi', parse=True)

# %%
mouse_orthologs = orth_df.loc[orth_df['orth_tax_id'] == 'NCBITaxon:10090']
mouse_ortho_sims = list()
for index, row in mouse_orthologs.iterrows():
    gene_name = row[0]
    gene_curie = row[1]
    ortholog_name = row[2]
    ortholog_curie = row[3]
    ortholog_taxon_curie = row[5]
    ortholog_taxon_name = row[4]
    mo = 'MGI:{}'.format(ortholog_curie)
    for mgene in list(asoc_mouse.subject_label_map.keys()):
        amScore = asoc_mouse.jaccard_similarity(mo, mgene)     
        if amScore > .7 and amScore < 1:
            mouse_ortho_sims.append({
                    'gene_name': gene_name,
                    'gene_curie': gene_curie,
                    'ortholog_name': ortholog_name,
                    'ortholog_curie': ortholog_curie,
                    'ortholog_taxon_curie': ortholog_taxon_curie,
                    'ortholog_taxon_name': ortholog_taxon_name,
                    'non_fa_hit_name': asoc_mouse.label(mgene),
                    'non_fa_hit_curie': mgene.replace('MGI:MGI:', 'MGI:'),
                    'sim_score' : amScore
                })

# %%
mouse_sims_columns = [ 'gene_name','gene_curie', 'ortholog_name', 
                      'ortholog_curie', 'ortholog_taxon_curie', 
                      'ortholog_taxon_name', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
mouse_sims_df = pd.DataFrame(data=mouse_ortho_sims, columns=mouse_sims_columns )

# %%
asoc_mouse.annotations('MGI:MGI:1920025')
# Out:
# ['GO:0008150', 'GO:0003674', 'GO:0043240']

# %%
asoc_mouse.annotations('MGI:MGI:1915971')
# Out:
# ['GO:0008150', 'GO:0005634', 'GO:0003674', 'GO:0005654']

# %%
mouse_sims_df
# Out:
#    gene_name      gene_curie ortholog_name ortholog_curie  \
# 0      FANCA   NCBIGene:2175         Fanca    MGI:1341823
# 1      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 2      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 3      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 4      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 5      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 6      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 7      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 8      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 9      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 10     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 11     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 12     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 13     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 14     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 15     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 16     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 17     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 18     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 19     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 20     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 21     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 22     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 23     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 24     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 25     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 26     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 27     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 28     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 29     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 30     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 31     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 32     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 33     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 34     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 35     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 36     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 37     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 38     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 39     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 40     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 41     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 42     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 43     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 44     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 45     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 46     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 47     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 48     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 49     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 50     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 51     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 52     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 53     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 54     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 55    FANCD2   NCBIGene:2177        Fancd2    MGI:2448480
# 56     UBE2T  NCBIGene:29089         Ube2t    MGI:1914446
#
#    ortholog_taxon_curie ortholog_taxon_name non_fa_hit_name non_fa_hit_curie  \
# 0       NCBITaxon:10090        Mus musculus          Fancd2      MGI:2448480
# 1       NCBITaxon:10090        Mus musculus   0610040J01Rik      MGI:1923511
# 2       NCBITaxon:10090        Mus musculus   1110032A03Rik      MGI:1915971
# 3       NCBITaxon:10090        Mus musculus   1700030J22Rik      MGI:1916778
# 4       NCBITaxon:10090        Mus musculus   2200002D01Rik      MGI:1919525
# 5       NCBITaxon:10090        Mus musculus   2310022A10Rik      MGI:1913617
# 6       NCBITaxon:10090        Mus musculus   A230006K03Rik      MGI:3644205
# 7       NCBITaxon:10090        Mus musculus         Ankrd12      MGI:1914357
# 8       NCBITaxon:10090        Mus musculus          Apold1      MGI:2685921
# 9       NCBITaxon:10090        Mus musculus        AW549877      MGI:2146232
# 10      NCBITaxon:10090        Mus musculus        BC005624      MGI:2385132
# 11      NCBITaxon:10090        Mus musculus         Caskin2      MGI:2157062
# 12      NCBITaxon:10090        Mus musculus         Ccdc174      MGI:2444652
# 13      NCBITaxon:10090        Mus musculus          Cfap45      MGI:1919120
# 14      NCBITaxon:10090        Mus musculus            Cmip      MGI:1921690
# 15      NCBITaxon:10090        Mus musculus           Cwc25      MGI:1914730
# 16      NCBITaxon:10090        Mus musculus      D8Ertd738e      MGI:1289231
# 17      NCBITaxon:10090        Mus musculus          Dcaf11        MGI:90168
# 18      NCBITaxon:10090        Mus musculus          Evx1os      MGI:1917843
# 19      NCBITaxon:10090        Mus musculus         Fam124b      MGI:3026880
# 20      NCBITaxon:10090        Mus musculus         Fam131b      MGI:1923406
# 21      NCBITaxon:10090        Mus musculus         Fam217b      MGI:1918782
# 22      NCBITaxon:10090        Mus musculus         Fam222b      MGI:2384939
# 23      NCBITaxon:10090        Mus musculus          Fam76a      MGI:2385211
# 24      NCBITaxon:10090        Mus musculus          Fam76b      MGI:1920076
# 25      NCBITaxon:10090        Mus musculus           Fem1c      MGI:2444737
# 26      NCBITaxon:10090        Mus musculus           Fnbp4      MGI:1860513
# 27      NCBITaxon:10090        Mus musculus            Gid8      MGI:1923675
# 28      NCBITaxon:10090        Mus musculus           Gpkow      MGI:1859610
# 29      NCBITaxon:10090        Mus musculus         Hcfc1r1      MGI:2663619
# 30      NCBITaxon:10090        Mus musculus          Hirip3      MGI:2142364
# 31      NCBITaxon:10090        Mus musculus           Hspb3      MGI:1928479
# 32      NCBITaxon:10090        Mus musculus         Kansl1l      MGI:1915941
# 33      NCBITaxon:10090        Mus musculus         Klhdc10      MGI:1924038
# 34      NCBITaxon:10090        Mus musculus           Lyrm1      MGI:1921169
# 35      NCBITaxon:10090        Mus musculus           Lyrm4      MGI:2683538
# 36      NCBITaxon:10090        Mus musculus         Magea10      MGI:3588211
# 37      NCBITaxon:10090        Mus musculus          Magea4      MGI:1333839
# 38      NCBITaxon:10090        Mus musculus             Mro      MGI:2152817
# 39      NCBITaxon:10090        Mus musculus           Myct1      MGI:1915882
# 40      NCBITaxon:10090        Mus musculus           Nol4l      MGI:1918765
# 41      NCBITaxon:10090        Mus musculus          Nudcd1      MGI:1914679
# 42      NCBITaxon:10090        Mus musculus          Nudt22      MGI:1915573
# 43      NCBITaxon:10090        Mus musculus         Plekhg1      MGI:2676551
# 44      NCBITaxon:10090        Mus musculus          Prdm15      MGI:1930121
# 45      NCBITaxon:10090        Mus musculus          Pwwp2b      MGI:2142008
# 46      NCBITaxon:10090        Mus musculus            Rnu6        MGI:97989
# 47      NCBITaxon:10090        Mus musculus           Rprd2      MGI:1922387
# 48      NCBITaxon:10090        Mus musculus         Snord21       MGI:102855
# 49      NCBITaxon:10090        Mus musculus        Tmem179b      MGI:1914956
# 50      NCBITaxon:10090        Mus musculus           Wdr26      MGI:1923825
# 51      NCBITaxon:10090        Mus musculus           Wdr27      MGI:1918932
# 52      NCBITaxon:10090        Mus musculus          Zbtb11      MGI:2443876
# 53      NCBITaxon:10090        Mus musculus          Zbtb34      MGI:2685195
# 54      NCBITaxon:10090        Mus musculus          Zfp672      MGI:2442105
# 55      NCBITaxon:10090        Mus musculus           Fanca      MGI:1341823
# 56      NCBITaxon:10090        Mus musculus           Ube2w      MGI:1914049
#
#     sim_score
# 0    0.705882
# 1    0.800000
# 2    0.833333
# 3    0.740741
# 4    0.703704
# 5    0.833333
# 6    0.750000
# 7    0.740741
# 8    0.740741
# 9    0.740741
# 10   0.740741
# 11   0.730769
# 12   0.833333
# 13   0.833333
# 14   0.740741
# 15   0.807692
# 16   0.703704
# 17   0.724138
# 18   0.709677
# 19   0.740741
# 20   0.703704
# 21   0.740741
# 22   0.833333
# 23   0.750000
# 24   0.730769
# 25   0.740741
# 26   0.750000
# 27   0.800000
# 28   0.714286
# 29   0.800000
# 30   0.703704
# 31   0.703704
# 32   0.724138
# 33   0.800000
# 34   0.714286
# 35   0.750000
# 36   0.740741
# 37   0.750000
# 38   0.703704
# 39   0.714286
# 40   0.703704
# 41   0.740741
# 42   0.769231
# 43   0.833333
# 44   0.760000
# 45   0.833333
# 46   0.807692
# 47   0.709677
# 48   0.703704
# 49   0.724138
# 50   0.740741
# 51   0.833333
# 52   0.833333
# 53   0.833333
# 54   0.791667
# 55   0.705882
# 56   0.735043

# %%
mouse_sims_df
# Out:
#    gene_name      gene_curie ortholog_name ortholog_curie  \
# 0      FANCA   NCBIGene:2175         Fanca    MGI:1341823
# 1      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 2      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 3      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 4      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 5      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 6      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 7      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 8      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 9      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 10     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 11     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 12     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 13     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 14     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 15     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 16     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 17     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 18     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 19     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 20     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 21     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 22     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 23     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 24     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 25     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 26     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 27     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 28     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 29     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 30     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 31     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 32     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 33     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 34     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 35     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 36     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 37     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 38     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 39     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 40     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 41     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 42     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 43     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 44     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 45     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 46     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 47     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 48     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 49     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 50     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 51     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 52     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 53     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 54     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 55    FANCD2   NCBIGene:2177        Fancd2    MGI:2448480
# 56     UBE2T  NCBIGene:29089         Ube2t    MGI:1914446
#
#    ortholog_taxon_curie ortholog_taxon_name non_fa_hit_name non_fa_hit_curie  \
# 0       NCBITaxon:10090        Mus musculus          Fancd2      MGI:2448480
# 1       NCBITaxon:10090        Mus musculus   0610040J01Rik      MGI:1923511
# 2       NCBITaxon:10090        Mus musculus   1110032A03Rik      MGI:1915971
# 3       NCBITaxon:10090        Mus musculus   1700030J22Rik      MGI:1916778
# 4       NCBITaxon:10090        Mus musculus   2200002D01Rik      MGI:1919525
# 5       NCBITaxon:10090        Mus musculus   2310022A10Rik      MGI:1913617
# 6       NCBITaxon:10090        Mus musculus   A230006K03Rik      MGI:3644205
# 7       NCBITaxon:10090        Mus musculus         Ankrd12      MGI:1914357
# 8       NCBITaxon:10090        Mus musculus          Apold1      MGI:2685921
# 9       NCBITaxon:10090        Mus musculus        AW549877      MGI:2146232
# 10      NCBITaxon:10090        Mus musculus        BC005624      MGI:2385132
# 11      NCBITaxon:10090        Mus musculus         Caskin2      MGI:2157062
# 12      NCBITaxon:10090        Mus musculus         Ccdc174      MGI:2444652
# 13      NCBITaxon:10090        Mus musculus          Cfap45      MGI:1919120
# 14      NCBITaxon:10090        Mus musculus            Cmip      MGI:1921690
# 15      NCBITaxon:10090        Mus musculus           Cwc25      MGI:1914730
# 16      NCBITaxon:10090        Mus musculus      D8Ertd738e      MGI:1289231
# 17      NCBITaxon:10090        Mus musculus          Dcaf11        MGI:90168
# 18      NCBITaxon:10090        Mus musculus          Evx1os      MGI:1917843
# 19      NCBITaxon:10090        Mus musculus         Fam124b      MGI:3026880
# 20      NCBITaxon:10090        Mus musculus         Fam131b      MGI:1923406
# 21      NCBITaxon:10090        Mus musculus         Fam217b      MGI:1918782
# 22      NCBITaxon:10090        Mus musculus         Fam222b      MGI:2384939
# 23      NCBITaxon:10090        Mus musculus          Fam76a      MGI:2385211
# 24      NCBITaxon:10090        Mus musculus          Fam76b      MGI:1920076
# 25      NCBITaxon:10090        Mus musculus           Fem1c      MGI:2444737
# 26      NCBITaxon:10090        Mus musculus           Fnbp4      MGI:1860513
# 27      NCBITaxon:10090        Mus musculus            Gid8      MGI:1923675
# 28      NCBITaxon:10090        Mus musculus           Gpkow      MGI:1859610
# 29      NCBITaxon:10090        Mus musculus         Hcfc1r1      MGI:2663619
# 30      NCBITaxon:10090        Mus musculus          Hirip3      MGI:2142364
# 31      NCBITaxon:10090        Mus musculus           Hspb3      MGI:1928479
# 32      NCBITaxon:10090        Mus musculus         Kansl1l      MGI:1915941
# 33      NCBITaxon:10090        Mus musculus         Klhdc10      MGI:1924038
# 34      NCBITaxon:10090        Mus musculus           Lyrm1      MGI:1921169
# 35      NCBITaxon:10090        Mus musculus           Lyrm4      MGI:2683538
# 36      NCBITaxon:10090        Mus musculus         Magea10      MGI:3588211
# 37      NCBITaxon:10090        Mus musculus          Magea4      MGI:1333839
# 38      NCBITaxon:10090        Mus musculus             Mro      MGI:2152817
# 39      NCBITaxon:10090        Mus musculus           Myct1      MGI:1915882
# 40      NCBITaxon:10090        Mus musculus           Nol4l      MGI:1918765
# 41      NCBITaxon:10090        Mus musculus          Nudcd1      MGI:1914679
# 42      NCBITaxon:10090        Mus musculus          Nudt22      MGI:1915573
# 43      NCBITaxon:10090        Mus musculus         Plekhg1      MGI:2676551
# 44      NCBITaxon:10090        Mus musculus          Prdm15      MGI:1930121
# 45      NCBITaxon:10090        Mus musculus          Pwwp2b      MGI:2142008
# 46      NCBITaxon:10090        Mus musculus            Rnu6        MGI:97989
# 47      NCBITaxon:10090        Mus musculus           Rprd2      MGI:1922387
# 48      NCBITaxon:10090        Mus musculus         Snord21       MGI:102855
# 49      NCBITaxon:10090        Mus musculus        Tmem179b      MGI:1914956
# 50      NCBITaxon:10090        Mus musculus           Wdr26      MGI:1923825
# 51      NCBITaxon:10090        Mus musculus           Wdr27      MGI:1918932
# 52      NCBITaxon:10090        Mus musculus          Zbtb11      MGI:2443876
# 53      NCBITaxon:10090        Mus musculus          Zbtb34      MGI:2685195
# 54      NCBITaxon:10090        Mus musculus          Zfp672      MGI:2442105
# 55      NCBITaxon:10090        Mus musculus           Fanca      MGI:1341823
# 56      NCBITaxon:10090        Mus musculus           Ube2w      MGI:1914049
#
#     sim_score
# 0    0.705882
# 1    0.800000
# 2    0.833333
# 3    0.740741
# 4    0.703704
# 5    0.833333
# 6    0.750000
# 7    0.740741
# 8    0.740741
# 9    0.740741
# 10   0.740741
# 11   0.730769
# 12   0.833333
# 13   0.833333
# 14   0.740741
# 15   0.807692
# 16   0.703704
# 17   0.724138
# 18   0.709677
# 19   0.740741
# 20   0.703704
# 21   0.740741
# 22   0.833333
# 23   0.750000
# 24   0.730769
# 25   0.740741
# 26   0.750000
# 27   0.800000
# 28   0.714286
# 29   0.800000
# 30   0.703704
# 31   0.703704
# 32   0.724138
# 33   0.800000
# 34   0.714286
# 35   0.750000
# 36   0.740741
# 37   0.750000
# 38   0.703704
# 39   0.714286
# 40   0.703704
# 41   0.740741
# 42   0.769231
# 43   0.833333
# 44   0.760000
# 45   0.833333
# 46   0.807692
# 47   0.709677
# 48   0.703704
# 49   0.724138
# 50   0.740741
# 51   0.833333
# 52   0.833333
# 53   0.833333
# 54   0.791667
# 55   0.705882
# 56   0.735043

# %%
asoc_hsap = make_assocs('human')

# %%
hsap_ortho_sims = list()
for index, row in fa_genes.iterrows():
    ukb = query_mygene(row[1])
    for hgene in list(asoc_hsap.subject_label_map.keys()):
        print(hgene)
#         amScore = asoc_hsap.jaccard_similarity(ukb, hgene)
#         if amScore > .7 and amScore < 1:
#             hsap_ortho_sims.append({
#                     'gene_name': row[0],
#                     'gene_curie': row[1],
#                     'non_fa_hit_name': asoc_hsap.label(hgene),
#                     'non_fa_hit_curie': hgene,
#                     'sim_score' : amScore
#                 })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e6b987459f43> in <module>()
#       2 for index, row in fa_genes.iterrows():
#       3     ukb = query_mygene(row[1])
# ----> 4     for hgene in list(asoc_hsap.subject_label_map.keys()):
#       5         print(hgene)
#       6 #         amScore = asoc_hsap.jaccard_similarity(ukb, hgene)
#
# NameError: name 'asoc_hsap' is not defined

# %%
hsap_ortho_sim_columns = [ 'gene_name','gene_curie', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
hsap_ortho_sims_df = pd.DataFrame(data=hsap_ortho_sims, columns=hsap_ortho_sim_columns )

# %%
hsap_ortho_sims_df
# Out:
#         gene_name gene_curie non_fa_hit_name  non_fa_hit_curie  sim_score
# 0   NCBIGene:2187      FANCB         FAAP100  UniProtKB:Q0VG06   0.813559
# 1   NCBIGene:2187      FANCB          FAAP24  UniProtKB:Q9BTP7   0.905660
# 2   NCBIGene:2187      FANCB           FANCE  UniProtKB:Q9HB96   0.958333
# 3   NCBIGene:2187      FANCB            INIP  UniProtKB:Q9NRY2   0.865385
# 4   NCBIGene:2178      FANCE         FAAP100  UniProtKB:Q0VG06   0.779661
# 5   NCBIGene:2178      FANCE           FANCB  UniProtKB:Q8NB91   0.958333
# 6   NCBIGene:2178      FANCE          FAAP24  UniProtKB:Q9BTP7   0.867925
# 7   NCBIGene:2178      FANCE           FANCF  UniProtKB:Q9NPI8   0.958333
# 8   NCBIGene:2178      FANCE            INIP  UniProtKB:Q9NRY2   0.826923
# 9   NCBIGene:2188      FANCF         FAAP100  UniProtKB:Q0VG06   0.813559
# 10  NCBIGene:2188      FANCF          FAAP24  UniProtKB:Q9BTP7   0.905660
# 11  NCBIGene:2188      FANCF           FANCE  UniProtKB:Q9HB96   0.958333
# 12  NCBIGene:2188      FANCF            INIP  UniProtKB:Q9NRY2   0.865385

# %%
asoc_rgd = make_assocs('rgd')

# %%
rat_orthologs = orth_df.loc[orth_df['orth_tax_id'] == 'NCBITaxon:10116']
rat_ortho_sims = list()

# %%
for index, row in rat_orthologs.iterrows():
    gene_name = row[0]
    gene_curie = row[1]
    ortholog_name = row[2]
    ortholog_curie = row[3]
    ortholog_taxon_curie = row[4]
    ortholog_taxon_name = row[5]
    for rgene in list(asoc_mouse.subject_label_map.keys()):
        amScore = asoc_rgd.jaccard_similarity(ortholog_curie, rgene)     
        if amScore > .7 and amScore < 1:
            rat_ortho_sims.append({
                    'gene_name': gene_name,
                    'gene_curie': gene_curie,
                    'ortholog_name': ortholog_name,
                    'ortholog_curie': row[3],
                    'ortholog_taxon_curie': row[4],
                    'ortholog_taxon_name': row[5],
                    'non_fa_hit_name': asoc_rgd.label(mgene),
                    'non_fa_hit_curie': rgene,
                    'sim_score' : amScore
                })

# %%
rat_sims_columns = [ 'gene_name','gene_curie', 'ortholog_name', 
                      'ortholog_curie', 'ortholog_taxon_curie', 
                      'ortholog_taxon_name', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
rat_sims_df = pd.DataFrame(data=rat_ortho_sims, columns=rat_sims_columns )

# %%
rat_sims_df
# Out:
# Empty DataFrame
# Columns: [gene_name, gene_curie, ortholog_name, ortholog_curie, ortholog_taxon_curie, ortholog_taxon_name, non_fa_hit_name, non_fa_hit_curie, sim_score]
# Index: []

# %%
# Provenance
# of go annotations, 
# manual comparisons 

#
