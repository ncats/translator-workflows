# %% [markdown]
# # lil' GIM and Big GIM Mody genes example
#
# swagger api specification: http://biggim.ncats.io/api
#
# # A few helper functions for posting and getting api requests

# %%
import json
import requests
import pandas
import time

base_url = 'http://biggim.ncats.io/api'

#a couple of simple helper functions
def post(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()

def get(endpoint, data={}, base_url=base_url):
    req = requests.get('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    print("Sent: GET %s?%s" % (req.request.url,req.request.body))
    return req.json()
    

def jprint(dct):
    print(json.dumps(dct, indent=2))
    
def wrapper(endpoint, data={}, base_url=base_url):
    try:
        response = get(endpoint, data, base_url)
        jprint(response)
    except requests.HTTPError as e:

        print(e)
        if e.response.status_code == 400:
            jprint(e.response.json())
        raise
    try:
        ctr = 1
        while True:
            query_status = get('%s/status/%s'% (endpoint.split('/')[0],response['request_id'],))
            jprint(query_status)
            if query_status['status'] !='running':
                # query has finished
                break
            else:
                time.sleep(ctr)
                ctr += 1
                #linear backoff
                print("Checking again")
    except requests.HTTPError as e:
        print(e)
        if e.response.status_code == 400:
            jprint(e.response.json())
        raise
    return pandas.concat(map(pandas.read_csv, query_status['request_uri']))

# %% [markdown]
# ## lilGIM
# Lil' GIM is a simplified interface to BigGIM

# %% [markdown]
# ### Initial mody query.
#
# We provide a list of 14 MODY genes. A query request is triggered, which returns a request_id You then query a results endpoint to find out if the request is finished processing and where the result is. Provided their are no errors you can download the CSV and interact with the values.
#
# This query will look at all tissues (whole_body in the Brenda tissue ontology) and limit the number of rows to 1000.

# %%
endpoint = "lilgim/query"
data = {'ids':'3630,2645,5078,6927,6928,1056,8462,4760,3172,3651,6833,640,3767,26060'}
results = wrapper(endpoint, data)
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/lilgim/query?ids=3630%2C2645%2C5078%2C6927%2C6928%2C1056%2C8462%2C4760%2C3172%2C3651%2C6833%2C640%2C3767%2C26060
# {
#   "status": "submitted",
#   "request_id": "8a2cc61f-47d0-4685-900c-cffc689f0aa1"
# }
# Sent: GET http://biggim.ncats.io/api/lilgim/status/8a2cc61f-47d0-4685-900c-cffc689f0aa1?None
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "8a2cc61f-47d0-4685-900c-cffc689f0aa1"
# }
# Checking again
# Sent: GET http://biggim.ncats.io/api/lilgim/status/8a2cc61f-47d0-4685-900c-cffc689f0aa1?None
# {
#   "request_id": "8a2cc61f-47d0-4685-900c-cffc689f0aa1",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/8a2cc61f-47d0-4685-900c-cffc689f0aa1000000000000.csv"
#   ],
#   "status": "complete",
#   "rows": 5380,
#   "processed_data": "0B",
#   "size": "305.9 KB"
# }
#    Gene1    Symbol1  Gene2 Symbol2  maxCorr  minCorr   aveCorr
# 0    931      MS4A1    640     BLK   0.9377  -0.0033  0.631467
# 1    973      CD79A    640     BLK   0.9356   0.0254  0.604439
# 2  23495  TNFRSF13B    640     BLK   0.8791   0.0019  0.565091
# 3    930       CD19    640     BLK   0.9280  -0.1733  0.544906
# 4  79368      FCRL2    640     BLK   0.9078  -0.0791  0.534111

# %% [markdown]
# ### View available tissues via the metadata/tissue endpoint

# %%
try:
    response = get('/metadata/tissue')
    print("Available Tissues")
    jprint(response)
except response.HTTPError as e:
    print(e)
# Out:
# Sent: GET http://biggim.ncats.io/api//metadata/tissue?None
# Available Tissues
# {
#   "tissues": [
#     "B_lymphocyte",
#     "B_lymphoma_cell_line",
#     "T_lymphocyte",
#     "acute_myeloid_leukemia_cell",
#     "adenocarcinoma_cell",
#     "adipose_tissue",
#     "adrenal_cortex",
#     "adrenal_gland",
#     "adrenal_gland_cancer_cell",
#     "adrenocortical_carcinoma_cell",
#     "adult_stem_cell",
#     "alimentary_canal",
#     "amygdala",
#     "animal",
#     "aorta",
#     "artery",
#     "astroblast",
#     "astrocyte",
#     "astrocytoma_cell",
#     "astroglia",
#     "astroglial_cell",
#     "avian_pallium",
#     "basal_ganglion",
#     "basophil",
#     "bile_duct",
#     "bile_duct_epithelium",
#     "biliary_epithelium",
#     "bladder",
#     "blast_cell",
#     "blastomere",
#     "blastula",
#     "blood",
#     "blood_cancer_cell",
#     "blood_plasma",
#     "blood_platelet",
#     "blood_vessel",
#     "blood_vessel_endothelium",
#     "bone",
#     "bone_cancer_cell",
#     "bone_marrow",
#     "bone_marrow_cell",
#     "brain",
#     "brain_stem",
#     "brain_ventricle",
#     "breast",
#     "breast_cancer_cell",
#     "breast_epithelium",
#     "bronchial_epithelial_cell",
#     "bronchial_epithelium",
#     "bronchoalveolar_system",
#     "bronchogenic_carcinoma_cell",
#     "bronchus",
#     "capsular_epithelium",
#     "carcinoid_cell",
#     "carcinoma_cell",
#     "cardiac_muscle",
#     "cardiovascular_system",
#     "cartilage",
#     "caudate_nucleus",
#     "caudate_putamen",
#     "cecum",
#     "cell_culture",
#     "central_nervous_system",
#     "cerebellar_cortex",
#     "cerebellum",
#     "cerebral_cortex",
#     "cerebral_hemisphere",
#     "cerebral_lobe",
#     "cervical_adenocarcinoma_cell",
#     "cervical_carcinoma_cell",
#     "cervical_squamous_cell_carcinoma_cell",
#     "cholangiocarcinoma_cell",
#     "chondrocyte",
#     "choroid",
#     "chromophobe_renal_cell_carcinoma_cell",
#     "cochlea",
#     "coelom",
#     "colon",
#     "colonic_cancer_cell",
#     "colorectal_adenocarcinoma_cell",
#     "colorectum",
#     "connecting_stalk",
#     "connective_tissue",
#     "cornea",
#     "corpus_callosum",
#     "corpus_luteum",
#     "corpus_striatum",
#     "culture_condition",
#     "culture_condition_CD8__cell",
#     "culture_condition_antigen_presenting_cell",
#     "dendritic_cell",
#     "dentate_gyrus",
#     "diencephalon",
#     "diffuse_large_B_cell_lymphoma_cell",
#     "digestive_gland",
#     "duodenum",
#     "ear",
#     "ectoderm",
#     "embryo",
#     "embryonic_structure",
#     "endocrine_gland",
#     "endocrine_pancreas",
#     "endometrioid_carcinoma_cell",
#     "endothelial_cell",
#     "endothelium",
#     "eosinophil",
#     "epidermal_cell",
#     "epidermis",
#     "epithelial_cell",
#     "epithelioma_cell",
#     "epithelium",
#     "esophageal_cancer_cell",
#     "esophagus",
#     "excretory_gland",
#     "exocrine_gland",
#     "exocrine_pancreas",
#     "eye",
#     "female_reproductive_gland",
#     "female_reproductive_system",
#     "fetus",
#     "fibroblast",
#     "forebrain",
#     "frontal_lobe",
#     "gametocyte",
#     "ganglion",
#     "gastric_adenocarcinoma_cell",
#     "gastric_cancer_cell",
#     "gastrointestinal_cancer_cell",
#     "gastrointestinal_tract",
#     "germ_cell",
#     "germ_layer",
#     "gland",
#     "glia",
#     "glial_cell",
#     "glioblastoma_cell",
#     "glioma_cell",
#     "glomerular_epithelium",
#     "gonad",
#     "granulocyte",
#     "hair_follicle",
#     "head",
#     "head_and_neck_cancer_cell",
#     "heart",
#     "hematopoietic_cell",
#     "hematopoietic_stem_cell",
#     "hematopoietic_system",
#     "hepatocyte",
#     "hindbrain",
#     "hippocampus",
#     "hypophysis",
#     "hypothalamus",
#     "ileocecum",
#     "ileum",
#     "immune_system",
#     "inner_ear",
#     "integument",
#     "internal_female_genital_organ",
#     "internal_male_genital_organ",
#     "intestinal_mucosa",
#     "intestine",
#     "jejunum",
#     "keratinocyte",
#     "kidney",
#     "kidney_cancer_cell",
#     "large_granular_lymphocyte",
#     "large_intestine",
#     "lateral_ventricle",
#     "lens",
#     "leukemia_cell",
#     "leukocyte",
#     "limbic_system",
#     "liver",
#     "liver_cancer_cell",
#     "locus_ceruleus",
#     "lung",
#     "lung_adenocarcinoma_cell",
#     "lung_cancer_cell",
#     "lung_squamous_cell_carcinoma_cell",
#     "lymph_node",
#     "lymphocyte",
#     "lymphoid_cell",
#     "lymphoid_cell_line",
#     "lymphoid_tissue",
#     "lymphoma_cell",
#     "lymphoma_cell_line",
#     "macroglia",
#     "macrophage",
#     "male_reproductive_gland",
#     "male_reproductive_system",
#     "mammary_epithelium",
#     "mammary_gland",
#     "marrow_cell",
#     "mast_cell",
#     "mature_ovarian_follicle",
#     "medulla_oblongata",
#     "megakaryoblast",
#     "megakaryocyte",
#     "melanocyte",
#     "melanoma_cell",
#     "mesoderm",
#     "mesothelioma_cell",
#     "mesothelium",
#     "metencephalon",
#     "midbrain",
#     "monocyte",
#     "mononuclear_cell",
#     "mononuclear_phagocyte",
#     "morula",
#     "mouth",
#     "mucosa",
#     "muscle",
#     "muscular_system",
#     "myelencephalon",
#     "myeloid_leukemia_cell",
#     "myeloid_progenitor_cell",
#     "myometrium",
#     "natural_killer_cell",
#     "neck",
#     "neostriatum",
#     "nephron",
#     "nerve",
#     "nervous_system",
#     "neural_crest",
#     "neural_crest_cell",
#     "neural_plate",
#     "neuroblast",
#     "neuroendocrine_cell",
#     "neuroendocrine_tumor_cell",
#     "neuron",
#     "neutrophil",
#     "non_small_cell_lung_cancer_cell",
#     "nucleus_accumbens",
#     "nucleus_lentiformis",
#     "null_cell",
#     "occipital_lobe",
#     "occipital_pole",
#     "organism_form",
#     "osteoblast",
#     "osteogenic_cell",
#     "other_source",
#     "ovarian_follicle",
#     "ovarian_serous_carcinoma_cell",
#     "ovary",
#     "ovary_cancer_cell",
#     "oviduct",
#     "pancreas",
#     "pancreatic_duct",
#     "pancreatic_ductal_adenocarcinoma_cell",
#     "pancreatic_ductal_carcinoma_cell",
#     "pancreatic_islet",
#     "papillary_renal_cell_carcinoma_cell",
#     "parietal_lobe",
#     "periosteum",
#     "peripheral_blood",
#     "peripheral_nervous_system",
#     "phagocyte",
#     "pheochromocytoma_cell",
#     "placenta",
#     "podocyte",
#     "pons",
#     "pre_T_lymphocyte",
#     "preosteoblast",
#     "primary_spermatocyte",
#     "prostate_adenocarcinoma_cell",
#     "prostate_gland",
#     "rectal_adenocarcinoma_cell",
#     "rectal_cancer_cell",
#     "rectum",
#     "renal_cell_carcinoma_cell",
#     "renal_clear_cell",
#     "renal_corpuscle",
#     "renal_glomerular_capsule",
#     "renal_glomerulus",
#     "renal_tubule",
#     "reproductive_system",
#     "respiratory_epithelium",
#     "respiratory_system",
#     "retina",
#     "salivary_gland",
#     "sarcoma_cell",
#     "secondary_spermatocyte",
#     "semen",
#     "sense_organ",
#     "serum",
#     "skeletal_muscle",
#     "skeletal_muscle_cancer_cell",
#     "skeletal_muscle_cell",
#     "skeletal_system",
#     "skin",
#     "skin_cancer_cell",
#     "skin_fibroblast",
#     "small_intestine",
#     "smooth_muscle",
#     "spermatid",
#     "spermatocyte",
#     "spermatogonium",
#     "spinal_cord",
#     "spleen",
#     "squamous_cell_carcinoma_cell",
#     "squamous_epithelium",
#     "stomach",
#     "stratum_spinosum",
#     "substantia_nigra",
#     "subthalamic_nucleus",
#     "tear_gland",
#     "telencephalon",
#     "temporal_lobe",
#     "testicular_cancer_cell",
#     "testis",
#     "thalamus",
#     "thorax",
#     "throat",
#     "thymic_cancer_cell",
#     "thymocyte",
#     "thymoma_cell",
#     "thymus",
#     "thyroid_cancer_cell",
#     "thyroid_gland",
#     "tissues__cell_types_and_enzyme_sources",
#     "tonsil",
#     "tooth",
#     "trachea",
#     "trophoblast",
#     "trunk",
#     "umbilical_cord",
#     "umbilical_vein",
#     "umbilical_vein_endothelial_cell",
#     "umbilical_vein_endothelium",
#     "urinary_bladder",
#     "urinary_bladder_cancer_cell",
#     "urinary_system",
#     "urinary_tract",
#     "uroepithelium",
#     "urogenital_system",
#     "uterine_cancer_cell",
#     "uterine_cervix",
#     "uterine_endometrium",
#     "uterine_sarcoma_cell",
#     "uterus",
#     "uveal_melanoma_cell",
#     "vascular_endothelial_cell",
#     "vascular_endothelium",
#     "vascular_system",
#     "vermiform_appendix",
#     "vertebrate_muscular_system",
#     "vestibular_labyrinth",
#     "vestibular_system",
#     "viscus",
#     "whole_body",
#     "zygote"
#   ]
# }

# %% [markdown]
# ### Mody query for pancreas
#
# We provide a list of 14 MODY genes. A query request is triggered, which returns a request_id You then query a results endpoint to find out if the request is finished processing and where the result is. Provided their are no errors you can download the CSV and interact with the values.
#
# This query will look at all tissues (whole_body in the Brenda tissue ontology) and limit the number of rows to 1000.

# %%
endpoint = "lilgim/query"
data = {'ids':'3630,2645,5078,6927,6928,1056,8462,4760,3172,3651,6833,640,3767,26060',
        'tissue': 'pancreas',
        'limit':10000
       }
results = wrapper(endpoint, data)
brain_lgresults = results.copy()
results.head()
# Out:
# Sent: GET http://biggim.ncats.io/api/lilgim/query?ids=3630%2C2645%2C5078%2C6927%2C6928%2C1056%2C8462%2C4760%2C3172%2C3651%2C6833%2C640%2C3767%2C26060&limit=10000&tissue=pancreas
# {
#   "status": "submitted",
#   "request_id": "3571bc45-4e40-45d6-bacb-b03a9ff92408"
# }
# Sent: GET http://biggim.ncats.io/api/lilgim/status/3571bc45-4e40-45d6-bacb-b03a9ff92408?None
# {
#   "request_id": "3571bc45-4e40-45d6-bacb-b03a9ff92408",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/3571bc45-4e40-45d6-bacb-b03a9ff92408000000000000.csv"
#   ],
#   "status": "complete",
#   "rows": 10000,
#   "processed_data": "0B",
#   "size": "461.97 KB"
# }
#     Gene1  Symbol1  Gene2  Symbol2  maxCorr  minCorr  aveCorr
# 0  169026  SLC30A8   4760  NEUROD1   0.9739   0.9017  0.93780
# 1  169026  SLC30A8   6833    ABCC8   0.9587   0.8869  0.92280
# 2   11189    CELF3   6833    ABCC8   0.9640   0.8737  0.91885
# 3   29106     SCG3   4760  NEUROD1   0.9649   0.8593  0.91210
# 4  222546     RFX6   4760  NEUROD1   0.9676   0.8310  0.89930

# %% [markdown]
#    ## Big GIM query for Mody genes in healthy pancreas

# %%
#prep
import time
import pandas
studies = get('metadata/study')
study_names = [s['name'] for s in studies]
tables = get('/metadata/table')
default_table = [t for t in tables if t['default'] == True][0]['name']
print(default_table)
# Out:
# Sent: GET http://biggim.ncats.io/api/metadata/study?None
# Sent: GET http://biggim.ncats.io/api//metadata/table?None
# BigGIM_70_v1

# %%
example_query = {
  "restriction_gt": "GTEx_Pancreas_Correlation,.2",
  "table": default_table,
  "columns": "GTEx_Pancreas_Correlation",
  "ids1": "3630,2645,5078,6927,6928,1056,8462,4760,3172,3651,6833,640,3767,26060",
  "limit": 100000
}
try:
    query_submit = get('biggim/query', data=example_query)
    jprint(query_submit)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())


try:
    while True:
        query_status = get('biggim/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(1)
            print("Checking again")
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
    
result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
result
# Out:
# Sent: GET http://biggim.ncats.io/api/biggim/query?table=BigGIM_70_v1&columns=GTEx_Pancreas_Correlation&restriction_gt=GTEx_Pancreas_Correlation%2C.2&ids1=3630%2C2645%2C5078%2C6927%2C6928%2C1056%2C8462%2C4760%2C3172%2C3651%2C6833%2C640%2C3767%2C26060&limit=100000
# {
#   "status": "submitted",
#   "request_id": "e2ca5607-3434-45a2-b46c-b88335c15ce4"
# }
# Sent: GET http://biggim.ncats.io/api/biggim/status/e2ca5607-3434-45a2-b46c-b88335c15ce4?None
# {
#   "request_id": "e2ca5607-3434-45a2-b46c-b88335c15ce4",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/e2ca5607-3434-45a2-b46c-b88335c15ce4000000000000.csv"
#   ],
#   "status": "complete",
#   "rows": 27919,
#   "processed_data": "0B",
#   "size": "898.09 KB"
# }
#                   GPID      Gene1  Gene2  GTEx_Pancreas_Correlation
# 0       84620000064225      64225   8462                     0.2500
# 1       20640000003172       3172   2064                     0.2500
# 2       26450000009839       9839   2645                     0.2500
# 3        6400000023151      23151    640                     0.2500
# 4        6400000055623      55623    640                     0.2500
# 5        6400000004221       4221    640                     0.2500
# 6       47600100134229  100134229   4760                     0.2500
# 7       68330000085004      85004   6833                     0.2500
# 8       68330000130940     130940   6833                     0.2500
# 9       37670000010979      10979   3767                     0.2500
# 10      37670000007525       7525   3767                     0.2500
# 11      40340000006833       6833   4034                     0.2500
# 12      50780000023299      23299   5078                     0.2500
# 13      69270000056127      56127   6927                     0.3125
# 14       8010000006927       6927    801                     0.3125
# 15       3300000026060      26060    330                     0.3125
# 16      37670000023025      23025   3767                     0.3125
# 17      69270000008767       8767   6927                     0.3750
# 18      26450000093190      93190   2645                     0.3750
# 19      26450000023373      23373   2645                     0.3750
# 20     259480000026060      26060  25948                     0.3750
# 21      31720000064145      64145   3172                     0.3750
# 22      70130000008462       8462   7013                     0.3750
# 23      68330000026575      26575   6833                     0.3750
# 24      37670000010522      10522   3767                     0.3750
# 25      37670000051061      51061   3767                     0.3750
# 26     260600000064785      64785  26060                     0.3750
# 27      84620000051522      51522   8462                     0.4375
# 28      69270000023604      23604   6927                     0.4375
# 29      69270000222643     222643   6927                     0.4375
# ...                ...        ...    ...                        ...
# 27889   47600000201176     201176   4760                     0.3018
# 27890    9390000003651       3651    939                     0.3018
# 27891   37670000010888      10888   3767                     0.3018
# 27892  260600000084376      84376  26060                     0.3018
# 27893   84620000079705      79705   8462                     0.3643
# 27894   84620000079577      79577   8462                     0.3643
# 27895   36720000004760       4760   3672                     0.3643
# 27896   31720000085417      85417   3172                     0.3643
# 27897   68330000009315       9315   6833                     0.3643
# 27898   37670000084186      84186   3767                     0.3643
# 27899   14650000003651       3651   1465                     0.3643
# 27900   30260000006927       6927   3026                     0.3643
# 27901   69270000126074     126074   6927                     0.4268
# 27902   36510000005792       5792   3651                     0.4268
# 27903   37670000057111      57111   3767                     0.4268
# 27904   37670000005409       5409   3767                     0.4268
# 27905  260600000081034      81034  26060                     0.4268
# 27906   76780000026060      26060   7678                     0.4268
# 27907   84620000010114      10114   8462                     0.4893
# 27908   69270000064779      64779   6927                     0.4893
# 27909   69270000026099      26099   6927                     0.4893
# 27910   31720000006490       6490   3172                     0.4893
# 27911   98410000026060      26060   9841                     0.4893
# 27912   42360000006927       6927   4236                     0.4893
# 27913  260600000120892     120892  26060                     0.4893
# 27914  230390000026060      26060  23039                     0.4893
# 27915   26450000121256     121256   2645                     0.6036
# 27916   68330000006855       6855   6833                     0.6661
# 27917   46010000026060      26060   4601                     0.6661
# 27918  260600000119504     119504  26060                     0.7286
#
# [27919 rows x 4 columns]

# %% [markdown]
#    ## Take 500 genes with highest similarity to the Mody genes

# %%
df = result
df = df.sort_values(by='GTEx_Pancreas_Correlation',ascending=False)
df = df.reset_index()
del df['index']
gene_list = []
i = len(gene_list)
for index, row in df.iterrows():
    if i==500:
        break
    gene_list.append(row['Gene1'])
    gene_list.append(row['Gene2'])
# %% [markdown]
#    ## Big GIM query for Mody genes in pancreas - NDEx input

# %%
#ids1 and ids2 now contain the 500 genes most associated with the 14 Mody genes (including the 14 Mody genes)
example_query = {
  "restriction_gt": "GTEx_Pancreas_Correlation,-2",
  "table": default_table,
  "columns": "GTEx_Pancreas_Correlation",
  "ids1": str1,
  "ids2": str1,
  "limit": 124750
}
try:
    query_submit = get('biggim/query', data=example_query)
    jprint(query_submit)
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())


try:
    while True:
        query_status = get('biggim/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(1)
            print("Checking again")
except requests.HTTPError as e:
    print(e)
    
    jprint(e.response.json())
    
result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
result
# Out:
# Sent: GET http://biggim.ncats.io/api/biggim/query?table=BigGIM_70_v1&columns=GTEx_Pancreas_Correlation&limit=124750&ids2=22%2C51%2C52%2C91%2C116%2C316%2C405%2C573%2C653%2C694%2C773%2C816%2C900%2C976%2C988%2C1045%2C1113%2C1114%2C1131%2C1141%2C1207%2C1272%2C1363%2C1457%2C1615%2C1662%2C1729%2C1951%2C1956%2C1965%2C1974%2C1992%2C1996%2C1997%2C2309%2C2339%2C2572%2C2641%2C2642%2C2645%2C2775%2C2781%2C2786%2C2864%2C2891%2C2892%2C2926%2C2961%2C2965%2C3185%2C3297%2C3326%2C3382%2C3431%2C3454%2C3588%2C3630%2C3642%2C3651%2C3652%2C3670%2C3735%2C3741%2C3752%2C3757%2C3763%2C3785%2C3800%2C3837%2C3840%2C3842%2C3843%2C3895%2C4013%2C4076%2C4135%2C4179%2C4217%2C4651%2C4661%2C4729%2C4733%2C4760%2C4763%2C4782%2C4821%2C4928%2C5001%2C5036%2C5045%2C5062%2C5080%2C5094%2C5108%2C5122%2C5126%2C5236%2C5283%2C5291%2C5432%2C5464%2C5501%2C5502%2C5522%2C5525%2C5537%2C5711%2C5718%2C5771%2C5798%2C5865%2C5887%2C5910%2C5917%2C5923%2C5981%2C5982%2C6009%2C6095%2C6198%2C6252%2C6258%2C6418%2C6456%2C6599%2C6616%2C6672%2C6732%2C6749%2C6750%2C6780%2C6804%2C6833%2C6855%2C6860%2C6861%2C6924%2C6927%2C7014%2C7049%2C7071%2C7084%2C7111%2C7251%2C7266%2C7270%2C7276%2C7320%2C7322%2C7323%2C7329%2C7345%2C7398%2C7444%2C7458%2C7469%2C7494%2C7525%2C7555%2C7844%2C7857%2C7913%2C8027%2C8030%2C8086%2C8204%2C8310%2C8315%2C8439%2C8443%2C8451%2C8452%2C8462%2C8533%2C8661%2C8662%2C8715%2C8725%2C8763%2C8780%2C8833%2C8881%2C8882%2C8883%2C8938%2C8941%2C9053%2C9066%2C9118%2C9188%2C9218%2C9254%2C9255%2C9312%2C9318%2C9342%2C9527%2C9541%2C9589%2C9616%2C9665%2C9699%2C9705%2C9729%2C9767%2C9821%2C9846%2C9868%2C9878%2C9892%2C9960%2C10006%2C10009%2C10054%2C10106%2C