# %% [markdown]
# # Workflow 1, Module 2, Question 4

# %% [markdown]
# ## What genes are involved in [pathway/process]?

# %% [markdown]
# ### Define some functions for use below

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import json
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://{robokop_server}/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %% [markdown]
# ### Get the inputs to question 4

# %% [markdown]
# We'll start question 4 by getting the set of genes from the enrichment version of question 3.

# %%
PRKAA1 = 'HGNC:9376'
XBP1 = 'HGNC:12801'
MTATP1 = 'HGNC:7414'
NEIL1 = 'HGNC:18448'
FRK = 'HGNC:3955'

mody_genes = [PRKAA1,XBP1,MTATP1,NEIL1,FRK]

# %%
enriched_processes = enrichment('gene',mody_genes,'biological_process_or_activity')
process_frame = pd.DataFrame(enriched_processes)
process_frame
# Out:
# Return Status: 200
#             id                                               name         p
# 0   GO:0055089                             fatty acid homeostasis  0.000004
# 1   GO:0006633                    fatty acid biosynthetic process  0.000025
# 2   GO:0042149            cellular response to glucose starvation  0.000025
# 3   GO:0071333              cellular response to glucose stimulus  0.000064
# 4   GO:0009631                                   cold acclimation  0.000425
# 5   GO:0062028              regulation of stress granule assembly  0.000425
# 6   GO:0050405           [acetyl-CoA carboxylase] kinase activity  0.000425
# 7   GO:2000758  positive regulation of peptidyl-lysine acetyla...  0.000425
# 8   GO:0047322  [hydroxymethylglutaryl-CoA reductase (NADPH)] ...  0.000425
# 9   GO:0035404                     histone-serine phosphorylation  0.000638
# 10  GO:0006990  positive regulation of transcription from RNA ...  0.000638
# 11  GO:0035470      positive regulation of vascular wound healing  0.000638
# 12  GO:0055092                                 sterol homeostasis  0.000638
# 13  GO:1990418    response to insulin-like growth factor stimulus  0.000638
# 14  GO:0061762                       CAMKK-AMPK signaling cascade  0.000638
# 15  GO:1903489                   positive regulation of lactation  0.000638
# 16  GO:0008022                         protein C-terminus binding  0.000780
# 17  GO:2001274  negative regulation of glucose import in respo...  0.000851
# 18  GO:0071417       cellular response to organonitrogen compound  0.000851
# 19  GO:0061744                                     motor behavior  0.000851
# 20  GO:0031670                      cellular response to nutrient  0.001063
# 21  GO:1900103  positive regulation of endoplasmic reticulum u...  0.001063
# 22  GO:1904428       negative regulation of tubulin deacetylation  0.001063
# 23  GO:0035174                     histone serine kinase activity  0.001063
# 24  GO:0045542  positive regulation of cholesterol biosyntheti...  0.001063
# 25  GO:0071332             cellular response to fructose stimulus  0.001063
# 26  GO:0045348  positive regulation of MHC class II biosynthet...  0.001276
# 27  GO:0004679              AMP-activated protein kinase activity  0.001276
# 28  GO:0016798       hydrolase activity, acting on glycosyl bonds  0.001276
# 29  GO:0002639   positive regulation of immunoglobulin production  0.001276
# ..         ...                                                ...       ...
# 70  GO:0032007               negative regulation of TOR signaling  0.006154
# 71  GO:0070507  regulation of microtubule cytoskeleton organiz...  0.006154
# 72  GO:0010332                        response to gamma radiation  0.006365
# 73  GO:0022857                 transmembrane transporter activity  0.006577
# 74  GO:0042407                                  cristae formation  0.006577
# 75  GO:1903955  positive regulation of protein targeting to mi...  0.006577
# 76  GO:0043066           negative regulation of apoptotic process  0.006608
# 77  GO:0070059  intrinsic apoptotic signaling pathway in respo...  0.006789
# 78  GO:0038083              peptidyl-tyrosine autophosphorylation  0.007000
# 79  GO:0097009                                 energy homeostasis  0.007000
# 80  GO:0030968    endoplasmic reticulum unfolded protein response  0.008269
# 81  GO:0006468                            protein phosphorylation  0.008644
# 82  GO:0006695                   cholesterol biosynthetic process  0.008691
# 83  GO:0031648                            protein destabilization  0.008902
# 84  GO:0014823                               response to activity  0.008902
# 85  GO:0004715  non-membrane spanning protein tyrosine kinase ...  0.009114
# 86  GO:0010508                   positive regulation of autophagy  0.009114
# 87  GO:0042752                     regulation of circadian rhythm  0.010169
# 88  GO:0045600    positive regulation of fat cell differentiation  0.010380
# 89  GO:0048666                                 neuron development  0.010591
# 90  GO:0048511                                   rhythmic process  0.010802
# 91  GO:0009411                                     response to UV  0.010802
# 92  GO:0001085     RNA polymerase II transcription factor binding  0.011013
# 93  GO:0036498            IRE1-mediated unfolded protein response  0.011223
# 94  GO:0071230           cellular response to amino acid stimulus  0.011434
# 95  GO:0030154                               cell differentiation  0.011598
# 96  GO:0001889                                  liver development  0.011856
# 97  GO:0070301             cellular response to hydrogen peroxide  0.012698
# 98  GO:0006284                               base-excision repair  0.012909
# 99  GO:0007169  transmembrane receptor protein tyrosine kinase...  0.014171
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Strategy 1: expand with loop

# %% [markdown]
# If you want to know the genes involved in a process, you can use expand.  If you have a list of processes and you want to know the union of all genes involved with, this is the best approach.

# %% [markdown]
# Expand takes a single process, so you need to call it individually.  Here we combine the results into a single frame, but you may wish to handle it differently.  We'll (arbitrarily) limit to the top 10 processes by enrichment score.

# %%
top_10 = process_frame.iloc[:10]

# %%
gframes = []
for process in top_10['id']:
    genes = expand('biological_process_or_activity',process,'gene')
    gene_frame = parse_answer(genes)
    gene_frame['process'] = process
    gframes.append(gene_frame)
all_genes = pd.concat(gframes)
all_genes
# Out:
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
# Return Status: 200
#      result_id result_name                                source  \
# 0    HGNC:7967       NR1H4  biolink.gene_get_process_or_function
# 1    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 2   HGNC:12744      MLXIPL  biolink.gene_get_process_or_function
# 3      HGNC:61       ABCD1  biolink.gene_get_process_or_function
# 4    HGNC:2843       DGAT1  biolink.gene_get_process_or_function
# 5   HGNC:14929       SIRT1  biolink.gene_get_process_or_function
# 6     HGNC:613        APOE  biolink.gene_get_process_or_function
# 7    HGNC:9175       POLD1  biolink.gene_get_process_or_function
# 8    HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 9   HGNC:24865        GPAM  biolink.gene_get_process_or_function
# 10   HGNC:4432        GOT1  biolink.gene_get_process_or_function
# 11    HGNC:262      ADORA1  biolink.gene_get_process_or_function
# 12  HGNC:16940       DGAT2  biolink.gene_get_process_or_function
# 13  HGNC:12801        XBP1  biolink.gene_get_process_or_function
# 14   HGNC:6081         INS  biolink.gene_get_process_or_function
# 0    HGNC:3594        FASN  biolink.gene_get_process_or_function
# 1      HGNC:84       ACACA  biolink.gene_get_process_or_function
# 2     HGNC:115        ACLY  biolink.gene_get_process_or_function
# 3   HGNC:29622        MCAT  biolink.gene_get_process_or_function
# 4      HGNC:85       ACACB  biolink.gene_get_process_or_function
# 5   HGNC:14415      ELOVL4  biolink.gene_get_process_or_function
# 6    HGNC:6677         LPL  biolink.gene_get_process_or_function
# 7    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 8   HGNC:19691        MECR  biolink.gene_get_process_or_function
# 9    HGNC:3570       ACSL3  biolink.gene_get_process_or_function
# 10  HGNC:12801        XBP1  biolink.gene_get_process_or_function
# 11   HGNC:9378      PRKAB1  biolink.gene_get_process_or_function
# 12   HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 13   HGNC:7150       MLYCD  biolink.gene_get_process_or_function
# 14  HGNC:25891        CBR4  biolink.gene_get_process_or_function
# ..         ...         ...                                   ...
# 43   HGNC:2651      CYP7A1  biolink.gene_get_process_or_function
# 44   HGNC:8616        PAX2  biolink.gene_get_process_or_function
# 45   HGNC:5344       ICAM1  biolink.gene_get_process_or_function
# 46   HGNC:6126        IRS2  biolink.gene_get_process_or_function
# 47   HGNC:1514        CASR  biolink.gene_get_process_or_function
# 48  HGNC:12801        XBP1  biolink.gene_get_process_or_function
# 49   HGNC:7010        MEN1  biolink.gene_get_process_or_function
# 50   HGNC:3821       FOXO3  biolink.gene_get_process_or_function
# 51   HGNC:7891        NOX4  biolink.gene_get_process_or_function
# 52  HGNC:12518        UCP2  biolink.gene_get_process_or_function
# 53   HGNC:4173       GATA4  biolink.gene_get_process_or_function
# 54  HGNC:11291         SRF  biolink.gene_get_process_or_function
# 55   HGNC:9237    PPARGC1A  biolink.gene_get_process_or_function
# 56   HGNC:5992        IL1B  biolink.gene_get_process_or_function
# 57   HGNC:8975      PIK3CA  biolink.gene_get_process_or_function
# 58  HGNC:11359        STAR  biolink.gene_get_process_or_function
# 59  HGNC:11782          TH  biolink.gene_get_process_or_function
# 0    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 1   HGNC:28566       SAXO1  biolink.gene_get_process_or_function
# 0    HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 1    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 0    HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 1    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 0    HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 1    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 0    HGNC:9377      PRKAA2  biolink.gene_get_process_or_function
# 1    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 0    HGNC:9376      PRKAA1  biolink.gene_get_process_or_function
# 1   HGNC:11391       AURKC  biolink.gene_get_process_or_function
# 2   HGNC:11393       AURKA  biolink.gene_get_process_or_function
#
#                     type     process
# 0   actively_involved_in  GO:0055089
# 1   actively_involved_in  GO:0055089
# 2   actively_involved_in  GO:0055089
# 3   actively_involved_in  GO:0055089
# 4   actively_involved_in  GO:0055089
# 5   actively_involved_in  GO:0055089
# 6   actively_involved_in  GO:0055089
# 7   actively_involved_in  GO:0055089
# 8   actively_involved_in  GO:0055089
# 9   actively_involved_in  GO:0055089
# 10  actively_involved_in  GO:0055089
# 11  actively_involved_in  GO:0055089
# 12  actively_involved_in  GO:0055089
# 13  actively_involved_in  GO:0055089
# 14  actively_involved_in  GO:0055089
# 0   actively_involved_in  GO:0006633
# 1   actively_involved_in  GO:0006633
# 2   actively_involved_in  GO:0006633
# 3   actively_involved_in  GO:0006633
# 4   actively_involved_in  GO:0006633
# 5   actively_involved_in  GO:0006633
# 6   actively_involved_in  GO:0006633
# 7   actively_involved_in  GO:0006633
# 8   actively_involved_in  GO:0006633
# 9   actively_involved_in  GO:0006633
# 10  actively_involved_in  GO:0006633
# 11  actively_involved_in  GO:0006633
# 12  actively_involved_in  GO:0006633
# 13  actively_involved_in  GO:0006633
# 14  actively_involved_in  GO:0006633
# ..                   ...         ...
# 43  actively_involved_in  GO:0071333
# 44  actively_involved_in  GO:0071333
# 45  actively_involved_in  GO:0071333
# 46  actively_involved_in  GO:0071333
# 47  actively_involved_in  GO:0071333
# 48  actively_involved_in  GO:0071333
# 49  actively_involved_in  GO:0071333
# 50  actively_involved_in  GO:0071333
# 51  actively_involved_in  GO:0071333
# 52  actively_involved_in  GO:0071333
# 53  actively_involved_in  GO:0071333
# 54  actively_involved_in  GO:0071333
# 55  actively_involved_in  GO:0071333
# 56  actively_involved_in  GO:0071333
# 57  actively_involved_in  GO:0071333
# 58  actively_involved_in  GO:0071333
# 59  actively_involved_in  GO:0071333
# 0   actively_involved_in  GO:0009631
# 1   actively_involved_in  GO:0009631
# 0   actively_involved_in  GO:0062028
# 1   actively_involved_in  GO:0062028
# 0   actively_involved_in  GO:0050405
# 1   actively_involved_in  GO:0050405
# 0   actively_involved_in  GO:2000758
# 1   actively_involved_in  GO:2000758
# 0   actively_involved_in  GO:0047322
# 1   actively_involved_in  GO:0047322
# 0   actively_involved_in  GO:0035404
# 1   actively_involved_in  GO:0035404
# 2   actively_involved_in  GO:0035404
#
# [164 rows x 5 columns]

# %% [markdown]
# ### Enrichment

# %% [markdown]
# If you don't care about every process that every gene is involved with, but are instead trying to find the most common process, you can use enrichment and do a single call.  Since biological processes are part of an ontology, let's also use descendants.

# %%
enriched_genes = enrichment('biological_process_or_activity',list(top_10['id']),'gene',include_descendants=True)
# Out:
# Return Status: 200

# %%
pd.DataFrame(enriched_genes)
# Out:
#             id       name             p
