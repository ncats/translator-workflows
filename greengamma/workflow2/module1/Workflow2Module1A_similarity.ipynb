# %% [markdown]
# # Workflow 2, Module 1A

# %% [markdown]
# ## Gene functional similarity

# %% [markdown]
# ### Set up functions

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def similarity(type1,ident,type2,by_type,threshhold=None,maxresults=None,rebuild=None):
    url=f'http://{robokop_server}/api/simple/similarity/{type1}/{ident}/{type2}/{by_type}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.get(url, params = params)
    print( 'Return code:',response.status_code )
    return response.json()

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %% [markdown]
# ### Expand from disease to genes

# %%
FA='MONDO:0019391'
fa_genes = expand('disease',FA,'gene')
fa_gene_frame = parse_answer(fa_genes)
fa_gene_frame
# Out:
# Return Status: 200
#      result_id result_name                   source  \
# 0    HGNC:3585      FANCD2  pharos.gene_get_disease
# 1    HGNC:3588       FANCG  pharos.gene_get_disease
# 2    HGNC:3582       FANCA  pharos.gene_get_disease
# 3   HGNC:23168       FANCM  pharos.disease_get_gene
# 4    HGNC:3587       FANCF  pharos.gene_get_disease
# 5   HGNC:26144       PALB2  pharos.disease_get_gene
# 6    HGNC:3586       FANCE  pharos.disease_get_gene
# 7    HGNC:9820      RAD51C  pharos.disease_get_gene
# 8    HGNC:3583       FANCB  pharos.disease_get_gene
# 9   HGNC:25009       UBE2T  pharos.gene_get_disease
# 10   HGNC:9817       RAD51  pharos.disease_get_gene
# 11   HGNC:3436       ERCC4  pharos.disease_get_gene
# 12  HGNC:25539       RFWD3  pharos.gene_get_disease
# 13   HGNC:3584       FANCC  pharos.gene_get_disease
# 14   HGNC:1101       BRCA2  pharos.gene_get_disease
# 15   HGNC:6764      MAD2L2  pharos.disease_get_gene
# 16  HGNC:25568       FANCI  pharos.disease_get_gene
# 17  HGNC:20748       FANCL  pharos.gene_get_disease
# 18  HGNC:20473       BRIP1  pharos.disease_get_gene
# 19  HGNC:23845        SLX4  pharos.disease_get_gene
# 20  HGNC:29170        FAN1  pharos.gene_get_disease
# 21  HGNC:29814       MUS81  pharos.gene_get_disease
# 22  HGNC:12791         WRN  pharos.gene_get_disease
# 23  HGNC:12814         XPA  pharos.disease_get_gene
# 24   HGNC:1058         BLM  pharos.gene_get_disease
# 25  HGNC:12829       XRCC2  pharos.gene_get_disease
# 26  HGNC:14060        REV1  pharos.disease_get_gene
# 27  HGNC:26171     FAAP100  pharos.disease_get_gene
# 28   HGNC:2736       DDX11  pharos.gene_get_disease
# 29  HGNC:33499       ATRIP  pharos.gene_get_disease
# 30   HGNC:4739       H2AFX  pharos.disease_get_gene
# 31  HGNC:10071        RNF8  pharos.gene_get_disease
# 32   HGNC:2939        DNA2  pharos.gene_get_disease
# 33  HGNC:17641     DCLRE1B  pharos.gene_get_disease
# 34   HGNC:9823      RAD51D  pharos.gene_get_disease
# 35  HGNC:25764        RMI1  pharos.disease_get_gene
# 36  HGNC:18536        HELQ  pharos.gene_get_disease
# 37  HGNC:16956    RAD51AP1  pharos.gene_get_disease
# 38  HGNC:11999     TP53BP1  pharos.gene_get_disease
# 39  HGNC:17660     DCLRE1A  pharos.disease_get_gene
# 40  HGNC:25752       ATAD5  pharos.gene_get_disease
# 41  HGNC:18870        POLN  pharos.gene_get_disease
# 42  HGNC:13620        FBH1  pharos.gene_get_disease
# 43   HGNC:7532         MX1  pharos.disease_get_gene
# 44  HGNC:19427      GGNBP1  pharos.gene_get_disease
# 45    HGNC:795         ATM  pharos.gene_get_disease
# 46  HGNC:23163       CENPS  pharos.gene_get_disease
# 47  HGNC:20994      ZSCAN2  pharos.disease_get_gene
# 48  HGNC:28748       SLX1B  pharos.gene_get_disease
# 49  HGNC:24965        EME1  pharos.gene_get_disease
# 50  HGNC:11422       CENPX  pharos.disease_get_gene
# 51  HGNC:20922       SLX1A  pharos.disease_get_gene
# 52  HGNC:37101     DDX11L8  pharos.gene_get_disease
# 53  HGNC:31792      BOD1L1  pharos.gene_get_disease
# 54   HGNC:2737      DDX12P  pharos.disease_get_gene
# 55  HGNC:30298       UIMC1  pharos.gene_get_disease
# 56  HGNC:11892         TNF  pharos.disease_get_gene
#
#                            type
# 0   disease_to_gene_association
# 1   disease_to_gene_association
# 2   disease_to_gene_association
# 3   disease_to_gene_association
# 4   disease_to_gene_association
# 5   disease_to_gene_association
# 6   disease_to_gene_association
# 7   disease_to_gene_association
# 8   disease_to_gene_association
# 9   disease_to_gene_association
# 10  disease_to_gene_association
# 11  disease_to_gene_association
# 12  disease_to_gene_association
# 13  disease_to_gene_association
# 14  disease_to_gene_association
# 15  disease_to_gene_association
# 16  disease_to_gene_association
# 17  disease_to_gene_association
# 18  disease_to_gene_association
# 19  disease_to_gene_association
# 20  disease_to_gene_association
# 21  disease_to_gene_association
# 22  disease_to_gene_association
# 23  disease_to_gene_association
# 24  disease_to_gene_association
# 25  disease_to_gene_association
# 26  disease_to_gene_association
# 27  disease_to_gene_association
# 28  disease_to_gene_association
# 29  disease_to_gene_association
# 30  disease_to_gene_association
# 31  disease_to_gene_association
# 32  disease_to_gene_association
# 33  disease_to_gene_association
# 34  disease_to_gene_association
# 35  disease_to_gene_association
# 36  disease_to_gene_association
# 37  disease_to_gene_association
# 38  disease_to_gene_association
# 39  disease_to_gene_association
# 40  disease_to_gene_association
# 41  disease_to_gene_association
# 42  disease_to_gene_association
# 43  disease_to_gene_association
# 44  disease_to_gene_association
# 45  disease_to_gene_association
# 46  disease_to_gene_association
# 47  disease_to_gene_association
# 48  disease_to_gene_association
# 49  disease_to_gene_association
# 50  disease_to_gene_association
# 51  disease_to_gene_association
# 52  disease_to_gene_association
# 53  disease_to_gene_association
# 54  disease_to_gene_association
# 55  disease_to_gene_association
# 56  disease_to_gene_association

# %% [markdown]
# ## Similiarity

# %% [markdown]
# Now we have a list of genes.  Let's find genes with similar biological processes.  Here's a query for doing that for one of the genes:

# %%
genes = list(fa_gene_frame['result_id'])
similar = similarity('gene',genes[0],'gene','biological_process_or_activity',threshhold=0.1)
pd.DataFrame(similar)
# Out:
# Return code: 200
#                  id              name  similarity
# 0         HGNC:3584             FANCC    0.333333
# 1         HGNC:3582             FANCA    0.315789
# 2        HGNC:25568             FANCI    0.214286
# 3        HGNC:20748             FANCL    0.142857
# 4        HGNC:30705           SPATA22    0.142857
# 5  UniProtKB:D9MXF4  UniProtKB:D9MXF4    0.117647
# 6        HGNC:11738             TEX15    0.111111
# 7        HGNC:19849          C14orf39    0.105263
# 8         HGNC:3588             FANCG    0.105263

# %% [markdown]
# So we want to do this for each of the FA genes, and we want to only include results that aren't already part of the original gene list.

# %%
sim_frames = []
for row in fa_gene_frame.iterrows():
    similar = similarity('gene',row[1]['result_id'],'gene','biological_process_or_activity',threshhold=0.1)
    sframe = pd.DataFrame(similar)
    sframe['query_id'] = row[1]['result_id']
    sframe['query_name'] = row[1]['result_name']
    sim_frames.append(sframe)
all_sim = pd.concat(sim_frames)
# Out:
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200

# %%
all_sim
# Out:
#                       id                  name  similarity    query_id  \
# 0              HGNC:3584                 FANCC    0.333333   HGNC:3585
# 1              HGNC:3582                 FANCA    0.315789   HGNC:3585
# 2             HGNC:25568                 FANCI    0.214286   HGNC:3585
# 3             HGNC:20748                 FANCL    0.142857   HGNC:3585
# 4             HGNC:30705               SPATA22    0.142857   HGNC:3585
# 5       UniProtKB:D9MXF4      UniProtKB:D9MXF4    0.117647   HGNC:3585
# 6             HGNC:11738                 TEX15    0.111111   HGNC:3585
# 7             HGNC:19849              C14orf39    0.105263   HGNC:3585
# 8              HGNC:3588                 FANCG    0.105263   HGNC:3585
# 0       UniProtKB:A1L461      UniProtKB:A1L461    0.333333   HGNC:3588
# 1       UniProtKB:D9MXF4      UniProtKB:D9MXF4    0.272727   HGNC:3588
# 2              HGNC:3587                 FANCF    0.272727   HGNC:3588
# 3       UniProtKB:B3KVC6      UniProtKB:B3KVC6    0.250000   HGNC:3588
# 4   UniProtKB:A0A2P9AC96  UniProtKB:A0A2P9AC96    0.250000   HGNC:3588
# 5             HGNC:26171               FAAP100    0.250000   HGNC:3588
# 6   UniProtKB:A0A2P9A9L1  UniProtKB:A0A2P9A9L1    0.250000   HGNC:3588
# 7       UniProtKB:B4DN49      UniProtKB:B4DN49    0.250000   HGNC:3588
# 8       UniProtKB:B7ZA36      UniProtKB:B7ZA36    0.250000   HGNC:3588
# 9       UniProtKB:B7Z780      UniProtKB:B7Z780    0.250000   HGNC:3588
# 10      UniProtKB:B4DRT6      UniProtKB:B4DRT6    0.222222   HGNC:3588
# 11  UniProtKB:A0A2P9AP44  UniProtKB:A0A2P9AP44    0.222222   HGNC:3588
# 12  UniProtKB:A0A2P9ASQ9  UniProtKB:A0A2P9ASQ9    0.222222   HGNC:3588
# 13  UniProtKB:A0A2P9AHK0  UniProtKB:A0A2P9AHK0    0.222222   HGNC:3588
# 14      UniProtKB:B4DUS0      UniProtKB:B4DUS0    0.222222   HGNC:3588
# 15            HGNC:24994                  INIP    0.222222   HGNC:3588
# 16            HGNC:31792                BOD1L1    0.222222   HGNC:3588
# 17      UniProtKB:B4E318      UniProtKB:B4E318    0.222222   HGNC:3588
# 18  UniProtKB:A0A2P9ATP0  UniProtKB:A0A2P9ATP0    0.222222   HGNC:3588
# 19      UniProtKB:B4DNU0      UniProtKB:B4DNU0    0.222222   HGNC:3588
# 20  UniProtKB:A0A126LB28  UniProtKB:A0A126LB28    0.222222   HGNC:3588
# ..                   ...                   ...         ...         ...
# 75            HGNC:20647                ZNF418    0.133333  HGNC:30298
# 76            HGNC:20646                ZNF417    0.133333  HGNC:30298
# 77            HGNC:17625                ZNF674    0.133333  HGNC:30298
# 78            HGNC:16673                ANP32E    0.133333  HGNC:30298
# 79            HGNC:25200                 CIART    0.133333  HGNC:30298
# 80             HGNC:1104                  BRD3    0.133333  HGNC:30298
# 81            HGNC:25117               RIPPLY1    0.133333  HGNC:30298
# 82            HGNC:29810              MPHOSPH8    0.133333  HGNC:30298
# 83             HGNC:1556                  CBX6    0.133333  HGNC:30298
# 84            HGNC:13013                 KAT6A    0.133333  HGNC:30298
# 85            HGNC:15866                 MRGBP    0.133333  HGNC:30298
# 86            HGNC:16223                COMMD7    0.133333  HGNC:30298
# 87            HGNC:24926               CCDC85B    0.133333  HGNC:30298
# 88            HGNC:24173                ATXN3L    0.133333  HGNC:30298
# 89            HGNC:13083                ZBTB21    0.133333  HGNC:30298
# 90            HGNC:26765                ZNF776    0.133333  HGNC:30298
# 91            HGNC:18071                  EMSY    0.133333  HGNC:30298
# 92            HGNC:30955                ZNF587    0.133333  HGNC:30298
# 93            HGNC:18291                 DMAP1    0.130435  HGNC:30298
# 94             HGNC:9350                 PRDM6    0.130435  HGNC:30298
# 95            HGNC:18128                HDAC10    0.130435  HGNC:30298
# 96            HGNC:13017                ZNF224    0.125000  HGNC:30298
# 97            HGNC:19866                 MBTD1    0.125000  HGNC:30298
# 98            HGNC:29090                SMCHD1    0.125000  HGNC:30298
# 0              HGNC:5992                  IL1B    0.171806  HGNC:11892
# 1              HGNC:6018                   IL6    0.114943  HGNC:11892
# 2              HGNC:7562                 MYD88    0.110390  HGNC:11892
# 3             HGNC:12036                 TRAF6    0.104972  HGNC:11892
# 4             HGNC:11849                  TLR3    0.104046  HGNC:11892
# 5              HGNC:5438                  IFNG    0.101190  HGNC:11892
#
#    query_name
# 0      FANCD2
# 1      FANCD2
# 2      FANCD2
# 3      FANCD2
# 4      FANCD2
# 5      FANCD2
# 6      FANCD2
# 7      FANCD2
# 8      FANCD2
# 0       FANCG
# 1       FANCG
# 2       FANCG
# 3       FANCG
# 4       FANCG
# 5       FANCG
# 6       FANCG
# 7       FANCG
# 8       FANCG
# 9       FANCG
# 10      FANCG
# 11      FANCG
# 12      FANCG
# 13      FANCG
# 14      FANCG
# 15      FANCG
# 16      FANCG
# 17      FANCG
# 18      FANCG
# 19      FANCG
# 20      FANCG
# ..        ...
# 75      UIMC1
# 76      UIMC1
# 77      UIMC1
# 78      UIMC1
# 79      UIMC1
# 80      UIMC1
# 81      UIMC1
# 82      UIMC1
# 83      UIMC1
# 84      UIMC1
# 85      UIMC1
# 86      UIMC1
# 87      UIMC1
# 88      UIMC1
# 89      UIMC1
# 90      UIMC1
# 91      UIMC1
# 92      UIMC1
# 93      UIMC1
# 94      UIMC1
# 95      UIMC1
# 96      UIMC1
# 97      UIMC1
# 98      UIMC1
# 0         TNF
# 1         TNF
# 2         TNF
# 3         TNF
# 4         TNF
# 5         TNF
#
# [4525 rows x 5 columns]

# %%
v = all_sim['query_name'].values
new_genes = all_sim[ ~ all_sim['name'].isin(v) ]
new_genes
# Out:
#                       id                  name  similarity    query_id  \
# 4             HGNC:30705               SPATA22    0.142857   HGNC:3585
# 5       UniProtKB:D9MXF4      UniProtKB:D9MXF4    0.117647   HGNC:3585
# 6             HGNC:11738                 TEX15    0.111111   HGNC:3585
# 7             HGNC:19849              C14orf39    0.105263   HGNC:3585
# 0       UniProtKB:A1L461      UniProtKB:A1L461    0.333333   HGNC:3588
# 1       UniProtKB:D9MXF4      UniProtKB:D9MXF4    0.272727   HGNC:3588
# 3       UniProtKB:B3KVC6      UniProtKB:B3KVC6    0.250000   HGNC:3588
# 4   UniProtKB:A0A2P9AC96  UniProtKB:A0A2P9AC96    0.250000   HGNC:3588
# 6   UniProtKB:A0A2P9A9L1  UniProtKB:A0A2P9A9L1    0.250000   HGNC:3588
# 7       UniProtKB:B4DN49      UniProtKB:B4DN49    0.250000   HGNC:3588
# 8       UniProtKB:B7ZA36      UniProtKB:B7ZA36    0.250000   HGNC:3588
# 9       UniProtKB:B7Z780      UniProtKB:B7Z780    0.250000   HGNC:3588
# 10      UniProtKB:B4DRT6      UniProtKB:B4DRT6    0.222222   HGNC:3588
# 11  UniProtKB:A0A2P9AP44  UniProtKB:A0A2P9AP44    0.222222   HGNC:3588
# 12  UniProtKB:A0A2P9ASQ9  UniProtKB:A0A2P9ASQ9    0.222222   HGNC:3588
# 13  UniProtKB:A0A2P9AHK0  UniProtKB:A0A2P9AHK0    0.222222   HGNC:3588
# 14      UniProtKB:B4DUS0      UniProtKB:B4DUS0    0.222222   HGNC:3588
# 15            HGNC:24994                  INIP    0.222222   HGNC:3588
# 17      UniProtKB:B4E318      UniProtKB:B4E318    0.222222   HGNC:3588
# 18  UniProtKB:A0A2P9ATP0  UniProtKB:A0A2P9ATP0    0.222222   HGNC:3588
# 19      UniProtKB:B4DNU0      UniProtKB:B4DNU0    0.222222   HGNC:3588
# 20  UniProtKB:A0A126LB28  UniProtKB:A0A126LB28    0.222222   HGNC:3588
# 21             HGNC:6919                  MBD4    0.214286   HGNC:3588
# 24      UniProtKB:C6YB47      UniProtKB:C6YB47    0.200000   HGNC:3588
# 26  UniProtKB:A0A2S1ZR87  UniProtKB:A0A2S1ZR87    0.200000   HGNC:3588
# 27  UniProtKB:A0A2P9ASD7  UniProtKB:A0A2P9ASD7    0.200000   HGNC:3588
# 28      UniProtKB:E5KNB2      UniProtKB:E5KNB2    0.200000   HGNC:3588
# 29      UniProtKB:E5KNC9      UniProtKB:E5KNC9    0.200000   HGNC:3588
# 30            HGNC:41994           MSH5-SAPCD1    0.200000   HGNC:3588
# 31      UniProtKB:G3XAC3      UniProtKB:G3XAC3    0.200000   HGNC:3588
# ..                   ...                   ...         ...         ...
# 75            HGNC:20647                ZNF418    0.133333  HGNC:30298
# 76            HGNC:20646                ZNF417    0.133333  HGNC:30298
# 77            HGNC:17625                ZNF674    0.133333  HGNC:30298
# 78            HGNC:16673                ANP32E    0.133333  HGNC:30298
# 79            HGNC:25200                 CIART    0.133333  HGNC:30298
# 80             HGNC:1104                  BRD3    0.133333  HGNC:30298
# 81            HGNC:25117               RIPPLY1    0.133333  HGNC:30298
# 82            HGNC:29810              MPHOSPH8    0.133333  HGNC:30298
# 83             HGNC:1556                  CBX6    0.133333  HGNC:30298
# 84            HGNC:13013                 KAT6A    0.133333  HGNC:30298
# 85            HGNC:15866                 MRGBP    0.133333  HGNC:30298
# 86            HGNC:16223                COMMD7    0.133333  HGNC:30298
# 87            HGNC:24926               CCDC85B    0.133333  HGNC:30298
# 88            HGNC:24173                ATXN3L    0.133333  HGNC:30298
# 89            HGNC:13083                ZBTB21    0.133333  HGNC:30298
# 90            HGNC:26765                ZNF776    0.133333  HGNC:30298
# 91            HGNC:18071                  EMSY    0.133333  HGNC:30298
# 92            HGNC:30955                ZNF587    0.133333  HGNC:30298
# 93            HGNC:18291                 DMAP1    0.130435  HGNC:30298
# 94             HGNC:9350                 PRDM6    0.130435  HGNC:30298
# 95            HGNC:18128                HDAC10    0.130435  HGNC:30298
# 96            HGNC:13017                ZNF224    0.125000  HGNC:30298
# 97            HGNC:19866                 MBTD1    0.125000  HGNC:30298
# 98            HGNC:29090                SMCHD1    0.125000  HGNC:30298
# 0              HGNC:5992                  IL1B    0.171806  HGNC:11892
# 1              HGNC:6018                   IL6    0.114943  HGNC:11892
# 2              HGNC:7562                 MYD88    0.110390  HGNC:11892
# 3             HGNC:12036                 TRAF6    0.104972  HGNC:11892
# 4             HGNC:11849                  TLR3    0.104046  HGNC:11892
# 5              HGNC:5438                  IFNG    0.101190  HGNC:11892
#
#    query_name
# 4      FANCD2
# 5      FANCD2
# 6      FANCD2
# 7      FANCD2
# 0       FANCG
# 1       FANCG
# 3       FANCG
# 4       FANCG
# 6       FANCG
# 7       FANCG
# 8       FANCG
# 9       FANCG
# 10      FANCG
# 11      FANCG
# 12      FANCG
# 13      FANCG
# 14      FANCG
# 15      FANCG
# 17      FANCG
# 18      FANCG
# 19      FANCG
# 20      FANCG
# 21      FANCG
# 24      FANCG
# 26      FANCG
# 27      FANCG
# 28      FANCG
# 29      FANCG
# 30      FANCG
# 31      FANCG
# ..        ...
# 75      UIMC1
# 76      UIMC1
# 77      UIMC1
# 78      UIMC1
# 79      UIMC1
# 80      UIMC1
# 81      UIMC1
# 82      UIMC1
# 83      UIMC1
# 84      UIMC1
# 85      UIMC1
# 86      UIMC1
# 87      UIMC1
# 88      UIMC1
# 89      UIMC1
# 90      UIMC1
# 91      UIMC1
# 92      UIMC1
# 93      UIMC1
# 94      UIMC1
# 95      UIMC1
# 96      UIMC1
# 97      UIMC1
# 98      UIMC1
# 0         TNF
# 1         TNF
# 2         TNF
# 3         TNF
# 4         TNF
# 5         TNF
#
# [4137 rows x 5 columns]

# %% [markdown]
# Currently the list is sorted by 1) the rank of the original FA gene and then 2) the similarity.  We can sort by overall similarity.

# %%
new_genes.sort_values(by=["similarity"],ascending=False)
# Out:
#                       id                  name  similarity    query_id  \
# 0       UniProtKB:B7Z6Y4      UniProtKB:B7Z6Y4    1.000000   HGNC:3586
# 1       UniProtKB:Q6MZN0      UniProtKB:Q6MZN0    1.000000   HGNC:3586
# 5   UniProtKB:A0A0S2Z3N5  UniProtKB:A0A0S2Z3N5    1.000000   HGNC:3586
# 4   UniProtKB:A0A024R8W1  UniProtKB:A0A024R8W1    1.000000   HGNC:3586
# 3       UniProtKB:B3KNQ3      UniProtKB:B3KNQ3    1.000000   HGNC:3586
# 2       UniProtKB:Q53FK7      UniProtKB:Q53FK7    1.000000   HGNC:3586
# 0             HGNC:13060                ZNF267    0.750000  HGNC:20994
# 1             HGNC:13139                  ZNF7    0.750000  HGNC:20994
# 1       UniProtKB:Q93000      UniProtKB:Q93000    0.666667  HGNC:37101
# 2              HGNC:4928                  HKR1    0.666667  HGNC:20994
# 0   UniProtKB:A0A2P9AC96  UniProtKB:A0A2P9AC96    0.666667  HGNC:31792
# 1       UniProtKB:B4DN49      UniProtKB:B4DN49    0.666667  HGNC:31792
# 1             HGNC:27289                  EME2    0.642857  HGNC:24965
# 3              HGNC:1081                  BNC1    0.636364  HGNC:20994
# 4             HGNC:25294                ZNF541    0.636364  HGNC:20994
# 57            HGNC:13093               ZSCAN20    0.625000  HGNC:20994
# 7             HGNC:32462                ZNF726    0.625000  HGNC:20994
# 16            HGNC:13057                ZNF264    0.625000  HGNC:20994
# 15            HGNC:13073                 ZNF28    0.625000  HGNC:20994
# 14            HGNC:34513                ZNF860    0.625000  HGNC:20994
# 13            HGNC:13842                ZNF320    0.625000  HGNC:20994
# 12            HGNC:13085                ZBTB22    0.625000  HGNC:20994
# 11            HGNC:12988                ZNF197    0.625000  HGNC:20994
# 10            HGNC:32464                ZNF729    0.625000  HGNC:20994
# 9             HGNC:28322                ZNF524    0.625000  HGNC:20994
# 8             HGNC:28857                ZNF682    0.625000  HGNC:20994
# 62            HGNC:13005                ZNF213    0.625000  HGNC:20994
# 56            HGNC:33202               ZNF705D    0.625000  HGNC:20994
# 61            HGNC:13001                ZNF182    0.625000  HGNC:20994
# 6             HGNC:12870                   ZFY    0.625000  HGNC:20994
# ..                   ...                   ...         ...         ...
# 87            HGNC:18398              SMARCAD1    0.102564   HGNC:2939
# 4              HGNC:9969                  RFC1    0.102564  HGNC:25752
# 85      UniProtKB:Q2TB79      UniProtKB:Q2TB79    0.102564   HGNC:2736
# 86            HGNC:29147                ZNF652    0.102564   HGNC:2736
# 87            HGNC:29653                ZNF771    0.102564   HGNC:2736
# 48  UniProtKB:A0A024R3V2  UniProtKB:A0A024R3V2    0.102564   HGNC:3436
# 47      UniProtKB:D9MXF4      UniProtKB:D9MXF4    0.102564   HGNC:3436
# 86             HGNC:9186                  POLQ    0.102564  HGNC:13620
# 62             HGNC:6327                   KIN    0.102564   HGNC:9817
# 91            HGNC:26955                ZBTB47    0.102564   HGNC:2736
# 59             HGNC:7329                  MSH6    0.102273  HGNC:12791
# 36            HGNC:10474                RUVBL1    0.102273   HGNC:1058
# 90             HGNC:9962                  UPF1    0.102041  HGNC:20473
# 64            HGNC:12269                 TREX1    0.102041   HGNC:9817
# 88             HGNC:9962                  UPF1    0.102041   HGNC:2939
# 87            HGNC:14410                 DHX36    0.102041  HGNC:13620
# 93             HGNC:3522                  EYA4    0.102041   HGNC:2736
# 88            HGNC:10475                RUVBL2    0.101695  HGNC:13620
# 49            HGNC:10762                SETMAR    0.101695   HGNC:3436
# 9             HGNC:12307                TRIP13    0.101695   HGNC:1101
# 51             HGNC:7329                  MSH6    0.101695  HGNC:12814
# 94              HGNC:882                   ATR    0.101695   HGNC:2736
# 89             HGNC:7652                   NBN    0.101695   HGNC:2939
# 89            HGNC:12833                 XRCC5    0.101695  HGNC:11999
# 60            HGNC:12830                 XRCC3    0.101449  HGNC:12791
# 37            HGNC:21484                  MCM9    0.101449   HGNC:1058
# 38             HGNC:1916                 CHD1L    0.101449   HGNC:1058
# 5              HGNC:5438                  IFNG    0.101190  HGNC:11892
# 61             HGNC:3435                 ERCC3    0.101010  HGNC:12791
# 13            HGNC:11389                 STK11    0.101010    HGNC:795
#
#    query_name
# 0       FANCE
# 1       FANCE
# 5       FANCE
# 4       FANCE
# 3       FANCE
# 2       FANCE
# 0      ZSCAN2
# 1      ZSCAN2
# 1     DDX11L8
# 2      ZSCAN2
# 0      BOD1L1
# 1      BOD1L1
# 1        EME1
# 3      ZSCAN2
# 4      ZSCAN2
# 57     ZSCAN2
# 7      ZSCAN2
# 16     ZSCAN2
# 15     ZSCAN2
# 14     ZSCAN2
# 13     ZSCAN2
# 12     ZSCAN2
# 11     ZSCAN2
# 10     ZSCAN2
# 9      ZSCAN2
# 8      ZSCAN2
# 62     ZSCAN2
# 56     ZSCAN2
# 61     ZSCAN2
# 6      ZSCAN2
# ..        ...
# 87       DNA2
# 4       ATAD5
# 85      DDX11
# 86      DDX11
# 87      DDX11
# 48      ERCC4
# 47      ERCC4
# 86       FBH1
# 62      RAD51
# 91      DDX11
# 59        WRN
# 36        BLM
# 90      BRIP1
# 64      RAD51
# 88       DNA2
# 87       FBH1
# 93      DDX11
# 88       FBH1
# 49      ERCC4
# 9       BRCA2
# 51        XPA
# 94      DDX11
# 89       DNA2
# 89    TP53BP1
# 60        WRN
# 37        BLM
# 38        BLM
# 5         TNF
# 61        WRN
# 13        ATM
#
# [4137 rows x 5 columns]

# %% [markdown]
# ### Probe Similarity
#
# We're getting back answers that we have said are similar by `biological_process_or_activity`.  But the similarity service doesn't tell us which processes the genes actually have in common, just that they have some in common.
#
# We can reconstruct what these common processes are by using a query to the quick service, where we will construct a query that goes `(gene1)-(set of biological processes)-(gene2)`.
#
# In the following snippet, we'll show how to do this for one particular pair of genes: ZNF267 and ZSCAN2.

# %%
def quick(question):
    url=f'http://{robokop_server}:80/api/simple/quick/'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %%
def make_question(types,curies,sets):
    question = {
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    for i,t in enumerate(types):
        newnode = {'id': f'n{i}', 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        if sets[i] is not None:
            newnode['set'] = True
        question['machine_question']['nodes'].append(newnode)
        if i > 0:
            edge = {'id': f'e{i}', 'source_id': f'n{i-1}', 'target_id': f'n{i}'}
            question['machine_question']['edges'].append( edge )
    return question

# %%
import json
question = make_question(['gene','biological_process_or_activity','gene'],
                         ['HGNC:13060',None,'HGNC:20994'],
                         [None,True,None])
print(json.dumps(question,indent=4))
a = quick(question)
# Out:
# {
#     "machine_question": {
#         "nodes": [
#             {
#                 "id": "n0",
#                 "type": "gene",
#                 "curie": "HGNC:13060"
#             },
#             {
#                 "id": "n1",
#                 "type": "biological_process_or_activity",
#                 "set": true
#             },
#             {
#                 "id": "n2",
#                 "type": "gene",
#                 "curie": "HGNC:20994"
#             }
#         ],
#         "edges": [
#             {
#                 "id": "e1",
#                 "source_id": "n0",
#                 "target_id": "n1"
#             },
#             {
#                 "id": "e2",
#                 "source_id": "n1",
#                 "target_id": "n2"
#             }
#         ]
#     }
# }
# Return Status: 200

# %% [markdown]
# Because we used sets on the intermediate node, we should get back a single answer, but let's double check that:

# %%
len(a['answers'])
# Out:
# 1

# %% [markdown]
# Now, let's make it a bit nicer to look at by extracting the process nodes from our answer and putting them in a data frame:

# %%
import pandas as pd
processes = [ {'id': n['id'], 'name': n['name']} for n in a['answers'][0]['nodes'] if n['type'] == 'biological_process_or_activity']
df = pd.DataFrame(processes)
df
# Out:
#            id                                               name
# 0  GO:0000981  DNA-binding transcription factor activity, RNA...
# 1  GO:0003677                                        DNA binding
# 2  GO:0006351                       transcription, DNA-templated
# 3  GO:0006357   regulation of transcription by RNA polymerase II
# 4  GO:0007275                 multicellular organism development
# 5  GO:0046872                                  metal ion binding
