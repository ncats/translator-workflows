# %%
#### This is also used for:
# WF2 MOD1A Q1
# WF2 MOD1B Q1
# WF2 MOD1D Q1
# WF2 MOD1E Q1

# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q7 - "What genes are associated with $disease"
#### Set diease to the DOID/OMIM curie id of the desired condition and run. (e.g. Fanconi Anemia - DOID:13636)
request = { "query_type_id": "Q7", "terms": { "disease": "DOID:13636" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# Fanconi anemia	DOID:13636	SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92
# Fanconi anemia	DOID:13636	FA complementation group I	UniProtKB:Q9NVI1
# Fanconi anemia	DOID:13636	FA complementation group B	UniProtKB:Q8NB91
# Fanconi anemia	DOID:13636	partner and localizer of BRCA2	UniProtKB:Q86YC2
# Fanconi anemia	DOID:13636	FA complementation group M	UniProtKB:Q8IYD8
# Fanconi anemia	DOID:13636	RAD51 paralog C	UniProtKB:O43502
# Fanconi anemia	DOID:13636	X-ray repair cross complementing 2	UniProtKB:O43543
# Fanconi anemia	DOID:13636	tumor necrosis factor	UniProtKB:P01375
# Fanconi anemia	DOID:13636	FA complementation group G	UniProtKB:O15287
# Fanconi anemia	DOID:13636	FA complementation group L	UniProtKB:Q9NW38
# Fanconi anemia	DOID:13636	FA complementation group A	UniProtKB:O15360
# Fanconi anemia	DOID:13636	ERCC excision repair 4, endonuclease catalytic subunit	UniProtKB:Q92889
# Fanconi anemia	DOID:13636	RAD51 recombinase	UniProtKB:Q06609
# Fanconi anemia	DOID:13636	BRCA2, DNA repair associated	UniProtKB:P51587
# Fanconi anemia	DOID:13636	FA complementation group C	UniProtKB:Q00597
# Fanconi anemia	DOID:13636	FA complementation group D2	UniProtKB:Q9BXW9
# Fanconi anemia	DOID:13636	BRCA1 interacting protein C-terminal helicase 1	UniProtKB:Q9BX63
# Fanconi anemia	DOID:13636	FA complementation group F	UniProtKB:Q9NPI8
# Fanconi anemia	DOID:13636	FA complementation group E	UniProtKB:Q9HB96
# Fanconi anemia	DOID:13636	ubiquitin conjugating enzyme E2 T	UniProtKB:Q9NPD8

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-11 21:29:56",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/374",
#     "message": "20 results found",
#     "original_question_text": "",
#     "query_type_id": "Q7",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "SLX4 structure-specific endonuclease subunit",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6535",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IY92",
#                         "source_id": "UniProtKB:Q8IY92",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92"
#             ],
#             "text": "Fanconi anemia and SLX4 structure-specific endonuclease subunit are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group I",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6531",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NVI1",
#                         "source_id": "UniProtKB:Q9NVI1",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group I. Alternative splicing results in two transcript variants encoding different isoforms. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9NVI1",
#                         "name": "FA complementation group I",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NVI1"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group I",
#                 "UniProtKB:Q9NVI1"
#             ],
#             "text": "Fanconi anemia and FA complementation group I are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group B",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6540",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8NB91",
#                         "source_id": "UniProtKB:Q8NB91",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the Fanconi anemia complementation group B. This protein is assembled into a nucleoprotein complex that is involved in the repair of DNA lesions. Mutations in this gene can cause chromosome instability and VACTERL syndrome with hydrocephalus. [provided by RefSeq, Apr 2016].",
#                         "id": "UniProtKB:Q8NB91",
#                         "name": "FA complementation group B",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8NB91"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group B",
#                 "UniProtKB:Q8NB91"
#             ],
#             "text": "Fanconi anemia and FA complementation group B are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "partner and localizer of BRCA2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6534",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q86YC2",
#                         "source_id": "UniProtKB:Q86YC2",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that may function in tumor suppression. This protein binds to and colocalizes with the breast cancer 2 early onset protein (BRCA2) in nuclear foci and likely permits the stable intranuclear localization and accumulation of BRCA2. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q86YC2",
#                         "name": "partner and localizer of BRCA2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q86YC2"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "partner and localizer of BRCA2",
#                 "UniProtKB:Q86YC2"
#             ],
#             "text": "Fanconi anemia and partner and localizer of BRCA2 are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group M",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6530",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8IYD8",
#                         "source_id": "UniProtKB:Q8IYD8",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group M. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Apr 2015].",
#                         "id": "UniProtKB:Q8IYD8",
#                         "name": "FA complementation group M",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IYD8"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group M",
#                 "UniProtKB:Q8IYD8"
#             ],
#             "text": "Fanconi anemia and FA complementation group M are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "RAD51 paralog C",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6536",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O43502",
#                         "source_id": "UniProtKB:O43502",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of the RAD51 family. RAD51 family members are highly similar to bacterial RecA and Saccharomyces cerevisiae Rad51 and are known to be involved in the homologous recombination and repair of DNA. This protein can interact with other RAD51 paralogs and is reported to be important for Holliday junction resolution. Mutations in this gene are associated with Fanconi anemia-like syndrome. This gene is one of four localized to a region of chromosome 17q23 where amplification occurs frequently in breast tumors. Overexpression of the four genes during amplification has been observed and suggests a possible role in tumor progression. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Jul 2013].",
#                         "id": "UniProtKB:O43502",
#                         "name": "RAD51 paralog C",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O43502"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "RAD51 paralog C",
#                 "UniProtKB:O43502"
#             ],
#             "text": "Fanconi anemia and RAD51 paralog C are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "X-ray repair cross complementing 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6544",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O43543",
#                         "source_id": "UniProtKB:O43543",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the RecA/Rad51-related protein family that participates in homologous recombination to maintain chromosome stability and repair DNA damage. This gene is involved in the repair of DNA double-strand breaks by homologous recombination and it functionally complements Chinese hamster irs1, a repair-deficient mutant that exhibits hypersensitivity to a number of different DNA-damaging agents. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O43543",
#                         "name": "X-ray repair cross complementing 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O43543"
#                     },
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "X-ray repair cross complementing 2",
#                 "UniProtKB:O43543"
#             ],
#             "text": "Fanconi anemia and X-ray repair cross complementing 2 are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tumor necrosis factor",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6529",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P01375",
#                         "source_id": "UniProtKB:P01375",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "This gene encodes a multifunctional proinflammatory cytokine that belongs to the tumor necrosis factor (TNF) superfamily. This cytokine is mainly secreted by macrophages. It can bind to, and thus functions through its receptors TNFRSF1A/TNFR1 and TNFRSF1B/TNFBR. This cytokine is involved in the regulation of a wide spectrum of biological processes including cell proliferation, differentiation, apoptosis, lipid metabolism, and coagulation. This cytokine has been implicated in a variety of diseases, including autoimmune diseases, insulin resistance, and cancer. Knockout studies in mice also suggested the neuroprotective function of this cytokine. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P01375",
#                         "name": "tumor necrosis factor",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P01375"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "tumor necrosis factor",
#                 "UniProtKB:P01375"
#             ],
#             "text": "Fanconi anemia and tumor necrosis factor are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group G",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6547",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O15287",
#                         "source_id": "UniProtKB:O15287",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group G. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O15287",
#                         "name": "FA complementation group G",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O15287"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group G",
#                 "UniProtKB:O15287"
#             ],
#             "text": "Fanconi anemia and FA complementation group G are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group L",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6537",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NW38",
#                         "source_id": "UniProtKB:Q9NW38",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group L. Alternative splicing results in two transcript variants encoding different isoforms. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9NW38",
#                         "name": "FA complementation group L",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NW38"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group L",
#                 "UniProtKB:Q9NW38"
#             ],
#             "text": "Fanconi anemia and FA complementation group L are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group A",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6532",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O15360",
#                         "source_id": "UniProtKB:O15360",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group A. Alternative splicing results in multiple transcript variants encoding different isoforms. Mutations in this gene are the most common cause of Fanconi anemia. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O15360",
#                         "name": "FA complementation group A",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O15360"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group A",
#                 "UniProtKB:O15360"
#             ],
#             "text": "Fanconi anemia and FA complementation group A are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ERCC excision repair 4, endonuclease catalytic subunit",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6538",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92889",
#                         "source_id": "UniProtKB:Q92889",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The protein encoded by this gene forms a complex with ERCC1 and is involved in the 5' incision made during nucleotide excision repair. This complex is a structure specific DNA repair endonuclease that interacts with EME1. Defects in this gene are a cause of xeroderma pigmentosum complementation group F (XP-F), or xeroderma pigmentosum VI (XP6).[provided by RefSeq, Mar 2009].",
#                         "id": "UniProtKB:Q92889",
#                         "name": "ERCC excision repair 4, endonuclease catalytic subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92889"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "ERCC excision repair 4, endonuclease catalytic subunit",
#                 "UniProtKB:Q92889"
#             ],
#             "text": "Fanconi anemia and ERCC excision repair 4, endonuclease catalytic subunit are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "RAD51 recombinase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6542",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q06609",
#                         "source_id": "UniProtKB:Q06609",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a member of the RAD51 protein family. RAD51 family members are highly similar to bacterial RecA and Saccharomyces cerevisiae Rad51, and are known to be involved in the homologous recombination and repair of DNA. This protein can interact with the ssDNA-binding protein RPA and RAD52, and it is thought to play roles in homologous pairing and strand transfer of DNA. This protein is also found to interact with BRCA1 and BRCA2, which may be important for the cellular response to DNA damage. BRCA2 is shown to regulate both the intracellular localization and DNA-binding ability of this protein. Loss of these controls following BRCA2 inactivation may be a key event leading to genomic instability and tumorigenesis. Multiple transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Aug 2009].",
#                         "id": "UniProtKB:Q06609",
#                         "name": "RAD51 recombinase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q06609"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "RAD51 recombinase",
#                 "UniProtKB:Q06609"
#             ],
#             "text": "Fanconi anemia and RAD51 recombinase are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "BRCA2, DNA repair associated",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6546",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P51587",
#                         "source_id": "UniProtKB:P51587",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "Inherited mutations in BRCA1 and this gene, BRCA2, confer increased lifetime risk of developing breast or ovarian cancer. Both BRCA1 and BRCA2 are involved in maintenance of genome stability, specifically the homologous recombination pathway for double-strand DNA repair. The BRCA2 protein contains several copies of a 70 aa motif called the BRC motif, and these motifs mediate binding to the RAD51 recombinase which functions in DNA repair. BRCA2 is considered a tumor suppressor gene, as tumors with BRCA2 mutations generally exhibit loss of heterozygosity (LOH) of the wild-type allele. [provided by RefSeq, Dec 2008].",
#                         "id": "UniProtKB:P51587",
#                         "name": "BRCA2, DNA repair associated",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P51587"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "BRCA2, DNA repair associated",
#                 "UniProtKB:P51587"
#             ],
#             "text": "Fanconi anemia and BRCA2, DNA repair associated are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group C",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6539",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q00597",
#                         "source_id": "UniProtKB:Q00597",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group C. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q00597",
#                         "name": "FA complementation group C",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q00597"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group C",
#                 "UniProtKB:Q00597"
#             ],
#             "text": "Fanconi anemia and FA complementation group C are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group D2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6533",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9BXW9",
#                         "source_id": "UniProtKB:Q9BXW9",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group D2. This protein is monoubiquinated in response to DNA damage, resulting in its localization to nuclear foci with other proteins (BRCA1 AND BRCA2) involved in homology-directed DNA repair. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Feb 2016].",
#                         "id": "UniProtKB:Q9BXW9",
#                         "name": "FA complementation group D2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9BXW9"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group D2",
#                 "UniProtKB:Q9BXW9"
#             ],
#             "text": "Fanconi anemia and FA complementation group D2 are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "BRCA1 interacting protein C-terminal helicase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6541",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9BX63",
#                         "source_id": "UniProtKB:Q9BX63",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a member of the RecQ DEAH helicase family and interacts with the BRCT repeats of breast cancer, type 1 (BRCA1). The bound complex is important in the normal double-strand break repair function of breast cancer, type 1 (BRCA1). This gene may be a target of germline cancer-inducing mutations. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9BX63",
#                         "name": "BRCA1 interacting protein C-terminal helicase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9BX63"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "BRCA1 interacting protein C-terminal helicase 1",
#                 "UniProtKB:Q9BX63"
#             ],
#             "text": "Fanconi anemia and BRCA1 interacting protein C-terminal helicase 1 are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group F",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6545",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NPI8",
#                         "source_id": "UniProtKB:Q9NPI8",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group F. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9NPI8",
#                         "name": "FA complementation group F",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NPI8"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group F",
#                 "UniProtKB:Q9NPI8"
#             ],
#             "text": "Fanconi anemia and FA complementation group F are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "FA complementation group E",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6548",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9HB96",
#                         "source_id": "UniProtKB:Q9HB96",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The Fanconi anemia complementation group (FANC) currently includes FANCA, FANCB, FANCC, FANCD1 (also called BRCA2), FANCD2, FANCE, FANCF, FANCG, FANCI, FANCJ (also called BRIP1), FANCL, FANCM and FANCN (also called PALB2). The previously defined group FANCH is the same as FANCA. Fanconi anemia is a genetically heterogeneous recessive disorder characterized by cytogenetic instability, hypersensitivity to DNA crosslinking agents, increased chromosomal breakage, and defective DNA repair. The members of the Fanconi anemia complementation group do not share sequence similarity; they are related by their assembly into a common nuclear protein complex. This gene encodes the protein for complementation group E. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9HB96",
#                         "name": "FA complementation group E",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9HB96"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "FA complementation group E",
#                 "UniProtKB:Q9HB96"
#             ],
#             "text": "Fanconi anemia and FA complementation group E are connected by the relationship gene_associated_with_condition"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ubiquitin conjugating enzyme E2 T",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6543",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NPD8",
#                         "source_id": "UniProtKB:Q9NPD8",
#                         "target_id": "DOID:13636",
#                         "type": "gene_associated_with_condition"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "A congenital hypoplastic anemia characterized by progressive pancytopenia with bone marrow failure, variable congenital malformations and predisposition to develop hematological or solid tumors. It is a result of a genetic defect in a cluster of proteins responsible for DNA repair.",
#                         "id": "DOID:13636",
#                         "name": "Fanconi anemia",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_13636"
#                     },
#                     {
#                         "description": "The protein encoded by this gene catalyzes the covalent attachment of ubiquitin to protein substrates. Defects in this gene have been associated with Fanconi anemia of complementation group T. Two transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jul 2015].",
#                         "id": "UniProtKB:Q9NPD8",
#                         "name": "ubiquitin conjugating enzyme E2 T",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NPD8"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "Fanconi anemia",
#                 "DOID:13636",
#                 "ubiquitin conjugating enzyme E2 T",
#                 "UniProtKB:Q9NPD8"
#             ],
#             "text": "Fanconi anemia and ubiquitin conjugating enzyme E2 T are connected by the relationship gene_associated_with_condition"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "disease": "DOID:13636"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
