# %%
from tranql.main import TranQL
t = TranQL ()

# %% [markdown]
# ## Clinical Outcome Pathways
#
# Build knowledge networks connecting chemicals to disease through several concepts.

# %%
t("""        
set metformin = 'PUBCHEM:4091'
set diabetes_type_2_mellitus = 'MONDO:0015887'

select chemical_substance->gene->biological_process_or_activity->cell->
        anatomical_entity->phenotypic_feature<-disease
  from '/graph/gamma/quick'
 where disease = $diabetes_type_2_mellitus
   and chemical_substance = $metformin
   set graph """)

# %%
t.context.toph (type_name='anatomical_entity', k='graph', n=500)
# Out:
# <table><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=retina' target='x'>retina</a></td><td><a href='https://www.google.com/search?q=UBERON:0000966' target='x'>UBERON:0000966</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=posterior segment of eyeball' target='x'>posterior segment of eyeball</a></td><td><a href='https://www.google.com/search?q=UBERON:0001802' target='x'>UBERON:0001802</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=photoreceptor array' target='x'>photoreceptor array</a></td><td><a href='https://www.google.com/search?q=UBERON:0005388' target='x'>UBERON:0005388</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=chorioretinal region' target='x'>chorioretinal region</a></td><td><a href='https://www.google.com/search?q=UBERON:0019207' target='x'>UBERON:0019207</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=retina' target='x'>retina</a></td><td><a href='https://www.google.com/search?q=UBERON:0000966' target='x'>UBERON:0000966</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=posterior segment of eyeball' target='x'>posterior segment of eyeball</a></td><td><a href='https://www.google.com/search?q=UBERON:0001802' target='x'>UBERON:0001802</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=photoreceptor array' target='x'>photoreceptor array</a></td><td><a href='https://www.google.com/search?q=UBERON:0005388' target='x'>UBERON:0005388</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/se ...
# "<table><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=retina' target='x'>retina</a></td><td><a href='https://www.google.com/search?q=UBERON:0000966' target='x'>UBERON:0000966</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=posterior segment of eyeball' target='x'>posterior segment of eyeball</a></td><td><a href='https://www.google.com/search?q=UBERON:0001802' target='x'>UBERON:0001802</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=photoreceptor array' target='x'>photoreceptor array</a></td><td><a href='https://www.google.com/search?q=UBERON:0005388' target='x'>UBERON:0005388</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=dopamanergic interplexiform cell' target='x'>dopamanergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011105' target='x'>CL:0011105</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=chorioretinal region' target='x'>chorioretinal region</a></td><td><a href='https://www.google.com/search?q=UBERON:0019207' target='x'>UBERON:0019207</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=retina' target='x'>retina</a></td><td><a href='https://www.google.com/search?q=UBERON:0000966' target='x'>UBERON:0000966</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=posterior segment of eyeball' target='x'>posterior segment of eyeball</a></td><td><a href='https://www.google.com/search?q=UBERON:0001802' target='x'>UBERON:0001802</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/search?q=CL:0011106' target='x'>CL:0011106</a></td><td><a href='https://biolink.github.io/biolink-model/docs/part_of.html' target='x'>part_of</a></td><td><a href='https://www.google.com/search?q=photoreceptor array' target='x'>photoreceptor array</a></td><td><a href='https://www.google.com/search?q=UBERON:0005388' target='x'>UBERON:0005388</a></td><td>0.26</td><td>[]</td></tr><tr><td><a href='https://www.google.com/search?q=GABAnergic interplexiform cell' target='x'>GABAnergic interplexiform cell</a></td><td><a href='https://www.google.com/s ...

# %%
t("""        
        set asthma = 'MONDO:0004979'
        set salbutamol = 'PUBCHEM:2083'        
        select chemical_substance->gene->biological_process_or_activity->cell->
               anatomical_entity->phenotypic_feature<-disease
          from '/graph/gamma/quick'
         where disease = $asthma
           and chemical_substance = $salbutamol """)

# %%
t.context.toph (type_name='biological_process_or_activity', n=500)
# Out:
# <table><tr></tr></table>
# '<table><tr></tr></table>'

# %%
t("""  
        set asthma = 'MONDO:0004979'
        set imatinib = 'MESH:D000068877' 
        select chemical_substance->gene->biological_process_or_activity->cell->
               anatomical_entity->phenotypic_feature<-disease
          from '/graph/gamma/quick'
         where disease = $asthma
           and chemical_substance = $imatinib """)
# Out:
# ERROR:tranql.ast:error performing request: {
#   "question_graph": {
#     "edges": [
#       {
#         "id": "e0",
#         "source_id": "n1",
#         "target_id": "n2"
#       },
#       {
#         "id": "e1",
#         "source_id": "n2",
#         "target_id": "n3"
#       },
#       {
#         "id": "e2",
#         "source_id": "n3",
#         "target_id": "n4"
#       },
#       {
#         "id": "e3",
#         "source_id": "n4",
#         "target_id": "n5"
#       },
#       {
#         "id": "e4",
#         "source_id": "n5",
#         "target_id": "n6"
#       },
#       {
#         "id": "e5",
#         "source_id": "n8",
#         "target_id": "n6"
#       }
#     ],
#     "nodes": [
#       {
#         "id": "n1",
#         "type": "chemical_substance",
#         "curie": "MESH:D000068877"
#       },
#       {
#         "id": "n2",
#         "type": "gene"
#       },
#       {
#         "id": "n3",
#         "type": "biological_process_or_activity"
#       },
#       {
#         "id": "n4",
#         "type": "cell"
#       },
#       {
#         "id": "n5",
#         "type": "anatomical_entity"
#       },
#       {
#         "id": "n6",
#         "type": "phenotypic_feature"
#       },
#       {
#         "id": "n8",
#         "type": "disease",
#         "curie": "MONDO:0004979"
#       }
#     ]
#   },
#   "knowledge_graph": {
#     "nodes": [],
#     "edges": []
#   },
#   "knowledge_maps": [
#     {}
#   ],
#   "options": {}
# } to url: http://localhost:8099/graph/gamma/quick
# Traceback (most recent call last):
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/urllib3/connectionpool.py", line 377, in _make_request
#     httplib_response = conn.getresponse(buffering=True)
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/scox/dev/tranql/tranql/ast.py", line 79, in request
#     'accept': 'application/json'
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/requests/api.py", line 116, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/scox/dev/venv/tranql/lib/python3.7/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py", line 1321, in getresponse
#     response.begin()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py", line 296, in begin
#     version, status, reason = self._read_status()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py", line 257, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt

# %%
t.context.toph (type_name='chemical_substance', n=500)
# Out:
# <table><tr></tr></table>
# '<table><tr></tr></table>'
