# %%
# further workup of owlsim-fa-1.7 orthologs showing the details of the tgfbeta match

# %% [raw]
# TGF beta (NCBIGene:7042) was found because it is an ortholog to MGI:98726 (mouse Tgfb2)

# %%
import requests
from itertools import chain
import pandas as pd
import json
with open("gene_genes_1.7_orthologs.json") as f:
    gene_genes = json.load(f)

# %%
n = len({k for k,v in gene_genes.items() if "MGI:98726" in [x[0] for x in v]})
print("mouse tgfb2 is above the phenotype similarity cutoff for {} of the 27 FA genes".format(n))
# Out:
# mouse tgfb2 is above the phenotype similarity cutoff for 21 of the 27 FA genes

# %%
# these are the FA genes that share similarity with mouse tgfb
tgf = {k:[y for y in v if y[0] == "MGI:98726"] for k,v in gene_genes.items()}
tgf
# Out:
# {'NCBIGene:10459': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:199990': [],
#  'NCBIGene:201254': [],
#  'NCBIGene:2072': [['MGI:98726', 56, 'Tgfb2']],
#  'NCBIGene:2175': [['MGI:98726', 62, 'Tgfb2']],
#  'NCBIGene:2176': [['MGI:98726', 61, 'Tgfb2']],
#  'NCBIGene:2177': [['MGI:98726', 62, 'Tgfb2']],
#  'NCBIGene:2178': [['MGI:98726', 61, 'Tgfb2']],
#  'NCBIGene:2187': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:2188': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:2189': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:29089': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:378708': [],
#  'NCBIGene:55120': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:55159': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:55215': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:57697': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:5888': [['MGI:98726', 62, 'Tgfb2']],
#  'NCBIGene:5889': [['MGI:98726', 61, 'Tgfb2']],
#  'NCBIGene:672': [],
#  'NCBIGene:675': [['MGI:98726', 57, 'Tgfb2']],
#  'NCBIGene:7516': [['MGI:98726', 63, 'Tgfb2']],
#  'NCBIGene:79728': [['MGI:98726', 61, 'Tgfb2']],
#  'NCBIGene:80233': [],
#  'NCBIGene:83990': [['MGI:98726', 61, 'Tgfb2']],
#  'NCBIGene:84464': [['MGI:98726', 62, 'Tgfb2']],
#  'NCBIGene:91442': []}

# %%
MONARCH_API = "https://api.monarchinitiative.org/api"
SIMSEARCH_API = "https://monarchinitiative.org/simsearch/phenotype"
def get_phenotype_from_gene_verbose(gene):
    # https://monarchinitiative.org/gene/NCBIGene%3A2176/phenotype_list.json
    url = "https://monarchinitiative.org/gene/{}/phenotype_list.json"
    return [(x['id'],x['label']) for x in requests.get(url.format(gene)).json()['phenotype_list']]
def get_phenotypically_similar_genes(phenotypes, taxon, return_all=False):
    headers = {
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.8',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
    }
    data = {'input_items': " ".join(phenotypes), "target_species": taxon}
    r = requests.post(SIMSEARCH_API, data=data, headers=headers)
    d = r.json()
    if return_all:
        return d
    if 'b' in d:
        scores = [(x['id'],x['score']['score'], x['label']) for x in d['b']]
    else:
        scores = []
    return scores

# %%
# get the single most phenotypically similar FA gene
# theres a bunch with the same highest score..... pick one... NCBIGene:2187 FANCB
phenotypes = get_phenotype_from_gene_verbose("NCBIGene:2187")
phenotypes
# Out:
# [('HP:0000164', 'Abnormality of the dentition'),
#  ('HP:0002860', 'Squamous cell carcinoma'),
#  ('HP:0004859', 'Amegakaryocytic thrombocytopenia'),
#  ('HP:0000639', 'Nystagmus'),
#  ('HP:0009892', 'Anotia'),
#  ('HP:0000252', 'Microcephaly'),
#  ('HP:0002827', 'Hip dislocation'),
#  ('HP:0007400', 'Irregular hyperpigmentation'),
#  ('HP:0011027', 'Abnormality of the fallopian tube'),
#  ('HP:0000028', 'Cryptorchidism'),
#  ('HP:0100587', 'Abnormality of the preputium'),
#  ('HP:0001000', 'Abnormality of skin pigmentation'),
#  ('HP:0000316', 'Hypertelorism'),
#  ('HP:0012745', 'Short palpebral fissure'),
#  ('HP:0000587', 'Abnormality of the optic nerve'),
#  ('HP:0000824', 'Growth hormone deficiency'),
#  ('HP:0100541', 'Femoral hernia'),
#  ('HP:0002937', 'Hemivertebrae'),
#  ('HP:0001763', 'Pes planus'),
#  ('HP:0001639', 'Hypertrophic cardiomyopathy'),
#  ('HP:0010469', 'Absent testis'),
#  ('HP:0000369', 'Low-set ears'),
#  ('HP:0001053', 'Hypopigmented skin patches'),
#  ('HP:0000072', 'Hydroureter'),
#  ('HP:0000175', 'Cleft palate'),
#  ('HP:0001915', 'Aplastic anemia'),
#  ('HP:0002245', 'Meckel diverticulum'),
#  ('HP:0001908', 'Hypoplastic anemia'),
#  ('HP:0003974', 'Absent radius'),
#  ('HP:0001627', 'Abnormal heart morphology'),
#  ('HP:0004431', 'Complement deficiency'),
#  ('HP:0001770', 'Toe syndactyly'),
#  ('HP:0000297', 'Facial hypotonia'),
#  ('HP:0002032', 'Esophageal atresia'),
#  ('HP:0001824', 'Weight loss'),
#  ('HP:0001402', 'Hepatocellular carcinoma'),
#  ('HP:0004349', 'Reduced bone mineral density'),
#  ('HP:0002093', 'Respiratory insufficiency'),
#  ('HP:0000278', 'Retrognathia'),
#  ('HP:0003826', 'Stillbirth'),
#  ('HP:0001646', 'Abnormal aortic valve morphology'),
#  ('HP:0001878', 'Hemolytic anemia'),
#  ('HP:0000463', 'Anteverted nares'),
#  ('HP:0000027', 'Azoospermia'),
#  ('HP:0100026', 'Arteriovenous malformation'),
#  ('HP:0001903', 'Anemia'),
#  ('HP:0000528', 'Anophthalmia'),
#  ('HP:0001873', 'Thrombocytopenia'),
#  ('HP:0000789', 'Infertility'),
#  ('HP:0010293', 'Aplasia/Hypoplasia of the uvula'),
#  ('HP:0002023', 'Anal atresia'),
#  ('HP:0003468', 'Abnormal vertebral morphology'),
#  ('HP:0002119', 'Ventriculomegaly'),
#  ('HP:0001895', 'Normochromic anemia'),
#  ('HP:0009777', 'Absent thumb'),
#  ('HP:0002410', 'Aqueductal stenosis'),
#  ('HP:0003220', 'Abnormality of chromosome stability'),
#  ('HP:0011267', 'Microtia, third degree'),
#  ('HP:0002863', 'Myelodysplasia'),
#  ('HP:0007874', 'Almond-shaped palpebral fissure'),
#  ('HP:0002251', 'Aganglionic megacolon'),
#  ('HP:0004430', 'Severe combined immunodeficiency'),
#  ('HP:0001511', 'Intrauterine growth retardation'),
#  ('HP:0002488', 'Acute leukemia'),
#  ('HP:0004059', 'Radial club hand'),
#  ('HP:0004810', 'Congenital hypoplastic anemia'),
#  ('HP:0000508', 'Ptosis'),
#  ('HP:0000568', 'Microphthalmia'),
#  ('HP:0005505', 'Refractory anemia'),
#  ('HP:0006501', 'Aplasia/Hypoplasia of the radius'),
#  ('HP:0003125', 'Reduced factor VIII activity'),
#  ('HP:0001679', 'Abnormal aortic morphology'),
#  ('HP:0007565', 'Multiple cafe-au-lait spots'),
#  ('HP:0008572', 'External ear malformation'),
#  ('HP:0010305', 'Absence of the sacrum'),
#  ('HP:0002721', 'Immunodeficiency'),
#  ('HP:0004377', 'Hematological neoplasm'),
#  ('HP:0000023', 'Inguinal hernia'),
#  ('HP:0000482', 'Microcornea'),
#  ('HP:0002101', 'Abnormal lung lobation'),
#  ('HP:0001973', 'Autoimmune thrombocytopenia'),
#  ('HP:0001199', 'Triphalangeal thumb'),
#  ('HP:0001900', 'Increased hemoglobin'),
#  ('HP:0001249', 'Intellectual disability'),
#  ('HP:0002823', 'Abnormality of femur morphology'),
#  ('HP:0100542', 'Abnormal localization of kidney'),
#  ('HP:0011018', 'Abnormality of the cell cycle'),
#  ('HP:0000505', 'Visual impairment'),
#  ('HP:0000077', 'Abnormality of the kidney'),
#  ('HP:0005510', 'Transient erythroblastopenia'),
#  ('HP:0000365', 'Hearing impairment'),
#  ('HP:0008678', 'Renal hypoplasia/aplasia'),
#  ('HP:0008064', 'Ichthyosis'),
#  ('HP:0000089', 'Renal hypoplasia'),
#  ('HP:0005522', 'Pyridoxine-responsive sideroblastic anemia'),
#  ('HP:0001009', 'Telangiectasia'),
#  ('HP:0001562', 'Oligohydramnios'),
#  ('HP:0001972', 'Macrocytic anemia'),
#  ('HP:0001643', 'Patent ductus arteriosus'),
#  ('HP:0000582', 'Upslanted palpebral fissure'),
#  ('HP:0000453', 'Choanal atresia'),
#  ('HP:0001875', 'Neutropenia'),
#  ('HP:0000268', 'Dolichocephaly'),
#  ('HP:0100867', 'Duodenal stenosis'),
#  ('HP:0000324', 'Facial asymmetry'),
#  ('HP:0005528', 'Bone marrow hypocellularity'),
#  ('HP:0001636', 'Tetralogy of Fallot'),
#  ('HP:0000104', 'Renal agenesis'),
#  ('HP:0100760', 'Clubbing of toes'),
#  ('HP:0006101', 'Finger syndactyly'),
#  ('HP:0012041', 'Decreased fertility in males'),
#  ('HP:0000218', 'High palate'),
#  ('HP:0002007', 'Frontal bossing'),
#  ('HP:0001251', 'Ataxia'),
#  ('HP:0100608', 'Metrorrhagia'),
#  ('HP:0005344', 'Abnormal carotid artery morphology'),
#  ('HP:0001195', 'Single umbilical artery'),
#  ('HP:0001347', 'Hyperreflexia'),
#  ('HP:0001909', 'Leukemia'),
#  ('HP:0000483', 'Astigmatism'),
#  ('HP:0001537', 'Umbilical hernia'),
#  ('HP:0001392', 'Abnormality of the liver'),
#  ('HP:0008053', 'Aplasia/Hypoplasia of the iris'),
#  ('HP:0006265', 'Aplasia/Hypoplasia of fingers'),
#  ('HP:0000347', 'Micrognathia'),
#  ('HP:0004322', 'Short stature'),
#  ('HP:0006824', 'Cranial nerve paralysis'),
#  ('HP:0001263', 'Global developmental delay'),
#  ('HP:0000520', 'Proptosis'),
#  ('HP:0100806', 'Sepsis'),
#  ('HP:0007354', 'Amyotrophic lateral sclerosis'),
#  ('HP:0000286', 'Epicanthus'),
#  ('HP:0005560', 'Imbalanced hemoglobin synthesis'),
#  ('HP:0004209', 'Clinodactyly of the 5th finger'),
#  ('HP:0000486', 'Strabismus'),
#  ('HP:0000047', 'Hypospadias'),
#  ('HP:0000953', 'Hyperpigmentation of the skin'),
#  ('HP:0011133', 'Increased sensitivity to ionizing radiation'),
#  ('HP:0001561', 'Polyhydramnios'),
#  ('HP:0002650', 'Scoliosis'),
#  ('HP:0006872', 'Cerebral hypoplasia'),
#  ('HP:0009778', 'Short thumb'),
#  ('HP:0001876', 'Pancytopenia'),
#  ('HP:0002984', 'Hypoplasia of the radius'),
#  ('HP:0000601', 'Hypotelorism'),
#  ('HP:0002414', 'Spina bifida'),
#  ('HP:0000340', 'Sloping forehead'),
#  ('HP:0002089', 'Pulmonary hypoplasia'),
#  ('HP:0000864', 'Abnormality of the hypothalamus-pituitary axis'),
#  ('HP:0003022', 'Hypoplasia of the ulna'),
#  ('HP:0000135', 'Hypogonadism'),
#  ('HP:0006721', 'Acute lymphoblastic leukemia'),
#  ('HP:0001882', 'Leukopenia'),
#  ('HP:0004820', 'Acute myelomonocytic leukemia'),
#  ('HP:0001631', 'Atrial septal defect'),
#  ('HP:0010650', 'Hypoplasia of the premaxilla'),
#  ('HP:0003002', 'Breast carcinoma'),
#  ('HP:0000813', 'Bicornuate uterus'),
#  ('HP:0001172', 'Abnormality of the thumb'),
#  ('HP:0000518', 'Cataract'),
#  ('HP:0001905', 'Congenital thrombocytopenia'),
#  ('HP:0030680', 'Abnormality of cardiovascular system morphology'),
#  ('HP:0003254', 'Abnormality of DNA repair'),
#  ('HP:0000238', 'Hydrocephalus'),
#  ('HP:0001510', 'Growth delay'),
#  ('HP:0002139', 'Arrhinencephaly'),
#  ('HP:0010972', 'Anemia of inadequate production'),
#  ('HP:0100615', 'Ovarian neoplasm'),
#  ('HP:0000010', 'Recurrent urinary tract infections'),
#  ('HP:0004808', 'Acute myeloid leukemia'),
#  ('HP:0002575', 'Tracheoesophageal fistula'),
#  ('HP:0000083', 'Renal insufficiency')]

# %%
d = get_phenotypically_similar_genes([x[0] for x in phenotypes], "10090", return_all=True)

# %%
# the details of the match between human FANCB and mouse tgfb
match = [x for x in d['b'] if x['id'] == "MGI:98726"][0]
print((match['id'],match['label']))
# Out:
# ('MGI:98726', 'Tgfb2')

# %%
print("There are {} phenotype matches".format(len(match['matches'])))
# Out:
# There are 31 phenotype matches

# %%
# sort by IC score
matches = sorted(match['matches'], key=lambda x:x['lcs']['IC'], reverse=True)
matches[:2]
# Out:
# [{'a': {'IC': 9.222230105740707,
#    'id': 'HP:0003022',
#    'label': 'Hypoplasia of the ulna'},
#   'b': {'IC': 9.222230105740707,
#    'id': 'HP:0003022',
#    'label': 'Hypoplasia of the ulna'},
#   'lcs': {'IC': 9.222230105740707, 'id': 'MP:0004359', 'label': 'short ulna'}},
#  {'a': {'IC': 9.407528756226537,
#    'id': 'HP:0010650',
#    'label': 'Hypoplasia of the premaxilla'},
#   'b': {'IC': 12.516685989266875,
#    'id': 'MP:0000430',
#    'label': 'absent maxillary shelf'},
#   'lcs': {'IC': 8.734293049024156,
#    'id': 'UBERON:0002244PHENOTYPE',
#    'label': 'premaxilla phenotype'}}]

# %%
# format nicely

pd.DataFrame([{'human phenotype': x['a']['label'],
  'mouse phenotype': x['b']['label'],
  'lcs': x['lcs']['label'],
  'score': x['lcs']['IC']} for x in matches])
# Out:
#                      human phenotype  \
# 0             Hypoplasia of the ulna
# 1       Hypoplasia of the premaxilla
# 2                     Renal agenesis
# 3                       Retrognathia
# 4                        Microcornea
# 5                       Spina bifida
# 6   Abnormal aortic valve morphology
# 7                Tetralogy of Fallot
# 8          Tracheoesophageal fistula
# 9                        Hypospadias
# 10                 Bicornuate uterus
# 11              Atrial septal defect
# 12           Single umbilical artery
# 13          Patent ductus arteriosus
# 14   Abnormality of femur morphology
# 15               Meckel diverticulum
# 16             Aganglionic megacolon
# 17                       Azoospermia
# 18                    Cryptorchidism
# 19    Aplasia/Hypoplasia of the iris
# 20                     Absent testis
# 21                      Micrognathia
# 22                   Hip dislocation
# 23                        Stillbirth
# 24         Growth hormone deficiency
# 25                    Dolichocephaly
# 26                        Ichthyosis
# 27                       Neutropenia
# 28                  Breast carcinoma
# 29               Renal insufficiency
# 30                       Weight loss
#
#                                                   lcs  \
# 0                                          short ulna
# 1                                premaxilla phenotype
# 2                                       absent kidney
# 3                             mandibular retrognathia
# 4                                         Microcornea
# 5                                        spina bifida
# 6                    Abnormal aortic valve morphology
# 7   interventricular septum membranous part phenotype
# 8     abnormal respiratory conducting tube morphology
# 9                              male urethra phenotype
# 10                         abnormal uterus morphology
# 11                               atrial septal defect
# 12                       Fetal ultrasound soft marker
# 13                  blood vessel remodeling phenotype
# 14                          abnormal femur morphology
# 15                abnormal small intestine morphology
# 16                            Abnormality of ganglion
# 17                              abnormal sperm number
# 18                                     ectopic testis
# 19                           abnormal iris morphology
# 20                   Aplasia/Hypoplasia of the testes
# 21                                       micrognathia
# 22                         girdle bone/zone phenotype
# 23                                perinatal lethality
# 24                 abnormal circulating hormone level
# 25                Abnormality of calvarial morphology
# 26                         skin development phenotype
# 27                  Abnormality of myeloid leukocytes
# 28                          Abnormality of the thorax
# 29           abnormal renal/urinary system physiology
# 30                              decreased body weight
#
#                                 mouse phenotype     score
# 0                        Hypoplasia of the ulna  9.222230
# 1                        absent maxillary shelf  8.734293
# 2                                Renal agenesis  8.313661
# 3                                  Retrognathia  8.286692
# 4            decreased corneal stroma thickness  8.076628
# 5                          spina bifida occulta  8.034480
# 6                           patent aortic valve  7.934124
# 7      Perimembranous ventricular septal defect  7.858723
# 8          dilated respiratory conducting tubes  7.819655
# 9       abnormal bulbourethral gland physiology  7.714192
# 10             abnormal uterine horn morphology  7.409292
# 11                  Primum atrial septal defect  7.142933
# 12                               Hydronephrosis  7.130894
# 13            blood vessel remodeling phenotype  7.062750
# 14               abnormal trochanter morphology  7.039225
# 15  abnormal small intestinal villus morphology  6.900303
# 16        abnormal cochlear ganglion morphology  6.810633
# 17                                 Oligospermia  6.805774
# 18                               Cryptorchidism  6.613337
# 19              abnormal iris stroma morphology  6.561368
# 20                            testis hypoplasia  6.491853
# 21                    Short mandibular condyles  6.111369
# 22                 abnormal clavicle morphology  5.971790
# 23   perinatal lethality, incomplete penetrance  5.613668
# 24                     decreased dopamine level  5.362990
# 25                          small parietal bone  5.298488
# 26          hair follicle development phenotype  5.147494
# 27               abnormal macrophage physiology  4.895006
# 28                                   rib fusion  4.715766
# 29                                  Proteinuria  4.650349
# 30                        decreased body weight  3.423637
