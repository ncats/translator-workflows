# %% [markdown]
# ## CQ1.7 - Gene-Gene Phenotype Similarity for FA Genes

# %% [markdown]
# Description: https://docs.google.com/document/d/10wvsoNLbbFOvHWVWRdYQdJ_PD0uO7SGGR-gIqCM8GWU/edit#

# %% [raw]
# Similar to Approach 1, but using the FA associated phenotypes only, instead of all phenotypes associated with FA genes. So, different step 1

# %% [raw]
# Human Pheno Cross-Species Analysis Approach: Single pooled set of input phenos used in a single cross-species phenosim analysis
#
# pheno profiles -> single cross-species phenosim -> trim input genes -> select hits -> map to human ortholog
#
# Input: Phenotypes associated with (the disease) FA
# Retrieve set of phenotypes associated with FA
# Use this set to execute a single cross-species phenosim analysis to compare against pheno profiles of genes from 5 species (human, mouse, zebrafish, fly, worm)
# 	-> one list of phenosim results/scores containing genes from 5 species
# Remove FA genes from results (i.e. trim inputs)
# -> one list of scores with input genes removed
# Take top 25 results as gene ‘hits’
# -> trimmed list of 25 gene hits
# Retrieve human orthologs of any non-human gene hits
# 	-> set of ortholog-human gene pairs
# Output: Return list of 25 gene ‘hits’ - along with phenosim score, taxon of the gene, and its human ortholog

# %%
# autogenerate biolink_client
# curl --insecure -X POST -H "content-type:application/json" -d '{"swaggerUrl":"https://api.monarchinitiative.org/api/swagger.json"}' https://generator.swagger.io/api/gen/clients/python
# and rename it to biolink_client

# %%
import os, sys
# change this path
sys.path.insert(0, "/home/gstupp/projects/NCATS-Tangerine/biolink_client")

# %%
import biolink_client
from biolink_client.api_client import ApiClient
from biolink_client.rest import ApiException
import requests
from itertools import chain
from collections import Counter
import pandas as pd
from pprint import pprint
from tqdm import tqdm, tqdm_notebook
from collections import defaultdict

pd.options.display.max_rows = 999

MONARCH_API = "https://api.monarchinitiative.org/api"
SIMSEARCH_API = "https://monarchinitiative.org/simsearch/phenotype"

gene_list = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_4_all_genes.txt"

client = ApiClient(host=MONARCH_API)
client.set_default_header('Content-Type', 'text/plain')
api_instance = biolink_client.BioentityApi(client)

# Get the gene list from github
dataframe = pd.read_csv(gene_list, sep='\t', names=['gene_id', 'symbol'])
df = dataframe.set_index('symbol')
human_FA_genes = set(df.gene_id)

# %%
def get_obj(obj_id):
    url = "https://api.monarchinitiative.org/api/bioentity/{}".format(obj_id)
    res = requests.get(url)
    d = res.json()
    return d
def get_taxon_from_gene(gene):
    return get_obj(gene)['taxon']['label']
def get_phenotype_from_gene(gene):
    # https://monarchinitiative.org/gene/NCBIGene%3A2176/phenotype_list.json
    url = "https://monarchinitiative.org/gene/{}/phenotype_list.json"
    return [x['id'] for x in requests.get(url.format(gene)).json()['phenotype_list']]
def get_phenotype_from_gene_verbose(gene):
    # https://monarchinitiative.org/gene/NCBIGene%3A2176/phenotype_list.json
    url = "https://monarchinitiative.org/gene/{}/phenotype_list.json"
    return [(x['id'],x['label']) for x in requests.get(url.format(gene)).json()['phenotype_list']]
def query_orthologs(gene_id, taxon=None):
    """Query Monarch to determine the orthologs of a gene."""
    url = "https://api.monarchinitiative.org/api/bioentity/gene/{}/homologs/".format(gene_id)
    if taxon:
        res = requests.get(url, params={'homolog_taxon': taxon})
    else:        
        res = requests.get(url)
    d = res.json()
    return [x['object']['id'] for x in d['associations']]
def get_phenotypes_from_disease(disease):
    url = "https://api.monarchinitiative.org/api/bioentity/disease/{}/phenotypes/?fetch_objects=true&rows=1000"
    d = requests.get(url.format(disease)).json()
    return d
#query_orthologs('MGI:88276', taxon="NCBITaxon:9606")
#get_phenotype_from_gene("NCBIGene:2176")
#get_taxon_from_gene('NCBIGene:2176')

# %%
def get_phenotypically_similar_genes(phenotypes, taxon, return_all=False):
    headers = {
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.8',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
    }
    data = {'input_items': " ".join(phenotypes), "target_species": taxon}
    r = requests.post(SIMSEARCH_API, data=data, headers=headers)
    d = r.json()
    if return_all:
        return d
    if 'b' in d:
        scores = [(x['id'],x['score']['score'], x['label']) for x in d['b']]
    else:
        scores = []
    return scores
#get_phenotypically_similar_genes(phenotypes, "10090")

# %%
# Step 1: Retrieve set of phenotypes associated with FA

phenotype_results = get_phenotypes_from_disease("DOID:13636")  # FA: DOID:13636

# %%
# look at the results
phenotype_results['associations'] = sorted(phenotype_results['associations'], key = lambda x: x['object']['label'])
for ass in phenotype_results['associations']:
    subject = ass['subject']
    relation = ass['relation']
    obj = ass['object']
    print(" ".join([subject['label'], "({})".format(subject['id']), "->", relation['label'], "->",
                   obj['label'], "({})".format(obj['id'])]))
# Out:
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormal aortic morphology (HP:0001679)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormal aortic valve morphology (HP:0001646)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormal carotid artery morphology (HP:0005344)
# Fanconi anemia complementation group L (MONDO:0013566) -> has phenotype -> Abnormal facial shape (HP:0001999)
# Fanconi anemia complementation group C (MONDO:0009213) -> has phenotype -> Abnormal heart morphology (HP:0001627)
# Fanconi anemia complementation group O (MONDO:0013248) -> has phenotype -> Abnormal heart morphology (HP:0001627)
# Fanconi anemia complementation group a (MONDO:0009215) -> has phenotype -> Abnormal heart morphology (HP:0001627)
# Fanconi anemia complementation group D2 (MONDO:0009214) -> has phenotype -> Abnormal heart morphology (HP:0001627)
# Fanconi anemia complementation group E (MONDO:0010953) -> has phenotype -> Abnormal heart morphology (HP:0001627)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormal localization of kidney (HP:0100542)
# Fanconi anemia complementation group b (MONDO:0010351) -> has phenotype -> Abnormal lung lobation (HP:0002101)
# Fanconi anemia complementation group i (MONDO:0012186) -> has phenotype -> Abnormal renal morphology (HP:0012210)
# Fanconi anemia complementation group b (MONDO:0010351) -> has phenotype -> Abnormal vertebral morphology (HP:0003468)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of DNA repair (HP:0003254)
# Fanconi anemia complementation group i (MONDO:0012186) -> has phenotype -> Abnormality of cardiovascular system morphology (HP:0030680)
# Fanconi anemia complementation group L (MONDO:0013566) -> has phenotype -> Abnormality of chromosome stability (HP:0003220)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of chromosome stability (HP:0003220)
# Fanconi anemia complementation group b (MONDO:0010351) -> has phenotype -> Abnormality of chromosome stability (HP:0003220)
# Fanconi anemia complementation group G (MONDO:0013565) -> has phenotype -> Abnormality of chromosome stability (HP:0003220)
# Fanconi anemia complementation group f (MONDO:0011325) -> has phenotype -> Abnormality of chromosome stability (HP:0003220)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of femur morphology (HP:0002823)
# Fanconi anemia complementation group C (MONDO:0009213) -> has phenotype -> Abnormality of skin pigmentation (HP:0001000)
# Fanconi anemia complementation group E (MONDO:0010953) -> has phenotype -> Abnormality of skin pigmentation (HP:0001000)
# Fanconi anemia complementation group a (MONDO:0009215) -> has phenotype -> Abnormality of skin pigmentation (HP:0001000)
# Fanconi anemia complementation group D2 (MONDO:0009214) -> has phenotype -> Abnormality of skin pigmentation (HP:0001000)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of skin pigmentation (HP:0001000)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the cell cycle (HP:0011018)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the dentition (HP:0000164)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the hypothalamus-pituitary axis (HP:0000864)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the kidney (HP:0000077)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the liver (HP:0001392)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the preputium (HP:0100587)
# Fanconi anemia complementation group G (MONDO:0013565) -> has phenotype -> Abnormality of the thumb (HP:0001172)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Abnormality of the thumb (HP:0001172)
# Fanconi anemia complementation group a (MONDO:0009215) -> has phenotype -> Absent radius (HP:0003974)
# Fanconi anemia complementation group C (MONDO:0009213) -> has phenotype -> Absent radius (HP:0003974)
# Fanconi anemia complementation group E (MONDO:0010953) -> has phenotype -> Absent radius (HP:0003974)
# Fanconi anemia complementation group b (MONDO:0010351) -> has phenotype -> Absent radius (HP:0003974)
# Fanconi anemia complementation group D2 (MONDO:0009214) -> has phenotype -> Absent radius (HP:0003974)
# Fanconi anemia complementation group U (MONDO:0014987) -> has phenotype -> Absent scaphoid (HP:0011835)
# Fanconi anemia (MONDO:0019391) -> has phenotype -> Absent testis (HP:0010469)
# Fanconi anemia complementation group D2 (MONDO:0009214) -> has phenotype -> Absent thumb (HP:0009777)
# Fanconi anemia complementation group P (MONDO:0013499) -> has phenotype -> Absent thumb (HP:0009777)
# Fanconi anemia complementation group C (MONDO:0009213) -> has phenotype -> Absent thumb (HP:0009777)
# Fanconi anemia complementation group Q (MONDO:0014108) -> has phenotype ->
# There's 193 total, so lets take the ones that appear in 2 or more subtypes (57 of them)
c = Counter([x['object']['label'] for x in phenotype_results['associations']])
print(len([x for x in c.values() if x>=2]))
c.most_common()
# Out:
# 57
# [('Microcephaly', 13),
#  ('Short stature', 12),
#  ('Anemia', 11),
#  ('Short thumb', 11),
#  ('Absent thumb', 9),
#  ('Bone marrow hypocellularity', 9),
#  ('Microphthalmia', 8),
#  ('Cafe-au-lait spot', 8),
#  ('Thrombocytopenia', 8),
#  ('Chromosomal breakage induced by crosslinking agents', 8),
#  ('Neutropenia', 7),
#  ('Cryptorchidism', 7),
#  ('Pancytopenia', 7),
#  ('Leukemia', 6),
#  ('Hearing impairment', 6),
#  ('Intellectual disability', 6),
#  ('Absent radius', 5),
#  ('Growth delay', 5),
#  ('Abnormality of chromosome stability', 5),
#  ('Renal agenesis', 5),
#  ('Abnormality of skin pigmentation', 5),
#  ('Strabismus', 5),
#  ('Horseshoe kidney', 5),
#  ('Abnormal heart morphology', 5),
#  ('Anal atresia', 5),
#  ('Reticulocytopenia', 4),
#  ('Deficient excision of UV-induced pyrimidine dimers in DNA', 4),
#  ('Complete duplication of thumb phalanx', 4),
#  ('Bruising susceptibility', 4),
#  ('Ectopic kidney', 4),
#  ('Intrauterine growth retardation', 4),
#  ('Prolonged G2 phase of cell cycle', 4),
#  ('Duplicated collecting system', 4),
#  ('Anemic pallor', 4),
#  ('Small for gestational age', 4),
#  ('Hypergonadotropic hypogonadism', 4),
#  ('Global developmental delay', 4),
#  ('Failure to thrive', 3),
#  ('Multiple cafe-au-lait spots', 3),
#  ('Tracheoesophageal fistula', 3),
#  ('Hypertelorism', 3),
#  ('Hydrocephalus', 3),
#  ('Patent ductus arteriosus', 2),
#  ('Low-set ears', 2),
#  ('Hypoplasia of the radius', 2),
#  ('Squamous cell carcinoma', 2),
#  ('Micrognathia', 2),
#  ('Aplastic anemia', 2),
#  ('Short neck', 2),
#  ('Acute myeloid leukemia', 2),
#  ('Esophageal atresia', 2),
#  ('Ventriculomegaly', 2),
#  ('Epicanthus', 2),
#  ('Abnormality of the thumb', 2),
#  ('Myelodysplasia', 2),
#  ('Cleft palate', 2),
#  ('Short palpebral fissure', 2),
#  ('Absent testis', 1),
#  ('Pes planus', 1),
#  ('Abnormality of DNA repair', 1),
#  ('Wide nasal bridge', 1),
#  ('Ptosis', 1),
#  ('Metrorrhagia', 1),
#  ('Clinodactyly of the 5th finger', 1),
#  ('Irregular hyperpigmentation', 1),
#  ('Aplasia/Hypoplasia of fingers', 1),
#  ('Imbalanced hemoglobin synthesis', 1),
#  ('Telangiectasia', 1),
#  ('Infertility', 1),
#  ('Facial asymmetry', 1),
#  ('Ichthyosis', 1),
#  ('Hypoplasia of the premaxilla', 1),
#  ('Absent scaphoid', 1),
#  ('Upslanted palpebral fissure', 1),
#  ('Hypospadias', 1),
#  ('Sloping forehead', 1),
#  ('Frontal bossing', 1),
#  ('Increased sensitivity to ionizing radiation', 1),
#  ('Facial hypotonia', 1),
#  ('External ear malformation', 1),
#  ('Pyridoxine-responsive sideroblastic anemia', 1),
#  ('Renal hypoplasia/aplasia', 1),
#  ('Abnormality of the kidney', 1),
#  ('Growth hormone deficiency', 1),
#  ('Bulbous nose', 1),
#  ('Ventricular septal defect', 1),
#  ('Renal cyst', 1),
#  ('Dolichocephaly', 1),
#  ('Bicornuate uterus', 1),
#  ('Abnormal vertebral morphology', 1),
#  ('Abnormal renal morphology', 1),
#  ('Cranial nerve paralysis', 1),
#  ('Almond-shaped palpebral fissure', 1),
#  ('Congenital thrombocytopenia', 1),
#  ('Rectal atresia', 1),
#  ('Weight loss', 1),
#  ('Abnormal lung lobation', 1),
#  ('Nephroblastoma', 1),
#  ('Abnormality of the preputium', 1),
#  ('Reduced bone mineral density', 1),
#  ('Abnormality of the dentition', 1),
#  ('Renal insufficiency', 1),
#  ('Immunodeficiency', 1),
#  ('High palate', 1),
#  ('Renal hypoplasia', 1),
#  ('Biliary atresia', 1),
#  ('Vitiligo', 1),
#  ('Hyperpigmentation of the skin', 1),
#  ('Toe syndactyly', 1),
#  ('Aganglionic megacolon', 1),
#  ('Hypoplasia of the ulna', 1),
#  ('Abnormal aortic morphology', 1),
#  ('Hydronephrosis', 1),
#  ('Spina bifida', 1),
#  ('Aplasia/Hypoplasia of the uvula', 1),
#  ('Acute leukemia', 1),
#  ('Microtia', 1),
#  ('Elevated alpha-fetoprotein', 1),
#  ('Abnormality of femur morphology', 1),
#  ('Medulloblastoma', 1),
#  ('Astigmatism', 1),
#  ('Abnormal facial shape', 1),
#  ('Aplasia/Hypoplasia of the radius', 1),
#  ('Ovarian neoplasm', 1),
#  ('Anteverted nares', 1),
#  ('Hypoplastic anemia', 1),
#  ('Arteriovenous malformation', 1),
#  ('Hypotelorism', 1),
#  ('Autoimmune thrombocytopenia', 1),
#  ('Macrocytic anemia', 1),
#  ('External genital hypoplasia', 1),
#  ('Hematological neoplasm', 1),
#  ('Abnormality of the cell cycle', 1),
#  ('Abnormality of cardiovascular system morphology', 1),
#  ('Aplasia/Hypoplasia of the iris', 1),
#  ('Acute lymphoblastic leukemia', 1),
#  ('Decreased fertility in males', 1),
#  ('Abnormal aortic valve morphology', 1),
#  ('Hypogonadism', 1),
#  ('Tetralogy of Fallot', 1),
#  ('T-cell acute lymphoblastic leukemias', 1),
#  ('Amegakaryocytic thrombocytopenia', 1),
#  ('Triphalangeal thumb', 1),
#  ('Meckel diverticulum', 1),
#  ('Acute myelomonocytic leukemia', 1),
#  ('Choanal atresia', 1),
#  ('Atrial septal defect', 1),
#  ('Hyperreflexia', 1),
#  ('Abnormal localization of kidney', 1),
#  ('Hydroureter', 1),
#  ('Chromosome breakage', 1),
#  ('Hepatocellular carcinoma', 1),
#  ('Scoliosis', 1),
#  ('Neuroblastoma', 1),
#  ('Breast carcinoma', 1),
#  ('Congenital hypoplastic anemia', 1),
#  ('Hypertrophic cardiomyopathy', 1),
#  ('Proptosis', 1),
#  ('Recurrent urinary tract infections', 1),
#  ('Reduced factor VIII activity', 1),
#  ('Duplication of thumb phalanx', 1),
#  ('Complement deficiency', 1),
#  ('Anemia of inadequate production', 1),
#  ('Cerebral hypoplasia', 1),
#  ('Micropenis', 1),
#  ('Finger syndactyly', 1),
#  ('Azoospermia', 1),
#  ('Pelvic kidney', 1),
#  ('Transient erythroblastopenia', 1),
#  ('Hypopigmented skin patches', 1),
#  ('Normochromic anemia', 1),
#  ('Abnormality of the liver', 1),
#  ('Duodenal stenosis', 1),
#  ('Sepsis', 1),
#  ('Hemolytic anemia', 1),
#  ('Refractory anemia', 1),
#  ('Leukopenia', 1),
#  ('Nystagmus', 1),
#  ('Visual impairment', 1),
#  ('Ataxia', 1),
#  ('Cataract', 1),
#  ('Amyotrophic lateral sclerosis', 1),
#  ('Hip dislocation', 1),
#  ('Umbilical hernia', 1),
#  ('Clubbing of toes', 1),
#  ('Oligohydramnios', 1),
#  ('Abnormality of the hypothalamus-pituitary axis', 1),
#  ('Increased hemoglobin', 1),
#  ('Depressed nasal bridge', 1),
#  ('Stage 5 chronic kidney disease', 1),
#  ('Abnormal carotid artery morphology', 1),
#  ('Severe combined immunodeficiency', 1),
#  ('Blepharophimosis', 1)]

# %%
# do the above-described filtering
c = Counter([x['object']['id'] for x in phenotype_results['associations']])
phenotypes = [k for k,v in c.items() if v>=2]
print(phenotypes)
print(len(phenotypes))
# Out:
# ['HP:0001915', 'HP:0009943', 'HP:0002860', 'HP:0001000', 'HP:0002032', 'HP:0000286', 'HP:0000081', 'HP:0001875', 'HP:0009778', 'HP:0000470', 'HP:0000252', 'HP:0001873', 'HP:0005528', 'HP:0001172', 'HP:0001510', 'HP:0001263', 'HP:0000815', 'HP:0000028', 'HP:0003221', 'HP:0001249', 'HP:0003220', 'HP:0000369', 'HP:0000365', 'HP:0007565', 'HP:0001518', 'HP:0012745', 'HP:0000347', 'HP:0000978', 'HP:0000486', 'HP:0001511', 'HP:0003213', 'HP:0000175', 'HP:0009777', 'HP:0002023', 'HP:0002119', 'HP:0001876', 'HP:0001643', 'HP:0000086', 'HP:0000957', 'HP:0001627', 'HP:0002984', 'HP:0003974', 'HP:0000085', 'HP:0001508', 'HP:0001909', 'HP:0001903', 'HP:0002863', 'HP:0003214', 'HP:0004322', 'HP:0000104', 'HP:0000568', 'HP:0000316', 'HP:0002575', 'HP:0001896', 'HP:0001017', 'HP:0000238', 'HP:0004808']
# 57

# %%
# 2. Use this set to execute a single cross-species phenosim analysis to compare against pheno profiles of 
# genes from 5 species (human, mouse, zebrafish, fly, worm)

# note: no human!!
taxids = [10090, 7955, 7227, 6239]
results = dict()
for taxid in taxids:
    response = get_phenotypically_similar_genes(phenotypes, taxid)
    results[taxid] = [{"id": r[0], "score": r[1], "symbol": r[2]} for r in response]

# %%
# 4. Remove FA genes from results (i.e. trim inputs)
# There's no human in here, so will do this after we get orthologs

# %%
# 5. Take top 25 results as gene ‘hits’
for taxid in results:
    print(taxid)
    print(results[taxid][:10])
# scores of each organism are very different, so I'll take the top X for each organism
# Out:
# 7227
# [{'id': 'FlyBase:FBgn0015218', 'symbol': 'eIF4E1', 'score': 44}, {'id': 'FlyBase:FBgn0003612', 'symbol': 'Su(var)2-10', 'score': 33}]
# 10090
# [{'id': 'MGI:1922667', 'symbol': 'Rspo2', 'score': 68}, {'id': 'MGI:95729', 'symbol': 'Gli3', 'score': 67}, {'id': 'MGI:1330810', 'symbol': 'Trp63', 'score': 65}, {'id': 'MGI:2443471', 'symbol': 'Sp8', 'score': 65}, {'id': 'MGI:104327', 'symbol': 'Nog', 'score': 65}, {'id': 'MGI:2682064', 'symbol': 'Ift172', 'score': 65}, {'id': 'MGI:106184', 'symbol': 'Npm1', 'score': 65}, {'id': 'MGI:99484', 'symbol': 'Chuk', 'score': 64}, {'id': 'MGI:1924238', 'symbol': 'Rdh10', 'score': 64}, {'id': 'MGI:1342540', 'symbol': 'Ikzf1', 'score': 63}]
# 7955
# [{'id': 'ZFIN:ZDB-GENE-030131-9685', 'symbol': 'ddx18', 'score': 60}, {'id': 'ZFIN:ZDB-GENE-041114-104', 'symbol': 'tbl3', 'score': 56}, {'id': 'ZFIN:ZDB-GENE-080405-1', 'symbol': 'tert', 'score': 56}, {'id': 'ZFIN:ZDB-GENE-040426-1947', 'symbol': 'chaf1b', 'score': 55}, {'id': 'ZFIN:ZDB-GENE-020424-3', 'symbol': 'lmna', 'score': 55}, {'id': 'ZFIN:ZDB-GENE-990415-270', 'symbol': 'tp53', 'score': 54}, {'id': 'ZFIN:ZDB-GENE-990415-206', 'symbol': 'pes', 'score': 54}, {'id': 'ZFIN:ZDB-GENE-001103-1', 'symbol': 'sox9a', 'score': 53}, {'id': 'ZFIN:ZDB-GENE-040728-1', 'symbol': 'ticrr', 'score': 53}, {'id': 'ZFIN:ZDB-GENE-020910-1', 'symbol': 'id2a', 'score': 52}]
# 6239
# [{'id': 'WormBase:WBGene00003901', 'symbol': 'paa-1', 'score': 49}, {'id': 'WormBase:WBGene00002363', 'symbol': 'let-92', 'score': 48}, {'id': 'WormBase:WBGene00000837', 'symbol': 'cul-2', 'score': 46}, {'id': 'WormBase:WBGene00000249', 'symbol': 'bir-1', 'score': 39}, {'id': 'WormBase:WBGene00016837', 'symbol': 'syf-1', 'score': 38}, {'id': 'WormBase:WBGene00010556', 'symbol': 'rack-1', 'score': 38}, {'id': 'WormBase:WBGene00000871', 'symbol': 'cye-1', 'score': 38}, {'id': 'WormBase:WBGene00010015', 'symbol': 'atad-3', 'score': 37}, {'id': 'WormBase:WBGene00000098', 'symbol': 'air-1', 'score': 37}, {'id': 'WormBase:WBGene00001005', 'symbol': 'dlc-1', 'score': 37}]

# %%
results = {k:sorted(v, key=lambda x:x['score'], reverse=True)[:10] for k,v in results.items()}

# %%
results_list = list(chain(*results.values()))
results_list
# Out:
# [{'id': 'ZFIN:ZDB-GENE-030131-9685', 'score': 60, 'symbol': 'ddx18'},
#  {'id': 'ZFIN:ZDB-GENE-041114-104', 'score': 56, 'symbol': 'tbl3'},
#  {'id': 'ZFIN:ZDB-GENE-080405-1', 'score': 56, 'symbol': 'tert'},
#  {'id': 'ZFIN:ZDB-GENE-040426-1947', 'score': 55, 'symbol': 'chaf1b'},
#  {'id': 'ZFIN:ZDB-GENE-020424-3', 'score': 55, 'symbol': 'lmna'},
#  {'id': 'ZFIN:ZDB-GENE-990415-270', 'score': 54, 'symbol': 'tp53'},
#  {'id': 'ZFIN:ZDB-GENE-990415-206', 'score': 54, 'symbol': 'pes'},
#  {'id': 'ZFIN:ZDB-GENE-001103-1', 'score': 53, 'symbol': 'sox9a'},
#  {'id': 'ZFIN:ZDB-GENE-040728-1', 'score': 53, 'symbol': 'ticrr'},
#  {'id': 'ZFIN:ZDB-GENE-020910-1', 'score': 52, 'symbol': 'id2a'},
#  {'id': 'MGI:1922667', 'score': 68, 'symbol': 'Rspo2'},
#  {'id': 'MGI:95729', 'score': 67, 'symbol': 'Gli3'},
#  {'id': 'MGI:1330810', 'score': 65, 'symbol': 'Trp63'},
#  {'id': 'MGI:2443471', 'score': 65, 'symbol': 'Sp8'},
#  {'id': 'MGI:104327', 'score': 65, 'symbol': 'Nog'},
#  {'id': 'MGI:2682064', 'score': 65, 'symbol': 'Ift172'},
#  {'id': 'MGI:106184', 'score': 65, 'symbol': 'Npm1'},
#  {'id': 'MGI:99484', 'score': 64, 'symbol': 'Chuk'},
#  {'id': 'MGI:1924238', 'score': 64, 'symbol': 'Rdh10'},
#  {'id': 'MGI:1342540', 'score': 63, 'symbol': 'Ikzf1'},
#  {'id': 'FlyBase:FBgn0015218', 'score': 44, 'symbol': 'eIF4E1'},
#  {'id': 'FlyBase:FBgn0003612', 'score': 33, 'symbol': 'Su(var)2-10'},
#  {'id': 'WormBase:WBGene00003901', 'score': 49, 'symbol': 'paa-1'},
#  {'id': 'WormBase:WBGene00002363', 'score': 48, 'symbol': 'let-92'},
#  {'id': 'WormBase:WBGene00000837', 'score': 46, 'symbol': 'cul-2'},
#  {'id': 'WormBase:WBGene00000249', 'score': 39, 'symbol': 'bir-1'},
#  {'id': 'WormBase:WBGene00016837', 'score': 38, 'symbol': 'syf-1'},
#  {'id': 'WormBase:WBGene00010556', 'score': 38, 'symbol': 'rack-1'},
#  {'id': 'WormBase:WBGene00000871', 'score': 38, 'symbol': 'cye-1'},
#  {'id': 'WormBase:WBGene00010015', 'score': 37, 'symbol': 'atad-3'},
#  {'id': 'WormBase:WBGene00000098', 'score': 37, 'symbol': 'air-1'},
#  {'id': 'WormBase:WBGene00001005', 'score': 37, 'symbol': 'dlc-1'}]

# %%
# 6. Retrieve human orthologs of any non-human gene hits
for r in tqdm_notebook(results_list):
    r['orthologs'] = query_orthologs(r['id'], "NCBITaxon:9606")
# Out:
# HBox(children=(IntProgress(value=0, max=32), HTML(value='')))

# %%
results_list = sorted(results_list, key=lambda x: x['score'], reverse=True)
df = pd.DataFrame(results_list)
df
# Out:
#                            id  \
# 0                 MGI:1922667
# 1                   MGI:95729
# 2                 MGI:1330810
# 3                 MGI:2443471
# 4                  MGI:104327
# 5                 MGI:2682064
# 6                  MGI:106184
# 7                   MGI:99484
# 8                 MGI:1924238
# 9                 MGI:1342540
# 10  ZFIN:ZDB-GENE-030131-9685
# 11   ZFIN:ZDB-GENE-041114-104
# 12     ZFIN:ZDB-GENE-080405-1
# 13  ZFIN:ZDB-GENE-040426-1947
# 14     ZFIN:ZDB-GENE-020424-3
# 15   ZFIN:ZDB-GENE-990415-270
# 16   ZFIN:ZDB-GENE-990415-206
# 17     ZFIN:ZDB-GENE-001103-1
# 18     ZFIN:ZDB-GENE-040728-1
# 19     ZFIN:ZDB-GENE-020910-1
# 20    WormBase:WBGene00003901
# 21    WormBase:WBGene00002363
# 22    WormBase:WBGene00000837
# 23        FlyBase:FBgn0015218
# 24    WormBase:WBGene00000249
# 25    WormBase:WBGene00016837
# 26    WormBase:WBGene00010556
# 27    WormBase:WBGene00000871
# 28    WormBase:WBGene00010015
# 29    WormBase:WBGene00000098
# 30    WormBase:WBGene00001005
# 31        FlyBase:FBgn0003612
#
#                                           orthologs  score       symbol
# 0                                      [HGNC:28583]     68        Rspo2
# 1                                       [HGNC:4319]     67         Gli3
# 2                                      [HGNC:15979]     65        Trp63
# 3                                      [HGNC:19196]     65          Sp8
# 4                                       [HGNC:7866]     65          Nog
# 5                                      [HGNC:30391]     65       Ift172
# 6                                       [HGNC:7910]     65         Npm1
# 7                                       [HGNC:1974]     64         Chuk
# 8                                      [HGNC:19975]     64        Rdh10
# 9                                      [HGNC:13176]     63        Ikzf1
# 10                                      [HGNC:2741]     60        ddx18
# 11                                     [HGNC:11587]     56         tbl3
# 12                                     [HGNC:11730]     56         tert
# 13                                      [HGNC:1911]     55       chaf1b
# 14                                      [HGNC:6636]     55         lmna
# 15                                     [HGNC:11998]     54         tp53
# 16                                      [HGNC:8848]     54          pes
# 17                                     [HGNC:11204]     53        sox9a
# 18                                     [HGNC:28704]     53        ticrr
# 19                                      [HGNC:5361]     52         id2a
# 20                           [HGNC:9303, HGNC:9302]     49        paa-1
# 21                           [HGNC:9300, HGNC:9299]     48       let-92
# 22                                      [HGNC:2552]     46        cul-2
# 23                          [HGNC:33179, HGNC:3287]     44       eIF4E1
# 24                                               []     39        bir-1
# 25                                     [HGNC:14089]     38        syf-1
# 26                                      [HGNC:4399]     38       rack-1
# 27                           [HGNC:1590, HGNC:1589]     38        cye-1
# 28             [HGNC:32151, HGNC:25567, HGNC:24007]     37       atad-3
# 29             [HGNC:11391, HGNC:11393, HGNC:11390]     37        air-1
# 30                                     [HGNC:24596]     37        dlc-1
# 31  [HGNC:2752, HGNC:17311, HGNC:17002, HGNC:16861]     33  Su(var)2-10

# %%
# mark any rows where the ortholog is a FA gene
df = pd.DataFrame(results_list)
df = df[df.orthologs.map(len)>0]
df1 = df.orthologs.apply(pd.Series).stack().rename('ortholog')
df1 = df1.to_frame().reset_index(1, drop=True)
df = df[['id', 'score', 'symbol']]
df = df.join(df1).reset_index(drop=True)
df['fa'] = df.ortholog.isin(human_FA_genes)

# %%
df['ortholog_label'] = df.ortholog.map(lambda x: get_obj(x)['label'])

# %%
df
# Out:
#                            id  score       symbol    ortholog     fa  \
# 0                 MGI:1922667     68        Rspo2  HGNC:28583  False
# 1                   MGI:95729     67         Gli3   HGNC:4319  False
# 2                 MGI:1330810     65        Trp63  HGNC:15979  False
# 3                 MGI:2443471     65          Sp8  HGNC:19196  False
# 4                  MGI:104327     65          Nog   HGNC:7866  False
# 5                 MGI:2682064     65       Ift172  HGNC:30391  False
# 6                  MGI:106184     65         Npm1   HGNC:7910  False
# 7                   MGI:99484     64         Chuk   HGNC:1974  False
# 8                 MGI:1924238     64        Rdh10  HGNC:19975  False
# 9                 MGI:1342540     63        Ikzf1  HGNC:13176  False
# 10  ZFIN:ZDB-GENE-030131-9685     60        ddx18   HGNC:2741  False
# 11   ZFIN:ZDB-GENE-041114-104     56         tbl3  HGNC:11587  False
# 12     ZFIN:ZDB-GENE-080405-1     56         tert  HGNC:11730  False
# 13  ZFIN:ZDB-GENE-040426-1947     55       chaf1b   HGNC:1911  False
# 14     ZFIN:ZDB-GENE-020424-3     55         lmna   HGNC:6636  False
# 15   ZFIN:ZDB-GENE-990415-270     54         tp53  HGNC:11998  False
# 16   ZFIN:ZDB-GENE-990415-206     54          pes   HGNC:8848  False
# 17     ZFIN:ZDB-GENE-001103-1     53        sox9a  HGNC:11204  False
# 18     ZFIN:ZDB-GENE-040728-1     53        ticrr  HGNC:28704  False
# 19     ZFIN:ZDB-GENE-020910-1     52         id2a   HGNC:5361  False
# 20    WormBase:WBGene00003901     49        paa-1   HGNC:9303  False
# 21    WormBase:WBGene00003901     49        paa-1   HGNC:9302  False
# 22    WormBase:WBGene00002363     48       let-92   HGNC:9300  False
# 23    WormBase:WBGene00002363     48       let-92   HGNC:9299  False
# 24    WormBase:WBGene00000837     46        cul-2   HGNC:2552  False
# 25        FlyBase:FBgn0015218     44       eIF4E1  HGNC:33179  False
# 26        FlyBase:FBgn0015218     44       eIF4E1   HGNC:3287  False
# 27    WormBase:WBGene00016837     38        syf-1  HGNC:14089  False
# 28    WormBase:WBGene00010556     38       rack-1   HGNC:4399  False
# 29    WormBase:WBGene00000871     38        cye-1   HGNC:1590  False
# 30    WormBase:WBGene00000871     38        cye-1   HGNC:1589  False
# 31    WormBase:WBGene00010015     37       atad-3  HGNC:32151  False
# 32    WormBase:WBGene00010015     37       atad-3  HGNC:25567  False
# 33    WormBase:WBGene00010015     37       atad-3  HGNC:24007  False
# 34    WormBase:WBGene00000098     37        air-1  HGNC:11391  False
# 35    WormBase:WBGene00000098     37        air-1  HGNC:11393  False
# 36    WormBase:WBGene00000098     37        air-1  HGNC:11390  False
# 37    WormBase:WBGene00001005     37        dlc-1  HGNC:24596  False
# 38        FlyBase:FBgn0003612     33  Su(var)2-10   HGNC:2752  False
# 39        FlyBase:FBgn0003612     33  Su(var)2-10  HGNC:17311  False
# 40        FlyBase:FBgn0003612     33  Su(var)2-10  HGNC:17002  False
# 41        FlyBase:FBgn0003612     33  Su(var)2-10  HGNC:16861  False
#
#    ortholog_label
# 0           RSPO2
# 1            GLI3
# 2            TP63
# 3             SP8
# 4             NOG
# 5          IFT172
# 6            NPM1
# 7            CHUK
# 8           RDH10
# 9           IKZF1
# 10          DDX18
# 11           TBL3
# 12           TERT
# 13         CHAF1B
# 14           LMNA
# 15           TP53
# 16           PES1
# 17           SOX9
# 18          TICRR
# 19            ID2
# 20        PPP2R1B
# 21        PPP2R1A
# 22         PPP2CB
# 23         PPP2CA
# 24           CUL2
# 25        EIF4E1B
# 26          EIF4E
# 27           XAB2
# 28          RACK1
# 29          CCNE2
# 30          CCNE1
# 31         ATAD3C
# 32         ATAD3A
# 33         ATAD3B
# 34          AURKC
# 35          AURKA
# 36          AURKB
# 37         DYNLL2
# 38          PIAS1
# 39          PIAS2
# 40          PIAS4
# 41          PIAS3

# %%
## Example of inspecting one gene result

# %%
# take the top match (MGI:1922667 Rspo2), and gets its phenotypes
mgi_1922667_pheno = get_phenotype_from_gene_verbose("MGI:1922667")
pprint(mgi_1922667_pheno)
# Out:
# [('HP:0003974', 'Absent radius'),
#  ('HP:0000175', 'Cleft palate'),
#  ('MP:0009898', 'maxillary shelf hypoplasia'),
#  ('MP:0002257', 'abnormal arytenoid cartilage morphology'),
#  ('MP:0000088', 'short mandible'),
#  ('MP:0001928', 'abnormal ovulation'),
#  ('MP:0005306', 'abnormal phalanx morphology'),
#  ('MP:0004540', 'small maxilla'),
#  ('MP:0009887', 'abnormal palatal shelf fusion at midline'),
#  ('MP:0013933', "short Meckel's cartilage"),
#  ('MP:0000527', 'abnormal kidney development'),
#  ('HP:0000204', 'Cleft upper lip'),
#  ('MP:0006279', 'abnormal limb development'),
#  ('MP:0011087', 'neonatal lethality, complete penetrance'),
#  ('MP:0008494', 'absence of all nails'),
#  ('HP:0009803', 'Short phalanx of finger'),
#  ('MP:0009885', 'abnormal palatal shelf elevation'),
#  ('HP:0001159', 'Syndactyly'),
#  ('HP:0000138', 'Ovarian cyst'),
#  ('HP:0006426', 'Rudimentary to absent tibiae'),
#  ('MP:0005270', 'abnormal zygomatic bone morphology'),
#  ('HP:0011849', 'Abnormal bone ossification'),
#  ('MP:0009888', 'palatal shelves fail to meet at midline'),
#  ('HP:0011297', 'Abnormality of digit'),
#  ('MP:0004912', 'absent mandibular coronoid process'),
#  ('HP:0000104', 'Renal agenesis'),
#  ('MP:0001923', 'reduced female fertility'),
#  ('HP:0010743', 'Short metatarsal'),
#  ('MP:0005359', 'growth retardation of incisors'),
#  ('GO:0060441PHENOTYPE',
#   'epithelial tube branching involved in lung morphogenesis phenotype'),
#  ('MP:0000550', 'abnormal forelimb morphology'),
#  ('MP:0002256', 'abnormal laryngeal cartilage morphology'),
#  ('MP:0011089', 'perinatal lethality, complete penetrance'),
#  ('HP:0005922', 'Abnormal hand morphology'),
#  ('HP:0012165', 'Oligodactyly'),
#  ('GO:0071542PHENOTYPE', 'dopaminergic neuron differentiation phenotype'),
#  ('HP:0005736', 'Short tibia'),
#  ('HP:0000961', 'Cyanosis'),
#  ('HP:0002088', 'Abnormal lung morphology'),
#  ('MP:0003120', 'abnormal tracheal cartilage morphology'),
#  ('MP:0000455', 'abnormal maxilla morphology'),
#  ('MP:0001676', 'abnormal apical ectodermal ridge morphology'),
#  ('HP:0000122', 'Unilateral renal agenesis'),
#  ('MP:0030302', 'abnormal maxillary zygomatic process morphology'),
#  ('MP:0004423', 'abnormal temporal bone squamous part morphology'),
#  ('MP:0003119', 'abnormal digestive system development'),
#  ('MP:0009895', 'decreased palatine bone horizontal plate size'),
#  ('MP:0004538', 'abnormal maxillary shelf morphology'),
#  ('MP:0000556', 'abnormal hindlimb morphology'),
#  ('HP:0000171', 'Microglossia'),
#  ('MP:0003855', 'abnormal forelimb zeugopod morphology'),
#  ('MP:0000116', 'abnormal tooth development'),
#  ('MP:0002270', 'abnormal pulmonary alveolus morphology'),
#  ('HP:0002089', 'Pulmonary hypoplasia'),
#  ('MP:0004596', 'abnormal mandibular angle morphology'),
#  ('MP:0002258', 'abnormal cricoid cartilage morphology'),
#  ('MP:0011262', 'abnormal pharyngeal arch mesenchyme morphology'),
#  ('MP:0000528', 'delayed kidney development'),
#  ('MP:0002109', 'abnormal limb morphology'),
#  ('MP:0001182', 'lung hemorrhage'),
#  ('HP:0005790', 'Short mandibular condyles'),
#  ('MP:0004007', 'abnormal lung vasculature morphology'),
#  ('HP:0002093', 'Respiratory insufficiency'),
#  ('HP:0003038', 'Fibular hypoplasia'),
#  ('MP:0006020', 'decreased tympanic ring size'),
#  ('HP:0002990', 'Fibular aplasia'),
#  ('MP:0004592', 'small mandible'),
#  ('MP:0000579', 'abnormal nail morphology')]

# %%
d = get_phenotypically_similar_genes(phenotypes, "10090", return_all=True)
genes = get_phenotypically_similar_genes(phenotypes, "10090", return_all=False)

# %%
# look at the matching phenotypes for Rspo2
match = d['b'][0]
(match['id'],match['label'])
# Out:
# ('MGI:1922667', 'Rspo2')

# %%
# one example phenotype match
match['matches'][0]
# Out:
# {'a': {'IC': 8.776246271125785,
#   'id': 'HP:0000978',
#   'label': 'Bruising susceptibility'},
#  'b': {'IC': 10.195197153340976,
#   'id': 'MP:0001182',
#   'label': 'lung hemorrhage'},
#  'lcs': {'IC': 5.6458484075315125,
#   'id': 'MP:0001634',
#   'label': 'internal hemorrhage'}}

# %%
# FA phenotypes and Rspo2 are "phenotypically similar" because of these phenotypes in common
# the phenotypes in the square brackets are the phenotypes that are determined to be similar to each other
for m in match['matches']:
    print(" ".join([m['lcs']['label'], "({})".format(m['lcs']['id']), 
                    "[{}, {}]".format(m['a']['label'], m['b']['label'])]))
# Out:
# internal hemorrhage (MP:0001634) [Bruising susceptibility, lung hemorrhage]
# tissue development phenotype (GO:0009888PHENOTYPE) [Bone marrow hypocellularity, epithelial tube branching involved in lung morphogenesis phenotype]
# Abnormality of the neck (HP:0000464) [Short neck, abnormal pharyngeal arch mesenchyme morphology]
# micrognathia (MP:0002639) [Micrognathia, small mandibular condyloid process]
# absent kidney (MP:0000520) [Renal agenesis, single kidney]
# absent radius (MP:0000553) [Absent radius, absent radius]
# thoracic segment blood vessel phenotype (UBERON:0003834PHENOTYPE) [Patent ductus arteriosus, abnormal lung vasculature morphology]
# abnormal trachea morphology (MP:0002282) [Tracheoesophageal fistula, abnormal tracheal cartilage morphology]
# abnormal ear morphology (MP:0002102) [Low-set ears, decreased tympanic ring size]
# abnormal phalanx morphology (MP:0005306) [Complete duplication of thumb phalanx, Short phalanx of finger]
# oligodactyly (MP:0000565) [Absent thumb, oligodactyly]
# cleft secondary palate (MP:0009890) [Cleft palate, palatal shelves fail to meet at midline]
# abnormal(ly) delayed developmental process (ZP:0000606) [Global developmental delay, delayed kidney development]
