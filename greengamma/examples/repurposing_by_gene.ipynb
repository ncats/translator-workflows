# %% [markdown]
# # Repurposing by gene

# %%
#To make nicer looking outputs
from IPython.core.display import display, HTML
import requests

#Load some functions for parsing quick output
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from gg_functions import parse_answer, get_view_url

robokop='robokop.renci.org'

# %%
common_diseases = [
("MONDO:0005578","arthritis"),
("MONDO:0005148","type 2 diabetes mellitus"),
("MONDO:0002406","dermatitis"),
("MONDO:0008383","rheumatoid arthritis"),
("MONDO:0005359","drug-induced liver injury"),
("MONDO:0006573","lipodystrophy (disease)"),
("MONDO:0008226","aggressive periodontitis"),
("MONDO:0001627","dementia"),
("MONDO:0005265","inflammatory bowel disease"),
("MONDO:0004979","asthma"),
("MONDO:0005298","osteoporosis"),
("MONDO:0006932","pulmonary edema"),
("MONDO:0005180","Parkinson disease"),
("MONDO:0006658","arteriolosclerosis"),
("MONDO:0005090","schizophrenia"),
("MONDO:0005152","hypopituitarism"),
("MONDO:0001835","facial paralysis"),
("MONDO:0001824","polyneuropathy"),
("MONDO:0005301","multiple sclerosis"),
("MONDO:0006644","alcoholic liver cirrhosis")
]

# %%
rare_diseases = [
    ("MONDO:0019600","xeroderma pigmentosum"),
    ("MONDO:0016006","cockayne syndrome"),
    ("MONDO:0015797","UV-sensitive syndrome"),
    ("MONDO:0011125","Triciothiodystrophy"),
    ("MONDO:0001076","glucose intolerance"),
    ("MONDO:0010086","sudden infant death syndrome"),
    ('MONDO:0010940', 'inherited susceptibility to asthma'),
    ('MONDO:0007319', 'familial calcium pyrophosphate deposition'),
    ('MONDO:0020087', 'genetic lipodystrophy'),
    ('MONDO:0007455', 'diabetes mellitus, noninsulin-dependent'),
    ('MONDO:0007191','Behcet disease'),
    ('MONDO:0005100','systemic sclerosis'),
    ('MONDO:0010602','hemophilia A'),
    ('MONDO:0006507','hereditary hemochromatosis'),
    ('MONDO:0019599','primary lipodystrophy'),
    ('MONDO:0015547','genetic dementia'),
    ('MONDO:0015978','functional neutrophil defect'),
    ('MONDO:0007186','gastroesophageal reflux disease'),
    ('MONDO:0009061','cystic fibrosis'),
    ('MONDO:0009971','newborn respiratory distress syndrome'),
    ('MONDO:0011565','metabolic syndrome X'),
    ('MONDO:0008752','Alexander disease'),
    ('MONDO:0008364','Raynaud disease')
]

# %%
#This is the templated query that goes (disease)-(set of phenotypes)-(genetic condition)
turl=lambda robokop,disease_id,disease_name: f'http://{robokop}/api/simple/quick/template/repurposing_by_gene/{disease_id}/?name1={disease_name}/?max_connectivity=1000'

for disease_id, disease_name in common_diseases + rare_diseases:
    url = turl(robokop,disease_id,disease_name)
    display(HTML(f'<h3>{disease_name}</h3>'))
    response = requests.get(url)
    if response.status_code != 200:
        print('Error')
        continue
    answers=response.json()
    view_url = get_view_url(answers)
    display(HTML(f'<a href={view_url}>View Answer in ROBOKOP</a>'))
    answer_frame = parse_answer(answers,node_list=['n1','n2','n3'],edge_list=[])
    display(answer_frame.head())
# Out:
# <h3>arthritis</h3>
# <a href=http://robokop.renci.org/simple/view/c99e191b-9fc6-4620-b683-6e0e5020a123>View Answer in ROBOKOP</a>
#     n1 - id  n1 - name        n2 - id             n2 - name      n3 - id   \
# 0  HGNC:5992       IL1B  MONDO:0008383  rheumatoid arthritis   CHEBI:9334
# 1  HGNC:9605      PTGS2  MONDO:0008383  rheumatoid arthritis  CHEBI:47381
# 2  HGNC:9605      PTGS2  MONDO:0008383  rheumatoid arthritis  CHEBI:15365
# 3  HGNC:9605      PTGS2  MONDO:0008383  rheumatoid arthritis  CHEBI:49662
# 4  HGNC:5992       IL1B  MONDO:0008383  rheumatoid arthritis  CHEBI:49662
#
#              n3 - name      score
# 0         sulfasalazine  1.549245
# 1            diclofenac  1.527538
# 2  acetylsalicylic acid  1.466144
# 3           indometacin  1.464441
# 4           indometacin  1.443556
# <h3>type 2 diabetes mellitus</h3>
# <a href=http://robokop.renci.org/simple/view/087fdf48-d3cc-4a56-9cb5-aee51fd3140a>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id                    n2 - name   \
# 0   HGNC:6081        INS  MONDO:0004946                 hypoglycemia
# 1  HGNC:11180       SOD2  MONDO:0004946                 hypoglycemia
# 2  HGNC:11005     SLC2A1  MONDO:0004946                 hypoglycemia
# 3  HGNC:11892        TNF  MONDO:0004946                 hypoglycemia
# 4   HGNC:9236      PPARG  MONDO:0005015  diabetes mellitus (disease)
#
#       n3 - id      n3 - name      score
# 0  CHEBI:17234        glucose  1.640596
# 1  CHEBI:17234        glucose  1.625354
# 2  CHEBI:17234        glucose  1.624671
# 3  CHEBI:17234        glucose  1.619602
# 4  CHEBI:50122  rosiglitazone  1.480010
# <h3>dermatitis</h3>
# <a href=http://robokop.renci.org/simple/view/b648e295-eae2-4ee5-8494-d7b275bd454b>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id           n2 - name      n3 - id   \
# 0  HGNC:11892        TNF  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 1   HGNC:9605      PTGS2  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 2    HGNC:270      PARP1  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 3  HGNC:11892        TNF  MONDO:0004992              cancer  CHEBI:28748
# 4   HGNC:5992       IL1B  MONDO:0005070  neoplasm (disease)  CHEBI:28748
#
#     n3 - name      score
# 0  doxorubicin  1.332763
# 1  doxorubicin  1.166760
# 2  doxorubicin  1.156890
# 3  doxorubicin  1.137048
# 4  doxorubicin  1.132071
# <h3>rheumatoid arthritis</h3>
# <a href=http://robokop.renci.org/simple/view/4b67ea7c-5261-4bdd-ad11-e170781f39a3>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id           n2 - name      n3 - id   \
# 0  HGNC:11892        TNF  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 1  HGNC:11892        TNF  MONDO:0005178      osteoarthritis  CHEBI:47381
# 2  HGNC:11998       TP53  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 3  HGNC:11920        FAS  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 4   HGNC:9605      PTGS2  MONDO:0005578           arthritis  CHEBI:15365
#
#              n3 - name      score
# 0           doxorubicin  1.534599
# 1            diclofenac  1.406937
# 2           doxorubicin  1.344782
# 3           doxorubicin  1.296991
# 4  acetylsalicylic acid  1.284262
# <h3>drug-induced liver injury</h3>
# <a href=http://robokop.renci.org/simple/view/90cc7359-0ed6-4456-8dd4-f5ed611ee5a7>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id             n2 - name      n3 - id   \
# 0  HGNC:11892        TNF  MONDO:0005070    neoplasm (disease)  CHEBI:28748
# 1     HGNC:40      ABCB1  MONDO:0005070    neoplasm (disease)  CHEBI:28748
# 2   HGNC:7436      MTHFR  MONDO:0008383  rheumatoid arthritis  CHEBI:44185
# 3     HGNC:53      ABCC2  MONDO:0008383  rheumatoid arthritis  CHEBI:44185
# 4  HGNC:11180       SOD2  MONDO:0005070    neoplasm (disease)  CHEBI:28748
#
#      n3 - name      score
# 0   doxorubicin  1.330195
# 1   doxorubicin  1.174525
# 2  methotrexate  1.157386
# 3  methotrexate  1.152073
# 4   doxorubicin  1.147612
# <h3>lipodystrophy (disease)</h3>
# <a href=http://robokop.renci.org/simple/view/8a8b0b7f-2388-497a-98bc-b9ee9026c773>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id                 n2 - name   \
# 0  HGNC:11892        TNF  MONDO:0005070        neoplasm (disease)
# 1  HGNC:11892        TNF  MONDO:0008383      rheumatoid arthritis
# 2  HGNC:11892        TNF  MONDO:0004992                    cancer
# 3  HGNC:11892        TNF  MONDO:0005148  type 2 diabetes mellitus
# 4  HGNC:11009     SLC2A4  MONDO:0005148  type 2 diabetes mellitus
#
#       n3 - id     n3 - name      score
# 0  CHEBI:28748   doxorubicin  1.329875
# 1  CHEBI:44185  methotrexate  1.154673
# 2  CHEBI:28748   doxorubicin  1.134306
# 3   CHEBI:6801     metformin  1.127883
# 4   CHEBI:6801     metformin  1.093118
# <h3>aggressive periodontitis</h3>
# <a href=http://robokop.renci.org/simple/view/ae36b276-9fe0-4281-afde-c0ef7515535f>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id                    n2 - name   \
# 0   HGNC:2528       CTSC  MONDO:0005070           neoplasm (disease)
# 1   HGNC:2528       CTSC  MONDO:0004992                       cancer
# 2   HGNC:2528       CTSC  MONDO:0005070           neoplasm (disease)
# 3   HGNC:2528       CTSC  MONDO:0004992                       cancer
# 4  HGNC:26877     CKAP2L  MONDO:0002985  pustulosis of palm and sole
#
#       n3 - id       n3 - name      score
# 0  CHEBI:32509  pirinixic acid  0.523460
# 1  CHEBI:32509  pirinixic acid  0.521689
# 2  CHEBI:39867   valproic acid  0.521646
# 3  CHEBI:39867   valproic acid  0.521617
# 4   CHEBI:4031   cyclosporin A  0.506364
# <h3>dementia</h3>
# <a href=http://robokop.renci.org/simple/view/00ff0577-94fd-4c10-bdd5-5ec5e9000ebc>View Answer in ROBOKOP</a>
#    n1 - id  n1 - name        n2 - id          n2 - name      n3 - id   \
# 0  HGNC:108       ACHE  MONDO:0004975  Alzheimer disease  CHEBI:42944
# 1  HGNC:108       ACHE  MONDO:0004975  Alzheimer disease  CHEBI:53289
# 2  HGNC:108       ACHE  MONDO:0004975  Alzheimer disease   CHEBI:8874
# 3  HGNC:983       BCHE  MONDO:0004975  Alzheimer disease  CHEBI:53289
# 4  HGNC:620        APP  MONDO:0004975  Alzheimer disease  CHEBI:45713
#
#           n3 - name      score
# 0       galanthamine  1.538689
# 1          donepezil  1.538651
# 2       rivastigmine  1.514700
# 3          donepezil  1.479617
# 4  trans-resveratrol  1.372596
# <h3>inflammatory bowel disease</h3>
# <a href=http://robokop.renci.org/simple/view/6f023ac7-b998-4b91-b17b-f165bb5143f6>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id                     n2 - name   \
# 0  HGNC:11892        TNF  MONDO:0005101  ulcerative colitis (disease)
# 1   HGNC:5992       IL1B  MONDO:0005101  ulcerative colitis (disease)
# 2  HGNC:11892        TNF  MONDO:0005070            neoplasm (disease)
# 3   HGNC:1504      CASP3  MONDO:0005070            neoplasm (disease)
# 4     HGNC:40      ABCB1  MONDO:0005070            neoplasm (disease)
#
#       n3 - id      n3 - name      score
# 0   CHEBI:9334  sulfasalazine  1.493110
# 1   CHEBI:9334  sulfasalazine  1.442453
# 2  CHEBI:28748    doxorubicin  1.413513
# 3  CHEBI:28748    doxorubicin  1.243069
# 4  CHEBI:28748    doxorubicin  1.230278
# <h3>asthma</h3>
# <a href=http://robokop.renci.org/simple/view/fe1cd50e-67d4-487b-b567-4140310fabb6>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id           n2 - name      n3 - id   \
# 0  HGNC:11892        TNF  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 1    HGNC:990       BCL2  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 2   HGNC:1516        CAT  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 3   HGNC:9605      PTGS2  MONDO:0005070  neoplasm (disease)  CHEBI:28748
# 4   HGNC:1771       CDK2  MONDO:0005070  neoplasm (disease)  CHEBI:28748
#
#     n3 - name      score
# 0  doxorubicin  1.334970
# 1  doxorubicin  1.177572
# 2  doxorubicin  1.168995
# 3  doxorubicin  1.168498
# 4  doxorubicin  1.163217
# <h3>osteoporosis</h3>
# <a href=http://robokop.renci.org/simple/view/e03ab040-5466-4e26-9456-4dfed3649832>View Answer in ROBOKOP</a>
#      n1 - id  n1 - name        n2 - id             n2 - name      n3 - id   \
# 0  HGNC:11892        TNF  MONDO:0005070    neoplasm (disease)  CHEBI:28748
# 1  HGNC:11892        TNF  MONDO:0008383  rheumatoid arthritis   CHEBI:9334
# 2  HGNC:11892        TNF  MONDO:0004992                cancer  CHEBI:28748
# 3   HGNC:7176       MMP9  MONDO:0005070    neoplasm (disease)  CHEBI:28748
# 4    HGNC:391       AKT1  MONDO:0005070    neoplasm (disease)  CHEBI:28748
#
#       n3 - name      score
# 0    doxorubicin  1.334222
# 1  sulfasalazine  1.178537
# 2    doxorubicin  1.169061
# 3    doxorubicin  1.161357
# 4    doxorubicin  1.160819
# <h3>pulmonary edema</h3>
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                     # otherwise it looks like a programming error was the cause.
# --> 386                     six.raise_from(e, None)
#     387         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                     # otherwise it looks like a programming error was the cause.
# --> 386                     six.raise_from(e, None)
#     387         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-cf67d4ed3975> in <module>()
#       5     url = turl(robokop,disease_id,disease_name)
#       6     display(HTML(f'<h3>{disease_name}</h3>'))
# ----> 7     response = requests.get(url)
#       8     if response.status_code != 200:
#       9         print('Error')
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /home/bizon/anaconda2/envs/robokop/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     486
#     487         except (ProtocolError, socket.error) as err:
# --> 488             raise ConnectionError(err, request=request)
#     489
#     490         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
