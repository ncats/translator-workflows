# %%
import requests

# define query sent to the reasoner
query = {"query_type_id": "compoundToIndication", "terms": {"chemical_substance": "CHEMBL:CHEMBL521"}}

# send query
r = requests.post("https://indigo.ncats.io/reasoner/api/v0/query", json=query)
print(r.text)
# Out:
# {
#   "context": "translator_indigo_qa",
#   "datetime": "2018-10-02 11:37:51.385877",
#   "result_list": [
#     {
#       "result_graph": {
#         "edge_list": [
#           {
#             "attribute_list": [
#               {
#                 "name": "id",
#                 "value": 106054
#               }
#             ],
#             "provided_by": "hgnc",
#             "source_id": "558349",
#             "target_id": "558348",
#             "type": "PRODUCT_OF"
#           },
#           {
#             "attribute_list": [
#               {
#                 "name": "activity_value",
#                 "value": 86000.0
#               },
#               {
#                 "name": "activity_unit",
#                 "value": "nM"
#               },
#               {
#                 "name": "activity_type",
#                 "value": "Ki"
#               },
#               {
#                 "name": "id",
#                 "value": 114342
#               }
# ...
