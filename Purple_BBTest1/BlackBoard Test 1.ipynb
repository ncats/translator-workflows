# %% [markdown]
# # Interacting with the Blackboard

# %%
import urllib, requests, json, time
bb_url = 'https://translator.ncats.io/blackboard/api/kg'
#bb_url = 'http://localhost:9000/blackboard/api/kg'

# %%
#query = {"type": "query", "name": "A simple blackboard example","term": "asthma"}
query = {"type":"drug", "uri":"https://pharos.ncats.io/idg/api/v1/ligands(31242)", 
         "name":"imatinib", "description": "This is an example query seeded with gleevec"}
json.dumps(query)
req = requests.post(bb_url, json=query)
req.status_code
# Out:
# 200

# %% [markdown]
# Having posted the query, we then retrieve the resultant knowledge graph (KG) is JSON form. The blackboard can contain multiple knowledge graphs (one for each query submitted to it). So we identify the KG with the highest id, which should correspond to the query we just submitted

# %%
kg = requests.get(bb_url).json()
latest_kg_id = max([x['id'] for x in kg])
kg_url = bb_url+"/"+str(latest_kg_id)
print('Currently have %d KGs. Will use KG ID=%d, %s' % (len(kg), latest_kg_id, kg_url))
# Out:
# Currently have 2 KGs. Will use KG ID=33, https://translator.ncats.io/blackboard/api/kg/33

# %% [markdown]
# We then update the KG using the Pharos KS (note this needs to be a `PUT` request)

# %%
req = requests.put(kg_url+"/ks.pharos")
req.status_code
time.sleep(10)

# %% [markdown]
# Now we retrieve the current state of the KG. By default we get a condensed representation of the KG. To get the complete JSON representation we append `?view=full`

# %%
req = requests.get(kg_url+"?view=full")
req.json()
# Out:
# {'edgeCount': 6,
#  'edges': [{'directed': False,
#    'id': 173,
#    'source': 34,
#    'target': 35,
#    'type': 'inhibitor'},
#   {'directed': False,
#    'id': 174,
#    'source': 34,
#    'target': 36,
#    'type': 'inhibitor'},
#   {'directed': False,
#    'id': 175,
#    'source': 34,
#    'target': 37,
#    'type': 'inhibitor'}],
#  'id': 33,
#  'name': 'imatinib',
#  'nodeCount': 4,
#  'nodes': [{'degree': 3,
#    'description': 'This is an example query seeded with gleevec',
#    'id': 34,
#    'inDegree': 0,
#    'kgraph': 33,
#    'name': 'imatinib',
#    'outDegree': 3,
#    'tags': ['KQuery', 'drug', 'KG:33'],
#    'type': 'drug',
#    'uri': 'https://pharos.ncats.io/idg/api/v1/ligands(31242)'},
#   {'degree': 1,
#    'id': 35,
#    'inDegree': 1,
#    'kgraph': 33,
#    'name': 'Tyrosine-protein kinase ABL1',
#    'outDegree': 0,
#    'synonyms': ['4J9D',
#     '4J9F',
#     '5DC0',
#     '5DC4',
#     '5DC9',
#     '1AB2',
#     '1ABL',
#     '1AWO',
#     '1BBZ',
#     '1JU5',
#     '1OPL',
#     '1ZZP',
#     '2ABL',
#     '2E2B',
#     '2F4J',
#     '2FO0',
#     '2G1T',
#     '2G2F',
#     '2G2H',
#     '2G2I',
#     '2GQG',
#     '2HIW',
#     '2HYY',
#     '2HZ0',
#     '2HZ4',
#     '2HZI',
#     '2O88',
#     '2V7A',
#     '3CS9',
#     '3EG0',
#     '3EG1',
#     '3EG2',
#     '3EG3',
#     '3EGU',
#     '3K2M',
#     '3PYY',
#     '3QRI',
#     '3QRJ',
#     '3QRK',
#     '3T04',
#     '3UE4',
#     '3UYO',
#     '4J9B',
#     '4J9C',
#     '4J9E',
#     '4J9G',
#     '4J9H',
#     '4J9I',
#     '4JJB',
#     '4JJC',
#     '4JJD',
#     '4TWP',
#     '4WA9',
#     '4XEY',
#     '4YC8',
#     '4ZOG',
#     '5HU9',
#     'P00519',
#     'ENSP00000361423',
#     'ABL1_HUMAN',
#     'ABL1',
#     '25',
#     'DTO_03100006',
#     'A3KFJ3',
#     'Q13869',
#     'Q13870',
#     'Q16133',
#     'Q17R61',
#     'Q45F09',
#     'ABL',
#     'JTK7',
#     'p150',
#     'c-ABL',
#     'v-abl',
#     'c-ABL1',
#     'bcr/abl',
#     'TCRD:120',
#     '608232',
#     'M14752',
#     'X16416',
#     'U07563',
#     'U07561',
#     'DQ145721',
#     'AL359092',
#     'AL161733',
#     'CH471090',
#     'BC117451',
#     'S69223',
#     'CCDS35165.1',
#     'CCDS35166.1',
#     'S08519',
#     'NP_005148.2',
#     'NP_009297.2',
#     'Hs.431048',
#     '106543',
#     'DIP-1042N',
#     'MINT-7236141',
#     '9606.ENSP00000361423',
#     'CHEMBL1862',
#     'DB00171',
#     'DB06616',
#     'DB01254',
#     'DB00619',
#     'DB04868',
#     'DB08901',
#     'DB08896',
#     '85681908',
#     'ENST00000318560',
#     'ENSP00000323315',
#     'ENSG00000097007',
#     'ENST00000372348',
#     'hsa:25',
#     'uc004bzv.4',
#     'HGNC:76',
#     'CAB002686',
#     'HPA027251',
#     'HPA027280',
#     'HPA028409',
#     '189980',
#     'NX_P00519',
#     '521',
#     '99860',
#     '99861',
#     'PA24413',
#     'KOG0197',
#     'COG0515',
#     'HBG004162',
#     'K06619',
#     'GAFRESG',
#     'EOG091G0D46',
#     'TF105081',
#     'ZFISH:HS01874-MONOMER',
#     '2.7.10.2',
#     'R-HSA-2029482',
#     'R-HSA-375170',
#     'R-HSA-428890',
#     'R-HSA-5663213',
#     'R-HSA-5685938',
#     'R-HSA-5693565',
#     'R-HSA-983231',
#     'ABL_(gene)',
#     'PR:P00519',
#     'UP000005640',
#     'HS_ABL1',
#     '3.30.505.10',
#     'IPR033221',
#     'IPR015015',
#     'IPR011009',
#     'IPR000719',
#     'IPR017441',
#     'IPR001245',
#     'IPR000980',
#     'IPR001452',
#     'IPR008266',
#     'IPR020635',
#     'PTHR24418:SF88',
#     'PF08919',
#     'PF07714',
#     'PF00017',
#     'PF00018',
#     'PR00401',
#     'PR00109',
#     'SM00808',
#     'SM00252',
#     'SM00326',
#     'SM00219',
#     'SSF50044',
#     'SSF55550',
#     'SSF56112',
#     'PS00107',
#     'PS50011',
#     'PS00109',
#     'PS50001',
#     'PS50002',
#     '258588232',
#     '594147088',
#     '576865144',
#     '185178034',
#     '109658752',
#     '109157768',
#     '88192844',
#     '334359317',
#     '93279684',
#     '1002351502',
#     '799532070',
#     '576865113',
#     '365813281',
#     '177943',
#     '158431055',
#     '576865120',
#     '258588237',
#     '576865152',
#     '126030694',
#     '756142820',
#     '292659701',
#     '30749935',
#     '109157754',
#     '576865142',
#     '384482326',
#     '576865128',
#     '149241245',
#     '514268',
#     '334359314',
#     '576865116',
#     '576865132',
#     '325534014',
#     '126030686',
#     '119389607',
#     '114794379',
#     '158431054',
#     '4139930',
#     '334359316',
#     '576865122',
#     '126030693',
#     '576865134',
#     '756142938',
#     '1002351501',
#     '75765955',
#     '1002351128',
#     '149241246',
#     '62362414',
#     '126030691',
#     '576865156',
#     '159162563',
#     '384482325',
#     '358009605',
#     '126030685',
#     '119389608',
#     '325534013',
#     '576865145',
#     '185178035',
#     '334359313',
#     '109157765',
#     '109157762',
#     '109157763',
#     '146386598',
#     '157834528',
#     '334359315',
#     '576865140',
#     '109157757',
#     '126030692',
#     '159162035',
#     '114794378',
#     '1048348417',
#     '126030688',
#     '126030690',
#     '756142939',
#     '1002351127',
#     '4261734',
#     '28237',
#     '109157766',
#     '157830118',
#     '576865126',
#     '258588230',
#     '185178036',
#     '576865138',
#     '71648778',
#     '576865136',
#     '4139936',
#     '576865143',
#     '109157756',
#     '185178033',
#     '62362412',
#     '126030689',
#     '1002351504',
#     '576865154',
#     '30749936',
#     '146386597',
#     '576865130',
#     '576865114',
#     '799532069',
#     '594147090',
#     '258588235',
#     '4139932',
#     '576865124',
#     '594147089',
#     '258588236',
#     '109157755',
#     '157838255',
#     '109157767',
#     '292659700',
#     '756142819',
#     '576865141',
#     '576865118',
#     '126030687',
#     '126030695',
#     '258588231',
#     'MGI:87859',
#     'UCSC',
#     'Abl1',
#     'HHG7H7',
#     'MIM:189980'],
#    'tags': ['protein', 'KS:pharos', 'KG:33'],
#    'type': 'protein',
#    'uri': 'https://pharos.ncats.io/idg/api/v1/targets(8442)'},
#   {'degree': 1,
#    'id': 36,
#    'inDegree': 1,
#    'kgraph': 33,
#    'name': 'Platelet-derived growth factor receptor beta',
#    'outDegree': 0,
#    'synonyms': ['3MJG',
#     '1H9O',
#     '1GQ5',
#     '1LWP',
#     '1SHA',
#     '2L6W',
#     '2PLD',
#     '2PLE',
#     'P09619',
#     'ENSP00000261799',
#     'PGFRB_HUMAN',
#     'PDGFRB',
#     '5159',
#     'DTO_03100404',
#     'B5A957',
#     'Q8N5L4',
#     'PDGF-R-beta',
#     'IMF1',
#     'KOGS',
#     'IBGC4',
#     'JTK12',
#     'PDGFR',
#     'PENTT',
#     'CD140B',
#     'PDGFR1',
#     'PDGFR-1',
#     'TCRD:12972',
#     '131440',
#     '601626',
#     '607785',
#     '615007',
#     '228550',
#     '616592',
#     '601812',
#     'J03278',
#     'M21616',
#     'EU826595',
#     'AC005895',
#     'AC011382',
#     'BC032224',
#     'U33172',
#     'CCDS4303.1',
#     'A28206',
#     'NP_002600.1',
#     'XP_011535960.1',
#     'XP_011535961.1',
#     'Hs.509067',
#     '111185',
#     'DIP-558N',
#     'MINT-148093',
#     '9606.ENSP00000261799',
#     'CHEMBL1913',
#     'DB00102',
#     'DB01254',
#     'DB00619',
#     'DB06589',
#     'DB08896',
#     'DB00398',
#     'DB01268',
#     '129890',
#     'ENST00000261799',
#     'ENSG00000113721',
#     'hsa:5159',
#     'uc003lro.4',
#     'HGNC:8804',
#     'CAB003842',
#     'CAB018144',
#     'HPA028499',
#     '173410',
#     'NX_P09619',
#     '1980',
#     '98823',
#     '2591',
#     '168950',
#     '314950',
#     '86830',
#     'PA33148',
#     'KOG0200',
#     'COG0515',
#     'HOG000112009',
#     'HBG004335',
#     'K05089',
#     'APYDNYV',
#     'EOG091G01TL',
#     'TF325768',
#     'ZFISH:HS03710-MONOMER',
#     '2.7.10.1',
#     'R-HSA-1257604',
#     'R-HSA-186763',
#     'R-HSA-186797',
#     'R-HSA-2219530',
#     'R-HSA-5673001',
#     'R-HSA-6811558',
#     'PR:P09619',
#     'UP000005640',
#     'HS_PDGFRB',
#     '2.60.40.10',
#     'IPR007110',
#     'IPR013783',
#     'IPR013098',
#     'IPR003599',
#     'IPR003598',
#     'IPR013151',
#     'IPR011009',
#     'IPR027288',
#     'IPR000719',
#     'IPR017441',
#     'IPR001245',
#     'IPR008266',
#     'IPR020635',
#     'IPR016243',
#     'IPR001824',
#     'PTHR24416:SF53',
#     'PF07679',
#     'PF00047',
#     'PF07714',
#     'PIRSF500948',
#     'PIRSF000615',
#     'SM00409',
#     'SM00408',
#     'SM00219',
#     'SSF48726',
#     'SSF56112',
#     'PS50835',
#     'PS00107',
#     'PS50011',
#     'PS00109',
#     'PS00240',
#     '298508636',
#     '189730',
#     '767937783',
#     '27065015',
#     '425684925',
#     '298508637',
#     '388603837',
#     '4505683',
#     '1074138095',
#     '194318486',
#     '2107947',
#     '21594833',
#     '388603836',
#     '444841757',
#     '767937785',
#     '189732',
#     '119582152',
#     'MGI:97531',
#     'UCSC',
#     'Pdgfrb',
#     'MIM:173410'],
#    'tags': ['protein', 'KS:pharos', 'KG:33'],
#    'type': 'protein',
#    'uri': 'https://pharos.ncats.io/idg/api/v1/targets(13027)'},
#   {'degree': 1,
#    'id': 37,
#    'inDegree': 1,
#    'kgraph': 33,
#    'name': 'Mast/stem cell growth factor receptor Kit',
#    'outDegree': 0,
#    'synonyms': ['2IUH',
#     '2VIF',
#     '2E9W',
#     '1PKG',
#     '1QZJ',
#     '1QZK',
#     '1R01',
#     '1T45',
#     '1T46',
#     '2EC8',
#     '3G0E',
#     '3G0F',
#     '4HVS',
#     '4K94',
#     '4K9E',
#     '4PGZ',
#     '4U0I',
#     'P10721',
#     'ENSP00000288135',
#     'KIT_HUMAN',
#     'KIT',
#     '3815',
#     'DTO_03100231',
#     'B5A956',
#     'D5LXN2',
#     'D5M931',
#     'F5H8F8',
#     'Q6IQ28',
#     'Q99662',
#     'Q9UM99',
#     'SCFR',
#     'PBT',
#     'C-Kit',
#     'CD117',
#     'TCRD:9532',
#     '172800',
#     '606764',
#     '273300',
#     '601626',
#     'X06182',
#     'X69301',
#     'X69302',
#     'X69303',
#     'X69304',
#     'X69305',
#     'X69306',
#     'X69307',
#     'X69308',
#     'X69309',
#     'X69310',
#     'X69311',
#     'X69312',
#     'X69313',
#     'X69314',
#     'X69315',
#     'X69316',
#     'U63834',
#     'EU826594',
#     'GU983671',
#     'HM015525',
#     'HM015526',
#     'AK304031',
#     'AC006552',
#     'AC092545',
#     'BC071593',
#     'S67773',
#     'CCDS3496.1',
#     'CCDS47058.1',
#     'S01426',
#     'NP_000213.1',
#     'NP_001087241.1',
#     'Hs.479754',
#     '110015',
#     'DIP-1055N',
#     'MINT-146746',
#     '9606.ENSP00000288135',
#     'CHEMBL1936',
#     'DB01254',
#     'DB00619',
#     'DB09078',
#     'DB04868',
#     'DB06589',
#     'DB08901',
#     'DB08896',
#     'DB00398',
#     'DB01268',
#     '125472',
#     'ENST00000288135',
#     'ENSG00000157404',
#     'ENST00000412167',
#     'ENSP00000390987',
#     'hsa:3815',
#     'uc010igr.4',
#     'HGNC:6342',
#     'CAB003288',
#     'CAB068253',
#     'CAB072867',
#     'HPA004471',
#     '164920',
#     'NX_P10721',
#     '98829',
#     '102724',
#     '98834',
#     '158799',
#     '280785',
#     '158796',
#     '79455',
#     '44890',
#     '158778',
#     '158793',
#     '158772',
#     '2884',
#     '158769',
#     '280794',
#     '158775',
#     '98849',
#     '90389',
#     '158766',
#     'PA30128',
#     'KOG0200',
#     'COG0515',
#     'HOG000112008',
#     'HBG104348',
#     'K05091',
#     'YFCPGTE',
#     'EOG091G01TL',
#     'TF325768',
#     'ZFISH:HS08211-MONOMER',
#     '2.7.10.1',
#     'R-HSA-1257604',
#     'R-HSA-1433557',
#     'R-HSA-1433559',
#     'R-HSA-2219530',
#     'R-HSA-5673001',
#     'R-HSA-6811558',
#     'R-HSA-8866910',
#     'PR:P10721',
#     'UP000005640',
#     'HS_KIT',
#     '2.60.40.10',
#     'IPR007110',
#     'IPR013783',
#     'IPR003599',
#     'IPR003598',
#     'IPR013151',
#     'IPR011009',
#     'IPR000719',
#     'IPR017441',
#     'IPR027263',
#     'IPR001245',
#     'IPR008266',
#     'IPR020635',
#     'IPR016243',
#     'IPR001824',
#     'PF00047',
#     'PF07714',
#     'PIRSF500951',
#     'PIRSF000615',
#     'SM00409',
#     'SM00408',
#     'SM00219',
#     'SSF48726',
#     'SSF56112',
#     'PS50835',
#     'PS00107',
#     'PS50011',
#     'PS00109',
#     'PS00240',
#     '224036434',
#     '695722224',
#     '550544549',
#     '1817734',
#     '550544552',
#     '194384344',
#     '34810084',
#     '224036435',
#     '157834865',
#     '50513700',
#     '770386295',
#     '459359',
#     '471270629',
#     '4557695',
#     '34810085',
#     '148005039',
#     '50513701',
#     '157834866',
#     '294961288',
#     '157834902',
#     '224036436',
#     '194318484',
#     '163931093',
#     '770386294',
#     '294769659',
#     '110590660',
#     '47938802',
#     '294961286',
#     '770386293',
#     'MGI:96677',
#     'UCSC',
#     'Kit',
#     'VG9H9',
#     'MIM:164920'],
#    'tags': ['protein', 'KS:pharos', 'KG:33'],
#    'type': 'protein',
#    'uri': 'https://pharos.ncats.io/idg/api/v1/targets(13578)'}],
#  'type': 'kgraph'}

# %% [markdown]
# As noted in the [documentation](https://spotlite.nih.gov/ncats/blackboard) we can rerun the Pharos KS to add more nodes and edges. The first call, above, added nodes that were related to the query node (and the associated edges). When we call it again, it will add nodes that are related to the nodes added in the previous run (i.e., 2nd neighbors of the query node)

# %%
req = requests.put(kg_url+"/ks.pharos")
time.sleep(30)

# %%
## Dump out the KG JSON for inspection
req = requests.get(kg_url+"?view=full")
ofile = open('kg.json', 'w') ## for reference
ofile.write(req.text)
ofile.close()

# %% [markdown]
# Currently the knowledge graph is stored in a [Neo4J](https://neo4j.com/) instance. We can interact with this assuming you have a Neo4J client running and pointed to `blackboard.db` that was created by the blackboard API.
#
# Alternatively, we can parse the JSON representation of the knowledge graph into an `igraph` object and then visualize it using the Cytoscape [extension](https://github.com/cytoscape/jupyter-cytoscape) for Jupyter notebooks. (This is most easily installed if you're using the Anaconda distribution of Python).
#
# First we make a function to go from the Knowlegde Graph JSON to an `igraph` object

# %%
from igraph import *

def kg2ig(kg):
    if kg['type'] != 'kgraph':
        raise Exception("Must provide a JSON kgraph")

    g = Graph(directed=False)

    nodes = kg['nodes']
    for node in nodes:
        d = {}
        for key in node.keys():
            if key in ['inDegree','outDegree','degree', 'id']: continue
            #key = key.encode("ascii")
            d[key] = node[key]
        g.add_vertex(**d)

    edges = kg['edges']
    for edge in edges:
        s = list(filter(lambda x: x['id'] == edge['source'], nodes))
        t = list(filter(lambda x: x['id'] == edge['target'], nodes))
        if len(s) == 1 and len(t) == 1:
            g.add_edge(s[0]['name'],t[0]['name'], type=edge['type'])
        
    return g

# %% [markdown]
# We then use this to get the object and then display it via the Cytoscape extension

# %%
req = requests.get(kg_url+"?view=full")
g = kg2ig(json.loads(req.text))
print(g.summary())
# Out:
# IGRAPH UN-T 39 70 --
# + attr: description (v), kgraph (v), name (v), synonyms (v), tags (v), type (v), uri (v), type (e)

# %%
from cyjs import *
cy = cyjs()
display(cy)

# %%
cy.deleteGraph()
cy.addGraph(g)
kkLayout = g.layout("kk")
cy.setPosition(kkLayout)
cy.fit(10)

# %%
cy.loadStyleFile('bb-style.js')

# %% [markdown]
# Given the current network, we can push it to [Ndex](http://www.ndexbio.org/). You should have created an account, which you'll need to push the KG into Ndex.

# %%
from ndex.networkn import NdexGraph
import ndex.client as nc
import uuid
ng = NdexGraph()
ng.set_name(kg_url)
for n in g.vs:
    ng.add_new_node(n['name'], n.attributes())
for idx, e in enumerate(g.es):
    eid = ng.add_edge_between(e.source+1, e.target+1)
    ng.set_edge_attribute(eid, 'type', e['type'])

client = nc.Ndex("http://dev.ndexbio.org", 'foobar123', 'hello123')
uri = client.save_new_network(ng.to_cx())
uuid = uri.rpartition('/')[-1]
##client.make_network_public(uuid)
print("KG is on Ndex at %s" % (uri))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/ndex/create_aspect.py in node_attributes(G, has_single_subnetwork)
#      84                     if not isinstance(attribute_value, string_types):
# ---> 85                         element['d'] = domain(attribute_value)
#      86
#
# /usr/local/lib/python3.4/dist-packages/ndex/create_aspect.py in domain(val)
#     224     if type(val) is list:
# --> 225         if isinstance(val[0], string_types):
#     226             return 'list_of_string'
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-c3314663f178> in <module>()
#      11
#      12 client = nc.Ndex("http://dev.ndexbio.org", 'foobar123', 'hello123')
# ---> 13 uri = client.save_new_network(ng.to_cx())
#      14 uuid = uri.rpartition('/')[-1]
#      15 ##client.make_network_public(uuid)
#
# /usr/local/lib/python3.4/dist-packages/ndex/networkn.py in to_cx(self, md_dict)
#     613         cx += ca.nodes(G)
#     614         cx += ca.edges(G)
# --> 615         node_att = ca.node_attributes(G, has_single_subnetwork)
#     616         if(node_att is not None):
#     617             cx += node_att
#
# /usr/local/lib/python3.4/dist-packages/ndex/create_aspect.py in node_attributes(G, has_single_subnetwork)
#      95
#      96     except Exception as e:
# ---> 97         print(e.message)
#      98
#      99
#
# AttributeError: 'IndexError' object has no attribute 'message'

# %% [markdown]
# Once the KG has been pushed to the Ndex server, you can search for it using the KG ID (or URL)
