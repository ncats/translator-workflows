# %% [markdown]
# ## Orange QB1.4

# %% [markdown]
# ### Query:
# Return sequences of FA genes associated with functional post-translational modifications.

# %%
# import biothing explorer (current in local, will make it an independent python package)
from visual import pathViewer

# %%
# pathViewer is a Python class for graphically display API connection maps and explore bio-entity relaitonships
k = pathViewer()

# %% [markdown]
# #### Show All Available IDs
# Users could call the **availbale_ids** function to retrieve all IDs as well as descriptions for these ids used in BioThings Explorer

# %%
# uncomment the code below to show all available ids in BioThings Explorer
# k.available_ids()

# %% [markdown]
# #### Show How APIs/Endpoints/Bio-Entities can be connected together
# graph is **interactive**

# %%
# uncomment the code the below to show api road map
# k.show_api_road_map()

# %% [markdown]
# #### Find Path
# The CQ question above ask to find the path connecting **NCBI Gene IDs** and **PTM info**.
# **find_path** function could be used here to find how two different biological entities/concepts can be connected together through API endpoints

# %%
# set display_graph to True to show graph display of the path between 'NCBI Gene' and 'PTM Object'
k.find_path('NCBI Gene', 'PTM Object', display_graph=False)
# Out:
# Path 0: [{'endpoint': 'http://mygene.info/v3/gene/geneid', 'input': 'NCBI Gene', 'output': 'UniProt Knowledgebase'}, {'endpoint': 'http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM', 'input': 'UniProt Knowledgebase', 'output': 'PTM Object'}]
# [[{'endpoint': 'http://mygene.info/v3/gene/geneid',
#    'input': 'NCBI Gene',
#    'output': 'UniProt Knowledgebase'},
#   {'endpoint': 'http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM',
#    'input': 'UniProt Knowledgebase',
#    'output': 'PTM Object'}]]

# %% [markdown]
# #### Find output for single input
# Users could utilize **find_output** function to find the output for one single input using the selected path

# %%
# 675 is a NCBI Gene ID in the FA Gene List
# find_output takes two parameters
# the first parameter is path, users should select the path ID based on the results from 'find_path'
# the second parameter is value, which represent the input value
k.find_output(path=k.paths[0], value='675', display_graph=False)

# %% [markdown]
# #### Print result summary

# %%
k.result_summary()
# Out:
# Your exploration starts from NCBI Gene: 675.
#  It goes through 2 API Endpoints.
#  The final output comes from API Endpoint http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM.
#  You can access the final output by calling the 'final_results' object in pathViewer Class.

# %% [markdown]
# #### Explore results
# The final results is represented using a dictionary with the key being the input, and the value being the final output

# %%
k.final_results
# Out:
# {'675': [{'begin': '70',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '70',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '445',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '445',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '492',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '492',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '755',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '755',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/17525332',
#       'id': '17525332',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17525332'}}],
#    'type': 'MOD_RES'},
#   {'begin': '1970',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '1970',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2035',
#    'category': 'PTM',
#    'description': 'Phosphothreonine',
#    'end': '2035',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '2095',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '2095',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3291',
#    'category': 'PTM',
#    'description': 'Phosphoserine; by CDK1 and CDK2',
#    'end': '3291',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/15800615',
#       'id': '15800615',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15800615'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3319',
#    'category': 'PTM',
#    'description': 'Phosphoserine',
#    'end': '3319',
#    'evidences': [{'code': 'ECO:0000244',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#       'id': '23186163',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#    'type': 'MOD_RES'},
#   {'begin': '3387',
#    'category': 'PTM',
#    'description': 'Phosphothreonine; by CHEK1 and CHEK2',
#    'end': '3387',
#    'evidences': [{'code': 'ECO:0000269',
#      'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/18317453',
#       'id': '18317453',
#       'name': 'PubMed',
#       'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18317453'}}],
#    'type': 'MOD_RES'}]}

# %% [markdown]
# #### Explorer a list of Inputs
# FA Gene List contains 26 different genes, users could input all these genes together using **find_output** function

# %%
import pandas as pd
'''
return list of FA genes from github txt file
'''
def get_fa_gene_list():
    gene_list_url = 'https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_4_all_genes.txt'
    gl = pd.read_table(gene_list_url, header=None)
    gene_id = [_gene.replace('NCBIGene:','') for _gene in gl[0].values.tolist()]
    gene_symbol = gl[1].values.tolist()
    new_dict = {}
    for i, _id in enumerate(gene_id):
        new_dict.update({_id: gene_symbol[i]})
    return new_dict
gene_dict = get_fa_gene_list()
gene_list = list(gene_dict.keys())

print(gene_list)
# Out:
# ['2187', '2178', '55215', '5888', '675', '378708', '199990', '5889', '2177', '2175', '55120', '84464', '201254', '2189', '7516', '2072', '91442', '79728', '29089', '80233', '55159', '672', '2176', '83990', '57697', '2188', '10459']

# %%
k.find_output(path=k.paths[0], value=gene_list, display_graph=False)

# %%
k.result_summary()
# Out:
# Your exploration starts from NCBI Gene: ['2187', '2178', '55215', '5888', '675', '378708', '199990', '5889', '2177', '2175', '55120', '84464', '201254', '2189', '7516', '2072', '91442', '79728', '29089', '80233', '55159', '672', '2176', '83990', '57697', '2188', '10459'].
#  It goes through 2 API Endpoints.
#  The final output comes from API Endpoint http://www.ebi.ac.uk/proteins/api/features/accession?categories=PTM.
#  You can access the final output by calling the 'final_results' object in pathViewer Class.

# %% [markdown]
# Each key in the final_results represent one input (e.g. NCBI Gene ID)

# %%
results = k.final_results

# %% [markdown]
# #### Retrieve output for a specific NCBI Gene ID in the FA Gene List

# %%
results['199990']
# Out:
# [{'begin': '113',
#   'category': 'PTM',
#   'description': 'Phosphoserine',
#   'end': '113',
#   'evidences': [{'code': 'ECO:0000244',
#     'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#      'id': '23186163',
#      'name': 'PubMed',
#      'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#   'type': 'MOD_RES'},
#  {'begin': '137',
#   'category': 'PTM',
#   'description': 'Phosphoserine',
#   'end': '137',
#   'evidences': [{'code': 'ECO:0000244',
#     'source': {'alternativeUrl': 'http://europepmc.org/abstract/MED/23186163',
#      'id': '23186163',
#      'name': 'PubMed',
#      'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23186163'}}],
#   'type': 'MOD_RES'}]

# %% [markdown]
# #### Organize data

# %%
from bs4 import BeautifulSoup
import requests

def get_label_for_eco_code(eco):
    url_template = 'http://data.bioontology.org/ontologies/ECO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2F{{input}}'
    request_url = url_template.replace('{{input}}', eco.replace(':', '_'))
    r = requests.get(request_url,  headers={ "Content-Type" : "application/json"}, params={'apikey': 'c97ec130-f6ee-45e2-91fd-46e34135051f'})
    if r.status_code == 200:
        return r.json()['prefLabel']
                    
                                                                                           
def rearrange_dict(ptm_dict):
    new_dict = {}
    i = 0
    eco_label_dict = {}
    for gene_id, ptm_info in ptm_dict.items():
        if ptm_info:
            for _info in ptm_info:
                _info.update({'NCBI Gene ID': gene_id, 'Gene Symbol': gene_dict[gene_id]})
                new_evidence = ''
                if 'evidences' in _info:
                    for _evidence in _info['evidences']:
                        if _evidence['code'] in eco_label_dict.keys():
                            eco_label = eco_label_dict[_evidence['code']]
                        else:
                            eco_label = get_label_for_eco_code(_evidence['code'])
                            eco_label_dict.update({_evidence['code']: eco_label})
                        new_evidence += (_evidence['code'] + ' - ' + eco_label + '\n')
                        if 'source' in _evidence and 'id' in _evidence['source']: 
                             new_evidence += ('PMID:' + _evidence['source']['id'] + '\n\n')
                _info.update({'evidences': new_evidence})
                if 'description' in _info:
                    _info['PTM_Type'] = _info.pop('description')
                new_dict.update({i: _info})
                i+=1
        else:
            new_dict.update({i: {'NCBI Gene ID': gene_id, 'Gene Symbol': gene_dict[gene_id]}})
            i+=1
    return new_dict

# %%
new_dict = rearrange_dict(k.final_results)

# %%
df = pd.DataFrame.from_dict(new_dict, orient="index")

# %%
df
# Out:
#                                              evidences begin   end  \
# 0    ECO:0000244 - combinatorial evidence used in m...     2     2
# 1    ECO:0000244 - combinatorial evidence used in m...   249   249
# 2    ECO:0000269 - experimental evidence used in ma...   346   346
# 3    ECO:0000269 - experimental evidence used in ma...   374   374
# 4    ECO:0000244 - combinatorial evidence used in m...     2     2
# 5    ECO:0000269 - experimental evidence used in ma...    54    54
# 6    ECO:0000269 - experimental evidence used in ma...   309   309
# 7    ECO:0000269 - experimental evidence used in ma...    58    58
# 8    ECO:0000269 - experimental evidence used in ma...    64    64
# 9    ECO:0000244 - combinatorial evidence used in m...    70    70
# 10   ECO:0000244 - combinatorial evidence used in m...   445   445
# 11   ECO:0000244 - combinatorial evidence used in m...   492   492
# 12   ECO:0000244 - combinatorial evidence used in m...   755   755
# 13   ECO:0000244 - combinatorial evidence used in m...  1970  1970
# 14   ECO:0000244 - combinatorial evidence used in m...  2035  2035
# 15   ECO:0000244 - combinatorial evidence used in m...  2095  2095
# 16   ECO:0000269 - experimental evidence used in ma...  3291  3291
# 17   ECO:0000244 - combinatorial evidence used in m...  3319  3319
# 18   ECO:0000269 - experimental evidence used in ma...  3387  3387
# 19   ECO:0000244 - combinatorial evidence used in m...     1     1
# 20   ECO:0000244 - combinatorial evidence used in m...   113   113
# 21   ECO:0000244 - combinatorial evidence used in m...   137   137
# 22   ECO:0000244 - combinatorial evidence used in m...    20    20
# 23                                                 NaN   NaN   NaN
# 24   ECO:0000244 - combinatorial evidence used in m...     8     8
# 25   ECO:0000269 - experimental evidence used in ma...   222   222
# 26   ECO:0000244 - combinatorial evidence used in m...   592   592
# 27   ECO:0000244 - combinatorial evidence used in m...   594   594
# 28   ECO:0000244 - combinatorial evidence used in m...   717   717
# 29   ECO:0000244 - combinatorial evidence used in m...  1257  1257
# ..                                                 ...   ...   ...
# 127  ECO:0000244 - combinatorial evidence used in m...   339   339
# 128  ECO:0000244 - combinatorial evidence used in m...   443   443
# 129  ECO:0000244 - combinatorial evidence used in m...   459   459
# 130  ECO:0000244 - combinatorial evidence used in m...   519   519
# 131  ECO:0000244 - combinatorial evidence used in m...   583   583
# 132  ECO:0000244 - combinatorial evidence used in m...   654   654
# 133  ECO:0000244 - combinatorial evidence used in m...   734   734
# 134  ECO:0000244 - combinatorial evidence used in m...   739   739
# 135  ECO:0000244 - combinatorial evidence used in m...   918   918
# 136  ECO:0000244 - combinatorial evidence used in m...   987   987
# 137  ECO:0000244 - combinatorial evidence used in m...  1079  1079
# 138                                                NaN   NaN   NaN
# 139  ECO:0000244 - combinatorial evidence used in m...   505   505
# 140  ECO:0000244 - combinatorial evidence used in m...   927   927
# 141  ECO:0000244 - combinatorial evidence used in m...   930   930
# 142  ECO:0000244 - combinatorial evidence used in m...   956   956
# 143  ECO:0000244 - combinatorial evidence used in m...   990   990
# 144  ECO:0000244 - combinatorial evidence used in m...  1004  1004
# 145  ECO:0000244 - combinatorial evidence used in m...  1032  1032
# 146  ECO:0000244 - combinatorial evidence used in m...  1237  1237
# 147  ECO:0000269 - experimental evidence used in ma...  1249  1249
# 148  ECO:0000244 - combinatorial evidence used in m...    34    34
# 149  ECO:0000244 - combinatorial evidence used in m...  1673  1673
# 150  ECO:0000244 - combinatorial evidence used in m...  1674  1674
# 151  ECO:0000244 - combinatorial evidence used in m...   184   184
# 152  ECO:0000269 - experimental evidence used in ma...    91    91
# 153  ECO:0000269 - experimental evidence used in ma...   182   182
# 154  ECO:0000244 - combinatorial evidence used in m...   191   191
# 155  ECO:0000244 - combinatorial evidence used in m...   192   192
# 156                                                NaN   NaN   NaN
#
#                                               PTM_Type category NCBI Gene ID  \
# 0                                    N-acetylthreonine      PTM         2187
# 1                                        Phosphoserine      PTM         2178
# 2                           Phosphothreonine; by CHEK1      PTM         2178
# 3                              Phosphoserine; by CHEK1      PTM         2178
# 4                                      N-acetylalanine      PTM         5888
# 5                             Phosphotyrosine; by ABL1      PTM         5888
# 6                           Phosphothreonine; by CHEK1      PTM         5888
# 7    Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM         5888
# 8    Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM         5888
# 9                                        Phosphoserine      PTM          675
# 10                                       Phosphoserine      PTM          675
# 11                                       Phosphoserine      PTM          675
# 12                                       Phosphoserine      PTM          675
# 13                                       Phosphoserine      PTM          675
# 14                                    Phosphothreonine      PTM          675
# 15                                       Phosphoserine      PTM          675
# 16                     Phosphoserine; by CDK1 and CDK2      PTM          675
# 17                                       Phosphoserine      PTM          675
# 18                Phosphothreonine; by CHEK1 and CHEK2      PTM          675
# 19                                  N-acetylmethionine      PTM       378708
# 20                                       Phosphoserine      PTM       199990
# 21                                       Phosphoserine      PTM       199990
# 22                                       Phosphoserine      PTM         5889
# 23                                                 NaN      NaN         2188
# 24                                       Phosphoserine      PTM         2177
# 25                               Phosphoserine; by ATM      PTM         2177
# 26                                       Phosphoserine      PTM         2177
# 27                                       Phosphoserine      PTM         2177
# 28                                       Phosphoserine      PTM         2177
# 29                                       Phosphoserine      PTM         2177
# ..                                                 ...      ...          ...
# 127  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 128  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 129  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 130  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 131  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 132  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 133  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 134  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 135  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 136  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 137  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM          672
# 138                                                NaN      NaN         2176
# 139                                      Phosphoserine      PTM        83990
# 140                                      Phosphoserine      PTM        83990
# 141                                      Phosphoserine      PTM        83990
# 142                                      Phosphoserine      PTM        83990
# 143                                      Phosphoserine      PTM        83990
# 144                                      Phosphoserine      PTM        83990
# 145                                      Phosphoserine      PTM        83990
# 146                                      Phosphoserine      PTM        83990
# 147                                    N6-acetyllysine      PTM        83990
# 148                                      Phosphoserine      PTM        57697
# 149                                      Phosphoserine      PTM        57697
# 150                                      Phosphoserine      PTM        57697
# 151                                      Phosphoserine      PTM        29089
# 152  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM        29089
# 153  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM        29089
# 154  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM        29089
# 155  Glycyl lysine isopeptide (Lys-Gly) (interchain...      PTM        29089
# 156                                                NaN      NaN        10459
#
#     Gene Symbol      type
# 0         FANCB   MOD_RES
# 1         FANCE   MOD_RES
# 2         FANCE   MOD_RES
# 3         FANCE   MOD_RES
# 4         RAD51   MOD_RES
# 5         RAD51   MOD_RES
# 6         RAD51   MOD_RES
# 7         RAD51  CROSSLNK
# 8         RAD51  CROSSLNK
# 9         BRCA2   MOD_RES
# 10        BRCA2   MOD_RES
# 11        BRCA2   MOD_RES
# 12        BRCA2   MOD_RES
# 13        BRCA2   MOD_RES
# 14        BRCA2   MOD_RES
# 15        BRCA2   MOD_RES
# 16        BRCA2   MOD_RES
# 17        BRCA2   MOD_RES
# 18        BRCA2   MOD_RES
# 19        CENPS   MOD_RES
# 20       FAAP20   MOD_RES
# 21       FAAP20   MOD_RES
# 22       RAD51C   MOD_RES
# 23        FANCF       NaN
# 24       FANCD2   MOD_RES
# 25       FANCD2   MOD_RES
# 26       FANCD2   MOD_RES
# 27       FANCD2   MOD_RES
# 28       FANCD2   MOD_RES
# 29       FANCD2   MOD_RES
# ..          ...       ...
# 127       BRCA1  CROSSLNK
# 128       BRCA1  CROSSLNK
# 129       BRCA1  CROSSLNK
# 130       BRCA1  CROSSLNK
# 131       BRCA1  CROSSLNK
# 132       BRCA1  CROSSLNK
# 133       BRCA1  CROSSLNK
# 134       BRCA1  CROSSLNK
# 135       BRCA1  CROSSLNK
# 136       BRCA1  CROSSLNK
# 137       BRCA1  CROSSLNK
# 138       FANCC       NaN
# 139       BRIP1   MOD_RES
# 140       BRIP1   MOD_RES
# 141       BRIP1   MOD_RES
# 142       BRIP1   MOD_RES
# 143       BRIP1   MOD_RES
# 144       BRIP1   MOD_RES
# 145       BRIP1   MOD_RES
# 146       BRIP1   MOD_RES
# 147       BRIP1   MOD_RES
# 148       FANCM   MOD_RES
# 149       FANCM   MOD_RES
# 150       FANCM   MOD_RES
# 151       UBE2T   MOD_RES
# 152       UBE2T  CROSSLNK
# 153       UBE2T  CROSSLNK
# 154       UBE2T  CROSSLNK
# 155       UBE2T  CROSSLNK
# 156      MAD2L2       NaN
#
# [157 rows x 8 columns]

# %%
# output final results to csv file
df.to_csv('ptm_final_results.csv')

# %% [markdown]
# The final output file could be viewed or downloaded at https://github.com/NCATS-Tangerine/cq-notebooks/blob/master/Orange_QB1_Benchmark_CQs/QB1.4_Post_Trans_Mod/final_results/ptm_final_results.csv
