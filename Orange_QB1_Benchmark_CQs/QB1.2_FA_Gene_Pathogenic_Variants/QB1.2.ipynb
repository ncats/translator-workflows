# %% [markdown]
# # Orange QB1.2_FA_Gene_Pathogenic_Variants

# %% [markdown]
# ## Query:
# What core FA gene variants are pathogenic, and for what conditions? (i.e. cause or contribute to pathogenic outcomes)

# %% [markdown]
# ## Input:
# Hardcoded tsv file from:
# https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt

# %% [markdown]
# ## Goals:
#
# A benchmarking query to assess information in the Translator system about pathogenicity of variants in human FA core genes.
# This query is independently answerable using only CIViC data accessible via Wikidata, or ClinVar data accessible via Monarch/Biolink. This query will be used as a simple test case for aggregating results that are from different primary sources, served different knowledge beacons, and may use differnet IRIs for equivalent concepts.

# %% [markdown]
# ## Proposed Data Types, Sources, and Access Endpoints:
#
# ClinVar variant-disease associations (via Monarch/Biolink)
#
# CIViC variant-disease associations (via Wikidata, and soon via Biolink))

# %% [markdown]
# ## Proposed Sub-Queries/Tasks:
#
# ### Input: FA Gene X
#
# Retrieve all variants of Gene X
# Gene -[has_affected_feature]-> Variant (Monarch)
# Gene-[biological variant of] -> Variant (Wikidata)
#
# Retrieve all diseases caused by variants in set above
# Variant -[causes_or_contribues_to_condition*]-> Disease (Monarch)
# Variant-[positive diagnostic predictor] -> Variant (Wikidata)
#
# Output: Set of diseases associated with variant in FA gene(s)

# %%
import requests
import pandas as pd
from pprint import pprint

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_all_genes = "FA_4_all_genes.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_all_genes, sep='\t', names=columns)

# %%
fa_genes
# Out:
#          gene_curie gene_symbol
# 0     NCBIGene:2175       FANCA
# 1     NCBIGene:2187       FANCB
# 2     NCBIGene:2176       FANCC
# 3     NCBIGene:2178       FANCE
# 4     NCBIGene:2188       FANCF
# 5     NCBIGene:2189       FANCG
# 6    NCBIGene:55120       FANCL
# 7    NCBIGene:57697       FANCM
# 8     NCBIGene:2177      FANCD2
# 9    NCBIGene:55215       FANCI
# 10   NCBIGene:29089       UBE2T
# 11     NCBIGene:675       BRCA2
# 12   NCBIGene:83990       BRIP1
# 13   NCBIGene:79728       PALB2
# 14    NCBIGene:5889      RAD51C
# 15   NCBIGene:84464        SLX4
# 16    NCBIGene:2072       ERCC4
# 17    NCBIGene:5888       RAD51
# 18     NCBIGene:672       BRCA1
# 19   NCBIGene:10459      MAD2L2
# 20    NCBIGene:7516       XRCC2
# 21   NCBIGene:55159       RFWD3
# 22   NCBIGene:80233     FAAP100
# 23   NCBIGene:91442      FAAP24
# 24  NCBIGene:199990      FAAP20
# 25  NCBIGene:378708       CENPS
# 26  NCBIGene:201254       CENPX

# %%
#  return gene disease association data from biolink
def query_biolink_gene_disease(gene_curie):
    bl_url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/diseases/'
    params = {
        'fetch_objects': True,   
    }
    r = requests.get(url=bl_url.format(gene_curie), params=params)
    return r.json()

# %%
# geno terms to human readable labels
term_map_reversed = {
    "GENO:0000840": "pathogenic",
    "GENO:0000841": "likely pathogenic",
    "GENO:0000843": "benign",
    "GENO:0000844": "likely benign",
    "GENO:0000845": "uncertain significance"    
}

# %%
"""
Look for pathogenic variants and the disease 
they are implicated with via biolink
"""
result_set = []
for index, row in fa_genes.iterrows():
    bl_dat = query_biolink_gene_disease(row[0])
    for assoc in bl_dat['associations']:
        edges = assoc['evidence_graph']['edges']
        nodes = assoc['evidence_graph']['nodes']
        node_map = dict()
        for node in nodes:
            node_map[node['id']] = node['lbl']
        for edge in edges:
            if edge['pred'] in term_map_reversed.keys():
                pd_row = [row[1], row[0], node_map[edge['sub']], 
                       edge['sub'], term_map_reversed[edge['pred']], 
                       edge['pred'], node_map[edge['obj']], edge['obj']]
                result_set.append(pd_row)
    column_names = ['gene_name', 'gene_curie', 'variant_name', 'variant_curie', 
                    'relation_label', 'relation_curie', 'disease_label', 'disease_curie']
result_frame = pd.DataFrame(data=result_set, columns=column_names)
result_frame.to_csv('FA_pathogenic_variant_BioLink.csv', sep=',')
result_frame

# Returns dataFrame with FA gene ClinVar data.
# Out:
#      gene_name      gene_curie  \
# 0        FANCA   NCBIGene:2175
# 1        FANCA   NCBIGene:2175
# 2        FANCA   NCBIGene:2175
# 3        FANCA   NCBIGene:2175
# 4        FANCA   NCBIGene:2175
# 5        FANCA   NCBIGene:2175
# 6        FANCA   NCBIGene:2175
# 7        FANCA   NCBIGene:2175
# 8        FANCA   NCBIGene:2175
# 9        FANCA   NCBIGene:2175
# 10       FANCA   NCBIGene:2175
# 11       FANCA   NCBIGene:2175
# 12       FANCA   NCBIGene:2175
# 13       FANCA   NCBIGene:2175
# 14       FANCA   NCBIGene:2175
# 15       FANCA   NCBIGene:2175
# 16       FANCA   NCBIGene:2175
# 17       FANCA   NCBIGene:2175
# 18       FANCA   NCBIGene:2175
# 19       FANCA   NCBIGene:2175
# 20       FANCA   NCBIGene:2175
# 21       FANCA   NCBIGene:2175
# 22       FANCA   NCBIGene:2175
# 23       FANCA   NCBIGene:2175
# 24       FANCA   NCBIGene:2175
# 25       FANCB   NCBIGene:2187
# 26       FANCB   NCBIGene:2187
# 27       FANCB   NCBIGene:2187
# 28       FANCB   NCBIGene:2187
# 29       FANCB   NCBIGene:2187
# ...        ...             ...
# 5591     BRCA1    NCBIGene:672
# 5592     BRCA1    NCBIGene:672
# 5593     BRCA1    NCBIGene:672
# 5594     BRCA1    NCBIGene:672
# 5595     BRCA1    NCBIGene:672
# 5596     BRCA1    NCBIGene:672
# 5597     BRCA1    NCBIGene:672
# 5598     BRCA1    NCBIGene:672
# 5599     BRCA1    NCBIGene:672
# 5600     BRCA1    NCBIGene:672
# 5601     BRCA1    NCBIGene:672
# 5602     BRCA1    NCBIGene:672
# 5603     BRCA1    NCBIGene:672
# 5604     BRCA1    NCBIGene:672
# 5605     BRCA1    NCBIGene:672
# 5606     BRCA1    NCBIGene:672
# 5607     BRCA1    NCBIGene:672
# 5608     BRCA1    NCBIGene:672
# 5609     BRCA1    NCBIGene:672
# 5610     BRCA1    NCBIGene:672
# 5611     BRCA1    NCBIGene:672
# 5612     BRCA1    NCBIGene:672
# 5613     BRCA1    NCBIGene:672
# 5614     BRCA1    NCBIGene:672
# 5615     BRCA1    NCBIGene:672
# 5616     BRCA1    NCBIGene:672
# 5617     BRCA1    NCBIGene:672
# 5618     BRCA1    NCBIGene:672
# 5619     BRCA1    NCBIGene:672
# 5620    MAD2L2  NCBIGene:10459
#
#                                            variant_name  \
# 0     NC_000016.9:g.(89837128_89837200)_(89847471_89...
# 1     NM_000135.2(FANCA):c.1115_1118delTTGG (p.Val37...
# 2                             FANCA, 156-BP DEL, NT1515
# 3            NM_000135.2(FANCA):c.2574C>G (p.Ser858Arg)
# 4     NM_000135.2(FANCA):c.3788_3790delTCT (p.Phe126...
# 5             NM_000135.2(FANCA):c.513G>A (p.Trp171Ter)
# 6         NM_000135.2(FANCA):c.2839dupT (p.Ser947Phefs)
# 7     NM_000135.2(FANCA):c.3761_3762delAG (p.Glu1254...
# 8         NM_000135.2(FANCA):c.1615delG (p.Asp539Thrfs)
# 9            NM_000135.2(FANCA):c.2557C>T (p.Arg853Ter)
# 10                          LRG_495t1:c.1627_1900del274
# 11    NM_000135.2(FANCA):c.987_990delTCAC (p.His330A...
# 12       NM_000135.2(FANCA):c.4015delC (p.Leu1339Serfs)
# 13             NM_000135.2(FANCA):c.295C>T (p.Gln99Ter)
# 14            NM_000135.2(FANCA):c.811C>T (p.Gln271Ter)
# 15           NM_000135.2(FANCA):c.2762A>T (p.Lys921Ile)
# 16                    NM_000135.2(FANCA):c.1007_3066del
# 17    NM_000135.2(FANCA):c.3720_3724delAAACA (p.Glu1...
# 18                               FANCA, IVS7DS, G-A, +5
# 19    NC_000016.9:g.(89829945_89831038)_(89836251_89...
# 20        NM_000135.2(FANCA):c.1606delT (p.Ser536Glnfs)
# 21             NM_000135.2(FANCA):c.154C>T (p.Arg52Ter)
# 22       NM_000135.2(FANCA):c.3558dupG (p.Arg1187Glufs)
# 23    NM_000135.2(FANCA):c.894_1006del113 (p.Trp298C...
# 24                       NM_000135.2(FANCA):c.3066+1G>T
# 25                               FANCB, 1-BP DEL, 1650T
# 26                               FANCB, 1-BP INS, 1838T
# 27                                     FANCB, LEU717TER
# 28                                   FANCB, 3314-BP DEL
# 29                               FANCB, IVS7DS, G-A, +5
# ...                                                 ...
# 5591         NM_007294.3(BRCA1):c.2800C>T (p.Gln934Ter)
# 5592      NM_007294.3(BRCA1):c.1923dupT (p.Asp642Terfs)
# 5593  NM_007294.3(BRCA1):c.1601_1602delAG (p.Gln534A...
# 5594  NM_007294.3(BRCA1):c.2125_2126insA (p.Phe709Ty...
# 5595        NM_007294.3(BRCA1):c.5444G>A (p.Trp1815Ter)
# 5596      NM_007294.3(BRCA1):c.1812delA (p.Ala605Hisfs)
# 5597  NM_007294.3(BRCA1):c.2110_2111delAA (p.Asn704C...
# 5598     NM_007294.3(BRCA1):c.3214delC (p.Leu1072Terfs)
# 5599                      NM_007294.3(BRCA1):c.212+1G>T
# 5600  NM_007294.3(BRCA1):c.2226_2227delTA (p.Asn742L...
# 5601      NM_007294.3(BRCA1):c.1961delA (p.Lys654Serfs)
# 5602  NM_007294.3(BRCA1):c.2912_2913delAT (p.His971A...
# 5603                     NM_007294.3(BRCA1):c.4675+1G>A
# 5604  NM_007294.3(BRCA1):c.5062_5064delGTT (p.Val168...
# 5605        NM_007294.3(BRCA1):c.4222C>T (p.Gln1408Ter)
# 5606          NM_007294.3(BRCA1):c.505C>T (p.Gln169Ter)
# 5607  NM_007294.3(BRCA1):c.3869_3870delAA (p.Lys1290...
# 5608         NM_007294.3(BRCA1):c.1960A>T (p.Lys654Ter)
# 5609  NM_007294.3(BRCA1):c.1953_1956delGAAA (p.Lys65...
# 5610     NM_007294.3(BRCA1):c.5335delC (p.Gln1779Asnfs)
# 5611  NM_007294.3(BRCA1):c.3770_3771delAG (p.Glu1257...
# 5612  NM_007294.3(BRCA1):c.3700_3704delGTAAA (p.Val1...
# 5613     NM_007294.3(BRCA1):c.3764dupA (p.Asn1255Lysfs)
# 5614        NM_007294.3(BRCA1):c.4656C>G (p.Tyr1552Ter)
# 5615                     NM_007294.3(BRCA1):c.5277+1G>A
# 5616        NM_007294.3(BRCA1):c.3910G>T (p.Glu1304Ter)
# 5617     NM_007294.3(BRCA1):c.5259delA (p.Glu1754Asnfs)
# 5618        NM_007294.3(BRCA1):c.5095C>T (p.Arg1699Trp)
# 5619  NM_007294.3(BRCA1):c.594_597delTGTG (p.Ser198A...
# 5620          NM_006341.3(MAD2L2):c.254T>A (p.Val85Glu)
#
#               variant_curie     relation_label relation_curie  \
# 0     ClinVarVariant:402243  likely pathogenic   GENO:0000841
# 1       ClinVarVariant:3440         pathogenic   GENO:0000840
# 2       ClinVarVariant:3441         pathogenic   GENO:0000840
# 3     ClinVarVariant:134256         pathogenic   GENO:0000840
# 4      ClinVarVariant:41003         pathogenic   GENO:0000840
# 5       ClinVarVariant:3447         pathogenic   GENO:0000840
# 6     ClinVarVariant:188383  likely pathogenic   GENO:0000841
# 7     ClinVarVariant:370466         pathogenic   GENO:0000840
# 8       ClinVarVariant:3443         pathogenic   GENO:0000840
# 9     ClinVarVariant:192384         pathogenic   GENO:0000840
# 10      ClinVarVariant:3439         pathogenic   GENO:0000840
# 11    ClinVarVariant:208580         pathogenic   GENO:0000840
# 12    ClinVarVariant:208638  likely pathogenic   GENO:0000841
# 13    ClinVarVariant:370361         pathogenic   GENO:0000840
# 14    ClinVarVariant:371093  likely pathogenic   GENO:0000841
# 15    ClinVarVariant:203995  likely pathogenic   GENO:0000841
# 16      ClinVarVariant:3445         pathogenic   GENO:0000840
# 17      ClinVarVariant:3448         pathogenic   GENO:0000840
# 18    ClinVarVariant:192385         pathogenic   GENO:0000840
# 19    ClinVarVariant:402242  likely pathogenic   GENO:0000841
# 20      ClinVarVariant:3446         pathogenic   GENO:0000840
# 21    ClinVarVariant:371668         pathogenic   GENO:0000840
# 22      ClinVarVariant:3444         pathogenic   GENO:0000840
# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def execute_query(query):
    endpoint = SPARQLWrapper('https://query.wikidata.org/sparql')
    endpoint.setQuery(query)
    endpoint.setReturnFormat(JSON)
    return endpoint.query().convert()

def var_query(entrez):
    """
    query wikidata by entrez id for variant that is 'positive diagnostic predictor of a disease'
    """    
    query = """
    SELECT distinct ?gene ?geneLabel ?variant ?variantLabel ?disease ?diseaseLabel
     WHERE {
      # ?gene wdt:P351 '%s'. 
      OPTIONAL {?variant wdt:P3433 ?gene.}        # variant of gene
      OPTIONAL {?variant wdt:P3433 ?gene;
                         wdt:P3356 ?disease.}    # variant is a positive diagnostic predictor of disease
       SERVICE wikibase:label {
            bd:serviceParam wikibase:language "en" .
      }
    }
    """ % (entrez)
    r = execute_query(query)
    return r['results']['bindings']

def keycheck(ckey, cdict):
    if ckey in cdict.keys():
        return cdict[ckey]['value']
    else:
        return None

# %%
"""
Look for variants of FA genes in wikidata that are 'positive diagnostic predictors' for a disease
"""
wd_columns = ['gene', 'geneLabel', 'variant', 'variantLabel', 'disease', "diseaseLabel"]
wd_result_frame = pd.DataFrame(columns=wd_columns)
  
for index, row in fa_genes.iterrows():
    entrez_id = row[0].split(":")[-1]
    wd_hits = var_query(entrez_id)
    for hit in wd_hits:
        result = dict()
        result['gene'] = keycheck('gene', hit)
        result['geneLabel'] = keycheck('geneLabel', hit)
        result['variant'] = keycheck('variant', hit)
        result['variantLabel'] = keycheck('variantLabel', hit)
        result['disease'] = keycheck('disease', hit)
        result['diseaseLabel'] = keycheck('diseaseLabel', hit)
        wd_result_frame = wd_result_frame.append(result, ignore_index=True)
        
wd_result_frame.to_csv('FA_pathogenic_variant_Wikidata.csv', sep=',')  
wd_result_frame

# Returns dataframe linking FA genes to Civic variant data
# Out:
#                                         gene geneLabel  \
# 0   http://www.wikidata.org/entity/Q17927056     FANCA
# 1   http://www.wikidata.org/entity/Q17927471     FANCB
# 2   http://www.wikidata.org/entity/Q18250517     FANCC
# 3   http://www.wikidata.org/entity/Q17927077     FANCE
# 4   http://www.wikidata.org/entity/Q17927502     FANCF
# 5   http://www.wikidata.org/entity/Q17927524     FANCG
# 6   http://www.wikidata.org/entity/Q18041564     FANCL
# 7   http://www.wikidata.org/entity/Q18044458     FANCM
# 8   http://www.wikidata.org/entity/Q17927069    FANCD2
# 9   http://www.wikidata.org/entity/Q18041663     FANCI
# 10  http://www.wikidata.org/entity/Q18039587     UBE2T
# 11  http://www.wikidata.org/entity/Q17853272     BRCA2
# 12  http://www.wikidata.org/entity/Q17853272     BRCA2
# 13  http://www.wikidata.org/entity/Q17853272     BRCA2
# 14  http://www.wikidata.org/entity/Q17853272     BRCA2
# 15  http://www.wikidata.org/entity/Q17853272     BRCA2
# 16  http://www.wikidata.org/entity/Q17853272     BRCA2
# 17  http://www.wikidata.org/entity/Q17853272     BRCA2
# 18  http://www.wikidata.org/entity/Q17853272     BRCA2
# 19  http://www.wikidata.org/entity/Q17853272     BRCA2
# 20  http://www.wikidata.org/entity/Q17853272     BRCA2
# 21  http://www.wikidata.org/entity/Q17853272     BRCA2
# 22  http://www.wikidata.org/entity/Q18047355     BRIP1
# 23  http://www.wikidata.org/entity/Q18046302     PALB2
# 24  http://www.wikidata.org/entity/Q18046302     PALB2
# 25  http://www.wikidata.org/entity/Q18031015    RAD51C
# 26  http://www.wikidata.org/entity/Q18047618      SLX4
# 27  http://www.wikidata.org/entity/Q17917469     ERCC4
# 28  http://www.wikidata.org/entity/Q14907732     RAD51
# 29    http://www.wikidata.org/entity/Q227339     BRCA1
# 30    http://www.wikidata.org/entity/Q227339     BRCA1
# 31    http://www.wikidata.org/entity/Q227339     BRCA1
# 32    http://www.wikidata.org/entity/Q227339     BRCA1
# 33    http://www.wikidata.org/entity/Q227339     BRCA1
# 34    http://www.wikidata.org/entity/Q227339     BRCA1
# 35    http://www.wikidata.org/entity/Q227339     BRCA1
# 36    http://www.wikidata.org/entity/Q227339     BRCA1
# 37    http://www.wikidata.org/entity/Q227339     BRCA1
# 38    http://www.wikidata.org/entity/Q227339     BRCA1
# 39    http://www.wikidata.org/entity/Q227339     BRCA1
# 40    http://www.wikidata.org/entity/Q227339     BRCA1
# 41    http://www.wikidata.org/entity/Q227339     BRCA1
# 42    http://www.wikidata.org/entity/Q227339     BRCA1
# 43    http://www.wikidata.org/entity/Q227339     BRCA1
# 44    http://www.wikidata.org/entity/Q227339     BRCA1
# 45    http://www.wikidata.org/entity/Q227339     BRCA1
# 46    http://www.wikidata.org/entity/Q227339     BRCA1
# 47    http://www.wikidata.org/entity/Q227339     BRCA1
# 48  http://www.wikidata.org/entity/Q18035401    MAD2L2
# 49  http://www.wikidata.org/entity/Q18032394     XRCC2
# 50  http://www.wikidata.org/entity/Q18041606     RFWD3
# 51  http://www.wikidata.org/entity/Q18046665   FAAP100
# 52  http://www.wikidata.org/entity/Q18048517    FAAP24
# 53  http://www.wikidata.org/entity/Q18053146    FAAP20
# 54  http://www.wikidata.org/entity/Q18056210     CENPS
# 55  http://www.wikidata.org/entity/Q18053211     CENPX
#
#                                      variant                  variantLabel  \
# 0                                       None                          None
# 1                                       None                          None
# 2   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 3                                       None                          None
# 4                                       None                          None
# 5                                       None                          None
# 6                                       None                          None
# 7                                       None                          None
# 8                                       None                          None
# 9                                       None                          None
# 10                                      None                          None
# 11  http://www.wikidata.org/entity/Q29938738                     BRCA2 M1I
# 12  http://www.wikidata.org/entity/Q29938739                   BRCA2 V159M
# 13  http://www.wikidata.org/entity/Q29938740                   BRCA2 V211L
# 14  http://www.wikidata.org/entity/Q28371625     BRCA2 TRUNCATING MUTATION
# 15  http://www.wikidata.org/entity/Q28444961                BRCA2 MUTATION
# 16  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 17  http://www.wikidata.org/entity/Q29938737                     BRCA2 M1R
# 18  http://www.wikidata.org/entity/Q29938742                  BRCA2 R2336P
# 19  http://www.wikidata.org/entity/Q29938743                  BRCA2 R2336H
# 20  http://www.wikidata.org/entity/Q29938741                   BRCA2 V211I
# 21  http://www.wikidata.org/entity/Q28371604                  BRCA2 D3095E
# 22                                      None                          None
# 23  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 24  http://www.wikidata.org/entity/Q28439607               PALB2 L531FS*30
# 25                                      None                          None
# 26                                      None                          None
# 27                                      None                          None
# 28                                      None                          None
# 29  http://www.wikidata.org/entity/Q29938727                    BRCA1 R71G
# 30  http://www.wikidata.org/entity/Q29938724                     BRCA1 M1I
# 31  http://www.wikidata.org/entity/Q28445090         BRCA1 UNDEREXPRESSION
# 32  http://www.wikidata.org/entity/Q29938730                  BRCA1 R1495M
# 33  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 34  http://www.wikidata.org/entity/Q28444960                BRCA1 MUTATION
# 35  http://www.wikidata.org/entity/Q28532483     BRCA1 TRUNCATING MUTATION
# 36  http://www.wikidata.org/entity/Q29938734                  BRCA1 D1692N
# 37  http://www.wikidata.org/entity/Q29938732                  BRCA1 E1559K
# 38  http://www.wikidata.org/entity/Q28445085              BRCA1 EXPRESSION
# 39  http://www.wikidata.org/entity/Q29938723                     BRCA1 M1V
# 40  http://www.wikidata.org/entity/Q29938726                    BRCA1 C64Y
# 41  http://www.wikidata.org/entity/Q29938725                    BRCA1 C61G
# 42  http://www.wikidata.org/entity/Q29938728                    BRCA1 R71K
# 43  http://www.wikidata.org/entity/Q29938735                  BRCA1 R1443*
# 44  http://www.wikidata.org/entity/Q29938736                  BRCA1 Q1467*
# 45  http://www.wikidata.org/entity/Q32965138                  BRCA1 W1815X
# 46  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 47  http://www.wikidata.org/entity/Q28381200                  BRCA1 P968FS
# 48                                      None                          None
# 49                                      None                          None
# 50                                      None                          None
# 51                                      None                          None
# 52                                      None                          None
# 53                                      None                          None
# 54                                      None                          None
# 55                                      None                          None
#
#                                    disease    diseaseLabel
# 0                                     None            None
# 1                                     None            None
# 2                                     None            None
# 3                                     None            None
# 4                                     None            None
# 5                                     None            None
# 6                                     None            None
# 7                                     None            None
# 8                                     None            None
# 9                                     None            None
# 10                                    None            None
# 11                                    None            None
# 12                                    None            None
# 13                                    None            None
# 14                                    None            None
# 15                                    None            None
# 16                                    None            None
# 17                                    None            None
# 18                                    None            None
# 19                                    None            None
# 20                                    None            None
# 21  http://www.wikidata.org/entity/Q128581   breast cancer
# 22                                    None            None
# 23                                    None            None
# 24  http://www.wikidata.org/entity/Q128581   breast cancer
# 25                                    None            None
# 26                                    None            None
# 27                                    None            None
# 28                                    None            None
# 29                                    None            None
# 30                                    None            None
# 31                                    None            None
# 32                                    None            None
# 33                                    None            None
# 34                                    None            None
# 35                                    None            None
# 36                                    None            None
# 37                                    None            None
# 38                                    None            None
# 39                                    None            None
# 40                                    None            None
# 41                                    None            None
# 42                                    None            None
# 43                                    None            None
# 44                                    None            None
# 45                                    None            None
# 46  http://www.wikidata.org/entity/Q128581   breast cancer
# 47  http://www.wikidata.org/entity/Q172341  ovarian cancer
# 48                                    None            None
# 49                                    None            None
# 50                                    None            None
# 51                                    None            None
# 52                                    None            None
# 53                                    None            None
# 54                                    None            None
# 55                                    None            None
