# %% [markdown]
# # Interacting with the Blackboard

# %%
import urllib, requests, json

bb_url = 'http://localhost:9000/blackboard/api'
query = {"type": "query", "name": "A simple blackboard example","term": "asthma"}
json.dumps(query)
req = requests.post(bb_url, json=query)
req.status_code
# Out:
# 200

# %% [markdown]
# Having posted the query, we then retrieve the resultant knowledge graph is JSON form.

# %%
kg = requests.get(bb_url)
kg.json()
# Out:
# [{u'edgeCount': 0,
#   u'edges': [],
#   u'id': 1,
#   u'name': u'A simple blackboard example',
#   u'nodeCount': 1,
#   u'nodes': [{u'degree': 0,
#     u'id': 2,
#     u'inDegree': 0,
#     u'name': u'A simple blackboard example',
#     u'outDegree': 0,
#     u'term': u'asthma',
#     u'type': u'query'}],
#   u'type': u'kgraph'}]

# %% [markdown]
# We then update the KG using the Pharos KS (not this needs to be a `PUT` request)

# %%
bb_id = kg.json()[0]['id']
req = requests.put(bb_url+'/'+str(bb_id)+"/ks.pharos")
req.status_code
# Out:
# 200

# %% [markdown]
# Now we retrieve the current state of the KG

# %%
req = requests.get(bb_url)
req.json()
# Out:
# [{u'edgeCount': 54,
#   u'edges': [{u'directed': False, u'id': 0, u'source': 2, u'target': 3},
#    {u'directed': False, u'id': 1, u'source': 2, u'target': 4},
#    {u'directed': False, u'id': 2, u'source': 2, u'target': 5},
#    {u'directed': False, u'id': 3, u'source': 2, u'target': 6},
#    {u'directed': False, u'id': 4, u'source': 2, u'target': 7},
#    {u'directed': False, u'id': 5, u'source': 2, u'target': 8},
#    {u'directed': False, u'id': 6, u'source': 2, u'target': 9},
#    {u'directed': False, u'id': 7, u'source': 2, u'target': 10},
#    {u'directed': False, u'id': 8, u'source': 2, u'target': 11},
#    {u'directed': False, u'id': 9, u'source': 2, u'target': 12},
#    {u'directed': False, u'id': 10, u'source': 2, u'target': 13},
#    {u'directed': False, u'id': 11, u'source': 2, u'target': 14},
#    {u'directed': False, u'id': 12, u'source': 2, u'target': 15},
#    {u'directed': False, u'id': 13, u'source': 2, u'target': 16},
#    {u'directed': False, u'id': 14, u'source': 2, u'target': 17},
#    {u'directed': False, u'id': 15, u'source': 2, u'target': 18},
#    {u'directed': False, u'id': 16, u'source': 2, u'target': 19},
#    {u'directed': False, u'id': 17, u'source': 2, u'target': 20},
#    {u'directed': False, u'id': 18, u'source': 2, u'target': 21},
#    {u'directed': False, u'id': 19, u'source': 2, u'target': 22},
#    {u'directed': False, u'id': 20, u'source': 2, u'target': 23},
#    {u'directed': False, u'id': 21, u'source': 2, u'target': 24},
#    {u'directed': False, u'id': 22, u'source': 2, u'target': 25},
#    {u'directed': False, u'id': 23, u'source': 2, u'target': 26},
#    {u'directed': False, u'id': 24, u'source': 2, u'target': 27},
#    {u'directed': False, u'id': 25, u'source': 2, u'target': 28},
#    {u'directed': False, u'id': 26, u'source': 2, u'target': 29}],
#   u'id': 1,
#   u'name': u'A simple blackboard example',
#   u'nodeCount': 28,
#   u'nodes': [{u'degree': 27,
#     u'id': 2,
#     u'inDegree': 0,
#     u'name': u'A simple blackboard example',
#     u'outDegree': 27,
#     u'term': u'asthma',
#     u'type': u'query'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 3,
#     u'inDegree': 1,
#     u'name': u'Prostaglandin D2 receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'Q13258',
#      u'PD2R_HUMAN',
#      u'PTGDR',
#      u'G3V5L3',
#      u'Q13250',
#      u'Q13251',
#      u'Q1ZZ52',
#      u'PGD receptor',
#      u'DP',
#      u'AS1',
#      u'DP1',
#      u'ASRT1',
#      u'PTGDR1'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(18313)'},
#    {u'degree': 1,
#     u'id': 4,
#     u'inDegree': 1,
#     u'name': u'fluticasone furoate',
#     u'outDegree': 0,
#     u'synonyms': [u'fluticasone furoate', u'CHEMBL1676'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(225323)'},
#    {u'degree': 1,
#     u'id': 5,
#     u'inDegree': 1,
#     u'name': u'ASTHMA, DIMINISHED RESPONSE TO ANTILEUKOTRIENE TREATMENT IN',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1833270'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(8540)'},
#    {u'degree': 1,
#     u'id': 6,
#     u'inDegree': 1,
#     u'name': u'reslizumab',
#     u'outDegree': 0,
#     u'synonyms': [u'reslizumab', u'CHEMBL2107884'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(199139)'},
#    {u'degree': 1,
#     u'id': 7,
#     u'inDegree': 1,
#     u'name': u'Diagnostic Test for Asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(9687)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 8,
#     u'inDegree': 1,
#     u'name': u'Cysteinyl leukotriene receptor 1',
#     u'outDegree': 0,
#     u'synonyms': [u'Q9Y271',
#      u'CLTR1_HUMAN',
#      u'CYSLTR1',
#      u'B2R954',
#      u'D3DTE4',
#      u'Q5JS94',
#      u'Q8IV19',
#      u'CysLTR1',
#      u'CYSLT1',
#      u'CYSLTR',
#      u'CYSLT1R',
#      u'HMTMF81'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(16922)'},
#    {u'degree': 1,
#     u'id': 9,
#     u'inDegree': 1,
#     u'name': u'Adjunct Therapy to Achieve Long-term Asthma Control',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(9777)'},
#    {u'degree': 1,
#     u'id': 10,
#     u'inDegree': 1,
#     u'name': u'omalizumab',
#     u'outDegree': 0,
#     u'synonyms': [u'omalizumab', u'CHEMBL1201589'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(102374)'},
#    {u'degree': 1,
#     u'id': 11,
#     u'inDegree': 1,
#     u'name': u'ASTHMA-RELATED TRAITS, SUSCEPTIBILITY TO, 1',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1846534'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(10285)'},
#    {u'degree': 1,
#     u'id': 12,
#     u'inDegree': 1,
#     u'name': u'betahistine',
#     u'outDegree': 0,
#     u'synonyms': [u'betahistine', u'CHEMBL24441'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(14631)'},
#    {u'degree': 1,
#     u'id': 13,
#     u'inDegree': 1,
#     u'name': u'ASTHMA, ASPIRIN-INDUCED, SUSCEPTIBILITY TO',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1876174'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(577)'},
#    {u'degree': 1,
#     u'id': 14,
#     u'inDegree': 1,
#     u'name': u'isoetarine',
#     u'outDegree': 0,
#     u'synonyms': [u'isoetarine', u'CHEMBL1201153'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(214992)'},
#    {u'degree': 1,
#     u'id': 15,
#     u'inDegree': 1,
#     u'name': u'Eosinophilic asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(3622)'},
#    {u'degree': 1,
#     u'id': 16,
#     u'inDegree': 1,
#     u'name': u'cinalukast',
#     u'outDegree': 0,
#     u'synonyms': [u'cinalukast', u'CHEMBL283754'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(219909)'},
#    {u'degree': 1,
#     u'id': 17,
#     u'inDegree': 1,
#     u'name': u'Anxiety due to Cardiac Asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(7061)'},
#    {u'degree': 1,
#     u'id': 18,
#     u'inDegree': 1,
#     u'name': u'nicardipine',
#     u'outDegree': 0,
#     u'synonyms': [u'nicardipine', u'CHEMBL1484'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(17445)'},
#    {u'degree': 1,
#     u'id': 19,
#     u'inDegree': 1,
#     u'name': u'Asthma, Nasal Polyps, And Aspirin Intolerance',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1859648'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(576)'},
#    {u'degree': 1,
#     u'id': 20,
#     u'inDegree': 1,
#     u'name': u'chlorphenamine',
#     u'outDegree': 0,
#     u'synonyms': [u'chlorphenamine', u'CHEMBL505', u'Chlorpheniramine'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105070)'},
#    {u'degree': 1,
#     u'id': 21,
#     u'inDegree': 1,
#     u'name': u'Non-allergic asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(8541)'},
#    {u'degree': 1,
#     u'id': 22,
#     u'inDegree': 1,
#     u'name': u'cetirizine',
#     u'outDegree': 0,
#     u'synonyms': [u'cetirizine', u'CHEMBL1000'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105071)'},
#    {u'degree': 1,
#     u'id': 23,
#     u'inDegree': 1,
#     u'name': u'Allergic asthma',
#     u'outDegree': 0,
#     u'synonyms': [u'DOID:9415'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(5333)'},
#    {u'degree': 1,
#     u'id': 24,
#     u'inDegree': 1,
#     u'name': u'tripelennamine',
#     u'outDegree': 0,
#     u'synonyms': [u'tripelennamine',
#      u'CHEMBL1241',
#      u"N-Benzyl-N',N'-dimethyl-N-pyridin-2-yl-ethane-1,2-diamine"],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105078)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 25,
#     u'inDegree': 1,
#     u'name': u'Beta-2 adrenergic receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'P07550',
#      u'ADRB2_HUMAN',
#      u'ADRB2',
#      u'B0LPE4',
#      u'B2R7X2',
#      u'O14823',
#      u'O14824',
#      u'O14825',
#      u'O14826',
#      u'Q4JG18',
#      u'Q53GA6',
#      u'Q6GMT4',
#      u'Q6P4D8',
#      u'Q8NEQ9',
#      u'Q96EC3',
#      u'Q9UCZ0',
#      u'Q9UCZ1',
#      u'Q9UCZ2',
#      u'Q9UCZ3',
#      u'Q9UH95',
#      u'Q9UHA1',
#      u'Q9UMZ5',
#      u'BAR',
#      u'B2AR',
#      u'ADRBR',
#      u'ADRB2R',
#      u'BETA2AR'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(16331)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 26,
#     u'inDegree': 1,
#     u'name': u'Thromboxane A2 receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'P21731',
#      u'TA2R_HUMAN',
#      u'TBXA2R',
#      u'O75228',
#      u'Q6DK52',
#      u'Q9UCY1',
#      u'Q9UCY2',
#      u'TXA2-R',
#      u'BDPLT13'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(15592)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 27,
#     u'inDegree': 1,
#     u'name': u'Ig epsilon chain C region',
#     u'outDegree': 0,
#     u'synonyms': [u'P01854', u'IGHE_HUMAN', u'IGHE', u'IgE'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(8436)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 28,
#     u'inDegree': 1,
#     u'name': u'Interleukin-5',
#     u'outDegree': 0,
#     u'synonyms': [u'P05113',
#      u'IL5_HUMAN',
#      u'IL5',
#      u'Q13840',
#      u'IL-5',
#      u'EDF',
#      u'TRF'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(14792)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 29,
#     u'inDegree': 1,
#     u'name': u'Interleukin-12 subunit beta',
#     u'outDegree': 0,
#     u'synonyms': [u'P29460',
#      u'IL12B_HUMAN',
#      u'IL12B',
#      u'IL-12B',
#      u'CLMF',
#      u'NKSF',
#      u'CLMF2',
#      u'IMD28',
#      u'IMD29',
#      u'NKSF2'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(17084)'}],
#   u'type': u'kgraph'}]

# %% [markdown]
# As noted in the [documentation](https://spotlite.nih.gov/ncats/blackboard) we can rerun the Pharos KS to add more nodes and edges. The first call, above, added nodes that were related to the query node (and the associated edges). When we call it again, it will add nodes that are related to the nodes added in the previous run (i.e., 2nd neighbors of the query node)

# %%
bb_id = kg.json()[0]['id']
req = requests.put(bb_url+'/'+str(bb_id)+"/ks.pharos")
req = requests.get(bb_url)
req.json()
# Out:
# [{u'edgeCount': 60,
#   u'edges': [{u'directed': False, u'id': 0, u'source': 2, u'target': 3},
#    {u'directed': False, u'id': 1, u'source': 2, u'target': 4},
#    {u'directed': False, u'id': 2, u'source': 2, u'target': 5},
#    {u'directed': False, u'id': 3, u'source': 2, u'target': 6},
#    {u'directed': False, u'id': 4, u'source': 2, u'target': 7},
#    {u'directed': False, u'id': 5, u'source': 2, u'target': 8},
#    {u'directed': False, u'id': 6, u'source': 2, u'target': 9},
#    {u'directed': False, u'id': 7, u'source': 2, u'target': 10},
#    {u'directed': False, u'id': 8, u'source': 2, u'target': 11},
#    {u'directed': False, u'id': 9, u'source': 2, u'target': 12},
#    {u'directed': False, u'id': 10, u'source': 2, u'target': 13},
#    {u'directed': False, u'id': 11, u'source': 2, u'target': 14},
#    {u'directed': False, u'id': 12, u'source': 2, u'target': 15},
#    {u'directed': False, u'id': 13, u'source': 2, u'target': 16},
#    {u'directed': False, u'id': 14, u'source': 2, u'target': 17},
#    {u'directed': False, u'id': 15, u'source': 2, u'target': 18},
#    {u'directed': False, u'id': 16, u'source': 2, u'target': 19},
#    {u'directed': False, u'id': 17, u'source': 2, u'target': 20},
#    {u'directed': False, u'id': 18, u'source': 2, u'target': 21},
#    {u'directed': False, u'id': 19, u'source': 2, u'target': 22},
#    {u'directed': False, u'id': 20, u'source': 2, u'target': 23},
#    {u'directed': False, u'id': 21, u'source': 2, u'target': 24},
#    {u'directed': False, u'id': 22, u'source': 2, u'target': 25},
#    {u'directed': False, u'id': 23, u'source': 2, u'target': 26},
#    {u'directed': False, u'id': 24, u'source': 2, u'target': 27},
#    {u'directed': False, u'id': 25, u'source': 2, u'target': 28},
#    {u'directed': False, u'id': 26, u'source': 2, u'target': 29},
#    {u'directed': False, u'id': 27, u'source': 2, u'target': 30},
#    {u'directed': False, u'id': 28, u'source': 2, u'target': 31},
#    {u'directed': False, u'id': 29, u'source': 2, u'target': 32}],
#   u'id': 1,
#   u'name': u'A simple blackboard example',
#   u'nodeCount': 31,
#   u'nodes': [{u'degree': 30,
#     u'id': 2,
#     u'inDegree': 0,
#     u'name': u'A simple blackboard example',
#     u'outDegree': 30,
#     u'term': u'asthma',
#     u'type': u'query'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 3,
#     u'inDegree': 1,
#     u'name': u'Prostaglandin D2 receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'Q13258',
#      u'PD2R_HUMAN',
#      u'PTGDR',
#      u'G3V5L3',
#      u'Q13250',
#      u'Q13251',
#      u'Q1ZZ52',
#      u'PGD receptor',
#      u'DP',
#      u'AS1',
#      u'DP1',
#      u'ASRT1',
#      u'PTGDR1'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(18313)'},
#    {u'degree': 1,
#     u'id': 4,
#     u'inDegree': 1,
#     u'name': u'fluticasone furoate',
#     u'outDegree': 0,
#     u'synonyms': [u'fluticasone furoate', u'CHEMBL1676'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(225323)'},
#    {u'degree': 1,
#     u'id': 5,
#     u'inDegree': 1,
#     u'name': u'ASTHMA, DIMINISHED RESPONSE TO ANTILEUKOTRIENE TREATMENT IN',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1833270'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(8540)'},
#    {u'degree': 1,
#     u'id': 6,
#     u'inDegree': 1,
#     u'name': u'reslizumab',
#     u'outDegree': 0,
#     u'synonyms': [u'reslizumab', u'CHEMBL2107884'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(199139)'},
#    {u'degree': 1,
#     u'id': 7,
#     u'inDegree': 1,
#     u'name': u'Diagnostic Test for Asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(9687)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 8,
#     u'inDegree': 1,
#     u'name': u'Cysteinyl leukotriene receptor 1',
#     u'outDegree': 0,
#     u'synonyms': [u'Q9Y271',
#      u'CLTR1_HUMAN',
#      u'CYSLTR1',
#      u'B2R954',
#      u'D3DTE4',
#      u'Q5JS94',
#      u'Q8IV19',
#      u'CysLTR1',
#      u'CYSLT1',
#      u'CYSLTR',
#      u'CYSLT1R',
#      u'HMTMF81'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(16922)'},
#    {u'degree': 1,
#     u'id': 9,
#     u'inDegree': 1,
#     u'name': u'Adjunct Therapy to Achieve Long-term Asthma Control',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(9777)'},
#    {u'degree': 1,
#     u'id': 10,
#     u'inDegree': 1,
#     u'name': u'omalizumab',
#     u'outDegree': 0,
#     u'synonyms': [u'omalizumab', u'CHEMBL1201589'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(102374)'},
#    {u'degree': 1,
#     u'id': 11,
#     u'inDegree': 1,
#     u'name': u'ASTHMA-RELATED TRAITS, SUSCEPTIBILITY TO, 1',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1846534'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(10285)'},
#    {u'degree': 1,
#     u'id': 12,
#     u'inDegree': 1,
#     u'name': u'betahistine',
#     u'outDegree': 0,
#     u'synonyms': [u'betahistine', u'CHEMBL24441'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(14631)'},
#    {u'degree': 1,
#     u'id': 13,
#     u'inDegree': 1,
#     u'name': u'ASTHMA, ASPIRIN-INDUCED, SUSCEPTIBILITY TO',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1876174'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(577)'},
#    {u'degree': 1,
#     u'id': 14,
#     u'inDegree': 1,
#     u'name': u'isoetarine',
#     u'outDegree': 0,
#     u'synonyms': [u'isoetarine', u'CHEMBL1201153'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(214992)'},
#    {u'degree': 1,
#     u'id': 15,
#     u'inDegree': 1,
#     u'name': u'Eosinophilic asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(3622)'},
#    {u'degree': 1,
#     u'id': 16,
#     u'inDegree': 1,
#     u'name': u'cinalukast',
#     u'outDegree': 0,
#     u'synonyms': [u'cinalukast', u'CHEMBL283754'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(219909)'},
#    {u'degree': 1,
#     u'id': 17,
#     u'inDegree': 1,
#     u'name': u'Anxiety due to Cardiac Asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(7061)'},
#    {u'degree': 1,
#     u'id': 18,
#     u'inDegree': 1,
#     u'name': u'nicardipine',
#     u'outDegree': 0,
#     u'synonyms': [u'nicardipine', u'CHEMBL1484'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(17445)'},
#    {u'degree': 1,
#     u'id': 19,
#     u'inDegree': 1,
#     u'name': u'Asthma, Nasal Polyps, And Aspirin Intolerance',
#     u'outDegree': 0,
#     u'synonyms': [u'umls:C1859648'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(576)'},
#    {u'degree': 1,
#     u'id': 20,
#     u'inDegree': 1,
#     u'name': u'chlorphenamine',
#     u'outDegree': 0,
#     u'synonyms': [u'chlorphenamine', u'CHEMBL505', u'Chlorpheniramine'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105070)'},
#    {u'degree': 1,
#     u'id': 21,
#     u'inDegree': 1,
#     u'name': u'Non-allergic asthma',
#     u'outDegree': 0,
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(8541)'},
#    {u'degree': 1,
#     u'id': 22,
#     u'inDegree': 1,
#     u'name': u'cetirizine',
#     u'outDegree': 0,
#     u'synonyms': [u'cetirizine', u'CHEMBL1000'],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105071)'},
#    {u'degree': 1,
#     u'id': 23,
#     u'inDegree': 1,
#     u'name': u'Allergic asthma',
#     u'outDegree': 0,
#     u'synonyms': [u'DOID:9415'],
#     u'type': u'disease',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/diseases(5333)'},
#    {u'degree': 1,
#     u'id': 24,
#     u'inDegree': 1,
#     u'name': u'tripelennamine',
#     u'outDegree': 0,
#     u'synonyms': [u'tripelennamine',
#      u'CHEMBL1241',
#      u"N-Benzyl-N',N'-dimethyl-N-pyridin-2-yl-ethane-1,2-diamine"],
#     u'type': u'drug',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/ligands(105078)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 25,
#     u'inDegree': 1,
#     u'name': u'Beta-2 adrenergic receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'P07550',
#      u'ADRB2_HUMAN',
#      u'ADRB2',
#      u'B0LPE4',
#      u'B2R7X2',
#      u'O14823',
#      u'O14824',
#      u'O14825',
#      u'O14826',
#      u'Q4JG18',
#      u'Q53GA6',
#      u'Q6GMT4',
#      u'Q6P4D8',
#      u'Q8NEQ9',
#      u'Q96EC3',
#      u'Q9UCZ0',
#      u'Q9UCZ1',
#      u'Q9UCZ2',
#      u'Q9UCZ3',
#      u'Q9UH95',
#      u'Q9UHA1',
#      u'Q9UMZ5',
#      u'BAR',
#      u'B2AR',
#      u'ADRBR',
#      u'ADRB2R',
#      u'BETA2AR'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(16331)'},
#    {u'degree': 1,
#     u'family': u'GPCR',
#     u'id': 26,
#     u'inDegree': 1,
#     u'name': u'Thromboxane A2 receptor',
#     u'outDegree': 0,
#     u'synonyms': [u'P21731',
#      u'TA2R_HUMAN',
#      u'TBXA2R',
#      u'O75228',
#      u'Q6DK52',
#      u'Q9UCY1',
#      u'Q9UCY2',
#      u'TXA2-R',
#      u'BDPLT13'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(15592)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 27,
#     u'inDegree': 1,
#     u'name': u'Ig epsilon chain C region',
#     u'outDegree': 0,
#     u'synonyms': [u'P01854', u'IGHE_HUMAN', u'IGHE', u'IgE'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(8436)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 28,
#     u'inDegree': 1,
#     u'name': u'Interleukin-5',
#     u'outDegree': 0,
#     u'synonyms': [u'P05113',
#      u'IL5_HUMAN',
#      u'IL5',
#      u'Q13840',
#      u'IL-5',
#      u'EDF',
#      u'TRF'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(14792)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 29,
#     u'inDegree': 1,
#     u'name': u'Interleukin-12 subunit beta',
#     u'outDegree': 0,
#     u'synonyms': [u'P29460',
#      u'IL12B_HUMAN',
#      u'IL12B',
#      u'IL-12B',
#      u'CLMF',
#      u'NKSF',
#      u'CLMF2',
#      u'IMD28',
#      u'IMD29',
#      u'NKSF2'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(17084)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 30,
#     u'inDegree': 1,
#     u'name': u'Interleukin-17A',
#     u'outDegree': 0,
#     u'synonyms': [u'Q16552',
#      u'IL17_HUMAN',
#      u'IL17A',
#      u'Q5T2P0',
#      u'IL-17',
#      u'IL17',
#      u'CTLA8',
#      u'CTLA-8',
#      u'IL-17A'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(16659)'},
#    {u'degree': 1,
#     u'family': u'Non-IDG',
#     u'id': 31,
#     u'inDegree': 1,
#     u'name': u'Interleukin-12 subunit alpha',
#     u'outDegree': 0,
#     u'synonyms': [u'P29459',
#      u'IL12A_HUMAN',
#      u'IL12A',
#      u'Q96QZ1',
#      u'IL-12A',
#      u'P35',
#      u'CLMF',
#      u'NFSK',
#      u'NKSF1'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(17119)'},
#    {u'degree': 1,
#     u'family': u'Enzyme',
#     u'id': 32,
#     u'inDegree': 1,
#     u'name': u'Tryptase alpha/beta-1',
#     u'outDegree': 0,
#     u'synonyms': [u'Q15661',
#      u'TRYB1_HUMAN',
#      u'TPSAB1',
#      u'D2E6R9',
#      u'D2E6S1',
#      u'P15157',
#      u'Q15663',
#      u'Q6B052',
#      u'Q9H2Y4',
#      u'Q9H2Y5',
#      u'Q9UQI1',
#      u'Tryptase-1',
#      u'TPS1',
#      u'TPS2',
#      u'TPSB1'],
#     u'type': u'protein',
#     u'uri': u'https://pharos.ncats.io/idg/api/v1/targets(19826)'}],
#   u'type': u'kgraph'}]

# %% [markdown]
# Currently the knowledge graph is stored in a [Neo4J](https://neo4j.com/) instance. We can interact with this assuming you have a Neo4J client running and pointed to `blackboard.db` that was created by the blackboard API.

# %%
from py2neo import Graph

graph = Graph('http://localhost:7474/db/data', user='neo4j', password='beeb1e')
graph.run("match(n:`KG:1`) return n").dump()
# Out:
#  n
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  (d88c4be:`KG:1`:query {name:"A simple blackboard example",term:"asthma",type:"query"})
#  (d9ae64e:`KG:1`:protein {family:"GPCR",name:"Prostaglandin D2 receptor",synonyms:["Q13258","PD2R_HUMAN","PTGDR","G3V5L3","Q13250","Q13251","Q1ZZ52","PGD receptor","DP","AS1","DP1","ASRT1","PTGDR1"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(18313)"})
#  (cdc761d:`KG:1`:drug {name:"fluticasone furoate",synonyms:["fluticasone furoate","CHEMBL1676"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(225323)"})
#  (a04cfbc:`KG:1`:disease {name:"ASTHMA, DIMINISHED RESPONSE TO ANTILEUKOTRIENE TREATMENT IN",synonyms:["umls:C1833270"],type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(8540)"})
#  (aa15561:`KG:1`:drug {name:"reslizumab",synonyms:["reslizumab","CHEMBL2107884"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(199139)"})
#  (feec0ee:`KG:1`:disease {name:"Diagnostic Test for Asthma",type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(9687)"})
#  (d3363d3:`KG:1`:protein {family:"GPCR",name:"Cysteinyl leukotriene receptor 1",synonyms:["Q9Y271","CLTR1_HUMAN","CYSLTR1","B2R954","D3DTE4","Q5JS94","Q8IV19","CysLTR1","CYSLT1","CYSLTR","CYSLT1R","HMTMF81"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(16922)"})
#  (b045505:`KG:1`:disease {name:"Adjunct Therapy to Achieve Long-term Asthma Control",type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(9777)"})
#  (ca3c0a6:`KG:1`:drug {name:"omalizumab",synonyms:["omalizumab","CHEMBL1201589"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(102374)"})
#  (a8dd9d6:`KG:1`:disease {name:"ASTHMA-RELATED TRAITS, SUSCEPTIBILITY TO, 1",synonyms:["umls:C1846534"],type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(10285)"})
#  (eb6c975:`KG:1`:drug {name:"betahistine",synonyms:["betahistine","CHEMBL24441"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(14631)"})
#  (ef97b18:`KG:1`:disease {name:"ASTHMA, ASPIRIN-INDUCED, SUSCEPTIBILITY TO",synonyms:["umls:C1876174"],type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(577)"})
#  (e3f61e6:`KG:1`:drug {name:"isoetarine",synonyms:["isoetarine","CHEMBL1201153"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214992)"})
#  (b6e92d9:`KG:1`:disease {name:"Eosinophilic asthma",type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(3622)"})
#  (c61f0b2:`KG:1`:drug {name:"cinalukast",synonyms:["cinalukast","CHEMBL283754"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(219909)"})
#  (a6f921f:`KG:1`:disease {name:"Anxiety due to Cardiac Asthma",type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(7061)"})
#  (e8d5117:`KG:1`:drug {name:"nicardipine",synonyms:["nicardipine","CHEMBL1484"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(17445)"})
#  (fbb21ce:`KG:1`:disease {name:"Asthma, Nasal Polyps, And Aspirin Intolerance",synonyms:["umls:C1859648"],type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(576)"})
#  (acad8a0:`KG:1`:drug {name:"chlorphenamine",synonyms:["chlorphenamine","CHEMBL505","Chlorpheniramine"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(105070)"})
#  (eacd81c:`KG:1`:disease {name:"Non-allergic asthma",type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(8541)"})
#  (a8e667a:`KG:1`:drug {name:"cetirizine",synonyms:["cetirizine","CHEMBL1000"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(105071)"})
#  (e056e1b:`KG:1`:disease {name:"Allergic asthma",synonyms:["DOID:9415"],type:"disease",uri:"https://pharos.ncats.io/idg/api/v1/diseases(5333)"})
#  (ac13a9f:`KG:1`:drug {name:"tripelennamine",synonyms:["tripelennamine","CHEMBL1241","N-Benzyl-N',N'-dimethyl-N-pyridin-2-yl-ethane-1,2-diamine"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(105078)"})
#  (d88a035:`KG:1`:protein {family:"GPCR",name:"Beta-2 adrenergic receptor",synonyms:["P07550","ADRB2_HUMAN","ADRB2","B0LPE4","B2R7X2","O14823","O14824","O14825","O14826","Q4JG18","Q53GA6","Q6GMT4","Q6P4D8","Q8NEQ9","Q96EC3","Q9UCZ0","Q9UCZ1","Q9UCZ2","Q9UCZ3","Q9UH95","Q9UHA1","Q9UMZ5","BAR","B2AR","ADRBR","ADRB2R","BETA2AR"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(16331)"})
#  (ef3e9ff:`KG:1`:protein {family:"GPCR",name:"Thromboxane A2 receptor",synonyms:["P21731","TA2R_HUMAN","TBXA2R","O75228","Q6DK52","Q9UCY1","Q9UCY2","TXA2-R","BDPLT13"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(15592)"})
#  (e2d9d3c:`KG:1`:protein {family:"Non-IDG",name:"Ig epsilon chain C region",synonyms:["P01854","IGHE_HUMAN","IGHE","IgE"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(8436)"})
#  (b027d6b:`KG:1`:protein {family:"Non-IDG",name:"Interleukin-5",synonyms:["P05113","IL5_HUMAN","IL5","Q13840","IL-5","EDF","TRF"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(14792)"})
#  (a3c2a51:`KG:1`:protein {family:"Non-IDG",name:"Interleukin-12 subunit beta",synonyms:["P29460","IL12B_HUMAN","IL12B","IL-12B","CLMF","NKSF","CLMF2","IMD28","IMD29","NKSF2"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(17084)"})
#  (db47cce:`KG:1`:protein {family:"Non-IDG",name:"Interleukin-17A",synonyms:["Q16552","IL17_HUMAN","IL17A","Q5T2P0","IL-17","IL17","CTLA8","CTLA-8","IL-17A"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(16659)"})
#  (f285b72:`KG:1`:protein {family:"Non-IDG",name:"Interleukin-12 subunit alpha",synonyms:["P29459","IL12A_HUMAN","IL12A","Q96QZ1","IL-12A","P35","CLMF","NFSK","NKSF1"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(17119)"})
#  (a5aed4e:`KG:1`:protein {family:"Enzyme",name:"Tryptase alpha/beta-1",synonyms:["Q15661","TRYB1_HUMAN","TPSAB1","D2E6R9","D2E6S1","P15157","Q15663","Q6B052","Q9H2Y4","Q9H2Y5","Q9UQI1","Tryptase-1","TPS1","TPS2","TPSB1"],type:"protein",uri:"https://pharos.ncats.io/idg/api/v1/targets(19826)"})
#  (bbade17:`KG:1`:drug {name:"pranlukast",synonyms:["pranlukast","CHEMBL21333"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(219910)"})
#  (ada44f7:`KG:1`:drug {name:"mepolizumab",synonyms:["mepolizumab","CHEMBL2108429"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(199138)"})
#  (d92df1e:`KG:1`:drug {name:"zafirlukast",synonyms:["CHEMBL603","Zafirlukast","zafirlukast"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(32912)"})
#  (f191665:`KG:1`:drug {name:"laropiprant",synonyms:["CHEMBL426559","[(3R)-4-(4-chlorobenzyl)-7-fluoro-5-(methylsulfonyl)-1,2,3,4-tetrahydrocyclopenta[b]indol-3-yl]-acetic acid","laropiprant"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(2588)"})
#  (b2e7e22:`KG:1`:drug {name:"montelukast",synonyms:["CHEMBL787","Montelukast","(1-{(R)-1-{3-[(E)-2-(7-Chloro-quinolin-2-yl)-vinyl]-phenyl}-3-[2-(1-hydroxy-1-methyl-ethyl)-phenyl]-propylsulfanylmethyl}-cyclopropyl)-acetic acid","montelukast"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(78646)"})
#  (b89c931:`KG:1`:drug {name:"ustekinumab",synonyms:["ustekinumab","CHEMBL1201835"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(194847)"})
#  (eec685b:`KG:1`:drug {name:"nafamostat",synonyms:["nafamostat","CHEMBL273264","4-Guanidino-benzoic acid 6-carbamimidoyl-naphthalen-2-yl ester"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(685)"})
#  (a813fd0:`KG:1`:drug {name:"secukinumab",synonyms:["secukinumab","CHEMBL1743068"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(218321)"})
#  (ec76af4:`KG:1`:drug {name:"ixekizumab",synonyms:["ixekizumab","CHEMBL1743034"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(218322)"})
#  (f436498:`KG:1`:drug {name:"ramatroban",synonyms:["ramatroban","CHEMBL361812"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(2526)"})
#  (e131b8d:`KG:1`:drug {name:"reproterol",synonyms:["reproterol","CHEMBL1095607"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214986)"})
#  (d6034a6:`KG:1`:drug {name:"tulobuterol",synonyms:["tulobuterol","CHEMBL1159717"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214987)"})
#  (b4d6de6:`KG:1`:drug {name:"olodaterol",synonyms:["olodaterol","CHEMBL605846"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214988)"})
#  (a248c40:`KG:1`:drug {name:"norepinephrine",synonyms:["CHEMBL1437","SID26754493","SID29215339","norepinephrine","4-((S)-2-Amino-1-hydroxy-ethyl)-benzene-1,2-diol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(25261)"})
#  (b2c8f61:`KG:1`:drug {name:"carvedilol",synonyms:["CHEMBL723","Carvedilol","1-(9H-Carbazol-4-yloxy)-3-[2-(2-methoxy-phenoxy)-ethylamino]-propan-2-ol","carvedilol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(19636)"})
#  (a4781ae:`KG:1`:drug {name:"bupranolol",synonyms:["bupranolol","CHEMBL305380"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171484)"})
#  (b8cfa7c:`KG:1`:drug {name:"nadolol",synonyms:["nadolol","CHEMBL649"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171486)"})
#  (f62c7cf:`KG:1`:drug {name:"ephedrine",synonyms:["ephedrine","CHEMBL211456"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214989)"})
#  (c37c9bf:`KG:1`:drug {name:"levobunolol",synonyms:["CHEMBL1201237","Levobunolol","levobunolol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(36281)"})
#  (e6051ab:`KG:1`:drug {name:"labetalol",synonyms:["CHEMBL429","Labetalol","labetalol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(36285)"})
#  (cbc2a04:`KG:1`:drug {name:"epinephrine",synonyms:["epinephrine","CHEMBL679","Adrenaline"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(48263)"})
#  (ed39d81:`KG:1`:drug {name:"orciprenaline",synonyms:["orciprenaline","CHEMBL776","Metaproterenol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214990)"})
#  (f7080f9:`KG:1`:drug {name:"droxidopa",synonyms:["droxidopa","CHEMBL2103827"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(48265)"})
#  (f6ac917:`KG:1`:drug {name:"levosalbutamol",synonyms:["levosalbutamol","CHEMBL1002"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214991)"})
#  (c3591a5:`KG:1`:drug {name:"metipranolol",synonyms:["metipranolol","CHEMBL1291"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171488)"})
#  (ccea6b0:`KG:1`:drug {name:"vilanterol",synonyms:["vilanterol","CHEMBL1198857"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214993)"})
#  (a953dd3:`KG:1`:drug {name:"timolol",synonyms:["CHEMBL499","Timolol","timolol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(111885)"})
#  (bcbf5c6:`KG:1`:drug {name:"terbutaline",synonyms:["terbutaline","CHEMBL1160544"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214994)"})
#  (d448456:`KG:1`:drug {name:"sotalol",synonyms:["sotalol","CHEMBL1700"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(44756)"})
#  (a6fe04b:`KG:1`:drug {name:"ritodrine",synonyms:["ritodrine","CHEMBL785"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214995)"})
#  (dfd564a:`KG:1`:drug {name:"propranolol",synonyms:["CHEMBL27","1-Isopropylamino-3-(naphthalen-1-yloxy)-propan-2-ol","Propranolol","propranolol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(19235)"})
#  (f73cf07:`KG:1`:drug {name:"pirbuterol",synonyms:["pirbuterol","CHEMBL1094966"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214996)"})
#  (d12b26c:`KG:1`:drug {name:"pindolol",synonyms:["CHEMBL500","1-(1H-Indol-4-yloxy)-3-isopropylamino-propan-2-ol","Pindolol","1-Dimethylamino-3-(1H-indol-4-yloxy)-propan-2-ol","1-(1H-indol-4-yloxy)-3-(isopropylamino)propan-2-ol","pindolol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(111943)"})
#  (c79d0aa:`KG:1`:drug {name:"penbutolol",synonyms:["penbutolol","CHEMBL1290"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171489)"})
#  (ba0905c:`KG:1`:drug {name:"oxprenolol",synonyms:["oxprenolol","CHEMBL546"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171490)"})
#  (c27372c:`KG:1`:drug {name:"nebivolol",synonyms:["nebivolol","CHEMBL434394"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171491)"})
#  (b499492:`KG:1`:drug {name:"isoprenaline",synonyms:["CHEMBL434","Isoprenaline","4-(1-Hydroxy-2-isopropylamino-ethyl)-benzene-1,2-diol","Isoproterenol","isoprenaline"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(111985)"})
#  (ff2e4b6:`KG:1`:drug {name:"dobutamine",synonyms:["CHEMBL926","Dobutamine","dobutamine"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(48549)"})
#  (bf7d8f8:`KG:1`:drug {name:"carteolol",synonyms:["carteolol","CHEMBL839","5-(3-tert-Butylamino-2-hydroxy-propoxy)-3,4-dihydro-1H-quinolin-2-one (carteolol)"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171493)"})
#  (ecfed0f:`KG:1`:drug {name:"salbutamol",synonyms:["salbutamol","CHEMBL714","4-(2-(tert-butylamino)-1-hydroxyethyl)-2-(hydroxymethyl)phenol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214997)"})
#  (a942449:`KG:1`:drug {name:"fenoterol",synonyms:["fenoterol","CHEMBL32800"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214998)"})
#  (f35a08e:`KG:1`:drug {name:"protokylol",synonyms:["protokylol","CHEMBL1200893"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(214999)"})
#  (e7dd0cf:`KG:1`:drug {name:"formoterol",synonyms:["CHEMBL1256786","Formoterol","Rel-Formoterol","N-(2-Hydroxy-5-{1-hydroxy-2-[2-(4-methoxy-phenyl)-1-methyl-ethylamino]-ethyl}-phenyl)-formamide","formoterol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171592)"})
#  (c0f8a98:`KG:1`:drug {name:"salmeterol",synonyms:["CHEMBL1263","Salmeterol","4-{1-Hydroxy-2-[6-(4-phenyl-butoxy)-hexylamino]-ethyl}-benzene-1,2-diol","salmeterol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171543)"})
#  (c02018e:`KG:1`:drug {name:"alprenolol",synonyms:["CHEMBL266195","Alprenolol","1-(2-Allyl-phenoxy)-3-isopropylamino-propan-2-ol","alprenolol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(111955)"})
#  (b9ed53c:`KG:1`:drug {name:"procaterol",synonyms:["procaterol","CHEMBL160519"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(215000)"})
#  (ddec728:`KG:1`:drug {name:"arformoterol",synonyms:["Formoterol","arformoterol","CHEMBL1363"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(215001)"})
#  (eb6cc64:`KG:1`:drug {name:"bitolterol",synonyms:["bitolterol","CHEMBL1201295"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(215002)"})
#  (b2dee6b:`KG:1`:drug {name:"indacaterol",synonyms:["Indacaterol","CHEMBL1095777","8-Hydroxy-5-[(R)-1-hydroxy-2-(5,6-diethylindan-2-ylamino)-ethyl]-1H-quinolin-2-one","indacaterol"],type:"drug",uri:"https://pharos.ncats.io/idg/api/v1/ligands(171591)"})
