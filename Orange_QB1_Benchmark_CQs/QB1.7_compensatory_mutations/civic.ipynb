# %%
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 999

# %%
# get gene sets from github
url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_4_all_genes.txt"
fa_genes = pd.read_csv(url, sep='\t', names=['ncbi', 'hgnc'])
fa_genes.head()
# Out:
#             ncbi   hgnc
# 0  NCBIGene:2175  FANCA
# 1  NCBIGene:2187  FANCB
# 2  NCBIGene:2176  FANCC
# 3  NCBIGene:2178  FANCE
# 4  NCBIGene:2188  FANCF

# %%
# Get all variants from civic by gene, print counts: 
url = "https://civic.genome.wustl.edu/api/genes/{}?identifier_type=entrez_symbol".format(",".join(fa_genes.hgnc))
d = requests.get(url).json()
gene_count = {x['name']:len(x['variants']) for x in d}
print(sum(gene_count.values()))
gene_count
# Out:
# 33
# {'BRCA1': 18,
#  'BRCA2': 11,
#  'BRIP1': 0,
#  'CENPS': 0,
#  'CENPX': 0,
#  'ERCC4': 0,
#  'FAAP100': 0,
#  'FAAP20': 0,
#  'FAAP24': 0,
#  'FANCA': 1,
#  'FANCB': 0,
#  'FANCC': 1,
#  'FANCD2': 0,
#  'FANCE': 0,
#  'FANCF': 0,
#  'FANCG': 0,
#  'FANCI': 0,
#  'FANCL': 0,
#  'FANCM': 0,
#  'MAD2L2': 0,
#  'PALB2': 2,
#  'RAD51': 0,
#  'RAD51C': 0,
#  'RFWD3': 0,
#  'SLX4': 0,
#  'UBE2T': 0,
#  'XRCC2': 0}

# %%
## query for the details from wikidata (note wikidata only contains the "high quality" results)

# %%
def query_and_format_result(query):
    params = {'query': query, 'format': 'json'}
    results = requests.get('https://query.wikidata.org/sparql', params=params).json()['results']['bindings']
    return pd.DataFrame([{k:v['value'] for k,v in item.items()} for item in results])

# %%
all_genes_quotes = '"' + '" "'.join(fa_genes.hgnc) + '"'

# %%
# which of those lead to drug resistance phenotype?
query = """select ?geneLabel ?variantLabel ?variant ?drugLabel ?cid ?civic ?diseaseLabel where {
  values ?hgnc {**hgnc**}
  # ?gene wdt:P353 ?hgnc .  # get gene item from hgnc id
  # ?variant wdt:P3433 ?gene . # get variants on the gene
  # ?variant wdt:P3329 ?civic . # get civic id
  # ?variant p:P3354|p:P3355 ?s . # variant is a "positive therapeutic predictor" or "negative therapeutic predictor"
  # ?s ps:P3354|ps:P3355 ?drug .  # get the drug associated
  OPTIONAL {?drug wdt:P662 ?cid} # get the pubchem ID for the drug
  # ?s pq:P2175 ?disease .  # get the disease associated
  SERVICE wikibase:label {  bd:serviceParam wikibase:language "en" }
}
"""
query = query.replace("**hgnc**", all_genes_quotes)
print(query)
# Out:
# select ?geneLabel ?variantLabel ?variant ?drugLabel ?cid ?civic ?diseaseLabel where {
#   values ?hgnc {"FANCA" "FANCB" "FANCC" "FANCE" "FANCF" "FANCG" "FANCL" "FANCM" "FANCD2" "FANCI" "UBE2T" "BRCA2" "BRIP1" "PALB2" "RAD51C" "SLX4" "ERCC4" "RAD51" "BRCA1" "MAD2L2" "XRCC2" "RFWD3" "FAAP100" "FAAP24" "FAAP20" "CENPS" "CENPX"}
#   ?gene wdt:P353 ?hgnc .  # get gene item from hgnc id
#   ?variant wdt:P3433 ?gene . # get variants on the gene
#   ?variant wdt:P3329 ?civic . # get civic id
#   ?variant p:P3354|p:P3355 ?s . # variant is a "positive therapeutic predictor" or "negative therapeutic predictor"
#   ?s ps:P3354|ps:P3355 ?drug .  # get the drug associated
#   OPTIONAL {?drug wdt:P662 ?cid} # get the pubchem ID for the drug
#   ?s pq:P2175 ?disease .  # get the disease associated
#   SERVICE wikibase:label {  bd:serviceParam wikibase:language "en" }
# }

# %%
query_and_format_result(query)
# Out:
#          cid civic                          diseaseLabel  \
# 0    5702198   534                     pancreatic cancer
# 1      60750   534                     pancreatic cancer
# 2       2708   534                     pancreatic cancer
# 3   73346703   397                          mesothelioma
# 4     460612   534                     pancreatic cancer
# 5   23725625   532                       prostate cancer
# 6   23725625   131  Her2-receptor negative breast cancer
# 7   23725625   131                       prostate cancer
# 8   23725625   131                        ovarian cancer
# 9   23725625   132                        ovarian cancer
# 10  23725625   132                       prostate cancer
# 11      5746   532                     pancreatic cancer
# 12      5746   132                     pancreatic cancer
# 13      5746   534                     pancreatic cancer
# 14  44819241   131                         breast cancer
# 15  44819241   131                        ovarian cancer
# 16  44819241   132                         breast cancer
# 17  44819241   132                        ovarian cancer
# 18  25257557   131                         breast cancer
# 19  11635763   131                         breast cancer
# 20       NaN   403                        ovarian cancer
#
#                                 drugLabel geneLabel  \
# 0                               cisplatin     FANCC
# 1                             gemcitabine     FANCC
# 2                            chlorambucil     FANCC
# 3                             Vinorelbine     BRCA1
# 4                               melphalan     FANCC
# 5                                olaparib     PALB2
# 6                                olaparib     BRCA1
# 7                                olaparib     BRCA1
# 8                                olaparib     BRCA1
# 9                                olaparib     BRCA2
# 10                               olaparib     BRCA2
# 11                              mitomycin     PALB2
# 12                              mitomycin     BRCA2
# 13                              mitomycin     FANCC
# 14                            talazoparib     BRCA1
# 15                            talazoparib     BRCA1
# 16                            talazoparib     BRCA2
# 17                            talazoparib     BRCA2
# 18                                cx-5461     BRCA1
# 19                             quarfloxin     BRCA1
# 20  platinum / taxane combination therapy     BRCA1
#
#                                      variant                  variantLabel
# 0   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 1   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 2   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 3   http://www.wikidata.org/entity/Q28445085              BRCA1 EXPRESSION
# 4   http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 5   http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 6   http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 7   http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 8   http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 9   http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 10  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 11  http://www.wikidata.org/entity/Q28371488  PALB2 BIALLELIC INACTIVATION
# 12  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 13  http://www.wikidata.org/entity/Q28445146        FANCC LOSS-OF-FUNCTION
# 14  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 15  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 16  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 17  http://www.wikidata.org/entity/Q28444938        BRCA2 LOSS-OF-FUNCTION
# 18  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 19  http://www.wikidata.org/entity/Q28444937        BRCA1 LOSS-OF-FUNCTION
# 20  http://www.wikidata.org/entity/Q28445090         BRCA1 UNDEREXPRESSION

# %%
## Get all results from civic directly

# %%
# get all variant IDs, from variants in FA genes
from itertools import chain
variant_ids = set(chain(*[[x['id'] for x in dd['variants']] for dd in d]))
# should be 33 of them
len(variant_ids)
# Out:
# 33

# %%
url = "https://civicdb.org/api/variants/{}"
variant_evs = dict()
for variant_id in variant_ids:
    d = requests.get(url.format(variant_id)).json()
    variant_evs[variant_id] = d

# %%
all_r = []
for variant_id, evs in variant_evs.items():
    records = [x for x in evs['evidence_items'] if x['evidence_type'] == 'Predictive']
    for record in records:
        record = {'disease': record['disease']['display_name'],
         'drugs': ";".join([x['name'] for x in record['drugs']]),
         'evidence_direction': record['evidence_direction'],
         'evidence_type': record['evidence_type'],
         'id': record['id'],
         'name': record['name'],
         'variant_id': record['variant_id'],
          'evidence_level': record['evidence_level'],
          'rating': record['rating'],
          'status': record['status'],
          'entrez_id': evs['entrez_id'],
            'entrez_name': evs['entrez_name'],
                  'url': "https://civic.genome.wustl.edu/links/variants/" + str(record['variant_id'])
         }
        all_r.append(record)

# %%
df = pd.DataFrame(all_r)
df.sort_values("evidence_level")
# Out:
#                                    disease  \
# 49                                  Cancer
# 26                                  Cancer
# 59                       Pancreatic Cancer
# 28                       Ovarian Carcinoma
# 29                          Ovarian Cancer
# 30  Triple-receptor Negative Breast Cancer
# 32  Triple-receptor Negative Breast Cancer
# 33                          Ovarian Cancer
# 34                           Breast Cancer
# 35                       Pancreatic Cancer
# 36                       Pancreatic Cancer
# 37                       Pancreatic Cancer
# 60                       Pancreatic Cancer
# 38                       Pancreatic Cancer
# 50                       Ovarian Carcinoma
# 51                       Ovarian Carcinoma
# 52                          Ovarian Cancer
# 53  Triple-receptor Negative Breast Cancer
# 54                          Ovarian Cancer
# 55  Triple-receptor Negative Breast Cancer
# 56                           Breast Cancer
# 57                       Pancreatic Cancer
# 58                       Pancreatic Cancer
# 27                       Ovarian Carcinoma
# 0                           Ovarian Cancer
# 31                          Ovarian Cancer
# 17                          Ovarian Cancer
# 1                            Breast Cancer
# 2     Her2-receptor Negative Breast Cancer
# 4                           Ovarian Cancer
# ..                                     ...
# 12                          Ovarian Cancer
# 46                          Ovarian Cancer
# 47                         Prostate Cancer
# 48                       Pancreatic Cancer
# 24                          Ovarian Cancer
# 5                          Prostate Cancer
# 61                       Pancreatic Cancer
# 25                          Ovarian Cancer
# 43                          Ovarian Cancer
# 44                          Ovarian Cancer
# 41                          Ovarian Cancer
# 23                          Ovarian Cancer
# 22                          Ovarian Cancer
# 21                          Ovarian Cancer
# 20                          Ovarian Cancer
# 62                          Ovarian Cancer
# 19                          Ovarian Cancer
# 18                          Ovarian Cancer
# 42                          Ovarian Cancer
# 63                         Prostate Cancer
# 16                          Ovarian Cancer
# 14                          Ovarian Cancer
# 39                          Ovarian Cancer
# 40                          Ovarian Cancer
# 15                  Malignant Mesothelioma
# 13                       Pancreatic Cancer
# 3                            Breast Cancer
# 45                          Ovarian Cancer
# 9                            Breast Cancer
# 8                        Pancreatic Cancer
#
#                                                        drugs  entrez_id  \
# 49                                                  Olaparib        675
# 26                                                  Olaparib        672
# 59                           Veliparib;Gemcitabine;Cisplatin        675
# 28                                                  PLATINUM        672
# 29                                        Olaparib;Cediranib        672
# 30                                     Cisplatin;Carboplatin        672
# 32                                                  Olaparib        672
# 33                                                 Rucaparib        672
# 34                                                  Olaparib        672
# 35                                                  Olaparib        672
# 36                                                  PLATINUM        672
# 37                           Veliparib;Gemcitabine;Cisplatin        672
# 60                                                 Veliparib        675
# 38                                                 Veliparib        672
# 50                                                  PLATINUM        675
# 51                                                  PLATINUM        675
# 52                                        Olaparib;Cediranib        675
# 53                                     Cisplatin;Carboplatin        675
# 54                                                  Olaparib        675
# 55                                                  Olaparib        675
# 56                                                  Olaparib        675
# 57                                                  Olaparib        675
# 58                                                  PLATINUM        675
# 27                                                  PLATINUM        672
# 0                                                Talazoparib        672
# 31                                                  Olaparib        672
# 17                                           Taxane;PLATINUM        672
# 1                                                Talazoparib        672
# 2                                                   Olaparib        672
# 4                                                   Olaparib        672
# ..                                                       ...        ...
# 12                                                  Olaparib        675
# 46                                                 Rucaparib        672
# 47                                                  Olaparib      79728
# 48                                               Mitomycin C      79728
# 24                                                 Rucaparib        672
# 5                                                   Olaparib        672
# 61                                                  Iniparib        675
# 25                                                 Rucaparib        672
# 43                                                 Rucaparib        675
# 44                                                 Rucaparib        675
# 41                                                 Rucaparib        675
# 23                                                 Rucaparib        672
# 22                                                 Rucaparib        672
# 21                                                 Rucaparib        672
# 20                                                 Rucaparib        672
# 62                                                 Rucaparib        675
# 19                                                 Rucaparib        672
# 18                                                 Rucaparib        672
# 42                                                 Rucaparib        675
# 63                                                 Cisplatin       2175
# 16                                                 Rucaparib        672
# 14                                                 Rucaparib        672
# 39                                                 Rucaparib        675
# 40                                                 Rucaparib        675
# 15                                               Vinorelbine        672
# 13  Gemcitabine;Melphalan;Chlorambucil;Cisplatin;Mitomycin C       2176
# 3                                            CX-3543;CX-5461        672
# 45                                                  Olaparib        672
# 9                                            CX-3543;CX-5461        675
# 8                                                Mitomycin C        675
#
#    entrez_name evidence_direction evidence_level evidence_type    id     name  \
# 49       BRCA2           Supports              A    Predictive  1371  EID1371
# 26       BRCA1           Supports              A    Predictive  1370  EID1370
# 59       BRCA2           Supports              B    Predictive  5933  EID5933
# 28       BRCA1           Supports              B    Predictive  1531  EID1531
# 29       BRCA1           Supports              B    Predictive  1677  EID1677
# 30       BRCA1           Supports              B    Predictive  1684  EID1684
# 32       BRCA1           Supports              B    Predictive  1775  EID1775
# 33       BRCA1           Supports              B    Predictive  1897  EID1897
# 34       BRCA1           Supports              B    Predictive  5830  EID5830
# 35       BRCA1           Supports              B    Predictive  5914  EID5914
# 36       BRCA1           Supports              B    Predictive  5915  EID5915
# 37       BRCA1           Supports              B    Predictive  5932  EID5932
# 60       BRCA2   Does Not Support              B    Predictive  5935  EID5935
# 38       BRCA1   Does Not Support              B    Predictive  5934  EID5934
# 50       BRCA2           Supports              B    Predictive  1530  EID1530
# 51       BRCA2           Supports              B    Predictive  1532  EID1532
# 52       BRCA2           Supports              B    Predictive  1678  EID1678
# 53       BRCA2           Supports              B    Predictive  1685  EID1685
# 54       BRCA2           Supports              B    Predictive  1773  EID1773
# 55       BRCA2           Supports              B    Predictive  1776  EID1776
# 56       BRCA2           Supports              B    Predictive  5831  EID5831
# 57       BRCA2           Supports              B    Predictive  5913  EID5913
# 58       BRCA2           Supports              B    Predictive  5916  EID5916
# 27       BRCA1           Supports              B    Predictive  1529  EID1529
# 0        BRCA1           Supports              B    Predictive  4876  EID4876
# 31       BRCA1           Supports              B    Predictive  1772  EID1772
# 17       BRCA1           Supports              B    Predictive   942   EID942
# 1        BRCA1           Supports              B    Predictive  4838  EID4838
# 2        BRCA1           Supports              B    Predictive  5815  EID5815
# 4        BRCA1           Supports              B    Predictive   211   EID211
# ..         ...                ...            ...           ...   ...      ...
# 12       BRCA2           Supports              B    Predictive   212   EID212
# 46       BRCA1           Supports              C    Predictive  2878  EID2878
# 47       PALB2           Supports              C    Predictive  1963  EID1963
# 48       PALB2           Supports              C    Predictive  1305  EID1305
# 24       BRCA1           Supports              C    Predictive  2875  EID2875
# 5        BRCA1           Supports              C    Predictive   845   EID845
# 61       BRCA2           Supports              C    Predictive  5936  EID5936
# 25       BRCA1           Supports              C    Predictive  2876  EID2876
# 43       BRCA2           Supports              C    Predictive  2884  EID2884
# 44       BRCA2           Supports              C    Predictive  2885  EID2885
# 41       BRCA2           Supports              C    Predictive  2882  EID2882
# 23       BRCA1           Supports              C    Predictive  2874  EID2874
# 22       BRCA1           Supports              C    Predictive  2872  EID2872
# 21       BRCA1           Supports              C    Predictive  2873  EID2873
# 20       BRCA1           Supports              C    Predictive  2870  EID2870
# 62       BRCA2           Supports              C    Predictive  2879  EID2879
# 19       BRCA1           Supports              C    Predictive  2869  EID2869
# 18       BRCA1           Supports              C    Predictive  2868  EID2868
# 42       BRCA2           Supports              C    Predictive  2883  EID2883
# 63       FANCA           Supports              C    Predictive  5813  EID5813
# 16       BRCA1           Supports              C    Predictive  2877  EID2877
# 14       BRCA1           Supports              C    Predictive  2871  EID2871
# 39       BRCA2           Supports              C    Predictive  2880  EID2880
# 40       BRCA2           Supports              C    Predictive  2881  EID2881
# 15       BRCA1           Supports              D    Predictive   933   EID933
# 13       FANCC           Supports              D    Predictive  1307  EID1307
# 3        BRCA1           Supports              D    Predictive  1924  EID1924
# 45       BRCA1           Supports              D    Predictive  4623  EID4623
# 9        BRCA2           Supports              D    Predictive  1925  EID1925
# 8        BRCA2           Supports              D    Predictive  1308  EID1308
#
#     rating     status                                                 url  \
# 49     4.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 26     4.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 59     3.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 28     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 29     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 30     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 32     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 33     4.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 34     4.0  submitted   https://civic.genome.wustl.edu/links/variants/185
# 35     4.0  submitted   https://civic.genome.wustl.edu/links/variants/185
# 36     4.0  submitted   https://civic.genome.wustl.edu/links/variants/185
# 37     3.0  submitted   https://civic.genome.wustl.edu/links/variants/185
# 60     3.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 38     3.0  submitted   https://civic.genome.wustl.edu/links/variants/185
# 50     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 51     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 52     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 53     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 54     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 55     3.0   accepted   https://civic.genome.wustl.edu/links/variants/186
# 56     4.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 57     4.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 58     4.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 27     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 0      3.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# 31     3.0   accepted   https://civic.genome.wustl.edu/links/variants/185
# 17     3.0   accepted   https://civic.genome.wustl.edu/links/variants/403
# 1      4.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# 2      5.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# 4      4.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# ..     ...        ...                                                 ...
# 12     4.0   accepted   https://civic.genome.wustl.edu/links/variants/132
# 46     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1246
# 47     3.0   accepted   https://civic.genome.wustl.edu/links/variants/532
# 48     4.0   accepted   https://civic.genome.wustl.edu/links/variants/532
# 24     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1243
# 5      2.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# 61     3.0  submitted   https://civic.genome.wustl.edu/links/variants/186
# 25     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1244
# 43     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1252
# 44     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1253
# 41     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1250
# 23     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1242
# 22     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1240
# 21     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1241
# 20     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1238
# 62     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1247
# 19     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1237
# 18     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1236
# 42     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1251
# 63     4.0  submitted  https://civic.genome.wustl.edu/links/variants/2165
# 16     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1245
# 14     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1239
# 39     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1248
# 40     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1249
# 15     2.0   accepted   https://civic.genome.wustl.edu/links/variants/397
# 13     3.0   accepted   https://civic.genome.wustl.edu/links/variants/534
# 3      4.0   accepted   https://civic.genome.wustl.edu/links/variants/131
# 45     NaN  submitted  https://civic.genome.wustl.edu/links/variants/1555
# 9      4.0  submitted   https://civic.genome.wustl.edu/links/variants/132
# 8      2.0   accepted   https://civic.genome.wustl.edu/links/variants/132
#
#     variant_id
# 49         186
# 26         185
# 59         186
# 28         185
# 29         185
# 30         185
# 32         185
# 33         185
# 34         185
# 35         185
# 36         185
# 37         185
# 60         186
# 38         185
# 50         186
# 51         186
# 52         186
# 53         186
# 54         186
# 55         186
# 56         186
# 57         186
# 58         186
# 27         185
# 0          131
# 31         185
# 17         403
# 1          131
# 2          131
# 4          131
# ..         ...
# 12         132
# 46        1246
# 47         532
# 48         532
# 24        1243
# 5          131
# 61         186
# 25        1244
# 43        1252
# 44        1253
# 41        1250
# 23        1242
# 22        1240
# 21        1241
# 20        1238
# 62        1247
# 19        1237
# 18        1236
# 42        1251
# 63        2165
# 16        1245
# 14        1239
# 39        1248
# 40        1249
# 15         397
# 13         534
# 3          131
# 45        1555
# 9          132
# 8          132
#
# [64 rows x 13 columns]

# %%
df.entrez_name.value_counts()
# Out:
# BRCA1    33
# BRCA2    27
# PALB2     2
# FANCC     1
# FANCA     1
# Name: entrez_name, dtype: int64

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df[df.entrez_name.isin({"PALB2", "FANCC", "FANCA"})]
# Out:
#               disease  \
# 13  Pancreatic Cancer
# 47    Prostate Cancer
# 48  Pancreatic Cancer
# 63    Prostate Cancer
#
#                                                        drugs  entrez_id  \
# 13  Gemcitabine;Melphalan;Chlorambucil;Cisplatin;Mitomycin C       2176
# 47                                                  Olaparib      79728
# 48                                               Mitomycin C      79728
# 63                                                 Cisplatin       2175
#
#    entrez_name evidence_direction evidence_level evidence_type    id     name  \
# 13       FANCC           Supports              D    Predictive  1307  EID1307
# 47       PALB2           Supports              C    Predictive  1963  EID1963
# 48       PALB2           Supports              C    Predictive  1305  EID1305
# 63       FANCA           Supports              C    Predictive  5813  EID5813
#
#     rating     status                                                 url  \
# 13     3.0   accepted   https://civic.genome.wustl.edu/links/variants/534
# 47     3.0   accepted   https://civic.genome.wustl.edu/links/variants/532
# 48     4.0   accepted   https://civic.genome.wustl.edu/links/variants/532
# 63     4.0  submitted  https://civic.genome.wustl.edu/links/variants/2165
#
#     variant_id
# 13         534
# 47         532
# 48         532
# 63        2165
