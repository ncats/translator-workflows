# %%
import urllib2
import json
import requests

# %% [markdown]
# # BigGIM example
#
# Big GIM (Gene Interaction Miner) is a Translator Knowledge Source that contains function interaction data for all pairs of genes. Functional interaction data are available from four different sources:
#
# 1. tissue-specific gene expression correlations from healthy tissue samples (GTEx),
# 2. tissue-specific gene expression correlations from cancer samples (TCGA),
# 3. tissue-specific probabilities of function interaction (GIANT), and
# 4. direct interactions (BioGRID).
#
# The data is stored as a Google BigQuery table enabling fast access.
#
# ## Swagger api specification
#
# http://biggim.ncats.io/api/
#
# ## Sections
#
# * 1.0 [Metadata Examples](#metadata_examples)
#     * 1.1 [Get available studies](#metadata_studies)
#     * 1.2 [Study descriptions](#metadata_study_descriptions)
#     * 1.3 [Get a single study](#metadata_single_study)
#     * 1.4 [Get substudies](#metadata_substudies)
#     * 1.5 [Get all tables](#metadata_tables)
#     * 1.6 [Get one table](#metadata_table)
#     * 1.7 [Get a single column](#metadata_column)
#     * 1.8 [List all tissues](#metadata_tissues)
#     * 1.9 [Get single tissue](#metadata_tissue)
# * 2.0 [Query Examples](#query_examples)
#     * 2.1 [Simple predefined query](#query_simple)
#     * 2.2 [Check the status of the simple predefined query](#query_status)
#     * 2.3 [Get the results as dataframe](#query_results)
# * 3.0 [Full Example](#full_example)

# %%
base_url = 'http://biggim.ncats.io/api'

# %%
#a couple of simple helper functions
def post(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()

def get(endpoint, data={}, base_url=base_url):
    req = requests.get('%s/%s' % (base_url,endpoint), data=data)
    req.raise_for_status()
    return req.json()
    

def jprint(dct):
    print json.dumps(dct, indent=2)

# %% [markdown]
# <a id="metadata_examples"></a>
# ## Example Metadata

# %% [markdown]
# <a id="metadata_studies"></a>
# ### Get available studies

# %%
try:
    studies = get('metadata/study')
    jprint(studies)
except requests.HTTPError as e:
    print e
# Out:
# [
#   {
#     "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        ",
#     "name": "BioGRID",
#     "substudies": [
#       {
#         "tissue_hierarchy": null,
#         "description": "Default",
#         "name": "Default",
#         "columns": [
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           },
#           {
#             "datatype": "BOOLEAN",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "BioGRID_Interaction",
#             "interactions_type": "Boolean Flag For Interaction"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "BioGRID_Experimental_System",
#             "interactions_type": "Experimental System Used"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "BioGRID_Experimental_System_Type",
#             "interactions_type": "Experimental System Type"
#           },
#           {
#             "datatype": "STRING",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "BioGRID_Throughput",
#             "interactions_type": "High or Low Throughput Measurement"
#           }
#         ],
#         "cell_of_origin": null
#       }
#     ]
#   },
#   {
#     "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        ",
#     "name": "TCGA",
#     "substudies": [
#       {
#         "tissue_hierarchy": "0 - ovarian serous carcinoma cell|1 - ovary cancer cell|2 - ovary|3 - female reproductive gland|3 - internal female genital organ|4 - female reproductive system|4 - endocrine gland|5 - reproductive system|5 - gland|6 - urogenital system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "description": "Ovarian serous cystadenocarcinoma",
#         "name": "OV",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_OV_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_OV_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "ovarian serous carcinoma cell"
#       },
#       {
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Adrenocortical carcinoma",
#         "name": "ACC",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_ACC_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_ACC_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "adrenocortical carcinoma cell"
#       },
#       {
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "description": "Glioblastoma multiforme",
#         "name": "GBM",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_GBM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_GBM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "glioblastoma cell"
#       },
#       {
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "description": "Brain Lower Grade Glioma",
#         "name": "LGG",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_LGG_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_LGG_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "glioma cell"
#       },
#       {
#         "tissue_hierarchy": "0 - uterine sarcoma cell|1 - sarcoma cell|1 - uterine cancer cell|2 - cartilage|2 - skeletal muscle cancer cell|2 - bone cancer cell|2 - uterus|3 - connective tissue|3 - skeletal system|3 - skeletal muscle cell|3 - bone|3 - internal female genital organ|4 - whole body|4 - skeletal muscle|4 - female reproductive system|5 - animal|5 - muscle|5 - vertebrate muscular system|5 - reproductive system|6 - tissues, cell types and enzyme sources|6 - muscular system|6 - urogenital system",
#         "description": "Uterine Carcinosarcoma",
#         "name": "UCS",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_UCS_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "TCGA_UCS_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "uterine sarcoma cell"
#       },
#       {
#         "tissue_hierarchy": "0 - uveal melanoma cell|1 - melanoma cell|2 - skin cancer cell|2 - melanocyte|3 - skin|3 - epidermal cell|4 - integument|4 - epidermis|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#         "description": "Uveal Melanoma",
#         "name": "UVM",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "TCGA_UVM_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "TCGA_UVM_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
# ...
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Blood_Vessel_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "Blood Vessel"
#       },
#       {
#         "tissue_hierarchy": "0 - adrenal gland|1 - viscus|1 - endocrine gland|2 - whole body|2 - gland|3 - animal|4 - tissues, cell types and enzyme sources",
#         "description": "Adrenal_Gland",
#         "name": "Adrenal_Gland",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Adrenal_Gland_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "Adrenal Gland"
#       },
#       {
#         "tissue_hierarchy": "0 - adipose tissue|1 - connective tissue|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "description": "Adipose_Tissue",
#         "name": "Adipose_Tissue",
#         "columns": [
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "BigGIM_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "CRC_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_70_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_80_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_90_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Correlation",
#             "interactions_type": "Spearman Rank Correlation Coefficient"
#           },
#           {
#             "datatype": "FLOAT",
#             "table": {
#               "name": "FA_v1"
#             },
#             "name": "GTEx_Adipose_Tissue_Pvalue",
#             "interactions_type": "P-value (-log10)"
#           }
#         ],
#         "cell_of_origin": "Adipose Tissue"
#       }
#     ]
#   }
# ]

# %% [markdown]
# <a id="metadata_study_descriptions"></a>
# ### Study descriptions

# %%
for study in studies:
    print("Study Name: %s" % study['name'])
    print("Study Description: %s" % study['description'])
# Out:
# Study Name: BioGRID
# Study Description:  Biological General Repository for Interaction Datasets
#         BioGRID is an interaction repository with data compiled through comprehensive curation efforts.
#
#         https://thebiogrid.org/
#
# Study Name: TCGA
# Study Description:  The Cancer Genome Atlas
#         The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.
#
#         https://cancergenome.nih.gov/
#
# Study Name: GIANT
# Study Description: Genetic Investigation of ANthropometric Traits
#         The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.
#
#         http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium
#
# Study Name: GTEx
# Study Description: Genotype-Tissue Expression (GTEx) program
#
#         Genotype-Tissue Expression (GTEx) program is providing valuable insights into the mechanisms of gene regulation by studying human gene expression and regulation in multiple tissues from health individuals; exploring disease-related perturbations in a variety of human diseases; and examining sexual dimorphisms in gene expression and regulation in multiple tissues. Genetic variation between individuals underlying the many differences in gene expression  will be examined for correlation with differences in gene expression level to identify regions of the genome that influence whether and how much a gene is expressed. Identifying unique genomic variations associated with gene expression is expected to stimulate research towards understanding the genetic basis of complex diseases.
#
#         https://www.gtexportal.org/home/

# %% [markdown]
# <a id="metadata_single_study"></a>
# ### Get a single study

# %%
try:
    tcga = get('metadata/study/%s' % ('TCGA'))
    jprint(tcga)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# {
#   "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        ",
#   "name": "TCGA",
#   "substudies": [
#     {
#       "tissue_hierarchy": "0 - ovarian serous carcinoma cell|1 - ovary cancer cell|2 - ovary|3 - female reproductive gland|3 - internal female genital organ|4 - female reproductive system|4 - endocrine gland|5 - reproductive system|5 - gland|6 - urogenital system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "Ovarian serous cystadenocarcinoma",
#       "name": "OV",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_OV_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_OV_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "ovarian serous carcinoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Adrenocortical carcinoma",
#       "name": "ACC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_ACC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_ACC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "adrenocortical carcinoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#       "description": "Glioblastoma multiforme",
#       "name": "GBM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_GBM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_GBM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "glioblastoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Brain Lower Grade Glioma",
#       "name": "LGG",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_LGG_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_LGG_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "glioma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - uterine sarcoma cell|1 - sarcoma cell|1 - uterine cancer cell|2 - cartilage|2 - skeletal muscle cancer cell|2 - bone cancer cell|2 - uterus|3 - connective tissue|3 - skeletal system|3 - skeletal muscle cell|3 - bone|3 - internal female genital organ|4 - whole body|4 - skeletal muscle|4 - female reproductive system|5 - animal|5 - muscle|5 - vertebrate muscular system|5 - reproductive system|6 - tissues, cell types and enzyme sources|6 - muscular system|6 - urogenital system",
#       "description": "Uterine Carcinosarcoma",
#       "name": "UCS",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UCS_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UCS_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "uterine sarcoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - uveal melanoma cell|1 - melanoma cell|2 - skin cancer cell|2 - melanocyte|3 - skin|3 - epidermal cell|4 - integument|4 - epidermis|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "Uveal Melanoma",
#       "name": "UVM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UVM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UVM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "uveal melanoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Bladder Urothelial Carcinoma",
#       "name": "BLCA",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_BLCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_BLCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "urinary bladder cancer cell"
#     },
#     {
#       "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#       "description": "Breast invasive carcinoma",
#       "name": "BRCA",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_BRCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_BRCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "breast cancer cell"
#     },
#     {
#       "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#       "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#       "name": "CESC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_CESC_Correlation",
# ...
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_THCA_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_THCA_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "thyroid cancer cell"
#     },
#     {
#       "tissue_hierarchy": "0 - thymoma cell|1 - thymic cancer cell|2 - thymus|3 - immune system|3 - thorax|3 - endocrine gland|3 - lymphoid tissue|4 - whole body|4 - trunk|4 - gland|4 - hematopoietic system|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "Thymoma",
#       "name": "THYM",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_THYM_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_THYM_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "thymoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - endometrioid carcinoma cell|1 - uterine endometrium|1 - ovary cancer cell|2 - mucosa|2 - uterus|2 - ovary|3 - integument|3 - internal female genital organ|3 - female reproductive gland|4 - whole body|4 - female reproductive system|4 - endocrine gland|5 - animal|5 - reproductive system|5 - gland|6 - tissues, cell types and enzyme sources|6 - urogenital system",
#       "description": "Uterine Corpus Endometrial Carcinoma",
#       "name": "UCEC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UCEC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_UCEC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "endometrioid carcinoma cell"
#     }
#   ]
# }

# %% [markdown]
# <a id="metadata_substudies"></a>
# ### Get a substudies

# %%
for substudy in tcga['substudies']:
    print("Substudy name: %s " % substudy['name'])
    print("Substudy description: %s" % substudy['description'])
    t_c_list = ', '.join("%s.%s" % (column['table']["name"], column['name']) for column in substudy['columns'])
    print("Table.column list: %s" % (t_c_list) )
    print
# Out:
# Substudy name: OV
# Substudy description: Ovarian serous cystadenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_OV_Correlation, BigGIM_70_v1.TCGA_OV_Pvalue, BigGIM_80_v1.TCGA_OV_Correlation, BigGIM_80_v1.TCGA_OV_Pvalue, BigGIM_90_v1.TCGA_OV_Correlation, BigGIM_90_v1.TCGA_OV_Pvalue, BigGIM_v1.TCGA_OV_Correlation, BigGIM_v1.TCGA_OV_Pvalue, CRC_70_v1.TCGA_OV_Correlation, CRC_70_v1.TCGA_OV_Pvalue, CRC_80_v1.TCGA_OV_Correlation, CRC_80_v1.TCGA_OV_Pvalue, CRC_90_v1.TCGA_OV_Correlation, CRC_90_v1.TCGA_OV_Pvalue, CRC_v1.TCGA_OV_Correlation, CRC_v1.TCGA_OV_Pvalue, FA_70_v1.TCGA_OV_Correlation, FA_70_v1.TCGA_OV_Pvalue, FA_80_v1.TCGA_OV_Correlation, FA_80_v1.TCGA_OV_Pvalue, FA_90_v1.TCGA_OV_Correlation, FA_90_v1.TCGA_OV_Pvalue, FA_v1.TCGA_OV_Correlation, FA_v1.TCGA_OV_Pvalue
#
# Substudy name: ACC
# Substudy description: Adrenocortical carcinoma
# Table.column list: BigGIM_70_v1.TCGA_ACC_Correlation, BigGIM_70_v1.TCGA_ACC_Pvalue, BigGIM_80_v1.TCGA_ACC_Correlation, BigGIM_80_v1.TCGA_ACC_Pvalue, BigGIM_90_v1.TCGA_ACC_Correlation, BigGIM_90_v1.TCGA_ACC_Pvalue, BigGIM_v1.TCGA_ACC_Correlation, BigGIM_v1.TCGA_ACC_Pvalue, CRC_70_v1.TCGA_ACC_Correlation, CRC_70_v1.TCGA_ACC_Pvalue, CRC_80_v1.TCGA_ACC_Correlation, CRC_80_v1.TCGA_ACC_Pvalue, CRC_90_v1.TCGA_ACC_Correlation, CRC_90_v1.TCGA_ACC_Pvalue, CRC_v1.TCGA_ACC_Correlation, CRC_v1.TCGA_ACC_Pvalue, FA_70_v1.TCGA_ACC_Correlation, FA_70_v1.TCGA_ACC_Pvalue, FA_80_v1.TCGA_ACC_Correlation, FA_80_v1.TCGA_ACC_Pvalue, FA_90_v1.TCGA_ACC_Correlation, FA_90_v1.TCGA_ACC_Pvalue, FA_v1.TCGA_ACC_Correlation, FA_v1.TCGA_ACC_Pvalue
#
# Substudy name: GBM
# Substudy description: Glioblastoma multiforme
# Table.column list: BigGIM_70_v1.TCGA_GBM_Correlation, BigGIM_70_v1.TCGA_GBM_Pvalue, BigGIM_80_v1.TCGA_GBM_Correlation, BigGIM_80_v1.TCGA_GBM_Pvalue, BigGIM_90_v1.TCGA_GBM_Correlation, BigGIM_90_v1.TCGA_GBM_Pvalue, BigGIM_v1.TCGA_GBM_Correlation, BigGIM_v1.TCGA_GBM_Pvalue, CRC_70_v1.TCGA_GBM_Correlation, CRC_70_v1.TCGA_GBM_Pvalue, CRC_80_v1.TCGA_GBM_Correlation, CRC_80_v1.TCGA_GBM_Pvalue, CRC_90_v1.TCGA_GBM_Correlation, CRC_90_v1.TCGA_GBM_Pvalue, CRC_v1.TCGA_GBM_Correlation, CRC_v1.TCGA_GBM_Pvalue, FA_70_v1.TCGA_GBM_Correlation, FA_70_v1.TCGA_GBM_Pvalue, FA_80_v1.TCGA_GBM_Correlation, FA_80_v1.TCGA_GBM_Pvalue, FA_90_v1.TCGA_GBM_Correlation, FA_90_v1.TCGA_GBM_Pvalue, FA_v1.TCGA_GBM_Correlation, FA_v1.TCGA_GBM_Pvalue
#
# Substudy name: LGG
# Substudy description: Brain Lower Grade Glioma
# Table.column list: BigGIM_70_v1.TCGA_LGG_Correlation, BigGIM_70_v1.TCGA_LGG_Pvalue, BigGIM_80_v1.TCGA_LGG_Correlation, BigGIM_80_v1.TCGA_LGG_Pvalue, BigGIM_90_v1.TCGA_LGG_Correlation, BigGIM_90_v1.TCGA_LGG_Pvalue, BigGIM_v1.TCGA_LGG_Correlation, BigGIM_v1.TCGA_LGG_Pvalue, CRC_70_v1.TCGA_LGG_Correlation, CRC_70_v1.TCGA_LGG_Pvalue, CRC_80_v1.TCGA_LGG_Correlation, CRC_80_v1.TCGA_LGG_Pvalue, CRC_90_v1.TCGA_LGG_Correlation, CRC_90_v1.TCGA_LGG_Pvalue, CRC_v1.TCGA_LGG_Correlation, CRC_v1.TCGA_LGG_Pvalue, FA_70_v1.TCGA_LGG_Correlation, FA_70_v1.TCGA_LGG_Pvalue, FA_80_v1.TCGA_LGG_Correlation, FA_80_v1.TCGA_LGG_Pvalue, FA_90_v1.TCGA_LGG_Correlation, FA_90_v1.TCGA_LGG_Pvalue, FA_v1.TCGA_LGG_Correlation, FA_v1.TCGA_LGG_Pvalue
#
# Substudy name: UCS
# Substudy description: Uterine Carcinosarcoma
# Table.column list: BigGIM_70_v1.TCGA_UCS_Correlation, BigGIM_70_v1.TCGA_UCS_Pvalue, BigGIM_80_v1.TCGA_UCS_Correlation, BigGIM_80_v1.TCGA_UCS_Pvalue, BigGIM_90_v1.TCGA_UCS_Correlation, BigGIM_90_v1.TCGA_UCS_Pvalue, BigGIM_v1.TCGA_UCS_Correlation, BigGIM_v1.TCGA_UCS_Pvalue, CRC_70_v1.TCGA_UCS_Correlation, CRC_70_v1.TCGA_UCS_Pvalue, CRC_80_v1.TCGA_UCS_Correlation, CRC_80_v1.TCGA_UCS_Pvalue, CRC_90_v1.TCGA_UCS_Correlation, CRC_90_v1.TCGA_UCS_Pvalue, CRC_v1.TCGA_UCS_Correlation, CRC_v1.TCGA_UCS_Pvalue, FA_70_v1.TCGA_UCS_Correlation, FA_70_v1.TCGA_UCS_Pvalue, FA_80_v1.TCGA_UCS_Correlation, FA_80_v1.TCGA_UCS_Pvalue, FA_90_v1.TCGA_UCS_Correlation, FA_90_v1.TCGA_UCS_Pvalue, FA_v1.TCGA_UCS_Correlation, FA_v1.TCGA_UCS_Pvalue
#
# Substudy name: UVM
# Substudy description: Uveal Melanoma
# Table.column list: BigGIM_70_v1.TCGA_UVM_Correlation, BigGIM_70_v1.TCGA_UVM_Pvalue, BigGIM_80_v1.TCGA_UVM_Correlation, BigGIM_80_v1.TCGA_UVM_Pvalue, BigGIM_90_v1.TCGA_UVM_Correlation, BigGIM_90_v1.TCGA_UVM_Pvalue, BigGIM_v1.TCGA_UVM_Correlation, BigGIM_v1.TCGA_UVM_Pvalue, CRC_70_v1.TCGA_UVM_Correlation, CRC_70_v1.TCGA_UVM_Pvalue, CRC_80_v1.TCGA_UVM_Correlation, CRC_80_v1.TCGA_UVM_Pvalue, CRC_90_v1.TCGA_UVM_Correlation, CRC_90_v1.TCGA_UVM_Pvalue, CRC_v1.TCGA_UVM_Correlation, CRC_v1.TCGA_UVM_Pvalue, FA_70_v1.TCGA_UVM_Correlation, FA_70_v1.TCGA_UVM_Pvalue, FA_80_v1.TCGA_UVM_Correlation, FA_80_v1.TCGA_UVM_Pvalue, FA_90_v1.TCGA_UVM_Correlation, FA_90_v1.TCGA_UVM_Pvalue, FA_v1.TCGA_UVM_Correlation, FA_v1.TCGA_UVM_Pvalue
#
# Substudy name: BLCA
# Substudy description: Bladder Urothelial Carcinoma
# Table.column list: BigGIM_70_v1.TCGA_BLCA_Correlation, BigGIM_70_v1.TCGA_BLCA_Pvalue, BigGIM_80_v1.TCGA_BLCA_Correlation, BigGIM_80_v1.TCGA_BLCA_Pvalue, BigGIM_90_v1.TCGA_BLCA_Correlation, BigGIM_90_v1.TCGA_BLCA_Pvalue, BigGIM_v1.TCGA_BLCA_Correlation, BigGIM_v1.TCGA_BLCA_Pvalue, CRC_70_v1.TCGA_BLCA_Correlation, CRC_70_v1.TCGA_BLCA_Pvalue, CRC_80_v1.TCGA_BLCA_Correlation, CRC_80_v1.TCGA_BLCA_Pvalue, CRC_90_v1.TCGA_BLCA_Correlation, CRC_90_v1.TCGA_BLCA_Pvalue, CRC_v1.TCGA_BLCA_Correlation, CRC_v1.TCGA_BLCA_Pvalue, FA_70_v1.TCGA_BLCA_Correlation, FA_70_v1.TCGA_BLCA_Pvalue, FA_80_v1.TCGA_BLCA_Correlation, FA_80_v1.TCGA_BLCA_Pvalue, FA_90_v1.TCGA_BLCA_Correlation, FA_90_v1.TCGA_BLCA_Pvalue, FA_v1.TCGA_BLCA_Correlation, FA_v1.TCGA_BLCA_Pvalue
#
# Substudy name: BRCA
# Substudy description: Breast invasive carcinoma
# Table.column list: BigGIM_70_v1.TCGA_BRCA_Correlation, BigGIM_70_v1.TCGA_BRCA_Pvalue, BigGIM_80_v1.TCGA_BRCA_Correlation, BigGIM_80_v1.TCGA_BRCA_Pvalue, BigGIM_90_v1.TCGA_BRCA_Correlation, BigGIM_90_v1.TCGA_BRCA_Pvalue, BigGIM_v1.TCGA_BRCA_Correlation, BigGIM_v1.TCGA_BRCA_Pvalue, CRC_70_v1.TCGA_BRCA_Correlation, CRC_70_v1.TCGA_BRCA_Pvalue, CRC_80_v1.TCGA_BRCA_Correlation, CRC_80_v1.TCGA_BRCA_Pvalue, CRC_90_v1.TCGA_BRCA_Correlation, CRC_90_v1.TCGA_BRCA_Pvalue, CRC_v1.TCGA_BRCA_Correlation, CRC_v1.TCGA_BRCA_Pvalue, FA_70_v1.TCGA_BRCA_Correlation, FA_70_v1.TCGA_BRCA_Pvalue, FA_80_v1.TCGA_BRCA_Correlation, FA_80_v1.TCGA_BRCA_Pvalue, FA_90_v1.TCGA_BRCA_Correlation, FA_90_v1.TCGA_BRCA_Pvalue, FA_v1.TCGA_BRCA_Correlation, FA_v1.TCGA_BRCA_Pvalue
#
# Substudy name: CESC
# Substudy description: Cervical squamous cell carcinoma and endocervical adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_CESC_Correlation, BigGIM_70_v1.TCGA_CESC_Pvalue, BigGIM_80_v1.TCGA_CESC_Correlation, BigGIM_80_v1.TCGA_CESC_Pvalue, BigGIM_90_v1.TCGA_CESC_Correlation, BigGIM_90_v1.TCGA_CESC_Pvalue, BigGIM_v1.TCGA_CESC_Correlation, BigGIM_v1.TCGA_CESC_Pvalue, CRC_70_v1.TCGA_CESC_Correlation, CRC_70_v1.TCGA_CESC_Pvalue, CRC_80_v1.TCGA_CESC_Correlation, CRC_80_v1.TCGA_CESC_Pvalue, CRC_90_v1.TCGA_CESC_Correlation, CRC_90_v1.TCGA_CESC_Pvalue, CRC_v1.TCGA_CESC_Correlation, CRC_v1.TCGA_CESC_Pvalue, FA_70_v1.TCGA_CESC_Correlation, FA_70_v1.TCGA_CESC_Pvalue, FA_80_v1.TCGA_CESC_Correlation, FA_80_v1.TCGA_CESC_Pvalue, FA_90_v1.TCGA_CESC_Correlation, FA_90_v1.TCGA_CESC_Pvalue, FA_v1.TCGA_CESC_Correlation, FA_v1.TCGA_CESC_Pvalue
#
# Substudy name: CHOL
# Substudy description: Cholangiocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_CHOL_Correlation, BigGIM_70_v1.TCGA_CHOL_Pvalue, BigGIM_80_v1.TCGA_CHOL_Correlation, BigGIM_80_v1.TCGA_CHOL_Pvalue, BigGIM_90_v1.TCGA_CHOL_Correlation, BigGIM_90_v1.TCGA_CHOL_Pvalue, BigGIM_v1.TCGA_CHOL_Correlation, BigGIM_v1.TCGA_CHOL_Pvalue, CRC_70_v1.TCGA_CHOL_Correlation, CRC_70_v1.TCGA_CHOL_Pvalue, CRC_80_v1.TCGA_CHOL_Correlation, CRC_80_v1.TCGA_CHOL_Pvalue, CRC_90_v1.TCGA_CHOL_Correlation, CRC_90_v1.TCGA_CHOL_Pvalue, CRC_v1.TCGA_CHOL_Correlation, CRC_v1.TCGA_CHOL_Pvalue, FA_70_v1.TCGA_CHOL_Correlation, FA_70_v1.TCGA_CHOL_Pvalue, FA_80_v1.TCGA_CHOL_Correlation, FA_80_v1.TCGA_CHOL_Pvalue, FA_90_v1.TCGA_CHOL_Correlation, FA_90_v1.TCGA_CHOL_Pvalue, FA_v1.TCGA_CHOL_Correlation, FA_v1.TCGA_CHOL_Pvalue
#
# Substudy name: COAD
# Substudy description: Colon adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_COAD_Correlation, BigGIM_70_v1.TCGA_COAD_Pvalue, BigGIM_80_v1.TCGA_COAD_Correlation, BigGIM_80_v1.TCGA_COAD_Pvalue, BigGIM_90_v1.TCGA_COAD_Correlation, BigGIM_90_v1.TCGA_COAD_Pvalue, BigGIM_v1.TCGA_COAD_Correlation, BigGIM_v1.TCGA_COAD_Pvalue, CRC_70_v1.TCGA_COAD_Correlation, CRC_70_v1.TCGA_COAD_Pvalue, CRC_80_v1.TCGA_COAD_Correlation, CRC_80_v1.TCGA_COAD_Pvalue, CRC_90_v1.TCGA_COAD_Correlation, CRC_90_v1.TCGA_COAD_Pvalue, CRC_v1.TCGA_COAD_Correlation, CRC_v1.TCGA_COAD_Pvalue, FA_70_v1.TCGA_COAD_Correlation, FA_70_v1.TCGA_COAD_Pvalue, FA_80_v1.TCGA_COAD_Correlation, FA_80_v1.TCGA_COAD_Pvalue, FA_90_v1.TCGA_COAD_Correlation, FA_90_v1.TCGA_COAD_Pvalue, FA_v1.TCGA_COAD_Correlation, FA_v1.TCGA_COAD_Pvalue
#
# Substudy name: DLBC
# Substudy description: Lymphoid Neoplasm Diffuse Large B-cell Lymphoma
# Table.column list: BigGIM_70_v1.TCGA_DLBC_Correlation, BigGIM_70_v1.TCGA_DLBC_Pvalue, BigGIM_80_v1.TCGA_DLBC_Correlation, BigGIM_80_v1.TCGA_DLBC_Pvalue, BigGIM_90_v1.TCGA_DLBC_Correlation, BigGIM_90_v1.TCGA_DLBC_Pvalue, BigGIM_v1.TCGA_DLBC_Correlation, BigGIM_v1.TCGA_DLBC_Pvalue, CRC_70_v1.TCGA_DLBC_Correlation, CRC_70_v1.TCGA_DLBC_Pvalue, CRC_80_v1.TCGA_DLBC_Correlation, CRC_80_v1.TCGA_DLBC_Pvalue, CRC_90_v1.TCGA_DLBC_Correlation, CRC_90_v1.TCGA_DLBC_Pvalue, CRC_v1.TCGA_DLBC_Correlation, CRC_v1.TCGA_DLBC_Pvalue, FA_70_v1.TCGA_DLBC_Correlation, FA_70_v1.TCGA_DLBC_Pvalue, FA_80_v1.TCGA_DLBC_Correlation, FA_80_v1.TCGA_DLBC_Pvalue, FA_90_v1.TCGA_DLBC_Correlation, FA_90_v1.TCGA_DLBC_Pvalue, FA_v1.TCGA_DLBC_Correlation, FA_v1.TCGA_DLBC_Pvalue
#
# Substudy name: ESCA
# Substudy description: Esophageal carcinoma
# Table.column list: BigGIM_70_v1.TCGA_ESCA_Correlation, BigGIM_70_v1.TCGA_ESCA_Pvalue, BigGIM_80_v1.TCGA_ESCA_Correlation, BigGIM_80_v1.TCGA_ESCA_Pvalue, BigGIM_90_v1.TCGA_ESCA_Correlation, BigGIM_90_v1.TCGA_ESCA_Pvalue, BigGIM_v1.TCGA_ESCA_Correlation, BigGIM_v1.TCGA_ESCA_Pvalue, CRC_70_v1.TCGA_ESCA_Correlation, CRC_70_v1.TCGA_ESCA_Pvalue, CRC_80_v1.TCGA_ESCA_Correlation, CRC_80_v1.TCGA_ESCA_Pvalue, CRC_90_v1.TCGA_ESCA_Correlation, CRC_90_v1.TCGA_ESCA_Pvalue, CRC_v1.TCGA_ESCA_Correlation, CRC_v1.TCGA_ESCA_Pvalue, FA_70_v1.TCGA_ESCA_Correlation, FA_70_v1.TCGA_ESCA_Pvalue, FA_80_v1.TCGA_ESCA_Correlation, FA_80_v1.TCGA_ESCA_Pvalue, FA_90_v1.TCGA_ESCA_Correlation, FA_90_v1.TCGA_ESCA_Pvalue, FA_v1.TCGA_ESCA_Correlation, FA_v1.TCGA_ESCA_Pvalue
#
# Substudy name: HNSC
# Substudy description: Head and Neck squamous cell carcinoma
# Table.column list: BigGIM_70_v1.TCGA_HNSC_Correlation, BigGIM_70_v1.TCGA_HNSC_Pvalue, BigGIM_80_v1.TCGA_HNSC_Correlation, BigGIM_80_v1.TCGA_HNSC_Pvalue, BigGIM_90_v1.TCGA_HNSC_Correlation, BigGIM_90_v1.TCGA_HNSC_Pvalue, BigGIM_v1.TCGA_HNSC_Correlation, BigGIM_v1.TCGA_HNSC_Pvalue, CRC_70_v1.TCGA_HNSC_Correlation, CRC_70_v1.TCGA_HNSC_Pvalue, CRC_80_v1.TCGA_HNSC_Correlation, CRC_80_v1.TCGA_HNSC_Pvalue, CRC_90_v1.TCGA_HNSC_Correlation, CRC_90_v1.TCGA_HNSC_Pvalue, CRC_v1.TCGA_HNSC_Correlation, CRC_v1.TCGA_HNSC_Pvalue, FA_70_v1.TCGA_HNSC_Correlation, FA_70_v1.TCGA_HNSC_Pvalue, FA_80_v1.TCGA_HNSC_Correlation, FA_80_v1.TCGA_HNSC_Pvalue, FA_90_v1.TCGA_HNSC_Correlation, FA_90_v1.TCGA_HNSC_Pvalue, FA_v1.TCGA_HNSC_Correlation, FA_v1.TCGA_HNSC_Pvalue
#
# Substudy name: KICH
# Substudy description: Kidney Chromophobe
# Table.column list: BigGIM_70_v1.TCGA_KICH_Correlation, BigGIM_70_v1.TCGA_KICH_Pvalue, BigGIM_80_v1.TCGA_KICH_Correlation, BigGIM_80_v1.TCGA_KICH_Pvalue, BigGIM_90_v1.TCGA_KICH_Correlation, BigGIM_90_v1.TCGA_KICH_Pvalue, BigGIM_v1.TCGA_KICH_Correlation, BigGIM_v1.TCGA_KICH_Pvalue, CRC_70_v1.TCGA_KICH_Correlation, CRC_70_v1.TCGA_KICH_Pvalue, CRC_80_v1.TCGA_KICH_Correlation, CRC_80_v1.TCGA_KICH_Pvalue, CRC_90_v1.TCGA_KICH_Correlation, CRC_90_v1.TCGA_KICH_Pvalue, CRC_v1.TCGA_KICH_Correlation, CRC_v1.TCGA_KICH_Pvalue, FA_70_v1.TCGA_KICH_Correlation, FA_70_v1.TCGA_KICH_Pvalue, FA_80_v1.TCGA_KICH_Correlation, FA_80_v1.TCGA_KICH_Pvalue, FA_90_v1.TCGA_KICH_Correlation, FA_90_v1.TCGA_KICH_Pvalue, FA_v1.TCGA_KICH_Correlation, FA_v1.TCGA_KICH_Pvalue
#
# Substudy name: KIRC
# Substudy description: Kidney renal clear cell carcinoma
# Table.column list: BigGIM_70_v1.TCGA_KIRC_Correlation, BigGIM_70_v1.TCGA_KIRC_Pvalue, BigGIM_80_v1.TCGA_KIRC_Correlation, BigGIM_80_v1.TCGA_KIRC_Pvalue, BigGIM_90_v1.TCGA_KIRC_Correlation, BigGIM_90_v1.TCGA_KIRC_Pvalue, BigGIM_v1.TCGA_KIRC_Correlation, BigGIM_v1.TCGA_KIRC_Pvalue, CRC_70_v1.TCGA_KIRC_Correlation, CRC_70_v1.TCGA_KIRC_Pvalue, CRC_80_v1.TCGA_KIRC_Correlation, CRC_80_v1.TCGA_KIRC_Pvalue, CRC_90_v1.TCGA_KIRC_Correlation, CRC_90_v1.TCGA_KIRC_Pvalue, CRC_v1.TCGA_KIRC_Correlation, CRC_v1.TCGA_KIRC_Pvalue, FA_70_v1.TCGA_KIRC_Correlation, FA_70_v1.TCGA_KIRC_Pvalue, FA_80_v1.TCGA_KIRC_Correlation, FA_80_v1.TCGA_KIRC_Pvalue, FA_90_v1.TCGA_KIRC_Correlation, FA_90_v1.TCGA_KIRC_Pvalue, FA_v1.TCGA_KIRC_Correlation, FA_v1.TCGA_KIRC_Pvalue
#
# Substudy name: KIRP
# Substudy description: Kidney renal papillary cell carcinoma
# Table.column list: BigGIM_70_v1.TCGA_KIRP_Correlation, BigGIM_70_v1.TCGA_KIRP_Pvalue, BigGIM_80_v1.TCGA_KIRP_Correlation, BigGIM_80_v1.TCGA_KIRP_Pvalue, BigGIM_90_v1.TCGA_KIRP_Correlation, BigGIM_90_v1.TCGA_KIRP_Pvalue, BigGIM_v1.TCGA_KIRP_Correlation, BigGIM_v1.TCGA_KIRP_Pvalue, CRC_70_v1.TCGA_KIRP_Correlation, CRC_70_v1.TCGA_KIRP_Pvalue, CRC_80_v1.TCGA_KIRP_Correlation, CRC_80_v1.TCGA_KIRP_Pvalue, CRC_90_v1.TCGA_KIRP_Correlation, CRC_90_v1.TCGA_KIRP_Pvalue, CRC_v1.TCGA_KIRP_Correlation, CRC_v1.TCGA_KIRP_Pvalue, FA_70_v1.TCGA_KIRP_Correlation, FA_70_v1.TCGA_KIRP_Pvalue, FA_80_v1.TCGA_KIRP_Correlation, FA_80_v1.TCGA_KIRP_Pvalue, FA_90_v1.TCGA_KIRP_Correlation, FA_90_v1.TCGA_KIRP_Pvalue, FA_v1.TCGA_KIRP_Correlation, FA_v1.TCGA_KIRP_Pvalue
#
# Substudy name: LAML
# Substudy description: Acute Myeloid Leukemia
# Table.column list: BigGIM_70_v1.TCGA_LAML_Correlation, BigGIM_70_v1.TCGA_LAML_Pvalue, BigGIM_80_v1.TCGA_LAML_Correlation, BigGIM_80_v1.TCGA_LAML_Pvalue, BigGIM_90_v1.TCGA_LAML_Correlation, BigGIM_90_v1.TCGA_LAML_Pvalue, BigGIM_v1.TCGA_LAML_Correlation, BigGIM_v1.TCGA_LAML_Pvalue, CRC_70_v1.TCGA_LAML_Correlation, CRC_70_v1.TCGA_LAML_Pvalue, CRC_80_v1.TCGA_LAML_Correlation, CRC_80_v1.TCGA_LAML_Pvalue, CRC_90_v1.TCGA_LAML_Correlation, CRC_90_v1.TCGA_LAML_Pvalue, CRC_v1.TCGA_LAML_Correlation, CRC_v1.TCGA_LAML_Pvalue, FA_70_v1.TCGA_LAML_Correlation, FA_70_v1.TCGA_LAML_Pvalue, FA_80_v1.TCGA_LAML_Correlation, FA_80_v1.TCGA_LAML_Pvalue, FA_90_v1.TCGA_LAML_Correlation, FA_90_v1.TCGA_LAML_Pvalue, FA_v1.TCGA_LAML_Correlation, FA_v1.TCGA_LAML_Pvalue
#
# Substudy name: LIHC
# Substudy description: Liver hepatocellular carcinoma
# Table.column list: BigGIM_70_v1.TCGA_LIHC_Correlation, BigGIM_70_v1.TCGA_LIHC_Pvalue, BigGIM_80_v1.TCGA_LIHC_Correlation, BigGIM_80_v1.TCGA_LIHC_Pvalue, BigGIM_90_v1.TCGA_LIHC_Correlation, BigGIM_90_v1.TCGA_LIHC_Pvalue, BigGIM_v1.TCGA_LIHC_Correlation, BigGIM_v1.TCGA_LIHC_Pvalue, CRC_70_v1.TCGA_LIHC_Correlation, CRC_70_v1.TCGA_LIHC_Pvalue, CRC_80_v1.TCGA_LIHC_Correlation, CRC_80_v1.TCGA_LIHC_Pvalue, CRC_90_v1.TCGA_LIHC_Correlation, CRC_90_v1.TCGA_LIHC_Pvalue, CRC_v1.TCGA_LIHC_Correlation, CRC_v1.TCGA_LIHC_Pvalue, FA_70_v1.TCGA_LIHC_Correlation, FA_70_v1.TCGA_LIHC_Pvalue, FA_80_v1.TCGA_LIHC_Correlation, FA_80_v1.TCGA_LIHC_Pvalue, FA_90_v1.TCGA_LIHC_Correlation, FA_90_v1.TCGA_LIHC_Pvalue, FA_v1.TCGA_LIHC_Correlation, FA_v1.TCGA_LIHC_Pvalue
#
# Substudy name: LUAD
# Substudy description: Lung adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_LUAD_Correlation, BigGIM_70_v1.TCGA_LUAD_Pvalue, BigGIM_80_v1.TCGA_LUAD_Correlation, BigGIM_80_v1.TCGA_LUAD_Pvalue, BigGIM_90_v1.TCGA_LUAD_Correlation, BigGIM_90_v1.TCGA_LUAD_Pvalue, BigGIM_v1.TCGA_LUAD_Correlation, BigGIM_v1.TCGA_LUAD_Pvalue, CRC_70_v1.TCGA_LUAD_Correlation, CRC_70_v1.TCGA_LUAD_Pvalue, CRC_80_v1.TCGA_LUAD_Correlation, CRC_80_v1.TCGA_LUAD_Pvalue, CRC_90_v1.TCGA_LUAD_Correlation, CRC_90_v1.TCGA_LUAD_Pvalue, CRC_v1.TCGA_LUAD_Correlation, CRC_v1.TCGA_LUAD_Pvalue, FA_70_v1.TCGA_LUAD_Correlation, FA_70_v1.TCGA_LUAD_Pvalue, FA_80_v1.TCGA_LUAD_Correlation, FA_80_v1.TCGA_LUAD_Pvalue, FA_90_v1.TCGA_LUAD_Correlation, FA_90_v1.TCGA_LUAD_Pvalue, FA_v1.TCGA_LUAD_Correlation, FA_v1.TCGA_LUAD_Pvalue
#
# Substudy name: LUSC
# Substudy description: Lung squamous cell carcinoma
# Table.column list: BigGIM_70_v1.TCGA_LUSC_Correlation, BigGIM_70_v1.TCGA_LUSC_Pvalue, BigGIM_80_v1.TCGA_LUSC_Correlation, BigGIM_80_v1.TCGA_LUSC_Pvalue, BigGIM_90_v1.TCGA_LUSC_Correlation, BigGIM_90_v1.TCGA_LUSC_Pvalue, BigGIM_v1.TCGA_LUSC_Correlation, BigGIM_v1.TCGA_LUSC_Pvalue, CRC_70_v1.TCGA_LUSC_Correlation, CRC_70_v1.TCGA_LUSC_Pvalue, CRC_80_v1.TCGA_LUSC_Correlation, CRC_80_v1.TCGA_LUSC_Pvalue, CRC_90_v1.TCGA_LUSC_Correlation, CRC_90_v1.TCGA_LUSC_Pvalue, CRC_v1.TCGA_LUSC_Correlation, CRC_v1.TCGA_LUSC_Pvalue, FA_70_v1.TCGA_LUSC_Correlation, FA_70_v1.TCGA_LUSC_Pvalue, FA_80_v1.TCGA_LUSC_Correlation, FA_80_v1.TCGA_LUSC_Pvalue, FA_90_v1.TCGA_LUSC_Correlation, FA_90_v1.TCGA_LUSC_Pvalue, FA_v1.TCGA_LUSC_Correlation, FA_v1.TCGA_LUSC_Pvalue
#
# Substudy name: MESO
# Substudy description: Mesothelioma
# Table.column list: BigGIM_70_v1.TCGA_MESO_Correlation, BigGIM_70_v1.TCGA_MESO_Pvalue, BigGIM_80_v1.TCGA_MESO_Correlation, BigGIM_80_v1.TCGA_MESO_Pvalue, BigGIM_90_v1.TCGA_MESO_Correlation, BigGIM_90_v1.TCGA_MESO_Pvalue, BigGIM_v1.TCGA_MESO_Correlation, BigGIM_v1.TCGA_MESO_Pvalue, CRC_70_v1.TCGA_MESO_Correlation, CRC_70_v1.TCGA_MESO_Pvalue, CRC_80_v1.TCGA_MESO_Correlation, CRC_80_v1.TCGA_MESO_Pvalue, CRC_90_v1.TCGA_MESO_Correlation, CRC_90_v1.TCGA_MESO_Pvalue, CRC_v1.TCGA_MESO_Correlation, CRC_v1.TCGA_MESO_Pvalue, FA_70_v1.TCGA_MESO_Correlation, FA_70_v1.TCGA_MESO_Pvalue, FA_80_v1.TCGA_MESO_Correlation, FA_80_v1.TCGA_MESO_Pvalue, FA_90_v1.TCGA_MESO_Correlation, FA_90_v1.TCGA_MESO_Pvalue, FA_v1.TCGA_MESO_Correlation, FA_v1.TCGA_MESO_Pvalue
#
# Substudy name: PAAD
# Substudy description: Pancreatic adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_PAAD_Correlation, BigGIM_70_v1.TCGA_PAAD_Pvalue, BigGIM_80_v1.TCGA_PAAD_Correlation, BigGIM_80_v1.TCGA_PAAD_Pvalue, BigGIM_90_v1.TCGA_PAAD_Correlation, BigGIM_90_v1.TCGA_PAAD_Pvalue, BigGIM_v1.TCGA_PAAD_Correlation, BigGIM_v1.TCGA_PAAD_Pvalue, CRC_70_v1.TCGA_PAAD_Correlation, CRC_70_v1.TCGA_PAAD_Pvalue, CRC_80_v1.TCGA_PAAD_Correlation, CRC_80_v1.TCGA_PAAD_Pvalue, CRC_90_v1.TCGA_PAAD_Correlation, CRC_90_v1.TCGA_PAAD_Pvalue, CRC_v1.TCGA_PAAD_Correlation, CRC_v1.TCGA_PAAD_Pvalue, FA_70_v1.TCGA_PAAD_Correlation, FA_70_v1.TCGA_PAAD_Pvalue, FA_80_v1.TCGA_PAAD_Correlation, FA_80_v1.TCGA_PAAD_Pvalue, FA_90_v1.TCGA_PAAD_Correlation, FA_90_v1.TCGA_PAAD_Pvalue, FA_v1.TCGA_PAAD_Correlation, FA_v1.TCGA_PAAD_Pvalue
#
# Substudy name: PCPG
# Substudy description: Pheochromocytoma and Paraganglioma
# Table.column list: BigGIM_70_v1.TCGA_PCPG_Correlation, BigGIM_70_v1.TCGA_PCPG_Pvalue, BigGIM_80_v1.TCGA_PCPG_Correlation, BigGIM_80_v1.TCGA_PCPG_Pvalue, BigGIM_90_v1.TCGA_PCPG_Correlation, BigGIM_90_v1.TCGA_PCPG_Pvalue, BigGIM_v1.TCGA_PCPG_Correlation, BigGIM_v1.TCGA_PCPG_Pvalue, CRC_70_v1.TCGA_PCPG_Correlation, CRC_70_v1.TCGA_PCPG_Pvalue, CRC_80_v1.TCGA_PCPG_Correlation, CRC_80_v1.TCGA_PCPG_Pvalue, CRC_90_v1.TCGA_PCPG_Correlation, CRC_90_v1.TCGA_PCPG_Pvalue, CRC_v1.TCGA_PCPG_Correlation, CRC_v1.TCGA_PCPG_Pvalue, FA_70_v1.TCGA_PCPG_Correlation, FA_70_v1.TCGA_PCPG_Pvalue, FA_80_v1.TCGA_PCPG_Correlation, FA_80_v1.TCGA_PCPG_Pvalue, FA_90_v1.TCGA_PCPG_Correlation, FA_90_v1.TCGA_PCPG_Pvalue, FA_v1.TCGA_PCPG_Correlation, FA_v1.TCGA_PCPG_Pvalue
#
# Substudy name: PRAD
# Substudy description: Prostate adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_PRAD_Correlation, BigGIM_70_v1.TCGA_PRAD_Pvalue, BigGIM_80_v1.TCGA_PRAD_Correlation, BigGIM_80_v1.TCGA_PRAD_Pvalue, BigGIM_90_v1.TCGA_PRAD_Correlation, BigGIM_90_v1.TCGA_PRAD_Pvalue, BigGIM_v1.TCGA_PRAD_Correlation, BigGIM_v1.TCGA_PRAD_Pvalue, CRC_70_v1.TCGA_PRAD_Correlation, CRC_70_v1.TCGA_PRAD_Pvalue, CRC_80_v1.TCGA_PRAD_Correlation, CRC_80_v1.TCGA_PRAD_Pvalue, CRC_90_v1.TCGA_PRAD_Correlation, CRC_90_v1.TCGA_PRAD_Pvalue, CRC_v1.TCGA_PRAD_Correlation, CRC_v1.TCGA_PRAD_Pvalue, FA_70_v1.TCGA_PRAD_Correlation, FA_70_v1.TCGA_PRAD_Pvalue, FA_80_v1.TCGA_PRAD_Correlation, FA_80_v1.TCGA_PRAD_Pvalue, FA_90_v1.TCGA_PRAD_Correlation, FA_90_v1.TCGA_PRAD_Pvalue, FA_v1.TCGA_PRAD_Correlation, FA_v1.TCGA_PRAD_Pvalue
#
# Substudy name: READ
# Substudy description: Rectum adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_READ_Correlation, BigGIM_70_v1.TCGA_READ_Pvalue, BigGIM_80_v1.TCGA_READ_Correlation, BigGIM_80_v1.TCGA_READ_Pvalue, BigGIM_90_v1.TCGA_READ_Correlation, BigGIM_90_v1.TCGA_READ_Pvalue, BigGIM_v1.TCGA_READ_Correlation, BigGIM_v1.TCGA_READ_Pvalue, CRC_70_v1.TCGA_READ_Correlation, CRC_70_v1.TCGA_READ_Pvalue, CRC_80_v1.TCGA_READ_Correlation, CRC_80_v1.TCGA_READ_Pvalue, CRC_90_v1.TCGA_READ_Correlation, CRC_90_v1.TCGA_READ_Pvalue, CRC_v1.TCGA_READ_Correlation, CRC_v1.TCGA_READ_Pvalue, FA_70_v1.TCGA_READ_Correlation, FA_70_v1.TCGA_READ_Pvalue, FA_80_v1.TCGA_READ_Correlation, FA_80_v1.TCGA_READ_Pvalue, FA_90_v1.TCGA_READ_Correlation, FA_90_v1.TCGA_READ_Pvalue, FA_v1.TCGA_READ_Correlation, FA_v1.TCGA_READ_Pvalue
#
# Substudy name: SARC
# Substudy description: Sarcoma
# Table.column list: BigGIM_70_v1.TCGA_SARC_Correlation, BigGIM_70_v1.TCGA_SARC_Pvalue, BigGIM_80_v1.TCGA_SARC_Correlation, BigGIM_80_v1.TCGA_SARC_Pvalue, BigGIM_90_v1.TCGA_SARC_Correlation, BigGIM_90_v1.TCGA_SARC_Pvalue, BigGIM_v1.TCGA_SARC_Correlation, BigGIM_v1.TCGA_SARC_Pvalue, CRC_70_v1.TCGA_SARC_Correlation, CRC_70_v1.TCGA_SARC_Pvalue, CRC_80_v1.TCGA_SARC_Correlation, CRC_80_v1.TCGA_SARC_Pvalue, CRC_90_v1.TCGA_SARC_Correlation, CRC_90_v1.TCGA_SARC_Pvalue, CRC_v1.TCGA_SARC_Correlation, CRC_v1.TCGA_SARC_Pvalue, FA_70_v1.TCGA_SARC_Correlation, FA_70_v1.TCGA_SARC_Pvalue, FA_80_v1.TCGA_SARC_Correlation, FA_80_v1.TCGA_SARC_Pvalue, FA_90_v1.TCGA_SARC_Correlation, FA_90_v1.TCGA_SARC_Pvalue, FA_v1.TCGA_SARC_Correlation, FA_v1.TCGA_SARC_Pvalue
#
# Substudy name: SKCM
# Substudy description: Skin Cutaneous Melanoma
# Table.column list: BigGIM_70_v1.TCGA_SKCM_Correlation, BigGIM_70_v1.TCGA_SKCM_Pvalue, BigGIM_80_v1.TCGA_SKCM_Correlation, BigGIM_80_v1.TCGA_SKCM_Pvalue, BigGIM_90_v1.TCGA_SKCM_Correlation, BigGIM_90_v1.TCGA_SKCM_Pvalue, BigGIM_v1.TCGA_SKCM_Correlation, BigGIM_v1.TCGA_SKCM_Pvalue, CRC_70_v1.TCGA_SKCM_Correlation, CRC_70_v1.TCGA_SKCM_Pvalue, CRC_80_v1.TCGA_SKCM_Correlation, CRC_80_v1.TCGA_SKCM_Pvalue, CRC_90_v1.TCGA_SKCM_Correlation, CRC_90_v1.TCGA_SKCM_Pvalue, CRC_v1.TCGA_SKCM_Correlation, CRC_v1.TCGA_SKCM_Pvalue, FA_70_v1.TCGA_SKCM_Correlation, FA_70_v1.TCGA_SKCM_Pvalue, FA_80_v1.TCGA_SKCM_Correlation, FA_80_v1.TCGA_SKCM_Pvalue, FA_90_v1.TCGA_SKCM_Correlation, FA_90_v1.TCGA_SKCM_Pvalue, FA_v1.TCGA_SKCM_Correlation, FA_v1.TCGA_SKCM_Pvalue
#
# Substudy name: STAD
# Substudy description: Stomach adenocarcinoma
# Table.column list: BigGIM_70_v1.TCGA_STAD_Correlation, BigGIM_70_v1.TCGA_STAD_Pvalue, BigGIM_80_v1.TCGA_STAD_Correlation, BigGIM_80_v1.TCGA_STAD_Pvalue, BigGIM_90_v1.TCGA_STAD_Correlation, BigGIM_90_v1.TCGA_STAD_Pvalue, BigGIM_v1.TCGA_STAD_Correlation, BigGIM_v1.TCGA_STAD_Pvalue, CRC_70_v1.TCGA_STAD_Correlation, CRC_70_v1.TCGA_STAD_Pvalue, CRC_80_v1.TCGA_STAD_Correlation, CRC_80_v1.TCGA_STAD_Pvalue, CRC_90_v1.TCGA_STAD_Correlation, CRC_90_v1.TCGA_STAD_Pvalue, CRC_v1.TCGA_STAD_Correlation, CRC_v1.TCGA_STAD_Pvalue, FA_70_v1.TCGA_STAD_Correlation, FA_70_v1.TCGA_STAD_Pvalue, FA_80_v1.TCGA_STAD_Correlation, FA_80_v1.TCGA_STAD_Pvalue, FA_90_v1.TCGA_STAD_Correlation, FA_90_v1.TCGA_STAD_Pvalue, FA_v1.TCGA_STAD_Correlation, FA_v1.TCGA_STAD_Pvalue
#
# Substudy name: TGCT
# Substudy description: Testicular Germ Cell Tumors
# Table.column list: BigGIM_70_v1.TCGA_TGCT_Correlation, BigGIM_70_v1.TCGA_TGCT_Pvalue, BigGIM_80_v1.TCGA_TGCT_Correlation, BigGIM_80_v1.TCGA_TGCT_Pvalue, BigGIM_90_v1.TCGA_TGCT_Correlation, BigGIM_90_v1.TCGA_TGCT_Pvalue, BigGIM_v1.TCGA_TGCT_Correlation, BigGIM_v1.TCGA_TGCT_Pvalue, CRC_70_v1.TCGA_TGCT_Correlation, CRC_70_v1.TCGA_TGCT_Pvalue, CRC_80_v1.TCGA_TGCT_Correlation, CRC_80_v1.TCGA_TGCT_Pvalue, CRC_90_v1.TCGA_TGCT_Correlation, CRC_90_v1.TCGA_TGCT_Pvalue, CRC_v1.TCGA_TGCT_Correlation, CRC_v1.TCGA_TGCT_Pvalue, FA_70_v1.TCGA_TGCT_Correlation, FA_70_v1.TCGA_TGCT_Pvalue, FA_80_v1.TCGA_TGCT_Correlation, FA_80_v1.TCGA_TGCT_Pvalue, FA_90_v1.TCGA_TGCT_Correlation, FA_90_v1.TCGA_TGCT_Pvalue, FA_v1.TCGA_TGCT_Correlation, FA_v1.TCGA_TGCT_Pvalue
#
# Substudy name: THCA
# Substudy description: Thyroid carcinoma
# Table.column list: BigGIM_70_v1.TCGA_THCA_Correlation, BigGIM_70_v1.TCGA_THCA_Pvalue, BigGIM_80_v1.TCGA_THCA_Correlation, BigGIM_80_v1.TCGA_THCA_Pvalue, BigGIM_90_v1.TCGA_THCA_Correlation, BigGIM_90_v1.TCGA_THCA_Pvalue, BigGIM_v1.TCGA_THCA_Correlation, BigGIM_v1.TCGA_THCA_Pvalue, CRC_70_v1.TCGA_THCA_Correlation, CRC_70_v1.TCGA_THCA_Pvalue, CRC_80_v1.TCGA_THCA_Correlation, CRC_80_v1.TCGA_THCA_Pvalue, CRC_90_v1.TCGA_THCA_Correlation, CRC_90_v1.TCGA_THCA_Pvalue, CRC_v1.TCGA_THCA_Correlation, CRC_v1.TCGA_THCA_Pvalue, FA_70_v1.TCGA_THCA_Correlation, FA_70_v1.TCGA_THCA_Pvalue, FA_80_v1.TCGA_THCA_Correlation, FA_80_v1.TCGA_THCA_Pvalue, FA_90_v1.TCGA_THCA_Correlation, FA_90_v1.TCGA_THCA_Pvalue, FA_v1.TCGA_THCA_Correlation, FA_v1.TCGA_THCA_Pvalue
#
# Substudy name: THYM
# Substudy description: Thymoma
# Table.column list: BigGIM_70_v1.TCGA_THYM_Correlation, BigGIM_70_v1.TCGA_THYM_Pvalue, BigGIM_80_v1.TCGA_THYM_Correlation, BigGIM_80_v1.TCGA_THYM_Pvalue, BigGIM_90_v1.TCGA_THYM_Correlation, BigGIM_90_v1.TCGA_THYM_Pvalue, BigGIM_v1.TCGA_THYM_Correlation, BigGIM_v1.TCGA_THYM_Pvalue, CRC_70_v1.TCGA_THYM_Correlation, CRC_70_v1.TCGA_THYM_Pvalue, CRC_80_v1.TCGA_THYM_Correlation, CRC_80_v1.TCGA_THYM_Pvalue, CRC_90_v1.TCGA_THYM_Correlation, CRC_90_v1.TCGA_THYM_Pvalue, CRC_v1.TCGA_THYM_Correlation, CRC_v1.TCGA_THYM_Pvalue, FA_70_v1.TCGA_THYM_Correlation, FA_70_v1.TCGA_THYM_Pvalue, FA_80_v1.TCGA_THYM_Correlation, FA_80_v1.TCGA_THYM_Pvalue, FA_90_v1.TCGA_THYM_Correlation, FA_90_v1.TCGA_THYM_Pvalue, FA_v1.TCGA_THYM_Correlation, FA_v1.TCGA_THYM_Pvalue
#
# Substudy name: UCEC
# Substudy description: Uterine Corpus Endometrial Carcinoma
# Table.column list: BigGIM_70_v1.TCGA_UCEC_Correlation, BigGIM_70_v1.TCGA_UCEC_Pvalue, BigGIM_80_v1.TCGA_UCEC_Correlation, BigGIM_80_v1.TCGA_UCEC_Pvalue, BigGIM_90_v1.TCGA_UCEC_Correlation, BigGIM_90_v1.TCGA_UCEC_Pvalue, BigGIM_v1.TCGA_UCEC_Correlation, BigGIM_v1.TCGA_UCEC_Pvalue, CRC_70_v1.TCGA_UCEC_Correlation, CRC_70_v1.TCGA_UCEC_Pvalue, CRC_80_v1.TCGA_UCEC_Correlation, CRC_80_v1.TCGA_UCEC_Pvalue, CRC_90_v1.TCGA_UCEC_Correlation, CRC_90_v1.TCGA_UCEC_Pvalue, CRC_v1.TCGA_UCEC_Correlation, CRC_v1.TCGA_UCEC_Pvalue, FA_70_v1.TCGA_UCEC_Correlation, FA_70_v1.TCGA_UCEC_Pvalue, FA_80_v1.TCGA_UCEC_Correlation, FA_80_v1.TCGA_UCEC_Pvalue, FA_90_v1.TCGA_UCEC_Correlation, FA_90_v1.TCGA_UCEC_Pvalue, FA_v1.TCGA_UCEC_Correlation, FA_v1.TCGA_UCEC_Pvalue

# %% [markdown]
# ### what an error looks like

# %%
try:
    ta = get('metadata/study/%s' % ('TCSG'))
    jprint(studies)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# 404 Client Error: NOT FOUND for url: http://biggim.ncats.io/api/metadata/study/TCSG
#
# {
#   "status": "error",
#   "message": "[TCSG] not a valid study"
# }
# None

# %% [markdown]
# <a id="metadata_tables"></a>
# ### Get all tables

# %%
try:
    tables = get('/metadata/table')
    jprint(tables)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# [
#   {
#     "num_rows": 51090886,
#     "default": true,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 146013971730,
#     "name": "BigGIM_70_v1"
#   },
#   {
#     "num_rows": 14210893,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 41062787154,
#     "name": "BigGIM_80_v1"
#   },
#   {
#     "num_rows": 1173151,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 3389718425,
#     "name": "BigGIM_90_v1"
#   },
#   {
#     "num_rows": 411827180,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions.",
#     "num_bytes": 931457211953,
#     "name": "BigGIM_v1"
#   },
#   {
#     "num_rows": 8604,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 26765474,
#     "name": "CRC_70_v1"
#   },
#   {
#     "num_rows": 2100,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 6536954,
#     "name": "CRC_80_v1"
#   },
#   {
#     "num_rows": 132,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 412721,
#     "name": "CRC_90_v1"
#   },
#   {
#     "num_rows": 27028,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020).",
#     "num_bytes": 83725184,
#     "name": "CRC_v1"
#   },
#   {
#     "num_rows": 161445,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#     "num_bytes": 482470699,
#     "name": "FA_70_v1"
#   },
#   {
#     "num_rows": 53392,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8",
#     "num_bytes": 160188930,
#     "name": "FA_80_v1"
#   },
#   {
#     "num_rows": 4151,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9",
#     "num_bytes": 12467222,
#     "name": "FA_90_v1"
#   },
#   {
#     "num_rows": 587730,
#     "default": false,
#     "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes.",
#     "num_bytes": 1519402925,
#     "name": "FA_v1"
#   }
# ]

# %%
for table in tables:
    print("Table name: %s" % table['name'])
    print("Table description: %s" % table['description'])
    print
# Out:
# Table name: BigGIM_70_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7
#
# Table name: BigGIM_80_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.8
#
# Table name: BigGIM_90_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.9
#
# Table name: BigGIM_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions.
#
# Table name: CRC_70_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7
#
# Table name: CRC_80_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8
#
# Table name: CRC_90_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020), and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9
#
# Table name: CRC_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where both genes in a pair are from the list of 233 core transcription factors (PMCID: PMC4772020).
#
# Table name: FA_70_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.7
#
# Table name: FA_80_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.8
#
# Table name: FA_90_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes, and where at least one of the TCGA or GTEx absolute correlations is higher than 0.9
#
# Table name: FA_v1
# Table description: Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of genes in a pair is one of the 20 FA genes.

# %% [markdown]
# <a id="metadata_table"></a>
# ### Get one table
#
# The default table

# %%
default_table = [t for t in tables if t['default'] == True][0]['name']
print("Default table name: %s" % default_table)
# Out:
# Default table name: BigGIM_70_v1

# %%
try:
    table = get('/metadata/table/%s' %  (default_table,))
    jprint(table)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# {
#   "description": "Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7",
#   "default": true,
#   "num_bytes": 146013971730,
#   "num_rows": 51090886,
#   "columns": [
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Adrenocortical carcinoma",
#         "name": "ACC",
#         "cell_of_origin": "adrenocortical carcinoma cell"
#       },
#       "name": "TCGA_ACC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Adrenocortical carcinoma",
#         "name": "ACC",
#         "cell_of_origin": "adrenocortical carcinoma cell"
#       },
#       "name": "TCGA_ACC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Bladder Urothelial Carcinoma",
#         "name": "BLCA",
#         "cell_of_origin": "urinary bladder cancer cell"
#       },
#       "name": "TCGA_BLCA_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - urinary bladder cancer cell|1 - urinary bladder|2 - bladder|2 - urinary system|2 - urinary tract|3 - viscus|3 - urogenital system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Bladder Urothelial Carcinoma",
#         "name": "BLCA",
#         "cell_of_origin": "urinary bladder cancer cell"
#       },
#       "name": "TCGA_BLCA_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Breast invasive carcinoma",
#         "name": "BRCA",
#         "cell_of_origin": "breast cancer cell"
#       },
#       "name": "TCGA_BRCA_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - breast cancer cell|1 - breast|1 - adenocarcinoma cell|2 - thorax|2 - female reproductive gland|2 - excretory gland|2 - carcinoma cell|3 - trunk|3 - female reproductive system|3 - endocrine gland|3 - gland|3 - epithelioma cell|4 - whole body|4 - reproductive system|4 - epithelial cell|5 - animal|5 - urogenital system|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Breast invasive carcinoma",
#         "name": "BRCA",
#         "cell_of_origin": "breast cancer cell"
#       },
#       "name": "TCGA_BRCA_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#         "name": "CESC",
#         "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell"
#       },
#       "name": "TCGA_CESC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - cervical adenocarcinoma cell|0 - cervical squamous cell carcinoma cell|1 - cervical carcinoma cell|1 - adenocarcinoma cell|1 - squamous cell carcinoma cell|2 - uterine cervix|2 - carcinoma cell|2 - squamous epithelium|3 - uterus|3 - epithelioma cell|3 - epithelium|4 - internal female genital organ|4 - epithelial cell|4 - integument|5 - female reproductive system|5 - whole body|6 - reproductive system|6 - animal|7 - urogenital system|7 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Cervical squamous cell carcinoma and endocervical adenocarcinoma",
#         "name": "CESC",
#         "cell_of_origin": "cervical adenocarcinoma cell,cervical squamous cell carcinoma cell"
#       },
#       "name": "TCGA_CESC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Cholangiocarcinoma",
#         "name": "CHOL",
#         "cell_of_origin": "cholangiocarcinoma cell"
#       },
#       "name": "TCGA_CHOL_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - cholangiocarcinoma cell|1 - bile duct epithelium|1 - bile duct|2 - biliary epithelium|2 - liver|3 - epithelium|3 - digestive gland|3 - viscus|4 - integument|4 - endocrine gland|4 - whole body|5 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Cholangiocarcinoma",
#         "name": "CHOL",
#         "cell_of_origin": "cholangiocarcinoma cell"
#       },
#       "name": "TCGA_CHOL_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - colorectal adenocarcinoma cell|1 - rectal cancer cell|1 - colonic cancer cell|1 - adenocarcinoma cell|2 - rectum|2 - gastrointestinal cancer cell|2 - colon|2 - carcinoma cell|3 - large intestine|3 - colorectum|3 - gastrointestinal tract|3 - epithelioma cell|4 - intestine|4 - alimentary canal|4 - epithelial cell|5 - viscus|5 - epithelium|6 - whole body|6 - integument|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Colon adenocarcinoma",
#         "name": "COAD",
#         "cell_of_origin": "colorectal adenocarcinoma cell"
#       },
#       "name": "TCGA_COAD_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - colorectal adenocarcinoma cell|1 - rectal cancer cell|1 - colonic cancer cell|1 - adenocarcinoma cell|2 - rectum|2 - gastrointestinal cancer cell|2 - colon|2 - carcinoma cell|3 - large intestine|3 - colorectum|3 - gastrointestinal tract|3 - epithelioma cell|4 - intestine|4 - alimentary canal|4 - epithelial cell|5 - viscus|5 - epithelium|6 - whole body|6 - integument|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Colon adenocarcinoma",
#         "name": "COAD",
#         "cell_of_origin": "colorectal adenocarcinoma cell"
#       },
#       "name": "TCGA_COAD_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#         "name": "DLBC",
#         "cell_of_origin": "diffuse large B-cell lymphoma cell"
#       },
#       "name": "TCGA_DLBC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#         "name": "DLBC",
#         "cell_of_origin": "diffuse large B-cell lymphoma cell"
#       },
#       "name": "TCGA_DLBC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - esophageal cancer cell|1 - esophagus|2 - alimentary canal|3 - viscus|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Esophageal carcinoma",
#         "name": "ESCA",
#         "cell_of_origin": "esophageal cancer cell"
#       },
#       "name": "TCGA_ESCA_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - esophageal cancer cell|1 - esophagus|2 - alimentary canal|3 - viscus|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Esophageal carcinoma",
#         "name": "ESCA",
#         "cell_of_origin": "esophageal cancer cell"
#       },
#       "name": "TCGA_ESCA_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Glioblastoma multiforme",
#         "name": "GBM",
#         "cell_of_origin": "glioblastoma cell"
#       },
#       "name": "TCGA_GBM_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - glioblastoma cell|1 - astrocytoma cell|2 - glioma cell|2 - astrocyte|3 - glia|3 - glial cell|3 - astroglial cell|3 - macroglia|3 - astroblast|4 - spinal cord|4 - brain|4 - astroglia|4 - neuroblast|5 - central nervous system|5 - head|5 - embryo|6 - nervous system|6 - whole body|6 - embryonic structure|7 - animal|7 - organism form|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Glioblastoma multiforme",
#         "name": "GBM",
#         "cell_of_origin": "glioblastoma cell"
#       },
#       "name": "TCGA_GBM_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - head and neck cancer cell|1 - head|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Head and Neck squamous cell carcinoma",
#         "name": "HNSC",
#         "cell_of_origin": "head and neck cancer cell"
#       },
#       "name": "TCGA_HNSC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - head and neck cancer cell|1 - head|2 - whole body|3 - animal|4 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Head and Neck squamous cell carcinoma",
#         "name": "HNSC",
#         "cell_of_origin": "head and neck cancer cell"
#       },
#       "name": "TCGA_HNSC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - chromophobe renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney Chromophobe",
#         "name": "KICH",
#         "cell_of_origin": "chromophobe renal cell carcinoma cell"
#       },
#       "name": "TCGA_KICH_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - chromophobe renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney Chromophobe",
#         "name": "KICH",
#         "cell_of_origin": "chromophobe renal cell carcinoma cell"
#       },
#       "name": "TCGA_KICH_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - renal clear cell|0 - renal cell carcinoma cell|1 - renal tubule|1 - kidney cancer cell|1 - adenocarcinoma cell|2 - nephron|2 - kidney|2 - carcinoma cell|3 - excretory gland|3 - viscus|3 - urinary system|3 - urinary tract|3 - epithelioma cell|4 - gland|4 - whole body|4 - urogenital system|4 - epithelial cell|5 - animal|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney renal clear cell carcinoma",
#         "name": "KIRC",
#         "cell_of_origin": "renal clear cell,renal cell carcinoma cell"
#       },
#       "name": "TCGA_KIRC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - renal clear cell|0 - renal cell carcinoma cell|1 - renal tubule|1 - kidney cancer cell|1 - adenocarcinoma cell|2 - nephron|2 - kidney|2 - carcinoma cell|3 - excretory gland|3 - viscus|3 - urinary system|3 - urinary tract|3 - epithelioma cell|4 - gland|4 - whole body|4 - urogenital system|4 - epithelial cell|5 - animal|5 - epithelium|6 - tissues, cell types and enzyme sources|6 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney renal clear cell carcinoma",
#         "name": "KIRC",
#         "cell_of_origin": "renal clear cell,renal cell carcinoma cell"
#       },
#       "name": "TCGA_KIRC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - papillary renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney renal papillary cell carcinoma",
#         "name": "KIRP",
#         "cell_of_origin": "papillary renal cell carcinoma cell"
#       },
#       "name": "TCGA_KIRP_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - papillary renal cell carcinoma cell|1 - renal cell carcinoma cell|2 - kidney cancer cell|2 - adenocarcinoma cell|3 - kidney|3 - carcinoma cell|4 - excretory gland|4 - viscus|4 - urinary system|4 - urinary tract|4 - epithelioma cell|5 - gland|5 - whole body|5 - urogenital system|5 - epithelial cell|6 - animal|6 - epithelium|7 - tissues, cell types and enzyme sources|7 - integument",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Kidney renal papillary cell carcinoma",
#         "name": "KIRP",
#         "cell_of_origin": "papillary renal cell carcinoma cell"
#       },
#       "name": "TCGA_KIRP_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - acute myeloid leukemia cell|1 - myeloid leukemia cell|2 - leukemia cell|3 - leukocyte|3 - blood cancer cell|4 - hematopoietic cell|5 - blood|6 - hematopoietic system|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Acute Myeloid Leukemia",
#         "name": "LAML",
#         "cell_of_origin": "acute myeloid leukemia cell"
#       },
#       "name": "TCGA_LAML_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - acute myeloid leukemia cell|1 - myeloid leukemia cell|2 - leukemia cell|3 - leukocyte|3 - blood cancer cell|4 - hematopoietic cell|5 - blood|6 - hematopoietic system|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Acute Myeloid Leukemia",
#         "name": "LAML",
#         "cell_of_origin": "acute myeloid leukemia cell"
#       },
#       "name": "TCGA_LAML_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Brain Lower Grade Glioma",
#         "name": "LGG",
#         "cell_of_origin": "glioma cell"
#       },
#       "name": "TCGA_LGG_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - glioma cell|1 - glia|1 - glial cell|2 - spinal cord|2 - brain|3 - central nervous system|3 - head|4 - nervous system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Brain Lower Grade Glioma",
#         "name": "LGG",
#         "cell_of_origin": "glioma cell"
#       },
#       "name": "TCGA_LGG_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - liver cancer cell|0 - hepatocyte|1 - liver|2 - digestive gland|2 - viscus|3 - endocrine gland|3 - whole body|4 - gland|4 - animal|5 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Liver hepatocellular carcinoma",
#         "name": "LIHC",
#         "cell_of_origin": "liver cancer cell,hepatocyte"
#       },
#       "name": "TCGA_LIHC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - liver cancer cell|0 - hepatocyte|1 - liver|2 - digestive gland|2 - viscus|3 - endocrine gland|3 - whole body|4 - gland|4 - animal|5 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Liver hepatocellular carcinoma",
#         "name": "LIHC",
#         "cell_of_origin": "liver cancer cell,hepatocyte"
#       },
#       "name": "TCGA_LIHC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - lung adenocarcinoma cell|1 - carcinoma cell|1 - non-small cell lung cancer cell|2 - epithelioma cell|2 - bronchogenic carcinoma cell|3 - epithelial cell|3 - lung cancer cell|4 - epithelium|4 - lung|5 - integument|5 - respiratory system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lung adenocarcinoma",
#         "name": "LUAD",
#         "cell_of_origin": "lung adenocarcinoma cell"
#       },
#       "name": "TCGA_LUAD_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - lung adenocarcinoma cell|1 - carcinoma cell|1 - non-small cell lung cancer cell|2 - epithelioma cell|2 - bronchogenic carcinoma cell|3 - epithelial cell|3 - lung cancer cell|4 - epithelium|4 - lung|5 - integument|5 - respiratory system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lung adenocarcinoma",
#         "name": "LUAD",
#         "cell_of_origin": "lung adenocarcinoma cell"
#       },
#       "name": "TCGA_LUAD_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - lung squamous cell carcinoma cell|1 - lung cancer cell|2 - lung|3 - respiratory system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lung squamous cell carcinoma",
#         "name": "LUSC",
#         "cell_of_origin": "lung squamous cell carcinoma cell"
#       },
#       "name": "TCGA_LUSC_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "P-value (-log10)",
#       "substudy": {
#         "tissue_hierarchy": "0 - lung squamous cell carcinoma cell|1 - lung cancer cell|2 - lung|3 - respiratory system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Lung squamous cell carcinoma",
#         "name": "LUSC",
#         "cell_of_origin": "lung squamous cell carcinoma cell"
#       },
#       "name": "TCGA_LUSC_Pvalue"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Spearman Rank Correlation Coefficient",
#       "substudy": {
#         "tissue_hierarchy": "0 - mesothelioma cell|1 - mesothelium|2 - mesoderm|2 - squamous epithelium|2 - coelom|3 - germ layer|3 - epithelium|4 - embryo|4 - integument|5 - embryonic structure|5 - whole body|6 - organism form|6 - animal|7 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "TCGA",
#           "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#         },
#         "description": "Mesothelioma",
#         "name": "MESO",
#         "cell_of_origin": "mesothelioma cell"
#       },
#       "name": "TCGA_MESO_Correlation"
#     },
#     {
#       "datatype": "FLOAT",
# ...
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - uterus|1 - internal female genital organ|2 - female reproductive system|3 - reproductive system|4 - urogenital system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "uterus",
#         "name": "uterus",
#         "cell_of_origin": "uterus"
#       },
#       "name": "GIANT_uterus_KnownFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - uterus|1 - internal female genital organ|2 - female reproductive system|3 - reproductive system|4 - urogenital system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "uterus",
#         "name": "uterus",
#         "cell_of_origin": "uterus"
#       },
#       "name": "GIANT_uterus_ProbabilityOfFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vascular endothelial cell|1 - vascular endothelium|1 - endothelial cell|2 - endothelium|2 - blood vessel endothelium|2 - heart|3 - epithelium|3 - blood vessel|3 - cardiovascular system|4 - integument|4 - vascular system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vascular_endothelial_cell",
#         "name": "vascular_endothelial_cell",
#         "cell_of_origin": "vascular endothelial cell"
#       },
#       "name": "GIANT_vascular_endothelial_cell_KnownFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vascular endothelial cell|1 - vascular endothelium|1 - endothelial cell|2 - endothelium|2 - blood vessel endothelium|2 - heart|3 - epithelium|3 - blood vessel|3 - cardiovascular system|4 - integument|4 - vascular system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vascular_endothelial_cell",
#         "name": "vascular_endothelial_cell",
#         "cell_of_origin": "vascular endothelial cell"
#       },
#       "name": "GIANT_vascular_endothelial_cell_ProbabilityOfFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vascular endothelium|1 - endothelium|2 - epithelium|3 - integument|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vascular_endothelium",
#         "name": "vascular_endothelium",
#         "cell_of_origin": "vascular endothelium"
#       },
#       "name": "GIANT_vascular_endothelium_KnownFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vascular endothelium|1 - endothelium|2 - epithelium|3 - integument|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vascular_endothelium",
#         "name": "vascular_endothelium",
#         "cell_of_origin": "vascular endothelium"
#       },
#       "name": "GIANT_vascular_endothelium_ProbabilityOfFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Binary Call For Known Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vermiform appendix|1 - cecum|2 - large intestine|2 - ileocecum|3 - intestine|4 - gastrointestinal tract|5 - alimentary canal|6 - viscus|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vermiform_appendix",
#         "name": "vermiform_appendix",
#         "cell_of_origin": "vermiform appendix"
#       },
#       "name": "GIANT_vermiform_appendix_KnownFunctionalInteraction"
#     },
#     {
#       "datatype": "FLOAT",
#       "interactions_type": "Bayesian Posterior Probability Of Functional Interaction",
#       "substudy": {
#         "tissue_hierarchy": "0 - vermiform appendix|1 - cecum|2 - large intestine|2 - ileocecum|3 - intestine|4 - gastrointestinal tract|5 - alimentary canal|6 - viscus|7 - whole body|8 - animal|9 - tissues, cell types and enzyme sources",
#         "study": {
#           "name": "GIANT",
#           "description": "Genetic Investigation of ANthropometric Traits\n        The Genetic Investigation of ANthropometric Traits (GIANT) consortium is an international collaboration that seeks to identify genetic loci that modulate human body size and shape, including height and measures of obesity. The GIANT consortium is a collaboration between investigators from many different groups, institutions, countries, and studies, and the results represent their combined efforts. The primary approach has been meta-analysis of genome-wide association data and other large-scale genetic data sets. Anthropometric traits that have been studied by GIANT include body mass index (BMI), height, and traits related to waist circumference (such as waist-hip ratio adjusted for BMI, or WHRadjBMI). Thus far, the GIANT consortium has identified common genetic variants at hundreds of loci that are associated with anthropometric traits.\n\n        http://portals.broadinstitute.org/collaboration/giant/index.php/GIANT_consortium\n        "
#         },
#         "description": "vermiform_appendix",
#         "name": "vermiform_appendix",
#         "cell_of_origin": "vermiform appendix"
#       },
#       "name": "GIANT_vermiform_appendix_ProbabilityOfFunctionalInteraction"
#     },
#     {
#       "datatype": "BOOLEAN",
#       "interactions_type": "Boolean Flag For Interaction",
#       "substudy": {
#         "tissue_hierarchy": null,
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "description": "Default",
#         "name": "Default",
#         "cell_of_origin": null
#       },
#       "name": "BioGRID_Interaction"
#     },
#     {
#       "datatype": "STRING",
#       "interactions_type": "Experimental System Used",
#       "substudy": {
#         "tissue_hierarchy": null,
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "description": "Default",
#         "name": "Default",
#         "cell_of_origin": null
#       },
#       "name": "BioGRID_Experimental_System"
#     },
#     {
#       "datatype": "STRING",
#       "interactions_type": "Experimental System Type",
#       "substudy": {
#         "tissue_hierarchy": null,
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "description": "Default",
#         "name": "Default",
#         "cell_of_origin": null
#       },
#       "name": "BioGRID_Experimental_System_Type"
#     },
#     {
#       "datatype": "STRING",
#       "interactions_type": "High or Low Throughput Measurement",
#       "substudy": {
#         "tissue_hierarchy": null,
#         "study": {
#           "name": "BioGRID",
#           "description": " Biological General Repository for Interaction Datasets\n        BioGRID is an interaction repository with data compiled through comprehensive curation efforts.\n\n        https://thebiogrid.org/\n        "
#         },
#         "description": "Default",
#         "name": "Default",
#         "cell_of_origin": null
#       },
#       "name": "BioGRID_Throughput"
#     }
#   ],
#   "name": "BigGIM_70_v1"
# }

# %% [markdown]
# ### First 10 columns in default table

# %%
for column in table['columns'][:10]:
    print("Column name: %s" % column['name'])
    print("Column interaction: %s" % column['interactions_type'])
    print("Column data type: %s" % column["datatype"])
    print
# Out:
# Column name: TCGA_ACC_Correlation
# Column interaction: Spearman Rank Correlation Coefficient
# Column data type: FLOAT
#
# Column name: TCGA_ACC_Pvalue
# Column interaction: P-value (-log10)
# Column data type: FLOAT
#
# Column name: TCGA_BLCA_Correlation
# Column interaction: Spearman Rank Correlation Coefficient
# Column data type: FLOAT
#
# Column name: TCGA_BLCA_Pvalue
# Column interaction: P-value (-log10)
# Column data type: FLOAT
#
# Column name: TCGA_BRCA_Correlation
# Column interaction: Spearman Rank Correlation Coefficient
# Column data type: FLOAT
#
# Column name: TCGA_BRCA_Pvalue
# Column interaction: P-value (-log10)
# Column data type: FLOAT
#
# Column name: TCGA_CESC_Correlation
# Column interaction: Spearman Rank Correlation Coefficient
# Column data type: FLOAT
#
# Column name: TCGA_CESC_Pvalue
# Column interaction: P-value (-log10)
# Column data type: FLOAT
#
# Column name: TCGA_CHOL_Correlation
# Column interaction: Spearman Rank Correlation Coefficient
# Column data type: FLOAT
#
# Column name: TCGA_CHOL_Pvalue
# Column interaction: P-value (-log10)
# Column data type: FLOAT

# %% [markdown]
# <a id="metadata_column"></a>
# ### Get a single column

# %%
try:
    column = get('/metadata/table/%s/column/%s' %  (default_table,'TCGA_ACC_Correlation'))
    jprint(column)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# {
#   "datatype": "FLOAT",
#   "interactions_type": "Spearman Rank Correlation Coefficient",
#   "substudy": {
#     "tissue_hierarchy": "0 - adrenocortical carcinoma cell|1 - adrenal cortex|2 - adrenal gland|3 - viscus|3 - endocrine gland|4 - whole body|4 - gland|5 - animal|6 - tissues, cell types and enzyme sources",
#     "study": {
#       "name": "TCGA",
#       "description": " The Cancer Genome Atlas\n        The Cancer Genome Atlas (TCGA) is a collaboration between the National Cancer Institute (NCI) and the National Human Genome Research Institute (NHGRI) that has generated comprehensive, multi-dimensional maps of the key genomic changes in 33 types of cancer. The TCGA dataset, comprising more than two petabytes of genomic data, has been made publically available, and this genomic information helps the cancer research community to improve the prevention, diagnosis, and treatment of cancer.\n\n        https://cancergenome.nih.gov/\n        "
#     },
#     "description": "Adrenocortical carcinoma",
#     "name": "ACC",
#     "cell_of_origin": "adrenocortical carcinoma cell"
#   },
#   "name": "TCGA_ACC_Correlation"
# }

# %% [markdown]
# <a id="metadata_tissues"></a>
# ### List all tissues

# %%
tissues = get('metadata/tissue')
jprint(tissues)
# Out:
# {
#   "tissues": [
#     "B_lymphocyte",
#     "B_lymphoma_cell_line",
#     "T_lymphocyte",
#     "acute_myeloid_leukemia_cell",
#     "adenocarcinoma_cell",
#     "adipose_tissue",
#     "adrenal_cortex",
#     "adrenal_gland",
#     "adrenal_gland_cancer_cell",
#     "adrenocortical_carcinoma_cell",
#     "adult_stem_cell",
#     "alimentary_canal",
#     "amygdala",
#     "animal",
#     "aorta",
#     "artery",
#     "astroblast",
#     "astrocyte",
#     "astrocytoma_cell",
#     "astroglia",
#     "astroglial_cell",
#     "avian_pallium",
#     "basal_ganglion",
#     "basophil",
#     "bile_duct",
#     "bile_duct_epithelium",
#     "biliary_epithelium",
#     "bladder",
#     "blast_cell",
#     "blastomere",
#     "blastula",
#     "blood",
#     "blood_cancer_cell",
#     "blood_plasma",
#     "blood_platelet",
#     "blood_vessel",
#     "blood_vessel_endothelium",
#     "bone",
#     "bone_cancer_cell",
#     "bone_marrow",
#     "bone_marrow_cell",
#     "brain",
#     "brain_stem",
#     "brain_ventricle",
#     "breast",
#     "breast_cancer_cell",
#     "breast_epithelium",
#     "bronchial_epithelial_cell",
#     "bronchial_epithelium",
#     "bronchoalveolar_system",
#     "bronchogenic_carcinoma_cell",
#     "bronchus",
#     "capsular_epithelium",
#     "carcinoid_cell",
#     "carcinoma_cell",
#     "cardiac_muscle",
#     "cardiovascular_system",
#     "cartilage",
#     "caudate_nucleus",
#     "caudate_putamen",
#     "cecum",
#     "cell_culture",
#     "central_nervous_system",
#     "cerebellar_cortex",
#     "cerebellum",
#     "cerebral_cortex",
#     "cerebral_hemisphere",
#     "cerebral_lobe",
#     "cervical_adenocarcinoma_cell",
#     "cervical_carcinoma_cell",
#     "cervical_squamous_cell_carcinoma_cell",
#     "cholangiocarcinoma_cell",
#     "chondrocyte",
#     "choroid",
#     "chromophobe_renal_cell_carcinoma_cell",
#     "cochlea",
#     "coelom",
#     "colon",
#     "colonic_cancer_cell",
#     "colorectal_adenocarcinoma_cell",
#     "colorectum",
#     "connecting_stalk",
#     "connective_tissue",
#     "cornea",
#     "corpus_callosum",
#     "corpus_luteum",
#     "corpus_striatum",
#     "culture_condition",
#     "culture_condition_CD8__cell",
#     "culture_condition_antigen_presenting_cell",
#     "dendritic_cell",
#     "dentate_gyrus",
#     "diencephalon",
#     "diffuse_large_B_cell_lymphoma_cell",
#     "digestive_gland",
#     "duodenum",
#     "ear",
#     "ectoderm",
#     "embryo",
#     "embryonic_structure",
#     "endocrine_gland",
#     "endocrine_pancreas",
#     "endometrioid_carcinoma_cell",
#     "endothelial_cell",
#     "endothelium",
#     "eosinophil",
#     "epidermal_cell",
#     "epidermis",
#     "epithelial_cell",
#     "epithelioma_cell",
#     "epithelium",
#     "esophageal_cancer_cell",
#     "esophagus",
#     "excretory_gland",
#     "exocrine_gland",
#     "exocrine_pancreas",
#     "eye",
#     "female_reproductive_gland",
#     "female_reproductive_system",
#     "fetus",
#     "fibroblast",
#     "forebrain",
#     "frontal_lobe",
#     "gametocyte",
#     "ganglion",
#     "gastric_adenocarcinoma_cell",
#     "gastric_cancer_cell",
#     "gastrointestinal_cancer_cell",
#     "gastrointestinal_tract",
#     "germ_cell",
#     "germ_layer",
#     "gland",
#     "glia",
#     "glial_cell",
#     "glioblastoma_cell",
#     "glioma_cell",
#     "glomerular_epithelium",
#     "gonad",
#     "granulocyte",
#     "hair_follicle",
#     "head",
#     "head_and_neck_cancer_cell",
#     "heart",
#     "hematopoietic_cell",
#     "hematopoietic_stem_cell",
#     "hematopoietic_system",
#     "hepatocyte",
#     "hindbrain",
#     "hippocampus",
#     "hypophysis",
#     "hypothalamus",
#     "ileocecum",
#     "ileum",
#     "immune_system",
#     "inner_ear",
#     "integument",
#     "internal_female_genital_organ",
#     "internal_male_genital_organ",
#     "intestinal_mucosa",
#     "intestine",
#     "jejunum",
#     "keratinocyte",
#     "kidney",
#     "kidney_cancer_cell",
#     "large_granular_lymphocyte",
#     "large_intestine",
#     "lateral_ventricle",
#     "lens",
#     "leukemia_cell",
#     "leukocyte",
#     "limbic_system",
#     "liver",
#     "liver_cancer_cell",
#     "locus_ceruleus",
#     "lung",
#     "lung_adenocarcinoma_cell",
#     "lung_cancer_cell",
#     "lung_squamous_cell_carcinoma_cell",
#     "lymph_node",
#     "lymphocyte",
#     "lymphoid_cell",
#     "lymphoid_cell_line",
#     "lymphoid_tissue",
#     "lymphoma_cell",
#     "lymphoma_cell_line",
#     "macroglia",
#     "macrophage",
#     "male_reproductive_gland",
#     "male_reproductive_system",
#     "mammary_epithelium",
#     "mammary_gland",
#     "marrow_cell",
#     "mast_cell",
#     "mature_ovarian_follicle",
#     "medulla_oblongata",
#     "megakaryoblast",
#     "megakaryocyte",
#     "melanocyte",
#     "melanoma_cell",
#     "mesoderm",
#     "mesothelioma_cell",
#     "mesothelium",
#     "metencephalon",
#     "midbrain",
#     "monocyte",
#     "mononuclear_cell",
#     "mononuclear_phagocyte",
#     "morula",
#     "mouth",
#     "mucosa",
#     "muscle",
#     "muscular_system",
#     "myelencephalon",
#     "myeloid_leukemia_cell",
#     "myeloid_progenitor_cell",
#     "myometrium",
#     "natural_killer_cell",
#     "neck",
#     "neostriatum",
#     "nephron",
#     "nerve",
#     "nervous_system",
#     "neural_crest",
#     "neural_crest_cell",
#     "neural_plate",
#     "neuroblast",
#     "neuroendocrine_cell",
#     "neuroendocrine_tumor_cell",
#     "neuron",
#     "neutrophil",
#     "non_small_cell_lung_cancer_cell",
#     "nucleus_accumbens",
#     "nucleus_lentiformis",
#     "null_cell",
#     "occipital_lobe",
#     "occipital_pole",
#     "organism_form",
#     "osteoblast",
#     "osteogenic_cell",
#     "other_source",
#     "ovarian_follicle",
#     "ovarian_serous_carcinoma_cell",
#     "ovary",
#     "ovary_cancer_cell",
#     "oviduct",
#     "pancreas",
#     "pancreatic_duct",
#     "pancreatic_ductal_adenocarcinoma_cell",
#     "pancreatic_ductal_carcinoma_cell",
#     "pancreatic_islet",
#     "papillary_renal_cell_carcinoma_cell",
#     "parietal_lobe",
#     "periosteum",
#     "peripheral_blood",
#     "peripheral_nervous_system",
#     "phagocyte",
#     "pheochromocytoma_cell",
#     "placenta",
#     "podocyte",
#     "pons",
#     "pre_T_lymphocyte",
#     "preosteoblast",
#     "primary_spermatocyte",
#     "prostate_adenocarcinoma_cell",
#     "prostate_gland",
#     "rectal_adenocarcinoma_cell",
#     "rectal_cancer_cell",
#     "rectum",
#     "renal_cell_carcinoma_cell",
#     "renal_clear_cell",
#     "renal_corpuscle",
#     "renal_glomerular_capsule",
#     "renal_glomerulus",
#     "renal_tubule",
#     "reproductive_system",
#     "respiratory_epithelium",
#     "respiratory_system",
#     "retina",
#     "salivary_gland",
#     "sarcoma_cell",
#     "secondary_spermatocyte",
#     "semen",
#     "sense_organ",
#     "serum",
#     "skeletal_muscle",
#     "skeletal_muscle_cancer_cell",
#     "skeletal_muscle_cell",
#     "skeletal_system",
#     "skin",
#     "skin_cancer_cell",
#     "skin_fibroblast",
#     "small_intestine",
#     "smooth_muscle",
#     "spermatid",
#     "spermatocyte",
#     "spermatogonium",
#     "spinal_cord",
#     "spleen",
#     "squamous_cell_carcinoma_cell",
#     "squamous_epithelium",
#     "stomach",
#     "stratum_spinosum",
#     "substantia_nigra",
#     "subthalamic_nucleus",
#     "tear_gland",
#     "telencephalon",
#     "temporal_lobe",
#     "testicular_cancer_cell",
#     "testis",
#     "thalamus",
#     "thorax",
#     "throat",
#     "thymic_cancer_cell",
#     "thymocyte",
#     "thymoma_cell",
#     "thymus",
#     "thyroid_cancer_cell",
#     "thyroid_gland",
#     "tissues__cell_types_and_enzyme_sources",
#     "tonsil",
#     "tooth",
#     "trachea",
#     "trophoblast",
#     "trunk",
#     "umbilical_cord",
#     "umbilical_vein",
#     "umbilical_vein_endothelial_cell",
#     "umbilical_vein_endothelium",
#     "urinary_bladder",
#     "urinary_bladder_cancer_cell",
#     "urinary_system",
#     "urinary_tract",
#     "uroepithelium",
#     "urogenital_system",
#     "uterine_cancer_cell",
#     "uterine_cervix",
#     "uterine_endometrium",
#     "uterine_sarcoma_cell",
#     "uterus",
#     "uveal_melanoma_cell",
#     "vascular_endothelial_cell",
#     "vascular_endothelium",
#     "vascular_system",
#     "vermiform_appendix",
#     "vertebrate_muscular_system",
#     "vestibular_labyrinth",
#     "vestibular_system",
#     "viscus",
#     "whole_body",
#     "zygote"
#   ]
# }

# %% [markdown]
# <a id="metadata_tissue"></a>
# ### Get single tissue

# %%
substudies = get('metadata/tissue/%s' % ("lymphoid_cell",))
jprint(substudies)
# Out:
# {
#   "tissue": "lymphoid_cell",
#   "substudies": [
#     {
#       "tissue_hierarchy": "0 - natural killer cell|1 - null cell|1 - large granular lymphocyte|2 - lymphocyte|3 - leukocyte|3 - lymphoid cell|4 - hematopoietic cell|4 - lymphoid tissue|5 - blood|5 - immune system|5 - hematopoietic system|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "natural_killer_cell",
#       "name": "natural_killer_cell",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_natural_killer_cell_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         }
#       ],
#       "cell_of_origin": "natural killer cell"
#     },
#     {
#       "tissue_hierarchy": "0 - B-lymphocyte|1 - lymphocyte|2 - leukocyte|2 - lymphoid cell|3 - hematopoietic cell|3 - lymphoid tissue|4 - blood|4 - immune system|4 - hematopoietic system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "b_lymphocyte",
#       "name": "b_lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_b_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         }
#       ],
#       "cell_of_origin": "B-lymphocyte"
#     },
#     {
#       "tissue_hierarchy": "0 - T-lymphocyte|1 - lymphocyte|2 - leukocyte|2 - lymphoid cell|3 - hematopoietic cell|3 - lymphoid tissue|4 - blood|4 - immune system|4 - hematopoietic system|5 - whole body|6 - animal|7 - tissues, cell types and enzyme sources",
#       "description": "t_lymphocyte",
#       "name": "t_lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_t_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         }
#       ],
#       "cell_of_origin": "T-lymphocyte"
#     },
#     {
#       "tissue_hierarchy": "0 - thymocyte|1 - thymus|1 - pre-T-lymphocyte|2 - immune system|2 - thorax|2 - endocrine gland|2 - lymphoid tissue|2 - T-lymphocyte|3 - whole body|3 - trunk|3 - gland|3 - hematopoietic system|3 - lymphocyte|4 - animal|4 - leukocyte|4 - lymphoid cell|5 - tissues, cell types and enzyme sources|5 - hematopoietic cell|6 - blood",
#       "description": "thymocyte",
#       "name": "thymocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_thymocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_thymocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         }
#       ],
#       "cell_of_origin": "thymocyte"
#     },
#     {
#       "tissue_hierarchy": "0 - diffuse large B-cell lymphoma cell|1 - B-lymphoma cell line|2 - lymphoma cell line|3 - lymphoid cell line|3 - lymphoma cell|4 - lymphoid cell|4 - blood cancer cell|4 - lymphoid tissue|5 - hematopoietic cell|5 - immune system|5 - hematopoietic system|6 - blood|6 - whole body|7 - animal|8 - tissues, cell types and enzyme sources",
#       "description": "Lymphoid Neoplasm Diffuse Large B-cell Lymphoma",
#       "name": "DLBC",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_DLBC_Correlation",
#           "interactions_type": "Spearman Rank Correlation Coefficient"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "TCGA_DLBC_Pvalue",
#           "interactions_type": "P-value (-log10)"
#         }
#       ],
#       "cell_of_origin": "diffuse large B-cell lymphoma cell"
#     },
#     {
#       "tissue_hierarchy": "0 - lymphocyte|1 - leukocyte|1 - lymphoid cell|2 - hematopoietic cell|2 - lymphoid tissue|3 - blood|3 - immune system|3 - hematopoietic system|4 - whole body|5 - animal|6 - tissues, cell types and enzyme sources",
#       "description": "lymphocyte",
#       "name": "lymphocyte",
#       "columns": [
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_70_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_80_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_90_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "BigGIM_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_70_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_80_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_90_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "CRC_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_70_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_80_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_90_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_lymphocyte_KnownFunctionalInteraction",
#           "interactions_type": "Binary Call For Known Functional Interaction"
#         },
#         {
#           "datatype": "FLOAT",
#           "table": {
#             "name": "FA_v1"
#           },
#           "name": "GIANT_lymphocyte_ProbabilityOfFunctionalInteraction",
#           "interactions_type": "Bayesian Posterior Probability Of Functional Interaction"
#         }
#       ],
#       "cell_of_origin": "lymphocyte"
#     }
#   ]
# }

# %% [markdown]
# <a id="query_examples"></a>
# ## Query examples

# %% [markdown]
# <a id="query_simple"></a>
# ### Simple predefined query

# %%
example_query = {
      # The table to select from.
      "table": default_table, 
      # A comma delimited list of column names to return.
      "columns": "TCGA_GBM_Correlation,TCGA_GBM_Pvalue,GTEx_Brain_Correlation,GTEx_Brain_Pvalue", 
      # A comma delimited list of Entrez gene ids to select.
      "ids1": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,5722,1111,112,3333",
      # Entrez gene ids to select. If not given, the query selects any gene related to a gene in ids 1. 
      # If given, the query only selects relations that contain a gene in ids1 and a gene in ids2.
      "ids2": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,3333,1111,112,3333", 
      # The type of join made on restrictions. Either intersect or union
      "restriction_join": "union", 
      # The maximum number of rows to return
      "restriction_gt": "TCGA_GBM_Correlation,.2, GTEx_Brain_Correlation,.2", 
      # A list of pairs of values column name,value with which to restrict 
      # the results of the query to rows where the value of the column is greater than the given value.
      "restriction_lt": "TCGA_GBM_Pvalue,.05, GTEx_Brain_Pvalue,.01",
      # The maximum number of rows to return.
      "limit": 10000 
}
print("Query request:")
jprint(example_query)
try:
    query_submit = get('interactions/query', data=example_query)
    jprint(query_submit)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# Query request:
# {
#   "restriction_join": "union",
#   "limit": 10000,
#   "restriction_gt": "TCGA_GBM_Correlation,.2, GTEx_Brain_Correlation,.2",
#   "restriction_lt": "TCGA_GBM_Pvalue,.05, GTEx_Brain_Pvalue,.01",
#   "table": "BigGIM_70_v1",
#   "ids2": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,3333,1111,112,3333",
#   "columns": "TCGA_GBM_Correlation,TCGA_GBM_Pvalue,GTEx_Brain_Correlation,GTEx_Brain_Pvalue",
#   "ids1": "5111,6996,57697,6815,889,7112,2176,1019,5888,5706,5722,1111,112,3333"
# }
# {
#   "status": "submitted",
#   "request_id": "107b518b-6e7b-4024-a664-0b0638fc9028"
# }

# %% [markdown]
# <a id="query_status"></a>
# ### Check the status of the simple predefined query

# %%
import time
try:
    while True:
        query_status = get('interactions/query/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(1)
            print "Checking again"
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())
# Out:
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "107b518b-6e7b-4024-a664-0b0638fc9028"
# }
# Checking again
# {
#   "status": "complete",
#   "rows": 54,
#   "processed_data": "0B",
#   "request_id": "107b518b-6e7b-4024-a664-0b0638fc9028",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/107b518b-6e7b-4024-a664-0b0638fc9028000000000000.csv"
#   ],
#   "size": "2.72 KB"
# }

# %% [markdown]
# <a id="query_results"></a>
# ### Get the results as dataframe

# %%
import pandas
result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
result
# Out:
#               GPID  Gene1  Gene2  TCGA_GBM_Correlation  TCGA_GBM_Pvalue  \
# 0   58880000057697  57697   5888                0.4545             6.74
# 1   58880000007112   7112   5888                0.7331            20.76
# 2   57060000057697  57697   5706                0.2880             2.85
# 3   57060000006996   6996   5706                0.4229             5.83
# 4   57060000006815   6815   5706                0.4009             5.24
# 5   57060000007112   7112   5706                0.1942             1.47
# 6   69960000007112   7112   6996                0.4991             8.18
# 7   69960000057697  57697   6996                0.3473             3.99
# 8   11110000006815   6815   1111               -0.1197             0.72
# 9   11110000007112   7112   1111                0.7026            18.42
# 10  11110000002176   2176   1111                0.7111            19.04
# 11  11110000057697  57697   1111                0.5158             8.78
# 12  11110000005888   5888   1111                0.6530            15.20
# 13  11110000005111   5111   1111                0.6174            13.23
# 14   1120000002176   2176    112                0.2329             1.98
# 15   1120000000889    889    112                0.1300             0.80
# 16   1120000005111   5111    112               -0.2945             2.96
# 17   1120000001111   1111    112               -0.0028             0.01
# 18   1120000007112   7112    112               -0.0171             0.07
# 19   1120000005888   5888    112                0.0019             0.01
# 20   1120000001019   1019    112               -0.2191             1.79
# 21   8890000006996   6996    889                0.0360             0.16
# 22   8890000005111   5111    889                0.0933             0.51
# 23   8890000007112   7112    889                0.0584             0.28
# 24   8890000006815   6815    889                0.0928             0.50
# 25   8890000005706   5706    889               -0.0382             0.17
# 26   8890000002176   2176    889                0.1706             1.20
# 27   8890000001019   1019    889               -0.0116             0.05
# 28   8890000057697  57697    889                0.2489             2.21
# 29  21760000007112   7112   2176                0.5989            12.30
# 30  21760000005888   5888   2176                0.5430             9.83
# 31  21760000006815   6815   2176               -0.2341             2.00
# 32  21760000057697  57697   2176                0.5478            10.02
# 33  21760000006996   6996   2176                0.0334             0.14
# 34  21760000005111   5111   2176                0.3506             4.06
# 35  68150000057697  57697   6815                0.2524             2.27
# 36  68150000007112   7112   6815               -0.1275             0.78
# 37  68150000006996   6996   6815                0.0446             0.20
# 38  71120000057697  57697   7112                0.6052            12.61
# 39  51110000006815   6815   5111                0.0325             0.14
# 40  51110000005706   5706   5111                0.3278             3.59
# 41  51110000007112   7112   5111                0.6164            13.18
# 42  51110000057697  57697   5111                0.3341             3.72
# 43  51110000005888   5888   5111                0.5431             9.83
# 44  51110000006996   6996   5111                0.2376             2.05
# 45  10190000006996   6996   1019                0.3294             3.62
# 46  10190000005706   5706   1019                0.2200             1.80
# 47  10190000005111   5111   1019                0.4983             8.16
# 48  10190000006815   6815   1019               -0.1305             0.81
# 49  10190000057697  57697   1019                0.2391             2.07
# 50  10190000005888   5888   1019                0.5021             8.29
# 51  10190000001111   1111   1019                0.4050             5.35
# 52  10190000007112   7112   1019                0.5341             9.48
# 53  10190000002176   2176   1019                0.3024             3.10
#
#     GTEx_Brain_Correlation  GTEx_Brain_Pvalue
# 0                   0.6227             135.34
# 1                   0.5651             106.40
# 2                   0.7209             201.65
# 3                   0.6719             165.37
# 4                   0.4885              75.74
# 5                   0.7647             241.41
# 6                   0.6653             161.01
# 7                   0.8152             299.70
# 8                   0.2608              20.30
# 9                  -0.0678               1.79
# 10                 -0.0246               0.42
# 11                  0.1124               4.19
# 12                 -0.0131               0.19
# 13                  0.1711               9.00
# 14                  0.6387             144.51
# 15                  0.7565             233.37
# 16                  0.5295              91.17
# 17                 -0.2528              19.09
# 18                  0.7397             217.76
# 19                  0.5560             102.35
# 20                  0.4109              51.74
# 21                  0.8080             290.39
# 22                  0.7489             226.12
# 23                  0.8263             315.00
# 24                  0.6010             123.74
# 25                  0.8163             301.20
# 26                  0.7029             187.50
# 27                  0.4816              73.38
# 28                  0.8262             314.88
# 29                  0.7369             215.25
# 30                  0.5403              95.62
# 31                  0.5937             120.03
# 32                  0.5941             120.24
# 33                  0.6541             153.85
# 34                  0.7075             191.00
# 35                  0.5279              90.55
# 36                  0.6142             130.73
# 37                  0.5802             113.44
# 38                  0.6201             133.93
# 39                  0.7579             234.72
# 40                  0.7406             218.54
# 41                  0.7789             256.21
# 42                  0.6808             171.41
# 43                  0.5510             100.17
# 44                  0.6761             168.19
# 45                  0.4184              53.80
# 46                  0.4353              58.63
# 47                  0.6435             147.39
# 48                  0.5813             113.97
# 49                  0.3888              45.98
# 50                  0.3958              47.76
# 51                  0.2117              13.49
# 52                  0.4414              60.44
# 53                  0.5253              89.52

# %% [markdown]
# <a id="full_example"></a>
# # Full example
#
# Lets get relationships for a certain tissue where any tissue related correlation has a pvalue < .05
#
#  Assume we are interested in issues in lymphoid tissues

# %%
# get lymphoid substudies
import numpy as np
query_status = None
# get lymphoid substudies
substudies = get('metadata/tissue/%s' % ("lymphoid_tissue",))

# we only want things in a specific table, we'll use the default
table = get('/metadata/table/%s' %  (default_table,))

print("Using table %s\n%s" % (table['name'], table['description']))

# grab pvalue columns
pvalue_columns = []
column_names = []
for ss in substudies['substudies']:
    for column in ss['columns']:
        # only if column is from our table
        if column['table']['name'] == table['name']:
            # add column to select
            column_names.append(column['name'])
            if column['interactions_type'] == 'P-value (-log10)':
                #add pvalue to where
                pvalue_columns.append(column['name'])
 
# grab columns with lower pvalues
pv = []
for p in pvalue_columns:
    pv.append(p)
    pv.append(str(abs(np.log10(.05))))
query_arg = {}
query_arg['table'] = table['name']
query_arg['columns'] = ','.join(sorted(column_names))
if len(pv):
    query_arg['restriction_gt'] = ','.join(pv)
# get if any of the lymphoid columns have 
query_arg['restriction_join'] = 'union'
query_arg['limit'] = 1000000
print "The constructed query."
jprint(query_arg)

print("Submitting query request.")
try:
    query_submit = get('interactions/query', data=query_arg)
    print("Query request response.")
    jprint(query_submit)
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())

print("Check query status")
try:
    ctr = 1
    while True:
        
        query_status = get('interactions/query/status/%s'% (query_submit['request_id'],))
        jprint(query_status)
        if query_status['status'] !='running':
            # query has finished
            break
        else:
            time.sleep(ctr)
            ctr += 1
            #linear backoff
            print "Checking again"
except requests.HTTPError as e:
    print e
    print #returned message
    print jprint(e.response.json())


if query_status and query_status['request_uri']:
    print("Query successful. Getting result.")
    result = pandas.concat(map(pandas.read_csv, query_status['request_uri']))
else:
    print "Error see above"
# Out:
# Using table BigGIM_70_v1
# Gene pairwise associations: correlation metrics from 33 TCGA tumor types, 21 GTEx tissues, functional interaction scores from 145 tissues (from GIANT), and BioGRID interactions. Containing only rows (gene pairs) where at least one of the TCGA or GTEx absolute correlations is higher than 0.7
# The constructed query.
# {
#   "table": "BigGIM_70_v1",
#   "limit": 1000000,
#   "restriction_gt": "GTEx_Spleen_Pvalue,1.30102999566,TCGA_DLBC_Pvalue,1.30102999566,TCGA_THYM_Pvalue,1.30102999566",
#   "columns": "GIANT_b_lymphocyte_KnownFunctionalInteraction,GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_dendritic_cell_KnownFunctionalInteraction,GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction,GIANT_lymph_node_KnownFunctionalInteraction,GIANT_lymph_node_ProbabilityOfFunctionalInteraction,GIANT_lymphocyte_KnownFunctionalInteraction,GIANT_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_natural_killer_cell_KnownFunctionalInteraction,GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction,GIANT_spleen_KnownFunctionalInteraction,GIANT_spleen_ProbabilityOfFunctionalInteraction,GIANT_t_lymphocyte_KnownFunctionalInteraction,GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction,GIANT_thymocyte_KnownFunctionalInteraction,GIANT_thymocyte_ProbabilityOfFunctionalInteraction,GIANT_tonsil_KnownFunctionalInteraction,GIANT_tonsil_ProbabilityOfFunctionalInteraction,GTEx_Spleen_Correlation,GTEx_Spleen_Pvalue,TCGA_DLBC_Correlation,TCGA_DLBC_Pvalue,TCGA_THYM_Correlation,TCGA_THYM_Pvalue",
#   "restriction_join": "union"
# }
# Submitting query request.
# Query request response.
# {
#   "status": "submitted",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Check query status
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "running",
#   "message": "Extraction job is running.",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d"
# }
# Checking again
# {
#   "status": "complete",
#   "rows": 1000000,
#   "processed_data": "0B",
#   "request_id": "04829dd7-e50b-4d70-9942-c5475ae76c2d",
#   "request_uri": [
#     "https://storage.googleapis.com/ncats_bigquery_results/04829dd7-e50b-4d70-9942-c5475ae76c2d000000000000.csv"
#   ],
#   "size": "154.41 MB"
# }
# Query successful. Getting result.

# %%
#Full example result
result.head()
# Out:
#               GPID      Gene1  Gene2  \
# 0   91170000171022     171022   9117
# 1  842700101927402  101927402  84270
# 2   46010000644759     644759   4601
# 3  796400100506686  100506686  79640
# 4  237740000729867     729867  23774
#
#    GIANT_b_lymphocyte_KnownFunctionalInteraction  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GIANT_dendritic_cell_KnownFunctionalInteraction  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GIANT_lymph_node_KnownFunctionalInteraction  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    GIANT_lymph_node_ProbabilityOfFunctionalInteraction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GIANT_lymphocyte_KnownFunctionalInteraction        ...         \
# 0                                          NaN        ...
# 1                                          NaN        ...
# 2                                          NaN        ...
# 3                                          NaN        ...
# 4                                          NaN        ...
#
#    GIANT_thymocyte_KnownFunctionalInteraction  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    GIANT_thymocyte_ProbabilityOfFunctionalInteraction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GIANT_tonsil_KnownFunctionalInteraction  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    GIANT_tonsil_ProbabilityOfFunctionalInteraction  GTEx_Spleen_Correlation  \
# 0                                              NaN                  -0.0303
# 1                                              NaN                  -0.2865
# 2                                              NaN                   0.2115
# 3                                              NaN                   0.2040
# 4                                              NaN                   0.2811
#
#    GTEx_Spleen_Pvalue  TCGA_DLBC_Correlation  TCGA_DLBC_Pvalue  \
# 0                0.12                    NaN               NaN
# 1                2.50                    NaN               NaN
# 2                1.51                    NaN               NaN
# 3                1.42                    NaN               NaN
# 4                2.42                    NaN               NaN
#
#    TCGA_THYM_Correlation  TCGA_THYM_Pvalue
# 0                -0.3085              3.19
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
#
# [5 rows x 27 columns]
