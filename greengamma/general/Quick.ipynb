# %% [markdown]
# # Using ROBOKOP's Quick Question Answering Service

# %% [markdown]
# The expand, enrich, and similarity services each offer bite-sized approaches to interacting with ROBOKOP.  The ROBOKOP "quick" service offers a slightly more complex approach to answering questions.   We'll be using the following function to call the quick service.  Note that calling the service requires posting a question.  We'll discuss the format of the question below.

# %%
robokop_server='robokop.renci.org'

# %%
import requests

def quick(question,max_results=None):
    url=f'http://{robokop_server}:80/api/simple/quick/'
    if max_results is not None:
        url += f'?max_results={max_results}'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %% [markdown]
# ## Question Format and Basic Usage

# %% [markdown]
# The question is a python dictionary.  It takes a key `machine_question`, which is a dictionary containing a list of `nodes` and a list of `edges`.   Each node object needs an integer `id`.   Any node can also have a `curie` specifying that node.  The edges define connections between the nodes using the identifiers of the nodes as source and targets. The following function shows how to construct a single-hop question.  It takes a specified node of `type1` and looks for any node of `type2`.

# %%
def make_one_step_question(type1, id1, type2,rebuild = None):
    question = {
                'machine_question': {
                    'nodes': [
                        {
                            'id': 'n0',
                            'curie': id1,
                            'type': type1
                        },
                        {
                            'id': 'n1',
                            'type': type2
                        }
                    ],
                    'edges': [
                        {
                            'id': 'e0',
                            'source_id': 'n0',
                            'target_id': 'n1'
                        }
                    ]
                }
            }
    if rebuild is not None and str(rebuild).upper() == 'TRUE':
        question['rebuild'] = 'True'
    return question

# %% [markdown]
# Here, we will specify a one-hop question asking for the phenotypes associated with Fanconi Anemia (MONDO:0019391).  We first construct the question then use it to call the quick service.  In fact, this is how the expand function is implemented internally.  The output is returned in the KG standard answer format.

# %%
q = make_one_step_question('disease','MONDO:0019391','phenotypic_feature')
r = quick(q)
# Out:
# Return Status: 200

# %%
# Uncomment to see a big long answer
#import json
#print( json.dumps(r, indent=4))

# %% [markdown]
# The output can be simplified with a function like this:

# %%
import pandas as pd

def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %%
parse_answer(r)
# Out:
#       result_id                             result_name  \
# 0    HP:0001915                         Aplastic anemia
# 1    HP:0001876                            Pancytopenia
# 2    HP:0003002                        Breast carcinoma
# 3    HP:0004808                  Acute myeloid leukemia
# 4    HP:0001873                        Thrombocytopenia
# 5    HP:0002860                 Squamous cell carcinoma
# 6    HP:0001875                             Neutropenia
# 7    HP:0100615                        Ovarian neoplasm
# 8    HP:0002488                          Acute leukemia
# 9    HP:0002721                        Immunodeficiency
# 10   HP:0000135                            Hypogonadism
# 11   HP:0004430        Severe combined immunodeficiency
# 12   HP:0004810           Congenital hypoplastic anemia
# 13   HP:0006721            Acute lymphoblastic leukemia
# 14   HP:0001908                      Hypoplastic anemia
# 15   HP:0001009                          Telangiectasia
# 16   HP:0000824               Growth hormone deficiency
# 17   HP:0001251                                  Ataxia
# 18   HP:0000789                             Infertility
# 19   HP:0010972         Anemia of inadequate production
# 20   HP:0001402                Hepatocellular carcinoma
# 21   HP:0100806                                  Sepsis
# 22   HP:0001972                       Macrocytic anemia
# 23   HP:0000953           Hyperpigmentation of the skin
# 24   HP:0003254               Abnormality of DNA repair
# 25   HP:0008064                              Ichthyosis
# 26   HP:0005510            Transient erythroblastopenia
# 27   HP:0005505                       Refractory anemia
# 28   HP:0001900                    Increased hemoglobin
# 29   HP:0011018           Abnormality of the cell cycle
# ..          ...                                     ...
# 220  HP:0000365                      Hearing impairment
# 221  HP:0011842      Abnormality of skeletal morphology
# 222  HP:0030976           Abnormal factor VIII activity
# 223  HP:0001928              Abnormality of coagulation
# 224  HP:0410004                  Cleft secondary palate
# 225  HP:0100737         Abnormal hard palate morphology
# 226  HP:0011875            Abnormal platelet morphology
# 227  HP:0000202                              Oral cleft
# 228  HP:0011338              Abnormality of mouth shape
# 229  HP:0010989    Abnormality of the intrinsic pathway
# 230  HP:0000152             Abnormality of head or neck
# 231  HP:0003256  Abnormality of the coagulation cascade
# 232  HP:0000153                Abnormality of the mouth
# 233  HP:0000268                          Dolichocephaly
# 234  HP:0006824                 Cranial nerve paralysis
# 235  HP:0002245                     Meckel diverticulum
# 236  HP:0001347                           Hyperreflexia
# 237  HP:0000340                        Sloping forehead
# 238  HP:0001537                        Umbilical hernia
# 239  HP:0000582             Upslanted palpebral fissure
# 240  HP:0100587            Abnormality of the preputium
# 241  HP:0002414                            Spina bifida
# 242  HP:0000453                         Choanal atresia
# 243  HP:0000027                             Azoospermia
# 244  HP:0001053              Hypopigmented skin patches
# 245  HP:0002823         Abnormality of femur morphology
# 246  HP:0005344      Abnormal carotid artery morphology
# 247  HP:0004349            Reduced bone mineral density
# 248  HP:0008053          Aplasia/Hypoplasia of the iris
# 249  HP:0000813                       Bicornuate uterus
#
#                             source           type
# 0    biolink.disease_get_phenotype  has_phenotype
# 1    biolink.disease_get_phenotype  has_phenotype
# 2    biolink.disease_get_phenotype  has_phenotype
# 3    biolink.disease_get_phenotype  has_phenotype
# 4    biolink.disease_get_phenotype  has_phenotype
# 5    biolink.disease_get_phenotype  has_phenotype
# 6    biolink.disease_get_phenotype  has_phenotype
# 7    biolink.disease_get_phenotype  has_phenotype
# 8    biolink.disease_get_phenotype  has_phenotype
# 9    biolink.disease_get_phenotype  has_phenotype
# 10   biolink.disease_get_phenotype  has_phenotype
# 11   biolink.disease_get_phenotype  has_phenotype
# 12   biolink.disease_get_phenotype  has_phenotype
# 13   biolink.disease_get_phenotype  has_phenotype
# 14   biolink.disease_get_phenotype  has_phenotype
# 15   biolink.disease_get_phenotype  has_phenotype
# 16   biolink.disease_get_phenotype  has_phenotype
# 17   biolink.disease_get_phenotype  has_phenotype
# 18   biolink.disease_get_phenotype  has_phenotype
# 19   biolink.disease_get_phenotype  has_phenotype
# 20   biolink.disease_get_phenotype  has_phenotype
# 21   biolink.disease_get_phenotype  has_phenotype
# 22   biolink.disease_get_phenotype  has_phenotype
# 23   biolink.disease_get_phenotype  has_phenotype
# 24   biolink.disease_get_phenotype  has_phenotype
# 25   biolink.disease_get_phenotype  has_phenotype
# 26   biolink.disease_get_phenotype  has_phenotype
# 27   biolink.disease_get_phenotype  has_phenotype
# 28   biolink.disease_get_phenotype  has_phenotype
# 29   biolink.disease_get_phenotype  has_phenotype
# ..                             ...            ...
# 220  biolink.disease_get_phenotype  has_phenotype
# 221  biolink.phenotype_get_disease  has_phenotype
# 222  biolink.phenotype_get_disease  has_phenotype
# 223  biolink.phenotype_get_disease  has_phenotype
# 224  biolink.phenotype_get_disease  has_phenotype
# 225  biolink.phenotype_get_disease  has_phenotype
# 226  biolink.phenotype_get_disease  has_phenotype
# 227  biolink.phenotype_get_disease  has_phenotype
# 228  biolink.phenotype_get_disease  has_phenotype
# 229  biolink.phenotype_get_disease  has_phenotype
# 230  biolink.phenotype_get_disease  has_phenotype
# 231  biolink.phenotype_get_disease  has_phenotype
# 232  biolink.phenotype_get_disease  has_phenotype
# 233  biolink.disease_get_phenotype  has_phenotype
# 234  biolink.disease_get_phenotype  has_phenotype
# 235  biolink.disease_get_phenotype  has_phenotype
# 236  biolink.disease_get_phenotype  has_phenotype
# 237  biolink.disease_get_phenotype  has_phenotype
# 238  biolink.disease_get_phenotype  has_phenotype
# 239  biolink.disease_get_phenotype  has_phenotype
# 240  biolink.disease_get_phenotype  has_phenotype
# 241  biolink.disease_get_phenotype  has_phenotype
# 242  biolink.disease_get_phenotype  has_phenotype
# 243  biolink.disease_get_phenotype  has_phenotype
# 244  biolink.disease_get_phenotype  has_phenotype
# 245  biolink.disease_get_phenotype  has_phenotype
# 246  biolink.disease_get_phenotype  has_phenotype
# 247  biolink.disease_get_phenotype  has_phenotype
# 248  biolink.disease_get_phenotype  has_phenotype
# 249  biolink.disease_get_phenotype  has_phenotype
#
# [250 rows x 4 columns]

# %% [markdown]
# ## Multi-step questions

# %% [markdown]
# It's straightforward to generalize this linear query to an N-item path.  This function constructs a question from a list of types and a list of identifiers.  The types are the types of nodes that will be traversed along the path, and the identifiers represent fixed elements in the path.  The length of types and ids should be equal, and free nodes should specify an id of None:

# %%
def make_N_step_question(types,curies,rebuild = None):
    question = {
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    if rebuild is not None and str(rebuild).upper() == 'TRUE':
        question['rebuild'] = 'True'
    ei = 0
    for i,t in enumerate(types):
        newnode = {'id': f'n{i}', 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        if i > 0:
            question['machine_question']['edges'].append( {'id': f'e{ei}','source_id': f'n{i-1}', 'target_id': f'n{i}'})
            ei += 1
    return question

# %% [markdown]
# We can recapitulate our previous question with this new function like this:

# %%
newq = make_N_step_question(['disease','phenotypic_feature'],['MONDO:0019391',None])
q == newq
# Out:
# True

# %% [markdown]
# Now we could expand to a longer query.  The following question will start at the disease MONDO:0019391, go to a gene, and from there to a biological process or activity.

# %%
two_step_question = make_N_step_question(['disease','gene','biological_process_or_activity'],['MONDO:0019391',None,None])

# %%
two_step_answer = quick(two_step_question)

# %% [markdown]
# We can extract the node names along the paths with a simple function:

# %%
def extract_node_names(returnanswer):
    nodes = [{f'node_{i}': (node['name'] if 'name' in node else node['id'])  
              for i,node in enumerate(answer['nodes'])} for answer in returnanswer['answers']]
    return pd.DataFrame(nodes)

# %%
two_step_nodes = extract_node_names(two_step_answer)
two_step_nodes
# Out:
#              node_0    node_1  \
# 0    Fanconi anemia    FANCD2
# 1    Fanconi anemia     FANCA
# 2    Fanconi anemia     FANCM
# 3    Fanconi anemia     FANCG
# 4    Fanconi anemia     FANCF
# 5    Fanconi anemia     FANCB
# 6    Fanconi anemia     ERCC4
# 7    Fanconi anemia     UBE2T
# 8    Fanconi anemia     RFWD3
# 9    Fanconi anemia     RAD51
# 10   Fanconi anemia     FANCI
# 11   Fanconi anemia     FANCC
# 12   Fanconi anemia      SLX4
# 13   Fanconi anemia      FAN1
# 14   Fanconi anemia     FANCL
# 15   Fanconi anemia     MUS81
# 16   Fanconi anemia     FANCM
# 17   Fanconi anemia   DCLRE1B
# 18   Fanconi anemia    RAD51C
# 19   Fanconi anemia   FAAP100
# 20   Fanconi anemia      RNF8
# 21   Fanconi anemia      REV1
# 22   Fanconi anemia     ERCC4
# 23   Fanconi anemia   DCLRE1A
# 24   Fanconi anemia     ERCC4
# 25   Fanconi anemia     FANCM
# 26   Fanconi anemia      POLN
# 27   Fanconi anemia    RAD51C
# 28   Fanconi anemia     FANCM
# 29   Fanconi anemia     RAD51
# ..              ...       ...
# 220  Fanconi anemia     BRIP1
# 221  Fanconi anemia      FAN1
# 222  Fanconi anemia      SLX4
# 223  Fanconi anemia     UBE2T
# 224  Fanconi anemia    RAD51D
# 225  Fanconi anemia     DDX11
# 226  Fanconi anemia       BLM
# 227  Fanconi anemia     ERCC4
# 228  Fanconi anemia     ERCC4
# 229  Fanconi anemia     MUS81
# 230  Fanconi anemia      EME1
# 231  Fanconi anemia      FBH1
# 232  Fanconi anemia     FANCL
# 233  Fanconi anemia     BRCA2
# 234  Fanconi anemia    MAD2L2
# 235  Fanconi anemia    RAD51C
# 236  Fanconi anemia     H2AFX
# 237  Fanconi anemia     DDX11
# 238  Fanconi anemia    MAD2L2
# 239  Fanconi anemia    RAD51D
# 240  Fanconi anemia     BRIP1
# 241  Fanconi anemia  RAD51AP1
# 242  Fanconi anemia      FBH1
# 243  Fanconi anemia     H2AFX
# 244  Fanconi anemia      FBH1
# 245  Fanconi anemia     DDX11
# 246  Fanconi anemia       ATM
# 247  Fanconi anemia     DDX11
# 248  Fanconi anemia      FAN1
# 249  Fanconi anemia   DCLRE1B
#
#                                                 node_2
# 0                        interstrand cross-link repair
# 1                        interstrand cross-link repair
# 2                        interstrand cross-link repair
# 3                        interstrand cross-link repair
# 4                        interstrand cross-link repair
# 5                        interstrand cross-link repair
# 6                        interstrand cross-link repair
# 7                        interstrand cross-link repair
# 8                        interstrand cross-link repair
# 9                        interstrand cross-link repair
# 10                       interstrand cross-link repair
# 11                       interstrand cross-link repair
# 12                       interstrand cross-link repair
# 13                       interstrand cross-link repair
# 14                       interstrand cross-link repair
# 15                       interstrand cross-link repair
# 16                                   helicase activity
# 17                       interstrand cross-link repair
# 18                           sister chromatid cohesion
# 19                       interstrand cross-link repair
# 20                       interstrand cross-link repair
# 21                               translesion synthesis
# 22                                telomere maintenance
# 23                       interstrand cross-link repair
# 24                          nucleotide-excision repair
# 25                                   chromatin binding
# 26                       interstrand cross-link repair
# 27   double-strand break repair via homologous reco...
# 28                                   nuclease activity
# 29            cellular response to DNA damage stimulus
# ..                                                 ...
# 220                         nucleotide-excision repair
# 221                         nucleotide-excision repair
# 222                                  DNA recombination
# 223                                         DNA repair
# 224                                  DNA recombination
# 225                                  chromatin binding
# 226                                    DNA replication
# 227                         protein C-terminus binding
# 228                            cellular response to UV
# 229                                  DNA recombination
# 230                         double-strand break repair
# 231                           DNA translocase activity
# 232                         protein monoubiquitination
# 233                                  DNA recombination
# 234                  error-prone translesion synthesis
# 235                                        DNA binding
# 236                                cellular senescence
# 237                        double-stranded DNA binding
# 238                          regulation of cell growth
# 239                      DNA-dependent ATPase activity
# 240                               DNA duplex unwinding
# 241                        double-stranded DNA binding
# 242  double-strand break repair via homologous reco...
# 243                                  DNA recombination
# 244                        double-stranded DNA binding
# 245                                         DNA repair
# 246                                         DNA repair
# 247                        replication fork processing
# 248                               exonuclease activity
# 249                               exonuclease activity
#
# [250 rows x 3 columns]

# %% [markdown]
# ## Specifying multiple fixed nodes

# %% [markdown]
# The examples above have all started from one known node and expanded from it, sometimes in multiple steps.  It's also possible to have more than one node specified.  For instance, if we wanted to look for genes that link Fanconi Aneima (MONDO:0019391) and DNA repair (GO:0006281), we could rerun our previous query, but setting the final curie, like this:

# %%
two_step_question_fixed_ends = \
   make_N_step_question(['disease','gene','biological_process_or_activity'],['MONDO:0019391',None,'GO:0006281'])
two_step_answer_fixed_ends = quick(two_step_question_fixed_ends)
# Out:
# Return Status: 200

# %%
extract_node_names(two_step_answer_fixed_ends)
# Out:
#             node_0    node_1      node_2
# 0   Fanconi anemia    FANCD2  DNA repair
# 1   Fanconi anemia     FANCA  DNA repair
# 2   Fanconi anemia    RAD51C  DNA repair
# 3   Fanconi anemia     FANCG  DNA repair
# 4   Fanconi anemia     ERCC4  DNA repair
# 5   Fanconi anemia     RAD51  DNA repair
# 6   Fanconi anemia     FANCC  DNA repair
# 7   Fanconi anemia     XRCC2  DNA repair
# 8   Fanconi anemia      FAN1  DNA repair
# 9   Fanconi anemia    RAD51D  DNA repair
# 10  Fanconi anemia  RAD51AP1  DNA repair
# 11  Fanconi anemia       BLM  DNA repair
# 12  Fanconi anemia       XPA  DNA repair
# 13  Fanconi anemia       WRN  DNA repair
# 14  Fanconi anemia     FANCI  DNA repair
# 15  Fanconi anemia     MUS81  DNA repair
# 16  Fanconi anemia      REV1  DNA repair
# 17  Fanconi anemia      SLX4  DNA repair
# 18  Fanconi anemia     BRCA2  DNA repair
# 19  Fanconi anemia     FANCL  DNA repair
# 20  Fanconi anemia     UBE2T  DNA repair
# 21  Fanconi anemia     DDX11  DNA repair
# 22  Fanconi anemia       ATM  DNA repair
# 23  Fanconi anemia      EME1  DNA repair
# 24  Fanconi anemia     CENPS  DNA repair
# 25  Fanconi anemia     CENPX  DNA repair
# 26  Fanconi anemia     SLX1A  DNA repair
# 27  Fanconi anemia     SLX1B  DNA repair
# 28  Fanconi anemia    BOD1L1  DNA repair

# %% [markdown]
# ## Non-path queries

# %% [markdown]
# So far, we've only looked at linear paths.  But the question format is actually more general than that - we can define a path pattern generally. So for instance, in the above query, we find all genes that are linked to both FA and DNA repair.  But what if we wanted to find entities that are connected to more than two specified entities.  Here is a query-generation function for the star query:

# %%
def make_star_question(types,curies,shared_type,rebuild=None):
    """Create a question to find entities of shared_type that are linked to all of the nodes specified in the
    types and curies arrays."""
    question = {
                #'rebuild': 'True',
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    if rebuild is not None and str(rebuild).upper() == 'TRUE':
        question['rebuild']='True'
    question['machine_question']['nodes'].append( {'id': 0, 'type': shared_type})
    for i,t in enumerate(types):
        newnode = {'id': i+1, 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        question['machine_question']['edges'].append( {'source_id': 0, 'target_id': i+1})
    return question

# %% [markdown]
# Suppose I have this set of GO terms, and I'd like to find genes that they all have in common:
#
# * 'voltage-gated sodium channel activity(GO:0005248)',
# * 'muscle contraction(GO:0006936)',
# * 'voltage-gated ion channel activity(GO:0005244)',
# * 'regulation of ion transmembrane transport(GO:0034765)',
# * 'sodium ion transmembrane transport(GO:0035725)',
# * 'neuronal action potential(GO:0019228)',
# * 'membrane depolarization during action potential(GO:0086010)',
# * 'sodium ion transport(GO:0006814)'

# %%
go_terms=['GO:0005248','GO:0006936','GO:0005244','GO:0034765','GO:0035725','GO:0019228','GO:0086010','GO:0006814']
types = ['biological_process_or_activity' for g in go_terms]
star_q = make_star_question(types,go_terms,'gene')
star_q
# Out:
# {'machine_question': {'edges': [{'source_id': 0, 'target_id': 1},
#    {'source_id': 0, 'target_id': 2},
#    {'source_id': 0, 'target_id': 3},
#    {'source_id': 0, 'target_id': 4},
#    {'source_id': 0, 'target_id': 5},
#    {'source_id': 0, 'target_id': 6},
#    {'source_id': 0, 'target_id': 7},
#    {'source_id': 0, 'target_id': 8}],
#   'nodes': [{'id': 0, 'type': 'gene'},
#    {'curie': 'GO:0005248', 'id': 1, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006936', 'id': 2, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0005244', 'id': 3, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0034765', 'id': 4, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0035725', 'id': 5, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0019228', 'id': 6, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0086010', 'id': 7, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006814',
#     'id': 8,
#     'type': 'biological_process_or_activity'}]}}

# %%
common_gene_answer = quick(star_q)
# Out:
# Return Status: 200

# %%
extract_node_names(common_gene_answer)
# Out:
#   node_0                                 node_1              node_2  \
# 0  SCN4A  voltage-gated sodium channel activity  muscle contraction
# 1  SCN7A  voltage-gated sodium channel activity  muscle contraction
#
#                                node_3  \
# 0  voltage-gated ion channel activity
# 1  voltage-gated ion channel activity
#
#                                       node_4  \
# 0  regulation of ion transmembrane transport
# 1  regulation of ion transmembrane transport
#
#                                node_5                     node_6  \
# 0  sodium ion transmembrane transport  neuronal action potential
# 1  sodium ion transmembrane transport  neuronal action potential
#
#                                             node_7                node_8
# 0  membrane depolarization during action potential  sodium ion transport
# 1  membrane depolarization during action potential  sodium ion transport

# %% [markdown]
# We can also have more than one unspecified node.  Suppose, for instance that we wanted to do the previous query, but we also wanted to know what chemicals interact with the genes that we find.  We can do another star query, where one of our spokes is unspecified:

# %%
go_terms=['GO:0005248','GO:0006936','GO:0005244','GO:0034765','GO:0035725','GO:0019228','GO:0086010','GO:0006814',None]
types = ['biological_process_or_activity' for i in range(8)]+['chemical_substance']
star_q_compound = make_star_question(types,go_terms,'gene',rebuild=True)
star_q_compound
# Out:
# {'machine_question': {'edges': [{'source_id': 0, 'target_id': 1},
#    {'source_id': 0, 'target_id': 2},
#    {'source_id': 0, 'target_id': 3},
#    {'source_id': 0, 'target_id': 4},
#    {'source_id': 0, 'target_id': 5},
#    {'source_id': 0, 'target_id': 6},
#    {'source_id': 0, 'target_id': 7},
#    {'source_id': 0, 'target_id': 8},
#    {'source_id': 0, 'target_id': 9}],
#   'nodes': [{'id': 0, 'type': 'gene'},
#    {'curie': 'GO:0005248', 'id': 1, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006936', 'id': 2, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0005244', 'id': 3, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0034765', 'id': 4, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0035725', 'id': 5, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0019228', 'id': 6, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0086010', 'id': 7, 'type': 'biological_process_or_activity'},
#    {'curie': 'GO:0006814', 'id': 8, 'type': 'biological_process_or_activity'},
#    {'id': 9, 'type': 'chemical_substance'}]},
#  'rebuild': 'True'}

# %% [markdown]
# **WARNING: This takes a long time to run**

# %%
common_gene_compound_answer = quick(star_q_compound)
# Out:
# Return Status: 200

# %%
cgc_nodes = extract_node_names(common_gene_compound_answer)
cgc_nodes[['node_0','node_9']]
# Out:
#     node_0                                             node_9
# 0    SCN4A                                        lamotrigine
# 1    SCN4A                                      Carbamazepine
# 2    SCN4A                                          Lidocaine
# 3    SCN4A                                         benzocaine
# 4    SCN4A                                          phenytoin
# 5    SCN4A                                          Tocainide
# 6    SCN4A                                         Mexiletine
# 7    SCN4A                                         Flecainide
# 8    SCN7A                                         benzocaine
# 9    SCN7A                                             Nickel
# 10   SCN4A                                      Valproic Acid
# 11   SCN4A                                         Zonisamide
# 12   SCN4A                                     pirinixic acid
# 13   SCN4A                                        mepivacaine
# 14   SCN4A                                       pilsicainide
# 15   SCN7A                                          Tocainide
# 16   SCN7A                                      Valproic Acid
# 17   SCN7A                        p-Chloromercuribenzoic Acid
# 18   SCN7A                                       panobinostat
# 19   SCN7A                             Phenylmercuric Acetate
# 20   SCN7A                                     trichostatin A
# 21   SCN4A                                         rufinamide
# 22   SCN4A                                           3-cresol
# 23   SCN4A                                       troglitazone
# 24   SCN4A                                      chloroxylenol
# 25   SCN4A                                     4-chlorophenol
# 26   SCN4A                                   (+)-JQ1 compound
# 27   SCN4A                                        ropivacaine
# 28   SCN4A                        1-Methyl-4-phenylpyridinium
# 29   SCN4A                                         etidocaine
# ..     ...                                                ...
# 148  SCN4A                                                 NA
# 149  SCN4A                                                 NA
# 150  SCN4A                                                 NA
# 151  SCN4A                                                 NA
# 152  SCN4A                                                 NA
# 153  SCN4A                                                 NA
# 154  SCN4A  (R)-1-(2,6-dimethylphenoxy)-3-methylbutan-2-amine
# 155  SCN4A                                                 NA
# 156  SCN4A                                                 NA
# 157  SCN4A  (S)-2-(2,6-dimethylphenylthio)-1-phenylethanamine
# 158  SCN4A                                                 NA
# 159  SCN4A  (E)-2-(4-(4-fluorophenoxy)benzylidene)hydrazin...
# 160  SCN4A  (S)-(-)-2(benzylamino)-N-(2,6-dimethylphenyl)p...
# 161  SCN4A  3-[4-(4-Nitro-phenoxy)-phenyl]-pyrazole-1-carb...
# 162  SCN4A     (R)-2-(2,6-dimethylphenoxy)-1-phenylethanamine
# 163  SCN4A  (S)-1-(2,6-dimethylphenoxy)-3-methylbutan-2-amine
# 164  SCN4A                                                 NA
# 165  SCN4A                                                 NA
# 166  SCN4A                                                 NA
# 167  SCN4A                                    levobupivacaine
# 168  SCN4A                                                 NA
# 169  SCN4A  3-(4-Phenoxy-phenyl)-pyrazole-1-carboxylic aci...
# 170  SCN4A                                                 NA
# 171  SCN4A                                                 NA
# 172  SCN4A                                             Sodium
# 173  SCN7A                            eslicarbazepine acetate
# 174  SCN7A                                    phenazopyridine
# 175  SCN7A                                        mephenytoin
# 176  SCN7A                                           Ethotoin
# 177  SCN7A                                             Sodium
#
# [178 rows x 2 columns]

# %% [markdown]
# Many other graph shapes are possible, these are simply a couple of examples.  For instance, we could add onto this query an edge from node 0 to a new disease node (node 10) and also include an edge from the target node (node 9) to this same disease node. Now we would be finding genes that share a set of GO terms, then looking for disease,drug pairs such that the disease, the drug, and the gene are all interconnected.

# %% [markdown]
# ### Controlling the number of results

# %% [markdown]
# By default, quick will return up to 250 results, but this can be raised or lowered using the max_resuls parameter:

# %%
common_gene_compound_answer_10 = quick(star_q_compound,max_results=10)
# Out:
# Return Status: 200

# %%
cgc_nodes_10 = extract_node_names(common_gene_compound_answer_10)
cgc_nodes_10[['node_0','node_9']]
# Out:
#   node_0         node_9
# 0  SCN4A    lamotrigine
# 1  SCN4A  Carbamazepine
# 2  SCN4A      Lidocaine
# 3  SCN4A     benzocaine
# 4  SCN4A      phenytoin
# 5  SCN4A      Tocainide
# 6  SCN4A     Mexiletine
# 7  SCN4A     Flecainide
# 8  SCN7A     benzocaine
# 9  SCN7A         Nickel

# %% [markdown]
# ## Rebuild and caching

# %% [markdown]
# For details on ROBOKOP caching, and guidance for when to use the `rebuild` parameter, see the notebook on the expand service.  Briefly, the quick service will only run against the cache unless the rebuild parameter is passed, in which case services are re-queried.   The rebuild parameter is passed as part of the json query as seen in the `make_star_query` function above.

# %% [markdown]
# ## Edge Properties

# %% [markdown]
# In the expand notebook, we saw how a particular predicate could be chosen to limit the results.  This same type information can in fact be added to any edge in a quick query, providing fine control to the results returned.
