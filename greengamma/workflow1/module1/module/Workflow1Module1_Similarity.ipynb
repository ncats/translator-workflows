# %% [markdown]
# # Workflow 1, Module 1 (Condition similarity)

# %% [markdown]
# Module one can be interpreted as: "Find me genetic conditions that are phenotypically similar to disease X".  We can attack this problem with our similiarity endpont directly.  This is because
# 1. ROBOKOP implements genetic_condition as a type, so we can use it in the query
# 2. ROBOKOP's similarity endpoint does not require that the query and result type are the same.

# %%
import requests
import pandas as pd

# %%
def similarity(type1,ident,type2,by_type,threshhold=None,maxresults=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/similarity/{type1}/{ident}/{type2}/{by_type}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.get(url, params = params)
    print( 'Return code:',response.status_code )
    return response.json()

# %%
diabetes = 'MONDO:0005148'
asthma = 'MONDO:0004979'

# %%
gc_similar_to_diabetes=similarity('disease',diabetes,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_diabetes)
# Out:
# Return code: 200
#                id                                               name  \
# 0   MONDO:0011565                               metabolic syndrome X
# 1   MONDO:0012819                              diabetic ketoacidosis
# 2   MONDO:0005109                             HIV infectious disease
# 3   MONDO:0001076                                glucose intolerance
# 4   MONDO:0009061                                    cystic fibrosis
# 5   MONDO:0017146           sickle cell disease and related diseases
# 6   MONDO:0011382                                 sickle cell anemia
# 7   MONDO:0018407  male infertility due to obstructive azoospermi...
# 8   MONDO:0000422                inborn glycogen metabolism disorder
# 9   MONDO:0002412                           glycogen storage disease
# 10  MONDO:0018409  rare genetic disorder with obstructive azoospe...
# 11  MONDO:0017763          disorder of iron metabolism and transport
# 12  MONDO:0015509                      genetic biliary tract disease
# 13  MONDO:0018377    rare hereditary disease with avascular necrosis
# 14  MONDO:0001336                            familial hyperlipidemia
# 15  MONDO:0015905                             syndromic dyslipidemia
# 16  MONDO:0006507                         hereditary hemochromatosis
# 17  MONDO:0019050                         inherited hemoglobinopathy
# 18  MONDO:0004689                   inborn metal metabolism disorder
# 19  MONDO:0003346                  central nervous system vasculitis
# 20  MONDO:0010526                                      Fabry disease
# 21  MONDO:0018384               avascular necrosis of genetic origin
# 22  MONDO:0006510                    renal tubular transport disease
# 23  MONDO:0015901                      rare inherited hyperlipidemia
# 24  MONDO:0000984                                        thalassemia
# 25  MONDO:0003689                          familial hemolytic anemia
# 26  MONDO:0008575                                nicotine dependence
# 27  MONDO:0017761       disorder of mineral absorption and transport
# 28  MONDO:0019747      hematological disorder with renal involvement
# 29  MONDO:0004739                                urea cycle disorder
# ..            ...                                                ...
# 70  MONDO:0017663                       rare genetic tremor disorder
# 71  MONDO:0008763                                   Alstrom syndrome
# 72  MONDO:0002413                         glycogen storage disease I
# 73  MONDO:0004675                    mitochondrial encephalomyopathy
# 74  MONDO:0015123                        rare inherited dyslipidemia
# 75  MONDO:0016341  lysosomal disease with restrictive cardiomyopathy
# 76  MONDO:0019039  rare hemorrhagic disorder due to a constitutio...
# 77  MONDO:0018299                     sphingolipidosis with epilepsy
# 78  MONDO:0015920  syndromic neurometabolic disease with X-linked...
# 79  MONDO:0010602                                       hemophilia A
# 80  MONDO:0015951                            genetic photodermatosis
# 81  MONDO:0001909                             renal tubular acidosis
# 82  MONDO:0016326  lysosomal disease with hypertrophic cardiomyop...
# 83  MONDO:0018660                                         hemophilia
# 84  MONDO:0016401           energy metabolism disorder with epilepsy
# 85  MONDO:0016402                mitochondrial disease with epilepsy
# 86  MONDO:0017290                  familial intrahepatic cholestasis
# 87  MONDO:0016335  mitochondrial disease with dilated cardiomyopathy
# 88  MONDO:0018634                             hereditary amyloidosis
# 89  MONDO:0019602                     other inborn metabolic disease
# 90  MONDO:0019852                  inherited primary ovarian failure
# 91  MONDO:0019810                         toxic epidermal necrolysis
# 92  MONDO:0020088                     familial partial lipodystrophy
# 93  MONDO:0000688                         inherited organic acidemia
# 94  MONDO:0010789                                     MELAS syndrome
# 95  MONDO:0016793  mitochondrial oxidative phosphorylation disord...
# 96  MONDO:0018412  rare female infertility due to adrenal disorde...
# 97  MONDO:0019599                              primary lipodystrophy
# 98  MONDO:0019215                           classic organic aciduria
# 99  MONDO:0019223  inborn disorder of fatty acid oxidation and ke...
#
#     similarity
# 0     0.355856
# 1     0.320197
# 2     0.249389
# 3     0.191176
# 4     0.182410
# 5     0.181269
# 6     0.181269
# 7     0.175978
# 8     0.169014
# 9     0.169014
# 10    0.166172
# 11    0.159639
# 12    0.156415
# 13    0.156098
# 14    0.155738
# 15    0.155709
# 16    0.154386
# 17    0.152450
# 18    0.151033
# 19    0.150780
# 20    0.150171
# 21    0.149254
# 22    0.146982
# 23    0.144981
# 24    0.144172
# 25    0.143345
# 26    0.142857
# 27    0.142384
# 28    0.141544
# 29    0.141343
# ..         ...
# 70    0.123494
# 71    0.122605
# 72    0.121951
# 73    0.121495
# 74    0.121372
# 75    0.121348
# 76    0.120907
# 77    0.120841
# 78    0.120427
# 79    0.120130
# 80    0.119782
# 81    0.119522
# 82    0.119433
# 83    0.118750
# 84    0.118699
# 85    0.118492
# 86    0.118421
# 87    0.117794
# 88    0.117647
# 89    0.117241
# 90    0.117199
# 91    0.117057
# 92    0.116981
# 93    0.116858
# 94    0.116719
# 95    0.116580
# 96    0.115942
# 97    0.115635
# 98    0.115473
# 99    0.115385
#
# [100 rows x 3 columns]

# %%
gc_similar_to_asthma=similarity('disease',asthma,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_asthma)
# Out:
# Return code: 200
#                id                                               name  \
# 0   MONDO:0010086                       sudden infant death syndrome
# 1   MONDO:0007186                    gastroesophageal reflux disease
# 2   MONDO:0005109                             HIV infectious disease
# 3   MONDO:0009061                                    cystic fibrosis
# 4   MONDO:0018409  rare genetic disorder with obstructive azoospe...
# 5   MONDO:0008575                                nicotine dependence
# 6   MONDO:0018229                           Stevens-Johnson syndrome
# 7   MONDO:0018407  male infertility due to obstructive azoospermi...
# 8   MONDO:0019810                         toxic epidermal necrolysis
# 9   MONDO:0017396                                   toxic dermatosis
# 10  MONDO:0008903                                        lung cancer
# 11  MONDO:0017146           sickle cell disease and related diseases
# 12  MONDO:0011382                                 sickle cell anemia
# 13  MONDO:0009971              newborn respiratory distress syndrome
# 14  MONDO:0015977                                 agammaglobulinemia
# 15  MONDO:0012819                              diabetic ketoacidosis
# 16  MONDO:0019602                     other inborn metabolic disease
# 17  MONDO:0002273                  plasma protein metabolism disease
# 18  MONDO:0015974         severe combined immunodeficiency (disease)
# 19  MONDO:0013282                     alpha 1-antitrypsin deficiency
# 20  MONDO:0003346                  central nervous system vasculitis
# 21  MONDO:0015132  immunodeficiency predominantly affecting antib...
# 22  MONDO:0008608                                      down syndrome
# 23  MONDO:0020193  secretory apparatus of the lacrimal system ano...
# 24  MONDO:0018377    rare hereditary disease with avascular necrosis
# 25  MONDO:0018305                      chronic granulomatous disease
# 26  MONDO:0016575                         primary ciliary dyskinesia
# 27  MONDO:0015517                   common variable immunodeficiency
# 28  MONDO:0016463                       syndromic agammaglobulinemia
# 29  MONDO:0015509                      genetic biliary tract disease
# ..            ...                                                ...
# 70  MONDO:0018389  male infertility due to gonadal dysgenesis or ...
# 71  MONDO:0019213                          cerebral organic aciduria
# 72  MONDO:0000167           Huntington disease and related disorders
# 73  MONDO:0006664                         atrial heart septal defect
# 74  MONDO:0013099  combined pituitary hormone deficiencies, genet...
# 75  MONDO:0015789  non-acquired combined pituitary hormone defici...
# 76  MONDO:0020072                  childhood-onset epilepsy syndrome
# 77  MONDO:0017369   autoinflammatory syndrome with immune deficiency
# 78  MONDO:0015133  quantitative and/or qualitative congenital pha...
# 79  MONDO:0015891  hypogonadotropic hypogonadism associated with ...
# 80  MONDO:0018299                     sphingolipidosis with epilepsy
# 81  MONDO:0019236               inborn disorder of purine metabolism
# 82  MONDO:0020112  vitamin B12- and folate-independent constituti...
# 83  MONDO:0018898                         primary cutaneous lymphoma
# 84  MONDO:0005100                                 systemic sclerosis
# 85  MONDO:0002412                           glycogen storage disease
# 86  MONDO:0000422                inborn glycogen metabolism disorder
# 87  MONDO:0017763          disorder of iron metabolism and transport
# 88  MONDO:0016341  lysosomal disease with restrictive cardiomyopathy
# 89  MONDO:0020257                      supranuclear oculomotor palsy
# 90  MONDO:0019255                                   sphingolipidosis
# 91  MONDO:0017758  disorder of vitamin and non-protein cofactor a...
# 92  MONDO:0010518                           Wiskott-Aldrich syndrome
# 93  MONDO:0020258   oculomotor apraxia or related oculomotor disease
# 94  MONDO:0019275                    other genetic epidermal disease
# 95  MONDO:0017738                 lysosomal glycogen storage disease
# 96  MONDO:0019142                                inherited porphyria
# 97  MONDO:0009691                                  mycosis fungoides
# 98  MONDO:0017953                 hereditary periodic fever syndrome
# 99  MONDO:0015816         indolent primary cutaneous T-cell lymphoma
#
#     similarity
# 0     0.223301
# 1     0.205882
# 2     0.200528
# 3     0.199219
# 4     0.182456
# 5     0.180328
# 6     0.172414
# 7     0.169872
# 8     0.168067
# 9     0.168000
# 10    0.156863
# 11    0.155172
# 12    0.155172
# 13    0.146739
# 14    0.146179
# 15    0.145946
# 16    0.145299
# 17    0.142222
# 18    0.138462
# 19    0.137363
# 20    0.136449
# 21    0.136000
# 22    0.133858
# 23    0.128821
# 24    0.126685
# 25    0.126638
# 26    0.126316
# 27    0.126050
# 28    0.126050
# 29    0.125234
# ..         ...
# 70    0.100000
# 71    0.099617
# 72    0.099415
# 73    0.099057
# 74    0.098940
# 75    0.098940
# 76    0.098901
# 77    0.098701
# 78    0.098592
# 79    0.097926
# 80    0.097744
# 81    0.097727
# 82    0.097458
# 83    0.096916
# 84    0.096886
# 85    0.096774
# 86    0.096774
# 87    0.096667
# 88    0.096535
# 89    0.096296
# 90    0.096273
# 91    0.095768
# 92    0.095652
# 93    0.095506
# 94    0.094987
# 95    0.094787
# 96    0.094595
# 97    0.094527
# 98    0.094340
# 99    0.094340
#
# [100 rows x 3 columns]
