# %% [markdown]
# # Workflow 1, Module 1, Question 2

# %% [markdown]
# ## What conditions present [symptoms]?

# %% [markdown]
# ### Approach 1:  Quick to find conditions that have every symptom.

# %% [markdown]
# If this question means find any condition that has all of the given set of symptoms, then we can use the quick service.  Here we will do what's called a "star query" in the quick notebook. First, we'll define a quick function that takes a question and calls the service, then we'll define a function for creating the proper question format. Finally, we'll show some examples using symptom lists derived from the workflow1, module1 question 1 notebook.

# %%
import requests
import pandas as pd

# %%
def quick(question):
    url=f'http://robokop.renci.org:80/api/simple/quick/'
    response = requests.post(url,json=question)
    print( f"Return Status: {response.status_code}" )
    if response.status_code == 200:
        return response.json()
    return response

# %%
def make_star_question(types,curies,shared_type):
    """Create a question to find entities of shared_type that are linked to all of the nodes specified in the
    types and curies arrays."""
    question = {
                'rebuild': 'False',  #We're doing disease/phenotype, so they're cached.
                'machine_question': {
                    'nodes': [],
                    'edges': []
                }
            }
    question['machine_question']['nodes'].append( {'id': 'n0', 'type': shared_type})
    for i,t in enumerate(types):
        newnode = {'id': f'n{i+1}', 'type': t}
        if curies[i] is not None:
            newnode['curie'] = curies[i]
        question['machine_question']['nodes'].append(newnode)
        question['machine_question']['edges'].append( {'id':f'e{i}','source_id': 'n0', 'target_id': f'n{i+1}'})
    return question

# %%
def make_shared_symptom_question(curies):
    types = [ 'phenotypic_feature' for c in curies ]
    shared_type = 'disease'
    return make_star_question(types,curies,shared_type)

# %% [markdown]
# We will use this function to pretty print quick results.

# %%
def extract_node_info(returnanswer):
    #First, parse out the parts of the kg that we want, names and types
    kg_node_names = { n['id']: n['name'] if 'name' in n else n['id'] for n in returnanswer['knowledge_graph']['nodes'] }
    #now put the answers into a table, looking up node/edge info from the above dicts
    #because of the question, we know that we're interested in the binding for "n0"
    answers = [ {"result_id": answer['node_bindings']['n0'], 
                 "result_name": kg_node_names[answer['node_bindings']['n0']], #if 'name' in node else node['id']
                }
              for answer in returnanswer['answers']]
    return pd.DataFrame(answers)

# %% [markdown]
# We can now pass a list of curies to make_shared_symptom_question, and then pass the result to quick.  We'll be using (arbitrarily) the top 5 phenotypes from ROBOKOP's answers to question 1.

# %%
# These are "Maturity-onset diabetes of the young", "Recurrent hypoglycemia", "Glucose intolerance", 
# "Beta-cell dysfunction", and "Hyperinsulinemia"
diabetes_symptoms=['HP:0004904', 'HP:0001988', 'HP:0000833', 'HP:0006279','HP:0000842']
diabetes_question = make_shared_symptom_question(diabetes_symptoms)
diabetes_question
# Out:
# {'machine_question': {'edges': [{'id': 'e0',
#     'source_id': 'n0',
#     'target_id': 'n1'},
#    {'id': 'e1', 'source_id': 'n0', 'target_id': 'n2'},
#    {'id': 'e2', 'source_id': 'n0', 'target_id': 'n3'},
#    {'id': 'e3', 'source_id': 'n0', 'target_id': 'n4'},
#    {'id': 'e4', 'source_id': 'n0', 'target_id': 'n5'}],
#   'nodes': [{'id': 'n0', 'type': 'disease'},
#    {'curie': 'HP:0004904', 'id': 'n1', 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0001988', 'id': 'n2', 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0000833', 'id': 'n3', 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0006279', 'id': 'n4', 'type': 'phenotypic_feature'},
#    {'curie': 'HP:0000842', 'id': 'n5', 'type': 'phenotypic_feature'}]},
#  'rebuild': 'False'}

# %%
diabetes_answer = quick(diabetes_question)
diabetes_nodes = extract_node_info(diabetes_answer)
diabetes_nodes
# Out:
# Return Status: 200
#         result_id                                        result_name
# 0   MONDO:0005048  pancreatic insulin-producing neuroendocrine tumor
# 1   MONDO:0005148                           type 2 diabetes mellitus
# 2   MONDO:0002177                          hyperinsulinism (disease)
# 3   MONDO:0005147                           type 1 diabetes mellitus
# 4   MONDO:0005815                 pancreatic neuroendocrine neoplasm
# 5   MONDO:0009831                      malignant pancreatic neoplasm
# 6   MONDO:0005015                        diabetes mellitus (disease)
# 7   MONDO:0002516                            digestive system cancer
# 8   MONDO:0015936                     rare tumor of endocrine glands
# 9   MONDO:0021069                       malignant endocrine neoplasm
# 10  MONDO:0016645                            rare neoplastic disease
# 11  MONDO:0015882                             rare tumor of pancreas
# 12  MONDO:0021040                                pancreatic neoplasm
# 13  MONDO:0019997                     rare gastroenterologic disease
# 14  MONDO:0004972                                            adenoma
# 15  MONDO:0000627                          benign endocrine neoplasm
# 16  MONDO:0004992                                             cancer
# 17  MONDO:0006181                         digestive system carcinoma
# 18  MONDO:0019954                    pancreatic neuroendocrine tumor
# 19  MONDO:0000386   digestive system neuroendocrine tumor, grade 1/2
# 20  MONDO:0021470                        benign neoplasm of pancreas
# 21  MONDO:0015112                            rare pancreatic disease
# 22  MONDO:0002120                           neuroendocrine carcinoma
# 23  MONDO:0004993                                          carcinoma
# 24  MONDO:0019496                            neuroendocrine neoplasm
# 25  MONDO:0005626                                epithelial neoplasm
# 26  MONDO:0015078     gastroenteropancreatic neuroendocrine neoplasm
# 27  MONDO:0018520                  rare epithelial tumor of pancreas
# 28  MONDO:0005893                     pancreatic endocrine carcinoma
# 29  MONDO:0000605                  hypersensitivity reaction disease
# 30  MONDO:0005046                              immune system disease
# 31  MONDO:0002356                                   pancreas disease
# 32  MONDO:0021223                          digestive system neoplasm
# 33  MONDO:0000569             autoimmune disease of endocrine system
# 34  MONDO:0020031                                         rare tumor
# 35  MONDO:0007179                                 autoimmune disease
# 36  MONDO:0020033                               rare digestive tumor
# 37  MONDO:0000385                   benign digestive system neoplasm
# 38  MONDO:0005070                                 neoplasm (disease)
# 39  MONDO:0002082                           endocrine gland neoplasm
# 40  MONDO:0019041                       rare genetic inherited tumor
# 41  MONDO:0005165                                    benign neoplasm
# 42  MONDO:0020005                             rare endocrine disease
# 43  MONDO:0015618                         genetic pancreatic disease
# 44  MONDO:0005066                                  metabolic disease
# 45  MONDO:0023370                     neoplastic disease or syndrome
# 46  MONDO:0005151                           endocrine system disease
# 47  MONDO:0001933                         endocrine pancreas disease
# 48  MONDO:0002908                         glucose metabolism disease
# 49  MONDO:0021200                                       rare disease
# 50  MONDO:0019052                        inborn errors of metabolism
# 51  MONDO:0004335                           digestive system disease
# 52  MONDO:0015615           rare genetic gastroenterological disease
# 53  MONDO:0015967                     rare genetic diabetes mellitus
# 54  MONDO:0015513                     rare genetic endocrine disease
# 55  MONDO:0015122                             rare diabetes mellitus
# 56  MONDO:0019214             inborn carbohydrate metabolic disorder

# %%
#['Exercise-induced asthma(HP:0012652)',
# 'Allergic rhinitis(HP:0003193)',
# 'Obstructive lung disease(HP:0006536)',
# 'Status asthmaticus(HP:0012653)',
# 'Increased IgE level(HP:0003212)',
asthma_symptoms=['HP:0012652','HP:0003193','HP:0006536','HP:0012653','HP:0003212']
asthma_question = make_shared_symptom_question(asthma_symptoms)

# %%
asthma_answer = quick(asthma_question)
asthma_nodes = extract_node_info(asthma_answer)
asthma_nodes
# Out:
# Return Status: 200
#        result_id                      result_name
# 0  MONDO:0004979                           asthma
# 1  MONDO:0005087       respiratory system disease
# 2  MONDO:0000270  lower respiratory tract disease
# 3  MONDO:0001358                bronchial disease

# %% [markdown]
# ### Approach 2: Enriched Expansion

# %% [markdown]
# A downside of the intersection approach above is that the conditions that come out must be attached to every phenotype.  The results then, can be very sensitive to exactly which phenotypes are chosen as input.  A less sensitive way to handle this is to find conditions that are enriched for the list of phenotypes.  This lets us be more open in which phenotypes we're including, and also which conditions are returning.  We'll use the same list of phenotypes for illustration, but it would also make sense to go back to the list and be more inclusive.  We'll also use `include_descendants=True`, but experimentation with that option would be worthwhile.

# %%
def enrichment(type1,identlist,type2,threshhold=None,maxresults=None,numtype1=None,include_descendants=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/enriched/{type1}/{type2}'
    params = { 'threshhold': threshhold, 'max_results': maxresults, 
              'num_type1':numtype1, 'identifiers': identlist, 
              'include_descendants':include_descendants, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.post(url, json = params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
diabetes_enriched = enrichment('phenotypic_feature',diabetes_symptoms,'disease',threshhold=0.01,include_descendants=True)
diabetes_enriched_frame = pd.DataFrame(diabetes_enriched)
diabetes_enriched_frame
# Out:
# Return Status: 200
#                id                                               name  \
# 0   MONDO:0021470                        benign neoplasm of pancreas
# 1   MONDO:0018520                  rare epithelial tumor of pancreas
# 2   MONDO:0019954                    pancreatic neuroendocrine tumor
# 3   MONDO:0015882                             rare tumor of pancreas
# 4   MONDO:0005893                     pancreatic endocrine carcinoma
# 5   MONDO:0005048  pancreatic insulin-producing neuroendocrine tumor
# 6   MONDO:0015078     gastroenteropancreatic neuroendocrine neoplasm
# 7   MONDO:0000386   digestive system neuroendocrine tumor, grade 1/2
# 8   MONDO:0002177                          hyperinsulinism (disease)
# 9   MONDO:0000385                   benign digestive system neoplasm
# 10  MONDO:0021040                                pancreatic neoplasm
# 11  MONDO:0005815                 pancreatic neuroendocrine neoplasm
# 12  MONDO:0015112                            rare pancreatic disease
# 13  MONDO:0019496                            neuroendocrine neoplasm
# 14  MONDO:0009831                      malignant pancreatic neoplasm
# 15  MONDO:0002120                           neuroendocrine carcinoma
# 16  MONDO:0020033                               rare digestive tumor
# 17  MONDO:0006181                         digestive system carcinoma
# 18  MONDO:0000627                          benign endocrine neoplasm
# 19  MONDO:0012381             hyperinsulinism due to INSR deficiency
# 20  MONDO:0004972                                            adenoma
# 21  MONDO:0002909                                      hyperglycemia
# 22  MONDO:0011236      hyperinsulinism due to glucokinase deficiency
# 23  MONDO:0021069                       malignant endocrine neoplasm
# 24  MONDO:0015967                     rare genetic diabetes mellitus
# 25  MONDO:0015122                             rare diabetes mellitus
# 26  MONDO:0002516                            digestive system cancer
# 27  MONDO:0015887                      rare diabetes mellitus type 2
# 28  MONDO:0002908                         glucose metabolism disease
# 29  MONDO:0005803            hyperinsulinemic hypoglycemia (disease)
# ..            ...                                                ...
# 70  MONDO:0005294                        peripheral vascular disease
# 71  MONDO:0006920                               prediabetes syndrome
# 72  MONDO:0016365               familial primary hyperparathyroidism
# 73  MONDO:0015897                           rare hyperparathyroidism
# 74  MONDO:0016166                        genetic hyperparathyroidism
# 75  MONDO:0015076                             rare parathyroid tumor
# 76  MONDO:0019716                                overgrowth syndrome
# 77  MONDO:0021227                             adrenal gland neoplasm
# 78  MONDO:0000208  microcephaly, short stature, and impaired gluc...
# 79  MONDO:0005495                              adrenal gland disease
# 80  MONDO:0017169                       multiple endocrine neoplasia
# 81  MONDO:0007179                                 autoimmune disease
# 82  MONDO:0004335                           digestive system disease
# 83  MONDO:0000605                  hypersensitivity reaction disease
# 84  MONDO:0009278  hyperinsulinism due to short chain 3-hydroxyla...
# 85  MONDO:0016464                 insulin-resistance syndrome type B
# 86  MONDO:0012382         hyperinsulinemic hypoglycemia, familial, 4
# 87  MONDO:0019041                       rare genetic inherited tumor
# 88  MONDO:0021360                         tumor of parathyroid gland
# 89  MONDO:0017713   disorder of fatty acid oxidation and ketogenesis
# 90  MONDO:0011717            hyperinsulinism-hyperammonemia syndrome
# 91  MONDO:0012819                              diabetic ketoacidosis
# 92  MONDO:0020031                                         rare tumor
# 93  MONDO:0016789                       pyruvate metabolism disorder
# 94  MONDO:0012552                multiple endocrine neoplasia type 4
# 95  MONDO:0015079                       multiple polyglandular tumor
# 96  MONDO:0002311                           retinal vascular disease
# 97  MONDO:0012396                   exercise-induced hyperinsulinism
# 98  MONDO:0017820   disease with Cushing syndrome as a major feature
# 99  MONDO:0018912                                   Cushing syndrome
#
#                p
# 0   1.303577e-15
# 1   5.203943e-13
# 2   5.203943e-13
# 3   5.426063e-13
# 4   8.133611e-13
# 5   1.714101e-12
# 6   3.699616e-12
# 7   4.745344e-12
# 8   1.624023e-11
# 9   1.753150e-11
# 10  1.798102e-11
# 11  1.001174e-10
# 12  1.264321e-10
# 13  1.364278e-10
# 14  1.138610e-09
# 15  1.254751e-09
# 16  2.451311e-09
# 17  2.513367e-09
# 18  3.211813e-09
# 19  3.227641e-09
# 20  5.917591e-09
# 21  1.667579e-08
# 22  1.987394e-08
# 23  2.760039e-08
# 24  2.987812e-08
# 25  3.014086e-08
# 26  5.123924e-08
# 27  6.686082e-08
# 28  1.584145e-07
# 29  1.685121e-07
# ..           ...
# 70  7.855958e-05
# 71  8.424667e-05
# 72  8.619374e-05
# 73  9.017612e-05
# 74  9.017612e-05
# 75  9.017612e-05
# 76  9.108314e-05
# 77  9.148926e-05
# 78  9.221183e-05
# 79  1.040031e-04
# 80  1.050625e-04
# 81  1.058161e-04
# 82  1.393964e-04
# 83  1.440037e-04
# 84  1.591695e-04
# 85  1.591695e-04
# 86  1.744040e-04
# 87  1.821274e-04
# 88  1.936267e-04
# 89  1.936267e-04
# 90  2.005620e-04
# 91  2.072701e-04
# 92  2.216728e-04
# 93  2.364105e-04
# 94  2.722505e-04
# 95  2.764383e-04
# 96  2.892531e-04
# 97  2.898572e-04
# 98  3.024493e-04
# 99  3.676989e-04
#
# [100 rows x 3 columns]

# %%
asthma_enriched = enrichment('phenotypic_feature',asthma_symptoms,'disease',threshhold=0.1,include_descendants=True)
asthma_enriched_frame = pd.DataFrame(asthma_enriched)
asthma_enriched_frame
# Out:
# Return Status: 200
#                id                                               name  \
# 0   MONDO:0001358                                  bronchial disease
# 1   MONDO:0004979                                             asthma
# 2   MONDO:0000771                       allergic respiratory disease
# 3   MONDO:0020028                  rare allergic respiratory disease
# 4   MONDO:0000270                    lower respiratory tract disease
# 5   MONDO:0005749                             eosinophilic pneumonia
# 6   MONDO:0002267                           obstructive lung disease
# 7   MONDO:0011751                           COPD, severe early onset
# 8   MONDO:0002232                               nasal cavity disease
# 9   MONDO:0005990                                         tracheitis
# 10  MONDO:0003781                                         bronchitis
# 11  MONDO:0011786                                  allergic rhinitis
# 12  MONDO:0003014                                           rhinitis
# 13  MONDO:0016575                         primary ciliary dyskinesia
# 14  MONDO:0015490              predominantly small-vessel vasculitis
# 15  MONDO:0004822                                     bronchiectasis
# 16  MONDO:0018395    male infertility due to sperm motility disorder
# 17  MONDO:0020027                              rare allergic disease
# 18  MONDO:0002436                                       nose disease
# 19  MONDO:0002567                                   tracheal disease
# 20  MONDO:0005961                                          sinusitis
# 21  MONDO:0002211                                  B cell deficiency
# 22  MONDO:0005271                                   allergic disease
# 23  MONDO:0005087                         respiratory system disease
# 24  MONDO:0005002              chronic obstructive pulmonary disease
# 25  MONDO:0017034  secondary interstitial lung disease in childho...
# 26  MONDO:0017035  secondary interstitial lung disease in childho...
# 27  MONDO:0007535                    emphysema, hereditary pulmonary
# 28  MONDO:0004553                      extrinsic allergic alveolitis
# 29  MONDO:0015243            allergic bronchopulmonary aspergillosis
# ..            ...                                                ...
# 70  MONDO:0018389  male infertility due to gonadal dysgenesis or ...
# 71  MONDO:0018037                                 hyper-IgE syndrome
# 72  MONDO:0021117                                      lung neoplasm
# 73  MONDO:0002468                       hyperimmunoglobulin syndrome
# 74  MONDO:0000807                                      latex allergy
# 75  MONDO:0005642                              atopic conjunctivitis
# 76  MONDO:0019305            immune deficiency with skin involvement
# 77  MONDO:0005849                             milk allergic reaction
# 78  MONDO:0001672                                    bronchus cancer
# 79  MONDO:0002273                  plasma protein metabolism disease
# 80  MONDO:0005657                                      aspergillosis
# 81  MONDO:0000376                          respiratory system cancer
# 82  MONDO:0008345                      idiopathic pulmonary fibrosis
# 83  MONDO:0017898  autosomal recessive mendelian susceptibility t...
# 84  MONDO:0019602                     other inborn metabolic disease
# 85  MONDO:0002977           autoimmune disease of the nervous system
# 86  MONDO:0017260           systemic diseases with posterior uveitis
# 87  MONDO:0016338                non-familial dilated cardiomyopathy
# 88  MONDO:0020000                           rare respiratory disease
# 89  MONDO:0015923                     acquired peripheral neuropathy
# 90  MONDO:0017271  autosomal ichthyosis syndrome with prominent h...
# 91  MONDO:0017261                  systemic diseases with panuveitis
# 92  MONDO:0015187                    rare inflammatory bowel disease
# 93  MONDO:0018882                                         vasculitis
# 94  MONDO:0001540                                         bagassosis
# 95  MONDO:0005113                       bacterial infectious disease
# 96  MONDO:0001901                  selective IgG subclass deficiency
# 97  MONDO:0015926                                     pneumoconiosis
# 98  MONDO:0005968                                     sporotrichosis
# 99  MONDO:0002465                            bronchiolitis (disease)
#
#                p
# 0   1.521630e-08
# 1   5.216939e-08
# 2   5.852291e-07
# 3   5.852291e-07
# 4   1.915463e-06
# 5   2.773158e-06
# 6   3.674500e-06
# 7   3.721814e-06
# 8   5.547244e-06
# 9   7.527456e-06
# 10  1.923064e-05
# 11  2.091070e-05
# 12  2.099078e-05
# 13  2.276444e-05
# 14  2.405124e-05
# 15  2.445574e-05
# 16  2.472354e-05
# 17  2.832651e-05
# 18  3.630150e-05
# 19  3.796372e-05
# 20  4.391203e-05
# 21  4.517957e-05
# 22  5.631443e-05
# 23  7.779954e-05
# 24  8.448371e-05
# 25  1.272532e-04
# 26  1.272532e-04
# 27  1.293336e-04
# 28  1.334457e-04
# 29  1.698329e-04
# ..           ...
# 70  2.948045e-03
# 71  2.948631e-03
# 72  3.015905e-03
# 73  3.065772e-03
# 74  3.245567e-03
# 75  3.306585e-03
# 76  3.419016e-03
# 77  3.814169e-03
# 78  3.880037e-03
# 79  4.013377e-03
# 80  4.015898e-03
# 81  4.043223e-03
# 82  4.148853e-03
# 83  4.205209e-03
# 84  4.496848e-03
# 85  4.630293e-03
# 86  4.856017e-03
# 87  5.006234e-03
# 88  5.166944e-03
# 89  5.201586e-03
# 90  5.232415e-03
# 91  5.362715e-03
# 92  5.463292e-03
# 93  5.525562e-03
# 94  5.541291e-03
# 95  5.650597e-03
# 96  5.698846e-03
# 97  5.778400e-03
# 98  5.858471e-03
# 99  5.858471e-03
#
# [100 rows x 3 columns]
