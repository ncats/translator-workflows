# %% [markdown]
# # Workflow 9: Tissue to Gene Occurrence

# %%
import bicluster_tissue_to_gene, importlib, asyncio

# %%
tissue_to_gene = bicluster_tissue_to_gene.tissue_to_gene()

# %%
tissue_set = ['MONDO:0010150',
'MONDO:0019086',
'MONDO:0006143',
'MONDO:0000554',
'MONDO:0007256',
'MONDO:0005082',
'UBERON:0001830',
'UBERON:0002107',
'UBERON:0002048',
'UBERON:0002469']

# %%
loop = asyncio.get_event_loop()

# %%
counted_genes = loop.run_until_complete(tissue_to_gene.tissue_to_gene_biclusters_async(tissue_set))

# %%
counted_genes[:500]
# Out:
# [('ENSG00000170477.8', 149),
#  ('ENSG00000186566.7', 108),
#  ('ENSG00000135164.14', 105),
#  ('ENSG00000173209.18', 93),
#  ('ENSG00000116539.6', 87),
#  ('ENSG00000137770.9', 86),
#  ('ENSG00000146247.13', 86),
#  ('ENSG00000143442.17', 85),
#  ('ENSG00000135046.9', 84),
#  ('ENSG00000214021.11', 82),
#  ('ENSG00000128422.11', 81),
#  ('ENSG00000115020.12', 79),
#  ('ENSG00000143970.12', 78),
#  ('ENSG00000139350.7', 77),
#  ('ENSG00000118058.16', 77),
#  ('ENSG00000160551.5', 76),
#  ('ENSG00000183426.11', 75),
#  ('ENSG00000134313.10', 75),
#  ('ENSG00000087086.9', 74),
#  ('ENSG00000131023.8', 73),
#  ('ENSG00000120458.5', 72),
#  ('ENSG00000135473.10', 72),
#  ('ENSG00000163482.7', 72),
#  ('ENSG00000204149.5', 72),
#  ('ENSG00000075826.12', 72),
#  ('ENSG00000104859.10', 72),
#  ('ENSG00000023516.7', 72),
#  ('ENSG00000176444.14', 71),
#  ('ENSG00000168096.10', 71),
#  ('ENSG00000148399.7', 70),
#  ('ENSG00000138468.11', 70),
#  ('ENSG00000123066.3', 70),
# ...
