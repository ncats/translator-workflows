# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q8 - "What genes are expressed in $anatomical_entity"
#### Set anatomical_entity to the desired curie id and run.
request = { "query_type_id": "Q8", "terms": { "anatomical_entity": "UBERON:0001638" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# vein	UBERON:0001638	selectin E	UniProtKB:P16581
# vein	UBERON:0001638	DnaJ heat shock protein family (Hsp40) member C8	UniProtKB:O75937
# vein	UBERON:0001638	2'-5'-oligoadenylate synthetase 2	UniProtKB:P29728
# vein	UBERON:0001638	matrix metallopeptidase 1	UniProtKB:P03956
# vein	UBERON:0001638	ring finger protein 40	UniProtKB:O75150
# vein	UBERON:0001638	proline rich 29	UniProtKB:P0C7W0
# vein	UBERON:0001638	tumor protein p53	UniProtKB:P04637
# vein	UBERON:0001638	bone morphogenetic protein 6	UniProtKB:P22004
# vein	UBERON:0001638	transmembrane protein 230	UniProtKB:Q96A57
# vein	UBERON:0001638	tribbles pseudokinase 3	UniProtKB:Q96RU7
# vein	UBERON:0001638	nudix hydrolase 16 like 1	UniProtKB:Q9BRJ7
# vein	UBERON:0001638	cullin 7	UniProtKB:Q14999
# vein	UBERON:0001638	matrix metallopeptidase 24	UniProtKB:Q9Y5R2
# vein	UBERON:0001638	matrix metallopeptidase 10	UniProtKB:P09238
# vein	UBERON:0001638	C-X-C motif chemokine ligand 1	UniProtKB:P09341
# vein	UBERON:0001638	inositol hexakisphosphate kinase 1	UniProtKB:Q92551
# vein	UBERON:0001638	activating transcription factor 4	UniProtKB:P18848
# vein	UBERON:0001638	pentraxin 3	UniProtKB:P26022
# vein	UBERON:0001638	basal body orientation factor 1	UniProtKB:Q8ND07
# vein	UBERON:0001638	tribbles pseudokinase 3	UniProtKB:J3KR25
# vein	UBERON:0001638	phospholipase A2 group IVA	UniProtKB:P47712
# vein	UBERON:0001638	ribosomal protein L32	UniProtKB:P62910
# vein	UBERON:0001638	Rac family small GTPase 2	UniProtKB:P15153
# vein	UBERON:0001638	STE20-related kinase adaptor alpha	UniProtKB:Q7RTN6

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-13 22:18:27",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/390",
#     "message": "24 results found",
#     "original_question_text": "",
#     "query_type_id": "Q8",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "selectin E",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17483",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P16581",
#                         "source_id": "UniProtKB:P16581",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is found in cytokine-stimulated endothelial cells and is thought to be responsible for the accumulation of blood leukocytes at sites of inflammation by mediating the adhesion of cells to the vascular lining. It exhibits structural features such as the presence of lectin- and EGF-like domains followed by short consensus repeat (SCR) domains that contain 6 conserved cysteine residues. These proteins are part of the selectin family of cell adhesion molecules. Adhesion molecules participate in the interaction between leukocytes and the endothelium and appear to be involved in the pathogenesis of atherosclerosis. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P16581",
#                         "name": "selectin E",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P16581"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "selectin E",
#                 "UniProtKB:P16581"
#             ],
#             "text": "vein and selectin E are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "DnaJ heat shock protein family (Hsp40) member C8",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17484",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O75937",
#                         "source_id": "UniProtKB:O75937",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:O75937",
#                         "name": "DnaJ heat shock protein family (Hsp40) member C8",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O75937"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "DnaJ heat shock protein family (Hsp40) member C8",
#                 "UniProtKB:O75937"
#             ],
#             "text": "vein and DnaJ heat shock protein family (Hsp40) member C8 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "2'-5'-oligoadenylate synthetase 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17485",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P29728",
#                         "source_id": "UniProtKB:P29728",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the 2-5A synthetase family, essential proteins involved in the innate immune response to viral infection. The encoded protein is induced by interferons and uses adenosine triphosphate in 2'-specific nucleotidyl transfer reactions to synthesize 2',5'-oligoadenylates (2-5As). These molecules activate latent RNase L, which results in viral RNA degradation and the inhibition of viral replication. The three known members of this gene family are located in a cluster on chromosome 12. Alternatively spliced transcript variants encoding different isoforms have been described. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P29728",
#                         "name": "2'-5'-oligoadenylate synthetase 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P29728"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "2'-5'-oligoadenylate synthetase 2",
#                 "UniProtKB:P29728"
#             ],
#             "text": "vein and 2'-5'-oligoadenylate synthetase 2 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "matrix metallopeptidase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17486",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P03956",
#                         "source_id": "UniProtKB:P03956",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the peptidase M10 family of matrix metalloproteinases (MMPs). Proteins in this family are involved in the breakdown of extracellular matrix in normal physiological processes, such as embryonic development, reproduction, and tissue remodeling, as well as in disease processes, such as arthritis and metastasis. The encoded preproprotein is proteolytically processed to generate the mature protease. This secreted protease breaks down the interstitial collagens, including types I, II, and III. The gene is part of a cluster of MMP genes on chromosome 11. Mutations in this gene are associated with chronic obstructive pulmonary disease (COPD). Alternative splicing results in multiple transcript variants, at least one of which encodes an isoform that is proteolytically processed. [provided by RefSeq, Jan 2016].",
#                         "id": "UniProtKB:P03956",
#                         "name": "matrix metallopeptidase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P03956"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "matrix metallopeptidase 1",
#                 "UniProtKB:P03956"
#             ],
#             "text": "vein and matrix metallopeptidase 1 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ring finger protein 40",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17487",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O75150",
#                         "source_id": "UniProtKB:O75150",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene contains a RING finger, a motif known to be involved in protein-protein and protein-DNA interactions. This protein was reported to interact with the tumor suppressor protein RB1. Studies of the rat counterpart suggested that this protein may function as an E3 ubiquitin-protein ligase, and facilitate the ubiquitination and degradation of syntaxin 1, which is an essential component of the neurotransmitter release machinery. Multiple alternatively spliced transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, May 2011].",
#                         "id": "UniProtKB:O75150",
#                         "name": "ring finger protein 40",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O75150"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "ring finger protein 40",
#                 "UniProtKB:O75150"
#             ],
#             "text": "vein and ring finger protein 40 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "proline rich 29",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17488",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P0C7W0",
#                         "source_id": "UniProtKB:P0C7W0",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:P0C7W0",
#                         "name": "proline rich 29",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P0C7W0"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "proline rich 29",
#                 "UniProtKB:P0C7W0"
#             ],
#             "text": "vein and proline rich 29 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tumor protein p53",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17489",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P04637",
#                         "source_id": "UniProtKB:P04637",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016].",
#                         "id": "UniProtKB:P04637",
#                         "name": "tumor protein p53",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04637"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "tumor protein p53",
#                 "UniProtKB:P04637"
#             ],
#             "text": "vein and tumor protein p53 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "bone morphogenetic protein 6",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17490",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P22004",
#                         "source_id": "UniProtKB:P22004",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a secreted ligand of the TGF-beta (transforming growth factor-beta) superfamily of proteins. Ligands of this family bind various TGF-beta receptors leading to recruitment and activation of SMAD family transcription factors that regulate gene expression. The encoded preproprotein is proteolytically processed to generate each subunit of the disulfide-linked homodimer. This protein regulates a wide range of biological processes including iron homeostasis, fat and bone development, and ovulation. Differential expression of this gene may be associated with progression of breast and prostate cancer. Mutations in this gene may be associated with iron overload in human patients. [provided by RefSeq, Jul 2016].",
#                         "id": "UniProtKB:P22004",
#                         "name": "bone morphogenetic protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P22004"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "bone morphogenetic protein 6",
#                 "UniProtKB:P22004"
#             ],
#             "text": "vein and bone morphogenetic protein 6 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "transmembrane protein 230",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17491",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q96A57",
#                         "source_id": "UniProtKB:Q96A57",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a multi-pass transmembrane protein that belongs to the TMEM134/TMEM230 protein family. The encoded protein localizes to secretory and recycling vesicle in the neuron and may be involved in synaptic vesicles trafficking and recycling. Mutations in this gene may be linked to familial Parkinson's disease. [provided by RefSeq, Mar 2017].",
#                         "id": "UniProtKB:Q96A57",
#                         "name": "transmembrane protein 230",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q96A57"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "transmembrane protein 230",
#                 "UniProtKB:Q96A57"
#             ],
#             "text": "vein and transmembrane protein 230 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tribbles pseudokinase 3",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17492",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q96RU7",
#                         "source_id": "UniProtKB:Q96RU7",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is a putative protein kinase that is induced by the transcription factor NF-kappaB. The encoded protein is a negative regulator of NF-kappaB and can also sensitize cells to TNF- and TRAIL-induced apoptosis. In addition, this protein can negatively regulate the cell survival serine-threonine kinase AKT1. Differential promoter usage and alternate splicing result in multiple transcript variants. [provided by RefSeq, Jul 2014].",
#                         "id": "UniProtKB:Q96RU7",
#                         "name": "tribbles pseudokinase 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q96RU7"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "tribbles pseudokinase 3",
#                 "UniProtKB:Q96RU7"
#             ],
#             "text": "vein and tribbles pseudokinase 3 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nudix hydrolase 16 like 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17493",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9BRJ7",
#                         "source_id": "UniProtKB:Q9BRJ7",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:Q9BRJ7",
#                         "name": "nudix hydrolase 16 like 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9BRJ7"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "nudix hydrolase 16 like 1",
#                 "UniProtKB:Q9BRJ7"
#             ],
#             "text": "vein and nudix hydrolase 16 like 1 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "cullin 7",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17494",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q14999",
#                         "source_id": "UniProtKB:Q14999",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is a component of an E3 ubiquitin-protein ligase complex. The encoded protein interacts with TP53, CUL9, and FBXW8 proteins. Defects in this gene are a cause of 3M syndrome type 1 (3M1). Two transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Dec 2009].",
#                         "id": "UniProtKB:Q14999",
#                         "name": "cullin 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q14999"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "cullin 7",
#                 "UniProtKB:Q14999"
#             ],
#             "text": "vein and cullin 7 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "matrix metallopeptidase 24",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17495",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9Y5R2",
#                         "source_id": "UniProtKB:Q9Y5R2",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the peptidase M10 family of matrix metalloproteinases (MMPs). Proteins in this family are involved in the breakdown of extracellular matrix in normal physiological processes, such as embryonic development, reproduction, and tissue remodeling, as well as in disease processes, such as arthritis and metastasis. The encoded preproprotein is proteolytically processed to generate the mature protease. Unlike most MMPs, which are secreted, this protease is a member of the membrane-type MMP (MT-MMP) subfamily, contains a transmembrane domain and is expressed at the cell surface. Substrates of this protease include the proteins cadherin 2 and matrix metallopeptidase 2 (also known as 72 kDa type IV collagenase). [provided by RefSeq, Feb 2016].",
#                         "id": "UniProtKB:Q9Y5R2",
#                         "name": "matrix metallopeptidase 24",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9Y5R2"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "matrix metallopeptidase 24",
#                 "UniProtKB:Q9Y5R2"
#             ],
#             "text": "vein and matrix metallopeptidase 24 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "matrix metallopeptidase 10",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17496",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P09238",
#                         "source_id": "UniProtKB:P09238",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the peptidase M10 family of matrix metalloproteinases (MMPs). Proteins in this family are involved in the breakdown of extracellular matrix in normal physiological processes, such as embryonic development, reproduction, and tissue remodeling, as well as in disease processes, such as arthritis and metastasis. The encoded preproprotein is proteolytically processed to generate the mature protease. This secreted protease breaks down fibronectin, laminin, elastin, proteoglycan core protein, gelatins, and several types of collagen. The gene is part of a cluster of MMP genes on chromosome 11. [provided by RefSeq, Jan 2016].",
#                         "id": "UniProtKB:P09238",
#                         "name": "matrix metallopeptidase 10",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P09238"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "matrix metallopeptidase 10",
#                 "UniProtKB:P09238"
#             ],
#             "text": "vein and matrix metallopeptidase 10 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "C-X-C motif chemokine ligand 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17497",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P09341",
#                         "source_id": "UniProtKB:P09341",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This antimicrobial gene encodes a member of the CXC subfamily of chemokines. The encoded protein is a secreted growth factor that signals through the G-protein coupled receptor, CXC receptor 2. This protein plays a role in inflammation and as a chemoattractant for neutrophils. Aberrant expression of this protein is associated with the growth and progression of certain tumors. A naturally occurring processed form of this protein has increased chemotactic activity. Alternate splicing results in coding and non-coding variants of this gene. A pseudogene of this gene is found on chromosome 4. [provided by RefSeq, Sep 2014].",
#                         "id": "UniProtKB:P09341",
#                         "name": "C-X-C motif chemokine ligand 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P09341"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "C-X-C motif chemokine ligand 1",
#                 "UniProtKB:P09341"
#             ],
#             "text": "vein and C-X-C motif chemokine ligand 1 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "inositol hexakisphosphate kinase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17498",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92551",
#                         "source_id": "UniProtKB:Q92551",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the inositol phosphokinase family. The encoded protein may be responsible for the conversion of inositol hexakisphosphate (InsP6) to diphosphoinositol pentakisphosphate (InsP7/PP-InsP5). It may also convert 1,3,4,5,6-pentakisphosphate (InsP5) to PP-InsP4. Alternatively spliced transcript variants have been described. [provided by RefSeq, Jun 2011].",
#                         "id": "UniProtKB:Q92551",
#                         "name": "inositol hexakisphosphate kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92551"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "inositol hexakisphosphate kinase 1",
#                 "UniProtKB:Q92551"
#             ],
#             "text": "vein and inositol hexakisphosphate kinase 1 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "activating transcription factor 4",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17499",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P18848",
#                         "source_id": "UniProtKB:P18848",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a transcription factor that was originally identified as a widely expressed mammalian DNA binding protein that could bind a tax-responsive enhancer element in the LTR of HTLV-1. The encoded protein was also isolated and characterized as the cAMP-response element binding protein 2 (CREB-2). The protein encoded by this gene belongs to a family of DNA-binding proteins that includes the AP-1 family of transcription factors, cAMP-response element binding proteins (CREBs) and CREB-like proteins. These transcription factors share a leucine zipper region that is involved in protein-protein interactions, located C-terminal to a stretch of basic amino acids that functions as a DNA binding domain. Two alternative transcripts encoding the same protein have been described. Two pseudogenes are located on the X chromosome at q28 in a region containing a large inverted duplication. [provided by RefSeq, Sep 2011].",
#                         "id": "UniProtKB:P18848",
#                         "name": "activating transcription factor 4",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P18848"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "activating transcription factor 4",
#                 "UniProtKB:P18848"
#             ],
#             "text": "vein and activating transcription factor 4 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "pentraxin 3",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17500",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P26022",
#                         "source_id": "UniProtKB:P26022",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a member of the pentraxin protein family. The expression of this protein is induced by inflammatory cytokines in response to inflammatory stimuli in several mesenchymal and epithelial cell types, particularly endothelial cells and mononuclear phagocytes. The protein promotes fibrocyte differentiation and is involved in regulating inflammation and complement activation. It also plays a role in angiogenesis and tissue remodeling. The protein serves as a biomarker for several inflammatory conditions. [provided by RefSeq, Jun 2016].",
#                         "id": "UniProtKB:P26022",
#                         "name": "pentraxin 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P26022"
#                     },
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "pentraxin 3",
#                 "UniProtKB:P26022"
#             ],
#             "text": "vein and pentraxin 3 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "basal body orientation factor 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17501",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q8ND07",
#                         "source_id": "UniProtKB:Q8ND07",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:Q8ND07",
#                         "name": "basal body orientation factor 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8ND07"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "basal body orientation factor 1",
#                 "UniProtKB:Q8ND07"
#             ],
#             "text": "vein and basal body orientation factor 1 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "tribbles pseudokinase 3",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17502",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/J3KR25",
#                         "source_id": "UniProtKB:J3KR25",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a putative protein kinase that is induced by the transcription factor NF-kappaB. The encoded protein is a negative regulator of NF-kappaB and can also sensitize cells to TNF- and TRAIL-induced apoptosis. In addition, this protein can negatively regulate the cell survival serine-threonine kinase AKT1. Differential promoter usage and alternate splicing result in multiple transcript variants. [provided by RefSeq, Jul 2014].",
#                         "id": "UniProtKB:J3KR25",
#                         "name": "tribbles pseudokinase 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/J3KR25"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "tribbles pseudokinase 3",
#                 "UniProtKB:J3KR25"
#             ],
#             "text": "vein and tribbles pseudokinase 3 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "phospholipase A2 group IVA",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17503",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P47712",
#                         "source_id": "UniProtKB:P47712",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "This gene encodes a member of the cytosolic phospholipase A2 group IV family. The enzyme catalyzes the hydrolysis of membrane phospholipids to release arachidonic acid which is subsequently metabolized into eicosanoids. Eicosanoids, including prostaglandins and leukotrienes, are lipid-based cellular hormones that regulate hemodynamics, inflammatory responses, and other intracellular pathways. The hydrolysis reaction also produces lysophospholipids that are converted into platelet-activating factor. The enzyme is activated by increased intracellular Ca(2+) levels and phosphorylation, resulting in its translocation from the cytosol and nucleus to perinuclear membrane vesicles. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Jul 2015].",
#                         "id": "UniProtKB:P47712",
#                         "name": "phospholipase A2 group IVA",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P47712"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "phospholipase A2 group IVA",
#                 "UniProtKB:P47712"
#             ],
#             "text": "vein and phospholipase A2 group IVA are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ribosomal protein L32",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17504",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P62910",
#                         "source_id": "UniProtKB:P62910",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "Ribosomes, the organelles that catalyze protein synthesis, consist of a small 40S subunit and a large 60S subunit. Together these subunits are composed of 4 RNA species and approximately 80 structurally distinct proteins. This gene encodes a ribosomal protein that is a component of the 60S subunit. The protein belongs to the L32E family of ribosomal proteins. It is located in the cytoplasm. Although some studies have mapped this gene to 3q13.3-q21, it is believed to map to 3p25-p24. As is typical for genes encoding ribosomal proteins, there are multiple processed pseudogenes of this gene dispersed through the genome. Alternatively spliced transcript variants encoding the same protein have been observed for this gene. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P62910",
#                         "name": "ribosomal protein L32",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P62910"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "ribosomal protein L32",
#                 "UniProtKB:P62910"
#             ],
#             "text": "vein and ribosomal protein L32 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "Rac family small GTPase 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17505",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P15153",
#                         "source_id": "UniProtKB:P15153",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "This gene encodes a member of the Ras superfamily of small guanosine triphosphate (GTP)-metabolizing proteins. The encoded protein localizes to the plasma membrane, where it regulates diverse processes, such as secretion, phagocytosis, and cell polarization. Activity of this protein is also involved in the generation of reactive oxygen species. Mutations in this gene are associated with neutrophil immunodeficiency syndrome. There is a pseudogene for this gene on chromosome 6. [provided by RefSeq, Jul 2013].",
#                         "id": "UniProtKB:P15153",
#                         "name": "Rac family small GTPase 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P15153"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "Rac family small GTPase 2",
#                 "UniProtKB:P15153"
#             ],
#             "text": "vein and Rac family small GTPase 2 are connected by the relationship expressed_in"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "STE20-related kinase adaptor alpha",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/17506",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q7RTN6",
#                         "source_id": "UniProtKB:Q7RTN6",
#                         "target_id": "UBERON:0001638",
#                         "type": "expressed_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "Any of the tubular branching vessels that carry blood from the capillaries toward the heart.",
#                         "id": "UBERON:0001638",
#                         "name": "vein",
#                         "type": "anatomical_entity",
#                         "uri": "http://purl.obolibrary.org/obo/UBERON_0001638"
#                     },
#                     {
#                         "description": "The protein encoded by this gene contains a STE20-like kinase domain, but lacks several residues that are critical for catalytic activity, so it is termed a 'pseudokinase'. The protein forms a heterotrimeric complex with serine/threonine kinase 11 (STK11, also known as LKB1) and the scaffolding protein calcium binding protein 39 (CAB39, also known as MO25). The protein activates STK11 leading to the phosphorylation of both proteins and excluding STK11 from the nucleus. The protein is necessary for STK11-induced G1 cell cycle arrest. A mutation in this gene has been shown to result in polyhydramnios, megalencephaly, and symptomatic epilepsy (PMSE) syndrome. Multiple transcript variants encoding different isoforms have been found for this gene. Additional transcript variants have been described but their full-length nature is not known. [provided by RefSeq, Sep 2009].",
#                         "id": "UniProtKB:Q7RTN6",
#                         "name": "STE20-related kinase adaptor alpha",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q7RTN6"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "vein",
#                 "UBERON:0001638",
#                 "STE20-related kinase adaptor alpha",
#                 "UniProtKB:Q7RTN6"
#             ],
#             "text": "vein and STE20-related kinase adaptor alpha are connected by the relationship expressed_in"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "anatomical_entity": "UBERON:0001638"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
