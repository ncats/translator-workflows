# %% [markdown]
# # Install Python Dependencies (including the NCATS MVP Module Library)

# %%
# You need to figure out where your Python site-packages are... After getting the answer to the following Jupyter 'type' directive
# change the path component 'bin' to 'lib' path, then append the suffix "/site-packages" Then use thge resultng path to 
# find the location at which you can complete 'Step 1' in the following cell.
# !type python
# Out:
# python is /anaconda3/bin/python

# %%
'''
Assuming that we've checked out the NCATS mvp-module-library 
alongside our ncats-translator-workflows project, this should work
'''
import sys
sys.path.append("../mvp-module-library")
#
# Hack to get around problematic updating of distutils installed PyYAML and a slightly older pandas requiring a compatible numpy
#
# Step 1 - MANUALLY remove the PyYAML and numpy module directories from the your site-packages noted above, then...
#
# Step 2 - Install your system (required new PyYAML updated version should be installed alongside?)#
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: ontobio in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.7.2)
# Requirement already satisfied: mygene==3.0.0 in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: numpy==1.16.1 in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (1.16.1)
# Requirement already satisfied: pandas==0.23.4 in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (0.23.4)
# Requirement already satisfied: typing>=0.0 in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (3.6.6)
# Requirement already satisfied: graphviz in /anaconda3/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (0.10.1)
# Requirement already satisfied: pysolr in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: jsobject in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: click in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (7.0)
# Requirement already satisfied: pyyaml>=4.2b1 in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (4.2b4)
# Requirement already satisfied: prefixcommons in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: networkx==2.2 in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (2.2)
# Requirement already satisfied: sparqlwrapper in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (2.21.0)
# Requirement already satisfied: scipy in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: yamldown in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: marshmallow==3.0.0b3 in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (3.0.0b3)
# Requirement already satisfied: cachier in /anaconda3/lib/python3.7/site-packages (from ontobio->-r requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas==0.23.4->-r requirements.txt (line 8)) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas==0.23.4->-r requirements.txt (line 8)) (2018.9)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda3/lib/python3.7/site-packages (from networkx==2.2->ontobio->-r requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: rdflib>=4.0 in /anaconda3/lib/python3.7/site-packages (from sparqlwrapper->ontobio->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->ontobio->-r requirements.txt (line 1)) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->ontobio->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->ontobio->-r requirements.txt (line 1)) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->ontobio->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: portalocker in /anaconda3/lib/python3.7/site-packages (from cachier->ontobio->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: watchdog in /anaconda3/lib/python3.7/site-packages (from cachier->ontobio->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas==0.23.4->-r requirements.txt (line 8)) (1.12.0)
# Requirement already satisfied: pyparsing in /anaconda3/lib/python3.7/site-packages (from rdflib>=4.0->sparqlwrapper->ontobio->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: isodate in /anaconda3/lib/python3.7/site-packages (from rdflib>=4.0->sparqlwrapper->ontobio->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: argh>=0.24.1 in /anaconda3/lib/python3.7/site-packages (from watchdog->cachier->ontobio->-r requirements.txt (line 1)) (0.26.2)
# Requirement already satisfied: pathtools>=0.1.1 in /anaconda3/lib/python3.7/site-packages (from watchdog->cachier->ontobio->-r requirements.txt (line 1)) (0.1.2)

# %%
from BioLink.biolink_client import BioLinkWrapper
import pandas as pd

# %% [markdown]
# # Workflow II Rare Disease Candidates

# %%
from Modules.Mod0_lookups import LookUp

# workflow input is a disease identifier
lu = LookUp()
# Out:
# Mod O DiseaseGeneLookup metadata:
# {'data_type': 'disease',
#  'input_type': {'complexity': 'single', 'id_type': ['MONDO', 'DO', 'OMIM']},
#  'limit': None,
#  'output_type': {'complexity': 'set', 'id_type': 'HGNC'},
#  'predicate': 'blm:gene associated with condition',
#  'source': 'Monarch Biolink',
#  'taxon': 'human'}

# %%
input_disease = 'MONDO:0019391' # Fanconi anemia  
input_object = {
    'input': input_disease,
    'parameters': {
        'taxon': 'human',
        'threshold': None,
    },
}

lu.load_input_object(input_object=input_object)
input_object = lu.input_object
# Out:
# {'description': 'Fanconi anemia (FA) is a hereditary DNA repair disorder '
#                 'characterized by progressive pancytopenia with bone marrow '
#                 'failure, variable congenital malformations and predisposition '
#                 'to develop hematological or solid tumors.',
#  'id': 'MONDO:0019391',
#  'label': 'Fanconi anemia'}

# %%
# get genes associated with disease from Biolink
disease_associated_genes = lu.disease_geneset_lookup()
# create list of gene curies for downstream module input
input_curie_set = disease_associated_genes[['hit_id', 'hit_symbol']].to_dict(orient='records')
# show the disease associated genes
disease_associated_genes['modules'] = 'Mod0'
disease_associated_genes
# genes to investigate TNF, FANCD2OS
# Out:
#          input_id    input_symbol      hit_id hit_symbol  \
# 0   MONDO:0019391  Fanconi anemia   HGNC:1100      BRCA1
# 1   MONDO:0019391  Fanconi anemia   HGNC:1101      BRCA2
# 2   MONDO:0019391  Fanconi anemia   HGNC:1101      BRCA2
# 3   MONDO:0019391  Fanconi anemia  HGNC:11892        TNF
# 4   MONDO:0019391  Fanconi anemia  HGNC:12829      XRCC2
# 5   MONDO:0019391  Fanconi anemia  HGNC:12829      XRCC2
# 6   MONDO:0019391  Fanconi anemia  HGNC:20473      BRIP1
# 7   MONDO:0019391  Fanconi anemia  HGNC:20473      BRIP1
# 8   MONDO:0019391  Fanconi anemia  HGNC:20748      FANCL
# 9   MONDO:0019391  Fanconi anemia  HGNC:20748      FANCL
# 10  MONDO:0019391  Fanconi anemia  HGNC:23168      FANCM
# 11  MONDO:0019391  Fanconi anemia  HGNC:23845       SLX4
# 12  MONDO:0019391  Fanconi anemia  HGNC:23845       SLX4
# 13  MONDO:0019391  Fanconi anemia  HGNC:25009      UBE2T
# 14  MONDO:0019391  Fanconi anemia  HGNC:25539      RFWD3
# 15  MONDO:0019391  Fanconi anemia  HGNC:25568      FANCI
# 16  MONDO:0019391  Fanconi anemia  HGNC:25568      FANCI
# 17  MONDO:0019391  Fanconi anemia  HGNC:26144      PALB2
# 18  MONDO:0019391  Fanconi anemia  HGNC:26144      PALB2
# 19  MONDO:0019391  Fanconi anemia  HGNC:28623   FANCD2OS
# 20  MONDO:0019391  Fanconi anemia   HGNC:3436      ERCC4
# 21  MONDO:0019391  Fanconi anemia   HGNC:3436      ERCC4
# 22  MONDO:0019391  Fanconi anemia   HGNC:3582      FANCA
# 23  MONDO:0019391  Fanconi anemia   HGNC:3582      FANCA
# 24  MONDO:0019391  Fanconi anemia   HGNC:3583      FANCB
# 25  MONDO:0019391  Fanconi anemia   HGNC:3583      FANCB
# 26  MONDO:0019391  Fanconi anemia   HGNC:3584      FANCC
# 27  MONDO:0019391  Fanconi anemia   HGNC:3584      FANCC
# 28  MONDO:0019391  Fanconi anemia   HGNC:3585     FANCD2
# 29  MONDO:0019391  Fanconi anemia   HGNC:3586      FANCE
# 30  MONDO:0019391  Fanconi anemia   HGNC:3587      FANCF
# 31  MONDO:0019391  Fanconi anemia   HGNC:3588      FANCG
# 32  MONDO:0019391  Fanconi anemia   HGNC:3588      FANCG
# 33  MONDO:0019391  Fanconi anemia   HGNC:6764     MAD2L2
# 34  MONDO:0019391  Fanconi anemia   HGNC:6764     MAD2L2
# 35  MONDO:0019391  Fanconi anemia   HGNC:7532        MX1
# 36  MONDO:0019391  Fanconi anemia   HGNC:9817      RAD51
# 37  MONDO:0019391  Fanconi anemia   HGNC:9817      RAD51
# 38  MONDO:0019391  Fanconi anemia   HGNC:9820     RAD51C
# 39  MONDO:0019391  Fanconi anemia   HGNC:9820     RAD51C
#
#                            relation                           sources modules
# 0          pathogenic_for_condition                           clinvar    Mod0
# 1                     has phenotype                           orphane    Mod0
# 2                     is marker for       omim, ctd, orphane, clinvar    Mod0
# 3                     is marker for                               ctd    Mod0
# 4                     has phenotype                           orphane    Mod0
# 5                     is marker for                         ctd, omim    Mod0
# 6                     is marker for                      ctd, orphane    Mod0
# 7   likely_pathogenic_for_condition                omim, ctd, clinvar    Mod0
# 8                     has phenotype                      ctd, orphane    Mod0
# 9                     is marker for                ctd, omim, clinvar    Mod0
# 10                    is marker for                      ctd, orphane    Mod0
# 11                    has phenotype                      ctd, orphane    Mod0
# 12         pathogenic_for_condition                ctd, omim, clinvar    Mod0
# 13                    has phenotype       omim, ctd, clinvar, orphane    Mod0
# 14                    has phenotype                           orphane    Mod0
# 15                    has phenotype                           orphane    Mod0
# 16                    is marker for                ctd, omim, clinvar    Mod0
# 17                    has phenotype                           orphane    Mod0
# 18                    is marker for                omim, ctd, clinvar    Mod0
# 19         pathogenic_for_condition                           clinvar    Mod0
# 20                    has phenotype                           orphane    Mod0
# 21                    is marker for                ctd, omim, clinvar    Mod0
# 22                    has phenotype                           orphane    Mod0
# 23         pathogenic_for_condition                ctd, omim, clinvar    Mod0
# 24                    has phenotype                           orphane    Mod0
# 25         pathogenic_for_condition                omim, ctd, clinvar    Mod0
# 26                    has phenotype                      ctd, orphane    Mod0
# 27  likely_pathogenic_for_condition                omim, ctd, clinvar    Mod0
# 28                    has phenotype  ctd, omim, clinvar, ctd, orphane    Mod0
# 29                    has phenotype       orphane, omim, ctd, clinvar    Mod0
# 30                    has phenotype       ctd, omim, clinvar, orphane    Mod0
# 31                    has phenotype                      ctd, orphane    Mod0
# 32         pathogenic_for_condition                omim, ctd, clinvar    Mod0
# 33                   contributes to                omim, ctd, clinvar    Mod0
# 34                    has phenotype                           orphane    Mod0
# 35                    is marker for                               ctd    Mod0
# 36                    has phenotype                           orphane    Mod0
# 37                    is marker for                ctd, omim, clinvar    Mod0
# 38                    has phenotype                      ctd, orphane    Mod0
# 39  likely_pathogenic_for_condition                omim, ctd, clinvar    Mod0

# %% [markdown]
# # Mod1A Functional Similarity
# ## Find similar genes based on GO functional annotations using OntoBio Jaccard similarity

# %%
from Modules.Mod1A_functional_sim import FunctionalSimilarity

# %% [markdown]
# ## Mod1A_human

# %%
# Module specification
mod1a_input_object_human = {
    'input': input_curie_set,
    'parameters': {
        'taxon': 'human',
        'threshold': 0.75,  # jaccard index threshold
    },
}
    
func_sim_human = FunctionalSimilarity()
# Out:
# Mod1A Functional Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:macromolecular machine to biological process association',
#                'macromolecular machine to molecular activity association'],
#  'source': 'Monarch Biolink'}

# %%
func_sim_human.load_input_object(mod1a_input_object_human)
func_sim_human.load_gene_set()

# %%
func_sim_human.load_associations()

# %%
mod1a_results = func_sim_human.compute_similarity()

# %%
Mod1A_results_human = pd.DataFrame(mod1a_results)
Mod1A_results_human = Mod1A_results_human[~Mod1A_results_human['hit_id'].isin(disease_associated_genes['hit_id'].tolist())].sort_values('score', ascending=False)
Mod1A_results_human['module'] = 'Mod1A'
Mod1A_results_human
# Out:
#         hit_id hit_symbol    input_id input_symbol     score module
# 33  HGNC:26171    FAAP100   HGNC:3583        FANCB  0.857143  Mod1A
# 25  HGNC:26171    FAAP100   HGNC:3583        FANCB  0.857143  Mod1A
# 51  HGNC:26171    FAAP100   HGNC:3587        FANCF  0.857143  Mod1A
# 58  HGNC:24994       INIP   HGNC:3587        FANCF  0.851852  Mod1A
# 40  HGNC:24994       INIP   HGNC:3583        FANCB  0.851852  Mod1A
# 32  HGNC:24994       INIP   HGNC:3583        FANCB  0.851852  Mod1A
# 55  HGNC:28467     FAAP24   HGNC:3587        FANCF  0.827586  Mod1A
# 37  HGNC:28467     FAAP24   HGNC:3583        FANCB  0.827586  Mod1A
# 29  HGNC:28467     FAAP24   HGNC:3583        FANCB  0.827586  Mod1A
# 34  HGNC:25021      ASTE1   HGNC:3583        FANCB  0.793103  Mod1A
# 52  HGNC:25021      ASTE1   HGNC:3587        FANCF  0.793103  Mod1A
# 26  HGNC:25021      ASTE1   HGNC:3583        FANCB  0.793103  Mod1A
# 35  HGNC:22223      EEPD1   HGNC:3583        FANCB  0.785714  Mod1A
# 44  HGNC:26171    FAAP100   HGNC:3586        FANCE  0.785714  Mod1A
# 27  HGNC:22223      EEPD1   HGNC:3583        FANCB  0.785714  Mod1A
# 53  HGNC:22223      EEPD1   HGNC:3587        FANCF  0.785714  Mod1A
# 14  HGNC:20922      SLX1A  HGNC:23845         SLX4  0.782313  Mod1A
# 12  HGNC:20922      SLX1A  HGNC:23845         SLX4  0.782313  Mod1A
# 45  HGNC:22223      EEPD1   HGNC:3586        FANCE  0.777778  Mod1A
# 50  HGNC:24994       INIP   HGNC:3586        FANCE  0.777778  Mod1A
# 47  HGNC:28467     FAAP24   HGNC:3586        FANCE  0.758621  Mod1A

# %% [markdown]
# # MOD1B Phenotype Similarity
# ## Find similar genes based on OwlSim calculated Phenotype Similarity

# %% [markdown]
# ## Mod1B Human

# %%
from Modules.Mod1B1_phenotype_similarity import PhenotypeSimilarity

# %%
# Module specification
mod1b_input_object_human = {
    'input': input_curie_set,
     'parameters': {
        'taxon': 'human',
        'threshold': .50,
    },
}


pheno_sim_human = PhenotypeSimilarity()
# Out:
# Mod1B Phenotype Similarity metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:has phenotype'],
#  'source': 'Monarch Biolink'}

# %%
pheno_sim_human.load_input_object(mod1b_input_object_human)
pheno_sim_human.load_gene_set()

# %%
pheno_sim_human.load_associations()

# %%
mod1b_results = pheno_sim_human.compute_similarity()

# %%
# compute phenotype similarity
Mod1B_results = pd.DataFrame(mod1b_results)
Mod1B_results = Mod1B_results[~Mod1B_results['hit_id'].isin(disease_associated_genes['hit_id'].tolist())].sort_values('score', ascending=False)
Mod1B_results['module'] = 'Mod1B'
Mod1B_results
# Out:
#          hit_id hit_symbol    input_id input_symbol     score module
# 43    HGNC:6709        LTA  HGNC:11892          TNF  0.966887  Mod1B
# 98    HGNC:8143      OPCML  HGNC:20473        BRIP1  0.508246  Mod1B
# 100  HGNC:17271      RRAS2  HGNC:20473        BRIP1  0.508246  Mod1B
# 105   HGNC:7499      MT-TT  HGNC:20473        BRIP1  0.508246  Mod1B
# 121   HGNC:8143      OPCML  HGNC:20473        BRIP1  0.508246  Mod1B
# 123  HGNC:17271      RRAS2  HGNC:20473        BRIP1  0.508246  Mod1B
# 128   HGNC:7499      MT-TT  HGNC:20473        BRIP1  0.508246  Mod1B
# 324   HGNC:8143      OPCML  HGNC:26144        PALB2  0.502967  Mod1B
# 326  HGNC:17271      RRAS2  HGNC:26144        PALB2  0.502967  Mod1B
# 331   HGNC:7499      MT-TT  HGNC:26144        PALB2  0.502967  Mod1B
# 347   HGNC:8143      OPCML  HGNC:26144        PALB2  0.502967  Mod1B
# 349  HGNC:17271      RRAS2  HGNC:26144        PALB2  0.502967  Mod1B
# 354   HGNC:7499      MT-TT  HGNC:26144        PALB2  0.502967  Mod1B

# %% [markdown]
# # Mod1E Protein Interaction

# %% [markdown]
# ## Mod1E Human

# %%
from Modules.Mod1E_interactions import GeneInteractions

# %%
# Module specification
mod1E_input_object_human = {
    'input': input_curie_set,
     'parameters': {
        'taxon': 'human',
        'threshold': None,
    },
}


interactions_human = GeneInteractions()
# Out:
# Mod1E Interaction Network metadata:
# {'input_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'output_type': {'complexity': 'set', 'data_type': 'gene', 'id_type': 'HGNC'},
#  'predicate': ['blm:interacts with'],
#  'source': 'Monarch Biolink'}

# %%
interactions_human.load_input_object(mod1E_input_object_human)
interactions_human.load_gene_set()

# %%
mod1e_results = interactions_human.get_interactions()

# %%
Mod1E_results_human = pd.DataFrame(mod1e_results)

# %%
counts = Mod1E_results_human['hit_symbol'].value_counts().rename_axis('unique_values').to_frame('counts').reset_index()
high_counts = counts[counts['counts'] > 12]['unique_values'].tolist()

# %%
Mod1E_results_final = pd.DataFrame(Mod1E_results_human[Mod1E_results_human['hit_symbol'].isin(high_counts)])

# %%
Mod1E_results_final['module'] = 'Mod1E'

# %%
Mod1E_results_final.head()
# Out:
#         hit_id hit_symbol   input_id input_symbol  score module
# 13  HGNC:10290       RPA2  HGNC:1100        BRCA1      0  Mod1E
# 60   HGNC:1925      CHEK1  HGNC:1100        BRCA1      0  Mod1E
# 66  HGNC:18755      POLE4  HGNC:1100        BRCA1      0  Mod1E
# 70   HGNC:3584      FANCC  HGNC:1100        BRCA1      0  Mod1E
# 92  HGNC:25764       RMI1  HGNC:1100        BRCA1      0  Mod1E

# %%
all_results = pd.concat([Mod1A_results_human, Mod1B_results])

# %%
from Modules.StandardOutput import StandardOutput

# %%
so = StandardOutput(results=all_results.to_dict(orient='records'), input_object=input_object)

# %%
std_api_response_json = so.output_object

# %%
std_api_response_json
# Out:
# {'context': 'https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld',
#  'datetime': '2019-02-22 21:27:11.035156',
#  'id': '',
#  'message': '34 results found',
#  'n_results': 34,
#  'original_question_text': 'What genes are functionally similar to genes associated with MONDO:0019391',
#  'query_type_id': 'query_id',
#  'reasoner_id': 'Orange',
#  'response_code': 'OK',
#  'restated_question_text': 'What genes are functionally similar to genes associated with MONDO:0019391',
#  'result_list': [{'confidence': 0.8571428571428571,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:26171',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:26171',
#       'name': 'FAAP100',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8571428571428571,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:26171',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:26171',
#       'name': 'FAAP100',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8571428571428571,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3587',
#       'target_id': 'HGNC:26171',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:26171',
#       'name': 'FAAP100',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3587',
#       'name': 'FANCF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8518518518518519,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3587',
#       'target_id': 'HGNC:24994',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:24994',
#       'name': 'INIP',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3587',
#       'name': 'FANCF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8518518518518519,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:24994',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:24994',
#       'name': 'INIP',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8518518518518519,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:24994',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:24994',
#       'name': 'INIP',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8275862068965517,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3587',
#       'target_id': 'HGNC:28467',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:28467',
#       'name': 'FAAP24',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3587',
#       'name': 'FANCF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8275862068965517,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:28467',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:28467',
#       'name': 'FAAP24',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.8275862068965517,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:28467',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:28467',
#       'name': 'FAAP24',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7931034482758621,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:25021',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:25021',
#       'name': 'ASTE1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7931034482758621,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3587',
#       'target_id': 'HGNC:25021',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:25021',
#       'name': 'ASTE1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3587',
#       'name': 'FANCF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7931034482758621,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:25021',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:25021',
#       'name': 'ASTE1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7857142857142857,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:22223',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:22223',
#       'name': 'EEPD1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7857142857142857,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3586',
#       'target_id': 'HGNC:26171',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:26171',
#       'name': 'FAAP100',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3586',
#       'name': 'FANCE',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7857142857142857,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3583',
#       'target_id': 'HGNC:22223',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:22223',
#       'name': 'EEPD1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3583',
#       'name': 'FANCB',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7857142857142857,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3587',
#       'target_id': 'HGNC:22223',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:22223',
#       'name': 'EEPD1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3587',
#       'name': 'FANCF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.782312925170068,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:23845',
#       'target_id': 'HGNC:20922',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:20922',
#       'name': 'SLX1A',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:23845',
#       'name': 'SLX4',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.782312925170068,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:23845',
#       'target_id': 'HGNC:20922',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:20922',
#       'name': 'SLX1A',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:23845',
#       'name': 'SLX4',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7777777777777778,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3586',
#       'target_id': 'HGNC:22223',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:22223',
#       'name': 'EEPD1',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3586',
#       'name': 'FANCE',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7777777777777778,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3586',
#       'target_id': 'HGNC:24994',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:24994',
#       'name': 'INIP',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3586',
#       'name': 'FANCE',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.7586206896551724,
#    'essence': 'gene, functional similarity',
#    'id': 'Mod1A',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:3586',
#       'target_id': 'HGNC:28467',
#       'type': 'functially_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:28467',
#       'name': 'FAAP24',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:3586',
#       'name': 'FANCE',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.9668874172185431,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:11892',
#       'target_id': 'HGNC:6709',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:6709',
#       'name': 'LTA',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:11892',
#       'name': 'TNF',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:8143',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:8143',
#       'name': 'OPCML',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:17271',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:17271',
#       'name': 'RRAS2',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:7499',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:7499',
#       'name': 'MT-TT',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:8143',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:8143',
#       'name': 'OPCML',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:17271',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:17271',
#       'name': 'RRAS2',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5082458770614693,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:20473',
#       'target_id': 'HGNC:7499',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:7499',
#       'name': 'MT-TT',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:20473',
#       'name': 'BRIP1',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:8143',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:8143',
#       'name': 'OPCML',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:17271',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:17271',
#       'name': 'RRAS2',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:7499',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:7499',
#       'name': 'MT-TT',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:8143',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:8143',
#       'name': 'OPCML',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:17271',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:17271',
#       'name': 'RRAS2',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''},
#   {'confidence': 0.5029673590504451,
#    'essence': 'gene, phenotypic similarity',
#    'id': 'Mod1B',
#    'reasoner_id': 'orange',
#    'result_graph': {'edge_list': [{'is_defined_by': 'orange',
#       'provided_by': 'BioLink',
#       'source_id': 'HGNC:26144',
#       'target_id': 'HGNC:7499',
#       'type': 'phenotypically_similar_to'}],
#     'node_list': [{'description': 'gene',
#       'id': 'HGNC:7499',
#       'name': 'MT-TT',
#       'type': 'gene',
#       'uri': ''},
#      {'description': 'gene',
#       'id': 'HGNC:26144',
#       'name': 'PALB2',
#       'type': 'gene',
#       'uri': ''}]},
#    'result_type': 'gene',
#    'row_data': ['hit_id,hit_symbol,input_id,input_symbol,score,module'],
#    'text': ''}],
#  'schema_version': '0.8.0',
#  'table_column_names': ['input_id',
#   'input_symbol',
#   'result_id',
#   'result_symbol',
#   'score'],
#  'terms': {'disease': 'gene_id'},
#  'tool_version': 'orange',
#  'type': 'medical_translator_query_response'}

# %%
import requests

# get the URL for these results displayed in the RTX UI
RTX_UI_REQUEST_URL = "https://rtx.ncats.io/api/rtx/v1/response/process"
to_post = {"options": ["Store", "ReturnResponseId"], "responses": [std_api_response_json]}
ui_url = requests.post(RTX_UI_REQUEST_URL, json=to_post)
print("Please visit the following website: https://rtx.ncats.io/?r=%s" % ui_url.json()['response_id'])
# Out:
# Please visit the following website: https://rtx.ncats.io/?r=1316

# %%
# Retrieving Details

print("Please visit the following link to retrieve JSON results: https://rtx.ncats.io/api/rtx/v1/response/%s" % ui_url.json()['response_id'])
# Out:
# Please visit the following link to retrieve JSON results: https://rtx.ncats.io/api/rtx/v1/response/1316
