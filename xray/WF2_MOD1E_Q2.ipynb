# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the the query type to Q3 - "What proteins interact with $protein"
request = { "query_type_id": "Q12", "terms": { "protein": "UniProtKB:Q8IY92" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# source name	source ID	target name	target ID
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	glyceronephosphate O-acyltransferase	UniProtKB:O15228
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	serpin family A member 1	UniProtKB:P01009
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	calmodulin like 3	UniProtKB:P27482
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	adenosylhomocysteinase like 2	UniProtKB:Q96HN2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	calmodulin like 5	UniProtKB:Q9NZT1
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	RAN, member RAS oncogene family	UniProtKB:P62826
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	TBC1 domain family member 4	UniProtKB:O60343
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	translocase of inner mitochondrial membrane 44	UniProtKB:O43615
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ERCC excision repair 4, endonuclease catalytic subunit	UniProtKB:Q92889
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	host cell factor C1	UniProtKB:P51610
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	leucine rich repeat containing 1	UniProtKB:Q9BTT6
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	erythrocyte membrane protein band 4.1 like 3	UniProtKB:Q9Y2J2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	coagulation factor VII	UniProtKB:P08709
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DNA topoisomerase II binding protein 1	UniProtKB:Q92547
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	karyopherin subunit alpha 4	UniProtKB:O00629
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	small ubiquitin-like modifier 2	UniProtKB:P61956
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	La ribonucleoprotein domain family member 7	UniProtKB:Q4G0J3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	checkpoint kinase 1	UniProtKB:O14757
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	G-patch domain containing 4	UniProtKB:Q5T3I0
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	valosin containing protein	UniProtKB:P55072
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DM1 locus, WD repeat containing	UniProtKB:Q09019
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	non-SMC condensin II complex subunit D3	UniProtKB:P42695
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	cullin associated and neddylation dissociated 1	UniProtKB:Q86VP6
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	glycogen synthase 1	UniProtKB:P13807
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	telomeric repeat binding factor 1	UniProtKB:P54274
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoporin 188	UniProtKB:Q5SRE5
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	aspartic peptidase retroviral like 1	UniProtKB:Q53RT3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	treacle ribosome biogenesis factor 1	UniProtKB:Q13428
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	immunoglobulin kappa variable 1-5	UniProtKB:P01602
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein L44	UniProtKB:Q9H9J2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	albumin	UniProtKB:P02768
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	phenylalanyl-tRNA synthetase subunit beta	UniProtKB:Q9NSD9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DNA cross-link repair 1B	UniProtKB:Q9H816
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	TSPY like 1	UniProtKB:Q9H0U9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nardilysin convertase	UniProtKB:O43847
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DEP domain containing 7	UniProtKB:Q96QD5
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	damage specific DNA binding protein 1	UniProtKB:Q16531
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ubiquitin like modifier activating enzyme 5	UniProtKB:Q9GZZ9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	programmed cell death 2 like	UniProtKB:Q9BRP1
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ATP synthase membrane subunit DAPIT	UniProtKB:Q96IX5
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mutS homolog 2	UniProtKB:P43246
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	heat shock protein family B (small) member 1	UniProtKB:P04792
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	MAGE family member D1	UniProtKB:Q9Y5V3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	A-kinase anchoring protein 11	UniProtKB:Q9UKA4
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	NMD3 ribosome export adaptor	UniProtKB:Q96D46
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein S21	UniProtKB:P82921
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	RNA polymerase II subunit G	UniProtKB:P62487
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	immunoglobulin heavy constant mu	UniProtKB:P01871
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	small ubiquitin-like modifier 3	UniProtKB:P55854
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SLX4 interacting protein	UniProtKB:Q5VYV7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	plastin 3	UniProtKB:P13797
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	muskelin 1	UniProtKB:Q9UL63
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	adaptor related protein complex 3 subunit mu 1	UniProtKB:Q9Y2T2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DExD-box helicase 39A	UniProtKB:O00148
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	casein kinase 2 alpha 1	UniProtKB:P68400
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	BCL2 associated athanogene 5	UniProtKB:Q9UL15
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	karyopherin subunit alpha 3	UniProtKB:O00505
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	importin 7	UniProtKB:O95373
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoporin 155	UniProtKB:O75694
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein phosphatase 2 regulatory subunit Bgamma	UniProtKB:Q9Y2T4
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial calcium uptake 1	UniProtKB:Q9BPX6
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	solute carrier family 25 member 13	UniProtKB:Q9UJS0
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	egl-9 family hypoxia inducible factor 3	UniProtKB:Q9H6Z9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ubiquitin protein ligase E3 component n-recognin 5	UniProtKB:O95071
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ribonuclease/angiogenin inhibitor 1	UniProtKB:P13489
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ubiquitin specific peptidase 45	UniProtKB:Q70EL2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	small ubiquitin-like modifier 1	UniProtKB:P63165
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ribosome binding protein 1	UniProtKB:Q9P2E9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DEAD-box helicase 24	UniProtKB:Q9GZR7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	cortactin	UniProtKB:Q14247
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	fatty acid binding protein 5	UniProtKB:Q01469
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	PNMA family member 2	UniProtKB:Q9UL42
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	peptidylprolyl cis/trans isomerase, NIMA-interacting 1	UniProtKB:Q13526
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein L9	UniProtKB:Q9BYD2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	poly(ADP-ribose) polymerase 1	UniProtKB:P09874
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein S16	UniProtKB:Q9Y3D3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	RAD54 like 2	UniProtKB:Q9Y4B4
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	FTO, alpha-ketoglutarate dependent dioxygenase	UniProtKB:Q9C0B1
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SDE2 telomere maintenance homolog	UniProtKB:Q6IQ49
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	proliferating cell nuclear antigen	UniProtKB:P12004
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein phosphatase, Mg2+/Mn2+ dependent 1G	UniProtKB:O15355
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	transglutaminase 3	UniProtKB:Q08188
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	sushi repeat containing protein X-linked	UniProtKB:P78539
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	serpin family B member 5	UniProtKB:P36952
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	amyloid beta precursor protein	UniProtKB:P05067
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	peroxisomal biogenesis factor 5	UniProtKB:P50542
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	G elongation factor mitochondrial 1	UniProtKB:Q96RP9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	transferrin	UniProtKB:P02787
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SART1, U4/U6.U5 tri-snRNP-associated protein 1	UniProtKB:O43290
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SEH1 like nucleoporin	UniProtKB:Q96EE3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	filamin A	UniProtKB:P21333
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DnaJ heat shock protein family (Hsp40) member B6	UniProtKB:O75190
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	casein kinase 2 beta	UniProtKB:P67870
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	PGAM family member 5, mitochondrial serine/threonine protein phosphatase	UniProtKB:Q96HS1
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	TERF2 interacting protein	UniProtKB:Q9NYB0
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	GPN-loop GTPase 3	UniProtKB:Q9UHW5
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	immunoglobulin heavy constant alpha 1	UniProtKB:P01876
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	proteasome subunit beta 4	UniProtKB:P28070
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	corneodesmosin	UniProtKB:Q15517
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	filaggrin	UniProtKB:P20930
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	serpin family B member 4	UniProtKB:P48594
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	kelch like ECH associated protein 1	UniProtKB:Q14145
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein L41	UniProtKB:Q8IXM3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	Ran GTPase activating protein 1	UniProtKB:P46060
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	calponin 3	UniProtKB:Q15417
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	myosin heavy chain 11	UniProtKB:P35749
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	aminoadipate-semialdehyde dehydrogenase-phosphopantetheinyl transferase	UniProtKB:Q9NRN7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	chromosome 11 open reading frame 58	UniProtKB:O00193
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	GID complex subunit 8 homolog	UniProtKB:Q9NWU2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SLX1 homolog A, structure-specific endonuclease subunit	UniProtKB:Q9BQ83
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	karyopherin subunit alpha 1	UniProtKB:P52294
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	homeobox C9	UniProtKB:P31274
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	RAN binding protein 9	UniProtKB:Q96S59
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	MUS81 structure-specific endonuclease subunit	UniProtKB:Q96NY9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	essential meiotic structure-specific endonuclease 1	UniProtKB:Q96AY2
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	testis expressed 10	UniProtKB:Q9NXF1
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoporin 93	UniProtKB:Q8N1F7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	Parkinsonism associated deglycase	UniProtKB:Q99497
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	alkB homolog 2, alpha-ketoglutarate dependent dioxygenase	UniProtKB:Q6NS38
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ubiquitin C	UniProtKB:P0CG48
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	gephyrin	UniProtKB:Q9NQX3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	TOR signaling pathway regulator	UniProtKB:O75663
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	desmocollin 1	UniProtKB:Q08554
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DDB1 and CUL4 associated factor 10	UniProtKB:Q5QP82
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	autophagy related 7	UniProtKB:O95352
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	CWC15 spliceosome associated protein homolog	UniProtKB:Q9P013
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	G elongation factor mitochondrial 2	UniProtKB:Q969S9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ERCC excision repair 1, endonuclease non-catalytic subunit	UniProtKB:P07992
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	scribbled planar cell polarity protein	UniProtKB:Q14160
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein S31	UniProtKB:Q92665
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ankyrin repeat domain 17	UniProtKB:O75179
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein phosphatase 2 regulatory subunit B''alpha	UniProtKB:Q06190
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	adenosylhomocysteinase like 1	UniProtKB:O43865
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	family with sequence similarity 192 member A	UniProtKB:Q9GZU8
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoporin 50	UniProtKB:Q9UKX7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ring finger protein 138	UniProtKB:Q8WVD3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein L15	UniProtKB:Q9P015
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mutS homolog 3	UniProtKB:P20585
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	valyl-tRNA synthetase	UniProtKB:P26640
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	pre-mRNA processing factor 31	UniProtKB:Q8WWY3
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	homeobox B9	UniProtKB:P17482
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	telomeric repeat binding factor 2	UniProtKB:Q15554
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ATP synthase peripheral stalk subunit OSCP	UniProtKB:P48047
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein phosphatase 2 regulatory subunit Bdelta	UniProtKB:Q66LE6
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	ubiquitin conjugating enzyme E2 O	UniProtKB:Q9C0C9
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	mitochondrial ribosomal protein S11	UniProtKB:P82912
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	haptoglobin	UniProtKB:P00738
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	DnaJ heat shock protein family (Hsp40) member C9	UniProtKB:Q8WXX5
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	coatomer protein complex subunit gamma 1	UniProtKB:Q9Y678
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	zyxin	UniProtKB:Q15942
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	protein kinase C iota	UniProtKB:P41743
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	replication protein A1	UniProtKB:P27694
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	myosin IC	UniProtKB:O00159
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	sequestosome 1	UniProtKB:Q13501
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	SprT-like N-terminal domain	UniProtKB:Q9H040
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	tubulin tyrosine ligase like 12	UniProtKB:Q14166
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	methylphosphate capping enzyme	UniProtKB:Q7L2J0
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	thymidine kinase 1	UniProtKB:P04183
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	nucleoporin 153	UniProtKB:P49790
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	S100 calcium binding protein A8	UniProtKB:P05109
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	zinc finger protein 282	UniProtKB:Q9UDV7
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	polo like kinase 1	UniProtKB:P53350
# SLX4 structure-specific endonuclease subunit	UniProtKB:Q8IY92	solute carrier family 25 member 1	UniProtKB:P53007

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-09-12 22:01:33",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/383",
#     "message": "163 results found",
#     "original_question_text": "",
#     "query_type_id": "Q12",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "",
#     "result_list": [
#         {
#             "confidence": 1.0,
#             "essence": "glyceronephosphate O-acyltransferase",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7148",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O15228",
#                         "source_id": "UniProtKB:O15228",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes an enzyme located in the peroxisomal membrane which is essential to the synthesis of ether phospholipids. Mutations in this gene are associated with rhizomelic chondrodysplasia punctata. Two transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Oct 2015].",
#                         "id": "UniProtKB:O15228",
#                         "name": "glyceronephosphate O-acyltransferase",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O15228"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "glyceronephosphate O-acyltransferase",
#                 "UniProtKB:O15228"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and glyceronephosphate O-acyltransferase are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "serpin family A member 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7149",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P01009",
#                         "source_id": "UniProtKB:P01009",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene is secreted and is a serine protease inhibitor whose targets include elastase, plasmin, thrombin, trypsin, chymotrypsin, and plasminogen activator. Defects in this gene can cause emphysema or liver disease. Several transcript variants encoding the same protein have been found for this gene. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P01009",
#                         "name": "serpin family A member 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P01009"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "serpin family A member 1",
#                 "UniProtKB:P01009"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and serpin family A member 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "calmodulin like 3",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7150",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P27482",
#                         "source_id": "UniProtKB:P27482",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:P27482",
#                         "name": "calmodulin like 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P27482"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "calmodulin like 3",
#                 "UniProtKB:P27482"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and calmodulin like 3 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "adenosylhomocysteinase like 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7151",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q96HN2",
#                         "source_id": "UniProtKB:Q96HN2",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene acts as a homotetramer and may be involved in the conversion of S-adenosyl-L-homocysteine to L-homocysteine and adenosine. Several transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jun 2011].",
#                         "id": "UniProtKB:Q96HN2",
#                         "name": "adenosylhomocysteinase like 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q96HN2"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "adenosylhomocysteinase like 2",
#                 "UniProtKB:Q96HN2"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and adenosylhomocysteinase like 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "calmodulin like 5",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7152",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9NZT1",
#                         "source_id": "UniProtKB:Q9NZT1",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a novel calcium binding protein expressed in the epidermis and related to the calmodulin family of calcium binding proteins. Functional studies with recombinant protein demonstrate it does bind calcium and undergoes a conformational change when it does so. Abundant expression is detected only in reconstructed epidermis and is restricted to differentiating keratinocytes. In addition, it can associate with transglutaminase 3, shown to be a key enzyme in the terminal differentiation of keratinocytes. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q9NZT1",
#                         "name": "calmodulin like 5",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9NZT1"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "calmodulin like 5",
#                 "UniProtKB:Q9NZT1"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and calmodulin like 5 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "RAN, member RAS oncogene family",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7153",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P62826",
#                         "source_id": "UniProtKB:P62826",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "RAN (ras-related nuclear protein) is a small GTP binding protein belonging to the RAS superfamily that is essential for the translocation of RNA and proteins through the nuclear pore complex. The RAN protein is also involved in control of DNA synthesis and cell cycle progression. Nuclear localization of RAN requires the presence of regulator of chromosome condensation 1 (RCC1). Mutations in RAN disrupt DNA synthesis. Because of its many functions, it is likely that RAN interacts with several other proteins. RAN regulates formation and organization of the microtubule network independently of its role in the nucleus-cytosol exchange of macromolecules. RAN could be a key signaling molecule regulating microtubule polymerization during mitosis. RCC1 generates a high local concentration of RAN-GTP around chromatin which, in turn, induces the local nucleation of microtubules.  RAN is an androgen receptor (AR) coactivator that binds differentially with different lengths of polyglutamine within the androgen receptor. Polyglutamine repeat expansion in the AR is linked to Kennedy's disease (X-linked spinal and bulbar muscular atrophy). RAN coactivation of the AR diminishes with polyglutamine expansion within the AR, and this weak coactivation may lead to partial androgen insensitivity during the development of Kennedy's disease. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P62826",
#                         "name": "RAN, member RAS oncogene family",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P62826"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "RAN, member RAS oncogene family",
#                 "UniProtKB:P62826"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and RAN, member RAS oncogene family are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "TBC1 domain family member 4",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7154",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O60343",
#                         "source_id": "UniProtKB:O60343",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of the Tre-2/BUB2/CDC16 domain family. The protein encoded by this gene is a Rab-GTPase-activating protein, and contains two phopshotyrosine-binding domains (PTB1 and PTB2), a calmodulin-binding domain (CBD), a Rab-GTPase domain, and multiple AKT phosphomotifs. This protein is thought to play an important role in glucose homeostasis by regulating the insulin-dependent trafficking of the glucose transporter 4 (GLUT4), important for removing glucose from the bloodstream into skeletal muscle and fat tissues. Reduced expression of this gene results in an increase in GLUT4 levels at the plasma membrane, suggesting that this protein is important in intracellular retention of GLUT4 under basal conditions. When exposed to insulin, this protein is phosphorylated, dissociates from GLUT4 vesicles, resulting in increased GLUT4 at the cell surface, and enhanced glucose transport. Phosphorylation of this protein by AKT is required for proper translocation of GLUT4 to the cell surface. Individuals homozygous for a mutation in this gene are at higher risk for type 2 diabetes and have higher levels of circulating glucose and insulin levels after glucose ingestion. Alternative splicing results in multiple transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015].",
#                         "id": "UniProtKB:O60343",
#                         "name": "TBC1 domain family member 4",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O60343"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "TBC1 domain family member 4",
#                 "UniProtKB:O60343"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and TBC1 domain family member 4 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "translocase of inner mitochondrial membrane 44",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7155",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O43615",
#                         "source_id": "UniProtKB:O43615",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a peripheral membrane protein associated with the mitochondrial inner membrane translocase, which functions in the import of proteins across the mitochondrial inner membrane and into the mitochondrial matrix. The encoded protein mediates binding of mitochondrial heat shock protein 70 to the translocase of inner mitochondrial membrane 23 (TIM23) complex. Expression of this gene is upregulated in kidney in a mouse model of diabetes. A mutation in this gene is associated with familial oncocytic thyroid carcinoma. [provided by RefSeq, Jul 2016].",
#                         "id": "UniProtKB:O43615",
#                         "name": "translocase of inner mitochondrial membrane 44",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O43615"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "translocase of inner mitochondrial membrane 44",
#                 "UniProtKB:O43615"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and translocase of inner mitochondrial membrane 44 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "ERCC excision repair 4, endonuclease catalytic subunit",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7156",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92889",
#                         "source_id": "UniProtKB:Q92889",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene forms a complex with ERCC1 and is involved in the 5' incision made during nucleotide excision repair. This complex is a structure specific DNA repair endonuclease that interacts with EME1. Defects in this gene are a cause of xeroderma pigmentosum complementation group F (XP-F), or xeroderma pigmentosum VI (XP6).[provided by RefSeq, Mar 2009].",
#                         "id": "UniProtKB:Q92889",
#                         "name": "ERCC excision repair 4, endonuclease catalytic subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92889"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "ERCC excision repair 4, endonuclease catalytic subunit",
#                 "UniProtKB:Q92889"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and ERCC excision repair 4, endonuclease catalytic subunit are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "host cell factor C1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7157",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P51610",
#                         "source_id": "UniProtKB:P51610",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of the host cell factor family and encodes a protein with five Kelch repeats, a fibronectin-like motif, and six HCF repeats, each of which contains a highly specific cleavage signal. This nuclear coactivator is proteolytically cleaved at one of the six possible sites, resulting in the creation of an N-terminal chain and the corresponding C-terminal chain. The final form of this protein consists of noncovalently bound N- and C-terminal chains. The protein is involved in control of the cell cycle and transcriptional regulation during herpes simplex virus infection. Alternatively spliced variants which encode different protein isoforms have been described; however, not all variants have been fully characterized. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P51610",
#                         "name": "host cell factor C1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P51610"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "host cell factor C1",
#                 "UniProtKB:P51610"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and host cell factor C1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "leucine rich repeat containing 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7158",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9BTT6",
#                         "source_id": "UniProtKB:Q9BTT6",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:Q9BTT6",
#                         "name": "leucine rich repeat containing 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9BTT6"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "leucine rich repeat containing 1",
#                 "UniProtKB:Q9BTT6"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and leucine rich repeat containing 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "erythrocyte membrane protein band 4.1 like 3",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7159",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9Y2J2",
#                         "source_id": "UniProtKB:Q9Y2J2",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:Q9Y2J2",
#                         "name": "erythrocyte membrane protein band 4.1 like 3",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9Y2J2"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "erythrocyte membrane protein band 4.1 like 3",
#                 "UniProtKB:Q9Y2J2"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and erythrocyte membrane protein band 4.1 like 3 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "coagulation factor VII",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7160",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P08709",
#                         "source_id": "UniProtKB:P08709",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes coagulation factor VII which is a vitamin K-dependent factor essential for hemostasis. This factor circulates in the blood in a zymogen form, and is converted to an active form by either factor IXa, factor Xa, factor XIIa, or thrombin by minor proteolysis. Upon activation of the factor VII, a heavy chain containing a catalytic domain and a light chain containing 2 EGF-like domains are generated, and two chains are held together by a disulfide bond. In the presence of factor III and calcium ions, the activated factor then further activates the coagulation cascade by converting factor IX to factor IXa and/or factor X to factor Xa. Defects in this gene can cause coagulopathy. Alternative splicing results in multiple transcript variants encoding different isoforms that may undergo similar proteolytic processing to generate mature polypeptides. [provided by RefSeq, Aug 2015].",
#                         "id": "UniProtKB:P08709",
#                         "name": "coagulation factor VII",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P08709"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "coagulation factor VII",
#                 "UniProtKB:P08709"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and coagulation factor VII are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "DNA topoisomerase II binding protein 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7161",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92547",
#                         "source_id": "UniProtKB:Q92547",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a binding protein which interacts with the C-terminal region of topoisomerase II beta. This interaction suggests a supportive role for this protein in the catalytic reactions of topoisomerase II beta through transient breakages of DNA strands. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:Q92547",
#                         "name": "DNA topoisomerase II binding protein 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92547"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "DNA topoisomerase II binding protein 1",
#                 "UniProtKB:Q92547"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and DNA topoisomerase II binding protein 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "karyopherin subunit alpha 4",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7162",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O00629",
#                         "source_id": "UniProtKB:O00629",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The nuclear import of karyophilic proteins is directed by short amino acid sequences termed nuclear localization signals (NLSs). Karyopherins, or importins, are cytoplasmic proteins that recognize NLSs and dock NLS-containing proteins to the nuclear pore complex. The protein encoded by this gene shares the sequence similarity with Xenopus importin-alpha and Saccharomyces cerevisiae Srp1. This protein is found to interact with the NLSs of DNA helicase Q1 and SV40 T antigen. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:O00629",
#                         "name": "karyopherin subunit alpha 4",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O00629"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "karyopherin subunit alpha 4",
#                 "UniProtKB:O00629"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and karyopherin subunit alpha 4 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "small ubiquitin-like modifier 2",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7163",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P61956",
#                         "source_id": "UniProtKB:P61956",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that is a member of the SUMO (small ubiquitin-like modifier) protein family. It functions in a manner similar to ubiquitin in that it is bound to target proteins as part of a post-translational modification system. However, unlike ubiquitin which targets proteins for degradation, this protein is involved in a variety of cellular processes, such as nuclear transport, transcriptional regulation, apoptosis, and protein stability. It is not active until the last two amino acids of the carboxy-terminus have been cleaved off. Numerous pseudogenes have been reported for this gene. Alternate transcriptional splice variants, encoding different isoforms, have been characterized. [provided by RefSeq, Jul 2008].",
#                         "id": "UniProtKB:P61956",
#                         "name": "small ubiquitin-like modifier 2",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P61956"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "small ubiquitin-like modifier 2",
#                 "UniProtKB:P61956"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and small ubiquitin-like modifier 2 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "La ribonucleoprotein domain family member 7",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7164",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q4G0J3",
#                         "source_id": "UniProtKB:Q4G0J3",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein which is found in the 7SK snRNP (small nuclear ribonucleoprotein). This snRNP complex inhibits a cyclin-dependent kinase, positive transcription elongation factor b, which is required for paused RNA polymerase II at a promoter to begin transcription elongation. A pseudogene of this gene is located on chromosome 3. Alternative splicing results in multiple transcript variants. [provided by RefSeq, May 2012].",
#                         "id": "UniProtKB:Q4G0J3",
#                         "name": "La ribonucleoprotein domain family member 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q4G0J3"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "La ribonucleoprotein domain family member 7",
#                 "UniProtKB:Q4G0J3"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and La ribonucleoprotein domain family member 7 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "checkpoint kinase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7165",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/O14757",
#                         "source_id": "UniProtKB:O14757",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "The protein encoded by this gene belongs to the Ser/Thr protein kinase family. It is required for checkpoint mediated cell cycle arrest in response to DNA damage or the presence of unreplicated DNA. This protein acts to integrate signals from ATM and ATR, two cell cycle proteins involved in DNA damage responses, that also associate with chromatin in meiotic prophase I. Phosphorylation of CDC25A protein phosphatase by this protein is required for cells to delay cell cycle progression in response to double-strand DNA breaks. Several alternatively spliced transcript variants have been found for this gene. [provided by RefSeq, Oct 2011].",
#                         "id": "UniProtKB:O14757",
#                         "name": "checkpoint kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/O14757"
#                     },
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
# ...
#         {
#             "confidence": 1.0,
#             "essence": "thymidine kinase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7305",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P04183",
#                         "source_id": "UniProtKB:P04183",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a cytosolic enzyme that catalyzes the addition of a gamma-phosphate group to thymidine. This creates dTMP and is the first step in the biosynthesis of dTTP, which is one component required for DNA replication. The encoded protein, whose levels fluctuate depending on the cell cycle stage, can act as a low activity dimer or a high activity tetramer. High levels of this protein have been used as a biomarker for diagnosing and categorizing many types of cancers. [provided by RefSeq, Oct 2016].",
#                         "id": "UniProtKB:P04183",
#                         "name": "thymidine kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P04183"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "thymidine kinase 1",
#                 "UniProtKB:P04183"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and thymidine kinase 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "nucleoporin 153",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7306",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P49790",
#                         "source_id": "UniProtKB:P49790",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "Nuclear pore complexes regulate the transport of macromolecules between the nucleus and cytoplasm. They are composed of at least 100 different polypeptide subunits, many of which belong to the nucleoporin family. Nucleoporins are glycoproteins found in nuclear pores and contain characteristic pentapeptide XFXFG repeats as well as O-linked N-acetylglucosamine residues oriented towards the cytoplasm. The protein encoded by this gene has three distinct domains: a N-terminal region containing a pore targeting and an RNA-binding domain domain, a central region containing multiple zinc finger motifs, and a C-terminal region containing multiple XFXFG repeats. Alternative splicing results in multiple transcript variants of this gene. [provided by RefSeq, May 2013].",
#                         "id": "UniProtKB:P49790",
#                         "name": "nucleoporin 153",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P49790"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "nucleoporin 153",
#                 "UniProtKB:P49790"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and nucleoporin 153 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "S100 calcium binding protein A8",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7307",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P05109",
#                         "source_id": "UniProtKB:P05109",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "The protein encoded by this gene is a member of the S100 family of proteins containing 2 EF-hand calcium-binding motifs. S100 proteins are localized in the cytoplasm and/or nucleus of a wide range of cells, and involved in the regulation of a number of cellular processes such as cell cycle progression and differentiation. S100 genes include at least 13 members which are located as a cluster on chromosome 1q21. This protein may function in the inhibition of casein kinase and as a cytokine. Altered expression of this protein is associated with the disease cystic fibrosis. Multiple transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Jan 2016].",
#                         "id": "UniProtKB:P05109",
#                         "name": "S100 calcium binding protein A8",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P05109"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "S100 calcium binding protein A8",
#                 "UniProtKB:P05109"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and S100 calcium binding protein A8 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "zinc finger protein 282",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7308",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q9UDV7",
#                         "source_id": "UniProtKB:Q9UDV7",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "None",
#                         "id": "UniProtKB:Q9UDV7",
#                         "name": "zinc finger protein 282",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q9UDV7"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "zinc finger protein 282",
#                 "UniProtKB:Q9UDV7"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and zinc finger protein 282 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "polo like kinase 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7309",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P53350",
#                         "source_id": "UniProtKB:P53350",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "The Ser/Thr protein kinase encoded by this gene belongs to the CDC5/Polo subfamily. It is highly expressed during mitosis and elevated levels are found in many different types of cancer. Depletion of this protein in cancer cells dramatically inhibited cell proliferation and induced apoptosis; hence, it is a target for cancer therapy. [provided by RefSeq, Sep 2015].",
#                         "id": "UniProtKB:P53350",
#                         "name": "polo like kinase 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P53350"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "polo like kinase 1",
#                 "UniProtKB:P53350"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and polo like kinase 1 are connected by the relationship physically_interacts_with"
#         },
#         {
#             "confidence": 1.0,
#             "essence": "solute carrier family 25 member 1",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/7310",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/P53007",
#                         "source_id": "UniProtKB:P53007",
#                         "target_id": "UniProtKB:Q8IY92",
#                         "type": "physically_interacts_with"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene encodes a protein that functions as an assembly component of multiple structure-specific endonucleases. These endonuclease complexes are required for repair of specific types of DNA lesions and critical for cellular responses to replication fork failure. Mutations in this gene were found in patients with Fanconi anemia. [provided by RefSeq, Sep 2016].",
#                         "id": "UniProtKB:Q8IY92",
#                         "name": "SLX4 structure-specific endonuclease subunit",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q8IY92"
#                     },
#                     {
#                         "description": "This gene encodes a member of the mitochondrial carrier subfamily of solute carrier proteins. Members of this family include nuclear-encoded transporters that translocate small metabolites across the mitochondrial membrane. This protein regulates the movement of citrate across the inner membranes of the mitochondria. Mutations in this gene have been associated with combined D-2- and L-2-hydroxyglutaric aciduria. Pseudogenes of this gene have been identified on chromosomes 7, 11, 16, and 19. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Dec 2013].",
#                         "id": "UniProtKB:P53007",
#                         "name": "solute carrier family 25 member 1",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/P53007"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "SLX4 structure-specific endonuclease subunit",
#                 "UniProtKB:Q8IY92",
#                 "solute carrier family 25 member 1",
#                 "UniProtKB:P53007"
#             ],
#             "text": "SLX4 structure-specific endonuclease subunit and solute carrier family 25 member 1 are connected by the relationship physically_interacts_with"
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "source name",
#         "source ID",
#         "target name",
#         "target ID"
#     ],
#     "terms": {
#         "protein": "UniProtKB:Q8IY92"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
