# %% [markdown]
# # Extract PTSD-related Dense Dynamic Data Cloud using Blackboard
#
# ## John C. Earls (ISB), Eric Sage(UCSD), Mike Yu (UCSD), Kevin Xin(SRI)
#
# **APIs used**:
# * http://isbtranslatorapi.adversary.us/
# * http://www.ndexbio.org/
# * http://biothings.io/
#
# **Preconditions**:
# * The problem of understanding PTSD has been posed to the blackboard.
# * Some text based knowledge source has proposed that adenosine is a key driver of cardiac related pathologies associated with PTSD based on this pnas paper http://www.pnas.org/content/111/8/3188.full performed on mouse models:
#
# > **Adenosine**, an important signaling molecule, affects an array of cardiovascular activities. Elevating the adenosine level in the heart causes vasodilation and an increase in heart rate (33). Adenosine has been implicated in the initial injury process, because it is a well-known signaling molecule for stress and tissue injury (34⇓–36). From this study, we observed a gradual increase in the adenosine deaminase transcript level (peaking in the T3R1 group). This observation may imply a compensatory process in heart tissue to reduce the adenosine level after the tissue is in the wound-healing stage
#
# * The blue team recognizes this beacon as a request to contextualize adenosine using Dense Dynamic Data Clouds
#
# **Blackboard steps performed**:
# * Create seeds from *adenosine*
# * Query HPWP API for Adenosine specific subnetwork
# * Write Adenosine specific subnetwork back to blackboard
# * NDEx imports network from blackboard
# * Some service calculates enrichment for certain metabolic pathways and returns to blackboard
# * Some service leverages the Biothings API to identify drugs that target correlated proteins
# * Some service suggests using correlated Clinical Labs as features for PTSD biomarker
#
# **NOTE** : This is real data, these are real results.  Someone could reasonably follow up on this.

# %%
import urllib2
import json
import requests
import logging
import pandas
from collections import Counter
logging.basicConfig(level=logging.WARNING,
                    format='%(asctime)s %(levelname)s %(message)s',)

#Some helper query functions to API
base_url = 'http://isbtranslatorapi.adversary.us'
def query_isb(endpoint, data={}, base_url=base_url):
    req = requests.post('%s/%s' % (base_url,endpoint), data=data)
    return req.json()

def get_analytes(kwargs):
    kw_local = kwargs.copy()
    frm = 0
    size = 1000
    meta = []
    kw_local['from'] = frm
    kw_local['size'] = size
    res = query_isb('/v1/analyte', data=kw_local)
    meta += res
    # Note: this is relying on the pagination, it would be smarter to just partition
    # the *sig_ids* set which would greatly speed up the query
    while len(res) > 0:
        kw_local['from'] += size
        logging.debug("Saving records from %i to %i" %(frm, frm+size))
        res = query_isb('/v1/analyte', data=kw_local)
        meta+=res
    return meta

# %% [markdown]
# ### The data service identifies a set of metabolites in the DDDC which contain adenosine

# %%
clin_vars = get_analytes({'category':"Metabolites"})
adenosine = [x['_id'] for x in clin_vars if x['_id'].find('adenosine') >-1]
for met in adenosine:
    print met
# Out:
# METAB.None.amino-acid.polyamine-metabolism.5-methylthioadenosine-(mta)
# METAB.None.nucleotide.purine-metabolism--adenine-containing.adenosine
# METAB.None.nucleotide.purine-metabolism--adenine-containing.adenosine-3'-5'-cyclic-monophosphate-(camp)
# METAB.None.nucleotide.purine-metabolism--adenine-containing.adenosine-5'-monophosphate-(amp)
# METAB.None.nucleotide.purine-metabolism--adenine-containing.n1-methyladenosine
# METAB.None.nucleotide.purine-metabolism--adenine-containing.n6-carbamoylthreonyladenosine
# METAB.None.nucleotide.purine-metabolism--adenine-containing.n6-methyladenosine
# METAB.None.nucleotide.purine-metabolism--adenine-containing.n6-succinyladenosine

# %% [markdown]
# ### The data service queries the correlation network from the Hundred Person Wellness Project for analytes related to these seeds

# %%
def get_correlations(kwargs):
    kw_local = kwargs.copy()
    sigs = []
    frm = 0
    size = 10000
    meta = []
    kw_local['from'] = frm
    kw_local['size'] = size
    res = query_isb('v1/correlation', data=kw_local)
    correlations = res[:]
    while len(res) > 0:
        logging.debug("Saving records from %i to %i" %(frm, frm+size))
        kw_local['from'] += size
        frm = kw_local['from']
        res = query_isb('v1/correlation', data=kw_local)
        correlations += res
    return correlations
# get correlation network based on seed network
acorr = get_correlations({'ids1':','.join(adenosine)})
adf = pandas.DataFrame(acorr)
sig_adf = adf[adf.bh_adjusted_pvalue < .1]
nodes = set(sig_adf._id_1.tolist() + sig_adf._id_2.tolist())
my_nodes = {a['_id']: a for a in get_analytes({'ids':','.join(nodes)})}
num_edges = len(sig_adf)
print "%i edges in HPWP in adinine seeded network." % (num_edges,)
num_nodes = len(my_nodes)
print "%i total nodes in HPWP Adenosine seeded subnetwork" % (num_nodes,)
for k, v in Counter([v['category'] for v in my_nodes.values()]).items():
    print "%i %s in HPWP Adenosine seeded network" % (v, k)
# Out:
# 388 edges in HPWP in adinine seeded network.
# 248 total nodes in HPWP Adenosine seeded subnetwork
# 14 Proteomics in HPWP Adenosine seeded network
# 196 Metabolites in HPWP Adenosine seeded network
# 38 Clinical Labs in HPWP Adenosine seeded network

# %% [markdown]
# ### The data service writes the HPWP seeded subnetwork back to the blackboard and is recognized by UCSD's NDEx service as consumable
#
# NDEx service ingests correlation network and generates an NDEx network object that is further computed on and produces a visualization.
#
# see : http://www.ndexbio.org/#/newNetwork/88fd2073-35c1-11e7-8f50-0ac135e8bacf

# %%
rec = sig_adf.to_dict('records')
json.dump(rec, open('sig_edges.json', 'w'))

# %% [markdown]
# ### Some data source performs basic metabolic pathway enrichment on adenisine seeded HPWP correlation network and returns results to blackboard

# %%
import scipy.stats
super_pathways_condition = []
for k, v in my_nodes.items():
    if 'super_pathway' in v:
        super_pathways_condition.append(v['super_pathway'])
spc = Counter(super_pathways_condition)
super_pathways_background = []
for v in clin_vars:
    super_pathways_background.append(v['super_pathway'])
spb = Counter(super_pathways_background)
df = pandas.DataFrame([spc, spb], index=['Adenosine-seeded HPWP', 'Total HPWP'])
perc = (df.iloc[0]/df.iloc[1])*100
perc.name = "Percent"
df = df.append(perc)
s = df.sum(axis=1)
not_ashpwp_total = s['Total HPWP'] - s['Adenosine-seeded HPWP']
odr = {}
pv = {}
for c in df.columns:
    ct = [[df.loc['Adenosine-seeded HPWP',c],  df.loc['Total HPWP',c]-df.loc['Adenosine-seeded HPWP',c]],
          [s['Adenosine-seeded HPWP'], not_ashpwp_total]
    ]
    res = scipy.stats.fisher_exact(ct)
    odr[c] = res[0]
    pv[c] = res[1]
df = df.append(pandas.Series(odr, name="Fisher OR"))
df = df.append(pandas.Series(pv, name="Fisher p-value"))
df.transpose().sort_values("Fisher p-value")
# Out:
#                         Adenosine-seeded HPWP  Total HPWP    Percent  \
# nucleotide                               23.0        32.0  71.875000
# lipid                                    54.0       252.0  21.428571
# carbohydrate                             12.0        18.0  66.666667
# amino-acid                               70.0       156.0  44.871795
# xenobiotics                              17.0        91.0  18.681319
# cofactors-and-vitamins                    4.0        24.0  16.666667
# peptide                                  12.0        27.0  44.444444
# energy                                    4.0         7.0  57.142857
#
#                         Fisher OR  Fisher p-value
# nucleotide               5.358844        0.000010
# lipid                    0.571892        0.001296
# carbohydrate             4.193878        0.004014
# amino-acid               1.706811        0.004598
# xenobiotics              0.481729        0.009971
# cofactors-and-vitamins   0.419388        0.121557
# peptide                  1.677551        0.210427
# energy                   2.795918        0.222863

# %%
import scipy.stats
super_pathways_condition = []
for k, v in my_nodes.items():
    if 'sub_pathway' in v:
        super_pathways_condition.append(v['sub_pathway'])
spc = Counter(super_pathways_condition)
super_pathways_background = []
for v in clin_vars:
    super_pathways_background.append(v['sub_pathway'])
spb = Counter(super_pathways_background)
df = pandas.DataFrame([spc, spb], index=['Adenosine-seeded HPWP', 'Total HPWP'])
df = df.fillna(0.0)
perc = (df.iloc[0]/df.iloc[1])*100
perc.name = "Percent"
df = df.append(perc)
s = df.sum(axis=1)
not_ashpwp_total = s['Total HPWP'] - s['Adenosine-seeded HPWP']
odr = {}
pv = {}
for c in df.columns:
    ct = [[df.loc['Adenosine-seeded HPWP',c],  df.loc['Total HPWP',c]-df.loc['Adenosine-seeded HPWP',c]],
          [s['Adenosine-seeded HPWP'], not_ashpwp_total]
    ]
    res = scipy.stats.fisher_exact(ct)
    odr[c] = res[0]
    pv[c] = res[1]
df = df.append(pandas.Series(odr, name="Fisher OR"))
df = df.append(pandas.Series(pv, name="Fisher p-value"))
df.transpose().sort_values('Fisher p-value')
# Out:
#                                                     Adenosine-seeded HPWP  \
# purine-metabolism,-adenine-containing                                 8.0
# methionine,-cysteine,-sam-and-taurine-metabolism                     10.0
# gamma-glutamyl-amino-acid                                             9.0
# histidine-metabolism                                                  7.0
# aminosugar-metabolism                                                 3.0
# purine-metabolism,-guanine-containing                                 3.0
# pyrimidine-metabolism,-orotate-containing                             3.0
# monoacylglycerol                                                      0.0
# polyamine-metabolism                                                  4.0
# tryptophan-metabolism                                                10.0
# steroid                                                               5.0
# pentose-metabolism                                                    4.0
# primary-bile-acid-metabolism                                          0.0
# tocopherol-metabolism                                                 0.0
# alanine-and-aspartate-metabolism                                      3.0
# ketone-bodies                                                         2.0
# fatty-acid-synthesis                                                  2.0
# pyrimidine-metabolism,-cytidine-containing                            2.0
# food-component/plant                                                  6.0
# mole-%-total-fatty-acid                                               6.0
# polypeptide                                                           0.0
# hemoglobin-and-porphyrin-metabolism                                   0.0
# polyunsaturated-fatty-acid-(n3-and-n6)                                1.0
# chemical                                                              3.0
# fatty-acid-metabolism(acyl-carnitine)                                 2.0
# pyrimidine-metabolism,-uracil-containing                              4.0
# phenylalanine-and-tyrosine-metabolism                                12.0
# oxidative-phosphorylation                                             1.0
# mevalonate-metabolism                                                 1.0
# dipeptide-derivative                                                  1.0
# ...                                                                   ...
# fructose,-mannose-and-galactose-metabolism                            2.0
# lysolipid                                                            11.0
# glutamate-metabolism                                                  1.0
# leucine,-isoleucine-and-valine-metabolism                             8.0
# medium-chain-fatty-acid                                               3.0
# glycine,-serine-and-threonine-metabolism                              3.0
# drug                                                                  2.0
# lysine-metabolism                                                     4.0
# fatty-acid,-dicarboxylate                                             3.0
# secondary-bile-acid-metabolism                                        3.0
# long-chain-fatty-acid                                                 4.0
# purine-metabolism,-(hypo)xanthine/inosine-conta...                    2.0
# urea-cycle;-arginine-and-proline-metabolism                           5.0
# ascorbate-and-aldarate-metabolism                                     1.0
# bacterial/fungal                                                      0.0
# vitamin-b6-metabolism                                                 0.0
# sterol                                                                0.0
# glycerolipid-metabolism                                               0.0
# sphingolipid-metabolism                                               3.0
# phospholipid-metabolism                                               2.0
# glutathione-metabolism                                                1.0
# quantitative-total-fatty-acid                                         0.0
# creatine-metabolism                                                   1.0
# fibrinogen-cleavage-peptide                                           0.0
# dipeptide                                                             2.0
# pantothenate-and-coa-metabolism                                       0.0
# fatty-acid-metabolism-(also-bcaa-metabolism)                          1.0
# fatty-acid-metabolism(acyl-glycine)                                   1.0
# riboflavin-metabolism                                                 0.0
# fatty-acid,-amino                                                     0.0
#
#                                                     Total HPWP     Percent  \
# purine-metabolism,-adenine-containing                      8.0  100.000000
# methionine,-cysteine,-sam-and-taurine-metabolism          15.0   66.666667
# gamma-glutamyl-amino-acid                                 13.0   69.230769
# histidine-metabolism                                      10.0   70.000000
# aminosugar-metabolism                                      3.0  100.000000
# purine-metabolism,-guanine-containing                      3.0  100.000000
# pyrimidine-metabolism,-orotate-containing                  3.0  100.000000
# monoacylglycerol                                          10.0    0.000000
# polyamine-metabolism                                       5.0   80.000000
# tryptophan-metabolism                                     18.0   55.555556
# steroid                                                   33.0   15.151515
# pentose-metabolism                                         6.0   66.666667
# primary-bile-acid-metabolism                               7.0    0.000000
# tocopherol-metabolism                                      7.0    0.000000
# alanine-and-aspartate-metabolism                           4.0   75.000000
# ketone-bodies                                              2.0  100.000000
# fatty-acid-synthesis                                       2.0  100.000000
# pyrimidine-metabolism,-cytidine-containing                 2.0  100.000000
# food-component/plant                                      32.0   18.750000
# mole-%-total-fatty-acid                                   32.0   18.750000
# polypeptide                                                5.0    0.000000
# hemoglobin-and-porphyrin-metabolism                        6.0    0.000000
# polyunsaturated-fatty-acid-(n3-and-n6)                    11.0    9.090909
# chemical                                                  18.0   16.666667
# fatty-acid-metabolism(acyl-carnitine)                     14.0   14.285714
# pyrimidine-metabolism,-uracil-containing                   8.0   50.000000
# phenylalanine-and-tyrosine-metabolism                     28.0   42.857143
# oxidative-phosphorylation                                  1.0  100.000000
# mevalonate-metabolism                                      1.0  100.000000
# dipeptide-derivative                                       1.0  100.000000
# ...                                                        ...         ...
# fructose,-mannose-and-galactose-metabolism                 4.0   50.000000
# lysolipid                                                 40.0   27.500000
# glutamate-metabolism                                       6.0   16.666667
# leucine,-isoleucine-and-valine-metabolism                 29.0   27.586207
# medium-chain-fatty-acid                                    7.0   42.857143
# glycine,-serine-and-threonine-metabolism                   8.0   37.500000
# drug                                                       9.0   22.222222
# lysine-metabolism                                         10.0   40.000000
# fatty-acid,-dicarboxylate                                 12.0   25.000000
# secondary-bile-acid-metabolism                            12.0   25.000000
# long-chain-fatty-acid                                     15.0   26.666667
# purine-metabolism,-(hypo)xanthine/inosine-conta...         6.0   33.333333
# urea-cycle;-arginine-and-proline-metabolism               15.0   33.333333
# ascorbate-and-aldarate-metabolism                          3.0   33.333333
# bacterial/fungal                                           1.0    0.000000
# vitamin-b6-metabolism                                      1.0    0.000000
# sterol                                                     2.0    0.000000
# glycerolipid-metabolism                                    2.0    0.000000
# sphingolipid-metabolism                                   11.0   27.272727
# phospholipid-metabolism                                    6.0   33.333333
# glutathione-metabolism                                     3.0   33.333333
# quantitative-total-fatty-acid                              1.0    0.000000
# creatine-metabolism                                        3.0   33.333333
# fibrinogen-cleavage-peptide                                2.0    0.000000
# dipeptide                                                  6.0   33.333333
# pantothenate-and-coa-metabolism                            1.0    0.000000
# fatty-acid-metabolism-(also-bcaa-metabolism)               3.0   33.333333
# fatty-acid-metabolism(acyl-glycine)                        3.0   33.333333
# riboflavin-metabolism                                      1.0    0.000000
# fatty-acid,-amino                                          2.0    0.000000
#
#                                                     Fisher OR  Fisher p-value
# purine-metabolism,-adenine-containing                     inf        0.000134
# methionine,-cysteine,-sam-and-taurine-metabolism     4.193878        0.009618
# gamma-glutamyl-amino-acid                            4.718112        0.012805
# histidine-metabolism                                 4.892857        0.017439
# aminosugar-metabolism                                     inf        0.034366
# purine-metabolism,-guanine-containing                     inf        0.034366
# pyrimidine-metabolism,-orotate-containing                 inf        0.034366
# monoacylglycerol                                     0.000000        0.035295
# polyamine-metabolism                                 8.387755        0.041468
# tryptophan-metabolism                                2.621173        0.044732
# steroid                                              0.374453        0.052188
# pentose-metabolism                                   4.193878        0.092243
# primary-bile-acid-metabolism                         0.000000        0.103467
# tocopherol-metabolism                                0.000000        0.103467
# alanine-and-aspartate-metabolism                     6.290816        0.103718
# ketone-bodies                                             inf        0.105344
# fatty-acid-synthesis                                      inf        0.105344
# pyrimidine-metabolism,-cytidine-containing                inf        0.105344
# food-component/plant                                 0.483909        0.121635
# mole-%-total-fatty-acid                              0.483909        0.121635
# polypeptide                                          0.000000        0.182490
# hemoglobin-and-porphyrin-metabolism                  0.000000        0.184168
# polyunsaturated-fatty-acid-(n3-and-n6)               0.209694        0.187594
# chemical                                             0.419388        0.204044
# fatty-acid-metabolism(acyl-carnitine)                0.349490        0.244873
# pyrimidine-metabolism,-uracil-containing             2.096939        0.283067
# phenylalanine-and-tyrosine-metabolism                1.572704        0.302547
# oxidative-phosphorylation                                 inf        0.324013
# mevalonate-metabolism                                     inf        0.324013
# dipeptide-derivative                                      inf        0.324013
# ...                                                       ...             ...
# fructose,-mannose-and-galactose-metabolism           2.096939        0.598651
# lysolipid                                            0.795391        0.602442
# glutamate-metabolism                                 0.419388        0.669781
# leucine,-isoleucine-and-valine-metabolism            0.798834        0.687173
# medium-chain-fatty-acid                              1.572704        0.687246
# glycine,-serine-and-threonine-metabolism             1.258163        0.717928
# drug                                                 0.599125        0.725626
# lysine-metabolism                                    1.397959        0.734733
# fatty-acid,-dicarboxylate                            0.698980        0.760105
# secondary-bile-acid-metabolism                       0.698980        0.760105
# long-chain-fatty-acid                                0.762523        0.784066
# purine-metabolism,-(hypo)xanthine/inosine-conta...   1.048469        1.000000
# urea-cycle;-arginine-and-proline-metabolism          1.048469        1.000000
# ascorbate-and-aldarate-metabolism                    1.048469        1.000000
# bacterial/fungal                                     0.000000        1.000000
# vitamin-b6-metabolism                                0.000000        1.000000
# sterol                                               0.000000        1.000000
# glycerolipid-metabolism                              0.000000        1.000000
# sphingolipid-metabolism                              0.786352        1.000000
# phospholipid-metabolism                              1.048469        1.000000
# glutathione-metabolism                               1.048469        1.000000
# quantitative-total-fatty-acid                        0.000000        1.000000
# creatine-metabolism                                  1.048469        1.000000
# fibrinogen-cleavage-peptide                          0.000000        1.000000
# dipeptide                                            1.048469        1.000000
# pantothenate-and-coa-metabolism                      0.000000        1.000000
# fatty-acid-metabolism-(also-bcaa-metabolism)         1.048469        1.000000
# fatty-acid-metabolism(acyl-glycine)                  1.048469        1.000000
# riboflavin-metabolism                                0.000000        1.000000
# fatty-acid,-amino                                    0.000000        1.000000
#
# [73 rows x 5 columns]

# %% [markdown]
# ### Some data source searches for drug targets for proteins in the adenisine seeded HPWP correlation network and returns results to blackboard

# %%
# get protein objects
p = [v for v in my_nodes.values() if v['category'] == "Proteomics"]

'''
load biothings_client and biothings_explorer
'''
from biothings_client import get_client
from biothings_explorer import IdListHandler
md = get_client('drug')
ih = IdListHandler()

# map all proteins to entrezgene using biothings API
symbs = {}
for x in [pp['abbreviation'] for pp in p if 'uniprot' not in pp ]:
    req = requests.get('http://mygene.info/v3/query?q=symbol:%s' % (x,))
    res = req.json()
    if res['total'] == 0:
        req = requests.get('http://mygene.info/v3/query?q=symbol:%s' % (x.replace('_','')))
        res = req.json()
        if res['total'] > 0:
            symbs[x] = res
        else:
            if x == 'PDGF_Subunit_B':
                req = requests.get('http://mygene.info/v3/query?q=symbol:%s' % ('PDGFB',))
                res = req.json()
                symbs[x] = res
            else:
                dd = {'HSP_27':'HSPB1', 'CD40L':'CD154','4E_BP1':'EIF4EBP1','STAMPB': 'STABP'}
                req = requests.get('http://mygene.info/v3/query?q=symbol:%s' % (dd[x],))
                res = req.json()
                if res['total'] > 0:
                     symbs[x] = res                                   
    else:
        symbs[x] = res
     


for pp in p:
    if 'uniprot' in pp:
        req = requests.get('http://mygene.info/v3/query?q=uniprot:%s' % (pp['uniprot']))
        res = req.json()
        symbs[pp['abbreviation']] = res

entrez_map = {k:v['hits'][0]['entrezgene'] for k,v in symbs.items()}

# now map all to uniprot
uniprot_list = ih.list_handler(input_id_list=map(str,entrez_map.values()), input_type='entrez_gene_id', output_type='uniprot_id')
uniprot_map = {k:u for u, k in zip(uniprot_list, entrez_map.keys())}
uniprot_id_list = uniprot_map.values()
#map u back to prots
uniprot2object = {} 
for a,u in uniprot_map.items():
    uniprot2object[u] = [pp for pp in p if pp['abbreviation'] == a][0]


md = get_client("drug")
prot2drug = []
for u in  uniprot_id_list:
    res =  md.query('drugbank.targets.uniprot:%s' % (u,), fields='drugbank.name')
    for j in res['hits']:
        prot2drug.append((u,j['drugbank']['name']))

drug_targets = {}
for u, d in prot2drug:
    drug_targets[d] = uniprot2object[u]
print "Putative drug and their adenisine related protein targets"
print "=" * 20
print json.dumps(drug_targets, indent=2)
# Out:
# Putative drug and their adenisine related protein targets
# ====================
# {
#   "Ethanesulfonic Acid": {
#     "category": "Proteomics",
#     "subsystem": "CVD",
#     "vendor": "Olink",
#     "name": "EGF",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "EGF",
#     "_id": "PROTE.None.CVD.EGF.None"
#   },
#   "OGX-427": {
#     "category": "Proteomics",
#     "subsystem": "Inflammation",
#     "vendor": "Olink",
#     "name": "IL_7",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "IL_7",
#     "_id": "PROTE.None.Inflammation.IL_7.None"
#   },
#   "Alpha-Aminobutyric Acid": {
#     "category": "Proteomics",
#     "subsystem": "Inflammation",
#     "vendor": "Olink",
#     "name": "SIRT2",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "SIRT2",
#     "_id": "PROTE.None.Inflammation.SIRT2.None"
#   },
#   "1,4-Dithiothreitol": {
#     "category": "Proteomics",
#     "subsystem": "CVD",
#     "vendor": "Olink",
#     "name": "ITGB1BP2",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "ITGB1BP2",
#     "_id": "PROTE.None.CVD.ITGB1BP2.None"
#   },
#   "Sucralfate": {
#     "category": "Proteomics",
#     "subsystem": "Inflammation",
#     "vendor": "Olink",
#     "name": "SIRT2",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "SIRT2",
#     "_id": "PROTE.None.Inflammation.SIRT2.None"
#   },
#   "XL647": {
#     "category": "Proteomics",
#     "subsystem": "Inflammation",
#     "vendor": "Olink",
#     "name": "SIRT2",
#     "measurement_technology": "antibody capture",
#     "abbreviation": "SIRT2",
#     "_id": "PROTE.None.Inflammation.SIRT2.None"
#   }
# }

# %% [markdown]
# ### Note these are just a few trivial examples of ways one could leverage DDDC and the Blackboard approach to better understand PTSD.
#
# We havent even looked at the clinical labs, which are enriched for cardiac markers and obvious candidates for study for the purpose of developing cheap ranges to identify solidiers undergoing PTSD.

# %%
print "Clinical Labs"
pandas.DataFrame([v for v in my_nodes.values() if v['category'] == "Clinical Labs"])
# Out:
# Clinical Labs
#                                                  _id       category  \
# 0                      CHEMS.None.Genova.adiponectin  Clinical Labs
# 1                  CHEMS.None.Quest.creatinine_quest  Clinical Labs
# 2                   CHEMS.None.Quest.ldl_small_quest  Clinical Labs
# 3                     CHEMS.None.Genova.benzoic_acid  Clinical Labs
# 4          CHEMS.None.Genova.3_hydroxypropionic_acid  Clinical Labs
# 5                 CHEMS.None.Quest.ldl_pattern_quest  Clinical Labs
# 6            CHEMS.None.Genova.a_ketoisocaproic_acid  Clinical Labs
# 7                   CHEMS.None.Genova.alanine_plasma  Clinical Labs
# 8         CHEMS.None.Genova.3_hydroxyisovaleric_acid  Clinical Labs
# 9               CHEMS.None.Quest.ldl_peak_size_quest  Clinical Labs
# 10              CHEMS.None.AGES.methionine sulfoxide  Clinical Labs
# 11                 CHEMS.None.Genova.hdl_cholesterol  Clinical Labs
# 12      CHEMS.None.Quest.egfr_african_american_quest  Clinical Labs
# 13        CHEMS.None.Genova.3_methylhistidine_plasma  Clinical Labs
# 14  CHEMS.None.Genova.3_methyl_4_hydroxyphenylglycol  Clinical Labs
# 15                 CHEMS.None.Genova.tyrosine_plasma  Clinical Labs
# 16                 CHEMS.None.Genova.body_mass_index  Clinical Labs
# 17                     CHEMS.None.Genova.urea_plasma  Clinical Labs
# 18              CHEMS.None.Genova.small_ldl_particle  Clinical Labs
# 19      CHEMS.None.Genova.linoleic_dihomo_y_linoleic  Clinical Labs
# 20           CHEMS.None.Genova.a_ketoisovaleric_acid  Clinical Labs
# 21              CHEMS.None.AGES.carboxymethyl-lysine  Clinical Labs
# 22                  CHEMS.None.Quest.uric_acid_quest  Clinical Labs
# 23                   CHEMS.None.Genova.linoleic_acid  Clinical Labs
# 24                       CHEMS.None.Genova.c_peptide  Clinical Labs
# 25      CHEMS.None.Quest.egfr_non_afr_american_quest  Clinical Labs
# 26        CHEMS.None.AGES.glyoxal-hydroimidazolone-1  Clinical Labs
# 27        CHEMS.None.Genova.beta_hydroxybutyric_acid  Clinical Labs
# 28    CHEMS.None.Genova.alpha_hydroxyisobutyric_acid  Clinical Labs
# 29     CHEMS.None.Genova.a_keto_b_methylvaleric_acid  Clinical Labs
# 30                    CHEMS.None.Genova.behenic_acid  Clinical Labs
# 31                 CHEMS.None.Genova.interleukin_il6  Clinical Labs
# 32                         CHEMS.None.Genova.insulin  Clinical Labs
# 33               CHEMS.None.AGES.carboxyethyl-lysine  Clinical Labs
# 34                      CHEMS.None.Genova.oleic_acid  Clinical Labs
# 35                  CHEMS.None.Genova.glycine_plasma  Clinical Labs
# 36                 CHEMS.None.Genova.total_lc_omega9  Clinical Labs
# 37              CHEMS.None.Quest.triglycerides_quest  Clinical Labs
#
#          hmdb                            name  vendor
# 0         NaN                     adiponectin  Genova
# 1         NaN                      creatinine   Quest
# 2         NaN                       ldl_small   Quest
# 3   HMDB01870                    benzoic_acid  Genova
# 4   HMDB00700         3_hydroxypropionic_acid  Genova
# 5         NaN                     ldl_pattern   Quest
# 6   HMDB00695           a_ketoisocaproic_acid  Genova
# 7   HMDB00161                         alanine  Genova
# 8   HMDB00754        3_hydroxyisovaleric_acid  Genova
# 9         NaN                   ldl_peak_size   Quest
# 10        NaN            methionine sulfoxide    AGES
# 11        NaN                 hdl_cholesterol  Genova
# 12        NaN           egfr_african_american   Quest
# 13  HMDB00479               3_methylhistidine  Genova
# 14  HMDB01490  3_methyl_4_hydroxyphenylglycol  Genova
# 15  HMDB00158                        tyrosine  Genova
# 16        NaN                 body_mass_index  Genova
# 17  HMDB00294                            urea  Genova
# 18        NaN              small_ldl_particle  Genova
# 19        NaN      linoleic_dihomo_y_linoleic  Genova
# 20  HMDB00019           a_ketoisovaleric_acid  Genova
# 21        NaN            carboxymethyl-lysine    AGES
# 22        NaN                       uric_acid   Quest
# 23  HMDB00673                   linoleic_acid  Genova
# 24        NaN                       c_peptide  Genova
# 25        NaN           egfr_non_afr_american   Quest
# 26        NaN      glyoxal-hydroimidazolone-1    AGES
# 27  HMDB00357        beta_hydroxybutyric_acid  Genova
# 28  HMDB00729    alpha_hydroxyisobutyric_acid  Genova
# 29  HMDB00491     a_keto_b_methylvaleric_acid  Genova
# 30  HMDB00944                    behenic_acid  Genova
# 31        NaN                 interleukin_il6  Genova
# 32        NaN                         insulin  Genova
# 33        NaN             carboxyethyl-lysine    AGES
# 34  HMDB00207                      oleic_acid  Genova
# 35  HMDB00123                         glycine  Genova
# 36        NaN                 total_lc_omega9  Genova
# 37        NaN                   triglycerides   Quest
