# %% [markdown]
# # Workflow 1, Module 1 (Condition similarity)

# %% [markdown]
# Module one can be interpreted as: "Find me genetic conditions that are phenotypically similar to disease X".  We can attack this problem with our similiarity endpont directly.  This is because
# 1. ROBOKOP implements genetic_condition as a type, so we can use it in the query
# 2. ROBOKOP's similarity endpoint does not require that the query and result type are the same.

# %%
import requests
import pandas as pd

# %%
def similarity(type1,ident,type2,by_type,threshhold=None,maxresults=None,rebuild=None):
    url=f'http://robokop.renci.org/api/simple/similarity/{type1}/{ident}/{type2}/{by_type}'
    params = { 'threshhold': threshhold, 'max_results': maxresults, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.get(url, params = params)
    print( 'Return code:',response.status_code )
    return response.json()

# %%
diabetes = 'MONDO:0005148'
asthma = 'MONDO:0004979'

# %%
gc_similar_to_diabetes=similarity('disease',diabetes,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_diabetes)
# Out:
# Return code: 200
#                 id                                               name  \
# 0    MONDO:0011565                               metabolic syndrome X
# 1    MONDO:0011382                                 sickle cell anemia
# 2    MONDO:0009061                                    cystic fibrosis
# 3    MONDO:0009693                                plasma cell myeloma
# 4    MONDO:0008315                                    prostate cancer
# 5    MONDO:0006507                         hereditary hemochromatosis
# 6    MONDO:0012819                              diabetic ketoacidosis
# 7    MONDO:0018150                                    Gaucher disease
# 8    MONDO:0002413                         glycogen storage disease I
# 9    MONDO:0008763                                   Alstrom syndrome
# 10   MONDO:0002615                            xanthomatosis (disease)
# 11   MONDO:0010526                                      Fabry disease
# 12   MONDO:0010196                                    Werner syndrome
# 13   MONDO:0008364                                    Raynaud disease
# 14   MONDO:0010602                                       hemophilia A
# 15   MONDO:0010789                                     MELAS syndrome
# 16   MONDO:0010200                                     Wilson disease
# 17   MONDO:0007191                                     Behcet disease
# 18   MONDO:0008056                          myotonic dystrophy type 1
# 19   MONDO:0001076                                glucose intolerance
# 20   MONDO:0016239                                         cystinosis
# 21   MONDO:0005100                                 systemic sclerosis
# 22   MONDO:0009410                                    Addison disease
# 23   MONDO:0019402                                   beta thalassemia
# 24   MONDO:0008575                                nicotine dependence
# 25   MONDO:0007886                           uterine corpus leiomyoma
# 26   MONDO:0010086                       sudden infant death syndrome
# 27   MONDO:0008678                                  Williams syndrome
# 28   MONDO:0013282                     alpha 1-antitrypsin deficiency
# 29   MONDO:0000984                                        thalassemia
# ..             ...                                                ...
# 220  MONDO:0017337  inherited isolated adrenal insufficiency due t...
# 221  MONDO:0018919                           McCune-Albright syndrome
# 222  MONDO:0004639                perinatal necrotizing enterocolitis
# 223  MONDO:0008394                            Silver-Russell syndrome
# 224  MONDO:0015028                                   48,XXYY syndrome
# 225  MONDO:0014888                                    MIRAGE syndrome
# 226  MONDO:0010726                                      Rett syndrome
# 227  MONDO:0009575  thiamine-responsive megaloblastic anemia syndrome
# 228  MONDO:0012004                        parathyroid gland carcinoma
# 229  MONDO:0009738                                  sialidosis type 2
# 230  MONDO:0009249                    hereditary fructose intolerance
# 231  MONDO:0015779                45,X/46,XY mixed gonadal dysgenesis
# 232  MONDO:0002797                          childhood medulloblastoma
# 233  MONDO:0011829                coenzyme Q10 deficiency, primary, 1
# 234  MONDO:0008891                  riboflavin transporter deficiency
# 235  MONDO:0008428                               septooptic dysplasia
# 236  MONDO:0019929                                  49,XXXXY syndrome
# 237  MONDO:0011441              complex regional pain syndrome type 1
# 238  MONDO:0010785         maternally-inherited diabetes and deafness
# 239  MONDO:0009666              holocarboxylase synthetase deficiency
# 240  MONDO:0008729  congenital adrenal hyperplasia due to 11-beta-...
# 241  MONDO:0008996               Joubert syndrome with hepatic defect
# 242  MONDO:0006277                      lung lymphangioleiomyomatosis
# 243  MONDO:0015285                                     Carney complex
# 244  MONDO:0009499                                     Krabbe disease
# 245  MONDO:0019312                          Hermansky-Pudlak syndrome
# 246  MONDO:0009611                 3-methylglutaconic aciduria type 4
# 247  MONDO:0012455                                 Kleefstra syndrome
# 248  MONDO:0009717                           Schwartz-Jampel syndrome
# 249  MONDO:0011758                                    Hurler syndrome
#
#      similarity
# 0      0.480357
# 1      0.341598
# 2      0.335616
# 3      0.327296
# 4      0.315625
# 5      0.308271
# 6      0.305970
# 7      0.300251
# 8      0.297872
# 9      0.292398
# 10     0.292101
# 11     0.290780
# 12     0.290647
# 13     0.284058
# 14     0.281792
# 15     0.279373
# 16     0.275424
# 17     0.274780
# 18     0.272606
# 19     0.271863
# 20     0.271057
# 21     0.268456
# 22     0.266471
# 23     0.263309
# 24     0.262522
# 25     0.262178
# 26     0.256839
# 27     0.254220
# 28     0.248299
# 29     0.247761
# ..          ...
# 220    0.170492
# 221    0.170396
# 222    0.170358
# 223    0.170183
# 224    0.170088
# 225    0.169935
# 226    0.169890
# 227    0.169748
# 228    0.169521
# 229    0.169355
# 230    0.169284
# 231    0.169054
# 232    0.169014
# 233    0.168966
# 234    0.168831
# 235    0.168693
# 236    0.168571
# 237    0.168504
# 238    0.168421
# 239    0.168403
# 240    0.168301
# 241    0.168168
# 242    0.167987
# 243    0.167975
# 244    0.167457
# 245    0.167169
# 246    0.166948
# 247    0.166889
# 248    0.166667
# 249    0.166445
#
# [250 rows x 3 columns]

# %%
gc_similar_to_asthma=similarity('disease',asthma,'genetic_condition','phenotypic_feature',threshhold=0.05)
pd.DataFrame(gc_similar_to_asthma)
# Out:
# Return code: 200
#                 id                                               name  \
# 0    MONDO:0010086                       sudden infant death syndrome
# 1    MONDO:0007186                    gastroesophageal reflux disease
# 2    MONDO:0009061                                    cystic fibrosis
# 3    MONDO:0018305                      chronic granulomatous disease
# 4    MONDO:0009971              newborn respiratory distress syndrome
# 5    MONDO:0010518                           Wiskott-Aldrich syndrome
# 6    MONDO:0013282                     alpha 1-antitrypsin deficiency
# 7    MONDO:0008575                                nicotine dependence
# 8    MONDO:0018229                           Stevens-Johnson syndrome
# 9    MONDO:0010602                                       hemophilia A
# 10   MONDO:0011382                                 sickle cell anemia
# 11   MONDO:0008364                                    Raynaud disease
# 12   MONDO:0008840                              ataxia telangiectasia
# 13   MONDO:0011096                       autosomal agammaglobulinemia
# 14   MONDO:0007191                                     Behcet disease
# 15   MONDO:0005100                                 systemic sclerosis
# 16   MONDO:0015517                   common variable immunodeficiency
# 17   MONDO:0015977                                 agammaglobulinemia
# 18   MONDO:0010383                                 fragile X syndrome
# 19   MONDO:0010604                                       hemophilia B
# 20   MONDO:0009623                         Nijmegen breakage syndrome
# 21   MONDO:0010526                                      Fabry disease
# 22   MONDO:0001901                  selective IgG subclass deficiency
# 23   MONDO:0015974         severe combined immunodeficiency (disease)
# 24   MONDO:0009666              holocarboxylase synthetase deficiency
# 25   MONDO:0008315                                    prostate cancer
# 26   MONDO:0005835                                     Lynch syndrome
# 27   MONDO:0018150                                    Gaucher disease
# 28   MONDO:0013863   combined immunodeficiency due to LRBA deficiency
# 29   MONDO:0001982                               Niemann-Pick disease
# ..             ...                                                ...
# 220  MONDO:0000607      primary cutaneous T-cell non-Hodgkin lymphoma
# 221  MONDO:0009499                                     Krabbe disease
# 222  MONDO:0010631                             incontinentia pigmenti
# 223  MONDO:0009863              BH4-deficient hyperphenylalaninemia A
# 224  MONDO:0014722                                   Roifman syndrome
# 225  MONDO:0012176                                   Emanuel syndrome
# 226  MONDO:0008667                          von Hippel-Lindau disease
# 227  MONDO:0014367                       Aicardi-Goutieres syndrome 7
# 228  MONDO:0010500    intellectual disability, X-linked, syndromic 33
# 229  MONDO:0009289                        glycogen storage disease IC
# 230  MONDO:0005808                           inclusion conjunctivitis
# 231  MONDO:0009218                          Farber lipogranulomatosis
# 232  MONDO:0014200  aldosterone-producing adenoma with seizures an...
# 233  MONDO:0008346                            pulmonary hemosiderosis
# 234  MONDO:0016022                     early myoclonic encephalopathy
# 235  MONDO:0012589                              Pitt-Hopkins syndrome
# 236  MONDO:0013546  mitochondrial complex V (ATP synthase) deficie...
# 237  MONDO:0008393  Rubinstein-Taybi syndrome due to CREBBP mutations
# 238  MONDO:0013276                                  Reynolds syndrome
# 239  MONDO:0019499                                    Turner syndrome
# 240  MONDO:0016028                                    erythromelalgia
# 241  MONDO:0009561                                 alpha-mannosidosis
# 242  MONDO:0008948                     cerebrotendinous xanthomatosis
# 243  MONDO:0010726                                      Rett syndrome
# 244  MONDO:0005775          glucosephosphate dehydrogenase deficiency
# 245  MONDO:0011776                                     CINCA syndrome
# 246  MONDO:0018060                   congenital fibrinogen deficiency
# 247  MONDO:0013925  methylmalonic acidemia with homocystinuria, ty...
# 248  MONDO:0020439                     patent foramen ovale (disease)
# 249  MONDO:0007918  microcephaly with or without chorioretinopathy...
#
#      similarity
# 0      0.360169
# 1      0.337719
# 2      0.334459
# 3      0.305835
# 4      0.300236
# 5      0.299603
# 6      0.297872
# 7      0.290780
# 8      0.285996
# 9      0.285714
# 10     0.276699
# 11     0.274545
# 12     0.274390
# 13     0.273902
# 14     0.268702
# 15     0.260365
# 16     0.257732
# 17     0.257194
# 18     0.254860
# 19     0.251101
# 20     0.250493
# 21     0.250000
# 22     0.247396
# 23     0.246503
# 24     0.244898
# 25     0.239623
# 26     0.239085
# 27     0.237263
# 28     0.235751
# 29     0.234694
# ..          ...
# 220    0.176596
# 221    0.176221
# 222    0.176090
# 223    0.176039
# 224    0.175983
# 225    0.175879
# 226    0.175824
# 227    0.175711
# 228    0.175503
# 229    0.175309
# 230    0.175000
# 231    0.174877
# 232    0.174825
# 233    0.174797
# 234    0.174636
# 235    0.174632
# 236    0.174603
# 237    0.174535
# 238    0.174528
# 239    0.174419
# 240    0.174129
# 241    0.174129
# 242    0.173820
# 243    0.173759
# 244    0.173210
# 245    0.173121
# 246    0.172949
# 247    0.172811
# 248    0.172775
# 249    0.172764
#
# [250 rows x 3 columns]
