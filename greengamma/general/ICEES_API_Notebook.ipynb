# %% [markdown]
# # ICEES API Notebook - RENCI Green Team
#
# ### __Example ICEES API Queries and Approaches for CQ1 and CQ4__

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>1a)</b> Create a cohort using the '/cohort' endpoint, linked below. <br><br>We'll start with the "accept" : "text/tabular" header/output, as it is more human-readable. The "accept" : "application/json" header/output will be demonstrated later on.
# </div>

# %% [markdown]
# https://icees.renci.org/apidocs/#/default/post__version___table___year__cohort

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br> version = 1.0.0, <br> table = patient, <br> year = 2010, <br> MaxDailyPM2.5Exposure > 2, <br> TotalEDInpatientVisits < 2
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>NOTE: </b> 'verify = False' is included in the call to the API to avoid an SSL error.
#     'requests.packages.urllib3.disable_warnings()' is used to suppress warnings about the 'verify=False' parameter.
# </div>

# %%
import requests
requests.packages.urllib3.disable_warnings() 

tabular_headers = {"Content-Type" : "application/json", "accept": "text/tabular"}

CQ4_1a_data = '{"MaxDailyPM2.5Exposure":{"operator":">","value":2},\
    "TotalEDInpatientVisits":{"operator":"<","value":2}}'

response_1a = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort', \
    data=CQ4_1a_data, headers = tabular_headers, verify = False)

output_1a = response_1a.text
print(output_1a)
# Out:
# The Translator Integrated Clinical and Environmental Exposures Service (ICEES) is providing you with Data that have been de-identified in accordance with 45 C.F.R. Â§Â§ 164.514(a) and (b) and that UNC Health Care System (UNCHCS) is permitted to provide under 45 C.F.R. Â§ 164.502(d)(2). Recipient agrees to notify UNCHCS via NC TraCS in the event that Recipient receives any identifiable data in error and to take such measures to return the identifiable data and/or destroy it at the direction of UNCHCS.
#
# Restrictions on Recipientâs Use of Data. Recipient further agrees to use the data exclusively for the purposes and functionalities provided by the ICEES: cohort discovery; feature-rich cohort discovery; hypothesis-driven queries; and exploratory queries. Recipient agrees to use appropriate safeguards to protect the Data from misuse and unauthorized access or disclosure. Recipient will report to UNCHCS any unauthorized access, use, or disclosure of the Data not provided for by the Service of which Recipient becomes aware. Recipient will not attempt to identify the individuals whose information is contained in any Data transferred pursuant to this Service Agreement or attempt to contact those individuals. Recipient agrees not to sell the Data to any third party for any purpose. Recipient agrees not to disclose or publish the Data in any manner that would identify the Data as originating from UNCHCS. Finally, Recipient agrees to reasonably limit the number of queries to the Service per IP address within a given time interval, in order to prevent rapid âattacksâ on the Service.
#
# We kindly request that Translator team members provide proper attribution for any products (e.g., manuscripts, podium presentations, software) derived from work related to Green Team's clinical datasets. Attribution should include acknowledgement of the funder (National Center for Advancing Translational Sciences [NCATS], Biomedical Data Translator Program awards, OT3TR002020 and OT2TR002514), the North Carolina Translational and Clinical Sciences (NC TraCS) Institute (NCATS, Center for Translational Science Award, UL1TR002489), UNC Hospitals and Health Care System, and all Green Team members who contributed to the work.
#
# +-------------+--------+
# | cohort_id   |   size |
# +=============+========+
# | COHORT:31   |   3958 |
# +-------------+--------+

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>1b)</b> Create another cohort using the /cohort endpoint. From here on out, we'll remove the opening text blurb after the request/response is received, for brevity.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br>version = 1.0.0, <br>table = patient, <br>year = 2010, <br>MaxDailyPM2.5Exposure > 2, <br>TotalEDInpatientVisits > 1
# </div>

# %%
CQ4_1b_data = '{"MaxDailyPM2.5Exposure":{"operator":">","value":2}, \
    "TotalEDInpatientVisits":{"operator":">","value":1}}'

response_1b = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort', \
    data=CQ4_1b_data, headers = tabular_headers, verify = False)

output_1b = response_1b.text

output_1b_disclaimer_removed = output_1b.split('Green Team members who contributed to the work.')[1]
print(output_1b_disclaimer_removed)
# Out:
# +-------------+--------+
# | cohort_id   |   size |
# +=============+========+
# | COHORT:32   |    992 |
# +-------------+--------+

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>2a)</b> With two cohorts (COHORT:31 and COHORT:32) defined, let's get a more detailed output for each using the /features endpoint. First, COHORT:31
# </div>

# %% [markdown]
# https://icees.renci.org/apidocs/#/default/get__version___table___year__cohort__cohort_id__features

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br>version = 1.0.0, <br>table = patient, <br>year = 2010, <br>cohort_id = COHORT:31
# </div>

# %%
response_2a = requests.get('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A31/features', \
                           headers = tabular_headers, verify = False)

output_2a = response_2a.text

output_2a_disclaimer_removed = output_2a.split('Green Team members who contributed to the work.')[1]
print(output_2a_disclaimer_removed)
# Out:
# +-----------------------+---------+
# | feature               | count   |
# +=======================+=========+
# | AgeStudyStart = 0-2   | 392     |
# |                       | 9.90%   |
# +-----------------------+---------+
# | AgeStudyStart = 3-17  | 717     |
# |                       | 18.12%  |
# +-----------------------+---------+
# | AgeStudyStart = 18-34 | 572     |
# |                       | 14.45%  |
# +-----------------------+---------+
# | AgeStudyStart = 35-50 | 824     |
# |                       | 20.82%  |
# +-----------------------+---------+
# | AgeStudyStart = 51-69 | 1107    |
# |                       | 27.97%  |
# +-----------------------+---------+
# | AgeStudyStart = 70+   | 346     |
# |                       | 8.74%   |
# +-----------------------+---------+
# +-----------+---------+
# | feature   | count   |
# +===========+=========+
# | Sex = M   | 1693    |
# |           | 42.77%  |
# +-----------+---------+
# | Sex = F   | 2265    |
# |           | 57.23%  |
# +-----------+---------+
# +-----------------------------+---------+
# | feature                     | count   |
# +=============================+=========+
# | Race = African American     | 1097    |
# |                             | 27.72%  |
# +-----------------------------+---------+
# | Race = Asian                | 16      |
# |                             | 0.40%   |
# +-----------------------------+---------+
# | Race = Caucasian            | 2327    |
# |                             | 58.79%  |
# +-----------------------------+---------+
# | Race = Hawaiian / Other Pac | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | Race = Native American      | 13      |
# |                             | 0.33%   |
# +-----------------------------+---------+
# | Race = Other                | 422     |
# |                             | 10.66%  |
# +-----------------------------+---------+
# | Race = Unknown              | 83      |
# |                             | 2.10%   |
# +-----------------------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Ethnicity = H    | 340     |
# |                  | 8.59%   |
# +------------------+---------+
# | Ethnicity = N    | 2578    |
# |                  | 65.13%  |
# +------------------+---------+
# | Ethnicity = U    | 330     |
# |                  | 8.34%   |
# +------------------+---------+
# | Ethnicity = None | 710     |
# |                  | 17.94%  |
# +------------------+---------+
# +--------------+---------+
# | feature      | count   |
# +==============+=========+
# | AsthmaDx = 0 | 2552    |
# |              | 64.48%  |
# +--------------+---------+
# | AsthmaDx = 1 | 1406    |
# |              | 35.52%  |
# +--------------+---------+
# +-------------+---------+
# | feature     | count   |
# +=============+=========+
# | CroupDx = 0 | 3894    |
# |             | 98.38%  |
# +-------------+---------+
# | CroupDx = 1 | 64      |
# |             | 1.62%   |
# +-------------+---------+
# +----------------------+---------+
# | feature              | count   |
# +======================+=========+
# | ReactiveAirwayDx = 0 | 3958    |
# |                      | 100.00% |
# +----------------------+---------+
# | ReactiveAirwayDx = 1 | 0       |
# |                      | 0.00%   |
# +----------------------+---------+
# +-------------+---------+
# | feature     | count   |
# +=============+=========+
# | CoughDx = 0 | 1088    |
# |             | 27.49%  |
# +-------------+---------+
# | CoughDx = 1 | 2870    |
# |             | 72.51%  |
# +-------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | PneumoniaDx = 0 | 3876    |
# |                 | 97.93%  |
# +-----------------+---------+
# | PneumoniaDx = 1 | 82      |
# |                 | 2.07%   |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | ObesityICD = 0 | 3594    |
# |                | 90.80%  |
# +----------------+---------+
# | ObesityICD = 1 | 364     |
# |                | 9.20%   |
# +----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | ObesityBMI = 0 | 3956    |
# |                | 99.95%  |
# +----------------+---------+
# | ObesityBMI = 1 | 2       |
# |                | 0.05%   |
# +----------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | AvgDailyPM2.5Exposure = 1 | 1       |
# |                           | 0.03%   |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 2 | 3       |
# |                           | 0.08%   |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 3 | 1357    |
# |                           | 34.28%  |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 4 | 2576    |
# |                           | 65.08%  |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 5 | 21      |
# |                           | 0.53%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | MaxDailyPM2.5Exposure = 1 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 2 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 3 | 3905    |
# |                           | 98.66%  |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 4 | 44      |
# |                           | 1.11%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 5 | 9       |
# |                           | 0.23%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | AvgDailyOzoneExposure = 1 | 7       |
# |                           | 0.18%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 2 | 3746    |
# |                           | 94.64%  |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 3 | 185     |
# |                           | 4.67%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 4 | 18      |
# |                           | 0.45%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 5 | 2       |
# |                           | 0.05%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | MaxDailyOzoneExposure = 1 | 3829    |
# |                           | 96.74%  |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 2 | 108     |
# |                           | 2.73%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 3 | 13      |
# |                           | 0.33%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 4 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 5 | 8       |
# |                           | 0.20%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | EstResidentialDensity = 1 | 2216    |
# |                           | 55.99%  |
# +---------------------------+---------+
# | EstResidentialDensity = 2 | 1693    |
# |                           | 42.77%  |
# +---------------------------+---------+
# | EstResidentialDensity = 3 | 49      |
# |                           | 1.24%   |
# +---------------------------+---------+
# | EstResidentialDensity = 4 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | EstResidentialDensity = 5 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# +---------------------------------+---------+
# | feature                         | count   |
# +=================================+=========+
# | EstResidentialDesnity25Plus = 1 | 1999    |
# |                                 | 50.51%  |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 2 | 1888    |
# |                                 | 47.70%  |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 3 | 68      |
# |                                 | 1.72%   |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 4 | 3       |
# |                                 | 0.08%   |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 5 | 0       |
# |                                 | 0.00%   |
# +---------------------------------+---------+
# +--------------------------------+---------+
# | feature                        | count   |
# +================================+=========+
# | EstProbabilityNonHispWhite = 1 | 261     |
# |                                | 6.59%   |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 2 | 739     |
# |                                | 18.67%  |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 3 | 1463    |
# |                                | 36.96%  |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 4 | 1488    |
# |                                | 37.59%  |
# +--------------------------------+---------+
# +-----------------------------------------+---------+
# | feature                                 | count   |
# +=========================================+=========+
# | EstProbabilityHouseholdNonHispWhite = 1 | 196     |
# |                                         | 4.95%   |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 2 | 696     |
# |                                         | 17.58%  |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 3 | 1293    |
# |                                         | 32.67%  |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 4 | 1766    |
# |                                         | 44.62%  |
# +-----------------------------------------+---------+
# +------------------------------------------+---------+
# | feature                                  | count   |
# +==========================================+=========+
# | EstProbabilityHighSchoolMaxEducation = 1 | 279     |
# |                                          | 7.05%   |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 2 | 1437    |
# |                                          | 36.31%  |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 3 | 1918    |
# |                                          | 48.46%  |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 4 | 317     |
# |                                          | 8.01%   |
# +------------------------------------------+---------+
# +--------------------------+---------+
# | feature                  | count   |
# +==========================+=========+
# | EstProbabilityNoAuto = 1 | 3673    |
# |                          | 92.80%  |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 2 | 221     |
# |                          | 5.58%   |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 3 | 46      |
# |                          | 1.16%   |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 4 | 2       |
# |                          | 0.05%   |
# +--------------------------+---------+
# +-------------------------------+---------+
# | feature                       | count   |
# +===============================+=========+
# | EstProbabilityNoHealthIns = 1 | 2293    |
# |                               | 57.93%  |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 2 | 1442    |
# |                               | 36.43%  |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 3 | 213     |
# |                               | 5.38%   |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 4 | 3       |
# |                               | 0.08%   |
# +-------------------------------+---------+
# +-----------------------+---------+
# | feature               | count   |
# +=======================+=========+
# | EstProbabilityESL = 1 | 3370    |
# |                       | 85.14%  |
# +-----------------------+---------+
# | EstProbabilityESL = 2 | 486     |
# |                       | 12.28%  |
# +-----------------------+---------+
# | EstProbabilityESL = 3 | 94      |
# |                       | 2.37%   |
# +-----------------------+---------+
# | EstProbabilityESL = 4 | 1       |
# |                       | 0.03%   |
# +-----------------------+---------+
# +------------------------+---------+
# | feature                | count   |
# +========================+=========+
# | EstHouseholdIncome = 1 | 2935    |
# |                        | 74.15%  |
# +------------------------+---------+
# | EstHouseholdIncome = 2 | 858     |
# |                        | 21.68%  |
# +------------------------+---------+
# | EstHouseholdIncome = 3 | 80      |
# |                        | 2.02%   |
# +------------------------+---------+
# | EstHouseholdIncome = 4 | 10      |
# |                        | 0.25%   |
# +------------------------+---------+
# | EstHouseholdIncome = 5 | 1       |
# |                        | 0.03%   |
# +------------------------+---------+
# +---------------------------------+---------+
# | feature                         | count   |
# +=================================+=========+
# | MajorRoadwayHighwayExposure = 1 | 221     |
# |                                 | 5.58%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 2 | 92      |
# |                                 | 2.32%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 3 | 221     |
# |                                 | 5.58%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 4 | 291     |
# |                                 | 7.35%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 5 | 681     |
# |                                 | 17.21%  |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 6 | 2452    |
# |                                 | 61.95%  |
# +---------------------------------+---------+
# +-----------------------------+---------+
# | feature                     | count   |
# +=============================+=========+
# | TotalEDInpatientVisits = 0  | 3158    |
# |                             | 79.79%  |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 1  | 800     |
# |                             | 20.21%  |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 2  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 3  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 4  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 5  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 6  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 7  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 8  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 9  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 10 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 11 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 12 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 13 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 14 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 15 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 16 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 17 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 18 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 19 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 20 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 21 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 22 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 23 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 25 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 27 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 33 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 37 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 50 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 51 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Prednisone = 0 | 3568    |
# |                | 90.15%  |
# +----------------+---------+
# | Prednisone = 1 | 390     |
# |                | 9.85%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Fluticasone = 0 | 3169    |
# |                 | 80.07%  |
# +-----------------+---------+
# | Fluticasone = 1 | 789     |
# |                 | 19.93%  |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Mometasone = 0 | 3898    |
# |                | 98.48%  |
# +----------------+---------+
# | Mometasone = 1 | 60      |
# |                | 1.52%   |
# +----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Budesonide = 0 | 3788    |
# |                | 95.70%  |
# +----------------+---------+
# | Budesonide = 1 | 170     |
# |                | 4.30%   |
# +----------------+---------+
# +--------------------+---------+
# | feature            | count   |
# +====================+=========+
# | Beclomethasone = 0 | 3855    |
# |                    | 97.40%  |
# +--------------------+---------+
# | Beclomethasone = 1 | 103     |
# |                    | 2.60%   |
# +--------------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Ciclesonide = 0 | 3956    |
# |                 | 99.95%  |
# +-----------------+---------+
# | Ciclesonide = 1 | 2       |
# |                 | 0.05%   |
# +-----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Flunisolide = 0 | 3956    |
# |                 | 99.95%  |
# +-----------------+---------+
# | Flunisolide = 1 | 2       |
# |                 | 0.05%   |
# +-----------------+---------+
# +---------------+---------+
# | feature       | count   |
# +===============+=========+
# | Albuterol = 0 | 2802    |
# |               | 70.79%  |
# +---------------+---------+
# | Albuterol = 1 | 1156    |
# |               | 29.21%  |
# +---------------+---------+
# +--------------------+---------+
# | feature            | count   |
# +====================+=========+
# | Metaproterenol = 0 | 3958    |
# |                    | 100.00% |
# +--------------------+---------+
# | Metaproterenol = 1 | 0       |
# |                    | 0.00%   |
# +--------------------+---------+
# +---------------------+---------+
# | feature             | count   |
# +=====================+=========+
# | Diphenhydramine = 0 | 3481    |
# |                     | 87.95%  |
# +---------------------+---------+
# | Diphenhydramine = 1 | 477     |
# |                     | 12.05%  |
# +---------------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Fexofenadine = 0 | 3864    |
# |                  | 97.63%  |
# +------------------+---------+
# | Fexofenadine = 1 | 94      |
# |                  | 2.37%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Cetirizine = 0 | 3755    |
# |                | 94.87%  |
# +----------------+---------+
# | Cetirizine = 1 | 203     |
# |                | 5.13%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Ipratropium = 0 | 3747    |
# |                 | 94.67%  |
# +-----------------+---------+
# | Ipratropium = 1 | 211     |
# |                 | 5.33%   |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Salmeterol = 0 | 3954    |
# |                | 99.90%  |
# +----------------+---------+
# | Salmeterol = 1 | 4       |
# |                | 0.10%   |
# +----------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Arformoterol = 0 | 3956    |
# |                  | 99.95%  |
# +------------------+---------+
# | Arformoterol = 1 | 2       |
# |                  | 0.05%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Formoterol = 0 | 3945    |
# |                | 99.67%  |
# +----------------+---------+
# | Formoterol = 1 | 13      |
# |                | 0.33%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Indacaterol = 0 | 3958    |
# |                 | 100.00% |
# +-----------------+---------+
# | Indacaterol = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Theophylline = 0 | 3952    |
# |                  | 99.85%  |
# +------------------+---------+
# | Theophylline = 1 | 6       |
# |                  | 0.15%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Omalizumab = 0 | 3955    |
# |                | 99.92%  |
# +----------------+---------+
# | Omalizumab = 1 | 3       |
# |                | 0.08%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Mepolizumab = 0 | 3958    |
# |                 | 100.00% |
# +-----------------+---------+
# | Mepolizumab = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>2b)</b> Second, COHORT:32
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br>version = 1.0.0, <br>table = patient, <br>year = 2010, <br>cohort_id = COHORT:32
# </div>

# %%
response_2b = requests.get('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A32/features', \
                           headers = tabular_headers, verify = False)

output_2b = response_2b.text

output_2b_disclaimer_removed = output_2b.split('Green Team members who contributed to the work.')[1]
print(output_2b_disclaimer_removed)
# Out:
# +-----------------------+---------+
# | feature               | count   |
# +=======================+=========+
# | AgeStudyStart = 0-2   | 20      |
# |                       | 2.02%   |
# +-----------------------+---------+
# | AgeStudyStart = 3-17  | 31      |
# |                       | 3.12%   |
# +-----------------------+---------+
# | AgeStudyStart = 18-34 | 285     |
# |                       | 28.73%  |
# +-----------------------+---------+
# | AgeStudyStart = 35-50 | 297     |
# |                       | 29.94%  |
# +-----------------------+---------+
# | AgeStudyStart = 51-69 | 298     |
# |                       | 30.04%  |
# +-----------------------+---------+
# | AgeStudyStart = 70+   | 61      |
# |                       | 6.15%   |
# +-----------------------+---------+
# +-----------+---------+
# | feature   | count   |
# +===========+=========+
# | Sex = M   | 422     |
# |           | 42.54%  |
# +-----------+---------+
# | Sex = F   | 570     |
# |           | 57.46%  |
# +-----------+---------+
# +-----------------------------+---------+
# | feature                     | count   |
# +=============================+=========+
# | Race = African American     | 327     |
# |                             | 32.96%  |
# +-----------------------------+---------+
# | Race = Asian                | 2       |
# |                             | 0.20%   |
# +-----------------------------+---------+
# | Race = Caucasian            | 582     |
# |                             | 58.67%  |
# +-----------------------------+---------+
# | Race = Hawaiian / Other Pac | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | Race = Native American      | 6       |
# |                             | 0.60%   |
# +-----------------------------+---------+
# | Race = Other                | 65      |
# |                             | 6.55%   |
# +-----------------------------+---------+
# | Race = Unknown              | 10      |
# |                             | 1.01%   |
# +-----------------------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Ethnicity = H    | 60      |
# |                  | 6.05%   |
# +------------------+---------+
# | Ethnicity = N    | 664     |
# |                  | 66.94%  |
# +------------------+---------+
# | Ethnicity = U    | 58      |
# |                  | 5.85%   |
# +------------------+---------+
# | Ethnicity = None | 210     |
# |                  | 21.17%  |
# +------------------+---------+
# +--------------+---------+
# | feature      | count   |
# +==============+=========+
# | AsthmaDx = 0 | 688     |
# |              | 69.35%  |
# +--------------+---------+
# | AsthmaDx = 1 | 304     |
# |              | 30.65%  |
# +--------------+---------+
# +-------------+---------+
# | feature     | count   |
# +=============+=========+
# | CroupDx = 0 | 980     |
# |             | 98.79%  |
# +-------------+---------+
# | CroupDx = 1 | 12      |
# |             | 1.21%   |
# +-------------+---------+
# +----------------------+---------+
# | feature              | count   |
# +======================+=========+
# | ReactiveAirwayDx = 0 | 992     |
# |                      | 100.00% |
# +----------------------+---------+
# | ReactiveAirwayDx = 1 | 0       |
# |                      | 0.00%   |
# +----------------------+---------+
# +-------------+---------+
# | feature     | count   |
# +=============+=========+
# | CoughDx = 0 | 56      |
# |             | 5.65%   |
# +-------------+---------+
# | CoughDx = 1 | 936     |
# |             | 94.35%  |
# +-------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | PneumoniaDx = 0 | 948     |
# |                 | 95.56%  |
# +-----------------+---------+
# | PneumoniaDx = 1 | 44      |
# |                 | 4.44%   |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | ObesityICD = 0 | 862     |
# |                | 86.90%  |
# +----------------+---------+
# | ObesityICD = 1 | 130     |
# |                | 13.10%  |
# +----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | ObesityBMI = 0 | 992     |
# |                | 100.00% |
# +----------------+---------+
# | ObesityBMI = 1 | 0       |
# |                | 0.00%   |
# +----------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | AvgDailyPM2.5Exposure = 1 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 2 | 1       |
# |                           | 0.10%   |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 3 | 282     |
# |                           | 28.43%  |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 4 | 702     |
# |                           | 70.77%  |
# +---------------------------+---------+
# | AvgDailyPM2.5Exposure = 5 | 7       |
# |                           | 0.71%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | MaxDailyPM2.5Exposure = 1 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 2 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 3 | 970     |
# |                           | 97.78%  |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 4 | 20      |
# |                           | 2.02%   |
# +---------------------------+---------+
# | MaxDailyPM2.5Exposure = 5 | 2       |
# |                           | 0.20%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | AvgDailyOzoneExposure = 1 | 4       |
# |                           | 0.40%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 2 | 947     |
# |                           | 95.46%  |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 3 | 34      |
# |                           | 3.43%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 4 | 6       |
# |                           | 0.60%   |
# +---------------------------+---------+
# | AvgDailyOzoneExposure = 5 | 1       |
# |                           | 0.10%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | MaxDailyOzoneExposure = 1 | 960     |
# |                           | 96.77%  |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 2 | 25      |
# |                           | 2.52%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 3 | 4       |
# |                           | 0.40%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 4 | 1       |
# |                           | 0.10%   |
# +---------------------------+---------+
# | MaxDailyOzoneExposure = 5 | 2       |
# |                           | 0.20%   |
# +---------------------------+---------+
# +---------------------------+---------+
# | feature                   | count   |
# +===========================+=========+
# | EstResidentialDensity = 1 | 575     |
# |                           | 57.96%  |
# +---------------------------+---------+
# | EstResidentialDensity = 2 | 406     |
# |                           | 40.93%  |
# +---------------------------+---------+
# | EstResidentialDensity = 3 | 10      |
# |                           | 1.01%   |
# +---------------------------+---------+
# | EstResidentialDensity = 4 | 1       |
# |                           | 0.10%   |
# +---------------------------+---------+
# | EstResidentialDensity = 5 | 0       |
# |                           | 0.00%   |
# +---------------------------+---------+
# +---------------------------------+---------+
# | feature                         | count   |
# +=================================+=========+
# | EstResidentialDesnity25Plus = 1 | 500     |
# |                                 | 50.40%  |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 2 | 479     |
# |                                 | 48.29%  |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 3 | 13      |
# |                                 | 1.31%   |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 4 | 0       |
# |                                 | 0.00%   |
# +---------------------------------+---------+
# | EstResidentialDesnity25Plus = 5 | 0       |
# |                                 | 0.00%   |
# +---------------------------------+---------+
# +--------------------------------+---------+
# | feature                        | count   |
# +================================+=========+
# | EstProbabilityNonHispWhite = 1 | 66      |
# |                                | 6.65%   |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 2 | 192     |
# |                                | 19.35%  |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 3 | 396     |
# |                                | 39.92%  |
# +--------------------------------+---------+
# | EstProbabilityNonHispWhite = 4 | 337     |
# |                                | 33.97%  |
# +--------------------------------+---------+
# +-----------------------------------------+---------+
# | feature                                 | count   |
# +=========================================+=========+
# | EstProbabilityHouseholdNonHispWhite = 1 | 50      |
# |                                         | 5.04%   |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 2 | 189     |
# |                                         | 19.05%  |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 3 | 352     |
# |                                         | 35.48%  |
# +-----------------------------------------+---------+
# | EstProbabilityHouseholdNonHispWhite = 4 | 400     |
# |                                         | 40.32%  |
# +-----------------------------------------+---------+
# +------------------------------------------+---------+
# | feature                                  | count   |
# +==========================================+=========+
# | EstProbabilityHighSchoolMaxEducation = 1 | 43      |
# |                                          | 4.33%   |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 2 | 377     |
# |                                          | 38.00%  |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 3 | 483     |
# |                                          | 48.69%  |
# +------------------------------------------+---------+
# | EstProbabilityHighSchoolMaxEducation = 4 | 88      |
# |                                          | 8.87%   |
# +------------------------------------------+---------+
# +--------------------------+---------+
# | feature                  | count   |
# +==========================+=========+
# | EstProbabilityNoAuto = 1 | 908     |
# |                          | 91.53%  |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 2 | 55      |
# |                          | 5.54%   |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 3 | 26      |
# |                          | 2.62%   |
# +--------------------------+---------+
# | EstProbabilityNoAuto = 4 | 0       |
# |                          | 0.00%   |
# +--------------------------+---------+
# +-------------------------------+---------+
# | feature                       | count   |
# +===============================+=========+
# | EstProbabilityNoHealthIns = 1 | 574     |
# |                               | 57.86%  |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 2 | 379     |
# |                               | 38.21%  |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 3 | 37      |
# |                               | 3.73%   |
# +-------------------------------+---------+
# | EstProbabilityNoHealthIns = 4 | 1       |
# |                               | 0.10%   |
# +-------------------------------+---------+
# +-----------------------+---------+
# | feature               | count   |
# +=======================+=========+
# | EstProbabilityESL = 1 | 848     |
# |                       | 85.48%  |
# +-----------------------+---------+
# | EstProbabilityESL = 2 | 121     |
# |                       | 12.20%  |
# +-----------------------+---------+
# | EstProbabilityESL = 3 | 21      |
# |                       | 2.12%   |
# +-----------------------+---------+
# | EstProbabilityESL = 4 | 1       |
# |                       | 0.10%   |
# +-----------------------+---------+
# +------------------------+---------+
# | feature                | count   |
# +========================+=========+
# | EstHouseholdIncome = 1 | 763     |
# |                        | 76.92%  |
# +------------------------+---------+
# | EstHouseholdIncome = 2 | 199     |
# |                        | 20.06%  |
# +------------------------+---------+
# | EstHouseholdIncome = 3 | 9       |
# |                        | 0.91%   |
# +------------------------+---------+
# | EstHouseholdIncome = 4 | 2       |
# |                        | 0.20%   |
# +------------------------+---------+
# | EstHouseholdIncome = 5 | 1       |
# |                        | 0.10%   |
# +------------------------+---------+
# +---------------------------------+---------+
# | feature                         | count   |
# +=================================+=========+
# | MajorRoadwayHighwayExposure = 1 | 48      |
# |                                 | 4.84%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 2 | 26      |
# |                                 | 2.62%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 3 | 63      |
# |                                 | 6.35%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 4 | 91      |
# |                                 | 9.17%   |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 5 | 170     |
# |                                 | 17.14%  |
# +---------------------------------+---------+
# | MajorRoadwayHighwayExposure = 6 | 594     |
# |                                 | 59.88%  |
# +---------------------------------+---------+
# +-----------------------------+---------+
# | feature                     | count   |
# +=============================+=========+
# | TotalEDInpatientVisits = 0  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 1  | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 2  | 630     |
# |                             | 63.51%  |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 3  | 201     |
# |                             | 20.26%  |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 4  | 80      |
# |                             | 8.06%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 5  | 31      |
# |                             | 3.12%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 6  | 18      |
# |                             | 1.81%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 7  | 10      |
# |                             | 1.01%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 8  | 4       |
# |                             | 0.40%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 9  | 3       |
# |                             | 0.30%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 10 | 3       |
# |                             | 0.30%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 11 | 4       |
# |                             | 0.40%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 12 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 13 | 3       |
# |                             | 0.30%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 14 | 1       |
# |                             | 0.10%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 15 | 1       |
# |                             | 0.10%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 16 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 17 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 18 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 19 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 20 | 1       |
# |                             | 0.10%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 21 | 1       |
# |                             | 0.10%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 22 | 1       |
# |                             | 0.10%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 23 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 25 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 27 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 33 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 37 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 50 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# | TotalEDInpatientVisits = 51 | 0       |
# |                             | 0.00%   |
# +-----------------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Prednisone = 0 | 827     |
# |                | 83.37%  |
# +----------------+---------+
# | Prednisone = 1 | 165     |
# |                | 16.63%  |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Fluticasone = 0 | 766     |
# |                 | 77.22%  |
# +-----------------+---------+
# | Fluticasone = 1 | 226     |
# |                 | 22.78%  |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Mometasone = 0 | 982     |
# |                | 98.99%  |
# +----------------+---------+
# | Mometasone = 1 | 10      |
# |                | 1.01%   |
# +----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Budesonide = 0 | 954     |
# |                | 96.17%  |
# +----------------+---------+
# | Budesonide = 1 | 38      |
# |                | 3.83%   |
# +----------------+---------+
# +--------------------+---------+
# | feature            | count   |
# +====================+=========+
# | Beclomethasone = 0 | 973     |
# |                    | 98.08%  |
# +--------------------+---------+
# | Beclomethasone = 1 | 19      |
# |                    | 1.92%   |
# +--------------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Ciclesonide = 0 | 992     |
# |                 | 100.00% |
# +-----------------+---------+
# | Ciclesonide = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Flunisolide = 0 | 992     |
# |                 | 100.00% |
# +-----------------+---------+
# | Flunisolide = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+
# +---------------+---------+
# | feature       | count   |
# +===============+=========+
# | Albuterol = 0 | 650     |
# |               | 65.52%  |
# +---------------+---------+
# | Albuterol = 1 | 342     |
# |               | 34.48%  |
# +---------------+---------+
# +--------------------+---------+
# | feature            | count   |
# +====================+=========+
# | Metaproterenol = 0 | 992     |
# |                    | 100.00% |
# +--------------------+---------+
# | Metaproterenol = 1 | 0       |
# |                    | 0.00%   |
# +--------------------+---------+
# +---------------------+---------+
# | feature             | count   |
# +=====================+=========+
# | Diphenhydramine = 0 | 780     |
# |                     | 78.63%  |
# +---------------------+---------+
# | Diphenhydramine = 1 | 212     |
# |                     | 21.37%  |
# +---------------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Fexofenadine = 0 | 973     |
# |                  | 98.08%  |
# +------------------+---------+
# | Fexofenadine = 1 | 19      |
# |                  | 1.92%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Cetirizine = 0 | 943     |
# |                | 95.06%  |
# +----------------+---------+
# | Cetirizine = 1 | 49      |
# |                | 4.94%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Ipratropium = 0 | 875     |
# |                 | 88.21%  |
# +-----------------+---------+
# | Ipratropium = 1 | 117     |
# |                 | 11.79%  |
# +-----------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Salmeterol = 0 | 985     |
# |                | 99.29%  |
# +----------------+---------+
# | Salmeterol = 1 | 7       |
# |                | 0.71%   |
# +----------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Arformoterol = 0 | 992     |
# |                  | 100.00% |
# +------------------+---------+
# | Arformoterol = 1 | 0       |
# |                  | 0.00%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Formoterol = 0 | 990     |
# |                | 99.80%  |
# +----------------+---------+
# | Formoterol = 1 | 2       |
# |                | 0.20%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Indacaterol = 0 | 992     |
# |                 | 100.00% |
# +-----------------+---------+
# | Indacaterol = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+
# +------------------+---------+
# | feature          | count   |
# +==================+=========+
# | Theophylline = 0 | 992     |
# |                  | 100.00% |
# +------------------+---------+
# | Theophylline = 1 | 0       |
# |                  | 0.00%   |
# +------------------+---------+
# +----------------+---------+
# | feature        | count   |
# +================+=========+
# | Omalizumab = 0 | 989     |
# |                | 99.70%  |
# +----------------+---------+
# | Omalizumab = 1 | 3       |
# |                | 0.30%   |
# +----------------+---------+
# +-----------------+---------+
# | feature         | count   |
# +=================+=========+
# | Mepolizumab = 0 | 992     |
# |                 | 100.00% |
# +-----------------+---------+
# | Mepolizumab = 1 | 0       |
# |                 | 0.00%   |
# +-----------------+---------+

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>3)</b> Consider a cohort of all patients, COHORT:22. We will now try out the '/feature_association' endpoint
#     using this full cohort.
# </div>

# %% [markdown]
# https://icees.renci.org/apidocs/#/default/post__version___table___year__cohort__cohort_id__feature_association

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br>version = 1.0.0, <br>table = patient, <br>year = 2010, <br>cohort_id = COHORT:22, <br>"feature_a":{"MaxDailyPM2.5Exposure":{"operator":">", "value":2}}, <br>"feature_b":{"TotalEDInpatientVisits":{"operator":">", "value":1}}
# </div>

# %%
CQ1_feature_association_data = '{"feature_a":{"MaxDailyPM2.5Exposure":{"operator":">", "value":2}}, \
                                  "feature_b":{"TotalEDInpatientVisits":{"operator":">", "value":1}}}'

response_3 = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A22/feature_association', \
                           headers = tabular_headers, data=CQ1_feature_association_data, verify = False)

output_3 = response_3.text

output_3_disclaimer_removed = output_3.split('Green Team members who contributed to the work.')[1]
print(output_3_disclaimer_removed)
# Out:
# +-----------------------------+-----------------------------+------------------------------+---------+
# | feature                     | MaxDailyPM2.5Exposure > 2   | MaxDailyPM2.5Exposure <= 2   |         |
# +=============================+=============================+==============================+=========+
# | TotalEDInpatientVisits > 1  | 992     26.69%              | 2725    73.31%               | 3717    |
# |                             | 20.04%  4.30%               | 15.02%  11.80%               | 16.10%  |
# +-----------------------------+-----------------------------+------------------------------+---------+
# | TotalEDInpatientVisits <= 1 | 3958    20.43%              | 15418   79.57%               | 19376   |
# |                             | 79.96%  17.14%              | 84.98%  66.76%               | 83.90%  |
# +-----------------------------+-----------------------------+------------------------------+---------+
# |                             | 4950                        | 18143                        | 23093   |
# |                             | 21.44%                      | 78.56%                       | 100.00% |
# +-----------------------------+-----------------------------+------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.18862e-15 |       72.5923 |
# +-------------+---------------+

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; font-weight: normal">
# <b>4)</b> Again using COHORT:22, take a look at the endpoint '/associations_to_all_features'
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:16px">
# <b>Inputs:</b> <br>version = 1.0.0, <br>table = patient, <br>year = 2010, <br>cohort_id = COHORT:22, \
#         <br>"feature":{"TotalEDInpatientVisits":{"operator":">", <br>"value":1}},"maximum_p_value":0.1}
# </div>

# %%
CQ1_associations_to_all_features_data = '{"feature":{"TotalEDInpatientVisits":{"operator":">", \
                                            "value":1}},"maximum_p_value":0.1}'

response_4 = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A22/associations_to_all_features', \
                           headers = tabular_headers, data=CQ1_associations_to_all_features_data, verify = False)

output_4 = response_4.text

output_4_disclaimer_removed = output_4.split('Green Team members who contributed to the work.')[1]
print(output_4_disclaimer_removed)
# Out:
# +-----------------------+------------------------------+-------------------------------+---------+
# | feature               | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=======================+==============================+===============================+=========+
# | AgeStudyStart = 0-2   | 105    5.22%                 | 1908   94.78%                 | 2013    |
# |                       | 2.82%  0.45%                 | 9.85%  8.26%                  | 8.72%   |
# +-----------------------+------------------------------+-------------------------------+---------+
# | AgeStudyStart = 3-17  | 145    3.86%                 | 3614    96.14%                | 3759    |
# |                       | 3.90%  0.63%                 | 18.65%  15.65%                | 16.28%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | AgeStudyStart = 18-34 | 927     26.17%               | 2615    73.83%                | 3542    |
# |                       | 24.94%  4.01%                | 13.50%  11.32%                | 15.34%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | AgeStudyStart = 35-50 | 1171    23.85%               | 3739    76.15%                | 4910    |
# |                       | 31.50%  5.07%                | 19.30%  16.19%                | 21.26%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | AgeStudyStart = 51-69 | 1043    16.26%               | 5373    83.74%                | 6416    |
# |                       | 28.06%  4.52%                | 27.73%  23.27%                | 27.78%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | AgeStudyStart = 70+   | 326    13.29%                | 2127    86.71%                | 2453    |
# |                       | 8.77%  1.41%                 | 10.98%  9.21%                 | 10.62%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# |                       | 3717                         | 19376                         | 23093   |
# |                       | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------------+------------------------------+-------------------------------+---------+
# +--------------+---------------+
# |      p_value |   chi_squared |
# +==============+===============+
# | 2.24967e-227 |       1092.58 |
# +--------------+---------------+
# +-----------------------------+------------------------------+-------------------------------+---------+
# | feature                     | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=============================+==============================+===============================+=========+
# | Race = African American     | 1306    20.47%               | 5073    79.53%                | 6379    |
# |                             | 35.14%  5.66%                | 26.18%  21.97%                | 27.62%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Asian                | 35     13.16%                | 231    86.84%                 | 266     |
# |                             | 0.94%  0.15%                 | 1.19%  1.00%                  | 1.15%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Caucasian            | 1985    15.07%               | 11191   84.93%                | 13176   |
# |                             | 53.40%  8.60%                | 57.76%  48.46%                | 57.06%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Hawaiian / Other Pac | 1      20.00%                | 4      80.00%                 | 5       |
# |                             | 0.03%  0.00%                 | 0.02%  0.02%                  | 0.02%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Native American      | 25     13.74%                | 157    86.26%                 | 182     |
# |                             | 0.67%  0.11%                 | 0.81%  0.68%                  | 0.79%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Other                | 313    12.48%                | 2195    87.52%                | 2508    |
# |                             | 8.42%  1.36%                 | 11.33%  9.51%                 | 10.86%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | Race = Unknown              | 52     9.01%                 | 525    90.99%                 | 577     |
# |                             | 1.40%  0.23%                 | 2.71%  2.27%                  | 2.50%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# |                             | 3717                         | 19376                         | 23093   |
# |                             | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 3.12437e-25 |       149.103 |
# +-------------+---------------+
# +------------------+------------------------------+-------------------------------+---------+
# | feature          | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +==================+==============================+===============================+=========+
# | Ethnicity = H    | 248    13.58%                | 1578   86.42%                 | 1826    |
# |                  | 6.67%  1.07%                 | 8.14%  6.83%                  | 7.91%   |
# +------------------+------------------------------+-------------------------------+---------+
# | Ethnicity = N    | 2555    17.35%               | 12172   82.65%                | 14727   |
# |                  | 68.74%  11.06%               | 62.82%  52.71%                | 63.77%  |
# +------------------+------------------------------+-------------------------------+---------+
# | Ethnicity = U    | 239    11.12%                | 1910   88.88%                 | 2149    |
# |                  | 6.43%  1.03%                 | 9.86%  8.27%                  | 9.31%   |
# +------------------+------------------------------+-------------------------------+---------+
# | Ethnicity = None | 675     15.37%               | 3716    84.63%                | 4391    |
# |                  | 18.16%  2.92%                | 19.18%  16.09%                | 19.01%  |
# +------------------+------------------------------+-------------------------------+---------+
# |                  | 3717                         | 19376                         | 23093   |
# |                  | 16.10%                       | 83.90%                        | 100.00% |
# +------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 6.68166e-12 |       66.7513 |
# +-------------+---------------+
# +--------------+------------------------------+-------------------------------+---------+
# | feature      | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +==============+==============================+===============================+=========+
# | AsthmaDx = 0 | 2615    17.42%               | 12394   82.58%                | 15009   |
# |              | 70.35%  11.32%               | 63.97%  53.67%                | 64.99%  |
# +--------------+------------------------------+-------------------------------+---------+
# | AsthmaDx = 1 | 1102    13.63%               | 6982    86.37%                | 8084    |
# |              | 29.65%  4.77%                | 36.03%  30.23%                | 35.01%  |
# +--------------+------------------------------+-------------------------------+---------+
# |              | 3717                         | 19376                         | 23093   |
# |              | 16.10%                       | 83.90%                        | 100.00% |
# +--------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 4.38448e-12 |        55.913 |
# +-------------+---------------+
# +-------------+------------------------------+-------------------------------+---------+
# | feature     | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=============+==============================+===============================+=========+
# | CoughDx = 0 | 221    3.83%                 | 5556    96.17%                | 5777    |
# |             | 5.95%  0.96%                 | 28.67%  24.06%                | 25.02%  |
# +-------------+------------------------------+-------------------------------+---------+
# | CoughDx = 1 | 3496    20.19%               | 13820   79.81%                | 17316   |
# |             | 94.05%  15.14%               | 71.33%  59.84%                | 74.98%  |
# +-------------+------------------------------+-------------------------------+---------+
# |             | 3717                         | 19376                         | 23093   |
# |             | 16.10%                       | 83.90%                        | 100.00% |
# +-------------+------------------------------+-------------------------------+---------+
# +--------------+---------------+
# |      p_value |   chi_squared |
# +==============+===============+
# | 7.23669e-186 |        858.91 |
# +--------------+---------------+
# +-----------------+------------------------------+-------------------------------+---------+
# | feature         | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=================+==============================+===============================+=========+
# | PneumoniaDx = 0 | 3577    15.82%               | 19030   84.18%                | 22607   |
# |                 | 96.23%  15.49%               | 98.21%  82.41%                | 97.90%  |
# +-----------------+------------------------------+-------------------------------+---------+
# | PneumoniaDx = 1 | 140    28.81%                | 346    71.19%                 | 486     |
# |                 | 3.77%  0.61%                 | 1.79%  1.50%                  | 2.10%   |
# +-----------------+------------------------------+-------------------------------+---------+
# |                 | 3717                         | 19376                         | 23093   |
# |                 | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 7.92987e-13 |       59.3914 |
# +-------------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | ObesityICD = 0 | 3301    15.59%               | 17873   84.41%                | 21174   |
# |                | 88.81%  14.29%               | 92.24%  77.40%                | 91.69%  |
# +----------------+------------------------------+-------------------------------+---------+
# | ObesityICD = 1 | 416     21.68%               | 1503   78.32%                 | 1919    |
# |                | 11.19%  1.80%                | 7.76%  6.51%                  | 8.31%   |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.84684e-10 |       48.2906 |
# +-------------+---------------+
# +---------------------------+------------------------------+-------------------------------+---------+
# | feature                   | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===========================+==============================+===============================+=========+
# | AvgDailyPM2.5Exposure = 1 | 30     17.34%                | 143    82.66%                 | 173     |
# |                           | 0.81%  0.13%                 | 0.74%  0.62%                  | 0.75%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyPM2.5Exposure = 2 | 97     6.79%                 | 1331   93.21%                 | 1428    |
# |                           | 2.61%  0.42%                 | 6.87%  5.76%                  | 6.18%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyPM2.5Exposure = 3 | 2864    15.84%               | 15220   84.16%                | 18084   |
# |                           | 77.05%  12.40%               | 78.55%  65.91%                | 78.31%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyPM2.5Exposure = 4 | 719     21.27%               | 2661    78.73%                | 3380    |
# |                           | 19.34%  3.11%                | 13.73%  11.52%                | 14.64%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyPM2.5Exposure = 5 | 7      25.00%                | 21     75.00%                 | 28      |
# |                           | 0.19%  0.03%                 | 0.11%  0.09%                  | 0.12%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# |                           | 3717                         | 19376                         | 23093   |
# |                           | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 3.96169e-30 |       161.313 |
# +-------------+---------------+
# +---------------------------+------------------------------+-------------------------------+---------+
# | feature                   | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===========================+==============================+===============================+=========+
# | MaxDailyPM2.5Exposure = 1 | 67     8.89%                 | 687    91.11%                 | 754     |
# |                           | 1.80%  0.29%                 | 3.55%  2.97%                  | 3.27%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyPM2.5Exposure = 2 | 2658    15.29%               | 14731   84.71%                | 17389   |
# |                           | 71.51%  11.51%               | 76.03%  63.79%                | 75.30%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyPM2.5Exposure = 3 | 970     19.90%               | 3905    80.10%                | 4875    |
# |                           | 26.10%  4.20%                | 20.15%  16.91%                | 21.11%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyPM2.5Exposure = 4 | 20     31.25%                | 44     68.75%                 | 64      |
# |                           | 0.54%  0.09%                 | 0.23%  0.19%                  | 0.28%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyPM2.5Exposure = 5 | 2      18.18%                | 9      81.82%                 | 11      |
# |                           | 0.05%  0.01%                 | 0.05%  0.04%                  | 0.05%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# |                           | 3717                         | 19376                         | 23093   |
# |                           | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.20993e-17 |       100.564 |
# +-------------+---------------+
# +---------------------------+------------------------------+-------------------------------+---------+
# | feature                   | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===========================+==============================+===============================+=========+
# | AvgDailyOzoneExposure = 1 | 6      30.00%                | 14     70.00%                 | 20      |
# |                           | 0.16%  0.03%                 | 0.07%  0.06%                  | 0.09%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyOzoneExposure = 2 | 1018    19.60%               | 4177    80.40%                | 5195    |
# |                           | 27.39%  4.41%                | 21.56%  18.09%                | 22.50%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyOzoneExposure = 3 | 2562    15.80%               | 13655   84.20%                | 16217   |
# |                           | 68.93%  11.09%               | 70.47%  59.13%                | 70.22%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyOzoneExposure = 4 | 30     12.82%                | 204    87.18%                 | 234     |
# |                           | 0.81%  0.13%                 | 1.05%  0.88%                  | 1.01%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | AvgDailyOzoneExposure = 5 | 101    7.08%                 | 1326   92.92%                 | 1427    |
# |                           | 2.72%  0.44%                 | 6.84%  5.74%                  | 6.18%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# |                           | 3717                         | 19376                         | 23093   |
# |                           | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.79274e-25 |       138.837 |
# +-------------+---------------+
# +---------------------------+------------------------------+-------------------------------+---------+
# | feature                   | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===========================+==============================+===============================+=========+
# | MaxDailyOzoneExposure = 1 | 3518    17.20%               | 16940   82.80%                | 20458   |
# |                           | 94.65%  15.23%               | 87.43%  73.36%                | 88.59%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyOzoneExposure = 2 | 164    7.36%                 | 2064    92.64%                | 2228    |
# |                           | 4.41%  0.71%                 | 10.65%  8.94%                 | 9.65%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyOzoneExposure = 3 | 32     8.08%                 | 364    91.92%                 | 396     |
# |                           | 0.86%  0.14%                 | 1.88%  1.58%                  | 1.71%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyOzoneExposure = 4 | 1      100.00%               | 0      0.00%                  | 1       |
# |                           | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | MaxDailyOzoneExposure = 5 | 2      20.00%                | 8      80.00%                 | 10      |
# |                           | 0.05%  0.01%                 | 0.04%  0.03%                  | 0.04%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# |                           | 3717                         | 19376                         | 23093   |
# |                           | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.34169e-31 |        168.38 |
# +-------------+---------------+
# +---------------------------+------------------------------+-------------------------------+---------+
# | feature                   | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===========================+==============================+===============================+=========+
# | EstResidentialDensity = 1 | 1868    16.61%               | 9380    83.39%                | 11248   |
# |                           | 50.26%  8.09%                | 48.41%  40.62%                | 48.71%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDensity = 2 | 1660    16.10%               | 8649    83.90%                | 10309   |
# |                           | 44.66%  7.19%                | 44.64%  37.45%                | 44.64%  |
# +---------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDensity = 3 | 142    12.36%                | 1007   87.64%                 | 1149    |
# |                           | 3.82%  0.61%                 | 5.20%  4.36%                  | 4.98%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDensity = 4 | 31     12.60%                | 215    87.40%                 | 246     |
# |                           | 0.83%  0.13%                 | 1.11%  0.93%                  | 1.07%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDensity = 5 | 16     11.35%                | 125    88.65%                 | 141     |
# |                           | 0.43%  0.07%                 | 0.65%  0.54%                  | 0.61%   |
# +---------------------------+------------------------------+-------------------------------+---------+
# |                           | 3717                         | 19376                         | 23093   |
# |                           | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------+------------------------------+-------------------------------+---------+
# +-----------+---------------+
# |   p_value |   chi_squared |
# +===========+===============+
# | 0.0284239 |       18.6411 |
# +-----------+---------------+
# +---------------------------------+------------------------------+-------------------------------+---------+
# | feature                         | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=================================+==============================+===============================+=========+
# | EstResidentialDesnity25Plus = 1 | 1553    16.05%               | 8125    83.95%                | 9678    |
# |                                 | 41.78%  6.72%                | 41.93%  35.18%                | 41.91%  |
# +---------------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDesnity25Plus = 2 | 1965    16.66%               | 9830    83.34%                | 11795   |
# |                                 | 52.87%  8.51%                | 50.73%  42.57%                | 51.08%  |
# +---------------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDesnity25Plus = 3 | 144    11.86%                | 1070   88.14%                 | 1214    |
# |                                 | 3.87%  0.62%                 | 5.52%  4.63%                  | 5.26%   |
# +---------------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDesnity25Plus = 4 | 17     10.30%                | 148    89.70%                 | 165     |
# |                                 | 0.46%  0.07%                 | 0.76%  0.64%                  | 0.71%   |
# +---------------------------------+------------------------------+-------------------------------+---------+
# | EstResidentialDesnity25Plus = 5 | 38     15.77%                | 203    84.23%                 | 241     |
# |                                 | 1.02%  0.16%                 | 1.05%  0.88%                  | 1.04%   |
# +---------------------------------+------------------------------+-------------------------------+---------+
# |                                 | 3717                         | 19376                         | 23093   |
# |                                 | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------------------+------------------------------+-------------------------------+---------+
# +------------+---------------+
# |    p_value |   chi_squared |
# +============+===============+
# | 0.00613221 |       23.0287 |
# +------------+---------------+
# +-----------------------+------------------------------+-------------------------------+---------+
# | feature               | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=======================+==============================+===============================+=========+
# | EstProbabilityESL = 1 | 2938    16.03%               | 15387   83.97%                | 18325   |
# |                       | 79.04%  12.72%               | 79.41%  66.63%                | 79.35%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | EstProbabilityESL = 2 | 602     15.49%               | 3284    84.51%                | 3886    |
# |                       | 16.20%  2.61%                | 16.95%  14.22%                | 16.83%  |
# +-----------------------+------------------------------+-------------------------------+---------+
# | EstProbabilityESL = 3 | 163    20.32%                | 639    79.68%                 | 802     |
# |                       | 4.39%  0.71%                 | 3.30%  2.77%                  | 3.47%   |
# +-----------------------+------------------------------+-------------------------------+---------+
# | EstProbabilityESL = 4 | 12     19.67%                | 49     80.33%                 | 61      |
# |                       | 0.32%  0.05%                 | 0.25%  0.21%                  | 0.26%   |
# +-----------------------+------------------------------+-------------------------------+---------+
# |                       | 3717                         | 19376                         | 23093   |
# |                       | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------------+------------------------------+-------------------------------+---------+
# +-----------+---------------+
# |   p_value |   chi_squared |
# +===========+===============+
# | 0.0911129 |       12.3001 |
# +-----------+---------------+
# +------------------------+------------------------------+-------------------------------+---------+
# | feature                | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +========================+==============================+===============================+=========+
# | EstHouseholdIncome = 1 | 2026    16.02%               | 10623   83.98%                | 12649   |
# |                        | 54.51%  8.77%                | 54.83%  46.00%                | 54.77%  |
# +------------------------+------------------------------+-------------------------------+---------+
# | EstHouseholdIncome = 2 | 1418    16.86%               | 6991    83.14%                | 8409    |
# |                        | 38.15%  6.14%                | 36.08%  30.27%                | 36.41%  |
# +------------------------+------------------------------+-------------------------------+---------+
# | EstHouseholdIncome = 3 | 161    12.44%                | 1133   87.56%                 | 1294    |
# |                        | 4.33%  0.70%                 | 5.85%  4.91%                  | 5.60%   |
# +------------------------+------------------------------+-------------------------------+---------+
# | EstHouseholdIncome = 4 | 31     16.58%                | 156    83.42%                 | 187     |
# |                        | 0.83%  0.13%                 | 0.81%  0.68%                  | 0.81%   |
# +------------------------+------------------------------+-------------------------------+---------+
# | EstHouseholdIncome = 5 | 1      20.00%                | 4      80.00%                 | 5       |
# |                        | 0.03%  0.00%                 | 0.02%  0.02%                  | 0.02%   |
# +------------------------+------------------------------+-------------------------------+---------+
# |                        | 3717                         | 19376                         | 23093   |
# |                        | 16.10%                       | 83.90%                        | 100.00% |
# +------------------------+------------------------------+-------------------------------+---------+
# +-----------+---------------+
# |   p_value |   chi_squared |
# +===========+===============+
# | 0.0553282 |       16.6019 |
# +-----------+---------------+
# +-----------------------------+------------------------------+-------------------------------+---------+
# | feature                     | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=============================+==============================+===============================+=========+
# | TotalEDInpatientVisits = 0  | 0      0.00%                 | 16082   100.00%               | 16082   |
# |                             | 0.00%  0.00%                 | 83.00%  69.64%                | 69.64%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 1  | 0      0.00%                 | 3294    100.00%               | 3294    |
# |                             | 0.00%  0.00%                 | 17.00%  14.26%                | 14.26%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 2  | 2440    100.00%              | 0      0.00%                  | 2440    |
# |                             | 65.64%  10.57%               | 0.00%  0.00%                  | 10.57%  |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 3  | 712     100.00%              | 0      0.00%                  | 712     |
# |                             | 19.16%  3.08%                | 0.00%  0.00%                  | 3.08%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 4  | 266    100.00%               | 0      0.00%                  | 266     |
# |                             | 7.16%  1.15%                 | 0.00%  0.00%                  | 1.15%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 5  | 120    100.00%               | 0      0.00%                  | 120     |
# |                             | 3.23%  0.52%                 | 0.00%  0.00%                  | 0.52%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 6  | 60     100.00%               | 0      0.00%                  | 60      |
# |                             | 1.61%  0.26%                 | 0.00%  0.00%                  | 0.26%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 7  | 30     100.00%               | 0      0.00%                  | 30      |
# |                             | 0.81%  0.13%                 | 0.00%  0.00%                  | 0.13%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 8  | 17     100.00%               | 0      0.00%                  | 17      |
# |                             | 0.46%  0.07%                 | 0.00%  0.00%                  | 0.07%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 9  | 15     100.00%               | 0      0.00%                  | 15      |
# |                             | 0.40%  0.06%                 | 0.00%  0.00%                  | 0.06%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 10 | 10     100.00%               | 0      0.00%                  | 10      |
# |                             | 0.27%  0.04%                 | 0.00%  0.00%                  | 0.04%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 11 | 9      100.00%               | 0      0.00%                  | 9       |
# |                             | 0.24%  0.04%                 | 0.00%  0.00%                  | 0.04%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 12 | 4      100.00%               | 0      0.00%                  | 4       |
# |                             | 0.11%  0.02%                 | 0.00%  0.00%                  | 0.02%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 13 | 7      100.00%               | 0      0.00%                  | 7       |
# |                             | 0.19%  0.03%                 | 0.00%  0.00%                  | 0.03%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 14 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 15 | 3      100.00%               | 0      0.00%                  | 3       |
# |                             | 0.08%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 16 | 5      100.00%               | 0      0.00%                  | 5       |
# |                             | 0.13%  0.02%                 | 0.00%  0.00%                  | 0.02%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 17 | 2      100.00%               | 0      0.00%                  | 2       |
# |                             | 0.05%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 18 | 2      100.00%               | 0      0.00%                  | 2       |
# |                             | 0.05%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 19 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 20 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 21 | 2      100.00%               | 0      0.00%                  | 2       |
# |                             | 0.05%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 22 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 23 | 2      100.00%               | 0      0.00%                  | 2       |
# |                             | 0.05%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 25 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 27 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 33 | 2      100.00%               | 0      0.00%                  | 2       |
# |                             | 0.05%  0.01%                 | 0.00%  0.00%                  | 0.01%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 37 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 50 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# | TotalEDInpatientVisits = 51 | 1      100.00%               | 0      0.00%                  | 1       |
# |                             | 0.03%  0.00%                 | 0.00%  0.00%                  | 0.00%   |
# +-----------------------------+------------------------------+-------------------------------+---------+
# |                             | 3717                         | 19376                         | 23093   |
# |                             | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------------------+------------------------------+-------------------------------+---------+
# +-----------+---------------+
# |   p_value |   chi_squared |
# +===========+===============+
# |         0 |         23093 |
# +-----------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | Prednisone = 0 | 3135    15.18%               | 17512   84.82%                | 20647   |
# |                | 84.34%  13.58%               | 90.38%  75.83%                | 89.41%  |
# +----------------+------------------------------+-------------------------------+---------+
# | Prednisone = 1 | 582     23.79%               | 1864   76.21%                 | 2446    |
# |                | 15.66%  2.52%                | 9.62%  8.07%                  | 10.59%  |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 7.53206e-26 |       120.049 |
# +-------------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | Mometasone = 0 | 3686    16.22%               | 19033   83.78%                | 22719   |
# |                | 99.17%  15.96%               | 98.23%  82.42%                | 98.38%  |
# +----------------+------------------------------+-------------------------------+---------+
# | Mometasone = 1 | 31     8.29%                 | 343    91.71%                 | 374     |
# |                | 0.83%  0.13%                 | 1.77%  1.49%                  | 1.62%   |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 0.000656146 |       17.1568 |
# +-------------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | Budesonide = 0 | 3582    16.29%               | 18405   83.71%                | 21987   |
# |                | 96.37%  15.51%               | 94.99%  79.70%                | 95.21%  |
# +----------------+------------------------------+-------------------------------+---------+
# | Budesonide = 1 | 135    12.21%                | 971    87.79%                 | 1106    |
# |                | 3.63%  0.58%                 | 5.01%  4.20%                  | 4.79%   |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +------------+---------------+
# |    p_value |   chi_squared |
# +============+===============+
# | 0.00460764 |       13.0134 |
# +------------+---------------+
# +---------------+------------------------------+-------------------------------+---------+
# | feature       | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +===============+==============================+===============================+=========+
# | Albuterol = 0 | 2564    15.67%               | 13795   84.33%                | 16359   |
# |               | 68.98%  11.10%               | 71.20%  59.74%                | 70.84%  |
# +---------------+------------------------------+-------------------------------+---------+
# | Albuterol = 1 | 1153    17.12%               | 5581    82.88%                | 6734    |
# |               | 31.02%  4.99%                | 28.80%  24.17%                | 29.16%  |
# +---------------+------------------------------+-------------------------------+---------+
# |               | 3717                         | 19376                         | 23093   |
# |               | 16.10%                       | 83.90%                        | 100.00% |
# +---------------+------------------------------+-------------------------------+---------+
# +-----------+---------------+
# |   p_value |   chi_squared |
# +===========+===============+
# | 0.0598188 |       7.41366 |
# +-----------+---------------+
# +---------------------+------------------------------+-------------------------------+---------+
# | feature             | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=====================+==============================+===============================+=========+
# | Diphenhydramine = 0 | 2963    14.84%               | 17009   85.16%                | 19972   |
# |                     | 79.71%  12.83%               | 87.78%  73.65%                | 86.49%  |
# +---------------------+------------------------------+-------------------------------+---------+
# | Diphenhydramine = 1 | 754     24.16%               | 2367    75.84%                | 3121    |
# |                     | 20.29%  3.27%                | 12.22%  10.25%                | 13.51%  |
# +---------------------+------------------------------+-------------------------------+---------+
# |                     | 3717                         | 19376                         | 23093   |
# |                     | 16.10%                       | 83.90%                        | 100.00% |
# +---------------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 1.99638e-37 |       173.726 |
# +-------------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | Cetirizine = 0 | 3567    16.33%               | 18281   83.67%                | 21848   |
# |                | 95.96%  15.45%               | 94.35%  79.16%                | 94.61%  |
# +----------------+------------------------------+-------------------------------+---------+
# | Cetirizine = 1 | 150    12.05%                | 1095   87.95%                 | 1245    |
# |                | 4.04%  0.65%                 | 5.65%  4.74%                  | 5.39%   |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +------------+---------------+
# |    p_value |   chi_squared |
# +============+===============+
# | 0.00115354 |       15.9638 |
# +------------+---------------+
# +-----------------+------------------------------+-------------------------------+---------+
# | feature         | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +=================+==============================+===============================+=========+
# | Ipratropium = 0 | 3350    15.31%               | 18525   84.69%                | 21875   |
# |                 | 90.13%  14.51%               | 95.61%  80.22%                | 94.73%  |
# +-----------------+------------------------------+-------------------------------+---------+
# | Ipratropium = 1 | 367    30.13%                | 851    69.87%                 | 1218    |
# |                 | 9.87%  1.59%                 | 4.39%  3.69%                  | 5.27%   |
# +-----------------+------------------------------+-------------------------------+---------+
# |                 | 3717                         | 19376                         | 23093   |
# |                 | 16.10%                       | 83.90%                        | 100.00% |
# +-----------------+------------------------------+-------------------------------+---------+
# +-------------+---------------+
# |     p_value |   chi_squared |
# +=============+===============+
# | 2.05262e-40 |       187.562 |
# +-------------+---------------+
# +----------------+------------------------------+-------------------------------+---------+
# | feature        | TotalEDInpatientVisits > 1   | TotalEDInpatientVisits <= 1   |         |
# +================+==============================+===============================+=========+
# | Salmeterol = 0 | 3699    16.05%               | 19343   83.95%                | 23042   |
# |                | 99.52%  16.02%               | 99.83%  83.76%                | 99.78%  |
# +----------------+------------------------------+-------------------------------+---------+
# | Salmeterol = 1 | 18     35.29%                | 33     64.71%                 | 51      |
# |                | 0.48%  0.08%                 | 0.17%  0.14%                  | 0.22%   |
# +----------------+------------------------------+-------------------------------+---------+
# |                | 3717                         | 19376                         | 23093   |
# |                | 16.10%                       | 83.90%                        | 100.00% |
# +----------------+------------------------------+-------------------------------+---------+
# +------------+---------------+
# |    p_value |   chi_squared |
# +============+===============+
# | 0.00297458 |       13.9496 |
# +------------+---------------+

# %% [markdown]
# ### __Up until now, the outputs have utilized the "text/tabular" output option.__
# ### __Next, let's demonstrate the "accept":"application/json" header output and usefulness using the same inputs from 4) immediately above.__

# %%
import json

json_headers = {"Content-Type" : "application/json", "accept": "application/json"}

response_4_json = requests.post('https://icees.renci.org/1.0.0/patient/2010/cohort/COHORT%3A22/associations_to_all_features', headers = json_headers, data=CQ1_associations_to_all_features_data, verify = False)
blob_4_json = response_4_json.json()

# %%
print("The output for ICEES API, using the new header, is now:", type(blob_4_json))
print()
print(blob_4_json)
# Out:
# The output for ICEES API, using the new header, is now: <class 'dict'>
#
# {'return value': [{'feature_matrix': [[{'column_percentage': 0.02824858757062147, 'frequency': 105, 'total_percentage': 0.004546832373446499, 'row_percentage': 0.05216095380029806}, {'column_percentage': 0.09847233691164327, 'frequency': 1908, 'total_percentage': 0.0826224397003421, 'row_percentage': 0.9478390461997019}], [{'column_percentage': 0.03900995426419155, 'frequency': 145, 'total_percentage': 0.006278958991902308, 'row_percentage': 0.03857408885341846}, {'column_percentage': 0.18651940545004128, 'frequency': 3614, 'total_percentage': 0.15649763997748237, 'row_percentage': 0.9614259111465815}], [{'column_percentage': 0.24939467312348668, 'frequency': 927, 'total_percentage': 0.040142034382713375, 'row_percentage': 0.26171654432524}, {'column_percentage': 0.13496077621800165, 'frequency': 2615, 'total_percentage': 0.11323777768154852, 'row_percentage': 0.7382834556747601}], [{'column_percentage': 0.3150390099542642, 'frequency': 1171, 'total_percentage': 0.050708006755293814, 'row_percentage': 0.2384928716904277}, {'column_percentage': 0.19297068538398018, 'frequency': 3739, 'total_percentage': 0.16191053566015676, 'row_percentage': 0.7615071283095723}], [{'column_percentage': 0.2806026365348399, 'frequency': 1043, 'total_percentage': 0.04516520157623522, 'row_percentage': 0.16256234413965087}, {'column_percentage': 0.2773018166804294, 'frequency': 5373, 'total_percentage': 0.23266790802407655, 'row_percentage': 0.8374376558603491}], [{'column_percentage': 0.08770513855259618, 'frequency': 326, 'total_percentage': 0.014116831940414845, 'row_percentage': 0.13289849164288625}, {'column_percentage': 0.10977497935590422, 'frequency': 2127, 'total_percentage': 0.09210583293638765, 'row_percentage': 0.8671015083571137}]], 'p_value': 2.2496672994629886e-227, 'feature_b': {'feature_name': 'AgeStudyStart', 'feature_qualifiers': [{'value': '0-2', 'operator': '='}, {'value': '3-17', 'operator': '='}, {'value': '18-34', 'operator': '='}, {'value': '35-50', 'operator': '='}, {'value': '51-69', 'operator': '='}, {'value': '70+', 'operator': '='}]}, 'columns': [{'percentage': 0.16095786602000606, 'frequency': 3717}, {'percentage': 0.8390421339799939, 'frequency': 19376}], 'chi_squared': 1092.5813125808113, 'total': 23093, 'feature_a': {'feature_name': 'TotalEDInpatientVisits', 'feature_qualifiers': [{'value': 1, 'operator': '>'}, {'value': 1, 'operator': '<='}]}, 'rows': [{'percentage': 0.08716927207378859, 'frequency': 2013}, {'percentage': 0.16277659896938465, 'frequency': 3759}, {'percentage': 0.1533798120642619, 'frequency': 3542}, {'percentage': 0.21261854241545056, 'frequency': 4910}, {'percentage': 0.27783310960031177, 'frequency': 6416}, {'percentage': 0.1062226648768025, 'frequency': 2453}]}, {'feature_matrix': [[{'column_percentage': 0.3513586225450632, 'frequency': 1306, 'total_percentage': 0.056553934092582164, 'row_percentage': 0.204734284370591}, {'column_percentage': 0.26181874483897605, 'frequency': 5073, 'total_percentage': 0.21967695838565798, 'row_percentage': 0.795265715629409}], [{'column_percentage': 0.009416195856873822, 'frequency': 35, 'total_percentage': 0.001515610791148833, 'row_percentage': 0.13157894736842105}, {'column_percentage': 0.011921965317919074, 'frequency': 231, 'total_percentage': 0.010003031221582298, 'row_percentage': 0.868421052631579}], [{'column_percentage': 0.5340328221684154, 'frequency': 1985, 'total_percentage': 0.08595678344086953, 'row_percentage': 0.15065270188221008}, {'column_percentage': 0.5775701899256812, 'frequency': 11191, 'total_percentage': 0.484605724678474, 'row_percentage': 0.84934729811779}], [{'column_percentage': 0.0002690341673392521, 'frequency': 1, 'total_percentage': 4.330316546139523e-05, 'row_percentage': 0.2}, {'column_percentage': 0.00020644095788604458, 'frequency': 4, 'total_percentage': 0.00017321266184558093, 'row_percentage': 0.8}], [{'column_percentage': 0.006725854183481302, 'frequency': 25, 'total_percentage': 0.0010825791365348808, 'row_percentage':  ...

# %% [markdown]
# ### With the output now in the dictionary format, accessing and using the information programmatically is straight-forward.
