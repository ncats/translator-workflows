# %%
import requests
import csv
from pprint import pprint
from io import StringIO
import pandas as pd

# %%
# methods for various utilities
# get gene sets from github and convert to dict
def gather_gene_sets(url):
    r = requests.get(url)
    f = StringIO(r.text)
    reader = csv.reader(f, delimiter='\t')
    dict_rows = list()
    for row in reader:
        dict_rows.append(
            {
                'curie': row[0],
                'name': row[1]
            }
        )
    return dict_rows

# %%
# Core FA Gene set
FA_1_core_complex = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/FA_1_core_complex.txt"
fa_genes = gather_gene_sets(FA_1_core_complex)

# %%
#  return gene disease association data from biolink
def query_biolink_gene_disease(gene_curie):
    bl_url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/diseases/'
    params = {
        'fetch_objects': True,   
    }
    r = requests.get(url=bl_url.format(gene_curie), params=params)
    return r.json()

# %%
# map of relation terms
term_map_reversed = {
    "GENO:0000840": "pathogenic",
    "GENO:0000841": "likely pathogenic",
    "GENO:0000843": "benign",
    "GENO:0000844": "likely benign",
    "GENO:0000845": "uncertain significance"    
}

# %%
result_set = []
# iterate through fa genes
for gene in fa_genes:
    bl_dat = query_biolink_gene_disease(gene['curie'])
    for assoc in bl_dat['associations']:
        edges = assoc['evidence_graph']['edges']
        nodes = assoc['evidence_graph']['nodes']
        node_map = dict()
        # create map of node ids and labels
        for node in nodes:
            node_map[node['id']] = node['lbl']
        # generate table of gene -> variant -> disease associations
        for edge in edges:
            # check for 
            if edge['pred'] in term_map_reversed.keys():
                row = [gene['name'], gene['curie'], node_map[edge['sub']], edge['sub'], term_map_reversed[edge['pred']], edge['pred'], node_map[edge['obj']], edge['obj']]
                result_set.append(row)
    column_names = ['gene_name', 'gene_curie', 'variant_name', 'variant_curie', 
                    'relation_label', 'relation_curie', 'disease_label', 'disease_curie']
result_frame = pd.DataFrame(data=result_set, columns=column_names)
result_frame.head(30)
# Out:
#    gene_name     gene_curie  \
# 0      FANCA  NCBIGene:2175
# 1      FANCA  NCBIGene:2175
# 2      FANCA  NCBIGene:2175
# 3      FANCA  NCBIGene:2175
# 4      FANCA  NCBIGene:2175
# 5      FANCA  NCBIGene:2175
# 6      FANCA  NCBIGene:2175
# 7      FANCA  NCBIGene:2175
# 8      FANCA  NCBIGene:2175
# 9      FANCA  NCBIGene:2175
# 10     FANCA  NCBIGene:2175
# 11     FANCA  NCBIGene:2175
# 12     FANCA  NCBIGene:2175
# 13     FANCA  NCBIGene:2175
# 14     FANCA  NCBIGene:2175
# 15     FANCA  NCBIGene:2175
# 16     FANCA  NCBIGene:2175
# 17     FANCA  NCBIGene:2175
# 18     FANCA  NCBIGene:2175
# 19     FANCA  NCBIGene:2175
# 20     FANCA  NCBIGene:2175
# 21     FANCA  NCBIGene:2175
# 22     FANCA  NCBIGene:2175
# 23     FANCB  NCBIGene:2187
# 24     FANCB  NCBIGene:2187
# 25     FANCB  NCBIGene:2187
# 26     FANCB  NCBIGene:2187
# 27     FANCB  NCBIGene:2187
# 28     FANCB  NCBIGene:2187
# 29     FANCB  NCBIGene:2187
#
#                                          variant_name          variant_curie  \
# 0   NM_000135.2(FANCA):c.1115_1118delTTGG (p.Val37...    ClinVarVariant:3440
# 1       NM_000135.2(FANCA):c.1615delG (p.Asp539Thrfs)    ClinVarVariant:3443
# 2      NM_000135.2(FANCA):c.4015delC (p.Leu1339Serfs)  ClinVarVariant:208638
# 3           NM_000135.2(FANCA):c.513G>A (p.Trp171Ter)    ClinVarVariant:3447
# 4       NM_000135.2(FANCA):c.2839dupT (p.Ser947Phefs)  ClinVarVariant:188383
# 5                              FANCA, IVS7DS, G-A, +5  ClinVarVariant:192385
# 6   NM_000135.2(FANCA):c.894_1006del113 (p.Trp298C...    ClinVarVariant:3442
# 7            NM_000135.2(FANCA):c.295C>T (p.Gln99Ter)  ClinVarVariant:370361
# 8           NM_000135.2(FANCA):c.811C>T (p.Gln271Ter)  ClinVarVariant:371093
# 9            NM_000135.2(FANCA):c.154C>T (p.Arg52Ter)  ClinVarVariant:371668
# 10     NM_000135.2(FANCA):c.3558dupG (p.Arg1187Glufs)    ClinVarVariant:3444
# 11                        LRG_495t1:c.1627_1900del274    ClinVarVariant:3439
# 12                     NM_000135.2(FANCA):c.3066+1G>T  ClinVarVariant:156400
# 13         NM_000135.2(FANCA):c.2574C>G (p.Ser858Arg)  ClinVarVariant:134256
# 14  NM_000135.2(FANCA):c.987_990delTCAC (p.His330A...  ClinVarVariant:208580
# 15  NM_000135.2(FANCA):c.3788_3790delTCT (p.Phe126...   ClinVarVariant:41003
# 16  NM_000135.2(FANCA):c.3720_3724delAAACA (p.Glu1...    ClinVarVariant:3448
# 17                          FANCA, 156-BP DEL, NT1515    ClinVarVariant:3441
# 18  NM_000135.2(FANCA):c.3761_3762delAG (p.Glu1254...  ClinVarVariant:370466
# 19         NM_000135.2(FANCA):c.2557C>T (p.Arg853Ter)  ClinVarVariant:192384
# 20         NM_000135.2(FANCA):c.2762A>T (p.Lys921Ile)  ClinVarVariant:203995
# 21      NM_000135.2(FANCA):c.1606delT (p.Ser536Glnfs)    ClinVarVariant:3446
# 22                  NM_000135.2(FANCA):c.1007_3066del    ClinVarVariant:3445
# 23                             FANCB, 1-BP DEL, 1650T   ClinVarVariant:10868
# 24                            FANCB, 2-BP DEL, 1857AG   ClinVarVariant:37044
# 25                             FANCB, 1-BP INS, 1838T   ClinVarVariant:10866
# 26                              FANCB, 1-BP INS, 811T   ClinVarVariant:10869
# 27                                 FANCB, 3314-BP DEL   ClinVarVariant:10867
# 28                                   FANCB, LEU717TER   ClinVarVariant:37043
# 29                             FANCB, IVS7DS, G-A, +5   ClinVarVariant:10870
#
#        relation_label relation_curie                            disease_label  \
# 0          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 1          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 2   likely pathogenic   GENO:0000841  Fanconi Anemia, Complementation Group a
# 3          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 4   likely pathogenic   GENO:0000841  Fanconi Anemia, Complementation Group a
# 5          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 6          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 7          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 8   likely pathogenic   GENO:0000841  Fanconi Anemia, Complementation Group a
# 9          pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 10         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 11         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 12         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 13         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 14         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 15         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 16         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 17         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 18         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 19         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 20  likely pathogenic   GENO:0000841  Fanconi Anemia, Complementation Group a
# 21         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 22         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group a
# 23         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 24         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 25         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 26         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 27         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 28         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
# 29         pathogenic   GENO:0000840  Fanconi Anemia, Complementation Group B
#
#    disease_curie
# 0    OMIM:227650
# 1    OMIM:227650
# 2    OMIM:227650
# 3    OMIM:227650
# 4    OMIM:227650
# 5    OMIM:227650
# 6    OMIM:227650
# 7    OMIM:227650
# 8    OMIM:227650
# 9    OMIM:227650
# 10   OMIM:227650
# 11   OMIM:227650
# 12   OMIM:227650
# 13   OMIM:227650
# 14   OMIM:227650
# 15   OMIM:227650
# 16   OMIM:227650
# 17   OMIM:227650
# 18   OMIM:227650
# 19   OMIM:227650
# 20   OMIM:227650
# 21   OMIM:227650
# 22   OMIM:227650
# 23   OMIM:300514
# 24   OMIM:300514
# 25   OMIM:300514
# 26   OMIM:300514
# 27   OMIM:300514
# 28   OMIM:300514
# 29   OMIM:300514
