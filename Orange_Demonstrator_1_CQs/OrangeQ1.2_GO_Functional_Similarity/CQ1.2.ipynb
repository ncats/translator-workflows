# %% [markdown]
# ## Orange Team CQ1.2
#
# ### Query:
# What genes express proteins that are functionally similar to the 11 Fanconi Anemia core complex genes (set FA-core), based on GO annotations?
#
# ### Goal:
# This query aims to expand the FA-core gene set based on GO functional similarity, in service of Task 1 in the St. Jude Life Demonstrator described [here](https://github.com/NCATS-Tangerine/cq-notebooks/wiki/St.-Judes-FA-Demonstrator).
#
# ### Data Types, Sources, and Routes:
# 1. **Gene-ortholog associations** - from Panther, via SciGraph (BioLink [/bioentity/gene/{id}/homologs/](https://api.monarchinitiative.org/api/#!/bioentity/get_gene_homolog_associations))
# 2. **Gene-protein associations** -  from Ensembl, via SciGraph ([BioLink API](https://api.monarchinitiative.org/api/) call or [Monarch API cypher query](https://scigraph-data-dev.monarchinitiative.org/scigraph/docs/#!/cypher/execute)?)
# 3. **Functional annotations** - from GO, via SciGraph ([BioLink API](https://api.monarchinitiative.org/api/) or via Wikidata (SPARQL API)
#
# ### Sub-Queries/Tasks:
#
# **Input:** NCBIGene identifiers for 11 FA-core genes
#   1. Retrieve orthologes of FA-core genes and add to human FA-core set
#   2. Retrieve proteins encoded by genes in this cross-species set
#   3. Retrieve GO terms annotated to these proteins
#   4. Execute analysis to return ranked list of funcionally similar proteins
#   5. Select subset of proteins meeting some defined threshhold
#   6. Retrieve genes that encode these proteins
#   7. Retrieve human orthologs of all non-human genes in this set
#
# **Output:** GeneSetQ2 (functionally similar human genes based on cross-species GO-similarity analysis)
#
# *Note that the subqueries above can be parameterized in any number of ways in their implementation (e.g. select specific taxa  for cross-species expansion, facet on a MF or BP or CC subset of GO annotations, different inclusion threshholds for GO-based similarity, selecting different knowledge sources or routes to retrieve a particular data type). Different combinations of parameters can be explored using different notebooks in this directory.*

# %%
import pandas as pd
import requests
from pprint import pprint
import ontobio

# %% [markdown]
# ### Get the 11 FA core genes from [here](https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/)

# %%
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_1_core_complex = "FA_1_core_complex.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_1_core_complex, sep='\t', names=columns)
fa_genes
# Out:
#         gene_curie gene_symbol
# 0    NCBIGene:2175       FANCA
# 1    NCBIGene:2187       FANCB
# 2    NCBIGene:2176       FANCC
# 3    NCBIGene:2178       FANCE
# 4    NCBIGene:2188       FANCF
# 5    NCBIGene:2189       FANCG
# 6   NCBIGene:55120       FANCL
# 7   NCBIGene:57697       FANCM
# 8    NCBIGene:2177      FANCD2
# 9   NCBIGene:55215       FANCI
# 10  NCBIGene:29089       UBE2T

# %% [markdown]
# ### Utility wrapper for [BioLink API](api.monarchinitiative.org/api)

# %%
class BioLinkWrapper(object):
    def __init__(self):
        self.endpoint = 'https://api.monarchinitiative.org/api/'
        self.params = {
            'fetch_objects':'true',
            'rows':'100'
        }
        
    def get_gene(self, gene_curie):
        params = {}
        url = '{}bioentity/gene/{}'.format(self.endpoint, gene_curie)
        response = requests.get(url, params)
        return response.json()

    def get_orthologs(self, gene_curie, orth_taxon=None):
        params = {}
        if orth_taxon:
            params['homolog_taxon'] = orth_taxon
        url = '{}bioentity/gene/{}/homologs/'.format(self.endpoint, gene_curie)
        response = requests.get(url, params)
        return response.json()

    def get_phenotypes(self,gene_curie):
        url = '{}bioentity/gene/{}/phenotypes/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_diseases(self, gene_curie):
        url = '{}bioentity/gene/{}/diseases/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_interactions(self, gene_curie):
        url = '{}bioentity/gene/{}/interactions/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_functions(self, gene_curie):
        url = '{}bioentity/gene/{}/function/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_disease_models(self, disease_curie):
        url = '{}/bioentity/disease/{}/models/'.format(self.endpoint, disease_curie)
        response = requests.get(url)
        return response.json()
    
    def get_all_phenotypes_for_taxon(self, taxon_curie):
        # get phenotypes associated with taxid
        url = "mart/gene/phenotype/{}".format(self.endpoint, taxon_curie)
        response = requests.get(url)
        return response.json()
    
    def get_gene_function(self, gene_curie):
        # get function associated with gene
        url = "{}bioentity/gene/{}/function/".format(self.endpoint, gene_curie)
        response = requests.get(url, params=self.params)
        return response.json()

# %% [markdown]
# ### Get orthologs from Biolink API

# %%
fa_genes_orthologs = list()
for index, gene in fa_genes.iterrows():
    orthologs = BLW.get_orthologs(gene[0])
    for orth in orthologs['associations']:
        orth_dict = {
            'gene_name': gene[1],
            'gene_curie': gene[0],
            'ortholog_name': orth['object']['label'],
            'ortholog_curie': orth['object']['id'],
            'orth_tax_label': orth['object']['taxon']['label'],
            'orth_tax_id': orth['object']['taxon']['id']
        }
        fa_genes_orthologs.append(orth_dict)

# %% [markdown]
# ### Load into data frame

# %%
orth_columns  = [ 'gene_name', 'gene_curie', 'ortholog_name', 'ortholog_curie', 'orth_tax_label', 'orth_tax_id']
orth_df = pd.DataFrame(data=fa_genes_orthologs, columns=orth_columns)
orth_df.head()
# Out:
#   gene_name     gene_curie ortholog_name      ortholog_curie  \
# 0     FANCA  NCBIGene:2175         FANCA  NCBIGene:100080126
# 1     FANCA  NCBIGene:2175         Fanca         RGD:1311380
# 2     FANCA  NCBIGene:2175         FANCA  NCBIGene:100621453
# 3     FANCA  NCBIGene:2175         FANCA     NCBIGene:618375
# 4     FANCA  NCBIGene:2175         FANCA     NCBIGene:454393
#
#              orth_tax_label      orth_tax_id
# 0  Ornithorhynchus anatinus   NCBITaxon:9258
# 1         Rattus norvegicus  NCBITaxon:10116
# 2                Sus scrofa   NCBITaxon:9823
# 3                Bos taurus   NCBITaxon:9913
# 4           Pan troglodytes   NCBITaxon:9598

# %%
'{} Orthologs found'.format(len(orth_df.index))
# Out:
# '111 Orthologs found'

# %% [markdown]
# ### Query wrapper for retrieving UniProt IDs from [MyGene.info](mygene.info)

# %%
def query_mygene(gene_curie):
    gene_curie = gene_curie.replace('NCBIGene:', '')
    url = 'https://mygene.info/v3/query?q={}&fields=all'.format(gene_curie)
    hit = requests.get(url)
    hit = hit.json()
    uniprot = hit['hits'][0]['uniprot']
    if 'Swiss-Prot' in uniprot.keys():
        if isinstance(uniprot['Swiss-Prot'], list):
            return uniprot['Swiss-Prot']
        elif isinstance(uniprot['Swiss-Prot'], str):
            return [uniprot['Swiss-Prot']]
        else:
            return None

# %% [markdown]
# ### Use [Ontobio](https://github.com/biolink/ontobio) for computing functional similarity between sets of GO terms annotated to genes

# %%
from ontobio.ontol_factory import OntologyFactory
# Create ontology object, for GO
# Transparently uses remote SPARQL service.
# (May take a few seconds to run first time, Jupyter will show '*'. BE PATIENT, do
# not re-execute cell)
ofactory = OntologyFactory()
ont = ofactory.create('go')

# %% [markdown]
# ### Get gene-function associations from the [GeneOntology](http://geneontology.org/)

# %%
from ontobio.io.gafparser import GafParser
from ontobio.assoc_factory import AssociationSetFactory

p = GafParser()
afactory = AssociationSetFactory()

def make_assocs(group, parse=False):
    url = "http://geneontology.org/gene-associations/gene_association.{}.gz".format(group)
    if group == 'human':
        url = "http://geneontology.org/gene-associations/goa_human.gaf.gz"
    assocs = p.parse(url)
    if parse:
        return assocs
    else:
        return afactory.create_from_assocs(assocs, ontology=ont)

# %% [markdown]
# ### Functionally similar human genes

# %%
asoc_hsap = make_assocs('human')

# %%
def parse_gene_functions(curie):
    BLW1 = BioLinkWrapper()
    function_list =list()
    functions = BLW1.get_gene_function(gene_curie=curie)
    if 'associations' in functions.keys():
        for assoc in functions['associations']:
            function_list.append(assoc['object']['label'])
    function_set = set(function_list)
    return ", ".join(function_set)

# %%
human_sims = list()
for index, row in fa_genes.iterrows():
    fa_gene_curie = row[0]
    fa_gene_name = row[1]
    ukb = query_mygene(fa_gene_curie)
    for hgene in list(asoc_hsap.subject_label_map.keys()):
        amScore = asoc_hsap.jaccard_similarity('UniProtKB:{}'.format("".join(ukb)), hgene)
        if amScore > .7 and amScore < 1:
            human_sims.append({
                'fa_gene_name': fa_gene_name,
                'fa_gene_curie': fa_gene_curie,
                'sim_gene_name': asoc_hsap.label(hgene),
                'sim_hit_curie': hgene,
                'sim_score': amScore,
            })

# %%
human_simDF = pd.DataFrame(data=human_sims)

# %%
human_simDF.head()
# Out:
#    fa_gene_curie fa_gene_name sim_gene_name     sim_hit_curie  sim_score
# 0  NCBIGene:2187        FANCB       FAAP100  UniProtKB:Q0VG06   0.813559
# 1  NCBIGene:2187        FANCB        FAAP24  UniProtKB:Q9BTP7   0.905660
# 2  NCBIGene:2187        FANCB         FANCE  UniProtKB:Q9HB96   0.958333
# 3  NCBIGene:2187        FANCB          INIP  UniProtKB:Q9NRY2   0.865385
# 4  NCBIGene:2187        FANCB          INIP        HGNC:24994   0.755102

# %%
human_simDF['sim_hit_functions'] = human_simDF['sim_hit_curie'].apply(parse_gene_functions)

# %%
human_simDF.to_csv('HumanFunctionallySimilarGenes.csv', sep='\t')

# %%
human_simDF
# Out:
#      fa_gene_curie fa_gene_name sim_gene_name     sim_hit_curie  sim_score  \
# 0    NCBIGene:2187        FANCB       FAAP100  UniProtKB:Q0VG06   0.813559
# 1    NCBIGene:2187        FANCB        FAAP24  UniProtKB:Q9BTP7   0.905660
# 2    NCBIGene:2187        FANCB         FANCE  UniProtKB:Q9HB96   0.958333
# 3    NCBIGene:2187        FANCB          INIP  UniProtKB:Q9NRY2   0.865385
# 4    NCBIGene:2187        FANCB          INIP        HGNC:24994   0.755102
# 5    NCBIGene:2187        FANCB         FANCC         HGNC:3584   0.830189
# 6    NCBIGene:2178        FANCE       FAAP100  UniProtKB:Q0VG06   0.779661
# 7    NCBIGene:2178        FANCE         FANCB  UniProtKB:Q8NB91   0.958333
# 8    NCBIGene:2178        FANCE        FAAP24  UniProtKB:Q9BTP7   0.867925
# 9    NCBIGene:2178        FANCE         FANCF  UniProtKB:Q9NPI8   0.958333
# 10   NCBIGene:2178        FANCE          INIP  UniProtKB:Q9NRY2   0.826923
# 11   NCBIGene:2178        FANCE          INIP        HGNC:24994   0.787234
# 12   NCBIGene:2178        FANCE         FANCC         HGNC:3584   0.862745
# 13   NCBIGene:2188        FANCF       FAAP100  UniProtKB:Q0VG06   0.813559
# 14   NCBIGene:2188        FANCF        FAAP24  UniProtKB:Q9BTP7   0.905660
# 15   NCBIGene:2188        FANCF         FANCE  UniProtKB:Q9HB96   0.958333
# 16   NCBIGene:2188        FANCF          INIP  UniProtKB:Q9NRY2   0.865385
# 17   NCBIGene:2188        FANCF          INIP        HGNC:24994   0.755102
# 18   NCBIGene:2188        FANCF         FANCC         HGNC:3584   0.830189
# 19  NCBIGene:57697        FANCM        STRA13        HGNC:11422   0.723577
# 20  NCBIGene:57697        FANCM        APITD1        HGNC:23163   0.731707
#
#                                     sim_hit_functions
# 0   DNA binding, Fanconi anaemia nuclear complex, ...
# 1   intracellular membrane-bounded organelle, DNA ...
# 2   molecular_function, nucleus, Fanconi anaemia n...
# 3   nucleus, DNA repair, cellular response to DNA ...
# 4                            DNA repair, SOSS complex
# 5   Fanconi anaemia nuclear complex, nucleotide-ex...
# 6   DNA binding, Fanconi anaemia nuclear complex, ...
# 7   interstrand cross-link repair, nucleoplasm, pr...
# 8   intracellular membrane-bounded organelle, DNA ...
# 9   molecular_function, biological_process, Fancon...
# 10  nucleus, DNA repair, cellular response to DNA ...
# 11                           DNA repair, SOSS complex
# 12  Fanconi anaemia nuclear complex, nucleotide-ex...
# 13  DNA binding, Fanconi anaemia nuclear complex, ...
# 14  intracellular membrane-bounded organelle, DNA ...
# 15  molecular_function, nucleus, Fanconi anaemia n...
# 16  nucleus, DNA repair, cellular response to DNA ...
# 17                           DNA repair, SOSS complex
# 18  Fanconi anaemia nuclear complex, nucleotide-ex...
# 19  replication fork processing, FANCM-MHF complex...
# 20  replication fork processing, FANCM-MHF complex...

# %% [markdown]
# ### Now look for genes in the mouse genome that are functionally similar to the mouse orthologs of the FA Core genes in humans

# %% [markdown]
# Get mouse gene function associations

# %%
asoc_mouse = make_assocs(group='mgi')

# %% [markdown]
# ### Compute Jaccard Similarity and assign scores

# %% [markdown]
# Use Ontobio's Jaccard similarity functionality to compare annotation sets of genes (within the same genome) and assign a sim score to those hits that have a similarity score of greater than 70%

# %%
mouse_orthologs = orth_df.loc[orth_df['orth_tax_id'] == 'NCBITaxon:10090']
mouse_ortho_sims = list()
for index, row in mouse_orthologs.iterrows():
    gene_name = row[0]
    gene_curie = row[1]
    ortholog_name = row[2]
    ortholog_curie = row[3]
    ortholog_taxon_curie = row[5]
    ortholog_taxon_name = row[4]
    mo = 'MGI:{}'.format(ortholog_curie)
    for mgene in list(asoc_mouse.subject_label_map.keys()):
        amScore = asoc_mouse.jaccard_similarity(mo, mgene)  
        if amScore > .7 and amScore < 1:
            mouse_ortho_sims.append({
                    'gene_name': gene_name,
                    'gene_curie': gene_curie,
                    'ortholog_name': ortholog_name,
                    'ortholog_curie': ortholog_curie,
                    'ortholog_taxon_curie': ortholog_taxon_curie,
                    'ortholog_taxon_name': ortholog_taxon_name,
                    'non_fa_hit_name': asoc_mouse.label(mgene),
                    'non_fa_hit_curie': mgene.replace('MGI:MGI:', 'MGI:'),
                    'sim_score' : amScore
                })

# %% [markdown]
# ### Load annotations into dataframe mouse specific dataframe

# %%
mouse_sims_columns = [ 'gene_name','gene_curie', 'ortholog_name', 
                      'ortholog_curie', 'ortholog_taxon_curie', 
                      'ortholog_taxon_name', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
mouse_sims_df = pd.DataFrame(data=mouse_ortho_sims, columns=mouse_sims_columns )

# %%
mouse_sims_df.sort_values(by=['sim_score'], ascending=False).head()
# Out:
#    gene_name     gene_curie ortholog_name ortholog_curie ortholog_taxon_curie  \
# 10     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 1      FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 62     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 61     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 4      FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
#
#    ortholog_taxon_name non_fa_hit_name non_fa_hit_curie  sim_score
# 10        Mus musculus          Cfap45      MGI:1919120   0.833333
# 1         Mus musculus   1110032A03Rik      MGI:1915971   0.833333
# 62        Mus musculus          Zbtb34      MGI:2685195   0.833333
# 61        Mus musculus          Zbtb11      MGI:2443876   0.833333
# 4         Mus musculus   2310022A10Rik      MGI:1913617   0.833333

# %% [markdown]
# ### Find human orthologs of mouse genes with functional similarity over 75% to mouse FA core gene orthologs

# %%
def find_human_orthologs(curie):
    orth_list = list()
    BioL = BioLinkWrapper()
    orths = BioL.get_orthologs(gene_curie=curie, orth_taxon='NCBITaxon:9606')
    if 'associations' in orths.keys():
        for orth in orths['associations']:
            orth_list.append(orth['object']['id'])
    return orth_list

# %%
mouse_sims_df['human_orth_hit'] = mouse_sims_df['non_fa_hit_curie'].apply(find_human_orthologs)

# %% [markdown]
# ### 'human_orth_hit' column are human genes, that orthologs to mouse genes that are functionally similar to
#
# Example Row[0]:
# FancE (NCBIGene:2178) has mouse ortholog Fance (MGI:1920025).
# Fance has functional similarity to the mouse gene  0610040J01Rik (MGI:1923511).
# 0610040J01Rik is an ortholog to the human gene (HGNC:25618, NCBIGene:55286)

# %%
mouse_sims_df.head()
# Out:
#   gene_name     gene_curie ortholog_name ortholog_curie ortholog_taxon_curie  \
# 0     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 1     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 2     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 3     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
# 4     FANCE  NCBIGene:2178         Fance    MGI:1920025      NCBITaxon:10090
#
#   ortholog_taxon_name non_fa_hit_name non_fa_hit_curie  sim_score  \
# 0        Mus musculus   0610040J01Rik      MGI:1923511   0.800000
# 1        Mus musculus   1110032A03Rik      MGI:1915971   0.833333
# 2        Mus musculus   1700030J22Rik      MGI:1916778   0.740741
# 3        Mus musculus   2200002D01Rik      MGI:1919525   0.703704
# 4        Mus musculus   2310022A10Rik      MGI:1913617   0.833333
#
#   human_orth_hit
# 0   [HGNC:25618]
# 1    [HGNC:1163]
# 2   [HGNC:26525]
# 3             []
# 4   [HGNC:26723]

# %%
human_functionally_similar_genes = mouse_sims_df['human_orth_hit'].tolist()

# %% [markdown]
# #### Final list of human genes that are orthologs of mouse genes that are functionally similar to mouse orthologs of FA core human genes.

# %%
final_set = set([j for i in human_functionally_similar_genes for j in i])

# %% [markdown]
# ### Display gene id, name and functional annotations

# %%
final_hits = list()
for index, gene in enumerate(final_set):
    function_list = list()
    gene_info = BLW.get_gene(gene_curie=gene)
    gene_function = BLW.get_gene_function(gene_curie=gene)
    if 'associations' in gene_function.keys():
        for assoc in gene_function['associations']:
            function_list.append(assoc['object']['label'])
    function_set = set(function_list)
    if len(function_set) > 0: 
        try:
            final_hits.append([gene, gene_info['label'], ", ".join(function_set)])
        except Exception as e:
            print(e)
hits_frame = pd.DataFrame(data=final_hits, columns=['HGNC', 'Symbol', 'Function(s)' ])
hits_frame.to_csv('MouseFunctionallySimilarGenes.csv', sep='\t')
pd.set_option('display.max_colwidth', -1)
# Out:
# sequence item 1: expected str instance, NoneType found

# %%
hits_frame
# Out:
#           HGNC    Symbol  \
# 0   HGNC:13574  MAGEC2
# 1   HGNC:17229  CFAP45
# 2   HGNC:26224  FAM124B
# 3   HGNC:16933  FEM1C
# 4   HGNC:21198  HCFC1R1
# 5   HGNC:24932  C9orf78
# 6   HGNC:21248  WDR27
# 7   HGNC:17305  TAF6L
# 8   HGNC:23219  NAALADL2
# 9   HGNC:25091  ZC3H18
# 10  HGNC:28492  FAM76B
# 11  HGNC:25563  FAM222B
# 12  HGNC:25806  GSTCD
# 13  HGNC:5043   HNRNPH3
# 14  HGNC:16106  NOL4L
# 15  HGNC:4917   HIRIP3
# 16  HGNC:25074  LYRM1
# 17  HGNC:26525  C16orf46
# 18  HGNC:16170  FAM217B
# 19  HGNC:24319  CMIP
# 20  HGNC:23172  MYCT1
# 21  HGNC:24306  NUDCD1
# 22  HGNC:24991  C19orf53
# 23  HGNC:25989  CWC25
# 24  HGNC:32070  LYSMD1
# 25  HGNC:25150  PWWP2B
# 26  HGNC:21931  UBN2
# 27  HGNC:25618  C4orf19
# 28  HGNC:28189  NUDT22
# 29  HGNC:20884  PLEKHG1
# 30  HGNC:6797   MAGEA10
# 31  HGNC:23484  FAM208B
# 32  HGNC:27750  C5orf51
# 33  HGNC:29108  SEL1L3
# 34  HGNC:18786  FAM50A
# 35  HGNC:26236  SH3D21
# 36  HGNC:6658   VWA5A
# 37  HGNC:15857  GID8
# 38  HGNC:1163   C11orf1
# 39  HGNC:26723  C19orf47
# 40  HGNC:28033  CCDC174
# 41  HGNC:33744  TMEM179B
# 42  HGNC:29135  ANKRD12
# 43  HGNC:22202  FAM131B
# 44  HGNC:25451  HNRNPUL2
# 45  HGNC:22194  KLHDC10
# 46  HGNC:29039  RPRD2
# 47  HGNC:21208  WDR26
# 48  HGNC:24661  REXO5
# 49  HGNC:6812   MAGEC1
# 50  HGNC:19752  FNBP4
# 51  HGNC:30763  NR2C2AP
# 52  HGNC:28530  FAM76A
# 53  HGNC:21365  LYRM4
#
#                                                                                                                                                                                                                                                                                                                                                                                             Function(s)
# 0   nucleus, cellular protein catabolic process, protein binding, nucleolus, cytoplasm, positive regulation of ubiquitin-protein transferase activity, cytosol, ubiquitin protein ligase binding
# 1   cilium, nucleoplasm, nucleus
# 2   nucleoplasm, protein binding, mitochondrion
# 3   post-translational protein modification, protein ubiquitination, nucleoplasm, protein binding, cytosol
# 4   cytoplasm, nucleoplasm
# 5   nucleoplasm, protein binding, cytosol
# 6   nucleoplasm, protein binding
# 7   transcription factor TFIID complex, transcription coactivator activity, chromatin organization, SAGA complex, transcription by RNA polymerase II, DNA binding transcription factor activity, histone H3 acetylation, histone acetyltransferase activity, RNA polymerase II activating transcription factor binding, RNA polymerase II transcriptional preinitiation complex assembly, STAGA complex
# 8   integral component of membrane, nucleoplasm, protein binding
# 9   metal ion binding, nuclear speck, protein binding, protein complex, RNA binding
# 10  protein binding, nuclear speck
# 11  nucleoplasm
# 12  cytoplasm
# 13  spliceosomal complex, nucleus, RNA processing, mRNA splicing, via spliceosome, epithelial cell differentiation, nucleoplasm, protein binding, RNA binding, RNA splicing
# 14  nucleoplasm, protein binding, cytosol
# 15  chromatin assembly or disassembly, protein binding, nucleus, nucleolus
# 16  mitochondrion
# 17  nucleoplasm, nucleus, cytosol
# 18  nucleoplasm, cytosol
# 19  nucleoplasm, protein binding, cytosol
# 20  nucleoplasm, intracellular membrane-bounded organelle
# 21  nucleoplasm, protein binding, cytosol, immune system process
# 22  nucleus, nucleolus
# 23  nucleoplasm, mRNA splicing, via spliceosome, nuclear speck
# 24  nucleoplasm, protein binding, nucleus
# 25  nucleoplasm, protein binding
# 26  nucleoplasm, extracellular space
# 27  nucleoplasm, protein binding, cell junction
# 28  nucleoplasm, protein binding, hydrolase activity
# 29  regulation of molecular function, nucleus, nucleoplasm, regulation of Rho protein signal transduction, Rho guanyl-nucleotide exchange factor activity
# 30  nucleoplasm, cytosol
# 31  nucleoplasm, protein binding, nucleus, cytosol
# 32  nucleoplasm, cytosol
# 33  integral component of membrane, nucleoplasm, nucleus
# 34  nucleoplasm, RNA binding, nucleus, spermatogenesis
# 35  nucleoplasm, plasma membrane, extracellular exosome, nucleus
# 36  nucleoplasm, nucleus
# 37  nucleoplasm, protein binding, cell junction
# 38  nucleoplasm, molecular_function, biological_process, nucleus
# 39  nucleoplasm, protein binding
# 40  nucleoplasm, protein binding, nucleus
# 41  azurophil granule membrane, nuclear speck, integral component of membrane, neutrophil degranulation, nucleolus, plasma membrane, ficolin-1-rich granule membrane, secretory granule membrane
# 42  nucleoplasm, cytosol
# 43  nucleoplasm, protein binding, cytosol
# 44  nucleus, biological_process, nucleoplasm, RNA binding, membrane
# 45  cytoplasm, nucleoplasm, protein binding
# 46  snRNA transcription by RNA polymerase II, nucleoplasm, DNA-directed RNA polymerase II, holoenzyme
# 47  nucleoplasm, protein binding, cytoplasm, cytosol, mitochondrion
# 48  extracellular exosome, nucleic acid phosphodiester bond hydrolysis, nucleolus, RNA binding, exonuclease activity
# 49  protein binding
# 50  protein binding, nuclear speck
# 51  nucleoplasm
# 52  nucleoplasm
# 53  mitochondrial matrix, small molecule metabolic process, nuclear body

# %% [markdown]
# TODO: This analysis is for human and mouse only.  This needs to be done on a species by species basis to find more candidates.
