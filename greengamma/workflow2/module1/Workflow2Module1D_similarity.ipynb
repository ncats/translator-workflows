# %% [markdown]
# # Workflow 2, Module 1D

# %% [markdown]
# ## Chemical similarity

# %% [markdown]
# The query as written links chenmicals to genes via GO terms, but we can more directly link chemicals to genes.

# %% [markdown]
# ### Set up functions

# %%
robokop_server = 'robokop.renci.org'

# %%
import requests
import pandas as pd

# %%
def expand(type1,identifier,type2,rebuild=None,csv=None,predicate=None):
    url=f'http://{robokop_server}:80/api/simple/expand/{type1}/{identifier}/{type2}'
    params = {'rebuild': rebuild, 
              'csv'    : csv,
              'predicate': predicate} 
    params = { k:v for k,v in params.items() if v is not None }
    response = requests.get(url,params=params)
    print( f'Return Status: {response.status_code}' )
    if response.status_code == 200:
        return response.json()
    return []

# %%
def similarity(type1,ident,type2,by_type,threshhold=None,maxresults=None,rebuild=None):
    url=f'http://{robokop_server}/api/simple/similarity/{type1}/{ident}/{type2}/{by_type}'
    params = { 'threshhold': threshhold, 'maxresults': maxresults, 'rebuild': rebuild }
    params = { k:v for k,v in params.items() if v is not None }
    response=requests.get(url, params = params)
    print( 'Return code:',response.status_code )
    return response.json()

# %%
def parse_answer(returnanswer):
    nodes = [answer['nodes'][1] for answer in returnanswer['answers']]
    edges = [answer['edges'][0] for answer in returnanswer['answers']]
    answers = [ {"result_id": node["id"], 
                 "result_name": node["name"] if 'name' in node else node['id'], 
                 "type": edge["type"],
                 "source": edge['edge_source']}
              for node,edge in zip(nodes,edges)]
    return pd.DataFrame(answers)

# %% [markdown]
# ### Expand from disease to genes

# %%
FA='MONDO:0019391'
fa_genes = expand('disease',FA,'gene')
fa_gene_frame = parse_answer(fa_genes)
fa_gene_frame
# Out:
# Return Status: 200
#      result_id result_name                   source  \
# 0    HGNC:3585      FANCD2  pharos.gene_get_disease
# 1    HGNC:3588       FANCG  pharos.gene_get_disease
# 2    HGNC:3582       FANCA  pharos.gene_get_disease
# 3   HGNC:23168       FANCM  pharos.disease_get_gene
# 4    HGNC:3587       FANCF  pharos.gene_get_disease
# 5   HGNC:26144       PALB2  pharos.disease_get_gene
# 6    HGNC:3586       FANCE  pharos.disease_get_gene
# 7    HGNC:9820      RAD51C  pharos.disease_get_gene
# 8    HGNC:3583       FANCB  pharos.disease_get_gene
# 9   HGNC:25009       UBE2T  pharos.gene_get_disease
# 10   HGNC:9817       RAD51  pharos.disease_get_gene
# 11   HGNC:3436       ERCC4  pharos.disease_get_gene
# 12  HGNC:25539       RFWD3  pharos.gene_get_disease
# 13   HGNC:3584       FANCC  pharos.gene_get_disease
# 14   HGNC:1101       BRCA2  pharos.gene_get_disease
# 15   HGNC:6764      MAD2L2  pharos.disease_get_gene
# 16  HGNC:25568       FANCI  pharos.disease_get_gene
# 17  HGNC:20748       FANCL  pharos.gene_get_disease
# 18  HGNC:20473       BRIP1  pharos.disease_get_gene
# 19  HGNC:23845        SLX4  pharos.disease_get_gene
# 20  HGNC:29170        FAN1  pharos.gene_get_disease
# 21  HGNC:29814       MUS81  pharos.gene_get_disease
# 22  HGNC:12791         WRN  pharos.gene_get_disease
# 23  HGNC:12814         XPA  pharos.disease_get_gene
# 24   HGNC:1058         BLM  pharos.gene_get_disease
# 25  HGNC:12829       XRCC2  pharos.gene_get_disease
# 26  HGNC:14060        REV1  pharos.disease_get_gene
# 27  HGNC:26171     FAAP100  pharos.disease_get_gene
# 28   HGNC:2736       DDX11  pharos.gene_get_disease
# 29  HGNC:33499       ATRIP  pharos.gene_get_disease
# 30   HGNC:4739       H2AFX  pharos.disease_get_gene
# 31  HGNC:10071        RNF8  pharos.gene_get_disease
# 32   HGNC:2939        DNA2  pharos.gene_get_disease
# 33  HGNC:17641     DCLRE1B  pharos.gene_get_disease
# 34   HGNC:9823      RAD51D  pharos.gene_get_disease
# 35  HGNC:25764        RMI1  pharos.disease_get_gene
# 36  HGNC:18536        HELQ  pharos.gene_get_disease
# 37  HGNC:16956    RAD51AP1  pharos.gene_get_disease
# 38  HGNC:11999     TP53BP1  pharos.gene_get_disease
# 39  HGNC:17660     DCLRE1A  pharos.disease_get_gene
# 40  HGNC:25752       ATAD5  pharos.gene_get_disease
# 41  HGNC:18870        POLN  pharos.gene_get_disease
# 42  HGNC:13620        FBH1  pharos.gene_get_disease
# 43   HGNC:7532         MX1  pharos.disease_get_gene
# 44  HGNC:19427      GGNBP1  pharos.gene_get_disease
# 45    HGNC:795         ATM  pharos.gene_get_disease
# 46  HGNC:23163       CENPS  pharos.gene_get_disease
# 47  HGNC:20994      ZSCAN2  pharos.disease_get_gene
# 48  HGNC:28748       SLX1B  pharos.gene_get_disease
# 49  HGNC:24965        EME1  pharos.gene_get_disease
# 50  HGNC:11422       CENPX  pharos.disease_get_gene
# 51  HGNC:20922       SLX1A  pharos.disease_get_gene
# 52  HGNC:37101     DDX11L8  pharos.gene_get_disease
# 53  HGNC:31792      BOD1L1  pharos.gene_get_disease
# 54   HGNC:2737      DDX12P  pharos.disease_get_gene
# 55  HGNC:30298       UIMC1  pharos.gene_get_disease
# 56  HGNC:11892         TNF  pharos.disease_get_gene
#
#                            type
# 0   disease_to_gene_association
# 1   disease_to_gene_association
# 2   disease_to_gene_association
# 3   disease_to_gene_association
# 4   disease_to_gene_association
# 5   disease_to_gene_association
# 6   disease_to_gene_association
# 7   disease_to_gene_association
# 8   disease_to_gene_association
# 9   disease_to_gene_association
# 10  disease_to_gene_association
# 11  disease_to_gene_association
# 12  disease_to_gene_association
# 13  disease_to_gene_association
# 14  disease_to_gene_association
# 15  disease_to_gene_association
# 16  disease_to_gene_association
# 17  disease_to_gene_association
# 18  disease_to_gene_association
# 19  disease_to_gene_association
# 20  disease_to_gene_association
# 21  disease_to_gene_association
# 22  disease_to_gene_association
# 23  disease_to_gene_association
# 24  disease_to_gene_association
# 25  disease_to_gene_association
# 26  disease_to_gene_association
# 27  disease_to_gene_association
# 28  disease_to_gene_association
# 29  disease_to_gene_association
# 30  disease_to_gene_association
# 31  disease_to_gene_association
# 32  disease_to_gene_association
# 33  disease_to_gene_association
# 34  disease_to_gene_association
# 35  disease_to_gene_association
# 36  disease_to_gene_association
# 37  disease_to_gene_association
# 38  disease_to_gene_association
# 39  disease_to_gene_association
# 40  disease_to_gene_association
# 41  disease_to_gene_association
# 42  disease_to_gene_association
# 43  disease_to_gene_association
# 44  disease_to_gene_association
# 45  disease_to_gene_association
# 46  disease_to_gene_association
# 47  disease_to_gene_association
# 48  disease_to_gene_association
# 49  disease_to_gene_association
# 50  disease_to_gene_association
# 51  disease_to_gene_association
# 52  disease_to_gene_association
# 53  disease_to_gene_association
# 54  disease_to_gene_association
# 55  disease_to_gene_association
# 56  disease_to_gene_association

# %% [markdown]
# ## Similiarity

# %% [markdown]
# Now we have a list of genes.  Let's find genes with similar chemical associations.  Here's a query for doing that for one of the genes:

# %%
genes = list(fa_gene_frame['result_id'])
similar = similarity('gene',genes[0],'gene','chemical_substance',threshhold=0.3)
pd.DataFrame(similar)
# Out:
# Return code: 200
#            id    name  similarity
# 0  HGNC:25568   FANCI    0.348837
# 1  HGNC:24573   NEIL3    0.304348
# 2  HGNC:17255   KNTC1    0.303030
# 3  HGNC:12307  TRIP13    0.302632
# 4  HGNC:14629   CDCA8    0.301205

# %% [markdown]
# So we want to do this for each of the FA genes, and we want to only include results that aren't already part of the original gene list.  For demo purposes, let's only use the first 10 rows of fa_genes.

# %%
subset_fa_gene_frame = fa_gene_frame.iloc[0:10]

# %%
sim_frames = []
for row in subset_fa_gene_frame.iterrows():
    similar = similarity('gene',row[1]['result_id'],'gene','chemical_substance',threshhold=0.3)
    sframe = pd.DataFrame(similar)
    sframe['query_id'] = row[1]['result_id']
    sframe['query_name'] = row[1]['result_name']
    sim_frames.append(sframe)
all_sim = pd.concat(sim_frames)
# Out:
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200
# Return code: 200

# %%
v = fa_gene_frame['result_name'].values
new_genes = all_sim[ ~ all_sim['name'].isin(v) ]
new_genes
# Out:
#             id     name    query_id query_name  similarity
# 1   HGNC:24573    NEIL3   HGNC:3585     FANCD2    0.304348
# 2   HGNC:17255    KNTC1   HGNC:3585     FANCD2    0.303030
# 3   HGNC:12307   TRIP13   HGNC:3585     FANCD2    0.302632
# 4   HGNC:14629    CDCA8   HGNC:3585     FANCD2    0.301205
# 0   HGNC:11629    TCF19   HGNC:3588      FANCG    0.410714
# 1    HGNC:3511     EXO1   HGNC:3588      FANCG    0.366667
# 2   HGNC:23170    WDHD1   HGNC:3588      FANCG    0.344828
# 4   HGNC:17228   RAD54B   HGNC:3588      FANCG    0.339623
# 5   HGNC:16673   ANP32E   HGNC:3588      FANCG    0.333333
# 6   HGNC:21348    CENPU   HGNC:3588      FANCG    0.328358
# 7    HGNC:4861    HELLS   HGNC:3588      FANCG    0.327869
# 8   HGNC:14553    LRP10   HGNC:3588      FANCG    0.327273
# 9   HGNC:17008   TOPBP1   HGNC:3588      FANCG    0.326531
# 10   HGNC:9186     POLQ   HGNC:3588      FANCG    0.322034
# 11   HGNC:9971     RFC3   HGNC:3588      FANCG    0.318841
# 12    HGNC:952    BARD1   HGNC:3588      FANCG    0.317460
# 14  HGNC:18037    ARID2   HGNC:3588      FANCG    0.312500
# 15   HGNC:6598     LIG1   HGNC:3588      FANCG    0.307692
# 16  HGNC:10879     STIL   HGNC:3588      FANCG    0.301887
# 0   HGNC:11524    TACC3   HGNC:3582      FANCA    0.333333
# 1   HGNC:16731   FBXO32   HGNC:3582      FANCA    0.333333
# 2   HGNC:20262     SKA3   HGNC:3582      FANCA    0.325581
# 3    HGNC:3097     DYSF   HGNC:3582      FANCA    0.317073
# 4   HGNC:16147     MCM8   HGNC:3582      FANCA    0.313725
# 6   HGNC:24134  ZCCHC14   HGNC:3582      FANCA    0.311111
# 7   HGNC:19751   SRGAP2   HGNC:3582      FANCA    0.309524
# 8   HGNC:28980    GINS1   HGNC:3582      FANCA    0.309091
# 9   HGNC:24573    NEIL3   HGNC:3582      FANCA    0.307692
# 10  HGNC:19125     FGD4   HGNC:3582      FANCA    0.307692
# 11  HGNC:11811    KLF11   HGNC:3582      FANCA    0.307692
# ..         ...      ...         ...        ...         ...
# 69   HGNC:9972     RFC4  HGNC:25009      UBE2T    0.338235
# 70  HGNC:14013     SMC4  HGNC:25009      UBE2T    0.338028
# 71   HGNC:6395    KPNA2  HGNC:25009      UBE2T    0.338028
# 72   HGNC:6945     MCM3  HGNC:25009      UBE2T    0.337662
# 73  HGNC:17759    PDSS1  HGNC:25009      UBE2T    0.333333
# 74   HGNC:4861    HELLS  HGNC:25009      UBE2T    0.333333
# 75   HGNC:1739    CDC45  HGNC:25009      UBE2T    0.333333
# 76   HGNC:9341     PRC1  HGNC:25009      UBE2T    0.333333
# 77  HGNC:19181    KIF14  HGNC:25009      UBE2T    0.333333
# 78  HGNC:10823  SH3BGRL  HGNC:25009      UBE2T    0.333333
# 79  HGNC:10879     STIL  HGNC:25009      UBE2T    0.333333
# 80  HGNC:29479    CENPK  HGNC:25009      UBE2T    0.333333
# 81   HGNC:1791    CDKN3  HGNC:25009      UBE2T    0.329670
# 82   HGNC:6510    STMN1  HGNC:25009      UBE2T    0.329412
# 83  HGNC:17273    KIF15  HGNC:25009      UBE2T    0.328767
# 84  HGNC:29501    GPSM2  HGNC:25009      UBE2T    0.328125
# 85   HGNC:9186     POLQ  HGNC:25009      UBE2T    0.328125
# 86  HGNC:16165     DSN1  HGNC:25009      UBE2T    0.327273
# 87  HGNC:19042    MASTL  HGNC:25009      UBE2T    0.327273
# 88  HGNC:11830      TK1  HGNC:25009      UBE2T    0.326316
# 89   HGNC:5000    HMGB2  HGNC:25009      UBE2T    0.324675
# 90  HGNC:13698    GTSE1  HGNC:25009      UBE2T    0.324324
# 91   HGNC:1723    CDC20  HGNC:25009      UBE2T    0.322581
# 92  HGNC:24453    DSCC1  HGNC:25009      UBE2T    0.322034
# 93  HGNC:20951    FOXQ1  HGNC:25009      UBE2T    0.322034
# 94  HGNC:19048     ASPM  HGNC:25009      UBE2T    0.321429
# 95   HGNC:6763   MAD2L1  HGNC:25009      UBE2T    0.321429
# 96   HGNC:5012     HMMR  HGNC:25009      UBE2T    0.320988
# 97   HGNC:7548    MYBL2  HGNC:25009      UBE2T    0.318841
# 98   HGNC:6700     LRP8  HGNC:25009      UBE2T    0.318841
#
# [322 rows x 5 columns]

# %% [markdown]
# Currently the list is sorted by 1) the rank of the original FA gene and then 2) the similarity.  We can sort by overall similarity.

# %%
new_genes.sort_values(by=["similarity"],ascending=False)
# Out:
#             id        name    query_id query_name  similarity
# 0   HGNC:33867      SDHAF1  HGNC:26144      PALB2    0.526316
# 1   HGNC:12994      ZNF202  HGNC:26144      PALB2    0.523810
# 2   HGNC:12962      TRIM26  HGNC:26144      PALB2    0.520000
# 2   HGNC:24575       GINS2  HGNC:25009      UBE2T    0.472222
# 3   HGNC:16122      FAM83D  HGNC:25009      UBE2T    0.465517
# 4    HGNC:9369       PRIM1  HGNC:25009      UBE2T    0.463768
# 3   HGNC:25714      CCDC51  HGNC:26144      PALB2    0.461538
# 5   HGNC:13026      ZNF232  HGNC:26144      PALB2    0.454545
# 4   HGNC:21948      ZNF746  HGNC:26144      PALB2    0.454545
# 6   HGNC:16192     SLC17A9  HGNC:26144      PALB2    0.450000
# 7   HGNC:18896    TMEM185B  HGNC:26144      PALB2    0.440000
# 8   HGNC:12993      ZNF200  HGNC:26144      PALB2    0.440000
# 5   HGNC:13584       FBXO5  HGNC:25009      UBE2T    0.438356
# 6   HGNC:14624       CDCA3  HGNC:25009      UBE2T    0.432836
# 7   HGNC:18043       MCM10  HGNC:25009      UBE2T    0.430556
# 8   HGNC:24304       NCAPG  HGNC:25009      UBE2T    0.428571
# 9   HGNC:24031       SPC25  HGNC:25009      UBE2T    0.426471
# 9   HGNC:12974     RNF113A  HGNC:26144      PALB2    0.423077
# 10  HGNC:16285      TRIM35  HGNC:26144      PALB2    0.421053
# 11  HGNC:13111       ZNF45  HGNC:26144      PALB2    0.416667
# 10   HGNC:1161       CEP55  HGNC:25009      UBE2T    0.415385
# 11  HGNC:13195       ZWINT  HGNC:25009      UBE2T    0.410959
# 12  HGNC:26877      CKAP2L  HGNC:25009      UBE2T    0.410714
# 0   HGNC:11629       TCF19   HGNC:3588      FANCG    0.410714
# 13  HGNC:31446      ZBTB34  HGNC:26144      PALB2    0.409091
# 13  HGNC:30288         DTL  HGNC:25009      UBE2T    0.409091
# 12   HGNC:2184        COIL  HGNC:26144      PALB2    0.409091
# 14  HGNC:14082        ANLN  HGNC:25009      UBE2T    0.402778
# 19  HGNC:30299       LRIF1  HGNC:26144      PALB2    0.400000
# 14  HGNC:33234       LIN37  HGNC:26144      PALB2    0.400000
# ..         ...         ...         ...        ...         ...
# 10  HGNC:19125        FGD4   HGNC:3582      FANCA    0.307692
# 9   HGNC:24573       NEIL3   HGNC:3582      FANCA    0.307692
# 15   HGNC:6598        LIG1   HGNC:3588      FANCG    0.307692
# 38  HGNC:20344        UBR7   HGNC:3586      FANCE    0.307692
# 37   HGNC:2034      CLDN12   HGNC:3586      FANCE    0.307692
# 18   HGNC:9862       RAP2B   HGNC:9820     RAD51C    0.306452
# 19   HGNC:9787      KIF20A   HGNC:9820     RAD51C    0.306122
# 12  HGNC:26877      CKAP2L   HGNC:3582      FANCA    0.306122
# 20  HGNC:25312     FAM198B   HGNC:9820     RAD51C    0.305556
# 17  HGNC:11188        SOS2  HGNC:23168      FANCM    0.305556
# 21  HGNC:14011        SMC2   HGNC:9820     RAD51C    0.304348
# 22  HGNC:30794       CEP57   HGNC:9820     RAD51C    0.304348
# 1   HGNC:24573       NEIL3   HGNC:3585     FANCD2    0.304348
# 18  HGNC:27614      ZNF763  HGNC:23168      FANCM    0.304348
# 42  HGNC:26531     CCDC138   HGNC:3586      FANCE    0.304348
# 39  HGNC:24972       HCFC2   HGNC:3586      FANCE    0.304348
# 19  HGNC:15861       DHX35  HGNC:23168      FANCM    0.304348
# 41  HGNC:13568      PGPEP1   HGNC:3586      FANCE    0.304348
# 40   HGNC:9310     PPP2R5B   HGNC:3586      FANCE    0.304348
# 43  HGNC:30545  CDKN2AIPNL   HGNC:3586      FANCE    0.304348
# 44  HGNC:24048     ARL6IP6   HGNC:3586      FANCE    0.304348
# 45  HGNC:30817       MRNIP   HGNC:3586      FANCE    0.304348
# 46  HGNC:30696       WDR36   HGNC:3586      FANCE    0.304348
# 23  HGNC:20392       SULF2   HGNC:9820     RAD51C    0.303371
# 2   HGNC:17255       KNTC1   HGNC:3585     FANCD2    0.303030
# 3   HGNC:12307      TRIP13   HGNC:3585     FANCD2    0.302632
# 16  HGNC:10879        STIL   HGNC:3588      FANCG    0.301887
# 24  HGNC:21488       CENPW   HGNC:9820     RAD51C    0.301587
# 25   HGNC:6392       KIF23   HGNC:9820     RAD51C    0.301205
# 4   HGNC:14629       CDCA8   HGNC:3585     FANCD2    0.301205
#
# [322 rows x 5 columns]
